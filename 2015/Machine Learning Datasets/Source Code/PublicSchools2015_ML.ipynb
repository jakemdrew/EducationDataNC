# %% [markdown]
# # Create Public School Machine Learning Datasets
# ** This program creates all the _ML datasets in the NCEA repository.**
# * This notebook reads each School Dataset file located at \EducationDataNC\ *schoolYear* \School Datasets\ as input data.
# * Different school years are processed by changing the *schoolYear* parameter.
# * Different input / output files are processed / created by changing the *inputFileName* paramter in the cell below.
# * While a single program is used to create all the _ML datasets, one program copy per dataset is maintained in the repositiory so the dataset specific tranformation reports may be reviewed.
#
# **Datasets ending in ML are preprocessed for Machine Learning and go through the following transformations: **
# 1. Missing student body racial compositions are imputed using district averages.
# 2. Columns that have the same value in every single row are deleted.
# 3. Columns that have a unique value in every single row (all values are different) are deleted.
# 4. Empty columns (all values are NA or NULL) are deleted.
# 5. Numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# 6. Remaining numeric, non-race columns with missing values are imputed / populated with 0.  In many cases, schools are not reporting values when they are zero. However, mean imputation or some other more sophisticated strategy might be considered here.
# 7. Categorical / text based columns with > *uniqueThreshold* unique values are deleted.
# 8. All remaining categorical / text based columns are one-hot encoded.  In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# 9. Duplicated or highly similar columns with > 95% correlation are delelted.

# %%
#import required Libraries
import pandas as pd
import numpy as np
import os
import string

#**********************************************************************************
# Set the following variables before running this code!!!
#**********************************************************************************
#All raw data files are processed for the year below
schoolYear = 2015

#Location where copies of the raw data files will be read in from csv files.
dataDir = 'C:/Users/Jake/Documents/GitHub/EducationDataNC/' + str(schoolYear) + '/School Datasets/'

#Name of the file to be processed
inputFileName = 'PublicSchools' + str(schoolYear)
#inputFileName = 'PublicHighSchools' + str(schoolYear)
#inputFileName = 'PublicMiddleSchools' + str(schoolYear)
#inputFileName = 'PublicElementarySchools' + str(schoolYear)

#Input file being transformed for machine learning 
inputFile = dataDir + inputFileName + '.csv'

#Location where the new school datasets will be created.
outputDir = 'C:/Users/Jake/Documents/GitHub/EducationDataNC/' + str(schoolYear) + '/Machine Learning Datasets/'

#Missing Data Threshold (Per Column)
missingThreshold = 0.60

#Unique Value Threshold (Per Column)
#Delete Columns >  uniqueThreshold unique values prior to one-hot encoding. 
#(each unique value becomes a new column during one-hot encoding)
uniqueThreshold = 25

#Read in the School Data File
schoolData = pd.read_csv(inputFile, low_memory=False, dtype={'unit_code': object})
print('*********Start: Beginning Column and Row Counts********************************************')
schoolData.info(verbose=False)

#Select only public schools as charter schools are missing data for many columns.
schoolData = schoolData[(schoolData['type_cd'] == 'P') & (schoolData['student_num'] > 0)]

print('\r\n*********After: Selecting Only Public School Campuses**********************************')
schoolData.info(verbose=False)

#Save primary key
unit_code = schoolData['unit_code']
#Convert zip code to string
schoolData['szip_ad'] = schoolData['szip_ad'].astype('object')
#Rename Lea_Name to District Name
schoolData.rename(columns={'Lea_Name': 'District Name'}, inplace=True)
# Out:
# *********Start: Beginning Column and Row Counts********************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2585 entries, 0 to 2584
# Columns: 1256 entries, vphone_ad to WhitePct
# dtypes: float64(1209), int64(3), object(44)
# memory usage: 24.8+ MB
#
# *********After: Selecting Only Public School Campuses**********************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2432 entries, 0 to 2584
# Columns: 1256 entries, vphone_ad to WhitePct
# dtypes: float64(1209), int64(3), object(44)
# memory usage: 23.3+ MB

# %% [markdown]
# # Prepare Consolidated Dataset for Machine Learning
# **Below we perform operations on the entire dataset to remove columns and update row values that could cause problems during machine learning.**

# %% [markdown]
# ## Student Body Racial Composition Features
# **Impute / update missing Student Body Racial Composition Fields using mean imputation.**
# * When there are no racial composition percentages for a particular school campus / unit_code, fill in the missing values

# %%
schoolData.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2432 entries, 0 to 2584
# Data columns (total 1256 columns):
# vphone_ad                                             object
# year                                                  int64
# unit_code                                             object
# street_ad                                             object
# scity_ad                                              object
# state_ad                                              object
# szip_ad                                               object
# type_cd                                               object
# closed_ind                                            float64
# new_ind                                               float64
# super_nm                                              object
# category_cd                                           object
# url_ad                                                object
# grade_range_cd                                        object
# calendar_type_txt                                     object
# sna_pgm_type_cd                                       object
# cover_letter_ad                                       object
# school_type_txt                                       object
# calendar_only_txt                                     object
# title1_type_cd                                        object
# clp_ind                                               object
# focus_clp_ind                                         object
# summer_program_ind                                    object
# asm_no_spg_ind                                        object
# no_data_spg_ind                                       object
# District Name                                         object
# School_Name                                           object
# State_Name                                            object
# esea_status                                           object
# student_num                                           float64
# lea_avg_student_num                                   float64
# st_avg_student_num                                    float64
# Grad_project_status                                   object
# stem                                                  float64
# url                                                   object
# 00_Size                                               float64
# 01_Size                                               float64
# 02_Size                                               float64
# 03_Size                                               float64
# 04_Size                                               float64
# 05_Size                                               float64
# 06_Size                                               float64
# 07_Size                                               float64
# 08_Size                                               float64
# Biology_Size                                          float64
# English II_Size                                       float64
# Math I_Size                                           float64
# total_expense_num                                     float64
# salary_expense_pct                                    float64
# benefits_expense_pct                                  float64
# services_expense_pct                                  float64
# supplies_expense_pct                                  float64
# instruct_equip_exp_pct                                float64
# other_expense_pct                                     float64
# federal_perpupil_num                                  float64
# local_perpupil_num                                    float64
# state_perpupil_num                                    float64
# lea_total_expense_num                                 float64
# lea_salary_expense_pct                                float64
# lea_benefits_expense_pct                              float64
# lea_services_expense_pct                              float64
# lea_supplies_expense_pct                              float64
# lea_instruct_equip_exp_pct                            float64
# lea_other_expense_pct                                 float64
# lea_federal_perpupil_num                              float64
# lea_local_perpupil_num                                float64
# lea_state_perpupil_num                                float64
# st_total_expense_num                                  float64
# st_salary_expense_pct                                 float64
# st_benefits_expense_pct                               float64
# st_services_expense_pct                               float64
# st_supplies_expense_pct                               float64
# st_instruct_equip_exp_pct                             float64
# st_other_expense_pct                                  float64
# st_federal_perpupil_num                               float64
# st_local_perpupil_num                                 float64
# st_state_perpupil_num                                 float64
# building_expense_pct                                  float64
# lea_building_expense_pct                              float64
# st_building_expense_pct                               float64
# LEA Name                                              object
# School Name                                           object
# SBE District                                          object
# SPG Grade                                             object
# SPG Score                                             float64
# Reading SPG Grade                                     object
# Reading  SPG Score                                    float64
# Math SPG Grade                                        object
# Math SPG Score                                        float64
# EVAAS Growth Status                                   object
# EVAAS Growth Score                                    float64
# Overall Achievement Score                             float64
# Read Score                                            float64
# Math Score                                            float64
# Science Score                                         float64
# Math I Score                                          float64
# English II Score                                      float64
# Biology Score                                         float64
# The ACT Score                                         float64
# ACT WorkKeys Score                                    float64
# Math Course Rigor Score                               float64
# Cohort Graduation Rate Standard Score                 float64
# State Gap Compared                                    object
# ACTCompositeScore_UNCMin_All                          float64
# ACTEnglish_ACTBenchmark_All                           float64
# ACTMath_ACTBenchmark_All                              float64
# ACTReading_ACTBenchmark_All                           float64
# ACTScience_ACTBenchmark_All                           float64
# ACTSubtests_BenchmarksMet_All                         float64
# ACTWorkKeys_SilverPlus_All                            float64
# ACTWriting_ACTBenchmark_All                           float64
# EOCBiology_CACR_All                                   float64
# EOCBiology_GLP_All                                    float64
# EOCEnglish2_CACR_All                                  float64
# EOCEnglish2_GLP_All                                   float64
# EOCMathI_CACR_All                                     float64
# EOCMathI_GLP_All                                      float64
# EOCSubjects_CACR_All                                  float64
# EOCSubjects_GLP_All                                   float64
# EOG/EOCSubjects_CACR_All                              float64
# EOG/EOCSubjects_GLP_All                               float64
# EOGGr3_CACR_All                                       float64
# EOGGr3_GLP_All                                        float64
# EOGGr4_CACR_All                                       float64
# EOGGr4_GLP_All                                        float64
# EOGGr5_CACR_All                                       float64
# EOGGr5_GLP_All                                        float64
# EOGGr6_CACR_All                                       float64
# EOGGr6_GLP_All                                        float64
# EOGGr7_CACR_All                                       float64
# EOGGr7_GLP_All                                        float64
# EOGGr8_CACR_All                                       float64
# EOGGr8_GLP_All                                        float64
# EOGMathGr3_CACR_All                                   float64
# EOGMathGr3_GLP_All                                    float64
# EOGMathGr3-8_CACR_All                                 float64
# EOGMathGr3-8_GLP_All                                  float64
# EOGMathGr4_CACR_All                                   float64
# EOGMathGr4_GLP_All                                    float64
# EOGMathGr5_CACR_All                                   float64
# EOGMathGr5_GLP_All                                    float64
# EOGMathGr6_CACR_All                                   float64
# EOGMathGr6_GLP_All                                    float64
# EOGMathGr7_CACR_All                                   float64
# EOGMathGr7_GLP_All                                    float64
# EOGMathGr8_CACR_All                                   float64
# EOGMathGr8_GLP_All                                    float64
# EOGReadingGr3_CACR_All                                float64
# EOGReadingGr3_GLP_All                                 float64
# EOGReadingGr3-8_CACR_All                              float64
# EOGReadingGr3-8_GLP_All                               float64
# EOGReadingGr4_CACR_All                                float64
# EOGReadingGr4_GLP_All                                 float64
# EOGReadingGr5_CACR_All                                float64
# EOGReadingGr5_GLP_All                                 float64
# EOGReadingGr6_CACR_All                                float64
# EOGReadingGr6_GLP_All                                 float64
# EOGReadingGr7_CACR_All                                float64
# EOGReadingGr7_GLP_All                                 float64
# EOGReadingGr8_CACR_All                                float64
# EOGReadingGr8_GLP_All                                 float64
# EOGScienceGr5_CACR_All                                float64
# EOGScienceGr5_GLP_All                                 float64
# EOGScienceGr5&8_CACR_All                              float64
# EOGScienceGr5&8_GLP_All                               float64
# EOGScienceGr8_CACR_All                                float64
# EOGScienceGr8_GLP_All                                 float64
# EOGSubjects_CACR_All                                  float64
# EOGSubjects_GLP_All                                   float64
# GraduationRate_4yr_All                                float64
# GraduationRate_5yr_All                                float64
# ACTCompositeScore_UNCMin_Female                       float64
# ACTEnglish_ACTBenchmark_Female                        float64
# ACTMath_ACTBenchmark_Female                           float64
# ACTReading_ACTBenchmark_Female                        float64
# ACTScience_ACTBenchmark_Female                        float64
# ACTSubtests_BenchmarksMet_Female                      float64
# ACTWorkKeys_SilverPlus_Female                         float64
# ACTWriting_ACTBenchmark_Female                        float64
# EOCBiology_CACR_Female                                float64
# EOCBiology_GLP_Female                                 float64
# EOCEnglish2_CACR_Female                               float64
# EOCEnglish2_GLP_Female                                float64
# EOCMathI_CACR_Female                                  float64
# EOCMathI_GLP_Female                                   float64
# EOCSubjects_CACR_Female                               float64
# EOCSubjects_GLP_Female                                float64
# EOG/EOCSubjects_CACR_Female                           float64
# EOG/EOCSubjects_GLP_Female                            float64
# EOGGr3_CACR_Female                                    float64
# EOGGr3_GLP_Female                                     float64
# EOGGr4_CACR_Female                                    float64
# EOGGr4_GLP_Female                                     float64
# EOGGr5_CACR_Female                                    float64
# EOGGr5_GLP_Female                                     float64
# EOGGr6_CACR_Female                                    float64
# EOGGr6_GLP_Female                                     float64
# EOGGr7_CACR_Female                                    float64
# EOGGr7_GLP_Female                                     float64
# EOGGr8_CACR_Female                                    float64
# EOGGr8_GLP_Female                                     float64
# EOGMathGr3_CACR_Female                                float64
# EOGMathGr3_GLP_Female                                 float64
# EOGMathGr3-8_CACR_Female                              float64
# EOGMathGr3-8_GLP_Female                               float64
# EOGMathGr4_CACR_Female                                float64
# EOGMathGr4_GLP_Female                                 float64
# EOGMathGr5_CACR_Female                                float64
# EOGMathGr5_GLP_Female                                 float64
# EOGMathGr6_CACR_Female                                float64
# EOGMathGr6_GLP_Female                                 float64
# EOGMathGr7_CACR_Female                                float64
# EOGMathGr7_GLP_Female                                 float64
# EOGMathGr8_CACR_Female                                float64
# EOGMathGr8_GLP_Female                                 float64
# EOGReadingGr3_CACR_Female                             float64
# EOGReadingGr3_GLP_Female                              float64
# EOGReadingGr3-8_CACR_Female                           float64
# EOGReadingGr3-8_GLP_Female                            float64
# EOGReadingGr4_CACR_Female                             float64
# EOGReadingGr4_GLP_Female                              float64
# EOGReadingGr5_CACR_Female                             float64
# EOGReadingGr5_GLP_Female                              float64
# EOGReadingGr6_CACR_Female                             float64
# EOGReadingGr6_GLP_Female                              float64
# EOGReadingGr7_CACR_Female                             float64
# EOGReadingGr7_GLP_Female                              float64
# EOGReadingGr8_CACR_Female                             float64
# EOGReadingGr8_GLP_Female                              float64
# EOGScienceGr5_CACR_Female                             float64
# EOGScienceGr5_GLP_Female                              float64
# EOGScienceGr5&8_CACR_Female                           float64
# EOGScienceGr5&8_GLP_Female                            float64
# EOGScienceGr8_CACR_Female                             float64
# EOGScienceGr8_GLP_Female                              float64
# EOGSubjects_CACR_Female                               float64
# EOGSubjects_GLP_Female                                float64
# GraduationRate_4yr_Female                             float64
# GraduationRate_5yr_Female                             float64
# ACTCompositeScore_UNCMin_Male                         float64
# ACTEnglish_ACTBenchmark_Male                          float64
# ACTMath_ACTBenchmark_Male                             float64
# ACTReading_ACTBenchmark_Male                          float64
# ACTScience_ACTBenchmark_Male                          float64
# ACTSubtests_BenchmarksMet_Male                        float64
# ACTWorkKeys_SilverPlus_Male                           float64
# ACTWriting_ACTBenchmark_Male                          float64
# EOCBiology_CACR_Male                                  float64
# EOCBiology_GLP_Male                                   float64
# EOCEnglish2_CACR_Male                                 float64
# EOCEnglish2_GLP_Male                                  float64
# EOCMathI_CACR_Male                                    float64
# EOCMathI_GLP_Male                                     float64
# EOCSubjects_CACR_Male                                 float64
# EOCSubjects_GLP_Male                                  float64
# EOG/EOCSubjects_CACR_Male                             float64
# EOG/EOCSubjects_GLP_Male                              float64
# EOGGr3_CACR_Male                                      float64
# EOGGr3_GLP_Male                                       float64
# EOGGr4_CACR_Male                                      float64
# EOGGr4_GLP_Male                                       float64
# EOGGr5_CACR_Male                                      float64
# EOGGr5_GLP_Male                                       float64
# EOGGr6_CACR_Male                                      float64
# EOGGr6_GLP_Male                                       float64
# EOGGr7_CACR_Male                                      float64
# EOGGr7_GLP_Male                                       float64
# EOGGr8_CACR_Male                                      float64
# EOGGr8_GLP_Male                                       float64
# EOGMathGr3_CACR_Male                                  float64
# EOGMathGr3_GLP_Male                                   float64
# EOGMathGr3-8_CACR_Male                                float64
# EOGMathGr3-8_GLP_Male                                 float64
# EOGMathGr4_CACR_Male                                  float64
# EOGMathGr4_GLP_Male                                   float64
# EOGMathGr5_CACR_Male                                  float64
# EOGMathGr5_GLP_Male                                   float64
# EOGMathGr6_CACR_Male                                  float64
# EOGMathGr6_GLP_Male                                   float64
# EOGMathGr7_CACR_Male                                  float64
# EOGMathGr7_GLP_Male                                   float64
# EOGMathGr8_CACR_Male                                  float64
# EOGMathGr8_GLP_Male                                   float64
# EOGReadingGr3_CACR_Male                               float64
# EOGReadingGr3_GLP_Male                                float64
# EOGReadingGr3-8_CACR_Male                             float64
# EOGReadingGr3-8_GLP_Male                              float64
# EOGReadingGr4_CACR_Male                               float64
# EOGReadingGr4_GLP_Male                                float64
# EOGReadingGr5_CACR_Male                               float64
# EOGReadingGr5_GLP_Male                                float64
# EOGReadingGr6_CACR_Male                               float64
# EOGReadingGr6_GLP_Male                                float64
# EOGReadingGr7_CACR_Male                               float64
# EOGReadingGr7_GLP_Male                                float64
# EOGReadingGr8_CACR_Male                               float64
# EOGReadingGr8_GLP_Male                                float64
# EOGScienceGr5_CACR_Male                               float64
# EOGScienceGr5_GLP_Male                                float64
# EOGScienceGr5&8_CACR_Male                             float64
# EOGScienceGr5&8_GLP_Male                              float64
# EOGScienceGr8_CACR_Male                               float64
# EOGScienceGr8_GLP_Male                                float64
# EOGSubjects_CACR_Male                                 float64
# EOGSubjects_GLP_Male                                  float64
# GraduationRate_4yr_Male                               float64
# GraduationRate_5yr_Male                               float64
# ACTCompositeScore_UNCMin_AmericanIndian               float64
# ACTEnglish_ACTBenchmark_AmericanIndian                float64
# ACTMath_ACTBenchmark_AmericanIndian                   float64
# ACTReading_ACTBenchmark_AmericanIndian                float64
# ACTScience_ACTBenchmark_AmericanIndian                float64
# ACTSubtests_BenchmarksMet_AmericanIndian              float64
# ACTWorkKeys_SilverPlus_AmericanIndian                 float64
# ACTWriting_ACTBenchmark_AmericanIndian                float64
# EOCBiology_CACR_AmericanIndian                        float64
# EOCBiology_GLP_AmericanIndian                         float64
# EOCEnglish2_CACR_AmericanIndian                       float64
# EOCEnglish2_GLP_AmericanIndian                        float64
# EOCMathI_CACR_AmericanIndian                          float64
# EOCMathI_GLP_AmericanIndian                           float64
# EOCSubjects_CACR_AmericanIndian                       float64
# EOCSubjects_GLP_AmericanIndian                        float64
# EOG/EOCSubjects_CACR_AmericanIndian                   float64
# EOG/EOCSubjects_GLP_AmericanIndian                    float64
# EOGGr3_CACR_AmericanIndian                            float64
# EOGGr3_GLP_AmericanIndian                             float64
# EOGGr4_CACR_AmericanIndian                            float64
# EOGGr4_GLP_AmericanIndian                             float64
# EOGGr5_CACR_AmericanIndian                            float64
# EOGGr5_GLP_AmericanIndian                             float64
# EOGGr6_CACR_AmericanIndian                            float64
# EOGGr6_GLP_AmericanIndian                             float64
# EOGGr7_CACR_AmericanIndian                            float64
# EOGGr7_GLP_AmericanIndian                             float64
# EOGGr8_CACR_AmericanIndian                            float64
# EOGGr8_GLP_AmericanIndian                             float64
# EOGMathGr3_CACR_AmericanIndian                        float64
# EOGMathGr3_GLP_AmericanIndian                         float64
# EOGMathGr3-8_CACR_AmericanIndian                      float64
# EOGMathGr3-8_GLP_AmericanIndian                       float64
# EOGMathGr4_CACR_AmericanIndian                        float64
# EOGMathGr4_GLP_AmericanIndian                         float64
# EOGMathGr5_CACR_AmericanIndian                        float64
# EOGMathGr5_GLP_AmericanIndian                         float64
# EOGMathGr6_CACR_AmericanIndian                        float64
# EOGMathGr6_GLP_AmericanIndian                         float64
# EOGMathGr7_CACR_AmericanIndian                        float64
# EOGMathGr7_GLP_AmericanIndian                         float64
# EOGMathGr8_CACR_AmericanIndian                        float64
# EOGMathGr8_GLP_AmericanIndian                         float64
# EOGReadingGr3_CACR_AmericanIndian                     float64
# EOGReadingGr3_GLP_AmericanIndian                      float64
# EOGReadingGr3-8_CACR_AmericanIndian                   float64
# EOGReadingGr3-8_GLP_AmericanIndian                    float64
# EOGReadingGr4_CACR_AmericanIndian                     float64
# EOGReadingGr4_GLP_AmericanIndian                      float64
# EOGReadingGr5_CACR_AmericanIndian                     float64
# EOGReadingGr5_GLP_AmericanIndian                      float64
# EOGReadingGr6_CACR_AmericanIndian                     float64
# EOGReadingGr6_GLP_AmericanIndian                      float64
# EOGReadingGr7_CACR_AmericanIndian                     float64
# EOGReadingGr7_GLP_AmericanIndian                      float64
# EOGReadingGr8_CACR_AmericanIndian                     float64
# EOGReadingGr8_GLP_AmericanIndian                      float64
# EOGScienceGr5_CACR_AmericanIndian                     float64
# EOGScienceGr5_GLP_AmericanIndian                      float64
# EOGScienceGr5&8_CACR_AmericanIndian                   float64
# EOGScienceGr5&8_GLP_AmericanIndian                    float64
# EOGScienceGr8_CACR_AmericanIndian                     float64
# EOGScienceGr8_GLP_AmericanIndian                      float64
# EOGSubjects_CACR_AmericanIndian                       float64
# EOGSubjects_GLP_AmericanIndian                        float64
# GraduationRate_4yr_AmericanIndian                     float64
# GraduationRate_5yr_AmericanIndian                     float64
# ACTCompositeScore_UNCMin_Asian                        float64
# ACTEnglish_ACTBenchmark_Asian                         float64
# ACTMath_ACTBenchmark_Asian                            float64
# ACTReading_ACTBenchmark_Asian                         float64
# ACTScience_ACTBenchmark_Asian                         float64
# ACTSubtests_BenchmarksMet_Asian                       float64
# ACTWorkKeys_SilverPlus_Asian                          float64
# ACTWriting_ACTBenchmark_Asian                         float64
# EOCBiology_CACR_Asian                                 float64
# EOCBiology_GLP_Asian                                  float64
# EOCEnglish2_CACR_Asian                                float64
# EOCEnglish2_GLP_Asian                                 float64
# EOCMathI_CACR_Asian                                   float64
# EOCMathI_GLP_Asian                                    float64
# EOCSubjects_CACR_Asian                                float64
# EOCSubjects_GLP_Asian                                 float64
# EOG/EOCSubjects_CACR_Asian                            float64
# EOG/EOCSubjects_GLP_Asian                             float64
# EOGGr3_CACR_Asian                                     float64
# EOGGr3_GLP_Asian                                      float64
# EOGGr4_CACR_Asian                                     float64
# EOGGr4_GLP_Asian                                      float64
# EOGGr5_CACR_Asian                                     float64
# EOGGr5_GLP_Asian                                      float64
# EOGGr6_CACR_Asian                                     float64
# EOGGr6_GLP_Asian                                      float64
# EOGGr7_CACR_Asian                                     float64
# EOGGr7_GLP_Asian                                      float64
# EOGGr8_CACR_Asian                                     float64
# EOGGr8_GLP_Asian                                      float64
# EOGMathGr3_CACR_Asian                                 float64
# EOGMathGr3_GLP_Asian                                  float64
# EOGMathGr3-8_CACR_Asian                               float64
# EOGMathGr3-8_GLP_Asian                                float64
# EOGMathGr4_CACR_Asian                                 float64
# EOGMathGr4_GLP_Asian                                  float64
# EOGMathGr5_CACR_Asian                                 float64
# EOGMathGr5_GLP_Asian                                  float64
# EOGMathGr6_CACR_Asian                                 float64
# EOGMathGr6_GLP_Asian                                  float64
# EOGMathGr7_CACR_Asian                                 float64
# EOGMathGr7_GLP_Asian                                  float64
# EOGMathGr8_CACR_Asian                                 float64
# EOGMathGr8_GLP_Asian                                  float64
# EOGReadingGr3_CACR_Asian                              float64
# EOGReadingGr3_GLP_Asian                               float64
# EOGReadingGr3-8_CACR_Asian                            float64
# EOGReadingGr3-8_GLP_Asian                             float64
# EOGReadingGr4_CACR_Asian                              float64
# EOGReadingGr4_GLP_Asian                               float64
# EOGReadingGr5_CACR_Asian                              float64
# EOGReadingGr5_GLP_Asian                               float64
# EOGReadingGr6_CACR_Asian                              float64
# EOGReadingGr6_GLP_Asian                               float64
# EOGReadingGr7_CACR_Asian                              float64
# EOGReadingGr7_GLP_Asian                               float64
# EOGReadingGr8_CACR_Asian                              float64
# EOGReadingGr8_GLP_Asian                               float64
# EOGScienceGr5_CACR_Asian                              float64
# EOGScienceGr5_GLP_Asian                               float64
# EOGScienceGr5&8_CACR_Asian                            float64
# EOGScienceGr5&8_GLP_Asian                             float64
# EOGScienceGr8_CACR_Asian                              float64
# EOGScienceGr8_GLP_Asian                               float64
# EOGSubjects_CACR_Asian                                float64
# EOGSubjects_GLP_Asian                                 float64
# GraduationRate_4yr_Asian                              float64
# GraduationRate_5yr_Asian                              float64
# ACTCompositeScore_UNCMin_Black                        float64
# ACTEnglish_ACTBenchmark_Black                         float64
# ACTMath_ACTBenchmark_Black                            float64
# ACTReading_ACTBenchmark_Black                         float64
# ACTScience_ACTBenchmark_Black                         float64
# ACTSubtests_BenchmarksMet_Black                       float64
# ACTWorkKeys_SilverPlus_Black                          float64
# ACTWriting_ACTBenchmark_Black                         float64
# EOCBiology_CACR_Black                                 float64
# EOCBiology_GLP_Black                                  float64
# EOCEnglish2_CACR_Black                                float64
# EOCEnglish2_GLP_Black                                 float64
# EOCMathI_CACR_Black                                   float64
# EOCMathI_GLP_Black                                    float64
# EOCSubjects_CACR_Black                                float64
# EOCSubjects_GLP_Black                                 float64
# EOG/EOCSubjects_CACR_Black                            float64
# EOG/EOCSubjects_GLP_Black                             float64
# EOGGr3_CACR_Black                                     float64
# EOGGr3_GLP_Black                                      float64
# EOGGr4_CACR_Black                                     float64
# EOGGr4_GLP_Black                                      float64
# EOGGr5_CACR_Black                                     float64
# EOGGr5_GLP_Black                                      float64
# EOGGr6_CACR_Black                                     float64
# EOGGr6_GLP_Black                                      float64
# EOGGr7_CACR_Black                                     float64
# EOGGr7_GLP_Black                                      float64
# EOGGr8_CACR_Black                                     float64
# EOGGr8_GLP_Black                                      float64
# EOGMathGr3_CACR_Black                                 float64
# EOGMathGr3_GLP_Black                                  float64
# EOGMathGr3-8_CACR_Black                               float64
# EOGMathGr3-8_GLP_Black                                float64
# EOGMathGr4_CACR_Black                                 float64
# EOGMathGr4_GLP_Black                                  float64
# EOGMathGr5_CACR_Black                                 float64
# EOGMathGr5_GLP_Black                                  float64
# EOGMathGr6_CACR_Black                                 float64
# EOGMathGr6_GLP_Black                                  float64
# EOGMathGr7_CACR_Black                                 float64
# EOGMathGr7_GLP_Black                                  float64
# EOGMathGr8_CACR_Black                                 float64
# EOGMathGr8_GLP_Black                                  float64
# EOGReadingGr3_CACR_Black                              float64
# EOGReadingGr3_GLP_Black                               float64
# EOGReadingGr3-8_CACR_Black                            float64
# EOGReadingGr3-8_GLP_Black                             float64
# EOGReadingGr4_CACR_Black                              float64
# EOGReadingGr4_GLP_Black                               float64
# EOGReadingGr5_CACR_Black                              float64
# EOGReadingGr5_GLP_Black                               float64
# EOGReadingGr6_CACR_Black                              float64
# EOGReadingGr6_GLP_Black                               float64
# EOGReadingGr7_CACR_Black                              float64
# EOGReadingGr7_GLP_Black                               float64
# EOGReadingGr8_CACR_Black                              float64
# EOGReadingGr8_GLP_Black                               float64
# EOGScienceGr5_CACR_Black                              float64
# EOGScienceGr5_GLP_Black                               float64
# EOGScienceGr5&8_CACR_Black                            float64
# EOGScienceGr5&8_GLP_Black                             float64
# EOGScienceGr8_CACR_Black                              float64
# EOGScienceGr8_GLP_Black                               float64
# EOGSubjects_CACR_Black                                float64
# EOGSubjects_GLP_Black                                 float64
# GraduationRate_4yr_Black                              float64
# GraduationRate_5yr_Black                              float64
# ACTCompositeScore_UNCMin_Hispanic                     float64
# ACTEnglish_ACTBenchmark_Hispanic                      float64
# ACTMath_ACTBenchmark_Hispanic                         float64
# ACTReading_ACTBenchmark_Hispanic                      float64
# ACTScience_ACTBenchmark_Hispanic                      float64
# ACTSubtests_BenchmarksMet_Hispanic                    float64
# ACTWorkKeys_SilverPlus_Hispanic                       float64
# ACTWriting_ACTBenchmark_Hispanic                      float64
# EOCBiology_CACR_Hispanic                              float64
# EOCBiology_GLP_Hispanic                               float64
# EOCEnglish2_CACR_Hispanic                             float64
# EOCEnglish2_GLP_Hispanic                              float64
# EOCMathI_CACR_Hispanic                                float64
# EOCMathI_GLP_Hispanic                                 float64
# EOCSubjects_CACR_Hispanic                             float64
# EOCSubjects_GLP_Hispanic                              float64
# EOG/EOCSubjects_CACR_Hispanic                         float64
# EOG/EOCSubjects_GLP_Hispanic                          float64
# EOGGr3_CACR_Hispanic                                  float64
# EOGGr3_GLP_Hispanic                                   float64
# EOGGr4_CACR_Hispanic                                  float64
# EOGGr4_GLP_Hispanic                                   float64
# EOGGr5_CACR_Hispanic                                  float64
# EOGGr5_GLP_Hispanic                                   float64
# EOGGr6_CACR_Hispanic                                  float64
# EOGGr6_GLP_Hispanic                                   float64
# EOGGr7_CACR_Hispanic                                  float64
# EOGGr7_GLP_Hispanic                                   float64
# EOGGr8_CACR_Hispanic                                  float64
# EOGGr8_GLP_Hispanic                                   float64
# EOGMathGr3_CACR_Hispanic                              float64
# EOGMathGr3_GLP_Hispanic                               float64
# EOGMathGr3-8_CACR_Hispanic                            float64
# EOGMathGr3-8_GLP_Hispanic                             float64
# EOGMathGr4_CACR_Hispanic                              float64
# EOGMathGr4_GLP_Hispanic                               float64
# EOGMathGr5_CACR_Hispanic                              float64
# EOGMathGr5_GLP_Hispanic                               float64
# EOGMathGr6_CACR_Hispanic                              float64
# EOGMathGr6_GLP_Hispanic                               float64
# EOGMathGr7_CACR_Hispanic                              float64
# EOGMathGr7_GLP_Hispanic                               float64
# EOGMathGr8_CACR_Hispanic                              float64
# EOGMathGr8_GLP_Hispanic                               float64
# EOGReadingGr3_CACR_Hispanic                           float64
# EOGReadingGr3_GLP_Hispanic                            float64
# EOGReadingGr3-8_CACR_Hispanic                         float64
# EOGReadingGr3-8_GLP_Hispanic                          float64
# EOGReadingGr4_CACR_Hispanic                           float64
# EOGReadingGr4_GLP_Hispanic                            float64
# EOGReadingGr5_CACR_Hispanic                           float64
# EOGReadingGr5_GLP_Hispanic                            float64
# EOGReadingGr6_CACR_Hispanic                           float64
# EOGReadingGr6_GLP_Hispanic                            float64
# EOGReadingGr7_CACR_Hispanic                           float64
# EOGReadingGr7_GLP_Hispanic                            float64
# EOGReadingGr8_CACR_Hispanic                           float64
# EOGReadingGr8_GLP_Hispanic                            float64
# EOGScienceGr5_CACR_Hispanic                           float64
# EOGScienceGr5_GLP_Hispanic                            float64
# EOGScienceGr5&8_CACR_Hispanic                         float64
# EOGScienceGr5&8_GLP_Hispanic                          float64
# EOGScienceGr8_CACR_Hispanic                           float64
# EOGScienceGr8_GLP_Hispanic                            float64
# EOGSubjects_CACR_Hispanic                             float64
# EOGSubjects_GLP_Hispanic                              float64
# GraduationRate_4yr_Hispanic                           float64
# GraduationRate_5yr_Hispanic                           float64
# ACTCompositeScore_UNCMin_TwoorMoreRaces               float64
# ACTEnglish_ACTBenchmark_TwoorMoreRaces                float64
# ACTMath_ACTBenchmark_TwoorMoreRaces                   float64
# ACTReading_ACTBenchmark_TwoorMoreRaces                float64
# ACTScience_ACTBenchmark_TwoorMoreRaces                float64
# ACTSubtests_BenchmarksMet_TwoorMoreRaces              float64
# ACTWorkKeys_SilverPlus_TwoorMoreRaces                 float64
# ACTWriting_ACTBenchmark_TwoorMoreRaces                float64
# EOCBiology_CACR_TwoorMoreRaces                        float64
# EOCBiology_GLP_TwoorMoreRaces                         float64
# EOCEnglish2_CACR_TwoorMoreRaces                       float64
# EOCEnglish2_GLP_TwoorMoreRaces                        float64
# EOCMathI_CACR_TwoorMoreRaces                          float64
# EOCMathI_GLP_TwoorMoreRaces                           float64
# EOCSubjects_CACR_TwoorMoreRaces                       float64
# EOCSubjects_GLP_TwoorMoreRaces                        float64
# EOG/EOCSubjects_CACR_TwoorMoreRaces                   float64
# EOG/EOCSubjects_GLP_TwoorMoreRaces                    float64
# EOGGr3_CACR_TwoorMoreRaces                            float64
# EOGGr3_GLP_TwoorMoreRaces                             float64
# EOGGr4_CACR_TwoorMoreRaces                            float64
# EOGGr4_GLP_TwoorMoreRaces                             float64
# EOGGr5_CACR_TwoorMoreRaces                            float64
# EOGGr5_GLP_TwoorMoreRaces                             float64
# EOGGr6_CACR_TwoorMoreRaces                            float64
# EOGGr6_GLP_TwoorMoreRaces                             float64
# EOGGr7_CACR_TwoorMoreRaces                            float64
# EOGGr7_GLP_TwoorMoreRaces                             float64
# EOGGr8_CACR_TwoorMoreRaces                            float64
# EOGGr8_GLP_TwoorMoreRaces                             float64
# EOGMathGr3_CACR_TwoorMoreRaces                        float64
# EOGMathGr3_GLP_TwoorMoreRaces                         float64
# EOGMathGr3-8_CACR_TwoorMoreRaces                      float64
# EOGMathGr3-8_GLP_TwoorMoreRaces                       float64
# EOGMathGr4_CACR_TwoorMoreRaces                        float64
# EOGMathGr4_GLP_TwoorMoreRaces                         float64
# EOGMathGr5_CACR_TwoorMoreRaces                        float64
# EOGMathGr5_GLP_TwoorMoreRaces                         float64
# EOGMathGr6_CACR_TwoorMoreRaces                        float64
# EOGMathGr6_GLP_TwoorMoreRaces                         float64
# EOGMathGr7_CACR_TwoorMoreRaces                        float64
# EOGMathGr7_GLP_TwoorMoreRaces                         float64
# EOGMathGr8_CACR_TwoorMoreRaces                        float64
# EOGMathGr8_GLP_TwoorMoreRaces                         float64
# EOGReadingGr3_CACR_TwoorMoreRaces                     float64
# EOGReadingGr3_GLP_TwoorMoreRaces                      float64
# EOGReadingGr3-8_CACR_TwoorMoreRaces                   float64
# EOGReadingGr3-8_GLP_TwoorMoreRaces                    float64
# EOGReadingGr4_CACR_TwoorMoreRaces                     float64
# EOGReadingGr4_GLP_TwoorMoreRaces                      float64
# EOGReadingGr5_CACR_TwoorMoreRaces                     float64
# EOGReadingGr5_GLP_TwoorMoreRaces                      float64
# EOGReadingGr6_CACR_TwoorMoreRaces                     float64
# EOGReadingGr6_GLP_TwoorMoreRaces                      float64
# EOGReadingGr7_CACR_TwoorMoreRaces                     float64
# EOGReadingGr7_GLP_TwoorMoreRaces                      float64
# EOGReadingGr8_CACR_TwoorMoreRaces                     float64
# EOGReadingGr8_GLP_TwoorMoreRaces                      float64
# EOGScienceGr5_CACR_TwoorMoreRaces                     float64
# EOGScienceGr5_GLP_TwoorMoreRaces                      float64
# EOGScienceGr5&8_CACR_TwoorMoreRaces                   float64
# EOGScienceGr5&8_GLP_TwoorMoreRaces                    float64
# EOGScienceGr8_CACR_TwoorMoreRaces                     float64
# EOGScienceGr8_GLP_TwoorMoreRaces                      float64
# EOGSubjects_CACR_TwoorMoreRaces                       float64
# EOGSubjects_GLP_TwoorMoreRaces                        float64
# GraduationRate_4yr_TwoorMoreRaces                     float64
# GraduationRate_5yr_TwoorMoreRaces                     float64
# ACTCompositeScore_UNCMin_White                        float64
# ACTEnglish_ACTBenchmark_White                         float64
# ACTMath_ACTBenchmark_White                            float64
# ACTReading_ACTBenchmark_White                         float64
# ACTScience_ACTBenchmark_White                         float64
# ACTSubtests_BenchmarksMet_White                       float64
# ACTWorkKeys_SilverPlus_White                          float64
# ACTWriting_ACTBenchmark_White                         float64
# EOCBiology_CACR_White                                 float64
# EOCBiology_GLP_White                                  float64
# EOCEnglish2_CACR_White                                float64
# EOCEnglish2_GLP_White                                 float64
# EOCMathI_CACR_White                                   float64
# EOCMathI_GLP_White                                    float64
# EOCSubjects_CACR_White                                float64
# EOCSubjects_GLP_White                                 float64
# EOG/EOCSubjects_CACR_White                            float64
# EOG/EOCSubjects_GLP_White                             float64
# EOGGr3_CACR_White                                     float64
# EOGGr3_GLP_White                                      float64
# EOGGr4_CACR_White                                     float64
# EOGGr4_GLP_White                                      float64
# EOGGr5_CACR_White                                     float64
# EOGGr5_GLP_White                                      float64
# EOGGr6_CACR_White                                     float64
# EOGGr6_GLP_White                                      float64
# EOGGr7_CACR_White                                     float64
# EOGGr7_GLP_White                                      float64
# EOGGr8_CACR_White                                     float64
# EOGGr8_GLP_White                                      float64
# EOGMathGr3_CACR_White                                 float64
# EOGMathGr3_GLP_White                                  float64
# EOGMathGr3-8_CACR_White                               float64
# EOGMathGr3-8_GLP_White                                float64
# EOGMathGr4_CACR_White                                 float64
# EOGMathGr4_GLP_White                                  float64
# EOGMathGr5_CACR_White                                 float64
# EOGMathGr5_GLP_White                                  float64
# EOGMathGr6_CACR_White                                 float64
# EOGMathGr6_GLP_White                                  float64
# EOGMathGr7_CACR_White                                 float64
# EOGMathGr7_GLP_White                                  float64
# EOGMathGr8_CACR_White                                 float64
# EOGMathGr8_GLP_White                                  float64
# EOGReadingGr3_CACR_White                              float64
# EOGReadingGr3_GLP_White                               float64
# EOGReadingGr3-8_CACR_White                            float64
# EOGReadingGr3-8_GLP_White                             float64
# EOGReadingGr4_CACR_White                              float64
# EOGReadingGr4_GLP_White                               float64
# EOGReadingGr5_CACR_White                              float64
# EOGReadingGr5_GLP_White                               float64
# EOGReadingGr6_CACR_White                              float64
# EOGReadingGr6_GLP_White                               float64
# EOGReadingGr7_CACR_White                              float64
# EOGReadingGr7_GLP_White                               float64
# EOGReadingGr8_CACR_White                              float64
# EOGReadingGr8_GLP_White                               float64
# EOGScienceGr5_CACR_White                              float64
# EOGScienceGr5_GLP_White                               float64
# EOGScienceGr5&8_CACR_White                            float64
# EOGScienceGr5&8_GLP_White                             float64
# EOGScienceGr8_CACR_White                              float64
# EOGScienceGr8_GLP_White                               float64
# EOGSubjects_CACR_White                                float64
# EOGSubjects_GLP_White                                 float64
# GraduationRate_4yr_White                              float64
# GraduationRate_5yr_White                              float64
# ACTCompositeScore_UNCMin_EDS                          float64
# ACTEnglish_ACTBenchmark_EDS                           float64
# ACTMath_ACTBenchmark_EDS                              float64
# ACTReading_ACTBenchmark_EDS                           float64
# ACTScience_ACTBenchmark_EDS                           float64
# ACTSubtests_BenchmarksMet_EDS                         float64
# ACTWorkKeys_SilverPlus_EDS                            float64
# ACTWriting_ACTBenchmark_EDS                           float64
# EOCBiology_CACR_EDS                                   float64
# EOCBiology_GLP_EDS                                    float64
# EOCEnglish2_CACR_EDS                                  float64
# EOCEnglish2_GLP_EDS                                   float64
# EOCMathI_CACR_EDS                                     float64
# EOCMathI_GLP_EDS                                      float64
# EOCSubjects_CACR_EDS                                  float64
# EOCSubjects_GLP_EDS                                   float64
# EOG/EOCSubjects_CACR_EDS                              float64
# EOG/EOCSubjects_GLP_EDS                               float64
# EOGGr3_CACR_EDS                                       float64
# EOGGr3_GLP_EDS                                        float64
# EOGGr4_CACR_EDS                                       float64
# EOGGr4_GLP_EDS                                        float64
# EOGGr5_CACR_EDS                                       float64
# EOGGr5_GLP_EDS                                        float64
# EOGGr6_CACR_EDS                                       float64
# EOGGr6_GLP_EDS                                        float64
# EOGGr7_CACR_EDS                                       float64
# EOGGr7_GLP_EDS                                        float64
# EOGGr8_CACR_EDS                                       float64
# EOGGr8_GLP_EDS                                        float64
# EOGMathGr3_CACR_EDS                                   float64
# EOGMathGr3_GLP_EDS                                    float64
# EOGMathGr3-8_CACR_EDS                                 float64
# EOGMathGr3-8_GLP_EDS                                  float64
# EOGMathGr4_CACR_EDS                                   float64
# EOGMathGr4_GLP_EDS                                    float64
# EOGMathGr5_CACR_EDS                                   float64
# EOGMathGr5_GLP_EDS                                    float64
# EOGMathGr6_CACR_EDS                                   float64
# EOGMathGr6_GLP_EDS                                    float64
# EOGMathGr7_CACR_EDS                                   float64
# EOGMathGr7_GLP_EDS                                    float64
# EOGMathGr8_CACR_EDS                                   float64
# EOGMathGr8_GLP_EDS                                    float64
# EOGReadingGr3_CACR_EDS                                float64
# EOGReadingGr3_GLP_EDS                                 float64
# EOGReadingGr3-8_CACR_EDS                              float64
# EOGReadingGr3-8_GLP_EDS                               float64
# EOGReadingGr4_CACR_EDS                                float64
# EOGReadingGr4_GLP_EDS                                 float64
# EOGReadingGr5_CACR_EDS                                float64
# EOGReadingGr5_GLP_EDS                                 float64
# EOGReadingGr6_CACR_EDS                                float64
# EOGReadingGr6_GLP_EDS                                 float64
# EOGReadingGr7_CACR_EDS                                float64
# EOGReadingGr7_GLP_EDS                                 float64
# EOGReadingGr8_CACR_EDS                                float64
# EOGReadingGr8_GLP_EDS                                 float64
# ...
# CurrentYearEOC_pTarget_PctMet                         float64
# MathGr10_pTarget_PctMet                               float64
# MathGr3-8_pTarget_PctMet                              float64
# ReadingGr10_pTarget_PctMet                            float64
# ReadingGr3-8_pTarget_PctMet                           float64
# SciGr11_pTarget_PctMet                                float64
# SciGr5&8_pTarget_PctMet                               float64
# TotalTargets_pTarget_PctMet                           float64
# Category_Cd                                           object
# sat_avg_score_num                                     float64
# lea_sat_avg_score_num                                 float64
# st_sat_avg_score_num                                  float64
# nat_sat_avg_score_num                                 float64
# sat_participation_pct                                 float64
# lea_sat_participation_pct                             float64
# st_sat_participation_pct                              float64
# nat_sat_participation_pct                             float64
# esea_attendance                                       object
# lea_esea_attendance                                   object
# ap_participation_pct                                  float64
# lea_ap_participation_pct                              float64
# st_ap_participation_pct                               float64
# ap_pct_3_or_above                                     float64
# lea_ap_pct_3_or_above                                 float64
# st_ap_pct_3_or_above                                  float64
# ib_participation_pct                                  float64
# lea_ib_participation_pct                              float64
# st_ib_participation_pct                               float64
# ib_pct_4_or_above                                     float64
# lea_ib_pct_4_or_above                                 float64
# st_ib_pct_4_or_above                                  float64
# total_specialized_courses                             float64
# ap_ib_courses                                         float64
# cte_courses                                           float64
# univ_college_courses                                  float64
# lea_total_specialized_courses                         float64
# lea_ap_ib_courses                                     float64
# lea_cte_courses                                       float64
# lea_univ_college_courses                              float64
# st_total_specialized_courses                          float64
# st_ap_ib_courses                                      float64
# st_cte_courses                                        float64
# st_univ_college_courses                               float64
# ALL_All Students (Total or Subtotal_ENROLL_sch_pct    float64
# ECODIS_Economically Disadvantaged_ENROLL_sch_pct      float64
# F_Female_ENROLL_sch_pct                               float64
# LEP_Limited English Proficiency_ENROLL_sch_pct        float64
# M_Male_ENROLL_sch_pct                                 float64
# MA_Asian_ENROLL_sch_pct                               float64
# MAN_American Indian_ENROLL_sch_pct                    float64
# MB_Black_ENROLL_sch_pct                               float64
# MHL_Hispanic_ENROLL_sch_pct                           float64
# MM_Multiracial_ENROLL_sch_pct                         float64
# MNP_Pacific Islander_ENROLL_sch_pct                   float64
# MW_White_ENROLL_sch_pct                               float64
# WDIS_Students With Disabilities_ENROLL_sch_pct        float64
# avg_daily_attend_pct                                  float64
# crime_per_c_num                                       float64
# short_susp_per_c_num                                  float64
# long_susp_per_c_num                                   float64
# expelled_per_c_num                                    float64
# ttl_crimes_num                                        float64
# stud_internet_comp_num                                float64
# lea_avg_daily_attend_pct                              float64
# lea_crime_per_c_num                                   float64
# lea_short_susp_per_c_num                              float64
# lea_long_susp_per_c_num                               float64
# lea_expelled_per_c_num                                float64
# lea_stud_internet_comp_num                            float64
# st_avg_daily_attend_pct                               float64
# st_crime_per_c_num                                    float64
# st_short_susp_per_c_num                               float64
# st_long_susp_per_c_num                                float64
# st_expelled_per_c_num                                 float64
# st_stud_internet_comp_num                             float64
# digital_media_pct                                     float64
# Byod                                                  object
# grades_BYOD                                           object
# avg_age_media_collection                              object
# _1_to_1_access                                        object
# books_per_student                                     float64
# grades_1_to_1_access                                  object
# lea_avg_age_media_collection                          object
# lea_books_per_student                                 float64
# st_avg_age_media_collection                           float64
# st_books_per_student                                  float64
# wap_num                                               float64
# wap_per_classroom                                     float64
# lea_wap_num                                           float64
# lea_wap_per_classroom                                 float64
# st_wap_num                                            float64
# st_wap_per_classroom                                  float64
# SRC_devices_sent_home                                 float64
# SRC_Grades_Devices_Sent_Home                          float64
# total_class_teacher_num                               int64
# total_nbpts_num                                       int64
# prin_other_pct                                        float64
# prinyrs_0thru3_pct                                    float64
# prinyrs_4thru10_pct                                   float64
# prinyrs_11plus_pct                                    float64
# prin_advance_dgr_pct                                  float64
# _1yr_prin_trnovr_pct                                  float64
# prin_male_pct                                         float64
# prin_female_pct                                       float64
# prin_black_pct                                        float64
# prin_white_pct                                        float64
# flicensed_teach_pct                                   float64
# tchyrs_0thru3_pct                                     float64
# tchyrs_4thru10_pct                                    float64
# tchyrs_11plus_pct                                     float64
# class_teach_num                                       float64
# nbpts_num                                             float64
# advance_dgr_pct                                       float64
# _1yr_tchr_trnovr_pct                                  float64
# emer_prov_teach_pct                                   float64
# lateral_teach_pct                                     float64
# highqual_class_pct                                    float64
# lea_flicensed_teach_pct                               float64
# lea_tchyrs_0thru3_pct                                 float64
# lea_tchyrs_4thru10_pct                                float64
# lea_tchyrs_11plus_pct                                 float64
# lea_class_teach_num                                   float64
# lea_nbpts_num                                         float64
# lea_advance_dgr_pct                                   float64
# lea_1yr_tchr_trnovr_pct                               float64
# lea_emer_prov_teach_pct                               float64
# lea_lateral_teach_pct                                 float64
# lea_highqual_class_pct                                float64
# lea_highqual_class_hp_pct                             float64
# lea_highqual_class_lp_pct                             float64
# lea_highqual_class_all_pct                            float64
# lea_not_highqual_class_hp_pct                         float64
# lea_not_highqual_class_lp_pct                         float64
# lea_not_highqual_class_all_pct                        float64
# st_flicensed_teach_pct                                float64
# st_tchyrs_0thru3_pct                                  float64
# st_tchyrs_4thru10_pct                                 float64
# st_tchyrs_11plus_pct                                  float64
# st_class_teach_num                                    float64
# st_nbpts_num                                          float64
# st_advance_dgr_pct                                    float64
# st_1yr_tchr_trnovr_pct                                float64
# st_emer_prov_teach_pct                                float64
# st_lateral_teach_pct                                  float64
# st_highqual_class_pct                                 float64
# st_highqual_class_hp_pct                              float64
# st_highqual_class_lp_pct                              float64
# st_highqual_class_all_pct                             float64
# st_not_highqual_class_hp_pct                          float64
# st_not_highqual_class_lp_pct                          float64
# st_not_highqual_class_all_pct                         float64
# st_prinyrs_0thru3_pct                                 float64
# st_prinyrs_4thru10_pct                                float64
# st_prinyrs_11plus_pct                                 float64
# st_prin_advance_dgr_pct                               float64
# st_1yr_prin_trnovr_pct                                float64
# st_prin_male_pct                                      float64
# st_prin_female_pct                                    float64
# st_prin_black_pct                                     float64
# st_prin_white_pct                                     float64
# st_prin_other_pct                                     float64
# 0-3 Years_Exp_Pct_Tch                                 float64
# 10+ Years_Exp_Pct_Tch                                 float64
# 4-10 Years_Exp_Pct_Tch                                float64
# 0-3 Years_LEA_Exp_Pct_Prin                            float64
# 10+ Years_LEA_Exp_Pct_Prin                            float64
# 4-10 Years_LEA_Exp_Pct_Prin                           float64
# Accomplished_PRIN_Standard 1_Pct                      float64
# Accomplished_PRIN_Standard 2_Pct                      float64
# Accomplished_PRIN_Standard 3_Pct                      float64
# Accomplished_PRIN_Standard 4_Pct                      float64
# Accomplished_PRIN_Standard 5_Pct                      float64
# Accomplished_PRIN_Standard 6_Pct                      float64
# Accomplished_PRIN_Standard 7_Pct                      float64
# Accomplished_TCHR_Standard 1_Pct                      float64
# Accomplished_TCHR_Standard 2_Pct                      float64
# Accomplished_TCHR_Standard 3_Pct                      float64
# Accomplished_TCHR_Standard 4_Pct                      float64
# Accomplished_TCHR_Standard 5_Pct                      float64
# Developing_PRIN_Standard 1_Pct                        float64
# Developing_PRIN_Standard 2_Pct                        float64
# Developing_PRIN_Standard 3_Pct                        float64
# Developing_PRIN_Standard 4_Pct                        float64
# Developing_PRIN_Standard 5_Pct                        float64
# Developing_PRIN_Standard 6_Pct                        float64
# Developing_PRIN_Standard 7_Pct                        float64
# Developing_TCHR_Standard 1_Pct                        float64
# Developing_TCHR_Standard 2_Pct                        float64
# Developing_TCHR_Standard 3_Pct                        float64
# Developing_TCHR_Standard 4_Pct                        float64
# Developing_TCHR_Standard 5_Pct                        float64
# Distinguished_PRIN_Standard 1_Pct                     float64
# Distinguished_PRIN_Standard 2_Pct                     float64
# Distinguished_PRIN_Standard 3_Pct                     float64
# Distinguished_PRIN_Standard 4_Pct                     float64
# Distinguished_PRIN_Standard 5_Pct                     float64
# Distinguished_PRIN_Standard 6_Pct                     float64
# Distinguished_PRIN_Standard 7_Pct                     float64
# Distinguished_TCHR_Standard 1_Pct                     float64
# Distinguished_TCHR_Standard 2_Pct                     float64
# Distinguished_TCHR_Standard 3_Pct                     float64
# Distinguished_TCHR_Standard 4_Pct                     float64
# Distinguished_TCHR_Standard 5_Pct                     float64
# Does Not Meet Expected Growth_PRIN_Standard 8_Pct     float64
# Does Not Meet Expected Growth_TCHR_Standard 6_Pct     float64
# Exceeds Expected Growth_PRIN_Standard 8_Pct           float64
# Exceeds Expected Growth_TCHR_Standard 6_Pct           float64
# Meets Expected Growth_PRIN_Standard 8_Pct             float64
# Meets Expected Growth_TCHR_Standard 6_Pct             float64
# Not Demostrated_PRIN_Standard 1_Pct                   float64
# Not Demostrated_PRIN_Standard 2_Pct                   float64
# Not Demostrated_PRIN_Standard 3_Pct                   float64
# Not Demostrated_PRIN_Standard 4_Pct                   float64
# Not Demostrated_PRIN_Standard 5_Pct                   float64
# Not Demostrated_PRIN_Standard 6_Pct                   float64
# Not Demostrated_PRIN_Standard 7_Pct                   float64
# Not Demostrated_TCHR_Standard 1_Pct                   float64
# Not Demostrated_TCHR_Standard 2_Pct                   float64
# Not Demostrated_TCHR_Standard 3_Pct                   float64
# Not Demostrated_TCHR_Standard 4_Pct                   float64
# Not Demostrated_TCHR_Standard 5_Pct                   float64
# Proficient_PRIN_Standard 1_Pct                        float64
# Proficient_PRIN_Standard 2_Pct                        float64
# Proficient_PRIN_Standard 3_Pct                        float64
# Proficient_PRIN_Standard 4_Pct                        float64
# Proficient_PRIN_Standard 5_Pct                        float64
# Proficient_PRIN_Standard 6_Pct                        float64
# Proficient_PRIN_Standard 7_Pct                        float64
# Proficient_TCHR_Standard 1_Pct                        float64
# Proficient_TCHR_Standard 2_Pct                        float64
# Proficient_TCHR_Standard 3_Pct                        float64
# Proficient_TCHR_Standard 4_Pct                        float64
# Proficient_TCHR_Standard 5_Pct                        float64
# AsianFemalePct                                        float64
# AsianMalePct                                          float64
# AsianPct                                              float64
# BlackFemalePct                                        float64
# BlackMalePct                                          float64
# BlackPct                                              float64
# HispanicFemalePct                                     float64
# HispanicMalePct                                       float64
# HispanicPct                                           float64
# IndianFemalePct                                       float64
# IndianMalePct                                         float64
# IndianPct                                             float64
# MinorityFemalePct                                     float64
# MinorityMalePct                                       float64
# MinorityPct                                           float64
# PacificIslandFemalePct                                float64
# PacificIslandMalePct                                  float64
# PacificIslandPct                                      float64
# TwoOrMoreFemalePct                                    float64
# TwoOrMoreMalePct                                      float64
# TwoOrMorePct                                          float64
# WhiteFemalePct                                        float64
# WhiteMalePct                                          float64
# WhitePct                                              float64
# dtypes: float64(1208), int64(3), object(45)
# memory usage: 23.3+ MB

# %%
#Get Student Body Racial Composition Fields
raceCompositionFields = schoolData.filter(regex='Indian|Asian|Hispanic|Black|White|PacificIsland|TwoOrMore|Minority')\
                                  .filter(regex='Pct').columns
    
rowsBefore = schoolData[raceCompositionFields].isnull().T.any().T.sum()

#Update missing race values with the district average when avaiable (No district averages for charter schools) 
schoolData[raceCompositionFields] = schoolData.groupby('District Name')[raceCompositionFields]\
                                              .transform(lambda x: x.fillna(x.mean()))

    #Review dataset contents after Racial Composition Imputation
print('*********After: Updating Missing Racial Compostion Values****************************')   
rowsAfter = schoolData[raceCompositionFields].isnull().T.any().T.sum()
rowsUpdated = rowsBefore - rowsAfter
print 'Rows Updated / Imputed: ', rowsUpdated 
print('\r\nTotal Rows Missing Racial Compositions By District Name') 
schoolData['District Name'][schoolData[raceCompositionFields].isnull().T.any().T].value_counts()
# Out:
# *********After: Updating Missing Racial Compostion Values****************************
# Rows Updated / Imputed:  0
#
# Total Rows Missing Racial Compositions By District Name
# Series([], Name: District Name, dtype: int64)

# %% [markdown]
# ## Remove Columns with Problematic Data
# **Here we remove entire columns that could cause problems during machine learning.  The following operations are performed:**
# * Remove any columns that have the same value in every single row.
# * Remove any columns that have a unique value in every single row (all values are different).
# * Remove empty columns (all values are NA or NULL).

# %%
#Remove any fields that have the same value in all rows
UniqueValueCounts = schoolData.nunique(dropna=False)
SingleValueCols = UniqueValueCounts[UniqueValueCounts == 1].index
schoolData = schoolData.drop(SingleValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with the same value in every row.*******************')
schoolData.info(verbose=False)
print '\r\nColumns Deleted: ', len(SingleValueCols)
# Out:
# *********After: Removing columns with the same value in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2432 entries, 0 to 2584
# Columns: 1137 entries, vphone_ad to WhitePct
# dtypes: float64(1097), object(40)
# memory usage: 21.2+ MB
#
# Columns Deleted:  119

# %%
#Remove any fields that have unique values in every row
schoolDataRecordCt = schoolData.shape[0]
UniqueValueCounts = schoolData.apply(pd.Series.nunique)
AllUniqueValueCols = UniqueValueCounts[UniqueValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(AllUniqueValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with unique values in every row.*******************')
schoolData.info(verbose=False)
print '\r\nColumns Deleted: ', len(AllUniqueValueCols)
# Out:
# *********After: Removing columns with unique values in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2432 entries, 0 to 2584
# Columns: 1135 entries, vphone_ad to WhitePct
# dtypes: float64(1097), object(38)
# memory usage: 21.2+ MB
#
# Columns Deleted:  2

# %%
#Remove any empty fields (null values in every row)
schoolDataRecordCt = schoolData.shape[0]
NullValueCounts = schoolData.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with null / blank values in every row.*************')
schoolData.info(verbose=False)
print '\r\nColumns Deleted: ', len(NullValueCols)
# Out:
# *********After: Removing columns with null / blank values in every row.*************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2432 entries, 0 to 2584
# Columns: 1135 entries, vphone_ad to WhitePct
# dtypes: float64(1097), object(38)
# memory usage: 21.1+ MB
#
# Columns Deleted:  0

# %% [markdown]
# ## Handle Other Missing Values Types
# * Here we eliminate any numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# * All remaining non-race, numeric column missing values are populated with 0.
# * In many cases, it seems that schools are not simply not reporting values when they are zero. However, mean imputation or some other strategy might be considered.

# %%
#Isolate continuous and categorical data types
#These are indexers into the schoolData dataframe and may be used similar to the schoolData dataframe 
sD_boolean = schoolData.loc[:, (schoolData.dtypes == bool) ]
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]
sD_continuous = schoolData.loc[:, (schoolData.dtypes != bool) & (schoolData.dtypes != object)]
print "Boolean Columns: ", sD_boolean.shape[1]
print "Nominal Columns: ", sD_nominal.shape[1]
print "Continuous Columns: ", sD_continuous.shape[1]
print "Columns Accounted for: ", sD_nominal.shape[1] + sD_continuous.shape[1] + sD_boolean.shape[1]
# Out:
# Boolean Columns:  0
# Nominal Columns:  38
# Continuous Columns:  1097
# Columns Accounted for:  1135

# %%
#Eliminate continuous columns with more than missingThreshold percentage of missing values
schoolDataRecordCt = sD_continuous.shape[0]
missingValueLimit = schoolDataRecordCt * missingThreshold
NullValueCounts = sD_continuous.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts >= missingValueLimit].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with >= missingThreshold % of missing values******')
schoolData.info(verbose=False)
print '\r\nColumns Deleted: ', len(NullValueCols)
# Out:
# *********After: Removing columns with >= missingThreshold % of missing values******
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2432 entries, 0 to 2584
# Columns: 637 entries, vphone_ad to WhitePct
# dtypes: float64(599), object(38)
# memory usage: 11.8+ MB
#
# Columns Deleted:  498

# %% [markdown]
# ## One-Hot Encoding of Categorical Variables
# **All categorical / string variables are converted to numberic variables via one hot encoding.  Each unique row value will become a new binary / numeric column in the dataset.**
# * All remaining categorical columns are one-hot encoded.
# * In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# * Prior to one-hot encoding, columns with > *uniqueThreshold* unique values are deleted.

# %%
#Delete categorical columns with > 25 unique values (Each unique value becomes a column during one-hot encoding)
oneHotUniqueValueCounts = schoolData[sD_nominal.columns].apply(lambda x: x.nunique())
oneHotUniqueValueCols = oneHotUniqueValueCounts[oneHotUniqueValueCounts >= uniqueThreshold].index
schoolData.drop(oneHotUniqueValueCols, axis=1, inplace=True) 

#Review dataset contents one hot high unique value drops
print('*********After: Removing columns with >= uniqueThreshold unique values***********')
schoolData.info(verbose=False)
print '\r\nColumns Deleted: ', len(oneHotUniqueValueCols)
# Out:
# *********After: Removing columns with >= uniqueThreshold unique values***********
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2432 entries, 0 to 2584
# Columns: 623 entries, closed_ind to WhitePct
# dtypes: float64(599), object(24)
# memory usage: 11.6+ MB
#
# Columns Deleted:  14

# %%
#Isolate remaining categorical variables
begColumnCt = len(schoolData.columns)
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]

#one hot encode categorical variables
schoolData = pd.get_dummies(data=schoolData, 
                       columns=sD_nominal, drop_first=True)

#Determine change in column count
endColumnCt = len(schoolData.columns)
columnsAdded = endColumnCt - begColumnCt

#Review dataset contents one hot high unique value drops
print 'Columns To One-Hot Encode: ', len(sD_nominal.columns)
print('\r\n*********After: Adding New Columns Via One-Hot Encoding*************************')
schoolData.info(verbose=False)
print '\r\nNew Columns Created Via One-Hot Encoding: ', columnsAdded
# Out:
# Columns To One-Hot Encode:  24
#
# *********After: Adding New Columns Via One-Hot Encoding*************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2432 entries, 0 to 2584
# Columns: 679 entries, closed_ind to lea_avg_age_media_collection_2010
# dtypes: float64(599), uint8(80)
# memory usage: 11.3 MB
#
# New Columns Created Via One-Hot Encoding:  56

# %% [markdown]
# ## Impute any Remaining Missing Values as Zero

# %%
#Print out all the missing value rows
pd.set_option('display.max_rows', 1000)

print('\r\n*********The Remaining Missing Values Below will be set to Zero!*************************')

#Check for Missing values 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# *********The Remaining Missing Values Below will be set to Zero!*************************
#                                          Variable Name  Number Missing Values
# 4                                              00_Size                   1179
# 5                                              01_Size                   1195
# 6                                              02_Size                   1195
# 7                                              03_Size                   1194
# 8                                              04_Size                   1168
# 9                                              05_Size                   1192
# 10                                         Math I_Size                   1397
# 20                                           SPG Score                    129
# 21                                  Reading  SPG Score                    604
# 22                                      Math SPG Score                    604
# 23                                  EVAAS Growth Score                    141
# 24                           Overall Achievement Score                    129
# 25                                          Read Score                    604
# 26                                          Math Score                    604
# 27                                       Science Score                    693
# 28                                        Math I Score                   1447
# 29                                   EOCMathI_CACR_All                   1377
# 30                                    EOCMathI_GLP_All                   1377
# 31                                EOCSubjects_CACR_All                   1366
# 32                                 EOCSubjects_GLP_All                   1366
# 33                            EOG/EOCSubjects_CACR_All                     45
# 34                             EOG/EOCSubjects_GLP_All                     45
# 35                                     EOGGr3_CACR_All                   1101
# 36                                      EOGGr3_GLP_All                   1101
# 37                                     EOGGr4_CACR_All                   1106
# 38                                      EOGGr4_GLP_All                   1106
# 39                                     EOGGr5_CACR_All                   1122
# 40                                      EOGGr5_GLP_All                   1122
# 41                                 EOGMathGr3_CACR_All                   1105
# 42                                  EOGMathGr3_GLP_All                   1105
# 43                               EOGMathGr3-8_CACR_All                    535
# 44                                EOGMathGr3-8_GLP_All                    535
# 45                                 EOGMathGr4_CACR_All                   1112
# 46                                  EOGMathGr4_GLP_All                   1112
# 47                                 EOGMathGr5_CACR_All                   1138
# 48                                  EOGMathGr5_GLP_All                   1138
# 49                              EOGReadingGr3_CACR_All                   1105
# 50                               EOGReadingGr3_GLP_All                   1105
# 51                            EOGReadingGr3-8_CACR_All                    535
# 52                             EOGReadingGr3-8_GLP_All                    535
# 53                              EOGReadingGr4_CACR_All                   1112
# 54                               EOGReadingGr4_GLP_All                   1112
# 55                              EOGReadingGr5_CACR_All                   1138
# 56                               EOGReadingGr5_GLP_All                   1138
# 57                              EOGScienceGr5_CACR_All                   1138
# 58                               EOGScienceGr5_GLP_All                   1138
# 59                            EOGScienceGr5&8_CACR_All                    631
# 60                             EOGScienceGr5&8_GLP_All                    631
# 61                                EOGSubjects_CACR_All                    532
# 62                                 EOGSubjects_GLP_All                    532
# 63                                EOCMathI_CACR_Female                   1377
# 64                                 EOCMathI_GLP_Female                   1377
# 65                             EOCSubjects_CACR_Female                   1366
# 66                              EOCSubjects_GLP_Female                   1366
# 67                         EOG/EOCSubjects_CACR_Female                     45
# 68                          EOG/EOCSubjects_GLP_Female                     45
# 69                                  EOGGr3_CACR_Female                   1101
# 70                                   EOGGr3_GLP_Female                   1101
# 71                                  EOGGr4_CACR_Female                   1106
# 72                                   EOGGr4_GLP_Female                   1106
# 73                                  EOGGr5_CACR_Female                   1122
# 74                                   EOGGr5_GLP_Female                   1122
# 75                              EOGMathGr3_CACR_Female                   1105
# 76                               EOGMathGr3_GLP_Female                   1105
# 77                            EOGMathGr3-8_CACR_Female                    535
# 78                             EOGMathGr3-8_GLP_Female                    535
# 79                              EOGMathGr4_CACR_Female                   1112
# 80                               EOGMathGr4_GLP_Female                   1112
# 81                              EOGMathGr5_CACR_Female                   1138
# 82                               EOGMathGr5_GLP_Female                   1138
# 83                           EOGReadingGr3_CACR_Female                   1105
# 84                            EOGReadingGr3_GLP_Female                   1105
# 85                         EOGReadingGr3-8_CACR_Female                    535
# 86                          EOGReadingGr3-8_GLP_Female                    535
# 87                           EOGReadingGr4_CACR_Female                   1112
# 88                            EOGReadingGr4_GLP_Female                   1112
# 89                           EOGReadingGr5_CACR_Female                   1138
# 90                            EOGReadingGr5_GLP_Female                   1138
# 91                           EOGScienceGr5_CACR_Female                   1138
# 92                            EOGScienceGr5_GLP_Female                   1138
# 93                         EOGScienceGr5&8_CACR_Female                    631
# 94                          EOGScienceGr5&8_GLP_Female                    631
# 95                             EOGSubjects_CACR_Female                    532
# 96                              EOGSubjects_GLP_Female                    532
# 97                                  EOCMathI_CACR_Male                   1377
# 98                                   EOCMathI_GLP_Male                   1377
# 99                               EOCSubjects_CACR_Male                   1366
# 100                               EOCSubjects_GLP_Male                   1366
# 101                          EOG/EOCSubjects_CACR_Male                     45
# 102                           EOG/EOCSubjects_GLP_Male                     45
# 103                                   EOGGr3_CACR_Male                   1101
# 104                                    EOGGr3_GLP_Male                   1101
# 105                                   EOGGr4_CACR_Male                   1106
# 106                                    EOGGr4_GLP_Male                   1106
# 107                                   EOGGr5_CACR_Male                   1122
# 108                                    EOGGr5_GLP_Male                   1122
# 109                               EOGMathGr3_CACR_Male                   1105
# 110                                EOGMathGr3_GLP_Male                   1105
# 111                             EOGMathGr3-8_CACR_Male                    535
# 112                              EOGMathGr3-8_GLP_Male                    535
# 113                               EOGMathGr4_CACR_Male                   1112
# 114                                EOGMathGr4_GLP_Male                   1112
# 115                               EOGMathGr5_CACR_Male                   1138
# 116                                EOGMathGr5_GLP_Male                   1138
# 117                            EOGReadingGr3_CACR_Male                   1105
# 118                             EOGReadingGr3_GLP_Male                   1105
# 119                          EOGReadingGr3-8_CACR_Male                    535
# 120                           EOGReadingGr3-8_GLP_Male                    535
# 121                            EOGReadingGr4_CACR_Male                   1112
# 122                             EOGReadingGr4_GLP_Male                   1112
# 123                            EOGReadingGr5_CACR_Male                   1138
# 124                             EOGReadingGr5_GLP_Male                   1138
# 125                            EOGScienceGr5_CACR_Male                   1138
# 126                             EOGScienceGr5_GLP_Male                   1138
# 127                          EOGScienceGr5&8_CACR_Male                    631
# 128                           EOGScienceGr5&8_GLP_Male                    631
# 129                              EOGSubjects_CACR_Male                    532
# 130                               EOGSubjects_GLP_Male                    532
# 131                       EOCMathI_CACR_AmericanIndian                   1377
# 132                        EOCMathI_GLP_AmericanIndian                   1377
# 133                    EOCSubjects_CACR_AmericanIndian                   1366
# 134                     EOCSubjects_GLP_AmericanIndian                   1366
# 135                EOG/EOCSubjects_CACR_AmericanIndian                     45
# 136                 EOG/EOCSubjects_GLP_AmericanIndian                     45
# 137                         EOGGr3_CACR_AmericanIndian                   1101
# 138                          EOGGr3_GLP_AmericanIndian                   1101
# 139                         EOGGr4_CACR_AmericanIndian                   1106
# 140                          EOGGr4_GLP_AmericanIndian                   1106
# 141                         EOGGr5_CACR_AmericanIndian                   1122
# 142                          EOGGr5_GLP_AmericanIndian                   1122
# 143                     EOGMathGr3_CACR_AmericanIndian                   1105
# 144                      EOGMathGr3_GLP_AmericanIndian                   1105
# 145                   EOGMathGr3-8_CACR_AmericanIndian                    535
# 146                    EOGMathGr3-8_GLP_AmericanIndian                    535
# 147                     EOGMathGr4_CACR_AmericanIndian                   1112
# 148                      EOGMathGr4_GLP_AmericanIndian                   1112
# 149                     EOGMathGr5_CACR_AmericanIndian                   1138
# 150                      EOGMathGr5_GLP_AmericanIndian                   1138
# 151                  EOGReadingGr3_CACR_AmericanIndian                   1105
# 152                   EOGReadingGr3_GLP_AmericanIndian                   1105
# 153                EOGReadingGr3-8_CACR_AmericanIndian                    535
# 154                 EOGReadingGr3-8_GLP_AmericanIndian                    535
# 155                  EOGReadingGr4_CACR_AmericanIndian                   1112
# 156                   EOGReadingGr4_GLP_AmericanIndian                   1112
# 157                  EOGReadingGr5_CACR_AmericanIndian                   1138
# 158                   EOGReadingGr5_GLP_AmericanIndian                   1138
# 159                  EOGScienceGr5_CACR_AmericanIndian                   1138
# 160                   EOGScienceGr5_GLP_AmericanIndian                   1138
# 161                EOGScienceGr5&8_CACR_AmericanIndian                    631
# 162                 EOGScienceGr5&8_GLP_AmericanIndian                    631
# 163                    EOGSubjects_CACR_AmericanIndian                    532
# 164                     EOGSubjects_GLP_AmericanIndian                    532
# 165                                EOCMathI_CACR_Asian                   1377
# 166                                 EOCMathI_GLP_Asian                   1377
# 167                             EOCSubjects_CACR_Asian                   1366
# 168                              EOCSubjects_GLP_Asian                   1366
# 169                         EOG/EOCSubjects_CACR_Asian                     45
# 170                          EOG/EOCSubjects_GLP_Asian                     45
# 171                                  EOGGr3_CACR_Asian                   1101
# 172                                   EOGGr3_GLP_Asian                   1101
# 173                                  EOGGr4_CACR_Asian                   1106
# 174                                   EOGGr4_GLP_Asian                   1106
# 175                                  EOGGr5_CACR_Asian                   1122
# 176                                   EOGGr5_GLP_Asian                   1122
# 177                              EOGMathGr3_CACR_Asian                   1105
# 178                               EOGMathGr3_GLP_Asian                   1105
# 179                            EOGMathGr3-8_CACR_Asian                    535
# 180                             EOGMathGr3-8_GLP_Asian                    535
# 181                              EOGMathGr4_CACR_Asian                   1112
# 182                               EOGMathGr4_GLP_Asian                   1112
# 183                              EOGMathGr5_CACR_Asian                   1138
# 184                               EOGMathGr5_GLP_Asian                   1138
# 185                           EOGReadingGr3_CACR_Asian                   1105
# 186                            EOGReadingGr3_GLP_Asian                   1105
# 187                         EOGReadingGr3-8_CACR_Asian                    535
# 188                          EOGReadingGr3-8_GLP_Asian                    535
# 189                           EOGReadingGr4_CACR_Asian                   1112
# 190                            EOGReadingGr4_GLP_Asian                   1112
# 191                           EOGReadingGr5_CACR_Asian                   1138
# 192                            EOGReadingGr5_GLP_Asian                   1138
# 193                           EOGScienceGr5_CACR_Asian                   1138
# 194                            EOGScienceGr5_GLP_Asian                   1138
# 195                         EOGScienceGr5&8_CACR_Asian                    631
# 196                          EOGScienceGr5&8_GLP_Asian                    631
# 197                             EOGSubjects_CACR_Asian                    532
# 198                              EOGSubjects_GLP_Asian                    532
# 199                                EOCMathI_CACR_Black                   1377
# 200                                 EOCMathI_GLP_Black                   1377
# 201                             EOCSubjects_CACR_Black                   1366
# 202                              EOCSubjects_GLP_Black                   1366
# 203                         EOG/EOCSubjects_CACR_Black                     45
# 204                          EOG/EOCSubjects_GLP_Black                     45
# 205                                  EOGGr3_CACR_Black                   1101
# 206                                   EOGGr3_GLP_Black                   1101
# 207                                  EOGGr4_CACR_Black                   1106
# 208                                   EOGGr4_GLP_Black                   1106
# 209                                  EOGGr5_CACR_Black                   1122
# 210                                   EOGGr5_GLP_Black                   1122
# 211                              EOGMathGr3_CACR_Black                   1105
# 212                               EOGMathGr3_GLP_Black                   1105
# 213                            EOGMathGr3-8_CACR_Black                    535
# 214                             EOGMathGr3-8_GLP_Black                    535
# 215                              EOGMathGr4_CACR_Black                   1112
# 216                               EOGMathGr4_GLP_Black                   1112
# 217                              EOGMathGr5_CACR_Black                   1138
# 218                               EOGMathGr5_GLP_Black                   1138
# 219                           EOGReadingGr3_CACR_Black                   1105
# 220                            EOGReadingGr3_GLP_Black                   1105
# 221                         EOGReadingGr3-8_CACR_Black                    535
# 222                          EOGReadingGr3-8_GLP_Black                    535
# 223                           EOGReadingGr4_CACR_Black                   1112
# 224                            EOGReadingGr4_GLP_Black                   1112
# 225                           EOGReadingGr5_CACR_Black                   1138
# 226                            EOGReadingGr5_GLP_Black                   1138
# 227                           EOGScienceGr5_CACR_Black                   1138
# 228                            EOGScienceGr5_GLP_Black                   1138
# 229                         EOGScienceGr5&8_CACR_Black                    631
# 230                          EOGScienceGr5&8_GLP_Black                    631
# 231                             EOGSubjects_CACR_Black                    532
# 232                              EOGSubjects_GLP_Black                    532
# 233                             EOCMathI_CACR_Hispanic                   1377
# 234                              EOCMathI_GLP_Hispanic                   1377
# 235                          EOCSubjects_CACR_Hispanic                   1366
# 236                           EOCSubjects_GLP_Hispanic                   1366
# 237                      EOG/EOCSubjects_CACR_Hispanic                     45
# 238                       EOG/EOCSubjects_GLP_Hispanic                     45
# 239                               EOGGr3_CACR_Hispanic                   1101
# 240                                EOGGr3_GLP_Hispanic                   1101
# 241                               EOGGr4_CACR_Hispanic                   1106
# 242                                EOGGr4_GLP_Hispanic                   1106
# 243                               EOGGr5_CACR_Hispanic                   1122
# 244                                EOGGr5_GLP_Hispanic                   1122
# 245                           EOGMathGr3_CACR_Hispanic                   1105
# 246                            EOGMathGr3_GLP_Hispanic                   1105
# 247                         EOGMathGr3-8_CACR_Hispanic                    535
# 248                          EOGMathGr3-8_GLP_Hispanic                    535
# 249                           EOGMathGr4_CACR_Hispanic                   1112
# 250                            EOGMathGr4_GLP_Hispanic                   1112
# 251                           EOGMathGr5_CACR_Hispanic                   1138
# 252                            EOGMathGr5_GLP_Hispanic                   1138
# 253                        EOGReadingGr3_CACR_Hispanic                   1105
# 254                         EOGReadingGr3_GLP_Hispanic                   1105
# 255                      EOGReadingGr3-8_CACR_Hispanic                    535
# 256                       EOGReadingGr3-8_GLP_Hispanic                    535
# 257                        EOGReadingGr4_CACR_Hispanic                   1112
# 258                         EOGReadingGr4_GLP_Hispanic                   1112
# 259                        EOGReadingGr5_CACR_Hispanic                   1138
# 260                         EOGReadingGr5_GLP_Hispanic                   1138
# 261                        EOGScienceGr5_CACR_Hispanic                   1138
# 262                         EOGScienceGr5_GLP_Hispanic                   1138
# 263                      EOGScienceGr5&8_CACR_Hispanic                    631
# 264                       EOGScienceGr5&8_GLP_Hispanic                    631
# 265                          EOGSubjects_CACR_Hispanic                    532
# 266                           EOGSubjects_GLP_Hispanic                    532
# 267                       EOCMathI_CACR_TwoorMoreRaces                   1377
# 268                        EOCMathI_GLP_TwoorMoreRaces                   1377
# 269                    EOCSubjects_CACR_TwoorMoreRaces                   1366
# 270                     EOCSubjects_GLP_TwoorMoreRaces                   1366
# 271                EOG/EOCSubjects_CACR_TwoorMoreRaces                     45
# 272                 EOG/EOCSubjects_GLP_TwoorMoreRaces                     45
# 273                         EOGGr3_CACR_TwoorMoreRaces                   1101
# 274                          EOGGr3_GLP_TwoorMoreRaces                   1101
# 275                         EOGGr4_CACR_TwoorMoreRaces                   1106
# 276                          EOGGr4_GLP_TwoorMoreRaces                   1106
# 277                         EOGGr5_CACR_TwoorMoreRaces                   1122
# 278                          EOGGr5_GLP_TwoorMoreRaces                   1122
# 279                     EOGMathGr3_CACR_TwoorMoreRaces                   1105
# 280                      EOGMathGr3_GLP_TwoorMoreRaces                   1105
# 281                   EOGMathGr3-8_CACR_TwoorMoreRaces                    535
# 282                    EOGMathGr3-8_GLP_TwoorMoreRaces                    535
# 283                     EOGMathGr4_CACR_TwoorMoreRaces                   1112
# 284                      EOGMathGr4_GLP_TwoorMoreRaces                   1112
# 285                     EOGMathGr5_CACR_TwoorMoreRaces                   1138
# 286                      EOGMathGr5_GLP_TwoorMoreRaces                   1138
# 287                  EOGReadingGr3_CACR_TwoorMoreRaces                   1105
# 288                   EOGReadingGr3_GLP_TwoorMoreRaces                   1105
# 289                EOGReadingGr3-8_CACR_TwoorMoreRaces                    535
# 290                 EOGReadingGr3-8_GLP_TwoorMoreRaces                    535
# 291                  EOGReadingGr4_CACR_TwoorMoreRaces                   1112
# 292                   EOGReadingGr4_GLP_TwoorMoreRaces                   1112
# 293                  EOGReadingGr5_CACR_TwoorMoreRaces                   1138
# 294                   EOGReadingGr5_GLP_TwoorMoreRaces                   1138
# 295                  EOGScienceGr5_CACR_TwoorMoreRaces                   1138
# 296                   EOGScienceGr5_GLP_TwoorMoreRaces                   1138
# 297                EOGScienceGr5&8_CACR_TwoorMoreRaces                    631
# 298                 EOGScienceGr5&8_GLP_TwoorMoreRaces                    631
# 299                    EOGSubjects_CACR_TwoorMoreRaces                    532
# 300                     EOGSubjects_GLP_TwoorMoreRaces                    532
# 301                                EOCMathI_CACR_White                   1377
# 302                                 EOCMathI_GLP_White                   1377
# 303                             EOCSubjects_CACR_White                   1366
# 304                              EOCSubjects_GLP_White                   1366
# 305                         EOG/EOCSubjects_CACR_White                     45
# 306                          EOG/EOCSubjects_GLP_White                     45
# 307                                  EOGGr3_CACR_White                   1101
# 308                                   EOGGr3_GLP_White                   1101
# 309                                  EOGGr4_CACR_White                   1106
# 310                                   EOGGr4_GLP_White                   1106
# 311                                  EOGGr5_CACR_White                   1122
# 312                                   EOGGr5_GLP_White                   1122
# 313                              EOGMathGr3_CACR_White                   1105
# 314                               EOGMathGr3_GLP_White                   1105
# 315                            EOGMathGr3-8_CACR_White                    535
# 316                             EOGMathGr3-8_GLP_White                    535
# 317                              EOGMathGr4_CACR_White                   1112
# 318                               EOGMathGr4_GLP_White                   1112
# 319                              EOGMathGr5_CACR_White                   1138
# 320                               EOGMathGr5_GLP_White                   1138
# 321                           EOGReadingGr3_CACR_White                   1105
# 322                            EOGReadingGr3_GLP_White                   1105
# 323                         EOGReadingGr3-8_CACR_White                    535
# 324                          EOGReadingGr3-8_GLP_White                    535
# 325                           EOGReadingGr4_CACR_White                   1112
# 326                            EOGReadingGr4_GLP_White                   1112
# 327                           EOGReadingGr5_CACR_White                   1138
# 328                            EOGReadingGr5_GLP_White                   1138
# 329                           EOGScienceGr5_CACR_White                   1138
# 330                            EOGScienceGr5_GLP_White                   1138
# 331                         EOGScienceGr5&8_CACR_White                    631
# 332                          EOGScienceGr5&8_GLP_White                    631
# 333                             EOGSubjects_CACR_White                    532
# 334                              EOGSubjects_GLP_White                    532
# 335                                  EOCMathI_CACR_EDS                   1377
# 336                                   EOCMathI_GLP_EDS                   1377
# 337                               EOCSubjects_CACR_EDS                   1366
# 338                                EOCSubjects_GLP_EDS                   1366
# 339                           EOG/EOCSubjects_CACR_EDS                     45
# 340                            EOG/EOCSubjects_GLP_EDS                     45
# 341                                    EOGGr3_CACR_EDS                   1101
# 342                                     EOGGr3_GLP_EDS                   1101
# 343                                    EOGGr4_CACR_EDS                   1106
# 344                                     EOGGr4_GLP_EDS                   1106
# 345                                    EOGGr5_CACR_EDS                   1122
# 346                                     EOGGr5_GLP_EDS                   1122
# 347                                EOGMathGr3_CACR_EDS                   1105
# 348                                 EOGMathGr3_GLP_EDS                   1105
# 349                              EOGMathGr3-8_CACR_EDS                    535
# 350                               EOGMathGr3-8_GLP_EDS                    535
# 351                                EOGMathGr4_CACR_EDS                   1112
# 352                                 EOGMathGr4_GLP_EDS                   1112
# 353                                EOGMathGr5_CACR_EDS                   1138
# 354                                 EOGMathGr5_GLP_EDS                   1138
# 355                             EOGReadingGr3_CACR_EDS                   1105
# 356                              EOGReadingGr3_GLP_EDS                   1105
# 357                           EOGReadingGr3-8_CACR_EDS                    535
# 358                            EOGReadingGr3-8_GLP_EDS                    535
# 359                             EOGReadingGr4_CACR_EDS                   1112
# 360                              EOGReadingGr4_GLP_EDS                   1112
# 361                             EOGReadingGr5_CACR_EDS                   1138
# 362                              EOGReadingGr5_GLP_EDS                   1138
# 363                             EOGScienceGr5_CACR_EDS                   1138
# 364                              EOGScienceGr5_GLP_EDS                   1138
# 365                           EOGScienceGr5&8_CACR_EDS                    631
# 366                            EOGScienceGr5&8_GLP_EDS                    631
# 367                               EOGSubjects_CACR_EDS                    532
# 368                                EOGSubjects_GLP_EDS                    532
# 369                                  EOCMathI_CACR_LEP                   1377
# 370                                   EOCMathI_GLP_LEP                   1377
# 371                               EOCSubjects_CACR_LEP                   1366
# 372                                EOCSubjects_GLP_LEP                   1366
# 373                           EOG/EOCSubjects_CACR_LEP                     45
# 374                            EOG/EOCSubjects_GLP_LEP                     45
# 375                                    EOGGr3_CACR_LEP                   1101
# 376                                     EOGGr3_GLP_LEP                   1101
# 377                                    EOGGr4_CACR_LEP                   1106
# 378                                     EOGGr4_GLP_LEP                   1106
# 379                                    EOGGr5_CACR_LEP                   1122
# 380                                     EOGGr5_GLP_LEP                   1122
# 381                                EOGMathGr3_CACR_LEP                   1105
# 382                                 EOGMathGr3_GLP_LEP                   1105
# 383                              EOGMathGr3-8_CACR_LEP                    535
# 384                               EOGMathGr3-8_GLP_LEP                    535
# 385                                EOGMathGr4_CACR_LEP                   1112
# 386                                 EOGMathGr4_GLP_LEP                   1112
# 387                                EOGMathGr5_CACR_LEP                   1138
# 388                                 EOGMathGr5_GLP_LEP                   1138
# 389                             EOGReadingGr3_CACR_LEP                   1105
# 390                              EOGReadingGr3_GLP_LEP                   1105
# 391                           EOGReadingGr3-8_CACR_LEP                    535
# 392                            EOGReadingGr3-8_GLP_LEP                    535
# 393                             EOGReadingGr4_CACR_LEP                   1112
# 394                              EOGReadingGr4_GLP_LEP                   1112
# 395                             EOGReadingGr5_CACR_LEP                   1138
# 396                              EOGReadingGr5_GLP_LEP                   1138
# 397                             EOGScienceGr5_CACR_LEP                   1138
# 398                              EOGScienceGr5_GLP_LEP                   1138
# 399                           EOGScienceGr5&8_CACR_LEP                    631
# 400                            EOGScienceGr5&8_GLP_LEP                    631
# 401                               EOGSubjects_CACR_LEP                    532
# 402                                EOGSubjects_GLP_LEP                    532
# 403                                  EOCMathI_CACR_SWD                   1377
# 404                                   EOCMathI_GLP_SWD                   1377
# 405                               EOCSubjects_CACR_SWD                   1366
# 406                                EOCSubjects_GLP_SWD                   1366
# 407                           EOG/EOCSubjects_CACR_SWD                     45
# 408                            EOG/EOCSubjects_GLP_SWD                     45
# 409                                    EOGGr3_CACR_SWD                   1101
# 410                                     EOGGr3_GLP_SWD                   1101
# 411                                    EOGGr4_CACR_SWD                   1106
# 412                                     EOGGr4_GLP_SWD                   1106
# 413                                    EOGGr5_CACR_SWD                   1122
# 414                                     EOGGr5_GLP_SWD                   1122
# 415                                EOGMathGr3_CACR_SWD                   1105
# 416                                 EOGMathGr3_GLP_SWD                   1105
# 417                              EOGMathGr3-8_CACR_SWD                    535
# 418                               EOGMathGr3-8_GLP_SWD                    535
# 419                                EOGMathGr4_CACR_SWD                   1112
# 420                                 EOGMathGr4_GLP_SWD                   1112
# 421                                EOGMathGr5_CACR_SWD                   1138
# 422                                 EOGMathGr5_GLP_SWD                   1138
# 423                             EOGReadingGr3_CACR_SWD                   1105
# 424                              EOGReadingGr3_GLP_SWD                   1105
# 425                           EOGReadingGr3-8_CACR_SWD                    535
# 426                            EOGReadingGr3-8_GLP_SWD                    535
# 427                             EOGReadingGr4_CACR_SWD                   1112
# 428                              EOGReadingGr4_GLP_SWD                   1112
# 429                             EOGReadingGr5_CACR_SWD                   1138
# 430                              EOGReadingGr5_GLP_SWD                   1138
# 431                             EOGScienceGr5_CACR_SWD                   1138
# 432                              EOGScienceGr5_GLP_SWD                   1138
# 433                           EOGScienceGr5&8_CACR_SWD                    631
# 434                            EOGScienceGr5&8_GLP_SWD                    631
# 435                               EOGSubjects_CACR_SWD                    532
# 436                                EOGSubjects_GLP_SWD                    532
# 437                                  EOCMathI_CACR_AIG                   1377
# 438                                   EOCMathI_GLP_AIG                   1377
# 439                               EOCSubjects_CACR_AIG                   1366
# 440                                EOCSubjects_GLP_AIG                   1366
# 441                           EOG/EOCSubjects_CACR_AIG                     45
# 442                            EOG/EOCSubjects_GLP_AIG                     45
# 443                                    EOGGr3_CACR_AIG                   1101
# 444                                     EOGGr3_GLP_AIG                   1101
# 445                                    EOGGr4_CACR_AIG                   1106
# 446                                     EOGGr4_GLP_AIG                   1106
# 447                                    EOGGr5_CACR_AIG                   1122
# 448                                     EOGGr5_GLP_AIG                   1122
# 449                                EOGMathGr3_CACR_AIG                   1105
# 450                                 EOGMathGr3_GLP_AIG                   1105
# 451                              EOGMathGr3-8_CACR_AIG                    535
# 452                               EOGMathGr3-8_GLP_AIG                    535
# 453                                EOGMathGr4_CACR_AIG                   1112
# 454                                 EOGMathGr4_GLP_AIG                   1112
# 455                                EOGMathGr5_CACR_AIG                   1138
# 456                                 EOGMathGr5_GLP_AIG                   1138
# 457                             EOGReadingGr3_CACR_AIG                   1105
# 458                              EOGReadingGr3_GLP_AIG                   1105
# 459                           EOGReadingGr3-8_CACR_AIG                    535
# 460                            EOGReadingGr3-8_GLP_AIG                    535
# 461                             EOGReadingGr4_CACR_AIG                   1112
# 462                              EOGReadingGr4_GLP_AIG                   1112
# 463                             EOGReadingGr5_CACR_AIG                   1138
# 464                              EOGReadingGr5_GLP_AIG                   1138
# 465                             EOGScienceGr5_CACR_AIG                   1138
# 466                              EOGScienceGr5_GLP_AIG                   1138
# 467                           EOGScienceGr5&8_CACR_AIG                    631
# 468                            EOGScienceGr5&8_GLP_AIG                    631
# 469                               EOGSubjects_CACR_AIG                    532
# 470                                EOGSubjects_GLP_AIG                    532
# 471                                        pct_GCE_ALL                   1089
# 472                                     pct_PASSED_EOG                   1118
# 473                                       pct_PROMOTED                   1105
# 474                           MathGr3-8_pTarget_PctMet                    578
# 475                        ReadingGr3-8_pTarget_PctMet                    578
# 476                            SciGr5&8_pTarget_PctMet                    750
# 477                        TotalTargets_pTarget_PctMet                     68
# 480                           lea_ap_participation_pct                    229
# 481                              lea_ap_pct_3_or_above                     24
# 482                              lea_ib_pct_4_or_above                   1412
# 488                             stud_internet_comp_num                     11
# 494                         lea_stud_internet_comp_num                      4
# 498                                  digital_media_pct                     16
# 499                                  books_per_student                     13
# 500                              lea_books_per_student                     13
# 501                        st_avg_age_media_collection                     13
# 502                               st_books_per_student                     13
# 503                                flicensed_teach_pct                      1
# 504                                  tchyrs_0thru3_pct                      1
# 505                                 tchyrs_4thru10_pct                      1
# 506                                  tchyrs_11plus_pct                      1
# 507                                    class_teach_num                      1
# 508                                          nbpts_num                    157
# 509                                    advance_dgr_pct                      1
# 510                               _1yr_tchr_trnovr_pct                     14
# 511                                  lateral_teach_pct                   1199
# 512                                 highqual_class_pct                      7
# 518                                      lea_nbpts_num                     23
# 520                            lea_1yr_tchr_trnovr_pct                      2
# 521                            lea_emer_prov_teach_pct                    944
# 522                              lea_lateral_teach_pct                    231
# 523                             lea_highqual_class_pct                      2
# 524                          lea_highqual_class_hp_pct                    287
# 525                          lea_highqual_class_lp_pct                    482
# 527                      lea_not_highqual_class_hp_pct                    287
# 528                      lea_not_highqual_class_lp_pct                    482
# 541                              0-3 Years_Exp_Pct_Tch                      1
# 542                              10+ Years_Exp_Pct_Tch                      1
# 543                             4-10 Years_Exp_Pct_Tch                      1
# 547                   Accomplished_TCHR_Standard 1_Pct                     34
# 548                   Accomplished_TCHR_Standard 2_Pct                     34
# 549                   Accomplished_TCHR_Standard 3_Pct                     34
# 550                   Accomplished_TCHR_Standard 4_Pct                     34
# 551                   Accomplished_TCHR_Standard 5_Pct                     34
# 552                     Developing_TCHR_Standard 1_Pct                     34
# 553                     Developing_TCHR_Standard 2_Pct                     34
# 554                     Developing_TCHR_Standard 3_Pct                     34
# 555                     Developing_TCHR_Standard 4_Pct                     34
# 556                     Developing_TCHR_Standard 5_Pct                     34
# 557                  Distinguished_TCHR_Standard 1_Pct                     34
# 558                  Distinguished_TCHR_Standard 2_Pct                     34
# 559                  Distinguished_TCHR_Standard 3_Pct                     34
# 560                  Distinguished_TCHR_Standard 4_Pct                     34
# 561                  Distinguished_TCHR_Standard 5_Pct                     34
# 562  Does Not Meet Expected Growth_TCHR_Standard 6_Pct                     34
# 563        Exceeds Expected Growth_TCHR_Standard 6_Pct                     34
# 564          Meets Expected Growth_TCHR_Standard 6_Pct                     34
# 565                Not Demostrated_TCHR_Standard 1_Pct                     34
# 566                Not Demostrated_TCHR_Standard 2_Pct                     34
# 567                Not Demostrated_TCHR_Standard 3_Pct                     34
# 568                Not Demostrated_TCHR_Standard 4_Pct                     34
# 569                Not Demostrated_TCHR_Standard 5_Pct                     34
# 570                     Proficient_TCHR_Standard 1_Pct                     34
# 571                     Proficient_TCHR_Standard 2_Pct                     34
# 572                     Proficient_TCHR_Standard 3_Pct                     34
# 573                     Proficient_TCHR_Standard 4_Pct                     34
# 574                     Proficient_TCHR_Standard 5_Pct                     34

# %%
#Replace all remaining NaN with 0
schoolData = schoolData.fillna(0)

#Check for Missing values after final imputation 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# Empty DataFrame
# Columns: [Variable Name, Number Missing Values]
# Index: []

# %% [markdown]
# ## Identify and Remove Highly Correlated Features
# **Find and remove any columns / features that are > 95% correlated**
# * https://stackoverflow.com/questions/39409866/correlation-heatmap
# * https://chrisalbon.com/machine_learning/feature_selection/drop_highly_correlated_features/
# * https://codeyarns.com/2015/04/20/how-to-change-font-size-in-seaborn/

# %%
# calculate the correlation matrix
corr_matrix  = schoolData.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
#Get all of the correlation values > 95%
x = np.where(upper > 0.95)

#Display all field combinations with > 95% correlation
cf = pd.DataFrame()
cf['Field1'] = upper.columns[x[1]]
cf['Field2'] = upper.index[x[0]]

#Get the correlation values for every field combination. (There must be a more pythonic way to do this!)
corr = [0] * len(cf)
for i in range(0, len(cf)):
    corr[i] =  upper[cf['Field1'][i]][cf['Field2'][i]] 
    
cf['Correlation'] = corr

print 'There are ', str(len(cf['Field1'])), ' field correlations > 95%.'
cf
# Out:
# There are  1074  field correlations > 95%.
#                                                  Field1  \
# 0                                       class_teach_num
# 1                                   lea_class_teach_num
# 2                                    st_class_teach_num
# 3                                          st_nbpts_num
# 4                                    st_advance_dgr_pct
# 5                             Overall Achievement Score
# 6                                        Math SPG Score
# 7                                            Read Score
# 8                                            Math Score
# 9                                  EOGMathGr3-8_GLP_All
# 10                             EOGReadingGr3-8_CACR_All
# 11                              EOGReadingGr3-8_GLP_All
# 12                                 EOGSubjects_CACR_All
# 13                                  EOGSubjects_GLP_All
# 14                          EOGReadingGr3-8_CACR_Female
# 15                           EOGReadingGr3-8_GLP_Female
# 16                              EOGSubjects_CACR_Female
# 17                               EOGSubjects_GLP_Female
# 18                             EOGReadingGr3-8_GLP_Male
# 19                                EOGSubjects_CACR_Male
# 20                                 EOGSubjects_GLP_Male
# 21                                           Read Score
# 22                                           Math Score
# 23                                EOGMathGr3-8_CACR_All
# 24                                 EOGMathGr3-8_GLP_All
# 25                              EOGReadingGr3-8_GLP_All
# 26                                 EOGSubjects_CACR_All
# 27                                  EOGSubjects_GLP_All
# 28                             EOGMathGr3-8_CACR_Female
# 29                              EOGMathGr3-8_GLP_Female
# 30                           EOGReadingGr3-8_GLP_Female
# 31                              EOGSubjects_CACR_Female
# 32                               EOGSubjects_GLP_Female
# 33                               EOGMathGr3-8_CACR_Male
# 34                                EOGMathGr3-8_GLP_Male
# 35                                EOGSubjects_CACR_Male
# 36                                 EOGSubjects_GLP_Male
# 37                                           Math Score
# 38                                EOGMathGr3-8_CACR_All
# 39                                 EOGMathGr3-8_GLP_All
# 40                             EOGReadingGr3-8_CACR_All
# 41                              EOGReadingGr3-8_GLP_All
# 42                                 EOGSubjects_CACR_All
# 43                                  EOGSubjects_GLP_All
# 44                              EOGMathGr3-8_GLP_Female
# 45                          EOGReadingGr3-8_CACR_Female
# 46                           EOGReadingGr3-8_GLP_Female
# 47                              EOGSubjects_CACR_Female
# 48                               EOGSubjects_GLP_Female
# 49                                EOGMathGr3-8_GLP_Male
# 50                            EOGReadingGr3-8_CACR_Male
# 51                             EOGReadingGr3-8_GLP_Male
# 52                                EOGSubjects_CACR_Male
# 53                                 EOGSubjects_GLP_Male
# 54                                EOGMathGr3-8_CACR_All
# 55                                 EOGMathGr3-8_GLP_All
# 56                                 EOGSubjects_CACR_All
# 57                                  EOGSubjects_GLP_All
# 58                             EOGMathGr3-8_CACR_Female
# 59                              EOGMathGr3-8_GLP_Female
# 60                              EOGSubjects_CACR_Female
# 61                               EOGSubjects_GLP_Female
# 62                               EOGMathGr3-8_CACR_Male
# 63                                EOGMathGr3-8_GLP_Male
# 64                                EOGSubjects_CACR_Male
# 65                                 EOGSubjects_GLP_Male
# 66                                 EOGMathGr3-8_GLP_EDS
# 67                             EOGScienceGr5&8_CACR_All
# 68                              EOGScienceGr5&8_GLP_All
# 69                          EOGScienceGr5&8_CACR_Female
# 70                           EOGScienceGr5&8_GLP_Female
# 71                            EOGScienceGr5&8_CACR_Male
# 72                             EOGScienceGr5&8_GLP_Male
# 73                                    EOCMathI_CACR_All
# 74                                     EOCMathI_GLP_All
# 75                                 EOCSubjects_CACR_All
# 76                                  EOCSubjects_GLP_All
# 77                                 EOCMathI_CACR_Female
# 78                                  EOCMathI_GLP_Female
# 79                              EOCSubjects_CACR_Female
# 80                               EOCSubjects_GLP_Female
# 81                                    EOCMathI_GLP_Male
# 82                                 EOCSubjects_GLP_Male
# 83                                     EOCMathI_GLP_All
# 84                                 EOCSubjects_CACR_All
# 85                                  EOCSubjects_GLP_All
# 86                                 EOCMathI_CACR_Female
# 87                                  EOCMathI_GLP_Female
# 88                              EOCSubjects_CACR_Female
# 89                               EOCSubjects_GLP_Female
# 90                                   EOCMathI_CACR_Male
# 91                                EOCSubjects_CACR_Male
# 92                                 EOCSubjects_CACR_All
# 93                                  EOCSubjects_GLP_All
# 94                                 EOCMathI_CACR_Female
# 95                                  EOCMathI_GLP_Female
# 96                              EOCSubjects_CACR_Female
# 97                               EOCSubjects_GLP_Female
# 98                                    EOCMathI_GLP_Male
# 99                                EOCSubjects_CACR_Male
# 100                                EOCSubjects_GLP_Male
# 101                                 EOCSubjects_GLP_All
# 102                                EOCMathI_CACR_Female
# 103                                 EOCMathI_GLP_Female
# 104                             EOCSubjects_CACR_Female
# 105                              EOCSubjects_GLP_Female
# 106                                  EOCMathI_CACR_Male
# 107                               EOCSubjects_CACR_Male
# 108                                EOCSubjects_GLP_Male
# 109                                EOCMathI_CACR_Female
# 110                                 EOCMathI_GLP_Female
# 111                             EOCSubjects_CACR_Female
# 112                              EOCSubjects_GLP_Female
# 113                                   EOCMathI_GLP_Male
# 114                               EOCSubjects_CACR_Male
# 115                                EOCSubjects_GLP_Male
# 116                             EOG/EOCSubjects_GLP_All
# 117                         EOG/EOCSubjects_CACR_Female
# 118                          EOG/EOCSubjects_GLP_Female
# 119                           EOG/EOCSubjects_CACR_Male
# 120                            EOG/EOCSubjects_GLP_Male
# 121                         EOG/EOCSubjects_CACR_Female
# 122                          EOG/EOCSubjects_GLP_Female
# 123                           EOG/EOCSubjects_CACR_Male
# 124                            EOG/EOCSubjects_GLP_Male
# 125                                      EOGGr3_GLP_All
# 126                                 EOGMathGr3_CACR_All
# 127                                  EOGMathGr3_GLP_All
# 128                              EOGReadingGr3_CACR_All
# 129                               EOGReadingGr3_GLP_All
# 130                                  EOGGr3_CACR_Female
# 131                                   EOGGr3_GLP_Female
# 132                              EOGMathGr3_CACR_Female
# 133                               EOGMathGr3_GLP_Female
# 134                           EOGReadingGr3_CACR_Female
# 135                            EOGReadingGr3_GLP_Female
# 136                                    EOGGr3_CACR_Male
# 137                                     EOGGr3_GLP_Male
# 138                                EOGMathGr3_CACR_Male
# 139                                 EOGMathGr3_GLP_Male
# 140                             EOGReadingGr3_CACR_Male
# 141                              EOGReadingGr3_GLP_Male
# 142                                   EOGGr3_CACR_White
# 143                                      pct_PASSED_EOG
# 144                                 EOGMathGr3_CACR_All
# 145                                  EOGMathGr3_GLP_All
# 146                              EOGReadingGr3_CACR_All
# 147                               EOGReadingGr3_GLP_All
# 148                                  EOGGr3_CACR_Female
# 149                                   EOGGr3_GLP_Female
# 150                              EOGMathGr3_CACR_Female
# 151                               EOGMathGr3_GLP_Female
# 152                           EOGReadingGr3_CACR_Female
# 153                            EOGReadingGr3_GLP_Female
# 154                                    EOGGr3_CACR_Male
# 155                                     EOGGr3_GLP_Male
# 156                                EOGMathGr3_CACR_Male
# 157                                 EOGMathGr3_GLP_Male
# 158                             EOGReadingGr3_CACR_Male
# 159                              EOGReadingGr3_GLP_Male
# 160                                    EOGGr3_GLP_White
# 161                                     EOGGr3_CACR_EDS
# 162                                      EOGGr3_GLP_EDS
# 163                               EOGReadingGr3_GLP_EDS
# 164                                      pct_PASSED_EOG
# 165                                        pct_PROMOTED
# 166                                      EOGGr4_GLP_All
# 167                                 EOGMathGr4_CACR_All
# 168                                  EOGMathGr4_GLP_All
# 169                              EOGReadingGr4_CACR_All
# 170                               EOGReadingGr4_GLP_All
# 171                                  EOGGr4_CACR_Female
# 172                                   EOGGr4_GLP_Female
# 173                              EOGMathGr4_CACR_Female
# 174                               EOGMathGr4_GLP_Female
# 175                           EOGReadingGr4_CACR_Female
# 176                            EOGReadingGr4_GLP_Female
# 177                                    EOGGr4_CACR_Male
# 178                                     EOGGr4_GLP_Male
# 179                                EOGMathGr4_CACR_Male
# 180                                 EOGMathGr4_GLP_Male
# 181                             EOGReadingGr4_CACR_Male
# 182                              EOGReadingGr4_GLP_Male
# 183                                      EOGGr4_GLP_EDS
# 184                                 EOGMathGr4_CACR_All
# 185                                  EOGMathGr4_GLP_All
# 186                              EOGReadingGr4_CACR_All
# 187                               EOGReadingGr4_GLP_All
# 188                                  EOGGr4_CACR_Female
# 189                                   EOGGr4_GLP_Female
# 190                              EOGMathGr4_CACR_Female
# 191                               EOGMathGr4_GLP_Female
# 192                           EOGReadingGr4_CACR_Female
# 193                            EOGReadingGr4_GLP_Female
# 194                                    EOGGr4_CACR_Male
# 195                                     EOGGr4_GLP_Male
# 196                                EOGMathGr4_CACR_Male
# 197                                 EOGMathGr4_GLP_Male
# 198                             EOGReadingGr4_CACR_Male
# 199                              EOGReadingGr4_GLP_Male
# 200                                     EOGGr4_CACR_EDS
# 201                                      EOGGr4_GLP_EDS
# 202                               EOGReadingGr4_GLP_EDS
# 203                                      EOGGr5_GLP_All
# 204                                 EOGMathGr5_CACR_All
# 205                                  EOGMathGr5_GLP_All
# 206                              EOGReadingGr5_CACR_All
# 207                               EOGReadingGr5_GLP_All
# 208                              EOGScienceGr5_CACR_All
# 209                               EOGScienceGr5_GLP_All
# 210                                  EOGGr5_CACR_Female
# 211                                   EOGGr5_GLP_Female
# 212                              EOGMathGr5_CACR_Female
# 213                               EOGMathGr5_GLP_Female
# 214                           EOGReadingGr5_CACR_Female
# 215                            EOGReadingGr5_GLP_Female
# 216                           EOGScienceGr5_CACR_Female
# 217                            EOGScienceGr5_GLP_Female
# 218                                    EOGGr5_CACR_Male
# 219                                     EOGGr5_GLP_Male
# 220                                EOGMathGr5_CACR_Male
# 221                                 EOGMathGr5_GLP_Male
# 222                             EOGReadingGr5_CACR_Male
# 223                              EOGReadingGr5_GLP_Male
# 224                             EOGScienceGr5_CACR_Male
# 225                              EOGScienceGr5_GLP_Male
# 226                                 EOGMathGr5_CACR_All
# 227                                  EOGMathGr5_GLP_All
# 228                              EOGReadingGr5_CACR_All
# 229                               EOGReadingGr5_GLP_All
# 230                              EOGScienceGr5_CACR_All
# 231                               EOGScienceGr5_GLP_All
# 232                                  EOGGr5_CACR_Female
# 233                                   EOGGr5_GLP_Female
# 234                              EOGMathGr5_CACR_Female
# 235                               EOGMathGr5_GLP_Female
# 236                            EOGReadingGr5_GLP_Female
# 237                            EOGScienceGr5_GLP_Female
# 238                                    EOGGr5_CACR_Male
# 239                                     EOGGr5_GLP_Male
# 240                                EOGMathGr5_CACR_Male
# 241                                 EOGMathGr5_GLP_Male
# 242                              EOGReadingGr5_GLP_Male
# 243                             EOGScienceGr5_CACR_Male
# 244                              EOGScienceGr5_GLP_Male
# 245                                      EOGGr5_GLP_EDS
# 246                                  EOGMathGr3_GLP_All
# 247                              EOGReadingGr3_CACR_All
# 248                               EOGReadingGr3_GLP_All
# 249                                  EOGGr3_CACR_Female
# 250                                   EOGGr3_GLP_Female
# 251                              EOGMathGr3_CACR_Female
# 252                               EOGMathGr3_GLP_Female
# 253                                    EOGGr3_CACR_Male
# 254                                     EOGGr3_GLP_Male
# 255                                EOGMathGr3_CACR_Male
# 256                                 EOGMathGr3_GLP_Male
# 257                              EOGReadingGr3_GLP_Male
# 258                                      pct_PASSED_EOG
# 259                              EOGReadingGr3_CACR_All
# 260                               EOGReadingGr3_GLP_All
# 261                                  EOGGr3_CACR_Female
# 262                                   EOGGr3_GLP_Female
# 263                              EOGMathGr3_CACR_Female
# 264                               EOGMathGr3_GLP_Female
# 265                            EOGReadingGr3_GLP_Female
# 266                                    EOGGr3_CACR_Male
# 267                                     EOGGr3_GLP_Male
# 268                                EOGMathGr3_CACR_Male
# 269                                 EOGMathGr3_GLP_Male
# 270                              EOGReadingGr3_GLP_Male
# 271                                     EOGGr3_CACR_EDS
# 272                                      EOGGr3_GLP_EDS
# 273                                  EOGMathGr3_GLP_EDS
# 274                                      pct_PASSED_EOG
# 275                                EOGMathGr3-8_GLP_All
# 276                            EOGReadingGr3-8_CACR_All
# 277                                EOGSubjects_CACR_All
# 278                                 EOGSubjects_GLP_All
# 279                            EOGMathGr3-8_CACR_Female
# 280                             EOGMathGr3-8_GLP_Female
# 281                             EOGSubjects_CACR_Female
# 282                              EOGSubjects_GLP_Female
# 283                              EOGMathGr3-8_CACR_Male
# 284                               EOGMathGr3-8_GLP_Male
# 285                               EOGSubjects_CACR_Male
# 286                                EOGSubjects_GLP_Male
# 287                            EOGReadingGr3-8_CACR_All
# 288                             EOGReadingGr3-8_GLP_All
# 289                                EOGSubjects_CACR_All
# 290                                 EOGSubjects_GLP_All
# 291                            EOGMathGr3-8_CACR_Female
# 292                             EOGMathGr3-8_GLP_Female
# 293                          EOGReadingGr3-8_GLP_Female
# 294                             EOGSubjects_CACR_Female
# 295                              EOGSubjects_GLP_Female
# 296                              EOGMathGr3-8_CACR_Male
# 297                               EOGMathGr3-8_GLP_Male
# 298                            EOGReadingGr3-8_GLP_Male
# 299                               EOGSubjects_CACR_Male
# 300                                EOGSubjects_GLP_Male
# 301                                EOGMathGr3-8_GLP_EDS
# 302                                  EOGMathGr4_GLP_All
# 303                              EOGReadingGr4_CACR_All
# 304                               EOGReadingGr4_GLP_All
# 305                                  EOGGr4_CACR_Female
# 306                                   EOGGr4_GLP_Female
# 307                              EOGMathGr4_CACR_Female
# 308                               EOGMathGr4_GLP_Female
# 309                           EOGReadingGr4_CACR_Female
# 310                                    EOGGr4_CACR_Male
# 311                                     EOGGr4_GLP_Male
# 312                                EOGMathGr4_CACR_Male
# 313                                 EOGMathGr4_GLP_Male
# 314                             EOGReadingGr4_CACR_Male
# 315                              EOGReadingGr4_GLP_Male
# 316                              EOGReadingGr4_CACR_All
# 317                               EOGReadingGr4_GLP_All
# 318                                  EOGGr4_CACR_Female
# 319                                   EOGGr4_GLP_Female
# 320                              EOGMathGr4_CACR_Female
# 321                               EOGMathGr4_GLP_Female
# 322                           EOGReadingGr4_CACR_Female
# 323                            EOGReadingGr4_GLP_Female
# 324                                    EOGGr4_CACR_Male
# 325                                     EOGGr4_GLP_Male
# 326                                EOGMathGr4_CACR_Male
# 327                                 EOGMathGr4_GLP_Male
# 328                             EOGReadingGr4_CACR_Male
# 329                              EOGReadingGr4_GLP_Male
# 330                                      EOGGr4_GLP_EDS
# 331                                  EOGMathGr4_GLP_EDS
# 332                                  EOGMathGr5_GLP_All
# 333                              EOGReadingGr5_CACR_All
# 334                               EOGReadingGr5_GLP_All
# 335                              EOGScienceGr5_CACR_All
# 336                               EOGScienceGr5_GLP_All
# 337                                  EOGGr5_CACR_Female
# 338                                   EOGGr5_GLP_Female
# 339                              EOGMathGr5_CACR_Female
# 340                               EOGMathGr5_GLP_Female
# 341                                    EOGGr5_CACR_Male
# 342                                     EOGGr5_GLP_Male
# 343                                EOGMathGr5_CACR_Male
# 344                                 EOGMathGr5_GLP_Male
# 345                              EOGReadingGr5_CACR_All
# 346                               EOGReadingGr5_GLP_All
# 347                              EOGScienceGr5_CACR_All
# 348                               EOGScienceGr5_GLP_All
# 349                                  EOGGr5_CACR_Female
# 350                                   EOGGr5_GLP_Female
# 351                              EOGMathGr5_CACR_Female
# 352                               EOGMathGr5_GLP_Female
# 353                            EOGScienceGr5_GLP_Female
# 354                                    EOGGr5_CACR_Male
# 355                                     EOGGr5_GLP_Male
# 356                                EOGMathGr5_CACR_Male
# 357                                 EOGMathGr5_GLP_Male
# 358                              EOGScienceGr5_GLP_Male
# 359                               EOGReadingGr3_GLP_All
# 360                                  EOGGr3_CACR_Female
# 361                                   EOGGr3_GLP_Female
# 362                           EOGReadingGr3_CACR_Female
# 363                            EOGReadingGr3_GLP_Female
# 364                                    EOGGr3_CACR_Male
# 365                                     EOGGr3_GLP_Male
# 366                                 EOGMathGr3_GLP_Male
# 367                             EOGReadingGr3_CACR_Male
# 368                              EOGReadingGr3_GLP_Male
# 369                                      pct_PASSED_EOG
# 370                                  EOGGr3_CACR_Female
# 371                                   EOGGr3_GLP_Female
# 372                               EOGMathGr3_GLP_Female
# 373                           EOGReadingGr3_CACR_Female
# 374                            EOGReadingGr3_GLP_Female
# 375                                    EOGGr3_CACR_Male
# 376                                     EOGGr3_GLP_Male
# 377                                 EOGMathGr3_GLP_Male
# 378                             EOGReadingGr3_CACR_Male
# 379                              EOGReadingGr3_GLP_Male
# 380                                      EOGGr3_GLP_EDS
# 381                               EOGReadingGr3_GLP_EDS
# 382                                      pct_PASSED_EOG
# 383                                        pct_PROMOTED
# 384                             EOGReadingGr3-8_GLP_All
# 385                                EOGSubjects_CACR_All
# 386                                 EOGSubjects_GLP_All
# 387                         EOGReadingGr3-8_CACR_Female
# 388                          EOGReadingGr3-8_GLP_Female
# 389                             EOGSubjects_CACR_Female
# 390                              EOGSubjects_GLP_Female
# 391                           EOGReadingGr3-8_CACR_Male
# 392                            EOGReadingGr3-8_GLP_Male
# 393                               EOGSubjects_CACR_Male
# 394                                EOGSubjects_GLP_Male
# 395                                EOGSubjects_CACR_All
# 396                                 EOGSubjects_GLP_All
# 397                         EOGReadingGr3-8_CACR_Female
# 398                          EOGReadingGr3-8_GLP_Female
# 399                             EOGSubjects_CACR_Female
# 400                              EOGSubjects_GLP_Female
# 401                               EOGMathGr3-8_GLP_Male
# 402                           EOGReadingGr3-8_CACR_Male
# 403                            EOGReadingGr3-8_GLP_Male
# 404                               EOGSubjects_CACR_Male
# 405                                EOGSubjects_GLP_Male
# 406                             EOGReadingGr3-8_GLP_EDS
# 407                               EOGReadingGr4_GLP_All
# 408                                  EOGGr4_CACR_Female
# 409                                   EOGGr4_GLP_Female
# 410                               EOGMathGr4_GLP_Female
# 411                           EOGReadingGr4_CACR_Female
# 412                            EOGReadingGr4_GLP_Female
# 413                                    EOGGr4_CACR_Male
# 414                                     EOGGr4_GLP_Male
# 415                                EOGMathGr4_CACR_Male
# 416                                 EOGMathGr4_GLP_Male
# 417                             EOGReadingGr4_CACR_Male
# 418                              EOGReadingGr4_GLP_Male
# 419                                  EOGGr4_CACR_Female
# 420                                   EOGGr4_GLP_Female
# 421                               EOGMathGr4_GLP_Female
# 422                           EOGReadingGr4_CACR_Female
# 423                            EOGReadingGr4_GLP_Female
# 424                                    EOGGr4_CACR_Male
# 425                                     EOGGr4_GLP_Male
# 426                                EOGMathGr4_CACR_Male
# 427                                 EOGMathGr4_GLP_Male
# 428                             EOGReadingGr4_CACR_Male
# 429                              EOGReadingGr4_GLP_Male
# 430                                      EOGGr4_GLP_EDS
# 431                               EOGReadingGr4_GLP_EDS
# 432                               EOGReadingGr5_GLP_All
# 433                                  EOGGr5_CACR_Female
# 434                                   EOGGr5_GLP_Female
# 435                           EOGReadingGr5_CACR_Female
# 436                            EOGReadingGr5_GLP_Female
# 437                                    EOGGr5_CACR_Male
# 438                                     EOGGr5_GLP_Male
# 439                             EOGReadingGr5_CACR_Male
# 440                              EOGReadingGr5_GLP_Male
# 441                              EOGScienceGr5_CACR_All
# 442                               EOGScienceGr5_GLP_All
# 443                                  EOGGr5_CACR_Female
# 444                                   EOGGr5_GLP_Female
# 445                           EOGReadingGr5_CACR_Female
# 446                            EOGReadingGr5_GLP_Female
# 447                                    EOGGr5_CACR_Male
# 448                                     EOGGr5_GLP_Male
# 449                             EOGReadingGr5_CACR_Male
# 450                              EOGReadingGr5_GLP_Male
# 451                               EOGScienceGr5_GLP_All
# 452                                  EOGGr5_CACR_Female
# 453                                   EOGGr5_GLP_Female
# 454                           EOGScienceGr5_CACR_Female
# 455                            EOGScienceGr5_GLP_Female
# 456                                    EOGGr5_CACR_Male
# 457                                     EOGGr5_GLP_Male
# 458                             EOGScienceGr5_CACR_Male
# 459                              EOGScienceGr5_GLP_Male
# 460                                  EOGGr5_CACR_Female
# 461                                   EOGGr5_GLP_Female
# 462                               EOGMathGr5_GLP_Female
# 463                           EOGScienceGr5_CACR_Female
# 464                            EOGScienceGr5_GLP_Female
# 465                                    EOGGr5_CACR_Male
# 466                                     EOGGr5_GLP_Male
# 467                             EOGScienceGr5_CACR_Male
# 468                              EOGScienceGr5_GLP_Male
# 469                                      EOGGr5_GLP_EDS
# 470                               EOGScienceGr5_GLP_EDS
# 471                             EOGScienceGr5&8_GLP_All
# 472                         EOGScienceGr5&8_CACR_Female
# 473                          EOGScienceGr5&8_GLP_Female
# 474                           EOGScienceGr5&8_CACR_Male
# 475                            EOGScienceGr5&8_GLP_Male
# 476                         EOGScienceGr5&8_CACR_Female
# 477                          EOGScienceGr5&8_GLP_Female
# 478                           EOGScienceGr5&8_CACR_Male
# 479                            EOGScienceGr5&8_GLP_Male
# 480                             EOGScienceGr5&8_GLP_EDS
# 481                                 EOGSubjects_GLP_All
# 482                            EOGMathGr3-8_CACR_Female
# 483                             EOGMathGr3-8_GLP_Female
# 484                         EOGReadingGr3-8_CACR_Female
# 485                          EOGReadingGr3-8_GLP_Female
# 486                             EOGSubjects_CACR_Female
# 487                              EOGSubjects_GLP_Female
# 488                              EOGMathGr3-8_CACR_Male
# 489                               EOGMathGr3-8_GLP_Male
# 490                           EOGReadingGr3-8_CACR_Male
# 491                            EOGReadingGr3-8_GLP_Male
# 492                               EOGSubjects_CACR_Male
# 493                                EOGSubjects_GLP_Male
# 494                            EOGMathGr3-8_CACR_Female
# 495                             EOGMathGr3-8_GLP_Female
# 496                         EOGReadingGr3-8_CACR_Female
# 497                          EOGReadingGr3-8_GLP_Female
# 498                             EOGSubjects_CACR_Female
# 499                              EOGSubjects_GLP_Female
# ...                                                 ...
# 574                                     EOGGr3_GLP_Male
# 575                                 EOGMathGr3_GLP_Male
# 576                                      pct_PASSED_EOG
# 577                             EOGMathGr3-8_GLP_Female
# 578                             EOGSubjects_CACR_Female
# 579                              EOGSubjects_GLP_Female
# 580                              EOGMathGr3-8_CACR_Male
# 581                               EOGMathGr3-8_GLP_Male
# 582                               EOGSubjects_CACR_Male
# 583                                EOGSubjects_GLP_Male
# 584                          EOGReadingGr3-8_GLP_Female
# 585                             EOGSubjects_CACR_Female
# 586                              EOGSubjects_GLP_Female
# 587                              EOGMathGr3-8_CACR_Male
# 588                               EOGMathGr3-8_GLP_Male
# 589                               EOGSubjects_CACR_Male
# 590                                EOGSubjects_GLP_Male
# 591                                EOGMathGr3-8_GLP_EDS
# 592                               EOGMathGr4_GLP_Female
# 593                           EOGReadingGr4_CACR_Female
# 594                           EOGReadingGr4_CACR_Female
# 595                            EOGReadingGr4_GLP_Female
# 596                                     EOGGr4_GLP_Male
# 597                                 EOGMathGr4_GLP_Male
# 598                               EOGMathGr5_GLP_Female
# 599                            EOGReadingGr5_GLP_Female
# 600                            EOGScienceGr5_GLP_Female
# 601                            EOGReadingGr5_GLP_Female
# 602                            EOGScienceGr5_GLP_Female
# 603                            EOGReadingGr3_GLP_Female
# 604                                      pct_PASSED_EOG
# 605                                     EOGGr3_GLP_Male
# 606                                      pct_PASSED_EOG
# 607                          EOGReadingGr3-8_GLP_Female
# 608                             EOGSubjects_CACR_Female
# 609                              EOGSubjects_GLP_Female
# 610                           EOGReadingGr3-8_CACR_Male
# 611                            EOGReadingGr3-8_GLP_Male
# 612                               EOGSubjects_CACR_Male
# 613                                EOGSubjects_GLP_Male
# 614                             EOGSubjects_CACR_Female
# 615                              EOGSubjects_GLP_Female
# 616                           EOGReadingGr3-8_CACR_Male
# 617                            EOGReadingGr3-8_GLP_Male
# 618                               EOGSubjects_CACR_Male
# 619                                EOGSubjects_GLP_Male
# 620                            EOGReadingGr4_GLP_Female
# 621                                     EOGGr4_GLP_Male
# 622                              EOGReadingGr4_GLP_Male
# 623                               EOGReadingGr4_GLP_EDS
# 624                            EOGReadingGr5_GLP_Female
# 625                            EOGScienceGr5_GLP_Female
# 626                            EOGScienceGr5_GLP_Female
# 627                              EOGScienceGr5_GLP_Male
# 628                          EOGScienceGr5&8_GLP_Female
# 629                              EOGSubjects_GLP_Female
# 630                              EOGMathGr3-8_CACR_Male
# 631                               EOGMathGr3-8_GLP_Male
# 632                           EOGReadingGr3-8_CACR_Male
# 633                            EOGReadingGr3-8_GLP_Male
# 634                               EOGSubjects_CACR_Male
# 635                                EOGSubjects_GLP_Male
# 636                               EOGMathGr3-8_GLP_Male
# 637                            EOGReadingGr3-8_GLP_Male
# 638                               EOGSubjects_CACR_Male
# 639                                EOGSubjects_GLP_Male
# 640                                 EOGSubjects_GLP_EDS
# 641                                   EOCMathI_GLP_Male
# 642                               EOCSubjects_CACR_Male
# 643                                EOCSubjects_GLP_Male
# 644                               EOCSubjects_CACR_Male
# 645                                EOCSubjects_GLP_Male
# 646                                EOCSubjects_GLP_Male
# 647                            EOG/EOCSubjects_GLP_Male
# 648                                     EOGGr3_GLP_Male
# 649                                EOGMathGr3_CACR_Male
# 650                                 EOGMathGr3_GLP_Male
# 651                             EOGReadingGr3_CACR_Male
# 652                              EOGReadingGr3_GLP_Male
# 653                                      pct_PASSED_EOG
# 654                                EOGMathGr3_CACR_Male
# 655                                 EOGMathGr3_GLP_Male
# 656                             EOGReadingGr3_CACR_Male
# 657                              EOGReadingGr3_GLP_Male
# 658                                      EOGGr3_GLP_EDS
# 659                                      pct_PASSED_EOG
# 660                                     EOGGr4_GLP_Male
# 661                                EOGMathGr4_CACR_Male
# 662                                 EOGMathGr4_GLP_Male
# 663                             EOGReadingGr4_CACR_Male
# 664                              EOGReadingGr4_GLP_Male
# 665                                EOGMathGr4_CACR_Male
# 666                                 EOGMathGr4_GLP_Male
# 667                             EOGReadingGr4_CACR_Male
# 668                              EOGReadingGr4_GLP_Male
# 669                                      EOGGr4_GLP_EDS
# 670                                     EOGGr5_GLP_Male
# 671                                EOGMathGr5_CACR_Male
# 672                                 EOGMathGr5_GLP_Male
# 673                             EOGReadingGr5_CACR_Male
# 674                              EOGReadingGr5_GLP_Male
# 675                             EOGScienceGr5_CACR_Male
# 676                              EOGScienceGr5_GLP_Male
# 677                                EOGMathGr5_CACR_Male
# 678                                 EOGMathGr5_GLP_Male
# 679                             EOGReadingGr5_CACR_Male
# 680                              EOGReadingGr5_GLP_Male
# 681                             EOGScienceGr5_CACR_Male
# 682                              EOGScienceGr5_GLP_Male
# 683                                 EOGMathGr3_GLP_Male
# 684                             EOGReadingGr3_CACR_Male
# 685                              EOGReadingGr3_GLP_Male
# 686                             EOGReadingGr3_CACR_Male
# 687                              EOGReadingGr3_GLP_Male
# 688                                      EOGGr3_GLP_EDS
# 689                                      pct_PASSED_EOG
# 690                               EOGMathGr3-8_GLP_Male
# 691                               EOGSubjects_CACR_Male
# 692                                EOGSubjects_GLP_Male
# 693                            EOGReadingGr3-8_GLP_Male
# 694                               EOGSubjects_CACR_Male
# 695                                EOGSubjects_GLP_Male
# 696                                 EOGMathGr4_GLP_Male
# 697                             EOGReadingGr4_CACR_Male
# 698                              EOGReadingGr4_GLP_Male
# 699                             EOGReadingGr4_CACR_Male
# 700                              EOGReadingGr4_GLP_Male
# 701                                 EOGMathGr5_GLP_Male
# 702                              EOGReadingGr5_GLP_Male
# 703                              EOGReadingGr5_GLP_Male
# 704                             EOGScienceGr5_CACR_Male
# 705                              EOGScienceGr5_GLP_Male
# 706                              EOGReadingGr3_GLP_Male
# 707                                      pct_PASSED_EOG
# 708                                      pct_PASSED_EOG
# 709                            EOGReadingGr3-8_GLP_Male
# 710                               EOGSubjects_CACR_Male
# 711                                EOGSubjects_GLP_Male
# 712                               EOGSubjects_CACR_Male
# 713                                EOGSubjects_GLP_Male
# 714                              EOGReadingGr4_GLP_Male
# 715                              EOGReadingGr5_GLP_Male
# 716                              EOGScienceGr5_GLP_Male
# 717                              EOGScienceGr5_GLP_Male
# 718                               EOGScienceGr5_GLP_EDS
# 719                            EOGScienceGr5&8_GLP_Male
# 720                                EOGSubjects_GLP_Male
# 721                                 EOGSubjects_GLP_EDS
# 722                         EOCMathI_GLP_AmericanIndian
# 723                      EOCSubjects_GLP_AmericanIndian
# 724                  EOG/EOCSubjects_GLP_AmericanIndian
# 725                           EOGGr3_GLP_AmericanIndian
# 726                           EOGGr4_GLP_AmericanIndian
# 727                           EOGGr5_GLP_AmericanIndian
# 728                       EOGMathGr3_GLP_AmericanIndian
# 729                     EOGMathGr3-8_GLP_AmericanIndian
# 730                       EOGMathGr4_GLP_AmericanIndian
# 731                   EOGReadingGr4_CACR_AmericanIndian
# 732                   EOGReadingGr4_CACR_AmericanIndian
# 733                    EOGReadingGr4_GLP_AmericanIndian
# 734                       EOGMathGr5_GLP_AmericanIndian
# 735                    EOGReadingGr3_GLP_AmericanIndian
# 736                  EOGReadingGr3-8_GLP_AmericanIndian
# 737                    EOGReadingGr4_GLP_AmericanIndian
# 738                    EOGScienceGr5_GLP_AmericanIndian
# 739                  EOGScienceGr5&8_GLP_AmericanIndian
# 740                      EOGSubjects_GLP_AmericanIndian
# 741                                  EOCMathI_GLP_Asian
# 742                               EOCSubjects_GLP_Asian
# 743                           EOG/EOCSubjects_GLP_Asian
# 744                                    EOGGr3_GLP_Asian
# 745                                    EOGGr4_GLP_Asian
# 746                                    EOGGr5_GLP_Asian
# 747                                EOGMathGr3_GLP_Asian
# 748                            EOGReadingGr3_CACR_Asian
# 749                             EOGReadingGr3_GLP_Asian
# 750                            EOGReadingGr3_CACR_Asian
# 751                             EOGReadingGr3_GLP_Asian
# 752                              EOGMathGr3-8_GLP_Asian
# 753                          EOGReadingGr3-8_CACR_Asian
# 754                           EOGReadingGr3-8_GLP_Asian
# 755                          EOGReadingGr3-8_CACR_Asian
# 756                           EOGReadingGr3-8_GLP_Asian
# 757                                EOGMathGr4_GLP_Asian
# 758                            EOGReadingGr4_CACR_Asian
# 759                             EOGReadingGr4_GLP_Asian
# 760                            EOGReadingGr4_CACR_Asian
# 761                             EOGReadingGr4_GLP_Asian
# 762                                EOGMathGr5_GLP_Asian
# 763                            EOGReadingGr5_CACR_Asian
# 764                             EOGReadingGr5_GLP_Asian
# 765                            EOGScienceGr5_CACR_Asian
# 766                             EOGScienceGr5_GLP_Asian
# 767                            EOGReadingGr5_CACR_Asian
# 768                             EOGReadingGr5_GLP_Asian
# 769                            EOGScienceGr5_CACR_Asian
# 770                             EOGScienceGr5_GLP_Asian
# 771                             EOGReadingGr3_GLP_Asian
# 772                           EOGReadingGr3-8_GLP_Asian
# 773                             EOGReadingGr4_GLP_Asian
# 774                             EOGReadingGr5_GLP_Asian
# 775                            EOGScienceGr5_CACR_Asian
# 776                             EOGScienceGr5_GLP_Asian
# 777                            EOGScienceGr5_CACR_Asian
# 778                             EOGScienceGr5_GLP_Asian
# 779                             EOGScienceGr5_GLP_Asian
# 780                           EOGScienceGr5&8_GLP_Asian
# 781                               EOGSubjects_GLP_Asian
# 782                                  EOCMathI_GLP_Black
# 783                              EOCSubjects_CACR_Black
# 784                              EOCSubjects_CACR_Black
# 785                               EOCSubjects_GLP_Black
# 786                               EOCSubjects_GLP_Black
# 787                           EOG/EOCSubjects_GLP_Black
# 788                                    EOGGr3_GLP_Black
# 789                                    EOGGr4_GLP_Black
# 790                                    EOGGr5_GLP_Black
# 791                                EOGMathGr3_GLP_Black
# 792                              EOGMathGr3-8_GLP_Black
# 793                                EOGMathGr4_GLP_Black
# 794                                EOGMathGr5_GLP_Black
# 795                             EOGReadingGr3_GLP_Black
# 796                           EOGReadingGr3-8_GLP_Black
# 797                             EOGReadingGr4_GLP_Black
# 798                             EOGReadingGr5_GLP_Black
# 799                             EOGScienceGr5_GLP_Black
# 800                           EOGScienceGr5&8_GLP_Black
# 801                               EOGSubjects_GLP_Black
# 802                               EOCMathI_GLP_Hispanic
# 803                           EOCSubjects_CACR_Hispanic
# 804                            EOCSubjects_GLP_Hispanic
# 805                            EOCSubjects_GLP_Hispanic
# 806                        EOG/EOCSubjects_GLP_Hispanic
# 807                                 EOGGr3_GLP_Hispanic
# 808                                 EOGGr4_GLP_Hispanic
# 809                                 EOGGr5_GLP_Hispanic
# 810                             EOGMathGr3_GLP_Hispanic
# 811                           EOGMathGr3-8_GLP_Hispanic
# 812                             EOGMathGr4_GLP_Hispanic
# 813                             EOGMathGr5_GLP_Hispanic
# 814                          EOGReadingGr3_GLP_Hispanic
# 815                        EOGReadingGr3-8_GLP_Hispanic
# 816                          EOGReadingGr4_GLP_Hispanic
# 817                          EOGScienceGr5_GLP_Hispanic
# 818                        EOGScienceGr5&8_GLP_Hispanic
# 819                            EOGSubjects_GLP_Hispanic
# 820                         EOCMathI_GLP_TwoorMoreRaces
# 821                      EOCSubjects_GLP_TwoorMoreRaces
# 822                  EOG/EOCSubjects_GLP_TwoorMoreRaces
# 823                           EOGGr3_GLP_TwoorMoreRaces
# 824                           EOGGr4_GLP_TwoorMoreRaces
# 825                           EOGGr5_GLP_TwoorMoreRaces
# 826                       EOGMathGr3_GLP_TwoorMoreRaces
# 827                    EOGReadingGr3_GLP_TwoorMoreRaces
# 828                     EOGMathGr3-8_GLP_TwoorMoreRaces
# 829                       EOGMathGr4_GLP_TwoorMoreRaces
# 830                       EOGMathGr5_GLP_TwoorMoreRaces
# 831                    EOGReadingGr3_GLP_TwoorMoreRaces
# 832                  EOGReadingGr3-8_GLP_TwoorMoreRaces
# 833                    EOGReadingGr4_GLP_TwoorMoreRaces
# 834                    EOGReadingGr5_GLP_TwoorMoreRaces
# 835                    EOGScienceGr5_GLP_TwoorMoreRaces
# 836                  EOGScienceGr5&8_GLP_TwoorMoreRaces
# 837                      EOGSubjects_GLP_TwoorMoreRaces
# 838                                  EOCMathI_GLP_White
# 839                              EOCSubjects_CACR_White
# 840                               EOCSubjects_GLP_White
# 841                              EOCSubjects_CACR_White
# 842                               EOCSubjects_GLP_White
# 843                               EOCSubjects_GLP_White
# 844                           EOG/EOCSubjects_GLP_White
# 845                                    EOGGr3_GLP_White
# 846                               EOGMathGr3_CACR_White
# 847                                EOGMathGr3_GLP_White
# 848                            EOGReadingGr3_CACR_White
# 849                             EOGReadingGr3_GLP_White
# 850                               EOGMathGr3_CACR_White
# 851                                EOGMathGr3_GLP_White
# 852                            EOGReadingGr3_CACR_White
# 853                             EOGReadingGr3_GLP_White
# 854                                    EOGGr4_GLP_White
# 855                               EOGMathGr4_CACR_White
# 856                                EOGMathGr4_GLP_White
# 857                            EOGReadingGr4_CACR_White
# 858                             EOGReadingGr4_GLP_White
# 859                               EOGMathGr4_CACR_White
# 860                                EOGMathGr4_GLP_White
# 861                            EOGReadingGr4_CACR_White
# 862                             EOGReadingGr4_GLP_White
# 863                                    EOGGr5_GLP_White
# 864                                EOGMathGr3_GLP_White
# 865                            EOGReadingGr3_CACR_White
# 866                             EOGReadingGr3_GLP_White
# 867                            EOGReadingGr3_CACR_White
# 868                             EOGReadingGr3_GLP_White
# 869                              EOGMathGr3-8_GLP_White
# 870                          EOGReadingGr3-8_CACR_White
# 871                              EOGSubjects_CACR_White
# 872                               EOGSubjects_GLP_White
# 873                          EOGReadingGr3-8_CACR_White
# 874                           EOGReadingGr3-8_GLP_White
# 875                              EOGSubjects_CACR_White
# 876                               EOGSubjects_GLP_White
# 877                                EOGMathGr4_GLP_White
# 878                            EOGReadingGr4_CACR_White
# 879                             EOGReadingGr4_GLP_White
# 880                            EOGReadingGr4_CACR_White
# 881                             EOGReadingGr4_GLP_White
# 882                                EOGMathGr5_GLP_White
# 883                            EOGReadingGr5_CACR_White
# ...
# 849                                   EOGGr3_CACR_White     0.961023
# 850                                    EOGGr3_GLP_White     0.955880
# 851                                    EOGGr3_GLP_White     0.970785
# 852                                    EOGGr3_GLP_White     0.959630
# 853                                    EOGGr3_GLP_White     0.970428
# 854                                   EOGGr4_CACR_White     0.991444
# 855                                   EOGGr4_CACR_White     0.975372
# 856                                   EOGGr4_CACR_White     0.972239
# 857                                   EOGGr4_CACR_White     0.974510
# 858                                   EOGGr4_CACR_White     0.966335
# 859                                    EOGGr4_GLP_White     0.963653
# 860                                    EOGGr4_GLP_White     0.972675
# 861                                    EOGGr4_GLP_White     0.965307
# 862                                    EOGGr4_GLP_White     0.972657
# 863                                   EOGGr5_CACR_White     0.992246
# 864                               EOGMathGr3_CACR_White     0.984080
# 865                               EOGMathGr3_CACR_White     0.964388
# 866                               EOGMathGr3_CACR_White     0.962446
# 867                                EOGMathGr3_GLP_White     0.968737
# 868                                EOGMathGr3_GLP_White     0.978223
# 869                             EOGMathGr3-8_CACR_White     0.988783
# 870                             EOGMathGr3-8_CACR_White     0.953945
# 871                             EOGMathGr3-8_CACR_White     0.968018
# 872                             EOGMathGr3-8_CACR_White     0.953738
# 873                              EOGMathGr3-8_GLP_White     0.958485
# 874                              EOGMathGr3-8_GLP_White     0.961454
# 875                              EOGMathGr3-8_GLP_White     0.965534
# 876                              EOGMathGr3-8_GLP_White     0.967456
# 877                               EOGMathGr4_CACR_White     0.990724
# 878                               EOGMathGr4_CACR_White     0.965733
# 879                               EOGMathGr4_CACR_White     0.963129
# 880                                EOGMathGr4_GLP_White     0.969992
# 881                                EOGMathGr4_GLP_White     0.972974
# 882                               EOGMathGr5_CACR_White     0.993292
# 883                               EOGMathGr5_CACR_White     0.962289
# 884                               EOGMathGr5_CACR_White     0.965604
# 885                               EOGMathGr5_CACR_White     0.961639
# 886                               EOGMathGr5_CACR_White     0.962832
# 887                                EOGMathGr5_GLP_White     0.961197
# 888                                EOGMathGr5_GLP_White     0.970168
# 889                                EOGMathGr5_GLP_White     0.965068
# 890                                EOGMathGr5_GLP_White     0.970708
# 891                            EOGReadingGr3_CACR_White     0.986317
# 892                          EOGReadingGr3-8_CACR_White     0.985584
# 893                          EOGReadingGr3-8_CACR_White     0.972673
# 894                          EOGReadingGr3-8_CACR_White     0.963450
# 895                           EOGReadingGr3-8_GLP_White     0.961684
# 896                           EOGReadingGr3-8_GLP_White     0.971658
# 897                            EOGReadingGr4_CACR_White     0.987360
# 898                            EOGReadingGr5_CACR_White     0.985241
# 899                            EOGReadingGr5_CACR_White     0.956393
# 900                            EOGReadingGr5_CACR_White     0.958369
# 901                             EOGReadingGr5_GLP_White     0.965393
# 902                             EOGReadingGr5_GLP_White     0.974342
# 903                            EOGScienceGr5_CACR_White     0.988368
# 904                          EOGScienceGr5&8_CACR_White     0.986108
# 905                              EOGSubjects_CACR_White     0.988948
# 906                                   EOCMathI_CACR_EDS     0.980954
# 907                                   EOCMathI_CACR_EDS     0.991734
# 908                                   EOCMathI_CACR_EDS     0.971450
# 909                                    EOCMathI_GLP_EDS     0.979861
# 910                                    EOCMathI_GLP_EDS     0.991903
# 911                                EOCSubjects_CACR_EDS     0.984335
# 912                            EOG/EOCSubjects_CACR_EDS     0.979576
# 913                                     EOGGr3_CACR_EDS     0.982398
# 914                                     EOGGr3_CACR_EDS     0.973206
# 915                                     EOGGr3_CACR_EDS     0.964116
# 916                                     EOGGr3_CACR_EDS     0.969207
# 917                                     EOGGr3_CACR_EDS     0.960229
# 918                                      EOGGr3_GLP_EDS     0.955409
# 919                                      EOGGr3_GLP_EDS     0.978632
# 920                                      EOGGr3_GLP_EDS     0.952556
# 921                                      EOGGr3_GLP_EDS     0.976502
# 922                                      EOGGr3_GLP_EDS     0.955668
# 923                                     EOGGr4_CACR_EDS     0.986535
# 924                                     EOGGr4_CACR_EDS     0.973821
# 925                                     EOGGr4_CACR_EDS     0.970838
# 926                                     EOGGr4_CACR_EDS     0.970833
# 927                                     EOGGr4_CACR_EDS     0.962141
# 928                                      EOGGr4_GLP_EDS     0.962216
# 929                                      EOGGr4_GLP_EDS     0.980517
# 930                                      EOGGr4_GLP_EDS     0.960322
# 931                                      EOGGr4_GLP_EDS     0.981364
# 932                                     EOGGr5_CACR_EDS     0.989366
# 933                                     EOGGr5_CACR_EDS     0.955151
# 934                                     EOGGr5_CACR_EDS     0.953844
# 935                                     EOGGr5_CACR_EDS     0.955918
# 936                                     EOGGr5_CACR_EDS     0.953915
# 937                                      EOGGr5_GLP_EDS     0.950176
# 938                                      EOGGr5_GLP_EDS     0.961217
# 939                                      EOGGr5_GLP_EDS     0.956512
# 940                                      EOGGr5_GLP_EDS     0.966197
# 941                                 EOGMathGr3_CACR_EDS     0.975299
# 942                               EOGMathGr3-8_CACR_EDS     0.985762
# 943                               EOGMathGr3-8_CACR_EDS     0.965145
# 944                               EOGMathGr3-8_CACR_EDS     0.952530
# 945                                EOGMathGr3-8_GLP_EDS     0.964727
# 946                                EOGMathGr3-8_GLP_EDS     0.971194
# 947                                 EOGMathGr4_CACR_EDS     0.983334
# 948                                 EOGMathGr5_CACR_EDS     0.987408
# 949                              EOGReadingGr3_CACR_EDS     0.972911
# 950                               EOGReadingGr3_GLP_EDS     0.958649
# 951                            EOGReadingGr3-8_CACR_EDS     0.980704
# 952                            EOGReadingGr3-8_CACR_EDS     0.975061
# 953                            EOGReadingGr3-8_CACR_EDS     0.965354
# 954                             EOGReadingGr3-8_GLP_EDS     0.968708
# 955                             EOGReadingGr3-8_GLP_EDS     0.982340
# 956                              EOGReadingGr4_CACR_EDS     0.974028
# 957                              EOGReadingGr5_CACR_EDS     0.968334
# 958                              EOGScienceGr5_CACR_EDS     0.978960
# 959                            EOGScienceGr5&8_CACR_EDS     0.976180
# 960                                EOGSubjects_CACR_EDS     0.988479
# 961                            EOG/EOCSubjects_CACR_LEP     0.965124
# 962                                     EOGGr5_CACR_LEP     0.951610
# 963                                 EOGMathGr3_CACR_LEP     0.950566
# 964                                 EOGMathGr5_CACR_LEP     0.955925
# 965                                EOCSubjects_CACR_SWD     0.955854
# 966                            EOG/EOCSubjects_CACR_SWD     0.955147
# 967                                     EOGGr4_CACR_SWD     0.952854
# 968                                     EOGGr5_CACR_SWD     0.956928
# 969                                EOGSubjects_CACR_SWD     0.967167
# 970                                   EOCMathI_CACR_AIG     0.994215
# 971                                   EOCMathI_CACR_AIG     0.976598
# 972                                   EOCMathI_CACR_AIG     0.970456
# 973                                    EOCMathI_GLP_AIG     0.974191
# 974                                    EOCMathI_GLP_AIG     0.976398
# 975                                EOCSubjects_CACR_AIG     0.995725
# 976                            EOG/EOCSubjects_CACR_AIG     0.983187
# 977                                     EOGGr3_CACR_AIG     0.996515
# 978                                     EOGGr4_CACR_AIG     0.997147
# 979                                     EOGGr5_CACR_AIG     0.997010
# 980                                 EOGMathGr3_CACR_AIG     0.997323
# 981                                 EOGMathGr3_CACR_AIG     0.992768
# 982                                 EOGMathGr3_CACR_AIG     0.994508
# 983                                  EOGMathGr3_GLP_AIG     0.994201
# 984                                  EOGMathGr3_GLP_AIG     0.997732
# 985                               EOGMathGr3-8_CACR_AIG     0.995630
# 986                               EOGMathGr3-8_CACR_AIG     0.983419
# 987                               EOGMathGr3-8_CACR_AIG     0.986531
# 988                                EOGMathGr3-8_GLP_AIG     0.985840
# 989                                EOGMathGr3-8_GLP_AIG     0.992097
# 990                                 EOGMathGr4_CACR_AIG     0.997724
# 991                                 EOGMathGr4_CACR_AIG     0.990302
# 992                                 EOGMathGr4_CACR_AIG     0.993045
# 993                                  EOGMathGr4_GLP_AIG     0.991097
# 994                                  EOGMathGr4_GLP_AIG     0.995298
# 995                                 EOGMathGr5_CACR_AIG     0.998326
# 996                                 EOGMathGr5_CACR_AIG     0.987075
# 997                                 EOGMathGr5_CACR_AIG     0.992496
# 998                                 EOGMathGr5_CACR_AIG     0.990768
# 999                                 EOGMathGr5_CACR_AIG     0.993840
# 1000                                 EOGMathGr5_GLP_AIG     0.987175
# 1001                                 EOGMathGr5_GLP_AIG     0.993902
# 1002                                 EOGMathGr5_GLP_AIG     0.991747
# 1003                                 EOGMathGr5_GLP_AIG     0.995537
# 1004                             EOGReadingGr3_CACR_AIG     0.996602
# 1005                           EOGReadingGr3-8_CACR_AIG     0.992677
# 1006                             EOGReadingGr4_CACR_AIG     0.995151
# 1007                             EOGReadingGr5_CACR_AIG     0.994031
# 1008                             EOGReadingGr5_CACR_AIG     0.986591
# 1009                             EOGReadingGr5_CACR_AIG     0.987158
# 1010                              EOGReadingGr5_GLP_AIG     0.991935
# 1011                              EOGReadingGr5_GLP_AIG     0.994659
# 1012                             EOGScienceGr5_CACR_AIG     0.996493
# 1013                           EOGScienceGr5&8_CACR_AIG     0.996022
# 1014                               EOGSubjects_CACR_AIG     0.995124
# 1015                                 st_crime_per_c_num     0.955145
# 1016                                 st_crime_per_c_num     0.983097
# 1017                        st_avg_age_media_collection     1.000000
# 1018                                  tchyrs_0thru3_pct     1.000000
# 1019                                 tchyrs_4thru10_pct     1.000000
# 1020                                  tchyrs_11plus_pct     1.000000
# 1021                            lea_flicensed_teach_pct     0.970256
# 1022                         lea_highqual_class_all_pct     1.000000
# 1023                              st_tchyrs_4thru10_pct     0.984356
# 1024                               st_tchyrs_11plus_pct     0.975890
# 1025                               st_tchyrs_11plus_pct     0.975890
# 1026                                 st_class_teach_num     0.962766
# 1027                                 st_class_teach_num     0.970490
# 1028                                       st_nbpts_num     0.962525
# 1029                             st_emer_prov_teach_pct     0.961271
# 1030                             st_emer_prov_teach_pct     0.961271
# 1031                                     AsianFemalePct     0.981563
# 1032                                       AsianMalePct     0.982697
# 1033                                     BlackFemalePct     0.960342
# 1034                                       BlackMalePct     0.967268
# 1035                                  HispanicFemalePct     0.977485
# 1036                                    HispanicMalePct     0.979179
# 1037                                    IndianFemalePct     0.978014
# 1038                                    IndianFemalePct     0.994300
# 1039                                      IndianMalePct     0.994673
# 1040                                  MinorityFemalePct     0.950294
# 1041                                  MinorityFemalePct     0.952271
# 1042                                  MinorityFemalePct     0.950294
# 1043                                    MinorityMalePct     0.957745
# 1044                                    MinorityMalePct     0.955857
# 1045                                    MinorityMalePct     0.957745
# 1046                                        MinorityPct     0.969208
# 1047                                        MinorityPct     0.972161
# 1048                                        MinorityPct     1.000000
# 1049                                     WhiteFemalePct     0.969208
# 1050                                       WhiteMalePct     0.972161
# 1051                                      category_cd_E     1.000000
# 1052                                      category_cd_H     1.000000
# 1053                                      category_cd_I     1.000000
# 1054                                      category_cd_M     1.000000
# 1055                                      category_cd_T     1.000000
# 1056                  calendar_type_txt_Hospital School     1.000000
# 1057                  calendar_type_txt_Hospital School     1.000000
# 1058  calendar_type_txt_Magnet School, Traditional C...     1.000000
# 1059  calendar_type_txt_Magnet School, Traditional C...     0.981760
# 1060  calendar_type_txt_Magnet School, Year-Round Ca...     1.000000
# 1061  calendar_type_txt_Regular School, Traditional ...     1.000000
# 1062  calendar_type_txt_Regular School, Traditional ...     1.000000
# 1063  calendar_type_txt_Regular School, Traditional ...     1.000000
# 1064  calendar_type_txt_Regular School, Year-Round C...     1.000000
# 1065  calendar_type_txt_Regular School, Year-Round C...     0.979158
# 1066  calendar_type_txt_Special Education, Tradition...     1.000000
# 1067  calendar_type_txt_Special Education, Tradition...     1.000000
# 1068                                  sna_pgm_type_cd_H     1.000000
# 1069                                  sna_pgm_type_cd_M     0.981760
# 1070                                  sna_pgm_type_cd_S     1.000000
# 1071                                  sna_pgm_type_cd_X     1.000000
# 1072                                  sna_pgm_type_cd_Y     0.979158
# 1073                                     SPG Grade_A+NG     1.000000
#
# [1074 rows x 3 columns]

# %%
print 'Dropping the following ', str(len(to_drop)), ' highly correlated fields.'
to_drop
# Out:
# Dropping the following  323  highly correlated fields.
# ['Math SPG Score',
#  'Overall Achievement Score',
#  'Read Score',
#  'Math Score',
#  'EOCMathI_CACR_All',
#  'EOCMathI_GLP_All',
#  'EOCSubjects_CACR_All',
#  'EOCSubjects_GLP_All',
#  'EOG/EOCSubjects_GLP_All',
#  'EOGGr3_GLP_All',
#  'EOGGr4_GLP_All',
#  'EOGGr5_GLP_All',
#  'EOGMathGr3_CACR_All',
#  'EOGMathGr3_GLP_All',
#  'EOGMathGr3-8_CACR_All',
#  'EOGMathGr3-8_GLP_All',
#  'EOGMathGr4_CACR_All',
#  'EOGMathGr4_GLP_All',
#  'EOGMathGr5_CACR_All',
#  'EOGMathGr5_GLP_All',
#  'EOGReadingGr3_CACR_All',
#  'EOGReadingGr3_GLP_All',
#  'EOGReadingGr3-8_CACR_All',
#  'EOGReadingGr3-8_GLP_All',
#  'EOGReadingGr4_CACR_All',
#  'EOGReadingGr4_GLP_All',
#  'EOGReadingGr5_CACR_All',
#  'EOGReadingGr5_GLP_All',
#  'EOGScienceGr5_CACR_All',
#  'EOGScienceGr5_GLP_All',
#  'EOGScienceGr5&8_CACR_All',
#  'EOGScienceGr5&8_GLP_All',
#  'EOGSubjects_CACR_All',
#  'EOGSubjects_GLP_All',
#  'EOCMathI_CACR_Female',
#  'EOCMathI_GLP_Female',
#  'EOCSubjects_CACR_Female',
#  'EOCSubjects_GLP_Female',
#  'EOG/EOCSubjects_CACR_Female',
#  'EOG/EOCSubjects_GLP_Female',
#  'EOGGr3_CACR_Female',
#  'EOGGr3_GLP_Female',
#  'EOGGr4_CACR_Female',
#  'EOGGr4_GLP_Female',
#  'EOGGr5_CACR_Female',
#  'EOGGr5_GLP_Female',
#  'EOGMathGr3_CACR_Female',
#  'EOGMathGr3_GLP_Female',
#  'EOGMathGr3-8_CACR_Female',
#  'EOGMathGr3-8_GLP_Female',
#  'EOGMathGr4_CACR_Female',
#  'EOGMathGr4_GLP_Female',
#  'EOGMathGr5_CACR_Female',
#  'EOGMathGr5_GLP_Female',
#  'EOGReadingGr3_CACR_Female',
#  'EOGReadingGr3_GLP_Female',
#  'EOGReadingGr3-8_CACR_Female',
#  'EOGReadingGr3-8_GLP_Female',
#  'EOGReadingGr4_CACR_Female',
#  'EOGReadingGr4_GLP_Female',
#  'EOGReadingGr5_CACR_Female',
#  'EOGReadingGr5_GLP_Female',
#  'EOGScienceGr5_CACR_Female',
#  'EOGScienceGr5_GLP_Female',
#  'EOGScienceGr5&8_CACR_Female',
#  'EOGScienceGr5&8_GLP_Female',
#  'EOGSubjects_CACR_Female',
#  'EOGSubjects_GLP_Female',
#  'EOCMathI_CACR_Male',
#  'EOCMathI_GLP_Male',
#  'EOCSubjects_CACR_Male',
#  'EOCSubjects_GLP_Male',
#  'EOG/EOCSubjects_CACR_Male',
#  'EOG/EOCSubjects_GLP_Male',
#  'EOGGr3_CACR_Male',
#  'EOGGr3_GLP_Male',
#  'EOGGr4_CACR_Male',
#  'EOGGr4_GLP_Male',
#  'EOGGr5_CACR_Male',
#  'EOGGr5_GLP_Male',
#  'EOGMathGr3_CACR_Male',
#  'EOGMathGr3_GLP_Male',
#  'EOGMathGr3-8_CACR_Male',
#  'EOGMathGr3-8_GLP_Male',
#  'EOGMathGr4_CACR_Male',
#  'EOGMathGr4_GLP_Male',
#  'EOGMathGr5_CACR_Male',
#  'EOGMathGr5_GLP_Male',
#  'EOGReadingGr3_CACR_Male',
#  'EOGReadingGr3_GLP_Male',
#  'EOGReadingGr3-8_CACR_Male',
#  'EOGReadingGr3-8_GLP_Male',
#  'EOGReadingGr4_CACR_Male',
#  'EOGReadingGr4_GLP_Male',
#  'EOGReadingGr5_CACR_Male',
#  'EOGReadingGr5_GLP_Male',
#  'EOGScienceGr5_CACR_Male',
#  'EOGScienceGr5_GLP_Male',
#  'EOGScienceGr5&8_CACR_Male',
#  'EOGScienceGr5&8_GLP_Male',
#  'EOGSubjects_CACR_Male',
#  'EOGSubjects_GLP_Male',
#  'EOCMathI_GLP_AmericanIndian',
#  'EOCSubjects_GLP_AmericanIndian',
#  'EOG/EOCSubjects_GLP_AmericanIndian',
#  'EOGGr3_GLP_AmericanIndian',
#  'EOGGr4_GLP_AmericanIndian',
#  'EOGGr5_GLP_AmericanIndian',
#  'EOGMathGr3_GLP_AmericanIndian',
#  'EOGMathGr3-8_GLP_AmericanIndian',
#  'EOGMathGr4_GLP_AmericanIndian',
#  'EOGMathGr5_GLP_AmericanIndian',
#  'EOGReadingGr3_GLP_AmericanIndian',
#  'EOGReadingGr3-8_GLP_AmericanIndian',
#  'EOGReadingGr4_CACR_AmericanIndian',
#  'EOGReadingGr4_GLP_AmericanIndian',
#  'EOGScienceGr5_GLP_AmericanIndian',
#  'EOGScienceGr5&8_GLP_AmericanIndian',
#  'EOGSubjects_GLP_AmericanIndian',
#  'EOCMathI_GLP_Asian',
#  'EOCSubjects_GLP_Asian',
#  'EOG/EOCSubjects_GLP_Asian',
#  'EOGGr3_GLP_Asian',
#  'EOGGr4_GLP_Asian',
#  'EOGGr5_GLP_Asian',
#  'EOGMathGr3_GLP_Asian',
#  'EOGMathGr3-8_GLP_Asian',
#  'EOGMathGr4_GLP_Asian',
#  'EOGMathGr5_GLP_Asian',
#  'EOGReadingGr3_CACR_Asian',
#  'EOGReadingGr3_GLP_Asian',
#  'EOGReadingGr3-8_CACR_Asian',
#  'EOGReadingGr3-8_GLP_Asian',
#  'EOGReadingGr4_CACR_Asian',
#  'EOGReadingGr4_GLP_Asian',
#  'EOGReadingGr5_CACR_Asian',
#  'EOGReadingGr5_GLP_Asian',
#  'EOGScienceGr5_CACR_Asian',
#  'EOGScienceGr5_GLP_Asian',
#  'EOGScienceGr5&8_GLP_Asian',
#  'EOGSubjects_GLP_Asian',
#  'EOCMathI_GLP_Black',
#  'EOCSubjects_CACR_Black',
#  'EOCSubjects_GLP_Black',
#  'EOG/EOCSubjects_GLP_Black',
#  'EOGGr3_GLP_Black',
#  'EOGGr4_GLP_Black',
#  'EOGGr5_GLP_Black',
#  'EOGMathGr3_GLP_Black',
#  'EOGMathGr3-8_GLP_Black',
#  'EOGMathGr4_GLP_Black',
#  'EOGMathGr5_GLP_Black',
#  'EOGReadingGr3_GLP_Black',
#  'EOGReadingGr3-8_GLP_Black',
#  'EOGReadingGr4_GLP_Black',
#  'EOGReadingGr5_GLP_Black',
#  'EOGScienceGr5_GLP_Black',
#  'EOGScienceGr5&8_GLP_Black',
#  'EOGSubjects_GLP_Black',
#  'EOCMathI_GLP_Hispanic',
#  'EOCSubjects_CACR_Hispanic',
#  'EOCSubjects_GLP_Hispanic',
#  'EOG/EOCSubjects_GLP_Hispanic',
#  'EOGGr3_GLP_Hispanic',
#  'EOGGr4_GLP_Hispanic',
#  'EOGGr5_GLP_Hispanic',
#  'EOGMathGr3_GLP_Hispanic',
#  'EOGMathGr3-8_GLP_Hispanic',
#  'EOGMathGr4_GLP_Hispanic',
#  'EOGMathGr5_GLP_Hispanic',
#  'EOGReadingGr3_GLP_Hispanic',
#  'EOGReadingGr3-8_GLP_Hispanic',
#  'EOGReadingGr4_GLP_Hispanic',
#  'EOGScienceGr5_GLP_Hispanic',
#  'EOGScienceGr5&8_GLP_Hispanic',
#  'EOGSubjects_GLP_Hispanic',
#  'EOCMathI_GLP_TwoorMoreRaces',
#  'EOCSubjects_GLP_TwoorMoreRaces',
#  'EOG/EOCSubjects_GLP_TwoorMoreRaces',
#  'EOGGr3_GLP_TwoorMoreRaces',
#  'EOGGr4_GLP_TwoorMoreRaces',
#  'EOGGr5_GLP_TwoorMoreRaces',
#  'EOGMathGr3_GLP_TwoorMoreRaces',
#  'EOGMathGr3-8_GLP_TwoorMoreRaces',
#  'EOGMathGr4_GLP_TwoorMoreRaces',
#  'EOGMathGr5_GLP_TwoorMoreRaces',
#  'EOGReadingGr3_GLP_TwoorMoreRaces',
#  'EOGReadingGr3-8_GLP_TwoorMoreRaces',
#  'EOGReadingGr4_GLP_TwoorMoreRaces',
#  'EOGReadingGr5_GLP_TwoorMoreRaces',
#  'EOGScienceGr5_GLP_TwoorMoreRaces',
#  'EOGScienceGr5&8_GLP_TwoorMoreRaces',
#  'EOGSubjects_GLP_TwoorMoreRaces',
#  'EOCMathI_GLP_White',
#  'EOCSubjects_CACR_White',
#  'EOCSubjects_GLP_White',
#  'EOG/EOCSubjects_GLP_White',
#  'EOGGr3_CACR_White',
#  'EOGGr3_GLP_White',
#  'EOGGr4_GLP_White',
#  'EOGGr5_GLP_White',
#  'EOGMathGr3_CACR_White',
#  'EOGMathGr3_GLP_White',
#  'EOGMathGr3-8_GLP_White',
#  'EOGMathGr4_CACR_White',
#  'EOGMathGr4_GLP_White',
#  'EOGMathGr5_GLP_White',
#  'EOGReadingGr3_CACR_White',
#  'EOGReadingGr3_GLP_White',
#  'EOGReadingGr3-8_CACR_White',
#  'EOGReadingGr3-8_GLP_White',
#  'EOGReadingGr4_CACR_White',
#  'EOGReadingGr4_GLP_White',
#  'EOGReadingGr5_CACR_White',
#  'EOGReadingGr5_GLP_White',
#  'EOGScienceGr5_CACR_White',
#  'EOGScienceGr5_GLP_White',
#  'EOGScienceGr5&8_GLP_White',
#  'EOGSubjects_CACR_White',
#  'EOGSubjects_GLP_White',
#  'EOCMathI_GLP_EDS',
#  'EOCSubjects_CACR_EDS',
#  'EOCSubjects_GLP_EDS',
#  'EOG/EOCSubjects_GLP_EDS',
#  'EOGGr3_CACR_EDS',
#  'EOGGr3_GLP_EDS',
#  'EOGGr4_CACR_EDS',
#  'EOGGr4_GLP_EDS',
#  'EOGGr5_GLP_EDS',
#  'EOGMathGr3_CACR_EDS',
#  'EOGMathGr3_GLP_EDS',
#  'EOGMathGr3-8_GLP_EDS',
#  'EOGMathGr4_CACR_EDS',
#  'EOGMathGr4_GLP_EDS',
#  'EOGMathGr5_CACR_EDS',
#  'EOGMathGr5_GLP_EDS',
#  'EOGReadingGr3_CACR_EDS',
#  'EOGReadingGr3_GLP_EDS',
#  'EOGReadingGr3-8_GLP_EDS',
#  'EOGReadingGr4_CACR_EDS',
#  'EOGReadingGr4_GLP_EDS',
#  'EOGReadingGr5_GLP_EDS',
#  'EOGScienceGr5_CACR_EDS',
#  'EOGScienceGr5_GLP_EDS',
#  'EOGScienceGr5&8_GLP_EDS',
#  'EOGSubjects_CACR_EDS',
#  'EOGSubjects_GLP_EDS',
#  'EOGGr5_GLP_LEP',
#  'EOGMathGr3_GLP_LEP',
#  'EOGMathGr5_GLP_LEP',
#  'EOGSubjects_CACR_LEP',
#  'EOCSubjects_GLP_SWD',
#  'EOG/EOCSubjects_GLP_SWD',
#  'EOGGr4_GLP_SWD',
#  'EOGGr5_GLP_SWD',
#  'EOGSubjects_GLP_SWD',
#  'EOCMathI_GLP_AIG',
#  'EOCSubjects_CACR_AIG',
#  'EOCSubjects_GLP_AIG',
#  'EOG/EOCSubjects_GLP_AIG',
#  'EOGGr3_GLP_AIG',
#  'EOGGr4_GLP_AIG',
#  'EOGGr5_GLP_AIG',
#  'EOGMathGr3_GLP_AIG',
#  'EOGMathGr3-8_GLP_AIG',
#  'EOGMathGr4_GLP_AIG',
#  'EOGMathGr5_GLP_AIG',
#  'EOGReadingGr3_CACR_AIG',
#  'EOGReadingGr3_GLP_AIG',
#  'EOGReadingGr3-8_CACR_AIG',
#  'EOGReadingGr3-8_GLP_AIG',
#  'EOGReadingGr4_CACR_AIG',
#  'EOGReadingGr4_GLP_AIG',
#  'EOGReadingGr5_CACR_AIG',
#  'EOGReadingGr5_GLP_AIG',
#  'EOGScienceGr5_CACR_AIG',
#  'EOGScienceGr5_GLP_AIG',
#  'EOGScienceGr5&8_GLP_AIG',
#  'EOGSubjects_GLP_AIG',
#  'pct_PASSED_EOG',
#  'pct_PROMOTED',
#  'st_books_per_student',
#  'class_teach_num',
#  'lea_class_teach_num',
#  'lea_lateral_teach_pct',
#  'lea_not_highqual_class_all_pct',
#  'st_tchyrs_4thru10_pct',
#  'st_class_teach_num',
#  'st_nbpts_num',
#  'st_advance_dgr_pct',
#  'st_lateral_teach_pct',
#  '0-3 Years_Exp_Pct_Tch',
#  '10+ Years_Exp_Pct_Tch',
#  '4-10 Years_Exp_Pct_Tch',
#  'AsianPct',
#  'BlackPct',
#  'HispanicPct',
#  'IndianMalePct',
#  'IndianPct',
#  'MinorityPct',
#  'WhiteFemalePct',
#  'WhiteMalePct',
#  'WhitePct',
#  'category_cd_H',
#  'category_cd_M',
#  'sna_pgm_type_cd_H',
#  'sna_pgm_type_cd_M',
#  'sna_pgm_type_cd_N',
#  'sna_pgm_type_cd_R',
#  'sna_pgm_type_cd_S',
#  'sna_pgm_type_cd_X',
#  'sna_pgm_type_cd_Y',
#  'school_type_txt_Hospital School',
#  'school_type_txt_Magnet School',
#  'school_type_txt_Special Education',
#  'calendar_only_txt_Traditional Calendar plus Year-Round Calendar',
#  'calendar_only_txt_Year-Round Calendar',
#  'State Gap Compared_Less Than',
#  'Category_Cd_E',
#  'Category_Cd_H',
#  'Category_Cd_I',
#  'Category_Cd_M',
#  'Category_Cd_T']

# %%
#Check columns before drop 
print('\r\n*********Before: Dropping Highly Correlated Fields*************************************')
schoolData.info(verbose=False)

# Drop the highly correlated features from our training data 
schoolData = schoolData.drop(to_drop, axis=1)

#Check columns after drop 
print('\r\n*********After: Dropping Highly Correlated Fields**************************************')
schoolData.info(verbose=False)
# Out:
# *********Before: Dropping Highly Correlated Fields*************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2432 entries, 0 to 2584
# Columns: 679 entries, closed_ind to lea_avg_age_media_collection_2010
# dtypes: float64(599), uint8(80)
# memory usage: 11.3 MB
#
# *********After: Dropping Highly Correlated Fields**************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2432 entries, 0 to 2584
# Columns: 356 entries, closed_ind to lea_avg_age_media_collection_2010
# dtypes: float64(296), uint8(60)
# memory usage: 5.6 MB

# %%
#Restore the unit_code before saving
schoolData['unit_code'] = unit_code
#Save the final dataset to a .csv file
schoolData.to_csv(outputDir + inputFileName + '_ML.csv', sep=',', index=False)

# %%
print('*********FINAL DATASET DETAILS*********************************************************\r\n')
schoolData.info(verbose=True)
# Out:
# *********FINAL DATASET DETAILS*********************************************************
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2432 entries, 0 to 2584
# Data columns (total 357 columns):
# closed_ind                                                                         float64
# student_num                                                                        float64
# lea_avg_student_num                                                                float64
# st_avg_student_num                                                                 float64
# 00_Size                                                                            float64
# 01_Size                                                                            float64
# 02_Size                                                                            float64
# 03_Size                                                                            float64
# 04_Size                                                                            float64
# 05_Size                                                                            float64
# Math I_Size                                                                        float64
# lea_total_expense_num                                                              float64
# lea_salary_expense_pct                                                             float64
# lea_benefits_expense_pct                                                           float64
# lea_services_expense_pct                                                           float64
# lea_supplies_expense_pct                                                           float64
# lea_instruct_equip_exp_pct                                                         float64
# lea_federal_perpupil_num                                                           float64
# lea_local_perpupil_num                                                             float64
# lea_state_perpupil_num                                                             float64
# SPG Score                                                                          float64
# Reading  SPG Score                                                                 float64
# EVAAS Growth Score                                                                 float64
# Science Score                                                                      float64
# Math I Score                                                                       float64
# EOG/EOCSubjects_CACR_All                                                           float64
# EOGGr3_CACR_All                                                                    float64
# EOGGr4_CACR_All                                                                    float64
# EOGGr5_CACR_All                                                                    float64
# EOCMathI_CACR_AmericanIndian                                                       float64
# EOCSubjects_CACR_AmericanIndian                                                    float64
# EOG/EOCSubjects_CACR_AmericanIndian                                                float64
# EOGGr3_CACR_AmericanIndian                                                         float64
# EOGGr4_CACR_AmericanIndian                                                         float64
# EOGGr5_CACR_AmericanIndian                                                         float64
# EOGMathGr3_CACR_AmericanIndian                                                     float64
# EOGMathGr3-8_CACR_AmericanIndian                                                   float64
# EOGMathGr4_CACR_AmericanIndian                                                     float64
# EOGMathGr5_CACR_AmericanIndian                                                     float64
# EOGReadingGr3_CACR_AmericanIndian                                                  float64
# EOGReadingGr3-8_CACR_AmericanIndian                                                float64
# EOGReadingGr5_CACR_AmericanIndian                                                  float64
# EOGReadingGr5_GLP_AmericanIndian                                                   float64
# EOGScienceGr5_CACR_AmericanIndian                                                  float64
# EOGScienceGr5&8_CACR_AmericanIndian                                                float64
# EOGSubjects_CACR_AmericanIndian                                                    float64
# EOCMathI_CACR_Asian                                                                float64
# EOCSubjects_CACR_Asian                                                             float64
# EOG/EOCSubjects_CACR_Asian                                                         float64
# EOGGr3_CACR_Asian                                                                  float64
# EOGGr4_CACR_Asian                                                                  float64
# EOGGr5_CACR_Asian                                                                  float64
# EOGMathGr3_CACR_Asian                                                              float64
# EOGMathGr3-8_CACR_Asian                                                            float64
# EOGMathGr4_CACR_Asian                                                              float64
# EOGMathGr5_CACR_Asian                                                              float64
# EOGScienceGr5&8_CACR_Asian                                                         float64
# EOGSubjects_CACR_Asian                                                             float64
# EOCMathI_CACR_Black                                                                float64
# EOG/EOCSubjects_CACR_Black                                                         float64
# EOGGr3_CACR_Black                                                                  float64
# EOGGr4_CACR_Black                                                                  float64
# EOGGr5_CACR_Black                                                                  float64
# EOGMathGr3_CACR_Black                                                              float64
# EOGMathGr3-8_CACR_Black                                                            float64
# EOGMathGr4_CACR_Black                                                              float64
# EOGMathGr5_CACR_Black                                                              float64
# EOGReadingGr3_CACR_Black                                                           float64
# EOGReadingGr3-8_CACR_Black                                                         float64
# EOGReadingGr4_CACR_Black                                                           float64
# EOGReadingGr5_CACR_Black                                                           float64
# EOGScienceGr5_CACR_Black                                                           float64
# EOGScienceGr5&8_CACR_Black                                                         float64
# EOGSubjects_CACR_Black                                                             float64
# EOCMathI_CACR_Hispanic                                                             float64
# EOG/EOCSubjects_CACR_Hispanic                                                      float64
# EOGGr3_CACR_Hispanic                                                               float64
# EOGGr4_CACR_Hispanic                                                               float64
# EOGGr5_CACR_Hispanic                                                               float64
# EOGMathGr3_CACR_Hispanic                                                           float64
# EOGMathGr3-8_CACR_Hispanic                                                         float64
# EOGMathGr4_CACR_Hispanic                                                           float64
# EOGMathGr5_CACR_Hispanic                                                           float64
# EOGReadingGr3_CACR_Hispanic                                                        float64
# EOGReadingGr3-8_CACR_Hispanic                                                      float64
# EOGReadingGr4_CACR_Hispanic                                                        float64
# EOGReadingGr5_CACR_Hispanic                                                        float64
# EOGReadingGr5_GLP_Hispanic                                                         float64
# EOGScienceGr5_CACR_Hispanic                                                        float64
# EOGScienceGr5&8_CACR_Hispanic                                                      float64
# EOGSubjects_CACR_Hispanic                                                          float64
# EOCMathI_CACR_TwoorMoreRaces                                                       float64
# EOCSubjects_CACR_TwoorMoreRaces                                                    float64
# EOG/EOCSubjects_CACR_TwoorMoreRaces                                                float64
# EOGGr3_CACR_TwoorMoreRaces                                                         float64
# EOGGr4_CACR_TwoorMoreRaces                                                         float64
# EOGGr5_CACR_TwoorMoreRaces                                                         float64
# EOGMathGr3_CACR_TwoorMoreRaces                                                     float64
# EOGMathGr3-8_CACR_TwoorMoreRaces                                                   float64
# EOGMathGr4_CACR_TwoorMoreRaces                                                     float64
# EOGMathGr5_CACR_TwoorMoreRaces                                                     float64
# EOGReadingGr3_CACR_TwoorMoreRaces                                                  float64
# EOGReadingGr3-8_CACR_TwoorMoreRaces                                                float64
# EOGReadingGr4_CACR_TwoorMoreRaces                                                  float64
# EOGReadingGr5_CACR_TwoorMoreRaces                                                  float64
# EOGScienceGr5_CACR_TwoorMoreRaces                                                  float64
# EOGScienceGr5&8_CACR_TwoorMoreRaces                                                float64
# EOGSubjects_CACR_TwoorMoreRaces                                                    float64
# EOCMathI_CACR_White                                                                float64
# EOG/EOCSubjects_CACR_White                                                         float64
# EOGGr4_CACR_White                                                                  float64
# EOGGr5_CACR_White                                                                  float64
# EOGMathGr3-8_CACR_White                                                            float64
# EOGMathGr5_CACR_White                                                              float64
# EOGScienceGr5&8_CACR_White                                                         float64
# EOCMathI_CACR_EDS                                                                  float64
# EOG/EOCSubjects_CACR_EDS                                                           float64
# EOGGr5_CACR_EDS                                                                    float64
# EOGMathGr3-8_CACR_EDS                                                              float64
# EOGReadingGr3-8_CACR_EDS                                                           float64
# EOGReadingGr5_CACR_EDS                                                             float64
# EOGScienceGr5&8_CACR_EDS                                                           float64
# EOCMathI_CACR_LEP                                                                  float64
# EOCMathI_GLP_LEP                                                                   float64
# EOCSubjects_CACR_LEP                                                               float64
# EOCSubjects_GLP_LEP                                                                float64
# EOG/EOCSubjects_CACR_LEP                                                           float64
# EOG/EOCSubjects_GLP_LEP                                                            float64
# EOGGr3_CACR_LEP                                                                    float64
# EOGGr3_GLP_LEP                                                                     float64
# EOGGr4_CACR_LEP                                                                    float64
# EOGGr4_GLP_LEP                                                                     float64
# EOGGr5_CACR_LEP                                                                    float64
# EOGMathGr3_CACR_LEP                                                                float64
# EOGMathGr3-8_CACR_LEP                                                              float64
# EOGMathGr3-8_GLP_LEP                                                               float64
# EOGMathGr4_CACR_LEP                                                                float64
# EOGMathGr4_GLP_LEP                                                                 float64
# EOGMathGr5_CACR_LEP                                                                float64
# EOGReadingGr3_CACR_LEP                                                             float64
# EOGReadingGr3_GLP_LEP                                                              float64
# EOGReadingGr3-8_CACR_LEP                                                           float64
# EOGReadingGr3-8_GLP_LEP                                                            float64
# EOGReadingGr4_CACR_LEP                                                             float64
# EOGReadingGr4_GLP_LEP                                                              float64
# EOGReadingGr5_CACR_LEP                                                             float64
# EOGReadingGr5_GLP_LEP                                                              float64
# EOGScienceGr5_CACR_LEP                                                             float64
# EOGScienceGr5_GLP_LEP                                                              float64
# EOGScienceGr5&8_CACR_LEP                                                           float64
# EOGScienceGr5&8_GLP_LEP                                                            float64
# EOGSubjects_GLP_LEP                                                                float64
# EOCMathI_CACR_SWD                                                                  float64
# EOCMathI_GLP_SWD                                                                   float64
# EOCSubjects_CACR_SWD                                                               float64
# EOG/EOCSubjects_CACR_SWD                                                           float64
# EOGGr3_CACR_SWD                                                                    float64
# EOGGr3_GLP_SWD                                                                     float64
# EOGGr4_CACR_SWD                                                                    float64
# EOGGr5_CACR_SWD                                                                    float64
# EOGMathGr3_CACR_SWD                                                                float64
# EOGMathGr3_GLP_SWD                                                                 float64
# EOGMathGr3-8_CACR_SWD                                                              float64
# EOGMathGr3-8_GLP_SWD                                                               float64
# EOGMathGr4_CACR_SWD                                                                float64
# EOGMathGr4_GLP_SWD                                                                 float64
# EOGMathGr5_CACR_SWD                                                                float64
# EOGMathGr5_GLP_SWD                                                                 float64
# EOGReadingGr3_CACR_SWD                                                             float64
# EOGReadingGr3_GLP_SWD                                                              float64
# EOGReadingGr3-8_CACR_SWD                                                           float64
# EOGReadingGr3-8_GLP_SWD                                                            float64
# EOGReadingGr4_CACR_SWD                                                             float64
# EOGReadingGr4_GLP_SWD                                                              float64
# EOGReadingGr5_CACR_SWD                                                             float64
# EOGReadingGr5_GLP_SWD                                                              float64
# EOGScienceGr5_CACR_SWD                                                             float64
# EOGScienceGr5_GLP_SWD                                                              float64
# EOGScienceGr5&8_CACR_SWD                                                           float64
# EOGScienceGr5&8_GLP_SWD                                                            float64
# EOGSubjects_CACR_SWD                                                               float64
# EOCMathI_CACR_AIG                                                                  float64
# EOG/EOCSubjects_CACR_AIG                                                           float64
# EOGGr3_CACR_AIG                                                                    float64
# EOGGr4_CACR_AIG                                                                    float64
# EOGGr5_CACR_AIG                                                                    float64
# EOGMathGr3_CACR_AIG                                                                float64
# EOGMathGr3-8_CACR_AIG                                                              float64
# EOGMathGr4_CACR_AIG                                                                float64
# EOGMathGr5_CACR_AIG                                                                float64
# EOGScienceGr5&8_CACR_AIG                                                           float64
# EOGSubjects_CACR_AIG                                                               float64
# pct_GCE_ALL                                                                        float64
# MathGr3-8_pTarget_PctMet                                                           float64
# ReadingGr3-8_pTarget_PctMet                                                        float64
# SciGr5&8_pTarget_PctMet                                                            float64
# TotalTargets_pTarget_PctMet                                                        float64
# lea_sat_avg_score_num                                                              float64
# lea_sat_participation_pct                                                          float64
# lea_ap_participation_pct                                                           float64
# lea_ap_pct_3_or_above                                                              float64
# lea_ib_pct_4_or_above                                                              float64
# avg_daily_attend_pct                                                               float64
# crime_per_c_num                                                                    float64
# short_susp_per_c_num                                                               float64
# long_susp_per_c_num                                                                float64
# expelled_per_c_num                                                                 float64
# stud_internet_comp_num                                                             float64
# lea_avg_daily_attend_pct                                                           float64
# lea_crime_per_c_num                                                                float64
# lea_short_susp_per_c_num                                                           float64
# lea_long_susp_per_c_num                                                            float64
# lea_expelled_per_c_num                                                             float64
# lea_stud_internet_comp_num                                                         float64
# st_avg_daily_attend_pct                                                            float64
# st_crime_per_c_num                                                                 float64
# st_short_susp_per_c_num                                                            float64
# digital_media_pct                                                                  float64
# books_per_student                                                                  float64
# lea_books_per_student                                                              float64
# st_avg_age_media_collection                                                        float64
# flicensed_teach_pct                                                                float64
# tchyrs_0thru3_pct                                                                  float64
# tchyrs_4thru10_pct                                                                 float64
# tchyrs_11plus_pct                                                                  float64
# nbpts_num                                                                          float64
# advance_dgr_pct                                                                    float64
# _1yr_tchr_trnovr_pct                                                               float64
# lateral_teach_pct                                                                  float64
# highqual_class_pct                                                                 float64
# lea_flicensed_teach_pct                                                            float64
# lea_tchyrs_0thru3_pct                                                              float64
# lea_tchyrs_4thru10_pct                                                             float64
# lea_tchyrs_11plus_pct                                                              float64
# lea_nbpts_num                                                                      float64
# lea_advance_dgr_pct                                                                float64
# lea_1yr_tchr_trnovr_pct                                                            float64
# lea_emer_prov_teach_pct                                                            float64
# lea_highqual_class_pct                                                             float64
# lea_highqual_class_hp_pct                                                          float64
# lea_highqual_class_lp_pct                                                          float64
# lea_highqual_class_all_pct                                                         float64
# lea_not_highqual_class_hp_pct                                                      float64
# lea_not_highqual_class_lp_pct                                                      float64
# st_flicensed_teach_pct                                                             float64
# st_tchyrs_0thru3_pct                                                               float64
# st_tchyrs_11plus_pct                                                               float64
# st_1yr_tchr_trnovr_pct                                                             float64
# st_emer_prov_teach_pct                                                             float64
# st_highqual_class_pct                                                              float64
# 0-3 Years_LEA_Exp_Pct_Prin                                                         float64
# 10+ Years_LEA_Exp_Pct_Prin                                                         float64
# 4-10 Years_LEA_Exp_Pct_Prin                                                        float64
# Accomplished_TCHR_Standard 1_Pct                                                   float64
# Accomplished_TCHR_Standard 2_Pct                                                   float64
# Accomplished_TCHR_Standard 3_Pct                                                   float64
# Accomplished_TCHR_Standard 4_Pct                                                   float64
# Accomplished_TCHR_Standard 5_Pct                                                   float64
# Developing_TCHR_Standard 1_Pct                                                     float64
# Developing_TCHR_Standard 2_Pct                                                     float64
# Developing_TCHR_Standard 3_Pct                                                     float64
# Developing_TCHR_Standard 4_Pct                                                     float64
# Developing_TCHR_Standard 5_Pct                                                     float64
# Distinguished_TCHR_Standard 1_Pct                                                  float64
# Distinguished_TCHR_Standard 2_Pct                                                  float64
# Distinguished_TCHR_Standard 3_Pct                                                  float64
# Distinguished_TCHR_Standard 4_Pct                                                  float64
# Distinguished_TCHR_Standard 5_Pct                                                  float64
# Does Not Meet Expected Growth_TCHR_Standard 6_Pct                                  float64
# Exceeds Expected Growth_TCHR_Standard 6_Pct                                        float64
# Meets Expected Growth_TCHR_Standard 6_Pct                                          float64
# Not Demostrated_TCHR_Standard 1_Pct                                                float64
# Not Demostrated_TCHR_Standard 2_Pct                                                float64
# Not Demostrated_TCHR_Standard 3_Pct                                                float64
# Not Demostrated_TCHR_Standard 4_Pct                                                float64
# Not Demostrated_TCHR_Standard 5_Pct                                                float64
# Proficient_TCHR_Standard 1_Pct                                                     float64
# Proficient_TCHR_Standard 2_Pct                                                     float64
# Proficient_TCHR_Standard 3_Pct                                                     float64
# Proficient_TCHR_Standard 4_Pct                                                     float64
# Proficient_TCHR_Standard 5_Pct                                                     float64
# AsianFemalePct                                                                     float64
# AsianMalePct                                                                       float64
# BlackFemalePct                                                                     float64
# BlackMalePct                                                                       float64
# HispanicFemalePct                                                                  float64
# HispanicMalePct                                                                    float64
# IndianFemalePct                                                                    float64
# MinorityFemalePct                                                                  float64
# MinorityMalePct                                                                    float64
# PacificIslandFemalePct                                                             float64
# PacificIslandMalePct                                                               float64
# PacificIslandPct                                                                   float64
# TwoOrMoreFemalePct                                                                 float64
# TwoOrMoreMalePct                                                                   float64
# TwoOrMorePct                                                                       float64
# category_cd_E                                                                      uint8
# category_cd_I                                                                      uint8
# category_cd_T                                                                      uint8
# calendar_type_txt_Hospital School                                                  uint8
# calendar_type_txt_Magnet School, Traditional Calendar                              uint8
# calendar_type_txt_Magnet School, Year-Round Calendar                               uint8
# calendar_type_txt_Regular School, Traditional Calendar                             uint8
# calendar_type_txt_Regular School, Traditional Calendar plus Year-Round Calendar    uint8
# calendar_type_txt_Regular School, Year-Round Calendar                              uint8
# calendar_type_txt_Special Education, Traditional Calendar                          uint8
# school_type_txt_Regular School                                                     uint8
# esea_status_P                                                                      uint8
# esea_status_R                                                                      uint8
# esea_status_RF                                                                     uint8
# Grad_project_status_Y                                                              uint8
# SBE District_Northeast                                                             uint8
# SBE District_Northwest                                                             uint8
# SBE District_Piedmont-Triad                                                        uint8
# SBE District_Sandhills                                                             uint8
# SBE District_Southeast                                                             uint8
# SBE District_Southwest                                                             uint8
# SBE District_Western                                                               uint8
# SPG Grade_A+NG                                                                     uint8
# SPG Grade_B                                                                        uint8
# SPG Grade_C                                                                        uint8
# SPG Grade_D                                                                        uint8
# SPG Grade_F                                                                        uint8
# SPG Grade_I                                                                        uint8
# Reading SPG Grade_B                                                                uint8
# Reading SPG Grade_C                                                                uint8
# Reading SPG Grade_D                                                                uint8
# Reading SPG Grade_F                                                                uint8
# Math SPG Grade_B                                                                   uint8
# Math SPG Grade_C                                                                   uint8
# Math SPG Grade_D                                                                   uint8
# Math SPG Grade_F                                                                   uint8
# EVAAS Growth Status_Met                                                            uint8
# EVAAS Growth Status_NotMet                                                         uint8
# State Gap Compared_Insufficient Data                                               uint8
# esea_attendance_Met                                                                uint8
# Byod_YES                                                                           uint8
# _1_to_1_access_YES                                                                 uint8
# lea_avg_age_media_collection_1936                                                  uint8
# lea_avg_age_media_collection_1988                                                  uint8
# lea_avg_age_media_collection_1991                                                  uint8
# lea_avg_age_media_collection_1993                                                  uint8
# lea_avg_age_media_collection_1994                                                  uint8
# lea_avg_age_media_collection_1995                                                  uint8
# lea_avg_age_media_collection_1996                                                  uint8
# lea_avg_age_media_collection_1997                                                  uint8
# lea_avg_age_media_collection_1998                                                  uint8
# lea_avg_age_media_collection_1999                                                  uint8
# lea_avg_age_media_collection_2000                                                  uint8
# lea_avg_age_media_collection_2001                                                  uint8
# lea_avg_age_media_collection_2002                                                  uint8
# lea_avg_age_media_collection_2003                                                  uint8
# lea_avg_age_media_collection_2005                                                  uint8
# lea_avg_age_media_collection_2006                                                  uint8
# lea_avg_age_media_collection_2007                                                  uint8
# lea_avg_age_media_collection_2010                                                  uint8
# unit_code                                                                          object
# dtypes: float64(296), object(1), uint8(60)
# memory usage: 5.7+ MB

# %%
import sklearn
import pandas as pd

print('Sklearn Version: ' + sklearn.__version__)
print('Pandas Version: ' + pd.__version__)
# Out:
# Sklearn Version: 0.19.1
# Pandas Version: 0.22.0

# %%
print 'Output File Location:\r\n\r\n' + outputDir + inputFileName + '_ML.csv'
# Out:
# Output File Location:
#
# C:/Users/Jake/Documents/GitHub/EducationDataNC/2015/Machine Learning Datasets/PublicSchools2015_ML.csv
