# %% [markdown]
# ### XBRL GAAP Facts
# **A single balance sheet item in an SEC filing is stored using:**
# * **XBRL** - (eXtensible Business Reporting Language) is a markup language for exchanging business information in a computer-readable format and is used to standardize the way that financial data is reported and shared. One filing's XBRL typically contains many documents. It is not uncommon for an average filing to contain hundreds of documents.
# * **XBRL instance document** - The core document in an SEC filing's XBRL data. It contains the actual reported financial data for the entity making the filing. An instance document consists of a series of **facts**, each of which represents a specific disclosure—such as a financial statement line item—taken from the financial reports.
# * **XML** - The SEC requires that the XBRL instance document be in XML (eXtensible Markup Language) providing universality, flexibility, and readability across platforms and geographies.
# * **Taxonomy** -  Each fact is tagged with a specific XBRL element (taken from the relevant taxonomy) that defines what the fact represents. The taxonomy plays a crucial role in providing a standardized definition and structure to the financial data being reported providing: concept definitions, standard structure, cross-filing comparability, and standardized concept reporting guidelines.
# * **US GAAP Financial Reporting Taxonomy** - The SEC uses this specific taxonomy which is aligned with Generally Accepted Accounting Principles (GAAP) used in the United States. Other jurisdictions may use different taxonomies aligned with their specific accounting standards. In addition, a majority of publicly traded companies also use custom taxonomies to define their own unique balance sheets and other relevant corporate data.
# * **Context** - Each fact or data point is associated with a specific context that includes, among other things, a period of time. This period can be one of two types: a **duration** or an **instant**.
# * **Fiscal Duration** - A fact with a duration period is one that applies over a span of time. For example, if a company is reporting its total revenue for the fiscal year 2023, the fact would be associated with a duration that starts on January 1, 2023, and ends on December 31, 2023. Durations are typically used for items on the income statement, cash flow statement, and the statement of changes in equity.
# * **Fiscal Instant** - A fact with an instant period applies at a specific point in time. For example, if a company is reporting its total assets as of the end of the fiscal year 2023, the fact would be associated with an instant that is December 31, 2023. Instants are typically used for items on the balance sheet.
# * **SEC Reporting Guidelines** - The SEC's rules specify when each type of period should be used. For example, facts representing balance sheet line items should have an instant period, while facts representing income statement line items should have a duration period. These rules help ensure that the XBRL data is consistent and comparable across different companies.

# %% [markdown]
# ### One Example Fact
# **The JSON output below illustrates the value and metadata for a single fact:**
# * An individual filing's XBRL contains hundreds of relevant facts across multiple taxonomies.
# * Each fact may contain any number of supporting properties or nested objects.
# * The actual piece of data provided in each fact is labeled 'value'.
# * All of the other information you see is metadata that is critical to understanding the what the 'value' actually is.

# %%
get_json(obj)
# Out:
# {'concept': {'xml_id': 'dei_EntityCentralIndexKey',
#   'schema_url': 'https://xbrl.sec.gov/dei/2022/dei-2022.xsd',
#   'name': 'EntityCentralIndexKey',
#   'substitution_group': 'item',
#   'concept_type': None,
#   'abstract': False,
#   'nillable': True,
#   'period_type': 'duration',
#   'balance': None,
#   'labels': [{'label': 'lab_dei_EntityCentralIndexKey',
#     'language': 'en-US',
#     'text': 'Entity Central Index Key',
#     'label_type': 'http://www.xbrl.org/2003/role/verboseLabel'},
#    {'label': 'lab_dei_EntityCentralIndexKey',
#     'language': 'en-US',
#     'text': 'Entity Central Index Key',
#     'label_type': 'http://www.xbrl.org/2003/role/label'}],
#   'type': 'dei:centralIndexKeyItemType'},
#  'context': {'xml_id': 'i824606a34d09452696ab35368f66cff9_D20230103-20230403',
#   'entity': '0001723580',
#   'segments': [],
#   'start_date': '2023-01-03',
#   'end_date': '2023-04-03'},
#  'value': '0001723580',
#  'xml_id': '_de04dc22-2865-42e8-913c-d2100dcec0a1',
#  'footnote': None}

# %% [markdown]
# ### GAAP Fact Extraction
# **I have created an entire library that can:**
# 1. Process, identify, and extract the XBRL instance document from each filing's XBRL document collection.
# 2. Donwload all relevant taxonomies associated with the filing and cache them. (The SEC will block systems that repeately download the same taxonomies, and each download counts against usage limits.)
# 3. Locate all facts embedded in each filing.
# 4. Recursively inspect each XBRL fact unpacking all fact contents (properties and objects) and flattening them into output containing one row per fact that includes all relevant metadata.

# %% [markdown]
# ### GAAP Fact metadata for one filing
# * The output below shows all of the fact metadata unpacked for a single filing.

# %%
import pandas as pd
import Source.MonitorFilings.Parameters as params

# Read in all facts extracted for a single filing 
gaap = pd.read_csv(params.GAAP_dir + '916789_0000916789-20-000003.csv')

gaap.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 512 entries, 0 to 511
# Data columns (total 35 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   concept_xml_id               512 non-null    object
#  1   concept_schema_url           512 non-null    object
#  2   concept_name                 512 non-null    object
#  3   concept_substitution_group   512 non-null    object
#  4   concept_concept_type         0 non-null      float64
#  5   concept_abstract             512 non-null    bool
#  6   concept_nillable             512 non-null    bool
#  7   concept_period_type          512 non-null    object
#  8   concept_balance              359 non-null    object
#  9   concept_labels_0_label       512 non-null    object
#  10  concept_labels_0_language    512 non-null    object
#  11  concept_labels_0_text        512 non-null    object
#  12  concept_labels_0_label_type  512 non-null    object
#  13  concept_labels_1_label       419 non-null    object
#  14  concept_labels_1_language    419 non-null    object
#  15  concept_labels_1_text        419 non-null    object
#  16  concept_labels_1_label_type  419 non-null    object
#  17  concept_type                 512 non-null    object
#  18  context_xml_id               512 non-null    object
#  19  context_entity               512 non-null    int64
#  20  context_start_date           362 non-null    object
#  21  context_end_date             362 non-null    object
#  22  value                        512 non-null    object
#  23  xml_id                       512 non-null    object
#  24  footnote                     0 non-null      float64
#  25  concept_labels_2_label       40 non-null     object
#  26  concept_labels_2_language    40 non-null     object
#  27  concept_labels_2_text        40 non-null     object
#  28  concept_labels_2_label_type  40 non-null     object
#  29  context_instant_date         150 non-null    object
#  30  unit_unit_id                 442 non-null    object
#  31  unit_unit                    404 non-null    object
#  32  decimals                     421 non-null    float64
#  33  unit_numerator               38 non-null     object
#  34  unit_denominator             38 non-null     object
# dtypes: bool(2), float64(3), int64(1), object(29)
# memory usage: 133.1+ KB

# %% [markdown]
# ### GAAP concept data flattened to one row per fact
# * This output shows a subset of metadata for each row's fact.
# * The first column shows the names for each piece of data disclosed in the filing.
# * **Important** - Multiple facts for each item or concept_name may be disclosed in a single filing.  These facts typically cover different fiscal durations using the context_start_date and context_end_date OR different fiscal instants using the context_instant_date

# %%
gaap_cols = ['concept_name','concept_period_type','concept_balance',
     'context_xml_id','context_start_date','context_end_date',
     'context_instant_date','value']

with pd.option_context('display.max_rows', 50, 'display.max_columns', None): 
    display(gaap[gaap_cols].head(25))
# Out:
#                                     concept_name concept_period_type  \
# 0                                  AmendmentFlag            duration
# 1                       CurrentFiscalYearEndDate            duration
# 2                      DocumentFiscalPeriodFocus            duration
# 3                        DocumentFiscalYearFocus            duration
# 4                          EntityCentralIndexKey            duration
# 5      AllowanceForDoubtfulReceivablesAndReturns             instant
# 6      AllowanceForDoubtfulReceivablesAndReturns             instant
# 7   OtherAssetsNoncurrentAccumulatedAmortization             instant
# 8   OtherAssetsNoncurrentAccumulatedAmortization             instant
# 9            CommonStockParOrStatedValuePerShare             instant
# 10                   CommonStockSharesAuthorized             instant
# 11                   CommonStockSharesAuthorized             instant
# 12                       CommonStockSharesIssued             instant
# 13                       CommonStockSharesIssued             instant
# 14                  CommonStockSharesOutstanding             instant
# 15                  CommonStockSharesOutstanding             instant
# 16        PreferredStockParOrStatedValuePerShare             instant
# 17        PreferredStockParOrStatedValuePerShare             instant
# 18                PreferredStockSharesAuthorized             instant
# 19                PreferredStockSharesAuthorized             instant
# 20                    PreferredStockSharesIssued             instant
# 21                    PreferredStockSharesIssued             instant
# 22                                  DocumentType            duration
# 23                       DocumentQuarterlyReport            duration
# 24                         DocumentPeriodEndDate            duration
#
#    concept_balance context_xml_id context_start_date context_end_date  \
# 0              NaN    FD2020Q3YTD         2019-03-01       2019-11-30
# 1              NaN    FD2020Q3YTD         2019-03-01       2019-11-30
# 2              NaN    FD2020Q3YTD         2019-03-01       2019-11-30
# 3              NaN    FD2020Q3YTD         2019-03-01       2019-11-30
# 4              NaN    FD2020Q3YTD         2019-03-01       2019-11-30
# 5           credit       FI2019Q4                NaN              NaN
# 6           credit       FI2020Q3                NaN              NaN
# 7           credit       FI2019Q4                NaN              NaN
# 8           credit       FI2020Q3                NaN              NaN
# 9              NaN       FI2019Q4                NaN              NaN
# 10             NaN       FI2019Q4                NaN              NaN
# 11             NaN       FI2020Q3                NaN              NaN
# 12             NaN       FI2019Q4                NaN              NaN
# 13             NaN       FI2020Q3                NaN              NaN
# 14             NaN       FI2019Q4                NaN              NaN
# 15             NaN       FI2020Q3                NaN              NaN
# 16             NaN       FI2019Q4                NaN              NaN
# 17             NaN       FI2020Q3                NaN              NaN
# 18             NaN       FI2019Q4                NaN              NaN
# 19             NaN       FI2020Q3                NaN              NaN
# 20             NaN       FI2019Q4                NaN              NaN
# 21             NaN       FI2020Q3                NaN              NaN
# 22             NaN    FD2020Q3YTD         2019-03-01       2019-11-30
# 23             NaN    FD2020Q3YTD         2019-03-01       2019-11-30
# 24             NaN    FD2020Q3YTD         2019-03-01       2019-11-30
#
#    context_instant_date       value
# 0                   NaN       false
# 1                   NaN     --02-28
# 2                   NaN          Q3
# 3                   NaN        2020
# 4                   NaN  0000916789
# 5            2019-02-28   2032000.0
# 6            2019-11-30   1486000.0
# 7            2019-02-28   2115000.0
# 8            2019-11-30   2167000.0
# 9            2019-02-28         0.1
# 10           2019-02-28  50000000.0
# 11           2019-11-30  50000000.0
# 12           2019-02-28  24946046.0
# 13           2019-11-30  25166771.0
# 14           2019-02-28  24946046.0
# 15           2019-11-30  25166771.0
# 16           2019-02-28         1.0
# 17           2019-11-30         1.0
# 18           2019-02-28   2000000.0
# 19           2019-11-30   2000000.0
# 20           2019-02-28         0.0
# 21           2019-11-30         0.0
# 22                  NaN        10-Q
# 23                  NaN        true
# 24                  NaN  2019-11-30

# %% [markdown]
# ### GAAP Period Considerations
#
# The most common instances and durations disclosed in SEC filings largely correspond to the primary types of financial statements companies are required to provide:
#
#  1. **Balance Sheet (Statement of Financial Position):** This provides a snapshot of a company's financial position at a specific point in time, typically the end of the fiscal year or quarter. As such, it uses an "instant" context for facts disclosed, like total assets, total liabilities, and equity.
#  2. **Income Statement (Statement of Comprehensive Income):** This covers a "duration" period, usually the fiscal year or quarter, during which the company's revenue, costs, profits, and losses occur. Facts disclosed under a duration context might include revenue, cost of goods sold, operating expenses, and net income.
#  3. **Statement of Cash Flows:** This also covers a "duration" period, describing the inflows and outflows of cash during a fiscal year or quarter in operating, investing, and financing activities.
#  4. **Statement of Changes in Equity:** This shows changes in equity over a "duration" period and may include items such as dividends, stock issuance, or changes due to net income.
#  5. **Notes to Financial Statements:** This part of the filing can have both "instant" and "duration" disclosures, depending on the nature of the data disclosed. This could range from detailed breakdowns of assets and liabilities (which might use "instant" context) to data about the company's revenue recognition policies or lease obligations (which might use "duration" context).
#
# The most common periods for SEC filings would be three months for the quarterly filings and one year for the annual filings with the most common instance dates being the last day of each fiscal quarter and the last day of the fiscal year.

# %% [markdown]
# ### View the Raw GAAP Data
# * Raw GAAP data is extracted from the XBRL instance document.  This document is one of possibly hundreds of documents embedded in the filing's xbrl.
# * The instance document may also be seen on the SEC's website for most filings when it is provided and can be located.
# * See the last document entry number 33 with the description "EXTRACTED XBRL INSTANCE DOCUMENT" in the following [sec website example](https://www.sec.gov/Archives/edgar/data/1066719/0001683168-23-003732-index.html).

# %%
from Source.GAAP.GaapFeatures import load_raw_gaap_data

gaap_raw = load_raw_gaap_data('916789_0000916789-20-000003.csv')

with pd.option_context('display.max_rows', 1000, 'display.max_columns', None): 
    display(gaap_raw.head(25))
# Out:
#                                        concept_xml_id  \
# 0                                   dei_AmendmentFlag
# 1                        dei_CurrentFiscalYearEndDate
# 2                       dei_DocumentFiscalPeriodFocus
# 3                         dei_DocumentFiscalYearFocus
# 4                           dei_EntityCentralIndexKey
# 5      hele_AllowanceForDoubtfulReceivablesAndReturns
# 6      hele_AllowanceForDoubtfulReceivablesAndReturns
# 7   hele_OtherAssetsNoncurrentAccumulatedAmortization
# 8   hele_OtherAssetsNoncurrentAccumulatedAmortization
# 9         us-gaap_CommonStockParOrStatedValuePerShare
# 10                us-gaap_CommonStockSharesAuthorized
# 11                us-gaap_CommonStockSharesAuthorized
# 12                    us-gaap_CommonStockSharesIssued
# 13                    us-gaap_CommonStockSharesIssued
# 14               us-gaap_CommonStockSharesOutstanding
# 15               us-gaap_CommonStockSharesOutstanding
# 16     us-gaap_PreferredStockParOrStatedValuePerShare
# 17     us-gaap_PreferredStockParOrStatedValuePerShare
# 18             us-gaap_PreferredStockSharesAuthorized
# 19             us-gaap_PreferredStockSharesAuthorized
# 20                 us-gaap_PreferredStockSharesIssued
# 21                 us-gaap_PreferredStockSharesIssued
# 22                                   dei_DocumentType
# 23                        dei_DocumentQuarterlyReport
# 24                          dei_DocumentPeriodEndDate
#
#                                    concept_schema_url  \
# 0    https://xbrl.sec.gov/dei/2019/dei-2019-01-31.xsd
# 1    https://xbrl.sec.gov/dei/2019/dei-2019-01-31.xsd
# 2    https://xbrl.sec.gov/dei/2019/dei-2019-01-31.xsd
# 3    https://xbrl.sec.gov/dei/2019/dei-2019-01-31.xsd
# 4    https://xbrl.sec.gov/dei/2019/dei-2019-01-31.xsd
# 5   https://www.sec.gov/Archives/edgar/data/916789...
# 6   https://www.sec.gov/Archives/edgar/data/916789...
# 7   https://www.sec.gov/Archives/edgar/data/916789...
# 8   https://www.sec.gov/Archives/edgar/data/916789...
# 9   http://xbrl.fasb.org/us-gaap/2018/elts/us-gaap...
# 10  http://xbrl.fasb.org/us-gaap/2018/elts/us-gaap...
# 11  http://xbrl.fasb.org/us-gaap/2018/elts/us-gaap...
# 12  http://xbrl.fasb.org/us-gaap/2018/elts/us-gaap...
# 13  http://xbrl.fasb.org/us-gaap/2018/elts/us-gaap...
# 14  http://xbrl.fasb.org/us-gaap/2018/elts/us-gaap...
# 15  http://xbrl.fasb.org/us-gaap/2018/elts/us-gaap...
# 16  http://xbrl.fasb.org/us-gaap/2018/elts/us-gaap...
# 17  http://xbrl.fasb.org/us-gaap/2018/elts/us-gaap...
# 18  http://xbrl.fasb.org/us-gaap/2018/elts/us-gaap...
# 19  http://xbrl.fasb.org/us-gaap/2018/elts/us-gaap...
# 20  http://xbrl.fasb.org/us-gaap/2018/elts/us-gaap...
# 21  http://xbrl.fasb.org/us-gaap/2018/elts/us-gaap...
# 22   https://xbrl.sec.gov/dei/2019/dei-2019-01-31.xsd
# 23   https://xbrl.sec.gov/dei/2019/dei-2019-01-31.xsd
# 24   https://xbrl.sec.gov/dei/2019/dei-2019-01-31.xsd
#
#                                     concept_name concept_substitution_group  \
# 0                                  AmendmentFlag                       item
# 1                       CurrentFiscalYearEndDate                       item
# 2                      DocumentFiscalPeriodFocus                       item
# 3                        DocumentFiscalYearFocus                       item
# 4                          EntityCentralIndexKey                       item
# 5      AllowanceForDoubtfulReceivablesAndReturns                       item
# 6      AllowanceForDoubtfulReceivablesAndReturns                       item
# 7   OtherAssetsNoncurrentAccumulatedAmortization                       item
# 8   OtherAssetsNoncurrentAccumulatedAmortization                       item
# 9            CommonStockParOrStatedValuePerShare                       item
# 10                   CommonStockSharesAuthorized                       item
# 11                   CommonStockSharesAuthorized                       item
# 12                       CommonStockSharesIssued                       item
# 13                       CommonStockSharesIssued                       item
# 14                  CommonStockSharesOutstanding                       item
# 15                  CommonStockSharesOutstanding                       item
# 16        PreferredStockParOrStatedValuePerShare                       item
# 17        PreferredStockParOrStatedValuePerShare                       item
# 18                PreferredStockSharesAuthorized                       item
# 19                PreferredStockSharesAuthorized                       item
# 20                    PreferredStockSharesIssued                       item
# 21                    PreferredStockSharesIssued                       item
# 22                                  DocumentType                       item
# 23                       DocumentQuarterlyReport                       item
# 24                         DocumentPeriodEndDate                       item
#
#     concept_concept_type  concept_abstract  concept_nillable  \
# 0                    NaN             False              True
# 1                    NaN             False              True
# 2                    NaN             False              True
# 3                    NaN             False              True
# 4                    NaN             False              True
# 5                    NaN             False              True
# 6                    NaN             False              True
# 7                    NaN             False              True
# 8                    NaN             False              True
# 9                    NaN             False              True
# 10                   NaN             False              True
# 11                   NaN             False              True
# 12                   NaN             False              True
# 13                   NaN             False              True
# 14                   NaN             False              True
# 15                   NaN             False              True
# 16                   NaN             False              True
# 17                   NaN             False              True
# 18                   NaN             False              True
# 19                   NaN             False              True
# 20                   NaN             False              True
# 21                   NaN             False              True
# 22                   NaN             False              True
# 23                   NaN             False              True
# 24                   NaN             False              True
#
#    concept_period_type concept_balance  \
# 0             duration             NaN
# 1             duration             NaN
# 2             duration             NaN
# 3             duration             NaN
# 4             duration             NaN
# 5              instant          credit
# 6              instant          credit
# 7              instant          credit
# 8              instant          credit
# 9              instant             NaN
# 10             instant             NaN
# 11             instant             NaN
# 12             instant             NaN
# 13             instant             NaN
# 14             instant             NaN
# 15             instant             NaN
# 16             instant             NaN
# 17             instant             NaN
# 18             instant             NaN
# 19             instant             NaN
# 20             instant             NaN
# 21             instant             NaN
# 22            duration             NaN
# 23            duration             NaN
# 24            duration             NaN
#
#                                concept_labels_0_label  \
# 0   lab_dei_AmendmentFlag_5D284E133EF572B0C51CDC8E...
# 1   lab_dei_CurrentFiscalYearEndDate_4345D9F5457CA...
# 2   lab_dei_DocumentFiscalPeriodFocus_0EE92EC39AC0...
# 3   lab_dei_DocumentFiscalYearFocus_D877BA5B88EF98...
# 4   lab_dei_EntityCentralIndexKey_4416755CF51C73A4...
# 5   lab_hele_AllowanceForDoubtfulReceivablesAndRet...
# 6   lab_hele_AllowanceForDoubtfulReceivablesAndRet...
# 7   lab_hele_OtherAssetsNoncurrentAccumulatedAmort...
# 8   lab_hele_OtherAssetsNoncurrentAccumulatedAmort...
# 9   lab_us-gaap_CommonStockParOrStatedValuePerShar...
# 10  lab_us-gaap_CommonStockSharesAuthorized_F8F2CE...
# 11  lab_us-gaap_CommonStockSharesAuthorized_F8F2CE...
# 12  lab_us-gaap_CommonStockSharesIssued_5D677A44B2...
# 13  lab_us-gaap_CommonStockSharesIssued_5D677A44B2...
# 14  lab_us-gaap_CommonStockSharesOutstanding_6C95F...
# 15  lab_us-gaap_CommonStockSharesOutstanding_6C95F...
# 16  lab_us-gaap_PreferredStockParOrStatedValuePerS...
# 17  lab_us-gaap_PreferredStockParOrStatedValuePerS...
# 18  lab_us-gaap_PreferredStockSharesAuthorized_C90...
# 19  lab_us-gaap_PreferredStockSharesAuthorized_C90...
# 20  lab_us-gaap_PreferredStockSharesIssued_0D9C56B...
# 21  lab_us-gaap_PreferredStockSharesIssued_0D9C56B...
# 22  lab_dei_DocumentType_82D562F645A7172E13DBDC8E1...
# 23  lab_dei_DocumentQuarterlyReport_2A09503CAC4FA8...
# 24  lab_dei_DocumentPeriodEndDate_8A2B11842A934BD0...
#
#    concept_labels_0_language  \
# 0                      en-US
# 1                      en-US
# 2                      en-US
# 3                      en-US
# 4                      en-US
# 5                      en-US
# 6                      en-US
# 7                      en-US
# 8                      en-US
# 9                      en-US
# 10                     en-US
# 11                     en-US
# 12                     en-US
# 13                     en-US
# 14                     en-US
# 15                     en-US
# 16                     en-US
# 17                     en-US
# 18                     en-US
# 19                     en-US
# 20                     en-US
# 21                     en-US
# 22                     en-US
# 23                     en-US
# 24                     en-US
#
#                                 concept_labels_0_text  \
# 0                                      Amendment Flag
# 1                        Current Fiscal Year End Date
# 2                        Document Fiscal Period Focus
# 3                          Document Fiscal Year Focus
# 4                            Entity Central Index Key
# 5   Receivables - principally trade, allowances (i...
# 6   Receivables - principally trade, allowances (i...
# 7   Other assets, accumulated amortization (in dol...
# 8   Other assets, accumulated amortization (in dol...
# 9     Common shares, par value (in dollars per share)
# 10        Common stock, authorized shares (in shares)
# 11        Common stock, authorized shares (in shares)
# 12            Common stock, shares issued (in shares)
# 13            Common stock, shares issued (in shares)
# 14       Common stock, shares outstanding (in shares)
# 15       Common stock, shares outstanding (in shares)
# 16  Cumulative preferred stock, non-voting, par (i...
# 17  Cumulative preferred stock, non-voting, par (i...
# 18  Cumulative preferred stock, non-voting, author...
# 19  Cumulative preferred stock, non-voting, author...
# 20  Cumulative preferred stock, non-voting, issued...
# 21  Cumulative preferred stock, non-voting, issued...
# 22                                      Document Type
# 23                          Document Quarterly Report
# 24                           Document Period End Date
#
#                    concept_labels_0_label_type  \
# 0     http://www.xbrl.org/2003/role/terseLabel
# 1     http://www.xbrl.org/2003/role/terseLabel
# 2     http://www.xbrl.org/2003/role/terseLabel
# 3     http://www.xbrl.org/2003/role/terseLabel
# 4     http://www.xbrl.org/2003/role/terseLabel
# 5     http://www.xbrl.org/2003/role/terseLabel
# 6     http://www.xbrl.org/2003/role/terseLabel
# 7     http://www.xbrl.org/2003/role/terseLabel
# 8     http://www.xbrl.org/2003/role/terseLabel
# 9   http://www.xbrl.org/2003/role/verboseLabel
# 10    http://www.xbrl.org/2003/role/terseLabel
# 11    http://www.xbrl.org/2003/role/terseLabel
# 12    http://www.xbrl.org/2003/role/terseLabel
# 13    http://www.xbrl.org/2003/role/terseLabel
# 14    http://www.xbrl.org/2003/role/terseLabel
# 15    http://www.xbrl.org/2003/role/terseLabel
# 16    http://www.xbrl.org/2003/role/terseLabel
# 17    http://www.xbrl.org/2003/role/terseLabel
# 18    http://www.xbrl.org/2003/role/terseLabel
# 19    http://www.xbrl.org/2003/role/terseLabel
# 20  http://www.xbrl.org/2003/role/verboseLabel
# 21  http://www.xbrl.org/2003/role/verboseLabel
# 22    http://www.xbrl.org/2003/role/terseLabel
# 23    http://www.xbrl.org/2003/role/terseLabel
# 24    http://www.xbrl.org/2003/role/terseLabel
#
#                                concept_labels_1_label  \
# 0   lab_dei_AmendmentFlag_5D284E133EF572B0C51CDC8E...
# 1   lab_dei_CurrentFiscalYearEndDate_4345D9F5457CA...
# 2   lab_dei_DocumentFiscalPeriodFocus_0EE92EC39AC0...
# 3   lab_dei_DocumentFiscalYearFocus_D877BA5B88EF98...
# 4   lab_dei_EntityCentralIndexKey_4416755CF51C73A4...
# 5   lab_hele_AllowanceForDoubtfulReceivablesAndRet...
# 6   lab_hele_AllowanceForDoubtfulReceivablesAndRet...
# 7   lab_hele_OtherAssetsNoncurrentAccumulatedAmort...
# 8   lab_hele_OtherAssetsNoncurrentAccumulatedAmort...
# 9                                                 NaN
# 10  lab_us-gaap_CommonStockSharesAuthorized_F8F2CE...
# 11  lab_us-gaap_CommonStockSharesAuthorized_F8F2CE...
# 12  lab_us-gaap_CommonStockSharesIssued_5D677A44B2...
# 13  lab_us-gaap_CommonStockSharesIssued_5D677A44B2...
# 14  lab_us-gaap_CommonStockSharesOutstanding_6C95F...
# 15  lab_us-gaap_CommonStockSharesOutstanding_6C95F...
# 16  lab_us-gaap_PreferredStockParOrStatedValuePerS...
# 17  lab_us-gaap_PreferredStockParOrStatedValuePerS...
# 18  lab_us-gaap_PreferredStockSharesAuthorized_C90...
# 19  lab_us-gaap_PreferredStockSharesAuthorized_C90...
# 20  lab_us-gaap_PreferredStockSharesIssued_0D9C56B...
# 21  lab_us-gaap_PreferredStockSharesIssued_0D9C56B...
# 22  lab_dei_DocumentType_82D562F645A7172E13DBDC8E1...
# 23  lab_dei_DocumentQuarterlyReport_2A09503CAC4FA8...
# 24  lab_dei_DocumentPeriodEndDate_8A2B11842A934BD0...
#
#    concept_labels_1_language  \
# 0                      en-US
# 1                      en-US
# 2                      en-US
# 3                      en-US
# 4                      en-US
# 5                      en-US
# 6                      en-US
# 7                      en-US
# 8                      en-US
# 9                        NaN
# 10                     en-US
# 11                     en-US
# 12                     en-US
# 13                     en-US
# 14                     en-US
# 15                     en-US
# 16                     en-US
# 17                     en-US
# 18                     en-US
# 19                     en-US
# 20                     en-US
# 21                     en-US
# 22                     en-US
# 23                     en-US
# 24                     en-US
#
#                                concept_labels_1_text  \
# 0                                     Amendment Flag
# 1                       Current Fiscal Year End Date
# 2                       Document Fiscal Period Focus
# 3                         Document Fiscal Year Focus
# 4                           Entity Central Index Key
# 5     Allowance for Doubtful Receivables and Returns
# 6     Allowance for Doubtful Receivables and Returns
# 7   Other Assets Noncurrent Accumulated Amortization
# 8   Other Assets Noncurrent Accumulated Amortization
# 9                                                NaN
# 10                   Common Stock, Shares Authorized
# 11                   Common Stock, Shares Authorized
# 12                      Common Stock, Shares, Issued
# 13                      Common Stock, Shares, Issued
# 14                 Common Stock, Shares, Outstanding
# 15                 Common Stock, Shares, Outstanding
# 16    Preferred Stock, Par or Stated Value Per Share
# 17    Preferred Stock, Par or Stated Value Per Share
# 18                Preferred Stock, Shares Authorized
# 19                Preferred Stock, Shares Authorized
# 20                    Preferred Stock, Shares Issued
# 21                    Preferred Stock, Shares Issued
# 22                                     Document Type
# 23                         Document Quarterly Report
# 24                          Document Period End Date
#
#             concept_labels_1_label_type                 concept_type  \
# 0   http://www.xbrl.org/2003/role/label        xbrli:booleanItemType
# 1   http://www.xbrl.org/2003/role/label      xbrli:gMonthDayItemType
# 2   http://www.xbrl.org/2003/role/label     dei:fiscalPeriodItemType
# 3   http://www.xbrl.org/2003/role/label          xbrli:gYearItemType
# 4   http://www.xbrl.org/2003/role/label  dei:centralIndexKeyItemType
# 5   http://www.xbrl.org/2003/role/label       xbrli:monetaryItemType
# 6   http://www.xbrl.org/2003/role/label       xbrli:monetaryItemType
# 7   http://www.xbrl.org/2003/role/label       xbrli:monetaryItemType
# 8   http://www.xbrl.org/2003/role/label       xbrli:monetaryItemType
# 9                                   NaN         num:perShareItemType
# 10  http://www.xbrl.org/2003/role/label         xbrli:sharesItemType
# 11  http://www.xbrl.org/2003/role/label         xbrli:sharesItemType
# 12  http://www.xbrl.org/2003/role/label         xbrli:sharesItemType
# 13  http://www.xbrl.org/2003/role/label         xbrli:sharesItemType
# 14  http://www.xbrl.org/2003/role/label         xbrli:sharesItemType
# 15  http://www.xbrl.org/2003/role/label         xbrli:sharesItemType
# 16  http://www.xbrl.org/2003/role/label         num:perShareItemType
# 17  http://www.xbrl.org/2003/role/label         num:perShareItemType
# 18  http://www.xbrl.org/2003/role/label         xbrli:sharesItemType
# 19  http://www.xbrl.org/2003/role/label         xbrli:sharesItemType
# 20  http://www.xbrl.org/2003/role/label         xbrli:sharesItemType
# 21  http://www.xbrl.org/2003/role/label         xbrli:sharesItemType
# 22  http://www.xbrl.org/2003/role/label   dei:submissionTypeItemType
# 23  http://www.xbrl.org/2003/role/label        xbrli:booleanItemType
# 24  http://www.xbrl.org/2003/role/label           xbrli:dateItemType
#
#    context_xml_id  context_entity context_start_date context_end_date  \
# 0     FD2020Q3YTD          916789         2019-03-01       2019-11-30
# 1     FD2020Q3YTD          916789         2019-03-01       2019-11-30
# 2     FD2020Q3YTD          916789         2019-03-01       2019-11-30
# 3     FD2020Q3YTD          916789         2019-03-01       2019-11-30
# 4     FD2020Q3YTD          916789         2019-03-01       2019-11-30
# 5        FI2019Q4          916789                NaT              NaT
# 6        FI2020Q3          916789                NaT              NaT
# 7        FI2019Q4          916789                NaT              NaT
# 8        FI2020Q3          916789                NaT              NaT
# 9        FI2019Q4          916789                NaT              NaT
# 10       FI2019Q4          916789                NaT              NaT
# 11       FI2020Q3          916789                NaT              NaT
# 12       FI2019Q4          916789                NaT              NaT
# 13       FI2020Q3          916789                NaT              NaT
# 14       FI2019Q4          916789                NaT              NaT
# 15       FI2020Q3          916789                NaT              NaT
# 16       FI2019Q4          916789                NaT              NaT
# 17       FI2020Q3          916789                NaT              NaT
# 18       FI2019Q4          916789                NaT              NaT
# 19       FI2020Q3          916789                NaT              NaT
# 20       FI2019Q4          916789                NaT              NaT
# 21       FI2020Q3          916789                NaT              NaT
# 22    FD2020Q3YTD          916789         2019-03-01       2019-11-30
# 23    FD2020Q3YTD          916789         2019-03-01       2019-11-30
# 24    FD2020Q3YTD          916789         2019-03-01       2019-11-30
#
#          value                                             xml_id  footnote  \
# 0        false  Fact-87588C95AF19570BA20A05231048F4A7-wk-Fact-...       NaN
# 1      --02-28  Fact-93FBA869F0515044BCA841D8B9ADA0DE-wk-Fact-...       NaN
# 2           Q3  Fact-AFA4036E9A9257A9B4359A764409D1AF-wk-Fact-...       NaN
# 3         2020  Fact-4FD82D8CF28E539390915456E914C901-wk-Fact-...       NaN
# 4   0000916789  Fact-A151E9D698F3599D99D70CABC61652C0-wk-Fact-...       NaN
# 5    2032000.0  Fact-26B25EF56B6B5D4CB66183C9A2A59756-wk-Fact-...       NaN
# 6    1486000.0  Fact-8F00B5266AA15932B3A434D42DBA1786-wk-Fact-...       NaN
# 7    2115000.0  Fact-F9A090E92C9354B9BEDE638CB0C432AF-wk-Fact-...       NaN
# 8    2167000.0  Fact-373A10C4BE9954ABBE8CB090B4C948D3-wk-Fact-...       NaN
# 9          0.1  Fact-540A4269266E5F49AC42A2F116D73801-wk-Fact-...       NaN
# 10  50000000.0  Fact-1BC3296873AA5402966FC65C2541ED88-wk-Fact-...       NaN
# 11  50000000.0  Fact-283892B55AD650898C14FAAB72E69186-wk-Fact-...       NaN
# 12  24946046.0  Fact-DFCDE7467D0157D7950AF90078F94D1E-wk-Fact-...       NaN
# 13  25166771.0  Fact-62B885C74F2857AB8234CA37A3401FD9-wk-Fact-...       NaN
# 14  24946046.0  Fact-0990F64B3C4A59C4B433BFD83E948FF9-wk-Fact-...       NaN
# 15  25166771.0  Fact-79519A0EBFBD591282986AE96AD8F19F-wk-Fact-...       NaN
# 16         1.0  Fact-47D854EBFDAE5D5B8FB6FB03A1A06C89-wk-Fact-...       NaN
# 17         1.0  Fact-0898E20E40345B43BED397A06885D378-wk-Fact-...       NaN
# 18   2000000.0  Fact-80995FEF5C0E5B339BFFAF85AEB1CA22-wk-Fact-...       NaN
# 19   2000000.0  Fact-05D29A99B43F5E848CAE3F122C3149D1-wk-Fact-...       NaN
# 20         0.0  Fact-F3583AF4A7895AA4A9707CF3F43FFEC2-wk-Fact-...       NaN
# 21         0.0  Fact-804F24DDEF59504CADEA33ECCBB9FB3D-wk-Fact-...       NaN
# 22        10-Q  d20510052e550-wk-Fact-8A31CAB07FFB598FB3A30EA7...       NaN
# 23        true  d20510052e563-wk-Fact-C843CBFE45E251ACA892EE50...       NaN
# 24  2019-11-30  d20510052e573-wk-Fact-BACD63ECEC445F87B0049422...       NaN
#
#                                concept_labels_2_label  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   lab_hele_AllowanceForDoubtfulReceivablesAndRet...
# 6   lab_hele_AllowanceForDoubtfulReceivablesAndRet...
# 7   lab_hele_OtherAssetsNoncurrentAccumulatedAmort...
# 8   lab_hele_OtherAssetsNoncurrentAccumulatedAmort...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
#
#    concept_labels_2_language  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5                      en-US
# 6                      en-US
# 7                      en-US
# 8                      en-US
# 9                        NaN
# 10                       NaN
# 11                       NaN
# 12                       NaN
# 13                       NaN
# 14                       NaN
# 15                       NaN
# 16                       NaN
# 17                       NaN
# 18                       NaN
# 19                       NaN
# 20                       NaN
# 21                       NaN
# 22                       NaN
# 23                       NaN
# 24                       NaN
#
#                                 concept_labels_2_text  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   A valuation allowance principally for trade re...
# 6   A valuation allowance principally for trade re...
# 7   This element represents the accumulated amount...
# 8   This element represents the accumulated amount...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
#
#                     concept_labels_2_label_type context_instant_date  \
# 0                                           NaN                  NaT
# 1                                           NaN                  NaT
# 2                                           NaN                  NaT
# 3                                           NaN                  NaT
# 4                                           NaN                  NaT
# 5   http://www.xbrl.org/2003/role/documentation           2019-02-28
# 6   http://www.xbrl.org/2003/role/documentation           2019-11-30
# 7   http://www.xbrl.org/2003/role/documentation           2019-02-28
# 8   http://www.xbrl.org/2003/role/documentation           2019-11-30
# 9                                           NaN           2019-02-28
# 10                                          NaN           2019-02-28
# 11                                          NaN           2019-11-30
# 12                                          NaN           2019-02-28
# 13                                          NaN           2019-11-30
# 14                                          NaN           2019-02-28
# 15                                          NaN           2019-11-30
# 16                                          NaN           2019-02-28
# 17                                          NaN           2019-11-30
# 18                                          NaN           2019-02-28
# 19                                          NaN           2019-11-30
# 20                                          NaN           2019-02-28
# 21                                          NaN           2019-11-30
# 22                                          NaN                  NaT
# 23                                          NaN                  NaT
# 24                                          NaN                  NaT
#
#    unit_unit_id    unit_unit  decimals unit_numerator unit_denominator
# 0           NaN          NaN       NaN            NaN              NaN
# 1           NaN          NaN       NaN            NaN              NaN
# 2           NaN          NaN       NaN            NaN              NaN
# 3           NaN          NaN       NaN            NaN              NaN
# 4           NaN          NaN       NaN            NaN              NaN
# 5           usd  iso4217:USD      -3.0            NaN              NaN
# 6           usd  iso4217:USD      -3.0            NaN              NaN
# 7           usd  iso4217:USD      -3.0            NaN              NaN
# 8           usd  iso4217:USD      -3.0            NaN              NaN
# 9   usdPerShare          NaN       NaN    iso4217:USD           shares
# 10       shares       shares       NaN            NaN              NaN
# 11       shares       shares       NaN            NaN              NaN
# 12       shares       shares       NaN            NaN              NaN
# 13       shares       shares       NaN            NaN              NaN
# 14       shares       shares       NaN            NaN              NaN
# 15       shares       shares       NaN            NaN              NaN
# 16  usdPerShare          NaN       NaN    iso4217:USD           shares
# 17  usdPerShare          NaN       NaN    iso4217:USD           shares
# 18       shares       shares       NaN            NaN              NaN
# 19       shares       shares       NaN            NaN              NaN
# 20       shares       shares       NaN            NaN              NaN
# 21       shares       shares       NaN            NaN              NaN
# 22          NaN          NaN       NaN            NaN              NaN
# 23          NaN          NaN       NaN            NaN              NaN
# 24          NaN          NaN       NaN            NaN              NaN

# %% [markdown]
# ### View the filing GAAP metadata
# * While most XBRL facts contain numeric GAAP data / balance sheet items, many others contain filing specific metadata and filing text items.
# * This code extracts all filing specific metadata.

# %%
from Source.GAAP.GaapFeatures import get_filing_metadata

gaap_meatadata = get_filing_metadata(gaap_raw)
gaap_meatadata
# Out:
#                                          concept_name  \
# 0                                       AmendmentFlag
# 1                            CurrentFiscalYearEndDate
# 2                           DocumentFiscalPeriodFocus
# 22                                       DocumentType
# 23                            DocumentQuarterlyReport
# 24                              DocumentPeriodEndDate
# 25                           DocumentTransitionReport
# 26                                   EntityFileNumber
# 27                               EntityRegistrantName
# 28                EntityIncorporationStateCountryCode
# 29                      EntityTaxIdentificationNumber
# 30                          EntityAddressAddressLine1
# 31                            EntityAddressCityOrTown
# 32                       EntityAddressStateOrProvince
# 35                                   LocalPhoneNumber
# 36                                   Security12bTitle
# 37                                      TradingSymbol
# 38                               SecurityExchangeName
# 39                       EntityCurrentReportingStatus
# 40                       EntityInteractiveDataCurrent
# 41                                EntityFilerCategory
# 42                                EntitySmallBusiness
# 43                        EntityEmergingGrowthCompany
# 44                                 EntityShellCompany
# 338  OperatingLeaseWeightedAverageRemainingLeaseTerm1
# 421              StockRepurchaseProgramPeriodInForce1
#
#                                         value
# 0                                       false
# 1                                     --02-28
# 2                                          Q3
# 22                                       10-Q
# 23                                       true
# 24                                 2019-11-30
# 25                                      false
# 26                                  001-14669
# 27                      HELEN OF TROY LIMITED
# 28                                         D0
# 29                                 74-2692550
# 30                      1 Helen of Troy Plaza
# 31                                    El Paso
# 32                                         TX
# 35                                   225-8000
# 36   Common Shares, $0.10 par value per share
# 37                                       HELE
# 38                                     NASDAQ
# 39                                        Yes
# 40                                        Yes
# 41                    Large Accelerated Filer
# 42                                      false
# 43                                      false
# 44                                      false
# 338                                P10Y10M24D
# 421                                       P3Y

# %% [markdown]
# ### What is the approximate 90 day period surrounding the filing?
# Here we use the filing specific metadata to determine the fiscal year ending date and the current quarter dates for the filing in process.

# %%
from datetime import datetime, timedelta, date, time

gaap_metadata_dict = get_filing_metadata(gaap_raw, as_dict=True)

# Get the DocumentPeriodEndDate reported for this filing 
document_period_end_date = pd.Timestamp(gaap_metadata_dict['DocumentPeriodEndDate'])

# Find a cutoff date for approximately one quarter before the DocumentPeriodEndDate
document_period_start_date = document_period_end_date - timedelta(days=97)

# Print the quarter and approximate dates for this filing 
print('CurrentFiscalYearEndDate:', gaap_metadata_dict['CurrentFiscalYearEndDate'])
print('DocumentFiscalPeriodFocus:', gaap_metadata_dict['DocumentFiscalPeriodFocus'])
print('Quarter Start Date:', document_period_start_date)
print('DocumentPeriodEndDate:', document_period_end_date)
# Out:
# CurrentFiscalYearEndDate: --02-28
# DocumentFiscalPeriodFocus: Q3
# Quarter Start Date: 2019-08-25 00:00:00
# DocumentPeriodEndDate: 2019-11-30 00:00:00

# %% [markdown]
# ### View All Fiscal Durations in this GAAP Data
# * This function identifies all fiscal durations disclosed in a filing's XBRL instance document facts.
# * The data is pivoted to create one row per duration containing all numeric facts / features disclosed in the filing.
# * Text / String and html concept types are excluded to avoid including items like a zip code that could possibly be converted to a numeric GAAP feature.

# %%
from Source.GAAP.GaapFeatures import get_fiscal_duration_features

gaap_FD = get_fiscal_duration_features(gaap_raw)

gaap_FD
# Out:
# concept_name context_start_date context_end_date  \
# 0                    2018-03-01       2018-11-30
# 1                    2018-09-01       2018-11-30
# 2                    2019-03-01       2019-03-01
# 3                    2019-03-01       2019-11-30
# 4                    2019-05-08       2019-05-08
# 5                    2019-09-01       2019-11-30
#
# concept_name  AllocatedShareBasedCompensationExpenseNetOfTax  \
# 0                                                 16020000.0
# 1                                                  5618000.0
# 2                                                        NaN
# 3                                                 17309000.0
# 4                                                        NaN
# 5                                                  4415000.0
#
# concept_name  AmortizationOfFinancingCosts  AmortizationOfIntangibleAssets  \
# 0                                 761000.0                      10822000.0
# 1                                      NaN                       3300000.0
# 2                                      NaN                             NaN
# 3                                 763000.0                      13129000.0
# 4                                      NaN                             NaN
# 5                                      NaN                       4790000.0
#
# concept_name  CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalentsPeriodIncreaseDecreaseExcludingExchangeRateEffect  \
# 0                                                    -1602000.0
# 1                                                           NaN
# 2                                                           NaN
# 3                                                     7766000.0
# 4                                                           NaN
# 5                                                           NaN
#
# concept_name  CashProvidedByUsedInFinancingActivitiesDiscontinuedOperations  \
# 0                                                           0.0
# 1                                                           NaN
# 2                                                           NaN
# 3                                                           0.0
# 4                                                           NaN
# 5                                                           NaN
#
# concept_name  CashProvidedByUsedInInvestingActivitiesDiscontinuedOperations  \
# 0                                                           0.0
# 1                                                           NaN
# 2                                                           NaN
# 3                                                           0.0
# 4                                                           NaN
# 5                                                           NaN
#
# concept_name  CashProvidedByUsedInOperatingActivitiesDiscontinuedOperations  \
# 0                                                    -5231000.0
# 1                                                           NaN
# 2                                                           NaN
# 3                                                           0.0
# 4                                                           NaN
# 5                                                           NaN
#
# concept_name  ComprehensiveIncomeNetOfTax  ...  \
# 0                             135855000.0  ...
# 1                              50030000.0  ...
# 2                                     NaN  ...
# 3                             149412000.0  ...
# 4                                     NaN  ...
# 5                              68569000.0  ...
#
# concept_name  StockIssuedDuringPeriodValueShareBasedCompensationExcludingStockOptionsAndEmployeeStockPurchaseProgramNetOfTaxEffect  \
# 0                                                    17029000.0
# 1                                                     6016000.0
# 2                                                           NaN
# 3                                                    18743000.0
# 4                                                           NaN
# 5                                                     4758000.0
#
# concept_name  StockIssuedDuringPeriodValueStockOptionsExercisedNetOfTaxEffect  \
# 0                                                     6081000.0
# 1                                                      566000.0
# 2                                                           NaN
# 3                                                     4190000.0
# 4                                                           NaN
# 5                                                      557000.0
#
# concept_name  StockRepurchasedAndRetiredDuringPeriodValue  \
# 0                                             142415000.0
# 1                                             100175000.0
# 2                                                     NaN
# 3                                              10133000.0
# 4                                                     NaN
# 5                                               1002000.0
#
# concept_name  UnrecognizedTaxBenefitsDecreasesResultingFromRecognitionOfExcessTaxBenefitsFromShareBasedCompensation  \
# 0                                                      700000.0
# 1                                                           NaN
# 2                                                           NaN
# 3                                                     1000000.0
# 4                                                           NaN
# 5                                                           NaN
#
# concept_name  Unrecognizedtaxbenefitfromfavorableresolutionofuncertaintaxposition  \
# 0                                                      800000.0
# 1                                                           NaN
# 2                                                           NaN
# 3                                                     2800000.0
# 4                                                           NaN
# 5                                                           NaN
#
# concept_name  WeightedAverageNumberOfDilutedSharesOutstanding  \
# 0                                                  26520000.0
# 1                                                  26366000.0
# 2                                                         NaN
# 3                                                  25295000.0
# 4                                                         NaN
# 5                                                  25396000.0
#
# concept_name  WeightedAverageNumberOfSharesOutstandingBasic  duration_days  \
# 0                                                26321000.0       274 days
# 1                                                26057000.0        90 days
# 2                                                       NaN         0 days
# 3                                                25099000.0       274 days
# 4                                                       NaN         0 days
# 5                                                25161000.0        90 days
#
# concept_name  duration_YTD_days_dist  duration_90_days_dist
# 0                             4 days               184 days
# 1                           180 days                 0 days
# 2                           270 days                90 days
# 3                             4 days               184 days
# 4                           270 days                90 days
# 5                           180 days                 0 days
#
# [6 rows x 101 columns]

# %% [markdown]
# ### Get the two most recent QoQ (quarter over quarter) fiscal durations
# **Here are the current rules I am using to identify a filng's current QoQ fiscal durations:**
# * The fiscal duration periods closest to 90 days are considered quarterly durations.
# * Fiscal durations must also be within 7 days of the 90 day period to qualify as 'quarterly'.
# * There must be at least two quarterly durations disclosed with the same number of days in each duration.
# * When there are more than two quarterly durations disclosed in a single filing, the two most recent durations are returned.
# * All QoQ raw GAAP features and values are returned in ascending order by context start and end date.

# %%
current_QoQ = get_current_QoQ_fiscal_durations(gaap_FD)

with pd.option_context('display.max_rows', 1000, 'display.max_columns', None):
    display(current_QoQ)
# Out:
# concept_name context_start_date context_end_date  \
# 1                    2018-09-01       2018-11-30
# 5                    2019-09-01       2019-11-30
#
# concept_name  AllocatedShareBasedCompensationExpenseNetOfTax  \
# 1                                                  5618000.0
# 5                                                  4415000.0
#
# concept_name  AmortizationOfIntangibleAssets  ComprehensiveIncomeNetOfTax  \
# 1                                  3300000.0                   50030000.0
# 5                                  4790000.0                   68569000.0
#
# concept_name  CostOfGoodsAndServicesSold  \
# 1                            249236000.0
# 5                            264764000.0
#
# concept_name  DepreciationDepletionAndAmortization  EarningsPerShareBasic  \
# 1                                        7195000.0                   1.90
# 5                                        8760000.0                   2.73
#
# concept_name  EarningsPerShareDiluted  GrossProfit  \
# 1                                1.88  181845000.0
# 5                                2.71  209973000.0
#
# concept_name  IncomeLossFromContinuingOperationsBeforeIncomeTaxesExtraordinaryItemsNoncontrollingInterest  \
# 1                                                    58340000.0
# 5                                                    76594000.0
#
# concept_name  IncomeLossFromContinuingOperationsIncludingPortionAttributableToNoncontrollingInterest  \
# 1                                                    54320000.0
# 5                                                    68699000.0
#
# concept_name  IncomeLossFromContinuingOperationsPerBasicShare  \
# 1                                                        2.08
# 5                                                        2.73
#
# concept_name  IncomeLossFromContinuingOperationsPerDilutedShare  \
# 1                                                          2.06
# 5                                                          2.71
#
# concept_name  IncomeLossFromDiscontinuedOperationsNetOfTax  \
# 1                                               -4850000.0
# 5                                                      0.0
#
# concept_name  IncomeLossFromDiscontinuedOperationsNetOfTaxPerBasicShare  \
# 1                                                         -0.19
# 5                                                          0.00
#
# concept_name  IncomeLossFromDiscontinuedOperationsNetOfTaxPerDilutedShare  \
# 1                                                         -0.18
# 5                                                          0.00
#
# concept_name  IncomeTaxExpenseBenefit  \
# 1                           4020000.0
# 5                           7895000.0
#
# concept_name  IncomeTaxExpenseBenefitPercentageOfIncomeBeforeIncomeTaxes  \
# 1                                                         0.069
# 5                                                         0.103
#
# concept_name  IncrementalCommonSharesAttributableToShareBasedPaymentArrangements  \
# 1                                                      309000.0
# 5                                                      235000.0
#
# concept_name  InterestExpense  NetIncomeLoss  \
# 1                   2971000.0     49470000.0
# 5                   2767000.0     68699000.0
#
# concept_name  NetIncomeLossAvailableToCommonStockholdersBasic  \
# 1                                                  49470000.0
# 5                                                  68699000.0
#
# concept_name  NetIncomeLossFromContinuingOperationsAvailableToCommonShareholdersBasic  \
# 1                                                    54320000.0
# 5                                                    68699000.0
#
# concept_name  NonoperatingIncomeExpense  OperatingIncomeLoss  \
# 1                               15000.0           61296000.0
# 5                               92000.0           79269000.0
#
# concept_name  OtherComprehensiveIncomeForeignCurrencyTransactionAndTranslationGainLossArisingDuringPeriodNetOfTax  \
# 1                                                      514000.0
# 5                                                    -1729000.0
#
# concept_name  OtherComprehensiveIncomeLossNetOfTax  \
# 1                                         560000.0
# 5                                        -130000.0
#
# concept_name  PaymentsToAcquireProductiveAssets  RestructuringCharges  \
# 1                                     9105000.0               25000.0
# 5                                     4386000.0               12000.0
#
# concept_name  RevenueFromContractWithCustomerExcludingAssessedTax  \
# 1                                                   431081000.0
# 5                                                   474737000.0
#
# concept_name  SellingGeneralAndAdministrativeExpense  \
# 1                                        120524000.0
# 5                                        130692000.0
#
# concept_name  ShareBasedCompensationEffectOnEarningsPerShareBasic  \
# 1                                                          0.22
# 5                                                          0.18
#
# concept_name  ShareBasedCompensationEffectOnEarningsPerShareDiluted  \
# 1                                                          0.21
# 5                                                          0.17
#
# concept_name  StockIssuedDuringPeriodValueEmployeeStockPurchasePlan  \
# 1                                                     1077000.0
# 5                                                     1427000.0
#
# concept_name  StockIssuedDuringPeriodValueRestrictedStockAwardNetOfForfeitures  \
# 1                                                           0.0
# 5                                                           0.0
#
# concept_name  StockIssuedDuringPeriodValueShareBasedCompensationExcludingStockOptionsAndEmployeeStockPurchaseProgramNetOfTaxEffect  \
# 1                                                     6016000.0
# 5                                                     4758000.0
#
# concept_name  StockIssuedDuringPeriodValueStockOptionsExercisedNetOfTaxEffect  \
# 1                                                      566000.0
# 5                                                      557000.0
#
# concept_name  StockRepurchasedAndRetiredDuringPeriodValue  \
# 1                                             100175000.0
# 5                                               1002000.0
#
# concept_name  WeightedAverageNumberOfDilutedSharesOutstanding  \
# 1                                                  26366000.0
# 5                                                  25396000.0
#
# concept_name  WeightedAverageNumberOfSharesOutstandingBasic duration_days  \
# 1                                                26057000.0       90 days
# 5                                                25161000.0       90 days
#
# concept_name duration_YTD_days_dist duration_90_days_dist
# 1                          180 days                0 days
# 5                          180 days                0 days

# %% [markdown]
# ## GAAP Feature Engineering for Machine Learning

# %% [markdown]
# ### Create QoQ Percentage Change Features for the most recent quarterly fiscal durations
# * Here percentage changes for the two most recent quarterly fiscal durations returned above are calculated.
# * The suffix '_QoQ' is added to each feature name.
#
# **Percentage changes create two primary benefits for machine learning in this instance:**
#  1. **Scale** - Percentage changes indicate movement across fiscal durations in the exact same scale for all balance sheet items *regardless of market cap, share price, or sector*.
#  2. **Imputation** - Most machine learning models do not handle missing values well. Many companies also have custom XBRL taxonomies and business or sector specific items on their balance sheet.  When many filing's GAAP data are combined into training datasets, these unique balance sheet features will become sparse features with many missing values.  Using a percentage indicating 0% change, implies no movement for a missing balance sheet item.  This imputation is more accurate for missing balance sheet items than mean imputation or other strategies which all require making an educated guess for missing values.

# %%
QoQ_features = create_QoQ_pct_chg_features(gaap_FD).T
QoQ_features.columns = ['Pct Change']

print('Total QoQ Percentage Change Features:', len(QoQ_features))
print('Total Non Zero QoQ Percentage Change Features:', len(QoQ_features[QoQ_features['Pct Change'] != 0]))

with pd.option_context('display.max_rows', 1000, 'display.max_columns', None):
    display(QoQ_features)
# Out:
# Total QoQ Percentage Change Features: 39
# Total Non Zero QoQ Percentage Change Features: 38
#                                                     Pct Change
# AllocatedShareBasedCompensationExpenseNetOfTax_QoQ   -0.214133
# AmortizationOfIntangibleAssets_QoQ                    0.451515
# ComprehensiveIncomeNetOfTax_QoQ                       0.370558
# CostOfGoodsAndServicesSold_QoQ                        0.062302
# DepreciationDepletionAndAmortization_QoQ              0.217512
# EarningsPerShareBasic_QoQ                             0.436842
# EarningsPerShareDiluted_QoQ                           0.441489
# GrossProfit_QoQ                                       0.154681
# IncomeLossFromContinuingOperationsBeforeIncomeT...    0.312890
# IncomeLossFromContinuingOperationsIncludingPort...    0.264709
# IncomeLossFromContinuingOperationsPerBasicShare...    0.312500
# IncomeLossFromContinuingOperationsPerDilutedSha...    0.315534
# IncomeLossFromDiscontinuedOperationsNetOfTax_QoQ     -1.000000
# IncomeLossFromDiscontinuedOperationsNetOfTaxPer...   -1.000000
# IncomeLossFromDiscontinuedOperationsNetOfTaxPer...   -1.000000
# IncomeTaxExpenseBenefit_QoQ                           0.963930
# IncomeTaxExpenseBenefitPercentageOfIncomeBefore...    0.492754
# IncrementalCommonSharesAttributableToShareBased...   -0.239482
# InterestExpense_QoQ                                  -0.068664
# NetIncomeLoss_QoQ                                     0.388700
# NetIncomeLossAvailableToCommonStockholdersBasic...    0.388700
# NetIncomeLossFromContinuingOperationsAvailableT...    0.264709
# NonoperatingIncomeExpense_QoQ                         5.133333
# OperatingIncomeLoss_QoQ                               0.293217
# OtherComprehensiveIncomeForeignCurrencyTransact...   -4.363813
# OtherComprehensiveIncomeLossNetOfTax_QoQ             -1.232143
# PaymentsToAcquireProductiveAssets_QoQ                -0.518287
# RestructuringCharges_QoQ                             -0.520000
# RevenueFromContractWithCustomerExcludingAssesse...    0.101271
# SellingGeneralAndAdministrativeExpense_QoQ            0.084365
# ShareBasedCompensationEffectOnEarningsPerShareB...   -0.181818
# ShareBasedCompensationEffectOnEarningsPerShareD...   -0.190476
# StockIssuedDuringPeriodValueEmployeeStockPurcha...    0.324977
# StockIssuedDuringPeriodValueRestrictedStockAwar...    0.000000
# StockIssuedDuringPeriodValueShareBasedCompensat...   -0.209109
# StockIssuedDuringPeriodValueStockOptionsExercis...   -0.015901
# StockRepurchasedAndRetiredDuringPeriodValue_QoQ      -0.989998
# WeightedAverageNumberOfDilutedSharesOutstanding...   -0.036790
# WeightedAverageNumberOfSharesOutstandingBasic_QoQ    -0.034386

# %% [markdown]
# ### Get the two most recent YTD durations for YoY (year over year) comparisons
# * The DocumentFiscalPeriodFocus for this filing is Q3 and comprises 90 * 3 = 270 days of fiscal performance.
# * The fiscal duration periods closest to 270 days are considered YTD durations for all Q3 filings.
# * Fiscal durations must also be with 7 days of the 270 day period to qualify as 'YTD'.
# * There must be at least two YTD durations disclosed with the same number of days in each duration.
# * When there are more than two YTD durations disclosed in a single filing, the two most recent durations are returned.
# * All YoY raw GAAP features and values are returned in chronological order.

# %%
with pd.option_context('display.max_rows', 1000, 'display.max_columns', None):
    display(get_current_YoY_fiscal_durations(gaap_FD))
# Out:
# concept_name context_start_date context_end_date  \
# 0                    2018-03-01       2018-11-30
# 3                    2019-03-01       2019-11-30
#
# concept_name  AllocatedShareBasedCompensationExpenseNetOfTax  \
# 0                                                 16020000.0
# 3                                                 17309000.0
#
# concept_name  AmortizationOfFinancingCosts  AmortizationOfIntangibleAssets  \
# 0                                 761000.0                      10822000.0
# 3                                 763000.0                      13129000.0
#
# concept_name  CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalentsPeriodIncreaseDecreaseExcludingExchangeRateEffect  \
# 0                                                    -1602000.0
# 3                                                     7766000.0
#
# concept_name  CashProvidedByUsedInFinancingActivitiesDiscontinuedOperations  \
# 0                                                           0.0
# 3                                                           0.0
#
# concept_name  CashProvidedByUsedInInvestingActivitiesDiscontinuedOperations  \
# 0                                                           0.0
# 3                                                           0.0
#
# concept_name  CashProvidedByUsedInOperatingActivitiesDiscontinuedOperations  \
# 0                                                    -5231000.0
# 3                                                           0.0
#
# concept_name  ComprehensiveIncomeNetOfTax  CostOfGoodsAndServicesSold  \
# 0                             135855000.0                 695732000.0
# 3                             149412000.0                 723216000.0
#
# concept_name  DeferredIncomeTaxesAndTaxCredits  \
# 0                                    4060000.0
# 3                                    -511000.0
#
# concept_name  DepreciationDepletionAndAmortization  EarningsPerShareBasic  \
# 0                                       22490000.0                   4.99
# 3                                       24876000.0                   6.19
#
# concept_name  EarningsPerShareDiluted  GainLossOnSaleOfPropertyPlantEquipment  \
# 0                                4.95                                536000.0
# 3                                6.15                                 14000.0
#
# concept_name  GrossProfit  \
# 0             483576000.0
# 3             541851000.0
#
# concept_name  IncomeLossFromContinuingOperationsBeforeIncomeTaxesExtraordinaryItemsNoncontrollingInterest  \
# 0                                                   147045000.0
# 3                                                   172018000.0
#
# concept_name  IncomeLossFromContinuingOperationsIncludingPortionAttributableToNoncontrollingInterest  \
# 0                                                   136510000.0
# 3                                                   155488000.0
#
# concept_name  IncomeLossFromContinuingOperationsPerBasicShare  \
# 0                                                        5.19
# 3                                                        6.19
#
# concept_name  IncomeLossFromContinuingOperationsPerDilutedShare  \
# 0                                                          5.15
# 3                                                          6.15
#
# concept_name  IncomeLossFromDiscontinuedOperationsNetOfTax  \
# 0                                               -5231000.0
# 3                                                      0.0
#
# concept_name  IncomeLossFromDiscontinuedOperationsNetOfTaxPerBasicShare  \
# 0                                                          -0.2
# 3                                                           0.0
#
# concept_name  IncomeLossFromDiscontinuedOperationsNetOfTaxPerDilutedShare  \
# 0                                                          -0.2
# 3                                                           0.0
#
# concept_name  IncomeTaxExpenseBenefit  \
# 0                          10535000.0
# 3                          16530000.0
#
# concept_name  IncomeTaxExpenseBenefitPercentageOfIncomeBeforeIncomeTaxes  \
# 0                                                         0.072
# 3                                                         0.096
#
# concept_name  IncreaseDecreaseInAccountsPayable  \
# 0                                    16694000.0
# 3                                    -2037000.0
#
# concept_name  IncreaseDecreaseInAccruedIncomeTaxesPayable  \
# 0                                               2969000.0
# 3                                               -980000.0
#
# concept_name  IncreaseDecreaseInAccruedLiabilities  \
# 0                                       17809000.0
# 3                                         477000.0
#
# concept_name  IncreaseDecreaseInInventories  \
# 0                                49137000.0
# 3                                31317000.0
#
# concept_name  IncreaseDecreaseInOtherOperatingCapitalNet  \
# 0                                             -5554000.0
# 3                                            -21091000.0
#
# concept_name  IncreaseDecreaseInPrepaidDeferredExpenseAndOtherAssets  \
# 0                                                     1149000.0
# 3                                                     1269000.0
#
# concept_name  IncreaseDecreaseInReceivables  \
# 0                                64284000.0
# 3                                85747000.0
#
# concept_name  IncrementalCommonSharesAttributableToShareBasedPaymentArrangements  \
# 0                                                      199000.0
# 3                                                      196000.0
#
# concept_name  InterestExpense  NetCashProvidedByUsedInFinancingActivities  \
# 0                   8413000.0                                 -84825000.0
# 3                   9291000.0                                 -80408000.0
#
# concept_name  NetCashProvidedByUsedInFinancingActivitiesContinuingOperations  \
# 0                                                   -84825000.0
# 3                                                   -80408000.0
#
# concept_name  NetCashProvidedByUsedInInvestingActivities  \
# 0                                            -21041000.0
# 3                                            -13244000.0
#
# concept_name  NetCashProvidedByUsedInInvestingActivitiesContinuingOperations  \
# 0                                                   -21041000.0
# 3                                                   -13244000.0
#
# concept_name  NetCashProvidedByUsedInOperatingActivities  \
# 0                                            104264000.0
# 3                                            101418000.0
#
# concept_name  NetCashProvidedByUsedInOperatingActivitiesContinuingOperations  \
# 0                                                   109495000.0
# 3                                                   101418000.0
#
# concept_name  NetIncomeLoss  NetIncomeLossAvailableToCommonStockholdersBasic  \
# 0               131279000.0                                      131279000.0
# 3               155488000.0                                      155488000.0
#
# concept_name  NetIncomeLossFromContinuingOperationsAvailableToCommonShareholdersBasic  \
# 0                                                   136510000.0
# 3                                                   155488000.0
#
# concept_name  NonoperatingIncomeExpense  OperatingIncomeLoss  \
# 0                              175000.0          155283000.0
# 3                              313000.0          180996000.0
#
# concept_name  OtherComprehensiveIncomeForeignCurrencyTransactionAndTranslationGainLossArisingDuringPeriodNetOfTax  \
# 0                                                     4325000.0
# 3                                                     -514000.0
#
# concept_name  OtherComprehensiveIncomeLossBeforeReclassificationsBeforeTax  \
# 0                                                     4034000.0
# 3                                                   -10649000.0
#
# concept_name  OtherComprehensiveIncomeLossBeforeReclassificationsTax  \
# 0                                                      559000.0
# 3                                                    -1733000.0
#
# concept_name  OtherComprehensiveIncomeLossNetOfTax  \
# 0                                        4576000.0
# 3                                       -6076000.0
#
# concept_name  PaymentsForRepurchaseOfCommonStock  \
# 0                                    142415000.0
# 3                                     10133000.0
#
# concept_name  PaymentsToAcquireProductiveAssets  \
# 0                                    22166000.0
# 3                                    13247000.0
#
# concept_name  ProceedsFromIssuanceOfSharesUnderIncentiveAndShareBasedCompensationPlansIncludingStockOptionsAndTaxBenefits  \
# 0                                                     8490000.0
# 3                                                     7025000.0
#
# concept_name  ProceedsFromLinesOfCredit  \
# 0                           462350000.0
# 3                           406600000.0
#
# concept_name  ProceedsFromSaleOfPropertyPlantAndEquipment   ProfitLoss  \
# 0                                               1125000.0  131279000.0
# 3                                                  3000.0  155488000.0
#
# concept_name  ProvisionForDoubtfulAccounts  \
# 0                                 725000.0
# 3                                 484000.0
#
# concept_name  ReclassificationFromAccumulatedOtherComprehensiveIncomeCurrentPeriodBeforeTax  \
# 0                                                    -1101000.0
# 3                                                    -2840000.0
#
# concept_name  RepaymentsOfLinesOfCredit  RepaymentsOfLongTermDebt  \
# 0                           411350000.0                 1900000.0
# 3                           482000000.0                 1900000.0
#
# concept_name  RestructuringCharges  \
# 0                        2609000.0
# 3                        1061000.0
#
# concept_name  RevenueFromContractWithCustomerExcludingAssessedTax  \
# 0                                                  1.179308e+09
# 3                                                  1.265067e+09
#
# concept_name  SellingGeneralAndAdministrativeExpense  ShareBasedCompensation  \
# 0                                        325684000.0              17029000.0
# 3                                        359794000.0              18743000.0
#
# concept_name  ShareBasedCompensationEffectOnEarningsPerShareBasic  \
# 0                                                          0.61
# 3                                                          0.69
#
# concept_name  ShareBasedCompensationEffectOnEarningsPerShareDiluted  \
# 0                                                          0.60
# 3                                                          0.68
#
# concept_name  StockIssuedDuringPeriodValueEmployeeStockPurchasePlan  \
# 0                                                     2412000.0
# 3                                                     2835000.0
#
# concept_name  StockIssuedDuringPeriodValueRestrictedStockAwardNetOfForfeitures  \
# 0                                                           0.0
# 3                                                           0.0
#
# concept_name  StockIssuedDuringPeriodValueShareBasedCompensationExcludingStockOptionsAndEmployeeStockPurchaseProgramNetOfTaxEffect  \
# 0                                                    17029000.0
# 3                                                    18743000.0
#
# concept_name  StockIssuedDuringPeriodValueStockOptionsExercisedNetOfTaxEffect  \
# 0                                                     6081000.0
# 3                                                     4190000.0
#
# concept_name  StockRepurchasedAndRetiredDuringPeriodValue  \
# 0                                             142415000.0
# 3                                              10133000.0
#
# concept_name  UnrecognizedTaxBenefitsDecreasesResultingFromRecognitionOfExcessTaxBenefitsFromShareBasedCompensation  \
# 0                                                      700000.0
# 3                                                     1000000.0
#
# concept_name  Unrecognizedtaxbenefitfromfavorableresolutionofuncertaintaxposition  \
# 0                                                      800000.0
# 3                                                     2800000.0
#
# concept_name  WeightedAverageNumberOfDilutedSharesOutstanding  \
# 0                                                  26520000.0
# 3                                                  25295000.0
#
# concept_name  WeightedAverageNumberOfSharesOutstandingBasic duration_days  \
# 0                                                26321000.0      274 days
# 3                                                25099000.0      274 days
#
# concept_name duration_YTD_days_dist duration_90_days_dist
# 0                            4 days              184 days
# 3                            4 days              184 days

# %% [markdown]
# ### Create YoY Percentage Change Features for the most recent quarterly fiscal durations
# * Here percentage changes for the two most recent YTD fiscal durations returned above are calculated.
# * The suffix '_YoY' is added to each feature name.
# * Percentage changes provide the same two primary benefits for machine learning regarding scale and imputation.

# %%
YoY_features = create_YoY_pct_chg_features(gaap_FD).T
YoY_features.columns = ['Pct Change']

print('Total YoY Percentage Change Features:', len(YoY_features))
print('Total Non Zero YoY Percentage Change Features:', len(YoY_features[YoY_features['Pct Change'] != 0]))

with pd.option_context('display.max_rows', 1000, 'display.max_columns', None):
    display(YoY_features)
# Out:
# Total YoY Percentage Change Features: 73
# Total Non Zero YoY Percentage Change Features: 69
#                                                     Pct Change
# AllocatedShareBasedCompensationExpenseNetOfTax_YoY    0.080462
# AmortizationOfFinancingCosts_YoY                      0.002628
# AmortizationOfIntangibleAssets_YoY                    0.213177
# CashCashEquivalentsRestrictedCashAndRestrictedC...   -5.847690
# CashProvidedByUsedInFinancingActivitiesDisconti...    0.000000
# CashProvidedByUsedInInvestingActivitiesDisconti...    0.000000
# CashProvidedByUsedInOperatingActivitiesDisconti...   -1.000000
# ComprehensiveIncomeNetOfTax_YoY                       0.099790
# CostOfGoodsAndServicesSold_YoY                        0.039504
# DeferredIncomeTaxesAndTaxCredits_YoY                 -1.125862
# DepreciationDepletionAndAmortization_YoY              0.106092
# EarningsPerShareBasic_YoY                             0.240481
# EarningsPerShareDiluted_YoY                           0.242424
# GainLossOnSaleOfPropertyPlantEquipment_YoY           -0.973881
# GrossProfit_YoY                                       0.120508
# IncomeLossFromContinuingOperationsBeforeIncomeT...    0.169832
# IncomeLossFromContinuingOperationsIncludingPort...    0.139023
# IncomeLossFromContinuingOperationsPerBasicShare...    0.192678
# IncomeLossFromContinuingOperationsPerDilutedSha...    0.194175
# IncomeLossFromDiscontinuedOperationsNetOfTax_YoY     -1.000000
# IncomeLossFromDiscontinuedOperationsNetOfTaxPer...   -1.000000
# IncomeLossFromDiscontinuedOperationsNetOfTaxPer...   -1.000000
# IncomeTaxExpenseBenefit_YoY                           0.569056
# IncomeTaxExpenseBenefitPercentageOfIncomeBefore...    0.333333
# IncreaseDecreaseInAccountsPayable_YoY                -1.122020
# IncreaseDecreaseInAccruedIncomeTaxesPayable_YoY      -1.330077
# IncreaseDecreaseInAccruedLiabilities_YoY             -0.973216
# IncreaseDecreaseInInventories_YoY                    -0.362660
# IncreaseDecreaseInOtherOperatingCapitalNet_YoY        2.797443
# IncreaseDecreaseInPrepaidDeferredExpenseAndOthe...    0.104439
# IncreaseDecreaseInReceivables_YoY                     0.333878
# IncrementalCommonSharesAttributableToShareBased...   -0.015075
# InterestExpense_YoY                                   0.104362
# NetCashProvidedByUsedInFinancingActivities_YoY       -0.052072
# NetCashProvidedByUsedInFinancingActivitiesConti...   -0.052072
# NetCashProvidedByUsedInInvestingActivities_YoY       -0.370562
# NetCashProvidedByUsedInInvestingActivitiesConti...   -0.370562
# NetCashProvidedByUsedInOperatingActivities_YoY       -0.027296
# NetCashProvidedByUsedInOperatingActivitiesConti...   -0.073766
# NetIncomeLoss_YoY                                     0.184409
# NetIncomeLossAvailableToCommonStockholdersBasic...    0.184409
# NetIncomeLossFromContinuingOperationsAvailableT...    0.139023
# NonoperatingIncomeExpense_YoY                         0.788571
# OperatingIncomeLoss_YoY                               0.165588
# OtherComprehensiveIncomeForeignCurrencyTransact...   -1.118844
# OtherComprehensiveIncomeLossBeforeReclassificat...   -3.639812
# OtherComprehensiveIncomeLossBeforeReclassificat...   -4.100179
# OtherComprehensiveIncomeLossNetOfTax_YoY             -2.327797
# PaymentsForRepurchaseOfCommonStock_YoY               -0.928849
# PaymentsToAcquireProductiveAssets_YoY                -0.402373
# ProceedsFromIssuanceOfSharesUnderIncentiveAndSh...   -0.172556
# ProceedsFromLinesOfCredit_YoY                        -0.120580
# ProceedsFromSaleOfPropertyPlantAndEquipment_YoY      -0.997333
# ProfitLoss_YoY                                        0.184409
# ProvisionForDoubtfulAccounts_YoY                     -0.332414
# ReclassificationFromAccumulatedOtherComprehensi...    1.579473
# RepaymentsOfLinesOfCredit_YoY                         0.171752
# RepaymentsOfLongTermDebt_YoY                          0.000000
# RestructuringCharges_YoY                             -0.593331
# RevenueFromContractWithCustomerExcludingAssesse...    0.072720
# SellingGeneralAndAdministrativeExpense_YoY            0.104733
# ShareBasedCompensation_YoY                            0.100652
# ShareBasedCompensationEffectOnEarningsPerShareB...    0.131148
# ShareBasedCompensationEffectOnEarningsPerShareD...    0.133333
# StockIssuedDuringPeriodValueEmployeeStockPurcha...    0.175373
# StockIssuedDuringPeriodValueRestrictedStockAwar...    0.000000
# StockIssuedDuringPeriodValueShareBasedCompensat...    0.100652
# StockIssuedDuringPeriodValueStockOptionsExercis...   -0.310969
# StockRepurchasedAndRetiredDuringPeriodValue_YoY      -0.928849
# UnrecognizedTaxBenefitsDecreasesResultingFromRe...    0.428571
# Unrecognizedtaxbenefitfromfavorableresolutionof...    2.500000
# WeightedAverageNumberOfDilutedSharesOutstanding...   -0.046192
# WeightedAverageNumberOfSharesOutstandingBasic_YoY    -0.046427

# %% [markdown]
# ### View the Fiscal Instance GAAP Data
# * This function identifies all fiscal instances disclosed in a filing's XBRL instance document facts.
# * The data is pivoted to create one row per instance date containing all numeric facts / features disclosed in the filing.

# %%
gaap_FI = get_fiscal_instance_features(gaap_raw)

with pd.option_context('display.max_rows', 1000, 'display.max_columns', None):
    display(gaap_FI)
# Out:
# concept_name context_instant_date  AccountsPayableCurrent  \
# 0                      2018-02-28                     NaN
# 1                      2018-03-01                     NaN
# 2                      2018-08-31                     NaN
# 3                      2018-09-01                     NaN
# 4                      2018-11-30                     NaN
# 5                      2019-02-28             143560000.0
# 6                      2019-03-01                     NaN
# 7                      2019-05-08                     NaN
# 8                      2019-05-31                     NaN
# 9                      2019-08-31                     NaN
# 10                     2019-11-30             141523000.0
# 11                     2020-01-03                     NaN
#
# concept_name  AccountsReceivableNetCurrent  AccruedAdvertisingCurrent  \
# 0                                      NaN                        NaN
# 1                                      NaN                        NaN
# 2                                      NaN                        NaN
# 3                                      NaN                        NaN
# 4                                      NaN                        NaN
# 5                              280280000.0                 26549000.0
# 6                                      NaN                        NaN
# 7                                      NaN                        NaN
# 8                                      NaN                        NaN
# 9                                      NaN                        NaN
# 10                             365543000.0                 30970000.0
# 11                                     NaN                        NaN
#
# concept_name  AccruedLiabilitiesCurrent  AccruedMarketingCostsCurrent  \
# 0                                   NaN                           NaN
# 1                                   NaN                           NaN
# 2                                   NaN                           NaN
# 3                                   NaN                           NaN
# 4                                   NaN                           NaN
# 5                           165160000.0                    28655000.0
# 6                                   NaN                           NaN
# 7                                   NaN                           NaN
# 8                                   NaN                           NaN
# 9                                   NaN                           NaN
# 10                          171269000.0                    31661000.0
# 11                                  NaN                           NaN
#
# concept_name  AccumulatedDepreciationDepletionAndAmortizationPropertyPlantAndEquipment  \
# 0                                                           NaN
# 1                                                           NaN
# 2                                                           NaN
# 3                                                           NaN
# 4                                                           NaN
# 5                                                   123744000.0
# 6                                                           NaN
# 7                                                           NaN
# 8                                                           NaN
# 9                                                           NaN
# 10                                                  133764000.0
# 11                                                          NaN
#
# concept_name  AccumulatedOtherComprehensiveIncomeLossNetOfTax  \
# 0                                                         NaN
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4                                                         NaN
# 5                                                   1191000.0
# 6                                                         NaN
# 7                                                         NaN
# 8                                                         NaN
# 9                                                         NaN
# 10                                                 -4885000.0
# 11                                                        NaN
#
# concept_name  AdditionalPaidInCapitalCommonStock  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                    246585000.0
# 6                                            NaN
# 7                                            NaN
# 8                                            NaN
# 9                                            NaN
# 10                                   262731000.0
# 11                                           NaN
#
# concept_name  AllowanceForDoubtfulReceivablesAndReturns        Assets  \
# 0                                                   NaN           NaN
# 1                                                   NaN           NaN
# 2                                                   NaN           NaN
# 3                                                   NaN           NaN
# 4                                                   NaN           NaN
# 5                                             2032000.0  1.649535e+09
# 6                                                   NaN           NaN
# 7                                                   NaN           NaN
# 8                                                   NaN           NaN
# 9                                                   NaN           NaN
# 10                                            1486000.0  1.791089e+09
# 11                                                  NaN           NaN
#
# concept_name  AssetsCurrent  CashAndCashEquivalentsAtCarryingValue  \
# 0                       NaN                                    NaN
# 1                       NaN                                    NaN
# 2                       NaN                                    NaN
# 3                       NaN                                    NaN
# 4                       NaN                                    NaN
# 5               604859000.0                             11871000.0
# 6                       NaN                                    NaN
# 7                       NaN                                    NaN
# 8                       NaN                                    NaN
# 9                       NaN                                    NaN
# 10              729239000.0                             19637000.0
# 11                      NaN                                    NaN
#
# concept_name  CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalents  \
# 0                                                           NaN
# 1                                                           NaN
# 2                                                           NaN
# 3                                                           NaN
# 4                                                    19136000.0
# 5                                                           NaN
# 6                                                           NaN
# 7                                                           NaN
# 8                                                           NaN
# 9                                                           NaN
# 10                                                   19637000.0
# 11                                                          NaN
#
# concept_name  CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalentsIncludingDisposalGroupAndDiscontinuedOperations  \
# 0                                                    20738000.0
# 1                                                           NaN
# 2                                                           NaN
# 3                                                           NaN
# 4                                                    19136000.0
# 5                                                    11871000.0
# 6                                                           NaN
# 7                                                           NaN
# 8                                                           NaN
# 9                                                           NaN
# 10                                                   19637000.0
# 11                                                          NaN
#
# concept_name  CommonStockParOrStatedValuePerShare  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# 5                                             0.1
# 6                                             NaN
# 7                                             NaN
# 8                                             NaN
# 9                                             NaN
# 10                                            0.1
# 11                                            NaN
#
# concept_name  CommonStockSharesAuthorized  CommonStockSharesIssued  \
# 0                                     NaN                      NaN
# 1                                     NaN                      NaN
# 2                                     NaN                      NaN
# 3                                     NaN                      NaN
# 4                                     NaN                      NaN
# 5                              50000000.0               24946046.0
# 6                                     NaN                      NaN
# 7                                     NaN                      NaN
# 8                                     NaN                      NaN
# 9                                     NaN                      NaN
# 10                             50000000.0               25166771.0
# 11                                    NaN                      NaN
#
# concept_name  CommonStockSharesOutstanding  CommonStockValue  \
# 0                                      NaN               NaN
# 1                                      NaN               NaN
# 2                                      NaN               NaN
# 3                                      NaN               NaN
# 4                                      NaN               NaN
# 5                               24946046.0         2495000.0
# 6                                      NaN               NaN
# 7                                      NaN               NaN
# 8                                      NaN               NaN
# 9                                      NaN               NaN
# 10                              25166771.0         2517000.0
# 11                                     NaN               NaN
#
# concept_name  DeferredTaxAssetsLiabilitiesNet  DeferredTaxLiabilities  \
# 0                                         NaN                     NaN
# 1                                         NaN                     NaN
# 2                                         NaN                     NaN
# 3                                         NaN                     NaN
# 4                                         NaN                     NaN
# 5                                   7991000.0               5748000.0
# 6                                         NaN                     NaN
# 7                                         NaN                     NaN
# 8                                         NaN                     NaN
# 9                                         NaN                     NaN
# 10                                 12926000.0               8439000.0
# 11                                        NaN                     NaN
#
# concept_name  DisposalGroupIncludingDiscontinuedOperationCashAndCashEquivalents  \
# 0                                                           NaN
# 1                                                           NaN
# 2                                                           NaN
# 3                                                           NaN
# 4                                                           0.0
# 5                                                           NaN
# 6                                                           NaN
# 7                                                           NaN
# 8                                                           NaN
# 9                                                           NaN
# 10                                                          0.0
# 11                                                          NaN
#
# concept_name  EmployeeRelatedLiabilitiesCurrent  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                    36782000.0
# 6                                           NaN
# 7                                           NaN
# 8                                           NaN
# 9                                           NaN
# 10                                   37410000.0
# 11                                          NaN
#
# concept_name  EntityCommonStockSharesOutstanding  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
# 6                                            NaN
# 7                                            NaN
# 8                                            NaN
# 9                                            NaN
# 10                                           NaN
# 11                                    25169734.0
#
# concept_name  FiniteLivedIntangibleAssetsAccumulatedAmortization  \
# 0                                                           NaN
# 1                                                           NaN
# 2                                                           NaN
# 3                                                           NaN
# 4                                                           NaN
# 5                                                   181463000.0
# 6                                                           NaN
# 7                                                           NaN
# 8                                                           NaN
# 9                                                           NaN
# 10                                                  194562000.0
# 11                                                          NaN
#
# concept_name  FiniteLivedIntangibleAssetsAmortizationExpenseRemainderOfFiscalYear  \
# 0                                                           NaN
# 1                                                           NaN
# 2                                                           NaN
# 3                                                           NaN
# 4                                                           NaN
# 5                                                           NaN
# 6                                                           NaN
# 7                                                           NaN
# 8                                                           NaN
# 9                                                           NaN
# 10                                                   17557000.0
# 11                                                          NaN
#
# concept_name  FiniteLivedIntangibleAssetsAmortizationExpenseYearFive  \
# 0                                                           NaN
# 1                                                           NaN
# 2                                                           NaN
# 3                                                           NaN
# 4                                                           NaN
# 5                                                           NaN
# 6                                                           NaN
# 7                                                           NaN
# 8                                                           NaN
# 9                                                           NaN
# 10                                                    7386000.0
# 11                                                          NaN
#
# concept_name  FiniteLivedIntangibleAssetsAmortizationExpenseYearFour  \
# 0                                                           NaN
# 1                                                           NaN
# 2                                                           NaN
# 3                                                           NaN
# 4                                                           NaN
# 5                                                           NaN
# 6                                                           NaN
# 7                                                           NaN
# 8                                                           NaN
# 9                                                           NaN
# 10                                                    9261000.0
# 11                                                          NaN
#
# concept_name  FiniteLivedIntangibleAssetsAmortizationExpenseYearSix  \
# 0                                                           NaN
# 1                                                           NaN
# 2                                                           NaN
# 3                                                           NaN
# 4                                                           NaN
# 5                                                           NaN
# 6                                                           NaN
# 7                                                           NaN
# 8                                                           NaN
# 9                                                           NaN
# 10                                                    6854000.0
# 11                                                          NaN
#
# concept_name  FiniteLivedIntangibleAssetsAmortizationExpenseYearThree  \
# 0                                                           NaN
# 1                                                           NaN
# 2                                                           NaN
# 3                                                           NaN
# 4                                                           NaN
# 5                                                           NaN
# 6                                                           NaN
# 7                                                           NaN
# 8                                                           NaN
# 9                                                           NaN
# 10                                                    9530000.0
# 11                                                          NaN
#
# concept_name  FiniteLivedIntangibleAssetsAmortizationExpenseYearTwo  \
# 0                                                           NaN
# 1                                                           NaN
# 2                                                           NaN
# 3                                                           NaN
# 4                                                           NaN
# 5                                                           NaN
# 6                                                           NaN
# 7                                                           NaN
# 8                                                           NaN
# 9                                                           NaN
# 10                                                   16437000.0
# 11                                                          NaN
#
# concept_name     Goodwill  GoodwillImpairedAccumulatedImpairmentLoss  \
# 0                     NaN                                        NaN
# 1                     NaN                                        NaN
# 2                     NaN                                        NaN
# 3                     NaN                                        NaN
# 4                     NaN                                        NaN
# 5             602320000.0                                 46490000.0
# 6                     NaN                                        NaN
# 7                     NaN                                        NaN
# 8                     NaN                                        NaN
# 9                     NaN                                        NaN
# 10            602320000.0                                 46490000.0
# 11                    NaN                                        NaN
#
# concept_name  IntangibleAssetsGrossIncludingGoodwill  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                       1.121799e+09
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 10                                      1.122400e+09
# 11                                               NaN
#
# concept_name  IntangibleAssetsNetExcludingGoodwill  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# 5                                      291526000.0
# 6                                              NaN
# 7                                              NaN
# 8                                              NaN
# 9                                              NaN
# 10                                     279028000.0
# 11                                             NaN
#
# concept_name  IntangibleAssetsNetIncludingGoodwill  InventoryNet  \
# 0                                              NaN           NaN
# 1                                              NaN           NaN
# 2                                              NaN           NaN
# 3                                              NaN           NaN
# 4                                              NaN           NaN
# 5                                      893846000.0   302339000.0
# 6                                              NaN           NaN
# 7                                              NaN           NaN
# 8                                              NaN           NaN
# 9                                              NaN           NaN
# 10                                     881348000.0   333656000.0
# 11                                             NaN           NaN
#
# concept_name  LesseeOperatingLeaseLiabilityPaymentsDue  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                          64148000.0
# 11                                                 NaN
#
# concept_name  LesseeOperatingLeaseLiabilityPaymentsDueAfterYearFive  \
# 0                                                           NaN
# 1                                                           NaN
# 2                                                           NaN
# 3                                                           NaN
# 4                                                           NaN
# 5                                                           NaN
# 6                                                           NaN
# 7                                                           NaN
# 8                                                           NaN
# 9                                                           NaN
# 10                                                   40132000.0
# 11                                                          NaN
#
# concept_name  LesseeOperatingLeaseLiabilityPaymentsDueYearFive  \
# 0                                                          NaN
# 1                                                          NaN
# 2                                                          NaN
# 3                                                          NaN
# 4                                                          NaN
# 5                                                          NaN
# 6                                                          NaN
# 7                                                          NaN
# 8                                                          NaN
# 9                                                          NaN
# 10                                                   5102000.0
# 11                                                         NaN
#
# concept_name  LesseeOperatingLeaseLiabilityPaymentsDueYearFour  \
# 0                                                          NaN
# 1                                                          NaN
# 2                                                          NaN
# 3                                                          NaN
# 4                                                          NaN
# 5                                                          NaN
# 6                                                          NaN
# 7                                                          NaN
# 8                                                          NaN
# 9                                                          NaN
# 10                                                   5601000.0
# 11                                                         NaN
#
# concept_name  LesseeOperatingLeaseLiabilityPaymentsDueYearThree  \
# 0                                                           NaN
# 1                                                           NaN
# 2                                                           NaN
# 3                                                           NaN
# 4                                                           NaN
# 5                                                           NaN
# 6                                                           NaN
# 7                                                           NaN
# 8                                                           NaN
# 9                                                           NaN
# 10                                                    5959000.0
# 11                                                          NaN
#
# concept_name  LesseeOperatingLeaseLiabilityPaymentsDueYearTwo  \
# 0                                                         NaN
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4                                                         NaN
# 5                                                         NaN
# 6                                                         NaN
# 7                                                         NaN
# 8                                                         NaN
# 9                                                         NaN
# 10                                                  6082000.0
# 11                                                        NaN
#
# concept_name  LesseeOperatingLeaseLiabilityPaymentsRemainderOfFiscalYear  \
# 0                                                           NaN
# 1                                                           NaN
# 2                                                           NaN
# 3                                                           NaN
# 4                                                           NaN
# 5                                                           NaN
# 6                                                           NaN
# 7                                                           NaN
# 8                                                           NaN
# 9                                                           NaN
# 10                                                    1272000.0
# 11                                                          NaN
#
# concept_name  LesseeOperatingLeaseLiabilityUndiscountedExcessAmount  \
# 0                                                           NaN
# 1                                                           NaN
# 2                                                           NaN
# 3                                                           NaN
# 4                                                           NaN
# 5                                                           NaN
# 6                                                           NaN
# 7                                                           NaN
# 8                                                           NaN
# 9                                                           NaN
# 10                                                   19057000.0
# 11                                                          NaN
#
# concept_name  Liabilities  LiabilitiesAndStockholdersEquity  \
# 0                     NaN                               NaN
# 1                     NaN                               NaN
# 2                     NaN                               NaN
# 3                     NaN                               NaN
# 4                     NaN                               NaN
# 5             652898000.0                      1.649535e+09
# 6                     NaN                               NaN
# 7                     NaN                               NaN
# 8                     NaN                               NaN
# 9                     NaN                               NaN
# 10            629405000.0                      1.791089e+09
# 11                    NaN                               NaN
#
# concept_name  LiabilitiesCurrent  LongTermDebt  LongTermDebtCurrent  \
# 0                            NaN           NaN                  NaN
# 1                            NaN           NaN                  NaN
# 2                            NaN           NaN                  NaN
# 3                            NaN           NaN                  NaN
# 4                            NaN           NaN                  NaN
# 5                    312031000.0   320784000.0            1884000.0
# 6                            NaN           NaN                  NaN
# 7                            NaN           NaN                  NaN
# 8                            NaN           NaN                  NaN
# 9                            NaN           NaN                  NaN
# 10                   317899000.0   244247000.0            1884000.0
# 11                           NaN           NaN                  NaN
#
# concept_name  LongTermDebtNoncurrent  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# 5                        318900000.0
# 6                                NaN
# 7                                NaN
# 8                                NaN
# 9                                NaN
# 10                       242363000.0
# 11                               NaN
#
# concept_name  NewAccountingPronouncementOrChangeInAccountingPrincipleCumulativeEffectOfChangeOnEquityOrNetAssets1  \
# 0                                                           NaN
# 1                                                     -163000.0
# 2                                                           NaN
# 3                                                        4000.0
# 4                                                           NaN
# 5                                                           NaN
# 6                                                           NaN
# 7                                                           NaN
# 8                                                           NaN
# 9                                                           NaN
# 10                                                          NaN
# 11                                                          NaN
#
# concept_name  NonCashIncreaseDecreaseInPrepaidExpenseAndOtherAssets  \
# 0                                                           NaN
# 1                                                           NaN
# 2                                                           NaN
# 3                                                           NaN
# 4                                                           NaN
# 5                                                           NaN
# 6                                                       43000.0
# 7                                                           NaN
# 8                                                           NaN
# 9                                                           NaN
# 10                                                          NaN
# 11                                                          NaN
#
# concept_name  OperatingLeaseLiability  OperatingLeaseLiabilityCurrent  \
# 0                                 NaN                             NaN
# 1                                 NaN                             NaN
# 2                                 NaN                             NaN
# 3                                 NaN                             NaN
# 4                                 NaN                             NaN
# 5                                 NaN                             NaN
# 6                          47223000.0                             NaN
# 7                                 NaN                             NaN
# 8                                 NaN                             NaN
# 9                                 NaN                             NaN
# 10                         45091000.0                       3331000.0
# 11                                NaN                             NaN
#
# concept_name  OperatingLeaseLiabilityNoncurrent  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
# 7                                           NaN
# 8                                           NaN
# 9                                           NaN
# 10                                   41760000.0
# 11                                          NaN
#
# concept_name  OperatingLeaseRightOfUseAsset  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 6                                       NaN
# 7                                       NaN
# 8                                       NaN
# 9                                       NaN
# 10                               33528000.0
# 11                                      NaN
#
# concept_name  OperatingLeaseWeightedAverageDiscountRatePercent  \
# 0                                                          NaN
# 1                                                          NaN
# 2                                                          NaN
# 3                                                          NaN
# 4                                                          NaN
# 5                                                          NaN
# 6                                                          NaN
# 7                                                          NaN
# 8                                                          NaN
# 9                                                          NaN
# 10                                                      0.0611
# 11                                                         NaN
#
# concept_name  OtherAccruedLiabilitiesCurrent  OtherAssetsNoncurrent  \
# 0                                        NaN                    NaN
# 1                                        NaN                    NaN
# 2                                        NaN                    NaN
# 3                                        NaN                    NaN
# 4                                        NaN                    NaN
# 5                                 49858000.0             12501000.0
# 6                                        NaN                    NaN
# 7                                        NaN                    NaN
# 8                                        NaN                    NaN
# 9                                        NaN                    NaN
# 10                                47069000.0              2869000.0
# 11                                       NaN                    NaN
#
# concept_name  OtherAssetsNoncurrentAccumulatedAmortization  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# 5                                                2115000.0
# 6                                                      NaN
# 7                                                      NaN
# 8                                                      NaN
# 9                                                      NaN
# 10                                               2167000.0
# 11                                                     NaN
#
# concept_name  OtherLiabilitiesNoncurrent  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# 5                             16219000.0
# 6                                    NaN
# 7                                    NaN
# 8                                    NaN
# 9                                    NaN
# 10                            18944000.0
# 11                                   NaN
#
# concept_name  PreferredStockParOrStatedValuePerShare  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                1.0
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 10                                               1.0
# 11                                               NaN
#
# concept_name  PreferredStockSharesAuthorized  PreferredStockSharesIssued  \
# 0                                        NaN                         NaN
# 1                                        NaN                         NaN
# 2                                        NaN                         NaN
# 3                                        NaN                         NaN
# 4                                        NaN                         NaN
# 5                                  2000000.0                         0.0
# 6                                        NaN                         NaN
# 7                                        NaN                         NaN
# 8                                        NaN                         NaN
# 9                                        NaN                         NaN
# 10                                 2000000.0                         0.0
# 11                                       NaN                         NaN
#
# concept_name  PreferredStockValue  PrepaidExpenseAndOtherAssetsCurrent  \
# 0                             NaN                                  NaN
# 1                             NaN                                  NaN
# 2                             NaN                                  NaN
# 3                             NaN                                  NaN
# 4                             NaN                                  NaN
# 5                             0.0                           10369000.0
# 6                             NaN                                  NaN
# 7                             NaN                                  NaN
# 8                             NaN                                  NaN
# 9                             NaN                                  NaN
# 10                            0.0                           10403000.0
# 11                            NaN                                  NaN
#
# concept_name  ProductWarrantyAccrualClassifiedCurrent  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                          23316000.0
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                         24159000.0
# 11                                                NaN
#
# concept_name  PropertyPlantAndEquipmentGross  PropertyPlantAndEquipmentNet  \
# 0                                        NaN                           NaN
# 1                                        NaN                           NaN
# 2                                        NaN                           NaN
# 3                                        NaN                           NaN
# 4                                        NaN                           NaN
# 5                                254082000.0                   130338000.0
# 6                                        NaN                           NaN
# 7                                        NaN                           NaN
# 8                                        NaN                           NaN
# 9                                        NaN                           NaN
# 10                               264943000.0                   131179000.0
# 11                                       NaN                           NaN
#
# concept_name  RetainedEarningsAccumulatedDeficit  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                    746366000.0
# 6                                            NaN
# 7                                            NaN
# 8                                            NaN
# 9                                            NaN
# 10                                   901321000.0
# 11                                           NaN
#
# concept_name  StockRepurchasePriorProgramRemainingAuthorizedRepurchaseAmount  \
# 0                                                           NaN
# 1                                                           NaN
# 2                                                           NaN
# 3                                                           NaN
# 4                                                           NaN
# 5                                                           NaN
# 6                                                           NaN
# 7                                                   107400000.0
# 8                                                           NaN
# 9                                                           NaN
# 10                                                          NaN
# 11                                                          NaN
#
# concept_name  StockRepurchaseProgramAuthorizedAmount1  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                         400000000.0
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
#
# concept_name  StockRepurchaseProgramRemainingAuthorizedRepurchaseAmount1  \
# 0                                                           NaN
# 1                                                           NaN
# 2                                                           NaN
# 3                                                           NaN
# 4                                                           NaN
# 5                                                           NaN
# 6                                                           NaN
# 7                                                           NaN
# 8                                                           NaN
# 9                                                           NaN
# 10                                                  393000000.0
# 11                                                          NaN
#
# concept_name  StockholdersEquity  TaxesPayableCurrentAndNoncurrent  \
# 0                   1.014459e+09                               NaN
# 1                            NaN                               NaN
# 2                   1.075740e+09                               NaN
# 3                            NaN                               NaN
# 4                   1.033258e+09                               NaN
# 5                   9.966370e+08                         1427000.0
# 6                            NaN                               NaN
# 7                            NaN                               NaN
# 8                            NaN                               NaN
# 9                   1.087375e+09                               NaN
# 10                  1.161684e+09                         3223000.0
# 11                           NaN                               NaN
#
# concept_name context_instant_days_diff period_end_date_days_diff
# 0                               0 days                 -640 days
# 1                               1 days                 -639 days
# 2                             183 days                 -456 days
# 3                               1 days                 -455 days
# 4                              90 days                 -365 days
# 5                              90 days                 -275 days
# 6                               1 days                 -274 days
# 7                              68 days                 -206 days
# 8                              23 days                 -183 days
# 9                              92 days                  -91 days
# 10                             91 days                    0 days
# 11                             34 days                   34 days

# %% [markdown]
# ### Important Fiscal Instances
#
# * It appears that there are two primary snapshots provided in the fiscal instance data above:
#  * **CurrentFiscalYearEndDate** - Snapshot as of fiscal year end
#  * **DocumentPeriodEndDate** - Snapshot as of the document period end
#
# ### The Filing Metadata below shows how the primary fiscal instants disclosed align with these dates

# %%
# Print important metadata from the filing
print('CurrentFiscalYearEndDate:', gaap_metadata_dict['CurrentFiscalYearEndDate'])
print('DocumentFiscalPeriodFocus:', gaap_metadata_dict['DocumentFiscalPeriodFocus'])
print('DocumentPeriodEndDate:', gaap_metadata_dict['1774'])
# Out:
# CurrentFiscalYearEndDate: --02-28
# DocumentFiscalPeriodFocus: Q3
# DocumentPeriodEndDate: 2019-11-30

# %% [markdown]
# ### Create FYED to DPED Percentage Change Features
# * Here percentage changes between the CurrentFiscalYearEndDate and DocumentPeriodEndDate fiscal instant data are calculated.
# * The suffix '_FYED_to_DPED' is added to each feature name.
# * Percentage changes provide the same two primary benefits for machine learning regarding scale and imputation.

# %%
gaap_metadata_dict = get_filing_metadata(gaap_raw, as_dict=True)
FYED_to_DPED_features = create_FYED_to_DPED_pct_chg_features(gaap_FI, gaap_metadata_dict, feature_suffix='_FYED_to_DPED').T
FYED_to_DPED_features.columns = ['Pct Change']

print('Total FYED to DPED Percentage Change Features:', len(FYED_to_DPED_features))
print('Total Non Zero FYED to DPED Percentage Change Features:', len(FYED_to_DPED_features[FYED_to_DPED_features['Pct Change'] != 0]))

FYED_to_DPED_features
# Out:
# Total FYED to DPED Percentage Change Features: 49
# Total Non Zero FYED to DPED Percentage Change Features: 42
#                                                     Pct Change
# AccountsPayableCurrent_FYED_to_DPED                  -0.014189
# AccountsReceivableNetCurrent_FYED_to_DPED             0.304207
# AccruedAdvertisingCurrent_FYED_to_DPED                0.166522
# AccruedLiabilitiesCurrent_FYED_to_DPED                0.036988
# AccruedMarketingCostsCurrent_FYED_to_DPED             0.104903
# AccumulatedDepreciationDepletionAndAmortization...    0.080974
# AccumulatedOtherComprehensiveIncomeLossNetOfTax...   -5.101595
# AdditionalPaidInCapitalCommonStock_FYED_to_DPED       0.065478
# AllowanceForDoubtfulReceivablesAndReturns_FYED_...   -0.268701
# Assets_FYED_to_DPED                                   0.085814
# AssetsCurrent_FYED_to_DPED                            0.205635
# CashAndCashEquivalentsAtCarryingValue_FYED_to_DPED    0.654199
# CashCashEquivalentsRestrictedCashAndRestrictedC...    0.654199
# CommonStockParOrStatedValuePerShare_FYED_to_DPED      0.000000
# CommonStockSharesAuthorized_FYED_to_DPED              0.000000
# CommonStockSharesIssued_FYED_to_DPED                  0.008848
# CommonStockSharesOutstanding_FYED_to_DPED             0.008848
# CommonStockValue_FYED_to_DPED                         0.008818
# DeferredTaxAssetsLiabilitiesNet_FYED_to_DPED          0.617570
# DeferredTaxLiabilities_FYED_to_DPED                   0.468163
# EmployeeRelatedLiabilitiesCurrent_FYED_to_DPED        0.017074
# FiniteLivedIntangibleAssetsAccumulatedAmortizat...    0.072186
# Goodwill_FYED_to_DPED                                 0.000000
# GoodwillImpairedAccumulatedImpairmentLoss_FYED_...    0.000000
# IntangibleAssetsGrossIncludingGoodwill_FYED_to_...    0.000536
# IntangibleAssetsNetExcludingGoodwill_FYED_to_DPED    -0.042871
# IntangibleAssetsNetIncludingGoodwill_FYED_to_DPED    -0.013982
# InventoryNet_FYED_to_DPED                             0.103582
# Liabilities_FYED_to_DPED                             -0.035983
# LiabilitiesAndStockholdersEquity_FYED_to_DPED         0.085814
# LiabilitiesCurrent_FYED_to_DPED                       0.018806
# LongTermDebt_FYED_to_DPED                            -0.238594
# LongTermDebtCurrent_FYED_to_DPED                      0.000000
# LongTermDebtNoncurrent_FYED_to_DPED                  -0.240003
# OtherAccruedLiabilitiesCurrent_FYED_to_DPED          -0.055939
# OtherAssetsNoncurrent_FYED_to_DPED                   -0.770498
# OtherAssetsNoncurrentAccumulatedAmortization_FY...    0.024586
# OtherLiabilitiesNoncurrent_FYED_to_DPED               0.168013
# PreferredStockParOrStatedValuePerShare_FYED_to_...    0.000000
# PreferredStockSharesAuthorized_FYED_to_DPED           0.000000
# PreferredStockSharesIssued_FYED_to_DPED                    NaN
# PreferredStockValue_FYED_to_DPED                           NaN
# PrepaidExpenseAndOtherAssetsCurrent_FYED_to_DPED      0.003279
# ProductWarrantyAccrualClassifiedCurrent_FYED_to...    0.036155
# PropertyPlantAndEquipmentGross_FYED_to_DPED           0.042746
# PropertyPlantAndEquipmentNet_FYED_to_DPED             0.006452
# RetainedEarningsAccumulatedDeficit_FYED_to_DPED       0.207613
# StockholdersEquity_FYED_to_DPED                       0.165604
# TaxesPayableCurrentAndNoncurrent_FYED_to_DPED         1.258584

# %% [markdown]
# ### GAAP Data Repositories Planned
# **I plan to organize and collect all GAAP data described above into the following data repositories:**
# * **10Q_XBRL_Instance** - Contains the extracted XBRL instance document for each 10-Q filing. (This repository is currently populated for all filings.)
# * **10Q_GAAP** - One fat file per filing that contains all **facts** extracted from the filing's XBRL instance document. (This repository is currently populated for all filings.)
# * **10Q_GAAP_Metadata** - One fat file per filing that contains the filing's extracted metadata.  It is possible that this might be stored as a single pickled dataframe file depending on size and performance.
# * **10Q_GAAP_Periods** - One fat file per filing containing all raw numeric fiscal instance and fiscal duration data extracted from the filing's XBRL instance document.
# * **10Q_GAAP_QoQ** - One fat file per filing containing the most recent raw numeric quarter over quarter fiscal duration features for all filings.
# * **10Q_GAAP_YoY** - One fat file per filing containing the most recent raw numeric year over year fiscal duration features for all filings.
# * **10Q_GAAP_FYED_to_DPED** - One fat file per filing containing the most recent raw numeric year end over document period end date fiscal instant features for all filings.
# * **10Q_GAAP_Percentages** - One record per filing containing all QoQ, YoY, and FYED_to_DPED percentage change features.
#
# These repositories are subject to change as I begin to populate each one and better understand how successful each collection strategy actually is.
