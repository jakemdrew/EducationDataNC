# %% [markdown]
# # Create 2018-2019 School Datasets¶
# ### This program uses all flattened raw datasets to create the school dataset files within the NCEA repository.
#
# 1. This notebook reads raw dataset .csv files directly from the \EducationDataNC\2018\Raw Datasets folder.
# 2. Each raw dataset is transformed to contain only one record per public school campus or unique agency_code.
# 3. Many raw datasets have more than one record per campus, per year. In these instances, table pivots are used to create new columns from row level entries and reduce each dataset to one record per school. This adds many new colums the flattened dataset. (see the code below for more details)
# 4. School datasets merge all flattened files into one dataset with one record per agency_code.

# %%
#import required Libraries
import pandas as pd
import numpy as np
import os
import string

#**********************************************************************************
# Set the following variables before running this code!!!
#**********************************************************************************

#'C:/Users/Jake/Documents/GitHub/EducationDataNC/2018/
dirPath = 'D:/BenepactLLC/Belk/NC_Report_Card_Data/2020/January 2020/2019/'

#Location where copies of the raw data files will be read in from csv files.
# 'C:/Users/Jake/Documents/GitHub/EducationDataNC/2018/Raw Datasets/'
dataDir = dirPath + 'Raw Datasets/Flattened Datasets/'

#Location where the new school datasets will be created.
# 'C:/Users/Jake/Documents/GitHub/EducationDataNC/2018/School Datasets/'
outputDir = dirPath + 'School Datasets/'

#All raw data files are processed for the year below
schoolYear = 2019

# %% [markdown]
# # Read in the Raw Data Files
# ### This section reads raw data files directly from the \\Raw Datasets folder.
#
# * The file input location is specified at the dataDir parameter.
# * The file output location is specified at the outputDir parameter.
# * The schoolYear parameter is used to specify the correct school year to process.

# %% [markdown]
# # A List of All Files Processed

# %%
#Use wildcards to find files in a directory
import glob
#Use ntpath.basename to get a filename from a filepath
import ntpath

#Get and display a list of all .csv file names for 2018 download
rcdFiles = glob.glob(dataDir + '*.csv')

rcdFileNames = [ntpath.basename(x)[:-4] for x in rcdFiles]

print('A List of File Names and Record Counts for Processing:\n')

#Create dataframes for each file
for fileName in rcdFileNames:
    #create one ataframe for each .csv file in rcdFileNames  
    exec(fileName + ' = pd.read_csv("' + dataDir + '" + "' + fileName + '" + ".csv", low_memory=False, dtype={"agency_code": object})')  
    print(fileName + ', ' + str(len(eval(fileName).index)) )
# Out:
# A List of File Names and Record Counts for Processing:
#
# ec_pupils_pct, 2569
# rcd_acc_aapart, 57
# rcd_acc_act, 743
# rcd_acc_awa, 699
# rcd_acc_cgr, 743
# rcd_acc_eds, 2770
# rcd_acc_eg, 2548
# rcd_acc_elp, 1887
# rcd_acc_essa_desig, 2654
# rcd_acc_gp, 596
# rcd_acc_irm, 1279
# rcd_acc_lowperf, 2769
# rcd_acc_ltg, 2526
# rcd_acc_ltg_detail, 2666
# rcd_acc_mcr, 726
# rcd_acc_part, 2538
# rcd_acc_part_detail, 2538
# rcd_acc_rta, 1578
# rcd_acc_spg1, 2584
# rcd_acc_spg2, 2544
# rcd_acc_wk, 520
# rcd_ap, 578
# rcd_charter, 270
# rcd_courses2, 595
# rcd_cte_concentrators, 553
# rcd_cte_credentials, 533
# rcd_cte_endorsement, 529
# rcd_cte_enrollment, 1189
# rcd_dlmi, 2818
# rcd_ib, 51
# rcd_inc1, 3097
# rcd_inc2, 2719
# rcd_location, 2770
# rcd_prin_demo, 116
# rcd_readiness, 1308
# rcd_sat, 694
# rcd_welcome, 1222

# %% [markdown]
# # Merge all datasets to one master dataset with one record per school
# * **Starting with the location table we left outer join on agency_code, merging data from each reshaped table into one master record.**
# * **The report below ensures that merges by location result in one unique record per public school campus.**
# * **This report also shows changes to the final dataset's column and row counts as each flattened raw dataset is merged into the final Public School Datasets.**

# %%
#Make a copy of a variable (by value) using copy() or deepcopy()
import copy 

#Remove state and district level location records before performing campus level merges
rcd_location = rcd_location[(rcd_location['agency_code'] != 'NC-SEA') & 
                            (rcd_location['agency_code'].str.contains("LEA") == False)]

#Do not merge file: rcd_acc_pc
mergeFileNames = copy.deepcopy(rcdFileNames)
mergeFileNames.remove('rcd_location')
#mergeFileNames.remove('rcd_acc_pc') - Missing in 2019

#Funds are only provided at the district level and require special handling
#mergeFileNames.remove('rcd_funds') - Missing in 2019


print('*********************************Start: RCD Location Data*********************************')
rcd_location.info(verbose=False)

for fileName in mergeFileNames:
    rcd_location = rcd_location.merge(eval(fileName),how='left',on='agency_code', suffixes=('', '_Drop'))
    print('*********************************After: ' + fileName + '**************************')
    rcd_location.info(verbose=False)
    

#Rename final merged rcd file! 
PublicSchools = rcd_location

#Delete all of the duplicate / overlapping columns 
#i.e. When two tables have columns with identical names, the column from the table inside the merge() is deleted.
dropCols = [x for x in PublicSchools.columns if x.endswith('_Drop')]
PublicSchools = PublicSchools.drop(dropCols, axis=1)

#Delete any masking columns that were missed. 
dropCols = [x for x in PublicSchools.columns if x.endswith('_masking')]
PublicSchools = PublicSchools.drop(dropCols, axis=1)

print('*********************************After: Deleting Duplicated Columns*********')
PublicSchools.info(verbose=False)
# Out:
# *********************************Start: RCD Location Data*********************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2651 entries, 0 to 2768
# Columns: 21 entries, agency_code to stem
# dtypes: object(21)
# memory usage: 455.6+ KB
# *********************************After: ec_pupils_pct**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2651 entries, 0 to 2650
# Columns: 46 entries, agency_code to TwoOrMoreFemalePct
# dtypes: float64(24), object(22)
# memory usage: 973.4+ KB
# *********************************After: rcd_acc_aapart**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2651 entries, 0 to 2650
# Columns: 66 entries, agency_code to pct_SC_HS_AAPART
# dtypes: float64(44), object(22)
# memory usage: 1.4+ MB
# *********************************After: rcd_acc_act**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2651 entries, 0 to 2650
# Columns: 199 entries, agency_code to pct_ACWR_WH7_ACT
# dtypes: float64(177), object(22)
# memory usage: 4.0+ MB
# *********************************After: rcd_acc_awa**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2651 entries, 0 to 2650
# Columns: 218 entries, agency_code to pct_WH7_AWA
# dtypes: float64(196), object(22)
# memory usage: 4.4+ MB
# *********************************After: rcd_acc_cgr**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2651 entries, 0 to 2650
# Columns: 254 entries, agency_code to pct_STD_WH7_CGR
# dtypes: float64(232), object(22)
# memory usage: 5.2+ MB
# *********************************After: rcd_acc_eds**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2651 entries, 0 to 2650
# Columns: 255 entries, agency_code to pct_eds
# dtypes: float64(233), object(22)
# memory usage: 5.2+ MB
# *********************************After: rcd_acc_eg**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2651 entries, 0 to 2650
# Columns: 281 entries, agency_code to eg_score_RD_ALL
# dtypes: float64(259), object(22)
# memory usage: 5.7+ MB
# *********************************After: rcd_acc_elp**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2651 entries, 0 to 2650
# Columns: 300 entries, agency_code to pct_WH7_ELP
# dtypes: float64(278), object(22)
# memory usage: 6.1+ MB
# *********************************After: rcd_acc_essa_desig**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2651 entries, 0 to 2650
# Columns: 304 entries, agency_code to tsi_at
# dtypes: float64(278), object(26)
# memory usage: 6.2+ MB
# *********************************After: rcd_acc_gp**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2651 entries, 0 to 2650
# Columns: 305 entries, agency_code to grad_project
# dtypes: float64(278), object(27)
# memory usage: 6.2+ MB
# *********************************After: rcd_acc_irm**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2651 entries, 0 to 2650
# Columns: 307 entries, agency_code to pct_prof_9gr_irm
# dtypes: float64(280), object(27)
# memory usage: 6.2+ MB
# *********************************After: rcd_acc_lowperf**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2651 entries, 0 to 2650
# Columns: 310 entries, agency_code to clpc_school
# dtypes: float64(280), object(30)
# memory usage: 6.3+ MB
# *********************************After: rcd_acc_ltg**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2651 entries, 0 to 2650
# Columns: 317 entries, agency_code to pct_met_Total Targets_LTG
# dtypes: float64(287), object(30)
# memory usage: 6.4+ MB
# *********************************After: rcd_acc_ltg_detail**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2651 entries, 0 to 2650
# Columns: 319 entries, agency_code to subgroup_list
# dtypes: float64(287), object(32)
# memory usage: 6.5+ MB
# *********************************After: rcd_acc_mcr**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2651 entries, 0 to 2650
# Columns: 338 entries, agency_code to pct_WH7_MCR
# dtypes: float64(306), object(32)
# memory usage: 6.9+ MB
# *********************************After: rcd_acc_part**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2651 entries, 0 to 2650
# Columns: 347 entries, agency_code to pct_met_Total Targets_PART
# dtypes: float64(315), object(32)
# memory usage: 7.0+ MB
# *********************************After: rcd_acc_part_detail**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2651 entries, 0 to 2650
# Columns: 427 entries, agency_code to pct_The ACT_WH7_PART_DET
# dtypes: float64(395), object(32)
# memory usage: 8.7+ MB
# *********************************After: rcd_acc_rta**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2651 entries, 0 to 2650
# Columns: 436 entries, agency_code to pct_retained_RTA
# dtypes: float64(404), object(32)
# memory usage: 8.8+ MB
# *********************************After: rcd_acc_spg1**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2651 entries, 0 to 2650
# Columns: 472 entries, agency_code to rd_eg_score
# dtypes: float64(432), object(40)
# memory usage: 9.6+ MB
# *********************************After: rcd_acc_spg2**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2651 entries, 0 to 2650
# Columns: 569 entries, agency_code to spg_score_WH7_SPG2
# dtypes: float64(529), object(40)
# memory usage: 11.5+ MB
# *********************************After: rcd_acc_wk**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2651 entries, 0 to 2650
# Columns: 588 entries, agency_code to pct_WH7_WK
# dtypes: float64(548), object(40)
# memory usage: 11.9+ MB
# *********************************After: rcd_ap**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2651 entries, 0 to 2650
# Columns: 590 entries, agency_code to pct_ap_participation
# dtypes: float64(550), object(40)
# memory usage: 12.0+ MB
# *********************************After: rcd_charter**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2651 entries, 0 to 2650
# Columns: 1280 entries, agency_code to pct_enrolled_NC-SEA_WH7_CHARTER
# dtypes: float64(1240), object(40)
# memory usage: 25.9+ MB
# *********************************After: rcd_courses2**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2651 entries, 0 to 2650
# Columns: 1340 entries, agency_code to pct_ib_H_WH7_COURSES2
# dtypes: float64(1300), object(40)
# memory usage: 27.1+ MB
# *********************************After: rcd_cte_concentrators**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2651 entries, 0 to 2650
# Columns: 1355 entries, agency_code to num_concentrators_TRAN
# dtypes: float64(1315), object(40)
# memory usage: 27.4+ MB
# *********************************After: rcd_cte_credentials**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2651 entries, 0 to 2650
# Columns: 1358 entries, agency_code to cred_earned_pct
# dtypes: float64(1318), object(40)
# memory usage: 27.5+ MB
# *********************************After: rcd_cte_endorsement**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2651 entries, 0 to 2650
# Columns: 1362 entries, agency_code to college_only
# dtypes: float64(1322), object(40)
# memory usage: 27.6+ MB
# *********************************After: rcd_cte_enrollment**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2651 entries, 0 to 2650
# Columns: 1365 entries, agency_code to cte_enrollment_pct
# dtypes: float64(1325), object(40)
# memory usage: 27.6+ MB
# *********************************After: rcd_dlmi**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2651 entries, 0 to 2650
# Columns: 1378 entries, agency_code to devices
# dtypes: float64(1327), object(51)
# memory usage: 27.9+ MB
# *********************************After: rcd_ib**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2651 entries, 0 to 2650
# Columns: 1380 entries, agency_code to pct_ib_participation
# dtypes: float64(1329), object(51)
# memory usage: 27.9+ MB
# *********************************After: rcd_inc1**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2651 entries, 0 to 2650
# Columns: 1384 entries, agency_code to expulsion
# dtypes: float64(1333), object(51)
# memory usage: 28.0+ MB
# *********************************After: rcd_inc2**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2651 entries, 0 to 2650
# Columns: 1488 entries, agency_code to sts_per1000_WH7
# dtypes: float64(1437), object(51)
# memory usage: 30.1+ MB
# *********************************After: rcd_prin_demo**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2651 entries, 0 to 2650
# Columns: 1493 entries, agency_code to pct_prin_demo_WH7
# dtypes: float64(1442), object(51)
# memory usage: 30.2+ MB
# *********************************After: rcd_readiness**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2708 entries, 0 to 2707
# Columns: 1494 entries, agency_code to pct_ready_kea
# dtypes: float64(1443), object(51)
# memory usage: 30.9+ MB
# *********************************After: rcd_sat**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2708 entries, 0 to 2707
# Columns: 1496 entries, agency_code to pct_sat_participation
# dtypes: float64(1445), object(51)
# memory usage: 30.9+ MB
# *********************************After: rcd_welcome**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2708 entries, 0 to 2707
# Columns: 1497 entries, agency_code to welcome_url
# dtypes: float64(1445), object(52)
# memory usage: 30.9+ MB
# *********************************After: Deleting Duplicated Columns*********
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2708 entries, 0 to 2707
# Columns: 1485 entries, agency_code to welcome_url
# dtypes: float64(1434), object(51)
# memory usage: 30.7+ MB

# %% [markdown]
# # This Data is currently missing for 2019
#
# ## Process District Level Funds Data
# * **Funds are only provided at the district level and require special handling**
# * **Funds are also reported for charter schools by agency code**
# * **Must join file by agency_code for charter schools and lea_code for all other schools**

# %%
#Missing in 2019 

# #Give rcd_funds columns names to indicate they are district level values.
# rcd_funds.rename(columns={'total_expense' : 'lea_total_expense' ,
#                           'pct_salary' : 'lea_pct_salary' ,
#                           'pct_benefits' : 'lea_pct_benefits' ,
#                           'pct_services' : 'lea_pct_services' ,
#                           'pct_supplies' : 'lea_pct_supplies' ,
#                           'pct_instruct_equip' : 'lea_pct_instruct_equip' ,
#                           'pct_building' : 'lea_pct_building' ,
#                           'pct_other' : 'lea_pct_other' ,
#                           'local_perpupil' : 'lea_local_perpupil' ,
#                           'state_perpupil' : 'lea_state_perpupil' ,
#                           'federal_perpupil' : 'lea_federal_perpupil'}, inplace=True)

# %%
#Missing in 2019 

#rcd_funds.info()

# %%
#Missing in 2019 

# #Create a new lookup table and field "agency_lea_code" using agency code for charter schools and lea_code for everyone else 
# lea_lookup = pd.DataFrame( rcd_location[['agency_code','lea_code']] )
# lea_lookup['agency_lea_code'] = np.where(lea_lookup['lea_code']=='CH', lea_lookup['agency_code'], lea_lookup['lea_code'])
# lea_lookup = lea_lookup[['agency_lea_code','lea_code']].drop_duplicates()

# #Create a new field "agency_lea_code" on PublicSchools table
# PublicSchools['agency_lea_code'] = np.where(PublicSchools['lea_code']=='CH', 
#                                             PublicSchools['agency_code'], PublicSchools['lea_code'])

# #Merge agency_lea_code to the funds table.
# rcd_funds = rcd_funds.merge(lea_lookup, left_on='agency_code', 
#                             right_on='agency_lea_code', suffixes=('', '_Drop'))

# #Merge PublicSchools and rcd_funds
# PublicSchools = PublicSchools.merge(rcd_funds, how='left',on='agency_lea_code', suffixes=('', '_Drop'))

# #Delete all of the duplicate / overlapping columns 
# #i.e. When two tables have columns with identical names, the column from the table inside the merge() is deleted.
# dropCols = [x for x in PublicSchools.columns if x.endswith('_Drop')]
# PublicSchools = PublicSchools.drop(dropCols, axis=1)

# print('*********************************After: rcd_funds **************************')
# PublicSchools.info(verbose=False)

# %%
#Save the master file to disk
PublicSchools.to_csv(outputDir + 'PublicSchools' + str(schoolYear) + '.csv', sep=',', index=False)

print('*********************************All Public Schools****************************')
PublicSchools.info(verbose=False)

#Filter regular public high schools
HighSchools = PublicSchools[((PublicSchools.category_code == 'H') | 
                             (PublicSchools.category_code == 'T') | 
                             (PublicSchools.category_code == 'A')) 
                            ]

#Save the file to disk
HighSchools.to_csv(outputDir + 'PublicHighSchools' + str(schoolYear) + '.csv', sep=',', index=False)

print('*********************************Regular Public High Schools*******************')
HighSchools.info(verbose=False)

#Filter regular public middle schools
MiddleSchools = PublicSchools[((PublicSchools.category_code == 'M') | 
                               (PublicSchools.category_code == 'T') | 
                               (PublicSchools.category_code == 'A') |
                               (PublicSchools.category_code == 'I'))
                             ]

#Save the file to disk
MiddleSchools.to_csv(outputDir + 'PublicMiddleSchools' + str(schoolYear) + '.csv', sep=',', index=False)

print('*********************************Regular Public Middle Schools******************')
MiddleSchools.info(verbose=False)


#Filter regular elementary high schools
ElementarySchools = PublicSchools[((PublicSchools.category_code == 'E') | 
                                   (PublicSchools.category_code == 'I') | 
                                   (PublicSchools.category_code == 'A')) 
                                 ]

#Save the file to disk
ElementarySchools.to_csv(outputDir + 'PublicElementarySchools' + str(schoolYear) + '.csv', sep=',', index=False)

print('*********************************Regular Public Elementary Schools**************')
ElementarySchools.info(verbose=False)
# Out:
# *********************************All Public Schools****************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2708 entries, 0 to 2707
# Columns: 1485 entries, agency_code to welcome_url
# dtypes: float64(1434), object(51)
# memory usage: 30.7+ MB
# *********************************Regular Public High Schools*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 685 entries, 0 to 2705
# Columns: 1485 entries, agency_code to welcome_url
# dtypes: float64(1434), object(51)
# memory usage: 7.8+ MB
# *********************************Regular Public Middle Schools******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 839 entries, 0 to 2705
# Columns: 1485 entries, agency_code to welcome_url
# dtypes: float64(1434), object(51)
# memory usage: 9.5+ MB
# *********************************Regular Public Elementary Schools**************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1636 entries, 0 to 2706
# Columns: 1485 entries, agency_code to welcome_url
# dtypes: float64(1434), object(51)
# memory usage: 18.5+ MB

# %% [markdown]
# # Data Columns Available in the Public School Dataset

# %%
PublicSchools.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2708 entries, 0 to 2707
# Data columns (total 1485 columns):
# agency_code                            object
# category_code                          object
# agency_level                           object
# lea_code                               object
# designation_type                       object
# name                                   object
# county                                 object
# street_addr                            object
# stree_addr2                            object
# city                                   object
# state                                  object
# zip                                    object
# phone                                  object
# grade_span                             object
# school_type                            object
# calendar_type                          object
# url                                    object
# super_name                             object
# title_I                                object
# esea                                   object
# stem                                   object
# School Name                            object
# IndianPct                              float64
# AsianPct                               float64
# HispanicPct                            float64
# BlackPct                               float64
# WhitePct                               float64
# PacificIslandPct                       float64
# TwoOrMorePct                           float64
# MinorityPct                            float64
# IndianMalePct                          float64
# AsianMalePct                           float64
# HispanicMalePct                        float64
# BlackMalePct                           float64
# WhiteMalePct                           float64
# PacificIslandMalePct                   float64
# TwoOrMoreMalePct                       float64
# MinorityMalePct                        float64
# IndianFemalePct                        float64
# AsianFemalePct                         float64
# HispanicFemalePct                      float64
# BlackFemalePct                         float64
# WhiteFemalePct                         float64
# MinorityFemalePct                      float64
# PacificIslandFemalePct                 float64
# TwoOrMoreFemalePct                     float64
# pct_MA_3_AAPART                        float64
# pct_MA_4_AAPART                        float64
# pct_MA_5_AAPART                        float64
# pct_MA_6_AAPART                        float64
# pct_MA_7_AAPART                        float64
# pct_MA_8_AAPART                        float64
# pct_MA_GS_AAPART                       float64
# pct_MA_HS_AAPART                       float64
# pct_RD_3_AAPART                        float64
# pct_RD_4_AAPART                        float64
# pct_RD_5_AAPART                        float64
# pct_RD_6_AAPART                        float64
# pct_RD_7_AAPART                        float64
# pct_RD_8_AAPART                        float64
# pct_RD_GS_AAPART                       float64
# pct_RD_HS_AAPART                       float64
# pct_SC_5_AAPART                        float64
# pct_SC_8_AAPART                        float64
# pct_SC_GS_AAPART                       float64
# pct_SC_HS_AAPART                       float64
# pct_ACALL_AIG_ACT                      float64
# pct_ACALL_ALL_ACT                      float64
# pct_ACALL_AM7_ACT                      float64
# pct_ACALL_AS7_ACT                      float64
# pct_ACALL_BL7_ACT                      float64
# pct_ACALL_EDS_ACT                      float64
# pct_ACALL_ELS_ACT                      float64
# pct_ACALL_FCS_ACT                      float64
# pct_ACALL_FEM_ACT                      float64
# pct_ACALL_HI7_ACT                      float64
# pct_ACALL_HMS_ACT                      float64
# pct_ACALL_MALE_ACT                     float64
# pct_ACALL_MIG_ACT                      float64
# pct_ACALL_MIL_ACT                      float64
# pct_ACALL_MU7_ACT                      float64
# pct_ACALL_NEDS_ACT                     float64
# pct_ACALL_NSWD_ACT                     float64
# pct_ACALL_SWD_ACT                      float64
# pct_ACALL_WH7_ACT                      float64
# pct_ACCO_AIG_ACT                       float64
# pct_ACCO_ALL_ACT                       float64
# pct_ACCO_AM7_ACT                       float64
# pct_ACCO_AS7_ACT                       float64
# pct_ACCO_BL7_ACT                       float64
# pct_ACCO_EDS_ACT                       float64
# pct_ACCO_ELS_ACT                       float64
# pct_ACCO_FCS_ACT                       float64
# pct_ACCO_FEM_ACT                       float64
# pct_ACCO_HI7_ACT                       float64
# pct_ACCO_HMS_ACT                       float64
# pct_ACCO_MALE_ACT                      float64
# pct_ACCO_MIG_ACT                       float64
# pct_ACCO_MIL_ACT                       float64
# pct_ACCO_MU7_ACT                       float64
# pct_ACCO_NEDS_ACT                      float64
# pct_ACCO_NSWD_ACT                      float64
# pct_ACCO_SWD_ACT                       float64
# pct_ACCO_WH7_ACT                       float64
# pct_ACEN_AIG_ACT                       float64
# pct_ACEN_ALL_ACT                       float64
# pct_ACEN_AM7_ACT                       float64
# pct_ACEN_AS7_ACT                       float64
# pct_ACEN_BL7_ACT                       float64
# pct_ACEN_EDS_ACT                       float64
# pct_ACEN_ELS_ACT                       float64
# pct_ACEN_FCS_ACT                       float64
# pct_ACEN_FEM_ACT                       float64
# pct_ACEN_HI7_ACT                       float64
# pct_ACEN_HMS_ACT                       float64
# pct_ACEN_MALE_ACT                      float64
# pct_ACEN_MIG_ACT                       float64
# pct_ACEN_MIL_ACT                       float64
# pct_ACEN_MU7_ACT                       float64
# pct_ACEN_NEDS_ACT                      float64
# pct_ACEN_NSWD_ACT                      float64
# pct_ACEN_SWD_ACT                       float64
# pct_ACEN_WH7_ACT                       float64
# pct_ACMA_AIG_ACT                       float64
# pct_ACMA_ALL_ACT                       float64
# pct_ACMA_AM7_ACT                       float64
# pct_ACMA_AS7_ACT                       float64
# pct_ACMA_BL7_ACT                       float64
# pct_ACMA_EDS_ACT                       float64
# pct_ACMA_ELS_ACT                       float64
# pct_ACMA_FCS_ACT                       float64
# pct_ACMA_FEM_ACT                       float64
# pct_ACMA_HI7_ACT                       float64
# pct_ACMA_HMS_ACT                       float64
# pct_ACMA_MALE_ACT                      float64
# pct_ACMA_MIG_ACT                       float64
# pct_ACMA_MIL_ACT                       float64
# pct_ACMA_MU7_ACT                       float64
# pct_ACMA_NEDS_ACT                      float64
# pct_ACMA_NSWD_ACT                      float64
# pct_ACMA_SWD_ACT                       float64
# pct_ACMA_WH7_ACT                       float64
# pct_ACRD_AIG_ACT                       float64
# pct_ACRD_ALL_ACT                       float64
# pct_ACRD_AM7_ACT                       float64
# pct_ACRD_AS7_ACT                       float64
# pct_ACRD_BL7_ACT                       float64
# pct_ACRD_EDS_ACT                       float64
# pct_ACRD_ELS_ACT                       float64
# pct_ACRD_FCS_ACT                       float64
# pct_ACRD_FEM_ACT                       float64
# pct_ACRD_HI7_ACT                       float64
# pct_ACRD_HMS_ACT                       float64
# pct_ACRD_MALE_ACT                      float64
# pct_ACRD_MIG_ACT                       float64
# pct_ACRD_MIL_ACT                       float64
# pct_ACRD_MU7_ACT                       float64
# pct_ACRD_NEDS_ACT                      float64
# pct_ACRD_NSWD_ACT                      float64
# pct_ACRD_SWD_ACT                       float64
# pct_ACRD_WH7_ACT                       float64
# pct_ACSC_AIG_ACT                       float64
# pct_ACSC_ALL_ACT                       float64
# pct_ACSC_AM7_ACT                       float64
# pct_ACSC_AS7_ACT                       float64
# pct_ACSC_BL7_ACT                       float64
# pct_ACSC_EDS_ACT                       float64
# pct_ACSC_ELS_ACT                       float64
# pct_ACSC_FCS_ACT                       float64
# pct_ACSC_FEM_ACT                       float64
# pct_ACSC_HI7_ACT                       float64
# pct_ACSC_HMS_ACT                       float64
# pct_ACSC_MALE_ACT                      float64
# pct_ACSC_MIG_ACT                       float64
# pct_ACSC_MIL_ACT                       float64
# pct_ACSC_MU7_ACT                       float64
# pct_ACSC_NEDS_ACT                      float64
# pct_ACSC_NSWD_ACT                      float64
# pct_ACSC_SWD_ACT                       float64
# pct_ACSC_WH7_ACT                       float64
# pct_ACWR_AIG_ACT                       float64
# pct_ACWR_ALL_ACT                       float64
# pct_ACWR_AM7_ACT                       float64
# pct_ACWR_AS7_ACT                       float64
# pct_ACWR_BL7_ACT                       float64
# pct_ACWR_EDS_ACT                       float64
# pct_ACWR_ELS_ACT                       float64
# pct_ACWR_FCS_ACT                       float64
# pct_ACWR_FEM_ACT                       float64
# pct_ACWR_HI7_ACT                       float64
# pct_ACWR_HMS_ACT                       float64
# pct_ACWR_MALE_ACT                      float64
# pct_ACWR_MIG_ACT                       float64
# pct_ACWR_MIL_ACT                       float64
# pct_ACWR_MU7_ACT                       float64
# pct_ACWR_NEDS_ACT                      float64
# pct_ACWR_NSWD_ACT                      float64
# pct_ACWR_SWD_ACT                       float64
# pct_ACWR_WH7_ACT                       float64
# pct_AIG_AWA                            float64
# pct_ALL_AWA                            float64
# pct_AM7_AWA                            float64
# pct_AS7_AWA                            float64
# pct_BL7_AWA                            float64
# pct_EDS_AWA                            float64
# pct_ELS_AWA                            float64
# pct_FCS_AWA                            float64
# pct_FEM_AWA                            float64
# pct_HI7_AWA                            float64
# pct_HMS_AWA                            float64
# pct_MALE_AWA                           float64
# pct_MIG_AWA                            float64
# pct_MIL_AWA                            float64
# pct_MU7_AWA                            float64
# pct_NEDS_AWA                           float64
# pct_NSWD_AWA                           float64
# pct_SWD_AWA                            float64
# pct_WH7_AWA                            float64
# pct_EXT_AIG_CGR                        float64
# pct_EXT_ALL_CGR                        float64
# pct_EXT_AM7_CGR                        float64
# pct_EXT_AS7_CGR                        float64
# pct_EXT_BL7_CGR                        float64
# pct_EXT_EDS_CGR                        float64
# pct_EXT_ELS_CGR                        float64
# pct_EXT_FCS_CGR                        float64
# pct_EXT_FEM_CGR                        float64
# pct_EXT_HI7_CGR                        float64
# pct_EXT_HMS_CGR                        float64
# pct_EXT_MALE_CGR                       float64
# pct_EXT_MIG_CGR                        float64
# pct_EXT_MU7_CGR                        float64
# pct_EXT_NEDS_CGR                       float64
# pct_EXT_NSWD_CGR                       float64
# pct_EXT_SWD_CGR                        float64
# pct_EXT_WH7_CGR                        float64
# pct_STD_AIG_CGR                        float64
# pct_STD_ALL_CGR                        float64
# pct_STD_AM7_CGR                        float64
# pct_STD_AS7_CGR                        float64
# pct_STD_BL7_CGR                        float64
# pct_STD_EDS_CGR                        float64
# pct_STD_ELS_CGR                        float64
# pct_STD_FCS_CGR                        float64
# pct_STD_FEM_CGR                        float64
# pct_STD_HI7_CGR                        float64
# pct_STD_HMS_CGR                        float64
# pct_STD_MALE_CGR                       float64
# pct_STD_MIG_CGR                        float64
# pct_STD_MU7_CGR                        float64
# pct_STD_NEDS_CGR                       float64
# pct_STD_NSWD_CGR                       float64
# pct_STD_SWD_CGR                        float64
# pct_STD_WH7_CGR                        float64
# pct_eds                                float64
# eg_index_ALL_AIG                       float64
# eg_index_ALL_ALL                       float64
# eg_index_ALL_AM7                       float64
# eg_index_ALL_AS7                       float64
# eg_index_ALL_BL7                       float64
# eg_index_ALL_EDS                       float64
# eg_index_ALL_ELS                       float64
# eg_index_ALL_HI7                       float64
# eg_index_ALL_MU7                       float64
# eg_index_ALL_SWD                       float64
# eg_index_ALL_WH7                       float64
# eg_index_MA_ALL                        float64
# eg_index_RD_ALL                        float64
# eg_score_ALL_AIG                       float64
# eg_score_ALL_ALL                       float64
# eg_score_ALL_AM7                       float64
# eg_score_ALL_AS7                       float64
# eg_score_ALL_BL7                       float64
# eg_score_ALL_EDS                       float64
# eg_score_ALL_ELS                       float64
# eg_score_ALL_HI7                       float64
# eg_score_ALL_MU7                       float64
# eg_score_ALL_SWD                       float64
# eg_score_ALL_WH7                       float64
# eg_score_MA_ALL                        float64
# eg_score_RD_ALL                        float64
# pct_AIG_ELP                            float64
# pct_ALL_ELP                            float64
# pct_AM7_ELP                            float64
# pct_AS7_ELP                            float64
# pct_BL7_ELP                            float64
# pct_EDS_ELP                            float64
# pct_ELS_ELP                            float64
# pct_FCS_ELP                            float64
# pct_FEM_ELP                            float64
# pct_HI7_ELP                            float64
# pct_HMS_ELP                            float64
# pct_MALE_ELP                           float64
# pct_MIG_ELP                            float64
# pct_MIL_ELP                            float64
# pct_MU7_ELP                            float64
# pct_NEDS_ELP                           float64
# pct_NSWD_ELP                           float64
# pct_SWD_ELP                            float64
# pct_WH7_ELP                            float64
# csi_lp                                 object
# csi_lg                                 object
# tsi_cu                                 object
# tsi_at                                 object
# grad_project                           object
# pct_prof_6gr_irm                       float64
# pct_prof_9gr_irm                       float64
# lp_school                              object
# rlp_school                             object
# clpc_school                            object
# pct_met_4 Year Graduation Rate_LTG     float64
# pct_met_EL Progress_LTG                float64
# pct_met_Math Grade 11_LTG              float64
# pct_met_Math Grades 3-8_LTG            float64
# pct_met_Reading Grade 10_LTG           float64
# pct_met_Reading Grades 3-8_LTG         float64
# pct_met_Total Targets_LTG              float64
# target_list                            object
# subgroup_list                          object
# pct_AIG_MCR                            float64
# pct_ALL_MCR                            float64
# pct_AM7_MCR                            float64
# pct_AS7_MCR                            float64
# pct_BL7_MCR                            float64
# pct_EDS_MCR                            float64
# pct_ELS_MCR                            float64
# pct_FCS_MCR                            float64
# pct_FEM_MCR                            float64
# pct_HI7_MCR                            float64
# pct_HMS_MCR                            float64
# pct_MALE_MCR                           float64
# pct_MIG_MCR                            float64
# pct_MIL_MCR                            float64
# pct_MU7_MCR                            float64
# pct_NEDS_MCR                           float64
# pct_NSWD_MCR                           float64
# pct_SWD_MCR                            float64
# pct_WH7_MCR                            float64
# pct_met_ACT WorkKeys_PART              float64
# pct_met_Biology_PART                   float64
# pct_met_English II_PART                float64
# pct_met_High School Math_PART          float64
# pct_met_Math Grades 3-8_PART           float64
# pct_met_Reading Grades 3-8_PART        float64
# pct_met_Science Grades 5&8_PART        float64
# pct_met_The ACT_PART                   float64
# pct_met_Total Targets_PART             float64
# pct_ACT WorkKeys_ALL_PART_DET          float64
# pct_ACT WorkKeys_AM7_PART_DET          float64
# pct_ACT WorkKeys_AS7_PART_DET          float64
# pct_ACT WorkKeys_BL7_PART_DET          float64
# pct_ACT WorkKeys_EDS_PART_DET          float64
# pct_ACT WorkKeys_ELS_PART_DET          float64
# pct_ACT WorkKeys_HI7_PART_DET          float64
# pct_ACT WorkKeys_MU7_PART_DET          float64
# pct_ACT WorkKeys_SWD_PART_DET          float64
# pct_ACT WorkKeys_WH7_PART_DET          float64
# pct_Biology_ALL_PART_DET               float64
# pct_Biology_AM7_PART_DET               float64
# pct_Biology_AS7_PART_DET               float64
# pct_Biology_BL7_PART_DET               float64
# pct_Biology_EDS_PART_DET               float64
# pct_Biology_ELS_PART_DET               float64
# pct_Biology_HI7_PART_DET               float64
# pct_Biology_MU7_PART_DET               float64
# pct_Biology_SWD_PART_DET               float64
# pct_Biology_WH7_PART_DET               float64
# pct_English II_ALL_PART_DET            float64
# pct_English II_AM7_PART_DET            float64
# pct_English II_AS7_PART_DET            float64
# pct_English II_BL7_PART_DET            float64
# pct_English II_EDS_PART_DET            float64
# pct_English II_ELS_PART_DET            float64
# pct_English II_HI7_PART_DET            float64
# pct_English II_MU7_PART_DET            float64
# pct_English II_SWD_PART_DET            float64
# pct_English II_WH7_PART_DET            float64
# pct_High School Math_ALL_PART_DET      float64
# pct_High School Math_AM7_PART_DET      float64
# pct_High School Math_AS7_PART_DET      float64
# pct_High School Math_BL7_PART_DET      float64
# pct_High School Math_EDS_PART_DET      float64
# pct_High School Math_ELS_PART_DET      float64
# pct_High School Math_HI7_PART_DET      float64
# pct_High School Math_MU7_PART_DET      float64
# pct_High School Math_SWD_PART_DET      float64
# pct_High School Math_WH7_PART_DET      float64
# pct_Math Grades 3-8_ALL_PART_DET       float64
# pct_Math Grades 3-8_AM7_PART_DET       float64
# pct_Math Grades 3-8_AS7_PART_DET       float64
# pct_Math Grades 3-8_BL7_PART_DET       float64
# pct_Math Grades 3-8_EDS_PART_DET       float64
# pct_Math Grades 3-8_ELS_PART_DET       float64
# pct_Math Grades 3-8_HI7_PART_DET       float64
# pct_Math Grades 3-8_MU7_PART_DET       float64
# pct_Math Grades 3-8_SWD_PART_DET       float64
# pct_Math Grades 3-8_WH7_PART_DET       float64
# pct_Reading Grades 3-8_ALL_PART_DET    float64
# pct_Reading Grades 3-8_AM7_PART_DET    float64
# pct_Reading Grades 3-8_AS7_PART_DET    float64
# pct_Reading Grades 3-8_BL7_PART_DET    float64
# pct_Reading Grades 3-8_EDS_PART_DET    float64
# pct_Reading Grades 3-8_ELS_PART_DET    float64
# pct_Reading Grades 3-8_HI7_PART_DET    float64
# pct_Reading Grades 3-8_MU7_PART_DET    float64
# pct_Reading Grades 3-8_SWD_PART_DET    float64
# pct_Reading Grades 3-8_WH7_PART_DET    float64
# pct_Science Grades 5&8_ALL_PART_DET    float64
# pct_Science Grades 5&8_AM7_PART_DET    float64
# pct_Science Grades 5&8_AS7_PART_DET    float64
# pct_Science Grades 5&8_BL7_PART_DET    float64
# pct_Science Grades 5&8_EDS_PART_DET    float64
# pct_Science Grades 5&8_ELS_PART_DET    float64
# pct_Science Grades 5&8_HI7_PART_DET    float64
# pct_Science Grades 5&8_MU7_PART_DET    float64
# pct_Science Grades 5&8_SWD_PART_DET    float64
# pct_Science Grades 5&8_WH7_PART_DET    float64
# pct_The ACT_ALL_PART_DET               float64
# pct_The ACT_AM7_PART_DET               float64
# pct_The ACT_AS7_PART_DET               float64
# pct_The ACT_BL7_PART_DET               float64
# pct_The ACT_EDS_PART_DET               float64
# pct_The ACT_ELS_PART_DET               float64
# pct_The ACT_HI7_PART_DET               float64
# pct_The ACT_MU7_PART_DET               float64
# pct_The ACT_SWD_PART_DET               float64
# pct_The ACT_WH7_PART_DET               float64
# pct_gce_all_RTA                        float64
# pct_gce_prm_RTA                        float64
# pct_gce_rpf_RTA                        float64
# pct_gce_swd_RTA                        float64
# pct_passed_eog_RTA                     float64
# pct_passed_laa_RTA                     float64
# pct_passed_rta_RTA                     float64
# pct_promoted_RTA                       float64
# pct_retained_RTA                       float64
# asm_option                             object
# subgroup                               object
# ma_score                               float64
# ma_grade                               object
# rd_score                               float64
# rd_grade                               object
# sc_score                               float64
# m1_score                               float64
# e2_score                               float64
# bi_score                               float64
# act_score                              float64
# wk_score                               float64
# mcr_score                              float64
# cgrs_score                             float64
# ach_score                              float64
# eg_status                              object
# eg_score                               float64
# spg_score                              float64
# spg_grade                              object
# ma_spg_score                           float64
# rd_spg_score                           float64
# ma_eg_status                           object
# rd_eg_status                           object
# ma_eg_score                            float64
# rd_eg_score                            float64
# aaa_score_ALL_SPG2                     float64
# aaa_score_AM7_SPG2                     float64
# aaa_score_AS7_SPG2                     float64
# aaa_score_BL7_SPG2                     float64
# aaa_score_EDS_SPG2                     float64
# aaa_score_ELS_SPG2                     float64
# aaa_score_HI7_SPG2                     float64
# aaa_score_MU7_SPG2                     float64
# aaa_score_SWD_SPG2                     float64
# aaa_score_WH7_SPG2                     float64
# ach_score_ALL_SPG2                     float64
# ach_score_AM7_SPG2                     float64
# ach_score_AS7_SPG2                     float64
# ach_score_BL7_SPG2                     float64
# ach_score_EDS_SPG2                     float64
# ach_score_ELS_SPG2                     float64
# ach_score_HI7_SPG2                     float64
# ach_score_MU7_SPG2                     float64
# ach_score_SWD_SPG2                     float64
# ach_score_WH7_SPG2                     float64
# awa_score_ALL_SPG2                     float64
# awa_score_AM7_SPG2                     float64
# awa_score_AS7_SPG2                     float64
# awa_score_BL7_SPG2                     float64
# awa_score_EDS_SPG2                     float64
# awa_score_ELS_SPG2                     float64
# awa_score_HI7_SPG2                     float64
# awa_score_MU7_SPG2                     float64
# awa_score_SWD_SPG2                     float64
# awa_score_WH7_SPG2                     float64
# bi_score_ALL_SPG2                      float64
# bi_score_AM7_SPG2                      float64
# bi_score_AS7_SPG2                      float64
# bi_score_BL7_SPG2                      float64
# bi_score_EDS_SPG2                      float64
# bi_score_ELS_SPG2                      float64
# bi_score_HI7_SPG2                      float64
# bi_score_MU7_SPG2                      float64
# bi_score_SWD_SPG2                      float64
# bi_score_WH7_SPG2                      float64
# cgrs_score_ALL_SPG2                    float64
# cgrs_score_AM7_SPG2                    float64
# cgrs_score_AS7_SPG2                    float64
# cgrs_score_BL7_SPG2                    float64
# cgrs_score_EDS_SPG2                    float64
# cgrs_score_ELS_SPG2                    float64
# cgrs_score_HI7_SPG2                    float64
# cgrs_score_MU7_SPG2                    float64
# cgrs_score_SWD_SPG2                    float64
# cgrs_score_WH7_SPG2                    float64
# eg_score_ALL_SPG2                      float64
# eg_score_AM7_SPG2                      float64
# eg_score_AS7_SPG2                      float64
# eg_score_BL7_SPG2                      float64
# eg_score_EDS_SPG2                      float64
# eg_score_ELS_SPG2                      float64
# eg_score_HI7_SPG2                      float64
# eg_score_MU7_SPG2                      float64
# eg_score_SWD_SPG2                      float64
# eg_score_WH7_SPG2                      float64
# elp_score_ALL_SPG2                     float64
# elp_score_AS7_SPG2                     float64
# elp_score_BL7_SPG2                     float64
# elp_score_EDS_SPG2                     float64
# elp_score_ELS_SPG2                     float64
# elp_score_HI7_SPG2                     float64
# elp_score_SWD_SPG2                     float64
# mcr_score_ALL_SPG2                     float64
# mcr_score_AM7_SPG2                     float64
# mcr_score_AS7_SPG2                     float64
# mcr_score_BL7_SPG2                     float64
# mcr_score_EDS_SPG2                     float64
# mcr_score_ELS_SPG2                     float64
# mcr_score_HI7_SPG2                     float64
# mcr_score_MU7_SPG2                     float64
# mcr_score_SWD_SPG2                     float64
# mcr_score_WH7_SPG2                     float64
# scgs_score_ALL_SPG2                    float64
# scgs_score_AM7_SPG2                    float64
# scgs_score_AS7_SPG2                    float64
# scgs_score_BL7_SPG2                    float64
# scgs_score_EDS_SPG2                    float64
# scgs_score_ELS_SPG2                    float64
# scgs_score_HI7_SPG2                    float64
# scgs_score_MU7_SPG2                    float64
# scgs_score_SWD_SPG2                    float64
# scgs_score_WH7_SPG2                    float64
# spg_score_ALL_SPG2                     float64
# spg_score_AM7_SPG2                     float64
# spg_score_AS7_SPG2                     float64
# spg_score_BL7_SPG2                     float64
# spg_score_EDS_SPG2                     float64
# spg_score_ELS_SPG2                     float64
# spg_score_HI7_SPG2                     float64
# spg_score_MU7_SPG2                     float64
# spg_score_SWD_SPG2                     float64
# spg_score_WH7_SPG2                     float64
# pct_AIG_WK                             float64
# pct_ALL_WK                             float64
# pct_AM7_WK                             float64
# pct_AS7_WK                             float64
# pct_BL7_WK                             float64
# pct_EDS_WK                             float64
# pct_ELS_WK                             float64
# pct_FCS_WK                             float64
# pct_FEM_WK                             float64
# pct_HI7_WK                             float64
# pct_HMS_WK                             float64
# pct_MALE_WK                            float64
# pct_MIG_WK                             float64
# pct_MIL_WK                             float64
# pct_MU7_WK                             float64
# pct_NEDS_WK                            float64
# pct_NSWD_WK                            float64
# pct_SWD_WK                             float64
# pct_WH7_WK                             float64
# pct_ap_pass                            float64
# pct_ap_participation                   float64
# pct_enrolled_010LEA_AM7_CHARTER        float64
# pct_enrolled_010LEA_AS7_CHARTER        float64
# pct_enrolled_010LEA_BL7_CHARTER        float64
# pct_enrolled_010LEA_EDS_CHARTER        float64
# pct_enrolled_010LEA_ELS_CHARTER        float64
# pct_enrolled_010LEA_HI7_CHARTER        float64
# pct_enrolled_010LEA_MU7_CHARTER        float64
# pct_enrolled_010LEA_PI7_CHARTER        float64
# pct_enrolled_010LEA_SWD_CHARTER        float64
# pct_enrolled_010LEA_WH7_CHARTER        float64
# pct_enrolled_060LEA_AM7_CHARTER        float64
# pct_enrolled_060LEA_AS7_CHARTER        float64
# pct_enrolled_060LEA_BL7_CHARTER        float64
# pct_enrolled_060LEA_EDS_CHARTER        float64
# pct_enrolled_060LEA_ELS_CHARTER        float64
# pct_enrolled_060LEA_HI7_CHARTER        float64
# pct_enrolled_060LEA_MU7_CHARTER        float64
# pct_enrolled_060LEA_PI7_CHARTER        float64
# pct_enrolled_060LEA_SWD_CHARTER        float64
# pct_enrolled_060LEA_WH7_CHARTER        float64
# pct_enrolled_070LEA_AM7_CHARTER        float64
# pct_enrolled_070LEA_AS7_CHARTER        float64
# pct_enrolled_070LEA_BL7_CHARTER        float64
# pct_enrolled_070LEA_EDS_CHARTER        float64
# pct_enrolled_070LEA_ELS_CHARTER        float64
# pct_enrolled_070LEA_HI7_CHARTER        float64
# pct_enrolled_070LEA_MU7_CHARTER        float64
# pct_enrolled_070LEA_PI7_CHARTER        float64
# pct_enrolled_070LEA_SWD_CHARTER        float64
# pct_enrolled_070LEA_WH7_CHARTER        float64
# pct_enrolled_080LEA_AM7_CHARTER        float64
# pct_enrolled_080LEA_AS7_CHARTER        float64
# pct_enrolled_080LEA_BL7_CHARTER        float64
# pct_enrolled_080LEA_EDS_CHARTER        float64
# pct_enrolled_080LEA_ELS_CHARTER        float64
# pct_enrolled_080LEA_HI7_CHARTER        float64
# pct_enrolled_080LEA_MU7_CHARTER        float64
# pct_enrolled_080LEA_PI7_CHARTER        float64
# pct_enrolled_080LEA_SWD_CHARTER        float64
# pct_enrolled_080LEA_WH7_CHARTER        float64
# pct_enrolled_090LEA_AM7_CHARTER        float64
# pct_enrolled_090LEA_AS7_CHARTER        float64
# pct_enrolled_090LEA_BL7_CHARTER        float64
# pct_enrolled_090LEA_EDS_CHARTER        float64
# pct_enrolled_090LEA_ELS_CHARTER        float64
# pct_enrolled_090LEA_HI7_CHARTER        float64
# pct_enrolled_090LEA_MU7_CHARTER        float64
# pct_enrolled_090LEA_PI7_CHARTER        float64
# pct_enrolled_090LEA_SWD_CHARTER        float64
# pct_enrolled_090LEA_WH7_CHARTER        float64
# pct_enrolled_100LEA_AM7_CHARTER        float64
# pct_enrolled_100LEA_AS7_CHARTER        float64
# pct_enrolled_100LEA_BL7_CHARTER        float64
# pct_enrolled_100LEA_EDS_CHARTER        float64
# pct_enrolled_100LEA_ELS_CHARTER        float64
# pct_enrolled_100LEA_HI7_CHARTER        float64
# pct_enrolled_100LEA_MU7_CHARTER        float64
# pct_enrolled_100LEA_PI7_CHARTER        float64
# pct_enrolled_100LEA_SWD_CHARTER        float64
# pct_enrolled_100LEA_WH7_CHARTER        float64
# pct_enrolled_110LEA_AM7_CHARTER        float64
# pct_enrolled_110LEA_AS7_CHARTER        float64
# pct_enrolled_110LEA_BL7_CHARTER        float64
# pct_enrolled_110LEA_EDS_CHARTER        float64
# pct_enrolled_110LEA_ELS_CHARTER        float64
# pct_enrolled_110LEA_HI7_CHARTER        float64
# pct_enrolled_110LEA_MU7_CHARTER        float64
# pct_enrolled_110LEA_PI7_CHARTER        float64
# pct_enrolled_110LEA_SWD_CHARTER        float64
# pct_enrolled_110LEA_WH7_CHARTER        float64
# pct_enrolled_111LEA_AM7_CHARTER        float64
# pct_enrolled_111LEA_AS7_CHARTER        float64
# pct_enrolled_111LEA_BL7_CHARTER        float64
# pct_enrolled_111LEA_EDS_CHARTER        float64
# pct_enrolled_111LEA_ELS_CHARTER        float64
# pct_enrolled_111LEA_HI7_CHARTER        float64
# pct_enrolled_111LEA_MU7_CHARTER        float64
# pct_enrolled_111LEA_PI7_CHARTER        float64
# pct_enrolled_111LEA_SWD_CHARTER        float64
# pct_enrolled_111LEA_WH7_CHARTER        float64
# pct_enrolled_120LEA_AM7_CHARTER        float64
# pct_enrolled_120LEA_AS7_CHARTER        float64
# pct_enrolled_120LEA_BL7_CHARTER        float64
# pct_enrolled_120LEA_EDS_CHARTER        float64
# pct_enrolled_120LEA_ELS_CHARTER        float64
# pct_enrolled_120LEA_HI7_CHARTER        float64
# pct_enrolled_120LEA_MU7_CHARTER        float64
# pct_enrolled_120LEA_PI7_CHARTER        float64
# pct_enrolled_120LEA_SWD_CHARTER        float64
# pct_enrolled_120LEA_WH7_CHARTER        float64
# pct_enrolled_130LEA_AM7_CHARTER        float64
# pct_enrolled_130LEA_AS7_CHARTER        float64
# pct_enrolled_130LEA_BL7_CHARTER        float64
# pct_enrolled_130LEA_EDS_CHARTER        float64
# pct_enrolled_130LEA_ELS_CHARTER        float64
# pct_enrolled_130LEA_HI7_CHARTER        float64
# pct_enrolled_130LEA_MU7_CHARTER        float64
# pct_enrolled_130LEA_PI7_CHARTER        float64
# pct_enrolled_130LEA_SWD_CHARTER        float64
# pct_enrolled_130LEA_WH7_CHARTER        float64
# pct_enrolled_160LEA_AM7_CHARTER        float64
# pct_enrolled_160LEA_AS7_CHARTER        float64
# pct_enrolled_160LEA_BL7_CHARTER        float64
# pct_enrolled_160LEA_EDS_CHARTER        float64
# pct_enrolled_160LEA_ELS_CHARTER        float64
# pct_enrolled_160LEA_HI7_CHARTER        float64
# pct_enrolled_160LEA_MU7_CHARTER        float64
# pct_enrolled_160LEA_PI7_CHARTER        float64
# pct_enrolled_160LEA_SWD_CHARTER        float64
# pct_enrolled_160LEA_WH7_CHARTER        float64
# pct_enrolled_190LEA_AM7_CHARTER        float64
# pct_enrolled_190LEA_AS7_CHARTER        float64
# pct_enrolled_190LEA_BL7_CHARTER        float64
# pct_enrolled_190LEA_EDS_CHARTER        float64
# pct_enrolled_190LEA_ELS_CHARTER        float64
# pct_enrolled_190LEA_HI7_CHARTER        float64
# pct_enrolled_190LEA_MU7_CHARTER        float64
# pct_enrolled_190LEA_PI7_CHARTER        float64
# pct_enrolled_190LEA_SWD_CHARTER        float64
# pct_enrolled_190LEA_WH7_CHARTER        float64
# pct_enrolled_200LEA_AM7_CHARTER        float64
# pct_enrolled_200LEA_AS7_CHARTER        float64
# pct_enrolled_200LEA_BL7_CHARTER        float64
# pct_enrolled_200LEA_EDS_CHARTER        float64
# pct_enrolled_200LEA_ELS_CHARTER        float64
# pct_enrolled_200LEA_HI7_CHARTER        float64
# pct_enrolled_200LEA_MU7_CHARTER        float64
# pct_enrolled_200LEA_PI7_CHARTER        float64
# pct_enrolled_200LEA_SWD_CHARTER        float64
# pct_enrolled_200LEA_WH7_CHARTER        float64
# pct_enrolled_230LEA_AM7_CHARTER        float64
# pct_enrolled_230LEA_AS7_CHARTER        float64
# pct_enrolled_230LEA_BL7_CHARTER        float64
# pct_enrolled_230LEA_EDS_CHARTER        float64
# pct_enrolled_230LEA_ELS_CHARTER        float64
# pct_enrolled_230LEA_HI7_CHARTER        float64
# pct_enrolled_230LEA_MU7_CHARTER        float64
# pct_enrolled_230LEA_PI7_CHARTER        float64
# pct_enrolled_230LEA_SWD_CHARTER        float64
# pct_enrolled_230LEA_WH7_CHARTER        float64
# pct_enrolled_240LEA_AM7_CHARTER        float64
# pct_enrolled_240LEA_AS7_CHARTER        float64
# pct_enrolled_240LEA_BL7_CHARTER        float64
# pct_enrolled_240LEA_EDS_CHARTER        float64
# pct_enrolled_240LEA_ELS_CHARTER        float64
# pct_enrolled_240LEA_HI7_CHARTER        float64
# pct_enrolled_240LEA_MU7_CHARTER        float64
# pct_enrolled_240LEA_PI7_CHARTER        float64
# pct_enrolled_240LEA_SWD_CHARTER        float64
# pct_enrolled_240LEA_WH7_CHARTER        float64
# pct_enrolled_241LEA_AM7_CHARTER        float64
# pct_enrolled_241LEA_AS7_CHARTER        float64
# pct_enrolled_241LEA_BL7_CHARTER        float64
# pct_enrolled_241LEA_EDS_CHARTER        float64
# pct_enrolled_241LEA_ELS_CHARTER        float64
# pct_enrolled_241LEA_HI7_CHARTER        float64
# pct_enrolled_241LEA_MU7_CHARTER        float64
# pct_enrolled_241LEA_PI7_CHARTER        float64
# pct_enrolled_241LEA_SWD_CHARTER        float64
# pct_enrolled_241LEA_WH7_CHARTER        float64
# pct_enrolled_260LEA_AM7_CHARTER        float64
# pct_enrolled_260LEA_AS7_CHARTER        float64
# pct_enrolled_260LEA_BL7_CHARTER        float64
# pct_enrolled_260LEA_EDS_CHARTER        float64
# pct_enrolled_260LEA_ELS_CHARTER        float64
# pct_enrolled_260LEA_HI7_CHARTER        float64
# pct_enrolled_260LEA_MU7_CHARTER        float64
# pct_enrolled_260LEA_PI7_CHARTER        float64
# pct_enrolled_260LEA_SWD_CHARTER        float64
# pct_enrolled_260LEA_WH7_CHARTER        float64
# pct_enrolled_270LEA_AM7_CHARTER        float64
# pct_enrolled_270LEA_AS7_CHARTER        float64
# pct_enrolled_270LEA_BL7_CHARTER        float64
# pct_enrolled_270LEA_EDS_CHARTER        float64
# pct_enrolled_270LEA_ELS_CHARTER        float64
# pct_enrolled_270LEA_HI7_CHARTER        float64
# pct_enrolled_270LEA_MU7_CHARTER        float64
# pct_enrolled_270LEA_PI7_CHARTER        float64
# pct_enrolled_270LEA_SWD_CHARTER        float64
# pct_enrolled_270LEA_WH7_CHARTER        float64
# pct_enrolled_290LEA_AM7_CHARTER        float64
# pct_enrolled_290LEA_AS7_CHARTER        float64
# pct_enrolled_290LEA_BL7_CHARTER        float64
# pct_enrolled_290LEA_EDS_CHARTER        float64
# pct_enrolled_290LEA_ELS_CHARTER        float64
# pct_enrolled_290LEA_HI7_CHARTER        float64
# pct_enrolled_290LEA_MU7_CHARTER        float64
# pct_enrolled_290LEA_PI7_CHARTER        float64
# pct_enrolled_290LEA_SWD_CHARTER        float64
# pct_enrolled_290LEA_WH7_CHARTER        float64
# pct_enrolled_320LEA_AM7_CHARTER        float64
# pct_enrolled_320LEA_AS7_CHARTER        float64
# pct_enrolled_320LEA_BL7_CHARTER        float64
# pct_enrolled_320LEA_EDS_CHARTER        float64
# pct_enrolled_320LEA_ELS_CHARTER        float64
# pct_enrolled_320LEA_HI7_CHARTER        float64
# pct_enrolled_320LEA_MU7_CHARTER        float64
# pct_enrolled_320LEA_PI7_CHARTER        float64
# pct_enrolled_320LEA_SWD_CHARTER        float64
# pct_enrolled_320LEA_WH7_CHARTER        float64
# pct_enrolled_330LEA_AM7_CHARTER        float64
# pct_enrolled_330LEA_AS7_CHARTER        float64
# pct_enrolled_330LEA_BL7_CHARTER        float64
# pct_enrolled_330LEA_EDS_CHARTER        float64
# pct_enrolled_330LEA_ELS_CHARTER        float64
# pct_enrolled_330LEA_HI7_CHARTER        float64
# pct_enrolled_330LEA_MU7_CHARTER        float64
# pct_enrolled_330LEA_PI7_CHARTER        float64
# pct_enrolled_330LEA_SWD_CHARTER        float64
# pct_enrolled_330LEA_WH7_CHARTER        float64
# pct_enrolled_340LEA_AM7_CHARTER        float64
# pct_enrolled_340LEA_AS7_CHARTER        float64
# pct_enrolled_340LEA_BL7_CHARTER        float64
# pct_enrolled_340LEA_EDS_CHARTER        float64
# pct_enrolled_340LEA_ELS_CHARTER        float64
# pct_enrolled_340LEA_HI7_CHARTER        float64
# pct_enrolled_340LEA_MU7_CHARTER        float64
# pct_enrolled_340LEA_PI7_CHARTER        float64
# pct_enrolled_340LEA_SWD_CHARTER        float64
# pct_enrolled_340LEA_WH7_CHARTER        float64
# pct_enrolled_350LEA_AM7_CHARTER        float64
# pct_enrolled_350LEA_AS7_CHARTER        float64
# pct_enrolled_350LEA_BL7_CHARTER        float64
# pct_enrolled_350LEA_EDS_CHARTER        float64
# pct_enrolled_350LEA_ELS_CHARTER        float64
# pct_enrolled_350LEA_HI7_CHARTER        float64
# pct_enrolled_350LEA_MU7_CHARTER        float64
# pct_enrolled_350LEA_PI7_CHARTER        float64
# pct_enrolled_350LEA_SWD_CHARTER        float64
# pct_enrolled_350LEA_WH7_CHARTER        float64
# pct_enrolled_360LEA_AM7_CHARTER        float64
# pct_enrolled_360LEA_AS7_CHARTER        float64
# pct_enrolled_360LEA_BL7_CHARTER        float64
# pct_enrolled_360LEA_EDS_CHARTER        float64
# pct_enrolled_360LEA_ELS_CHARTER        float64
# pct_enrolled_360LEA_HI7_CHARTER        float64
# pct_enrolled_360LEA_MU7_CHARTER        float64
# pct_enrolled_360LEA_PI7_CHARTER        float64
# pct_enrolled_360LEA_SWD_CHARTER        float64
# pct_enrolled_360LEA_WH7_CHARTER        float64
# pct_enrolled_390LEA_AM7_CHARTER        float64
# pct_enrolled_390LEA_AS7_CHARTER        float64
# pct_enrolled_390LEA_BL7_CHARTER        float64
# pct_enrolled_390LEA_EDS_CHARTER        float64
# pct_enrolled_390LEA_ELS_CHARTER        float64
# pct_enrolled_390LEA_HI7_CHARTER        float64
# pct_enrolled_390LEA_MU7_CHARTER        float64
# pct_enrolled_390LEA_PI7_CHARTER        float64
# pct_enrolled_390LEA_SWD_CHARTER        float64
# pct_enrolled_390LEA_WH7_CHARTER        float64
# pct_enrolled_410LEA_AM7_CHARTER        float64
# pct_enrolled_410LEA_AS7_CHARTER        float64
# pct_enrolled_410LEA_BL7_CHARTER        float64
# pct_enrolled_410LEA_EDS_CHARTER        float64
# pct_enrolled_410LEA_ELS_CHARTER        float64
# pct_enrolled_410LEA_HI7_CHARTER        float64
# pct_enrolled_410LEA_MU7_CHARTER        float64
# pct_enrolled_410LEA_PI7_CHARTER        float64
# pct_enrolled_410LEA_SWD_CHARTER        float64
# pct_enrolled_410LEA_WH7_CHARTER        float64
# pct_enrolled_420LEA_AM7_CHARTER        float64
# pct_enrolled_420LEA_AS7_CHARTER        float64
# pct_enrolled_420LEA_BL7_CHARTER        float64
# pct_enrolled_420LEA_EDS_CHARTER        float64
# pct_enrolled_420LEA_ELS_CHARTER        float64
# pct_enrolled_420LEA_HI7_CHARTER        float64
# pct_enrolled_420LEA_MU7_CHARTER        float64
# pct_enrolled_420LEA_PI7_CHARTER        float64
# pct_enrolled_420LEA_SWD_CHARTER        float64
# pct_enrolled_420LEA_WH7_CHARTER        float64
# pct_enrolled_430LEA_AM7_CHARTER        float64
# pct_enrolled_430LEA_AS7_CHARTER        float64
# pct_enrolled_430LEA_BL7_CHARTER        float64
# pct_enrolled_430LEA_EDS_CHARTER        float64
# pct_enrolled_430LEA_ELS_CHARTER        float64
# pct_enrolled_430LEA_HI7_CHARTER        float64
# pct_enrolled_430LEA_MU7_CHARTER        float64
# pct_enrolled_430LEA_PI7_CHARTER        float64
# pct_enrolled_430LEA_SWD_CHARTER        float64
# pct_enrolled_430LEA_WH7_CHARTER        float64
# pct_enrolled_440LEA_AM7_CHARTER        float64
# pct_enrolled_440LEA_AS7_CHARTER        float64
# pct_enrolled_440LEA_BL7_CHARTER        float64
# pct_enrolled_440LEA_EDS_CHARTER        float64
# pct_enrolled_440LEA_ELS_CHARTER        float64
# pct_enrolled_440LEA_HI7_CHARTER        float64
# pct_enrolled_440LEA_MU7_CHARTER        float64
# pct_enrolled_440LEA_PI7_CHARTER        float64
# pct_enrolled_440LEA_SWD_CHARTER        float64
# pct_enrolled_440LEA_WH7_CHARTER        float64
# pct_enrolled_450LEA_AM7_CHARTER        float64
# pct_enrolled_450LEA_AS7_CHARTER        float64
# pct_enrolled_450LEA_BL7_CHARTER        float64
# pct_enrolled_450LEA_EDS_CHARTER        float64
# pct_enrolled_450LEA_ELS_CHARTER        float64
# pct_enrolled_450LEA_HI7_CHARTER        float64
# pct_enrolled_450LEA_MU7_CHARTER        float64
# pct_enrolled_450LEA_PI7_CHARTER        float64
# pct_enrolled_450LEA_SWD_CHARTER        float64
# pct_enrolled_450LEA_WH7_CHARTER        float64
# pct_enrolled_490LEA_AM7_CHARTER        float64
# pct_enrolled_490LEA_AS7_CHARTER        float64
# pct_enrolled_490LEA_BL7_CHARTER        float64
# pct_enrolled_490LEA_EDS_CHARTER        float64
# pct_enrolled_490LEA_ELS_CHARTER        float64
# pct_enrolled_490LEA_HI7_CHARTER        float64
# pct_enrolled_490LEA_MU7_CHARTER        float64
# pct_enrolled_490LEA_PI7_CHARTER        float64
# pct_enrolled_490LEA_SWD_CHARTER        float64
# pct_enrolled_490LEA_WH7_CHARTER        float64
# pct_enrolled_500LEA_AM7_CHARTER        float64
# pct_enrolled_500LEA_AS7_CHARTER        float64
# pct_enrolled_500LEA_BL7_CHARTER        float64
# pct_enrolled_500LEA_EDS_CHARTER        float64
# pct_enrolled_500LEA_ELS_CHARTER        float64
# pct_enrolled_500LEA_HI7_CHARTER        float64
# pct_enrolled_500LEA_MU7_CHARTER        float64
# pct_enrolled_500LEA_PI7_CHARTER        float64
# pct_enrolled_500LEA_SWD_CHARTER        float64
# pct_enrolled_500LEA_WH7_CHARTER        float64
# pct_enrolled_510LEA_AM7_CHARTER        float64
# pct_enrolled_510LEA_AS7_CHARTER        float64
# pct_enrolled_510LEA_BL7_CHARTER        float64
# pct_enrolled_510LEA_EDS_CHARTER        float64
# pct_enrolled_510LEA_ELS_CHARTER        float64
# pct_enrolled_510LEA_HI7_CHARTER        float64
# pct_enrolled_510LEA_MU7_CHARTER        float64
# pct_enrolled_510LEA_PI7_CHARTER        float64
# pct_enrolled_510LEA_SWD_CHARTER        float64
# pct_enrolled_510LEA_WH7_CHARTER        float64
# pct_enrolled_530LEA_AM7_CHARTER        float64
# pct_enrolled_530LEA_AS7_CHARTER        float64
# pct_enrolled_530LEA_BL7_CHARTER        float64
# pct_enrolled_530LEA_EDS_CHARTER        float64
# pct_enrolled_530LEA_ELS_CHARTER        float64
# pct_enrolled_530LEA_HI7_CHARTER        float64
# pct_enrolled_530LEA_MU7_CHARTER        float64
# pct_enrolled_530LEA_PI7_CHARTER        float64
# pct_enrolled_530LEA_SWD_CHARTER        float64
# pct_enrolled_530LEA_WH7_CHARTER        float64
# pct_enrolled_540LEA_AM7_CHARTER        float64
# pct_enrolled_540LEA_AS7_CHARTER        float64
# pct_enrolled_540LEA_BL7_CHARTER        float64
# pct_enrolled_540LEA_EDS_CHARTER        float64
# pct_enrolled_540LEA_ELS_CHARTER        float64
# pct_enrolled_540LEA_HI7_CHARTER        float64
# pct_enrolled_540LEA_MU7_CHARTER        float64
# pct_enrolled_540LEA_PI7_CHARTER        float64
# pct_enrolled_540LEA_SWD_CHARTER        float64
# pct_enrolled_540LEA_WH7_CHARTER        float64
# pct_enrolled_550LEA_AM7_CHARTER        float64
# pct_enrolled_550LEA_AS7_CHARTER        float64
# pct_enrolled_550LEA_BL7_CHARTER        float64
# pct_enrolled_550LEA_EDS_CHARTER        float64
# pct_enrolled_550LEA_ELS_CHARTER        float64
# pct_enrolled_550LEA_HI7_CHARTER        float64
# pct_enrolled_550LEA_MU7_CHARTER        float64
# pct_enrolled_550LEA_PI7_CHARTER        float64
# pct_enrolled_550LEA_SWD_CHARTER        float64
# pct_enrolled_550LEA_WH7_CHARTER        float64
# pct_enrolled_580LEA_AM7_CHARTER        float64
# pct_enrolled_580LEA_AS7_CHARTER        float64
# pct_enrolled_580LEA_BL7_CHARTER        float64
# pct_enrolled_580LEA_EDS_CHARTER        float64
# pct_enrolled_580LEA_ELS_CHARTER        float64
# pct_enrolled_580LEA_HI7_CHARTER        float64
# pct_enrolled_580LEA_MU7_CHARTER        float64
# pct_enrolled_580LEA_PI7_CHARTER        float64
# pct_enrolled_580LEA_SWD_CHARTER        float64
# pct_enrolled_580LEA_WH7_CHARTER        float64
# pct_enrolled_600LEA_AM7_CHARTER        float64
# pct_enrolled_600LEA_AS7_CHARTER        float64
# pct_enrolled_600LEA_BL7_CHARTER        float64
# pct_enrolled_600LEA_EDS_CHARTER        float64
# pct_enrolled_600LEA_ELS_CHARTER        float64
# pct_enrolled_600LEA_HI7_CHARTER        float64
# pct_enrolled_600LEA_MU7_CHARTER        float64
# pct_enrolled_600LEA_PI7_CHARTER        float64
# pct_enrolled_600LEA_SWD_CHARTER        float64
# pct_enrolled_600LEA_WH7_CHARTER        float64
# pct_enrolled_620LEA_AM7_CHARTER        float64
# pct_enrolled_620LEA_AS7_CHARTER        float64
# pct_enrolled_620LEA_BL7_CHARTER        float64
# pct_enrolled_620LEA_EDS_CHARTER        float64
# pct_enrolled_620LEA_ELS_CHARTER        float64
# pct_enrolled_620LEA_HI7_CHARTER        float64
# pct_enrolled_620LEA_MU7_CHARTER        float64
# pct_enrolled_620LEA_PI7_CHARTER        float64
# pct_enrolled_620LEA_SWD_CHARTER        float64
# pct_enrolled_620LEA_WH7_CHARTER        float64
# pct_enrolled_630LEA_AM7_CHARTER        float64
# pct_enrolled_630LEA_AS7_CHARTER        float64
# pct_enrolled_630LEA_BL7_CHARTER        float64
# pct_enrolled_630LEA_EDS_CHARTER        float64
# pct_enrolled_630LEA_ELS_CHARTER        float64
# pct_enrolled_630LEA_HI7_CHARTER        float64
# pct_enrolled_630LEA_MU7_CHARTER        float64
# pct_enrolled_630LEA_PI7_CHARTER        float64
# pct_enrolled_630LEA_SWD_CHARTER        float64
# pct_enrolled_630LEA_WH7_CHARTER        float64
# pct_enrolled_640LEA_AM7_CHARTER        float64
# pct_enrolled_640LEA_AS7_CHARTER        float64
# pct_enrolled_640LEA_BL7_CHARTER        float64
# pct_enrolled_640LEA_EDS_CHARTER        float64
# pct_enrolled_640LEA_ELS_CHARTER        float64
# pct_enrolled_640LEA_HI7_CHARTER        float64
# pct_enrolled_640LEA_MU7_CHARTER        float64
# pct_enrolled_640LEA_PI7_CHARTER        float64
# pct_enrolled_640LEA_SWD_CHARTER        float64
# pct_enrolled_640LEA_WH7_CHARTER        float64
# pct_enrolled_650LEA_AM7_CHARTER        float64
# pct_enrolled_650LEA_AS7_CHARTER        float64
# pct_enrolled_650LEA_BL7_CHARTER        float64
# pct_enrolled_650LEA_EDS_CHARTER        float64
# pct_enrolled_650LEA_ELS_CHARTER        float64
# pct_enrolled_650LEA_HI7_CHARTER        float64
# pct_enrolled_650LEA_MU7_CHARTER        float64
# pct_enrolled_650LEA_PI7_CHARTER        float64
# pct_enrolled_650LEA_SWD_CHARTER        float64
# pct_enrolled_650LEA_WH7_CHARTER        float64
# pct_enrolled_660LEA_AM7_CHARTER        float64
# pct_enrolled_660LEA_AS7_CHARTER        float64
# pct_enrolled_660LEA_BL7_CHARTER        float64
# pct_enrolled_660LEA_EDS_CHARTER        float64
# pct_enrolled_660LEA_ELS_CHARTER        float64
# pct_enrolled_660LEA_HI7_CHARTER        float64
# pct_enrolled_660LEA_MU7_CHARTER        float64
# pct_enrolled_660LEA_PI7_CHARTER        float64
# pct_enrolled_660LEA_SWD_CHARTER        float64
# pct_enrolled_660LEA_WH7_CHARTER        float64
# pct_enrolled_670LEA_AM7_CHARTER        float64
# pct_enrolled_670LEA_AS7_CHARTER        float64
# pct_enrolled_670LEA_BL7_CHARTER        float64
# pct_enrolled_670LEA_EDS_CHARTER        float64
# pct_enrolled_670LEA_ELS_CHARTER        float64
# pct_enrolled_670LEA_HI7_CHARTER        float64
# pct_enrolled_670LEA_MU7_CHARTER        float64
# pct_enrolled_670LEA_PI7_CHARTER        float64
# pct_enrolled_670LEA_SWD_CHARTER        float64
# pct_enrolled_670LEA_WH7_CHARTER        float64
# ...
# pct_enrolled_862LEA_PI7_CHARTER        float64
# pct_enrolled_862LEA_SWD_CHARTER        float64
# pct_enrolled_862LEA_WH7_CHARTER        float64
# pct_enrolled_870LEA_AM7_CHARTER        float64
# pct_enrolled_870LEA_AS7_CHARTER        float64
# pct_enrolled_870LEA_BL7_CHARTER        float64
# pct_enrolled_870LEA_EDS_CHARTER        float64
# pct_enrolled_870LEA_ELS_CHARTER        float64
# pct_enrolled_870LEA_HI7_CHARTER        float64
# pct_enrolled_870LEA_MU7_CHARTER        float64
# pct_enrolled_870LEA_PI7_CHARTER        float64
# pct_enrolled_870LEA_SWD_CHARTER        float64
# pct_enrolled_870LEA_WH7_CHARTER        float64
# pct_enrolled_880LEA_AM7_CHARTER        float64
# pct_enrolled_880LEA_AS7_CHARTER        float64
# pct_enrolled_880LEA_BL7_CHARTER        float64
# pct_enrolled_880LEA_EDS_CHARTER        float64
# pct_enrolled_880LEA_ELS_CHARTER        float64
# pct_enrolled_880LEA_HI7_CHARTER        float64
# pct_enrolled_880LEA_MU7_CHARTER        float64
# pct_enrolled_880LEA_PI7_CHARTER        float64
# pct_enrolled_880LEA_SWD_CHARTER        float64
# pct_enrolled_880LEA_WH7_CHARTER        float64
# pct_enrolled_900LEA_AM7_CHARTER        float64
# pct_enrolled_900LEA_AS7_CHARTER        float64
# pct_enrolled_900LEA_BL7_CHARTER        float64
# pct_enrolled_900LEA_EDS_CHARTER        float64
# pct_enrolled_900LEA_ELS_CHARTER        float64
# pct_enrolled_900LEA_HI7_CHARTER        float64
# pct_enrolled_900LEA_MU7_CHARTER        float64
# pct_enrolled_900LEA_PI7_CHARTER        float64
# pct_enrolled_900LEA_SWD_CHARTER        float64
# pct_enrolled_900LEA_WH7_CHARTER        float64
# pct_enrolled_910LEA_AM7_CHARTER        float64
# pct_enrolled_910LEA_AS7_CHARTER        float64
# pct_enrolled_910LEA_BL7_CHARTER        float64
# pct_enrolled_910LEA_EDS_CHARTER        float64
# pct_enrolled_910LEA_ELS_CHARTER        float64
# pct_enrolled_910LEA_HI7_CHARTER        float64
# pct_enrolled_910LEA_MU7_CHARTER        float64
# pct_enrolled_910LEA_PI7_CHARTER        float64
# pct_enrolled_910LEA_SWD_CHARTER        float64
# pct_enrolled_910LEA_WH7_CHARTER        float64
# pct_enrolled_920LEA_AM7_CHARTER        float64
# pct_enrolled_920LEA_AS7_CHARTER        float64
# pct_enrolled_920LEA_BL7_CHARTER        float64
# pct_enrolled_920LEA_EDS_CHARTER        float64
# pct_enrolled_920LEA_ELS_CHARTER        float64
# pct_enrolled_920LEA_HI7_CHARTER        float64
# pct_enrolled_920LEA_MU7_CHARTER        float64
# pct_enrolled_920LEA_PI7_CHARTER        float64
# pct_enrolled_920LEA_SWD_CHARTER        float64
# pct_enrolled_920LEA_WH7_CHARTER        float64
# pct_enrolled_930LEA_AM7_CHARTER        float64
# pct_enrolled_930LEA_AS7_CHARTER        float64
# pct_enrolled_930LEA_BL7_CHARTER        float64
# pct_enrolled_930LEA_EDS_CHARTER        float64
# pct_enrolled_930LEA_ELS_CHARTER        float64
# pct_enrolled_930LEA_HI7_CHARTER        float64
# pct_enrolled_930LEA_MU7_CHARTER        float64
# pct_enrolled_930LEA_PI7_CHARTER        float64
# pct_enrolled_930LEA_SWD_CHARTER        float64
# pct_enrolled_930LEA_WH7_CHARTER        float64
# pct_enrolled_940LEA_AM7_CHARTER        float64
# pct_enrolled_940LEA_AS7_CHARTER        float64
# pct_enrolled_940LEA_BL7_CHARTER        float64
# pct_enrolled_940LEA_EDS_CHARTER        float64
# pct_enrolled_940LEA_ELS_CHARTER        float64
# pct_enrolled_940LEA_HI7_CHARTER        float64
# pct_enrolled_940LEA_MU7_CHARTER        float64
# pct_enrolled_940LEA_PI7_CHARTER        float64
# pct_enrolled_940LEA_SWD_CHARTER        float64
# pct_enrolled_940LEA_WH7_CHARTER        float64
# pct_enrolled_950LEA_AM7_CHARTER        float64
# pct_enrolled_950LEA_AS7_CHARTER        float64
# pct_enrolled_950LEA_BL7_CHARTER        float64
# pct_enrolled_950LEA_EDS_CHARTER        float64
# pct_enrolled_950LEA_ELS_CHARTER        float64
# pct_enrolled_950LEA_HI7_CHARTER        float64
# pct_enrolled_950LEA_MU7_CHARTER        float64
# pct_enrolled_950LEA_PI7_CHARTER        float64
# pct_enrolled_950LEA_SWD_CHARTER        float64
# pct_enrolled_950LEA_WH7_CHARTER        float64
# pct_enrolled_960LEA_AM7_CHARTER        float64
# pct_enrolled_960LEA_AS7_CHARTER        float64
# pct_enrolled_960LEA_BL7_CHARTER        float64
# pct_enrolled_960LEA_EDS_CHARTER        float64
# pct_enrolled_960LEA_ELS_CHARTER        float64
# pct_enrolled_960LEA_HI7_CHARTER        float64
# pct_enrolled_960LEA_MU7_CHARTER        float64
# pct_enrolled_960LEA_PI7_CHARTER        float64
# pct_enrolled_960LEA_SWD_CHARTER        float64
# pct_enrolled_960LEA_WH7_CHARTER        float64
# pct_enrolled_970LEA_AM7_CHARTER        float64
# pct_enrolled_970LEA_AS7_CHARTER        float64
# pct_enrolled_970LEA_BL7_CHARTER        float64
# pct_enrolled_970LEA_EDS_CHARTER        float64
# pct_enrolled_970LEA_ELS_CHARTER        float64
# pct_enrolled_970LEA_HI7_CHARTER        float64
# pct_enrolled_970LEA_MU7_CHARTER        float64
# pct_enrolled_970LEA_PI7_CHARTER        float64
# pct_enrolled_970LEA_SWD_CHARTER        float64
# pct_enrolled_970LEA_WH7_CHARTER        float64
# pct_enrolled_980LEA_AM7_CHARTER        float64
# pct_enrolled_980LEA_AS7_CHARTER        float64
# pct_enrolled_980LEA_BL7_CHARTER        float64
# pct_enrolled_980LEA_EDS_CHARTER        float64
# pct_enrolled_980LEA_ELS_CHARTER        float64
# pct_enrolled_980LEA_HI7_CHARTER        float64
# pct_enrolled_980LEA_MU7_CHARTER        float64
# pct_enrolled_980LEA_PI7_CHARTER        float64
# pct_enrolled_980LEA_SWD_CHARTER        float64
# pct_enrolled_980LEA_WH7_CHARTER        float64
# pct_enrolled_NC-SEA_AM7_CHARTER        float64
# pct_enrolled_NC-SEA_AS7_CHARTER        float64
# pct_enrolled_NC-SEA_BL7_CHARTER        float64
# pct_enrolled_NC-SEA_EDS_CHARTER        float64
# pct_enrolled_NC-SEA_ELS_CHARTER        float64
# pct_enrolled_NC-SEA_HI7_CHARTER        float64
# pct_enrolled_NC-SEA_MU7_CHARTER        float64
# pct_enrolled_NC-SEA_PI7_CHARTER        float64
# pct_enrolled_NC-SEA_SWD_CHARTER        float64
# pct_enrolled_NC-SEA_WH7_CHARTER        float64
# pct_ap_A_AS7_COURSES2                  float64
# pct_ap_A_BL7_COURSES2                  float64
# pct_ap_A_FEM_COURSES2                  float64
# pct_ap_A_HI7_COURSES2                  float64
# pct_ap_A_MALE_COURSES2                 float64
# pct_ap_A_MU7_COURSES2                  float64
# pct_ap_A_SWD_COURSES2                  float64
# pct_ap_A_WH7_COURSES2                  float64
# pct_ap_H_AM7_COURSES2                  float64
# pct_ap_H_AS7_COURSES2                  float64
# pct_ap_H_BL7_COURSES2                  float64
# pct_ap_H_ELS_COURSES2                  float64
# pct_ap_H_FEM_COURSES2                  float64
# pct_ap_H_HI7_COURSES2                  float64
# pct_ap_H_MALE_COURSES2                 float64
# pct_ap_H_MU7_COURSES2                  float64
# pct_ap_H_SWD_COURSES2                  float64
# pct_ap_H_WH7_COURSES2                  float64
# pct_ap_T_AS7_COURSES2                  float64
# pct_ap_T_BL7_COURSES2                  float64
# pct_ap_T_FEM_COURSES2                  float64
# pct_ap_T_HI7_COURSES2                  float64
# pct_ap_T_MALE_COURSES2                 float64
# pct_ap_T_MU7_COURSES2                  float64
# pct_ap_T_WH7_COURSES2                  float64
# pct_ccp_A_AM7_COURSES2                 float64
# pct_ccp_A_AS7_COURSES2                 float64
# pct_ccp_A_BL7_COURSES2                 float64
# pct_ccp_A_ELS_COURSES2                 float64
# pct_ccp_A_FEM_COURSES2                 float64
# pct_ccp_A_HI7_COURSES2                 float64
# pct_ccp_A_MALE_COURSES2                float64
# pct_ccp_A_MU7_COURSES2                 float64
# pct_ccp_A_SWD_COURSES2                 float64
# pct_ccp_A_WH7_COURSES2                 float64
# pct_ccp_H_AM7_COURSES2                 float64
# pct_ccp_H_AS7_COURSES2                 float64
# pct_ccp_H_BL7_COURSES2                 float64
# pct_ccp_H_ELS_COURSES2                 float64
# pct_ccp_H_FEM_COURSES2                 float64
# pct_ccp_H_HI7_COURSES2                 float64
# pct_ccp_H_MALE_COURSES2                float64
# pct_ccp_H_MU7_COURSES2                 float64
# pct_ccp_H_SWD_COURSES2                 float64
# pct_ccp_H_WH7_COURSES2                 float64
# pct_ccp_T_BL7_COURSES2                 float64
# pct_ccp_T_ELS_COURSES2                 float64
# pct_ccp_T_FEM_COURSES2                 float64
# pct_ccp_T_HI7_COURSES2                 float64
# pct_ccp_T_MALE_COURSES2                float64
# pct_ccp_T_MU7_COURSES2                 float64
# pct_ccp_T_SWD_COURSES2                 float64
# pct_ccp_T_WH7_COURSES2                 float64
# pct_ib_H_AS7_COURSES2                  float64
# pct_ib_H_BL7_COURSES2                  float64
# pct_ib_H_FEM_COURSES2                  float64
# pct_ib_H_HI7_COURSES2                  float64
# pct_ib_H_MALE_COURSES2                 float64
# pct_ib_H_MU7_COURSES2                  float64
# pct_ib_H_WH7_COURSES2                  float64
# num_concentrators_AAVC                 float64
# num_concentrators_AGNR                 float64
# num_concentrators_ARCH                 float64
# num_concentrators_BMA                  float64
# num_concentrators_EDUC                 float64
# num_concentrators_FINA                 float64
# num_concentrators_HLTH                 float64
# num_concentrators_HOSP                 float64
# num_concentrators_HUMA                 float64
# num_concentrators_INFO                 float64
# num_concentrators_LAW                  float64
# num_concentrators_MANU                 float64
# num_concentrators_MRKT                 float64
# num_concentrators_STEM                 float64
# num_concentrators_TRAN                 float64
# num_credentials                        float64
# num_enrollments                        float64
# cred_earned_pct                        float64
# career_only                            float64
# career_college_college_unc             float64
# college_college_unc_only               float64
# college_only                           float64
# stu_enroll                             float64
# cte_enroll                             float64
# cte_enrollment_pct                     float64
# digital_media                          object
# device_access                          object
# device_access_grades                   object
# device_home                            object
# device_home_grades                     object
# BYOD                                   object
# byod_grades                            object
# Book_TitlesPer_Student                 object
# wap                                    object
# wap_class                              float64
# media_school                           float64
# devices                                object
# pct_ib_pass                            float64
# pct_ib_participation                   float64
# crime                                  float64
# short_term                             float64
# long_term                              float64
# expulsion                              float64
# act_per1000_ALL                        float64
# act_per1000_AM7                        float64
# act_per1000_AS7                        float64
# act_per1000_BL7                        float64
# act_per1000_EDS                        float64
# act_per1000_ELS                        float64
# act_per1000_FEM                        float64
# act_per1000_HI7                        float64
# act_per1000_MALE                       float64
# act_per1000_MU7                        float64
# act_per1000_PI7                        float64
# act_per1000_SWD                        float64
# act_per1000_WH7                        float64
# arr_per1000_ALL                        float64
# arr_per1000_AM7                        float64
# arr_per1000_AS7                        float64
# arr_per1000_BL7                        float64
# arr_per1000_EDS                        float64
# arr_per1000_ELS                        float64
# arr_per1000_FEM                        float64
# arr_per1000_HI7                        float64
# arr_per1000_MALE                       float64
# arr_per1000_MU7                        float64
# arr_per1000_PI7                        float64
# arr_per1000_SWD                        float64
# arr_per1000_WH7                        float64
# bha_per1000_ALL                        float64
# bha_per1000_AM7                        float64
# bha_per1000_AS7                        float64
# bha_per1000_BL7                        float64
# bha_per1000_EDS                        float64
# bha_per1000_ELS                        float64
# bha_per1000_FEM                        float64
# bha_per1000_HI7                        float64
# bha_per1000_MALE                       float64
# bha_per1000_MU7                        float64
# bha_per1000_PI7                        float64
# bha_per1000_SWD                        float64
# bha_per1000_WH7                        float64
# exp_per1000_ALL                        float64
# exp_per1000_AM7                        float64
# exp_per1000_AS7                        float64
# exp_per1000_BL7                        float64
# exp_per1000_EDS                        float64
# exp_per1000_ELS                        float64
# exp_per1000_FEM                        float64
# exp_per1000_HI7                        float64
# exp_per1000_MALE                       float64
# exp_per1000_MU7                        float64
# exp_per1000_PI7                        float64
# exp_per1000_SWD                        float64
# exp_per1000_WH7                        float64
# iss_per1000_ALL                        float64
# iss_per1000_AM7                        float64
# iss_per1000_AS7                        float64
# iss_per1000_BL7                        float64
# iss_per1000_EDS                        float64
# iss_per1000_ELS                        float64
# iss_per1000_FEM                        float64
# iss_per1000_HI7                        float64
# iss_per1000_MALE                       float64
# iss_per1000_MU7                        float64
# iss_per1000_PI7                        float64
# iss_per1000_SWD                        float64
# iss_per1000_WH7                        float64
# lts_per1000_ALL                        float64
# lts_per1000_AM7                        float64
# lts_per1000_AS7                        float64
# lts_per1000_BL7                        float64
# lts_per1000_EDS                        float64
# lts_per1000_ELS                        float64
# lts_per1000_FEM                        float64
# lts_per1000_HI7                        float64
# lts_per1000_MALE                       float64
# lts_per1000_MU7                        float64
# lts_per1000_PI7                        float64
# lts_per1000_SWD                        float64
# lts_per1000_WH7                        float64
# rpt_per1000_ALL                        float64
# rpt_per1000_AM7                        float64
# rpt_per1000_AS7                        float64
# rpt_per1000_BL7                        float64
# rpt_per1000_EDS                        float64
# rpt_per1000_ELS                        float64
# rpt_per1000_FEM                        float64
# rpt_per1000_HI7                        float64
# rpt_per1000_MALE                       float64
# rpt_per1000_MU7                        float64
# rpt_per1000_PI7                        float64
# rpt_per1000_SWD                        float64
# rpt_per1000_WH7                        float64
# sts_per1000_ALL                        float64
# sts_per1000_AM7                        float64
# sts_per1000_AS7                        float64
# sts_per1000_BL7                        float64
# sts_per1000_EDS                        float64
# sts_per1000_ELS                        float64
# sts_per1000_FEM                        float64
# sts_per1000_HI7                        float64
# sts_per1000_MALE                       float64
# sts_per1000_MU7                        float64
# sts_per1000_PI7                        float64
# sts_per1000_SWD                        float64
# sts_per1000_WH7                        float64
# pct_prin_demo_BL7                      float64
# pct_prin_demo_FEM                      float64
# pct_prin_demo_MALE                     float64
# pct_prin_demo_OTHER                    float64
# pct_prin_demo_WH7                      float64
# pct_ready_kea                          float64
# avg_sat_score                          float64
# pct_sat_participation                  float64
# welcome_url                            object
# dtypes: float64(1434), object(51)
# memory usage: 30.7+ MB
