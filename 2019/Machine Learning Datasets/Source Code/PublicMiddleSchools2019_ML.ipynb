# %% [markdown]
# # Create Public School Machine Learning Datasets
# ** This program creates all the _ML datasets in the NCEA repository.**
# * This notebook reads each School Dataset file located at \EducationDataNC\ *schoolYear* \School Datasets\ as input data.
# * Different school years are processed by changing the *schoolYear* parameter.
# * Different input / output files are processed / created by changing the *inputFileName* paramter in the cell below.
# * While a single program is used to create all the _ML datasets, one program copy per dataset is maintained in the repositiory so the dataset specific tranformation reports may be reviewed.
#
# **Datasets ending in ML are preprocessed for Machine Learning and go through the following transformations: **
# 1. Missing student body racial compositions are imputed using district averages.
# 2. Columns that have the same value in every single row are deleted.
# 3. Columns that have a unique value in every single row (all values are different) are deleted.
# 4. Empty columns (all values are NA or NULL) are deleted.
# 5. Numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# 6. Remaining numeric, non-race columns with missing values are imputed / populated with 0.  In many cases, schools are not reporting values when they are zero. However, mean imputation or some other more sophisticated strategy might be considered here.
# 7. Categorical / text based columns with > *uniqueThreshold* unique values are deleted.
# 8. All remaining categorical / text based columns are one-hot encoded.  In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# 9. Duplicated or highly similar columns with > 95% correlation are delelted.

# %%
#import required Libraries
import pandas as pd
import numpy as np
import os
import string

#**********************************************************************************
# Set the following variables before running this code!!!
#**********************************************************************************
#All raw data files are processed for the year below
schoolYear = 2019

#Location where copies of the raw data files will be read in from csv files.
dataDir = 'D:/BenepactLLC/Belk/NC_Report_Card_Data/2020/May 2020/' + str(schoolYear) + '/School Datasets/'

#Name of the file to be processed
#inputFileName = 'PublicSchools2019'
#inputFileName = 'PublicHighSchools2019'
inputFileName = 'PublicMiddleSchools2019'
#inputFileName = 'PublicElementarySchools2019'

#Input file being transformed for machine learning 
inputFile = dataDir + inputFileName + '.csv'

#Location where the new school datasets will be created.
outputDir = 'D:/BenepactLLC/Belk/NC_Report_Card_Data/2020/May 2020/' + str(schoolYear) + '/Machine Learning Datasets/'

#Missing Data Threshold (Per Column)
missingThreshold = 0.60

#Unique Value Threshold (Per Column)
#Delete Columns >  uniqueThreshold unique values prior to one-hot encoding. 
#(each unique value becomes a new column during one-hot encoding)
uniqueThreshold = 200

#Read in the School Data File
schoolData = pd.read_csv(inputFile, low_memory=False, dtype={'agency_code': object})
print('*********Start: Beginning Column and Row Counts********************************************')
schoolData.info(verbose=False)

#Select only public schools as charter schools are missing data for many columns.
schoolData = schoolData[(schoolData['designation_type_loc'] == 'P')] #& (schoolData['avg_student_num'] > 0)] -rcd_admin missing

print('\r\n*********After: Selecting Only Public School Campuses**********************************')
schoolData.info(verbose=False)

#Save primary key
agency_code = schoolData['agency_code']
#Convert zip code to string
schoolData['zip_loc'] = schoolData['zip_loc'].astype('object')
# Out:
# *********Start: Beginning Column and Row Counts********************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 846 entries, 0 to 845
# Columns: 4649 entries, agency_code to welcome_url
# dtypes: float64(4611), object(38)
# memory usage: 30.0+ MB
#
# *********After: Selecting Only Public School Campuses**********************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 691 entries, 2 to 845
# Columns: 4649 entries, agency_code to welcome_url
# dtypes: float64(4611), object(38)
# memory usage: 24.5+ MB

# %%
schoolData.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 691 entries, 2 to 845
# Data columns (total 4649 columns):
#  #    Column                                         Dtype
# ---   ------                                         -----
#  0    agency_code                                    object
#  1    category_code_loc                              object
#  2    agency_level_loc                               object
#  3    lea_code_loc                                   object
#  4    designation_type_loc                           object
#  5    name_loc                                       object
#  6    county_loc                                     object
#  7    street_addr_loc                                object
#  8    stree_addr2_loc                                object
#  9    city_loc                                       object
#  10   state_loc                                      object
#  11   zip_loc                                        object
#  12   phone_loc                                      object
#  13   grade_span_loc                                 object
#  14   school_type_loc                                object
#  15   calendar_type_loc                              object
#  16   url_loc                                        object
#  17   super_name_loc                                 object
#  18   title_i_loc                                    object
#  19   esea_loc                                       float64
#  20   stem_loc                                       object
#  21   purple_star_loc                                object
#  22   lea                                            float64
#  23   lea_name                                       object
#  24   school                                         float64
#  25   school_name                                    object
#  26   indian_pct                                     float64
#  27   asian_pct                                      float64
#  28   hispanic_pct                                   float64
#  29   black_pct                                      float64
#  30   white_pct                                      float64
#  31   pacific_island_pct                             float64
#  32   two_or_more_pct                                float64
#  33   minority_pct                                   float64
#  34   indian_male_pct                                float64
#  35   asian_male_pct                                 float64
#  36   hispanic_male_pct                              float64
#  37   black_male_pct                                 float64
#  38   white_male_pct                                 float64
#  39   pacific_island_male_pct                        float64
#  40   two_or_more_male_pct                           float64
#  41   minority_male_pct                              float64
#  42   indian_female_pct                              float64
#  43   asian_female_pct                               float64
#  44   hispanic_female_pct                            float64
#  45   black_female_pct                               float64
#  46   white_female_pct                               float64
#  47   minority_female_pct                            float64
#  48   pacific_island_female_pct                      float64
#  49   two_or_more_female_pct                         float64
#  50   pct_ma_03_aapart                               float64
#  51   pct_ma_04_aapart                               float64
#  52   pct_ma_05_aapart                               float64
#  53   pct_ma_06_aapart                               float64
#  54   pct_ma_07_aapart                               float64
#  55   pct_ma_08_aapart                               float64
#  56   pct_ma_gs_aapart                               float64
#  57   pct_ma_hs_aapart                               float64
#  58   pct_rd_03_aapart                               float64
#  59   pct_rd_04_aapart                               float64
#  60   pct_rd_05_aapart                               float64
#  61   pct_rd_06_aapart                               float64
#  62   pct_rd_07_aapart                               float64
#  63   pct_rd_08_aapart                               float64
#  64   pct_rd_gs_aapart                               float64
#  65   pct_rd_hs_aapart                               float64
#  66   pct_sc_05_aapart                               float64
#  67   pct_sc_08_aapart                               float64
#  68   pct_sc_gs_aapart                               float64
#  69   pct_sc_hs_aapart                               float64
#  70   pct_acall_aig_act                              float64
#  71   pct_acall_all_act                              float64
#  72   pct_acall_am7_act                              float64
#  73   pct_acall_as7_act                              float64
#  74   pct_acall_bl7_act                              float64
#  75   pct_acall_eds_act                              float64
#  76   pct_acall_els_act                              float64
#  77   pct_acall_fcs_act                              float64
#  78   pct_acall_fem_act                              float64
#  79   pct_acall_hi7_act                              float64
#  80   pct_acall_hms_act                              float64
#  81   pct_acall_male_act                             float64
#  82   pct_acall_mig_act                              float64
#  83   pct_acall_mil_act                              float64
#  84   pct_acall_mu7_act                              float64
#  85   pct_acall_neds_act                             float64
#  86   pct_acall_nswd_act                             float64
#  87   pct_acall_swd_act                              float64
#  88   pct_acall_wh7_act                              float64
#  89   pct_acco_aig_act                               float64
#  90   pct_acco_all_act                               float64
#  91   pct_acco_am7_act                               float64
#  92   pct_acco_as7_act                               float64
#  93   pct_acco_bl7_act                               float64
#  94   pct_acco_eds_act                               float64
#  95   pct_acco_els_act                               float64
#  96   pct_acco_fem_act                               float64
#  97   pct_acco_hi7_act                               float64
#  98   pct_acco_hms_act                               float64
#  99   pct_acco_male_act                              float64
#  100  pct_acco_mil_act                               float64
#  101  pct_acco_mu7_act                               float64
#  102  pct_acco_neds_act                              float64
#  103  pct_acco_nswd_act                              float64
#  104  pct_acco_swd_act                               float64
#  105  pct_acco_wh7_act                               float64
#  106  pct_acen_aig_act                               float64
#  107  pct_acen_all_act                               float64
#  108  pct_acen_am7_act                               float64
#  109  pct_acen_as7_act                               float64
#  110  pct_acen_bl7_act                               float64
#  111  pct_acen_eds_act                               float64
#  112  pct_acen_els_act                               float64
#  113  pct_acen_fem_act                               float64
#  114  pct_acen_hi7_act                               float64
#  115  pct_acen_hms_act                               float64
#  116  pct_acen_male_act                              float64
#  117  pct_acen_mil_act                               float64
#  118  pct_acen_mu7_act                               float64
#  119  pct_acen_neds_act                              float64
#  120  pct_acen_nswd_act                              float64
#  121  pct_acen_swd_act                               float64
#  122  pct_acen_wh7_act                               float64
#  123  pct_acma_aig_act                               float64
#  124  pct_acma_all_act                               float64
#  125  pct_acma_am7_act                               float64
#  126  pct_acma_as7_act                               float64
#  127  pct_acma_bl7_act                               float64
#  128  pct_acma_eds_act                               float64
#  129  pct_acma_els_act                               float64
#  130  pct_acma_fem_act                               float64
#  131  pct_acma_hi7_act                               float64
#  132  pct_acma_hms_act                               float64
#  133  pct_acma_male_act                              float64
#  134  pct_acma_mil_act                               float64
#  135  pct_acma_mu7_act                               float64
#  136  pct_acma_neds_act                              float64
#  137  pct_acma_nswd_act                              float64
#  138  pct_acma_swd_act                               float64
#  139  pct_acma_wh7_act                               float64
#  140  pct_acrd_aig_act                               float64
#  141  pct_acrd_all_act                               float64
#  142  pct_acrd_am7_act                               float64
#  143  pct_acrd_as7_act                               float64
#  144  pct_acrd_bl7_act                               float64
#  145  pct_acrd_eds_act                               float64
#  146  pct_acrd_els_act                               float64
#  147  pct_acrd_fem_act                               float64
#  148  pct_acrd_hi7_act                               float64
#  149  pct_acrd_hms_act                               float64
#  150  pct_acrd_male_act                              float64
#  151  pct_acrd_mil_act                               float64
#  152  pct_acrd_mu7_act                               float64
#  153  pct_acrd_neds_act                              float64
#  154  pct_acrd_nswd_act                              float64
#  155  pct_acrd_swd_act                               float64
#  156  pct_acrd_wh7_act                               float64
#  157  pct_acsc_aig_act                               float64
#  158  pct_acsc_all_act                               float64
#  159  pct_acsc_am7_act                               float64
#  160  pct_acsc_as7_act                               float64
#  161  pct_acsc_bl7_act                               float64
#  162  pct_acsc_eds_act                               float64
#  163  pct_acsc_els_act                               float64
#  164  pct_acsc_fem_act                               float64
#  165  pct_acsc_hi7_act                               float64
#  166  pct_acsc_hms_act                               float64
#  167  pct_acsc_male_act                              float64
#  168  pct_acsc_mil_act                               float64
#  169  pct_acsc_mu7_act                               float64
#  170  pct_acsc_neds_act                              float64
#  171  pct_acsc_nswd_act                              float64
#  172  pct_acsc_swd_act                               float64
#  173  pct_acsc_wh7_act                               float64
#  174  pct_acwr_aig_act                               float64
#  175  pct_acwr_all_act                               float64
#  176  pct_acwr_am7_act                               float64
#  177  pct_acwr_as7_act                               float64
#  178  pct_acwr_bl7_act                               float64
#  179  pct_acwr_eds_act                               float64
#  180  pct_acwr_els_act                               float64
#  181  pct_acwr_fem_act                               float64
#  182  pct_acwr_hi7_act                               float64
#  183  pct_acwr_hms_act                               float64
#  184  pct_acwr_male_act                              float64
#  185  pct_acwr_mil_act                               float64
#  186  pct_acwr_mu7_act                               float64
#  187  pct_acwr_neds_act                              float64
#  188  pct_acwr_nswd_act                              float64
#  189  pct_acwr_swd_act                               float64
#  190  pct_acwr_wh7_act                               float64
#  191  pct_aig_awa                                    float64
#  192  pct_all_awa                                    float64
#  193  pct_am7_awa                                    float64
#  194  pct_as7_awa                                    float64
#  195  pct_bl7_awa                                    float64
#  196  pct_eds_awa                                    float64
#  197  pct_els_awa                                    float64
#  198  pct_fem_awa                                    float64
#  199  pct_hi7_awa                                    float64
#  200  pct_hms_awa                                    float64
#  201  pct_male_awa                                   float64
#  202  pct_mig_awa                                    float64
#  203  pct_mil_awa                                    float64
#  204  pct_mu7_awa                                    float64
#  205  pct_neds_awa                                   float64
#  206  pct_nswd_awa                                   float64
#  207  pct_swd_awa                                    float64
#  208  pct_wh7_awa                                    float64
#  209  pct_ext_aig_cgr                                float64
#  210  pct_ext_all_cgr                                float64
#  211  pct_ext_am7_cgr                                float64
#  212  pct_ext_as7_cgr                                float64
#  213  pct_ext_bl7_cgr                                float64
#  214  pct_ext_eds_cgr                                float64
#  215  pct_ext_els_cgr                                float64
#  216  pct_ext_fem_cgr                                float64
#  217  pct_ext_hi7_cgr                                float64
#  218  pct_ext_hms_cgr                                float64
#  219  pct_ext_male_cgr                               float64
#  220  pct_ext_mig_cgr                                float64
#  221  pct_ext_mu7_cgr                                float64
#  222  pct_ext_neds_cgr                               float64
#  223  pct_ext_nswd_cgr                               float64
#  224  pct_ext_swd_cgr                                float64
#  225  pct_ext_wh7_cgr                                float64
#  226  pct_std_aig_cgr                                float64
#  227  pct_std_all_cgr                                float64
#  228  pct_std_am7_cgr                                float64
#  229  pct_std_as7_cgr                                float64
#  230  pct_std_bl7_cgr                                float64
#  231  pct_std_eds_cgr                                float64
#  232  pct_std_els_cgr                                float64
#  233  pct_std_fcs_cgr                                float64
#  234  pct_std_fem_cgr                                float64
#  235  pct_std_hi7_cgr                                float64
#  236  pct_std_hms_cgr                                float64
#  237  pct_std_male_cgr                               float64
#  238  pct_std_mig_cgr                                float64
#  239  pct_std_mu7_cgr                                float64
#  240  pct_std_neds_cgr                               float64
#  241  pct_std_nswd_cgr                               float64
#  242  pct_std_swd_cgr                                float64
#  243  pct_std_wh7_cgr                                float64
#  244  pct_eds                                        float64
#  245  eg_index_all_aig_eg                            float64
#  246  eg_index_all_all_eg                            float64
#  247  eg_index_all_am7_eg                            float64
#  248  eg_index_all_as7_eg                            float64
#  249  eg_index_all_bl7_eg                            float64
#  250  eg_index_all_eds_eg                            float64
#  251  eg_index_all_els_eg                            float64
#  252  eg_index_all_hi7_eg                            float64
#  253  eg_index_all_mu7_eg                            float64
#  254  eg_index_all_swd_eg                            float64
#  255  eg_index_all_wh7_eg                            float64
#  256  eg_index_ma_all_eg                             float64
#  257  eg_index_rd_all_eg                             float64
#  258  eg_score_all_aig_eg                            float64
#  259  eg_score_all_all_eg                            float64
#  260  eg_score_all_am7_eg                            float64
#  261  eg_score_all_as7_eg                            float64
#  262  eg_score_all_bl7_eg                            float64
#  263  eg_score_all_eds_eg                            float64
#  264  eg_score_all_els_eg                            float64
#  265  eg_score_all_hi7_eg                            float64
#  266  eg_score_all_mu7_eg                            float64
#  267  eg_score_all_swd_eg                            float64
#  268  eg_score_all_wh7_eg                            float64
#  269  eg_score_ma_all_eg                             float64
#  270  eg_score_rd_all_eg                             float64
#  271  den_aig_elp                                    float64
#  272  den_all_elp                                    float64
#  273  den_as7_elp                                    float64
#  274  den_bl7_elp                                    float64
#  275  den_eds_elp                                    float64
#  276  den_els_elp                                    float64
#  277  den_fem_elp                                    float64
#  278  den_hi7_elp                                    float64
#  279  den_hms_elp                                    float64
#  280  den_male_elp                                   float64
#  281  den_mig_elp                                    float64
#  282  den_mil_elp                                    float64
#  283  den_neds_elp                                   float64
#  284  den_nswd_elp                                   float64
#  285  den_swd_elp                                    float64
#  286  den_wh7_elp                                    float64
#  287  pct_aig_elp                                    float64
#  288  pct_all_elp                                    float64
#  289  pct_as7_elp                                    float64
#  290  pct_bl7_elp                                    float64
#  291  pct_eds_elp                                    float64
#  292  pct_els_elp                                    float64
#  293  pct_fem_elp                                    float64
#  294  pct_hi7_elp                                    float64
#  295  pct_hms_elp                                    float64
#  296  pct_male_elp                                   float64
#  297  pct_mig_elp                                    float64
#  298  pct_mil_elp                                    float64
#  299  pct_neds_elp                                   float64
#  300  pct_nswd_elp                                   float64
#  301  pct_swd_elp                                    float64
#  302  pct_wh7_elp                                    float64
#  303  csi_lp_esea_desig                              object
#  304  csi_lg_esea_desig                              object
#  305  tsi_cu_esea_desig                              object
#  306  tsi_at_esea_desig                              object
#  307  grad_project_GP                                object
#  308  pct_prof_6gr_irm                               float64
#  309  pct_prof_9gr_irm                               float64
#  310  lp_school_lowperf                              object
#  311  rlp_school_lowperf                             object
#  312  clpc_school_lowperf                            object
#  313  pct_met_4_year_graduation_rate_ltg             float64
#  314  pct_met_el_progress_ltg                        float64
#  315  pct_met_math_grade_11_ltg                      float64
#  316  pct_met_math_grades_3-8_ltg                    float64
#  317  pct_met_reading_grade_10_ltg                   float64
#  318  pct_met_reading_grades_3-8_ltg                 float64
#  319  pct_met_total_targets_ltg                      float64
#  320  target_assign_4_year_graduation_rate_ltg       float64
#  321  target_assign_el_progress_ltg                  float64
#  322  target_assign_math_grade_11_ltg                float64
#  323  target_assign_math_grades_3-8_ltg              float64
#  324  target_assign_reading_grade_10_ltg             float64
#  325  target_assign_reading_grades_3-8_ltg           float64
#  326  target_assign_total_targets_ltg                float64
#  327  target_met_4_year_graduation_rate_ltg          float64
#  328  target_met_el_progress_ltg                     float64
#  329  target_met_math_grade_11_ltg                   float64
#  330  target_met_math_grades_3-8_ltg                 float64
#  331  target_met_reading_grade_10_ltg                float64
#  332  target_met_reading_grades_3-8_ltg              float64
#  333  target_met_total_targets_ltg                   float64
#  334  target_list_ltg_detail                         object
#  335  subgroup_list_ltg_detail                       object
#  336  pct_aig_mcr                                    float64
#  337  pct_all_mcr                                    float64
#  338  pct_am7_mcr                                    float64
#  339  pct_as7_mcr                                    float64
#  340  pct_bl7_mcr                                    float64
#  341  pct_eds_mcr                                    float64
#  342  pct_els_mcr                                    float64
#  343  pct_fem_mcr                                    float64
#  344  pct_hi7_mcr                                    float64
#  345  pct_hms_mcr                                    float64
#  346  pct_male_mcr                                   float64
#  347  pct_mig_mcr                                    float64
#  348  pct_mil_mcr                                    float64
#  349  pct_mu7_mcr                                    float64
#  350  pct_neds_mcr                                   float64
#  351  pct_nswd_mcr                                   float64
#  352  pct_swd_mcr                                    float64
#  353  pct_wh7_mcr                                    float64
#  354  pct_met_act_workkeys_part                      float64
#  355  pct_met_biology_part                           float64
#  356  pct_met_english_ii_part                        float64
#  357  pct_met_high_school_math_part                  float64
#  358  pct_met_math_grades_3-8_part                   float64
#  359  pct_met_reading_grades_3-8_part                float64
#  360  pct_met_science_grades_5&8_part                float64
#  361  pct_met_the_act_part                           float64
#  362  pct_met_total_targets_part                     float64
#  363  target_assign_act_workkeys_part                float64
#  364  target_assign_biology_part                     float64
#  365  target_assign_english_ii_part                  float64
#  366  target_assign_high_school_math_part            float64
#  367  target_assign_math_grades_3-8_part             float64
#  368  target_assign_reading_grades_3-8_part          float64
#  369  target_assign_science_grades_5&8_part          float64
#  370  target_assign_the_act_part                     float64
#  371  target_assign_total_targets_part               float64
#  372  target_met_act_workkeys_part                   float64
#  373  target_met_biology_part                        float64
#  374  target_met_english_ii_part                     float64
#  375  target_met_high_school_math_part               float64
#  376  target_met_math_grades_3-8_part                float64
#  377  target_met_reading_grades_3-8_part             float64
#  378  target_met_science_grades_5&8_part             float64
#  379  target_met_the_act_part                        float64
#  380  target_met_total_targets_part                  float64
#  381  pct_act_workkeys_all_part_det                  float64
#  382  pct_act_workkeys_am7_part_det                  float64
#  383  pct_act_workkeys_as7_part_det                  float64
#  384  pct_act_workkeys_bl7_part_det                  float64
#  385  pct_act_workkeys_eds_part_det                  float64
#  386  pct_act_workkeys_hi7_part_det                  float64
#  387  pct_act_workkeys_wh7_part_det                  float64
#  388  pct_biology_all_part_det                       float64
#  389  pct_biology_am7_part_det                       float64
#  390  pct_biology_as7_part_det                       float64
#  391  pct_biology_bl7_part_det                       float64
#  392  pct_biology_eds_part_det                       float64
#  393  pct_biology_els_part_det                       float64
#  394  pct_biology_hi7_part_det                       float64
#  395  pct_biology_mu7_part_det                       float64
#  396  pct_biology_swd_part_det                       float64
#  397  pct_biology_wh7_part_det                       float64
#  398  pct_english_ii_all_part_det                    float64
#  399  pct_english_ii_am7_part_det                    float64
#  400  pct_english_ii_as7_part_det                    float64
#  401  pct_english_ii_bl7_part_det                    float64
#  402  pct_english_ii_eds_part_det                    float64
#  403  pct_english_ii_els_part_det                    float64
#  404  pct_english_ii_hi7_part_det                    float64
#  405  pct_english_ii_mu7_part_det                    float64
#  406  pct_english_ii_swd_part_det                    float64
#  407  pct_english_ii_wh7_part_det                    float64
#  408  pct_high_school_math_all_part_det              float64
#  409  pct_high_school_math_am7_part_det              float64
#  410  pct_high_school_math_as7_part_det              float64
#  411  pct_high_school_math_bl7_part_det              float64
#  412  pct_high_school_math_eds_part_det              float64
#  413  pct_high_school_math_els_part_det              float64
#  414  pct_high_school_math_hi7_part_det              float64
#  415  pct_high_school_math_mu7_part_det              float64
#  416  pct_high_school_math_swd_part_det              float64
#  417  pct_high_school_math_wh7_part_det              float64
#  418  pct_math_grades_3-8_all_part_det               float64
#  419  pct_math_grades_3-8_am7_part_det               float64
#  420  pct_math_grades_3-8_as7_part_det               float64
#  421  pct_math_grades_3-8_bl7_part_det               float64
#  422  pct_math_grades_3-8_eds_part_det               float64
#  423  pct_math_grades_3-8_els_part_det               float64
#  424  pct_math_grades_3-8_hi7_part_det               float64
#  425  pct_math_grades_3-8_mu7_part_det               float64
#  426  pct_math_grades_3-8_swd_part_det               float64
#  427  pct_math_grades_3-8_wh7_part_det               float64
#  428  pct_reading_grades_3-8_all_part_det            float64
#  429  pct_reading_grades_3-8_am7_part_det            float64
#  430  pct_reading_grades_3-8_as7_part_det            float64
#  431  pct_reading_grades_3-8_bl7_part_det            float64
#  432  pct_reading_grades_3-8_eds_part_det            float64
#  433  pct_reading_grades_3-8_els_part_det            float64
#  434  pct_reading_grades_3-8_hi7_part_det            float64
#  435  pct_reading_grades_3-8_mu7_part_det            float64
#  436  pct_reading_grades_3-8_swd_part_det            float64
#  437  pct_reading_grades_3-8_wh7_part_det            float64
#  438  pct_science_grades_5&8_all_part_det            float64
#  439  pct_science_grades_5&8_am7_part_det            float64
#  440  pct_science_grades_5&8_as7_part_det            float64
#  441  pct_science_grades_5&8_bl7_part_det            float64
#  442  pct_science_grades_5&8_eds_part_det            float64
#  443  pct_science_grades_5&8_els_part_det            float64
#  444  pct_science_grades_5&8_hi7_part_det            float64
#  445  pct_science_grades_5&8_mu7_part_det            float64
#  446  pct_science_grades_5&8_swd_part_det            float64
#  447  pct_science_grades_5&8_wh7_part_det            float64
#  448  pct_the_act_all_part_det                       float64
#  449  pct_the_act_am7_part_det                       float64
#  450  pct_the_act_as7_part_det                       float64
#  451  pct_the_act_bl7_part_det                       float64
#  452  pct_the_act_eds_part_det                       float64
#  453  pct_the_act_els_part_det                       float64
#  454  pct_the_act_hi7_part_det                       float64
#  455  pct_the_act_mu7_part_det                       float64
#  456  pct_the_act_swd_part_det                       float64
#  457  pct_the_act_wh7_part_det                       float64
#  458  pct_ccr_bi_eoc_aig_pc                          float64
#  459  pct_ccr_bi_eoc_all_pc                          float64
#  460  pct_ccr_bi_eoc_am7_pc                          float64
#  461  pct_ccr_bi_eoc_as7_pc                          float64
#  462  pct_ccr_bi_eoc_bl7_pc                          float64
#  463  pct_ccr_bi_eoc_eds_pc                          float64
#  464  pct_ccr_bi_eoc_els_pc                          float64
#  465  pct_ccr_bi_eoc_fcs_pc                          float64
#  466  pct_ccr_bi_eoc_fem_pc                          float64
#  467  pct_ccr_bi_eoc_hi7_pc                          float64
#  468  pct_ccr_bi_eoc_hms_pc                          float64
#  469  pct_ccr_bi_eoc_male_pc                         float64
#  470  pct_ccr_bi_eoc_mig_pc                          float64
#  471  pct_ccr_bi_eoc_mil_pc                          float64
#  472  pct_ccr_bi_eoc_mu7_pc                          float64
#  473  pct_ccr_bi_eoc_neds_pc                         float64
#  474  pct_ccr_bi_eoc_nswd_pc                         float64
#  475  pct_ccr_bi_eoc_swd_pc                          float64
#  476  pct_ccr_bi_eoc_wh7_pc                          float64
#  477  pct_ccr_e2_eoc_aig_pc                          float64
#  478  pct_ccr_e2_eoc_all_pc                          float64
#  479  pct_ccr_e2_eoc_am7_pc                          float64
#  480  pct_ccr_e2_eoc_as7_pc                          float64
#  481  pct_ccr_e2_eoc_bl7_pc                          float64
#  482  pct_ccr_e2_eoc_eds_pc                          float64
#  483  pct_ccr_e2_eoc_els_pc                          float64
#  484  pct_ccr_e2_eoc_fem_pc                          float64
#  485  pct_ccr_e2_eoc_hi7_pc                          float64
#  486  pct_ccr_e2_eoc_hms_pc                          float64
#  487  pct_ccr_e2_eoc_male_pc                         float64
#  488  pct_ccr_e2_eoc_mig_pc                          float64
#  489  pct_ccr_e2_eoc_mil_pc                          float64
#  490  pct_ccr_e2_eoc_mu7_pc                          float64
#  491  pct_ccr_e2_eoc_neds_pc                         float64
#  492  pct_ccr_e2_eoc_nswd_pc                         float64
#  493  pct_ccr_e2_eoc_swd_pc                          float64
#  494  pct_ccr_e2_eoc_wh7_pc                          float64
#  495  pct_ccr_eoc_eoc_aig_pc                         float64
#  496  pct_ccr_eoc_eoc_all_pc                         float64
#  497  pct_ccr_eoc_eoc_am7_pc                         float64
#  498  pct_ccr_eoc_eoc_as7_pc                         float64
#  499  pct_ccr_eoc_eoc_bl7_pc                         float64
#  500  pct_ccr_eoc_eoc_eds_pc                         float64
#  501  pct_ccr_eoc_eoc_els_pc                         float64
#  502  pct_ccr_eoc_eoc_fcs_pc                         float64
#  503  pct_ccr_eoc_eoc_fem_pc                         float64
#  504  pct_ccr_eoc_eoc_hi7_pc                         float64
#  505  pct_ccr_eoc_eoc_hms_pc                         float64
#  506  pct_ccr_eoc_eoc_male_pc                        float64
#  507  pct_ccr_eoc_eoc_mig_pc                         float64
#  508  pct_ccr_eoc_eoc_mil_pc                         float64
#  509  pct_ccr_eoc_eoc_mu7_pc                         float64
#  510  pct_ccr_eoc_eoc_neds_pc                        float64
#  511  pct_ccr_eoc_eoc_nswd_pc                        float64
#  512  pct_ccr_eoc_eoc_swd_pc                         float64
#  513  pct_ccr_eoc_eoc_wh7_pc                         float64
#  514  pct_ccr_eog_03_aig_pc                          float64
#  515  pct_ccr_eog_03_all_pc                          float64
#  516  pct_ccr_eog_03_am7_pc                          float64
#  517  pct_ccr_eog_03_as7_pc                          float64
#  518  pct_ccr_eog_03_bl7_pc                          float64
#  519  pct_ccr_eog_03_eds_pc                          float64
#  520  pct_ccr_eog_03_els_pc                          float64
#  521  pct_ccr_eog_03_fcs_pc                          float64
#  522  pct_ccr_eog_03_fem_pc                          float64
#  523  pct_ccr_eog_03_hi7_pc                          float64
#  524  pct_ccr_eog_03_hms_pc                          float64
#  525  pct_ccr_eog_03_male_pc                         float64
#  526  pct_ccr_eog_03_mig_pc                          float64
#  527  pct_ccr_eog_03_mil_pc                          float64
#  528  pct_ccr_eog_03_mu7_pc                          float64
#  529  pct_ccr_eog_03_neds_pc                         float64
#  530  pct_ccr_eog_03_nswd_pc                         float64
#  531  pct_ccr_eog_03_swd_pc                          float64
#  532  pct_ccr_eog_03_wh7_pc                          float64
#  533  pct_ccr_eog_04_aig_pc                          float64
#  534  pct_ccr_eog_04_all_pc                          float64
#  535  pct_ccr_eog_04_am7_pc                          float64
#  536  pct_ccr_eog_04_as7_pc                          float64
#  537  pct_ccr_eog_04_bl7_pc                          float64
#  538  pct_ccr_eog_04_eds_pc                          float64
#  539  pct_ccr_eog_04_els_pc                          float64
#  540  pct_ccr_eog_04_fcs_pc                          float64
#  541  pct_ccr_eog_04_fem_pc                          float64
#  542  pct_ccr_eog_04_hi7_pc                          float64
#  543  pct_ccr_eog_04_hms_pc                          float64
#  544  pct_ccr_eog_04_male_pc                         float64
#  545  pct_ccr_eog_04_mig_pc                          float64
#  546  pct_ccr_eog_04_mil_pc                          float64
#  547  pct_ccr_eog_04_mu7_pc                          float64
#  548  pct_ccr_eog_04_neds_pc                         float64
#  549  pct_ccr_eog_04_nswd_pc                         float64
#  550  pct_ccr_eog_04_swd_pc                          float64
#  551  pct_ccr_eog_04_wh7_pc                          float64
#  552  pct_ccr_eog_05_aig_pc                          float64
#  553  pct_ccr_eog_05_all_pc                          float64
#  554  pct_ccr_eog_05_am7_pc                          float64
#  555  pct_ccr_eog_05_as7_pc                          float64
#  556  pct_ccr_eog_05_bl7_pc                          float64
#  557  pct_ccr_eog_05_eds_pc                          float64
#  558  pct_ccr_eog_05_els_pc                          float64
#  559  pct_ccr_eog_05_fcs_pc                          float64
#  560  pct_ccr_eog_05_fem_pc                          float64
#  561  pct_ccr_eog_05_hi7_pc                          float64
#  562  pct_ccr_eog_05_hms_pc                          float64
#  563  pct_ccr_eog_05_male_pc                         float64
#  564  pct_ccr_eog_05_mig_pc                          float64
#  565  pct_ccr_eog_05_mil_pc                          float64
#  566  pct_ccr_eog_05_mu7_pc                          float64
#  567  pct_ccr_eog_05_neds_pc                         float64
#  568  pct_ccr_eog_05_nswd_pc                         float64
#  569  pct_ccr_eog_05_swd_pc                          float64
#  570  pct_ccr_eog_05_wh7_pc                          float64
#  571  pct_ccr_eog_06_aig_pc                          float64
#  572  pct_ccr_eog_06_all_pc                          float64
#  573  pct_ccr_eog_06_am7_pc                          float64
#  574  pct_ccr_eog_06_as7_pc                          float64
#  575  pct_ccr_eog_06_bl7_pc                          float64
#  576  pct_ccr_eog_06_eds_pc                          float64
#  577  pct_ccr_eog_06_els_pc                          float64
#  578  pct_ccr_eog_06_fcs_pc                          float64
#  579  pct_ccr_eog_06_fem_pc                          float64
#  580  pct_ccr_eog_06_hi7_pc                          float64
#  581  pct_ccr_eog_06_hms_pc                          float64
#  582  pct_ccr_eog_06_male_pc                         float64
#  583  pct_ccr_eog_06_mig_pc                          float64
#  584  pct_ccr_eog_06_mil_pc                          float64
#  585  pct_ccr_eog_06_mu7_pc                          float64
#  586  pct_ccr_eog_06_neds_pc                         float64
#  587  pct_ccr_eog_06_nswd_pc                         float64
#  588  pct_ccr_eog_06_swd_pc                          float64
#  589  pct_ccr_eog_06_wh7_pc                          float64
#  590  pct_ccr_eog_07_aig_pc                          float64
#  591  pct_ccr_eog_07_all_pc                          float64
#  592  pct_ccr_eog_07_am7_pc                          float64
#  593  pct_ccr_eog_07_as7_pc                          float64
#  594  pct_ccr_eog_07_bl7_pc                          float64
#  595  pct_ccr_eog_07_eds_pc                          float64
#  596  pct_ccr_eog_07_els_pc                          float64
#  597  pct_ccr_eog_07_fcs_pc                          float64
#  598  pct_ccr_eog_07_fem_pc                          float64
#  599  pct_ccr_eog_07_hi7_pc                          float64
#  600  pct_ccr_eog_07_hms_pc                          float64
#  601  pct_ccr_eog_07_male_pc                         float64
#  602  pct_ccr_eog_07_mig_pc                          float64
#  603  pct_ccr_eog_07_mil_pc                          float64
#  604  pct_ccr_eog_07_mu7_pc                          float64
#  605  pct_ccr_eog_07_neds_pc                         float64
#  606  pct_ccr_eog_07_nswd_pc                         float64
#  607  pct_ccr_eog_07_swd_pc                          float64
#  608  pct_ccr_eog_07_wh7_pc                          float64
#  609  pct_ccr_eog_08_aig_pc                          float64
#  610  pct_ccr_eog_08_all_pc                          float64
#  611  pct_ccr_eog_08_am7_pc                          float64
#  612  pct_ccr_eog_08_as7_pc                          float64
#  613  pct_ccr_eog_08_bl7_pc                          float64
#  614  pct_ccr_eog_08_eds_pc                          float64
#  615  pct_ccr_eog_08_els_pc                          float64
#  616  pct_ccr_eog_08_fcs_pc                          float64
#  617  pct_ccr_eog_08_fem_pc                          float64
#  618  pct_ccr_eog_08_hi7_pc                          float64
#  619  pct_ccr_eog_08_hms_pc                          float64
#  620  pct_ccr_eog_08_male_pc                         float64
#  621  pct_ccr_eog_08_mig_pc                          float64
#  622  pct_ccr_eog_08_mil_pc                          float64
#  623  pct_ccr_eog_08_mu7_pc                          float64
#  624  pct_ccr_eog_08_neds_pc                         float64
#  625  pct_ccr_eog_08_nswd_pc                         float64
#  626  pct_ccr_eog_08_swd_pc                          float64
#  627  pct_ccr_eog_08_wh7_pc                          float64
#  628  pct_ccr_eog_all_aig_pc                         float64
#  629  pct_ccr_eog_all_all_pc                         float64
#  630  pct_ccr_eog_all_am7_pc                         float64
#  631  pct_ccr_eog_all_as7_pc                         float64
#  632  pct_ccr_eog_all_bl7_pc                         float64
#  633  pct_ccr_eog_all_eds_pc                         float64
#  634  pct_ccr_eog_all_els_pc                         float64
#  635  pct_ccr_eog_all_fcs_pc                         float64
#  636  pct_ccr_eog_all_fem_pc                         float64
#  637  pct_ccr_eog_all_hi7_pc                         float64
#  638  pct_ccr_eog_all_hms_pc                         float64
#  639  pct_ccr_eog_all_male_pc                        float64
#  640  pct_ccr_eog_all_mig_pc                         float64
#  641  pct_ccr_eog_all_mil_pc                         float64
#  642  pct_ccr_eog_all_mu7_pc                         float64
#  643  pct_ccr_eog_all_neds_pc                        float64
#  644  pct_ccr_eog_all_nswd_pc                        float64
#  645  pct_ccr_eog_all_swd_pc                         float64
#  646  pct_ccr_eog_all_wh7_pc                         float64
#  647  pct_ccr_m1_eoc_aig_pc                          float64
#  648  pct_ccr_m1_eoc_all_pc                          float64
#  649  pct_ccr_m1_eoc_am7_pc                          float64
#  650  pct_ccr_m1_eoc_as7_pc                          float64
#  651  pct_ccr_m1_eoc_bl7_pc                          float64
#  652  pct_ccr_m1_eoc_eds_pc                          float64
#  653  pct_ccr_m1_eoc_els_pc                          float64
#  654  pct_ccr_m1_eoc_fem_pc                          float64
#  655  pct_ccr_m1_eoc_hi7_pc                          float64
#  656  pct_ccr_m1_eoc_hms_pc                          float64
#  657  pct_ccr_m1_eoc_male_pc                         float64
#  658  pct_ccr_m1_eoc_mig_pc                          float64
#  659  pct_ccr_m1_eoc_mil_pc                          float64
#  660  pct_ccr_m1_eoc_mu7_pc                          float64
#  661  pct_ccr_m1_eoc_neds_pc                         float64
#  662  pct_ccr_m1_eoc_nswd_pc                         float64
#  663  pct_ccr_m1_eoc_swd_pc                          float64
#  664  pct_ccr_m1_eoc_wh7_pc                          float64
#  665  pct_ccr_m3_eoc_aig_pc                          float64
#  666  pct_ccr_m3_eoc_all_pc                          float64
#  667  pct_ccr_m3_eoc_am7_pc                          float64
#  668  pct_ccr_m3_eoc_as7_pc                          float64
#  669  pct_ccr_m3_eoc_bl7_pc                          float64
#  670  pct_ccr_m3_eoc_eds_pc                          float64
#  671  pct_ccr_m3_eoc_els_pc                          float64
#  672  pct_ccr_m3_eoc_fem_pc                          float64
#  673  pct_ccr_m3_eoc_hi7_pc                          float64
#  674  pct_ccr_m3_eoc_hms_pc                          float64
#  675  pct_ccr_m3_eoc_male_pc                         float64
#  676  pct_ccr_m3_eoc_mig_pc                          float64
#  677  pct_ccr_m3_eoc_mil_pc                          float64
#  678  pct_ccr_m3_eoc_mu7_pc                          float64
#  679  pct_ccr_m3_eoc_neds_pc                         float64
#  680  pct_ccr_m3_eoc_nswd_pc                         float64
#  681  pct_ccr_m3_eoc_swd_pc                          float64
#  682  pct_ccr_m3_eoc_wh7_pc                          float64
#  683  pct_ccr_ma_03_aig_pc                           float64
#  684  pct_ccr_ma_03_all_pc                           float64
#  685  pct_ccr_ma_03_am7_pc                           float64
#  686  pct_ccr_ma_03_as7_pc                           float64
#  687  pct_ccr_ma_03_bl7_pc                           float64
#  688  pct_ccr_ma_03_eds_pc                           float64
#  689  pct_ccr_ma_03_els_pc                           float64
#  690  pct_ccr_ma_03_fem_pc                           float64
#  691  pct_ccr_ma_03_hi7_pc                           float64
#  692  pct_ccr_ma_03_hms_pc                           float64
#  693  pct_ccr_ma_03_male_pc                          float64
#  694  pct_ccr_ma_03_mig_pc                           float64
#  695  pct_ccr_ma_03_mil_pc                           float64
#  696  pct_ccr_ma_03_mu7_pc                           float64
#  697  pct_ccr_ma_03_neds_pc                          float64
#  698  pct_ccr_ma_03_nswd_pc                          float64
#  699  pct_ccr_ma_03_swd_pc                           float64
#  700  pct_ccr_ma_03_wh7_pc                           float64
#  701  pct_ccr_ma_04_aig_pc                           float64
#  702  pct_ccr_ma_04_all_pc                           float64
#  703  pct_ccr_ma_04_am7_pc                           float64
#  704  pct_ccr_ma_04_as7_pc                           float64
#  705  pct_ccr_ma_04_bl7_pc                           float64
#  706  pct_ccr_ma_04_eds_pc                           float64
#  707  pct_ccr_ma_04_els_pc                           float64
#  708  pct_ccr_ma_04_fem_pc                           float64
#  709  pct_ccr_ma_04_hi7_pc                           float64
#  710  pct_ccr_ma_04_hms_pc                           float64
#  711  pct_ccr_ma_04_male_pc                          float64
#  712  pct_ccr_ma_04_mig_pc                           float64
#  713  pct_ccr_ma_04_mil_pc                           float64
#  714  pct_ccr_ma_04_mu7_pc                           float64
#  715  pct_ccr_ma_04_neds_pc                          float64
#  716  pct_ccr_ma_04_nswd_pc                          float64
#  717  pct_ccr_ma_04_swd_pc                           float64
#  718  pct_ccr_ma_04_wh7_pc                           float64
#  719  pct_ccr_ma_05_aig_pc                           float64
#  720  pct_ccr_ma_05_all_pc                           float64
#  721  pct_ccr_ma_05_am7_pc                           float64
#  722  pct_ccr_ma_05_as7_pc                           float64
#  723  pct_ccr_ma_05_bl7_pc                           float64
#  724  pct_ccr_ma_05_eds_pc                           float64
#  725  pct_ccr_ma_05_els_pc                           float64
#  726  pct_ccr_ma_05_fem_pc                           float64
#  727  pct_ccr_ma_05_hi7_pc                           float64
#  728  pct_ccr_ma_05_hms_pc                           float64
#  729  pct_ccr_ma_05_male_pc                          float64
#  730  pct_ccr_ma_05_mig_pc                           float64
#  731  pct_ccr_ma_05_mil_pc                           float64
#  732  pct_ccr_ma_05_mu7_pc                           float64
#  733  pct_ccr_ma_05_neds_pc                          float64
#  734  pct_ccr_ma_05_nswd_pc                          float64
#  735  pct_ccr_ma_05_swd_pc                           float64
#  736  pct_ccr_ma_05_wh7_pc                           float64
#  737  pct_ccr_ma_06_aig_pc                           float64
#  738  pct_ccr_ma_06_all_pc                           float64
#  739  pct_ccr_ma_06_am7_pc                           float64
#  740  pct_ccr_ma_06_as7_pc                           float64
#  741  pct_ccr_ma_06_bl7_pc                           float64
#  742  pct_ccr_ma_06_eds_pc                           float64
#  743  pct_ccr_ma_06_els_pc                           float64
#  744  pct_ccr_ma_06_fem_pc                           float64
#  745  pct_ccr_ma_06_hi7_pc                           float64
#  746  pct_ccr_ma_06_hms_pc                           float64
#  747  pct_ccr_ma_06_male_pc                          float64
#  748  pct_ccr_ma_06_mig_pc                           float64
#  749  pct_ccr_ma_06_mil_pc                           float64
#  750  pct_ccr_ma_06_mu7_pc                           float64
#  751  pct_ccr_ma_06_neds_pc                          float64
#  752  pct_ccr_ma_06_nswd_pc                          float64
#  753  pct_ccr_ma_06_swd_pc                           float64
#  754  pct_ccr_ma_06_wh7_pc                           float64
#  755  pct_ccr_ma_07_aig_pc                           float64
#  756  pct_ccr_ma_07_all_pc                           float64
#  757  pct_ccr_ma_07_am7_pc                           float64
#  758  pct_ccr_ma_07_as7_pc                           float64
#  759  pct_ccr_ma_07_bl7_pc                           float64
#  760  pct_ccr_ma_07_eds_pc                           float64
#  761  pct_ccr_ma_07_els_pc                           float64
#  762  pct_ccr_ma_07_fem_pc                           float64
#  763  pct_ccr_ma_07_hi7_pc                           float64
#  764  pct_ccr_ma_07_hms_pc                           float64
#  765  pct_ccr_ma_07_male_pc                          float64
#  766  pct_ccr_ma_07_mig_pc                           float64
#  767  pct_ccr_ma_07_mil_pc                           float64
#  768  pct_ccr_ma_07_mu7_pc                           float64
#  769  pct_ccr_ma_07_neds_pc                          float64
#  770  pct_ccr_ma_07_nswd_pc                          float64
#  771  pct_ccr_ma_07_swd_pc                           float64
#  772  pct_ccr_ma_07_wh7_pc                           float64
#  773  pct_ccr_ma_08_aig_pc                           float64
#  774  pct_ccr_ma_08_all_pc                           float64
#  775  pct_ccr_ma_08_am7_pc                           float64
#  776  pct_ccr_ma_08_as7_pc                           float64
#  777  pct_ccr_ma_08_bl7_pc                           float64
#  778  pct_ccr_ma_08_eds_pc                           float64
#  779  pct_ccr_ma_08_els_pc                           float64
#  780  pct_ccr_ma_08_fem_pc                           float64
#  781  pct_ccr_ma_08_hi7_pc                           float64
#  782  pct_ccr_ma_08_hms_pc                           float64
# ...
#  4388 num_credentials_cte_cred                       float64
#  4389 num_enrollments_cte_cred                       float64
#  4390 cred_earned_pct_cte_cred                       float64
#  4391 career_only_cte_end_cte_enroll                 float64
#  4392 career_college_college_unc_cte_end_cte_enroll  float64
#  4393 college_college_unc_only_cte_end_cte_enroll    float64
#  4394 college_only_cte_end_cte_enroll                float64
#  4395 stu_enroll                                     float64
#  4396 cte_enroll                                     float64
#  4397 pct                                            float64
#  4398 digital_media_dlmi                             float64
#  4399 category_code_dlmi                             float64
#  4400 device_access_dlmi                             float64
#  4401 device_access_grades_dlmi                      float64
#  4402 device_home_dlmi                               float64
#  4403 device_home_grades_dlmi                        float64
#  4404 byod_dlmi                                      float64
#  4405 byod_grades_dlmi                               float64
#  4406 book_titlesper_student_dlmi                    float64
#  4407 wap_dlmi                                       float64
#  4408 wap_class_dlmi                                 float64
#  4409 media_school_dlmi                              float64
#  4410 devices_dlmi                                   float64
#  4411 ni_effect3                                     float64
#  4412 eff_effect3                                    float64
#  4413 he_effect3                                     float64
#  4414 ni_pct_effect3                                 float64
#  4415 eff_pct_effect3                                float64
#  4416 he_pct_effect3                                 float64
#  4417 poverty_eq                                     object
#  4418 number_of_teachers_eq                          float64
#  4419 beg_teacher_eq                                 float64
#  4420 pct_beg_teachers_eq                            float64
#  4421 prov_teachers_eq                               float64
#  4422 pct_prov_teachers_eq                           float64
#  4423 num_prin_eq                                    float64
#  4424 inexp_count_prin_eq                            float64
#  4425 pct_inexp_prin_eq                              float64
#  4426 adm_central_expense_funds2                     float64
#  4427 adm_employee_benefits_funds2                   float64
#  4428 adm_instructional_equip._funds2                float64
#  4429 adm_other_objects_funds2                       float64
#  4430 adm_purchased_services_funds2                  float64
#  4431 adm_salaries_funds2                            float64
#  4432 adm_supplies_&_materials_funds2                float64
#  4433 adm_total_funds2                               float64
#  4434 federal_funds_central_expense_funds2           float64
#  4435 federal_funds_employee_benefits_funds2         float64
#  4436 federal_funds_instructional_equip._funds2      float64
#  4437 federal_funds_other_objects_funds2             float64
#  4438 federal_funds_purchased_services_funds2        float64
#  4439 federal_funds_salaries_funds2                  float64
#  4440 federal_funds_supplies_&_materials_funds2      float64
#  4441 federal_funds_total_funds2                     float64
#  4442 federal_ppe_central_expense_funds2             float64
#  4443 federal_ppe_employee_benefits_funds2           float64
#  4444 federal_ppe_instructional_equip._funds2        float64
#  4445 federal_ppe_other_objects_funds2               float64
#  4446 federal_ppe_purchased_services_funds2          float64
#  4447 federal_ppe_salaries_funds2                    float64
#  4448 federal_ppe_supplies_&_materials_funds2        float64
#  4449 federal_ppe_total_funds2                       float64
#  4450 local_funds_central_expense_funds2             float64
#  4451 local_funds_employee_benefits_funds2           float64
#  4452 local_funds_instructional_equip._funds2        float64
#  4453 local_funds_other_objects_funds2               float64
#  4454 local_funds_purchased_services_funds2          float64
#  4455 local_funds_salaries_funds2                    float64
#  4456 local_funds_supplies_&_materials_funds2        float64
#  4457 local_funds_total_funds2                       float64
#  4458 local_ppe_central_expense_funds2               float64
#  4459 local_ppe_employee_benefits_funds2             float64
#  4460 local_ppe_instructional_equip._funds2          float64
#  4461 local_ppe_other_objects_funds2                 float64
#  4462 local_ppe_purchased_services_funds2            float64
#  4463 local_ppe_salaries_funds2                      float64
#  4464 local_ppe_supplies_&_materials_funds2          float64
#  4465 local_ppe_total_funds2                         float64
#  4466 state_funds_central_expense_funds2             float64
#  4467 state_funds_employee_benefits_funds2           float64
#  4468 state_funds_instructional_equip._funds2        float64
#  4469 state_funds_other_objects_funds2               float64
#  4470 state_funds_purchased_services_funds2          float64
#  4471 state_funds_salaries_funds2                    float64
#  4472 state_funds_supplies_&_materials_funds2        float64
#  4473 state_funds_total_funds2                       float64
#  4474 state_ppe_central_expense_funds2               float64
#  4475 state_ppe_employee_benefits_funds2             float64
#  4476 state_ppe_instructional_equip._funds2          float64
#  4477 state_ppe_other_objects_funds2                 float64
#  4478 state_ppe_purchased_services_funds2            float64
#  4479 state_ppe_salaries_funds2                      float64
#  4480 state_ppe_supplies_&_materials_funds2          float64
#  4481 state_ppe_total_funds2                         float64
#  4482 total_funds_central_expense_funds2             float64
#  4483 total_funds_employee_benefits_funds2           float64
#  4484 total_funds_instructional_equip._funds2        float64
#  4485 total_funds_other_objects_funds2               float64
#  4486 total_funds_purchased_services_funds2          float64
#  4487 total_funds_salaries_funds2                    float64
#  4488 total_funds_supplies_&_materials_funds2        float64
#  4489 total_funds_total_funds2                       float64
#  4490 total_ppe_central_expense_funds2               float64
#  4491 total_ppe_employee_benefits_funds2             float64
#  4492 total_ppe_instructional_equip._funds2          float64
#  4493 total_ppe_other_objects_funds2                 float64
#  4494 total_ppe_purchased_services_funds2            float64
#  4495 total_ppe_salaries_funds2                      float64
#  4496 total_ppe_supplies_&_materials_funds2          float64
#  4497 total_ppe_total_funds2                         float64
#  4498 pct_ib_pass                                    float64
#  4499 pct_ib_participation                           float64
#  4500 amount_improvement                             float64
#  4501 act_per1000_all_inc2                           float64
#  4502 act_per1000_am7_inc2                           float64
#  4503 act_per1000_as7_inc2                           float64
#  4504 act_per1000_bl7_inc2                           float64
#  4505 act_per1000_eds_inc2                           float64
#  4506 act_per1000_els_inc2                           float64
#  4507 act_per1000_fem_inc2                           float64
#  4508 act_per1000_hi7_inc2                           float64
#  4509 act_per1000_male_inc2                          float64
#  4510 act_per1000_mu7_inc2                           float64
#  4511 act_per1000_pi7_inc2                           float64
#  4512 act_per1000_swd_inc2                           float64
#  4513 act_per1000_wh7_inc2                           float64
#  4514 arr_per1000_all_inc2                           float64
#  4515 arr_per1000_am7_inc2                           float64
#  4516 arr_per1000_as7_inc2                           float64
#  4517 arr_per1000_bl7_inc2                           float64
#  4518 arr_per1000_eds_inc2                           float64
#  4519 arr_per1000_els_inc2                           float64
#  4520 arr_per1000_fem_inc2                           float64
#  4521 arr_per1000_hi7_inc2                           float64
#  4522 arr_per1000_male_inc2                          float64
#  4523 arr_per1000_mu7_inc2                           float64
#  4524 arr_per1000_pi7_inc2                           float64
#  4525 arr_per1000_swd_inc2                           float64
#  4526 arr_per1000_wh7_inc2                           float64
#  4527 bha_per1000_all_inc2                           float64
#  4528 bha_per1000_am7_inc2                           float64
#  4529 bha_per1000_as7_inc2                           float64
#  4530 bha_per1000_bl7_inc2                           float64
#  4531 bha_per1000_eds_inc2                           float64
#  4532 bha_per1000_els_inc2                           float64
#  4533 bha_per1000_fem_inc2                           float64
#  4534 bha_per1000_hi7_inc2                           float64
#  4535 bha_per1000_male_inc2                          float64
#  4536 bha_per1000_mu7_inc2                           float64
#  4537 bha_per1000_pi7_inc2                           float64
#  4538 bha_per1000_swd_inc2                           float64
#  4539 bha_per1000_wh7_inc2                           float64
#  4540 exp_per1000_all_inc2                           float64
#  4541 exp_per1000_am7_inc2                           float64
#  4542 exp_per1000_as7_inc2                           float64
#  4543 exp_per1000_bl7_inc2                           float64
#  4544 exp_per1000_eds_inc2                           float64
#  4545 exp_per1000_els_inc2                           float64
#  4546 exp_per1000_fem_inc2                           float64
#  4547 exp_per1000_hi7_inc2                           float64
#  4548 exp_per1000_male_inc2                          float64
#  4549 exp_per1000_mu7_inc2                           float64
#  4550 exp_per1000_pi7_inc2                           float64
#  4551 exp_per1000_swd_inc2                           float64
#  4552 exp_per1000_wh7_inc2                           float64
#  4553 iss_per1000_all_inc2                           float64
#  4554 iss_per1000_am7_inc2                           float64
#  4555 iss_per1000_as7_inc2                           float64
#  4556 iss_per1000_bl7_inc2                           float64
#  4557 iss_per1000_eds_inc2                           float64
#  4558 iss_per1000_els_inc2                           float64
#  4559 iss_per1000_fem_inc2                           float64
#  4560 iss_per1000_hi7_inc2                           float64
#  4561 iss_per1000_male_inc2                          float64
#  4562 iss_per1000_mu7_inc2                           float64
#  4563 iss_per1000_pi7_inc2                           float64
#  4564 iss_per1000_swd_inc2                           float64
#  4565 iss_per1000_wh7_inc2                           float64
#  4566 lts_per1000_all_inc2                           float64
#  4567 lts_per1000_am7_inc2                           float64
#  4568 lts_per1000_as7_inc2                           float64
#  4569 lts_per1000_bl7_inc2                           float64
#  4570 lts_per1000_eds_inc2                           float64
#  4571 lts_per1000_els_inc2                           float64
#  4572 lts_per1000_fem_inc2                           float64
#  4573 lts_per1000_hi7_inc2                           float64
#  4574 lts_per1000_male_inc2                          float64
#  4575 lts_per1000_mu7_inc2                           float64
#  4576 lts_per1000_pi7_inc2                           float64
#  4577 lts_per1000_swd_inc2                           float64
#  4578 lts_per1000_wh7_inc2                           float64
#  4579 rpt_per1000_all_inc2                           float64
#  4580 rpt_per1000_am7_inc2                           float64
#  4581 rpt_per1000_as7_inc2                           float64
#  4582 rpt_per1000_bl7_inc2                           float64
#  4583 rpt_per1000_eds_inc2                           float64
#  4584 rpt_per1000_els_inc2                           float64
#  4585 rpt_per1000_fem_inc2                           float64
#  4586 rpt_per1000_hi7_inc2                           float64
#  4587 rpt_per1000_male_inc2                          float64
#  4588 rpt_per1000_mu7_inc2                           float64
#  4589 rpt_per1000_pi7_inc2                           float64
#  4590 rpt_per1000_swd_inc2                           float64
#  4591 rpt_per1000_wh7_inc2                           float64
#  4592 sts_per1000_all_inc2                           float64
#  4593 sts_per1000_am7_inc2                           float64
#  4594 sts_per1000_as7_inc2                           float64
#  4595 sts_per1000_bl7_inc2                           float64
#  4596 sts_per1000_eds_inc2                           float64
#  4597 sts_per1000_els_inc2                           float64
#  4598 sts_per1000_fem_inc2                           float64
#  4599 sts_per1000_hi7_inc2                           float64
#  4600 sts_per1000_male_inc2                          float64
#  4601 sts_per1000_mu7_inc2                           float64
#  4602 sts_per1000_pi7_inc2                           float64
#  4603 sts_per1000_swd_inc2                           float64
#  4604 sts_per1000_wh7_inc2                           float64
#  4605 count_ALL_PK_ENROLL                            float64
#  4606 count_AM7_PK_ENROLL                            float64
#  4607 count_AS7_PK_ENROLL                            float64
#  4608 count_BL7_PK_ENROLL                            float64
#  4609 count_ELS_PK_ENROLL                            float64
#  4610 count_FEM_PK_ENROLL                            float64
#  4611 count_HI7_PK_ENROLL                            float64
#  4612 count_MALE_PK_ENROLL                           float64
#  4613 count_MU7_PK_ENROLL                            float64
#  4614 count_PI7_PK_ENROLL                            float64
#  4615 count_SWD_PK_ENROLL                            float64
#  4616 count_WH7_PK_ENROLL                            float64
#  4617 pct_ALL_PK_ENROLL                              float64
#  4618 pct_AM7_PK_ENROLL                              float64
#  4619 pct_AS7_PK_ENROLL                              float64
#  4620 pct_BL7_PK_ENROLL                              float64
#  4621 pct_ELS_PK_ENROLL                              float64
#  4622 pct_FEM_PK_ENROLL                              float64
#  4623 pct_HI7_PK_ENROLL                              float64
#  4624 pct_MALE_PK_ENROLL                             float64
#  4625 pct_MU7_PK_ENROLL                              float64
#  4626 pct_PI7_PK_ENROLL                              float64
#  4627 pct_SWD_PK_ENROLL                              float64
#  4628 pct_WH7_PK_ENROLL                              float64
#  4629 pct_ready_kea_a_cat_code                       float64
#  4630 pct_ready_kea_e_cat_code                       float64
#  4631 pct_ready_kea_i_cat_code                       float64
#  4632 pct_ready_kea_m_cat_code                       float64
#  4633 avg_size_00_sar                                float64
#  4634 avg_size_01_sar                                float64
#  4635 avg_size_02_sar                                float64
#  4636 avg_size_03_sar                                float64
#  4637 avg_size_04_sar                                float64
#  4638 avg_size_05_sar                                float64
#  4639 avg_size_06_sar                                float64
#  4640 avg_size_07_sar                                float64
#  4641 avg_size_08_sar                                float64
#  4642 avg_size_biology_sar                           float64
#  4643 avg_size_english_ii_sar                        float64
#  4644 avg_size_nc_math_1_sar                         float64
#  4645 avg_size_nc_math_3_sar                         float64
#  4646 avg_sat_score                                  float64
#  4647 pct_sat_participation                          float64
#  4648 welcome_url                                    object
# dtypes: float64(4610), object(39)
# memory usage: 24.5+ MB

# %% [markdown]
# # Prepare Consolidated Dataset for Machine Learning
# **Below we perform operations on the entire dataset to remove columns and update row values that could cause problems during machine learning.**

# %% [markdown]
# ## Student Body Racial Composition Features
# **Impute / update missing Student Body Racial Composition Fields using mean imputation.**
# * When there are no racial composition percentages for a particular school campus / agency_code, fill in the missing values

# %%
#Get Student Body Racial Composition Fields
raceCompositionFields = schoolData.filter(regex='indian|asian|hispanic|black|white|pacific_island|two_or_more|minority')\
                                  .filter(regex='pct').columns
    
rowsBefore = schoolData[raceCompositionFields].isnull().T.any().T.sum()

#Update missing race values with the district average when avaiable (No district averages for charter schools) 
schoolData[raceCompositionFields] = schoolData.groupby('lea_code_loc')[raceCompositionFields]\
                                              .transform(lambda x: x.fillna(x.mean()))

    #Review dataset contents after Racial Composition Imputation
print('*********After: Updating Missing Racial Compostion Values****************************')   
rowsAfter = schoolData[raceCompositionFields].isnull().T.any().T.sum()
rowsUpdated = rowsBefore - rowsAfter
print('Rows Updated / Imputed: ', rowsUpdated) 
print('\r\nTotal Rows Missing Racial Compositions By District Code') 
schoolData['lea_code_loc'][schoolData[raceCompositionFields].isnull().T.any().T].value_counts()
# Out:
# *********After: Updating Missing Racial Compostion Values****************************
# Rows Updated / Imputed:  4
#
# Total Rows Missing Racial Compositions By District Code
# 998LEA    13
# 997LEA     9
# 298LEA     3
# 269LEA     2
# 679LEA     1
# 299LEA     1
# Name: lea_code_loc, dtype: int64

# %% [markdown]
# ## Remove Columns with Problematic Data
# **Here we remove entire columns that could cause problems during machine learning.  The following operations are performed:**
# * Remove any columns that have the same value in every single row.
# * Remove any columns that have a unique value in every single row (all values are different).
# * Remove empty columns (all values are NA or NULL).

# %%
#Remove any fields that have the same value in all rows
UniqueValueCounts = schoolData.nunique(dropna=False)
SingleValueCols = UniqueValueCounts[UniqueValueCounts == 1].index
schoolData = schoolData.drop(SingleValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with the same value in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(SingleValueCols))
# Out:
# *********After: Removing columns with the same value in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 691 entries, 2 to 845
# Columns: 4150 entries, agency_code to welcome_url
# dtypes: float64(4115), object(35)
# memory usage: 21.9+ MB
#
# Columns Deleted:  499

# %%
#Remove any fields that have unique values in every row
schoolDataRecordCt = schoolData.shape[0]
UniqueValueCounts = schoolData.apply(pd.Series.nunique)
AllUniqueValueCols = UniqueValueCounts[UniqueValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(AllUniqueValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with unique values in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(AllUniqueValueCols))
# Out:
# *********After: Removing columns with unique values in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 691 entries, 2 to 845
# Columns: 4149 entries, category_code_loc to welcome_url
# dtypes: float64(4115), object(34)
# memory usage: 21.9+ MB
#
# Columns Deleted:  1

# %%
#Remove any empty fields (null values in every row)
schoolDataRecordCt = schoolData.shape[0]
NullValueCounts = schoolData.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with null / blank values in every row.*************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with null / blank values in every row.*************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 691 entries, 2 to 845
# Columns: 4149 entries, category_code_loc to welcome_url
# dtypes: float64(4115), object(34)
# memory usage: 21.9+ MB
#
# Columns Deleted:  0

# %% [markdown]
# ## Handle Other Missing Values Types
# * Here we eliminate any numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# * All remaining non-race, numeric column missing values are populated with 0.
# * In many cases, it seems that schools are not simply not reporting values when they are zero. However, mean imputation or some other strategy might be considered.

# %%
#Isolate continuous and categorical data types
#These are indexers into the schoolData dataframe and may be used similar to the schoolData dataframe 
sD_boolean = schoolData.loc[:, (schoolData.dtypes == bool) ]
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]
sD_continuous = schoolData.loc[:, (schoolData.dtypes != bool) & (schoolData.dtypes != object)]
print ("Boolean Columns: ", sD_boolean.shape[1])
print ("Nominal Columns: ", sD_nominal.shape[1])
print ("Continuous Columns: ", sD_continuous.shape[1])
print ("Columns Accounted for: ", sD_nominal.shape[1] + sD_continuous.shape[1] + sD_boolean.shape[1])
# Out:
# Boolean Columns:  0
# Nominal Columns:  34
# Continuous Columns:  4115
# Columns Accounted for:  4149

# %%
#Eliminate continuous columns with more than missingThreshold percentage of missing values
schoolDataRecordCt = sD_continuous.shape[0]
missingValueLimit = schoolDataRecordCt * missingThreshold
NullValueCounts = sD_continuous.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts >= missingValueLimit].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with >= missingThreshold % of missing values******')
schoolData.info(verbose=False)
print('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with >= missingThreshold % of missing values******
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 691 entries, 2 to 845
# Columns: 1392 entries, category_code_loc to welcome_url
# dtypes: float64(1358), object(34)
# memory usage: 7.3+ MB
#
# Columns Deleted:  2757

# %% [markdown]
# ## One-Hot Encoding of Categorical Variables
# **All categorical / string variables are converted to numberic variables via one hot encoding.  Each unique row value will become a new binary / numeric column in the dataset.**
# * All remaining categorical columns are one-hot encoded.
# * In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# * Prior to one-hot encoding, columns with > *uniqueThreshold* unique values are deleted.

# %%
#Delete categorical columns with > uniqueThreshold unique values 
#(Each unique value becomes a column during one-hot encoding)
oneHotUniqueValueCounts = schoolData[sD_nominal.columns].apply(lambda x: x.nunique())
oneHotUniqueValueCols = oneHotUniqueValueCounts[oneHotUniqueValueCounts >= uniqueThreshold].index
schoolData.drop(oneHotUniqueValueCols, axis=1, inplace=True) 

#Remove categorical columns which do not add value to machine learning
#Grades columns dropped since they all have indicator fields (device_access, device_home, BYOD)
#with less unique values to one-hot encode

# _dlmi columns may or may not exist after running cleanups above.

#----MUST CHECK FOR:---- 'device_access_grades_dlmi','device_home_grades_dlmi','byod_grades_dlmi'
# to fields below, if they exist
schoolData.drop(['welcome_url'], axis=1, inplace=True) 

#Review dataset contents one hot high unique value drops
print('*********After: Removing columns with >= uniqueThreshold unique values***********')
schoolData.info(verbose=False)
print('\r\nColumns Deleted: ', len(oneHotUniqueValueCols))
print(oneHotUniqueValueCols)
print('Dropped Manually: welcome_url,device_access_grades_dlmi ,device_home_grades_dlmi ,byod_grades_dlmi ')
# Out:
# *********After: Removing columns with >= uniqueThreshold unique values***********
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 691 entries, 2 to 845
# Columns: 1384 entries, category_code_loc to avg_size_nc_math_1_sar
# dtypes: float64(1358), object(26)
# memory usage: 7.3+ MB
#
# Columns Deleted:  7
# Index(['name_loc', 'street_addr_loc', 'city_loc', 'zip_loc', 'phone_loc',
#        'url_loc', 'school_name'],
#       dtype='object')
# Dropped Manually: welcome_url,device_access_grades_dlmi ,device_home_grades_dlmi ,byod_grades_dlmi

# %%
#Isolate remaining categorical variables
begColumnCt = len(schoolData.columns)
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]

#one hot encode categorical variables
schoolData = pd.get_dummies(data=schoolData, 
                       columns=sD_nominal.columns, drop_first=True)

#Determine change in column count
endColumnCt = len(schoolData.columns)
columnsAdded = endColumnCt - begColumnCt

#Review dataset contents one hot high unique value drops
print('Columns To One-Hot Encode: ', len(sD_nominal.columns))
print('\r\n*********After: Adding New Columns Via One-Hot Encoding*************************')
schoolData.info(verbose=False)
print('\r\nNew Columns Created Via One-Hot Encoding: ', columnsAdded)
# Out:
# Columns To One-Hot Encode:  26
#
# *********After: Adding New Columns Via One-Hot Encoding*************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 691 entries, 2 to 845
# Columns: 1821 entries, lea to poverty_eq_NEITHER
# dtypes: float64(1358), uint8(463)
# memory usage: 7.5 MB
#
# New Columns Created Via One-Hot Encoding:  437

# %%
#Remove any fields that have the same value in all rows after one-hot encoding
UniqueValueCounts = schoolData.nunique(dropna=False)
SingleValueCols = UniqueValueCounts[UniqueValueCounts == 1].index
schoolData = schoolData.drop(SingleValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing one-hot encoded columns with the same value in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(SingleValueCols))
# Out:
# *********After: Removing one-hot encoded columns with the same value in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 691 entries, 2 to 845
# Columns: 1821 entries, lea to poverty_eq_NEITHER
# dtypes: float64(1358), uint8(463)
# memory usage: 7.5 MB
#
# Columns Deleted:  0

# %% [markdown]
# ## Impute any Remaining Missing Values as Zero

# %%
#Print out all the missing value rows
pd.set_option('display.max_rows', 1500)

print('\r\n*********The Remaining Missing Values Below will be set to Zero!*************************')

#Check for Missing values 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# *********The Remaining Missing Values Below will be set to Zero!*************************
#                                   Variable Name  Number Missing Values
# 0                                           lea                     33
# 1                                        school                     33
# 2                                    indian_pct                     29
# 3                                     asian_pct                     29
# 4                                  hispanic_pct                     29
# 5                                     black_pct                     29
# 6                                     white_pct                     29
# 7                            pacific_island_pct                     29
# 8                               two_or_more_pct                     29
# 9                                  minority_pct                     29
# 10                              indian_male_pct                     29
# 11                               asian_male_pct                     29
# 12                            hispanic_male_pct                     29
# 13                               black_male_pct                     29
# 14                               white_male_pct                     29
# 15                      pacific_island_male_pct                     29
# 16                         two_or_more_male_pct                     29
# 17                            minority_male_pct                     29
# 18                            indian_female_pct                     29
# 19                             asian_female_pct                     29
# 20                          hispanic_female_pct                     29
# 21                             black_female_pct                     29
# 22                             white_female_pct                     29
# 23                          minority_female_pct                     29
# 24                    pacific_island_female_pct                     29
# 25                       two_or_more_female_pct                     29
# 26                                      pct_eds                     34
# 27                          eg_index_all_aig_eg                    170
# 28                          eg_index_all_all_eg                     67
# 29                          eg_index_all_bl7_eg                    185
# 30                          eg_index_all_eds_eg                     80
# 31                          eg_index_all_els_eg                    216
# 32                          eg_index_all_hi7_eg                    163
# 33                          eg_index_all_mu7_eg                    289
# 34                          eg_index_all_swd_eg                    137
# 35                          eg_index_all_wh7_eg                    125
# 36                           eg_index_ma_all_eg                     81
# 37                           eg_index_rd_all_eg                     96
# 38                          eg_score_all_aig_eg                    195
# 39                          eg_score_all_all_eg                     86
# 40                          eg_score_all_bl7_eg                    215
# 41                          eg_score_all_eds_eg                    101
# 42                          eg_score_all_els_eg                    279
# 43                          eg_score_all_hi7_eg                    189
# 44                          eg_score_all_mu7_eg                    389
# 45                          eg_score_all_swd_eg                    167
# 46                          eg_score_all_wh7_eg                    141
# 47                           eg_score_ma_all_eg                    106
# 48                           eg_score_rd_all_eg                    111
# 49                                  den_all_elp                    278
# 50                                  den_eds_elp                    325
# 51                                  den_els_elp                    278
# 52                                  den_hi7_elp                    316
# 53                                 den_male_elp                    365
# 54                                 den_nswd_elp                    335
# 55                                  pct_all_elp                    278
# 56                                  pct_eds_elp                    325
# 57                                  pct_els_elp                    278
# 58                                  pct_hi7_elp                    316
# 59                                 pct_male_elp                    365
# 60                                 pct_nswd_elp                    335
# 61                             pct_prof_6gr_irm                    130
# 62                  pct_met_math_grades_3-8_ltg                     88
# 63               pct_met_reading_grades_3-8_ltg                     88
# 64                    pct_met_total_targets_ltg                     63
# 65            target_assign_math_grades_3-8_ltg                     88
# 66         target_assign_reading_grades_3-8_ltg                     88
# 67              target_assign_total_targets_ltg                     63
# 68               target_met_math_grades_3-8_ltg                     88
# 69            target_met_reading_grades_3-8_ltg                     88
# 70                 target_met_total_targets_ltg                     63
# 71                 pct_met_math_grades_3-8_part                     75
# 72              pct_met_reading_grades_3-8_part                     75
# 73              pct_met_science_grades_5&8_part                    114
# 74                   pct_met_total_targets_part                     67
# 75           target_assign_math_grades_3-8_part                     75
# 76        target_assign_reading_grades_3-8_part                     75
# 77        target_assign_science_grades_5&8_part                    114
# 78             target_assign_total_targets_part                     67
# 79              target_met_math_grades_3-8_part                     75
# 80           target_met_reading_grades_3-8_part                     75
# 81           target_met_science_grades_5&8_part                    114
# 82                target_met_total_targets_part                     67
# 83             pct_math_grades_3-8_all_part_det                     75
# 84             pct_math_grades_3-8_bl7_part_det                    227
# 85             pct_math_grades_3-8_eds_part_det                     95
# 86             pct_math_grades_3-8_els_part_det                    313
# 87             pct_math_grades_3-8_hi7_part_det                    207
# 88             pct_math_grades_3-8_swd_part_det                    164
# 89             pct_math_grades_3-8_wh7_part_det                    156
# 90          pct_reading_grades_3-8_all_part_det                     75
# 91          pct_reading_grades_3-8_bl7_part_det                    227
# 92          pct_reading_grades_3-8_eds_part_det                     95
# 93          pct_reading_grades_3-8_els_part_det                    313
# 94          pct_reading_grades_3-8_hi7_part_det                    207
# 95          pct_reading_grades_3-8_swd_part_det                    164
# 96          pct_reading_grades_3-8_wh7_part_det                    156
# 97          pct_science_grades_5&8_all_part_det                    114
# 98          pct_science_grades_5&8_bl7_part_det                    358
# 99          pct_science_grades_5&8_eds_part_det                    154
# 100         pct_science_grades_5&8_hi7_part_det                    411
# 101         pct_science_grades_5&8_wh7_part_det                    239
# 102                       pct_ccr_eog_06_aig_pc                    204
# 103                       pct_ccr_eog_06_all_pc                    118
# 104                       pct_ccr_eog_06_bl7_pc                    223
# 105                       pct_ccr_eog_06_eds_pc                    132
# 106                       pct_ccr_eog_06_fem_pc                    141
# 107                       pct_ccr_eog_06_hi7_pc                    189
# 108                      pct_ccr_eog_06_male_pc                    129
# 109                       pct_ccr_eog_06_mu7_pc                    314
# 110                      pct_ccr_eog_06_neds_pc                    139
# 111                      pct_ccr_eog_06_nswd_pc                    129
# 112                       pct_ccr_eog_06_swd_pc                    309
# 113                       pct_ccr_eog_06_wh7_pc                    158
# 114                       pct_ccr_eog_07_aig_pc                    189
# 115                       pct_ccr_eog_07_all_pc                     96
# 116                       pct_ccr_eog_07_bl7_pc                    214
# 117                       pct_ccr_eog_07_eds_pc                    112
# 118                       pct_ccr_eog_07_fem_pc                    121
# 119                       pct_ccr_eog_07_hi7_pc                    181
# 120                      pct_ccr_eog_07_male_pc                    107
# 121                       pct_ccr_eog_07_mu7_pc                    313
# 122                      pct_ccr_eog_07_neds_pc                    119
# 123                      pct_ccr_eog_07_nswd_pc                    106
# 124                       pct_ccr_eog_07_swd_pc                    298
# 125                       pct_ccr_eog_07_wh7_pc                    137
# 126                       pct_ccr_eog_08_aig_pc                    179
# 127                       pct_ccr_eog_08_all_pc                     91
# 128                       pct_ccr_eog_08_bl7_pc                    200
# 129                       pct_ccr_eog_08_eds_pc                    100
# 130                       pct_ccr_eog_08_fem_pc                    112
# 131                       pct_ccr_eog_08_hi7_pc                    172
# 132                      pct_ccr_eog_08_male_pc                    100
# 133                       pct_ccr_eog_08_mu7_pc                    286
# 134                      pct_ccr_eog_08_neds_pc                    110
# 135                      pct_ccr_eog_08_nswd_pc                     99
# 136                       pct_ccr_eog_08_swd_pc                    195
# 137                       pct_ccr_eog_08_wh7_pc                    131
# 138                      pct_ccr_eog_all_aig_pc                    124
# 139                      pct_ccr_eog_all_all_pc                     71
# 140                      pct_ccr_eog_all_as7_pc                    373
# 141                      pct_ccr_eog_all_bl7_pc                    151
# 142                      pct_ccr_eog_all_eds_pc                     81
# 143                      pct_ccr_eog_all_els_pc                    291
# 144                      pct_ccr_eog_all_fem_pc                     81
# 145                      pct_ccr_eog_all_hi7_pc                    108
# 146                      pct_ccr_eog_all_hms_pc                    307
# 147                     pct_ccr_eog_all_male_pc                     68
# 148                      pct_ccr_eog_all_mu7_pc                    153
# 149                     pct_ccr_eog_all_neds_pc                     79
# 150                     pct_ccr_eog_all_nswd_pc                     79
# 151                      pct_ccr_eog_all_swd_pc                    153
# 152                      pct_ccr_eog_all_wh7_pc                     79
# 153                        pct_ccr_ma_06_aig_pc                    271
# 154                        pct_ccr_ma_06_all_pc                    141
# 155                        pct_ccr_ma_06_bl7_pc                    284
# 156                        pct_ccr_ma_06_eds_pc                    160
# 157                        pct_ccr_ma_06_fem_pc                    156
# 158                        pct_ccr_ma_06_hi7_pc                    247
# 159                       pct_ccr_ma_06_male_pc                    152
# 160                       pct_ccr_ma_06_neds_pc                    161
# 161                       pct_ccr_ma_06_nswd_pc                    140
# 162                        pct_ccr_ma_06_wh7_pc                    195
# 163                        pct_ccr_ma_07_aig_pc                    265
# 164                        pct_ccr_ma_07_all_pc                    121
# 165                        pct_ccr_ma_07_bl7_pc                    269
# 166                        pct_ccr_ma_07_eds_pc                    142
# 167                        pct_ccr_ma_07_fem_pc                    148
# 168                        pct_ccr_ma_07_hi7_pc                    241
# 169                       pct_ccr_ma_07_male_pc                    139
# 170                       pct_ccr_ma_07_neds_pc                    146
# 171                       pct_ccr_ma_07_nswd_pc                    121
# 172                        pct_ccr_ma_07_wh7_pc                    175
# 173                        pct_ccr_ma_08_aig_pc                    260
# 174                        pct_ccr_ma_08_all_pc                    139
# 175                        pct_ccr_ma_08_bl7_pc                    321
# 176                        pct_ccr_ma_08_eds_pc                    187
# 177                        pct_ccr_ma_08_fem_pc                    158
# 178                        pct_ccr_ma_08_hi7_pc                    265
# 179                       pct_ccr_ma_08_male_pc                    161
# 180                       pct_ccr_ma_08_neds_pc                    153
# 181                       pct_ccr_ma_08_nswd_pc                    137
# 182                        pct_ccr_ma_08_wh7_pc                    182
# 183                       pct_ccr_ma_all_aig_pc                    141
# 184                       pct_ccr_ma_all_all_pc                    109
# 185                       pct_ccr_ma_all_bl7_pc                    197
# 186                       pct_ccr_ma_all_eds_pc                    116
# 187                       pct_ccr_ma_all_els_pc                    389
# 188                       pct_ccr_ma_all_fem_pc                    113
# 189                       pct_ccr_ma_all_hi7_pc                    138
# 190                      pct_ccr_ma_all_male_pc                    110
# 191                       pct_ccr_ma_all_mu7_pc                    231
# 192                      pct_ccr_ma_all_neds_pc                    100
# 193                      pct_ccr_ma_all_nswd_pc                    103
# 194                       pct_ccr_ma_all_swd_pc                    367
# 195                       pct_ccr_ma_all_wh7_pc                    119
# 196                        pct_ccr_rd_06_aig_pc                    271
# 197                        pct_ccr_rd_06_all_pc                    132
# 198                        pct_ccr_rd_06_bl7_pc                    261
# 199                        pct_ccr_rd_06_eds_pc                    143
# 200                        pct_ccr_rd_06_fem_pc                    149
# 201                        pct_ccr_rd_06_hi7_pc                    246
# 202                       pct_ccr_rd_06_male_pc                    142
# 203                       pct_ccr_rd_06_neds_pc                    156
# 204                       pct_ccr_rd_06_nswd_pc                    137
# 205                        pct_ccr_rd_06_swd_pc                    325
# 206                        pct_ccr_rd_06_wh7_pc                    191
# 207                        pct_ccr_rd_07_aig_pc                    265
# 208                        pct_ccr_rd_07_all_pc                    108
# 209                        pct_ccr_rd_07_bl7_pc                    251
# 210                        pct_ccr_rd_07_eds_pc                    129
# 211                        pct_ccr_rd_07_fem_pc                    138
# 212                        pct_ccr_rd_07_hi7_pc                    236
# 213                       pct_ccr_rd_07_male_pc                    128
# 214                       pct_ccr_rd_07_neds_pc                    144
# 215                       pct_ccr_rd_07_nswd_pc                    115
# 216                        pct_ccr_rd_07_swd_pc                    322
# 217                        pct_ccr_rd_07_wh7_pc                    172
# 218                        pct_ccr_rd_08_aig_pc                    260
# 219                        pct_ccr_rd_08_all_pc                    107
# 220                        pct_ccr_rd_08_bl7_pc                    255
# 221                        pct_ccr_rd_08_eds_pc                    140
# 222                        pct_ccr_rd_08_fem_pc                    136
# 223                        pct_ccr_rd_08_hi7_pc                    251
# 224                       pct_ccr_rd_08_male_pc                    134
# 225                       pct_ccr_rd_08_neds_pc                    140
# 226                       pct_ccr_rd_08_nswd_pc                    116
# 227                        pct_ccr_rd_08_swd_pc                    369
# 228                        pct_ccr_rd_08_wh7_pc                    166
# 229                       pct_ccr_rd_all_aig_pc                    141
# 230                       pct_ccr_rd_all_all_pc                     69
# 231                       pct_ccr_rd_all_bl7_pc                    176
# 232                       pct_ccr_rd_all_eds_pc                     81
# 233                       pct_ccr_rd_all_fem_pc                     96
# 234                       pct_ccr_rd_all_hi7_pc                    130
# 235                      pct_ccr_rd_all_male_pc                     74
# 236                       pct_ccr_rd_all_mu7_pc                    226
# 237                      pct_ccr_rd_all_neds_pc                     85
# 238                      pct_ccr_rd_all_nswd_pc                     86
# 239                       pct_ccr_rd_all_swd_pc                    186
# 240                       pct_ccr_rd_all_wh7_pc                    105
# 241                        pct_ccr_sc_08_aig_pc                    260
# 242                        pct_ccr_sc_08_all_pc                     96
# 243                        pct_ccr_sc_08_bl7_pc                    247
# 244                        pct_ccr_sc_08_eds_pc                    127
# 245                        pct_ccr_sc_08_fem_pc                    134
# 246                        pct_ccr_sc_08_hi7_pc                    248
# 247                       pct_ccr_sc_08_male_pc                    122
# 248                       pct_ccr_sc_08_neds_pc                    138
# 249                       pct_ccr_sc_08_nswd_pc                    107
# 250                        pct_ccr_sc_08_swd_pc                    249
# 251                        pct_ccr_sc_08_wh7_pc                    167
# 252                       pct_ccr_sc_all_aig_pc                    222
# 253                       pct_ccr_sc_all_all_pc                     82
# 254                       pct_ccr_sc_all_bl7_pc                    233
# 255                       pct_ccr_sc_all_eds_pc                    101
# 256                       pct_ccr_sc_all_fem_pc                    114
# 257                       pct_ccr_sc_all_hi7_pc                    213
# 258                      pct_ccr_sc_all_male_pc                     98
# 259                      pct_ccr_sc_all_neds_pc                    114
# 260                      pct_ccr_sc_all_nswd_pc                     96
# 261                       pct_ccr_sc_all_swd_pc                    182
# 262                       pct_ccr_sc_all_wh7_pc                    144
# 263                       pct_glp_eog_06_aig_pc                    204
# 264                       pct_glp_eog_06_all_pc                    107
# 265                       pct_glp_eog_06_bl7_pc                    210
# 266                       pct_glp_eog_06_eds_pc                    126
# 267                       pct_glp_eog_06_els_pc                    396
# 268                       pct_glp_eog_06_fem_pc                    135
# 269                       pct_glp_eog_06_hi7_pc                    186
# 270                      pct_glp_eog_06_male_pc                    120
# 271                       pct_glp_eog_06_mu7_pc                    313
# 272                      pct_glp_eog_06_neds_pc                    136
# 273                      pct_glp_eog_06_nswd_pc                    124
# 274                       pct_glp_eog_06_swd_pc                    212
# 275                       pct_glp_eog_06_wh7_pc                    156
# 276                       pct_glp_eog_07_aig_pc                    189
# 277                       pct_glp_eog_07_all_pc                     85
# 278                       pct_glp_eog_07_bl7_pc                    206
# 279                       pct_glp_eog_07_eds_pc                    100
# 280                       pct_glp_eog_07_fem_pc                    115
# 281                       pct_glp_eog_07_hi7_pc                    176
# 282                      pct_glp_eog_07_male_pc                     96
# 283                       pct_glp_eog_07_mu7_pc                    309
# 284                      pct_glp_eog_07_neds_pc                    114
# 285                      pct_glp_eog_07_nswd_pc                    102
# 286                       pct_glp_eog_07_swd_pc                    193
# 287                       pct_glp_eog_07_wh7_pc                    132
# 288                       pct_glp_eog_08_aig_pc                    179
# 289                       pct_glp_eog_08_all_pc                     75
# 290                       pct_glp_eog_08_bl7_pc                    190
# 291                       pct_glp_eog_08_eds_pc                     90
# 292                       pct_glp_eog_08_els_pc                    372
# 293                       pct_glp_eog_08_fem_pc                    108
# 294                       pct_glp_eog_08_hi7_pc                    171
# 295                      pct_glp_eog_08_male_pc                     86
# 296                       pct_glp_eog_08_mu7_pc                    286
# 297                      pct_glp_eog_08_neds_pc                    105
# 298                      pct_glp_eog_08_nswd_pc                     92
# 299                       pct_glp_eog_08_swd_pc                    156
# 300                       pct_glp_eog_08_wh7_pc                    127
# 301                      pct_glp_eog_all_aig_pc                    124
# 302                      pct_glp_eog_all_all_pc                     55
# 303                      pct_glp_eog_all_as7_pc                    372
# 304                      pct_glp_eog_all_bl7_pc                    130
# 305                      pct_glp_eog_all_eds_pc                     61
# 306                      pct_glp_eog_all_els_pc                    201
# 307                      pct_glp_eog_all_fem_pc                     67
# 308                      pct_glp_eog_all_hi7_pc                    102
# 309                      pct_glp_eog_all_hms_pc                    296
# 310                     pct_glp_eog_all_male_pc                     55
# 311                      pct_glp_eog_all_mu7_pc                    152
# 312                     pct_glp_eog_all_neds_pc                     69
# 313                     pct_glp_eog_all_nswd_pc                     73
# 314                      pct_glp_eog_all_swd_pc                     98
# 315                      pct_glp_eog_all_wh7_pc                     68
# 316                        pct_glp_ma_06_aig_pc                    271
# 317                        pct_glp_ma_06_all_pc                    133
# 318                        pct_glp_ma_06_bl7_pc                    261
# 319                        pct_glp_ma_06_eds_pc                    145
# 320                        pct_glp_ma_06_fem_pc                    146
# 321                        pct_glp_ma_06_hi7_pc                    246
# 322                       pct_glp_ma_06_male_pc                    140
# 323                       pct_glp_ma_06_neds_pc                    156
# 324                       pct_glp_ma_06_nswd_pc                    137
# 325                        pct_glp_ma_06_swd_pc                    293
# 326                        pct_glp_ma_06_wh7_pc                    192
# 327                        pct_glp_ma_07_aig_pc                    265
# 328                        pct_glp_ma_07_all_pc                    105
# 329                        pct_glp_ma_07_bl7_pc                    248
# 330                        pct_glp_ma_07_eds_pc                    128
# 331                        pct_glp_ma_07_fem_pc                    140
# 332                        pct_glp_ma_07_hi7_pc                    236
# 333                       pct_glp_ma_07_male_pc                    124
# 334                       pct_glp_ma_07_neds_pc                    143
# 335                       pct_glp_ma_07_nswd_pc                    112
# 336                        pct_glp_ma_07_swd_pc                    273
# 337                        pct_glp_ma_07_wh7_pc                    172
# 338                        pct_glp_ma_08_aig_pc                    260
# 339                        pct_glp_ma_08_all_pc                    114
# 340                        pct_glp_ma_08_bl7_pc                    259
# 341                        pct_glp_ma_08_eds_pc                    148
# 342                        pct_glp_ma_08_fem_pc                    135
# 343                        pct_glp_ma_08_hi7_pc                    249
# 344                       pct_glp_ma_08_male_pc                    140
# 345                       pct_glp_ma_08_neds_pc                    141
# 346                       pct_glp_ma_08_nswd_pc                    119
# 347                        pct_glp_ma_08_swd_pc                    335
# 348                        pct_glp_ma_08_wh7_pc                    170
# 349                       pct_glp_ma_all_aig_pc                    141
# 350                       pct_glp_ma_all_all_pc                     72
# 351                       pct_glp_ma_all_bl7_pc                    172
# 352                       pct_glp_ma_all_eds_pc                     83
# 353                       pct_glp_ma_all_els_pc                    289
# 354                       pct_glp_ma_all_fem_pc                     91
# 355                       pct_glp_ma_all_hi7_pc                    130
# 356                      pct_glp_ma_all_male_pc                     81
# 357                       pct_glp_ma_all_mu7_pc                    226
# 358                      pct_glp_ma_all_neds_pc                     83
# 359                      pct_glp_ma_all_nswd_pc                     89
# 360                       pct_glp_ma_all_swd_pc                    143
# 361                       pct_glp_ma_all_wh7_pc                    106
# 362                        pct_glp_rd_06_aig_pc                    271
# 363                        pct_glp_rd_06_all_pc                    129
# 364                        pct_glp_rd_06_bl7_pc                    257
# 365                        pct_glp_rd_06_eds_pc                    140
# 366                        pct_glp_rd_06_fem_pc                    145
# 367                        pct_glp_rd_06_hi7_pc                    245
# 368                       pct_glp_rd_06_male_pc                    140
# 369                       pct_glp_rd_06_neds_pc                    156
# 370                       pct_glp_rd_06_nswd_pc                    135
# 371                        pct_glp_rd_06_swd_pc                    281
# 372                        pct_glp_rd_06_wh7_pc                    191
# 373                        pct_glp_rd_07_aig_pc                    265
# 374                        pct_glp_rd_07_all_pc                    103
# 375                        pct_glp_rd_07_bl7_pc                    244
# 376                        pct_glp_rd_07_eds_pc                    125
# 377                        pct_glp_rd_07_fem_pc                    138
# 378                        pct_glp_rd_07_hi7_pc                    234
# 379                       pct_glp_rd_07_male_pc                    123
# 380                       pct_glp_rd_07_neds_pc                    144
# 381                       pct_glp_rd_07_nswd_pc                    111
# 382                        pct_glp_rd_07_swd_pc                    266
# 383                        pct_glp_rd_07_wh7_pc                    172
# 384                        pct_glp_rd_08_aig_pc                    260
# 385                        pct_glp_rd_08_all_pc                     99
# 386                        pct_glp_rd_08_bl7_pc                    249
# 387                        pct_glp_rd_08_eds_pc                    133
# 388                        pct_glp_rd_08_fem_pc                    135
# 389                        pct_glp_rd_08_hi7_pc                    248
# 390                       pct_glp_rd_08_male_pc                    126
# 391                       pct_glp_rd_08_neds_pc                    139
# 392                       pct_glp_rd_08_nswd_pc                    111
# 393                        pct_glp_rd_08_swd_pc                    293
# 394                        pct_glp_rd_08_wh7_pc                    165
# 395                       pct_glp_rd_all_aig_pc                    141
# 396                       pct_glp_rd_all_all_pc                     61
# 397                       pct_glp_rd_all_bl7_pc                    162
# 398                       pct_glp_rd_all_eds_pc                     71
# 399                       pct_glp_rd_all_els_pc                    354
# 400                       pct_glp_rd_all_fem_pc                     84
# 401                       pct_glp_rd_all_hi7_pc                    128
# 402                      pct_glp_rd_all_male_pc                     69
# 403                       pct_glp_rd_all_mu7_pc                    226
# 404                      pct_glp_rd_all_neds_pc                     82
# 405                      pct_glp_rd_all_nswd_pc                     82
# 406                       pct_glp_rd_all_swd_pc                    127
# 407                       pct_glp_rd_all_wh7_pc                    102
# 408                        pct_glp_sc_08_aig_pc                    260
# 409                        pct_glp_sc_08_all_pc                     94
# 410                        pct_glp_sc_08_bl7_pc                    244
# 411                        pct_glp_sc_08_eds_pc                    127
# 412                        pct_glp_sc_08_fem_pc                    132
# 413                        pct_glp_sc_08_hi7_pc                    248
# 414                       pct_glp_sc_08_male_pc                    120
# 415                       pct_glp_sc_08_neds_pc                    137
# 416                       pct_glp_sc_08_nswd_pc                    107
# 417                        pct_glp_sc_08_swd_pc                    241
# 418                        pct_glp_sc_08_wh7_pc                    167
# 419                       pct_glp_sc_all_aig_pc                    222
# 420                       pct_glp_sc_all_all_pc                     78
# 421                       pct_glp_sc_all_bl7_pc                    228
# 422                       pct_glp_sc_all_eds_pc                     98
# 423                       pct_glp_sc_all_fem_pc                    111
# 424                       pct_glp_sc_all_hi7_pc                    213
# 425                      pct_glp_sc_all_male_pc                     94
# 426                      pct_glp_sc_all_neds_pc                    113
# 427                      pct_glp_sc_all_nswd_pc                     95
# 428                       pct_glp_sc_all_swd_pc                    174
# 429                       pct_glp_sc_all_wh7_pc                    143
# 430                         pct_l1_rd_06_all_pc                    153
# 431                         pct_l1_rd_06_bl7_pc                    266
# 432                         pct_l1_rd_06_eds_pc                    151
# 433                         pct_l1_rd_06_fem_pc                    187
# 434                         pct_l1_rd_06_hi7_pc                    264
# 435                        pct_l1_rd_06_male_pc                    163
# 436                        pct_l1_rd_06_neds_pc                    258
# 437                        pct_l1_rd_06_nswd_pc                    217
# 438                         pct_l1_rd_06_swd_pc                    240
# 439                         pct_l1_rd_06_wh7_pc                    276
# 440                         pct_l1_rd_07_all_pc                    120
# 441                         pct_l1_rd_07_bl7_pc                    245
# 442                         pct_l1_rd_07_eds_pc                    128
# 443                         pct_l1_rd_07_fem_pc                    174
# 444                         pct_l1_rd_07_hi7_pc                    248
# 445                        pct_l1_rd_07_male_pc                    136
# 446                        pct_l1_rd_07_neds_pc                    222
# 447                        pct_l1_rd_07_nswd_pc                    169
# 448                         pct_l1_rd_07_swd_pc                    218
# 449                         pct_l1_rd_07_wh7_pc                    244
# 450                         pct_l1_rd_08_all_pc                    114
# 451                         pct_l1_rd_08_bl7_pc                    250
# 452                         pct_l1_rd_08_eds_pc                    132
# 453                         pct_l1_rd_08_fem_pc                    168
# 454                         pct_l1_rd_08_hi7_pc                    259
# 455                        pct_l1_rd_08_male_pc                    130
# 456                        pct_l1_rd_08_neds_pc                    195
# 457                        pct_l1_rd_08_nswd_pc                    156
# 458                         pct_l1_rd_08_swd_pc                    238
# 459                         pct_l1_rd_08_wh7_pc                    223
# 460                        pct_l1_rd_all_all_pc                     68
# 461                        pct_l1_rd_all_bl7_pc                    158
# 462                        pct_l1_rd_all_eds_pc                     70
# 463                        pct_l1_rd_all_els_pc                    265
# 464                        pct_l1_rd_all_fem_pc                    102
# 465                        pct_l1_rd_all_hi7_pc                    142
# 466                       pct_l1_rd_all_male_pc                     76
# 467                        pct_l1_rd_all_mu7_pc                    258
# 468                       pct_l1_rd_all_neds_pc                    134
# 469                       pct_l1_rd_all_nswd_pc                    121
# 470                        pct_l1_rd_all_swd_pc                     88
# 471                        pct_l1_rd_all_wh7_pc                    158
# 472                         pct_l1_sc_08_all_pc                    174
# 473                         pct_l1_sc_08_bl7_pc                    260
# 474                         pct_l1_sc_08_eds_pc                    152
# 475                         pct_l1_sc_08_fem_pc                    239
# 476                         pct_l1_sc_08_hi7_pc                    299
# 477                        pct_l1_sc_08_male_pc                    184
# 478                        pct_l1_sc_08_neds_pc                    354
# 479                        pct_l1_sc_08_nswd_pc                    282
# 480                         pct_l1_sc_08_swd_pc                    239
# 481                         pct_l1_sc_08_wh7_pc                    359
# 482                        pct_l1_sc_all_all_pc                    145
# 483                        pct_l1_sc_all_bl7_pc                    240
# 484                        pct_l1_sc_all_eds_pc                    125
# 485                        pct_l1_sc_all_fem_pc                    212
# 486                        pct_l1_sc_all_hi7_pc                    262
# 487                       pct_l1_sc_all_male_pc                    153
# 488                       pct_l1_sc_all_neds_pc                    325
# 489                       pct_l1_sc_all_nswd_pc                    256
# 490                        pct_l1_sc_all_swd_pc                    172
# 491                        pct_l1_sc_all_wh7_pc                    335
# 492                         pct_l2_rd_06_all_pc                    132
# 493                         pct_l2_rd_06_bl7_pc                    256
# 494                         pct_l2_rd_06_eds_pc                    140
# 495                         pct_l2_rd_06_fem_pc                    149
# 496                         pct_l2_rd_06_hi7_pc                    250
# 497                        pct_l2_rd_06_male_pc                    144
# 498                        pct_l2_rd_06_neds_pc                    183
# 499                        pct_l2_rd_06_nswd_pc                    139
# 500                         pct_l2_rd_06_swd_pc                    247
# 501                         pct_l2_rd_06_wh7_pc                    220
# 502                         pct_l2_rd_07_all_pc                    105
# 503                         pct_l2_rd_07_bl7_pc                    241
# 504                         pct_l2_rd_07_eds_pc                    121
# 505                         pct_l2_rd_07_fem_pc                    148
# 506                         pct_l2_rd_07_hi7_pc                    240
# 507                        pct_l2_rd_07_male_pc                    129
# 508                        pct_l2_rd_07_neds_pc                    162
# 509                        pct_l2_rd_07_nswd_pc                    116
# 510                         pct_l2_rd_07_swd_pc                    233
# 511                         pct_l2_rd_07_wh7_pc                    194
# 512                         pct_l2_rd_08_all_pc                     97
# 513                         pct_l2_rd_08_bl7_pc                    247
# 514                         pct_l2_rd_08_eds_pc                    128
# 515                         pct_l2_rd_08_fem_pc                    137
# 516                         pct_l2_rd_08_hi7_pc                    257
# 517                        pct_l2_rd_08_male_pc                    123
# 518                        pct_l2_rd_08_neds_pc                    146
# 519                        pct_l2_rd_08_nswd_pc                    110
# 520                         pct_l2_rd_08_swd_pc                    253
# 521                         pct_l2_rd_08_wh7_pc                    182
# 522                        pct_l2_rd_all_all_pc                     58
# 523                        pct_l2_rd_all_bl7_pc                    153
# 524                        pct_l2_rd_all_eds_pc                     64
# 525                        pct_l2_rd_all_els_pc                    272
# 526                        pct_l2_rd_all_fem_pc                     83
# 527                        pct_l2_rd_all_hi7_pc                    131
# 528                       pct_l2_rd_all_male_pc                     71
# 529                        pct_l2_rd_all_mu7_pc                    241
# 530                       pct_l2_rd_all_neds_pc                     88
# 531                       pct_l2_rd_all_nswd_pc                     79
# 532                        pct_l2_rd_all_swd_pc                     98
# 533                        pct_l2_rd_all_wh7_pc                    115
# 534                         pct_l2_sc_08_all_pc                    228
# 535                         pct_l2_sc_08_bl7_pc                    294
# 536                         pct_l2_sc_08_eds_pc                    191
# 537                         pct_l2_sc_08_fem_pc                    270
# 538                         pct_l2_sc_08_hi7_pc                    344
# 539                        pct_l2_sc_08_male_pc                    248
# 540                        pct_l2_sc_08_neds_pc                    405
# 541                        pct_l2_sc_08_nswd_pc                    288
# 542                         pct_l2_sc_08_swd_pc                    275
# 543                        pct_l2_sc_all_all_pc                    196
# 544                        pct_l2_sc_all_bl7_pc                    272
# 545                        pct_l2_sc_all_eds_pc                    150
# 546                        pct_l2_sc_all_fem_pc                    228
# 547                        pct_l2_sc_all_hi7_pc                    306
# 548                       pct_l2_sc_all_male_pc                    211
# 549                       pct_l2_sc_all_neds_pc                    362
# 550                       pct_l2_sc_all_nswd_pc                    257
# 551                        pct_l2_sc_all_swd_pc                    209
# 552                        pct_l2_sc_all_wh7_pc                    384
# 553                       pct_l3_all_all_aig_pc                    358
# 554                       pct_l3_all_all_all_pc                     70
# 555                       pct_l3_all_all_bl7_pc                    144
# 556                       pct_l3_all_all_eds_pc                     78
# 557                       pct_l3_all_all_els_pc                    300
# 558                       pct_l3_all_all_fem_pc                     73
# 559                       pct_l3_all_all_hi7_pc                    108
# 560                       pct_l3_all_all_hms_pc                    346
# 561                      pct_l3_all_all_male_pc                     78
# 562                       pct_l3_all_all_mu7_pc                    169
# 563                      pct_l3_all_all_neds_pc                     74
# 564                      pct_l3_all_all_nswd_pc                     86
# 565                       pct_l3_all_all_swd_pc                    178
# 566                       pct_l3_all_all_wh7_pc                     77
# 567                        pct_l3_eog_06_all_pc                    118
# 568                        pct_l3_eog_06_bl7_pc                    231
# 569                        pct_l3_eog_06_eds_pc                    138
# 570                        pct_l3_eog_06_fem_pc                    140
# 571                        pct_l3_eog_06_hi7_pc                    199
# 572                       pct_l3_eog_06_male_pc                    138
# 573                        pct_l3_eog_06_mu7_pc                    356
# 574                       pct_l3_eog_06_neds_pc                    148
# 575                       pct_l3_eog_06_nswd_pc                    134
# 576                        pct_l3_eog_06_swd_pc                    310
# 577                        pct_l3_eog_06_wh7_pc                    176
# 578                        pct_l3_eog_07_all_pc                    101
# 579                        pct_l3_eog_07_bl7_pc                    228
# 580                        pct_l3_eog_07_eds_pc                    119
# 581                        pct_l3_eog_07_fem_pc                    126
# 582                        pct_l3_eog_07_hi7_pc                    203
# 583                       pct_l3_eog_07_male_pc                    122
# 584                        pct_l3_eog_07_mu7_pc                    368
# 585                       pct_l3_eog_07_neds_pc                    131
# 586                       pct_l3_eog_07_nswd_pc                    116
# 587                        pct_l3_eog_07_swd_pc                    296
# 588                        pct_l3_eog_07_wh7_pc                    153
# 589                        pct_l3_eog_08_aig_pc                    347
# 590                        pct_l3_eog_08_all_pc                     95
# 591                        pct_l3_eog_08_bl7_pc                    213
# 592                        pct_l3_eog_08_eds_pc                    105
# 593                        pct_l3_eog_08_fem_pc                    117
# 594                        pct_l3_eog_08_hi7_pc                    184
# 595                       pct_l3_eog_08_male_pc                    108
# 596                        pct_l3_eog_08_mu7_pc                    328
# 597                       pct_l3_eog_08_neds_pc                    123
# 598                       pct_l3_eog_08_nswd_pc                    110
# 599                        pct_l3_eog_08_swd_pc                    280
# 600                        pct_l3_eog_08_wh7_pc                    143
# 601                       pct_l3_eog_all_aig_pc                    366
# 602                       pct_l3_eog_all_all_pc                     73
# 603                       pct_l3_eog_all_bl7_pc                    152
# 604                       pct_l3_eog_all_eds_pc                     80
# 605                       pct_l3_eog_all_els_pc                    305
# 606                       pct_l3_eog_all_fem_pc                     79
# 607                       pct_l3_eog_all_hi7_pc                    115
# 608                       pct_l3_eog_all_hms_pc                    350
# 609                      pct_l3_eog_all_male_pc                     80
# 610                       pct_l3_eog_all_mu7_pc                    175
# 611                      pct_l3_eog_all_neds_pc                     80
# 612                      pct_l3_eog_all_nswd_pc                     90
# 613                       pct_l3_eog_all_swd_pc                    184
# 614                       pct_l3_eog_all_wh7_pc                     84
# 615                         pct_l3_ma_06_all_pc                    139
# 616                         pct_l3_ma_06_bl7_pc                    278
# 617                         pct_l3_ma_06_eds_pc                    152
# 618                         pct_l3_ma_06_fem_pc                    156
# 619                         pct_l3_ma_06_hi7_pc                    261
# 620                        pct_l3_ma_06_male_pc                    152
# 621                        pct_l3_ma_06_neds_pc                    166
# 622                        pct_l3_ma_06_nswd_pc                    145
# 623                         pct_l3_ma_06_swd_pc                    336
# 624                         pct_l3_ma_06_wh7_pc                    202
# 625                         pct_l3_ma_07_all_pc                    121
# 626                         pct_l3_ma_07_bl7_pc                    275
# 627                         pct_l3_ma_07_eds_pc                    147
# 628                         pct_l3_ma_07_fem_pc                    151
# 629                         pct_l3_ma_07_hi7_pc                    268
# 630                        pct_l3_ma_07_male_pc                    147
# 631                        pct_l3_ma_07_neds_pc                    160
# 632                        pct_l3_ma_07_nswd_pc                    127
# 633                         pct_l3_ma_07_swd_pc                    333
# 634                         pct_l3_ma_07_wh7_pc                    192
# 635                         pct_l3_ma_08_aig_pc                    337
# 636                         pct_l3_ma_08_all_pc                    121
# 637                         pct_l3_ma_08_bl7_pc                    280
# 638                         pct_l3_ma_08_eds_pc                    155
# 639                         pct_l3_ma_08_fem_pc                    138
# 640                         pct_l3_ma_08_hi7_pc                    259
# 641                        pct_l3_ma_08_male_pc                    153
# 642                        pct_l3_ma_08_neds_pc                    144
# 643                        pct_l3_ma_08_nswd_pc                    126
# 644                         pct_l3_ma_08_swd_pc                    400
# 645                         pct_l3_ma_08_wh7_pc                    176
# 646                        pct_l3_ma_all_aig_pc                    297
# 647                        pct_l3_ma_all_all_pc                     83
# 648                        pct_l3_ma_all_bl7_pc                    181
# 649                        pct_l3_ma_all_eds_pc                     94
# 650                        pct_l3_ma_all_els_pc                    341
# 651                        pct_l3_ma_all_fem_pc                     96
# 652                        pct_l3_ma_all_hi7_pc                    143
# 653                       pct_l3_ma_all_male_pc                     90
# 654                        pct_l3_ma_all_mu7_pc                    250
# 655                       pct_l3_ma_all_neds_pc                     92
# 656                       pct_l3_ma_all_nswd_pc                    100
# 657                        pct_l3_ma_all_swd_pc                    195
# 658                        pct_l3_ma_all_wh7_pc                    115
# 659                         pct_l3_rd_06_all_pc                    153
# 660                         pct_l3_rd_06_bl7_pc                    291
# 661                         pct_l3_rd_06_eds_pc                    169
# 662                         pct_l3_rd_06_fem_pc                    169
# 663                         pct_l3_rd_06_hi7_pc                    288
# 664                        pct_l3_rd_06_male_pc                    176
# 665                        pct_l3_rd_06_neds_pc                    213
# 666                        pct_l3_rd_06_nswd_pc                    158
# 667                         pct_l3_rd_06_wh7_pc                    261
# 668                         pct_l3_rd_07_all_pc                    129
# 669                         pct_l3_rd_07_bl7_pc                    293
# 670                         pct_l3_rd_07_eds_pc                    162
# 671                         pct_l3_rd_07_fem_pc                    169
# 672                         pct_l3_rd_07_hi7_pc                    285
# ...
# 1133                         aaa_score_swd_spg2                    131
# 1134                         aaa_score_wh7_spg2                    134
# 1135                         ach_score_all_spg2                    109
# 1136                         ach_score_bl7_spg2                    204
# 1137                         ach_score_eds_spg2                    112
# 1138                         ach_score_els_spg2                    231
# 1139                         ach_score_hi7_spg2                    157
# 1140                         ach_score_mu7_spg2                    293
# 1141                         ach_score_swd_spg2                    131
# 1142                         ach_score_wh7_spg2                    134
# 1143                          eg_score_all_spg2                    112
# 1144                          eg_score_bl7_spg2                    222
# 1145                          eg_score_eds_spg2                    118
# 1146                          eg_score_els_spg2                    279
# 1147                          eg_score_hi7_spg2                    191
# 1148                          eg_score_mu7_spg2                    389
# 1149                          eg_score_swd_spg2                    169
# 1150                          eg_score_wh7_spg2                    145
# 1151                       ma_eg_score_all_spg2                    114
# 1152                      ma_spg_score_all_spg2                    112
# 1153                        mags_score_all_spg2                    112
# 1154                       rd_eg_score_all_spg2                    115
# 1155                      rd_spg_score_all_spg2                    112
# 1156                        rdgs_score_all_spg2                    112
# 1157                        scgs_score_all_spg2                    124
# 1158                        scgs_score_bl7_spg2                    367
# 1159                        scgs_score_eds_spg2                    165
# 1160                        scgs_score_wh7_spg2                    242
# 1161                         spg_score_all_spg2                    109
# 1162                         spg_score_bl7_spg2                    204
# 1163                         spg_score_eds_spg2                    112
# 1164                         spg_score_els_spg2                    231
# 1165                         spg_score_hi7_spg2                    157
# 1166                         spg_score_mu7_spg2                    293
# 1167                         spg_score_swd_spg2                    131
# 1168                         spg_score_wh7_spg2                    134
# 1169                        avg_student_num_adm                     33
# 1170                     count_all_chron_absent                     38
# 1171                     count_bl7_chron_absent                     91
# 1172                     count_els_chron_absent                    160
# 1173                     count_fem_chron_absent                     40
# 1174                     count_hi7_chron_absent                     56
# 1175                    count_male_chron_absent                     39
# 1176                     count_mu7_chron_absent                     99
# 1177                     count_swd_chron_absent                     49
# 1178                     count_wh7_chron_absent                     43
# 1179                       pct_all_chron_absent                     38
# 1180                       pct_bl7_chron_absent                     91
# 1181                       pct_els_chron_absent                    160
# 1182                       pct_fem_chron_absent                     40
# 1183                       pct_hi7_chron_absent                     56
# 1184                      pct_male_chron_absent                     39
# 1185                       pct_mu7_chron_absent                     99
# 1186                       pct_swd_chron_absent                     49
# 1187                       pct_wh7_chron_absent                     43
# 1188                                 stu_enroll                     69
# 1189                                 cte_enroll                     69
# 1190                                        pct                     69
# 1191                                 ni_effect3                     31
# 1192                                eff_effect3                     31
# 1193                                 he_effect3                     31
# 1194                             ni_pct_effect3                     31
# 1195                            eff_pct_effect3                     31
# 1196                             he_pct_effect3                     31
# 1197                      number_of_teachers_eq                     30
# 1198                             beg_teacher_eq                     30
# 1199                        pct_beg_teachers_eq                     30
# 1200                           prov_teachers_eq                     30
# 1201                       pct_prov_teachers_eq                     30
# 1202                 adm_central_expense_funds2                     33
# 1203               adm_employee_benefits_funds2                     33
# 1204            adm_instructional_equip._funds2                     33
# 1205                   adm_other_objects_funds2                     33
# 1206              adm_purchased_services_funds2                     33
# 1207                        adm_salaries_funds2                     33
# 1208            adm_supplies_&_materials_funds2                     33
# 1209                           adm_total_funds2                     33
# 1210       federal_funds_central_expense_funds2                     33
# 1211     federal_funds_employee_benefits_funds2                     33
# 1212  federal_funds_instructional_equip._funds2                     33
# 1213         federal_funds_other_objects_funds2                     33
# 1214    federal_funds_purchased_services_funds2                     33
# 1215              federal_funds_salaries_funds2                     33
# 1216  federal_funds_supplies_&_materials_funds2                     33
# 1217                 federal_funds_total_funds2                     33
# 1218         federal_ppe_central_expense_funds2                     33
# 1219       federal_ppe_employee_benefits_funds2                     33
# 1220    federal_ppe_instructional_equip._funds2                     33
# 1221           federal_ppe_other_objects_funds2                     33
# 1222      federal_ppe_purchased_services_funds2                     33
# 1223                federal_ppe_salaries_funds2                     33
# 1224    federal_ppe_supplies_&_materials_funds2                     33
# 1225                   federal_ppe_total_funds2                     33
# 1226         local_funds_central_expense_funds2                     33
# 1227       local_funds_employee_benefits_funds2                     33
# 1228    local_funds_instructional_equip._funds2                     33
# 1229           local_funds_other_objects_funds2                     33
# 1230      local_funds_purchased_services_funds2                     33
# 1231                local_funds_salaries_funds2                     33
# 1232    local_funds_supplies_&_materials_funds2                     33
# 1233                   local_funds_total_funds2                     33
# 1234           local_ppe_central_expense_funds2                     33
# 1235         local_ppe_employee_benefits_funds2                     33
# 1236      local_ppe_instructional_equip._funds2                     33
# 1237             local_ppe_other_objects_funds2                     33
# 1238        local_ppe_purchased_services_funds2                     33
# 1239                  local_ppe_salaries_funds2                     33
# 1240      local_ppe_supplies_&_materials_funds2                     33
# 1241                     local_ppe_total_funds2                     33
# 1242         state_funds_central_expense_funds2                     33
# 1243       state_funds_employee_benefits_funds2                     33
# 1244    state_funds_instructional_equip._funds2                     33
# 1245           state_funds_other_objects_funds2                     33
# 1246      state_funds_purchased_services_funds2                     33
# 1247                state_funds_salaries_funds2                     33
# 1248    state_funds_supplies_&_materials_funds2                     33
# 1249                   state_funds_total_funds2                     33
# 1250           state_ppe_central_expense_funds2                     33
# 1251         state_ppe_employee_benefits_funds2                     33
# 1252      state_ppe_instructional_equip._funds2                     33
# 1253             state_ppe_other_objects_funds2                     33
# 1254        state_ppe_purchased_services_funds2                     33
# 1255                  state_ppe_salaries_funds2                     33
# 1256      state_ppe_supplies_&_materials_funds2                     33
# 1257                     state_ppe_total_funds2                     33
# 1258         total_funds_central_expense_funds2                     33
# 1259       total_funds_employee_benefits_funds2                     33
# 1260    total_funds_instructional_equip._funds2                     33
# 1261           total_funds_other_objects_funds2                     33
# 1262      total_funds_purchased_services_funds2                     33
# 1263                total_funds_salaries_funds2                     33
# 1264    total_funds_supplies_&_materials_funds2                     33
# 1265                   total_funds_total_funds2                     33
# 1266           total_ppe_central_expense_funds2                     33
# 1267         total_ppe_employee_benefits_funds2                     33
# 1268      total_ppe_instructional_equip._funds2                     33
# 1269             total_ppe_other_objects_funds2                     33
# 1270        total_ppe_purchased_services_funds2                     33
# 1271                  total_ppe_salaries_funds2                     33
# 1272      total_ppe_supplies_&_materials_funds2                     33
# 1273                     total_ppe_total_funds2                     33
# 1274                       act_per1000_all_inc2                     47
# 1275                       act_per1000_bl7_inc2                    136
# 1276                       act_per1000_eds_inc2                     52
# 1277                       act_per1000_els_inc2                    257
# 1278                       act_per1000_fem_inc2                     72
# 1279                       act_per1000_hi7_inc2                    126
# 1280                      act_per1000_male_inc2                     56
# 1281                       act_per1000_mu7_inc2                    242
# 1282                       act_per1000_swd_inc2                     67
# 1283                       act_per1000_wh7_inc2                     87
# 1284                       arr_per1000_all_inc2                     47
# 1285                       arr_per1000_bl7_inc2                    136
# 1286                       arr_per1000_eds_inc2                     52
# 1287                       arr_per1000_els_inc2                    257
# 1288                       arr_per1000_fem_inc2                     72
# 1289                       arr_per1000_hi7_inc2                    126
# 1290                      arr_per1000_male_inc2                     56
# 1291                       arr_per1000_mu7_inc2                    242
# 1292                       arr_per1000_swd_inc2                     67
# 1293                       arr_per1000_wh7_inc2                     87
# 1294                       bha_per1000_all_inc2                     47
# 1295                       bha_per1000_bl7_inc2                    136
# 1296                       bha_per1000_eds_inc2                     52
# 1297                       bha_per1000_els_inc2                    257
# 1298                       bha_per1000_fem_inc2                     72
# 1299                       bha_per1000_hi7_inc2                    126
# 1300                      bha_per1000_male_inc2                     56
# 1301                       bha_per1000_mu7_inc2                    242
# 1302                       bha_per1000_swd_inc2                     67
# 1303                       bha_per1000_wh7_inc2                     87
# 1304                       exp_per1000_all_inc2                     47
# 1305                       exp_per1000_bl7_inc2                    136
# 1306                       exp_per1000_eds_inc2                     52
# 1307                       exp_per1000_els_inc2                    257
# 1308                       exp_per1000_fem_inc2                     72
# 1309                       exp_per1000_hi7_inc2                    126
# 1310                      exp_per1000_male_inc2                     56
# 1311                       exp_per1000_mu7_inc2                    242
# 1312                       exp_per1000_swd_inc2                     67
# 1313                       exp_per1000_wh7_inc2                     87
# 1314                       iss_per1000_all_inc2                     47
# 1315                       iss_per1000_bl7_inc2                    137
# 1316                       iss_per1000_eds_inc2                     52
# 1317                       iss_per1000_els_inc2                    257
# 1318                       iss_per1000_fem_inc2                     72
# 1319                       iss_per1000_hi7_inc2                    126
# 1320                      iss_per1000_male_inc2                     56
# 1321                       iss_per1000_mu7_inc2                    242
# 1322                       iss_per1000_swd_inc2                     67
# 1323                       iss_per1000_wh7_inc2                     87
# 1324                       lts_per1000_all_inc2                     47
# 1325                       lts_per1000_bl7_inc2                    136
# 1326                       lts_per1000_eds_inc2                     52
# 1327                       lts_per1000_els_inc2                    257
# 1328                       lts_per1000_fem_inc2                     72
# 1329                       lts_per1000_hi7_inc2                    126
# 1330                      lts_per1000_male_inc2                     56
# 1331                       lts_per1000_mu7_inc2                    242
# 1332                       lts_per1000_swd_inc2                     67
# 1333                       lts_per1000_wh7_inc2                     87
# 1334                       rpt_per1000_all_inc2                     47
# 1335                       rpt_per1000_bl7_inc2                    136
# 1336                       rpt_per1000_eds_inc2                     52
# 1337                       rpt_per1000_els_inc2                    257
# 1338                       rpt_per1000_fem_inc2                     72
# 1339                       rpt_per1000_hi7_inc2                    126
# 1340                      rpt_per1000_male_inc2                     56
# 1341                       rpt_per1000_mu7_inc2                    242
# 1342                       rpt_per1000_swd_inc2                     67
# 1343                       rpt_per1000_wh7_inc2                     87
# 1344                       sts_per1000_all_inc2                     48
# 1345                       sts_per1000_bl7_inc2                    141
# 1346                       sts_per1000_eds_inc2                     52
# 1347                       sts_per1000_els_inc2                    257
# 1348                       sts_per1000_fem_inc2                     73
# 1349                       sts_per1000_hi7_inc2                    127
# 1350                      sts_per1000_male_inc2                     61
# 1351                       sts_per1000_mu7_inc2                    242
# 1352                       sts_per1000_swd_inc2                     67
# 1353                       sts_per1000_wh7_inc2                     88
# 1354                            avg_size_06_sar                    138
# 1355                            avg_size_07_sar                    114
# 1356                            avg_size_08_sar                    109
# 1357                     avg_size_nc_math_1_sar                    160

# %%
#Replace all remaining NaN with 0
schoolData = schoolData.fillna(0)

#Check for Missing values after final imputation 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# Empty DataFrame
# Columns: [Variable Name, Number Missing Values]
# Index: []

# %% [markdown]
# ## Identify and Remove Highly Correlated Features
# **Find and remove any columns / features that are > 95% correlated**
# * https://stackoverflow.com/questions/39409866/correlation-heatmap
# * https://chrisalbon.com/machine_learning/feature_selection/drop_highly_correlated_features/
# * https://codeyarns.com/2015/04/20/how-to-change-font-size-in-seaborn/

# %%
# calculate the correlation matrix
corr_matrix  = schoolData.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
#Print out all the missing value rows
pd.set_option('display.max_rows', 3500)

#Get all of the correlation values > 95%
x = np.where(upper > 0.95)

#Display all field combinations with > 95% correlation
cf = pd.DataFrame()
cf['Field1'] = upper.columns[x[1]]
cf['Field2'] = upper.index[x[0]]

#Get the correlation values for every field combination. (There must be a more pythonic way to do this!)
corr = [0] * len(cf)
for i in range(0, len(cf)):
    corr[i] =  upper[cf['Field1'][i]][cf['Field2'][i]] 
    
cf['Correlation'] = corr

print ('There are ', str(len(cf['Field1'])), ' field correlations > 95%.')
cf
# Out:
# There are  1541  field correlations > 95%.
#                                              Field1  \
# 0                                   indian_male_pct
# 1                                 indian_female_pct
# 2                                    asian_male_pct
# 3                                  asian_female_pct
# 4                                 hispanic_male_pct
# 5                               hispanic_female_pct
# 6                                    black_male_pct
# 7                                    white_male_pct
# 8                                  white_female_pct
# 9                                 indian_female_pct
# 10                               eg_index_ma_all_eg
# 11                               eg_index_rd_all_eg
# 12                               eg_index_rd_all_eg
# 13                                eg_score_bl7_spg2
# 14                                eg_score_els_spg2
# 15                                eg_score_hi7_spg2
# 16                                eg_score_mu7_spg2
# 17                                eg_score_swd_spg2
# 18                                eg_score_wh7_spg2
# 19                               eg_score_rd_all_eg
# 20                                eg_score_all_spg2
# 21                             ma_eg_score_all_spg2
# 22                                eg_score_all_spg2
# 23                             ma_eg_score_all_spg2
# 24                                      den_els_elp
# 25                                      den_hi7_elp
# 26                                     den_male_elp
# 27                                     den_nswd_elp
# 28                                      den_hi7_elp
# 29                                     den_male_elp
# 30                                     den_nswd_elp
# 31                                     den_male_elp
# 32                                     den_nswd_elp
# 33                                     den_nswd_elp
# 34                                      pct_els_elp
# 35                             pct_ccr_rd_06_all_pc
# 36                            pct_ccr_rd_06_nswd_pc
# 37                             pct_glp_rd_06_all_pc
# 38             target_assign_reading_grades_3-8_ltg
# 39                  target_assign_total_targets_ltg
# 40               target_assign_math_grades_3-8_part
# 41            target_assign_reading_grades_3-8_part
# 42                  target_met_math_grades_3-8_part
# 43               target_met_reading_grades_3-8_part
# 44                  target_assign_total_targets_ltg
# 45               target_assign_math_grades_3-8_part
# 46            target_assign_reading_grades_3-8_part
# 47                  target_met_math_grades_3-8_part
# 48               target_met_reading_grades_3-8_part
# 49                 target_assign_total_targets_part
# 50                    target_met_total_targets_part
# 51                  pct_met_reading_grades_3-8_part
# 52                       pct_met_total_targets_part
# 53                       pct_met_total_targets_part
# 54              pct_science_grades_5&8_all_part_det
# 55            target_assign_reading_grades_3-8_part
# 56                 target_assign_total_targets_part
# 57                  target_met_math_grades_3-8_part
# 58               target_met_reading_grades_3-8_part
# 59                    target_met_total_targets_part
# 60                 target_assign_total_targets_part
# 61                  target_met_math_grades_3-8_part
# 62               target_met_reading_grades_3-8_part
# 63                    target_met_total_targets_part
# 64               target_met_science_grades_5&8_part
# 65               target_met_reading_grades_3-8_part
# 66                    target_met_total_targets_part
# 67               target_met_reading_grades_3-8_part
# 68                    target_met_total_targets_part
# 69                    target_met_total_targets_part
# 70              pct_reading_grades_3-8_all_part_det
# 71              pct_reading_grades_3-8_bl7_part_det
# 72              pct_reading_grades_3-8_eds_part_det
# 73              pct_reading_grades_3-8_els_part_det
# 74              pct_reading_grades_3-8_hi7_part_det
# 75              pct_reading_grades_3-8_swd_part_det
# 76              pct_reading_grades_3-8_wh7_part_det
# 77                              scgs_score_wh7_spg2
# 78                            pct_glp_eog_06_aig_pc
# 79                            pct_ccr_eog_06_fem_pc
# 80                           pct_ccr_eog_06_male_pc
# 81                           pct_ccr_eog_06_nswd_pc
# 82                             pct_ccr_ma_06_all_pc
# 83                            pct_ccr_ma_06_nswd_pc
# 84                             pct_ccr_rd_06_all_pc
# 85                            pct_ccr_rd_06_nswd_pc
# 86                            pct_glp_eog_06_all_pc
# 87                           pct_glp_eog_06_nswd_pc
# 88                             pct_glp_ma_06_all_pc
# 89                             pct_l4_eog_06_all_pc
# 90                            pct_glp_eog_06_bl7_pc
# 91                             pct_l4_eog_06_bl7_pc
# 92                            pct_glp_eog_06_eds_pc
# 93                             pct_l4_eog_06_eds_pc
# 94                           pct_ccr_eog_06_nswd_pc
# 95                             pct_ccr_ma_06_all_pc
# 96                             pct_ccr_ma_06_fem_pc
# 97                            pct_ccr_ma_06_nswd_pc
# 98                             pct_ccr_rd_06_all_pc
# 99                             pct_ccr_rd_06_fem_pc
# 100                           pct_ccr_rd_06_nswd_pc
# 101                           pct_glp_eog_06_fem_pc
# 102                            pct_glp_ma_06_all_pc
# 103                            pct_glp_ma_06_fem_pc
# 104                           pct_glp_ma_06_nswd_pc
# 105                           pct_glp_eog_06_hi7_pc
# 106                            pct_l4_eog_06_hi7_pc
# 107                          pct_ccr_eog_06_nswd_pc
# 108                            pct_ccr_ma_06_all_pc
# 109                           pct_ccr_ma_06_male_pc
# 110                           pct_ccr_ma_06_nswd_pc
# 111                            pct_ccr_rd_06_all_pc
# 112                           pct_ccr_rd_06_male_pc
# 113                          pct_glp_eog_06_male_pc
# 114                           pct_l4_eog_06_male_pc
# 115                           pct_glp_eog_06_mu7_pc
# 116                          pct_ccr_eog_06_nswd_pc
# 117                           pct_ccr_ma_06_neds_pc
# 118                            pct_ccr_rd_06_all_pc
# 119                           pct_ccr_rd_06_neds_pc
# 120                           pct_ccr_rd_06_nswd_pc
# 121                          pct_glp_eog_06_neds_pc
# 122                            pct_glp_ma_06_all_pc
# 123                            pct_ccr_ma_06_all_pc
# 124                           pct_ccr_ma_06_nswd_pc
# 125                            pct_ccr_rd_06_all_pc
# 126                           pct_ccr_rd_06_nswd_pc
# 127                           pct_glp_eog_06_all_pc
# 128                           pct_glp_eog_06_fem_pc
# 129                          pct_glp_eog_06_nswd_pc
# 130                            pct_glp_ma_06_all_pc
# 131                           pct_glp_ma_06_nswd_pc
# 132                            pct_glp_rd_06_all_pc
# 133                            pct_l4_eog_06_all_pc
# 134                           pct_l4_eog_06_nswd_pc
# 135                           pct_glp_eog_06_wh7_pc
# 136                           pct_glp_eog_07_aig_pc
# 137                           pct_ccr_eog_07_fem_pc
# 138                          pct_ccr_eog_07_nswd_pc
# 139                            pct_ccr_ma_07_all_pc
# 140                           pct_ccr_ma_07_nswd_pc
# 141                            pct_ccr_rd_07_all_pc
# 142                           pct_ccr_rd_07_nswd_pc
# 143                           pct_glp_eog_07_all_pc
# 144                          pct_glp_eog_07_nswd_pc
# 145                            pct_glp_ma_07_all_pc
# 146                           pct_glp_eog_07_bl7_pc
# 147                            pct_l4_eog_07_bl7_pc
# 148                           pct_glp_eog_07_eds_pc
# 149                            pct_l4_eog_07_eds_pc
# 150                          pct_ccr_eog_07_nswd_pc
# 151                            pct_ccr_ma_07_all_pc
# 152                           pct_ccr_ma_07_nswd_pc
# 153                            pct_ccr_rd_07_all_pc
# 154                           pct_ccr_rd_07_nswd_pc
# 155                           pct_glp_eog_07_fem_pc
# 156                            pct_glp_ma_07_all_pc
# 157                           pct_glp_ma_07_nswd_pc
# 158                           pct_glp_eog_07_hi7_pc
# 159                            pct_l4_eog_07_hi7_pc
# 160                          pct_glp_eog_07_male_pc
# 161                           pct_glp_eog_07_mu7_pc
# 162                          pct_ccr_eog_07_nswd_pc
# 163                          pct_glp_eog_07_neds_pc
# 164                            pct_ccr_ma_07_all_pc
# 165                           pct_ccr_ma_07_nswd_pc
# 166                            pct_ccr_rd_07_all_pc
# 167                           pct_ccr_rd_07_nswd_pc
# 168                           pct_glp_eog_07_all_pc
# 169                          pct_glp_eog_07_nswd_pc
# 170                            pct_glp_ma_07_all_pc
# 171                           pct_glp_ma_07_nswd_pc
# 172                            pct_glp_rd_07_all_pc
# 173                           pct_glp_rd_07_nswd_pc
# 174                           pct_glp_eog_07_wh7_pc
# 175                           pct_glp_eog_08_aig_pc
# 176                           pct_ccr_eog_08_fem_pc
# 177                          pct_ccr_eog_08_male_pc
# 178                          pct_ccr_eog_08_neds_pc
# 179                          pct_ccr_eog_08_nswd_pc
# 180                            pct_ccr_rd_08_all_pc
# 181                           pct_ccr_rd_08_nswd_pc
# 182                           pct_glp_eog_08_all_pc
# 183                          pct_glp_eog_08_male_pc
# 184                          pct_glp_eog_08_nswd_pc
# 185                            pct_glp_ma_08_all_pc
# 186                           pct_glp_ma_08_nswd_pc
# 187                            pct_glp_rd_08_all_pc
# 188                           pct_glp_rd_08_nswd_pc
# 189                           pct_glp_eog_08_bl7_pc
# 190                            pct_l4_eog_08_bl7_pc
# 191                           pct_glp_eog_08_eds_pc
# 192                            pct_l4_eog_08_eds_pc
# 193                          pct_ccr_eog_08_nswd_pc
# 194                            pct_ccr_rd_08_all_pc
# 195                           pct_ccr_rd_08_nswd_pc
# 196                           pct_glp_eog_08_all_pc
# 197                           pct_glp_eog_08_fem_pc
# 198                          pct_glp_eog_08_nswd_pc
# 199                            pct_glp_rd_08_all_pc
# 200                           pct_glp_rd_08_nswd_pc
# 201                           pct_glp_eog_08_hi7_pc
# 202                            pct_l4_eog_08_hi7_pc
# 203                          pct_ccr_eog_08_nswd_pc
# 204                          pct_glp_eog_08_male_pc
# 205                           pct_glp_eog_08_mu7_pc
# 206                          pct_ccr_eog_08_nswd_pc
# 207                           pct_glp_eog_08_all_pc
# 208                          pct_glp_eog_08_neds_pc
# 209                          pct_glp_eog_08_nswd_pc
# 210                            pct_ccr_rd_08_all_pc
# 211                           pct_ccr_rd_08_nswd_pc
# 212                            pct_ccr_sc_08_all_pc
# 213                           pct_glp_eog_08_all_pc
# 214                           pct_glp_eog_08_fem_pc
# 215                          pct_glp_eog_08_male_pc
# 216                          pct_glp_eog_08_nswd_pc
# 217                            pct_glp_ma_08_all_pc
# 218                           pct_glp_ma_08_nswd_pc
# 219                            pct_glp_rd_08_all_pc
# 220                           pct_glp_rd_08_nswd_pc
# 221                           pct_glp_eog_08_wh7_pc
# 222                          pct_glp_eog_all_aig_pc
# 223                          pct_ccr_eog_all_fem_pc
# 224                         pct_ccr_eog_all_male_pc
# 225                         pct_ccr_eog_all_neds_pc
# 226                         pct_ccr_eog_all_nswd_pc
# 227                           pct_ccr_ma_all_all_pc
# 228                           pct_ccr_ma_all_fem_pc
# 229                          pct_ccr_ma_all_nswd_pc
# 230                           pct_ccr_rd_all_all_pc
# 231                           pct_ccr_rd_all_fem_pc
# 232                          pct_ccr_rd_all_male_pc
# 233                          pct_ccr_rd_all_nswd_pc
# 234                          pct_glp_eog_all_all_pc
# 235                         pct_glp_eog_all_male_pc
# 236                         pct_glp_eog_all_nswd_pc
# 237                           pct_glp_ma_all_all_pc
# 238                          pct_glp_ma_all_nswd_pc
# 239                           pct_glp_rd_all_all_pc
# 240                              aaa_score_all_spg2
# 241                             mags_score_all_spg2
# 242                             rdgs_score_all_spg2
# 243                          pct_glp_eog_all_as7_pc
# 244                          pct_glp_eog_all_bl7_pc
# 245                           pct_l4_all_all_bl7_pc
# 246                           pct_l4_eog_all_bl7_pc
# 247                           pct_ccr_ma_all_eds_pc
# 248                           pct_ccr_rd_all_eds_pc
# 249                          pct_glp_eog_all_eds_pc
# 250                           pct_l4_all_all_eds_pc
# 251                           pct_l4_eog_all_eds_pc
# 252                              aaa_score_eds_spg2
# 253                           pct_l4_eog_all_els_pc
# 254                         pct_ccr_eog_all_neds_pc
# 255                         pct_ccr_eog_all_nswd_pc
# 256                           pct_ccr_ma_all_all_pc
# 257                           pct_ccr_ma_all_fem_pc
# 258                          pct_ccr_ma_all_nswd_pc
# 259                           pct_ccr_rd_all_all_pc
# 260                           pct_ccr_rd_all_fem_pc
# 261                          pct_ccr_rd_all_nswd_pc
# 262                          pct_glp_eog_all_all_pc
# 263                          pct_glp_eog_all_fem_pc
# 264                           pct_glp_ma_all_all_pc
# 265                           pct_glp_ma_all_fem_pc
# 266                          pct_glp_ma_all_nswd_pc
# 267                           pct_glp_rd_all_all_pc
# 268                           pct_glp_rd_all_fem_pc
# 269                              aaa_score_all_spg2
# 270                              ach_score_all_spg2
# 271                             mags_score_all_spg2
# 272                             rdgs_score_all_spg2
# 273                          pct_glp_eog_all_hi7_pc
# 274                           pct_l4_eog_all_hi7_pc
# 275                          pct_glp_eog_all_hms_pc
# 276                           pct_l4_eog_all_hms_pc
# 277                         pct_ccr_eog_all_nswd_pc
# 278                           pct_ccr_ma_all_all_pc
# 279                          pct_ccr_ma_all_male_pc
# 280                           pct_ccr_rd_all_all_pc
# 281                          pct_ccr_rd_all_male_pc
# 282                          pct_glp_eog_all_all_pc
# 283                         pct_glp_eog_all_male_pc
# 284                          pct_glp_ma_all_male_pc
# 285                          pct_glp_rd_all_male_pc
# 286                          pct_glp_eog_all_mu7_pc
# 287                         pct_ccr_eog_all_nswd_pc
# 288                          pct_ccr_ma_all_neds_pc
# 289                          pct_ccr_rd_all_neds_pc
# 290                          pct_glp_eog_all_all_pc
# 291                         pct_glp_eog_all_neds_pc
# 292                         pct_glp_eog_all_nswd_pc
# 293                          pct_glp_ma_all_neds_pc
# 294                          pct_glp_rd_all_neds_pc
# 295                           pct_ccr_ma_all_all_pc
# 296                           pct_ccr_ma_all_fem_pc
# 297                          pct_ccr_ma_all_nswd_pc
# 298                           pct_ccr_rd_all_all_pc
# 299                           pct_ccr_rd_all_fem_pc
# 300                          pct_ccr_rd_all_nswd_pc
# 301                          pct_glp_eog_all_all_pc
# 302                         pct_glp_eog_all_male_pc
# 303                         pct_glp_eog_all_nswd_pc
# 304                           pct_glp_ma_all_all_pc
# 305                          pct_glp_ma_all_nswd_pc
# 306                           pct_glp_rd_all_all_pc
# 307                          pct_glp_rd_all_nswd_pc
# 308                              aaa_score_all_spg2
# 309                              ach_score_all_spg2
# 310                             mags_score_all_spg2
# 311                             rdgs_score_all_spg2
# 312                           pct_l4_eog_all_swd_pc
# 313                           pct_ccr_rd_all_wh7_pc
# 314                          pct_glp_eog_all_wh7_pc
# 315                            pct_ccr_rd_06_aig_pc
# 316                            pct_glp_ma_06_aig_pc
# 317                            pct_glp_rd_06_aig_pc
# 318                            pct_ccr_ma_06_fem_pc
# 319                           pct_ccr_ma_06_male_pc
# 320                           pct_ccr_ma_06_nswd_pc
# 321                            pct_glp_ma_06_all_pc
# 322                           pct_glp_ma_06_nswd_pc
# 323                             pct_l4_ma_06_bl7_pc
# 324                             pct_l4_ma_06_eds_pc
# 325                           pct_ccr_ma_06_nswd_pc
# 326                            pct_glp_ma_06_fem_pc
# 327                            pct_glp_ma_06_hi7_pc
# 328                             pct_l4_ma_06_hi7_pc
# 329                           pct_ccr_ma_06_nswd_pc
# 330                           pct_glp_ma_06_male_pc
# 331                           pct_glp_ma_06_neds_pc
# 332                            pct_glp_ma_06_all_pc
# 333                           pct_glp_ma_06_nswd_pc
# 334                            pct_glp_ma_06_wh7_pc
# 335                            pct_ccr_rd_07_aig_pc
# 336                            pct_glp_ma_07_aig_pc
# 337                            pct_glp_rd_07_aig_pc
# 338                           pct_ccr_ma_07_nswd_pc
# 339                            pct_glp_ma_07_all_pc
# 340                           pct_glp_ma_07_nswd_pc
# 341                             pct_l4_ma_07_bl7_pc
# 342                            pct_glp_ma_07_eds_pc
# 343                             pct_l4_ma_07_eds_pc
# 344                            pct_glp_ma_07_fem_pc
# 345                            pct_glp_ma_07_hi7_pc
# 346                             pct_l4_ma_07_hi7_pc
# 347                           pct_glp_ma_07_male_pc
# 348                           pct_glp_ma_07_neds_pc
# 349                            pct_glp_ma_07_all_pc
# 350                           pct_glp_ma_07_nswd_pc
# 351                            pct_glp_ma_07_wh7_pc
# 352                            pct_ccr_rd_08_aig_pc
# 353                            pct_glp_ma_08_aig_pc
# 354                            pct_ccr_ma_08_fem_pc
# 355                           pct_ccr_ma_08_nswd_pc
# 356                             pct_l4_ma_08_bl7_pc
# 357                           pct_ccr_ma_08_nswd_pc
# 358                            pct_glp_ma_08_all_pc
# 359                           pct_ccr_rd_all_aig_pc
# 360                           pct_glp_ma_all_aig_pc
# 361                           pct_glp_rd_all_aig_pc
# 362                           pct_ccr_ma_all_fem_pc
# 363                          pct_ccr_ma_all_male_pc
# 364                          pct_ccr_ma_all_neds_pc
# 365                          pct_ccr_ma_all_nswd_pc
# 366                           pct_glp_ma_all_all_pc
# 367                          pct_glp_ma_all_nswd_pc
# 368                             mags_score_all_spg2
# 369                            pct_l4_ma_all_bl7_pc
# 370                           pct_glp_ma_all_eds_pc
# 371                            pct_l4_ma_all_eds_pc
# 372                            pct_l4_ma_all_els_pc
# 373                          pct_ccr_ma_all_neds_pc
# 374                          pct_ccr_ma_all_nswd_pc
# 375                           pct_glp_ma_all_all_pc
# 376                           pct_glp_ma_all_fem_pc
# 377                          pct_glp_ma_all_nswd_pc
# 378                             mags_score_all_spg2
# 379                          pct_ccr_ma_all_nswd_pc
# 380                          pct_glp_ma_all_male_pc
# 381                          pct_ccr_ma_all_nswd_pc
# 382                           pct_glp_ma_all_all_pc
# 383                          pct_glp_ma_all_neds_pc
# 384                          pct_glp_ma_all_nswd_pc
# 385                             mags_score_all_spg2
# 386                           pct_glp_ma_all_all_pc
# 387                           pct_glp_ma_all_fem_pc
# 388                          pct_glp_ma_all_nswd_pc
# 389                             mags_score_all_spg2
# 390                            pct_l4_ma_all_swd_pc
# 391                           pct_glp_ma_all_wh7_pc
# 392                            pct_glp_ma_06_aig_pc
# 393                            pct_glp_rd_06_aig_pc
# 394                            pct_ccr_rd_06_fem_pc
# 395                           pct_ccr_rd_06_nswd_pc
# 396                           pct_glp_eog_06_all_pc
# 397                          pct_glp_eog_06_male_pc
# 398                          pct_glp_eog_06_nswd_pc
# 399                            pct_glp_ma_06_all_pc
# 400                            pct_glp_rd_06_all_pc
# 401                           pct_glp_rd_06_nswd_pc
# 402                             pct_l4_rd_06_all_pc
# 403                            pct_glp_rd_06_bl7_pc
# 404                             pct_l4_rd_06_bl7_pc
# 405                            pct_glp_rd_06_eds_pc
# 406                             pct_l4_rd_06_eds_pc
# 407                           pct_ccr_rd_06_nswd_pc
# 408                           pct_glp_eog_06_fem_pc
# 409                            pct_glp_rd_06_fem_pc
# 410                            pct_glp_rd_06_hi7_pc
# 411                             pct_l4_rd_06_hi7_pc
# 412                           pct_glp_rd_06_male_pc
# 413                            pct_l4_rd_06_male_pc
# 414                           pct_glp_ma_06_neds_pc
# 415                           pct_glp_rd_06_neds_pc
# 416                           pct_glp_eog_06_all_pc
# 417                           pct_glp_eog_06_fem_pc
# 418                          pct_glp_eog_06_male_pc
# 419                          pct_glp_eog_06_nswd_pc
# 420                            pct_glp_ma_06_all_pc
# 421                           pct_glp_ma_06_nswd_pc
# 422                            pct_glp_rd_06_all_pc
# 423                            pct_glp_rd_06_fem_pc
# 424                           pct_glp_rd_06_nswd_pc
# 425                            pct_l4_rd_06_nswd_pc
# 426                            pct_glp_ma_06_wh7_pc
# 427                            pct_glp_rd_06_wh7_pc
# 428                            pct_glp_ma_07_aig_pc
# 429                            pct_glp_rd_07_aig_pc
# 430                           pct_ccr_rd_07_nswd_pc
# 431                          pct_glp_eog_07_nswd_pc
# 432                            pct_glp_rd_07_all_pc
# 433                           pct_glp_rd_07_nswd_pc
# 434                             pct_l4_rd_07_all_pc
# 435                            pct_glp_rd_07_bl7_pc
# 436                             pct_l4_rd_07_bl7_pc
# 437                            pct_glp_rd_07_eds_pc
# 438                             pct_l4_rd_07_eds_pc
# 439                            pct_glp_rd_07_fem_pc
# 440                             pct_l4_rd_07_fem_pc
# 441                            pct_glp_rd_07_hi7_pc
# 442                             pct_l4_rd_07_hi7_pc
# 443                           pct_glp_rd_07_male_pc
# 444                            pct_l4_rd_07_male_pc
# 445                           pct_glp_ma_07_neds_pc
# 446                           pct_glp_rd_07_neds_pc
# 447                            pct_l4_rd_07_neds_pc
# 448                          pct_glp_eog_07_nswd_pc
# 449                            pct_glp_rd_07_all_pc
# 450                           pct_glp_rd_07_nswd_pc
# 451                             pct_l4_rd_07_all_pc
# 452                            pct_l4_rd_07_nswd_pc
# 453                            pct_glp_ma_07_wh7_pc
# 454                            pct_glp_rd_07_wh7_pc
# 455                            pct_ccr_sc_08_aig_pc
# 456                            pct_glp_ma_08_aig_pc
# 457                            pct_glp_rd_08_aig_pc
# 458                            pct_glp_sc_08_aig_pc
# 459                             pct_l5_sc_08_aig_pc
# 460                           pct_ccr_rd_08_nswd_pc
# 461                            pct_glp_rd_08_all_pc
# 462                           pct_glp_rd_08_nswd_pc
# 463                             pct_l4_rd_08_all_pc
# 464                            pct_glp_rd_08_bl7_pc
# 465                             pct_l4_rd_08_bl7_pc
# 466                            pct_glp_rd_08_eds_pc
# 467                             pct_l4_rd_08_eds_pc
# 468                            pct_glp_rd_08_fem_pc
# 469                             pct_l4_rd_08_fem_pc
# 470                            pct_glp_rd_08_hi7_pc
# 471                             pct_l4_rd_08_hi7_pc
# 472                           pct_glp_rd_08_male_pc
# 473                            pct_l4_rd_08_male_pc
# 474                           pct_glp_rd_08_neds_pc
# 475                            pct_l4_rd_08_neds_pc
# 476                            pct_glp_rd_08_all_pc
# 477                           pct_glp_rd_08_nswd_pc
# 478                             pct_l4_rd_08_all_pc
# 479                            pct_l4_rd_08_nswd_pc
# 480                            pct_glp_rd_08_wh7_pc
# 481                             pct_l4_rd_08_wh7_pc
# 482                           pct_glp_ma_all_aig_pc
# 483                           pct_glp_rd_all_aig_pc
# 484                           pct_ccr_rd_all_fem_pc
# 485                          pct_ccr_rd_all_male_pc
# 486                          pct_ccr_rd_all_neds_pc
# 487                          pct_ccr_rd_all_nswd_pc
# 488                          pct_glp_eog_all_all_pc
# 489                           pct_glp_rd_all_all_pc
# 490                          pct_glp_rd_all_male_pc
# 491                          pct_glp_rd_all_nswd_pc
# 492                            pct_l4_rd_all_all_pc
# 493                             rdgs_score_all_spg2
# 494                           pct_glp_rd_all_bl7_pc
# 495                            pct_l4_rd_all_bl7_pc
# 496                          pct_glp_eog_all_eds_pc
# 497                           pct_glp_rd_all_eds_pc
# 498                            pct_l4_rd_all_eds_pc
# 499                          pct_ccr_rd_all_nswd_pc
# 500                          pct_glp_eog_all_fem_pc
# 501                           pct_glp_rd_all_all_pc
# 502                           pct_glp_rd_all_fem_pc
# 503                          pct_glp_rd_all_nswd_pc
# 504                            pct_l4_rd_all_fem_pc
# 505                              aaa_score_all_spg2
# 506                             rdgs_score_all_spg2
# 507                           pct_glp_rd_all_hi7_pc
# 508                            pct_l4_rd_all_hi7_pc
# 509                          pct_ccr_rd_all_nswd_pc
# 510                         pct_glp_eog_all_male_pc
# 511                           pct_glp_rd_all_all_pc
# 512                          pct_glp_rd_all_male_pc
# 513                           pct_l4_rd_all_male_pc
# 514                           pct_glp_rd_all_mu7_pc
# 515                          pct_ccr_rd_all_nswd_pc
# 516                         pct_glp_eog_all_neds_pc
# 517                          pct_glp_ma_all_neds_pc
# 518                           pct_glp_rd_all_all_pc
# 519                          pct_glp_rd_all_neds_pc
# 520                           pct_l4_rd_all_neds_pc
# 521                             rdgs_score_all_spg2
# 522                          pct_glp_eog_all_all_pc
# 523                         pct_glp_eog_all_nswd_pc
# 524                          pct_glp_ma_all_nswd_pc
# 525                           pct_glp_rd_all_all_pc
# 526                          pct_glp_rd_all_male_pc
# 527                          pct_glp_rd_all_nswd_pc
# 528                            pct_l4_rd_all_all_pc
# 529                           pct_l4_rd_all_nswd_pc
# 530                              aaa_score_all_spg2
# 531                              ach_score_all_spg2
# 532                           rd_spg_score_all_spg2
# 533                             rdgs_score_all_spg2
# 534                           pct_glp_ma_all_wh7_pc
# 535                           pct_glp_rd_all_wh7_pc
# 536                              aaa_score_wh7_spg2
# 537                            pct_glp_ma_08_aig_pc
# 538                            pct_glp_rd_08_aig_pc
# 539                            pct_glp_sc_08_aig_pc
# 540                             pct_l4_rd_08_aig_pc
# 541                           pct_ccr_sc_08_nswd_pc
# 542                           pct_glp_eog_08_all_pc
# 543                           pct_glp_eog_08_fem_pc
# 544                          pct_glp_eog_08_male_pc
# 545                          pct_glp_eog_08_nswd_pc
# 546                            pct_glp_sc_08_all_pc
# 547                           pct_glp_sc_08_nswd_pc
# 548                           pct_ccr_sc_all_bl7_pc
# 549                            pct_glp_sc_08_bl7_pc
# 550                             pct_l4_sc_08_bl7_pc
# 551                            pct_glp_sc_08_eds_pc
# 552                            pct_glp_rd_08_fem_pc
# 553                            pct_glp_sc_08_fem_pc
# 554                            pct_glp_rd_08_hi7_pc
# 555                            pct_glp_sc_08_hi7_pc
# 556                           pct_glp_sc_08_male_pc
# 557                           pct_glp_rd_08_neds_pc
# 558                           pct_glp_sc_08_neds_pc
# 559                           pct_glp_eog_08_fem_pc
# 560                          pct_glp_eog_08_nswd_pc
# 561                           pct_glp_rd_08_nswd_pc
# 562                            pct_glp_sc_08_all_pc
# 563                           pct_glp_sc_08_nswd_pc
# 564                            pct_glp_sc_08_swd_pc
# 565                             pct_l4_sc_08_swd_pc
# 566                            pct_glp_rd_08_wh7_pc
# 567                            pct_glp_sc_08_wh7_pc
# 568                           pct_glp_sc_all_aig_pc
# 569                           pct_ccr_sc_all_fem_pc
# 570                          pct_ccr_sc_all_male_pc
# 571                          pct_ccr_sc_all_nswd_pc
# 572                           pct_glp_sc_all_all_pc
# 573                          pct_glp_sc_all_nswd_pc
# 574                           pct_glp_sc_all_bl7_pc
# 575                            pct_l4_sc_all_bl7_pc
# 576                           pct_glp_sc_all_eds_pc
# 577                          pct_ccr_sc_all_nswd_pc
# 578                           pct_glp_sc_all_fem_pc
# 579                           pct_glp_sc_all_hi7_pc
# 580                          pct_ccr_sc_all_nswd_pc
# 581                          pct_glp_sc_all_male_pc
# 582                          pct_glp_sc_all_neds_pc
# 583                           pct_glp_sc_all_all_pc
# 584                           pct_glp_sc_all_fem_pc
# 585                          pct_glp_sc_all_nswd_pc
# 586                             scgs_score_all_spg2
# 587                           pct_glp_sc_all_swd_pc
# 588                            pct_l4_sc_all_swd_pc
# 589                           pct_glp_sc_all_wh7_pc
# 590                           pct_glp_eog_06_fem_pc
# 591                          pct_glp_eog_06_male_pc
# 592                          pct_glp_eog_06_nswd_pc
# 593                            pct_glp_ma_06_all_pc
# 594                           pct_glp_ma_06_nswd_pc
# 595                            pct_glp_rd_06_all_pc
# 596                           pct_glp_rd_06_nswd_pc
# 597                            pct_l4_eog_06_all_pc
# 598                           pct_l4_eog_06_nswd_pc
# 599                            pct_l4_eog_06_bl7_pc
# 600                            pct_l4_eog_06_eds_pc
# 601                          pct_glp_eog_06_neds_pc
# 602                          pct_glp_eog_06_nswd_pc
# 603                            pct_glp_ma_06_all_pc
# 604                            pct_glp_ma_06_fem_pc
# 605                           pct_glp_ma_06_nswd_pc
# 606                            pct_glp_rd_06_all_pc
# 607                            pct_glp_rd_06_fem_pc
# 608                           pct_glp_rd_06_nswd_pc
# 609                            pct_l4_eog_06_fem_pc
# 610                            pct_l4_eog_06_hi7_pc
# 611                          pct_glp_eog_06_nswd_pc
# 612                            pct_glp_ma_06_all_pc
# 613                           pct_glp_ma_06_male_pc
# 614                           pct_glp_ma_06_nswd_pc
# 615                            pct_glp_rd_06_all_pc
# 616                           pct_glp_rd_06_male_pc
# 617                           pct_glp_rd_06_nswd_pc
# 618                           pct_l4_eog_06_male_pc
# 619                          pct_glp_eog_06_nswd_pc
# 620                            pct_glp_ma_06_all_pc
# 621                           pct_glp_ma_06_neds_pc
# 622                           pct_glp_ma_06_nswd_pc
# 623                            pct_glp_rd_06_all_pc
# 624                           pct_glp_rd_06_nswd_pc
# 625                           pct_l4_eog_06_neds_pc
# 626                            pct_glp_ma_06_all_pc
# 627                           pct_glp_ma_06_nswd_pc
# 628                            pct_glp_rd_06_all_pc
# 629                           pct_glp_rd_06_nswd_pc
# 630                            pct_l4_eog_06_all_pc
# 631                           pct_l4_eog_06_nswd_pc
# 632                            pct_l4_eog_06_wh7_pc
# 633                          pct_glp_eog_07_nswd_pc
# 634                            pct_glp_ma_07_all_pc
# 635                            pct_glp_rd_07_all_pc
# 636                            pct_l4_eog_07_all_pc
# 637                            pct_l4_eog_07_bl7_pc
# 638                          pct_glp_eog_07_nswd_pc
# 639                            pct_glp_ma_07_all_pc
# 640                           pct_glp_ma_07_nswd_pc
# 641                            pct_glp_rd_07_all_pc
# 642                           pct_glp_rd_07_nswd_pc
# 643                            pct_l4_eog_07_fem_pc
# 644                           pct_l4_eog_07_male_pc
# 645                          pct_glp_eog_07_nswd_pc
# 646                           pct_glp_ma_07_nswd_pc
# 647                           pct_glp_rd_07_nswd_pc
# 648                           pct_l4_eog_07_neds_pc
# 649                            pct_glp_ma_07_all_pc
# 650                           pct_glp_ma_07_nswd_pc
# 651                            pct_glp_rd_07_all_pc
# 652                           pct_glp_rd_07_nswd_pc
# 653                            pct_l4_eog_07_all_pc
# 654                           pct_l4_eog_07_nswd_pc
# 655                            pct_l4_eog_07_wh7_pc
# 656                           pct_glp_eog_08_fem_pc
# 657                          pct_glp_eog_08_male_pc
# 658                          pct_glp_eog_08_neds_pc
# 659                          pct_glp_eog_08_nswd_pc
# 660                            pct_glp_rd_08_all_pc
# 661                           pct_glp_rd_08_nswd_pc
# 662                            pct_l4_eog_08_all_pc
# 663                            pct_l4_eog_08_bl7_pc
# 664                            pct_l4_eog_08_eds_pc
# 665                          pct_glp_eog_08_nswd_pc
# 666                            pct_glp_rd_08_all_pc
# 667                           pct_glp_rd_08_nswd_pc
# 668                            pct_glp_sc_08_all_pc
# 669                            pct_l4_eog_08_fem_pc
# 670                            pct_l4_eog_08_hi7_pc
# 671                          pct_glp_eog_08_nswd_pc
# 672                            pct_glp_rd_08_all_pc
# 673                           pct_l4_eog_08_male_pc
# 674                          pct_glp_eog_08_nswd_pc
# 675                           pct_glp_ma_08_nswd_pc
# 676                            pct_glp_rd_08_all_pc
# 677                           pct_glp_rd_08_nswd_pc
# 678                            pct_glp_sc_08_all_pc
# 679                           pct_glp_sc_08_nswd_pc
# 680                            pct_l4_eog_08_all_pc
# 681                           pct_l4_eog_08_nswd_pc
# 682                          pct_glp_eog_all_fem_pc
# 683                         pct_glp_eog_all_male_pc
# 684                         pct_glp_eog_all_neds_pc
# 685                         pct_glp_eog_all_nswd_pc
# 686                           pct_glp_ma_all_all_pc
# 687                          pct_glp_ma_all_male_pc
# 688                          pct_glp_ma_all_neds_pc
# 689                          pct_glp_ma_all_nswd_pc
# 690                           pct_glp_rd_all_all_pc
# 691                          pct_glp_rd_all_male_pc
# 692                          pct_glp_rd_all_nswd_pc
# 693                           pct_l4_eog_all_all_pc
# 694                            pct_l4_rd_all_all_pc
# 695                              aaa_score_all_spg2
# 696                              ach_score_all_spg2
# 697                             mags_score_all_spg2
# 698                             rdgs_score_all_spg2
# 699                           pct_l4_all_all_bl7_pc
# 700                           pct_l4_eog_all_bl7_pc
# 701                           pct_glp_ma_all_eds_pc
# 702                           pct_glp_rd_all_eds_pc
# 703                           pct_l4_all_all_eds_pc
# 704                           pct_l4_eog_all_eds_pc
# 705                              aaa_score_eds_spg2
# 706                           pct_glp_ma_all_all_pc
# 707                           pct_glp_ma_all_fem_pc
# 708                          pct_glp_ma_all_nswd_pc
# 709                           pct_glp_rd_all_all_pc
# 710                           pct_glp_rd_all_fem_pc
# 711                           pct_l4_eog_all_fem_pc
# 712                           pct_l4_eog_all_hi7_pc
# 713                         pct_glp_eog_all_nswd_pc
# 714                           pct_glp_ma_all_all_pc
# 715                          pct_glp_ma_all_male_pc
# 716                           pct_glp_rd_all_all_pc
# 717                          pct_glp_rd_all_male_pc
# 718                          pct_l4_all_all_male_pc
# 719                          pct_l4_eog_all_male_pc
# 720                           pct_l4_rd_all_male_pc
# 721                         pct_glp_eog_all_nswd_pc
# 722                          pct_glp_ma_all_neds_pc
# 723                           pct_glp_rd_all_all_pc
# 724                          pct_glp_rd_all_neds_pc
# 725                          pct_l4_eog_all_neds_pc
# 726                          pct_glp_ma_all_nswd_pc
# 727                           pct_glp_rd_all_all_pc
# 728                          pct_glp_rd_all_nswd_pc
# 729                          pct_l4_all_all_nswd_pc
# 730                           pct_l4_eog_all_all_pc
# 731                          pct_l4_eog_all_nswd_pc
# 732                            pct_l4_rd_all_all_pc
# 733                           pct_l4_rd_all_nswd_pc
# 734                              aaa_score_all_spg2
# 735                              ach_score_all_spg2
# 736                           ma_spg_score_all_spg2
# 737                             mags_score_all_spg2
# 738                           rd_spg_score_all_spg2
# 739                             rdgs_score_all_spg2
# 740                              spg_score_all_spg2
# 741                           pct_l4_eog_all_wh7_pc
# 742                            pct_glp_rd_06_aig_pc
# 743                            pct_glp_ma_06_fem_pc
# 744                           pct_glp_ma_06_male_pc
# 745                           pct_glp_ma_06_nswd_pc
# 746                            pct_glp_rd_06_all_pc
# 747                           pct_glp_rd_06_nswd_pc
# 748                             pct_l4_ma_06_all_pc
# 749                            pct_l4_ma_06_nswd_pc
# 750                           pct_glp_ma_06_nswd_pc
# 751                            pct_glp_rd_06_fem_pc
# 752                           pct_glp_ma_06_nswd_pc
# 753                           pct_glp_rd_06_male_pc
# 754                           pct_glp_rd_06_neds_pc
# 755                           pct_glp_rd_06_nswd_pc
# 756                             pct_l4_ma_06_all_pc
# 757                            pct_l4_ma_06_nswd_pc
# 758                            pct_glp_rd_06_wh7_pc
# 759                             pct_l4_ma_06_wh7_pc
# 760                            pct_glp_rd_07_aig_pc
# 761                           pct_glp_ma_07_nswd_pc
# 762                           pct_glp_rd_07_neds_pc
# 763                            pct_glp_rd_07_wh7_pc
# 764                            pct_glp_rd_08_aig_pc
# 765                            pct_glp_sc_08_aig_pc
# 766                           pct_glp_ma_08_nswd_pc
# 767                           pct_glp_rd_all_aig_pc
# 768                           pct_glp_ma_all_fem_pc
# 769                          pct_glp_ma_all_male_pc
# 770                          pct_glp_ma_all_neds_pc
# 771                          pct_glp_ma_all_nswd_pc
# 772                           pct_glp_rd_all_all_pc
# 773                            pct_l4_ma_all_all_pc
# 774                              aaa_score_all_spg2
# 775                              ach_score_all_spg2
# 776                           ma_spg_score_all_spg2
# 777                             mags_score_all_spg2
# 778                            pct_l4_ma_all_eds_pc
# 779                              aaa_score_eds_spg2
# 780                          pct_glp_ma_all_neds_pc
# 781                          pct_glp_ma_all_nswd_pc
# 782                            pct_l4_ma_all_fem_pc
# 783                              aaa_score_all_spg2
# 784                           ma_spg_score_all_spg2
# 785                             mags_score_all_spg2
# 786                          pct_glp_ma_all_neds_pc
# 787                          pct_glp_ma_all_nswd_pc
# 788                          pct_glp_rd_all_male_pc
# 789                             mags_score_all_spg2
# 790                          pct_glp_ma_all_nswd_pc
# 791                          pct_glp_rd_all_neds_pc
# 792                              aaa_score_all_spg2
# 793                           ma_spg_score_all_spg2
# 794                             mags_score_all_spg2
# 795                          pct_glp_rd_all_nswd_pc
# 796                            pct_l4_ma_all_all_pc
# 797                           pct_l4_ma_all_nswd_pc
# 798                              aaa_score_all_spg2
# 799                              ach_score_all_spg2
# 800                           ma_spg_score_all_spg2
# 801                             mags_score_all_spg2
# 802                             rdgs_score_all_spg2
# 803                              spg_score_all_spg2
# 804                           pct_glp_rd_all_wh7_pc
# 805                              aaa_score_wh7_spg2
# 806                              ach_score_wh7_spg2
# 807                            pct_glp_rd_06_fem_pc
# 808                           pct_glp_rd_06_male_pc
# 809                           pct_glp_rd_06_nswd_pc
# 810                             pct_l4_rd_06_all_pc
# 811                            pct_l4_rd_06_nswd_pc
# 812                             pct_l4_rd_06_bl7_pc
# 813                             pct_l4_rd_06_eds_pc
# 814                           pct_glp_rd_06_nswd_pc
# 815                             pct_l4_rd_06_fem_pc
# 816                             pct_l4_rd_06_hi7_pc
# 817                           pct_glp_rd_06_nswd_pc
# 818                            pct_l4_rd_06_male_pc
# 819                             pct_l4_rd_06_all_pc
# 820                            pct_l4_rd_06_nswd_pc
# 821                             pct_l4_rd_06_wh7_pc
# 822                           pct_glp_rd_07_nswd_pc
# 823                             pct_l4_rd_07_all_pc
# 824                            pct_l4_rd_07_nswd_pc
# 825                             pct_l4_rd_07_bl7_pc
# 826                             pct_l4_rd_07_eds_pc
# 827                             pct_l4_rd_07_fem_pc
# 828                             pct_l4_rd_07_hi7_pc
# 829                            pct_l4_rd_07_male_pc
# 830                            pct_l4_rd_07_neds_pc
# 831                             pct_l4_rd_07_all_pc
# 832                            pct_l4_rd_07_nswd_pc
# 833                             pct_l4_rd_07_wh7_pc
# 834                            pct_glp_sc_08_aig_pc
# 835                             pct_l4_rd_08_aig_pc
# 836                           pct_glp_rd_08_nswd_pc
# 837                             pct_l4_rd_08_all_pc
# 838                            pct_l4_rd_08_nswd_pc
# 839                             pct_l4_rd_08_eds_pc
# 840                             pct_l4_rd_08_fem_pc
# 841                            pct_l4_rd_08_male_pc
# 842                            pct_l4_rd_08_neds_pc
# 843                             pct_l4_rd_08_all_pc
# 844                            pct_l4_rd_08_nswd_pc
# 845                             pct_l4_rd_08_wh7_pc
# 846                           pct_glp_rd_all_fem_pc
# 847                          pct_glp_rd_all_male_pc
# 848                          pct_glp_rd_all_neds_pc
# 849                          pct_glp_rd_all_nswd_pc
# 850                            pct_l4_rd_all_all_pc
# 851                           pct_l4_rd_all_male_pc
# 852                           pct_l4_rd_all_nswd_pc
# 853                              aaa_score_all_spg2
# 854                           rd_spg_score_all_spg2
# 855                             rdgs_score_all_spg2
# 856                            pct_l4_rd_all_bl7_pc
# 857                            pct_l4_rd_all_eds_pc
# 858                          pct_glp_rd_all_nswd_pc
# 859                            pct_l4_rd_all_all_pc
# 860                            pct_l4_rd_all_fem_pc
# 861                           rd_spg_score_all_spg2
# 862                             rdgs_score_all_spg2
# 863                            pct_l4_rd_all_hi7_pc
# 864                          pct_glp_rd_all_nswd_pc
# 865                            pct_l4_rd_all_all_pc
# 866                           pct_l4_rd_all_male_pc
# 867                             rdgs_score_all_spg2
# 868                          pct_glp_rd_all_nswd_pc
# 869                           pct_l4_rd_all_neds_pc
# ...
# 1275                     lea_code_loc_070LEA     1.000000
# 1276                     lea_code_loc_070LEA     1.000000
# 1277                     lea_code_loc_080LEA     1.000000
# 1278                     lea_code_loc_080LEA     1.000000
# 1279                     lea_code_loc_090LEA     1.000000
# 1280                     lea_code_loc_090LEA     1.000000
# 1281                     lea_code_loc_100LEA     1.000000
# 1282                     lea_code_loc_100LEA     1.000000
# 1283                     lea_code_loc_110LEA     1.000000
# 1284                     lea_code_loc_111LEA     1.000000
# 1285                     lea_code_loc_120LEA     1.000000
# 1286                     lea_code_loc_120LEA     1.000000
# 1287                     lea_code_loc_130LEA     1.000000
# 1288                     lea_code_loc_132LEA     1.000000
# 1289                     lea_code_loc_140LEA     1.000000
# 1290                     lea_code_loc_140LEA     1.000000
# 1291                     lea_code_loc_150LEA     1.000000
# 1292                     lea_code_loc_150LEA     1.000000
# 1293                     lea_code_loc_160LEA     1.000000
# 1294                     lea_code_loc_160LEA     1.000000
# 1295                     lea_code_loc_170LEA     1.000000
# 1296                     lea_code_loc_170LEA     1.000000
# 1297                     lea_code_loc_180LEA     1.000000
# 1298                     lea_code_loc_181LEA     1.000000
# 1299                     lea_code_loc_182LEA     1.000000
# 1300                     lea_code_loc_190LEA     1.000000
# 1301                     lea_code_loc_200LEA     1.000000
# 1302                     lea_code_loc_200LEA     1.000000
# 1303                     lea_code_loc_210LEA     1.000000
# 1304                     lea_code_loc_210LEA     1.000000
# 1305                     lea_code_loc_220LEA     1.000000
# 1306                     lea_code_loc_220LEA     1.000000
# 1307                     lea_code_loc_230LEA     1.000000
# 1308                     lea_code_loc_230LEA     1.000000
# 1309                     lea_code_loc_240LEA     1.000000
# 1310                     lea_code_loc_241LEA     1.000000
# 1311                     lea_code_loc_250LEA     1.000000
# 1312                     lea_code_loc_250LEA     1.000000
# 1313                     lea_code_loc_260LEA     1.000000
# 1314                     lea_code_loc_270LEA     1.000000
# 1315                     lea_code_loc_270LEA     1.000000
# 1316                     lea_code_loc_280LEA     1.000000
# 1317                     lea_code_loc_280LEA     1.000000
# 1318                     lea_code_loc_290LEA     1.000000
# 1319                     lea_code_loc_291LEA     1.000000
# 1320                     lea_code_loc_292LEA     1.000000
# 1321                     lea_code_loc_299LEA     1.000000
# 1322                     lea_code_loc_300LEA     1.000000
# 1323                     lea_code_loc_300LEA     1.000000
# 1324                     lea_code_loc_310LEA     1.000000
# 1325                     lea_code_loc_310LEA     1.000000
# 1326                     lea_code_loc_320LEA     1.000000
# 1327                     lea_code_loc_320LEA     0.965378
# 1328                     lea_code_loc_330LEA     1.000000
# 1329                     lea_code_loc_330LEA     1.000000
# 1330                     lea_code_loc_340LEA     1.000000
# 1331                     lea_code_loc_340LEA     1.000000
# 1332                     lea_code_loc_350LEA     1.000000
# 1333                     lea_code_loc_350LEA     1.000000
# 1334                     lea_code_loc_360LEA     1.000000
# 1335                     lea_code_loc_360LEA     1.000000
# 1336                     lea_code_loc_370LEA     1.000000
# 1337                     lea_code_loc_370LEA     1.000000
# 1338                     lea_code_loc_380LEA     1.000000
# 1339                     lea_code_loc_380LEA     1.000000
# 1340                     lea_code_loc_390LEA     1.000000
# 1341                     lea_code_loc_390LEA     1.000000
# 1342                     lea_code_loc_400LEA     1.000000
# 1343                     lea_code_loc_400LEA     1.000000
# 1344                     lea_code_loc_410LEA     1.000000
# 1345                     lea_code_loc_410LEA     1.000000
# 1346                     lea_code_loc_420LEA     1.000000
# 1347                     lea_code_loc_421LEA     1.000000
# 1348                     lea_code_loc_422LEA     1.000000
# 1349                     lea_code_loc_430LEA     1.000000
# 1350                     lea_code_loc_430LEA     1.000000
# 1351                     lea_code_loc_440LEA     1.000000
# 1352                     lea_code_loc_440LEA     1.000000
# 1353                     lea_code_loc_450LEA     1.000000
# 1354                     lea_code_loc_450LEA     1.000000
# 1355                     lea_code_loc_460LEA     1.000000
# 1356                     lea_code_loc_460LEA     1.000000
# 1357                     lea_code_loc_470LEA     1.000000
# 1358                     lea_code_loc_470LEA     1.000000
# 1359                     lea_code_loc_480LEA     1.000000
# 1360                     lea_code_loc_480LEA     1.000000
# 1361                     lea_code_loc_490LEA     1.000000
# 1362                     lea_code_loc_500LEA     1.000000
# 1363                     lea_code_loc_500LEA     1.000000
# 1364                     lea_code_loc_510LEA     1.000000
# 1365                     lea_code_loc_510LEA     1.000000
# 1366                     lea_code_loc_520LEA     1.000000
# 1367                     lea_code_loc_520LEA     1.000000
# 1368                     lea_code_loc_530LEA     1.000000
# 1369                     lea_code_loc_530LEA     1.000000
# 1370                     lea_code_loc_540LEA     1.000000
# 1371                     lea_code_loc_550LEA     1.000000
# 1372                     lea_code_loc_560LEA     1.000000
# 1373                     lea_code_loc_560LEA     1.000000
# 1374                     lea_code_loc_570LEA     1.000000
# 1375                     lea_code_loc_570LEA     1.000000
# 1376                     lea_code_loc_580LEA     1.000000
# 1377                     lea_code_loc_580LEA     1.000000
# 1378                     lea_code_loc_590LEA     1.000000
# 1379                     lea_code_loc_590LEA     1.000000
# 1380                     lea_code_loc_600LEA     1.000000
# 1381                     lea_code_loc_600LEA     1.000000
# 1382                     lea_code_loc_610LEA     1.000000
# 1383                     lea_code_loc_610LEA     1.000000
# 1384                     lea_code_loc_620LEA     1.000000
# 1385                     lea_code_loc_630LEA     1.000000
# 1386                     lea_code_loc_630LEA     1.000000
# 1387                     lea_code_loc_640LEA     1.000000
# 1388                     lea_code_loc_650LEA     0.956723
# 1389                     lea_code_loc_650LEA     1.000000
# 1390                     lea_code_loc_660LEA     1.000000
# 1391                     lea_code_loc_660LEA     1.000000
# 1392                     lea_code_loc_670LEA     1.000000
# 1393                     lea_code_loc_670LEA     1.000000
# 1394                     lea_code_loc_680LEA     1.000000
# 1395                     lea_code_loc_681LEA     1.000000
# 1396                     lea_code_loc_690LEA     1.000000
# 1397                     lea_code_loc_690LEA     1.000000
# 1398                     lea_code_loc_700LEA     1.000000
# 1399                     lea_code_loc_700LEA     1.000000
# 1400                     lea_code_loc_710LEA     1.000000
# 1401                     lea_code_loc_710LEA     1.000000
# 1402                     lea_code_loc_720LEA     1.000000
# 1403                     lea_code_loc_720LEA     1.000000
# 1404                     lea_code_loc_730LEA     1.000000
# 1405                     lea_code_loc_730LEA     1.000000
# 1406                     lea_code_loc_740LEA     0.965378
# 1407                     lea_code_loc_740LEA     1.000000
# 1408                     lea_code_loc_750LEA     1.000000
# 1409                     lea_code_loc_750LEA     1.000000
# 1410                     lea_code_loc_760LEA     1.000000
# 1411                     lea_code_loc_761LEA     1.000000
# 1412                     lea_code_loc_770LEA     1.000000
# 1413                     lea_code_loc_770LEA     1.000000
# 1414                     lea_code_loc_780LEA     1.000000
# 1415                     lea_code_loc_780LEA     0.962913
# 1416                     lea_code_loc_790LEA     1.000000
# 1417                     lea_code_loc_790LEA     1.000000
# 1418                     lea_code_loc_800LEA     1.000000
# 1419                     lea_code_loc_800LEA     1.000000
# 1420                     lea_code_loc_810LEA     1.000000
# 1421                     lea_code_loc_810LEA     1.000000
# 1422                     lea_code_loc_820LEA     1.000000
# 1423                     lea_code_loc_821LEA     1.000000
# 1424                     lea_code_loc_830LEA     1.000000
# 1425                     lea_code_loc_830LEA     1.000000
# 1426                     lea_code_loc_840LEA     1.000000
# 1427                     lea_code_loc_840LEA     1.000000
# 1428                     lea_code_loc_850LEA     1.000000
# 1429                     lea_code_loc_850LEA     1.000000
# 1430                     lea_code_loc_860LEA     1.000000
# 1431                     lea_code_loc_861LEA     1.000000
# 1432                     lea_code_loc_862LEA     1.000000
# 1433                     lea_code_loc_870LEA     1.000000
# 1434                     lea_code_loc_870LEA     1.000000
# 1435                     lea_code_loc_880LEA     1.000000
# 1436                     lea_code_loc_880LEA     1.000000
# 1437                     lea_code_loc_890LEA     1.000000
# 1438                     lea_code_loc_890LEA     1.000000
# 1439                     lea_code_loc_900LEA     1.000000
# 1440                     lea_code_loc_900LEA     1.000000
# 1441                     lea_code_loc_910LEA     1.000000
# 1442                     lea_code_loc_910LEA     1.000000
# 1443                     lea_code_loc_920LEA     0.987808
# 1444                     lea_code_loc_920LEA     1.000000
# 1445                     lea_code_loc_930LEA     1.000000
# 1446                     lea_code_loc_940LEA     1.000000
# 1447                     lea_code_loc_940LEA     1.000000
# 1448                     lea_code_loc_950LEA     1.000000
# 1449                     lea_code_loc_950LEA     1.000000
# 1450                     lea_code_loc_960LEA     1.000000
# 1451                     lea_code_loc_960LEA     1.000000
# 1452                     lea_code_loc_970LEA     1.000000
# 1453                     lea_code_loc_980LEA     1.000000
# 1454                     lea_code_loc_980LEA     1.000000
# 1455                     lea_code_loc_990LEA     1.000000
# 1456                     lea_code_loc_990LEA     1.000000
# 1457                     lea_code_loc_995LEA     1.000000
# 1458                     lea_code_loc_995LEA     1.000000
# 1459                     lea_code_loc_998LEA     1.000000
# 1460                    county_loc_Alleghany     1.000000
# 1461                        county_loc_Anson     1.000000
# 1462                         county_loc_Ashe     1.000000
# 1463                        county_loc_Avery     1.000000
# 1464                     county_loc_Beaufort     1.000000
# 1465                       county_loc_Bertie     1.000000
# 1466                       county_loc_Bladen     1.000000
# 1467                    county_loc_Brunswick     1.000000
# 1468                        county_loc_Burke     1.000000
# 1469                     county_loc_Caldwell     1.000000
# 1470                       county_loc_Camden     1.000000
# 1471                     county_loc_Carteret     1.000000
# 1472                      county_loc_Caswell     1.000000
# 1473                     county_loc_Cherokee     1.000000
# 1474                       county_loc_Chowan     1.000000
# 1475                         county_loc_Clay     1.000000
# 1476                    county_loc_Cleveland     1.000000
# 1477                       county_loc_Craven     1.000000
# 1478                    county_loc_Currituck     1.000000
# 1479                         county_loc_Dare     1.000000
# 1480                        county_loc_Davie     1.000000
# 1481                       county_loc_Duplin     1.000000
# 1482                       county_loc_Durham     0.965378
# 1483                    county_loc_Edgecombe     1.000000
# 1484                      county_loc_Forsyth     1.000000
# 1485                     county_loc_Franklin     1.000000
# 1486                       county_loc_Gaston     1.000000
# 1487                        county_loc_Gates     1.000000
# 1488                       county_loc_Graham     1.000000
# 1489                    county_loc_Granville     1.000000
# 1490                       county_loc_Greene     1.000000
# 1491                     county_loc_Guilford     1.000000
# 1492                      county_loc_Harnett     1.000000
# 1493                      county_loc_Haywood     1.000000
# 1494                    county_loc_Henderson     1.000000
# 1495                     county_loc_Hertford     1.000000
# 1496                         county_loc_Hoke     1.000000
# 1497                         county_loc_Hyde     1.000000
# 1498                      county_loc_Jackson     1.000000
# 1499                     county_loc_Johnston     1.000000
# 1500                        county_loc_Jones     1.000000
# 1501                          county_loc_Lee     1.000000
# 1502                        county_loc_Macon     1.000000
# 1503                      county_loc_Madison     1.000000
# 1504                       county_loc_Martin     1.000000
# 1505                     county_loc_McDowell     1.000000
# 1506                  county_loc_Mecklenburg     1.000000
# 1507                     county_loc_Mitchell     1.000000
# 1508                        county_loc_Moore     1.000000
# 1509                  county_loc_New Hanover     0.956723
# 1510                  county_loc_Northampton     1.000000
# 1511                       county_loc_Onslow     1.000000
# 1512                      county_loc_Pamlico     1.000000
# 1513                   county_loc_Pasquotank     1.000000
# 1514                       county_loc_Pender     1.000000
# 1515                   county_loc_Perquimans     1.000000
# 1516                       county_loc_Person     1.000000
# 1517                         county_loc_Pitt     0.965378
# 1518                         county_loc_Polk     1.000000
# 1519                     county_loc_Richmond     1.000000
# 1520                      county_loc_Robeson     0.962913
# 1521                   county_loc_Rockingham     1.000000
# 1522                        county_loc_Rowan     1.000000
# 1523                   county_loc_Rutherford     1.000000
# 1524                     county_loc_Scotland     1.000000
# 1525                       county_loc_Stanly     1.000000
# 1526                       county_loc_Stokes     1.000000
# 1527                        county_loc_Swain     1.000000
# 1528                 county_loc_Transylvania     1.000000
# 1529                      county_loc_Tyrrell     1.000000
# 1530                        county_loc_Union     1.000000
# 1531                        county_loc_Vance     1.000000
# 1532                         county_loc_Wake     0.987808
# 1533                   county_loc_Washington     1.000000
# 1534                      county_loc_Watauga     1.000000
# 1535                        county_loc_Wayne     1.000000
# 1536                       county_loc_Wilson     1.000000
# 1537                       county_loc_Yadkin     1.000000
# 1538                       county_loc_Yancey     1.000000
# 1539            stree_addr2_loc_309 Ashe Ave     1.000000
# 1540                       grade_span_loc_NG     1.000000

# %%
print('Dropping the following ', str(len(cf['Field2'].unique())), ' highly correlated, unique fields.')
cf['Field2'].unique()
# Out:
# Dropping the following  651  highly correlated, unique fields.
# array(['indian_pct', 'asian_pct', 'hispanic_pct', 'black_pct',
#        'white_pct', 'indian_male_pct', 'eg_index_all_all_eg',
#        'eg_index_ma_all_eg', 'eg_score_all_bl7_eg', 'eg_score_all_els_eg',
#        'eg_score_all_hi7_eg', 'eg_score_all_mu7_eg',
#        'eg_score_all_swd_eg', 'eg_score_all_wh7_eg', 'eg_score_ma_all_eg',
#        'eg_score_rd_all_eg', 'den_all_elp', 'den_els_elp', 'den_hi7_elp',
#        'den_male_elp', 'pct_all_elp', 'pct_prof_6gr_irm',
#        'target_assign_math_grades_3-8_ltg',
#        'target_assign_reading_grades_3-8_ltg',
#        'target_assign_total_targets_ltg', 'pct_met_math_grades_3-8_part',
#        'pct_met_reading_grades_3-8_part',
#        'pct_met_science_grades_5&8_part',
#        'target_assign_math_grades_3-8_part',
#        'target_assign_reading_grades_3-8_part',
#        'target_assign_science_grades_5&8_part',
#        'target_assign_total_targets_part',
#        'target_met_math_grades_3-8_part',
#        'target_met_reading_grades_3-8_part',
#        'pct_math_grades_3-8_all_part_det',
#        'pct_math_grades_3-8_bl7_part_det',
#        'pct_math_grades_3-8_eds_part_det',
#        'pct_math_grades_3-8_els_part_det',
#        'pct_math_grades_3-8_hi7_part_det',
#        'pct_math_grades_3-8_swd_part_det',
#        'pct_math_grades_3-8_wh7_part_det',
#        'pct_science_grades_5&8_wh7_part_det', 'pct_ccr_eog_06_aig_pc',
#        'pct_ccr_eog_06_all_pc', 'pct_ccr_eog_06_bl7_pc',
#        'pct_ccr_eog_06_eds_pc', 'pct_ccr_eog_06_fem_pc',
#        'pct_ccr_eog_06_hi7_pc', 'pct_ccr_eog_06_male_pc',
#        'pct_ccr_eog_06_mu7_pc', 'pct_ccr_eog_06_neds_pc',
#        'pct_ccr_eog_06_nswd_pc', 'pct_ccr_eog_06_wh7_pc',
#        'pct_ccr_eog_07_aig_pc', 'pct_ccr_eog_07_all_pc',
#        'pct_ccr_eog_07_bl7_pc', 'pct_ccr_eog_07_eds_pc',
#        'pct_ccr_eog_07_fem_pc', 'pct_ccr_eog_07_hi7_pc',
#        'pct_ccr_eog_07_male_pc', 'pct_ccr_eog_07_mu7_pc',
#        'pct_ccr_eog_07_neds_pc', 'pct_ccr_eog_07_nswd_pc',
#        'pct_ccr_eog_07_wh7_pc', 'pct_ccr_eog_08_aig_pc',
#        'pct_ccr_eog_08_all_pc', 'pct_ccr_eog_08_bl7_pc',
#        'pct_ccr_eog_08_eds_pc', 'pct_ccr_eog_08_fem_pc',
#        'pct_ccr_eog_08_hi7_pc', 'pct_ccr_eog_08_male_pc',
#        'pct_ccr_eog_08_mu7_pc', 'pct_ccr_eog_08_neds_pc',
#        'pct_ccr_eog_08_nswd_pc', 'pct_ccr_eog_08_wh7_pc',
#        'pct_ccr_eog_all_aig_pc', 'pct_ccr_eog_all_all_pc',
#        'pct_ccr_eog_all_as7_pc', 'pct_ccr_eog_all_bl7_pc',
#        'pct_ccr_eog_all_eds_pc', 'pct_ccr_eog_all_els_pc',
#        'pct_ccr_eog_all_fem_pc', 'pct_ccr_eog_all_hi7_pc',
#        'pct_ccr_eog_all_hms_pc', 'pct_ccr_eog_all_male_pc',
#        'pct_ccr_eog_all_mu7_pc', 'pct_ccr_eog_all_neds_pc',
#        'pct_ccr_eog_all_nswd_pc', 'pct_ccr_eog_all_swd_pc',
#        'pct_ccr_eog_all_wh7_pc', 'pct_ccr_ma_06_aig_pc',
#        'pct_ccr_ma_06_all_pc', 'pct_ccr_ma_06_bl7_pc',
#        'pct_ccr_ma_06_eds_pc', 'pct_ccr_ma_06_fem_pc',
#        'pct_ccr_ma_06_hi7_pc', 'pct_ccr_ma_06_male_pc',
#        'pct_ccr_ma_06_neds_pc', 'pct_ccr_ma_06_nswd_pc',
#        'pct_ccr_ma_06_wh7_pc', 'pct_ccr_ma_07_aig_pc',
#        'pct_ccr_ma_07_all_pc', 'pct_ccr_ma_07_bl7_pc',
#        'pct_ccr_ma_07_eds_pc', 'pct_ccr_ma_07_fem_pc',
#        'pct_ccr_ma_07_hi7_pc', 'pct_ccr_ma_07_male_pc',
#        'pct_ccr_ma_07_neds_pc', 'pct_ccr_ma_07_nswd_pc',
#        'pct_ccr_ma_07_wh7_pc', 'pct_ccr_ma_08_aig_pc',
#        'pct_ccr_ma_08_all_pc', 'pct_ccr_ma_08_bl7_pc',
#        'pct_ccr_ma_08_fem_pc', 'pct_ccr_ma_08_nswd_pc',
#        'pct_ccr_ma_all_aig_pc', 'pct_ccr_ma_all_all_pc',
#        'pct_ccr_ma_all_bl7_pc', 'pct_ccr_ma_all_eds_pc',
#        'pct_ccr_ma_all_els_pc', 'pct_ccr_ma_all_fem_pc',
#        'pct_ccr_ma_all_male_pc', 'pct_ccr_ma_all_neds_pc',
#        'pct_ccr_ma_all_nswd_pc', 'pct_ccr_ma_all_swd_pc',
#        'pct_ccr_ma_all_wh7_pc', 'pct_ccr_rd_06_aig_pc',
#        'pct_ccr_rd_06_all_pc', 'pct_ccr_rd_06_bl7_pc',
#        'pct_ccr_rd_06_eds_pc', 'pct_ccr_rd_06_fem_pc',
#        'pct_ccr_rd_06_hi7_pc', 'pct_ccr_rd_06_male_pc',
#        'pct_ccr_rd_06_neds_pc', 'pct_ccr_rd_06_nswd_pc',
#        'pct_ccr_rd_06_wh7_pc', 'pct_ccr_rd_07_aig_pc',
#        'pct_ccr_rd_07_all_pc', 'pct_ccr_rd_07_bl7_pc',
#        'pct_ccr_rd_07_eds_pc', 'pct_ccr_rd_07_fem_pc',
#        'pct_ccr_rd_07_hi7_pc', 'pct_ccr_rd_07_male_pc',
#        'pct_ccr_rd_07_neds_pc', 'pct_ccr_rd_07_nswd_pc',
#        'pct_ccr_rd_07_wh7_pc', 'pct_ccr_rd_08_aig_pc',
#        'pct_ccr_rd_08_all_pc', 'pct_ccr_rd_08_bl7_pc',
#        'pct_ccr_rd_08_eds_pc', 'pct_ccr_rd_08_fem_pc',
#        'pct_ccr_rd_08_hi7_pc', 'pct_ccr_rd_08_male_pc',
#        'pct_ccr_rd_08_neds_pc', 'pct_ccr_rd_08_nswd_pc',
#        'pct_ccr_rd_08_wh7_pc', 'pct_ccr_rd_all_aig_pc',
#        'pct_ccr_rd_all_all_pc', 'pct_ccr_rd_all_bl7_pc',
#        'pct_ccr_rd_all_eds_pc', 'pct_ccr_rd_all_fem_pc',
#        'pct_ccr_rd_all_hi7_pc', 'pct_ccr_rd_all_male_pc',
#        'pct_ccr_rd_all_mu7_pc', 'pct_ccr_rd_all_neds_pc',
#        'pct_ccr_rd_all_nswd_pc', 'pct_ccr_rd_all_wh7_pc',
#        'pct_ccr_sc_08_aig_pc', 'pct_ccr_sc_08_all_pc',
#        'pct_ccr_sc_08_bl7_pc', 'pct_ccr_sc_08_eds_pc',
#        'pct_ccr_sc_08_fem_pc', 'pct_ccr_sc_08_hi7_pc',
#        'pct_ccr_sc_08_male_pc', 'pct_ccr_sc_08_neds_pc',
#        'pct_ccr_sc_08_nswd_pc', 'pct_ccr_sc_08_swd_pc',
#        'pct_ccr_sc_08_wh7_pc', 'pct_ccr_sc_all_aig_pc',
#        'pct_ccr_sc_all_all_pc', 'pct_ccr_sc_all_bl7_pc',
#        'pct_ccr_sc_all_eds_pc', 'pct_ccr_sc_all_fem_pc',
#        'pct_ccr_sc_all_hi7_pc', 'pct_ccr_sc_all_male_pc',
#        'pct_ccr_sc_all_neds_pc', 'pct_ccr_sc_all_nswd_pc',
#        'pct_ccr_sc_all_swd_pc', 'pct_ccr_sc_all_wh7_pc',
#        'pct_glp_eog_06_all_pc', 'pct_glp_eog_06_bl7_pc',
#        'pct_glp_eog_06_eds_pc', 'pct_glp_eog_06_fem_pc',
#        'pct_glp_eog_06_hi7_pc', 'pct_glp_eog_06_male_pc',
#        'pct_glp_eog_06_neds_pc', 'pct_glp_eog_06_nswd_pc',
#        'pct_glp_eog_06_wh7_pc', 'pct_glp_eog_07_all_pc',
#        'pct_glp_eog_07_bl7_pc', 'pct_glp_eog_07_fem_pc',
#        'pct_glp_eog_07_male_pc', 'pct_glp_eog_07_neds_pc',
#        'pct_glp_eog_07_nswd_pc', 'pct_glp_eog_07_wh7_pc',
#        'pct_glp_eog_08_all_pc', 'pct_glp_eog_08_bl7_pc',
#        'pct_glp_eog_08_eds_pc', 'pct_glp_eog_08_fem_pc',
#        'pct_glp_eog_08_hi7_pc', 'pct_glp_eog_08_male_pc',
#        'pct_glp_eog_08_neds_pc', 'pct_glp_eog_08_nswd_pc',
#        'pct_glp_eog_all_all_pc', 'pct_glp_eog_all_bl7_pc',
#        'pct_glp_eog_all_eds_pc', 'pct_glp_eog_all_fem_pc',
#        'pct_glp_eog_all_hi7_pc', 'pct_glp_eog_all_male_pc',
#        'pct_glp_eog_all_neds_pc', 'pct_glp_eog_all_nswd_pc',
#        'pct_glp_eog_all_wh7_pc', 'pct_glp_ma_06_aig_pc',
#        'pct_glp_ma_06_all_pc', 'pct_glp_ma_06_fem_pc',
#        'pct_glp_ma_06_male_pc', 'pct_glp_ma_06_neds_pc',
#        'pct_glp_ma_06_nswd_pc', 'pct_glp_ma_06_wh7_pc',
#        'pct_glp_ma_07_aig_pc', 'pct_glp_ma_07_all_pc',
#        'pct_glp_ma_07_neds_pc', 'pct_glp_ma_07_wh7_pc',
#        'pct_glp_ma_08_aig_pc', 'pct_glp_ma_08_all_pc',
#        'pct_glp_ma_all_aig_pc', 'pct_glp_ma_all_all_pc',
#        'pct_glp_ma_all_eds_pc', 'pct_glp_ma_all_fem_pc',
#        'pct_glp_ma_all_male_pc', 'pct_glp_ma_all_neds_pc',
#        'pct_glp_ma_all_nswd_pc', 'pct_glp_ma_all_wh7_pc',
#        'pct_glp_rd_06_all_pc', 'pct_glp_rd_06_bl7_pc',
#        'pct_glp_rd_06_eds_pc', 'pct_glp_rd_06_fem_pc',
#        'pct_glp_rd_06_hi7_pc', 'pct_glp_rd_06_male_pc',
#        'pct_glp_rd_06_nswd_pc', 'pct_glp_rd_06_wh7_pc',
#        'pct_glp_rd_07_all_pc', 'pct_glp_rd_07_bl7_pc',
#        'pct_glp_rd_07_eds_pc', 'pct_glp_rd_07_fem_pc',
#        'pct_glp_rd_07_hi7_pc', 'pct_glp_rd_07_male_pc',
#        'pct_glp_rd_07_neds_pc', 'pct_glp_rd_07_nswd_pc',
#        'pct_glp_rd_07_wh7_pc', 'pct_glp_rd_08_aig_pc',
#        'pct_glp_rd_08_all_pc', 'pct_glp_rd_08_eds_pc',
#        'pct_glp_rd_08_fem_pc', 'pct_glp_rd_08_male_pc',
#        'pct_glp_rd_08_neds_pc', 'pct_glp_rd_08_nswd_pc',
#        'pct_glp_rd_08_wh7_pc', 'pct_glp_rd_all_all_pc',
#        'pct_glp_rd_all_bl7_pc', 'pct_glp_rd_all_eds_pc',
#        'pct_glp_rd_all_fem_pc', 'pct_glp_rd_all_hi7_pc',
#        'pct_glp_rd_all_male_pc', 'pct_glp_rd_all_neds_pc',
#        'pct_glp_rd_all_nswd_pc', 'pct_glp_rd_all_wh7_pc',
#        'pct_glp_sc_08_aig_pc', 'pct_glp_sc_08_all_pc',
#        'pct_glp_sc_08_bl7_pc', 'pct_glp_sc_all_all_pc',
#        'pct_glp_sc_all_bl7_pc', 'pct_glp_sc_all_fem_pc',
#        'pct_l1_rd_08_swd_pc', 'pct_l1_rd_all_els_pc',
#        'pct_l1_sc_08_all_pc', 'pct_l1_sc_08_fem_pc',
#        'pct_l1_sc_08_nswd_pc', 'pct_l3_all_all_aig_pc',
#        'pct_l3_all_all_bl7_pc', 'pct_l3_all_all_els_pc',
#        'pct_l3_all_all_hi7_pc', 'pct_l3_all_all_hms_pc',
#        'pct_l3_all_all_male_pc', 'pct_l3_all_all_mu7_pc',
#        'pct_l3_all_all_swd_pc', 'pct_l3_ma_06_all_pc',
#        'pct_l3_ma_08_all_pc', 'pct_l4_all_all_aig_pc',
#        'pct_l4_all_all_all_pc', 'pct_l4_all_all_as7_pc',
#        'pct_l4_all_all_bl7_pc', 'pct_l4_all_all_eds_pc',
#        'pct_l4_all_all_els_pc', 'pct_l4_all_all_fem_pc',
#        'pct_l4_all_all_hi7_pc', 'pct_l4_all_all_hms_pc',
#        'pct_l4_all_all_male_pc', 'pct_l4_all_all_mu7_pc',
#        'pct_l4_all_all_neds_pc', 'pct_l4_all_all_nswd_pc',
#        'pct_l4_all_all_wh7_pc', 'pct_l4_eog_06_all_pc',
#        'pct_l4_eog_06_fem_pc', 'pct_l4_eog_06_nswd_pc',
#        'pct_l4_eog_07_all_pc', 'pct_l4_eog_07_fem_pc',
#        'pct_l4_eog_07_nswd_pc', 'pct_l4_eog_08_all_pc',
#        'pct_l4_eog_all_all_pc', 'pct_l4_eog_all_eds_pc',
#        'pct_l4_eog_all_fem_pc', 'pct_l4_eog_all_male_pc',
#        'pct_l4_eog_all_neds_pc', 'pct_l4_eog_all_nswd_pc',
#        'pct_l4_ma_06_all_pc', 'pct_l4_ma_07_all_pc',
#        'pct_l4_ma_08_all_pc', 'pct_l4_ma_all_all_pc',
#        'pct_l4_ma_all_fem_pc', 'pct_l4_ma_all_male_pc',
#        'pct_l4_ma_all_neds_pc', 'pct_l4_ma_all_nswd_pc',
#        'pct_l4_rd_06_all_pc', 'pct_l4_rd_07_all_pc',
#        'pct_l4_rd_08_all_pc', 'pct_l4_rd_all_all_pc',
#        'pct_l4_rd_all_fem_pc', 'pct_l4_rd_all_nswd_pc',
#        'pct_l4_sc_08_all_pc', 'pct_l4_sc_all_all_pc',
#        'pct_l5_all_all_aig_pc', 'pct_l5_all_all_all_pc',
#        'pct_l5_all_all_as7_pc', 'pct_l5_all_all_eds_pc',
#        'pct_l5_all_all_fem_pc', 'pct_l5_all_all_hi7_pc',
#        'pct_l5_all_all_male_pc', 'pct_l5_all_all_mu7_pc',
#        'pct_l5_all_all_neds_pc', 'pct_l5_all_all_nswd_pc',
#        'pct_l5_all_all_wh7_pc', 'pct_l5_eog_06_all_pc',
#        'pct_l5_eog_06_fem_pc', 'pct_l5_eog_06_neds_pc',
#        'pct_l5_eog_06_nswd_pc', 'pct_l5_eog_07_all_pc',
#        'pct_l5_eog_07_fem_pc', 'pct_l5_eog_07_nswd_pc',
#        'pct_l5_eog_08_all_pc', 'pct_l5_eog_08_fem_pc',
#        'pct_l5_eog_08_male_pc', 'pct_l5_eog_08_nswd_pc',
#        'pct_l5_eog_all_all_pc', 'pct_l5_eog_all_fem_pc',
#        'pct_l5_eog_all_male_pc', 'pct_l5_eog_all_neds_pc',
#        'pct_l5_eog_all_nswd_pc', 'pct_l5_ma_06_all_pc',
#        'pct_l5_ma_06_fem_pc', 'pct_l5_ma_06_male_pc',
#        'pct_l5_ma_07_all_pc', 'pct_l5_ma_07_male_pc',
#        'pct_l5_ma_08_all_pc', 'pct_l5_ma_08_fem_pc',
#        'pct_l5_ma_all_all_pc', 'pct_l5_ma_all_fem_pc',
#        'pct_l5_ma_all_male_pc', 'pct_l5_ma_all_neds_pc',
#        'pct_l5_rd_06_all_pc', 'pct_l5_rd_07_all_pc',
#        'pct_l5_rd_08_all_pc', 'pct_l5_rd_all_all_pc',
#        'pct_l5_rd_all_fem_pc', 'pct_l5_sc_08_all_pc',
#        'pct_l5_sc_08_bl7_pc', 'pct_l5_sc_08_fem_pc',
#        'pct_l5_sc_08_hi7_pc', 'pct_l5_sc_08_male_pc',
#        'pct_l5_sc_08_neds_pc', 'pct_l5_sc_08_nswd_pc',
#        'pct_l5_sc_08_wh7_pc', 'pct_l5_sc_all_all_pc',
#        'pct_l5_sc_all_fem_pc', 'pct_l5_sc_all_male_pc',
#        'pct_l5_sc_all_neds_pc', 'pct_notprof_all_all_all_pc',
#        'pct_notprof_all_all_as7_pc', 'pct_notprof_all_all_els_pc',
#        'pct_notprof_all_all_hms_pc', 'pct_notprof_eog_all_all_pc',
#        'aaa_score_all_spg2', 'aaa_score_bl7_spg2', 'aaa_score_eds_spg2',
#        'aaa_score_els_spg2', 'aaa_score_hi7_spg2', 'aaa_score_mu7_spg2',
#        'aaa_score_swd_spg2', 'aaa_score_wh7_spg2', 'ach_score_all_spg2',
#        'ach_score_bl7_spg2', 'ach_score_eds_spg2', 'ach_score_els_spg2',
#        'ach_score_hi7_spg2', 'ach_score_mu7_spg2', 'ach_score_wh7_spg2',
#        'eg_score_all_spg2', 'ma_spg_score_all_spg2',
#        'mags_score_all_spg2', 'rd_spg_score_all_spg2',
#        'rdgs_score_all_spg2', 'spg_score_all_spg2', 'avg_student_num_adm',
#        'count_all_chron_absent', 'pct_all_chron_absent',
#        'number_of_teachers_eq', 'adm_central_expense_funds2',
#        'adm_employee_benefits_funds2', 'adm_instructional_equip._funds2',
#        'adm_other_objects_funds2', 'adm_purchased_services_funds2',
#        'adm_salaries_funds2', 'adm_supplies_&_materials_funds2',
#        'federal_funds_employee_benefits_funds2',
#        'federal_funds_other_objects_funds2',
#        'federal_ppe_employee_benefits_funds2',
#        'federal_ppe_other_objects_funds2', 'federal_ppe_salaries_funds2',
#        'local_funds_central_expense_funds2',
#        'local_funds_employee_benefits_funds2',
#        'local_funds_other_objects_funds2', 'local_funds_salaries_funds2',
#        'local_ppe_employee_benefits_funds2',
#        'local_ppe_other_objects_funds2',
#        'state_funds_employee_benefits_funds2',
#        'state_funds_salaries_funds2', 'state_funds_total_funds2',
#        'state_ppe_employee_benefits_funds2',
#        'total_funds_employee_benefits_funds2',
#        'total_funds_salaries_funds2', 'arr_per1000_all_inc2',
#        'arr_per1000_bl7_inc2', 'arr_per1000_eds_inc2',
#        'iss_per1000_all_inc2', 'rpt_per1000_all_inc2',
#        'lea_code_loc_020LEA', 'lea_code_loc_030LEA',
#        'lea_code_loc_040LEA', 'lea_code_loc_050LEA',
#        'lea_code_loc_060LEA', 'lea_code_loc_070LEA',
#        'lea_code_loc_080LEA', 'lea_code_loc_090LEA',
#        'lea_code_loc_100LEA', 'lea_code_loc_110LEA',
#        'lea_code_loc_111LEA', 'lea_code_loc_120LEA',
#        'lea_code_loc_130LEA', 'lea_code_loc_132LEA',
#        'lea_code_loc_140LEA', 'lea_code_loc_150LEA',
#        'lea_code_loc_160LEA', 'lea_code_loc_170LEA',
#        'lea_code_loc_180LEA', 'lea_code_loc_181LEA',
#        'lea_code_loc_182LEA', 'lea_code_loc_190LEA',
#        'lea_code_loc_200LEA', 'lea_code_loc_210LEA',
#        'lea_code_loc_220LEA', 'lea_code_loc_230LEA',
#        'lea_code_loc_240LEA', 'lea_code_loc_241LEA',
#        'lea_code_loc_250LEA', 'lea_code_loc_260LEA',
#        'lea_code_loc_270LEA', 'lea_code_loc_280LEA',
#        'lea_code_loc_290LEA', 'lea_code_loc_291LEA',
#        'lea_code_loc_292LEA', 'lea_code_loc_299LEA',
#        'lea_code_loc_300LEA', 'lea_code_loc_310LEA',
#        'lea_code_loc_320LEA', 'lea_code_loc_330LEA',
#        'lea_code_loc_340LEA', 'lea_code_loc_350LEA',
#        'lea_code_loc_360LEA', 'lea_code_loc_370LEA',
#        'lea_code_loc_380LEA', 'lea_code_loc_390LEA',
#        'lea_code_loc_400LEA', 'lea_code_loc_410LEA',
#        'lea_code_loc_420LEA', 'lea_code_loc_421LEA',
#        'lea_code_loc_422LEA', 'lea_code_loc_430LEA',
#        'lea_code_loc_440LEA', 'lea_code_loc_450LEA',
#        'lea_code_loc_460LEA', 'lea_code_loc_470LEA',
#        'lea_code_loc_480LEA', 'lea_code_loc_490LEA',
#        'lea_code_loc_500LEA', 'lea_code_loc_510LEA',
#        'lea_code_loc_520LEA', 'lea_code_loc_530LEA',
#        'lea_code_loc_540LEA', 'lea_code_loc_550LEA',
#        'lea_code_loc_560LEA', 'lea_code_loc_570LEA',
#        'lea_code_loc_580LEA', 'lea_code_loc_590LEA',
#        'lea_code_loc_600LEA', 'lea_code_loc_610LEA',
#        'lea_code_loc_620LEA', 'lea_code_loc_630LEA',
#        'lea_code_loc_640LEA', 'lea_code_loc_650LEA',
#        'lea_code_loc_660LEA', 'lea_code_loc_670LEA',
#        'lea_code_loc_680LEA', 'lea_code_loc_681LEA',
#        'lea_code_loc_690LEA', 'lea_code_loc_700LEA',
#        'lea_code_loc_710LEA', 'lea_code_loc_720LEA',
#        'lea_code_loc_730LEA', 'lea_code_loc_740LEA',
#        'lea_code_loc_750LEA', 'lea_code_loc_760LEA',
#        'lea_code_loc_761LEA', 'lea_code_loc_770LEA',
#        'lea_code_loc_780LEA', 'lea_code_loc_790LEA',
#        'lea_code_loc_800LEA', 'lea_code_loc_810LEA',
#        'lea_code_loc_820LEA', 'lea_code_loc_821LEA',
#        'lea_code_loc_830LEA', 'lea_code_loc_840LEA',
#        'lea_code_loc_850LEA', 'lea_code_loc_860LEA',
#        'lea_code_loc_861LEA', 'lea_code_loc_862LEA',
#        'lea_code_loc_870LEA', 'lea_code_loc_880LEA',
#        'lea_code_loc_890LEA', 'lea_code_loc_900LEA',
#        'lea_code_loc_910LEA', 'lea_code_loc_920LEA',
#        'lea_code_loc_930LEA', 'lea_code_loc_940LEA',
#        'lea_code_loc_950LEA', 'lea_code_loc_960LEA',
#        'lea_code_loc_970LEA', 'lea_code_loc_980LEA',
#        'lea_code_loc_990LEA', 'lea_code_loc_995LEA',
#        'lea_code_loc_998LEA', 'county_loc_Alleghany', 'county_loc_Anson',
#        'county_loc_Ashe', 'county_loc_Avery', 'county_loc_Beaufort',
#        'county_loc_Bertie', 'county_loc_Bladen', 'county_loc_Brunswick',
#        'county_loc_Burke', 'county_loc_Caldwell', 'county_loc_Camden',
#        'county_loc_Carteret', 'county_loc_Caswell', 'county_loc_Cherokee',
#        'county_loc_Chowan', 'county_loc_Clay', 'county_loc_Cleveland',
#        'county_loc_Craven', 'county_loc_Currituck', 'county_loc_Dare',
#        'county_loc_Davie', 'county_loc_Duplin', 'county_loc_Durham',
#        'county_loc_Edgecombe', 'county_loc_Forsyth',
#        'county_loc_Franklin', 'county_loc_Gaston', 'county_loc_Gates',
#        'county_loc_Graham', 'county_loc_Granville', 'county_loc_Greene',
#        'county_loc_Guilford', 'county_loc_Harnett', 'county_loc_Haywood',
#        'county_loc_Henderson', 'county_loc_Hertford', 'county_loc_Hoke',
#        'county_loc_Hyde', 'county_loc_Jackson', 'county_loc_Johnston',
#        'county_loc_Jones', 'county_loc_Lee', 'county_loc_Macon',
#        'county_loc_Madison', 'county_loc_Martin', 'county_loc_McDowell',
#        'county_loc_Mecklenburg', 'county_loc_Mitchell',
#        'county_loc_Moore', 'county_loc_New Hanover',
#        'county_loc_Northampton', 'county_loc_Onslow',
#        'county_loc_Pamlico', 'county_loc_Pasquotank', 'county_loc_Pender',
#        'county_loc_Perquimans', 'county_loc_Person', 'county_loc_Pitt',
#        'county_loc_Polk', 'county_loc_Richmond', 'county_loc_Robeson',
#        'county_loc_Rockingham', 'county_loc_Rowan',
#        'county_loc_Rutherford', 'county_loc_Scotland',
#        'county_loc_Stanly', 'county_loc_Stokes', 'county_loc_Swain',
#        'county_loc_Transylvania', 'county_loc_Tyrrell',
#        'county_loc_Union', 'county_loc_Vance', 'county_loc_Wake',
#        'county_loc_Washington', 'county_loc_Watauga', 'county_loc_Wayne',
#        'county_loc_Wilson', 'county_loc_Yadkin', 'county_loc_Yancey',
#        'stree_addr2_loc_309 Ashe Ave', 'grade_span_loc_NG'], dtype=object)

# %%
#Check columns before drop 
print('\r\n*********Before: Dropping Highly Correlated Fields*************************************')
schoolData.info(verbose=False)

# Drop the highly correlated features from our training data 
#schoolData = schoolData.drop(to_drop, axis=1)
schoolData = schoolData.drop(cf['Field2'], axis=1)

#Check columns after drop 
print('\r\n*********After: Dropping Highly Correlated Fields**************************************')
schoolData.info(verbose=False)
# Out:
# *********Before: Dropping Highly Correlated Fields*************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 691 entries, 2 to 845
# Columns: 1821 entries, lea to poverty_eq_NEITHER
# dtypes: float64(1358), uint8(463)
# memory usage: 7.5 MB
#
# *********After: Dropping Highly Correlated Fields**************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 691 entries, 2 to 845
# Columns: 1170 entries, lea to poverty_eq_NEITHER
# dtypes: float64(903), uint8(267)
# memory usage: 4.9 MB

# %%
#Restore the unit_code before saving
schoolData['agency_code'] = agency_code
#Save the final dataset to a .csv file
schoolData.to_csv(outputDir + inputFileName + '_ML.csv', sep=',', index=False)

# %%
print('*********FINAL DATASET DETAILS*********************************************************\r\n')
schoolData.info(verbose=True)
# Out:
# *********FINAL DATASET DETAILS*********************************************************
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 691 entries, 2 to 845
# Data columns (total 1171 columns):
#  #    Column                                                                                                                       Dtype
# ---   ------                                                                                                                       -----
#  0    lea                                                                                                                          float64
#  1    school                                                                                                                       float64
#  2    pacific_island_pct                                                                                                           float64
#  3    two_or_more_pct                                                                                                              float64
#  4    minority_pct                                                                                                                 float64
#  5    asian_male_pct                                                                                                               float64
#  6    hispanic_male_pct                                                                                                            float64
#  7    black_male_pct                                                                                                               float64
#  8    white_male_pct                                                                                                               float64
#  9    pacific_island_male_pct                                                                                                      float64
#  10   two_or_more_male_pct                                                                                                         float64
#  11   minority_male_pct                                                                                                            float64
#  12   indian_female_pct                                                                                                            float64
#  13   asian_female_pct                                                                                                             float64
#  14   hispanic_female_pct                                                                                                          float64
#  15   black_female_pct                                                                                                             float64
#  16   white_female_pct                                                                                                             float64
#  17   minority_female_pct                                                                                                          float64
#  18   pacific_island_female_pct                                                                                                    float64
#  19   two_or_more_female_pct                                                                                                       float64
#  20   pct_eds                                                                                                                      float64
#  21   eg_index_all_aig_eg                                                                                                          float64
#  22   eg_index_all_bl7_eg                                                                                                          float64
#  23   eg_index_all_eds_eg                                                                                                          float64
#  24   eg_index_all_els_eg                                                                                                          float64
#  25   eg_index_all_hi7_eg                                                                                                          float64
#  26   eg_index_all_mu7_eg                                                                                                          float64
#  27   eg_index_all_swd_eg                                                                                                          float64
#  28   eg_index_all_wh7_eg                                                                                                          float64
#  29   eg_index_rd_all_eg                                                                                                           float64
#  30   eg_score_all_aig_eg                                                                                                          float64
#  31   eg_score_all_all_eg                                                                                                          float64
#  32   eg_score_all_eds_eg                                                                                                          float64
#  33   den_eds_elp                                                                                                                  float64
#  34   den_nswd_elp                                                                                                                 float64
#  35   pct_eds_elp                                                                                                                  float64
#  36   pct_els_elp                                                                                                                  float64
#  37   pct_hi7_elp                                                                                                                  float64
#  38   pct_male_elp                                                                                                                 float64
#  39   pct_nswd_elp                                                                                                                 float64
#  40   pct_met_math_grades_3-8_ltg                                                                                                  float64
#  41   pct_met_reading_grades_3-8_ltg                                                                                               float64
#  42   pct_met_total_targets_ltg                                                                                                    float64
#  43   target_met_math_grades_3-8_ltg                                                                                               float64
#  44   target_met_reading_grades_3-8_ltg                                                                                            float64
#  45   target_met_total_targets_ltg                                                                                                 float64
#  46   pct_met_total_targets_part                                                                                                   float64
#  47   target_met_science_grades_5&8_part                                                                                           float64
#  48   target_met_total_targets_part                                                                                                float64
#  49   pct_reading_grades_3-8_all_part_det                                                                                          float64
#  50   pct_reading_grades_3-8_bl7_part_det                                                                                          float64
#  51   pct_reading_grades_3-8_eds_part_det                                                                                          float64
#  52   pct_reading_grades_3-8_els_part_det                                                                                          float64
#  53   pct_reading_grades_3-8_hi7_part_det                                                                                          float64
#  54   pct_reading_grades_3-8_swd_part_det                                                                                          float64
#  55   pct_reading_grades_3-8_wh7_part_det                                                                                          float64
#  56   pct_science_grades_5&8_all_part_det                                                                                          float64
#  57   pct_science_grades_5&8_bl7_part_det                                                                                          float64
#  58   pct_science_grades_5&8_eds_part_det                                                                                          float64
#  59   pct_science_grades_5&8_hi7_part_det                                                                                          float64
#  60   pct_ccr_eog_06_swd_pc                                                                                                        float64
#  61   pct_ccr_eog_07_swd_pc                                                                                                        float64
#  62   pct_ccr_eog_08_swd_pc                                                                                                        float64
#  63   pct_ccr_ma_08_eds_pc                                                                                                         float64
#  64   pct_ccr_ma_08_hi7_pc                                                                                                         float64
#  65   pct_ccr_ma_08_male_pc                                                                                                        float64
#  66   pct_ccr_ma_08_neds_pc                                                                                                        float64
#  67   pct_ccr_ma_08_wh7_pc                                                                                                         float64
#  68   pct_ccr_ma_all_hi7_pc                                                                                                        float64
#  69   pct_ccr_ma_all_mu7_pc                                                                                                        float64
#  70   pct_ccr_rd_06_swd_pc                                                                                                         float64
#  71   pct_ccr_rd_07_swd_pc                                                                                                         float64
#  72   pct_ccr_rd_08_swd_pc                                                                                                         float64
#  73   pct_ccr_rd_all_swd_pc                                                                                                        float64
#  74   pct_glp_eog_06_aig_pc                                                                                                        float64
#  75   pct_glp_eog_06_els_pc                                                                                                        float64
#  76   pct_glp_eog_06_mu7_pc                                                                                                        float64
#  77   pct_glp_eog_06_swd_pc                                                                                                        float64
#  78   pct_glp_eog_07_aig_pc                                                                                                        float64
#  79   pct_glp_eog_07_eds_pc                                                                                                        float64
#  80   pct_glp_eog_07_hi7_pc                                                                                                        float64
#  81   pct_glp_eog_07_mu7_pc                                                                                                        float64
#  82   pct_glp_eog_07_swd_pc                                                                                                        float64
#  83   pct_glp_eog_08_aig_pc                                                                                                        float64
#  84   pct_glp_eog_08_els_pc                                                                                                        float64
#  85   pct_glp_eog_08_mu7_pc                                                                                                        float64
#  86   pct_glp_eog_08_swd_pc                                                                                                        float64
#  87   pct_glp_eog_08_wh7_pc                                                                                                        float64
#  88   pct_glp_eog_all_aig_pc                                                                                                       float64
#  89   pct_glp_eog_all_as7_pc                                                                                                       float64
#  90   pct_glp_eog_all_els_pc                                                                                                       float64
#  91   pct_glp_eog_all_hms_pc                                                                                                       float64
#  92   pct_glp_eog_all_mu7_pc                                                                                                       float64
#  93   pct_glp_eog_all_swd_pc                                                                                                       float64
#  94   pct_glp_ma_06_bl7_pc                                                                                                         float64
#  95   pct_glp_ma_06_eds_pc                                                                                                         float64
#  96   pct_glp_ma_06_hi7_pc                                                                                                         float64
#  97   pct_glp_ma_06_swd_pc                                                                                                         float64
#  98   pct_glp_ma_07_bl7_pc                                                                                                         float64
#  99   pct_glp_ma_07_eds_pc                                                                                                         float64
#  100  pct_glp_ma_07_fem_pc                                                                                                         float64
#  101  pct_glp_ma_07_hi7_pc                                                                                                         float64
#  102  pct_glp_ma_07_male_pc                                                                                                        float64
#  103  pct_glp_ma_07_nswd_pc                                                                                                        float64
#  104  pct_glp_ma_07_swd_pc                                                                                                         float64
#  105  pct_glp_ma_08_bl7_pc                                                                                                         float64
#  106  pct_glp_ma_08_eds_pc                                                                                                         float64
#  107  pct_glp_ma_08_fem_pc                                                                                                         float64
#  108  pct_glp_ma_08_hi7_pc                                                                                                         float64
#  109  pct_glp_ma_08_male_pc                                                                                                        float64
#  110  pct_glp_ma_08_neds_pc                                                                                                        float64
#  111  pct_glp_ma_08_nswd_pc                                                                                                        float64
#  112  pct_glp_ma_08_swd_pc                                                                                                         float64
#  113  pct_glp_ma_08_wh7_pc                                                                                                         float64
#  114  pct_glp_ma_all_bl7_pc                                                                                                        float64
#  115  pct_glp_ma_all_els_pc                                                                                                        float64
#  116  pct_glp_ma_all_hi7_pc                                                                                                        float64
#  117  pct_glp_ma_all_mu7_pc                                                                                                        float64
#  118  pct_glp_ma_all_swd_pc                                                                                                        float64
#  119  pct_glp_rd_06_aig_pc                                                                                                         float64
#  120  pct_glp_rd_06_neds_pc                                                                                                        float64
#  121  pct_glp_rd_06_swd_pc                                                                                                         float64
#  122  pct_glp_rd_07_aig_pc                                                                                                         float64
#  123  pct_glp_rd_07_swd_pc                                                                                                         float64
#  124  pct_glp_rd_08_bl7_pc                                                                                                         float64
#  125  pct_glp_rd_08_hi7_pc                                                                                                         float64
#  126  pct_glp_rd_08_swd_pc                                                                                                         float64
#  127  pct_glp_rd_all_aig_pc                                                                                                        float64
#  128  pct_glp_rd_all_els_pc                                                                                                        float64
#  129  pct_glp_rd_all_mu7_pc                                                                                                        float64
#  130  pct_glp_rd_all_swd_pc                                                                                                        float64
#  131  pct_glp_sc_08_eds_pc                                                                                                         float64
#  132  pct_glp_sc_08_fem_pc                                                                                                         float64
#  133  pct_glp_sc_08_hi7_pc                                                                                                         float64
#  134  pct_glp_sc_08_male_pc                                                                                                        float64
#  135  pct_glp_sc_08_neds_pc                                                                                                        float64
#  136  pct_glp_sc_08_nswd_pc                                                                                                        float64
#  137  pct_glp_sc_08_swd_pc                                                                                                         float64
#  138  pct_glp_sc_08_wh7_pc                                                                                                         float64
#  139  pct_glp_sc_all_aig_pc                                                                                                        float64
#  140  pct_glp_sc_all_eds_pc                                                                                                        float64
#  141  pct_glp_sc_all_hi7_pc                                                                                                        float64
#  142  pct_glp_sc_all_male_pc                                                                                                       float64
#  143  pct_glp_sc_all_neds_pc                                                                                                       float64
#  144  pct_glp_sc_all_nswd_pc                                                                                                       float64
#  145  pct_glp_sc_all_swd_pc                                                                                                        float64
#  146  pct_glp_sc_all_wh7_pc                                                                                                        float64
#  147  pct_l1_rd_06_all_pc                                                                                                          float64
#  148  pct_l1_rd_06_bl7_pc                                                                                                          float64
#  149  pct_l1_rd_06_eds_pc                                                                                                          float64
#  150  pct_l1_rd_06_fem_pc                                                                                                          float64
#  151  pct_l1_rd_06_hi7_pc                                                                                                          float64
#  152  pct_l1_rd_06_male_pc                                                                                                         float64
#  153  pct_l1_rd_06_neds_pc                                                                                                         float64
#  154  pct_l1_rd_06_nswd_pc                                                                                                         float64
#  155  pct_l1_rd_06_swd_pc                                                                                                          float64
#  156  pct_l1_rd_06_wh7_pc                                                                                                          float64
#  157  pct_l1_rd_07_all_pc                                                                                                          float64
#  158  pct_l1_rd_07_bl7_pc                                                                                                          float64
#  159  pct_l1_rd_07_eds_pc                                                                                                          float64
#  160  pct_l1_rd_07_fem_pc                                                                                                          float64
#  161  pct_l1_rd_07_hi7_pc                                                                                                          float64
#  162  pct_l1_rd_07_male_pc                                                                                                         float64
#  163  pct_l1_rd_07_neds_pc                                                                                                         float64
#  164  pct_l1_rd_07_nswd_pc                                                                                                         float64
#  165  pct_l1_rd_07_swd_pc                                                                                                          float64
#  166  pct_l1_rd_07_wh7_pc                                                                                                          float64
#  167  pct_l1_rd_08_all_pc                                                                                                          float64
#  168  pct_l1_rd_08_bl7_pc                                                                                                          float64
#  169  pct_l1_rd_08_eds_pc                                                                                                          float64
#  170  pct_l1_rd_08_fem_pc                                                                                                          float64
#  171  pct_l1_rd_08_hi7_pc                                                                                                          float64
#  172  pct_l1_rd_08_male_pc                                                                                                         float64
#  173  pct_l1_rd_08_neds_pc                                                                                                         float64
#  174  pct_l1_rd_08_nswd_pc                                                                                                         float64
#  175  pct_l1_rd_08_wh7_pc                                                                                                          float64
#  176  pct_l1_rd_all_all_pc                                                                                                         float64
#  177  pct_l1_rd_all_bl7_pc                                                                                                         float64
#  178  pct_l1_rd_all_eds_pc                                                                                                         float64
#  179  pct_l1_rd_all_fem_pc                                                                                                         float64
#  180  pct_l1_rd_all_hi7_pc                                                                                                         float64
#  181  pct_l1_rd_all_male_pc                                                                                                        float64
#  182  pct_l1_rd_all_mu7_pc                                                                                                         float64
#  183  pct_l1_rd_all_neds_pc                                                                                                        float64
#  184  pct_l1_rd_all_nswd_pc                                                                                                        float64
#  185  pct_l1_rd_all_swd_pc                                                                                                         float64
#  186  pct_l1_rd_all_wh7_pc                                                                                                         float64
#  187  pct_l1_sc_08_bl7_pc                                                                                                          float64
#  188  pct_l1_sc_08_eds_pc                                                                                                          float64
#  189  pct_l1_sc_08_hi7_pc                                                                                                          float64
#  190  pct_l1_sc_08_male_pc                                                                                                         float64
#  191  pct_l1_sc_08_neds_pc                                                                                                         float64
#  192  pct_l1_sc_08_swd_pc                                                                                                          float64
#  193  pct_l1_sc_08_wh7_pc                                                                                                          float64
#  194  pct_l1_sc_all_all_pc                                                                                                         float64
#  195  pct_l1_sc_all_bl7_pc                                                                                                         float64
#  196  pct_l1_sc_all_eds_pc                                                                                                         float64
#  197  pct_l1_sc_all_fem_pc                                                                                                         float64
#  198  pct_l1_sc_all_hi7_pc                                                                                                         float64
#  199  pct_l1_sc_all_male_pc                                                                                                        float64
#  200  pct_l1_sc_all_neds_pc                                                                                                        float64
#  201  pct_l1_sc_all_nswd_pc                                                                                                        float64
#  202  pct_l1_sc_all_swd_pc                                                                                                         float64
#  203  pct_l1_sc_all_wh7_pc                                                                                                         float64
#  204  pct_l2_rd_06_all_pc                                                                                                          float64
#  205  pct_l2_rd_06_bl7_pc                                                                                                          float64
#  206  pct_l2_rd_06_eds_pc                                                                                                          float64
#  207  pct_l2_rd_06_fem_pc                                                                                                          float64
#  208  pct_l2_rd_06_hi7_pc                                                                                                          float64
#  209  pct_l2_rd_06_male_pc                                                                                                         float64
#  210  pct_l2_rd_06_neds_pc                                                                                                         float64
#  211  pct_l2_rd_06_nswd_pc                                                                                                         float64
#  212  pct_l2_rd_06_swd_pc                                                                                                          float64
#  213  pct_l2_rd_06_wh7_pc                                                                                                          float64
#  214  pct_l2_rd_07_all_pc                                                                                                          float64
#  215  pct_l2_rd_07_bl7_pc                                                                                                          float64
#  216  pct_l2_rd_07_eds_pc                                                                                                          float64
#  217  pct_l2_rd_07_fem_pc                                                                                                          float64
#  218  pct_l2_rd_07_hi7_pc                                                                                                          float64
#  219  pct_l2_rd_07_male_pc                                                                                                         float64
#  220  pct_l2_rd_07_neds_pc                                                                                                         float64
#  221  pct_l2_rd_07_nswd_pc                                                                                                         float64
#  222  pct_l2_rd_07_swd_pc                                                                                                          float64
#  223  pct_l2_rd_07_wh7_pc                                                                                                          float64
#  224  pct_l2_rd_08_all_pc                                                                                                          float64
#  225  pct_l2_rd_08_bl7_pc                                                                                                          float64
#  226  pct_l2_rd_08_eds_pc                                                                                                          float64
#  227  pct_l2_rd_08_fem_pc                                                                                                          float64
#  228  pct_l2_rd_08_hi7_pc                                                                                                          float64
#  229  pct_l2_rd_08_male_pc                                                                                                         float64
#  230  pct_l2_rd_08_neds_pc                                                                                                         float64
#  231  pct_l2_rd_08_nswd_pc                                                                                                         float64
#  232  pct_l2_rd_08_swd_pc                                                                                                          float64
#  233  pct_l2_rd_08_wh7_pc                                                                                                          float64
#  234  pct_l2_rd_all_all_pc                                                                                                         float64
#  235  pct_l2_rd_all_bl7_pc                                                                                                         float64
#  236  pct_l2_rd_all_eds_pc                                                                                                         float64
#  237  pct_l2_rd_all_els_pc                                                                                                         float64
#  238  pct_l2_rd_all_fem_pc                                                                                                         float64
#  239  pct_l2_rd_all_hi7_pc                                                                                                         float64
#  240  pct_l2_rd_all_male_pc                                                                                                        float64
#  241  pct_l2_rd_all_mu7_pc                                                                                                         float64
#  242  pct_l2_rd_all_neds_pc                                                                                                        float64
#  243  pct_l2_rd_all_nswd_pc                                                                                                        float64
#  244  pct_l2_rd_all_swd_pc                                                                                                         float64
#  245  pct_l2_rd_all_wh7_pc                                                                                                         float64
#  246  pct_l2_sc_08_all_pc                                                                                                          float64
#  247  pct_l2_sc_08_bl7_pc                                                                                                          float64
#  248  pct_l2_sc_08_eds_pc                                                                                                          float64
#  249  pct_l2_sc_08_fem_pc                                                                                                          float64
#  250  pct_l2_sc_08_hi7_pc                                                                                                          float64
#  251  pct_l2_sc_08_male_pc                                                                                                         float64
#  252  pct_l2_sc_08_neds_pc                                                                                                         float64
#  253  pct_l2_sc_08_nswd_pc                                                                                                         float64
#  254  pct_l2_sc_08_swd_pc                                                                                                          float64
#  255  pct_l2_sc_all_all_pc                                                                                                         float64
#  256  pct_l2_sc_all_bl7_pc                                                                                                         float64
#  257  pct_l2_sc_all_eds_pc                                                                                                         float64
#  258  pct_l2_sc_all_fem_pc                                                                                                         float64
#  259  pct_l2_sc_all_hi7_pc                                                                                                         float64
#  260  pct_l2_sc_all_male_pc                                                                                                        float64
#  261  pct_l2_sc_all_neds_pc                                                                                                        float64
#  262  pct_l2_sc_all_nswd_pc                                                                                                        float64
#  263  pct_l2_sc_all_swd_pc                                                                                                         float64
#  264  pct_l2_sc_all_wh7_pc                                                                                                         float64
#  265  pct_l3_all_all_all_pc                                                                                                        float64
#  266  pct_l3_all_all_eds_pc                                                                                                        float64
#  267  pct_l3_all_all_fem_pc                                                                                                        float64
#  268  pct_l3_all_all_neds_pc                                                                                                       float64
#  269  pct_l3_all_all_nswd_pc                                                                                                       float64
#  270  pct_l3_all_all_wh7_pc                                                                                                        float64
#  271  pct_l3_eog_06_all_pc                                                                                                         float64
#  272  pct_l3_eog_06_bl7_pc                                                                                                         float64
#  273  pct_l3_eog_06_eds_pc                                                                                                         float64
#  274  pct_l3_eog_06_fem_pc                                                                                                         float64
#  275  pct_l3_eog_06_hi7_pc                                                                                                         float64
#  276  pct_l3_eog_06_male_pc                                                                                                        float64
#  277  pct_l3_eog_06_mu7_pc                                                                                                         float64
#  278  pct_l3_eog_06_neds_pc                                                                                                        float64
#  279  pct_l3_eog_06_nswd_pc                                                                                                        float64
#  280  pct_l3_eog_06_swd_pc                                                                                                         float64
#  281  pct_l3_eog_06_wh7_pc                                                                                                         float64
#  282  pct_l3_eog_07_all_pc                                                                                                         float64
#  283  pct_l3_eog_07_bl7_pc                                                                                                         float64
#  284  pct_l3_eog_07_eds_pc                                                                                                         float64
#  285  pct_l3_eog_07_fem_pc                                                                                                         float64
#  286  pct_l3_eog_07_hi7_pc                                                                                                         float64
#  287  pct_l3_eog_07_male_pc                                                                                                        float64
#  288  pct_l3_eog_07_mu7_pc                                                                                                         float64
#  289  pct_l3_eog_07_neds_pc                                                                                                        float64
#  290  pct_l3_eog_07_nswd_pc                                                                                                        float64
#  291  pct_l3_eog_07_swd_pc                                                                                                         float64
#  292  pct_l3_eog_07_wh7_pc                                                                                                         float64
#  293  pct_l3_eog_08_aig_pc                                                                                                         float64
#  294  pct_l3_eog_08_all_pc                                                                                                         float64
#  295  pct_l3_eog_08_bl7_pc                                                                                                         float64
#  296  pct_l3_eog_08_eds_pc                                                                                                         float64
#  297  pct_l3_eog_08_fem_pc                                                                                                         float64
#  298  pct_l3_eog_08_hi7_pc                                                                                                         float64
#  299  pct_l3_eog_08_male_pc                                                                                                        float64
#  300  pct_l3_eog_08_mu7_pc                                                                                                         float64
#  301  pct_l3_eog_08_neds_pc                                                                                                        float64
#  302  pct_l3_eog_08_nswd_pc                                                                                                        float64
#  303  pct_l3_eog_08_swd_pc                                                                                                         float64
#  304  pct_l3_eog_08_wh7_pc                                                                                                         float64
#  305  pct_l3_eog_all_aig_pc                                                                                                        float64
#  306  pct_l3_eog_all_all_pc                                                                                                        float64
#  307  pct_l3_eog_all_bl7_pc                                                                                                        float64
#  308  pct_l3_eog_all_eds_pc                                                                                                        float64
#  309  pct_l3_eog_all_els_pc                                                                                                        float64
#  310  pct_l3_eog_all_fem_pc                                                                                                        float64
#  311  pct_l3_eog_all_hi7_pc                                                                                                        float64
#  312  pct_l3_eog_all_hms_pc                                                                                                        float64
#  313  pct_l3_eog_all_male_pc                                                                                                       float64
#  314  pct_l3_eog_all_mu7_pc                                                                                                        float64
#  315  pct_l3_eog_all_neds_pc                                                                                                       float64
#  316  pct_l3_eog_all_nswd_pc                                                                                                       float64
#  317  pct_l3_eog_all_swd_pc                                                                                                        float64
#  318  pct_l3_eog_all_wh7_pc                                                                                                        float64
#  319  pct_l3_ma_06_bl7_pc                                                                                                          float64
#  320  pct_l3_ma_06_eds_pc                                                                                                          float64
#  321  pct_l3_ma_06_fem_pc                                                                                                          float64
#  322  pct_l3_ma_06_hi7_pc                                                                                                          float64
#  323  pct_l3_ma_06_male_pc                                                                                                         float64
#  324  pct_l3_ma_06_neds_pc                                                                                                         float64
#  325  pct_l3_ma_06_nswd_pc                                                                                                         float64
#  326  pct_l3_ma_06_swd_pc                                                                                                          float64
#  327  pct_l3_ma_06_wh7_pc                                                                                                          float64
#  328  pct_l3_ma_07_all_pc                                                                                                          float64
#  329  pct_l3_ma_07_bl7_pc                                                                                                          float64
#  330  pct_l3_ma_07_eds_pc                                                                                                          float64
#  331  pct_l3_ma_07_fem_pc                                                                                                          float64
#  332  pct_l3_ma_07_hi7_pc                                                                                                          float64
#  333  pct_l3_ma_07_male_pc                                                                                                         float64
#  334  pct_l3_ma_07_neds_pc                                                                                                         float64
#  335  pct_l3_ma_07_nswd_pc                                                                                                         float64
#  336  pct_l3_ma_07_swd_pc                                                                                                          float64
#  337  pct_l3_ma_07_wh7_pc                                                                                                          float64
#  338  pct_l3_ma_08_aig_pc                                                                                                          float64
#  339  pct_l3_ma_08_bl7_pc                                                                                                          float64
#  340  pct_l3_ma_08_eds_pc                                                                                                          float64
# ...
#  1057 lea_name_Person County Schools                                                                                               uint8
#  1058 lea_name_Pitt County Schools                                                                                                 uint8
#  1059 lea_name_Polk County Schools                                                                                                 uint8
#  1060 lea_name_Randolph County Schools                                                                                             uint8
#  1061 lea_name_Richmond County Schools                                                                                             uint8
#  1062 lea_name_Roanoke Rapids City Schools                                                                                         uint8
#  1063 lea_name_Robeson County Schools                                                                                              uint8
#  1064 lea_name_Rockingham County Schools                                                                                           uint8
#  1065 lea_name_Rowan-Salisbury County Schools                                                                                      uint8
#  1066 lea_name_Rutherford County Schools                                                                                           uint8
#  1067 lea_name_Sampson County Schools                                                                                              uint8
#  1068 lea_name_Scotland County Schools                                                                                             uint8
#  1069 lea_name_Stanly County Schools                                                                                               uint8
#  1070 lea_name_Stokes County Schools                                                                                               uint8
#  1071 lea_name_Surry County Schools                                                                                                uint8
#  1072 lea_name_Swain County Schools                                                                                                uint8
#  1073 lea_name_Thomasville City Schools                                                                                            uint8
#  1074 lea_name_Transylvania County Schools                                                                                         uint8
#  1075 lea_name_Tyrrell County Schools                                                                                              uint8
#  1076 lea_name_Union County Schools                                                                                                uint8
#  1077 lea_name_Vance County Schools                                                                                                uint8
#  1078 lea_name_Wake County Schools                                                                                                 uint8
#  1079 lea_name_Warren County Schools                                                                                               uint8
#  1080 lea_name_Washington County Schools                                                                                           uint8
#  1081 lea_name_Watauga County Schools                                                                                              uint8
#  1082 lea_name_Wayne County Schools                                                                                                uint8
#  1083 lea_name_Weldon City Schools                                                                                                 uint8
#  1084 lea_name_Whiteville City Schools                                                                                             uint8
#  1085 lea_name_Wilkes County Schools                                                                                               uint8
#  1086 lea_name_Wilson County Schools                                                                                               uint8
#  1087 lea_name_Yadkin County Schools                                                                                               uint8
#  1088 lea_name_Yancey County Schools                                                                                               uint8
#  1089 csi_lp_esea_desig_Y                                                                                                          uint8
#  1090 csi_lg_esea_desig_Y                                                                                                          uint8
#  1091 tsi_cu_esea_desig_Y                                                                                                          uint8
#  1092 tsi_at_esea_desig_Y                                                                                                          uint8
#  1093 grad_project_GP_Y                                                                                                            uint8
#  1094 lp_school_lowperf_Y                                                                                                          uint8
#  1095 rlp_school_lowperf_Y                                                                                                         uint8
#  1096 target_list_ltg_detail_4 Year Graduation Rate,EL Progress,Math Grade 11,Math Grades 3-8,Reading Grade 10,Reading Grades 3-8  uint8
#  1097 target_list_ltg_detail_4 Year Graduation Rate,EL Progress,Math Grades 3-8,Reading Grade 10,Reading Grades 3-8                uint8
#  1098 target_list_ltg_detail_4 Year Graduation Rate,Math Grade 11                                                                  uint8
#  1099 target_list_ltg_detail_4 Year Graduation Rate,Math Grade 11,Math Grades 3-8,Reading Grade 10,Reading Grades 3-8              uint8
#  1100 target_list_ltg_detail_4 Year Graduation Rate,Math Grade 11,Math Grades 3-8,Reading Grades 3-8                               uint8
#  1101 target_list_ltg_detail_4 Year Graduation Rate,Math Grade 11,Reading Grade 10                                                 uint8
#  1102 target_list_ltg_detail_4 Year Graduation Rate,Math Grades 3-8,Reading Grades 3-8                                             uint8
#  1103 target_list_ltg_detail_EL Progress,Math Grades 3-8,Reading Grades 3-8                                                        uint8
#  1104 target_list_ltg_detail_Math Grade 11,Math Grades 3-8,Reading Grades 3-8                                                      uint8
#  1105 target_list_ltg_detail_Math Grades 3-8,Reading Grade 10,Reading Grades 3-8                                                   uint8
#  1106 target_list_ltg_detail_Math Grades 3-8,Reading Grades 3-8                                                                    uint8
#  1107 target_list_ltg_detail_Reading Grade 10                                                                                      uint8
#  1108 subgroup_list_ltg_detail_ALL,AM7,BL7,EDS                                                                                     uint8
#  1109 subgroup_list_ltg_detail_ALL,AM7,BL7,EDS,ELS,HI7,MU7,SWD                                                                     uint8
#  1110 subgroup_list_ltg_detail_ALL,AM7,BL7,EDS,ELS,HI7,MU7,SWD,WH7                                                                 uint8
#  1111 subgroup_list_ltg_detail_ALL,AM7,BL7,EDS,ELS,HI7,SWD                                                                         uint8
#  1112 subgroup_list_ltg_detail_ALL,AM7,BL7,EDS,ELS,HI7,SWD,WH7                                                                     uint8
#  1113 subgroup_list_ltg_detail_ALL,AM7,BL7,EDS,HI7,SWD,WH7                                                                         uint8
#  1114 subgroup_list_ltg_detail_ALL,AM7,BL7,EDS,MU7,SWD,WH7                                                                         uint8
#  1115 subgroup_list_ltg_detail_ALL,AM7,BL7,EDS,SWD                                                                                 uint8
#  1116 subgroup_list_ltg_detail_ALL,AM7,BL7,EDS,SWD,WH7                                                                             uint8
#  1117 subgroup_list_ltg_detail_ALL,AM7,BL7,EDS,WH7                                                                                 uint8
#  1118 subgroup_list_ltg_detail_ALL,AM7,EDS,SWD                                                                                     uint8
#  1119 subgroup_list_ltg_detail_ALL,AM7,EDS,SWD,WH7                                                                                 uint8
#  1120 subgroup_list_ltg_detail_ALL,AS7,BL7,EDS,ELS,HI7                                                                             uint8
#  1121 subgroup_list_ltg_detail_ALL,AS7,BL7,EDS,ELS,HI7,MU7,SWD,WH7                                                                 uint8
#  1122 subgroup_list_ltg_detail_ALL,AS7,BL7,EDS,ELS,HI7,SWD                                                                         uint8
#  1123 subgroup_list_ltg_detail_ALL,AS7,BL7,EDS,ELS,HI7,SWD,WH7                                                                     uint8
#  1124 subgroup_list_ltg_detail_ALL,AS7,BL7,EDS,ELS,HI7,WH7                                                                         uint8
#  1125 subgroup_list_ltg_detail_ALL,AS7,BL7,EDS,ELS,MU7,SWD,WH7                                                                     uint8
#  1126 subgroup_list_ltg_detail_ALL,AS7,BL7,EDS,HI7,MU7,SWD,WH7                                                                     uint8
#  1127 subgroup_list_ltg_detail_ALL,AS7,BL7,EDS,HI7,MU7,WH7                                                                         uint8
#  1128 subgroup_list_ltg_detail_ALL,AS7,BL7,EDS,HI7,SWD,WH7                                                                         uint8
#  1129 subgroup_list_ltg_detail_ALL,AS7,BL7,HI7,MU7,SWD,WH7                                                                         uint8
#  1130 subgroup_list_ltg_detail_ALL,AS7,EDS,ELS,HI7,MU7,SWD,WH7                                                                     uint8
#  1131 subgroup_list_ltg_detail_ALL,AS7,EDS,ELS,HI7,SWD,WH7                                                                         uint8
#  1132 subgroup_list_ltg_detail_ALL,AS7,EDS,HI7,SWD,WH7                                                                             uint8
#  1133 subgroup_list_ltg_detail_ALL,AS7,WH7                                                                                         uint8
#  1134 subgroup_list_ltg_detail_ALL,BL7,EDS                                                                                         uint8
#  1135 subgroup_list_ltg_detail_ALL,BL7,EDS,ELS,HI7                                                                                 uint8
#  1136 subgroup_list_ltg_detail_ALL,BL7,EDS,ELS,HI7,MU7,SWD,WH7                                                                     uint8
#  1137 subgroup_list_ltg_detail_ALL,BL7,EDS,ELS,HI7,SWD                                                                             uint8
#  1138 subgroup_list_ltg_detail_ALL,BL7,EDS,ELS,HI7,SWD,WH7                                                                         uint8
#  1139 subgroup_list_ltg_detail_ALL,BL7,EDS,ELS,HI7,WH7                                                                             uint8
#  1140 subgroup_list_ltg_detail_ALL,BL7,EDS,HI7,MU7,SWD,WH7                                                                         uint8
#  1141 subgroup_list_ltg_detail_ALL,BL7,EDS,HI7,SWD                                                                                 uint8
#  1142 subgroup_list_ltg_detail_ALL,BL7,EDS,HI7,SWD,WH7                                                                             uint8
#  1143 subgroup_list_ltg_detail_ALL,BL7,EDS,HI7,WH7                                                                                 uint8
#  1144 subgroup_list_ltg_detail_ALL,BL7,EDS,MU7,SWD,WH7                                                                             uint8
#  1145 subgroup_list_ltg_detail_ALL,BL7,EDS,SWD                                                                                     uint8
#  1146 subgroup_list_ltg_detail_ALL,BL7,EDS,SWD,WH7                                                                                 uint8
#  1147 subgroup_list_ltg_detail_ALL,BL7,EDS,WH7                                                                                     uint8
#  1148 subgroup_list_ltg_detail_ALL,BL7,SWD                                                                                         uint8
#  1149 subgroup_list_ltg_detail_ALL,EDS                                                                                             uint8
#  1150 subgroup_list_ltg_detail_ALL,EDS,ELS,HI7                                                                                     uint8
#  1151 subgroup_list_ltg_detail_ALL,EDS,ELS,HI7,MU7,SWD,WH7                                                                         uint8
#  1152 subgroup_list_ltg_detail_ALL,EDS,ELS,HI7,SWD,WH7                                                                             uint8
#  1153 subgroup_list_ltg_detail_ALL,EDS,ELS,HI7,WH7                                                                                 uint8
#  1154 subgroup_list_ltg_detail_ALL,EDS,HI7,MU7,SWD,WH7                                                                             uint8
#  1155 subgroup_list_ltg_detail_ALL,EDS,HI7,SWD,WH7                                                                                 uint8
#  1156 subgroup_list_ltg_detail_ALL,EDS,HI7,WH7                                                                                     uint8
#  1157 subgroup_list_ltg_detail_ALL,EDS,MU7,SWD,WH7                                                                                 uint8
#  1158 subgroup_list_ltg_detail_ALL,EDS,SWD                                                                                         uint8
#  1159 subgroup_list_ltg_detail_ALL,EDS,SWD,WH7                                                                                     uint8
#  1160 subgroup_list_ltg_detail_ALL,EDS,WH7                                                                                         uint8
#  1161 subgroup_list_ltg_detail_ALL,HI7,WH7                                                                                         uint8
#  1162 subgroup_list_ltg_detail_ALL,SWD                                                                                             uint8
#  1163 subgroup_list_ltg_detail_ALL,WH7                                                                                             uint8
#  1164 dance_cat_arts_Y                                                                                                             uint8
#  1165 music_cat_arts_Y                                                                                                             uint8
#  1166 theatre_cat_arts_Y                                                                                                           uint8
#  1167 va_cat_arts_Y                                                                                                                uint8
#  1168 poverty_eq_LOW                                                                                                               uint8
#  1169 poverty_eq_NEITHER                                                                                                           uint8
#  1170 agency_code                                                                                                                  object
# dtypes: float64(903), object(1), uint8(267)
# memory usage: 4.9+ MB

# %%
import sklearn
import pandas as pd

print('Sklearn Version: ' + sklearn.__version__)
print('Pandas Version: ' + pd.__version__)
# Out:
# Sklearn Version: 0.22.1
# Pandas Version: 1.0.3

# %%
print('Output File Location:\r\n\r\n' + outputDir + inputFileName + '_ML.csv')
# Out:
# Output File Location:
#
# D:/BenepactLLC/Belk/NC_Report_Card_Data/2020/May 2020/2019/Machine Learning Datasets/PublicMiddleSchools2019_ML.csv
