# %% [markdown]
# # Create Public School Machine Learning Datasets
# ** This program creates all the _ML datasets in the NCEA repository.**
# * This notebook reads each School Dataset file located at \EducationDataNC\ *schoolYear* \School Datasets\ as input data.
# * Different school years are processed by changing the *schoolYear* parameter.
# * Different input / output files are processed / created by changing the *inputFileName* paramter in the cell below.
# * While a single program is used to create all the _ML datasets, one program copy per dataset is maintained in the repositiory so the dataset specific tranformation reports may be reviewed.
#
# **Datasets ending in ML are preprocessed for Machine Learning and go through the following transformations: **
# 1. Missing student body racial compositions are imputed using district averages.
# 2. Columns that have the same value in every single row are deleted.
# 3. Columns that have a unique value in every single row (all values are different) are deleted.
# 4. Empty columns (all values are NA or NULL) are deleted.
# 5. Numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# 6. Remaining numeric, non-race columns with missing values are imputed / populated with 0.  In many cases, schools are not reporting values when they are zero. However, mean imputation or some other more sophisticated strategy might be considered here.
# 7. Categorical / text based columns with > *uniqueThreshold* unique values are deleted.
# 8. All remaining categorical / text based columns are one-hot encoded.  In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# 9. Duplicated or highly similar columns with > 95% correlation are delelted.

# %%
#import required Libraries
import pandas as pd
import numpy as np
import os
import string

#**********************************************************************************
# Set the following variables before running this code!!!
#**********************************************************************************
#All raw data files are processed for the year below
schoolYear = 2019

#Location where copies of the raw data files will be read in from csv files.
dataDir = 'C:/Users/Jake/Documents/GitHub/EducationDataNC/' + str(schoolYear) + '/School Datasets/'

#Name of the file to be processed
inputFileName = 'PublicSchools2019'
#inputFileName = 'PublicHighSchools2019'
#inputFileName = 'PublicMiddleSchools2019'
#inputFileName = 'PublicElementarySchools2019'

#Input file being transformed for machine learning 
inputFile = dataDir + inputFileName + '.csv'

#Location where the new school datasets will be created.
outputDir = 'C:/Users/Jake/Documents/GitHub/EducationDataNC/' + str(schoolYear) + '/Machine Learning Datasets/'

#Missing Data Threshold (Per Column)
missingThreshold = 0.60

#Unique Value Threshold (Per Column)
#Delete Columns >  uniqueThreshold unique values prior to one-hot encoding. 
#(each unique value becomes a new column during one-hot encoding)
uniqueThreshold = 200

#Read in the School Data File
schoolData = pd.read_csv(inputFile, low_memory=False, dtype={'agency_code': object})
print('*********Start: Beginning Column and Row Counts********************************************')
schoolData.info(verbose=False)

#Select only public schools as charter schools are missing data for many columns.
schoolData = schoolData[(schoolData['designation_type'] == 'P')] #& (schoolData['avg_student_num'] > 0)] -rcd_admin missing

print('\r\n*********After: Selecting Only Public School Campuses**********************************')
schoolData.info(verbose=False)

#Save primary key
agency_code = schoolData['agency_code']
#Convert zip code to string
schoolData['zip'] = schoolData['zip'].astype('object')
# Out:
# *********Start: Beginning Column and Row Counts********************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2708 entries, 0 to 2707
# Columns: 1485 entries, agency_code to welcome_url
# dtypes: float64(1435), object(50)
# memory usage: 30.7+ MB
#
# *********After: Selecting Only Public School Campuses**********************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2517 entries, 2 to 2706
# Columns: 1485 entries, agency_code to welcome_url
# dtypes: float64(1435), object(50)
# memory usage: 28.5+ MB

# %% [markdown]
# # Prepare Consolidated Dataset for Machine Learning
# **Below we perform operations on the entire dataset to remove columns and update row values that could cause problems during machine learning.**

# %% [markdown]
# ## Student Body Racial Composition Features
# **Impute / update missing Student Body Racial Composition Fields using mean imputation.**
# * When there are no racial composition percentages for a particular school campus / agency_code, fill in the missing values

# %%
#Get Student Body Racial Composition Fields
raceCompositionFields = schoolData.filter(regex='Indian|Asian|Hispanic|Black|White|PacificIsland|TwoOrMore|Minority')\
                                  .filter(regex='Pct').columns
    
rowsBefore = schoolData[raceCompositionFields].isnull().T.any().T.sum()

#Update missing race values with the district average when avaiable (No district averages for charter schools) 
schoolData[raceCompositionFields] = schoolData.groupby('lea_code')[raceCompositionFields]\
                                              .transform(lambda x: x.fillna(x.mean()))

    #Review dataset contents after Racial Composition Imputation
print('*********After: Updating Missing Racial Compostion Values****************************')   
rowsAfter = schoolData[raceCompositionFields].isnull().T.any().T.sum()
rowsUpdated = rowsBefore - rowsAfter
print('Rows Updated / Imputed: ', rowsUpdated) 
print('\r\nTotal Rows Missing Racial Compositions By District Code') 
schoolData['lea_code'][schoolData[raceCompositionFields].isnull().T.any().T].value_counts()
# Out:
# *********After: Updating Missing Racial Compostion Values****************************
# Rows Updated / Imputed:  11
#
# Total Rows Missing Racial Compositions By District Code
# 010LEA    36
# 070LEA    15
# 090LEA    13
# 060LEA    11
# 020LEA    11
# 040LEA    10
# 080LEA     7
# 050LEA     6
# 030LEA     4
# Name: lea_code, dtype: int64

# %% [markdown]
# ## Remove Columns with Problematic Data
# **Here we remove entire columns that could cause problems during machine learning.  The following operations are performed:**
# * Remove any columns that have the same value in every single row.
# * Remove any columns that have a unique value in every single row (all values are different).
# * Remove empty columns (all values are NA or NULL).

# %%
#Remove any fields that have the same value in all rows
UniqueValueCounts = schoolData.nunique(dropna=False)
SingleValueCols = UniqueValueCounts[UniqueValueCounts == 1].index
schoolData = schoolData.drop(SingleValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with the same value in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(SingleValueCols))
# Out:
# *********After: Removing columns with the same value in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2517 entries, 2 to 2706
# Columns: 753 entries, agency_code to welcome_url
# dtypes: float64(709), object(44)
# memory usage: 14.5+ MB
#
# Columns Deleted:  732

# %%
#Remove any fields that have unique values in every row
schoolDataRecordCt = schoolData.shape[0]
UniqueValueCounts = schoolData.apply(pd.Series.nunique)
AllUniqueValueCols = UniqueValueCounts[UniqueValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(AllUniqueValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with unique values in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(AllUniqueValueCols))
# Out:
# *********After: Removing columns with unique values in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2517 entries, 2 to 2706
# Columns: 753 entries, agency_code to welcome_url
# dtypes: float64(709), object(44)
# memory usage: 14.5+ MB
#
# Columns Deleted:  0

# %%
#Remove any empty fields (null values in every row)
schoolDataRecordCt = schoolData.shape[0]
NullValueCounts = schoolData.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with null / blank values in every row.*************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with null / blank values in every row.*************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2517 entries, 2 to 2706
# Columns: 753 entries, agency_code to welcome_url
# dtypes: float64(709), object(44)
# memory usage: 14.5+ MB
#
# Columns Deleted:  0

# %% [markdown]
# ## Handle Other Missing Values Types
# * Here we eliminate any numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# * All remaining non-race, numeric column missing values are populated with 0.
# * In many cases, it seems that schools are not simply not reporting values when they are zero. However, mean imputation or some other strategy might be considered.

# %%
#Isolate continuous and categorical data types
#These are indexers into the schoolData dataframe and may be used similar to the schoolData dataframe 
sD_boolean = schoolData.loc[:, (schoolData.dtypes == bool) ]
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]
sD_continuous = schoolData.loc[:, (schoolData.dtypes != bool) & (schoolData.dtypes != object)]
print ("Boolean Columns: ", sD_boolean.shape[1])
print ("Nominal Columns: ", sD_nominal.shape[1])
print ("Continuous Columns: ", sD_continuous.shape[1])
print ("Columns Accounted for: ", sD_nominal.shape[1] + sD_continuous.shape[1] + sD_boolean.shape[1])
# Out:
# Boolean Columns:  0
# Nominal Columns:  44
# Continuous Columns:  709
# Columns Accounted for:  753

# %%
#Eliminate continuous columns with more than missingThreshold percentage of missing values
schoolDataRecordCt = sD_continuous.shape[0]
missingValueLimit = schoolDataRecordCt * missingThreshold
NullValueCounts = sD_continuous.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts >= missingValueLimit].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with >= missingThreshold % of missing values******')
schoolData.info(verbose=False)
print('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with >= missingThreshold % of missing values******
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2517 entries, 2 to 2706
# Columns: 252 entries, agency_code to welcome_url
# dtypes: float64(208), object(44)
# memory usage: 4.9+ MB
#
# Columns Deleted:  501

# %% [markdown]
# ## One-Hot Encoding of Categorical Variables
# **All categorical / string variables are converted to numberic variables via one hot encoding.  Each unique row value will become a new binary / numeric column in the dataset.**
# * All remaining categorical columns are one-hot encoded.
# * In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# * Prior to one-hot encoding, columns with > *uniqueThreshold* unique values are deleted.

# %%
#Delete categorical columns with > uniqueThreshold unique values 
#(Each unique value becomes a column during one-hot encoding)
oneHotUniqueValueCounts = schoolData[sD_nominal.columns].apply(lambda x: x.nunique())
oneHotUniqueValueCols = oneHotUniqueValueCounts[oneHotUniqueValueCounts >= uniqueThreshold].index
schoolData.drop(oneHotUniqueValueCols, axis=1, inplace=True) 

#Remove categorical columns which do not add value to machine learning
#Grades columns dropped since they all have indicator fields (device_access, device_home, BYOD)
#with less unique values to one-hot encode
schoolData.drop(['welcome_url','device_access_grades',
                 'device_home_grades','byod_grades'], axis=1, inplace=True) 

#Review dataset contents one hot high unique value drops
print('*********After: Removing columns with >= uniqueThreshold unique values***********')
schoolData.info(verbose=False)
print('\r\nColumns Deleted: ', len(oneHotUniqueValueCols))
print(oneHotUniqueValueCols)
print('Dropped Manually: welcome_url,device_access_grades,device_home_grades,byod_grades')
# Out:
# *********After: Removing columns with >= uniqueThreshold unique values***********
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2517 entries, 2 to 2706
# Columns: 238 entries, category_code to pct_ready_kea
# dtypes: float64(208), object(30)
# memory usage: 4.6+ MB
#
# Columns Deleted:  10
# Index(['agency_code', 'name', 'street_addr', 'city', 'zip', 'phone', 'url',
#        'School Name', 'Book_TitlesPer_Student', 'devices'],
#       dtype='object')
# Dropped Manually: welcome_url,device_access_grades,device_home_grades,byod_grades

# %%
#Isolate remaining categorical variables
begColumnCt = len(schoolData.columns)
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]

#one hot encode categorical variables
schoolData = pd.get_dummies(data=schoolData, 
                       columns=sD_nominal.columns, drop_first=True)

#Determine change in column count
endColumnCt = len(schoolData.columns)
columnsAdded = endColumnCt - begColumnCt

#Review dataset contents one hot high unique value drops
print('Columns To One-Hot Encode: ', len(sD_nominal.columns))
print('\r\n*********After: Adding New Columns Via One-Hot Encoding*************************')
schoolData.info(verbose=False)
print('\r\nNew Columns Created Via One-Hot Encoding: ', columnsAdded)
# Out:
# Columns To One-Hot Encode:  30
#
# *********After: Adding New Columns Via One-Hot Encoding*************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2517 entries, 2 to 2706
# Columns: 704 entries, IndianPct to BYOD_Yes
# dtypes: float64(208), uint8(496)
# memory usage: 5.2 MB
#
# New Columns Created Via One-Hot Encoding:  466

# %%
#Remove any fields that have the same value in all rows after one-hot encoding
UniqueValueCounts = schoolData.nunique(dropna=False)
SingleValueCols = UniqueValueCounts[UniqueValueCounts == 1].index
schoolData = schoolData.drop(SingleValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing one-hot encoded columns with the same value in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(SingleValueCols))
# Out:
# *********After: Removing one-hot encoded columns with the same value in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2517 entries, 2 to 2706
# Columns: 704 entries, IndianPct to BYOD_Yes
# dtypes: float64(208), uint8(496)
# memory usage: 5.2 MB
#
# Columns Deleted:  0

# %% [markdown]
# ## Impute any Remaining Missing Values as Zero

# %%
#Print out all the missing value rows
pd.set_option('display.max_rows', 1000)

print('\r\n*********The Remaining Missing Values Below will be set to Zero!*************************')

#Check for Missing values 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# *********The Remaining Missing Values Below will be set to Zero!*************************
#                            Variable Name  Number Missing Values
# 0                              IndianPct                    113
# 1                               AsianPct                    113
# 2                            HispanicPct                    113
# 3                               BlackPct                    113
# 4                               WhitePct                    113
# 5                       PacificIslandPct                    113
# 6                           TwoOrMorePct                    113
# 7                            MinorityPct                    113
# 8                          IndianMalePct                    113
# 9                           AsianMalePct                    113
# 10                       HispanicMalePct                    113
# 11                          BlackMalePct                    113
# 12                          WhiteMalePct                    113
# 13                  PacificIslandMalePct                    113
# 14                      TwoOrMoreMalePct                    113
# 15                       MinorityMalePct                    113
# 16                       IndianFemalePct                    113
# 17                        AsianFemalePct                    113
# 18                     HispanicFemalePct                    113
# 19                        BlackFemalePct                    113
# 20                        WhiteFemalePct                    113
# 21                     MinorityFemalePct                    113
# 22                PacificIslandFemalePct                    113
# 23                    TwoOrMoreFemalePct                    113
# 24                               pct_eds                      9
# 25                      eg_index_ALL_AIG                    617
# 26                      eg_index_ALL_ALL                     99
# 27                      eg_index_ALL_BL7                    629
# 28                      eg_index_ALL_EDS                    126
# 29                      eg_index_ALL_ELS                   1032
# 30                      eg_index_ALL_HI7                    574
# 31                      eg_index_ALL_SWD                    450
# 32                      eg_index_ALL_WH7                    355
# 33                       eg_index_MA_ALL                    623
# 34                       eg_index_RD_ALL                    620
# 35                      eg_score_ALL_AIG                    964
# 36                      eg_score_ALL_ALL                    120
# 37                      eg_score_ALL_BL7                    828
# 38                      eg_score_ALL_EDS                    194
# 39                      eg_score_ALL_ELS                   1347
# 40                      eg_score_ALL_HI7                    845
# 41                      eg_score_ALL_SWD                    759
# 42                      eg_score_ALL_WH7                    460
# 43                       eg_score_MA_ALL                    659
# 44                       eg_score_RD_ALL                    636
# 45                           pct_ALL_ELP                    773
# 46                           pct_EDS_ELP                    996
# 47                           pct_ELS_ELP                    773
# 48                           pct_FEM_ELP                   1284
# 49                           pct_HI7_ELP                    940
# 50                          pct_MALE_ELP                   1094
# 51                          pct_NSWD_ELP                    924
# 52           pct_met_Math Grades 3-8_LTG                    622
# 53        pct_met_Reading Grades 3-8_LTG                    622
# 54             pct_met_Total Targets_LTG                    109
# 55          pct_met_Math Grades 3-8_PART                    601
# 56       pct_met_Reading Grades 3-8_PART                    601
# 57       pct_met_Science Grades 5&8_PART                    770
# 58            pct_met_Total Targets_PART                    110
# 59      pct_Math Grades 3-8_ALL_PART_DET                    601
# 60      pct_Math Grades 3-8_BL7_PART_DET                   1216
# 61      pct_Math Grades 3-8_EDS_PART_DET                    652
# 62      pct_Math Grades 3-8_HI7_PART_DET                   1280
# 63      pct_Math Grades 3-8_SWD_PART_DET                   1229
# 64      pct_Math Grades 3-8_WH7_PART_DET                    923
# 65   pct_Reading Grades 3-8_ALL_PART_DET                    601
# 66   pct_Reading Grades 3-8_BL7_PART_DET                   1216
# 67   pct_Reading Grades 3-8_EDS_PART_DET                    652
# 68   pct_Reading Grades 3-8_HI7_PART_DET                   1280
# 69   pct_Reading Grades 3-8_SWD_PART_DET                   1229
# 70   pct_Reading Grades 3-8_WH7_PART_DET                    923
# 71   pct_Science Grades 5&8_ALL_PART_DET                    770
# 72   pct_Science Grades 5&8_EDS_PART_DET                   1109
# 73   pct_Science Grades 5&8_WH7_PART_DET                   1360
# 74                    pct_passed_eog_RTA                   1180
# 75                      pct_promoted_RTA                   1147
# 76                              ma_score                    659
# 77                              rd_score                    659
# 78                              sc_score                    745
# 79                             ach_score                    182
# 80                              eg_score                    193
# 81                             spg_score                    182
# 82                          ma_spg_score                    659
# 83                          rd_spg_score                    659
# 84                           ma_eg_score                    683
# 85                           rd_eg_score                    662
# 86                    aaa_score_ALL_SPG2                    150
# 87                    aaa_score_BL7_SPG2                    712
# 88                    aaa_score_EDS_SPG2                    192
# 89                    aaa_score_ELS_SPG2                   1139
# 90                    aaa_score_HI7_SPG2                    641
# 91                    aaa_score_SWD_SPG2                    442
# 92                    aaa_score_WH7_SPG2                    377
# 93                    ach_score_ALL_SPG2                    141
# 94                    ach_score_BL7_SPG2                    708
# 95                    ach_score_EDS_SPG2                    190
# 96                    ach_score_ELS_SPG2                   1139
# 97                    ach_score_HI7_SPG2                    641
# 98                    ach_score_SWD_SPG2                    442
# 99                    ach_score_WH7_SPG2                    370
# 100                    eg_score_ALL_SPG2                    154
# 101                    eg_score_BL7_SPG2                    837
# 102                    eg_score_EDS_SPG2                    216
# 103                    eg_score_ELS_SPG2                   1347
# 104                    eg_score_HI7_SPG2                    848
# 105                    eg_score_SWD_SPG2                    761
# 106                    eg_score_WH7_SPG2                    466
# 107                  scgs_score_ALL_SPG2                    783
# 108                  scgs_score_EDS_SPG2                   1155
# 109                  scgs_score_WH7_SPG2                   1372
# 110                   spg_score_ALL_SPG2                    102
# 111                   spg_score_BL7_SPG2                    672
# 112                   spg_score_EDS_SPG2                    151
# 113                   spg_score_ELS_SPG2                   1115
# 114                   spg_score_HI7_SPG2                    604
# 115                   spg_score_SWD_SPG2                    403
# 116                   spg_score_WH7_SPG2                    334
# 117                           stu_enroll                   1372
# 118                           cte_enroll                   1372
# 119                   cte_enrollment_pct                   1372
# 120                                  wap                     33
# 121                            wap_class                     33
# 122                         media_school                    148
# 123                                crime                     55
# 124                           short_term                     55
# 125                            long_term                     55
# 126                            expulsion                     55
# 127                      act_per1000_ALL                     52
# 128                      act_per1000_BL7                    402
# 129                      act_per1000_EDS                     79
# 130                      act_per1000_ELS                    966
# 131                      act_per1000_FEM                    163
# 132                      act_per1000_HI7                    441
# 133                     act_per1000_MALE                     71
# 134                      act_per1000_MU7                    879
# 135                      act_per1000_SWD                    216
# 136                      act_per1000_WH7                    212
# 137                      arr_per1000_ALL                     52
# 138                      arr_per1000_BL7                    402
# 139                      arr_per1000_EDS                     79
# 140                      arr_per1000_ELS                    966
# 141                      arr_per1000_FEM                    163
# 142                      arr_per1000_HI7                    441
# 143                     arr_per1000_MALE                     71
# 144                      arr_per1000_MU7                    879
# 145                      arr_per1000_SWD                    216
# 146                      arr_per1000_WH7                    212
# 147                      bha_per1000_ALL                     52
# 148                      bha_per1000_BL7                    402
# 149                      bha_per1000_EDS                     79
# 150                      bha_per1000_ELS                    966
# 151                      bha_per1000_FEM                    163
# 152                      bha_per1000_HI7                    441
# 153                     bha_per1000_MALE                     71
# 154                      bha_per1000_MU7                    879
# 155                      bha_per1000_SWD                    216
# 156                      bha_per1000_WH7                    212
# 157                      exp_per1000_ALL                     52
# 158                      exp_per1000_BL7                    402
# 159                      exp_per1000_EDS                     79
# 160                      exp_per1000_ELS                    966
# 161                      exp_per1000_FEM                    163
# 162                      exp_per1000_HI7                    441
# 163                     exp_per1000_MALE                     71
# 164                      exp_per1000_MU7                    879
# 165                      exp_per1000_SWD                    216
# 166                      exp_per1000_WH7                    212
# 167                      iss_per1000_ALL                     52
# 168                      iss_per1000_BL7                    403
# 169                      iss_per1000_EDS                     79
# 170                      iss_per1000_ELS                    966
# 171                      iss_per1000_FEM                    163
# 172                      iss_per1000_HI7                    441
# 173                     iss_per1000_MALE                     71
# 174                      iss_per1000_MU7                    879
# 175                      iss_per1000_SWD                    216
# 176                      iss_per1000_WH7                    212
# 177                      lts_per1000_ALL                     52
# 178                      lts_per1000_BL7                    402
# 179                      lts_per1000_EDS                     79
# 180                      lts_per1000_ELS                    966
# 181                      lts_per1000_FEM                    163
# 182                      lts_per1000_HI7                    441
# 183                     lts_per1000_MALE                     71
# 184                      lts_per1000_MU7                    879
# 185                      lts_per1000_SWD                    216
# 186                      lts_per1000_WH7                    212
# 187                      rpt_per1000_ALL                     52
# 188                      rpt_per1000_BL7                    402
# 189                      rpt_per1000_EDS                     79
# 190                      rpt_per1000_ELS                    966
# 191                      rpt_per1000_FEM                    163
# 192                      rpt_per1000_HI7                    441
# 193                     rpt_per1000_MALE                     71
# 194                      rpt_per1000_MU7                    879
# 195                      rpt_per1000_SWD                    216
# 196                      rpt_per1000_WH7                    212
# 197                      sts_per1000_ALL                     53
# 198                      sts_per1000_BL7                    408
# 199                      sts_per1000_EDS                     79
# 200                      sts_per1000_ELS                    966
# 201                      sts_per1000_FEM                    165
# 202                      sts_per1000_HI7                    442
# 203                     sts_per1000_MALE                     77
# 204                      sts_per1000_MU7                    879
# 205                      sts_per1000_SWD                    216
# 206                      sts_per1000_WH7                    213
# 207                        pct_ready_kea                   1212

# %%
#Replace all remaining NaN with 0
schoolData = schoolData.fillna(0)

#Check for Missing values after final imputation 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# Empty DataFrame
# Columns: [Variable Name, Number Missing Values]
# Index: []

# %% [markdown]
# ## Identify and Remove Highly Correlated Features
# **Find and remove any columns / features that are > 95% correlated**
# * https://stackoverflow.com/questions/39409866/correlation-heatmap
# * https://chrisalbon.com/machine_learning/feature_selection/drop_highly_correlated_features/
# * https://codeyarns.com/2015/04/20/how-to-change-font-size-in-seaborn/

# %%
# calculate the correlation matrix
corr_matrix  = schoolData.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
#Get all of the correlation values > 95%
x = np.where(upper > 0.95)

#Display all field combinations with > 95% correlation
cf = pd.DataFrame()
cf['Field1'] = upper.columns[x[1]]
cf['Field2'] = upper.index[x[0]]

#Get the correlation values for every field combination. (There must be a more pythonic way to do this!)
corr = [0] * len(cf)
for i in range(0, len(cf)):
    corr[i] =  upper[cf['Field1'][i]][cf['Field2'][i]] 
    
cf['Correlation'] = corr

print ('There are ', str(len(cf['Field1'])), ' field correlations > 95%.')
cf
# Out:
# There are  158  field correlations > 95%.
#                                   Field1                               Field2  \
# 0                          IndianMalePct                            IndianPct
# 1                        IndianFemalePct                            IndianPct
# 2                           AsianMalePct                             AsianPct
# 3                         AsianFemalePct                             AsianPct
# 4                        HispanicMalePct                          HispanicPct
# 5                      HispanicFemalePct                          HispanicPct
# 6                           BlackMalePct                             BlackPct
# 7                         BlackFemalePct                             BlackPct
# 8                           WhiteMalePct                             WhitePct
# 9                         WhiteFemalePct                             WhitePct
# 10                       MinorityMalePct                          MinorityPct
# 11                     MinorityFemalePct                          MinorityPct
# 12                       IndianFemalePct                        IndianMalePct
# 13                       eg_index_RD_ALL                      eg_index_MA_ALL
# 14                     eg_score_BL7_SPG2                     eg_score_ALL_BL7
# 15                     eg_score_EDS_SPG2                     eg_score_ALL_EDS
# 16                     eg_score_ELS_SPG2                     eg_score_ALL_ELS
# 17                     eg_score_HI7_SPG2                     eg_score_ALL_HI7
# 18                     eg_score_SWD_SPG2                     eg_score_ALL_SWD
# 19                     eg_score_WH7_SPG2                     eg_score_ALL_WH7
# 20                       eg_score_RD_ALL                      eg_score_MA_ALL
# 21                           pct_ELS_ELP                          pct_ALL_ELP
# 22       pct_met_Reading Grades 3-8_PART         pct_met_Math Grades 3-8_PART
# 23      pct_Math Grades 3-8_ALL_PART_DET         pct_met_Math Grades 3-8_PART
# 24   pct_Reading Grades 3-8_ALL_PART_DET         pct_met_Math Grades 3-8_PART
# 25      pct_Math Grades 3-8_ALL_PART_DET      pct_met_Reading Grades 3-8_PART
# 26   pct_Reading Grades 3-8_ALL_PART_DET      pct_met_Reading Grades 3-8_PART
# 27   pct_Science Grades 5&8_ALL_PART_DET      pct_met_Science Grades 5&8_PART
# 28   pct_Reading Grades 3-8_ALL_PART_DET     pct_Math Grades 3-8_ALL_PART_DET
# 29   pct_Reading Grades 3-8_BL7_PART_DET     pct_Math Grades 3-8_BL7_PART_DET
# 30   pct_Reading Grades 3-8_EDS_PART_DET     pct_Math Grades 3-8_EDS_PART_DET
# 31   pct_Reading Grades 3-8_HI7_PART_DET     pct_Math Grades 3-8_HI7_PART_DET
# 32   pct_Reading Grades 3-8_SWD_PART_DET     pct_Math Grades 3-8_SWD_PART_DET
# 33   pct_Reading Grades 3-8_WH7_PART_DET     pct_Math Grades 3-8_WH7_PART_DET
# 34                   scgs_score_WH7_SPG2  pct_Science Grades 5&8_WH7_PART_DET
# 35                              rd_score                             ma_score
# 36                          ma_spg_score                             ma_score
# 37                          rd_spg_score                             ma_score
# 38                          ma_spg_score                             rd_score
# 39                          rd_spg_score                             rd_score
# 40                             spg_score                            ach_score
# 41                          rd_spg_score                         ma_spg_score
# 42                    ach_score_BL7_SPG2                   aaa_score_BL7_SPG2
# 43                    ach_score_ELS_SPG2                   aaa_score_ELS_SPG2
# 44                    spg_score_ELS_SPG2                   aaa_score_ELS_SPG2
# 45                    ach_score_HI7_SPG2                   aaa_score_HI7_SPG2
# 46                    ach_score_WH7_SPG2                   aaa_score_WH7_SPG2
# 47                    spg_score_BL7_SPG2                   ach_score_BL7_SPG2
# 48                    spg_score_ELS_SPG2                   ach_score_ELS_SPG2
# 49                    spg_score_HI7_SPG2                   ach_score_HI7_SPG2
# 50                            cte_enroll                           stu_enroll
# 51                      act_per1000_MALE                      act_per1000_ALL
# 52                       act_per1000_SWD                      act_per1000_ALL
# 53                       act_per1000_WH7                      act_per1000_ALL
# 54                       act_per1000_SWD                     act_per1000_MALE
# 55                       act_per1000_WH7                     act_per1000_MALE
# 56                       act_per1000_WH7                      act_per1000_SWD
# 57                       arr_per1000_BL7                      arr_per1000_ALL
# 58                      arr_per1000_MALE                      arr_per1000_ALL
# 59                      arr_per1000_MALE                      arr_per1000_BL7
# 60                      bha_per1000_MALE                      bha_per1000_ALL
# 61                       exp_per1000_BL7                      exp_per1000_ALL
# 62                      exp_per1000_MALE                      exp_per1000_ALL
# 63                       exp_per1000_EDS                      exp_per1000_BL7
# 64                       exp_per1000_ELS                      exp_per1000_BL7
# 65                       exp_per1000_WH7                      exp_per1000_ELS
# 66                      iss_per1000_MALE                      iss_per1000_ALL
# 67                       lts_per1000_FEM                      lts_per1000_BL7
# 68                      county_Alexander                      lea_code_020LEA
# 69                      county_Alleghany                      lea_code_030LEA
# 70                          county_Anson                      lea_code_040LEA
# 71                           county_Ashe                      lea_code_050LEA
# 72                          county_Avery                      lea_code_060LEA
# 73                       county_Beaufort                      lea_code_070LEA
# 74                         county_Bertie                      lea_code_080LEA
# 75                         county_Bladen                      lea_code_090LEA
# 76                      county_Brunswick                      lea_code_100LEA
# 77                          county_Burke                      lea_code_120LEA
# 78                       county_Caldwell                      lea_code_140LEA
# 79                         county_Camden                      lea_code_150LEA
# 80                       county_Carteret                      lea_code_160LEA
# 81                        county_Caswell                      lea_code_170LEA
# 82                        county_Chatham                      lea_code_190LEA
# 83                       county_Cherokee                      lea_code_200LEA
# 84                         county_Chowan                      lea_code_210LEA
# 85                           county_Clay                      lea_code_220LEA
# 86                      county_Cleveland                      lea_code_230LEA
# 87                         county_Craven                      lea_code_250LEA
# 88                     county_Cumberland                      lea_code_260LEA
# 89                      county_Currituck                      lea_code_270LEA
# 90                           county_Dare                      lea_code_280LEA
# 91                          county_Davie                      lea_code_300LEA
# 92                         county_Duplin                      lea_code_310LEA
# 93                         county_Durham                      lea_code_320LEA
# 94                      county_Edgecombe                      lea_code_330LEA
# 95                        county_Forsyth                      lea_code_340LEA
# 96                       county_Franklin                      lea_code_350LEA
# 97                         county_Gaston                      lea_code_360LEA
# 98                          county_Gates                      lea_code_370LEA
# 99                         county_Graham                      lea_code_380LEA
# 100                     county_Granville                      lea_code_390LEA
# 101                        county_Greene                      lea_code_400LEA
# 102                      county_Guilford                      lea_code_410LEA
# 103                       county_Harnett                      lea_code_430LEA
# 104                       county_Haywood                      lea_code_440LEA
# 105                     county_Henderson                      lea_code_450LEA
# 106                      county_Hertford                      lea_code_460LEA
# 107                          county_Hoke                      lea_code_470LEA
# 108                          county_Hyde                      lea_code_480LEA
# 109                       county_Jackson                      lea_code_500LEA
# 110                      county_Johnston                      lea_code_510LEA
# 111                         county_Jones                      lea_code_520LEA
# 112                           county_Lee                      lea_code_530LEA
# 113                        county_Lenoir                      lea_code_540LEA
# 114                       county_Lincoln                      lea_code_550LEA
# 115                         county_Macon                      lea_code_560LEA
# 116                       county_Madison                      lea_code_570LEA
# 117                        county_Martin                      lea_code_580LEA
# 118                      county_McDowell                      lea_code_590LEA
# 119                   county_Mecklenburg                      lea_code_600LEA
# 120                      county_Mitchell                      lea_code_610LEA
# 121                    county_Montgomery                      lea_code_620LEA
# 122                         county_Moore                      lea_code_630LEA
# 123                          county_Nash                      lea_code_640LEA
# 124                   county_New Hanover                      lea_code_650LEA
# 125                   county_Northampton                      lea_code_660LEA
# 126                        county_Onslow                      lea_code_670LEA
# 127                       county_Pamlico                      lea_code_690LEA
# 128                    county_Pasquotank                      lea_code_700LEA
# 129                        county_Pender                      lea_code_710LEA
# 130                    county_Perquimans                      lea_code_720LEA
# 131                        county_Person                      lea_code_730LEA
# 132                          county_Pitt                      lea_code_740LEA
# 133                          county_Polk                      lea_code_750LEA
# 134                      county_Richmond                      lea_code_770LEA
# 135                       county_Robeson                      lea_code_780LEA
# 136                    county_Rockingham                      lea_code_790LEA
# 137                         county_Rowan                      lea_code_800LEA
# 138                    county_Rutherford                      lea_code_810LEA
# 139                      county_Scotland                      lea_code_830LEA
# 140                        county_Stanly                      lea_code_840LEA
# 141                        county_Stokes                      lea_code_850LEA
# 142                         county_Swain                      lea_code_870LEA
# 143                  county_Transylvania                      lea_code_880LEA
# 144                       county_Tyrrell                      lea_code_890LEA
# 145                         county_Union                      lea_code_900LEA
# 146                         county_Vance                      lea_code_910LEA
# 147                          county_Wake                      lea_code_920LEA
# 148                        county_Warren                      lea_code_930LEA
# 149                    county_Washington                      lea_code_940LEA
# 150                       county_Watauga                      lea_code_950LEA
# 151                         county_Wayne                      lea_code_960LEA
# 152                        county_Wilkes                      lea_code_970LEA
# 153                        county_Wilson                      lea_code_980LEA
# 154                        county_Yadkin                      lea_code_990LEA
# 155                        county_Yancey                      lea_code_995LEA
# 156                     digital_media_26                     grade_span_KG:07
# 157            subgroup_list_ALL,BL7,SWD                     grade_span_KG:13
#
#      Correlation
# 0       0.992748
# 1       0.992154
# 2       0.969875
# 3       0.971541
# 4       0.964099
# 5       0.963415
# 6       0.972500
# 7       0.968160
# 8       0.980191
# 9       0.977463
# 10      0.958893
# 11      0.954274
# 12      0.969929
# 13      0.991632
# 14      0.994385
# 15      0.967802
# 16      1.000000
# 17      0.997087
# 18      0.998154
# 19      0.995663
# 20      0.965394
# 21      1.000000
# 22      0.998290
# 23      0.988319
# 24      0.988457
# 25      0.988603
# 26      0.988860
# 27      0.994449
# 28      0.999988
# 29      0.999996
# 30      0.999992
# 31      0.999996
# 32      0.999944
# 33      0.999999
# 34      0.981765
# 35      0.967796
# 36      0.992478
# 37      0.964146
# 38      0.969575
# 39      0.993720
# 40      0.989466
# 41      0.976359
# 42      0.953749
# 43      0.984223
# 44      0.953008
# 45      0.983538
# 46      0.970569
# 47      0.966060
# 48      0.970940
# 49      0.963419
# 50      0.975520
# 51      0.984244
# 52      0.967167
# 53      0.975292
# 54      0.959426
# 55      0.955422
# 56      0.951531
# 57      0.967011
# 58      0.981624
# 59      0.977000
# 60      0.951716
# 61      0.950828
# 62      0.999664
# 63      0.980966
# 64      0.963452
# 65      0.956657
# 66      0.971040
# 67      0.957029
# 68      1.000000
# 69      1.000000
# 70      1.000000
# 71      1.000000
# 72      1.000000
# 73      1.000000
# 74      1.000000
# 75      1.000000
# 76      1.000000
# 77      1.000000
# 78      1.000000
# 79      1.000000
# 80      1.000000
# 81      1.000000
# 82      1.000000
# 83      1.000000
# 84      1.000000
# 85      1.000000
# 86      1.000000
# 87      1.000000
# 88      1.000000
# 89      1.000000
# 90      1.000000
# 91      1.000000
# 92      1.000000
# 93      1.000000
# 94      1.000000
# 95      1.000000
# 96      1.000000
# 97      1.000000
# 98      1.000000
# 99      1.000000
# 100     1.000000
# 101     1.000000
# 102     1.000000
# 103     1.000000
# 104     1.000000
# 105     1.000000
# 106     1.000000
# 107     1.000000
# 108     1.000000
# 109     1.000000
# 110     1.000000
# 111     1.000000
# 112     1.000000
# 113     1.000000
# 114     1.000000
# 115     1.000000
# 116     1.000000
# 117     1.000000
# 118     1.000000
# 119     1.000000
# 120     1.000000
# 121     1.000000
# 122     1.000000
# 123     1.000000
# 124     1.000000
# 125     1.000000
# 126     1.000000
# 127     1.000000
# 128     1.000000
# 129     1.000000
# 130     1.000000
# 131     1.000000
# 132     1.000000
# 133     1.000000
# 134     1.000000
# 135     0.987530
# 136     1.000000
# 137     1.000000
# 138     1.000000
# 139     1.000000
# 140     1.000000
# 141     1.000000
# 142     1.000000
# 143     1.000000
# 144     1.000000
# 145     1.000000
# 146     1.000000
# 147     1.000000
# 148     1.000000
# 149     1.000000
# 150     1.000000
# 151     1.000000
# 152     1.000000
# 153     1.000000
# 154     1.000000
# 155     1.000000
# 156     1.000000
# 157     1.000000

# %%
#The old way
#print('Dropping the following ', str(len(to_drop)), ' highly correlated fields.')
#to_drop

# Comparing highly correlated unique field names in field 1 vs field 2 list above will allow you to 
# remove the least amount of fields possible.  
#len(cf['Field1'].unique())
#len(cf['Field2'].unique())

print('Dropping the following ', str(len(cf['Field2'].unique())), ' highly correlated, unique fields.')
cf['Field2'].unique()
# Out:
# Dropping the following  247  highly correlated, unique fields.
# array(['IndianPct', 'AsianPct', 'HispanicPct', 'BlackPct', 'WhitePct',
#        'MinorityPct', 'IndianMalePct', 'MinorityMalePct', 'pct_ALL_ELP',
#        'pct_met_Math Grades 3-8_PART', 'pct_met_Reading Grades 3-8_PART',
#        'pct_met_Science Grades 5&8_PART',
#        'pct_Math Grades 3-8_ALL_PART_DET',
#        'pct_Math Grades 3-8_BL7_PART_DET',
#        'pct_Math Grades 3-8_EDS_PART_DET',
#        'pct_Math Grades 3-8_HI7_PART_DET',
#        'pct_Math Grades 3-8_SWD_PART_DET',
#        'pct_Math Grades 3-8_WH7_PART_DET',
#        'pct_Science Grades 5&8_WH7_PART_DET', 'ma_score', 'rd_score',
#        'ach_score', 'ma_spg_score', 'aaa_score_BL7_SPG2',
#        'aaa_score_ELS_SPG2', 'aaa_score_HI7_SPG2', 'aaa_score_WH7_SPG2',
#        'ach_score_BL7_SPG2', 'ach_score_ELS_SPG2', 'ach_score_HI7_SPG2',
#        'avg_student_num', 'pct_ALL_CHRON_ABSENT', 'stu_enroll',
#        'highqual_class_pct_E', 'crime', 'arre_per1000_ALL',
#        'arre_per1000_BL7', 'crime_per1000_ALL', 'crime_per1000_ELS',
#        'crime_per1000_MU7', 'exp_per1000_ALL', 'exp_per1000_BL7',
#        'iss_per1000_ALL', 'avg_size_01_SAR', 'lea_code_020LEA',
#        'lea_code_030LEA', 'lea_code_040LEA', 'lea_code_050LEA',
#        'lea_code_060LEA', 'lea_code_070LEA', 'lea_code_080LEA',
#        'lea_code_090LEA', 'lea_code_100LEA', 'lea_code_110LEA',
#        'lea_code_111LEA', 'lea_code_120LEA', 'lea_code_130LEA',
#        'lea_code_132LEA', 'lea_code_140LEA', 'lea_code_150LEA',
#        'lea_code_160LEA', 'lea_code_170LEA', 'lea_code_180LEA',
#        'lea_code_181LEA', 'lea_code_182LEA', 'lea_code_190LEA',
#        'lea_code_200LEA', 'lea_code_210LEA', 'lea_code_220LEA',
#        'lea_code_230LEA', 'lea_code_240LEA', 'lea_code_241LEA',
#        'lea_code_250LEA', 'lea_code_260LEA', 'lea_code_270LEA',
#        'lea_code_280LEA', 'lea_code_290LEA', 'lea_code_291LEA',
#        'lea_code_292LEA', 'lea_code_300LEA', 'lea_code_310LEA',
#        'lea_code_320LEA', 'lea_code_330LEA', 'lea_code_340LEA',
#        'lea_code_350LEA', 'lea_code_360LEA', 'lea_code_370LEA',
#        'lea_code_380LEA', 'lea_code_390LEA', 'lea_code_400LEA',
#        'lea_code_410LEA', 'lea_code_420LEA', 'lea_code_421LEA',
#        'lea_code_422LEA', 'lea_code_430LEA', 'lea_code_440LEA',
#        'lea_code_450LEA', 'lea_code_460LEA', 'lea_code_470LEA',
#        'lea_code_480LEA', 'lea_code_490LEA', 'lea_code_491LEA',
#        'lea_code_500LEA', 'lea_code_510LEA', 'lea_code_520LEA',
#        'lea_code_530LEA', 'lea_code_540LEA', 'lea_code_550LEA',
#        'lea_code_560LEA', 'lea_code_570LEA', 'lea_code_580LEA',
#        'lea_code_590LEA', 'lea_code_600LEA', 'lea_code_610LEA',
#        'lea_code_620LEA', 'lea_code_630LEA', 'lea_code_640LEA',
#        'lea_code_650LEA', 'lea_code_660LEA', 'lea_code_670LEA',
#        'lea_code_680LEA', 'lea_code_681LEA', 'lea_code_690LEA',
#        'lea_code_700LEA', 'lea_code_710LEA', 'lea_code_720LEA',
#        'lea_code_730LEA', 'lea_code_740LEA', 'lea_code_750LEA',
#        'lea_code_760LEA', 'lea_code_761LEA', 'lea_code_770LEA',
#        'lea_code_780LEA', 'lea_code_790LEA', 'lea_code_800LEA',
#        'lea_code_810LEA', 'lea_code_820LEA', 'lea_code_821LEA',
#        'lea_code_830LEA', 'lea_code_840LEA', 'lea_code_850LEA',
#        'lea_code_860LEA', 'lea_code_861LEA', 'lea_code_862LEA',
#        'lea_code_870LEA', 'lea_code_880LEA', 'lea_code_890LEA',
#        'lea_code_900LEA', 'lea_code_910LEA', 'lea_code_920LEA',
#        'lea_code_930LEA', 'lea_code_940LEA', 'lea_code_950LEA',
#        'lea_code_960LEA', 'lea_code_970LEA', 'lea_code_980LEA',
#        'lea_code_990LEA', 'lea_code_995LEA', 'county_Alexander',
#        'county_Alleghany', 'county_Anson', 'county_Ashe', 'county_Avery',
#        'county_Beaufort', 'county_Bertie', 'county_Bladen',
#        'county_Brunswick', 'county_Burke', 'county_Caldwell',
#        'county_Camden', 'county_Carteret', 'county_Caswell',
#        'county_Chatham', 'county_Cherokee', 'county_Chowan',
#        'county_Clay', 'county_Cleveland', 'county_Craven',
#        'county_Cumberland', 'county_Currituck', 'county_Dare',
#        'county_Davie', 'county_Duplin', 'county_Durham',
#        'county_Edgecombe', 'county_Forsyth', 'county_Franklin',
#        'county_Gaston', 'county_Gates', 'county_Graham',
#        'county_Granville', 'county_Greene', 'county_Guilford',
#        'county_Harnett', 'county_Haywood', 'county_Henderson',
#        'county_Hertford', 'county_Hoke', 'county_Hyde', 'county_Jackson',
#        'county_Johnston', 'county_Jones', 'county_Lee', 'county_Lenoir',
#        'county_Lincoln', 'county_Macon', 'county_Madison',
#        'county_Martin', 'county_McDowell', 'county_Mecklenburg',
#        'county_Mitchell', 'county_Montgomery', 'county_Moore',
#        'county_Nash', 'county_New Hanover', 'county_Northampton',
#        'county_Onslow', 'county_Pamlico', 'county_Pasquotank',
#        'county_Pender', 'county_Perquimans', 'county_Person',
#        'county_Pitt', 'county_Polk', 'county_Richmond', 'county_Robeson',
#        'county_Rockingham', 'county_Rowan', 'county_Rutherford',
#        'county_Scotland', 'county_Stanly', 'county_Stokes',
#        'county_Swain', 'county_Transylvania', 'county_Tyrrell',
#        'county_Union', 'county_Vance', 'county_Wake', 'county_Warren',
#        'county_Washington', 'county_Watauga', 'county_Wayne',
#        'county_Wilkes', 'county_Wilson', 'county_Yadkin', 'county_Yancey',
#        'grade_span_KG:13'], dtype=object)

# %%
#Check columns before drop 
print('\r\n*********Before: Dropping Highly Correlated Fields*************************************')
schoolData.info(verbose=False)

# Drop the highly correlated features from our training data 
#schoolData = schoolData.drop(to_drop, axis=1)
schoolData = schoolData.drop(cf['Field2'], axis=1)

#Check columns after drop 
print('\r\n*********After: Dropping Highly Correlated Fields**************************************')
schoolData.info(verbose=False)
# Out:
# *********Before: Dropping Highly Correlated Fields*************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2517 entries, 2 to 2706
# Columns: 704 entries, IndianPct to BYOD_Yes
# dtypes: float64(208), uint8(496)
# memory usage: 5.2 MB
#
# *********After: Dropping Highly Correlated Fields**************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2517 entries, 2 to 2706
# Columns: 565 entries, PacificIslandPct to BYOD_Yes
# dtypes: float64(159), uint8(406)
# memory usage: 4.0 MB

# %%
#Restore the unit_code before saving
schoolData['agency_code'] = agency_code
#Save the final dataset to a .csv file
schoolData.to_csv(outputDir + inputFileName + '_ML.csv', sep=',', index=False)

# %%
print('*********FINAL DATASET DETAILS*********************************************************\r\n')
schoolData.info(verbose=True)
# Out:
# *********FINAL DATASET DETAILS*********************************************************
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2517 entries, 2 to 2706
# Data columns (total 566 columns):
# PacificIslandPct                                                                                                    float64
# TwoOrMorePct                                                                                                        float64
# AsianMalePct                                                                                                        float64
# HispanicMalePct                                                                                                     float64
# BlackMalePct                                                                                                        float64
# WhiteMalePct                                                                                                        float64
# PacificIslandMalePct                                                                                                float64
# TwoOrMoreMalePct                                                                                                    float64
# MinorityMalePct                                                                                                     float64
# IndianFemalePct                                                                                                     float64
# AsianFemalePct                                                                                                      float64
# HispanicFemalePct                                                                                                   float64
# BlackFemalePct                                                                                                      float64
# WhiteFemalePct                                                                                                      float64
# MinorityFemalePct                                                                                                   float64
# PacificIslandFemalePct                                                                                              float64
# TwoOrMoreFemalePct                                                                                                  float64
# pct_eds                                                                                                             float64
# eg_index_ALL_AIG                                                                                                    float64
# eg_index_ALL_ALL                                                                                                    float64
# eg_index_ALL_BL7                                                                                                    float64
# eg_index_ALL_EDS                                                                                                    float64
# eg_index_ALL_ELS                                                                                                    float64
# eg_index_ALL_HI7                                                                                                    float64
# eg_index_ALL_SWD                                                                                                    float64
# eg_index_ALL_WH7                                                                                                    float64
# eg_index_RD_ALL                                                                                                     float64
# eg_score_ALL_AIG                                                                                                    float64
# eg_score_ALL_ALL                                                                                                    float64
# eg_score_RD_ALL                                                                                                     float64
# pct_EDS_ELP                                                                                                         float64
# pct_ELS_ELP                                                                                                         float64
# pct_FEM_ELP                                                                                                         float64
# pct_HI7_ELP                                                                                                         float64
# pct_MALE_ELP                                                                                                        float64
# pct_NSWD_ELP                                                                                                        float64
# pct_met_Math Grades 3-8_LTG                                                                                         float64
# pct_met_Reading Grades 3-8_LTG                                                                                      float64
# pct_met_Total Targets_LTG                                                                                           float64
# pct_met_Total Targets_PART                                                                                          float64
# pct_Reading Grades 3-8_ALL_PART_DET                                                                                 float64
# pct_Reading Grades 3-8_BL7_PART_DET                                                                                 float64
# pct_Reading Grades 3-8_EDS_PART_DET                                                                                 float64
# pct_Reading Grades 3-8_HI7_PART_DET                                                                                 float64
# pct_Reading Grades 3-8_SWD_PART_DET                                                                                 float64
# pct_Reading Grades 3-8_WH7_PART_DET                                                                                 float64
# pct_Science Grades 5&8_ALL_PART_DET                                                                                 float64
# pct_Science Grades 5&8_EDS_PART_DET                                                                                 float64
# pct_passed_eog_RTA                                                                                                  float64
# pct_promoted_RTA                                                                                                    float64
# sc_score                                                                                                            float64
# eg_score                                                                                                            float64
# spg_score                                                                                                           float64
# rd_spg_score                                                                                                        float64
# ma_eg_score                                                                                                         float64
# rd_eg_score                                                                                                         float64
# aaa_score_ALL_SPG2                                                                                                  float64
# aaa_score_EDS_SPG2                                                                                                  float64
# aaa_score_SWD_SPG2                                                                                                  float64
# ach_score_ALL_SPG2                                                                                                  float64
# ach_score_EDS_SPG2                                                                                                  float64
# ach_score_SWD_SPG2                                                                                                  float64
# ach_score_WH7_SPG2                                                                                                  float64
# eg_score_ALL_SPG2                                                                                                   float64
# eg_score_BL7_SPG2                                                                                                   float64
# eg_score_EDS_SPG2                                                                                                   float64
# eg_score_ELS_SPG2                                                                                                   float64
# eg_score_HI7_SPG2                                                                                                   float64
# eg_score_SWD_SPG2                                                                                                   float64
# eg_score_WH7_SPG2                                                                                                   float64
# scgs_score_ALL_SPG2                                                                                                 float64
# scgs_score_EDS_SPG2                                                                                                 float64
# scgs_score_WH7_SPG2                                                                                                 float64
# spg_score_ALL_SPG2                                                                                                  float64
# spg_score_BL7_SPG2                                                                                                  float64
# spg_score_EDS_SPG2                                                                                                  float64
# spg_score_ELS_SPG2                                                                                                  float64
# spg_score_HI7_SPG2                                                                                                  float64
# spg_score_SWD_SPG2                                                                                                  float64
# spg_score_WH7_SPG2                                                                                                  float64
# cte_enroll                                                                                                          float64
# cte_enrollment_pct                                                                                                  float64
# wap                                                                                                                 float64
# wap_class                                                                                                           float64
# media_school                                                                                                        float64
# crime                                                                                                               float64
# short_term                                                                                                          float64
# long_term                                                                                                           float64
# expulsion                                                                                                           float64
# act_per1000_BL7                                                                                                     float64
# act_per1000_EDS                                                                                                     float64
# act_per1000_ELS                                                                                                     float64
# act_per1000_FEM                                                                                                     float64
# act_per1000_HI7                                                                                                     float64
# act_per1000_MU7                                                                                                     float64
# act_per1000_WH7                                                                                                     float64
# arr_per1000_EDS                                                                                                     float64
# arr_per1000_ELS                                                                                                     float64
# arr_per1000_FEM                                                                                                     float64
# arr_per1000_HI7                                                                                                     float64
# arr_per1000_MALE                                                                                                    float64
# arr_per1000_MU7                                                                                                     float64
# arr_per1000_SWD                                                                                                     float64
# arr_per1000_WH7                                                                                                     float64
# bha_per1000_BL7                                                                                                     float64
# bha_per1000_EDS                                                                                                     float64
# bha_per1000_ELS                                                                                                     float64
# bha_per1000_FEM                                                                                                     float64
# bha_per1000_HI7                                                                                                     float64
# bha_per1000_MALE                                                                                                    float64
# bha_per1000_MU7                                                                                                     float64
# bha_per1000_SWD                                                                                                     float64
# bha_per1000_WH7                                                                                                     float64
# exp_per1000_EDS                                                                                                     float64
# exp_per1000_FEM                                                                                                     float64
# exp_per1000_HI7                                                                                                     float64
# exp_per1000_MALE                                                                                                    float64
# exp_per1000_MU7                                                                                                     float64
# exp_per1000_SWD                                                                                                     float64
# exp_per1000_WH7                                                                                                     float64
# iss_per1000_BL7                                                                                                     float64
# iss_per1000_EDS                                                                                                     float64
# iss_per1000_ELS                                                                                                     float64
# iss_per1000_FEM                                                                                                     float64
# iss_per1000_HI7                                                                                                     float64
# iss_per1000_MALE                                                                                                    float64
# iss_per1000_MU7                                                                                                     float64
# iss_per1000_SWD                                                                                                     float64
# iss_per1000_WH7                                                                                                     float64
# lts_per1000_ALL                                                                                                     float64
# lts_per1000_EDS                                                                                                     float64
# lts_per1000_ELS                                                                                                     float64
# lts_per1000_FEM                                                                                                     float64
# lts_per1000_HI7                                                                                                     float64
# lts_per1000_MALE                                                                                                    float64
# lts_per1000_MU7                                                                                                     float64
# lts_per1000_SWD                                                                                                     float64
# lts_per1000_WH7                                                                                                     float64
# rpt_per1000_ALL                                                                                                     float64
# rpt_per1000_BL7                                                                                                     float64
# rpt_per1000_EDS                                                                                                     float64
# rpt_per1000_ELS                                                                                                     float64
# rpt_per1000_FEM                                                                                                     float64
# rpt_per1000_HI7                                                                                                     float64
# rpt_per1000_MALE                                                                                                    float64
# rpt_per1000_MU7                                                                                                     float64
# rpt_per1000_SWD                                                                                                     float64
# rpt_per1000_WH7                                                                                                     float64
# sts_per1000_ALL                                                                                                     float64
# sts_per1000_BL7                                                                                                     float64
# sts_per1000_EDS                                                                                                     float64
# sts_per1000_ELS                                                                                                     float64
# sts_per1000_FEM                                                                                                     float64
# sts_per1000_HI7                                                                                                     float64
# sts_per1000_MALE                                                                                                    float64
# sts_per1000_MU7                                                                                                     float64
# sts_per1000_SWD                                                                                                     float64
# sts_per1000_WH7                                                                                                     float64
# pct_ready_kea                                                                                                       float64
# category_code_E                                                                                                     uint8
# category_code_H                                                                                                     uint8
# category_code_I                                                                                                     uint8
# category_code_M                                                                                                     uint8
# category_code_T                                                                                                     uint8
# lea_code_110LEA                                                                                                     uint8
# lea_code_111LEA                                                                                                     uint8
# lea_code_130LEA                                                                                                     uint8
# lea_code_132LEA                                                                                                     uint8
# lea_code_180LEA                                                                                                     uint8
# lea_code_181LEA                                                                                                     uint8
# lea_code_182LEA                                                                                                     uint8
# lea_code_240LEA                                                                                                     uint8
# lea_code_241LEA                                                                                                     uint8
# lea_code_290LEA                                                                                                     uint8
# lea_code_291LEA                                                                                                     uint8
# lea_code_292LEA                                                                                                     uint8
# lea_code_295LEA                                                                                                     uint8
# lea_code_420LEA                                                                                                     uint8
# lea_code_421LEA                                                                                                     uint8
# lea_code_422LEA                                                                                                     uint8
# lea_code_490LEA                                                                                                     uint8
# lea_code_491LEA                                                                                                     uint8
# lea_code_680LEA                                                                                                     uint8
# lea_code_681LEA                                                                                                     uint8
# lea_code_760LEA                                                                                                     uint8
# lea_code_761LEA                                                                                                     uint8
# lea_code_820LEA                                                                                                     uint8
# lea_code_821LEA                                                                                                     uint8
# lea_code_860LEA                                                                                                     uint8
# lea_code_861LEA                                                                                                     uint8
# lea_code_862LEA                                                                                                     uint8
# county_Alexander                                                                                                    uint8
# county_Alleghany                                                                                                    uint8
# county_Anson                                                                                                        uint8
# county_Ashe                                                                                                         uint8
# county_Avery                                                                                                        uint8
# county_Beaufort                                                                                                     uint8
# county_Bertie                                                                                                       uint8
# county_Bladen                                                                                                       uint8
# county_Brunswick                                                                                                    uint8
# county_Buncombe                                                                                                     uint8
# county_Burke                                                                                                        uint8
# county_Cabarrus                                                                                                     uint8
# county_Caldwell                                                                                                     uint8
# county_Camden                                                                                                       uint8
# county_Carteret                                                                                                     uint8
# county_Caswell                                                                                                      uint8
# county_Catawba                                                                                                      uint8
# county_Chatham                                                                                                      uint8
# county_Cherokee                                                                                                     uint8
# county_Chowan                                                                                                       uint8
# county_Clay                                                                                                         uint8
# county_Cleveland                                                                                                    uint8
# county_Columbus                                                                                                     uint8
# county_Craven                                                                                                       uint8
# county_Cumberland                                                                                                   uint8
# county_Currituck                                                                                                    uint8
# county_Dare                                                                                                         uint8
# county_Davidson                                                                                                     uint8
# county_Davie                                                                                                        uint8
# county_Duplin                                                                                                       uint8
# county_Durham                                                                                                       uint8
# county_Edgecombe                                                                                                    uint8
# county_Forsyth                                                                                                      uint8
# county_Franklin                                                                                                     uint8
# county_Gaston                                                                                                       uint8
# county_Gates                                                                                                        uint8
# county_Graham                                                                                                       uint8
# county_Granville                                                                                                    uint8
# county_Greene                                                                                                       uint8
# county_Guilford                                                                                                     uint8
# county_Halifax                                                                                                      uint8
# county_Harnett                                                                                                      uint8
# county_Haywood                                                                                                      uint8
# county_Henderson                                                                                                    uint8
# county_Hertford                                                                                                     uint8
# county_Hoke                                                                                                         uint8
# county_Hyde                                                                                                         uint8
# county_Iredell                                                                                                      uint8
# county_Jackson                                                                                                      uint8
# county_Johnston                                                                                                     uint8
# county_Jones                                                                                                        uint8
# county_Lee                                                                                                          uint8
# county_Lenoir                                                                                                       uint8
# county_Lincoln                                                                                                      uint8
# county_Macon                                                                                                        uint8
# county_Madison                                                                                                      uint8
# county_Martin                                                                                                       uint8
# county_McDowell                                                                                                     uint8
# county_Mecklenburg                                                                                                  uint8
# county_Mitchell                                                                                                     uint8
# county_Montgomery                                                                                                   uint8
# county_Moore                                                                                                        uint8
# county_Nash                                                                                                         uint8
# county_New Hanover                                                                                                  uint8
# county_Northampton                                                                                                  uint8
# county_Onslow                                                                                                       uint8
# county_Orange                                                                                                       uint8
# county_Pamlico                                                                                                      uint8
# county_Pasquotank                                                                                                   uint8
# county_Pender                                                                                                       uint8
# county_Perquimans                                                                                                   uint8
# county_Person                                                                                                       uint8
# county_Pitt                                                                                                         uint8
# county_Polk                                                                                                         uint8
# county_Randolph                                                                                                     uint8
# county_Richmond                                                                                                     uint8
# county_Robeson                                                                                                      uint8
# county_Rockingham                                                                                                   uint8
# county_Rowan                                                                                                        uint8
# county_Rutherford                                                                                                   uint8
# county_Sampson                                                                                                      uint8
# county_Scotland                                                                                                     uint8
# county_Stanly                                                                                                       uint8
# county_Stokes                                                                                                       uint8
# county_Surry                                                                                                        uint8
# county_Swain                                                                                                        uint8
# county_Transylvania                                                                                                 uint8
# county_Tyrrell                                                                                                      uint8
# county_Union                                                                                                        uint8
# county_Vance                                                                                                        uint8
# county_Wake                                                                                                         uint8
# county_Warren                                                                                                       uint8
# county_Washington                                                                                                   uint8
# county_Watauga                                                                                                      uint8
# county_Wayne                                                                                                        uint8
# county_Wilkes                                                                                                       uint8
# county_Wilson                                                                                                       uint8
# county_Yadkin                                                                                                       uint8
# county_Yancey                                                                                                       uint8
# stree_addr2_201 Hwy 321 South                                                                                       uint8
# stree_addr2_600 Building                                                                                            uint8
# stree_addr2_Building 10                                                                                             uint8
# stree_addr2_East Carolina University                                                                                uint8
# stree_addr2_Governor Morehead                                                                                       uint8
# stree_addr2_Haigler-Overcash Education Center                                                                       uint8
# stree_addr2_J Knuckles Science Annex                                                                                uint8
# stree_addr2_NCCU-Robinson Science Building                                                                          uint8
# stree_addr2_PO Box 69                                                                                               uint8
# stree_addr2_Parker Building                                                                                         uint8
# stree_addr2_Suite 744                                                                                               uint8
# stree_addr2_WECHS Bldg.ND122                                                                                        uint8
# grade_span_02:03:00                                                                                                 uint8
# grade_span_02:04:00                                                                                                 uint8
# grade_span_02:05:00                                                                                                 uint8
# grade_span_03:05:00                                                                                                 uint8
# grade_span_03:12:00                                                                                                 uint8
# grade_span_04:05:00                                                                                                 uint8
# grade_span_04:06:00                                                                                                 uint8
# grade_span_04:08:00                                                                                                 uint8
# grade_span_04:09:00                                                                                                 uint8
# grade_span_05:06:00                                                                                                 uint8
# grade_span_05:08:00                                                                                                 uint8
# grade_span_06:07:00                                                                                                 uint8
# grade_span_06:08:00                                                                                                 uint8
# grade_span_06:09:00                                                                                                 uint8
# grade_span_06:10:00                                                                                                 uint8
# grade_span_06:12:00                                                                                                 uint8
# grade_span_06:13:00                                                                                                 uint8
# grade_span_07:08:00                                                                                                 uint8
# grade_span_07:12:00                                                                                                 uint8
# grade_span_07:13:00                                                                                                 uint8
# grade_span_08:12:00                                                                                                 uint8
# grade_span_08:13:00                                                                                                 uint8
# grade_span_09:10:00                                                                                                 uint8
# grade_span_09:11:00                                                                                                 uint8
# grade_span_09:12:00                                                                                                 uint8
# grade_span_09:13:00                                                                                                 uint8
# grade_span_10:12:00                                                                                                 uint8
# grade_span_11:12:00                                                                                                 uint8
# grade_span_11:13:00                                                                                                 uint8
# grade_span_6                                                                                                        uint8
# grade_span_9                                                                                                        uint8
# grade_span_KG:01                                                                                                    uint8
# grade_span_KG:02                                                                                                    uint8
# grade_span_KG:03                                                                                                    uint8
# grade_span_KG:04                                                                                                    uint8
# grade_span_KG:05                                                                                                    uint8
# grade_span_KG:06                                                                                                    uint8
# grade_span_KG:08                                                                                                    uint8
# grade_span_KG:12                                                                                                    uint8
# grade_span_NG                                                                                                       uint8
# grade_span_P0:01                                                                                                    uint8
# grade_span_P0:02                                                                                                    uint8
# grade_span_P0:03                                                                                                    uint8
# grade_span_P0:04                                                                                                    uint8
# grade_span_P0:05                                                                                                    uint8
# grade_span_P0:08                                                                                                    uint8
# grade_span_P0:12                                                                                                    uint8
# grade_span_P0:13                                                                                                    uint8
# grade_span_P1:02                                                                                                    uint8
# grade_span_P1:05                                                                                                    uint8
# grade_span_P1:12                                                                                                    uint8
# grade_span_P2:02                                                                                                    uint8
# grade_span_P2:03                                                                                                    uint8
# grade_span_P2:04                                                                                                    uint8
# grade_span_P2:05                                                                                                    uint8
# grade_span_P2:07                                                                                                    uint8
# grade_span_P2:08                                                                                                    uint8
# grade_span_P2:12                                                                                                    uint8
# grade_span_P2:13                                                                                                    uint8
# grade_span_P2:KG                                                                                                    uint8
# grade_span_P3:01                                                                                                    uint8
# grade_span_P3:02                                                                                                    uint8
# grade_span_P3:03                                                                                                    uint8
# grade_span_P3:04                                                                                                    uint8
# grade_span_P3:05                                                                                                    uint8
# grade_span_P3:06                                                                                                    uint8
# grade_span_P3:08                                                                                                    uint8
# grade_span_P3:12                                                                                                    uint8
# grade_span_P3:KG                                                                                                    uint8
# grade_span_PK:01                                                                                                    uint8
# grade_span_PK:02                                                                                                    uint8
# grade_span_PK:03                                                                                                    uint8
# grade_span_PK:04                                                                                                    uint8
# grade_span_PK:05                                                                                                    uint8
# grade_span_PK:06                                                                                                    uint8
# grade_span_PK:08                                                                                                    uint8
# grade_span_PK:09                                                                                                    uint8
# grade_span_PK:12                                                                                                    uint8
# school_type_CTE School                                                                                              uint8
# school_type_EC School                                                                                               uint8
# school_type_Regular School                                                                                          uint8
# calendar_type_Traditional                                                                                           uint8
# calendar_type_Year Round                                                                                            uint8
# csi_lp_Y                                                                                                            uint8
# csi_lg_Y                                                                                                            uint8
# tsi_cu_Y                                                                                                            uint8
# tsi_at_Y                                                                                                            uint8
# ...
# subgroup_list_ALL,AS7,BL7,EDS,HI7,MU7,SWD,WH7                                                                       uint8
# subgroup_list_ALL,AS7,BL7,EDS,HI7,MU7,WH7                                                                           uint8
# subgroup_list_ALL,AS7,BL7,EDS,HI7,SWD,WH7                                                                           uint8
# subgroup_list_ALL,AS7,BL7,EDS,HI7,WH7                                                                               uint8
# subgroup_list_ALL,AS7,BL7,EDS,SWD,WH7                                                                               uint8
# subgroup_list_ALL,AS7,BL7,EDS,WH7                                                                                   uint8
# subgroup_list_ALL,AS7,BL7,ELS,HI7,SWD,WH7                                                                           uint8
# subgroup_list_ALL,AS7,BL7,HI7,MU7,SWD,WH7                                                                           uint8
# subgroup_list_ALL,AS7,EDS,ELS,HI7,MU7,SWD,WH7                                                                       uint8
# subgroup_list_ALL,AS7,EDS,ELS,HI7,SWD,WH7                                                                           uint8
# subgroup_list_ALL,AS7,EDS,ELS,WH7                                                                                   uint8
# subgroup_list_ALL,AS7,EDS,HI7,SWD,WH7                                                                               uint8
# subgroup_list_ALL,AS7,ELS,SWD,WH7                                                                                   uint8
# subgroup_list_ALL,AS7,ELS,WH7                                                                                       uint8
# subgroup_list_ALL,AS7,SWD,WH7                                                                                       uint8
# subgroup_list_ALL,AS7,WH7                                                                                           uint8
# subgroup_list_ALL,BL7                                                                                               uint8
# subgroup_list_ALL,BL7,EDS                                                                                           uint8
# subgroup_list_ALL,BL7,EDS,ELS,HI7                                                                                   uint8
# subgroup_list_ALL,BL7,EDS,ELS,HI7,MU7,SWD,WH7                                                                       uint8
# subgroup_list_ALL,BL7,EDS,ELS,HI7,SWD                                                                               uint8
# subgroup_list_ALL,BL7,EDS,ELS,HI7,SWD,WH7                                                                           uint8
# subgroup_list_ALL,BL7,EDS,ELS,HI7,WH7                                                                               uint8
# subgroup_list_ALL,BL7,EDS,HI7                                                                                       uint8
# subgroup_list_ALL,BL7,EDS,HI7,MU7,SWD                                                                               uint8
# subgroup_list_ALL,BL7,EDS,HI7,MU7,SWD,WH7                                                                           uint8
# subgroup_list_ALL,BL7,EDS,HI7,SWD                                                                                   uint8
# subgroup_list_ALL,BL7,EDS,HI7,SWD,WH7                                                                               uint8
# subgroup_list_ALL,BL7,EDS,HI7,WH7                                                                                   uint8
# subgroup_list_ALL,BL7,EDS,MU7,SWD,WH7                                                                               uint8
# subgroup_list_ALL,BL7,EDS,SWD                                                                                       uint8
# subgroup_list_ALL,BL7,EDS,SWD,WH7                                                                                   uint8
# subgroup_list_ALL,BL7,EDS,WH7                                                                                       uint8
# subgroup_list_ALL,BL7,HI7,SWD,WH7                                                                                   uint8
# subgroup_list_ALL,BL7,SWD                                                                                           uint8
# subgroup_list_ALL,BL7,WH7                                                                                           uint8
# subgroup_list_ALL,EDS                                                                                               uint8
# subgroup_list_ALL,EDS,ELS,HI7                                                                                       uint8
# subgroup_list_ALL,EDS,ELS,HI7,MU7,SWD,WH7                                                                           uint8
# subgroup_list_ALL,EDS,ELS,HI7,SWD,WH7                                                                               uint8
# subgroup_list_ALL,EDS,ELS,HI7,WH7                                                                                   uint8
# subgroup_list_ALL,EDS,ELS,SWD,WH7                                                                                   uint8
# subgroup_list_ALL,EDS,HI7                                                                                           uint8
# subgroup_list_ALL,EDS,HI7,MU7,SWD,WH7                                                                               uint8
# subgroup_list_ALL,EDS,HI7,SWD,WH7                                                                                   uint8
# subgroup_list_ALL,EDS,HI7,WH7                                                                                       uint8
# subgroup_list_ALL,EDS,MU7,SWD,WH7                                                                                   uint8
# subgroup_list_ALL,EDS,SWD                                                                                           uint8
# subgroup_list_ALL,EDS,SWD,WH7                                                                                       uint8
# subgroup_list_ALL,EDS,WH7                                                                                           uint8
# subgroup_list_ALL,HI7                                                                                               uint8
# subgroup_list_ALL,HI7,SWD,WH7                                                                                       uint8
# subgroup_list_ALL,HI7,WH7                                                                                           uint8
# subgroup_list_ALL,SWD                                                                                               uint8
# subgroup_list_ALL,SWD,WH7                                                                                           uint8
# subgroup_list_ALL,WH7                                                                                               uint8
# ma_grade_B                                                                                                          uint8
# ma_grade_C                                                                                                          uint8
# ma_grade_D                                                                                                          uint8
# ma_grade_F                                                                                                          uint8
# rd_grade_B                                                                                                          uint8
# rd_grade_C                                                                                                          uint8
# rd_grade_D                                                                                                          uint8
# rd_grade_F                                                                                                          uint8
# eg_status_Met                                                                                                       uint8
# eg_status_NotMet                                                                                                    uint8
# spg_grade_A+NG                                                                                                      uint8
# spg_grade_B                                                                                                         uint8
# spg_grade_C                                                                                                         uint8
# spg_grade_D                                                                                                         uint8
# spg_grade_F                                                                                                         uint8
# ma_eg_status_Met                                                                                                    uint8
# ma_eg_status_NotMet                                                                                                 uint8
# rd_eg_status_Met                                                                                                    uint8
# rd_eg_status_NotMet                                                                                                 uint8
# digital_media_0                                                                                                     uint8
# digital_media_1                                                                                                     uint8
# digital_media_10                                                                                                    uint8
# digital_media_100                                                                                                   uint8
# digital_media_11                                                                                                    uint8
# digital_media_12                                                                                                    uint8
# digital_media_13                                                                                                    uint8
# digital_media_14                                                                                                    uint8
# digital_media_15                                                                                                    uint8
# digital_media_16                                                                                                    uint8
# digital_media_17                                                                                                    uint8
# digital_media_18                                                                                                    uint8
# digital_media_19                                                                                                    uint8
# digital_media_2                                                                                                     uint8
# digital_media_20                                                                                                    uint8
# digital_media_21                                                                                                    uint8
# digital_media_23                                                                                                    uint8
# digital_media_24                                                                                                    uint8
# digital_media_25                                                                                                    uint8
# digital_media_26                                                                                                    uint8
# digital_media_27                                                                                                    uint8
# digital_media_29                                                                                                    uint8
# digital_media_3                                                                                                     uint8
# digital_media_30                                                                                                    uint8
# digital_media_31                                                                                                    uint8
# digital_media_32                                                                                                    uint8
# digital_media_33                                                                                                    uint8
# digital_media_34                                                                                                    uint8
# digital_media_35                                                                                                    uint8
# digital_media_36                                                                                                    uint8
# digital_media_38                                                                                                    uint8
# digital_media_39                                                                                                    uint8
# digital_media_4                                                                                                     uint8
# digital_media_40                                                                                                    uint8
# digital_media_41                                                                                                    uint8
# digital_media_42                                                                                                    uint8
# digital_media_43                                                                                                    uint8
# digital_media_45                                                                                                    uint8
# digital_media_46                                                                                                    uint8
# digital_media_48                                                                                                    uint8
# digital_media_5                                                                                                     uint8
# digital_media_50                                                                                                    uint8
# digital_media_54                                                                                                    uint8
# digital_media_6                                                                                                     uint8
# digital_media_64                                                                                                    uint8
# digital_media_68                                                                                                    uint8
# digital_media_7                                                                                                     uint8
# digital_media_8                                                                                                     uint8
# digital_media_9                                                                                                     uint8
# digital_media_92                                                                                                    uint8
# digital_media_97                                                                                                    uint8
# device_access_Yes                                                                                                   uint8
# device_home_Yes                                                                                                     uint8
# BYOD_Yes                                                                                                            uint8
# agency_code                                                                                                         object
# dtypes: float64(159), object(1), uint8(406)
# memory usage: 4.1+ MB

# %%
import sklearn
import pandas as pd

print('Sklearn Version: ' + sklearn.__version__)
print('Pandas Version: ' + pd.__version__)
# Out:
# Sklearn Version: 0.21.2
# Pandas Version: 0.23.4

# %%
print('Output File Location:\r\n\r\n' + outputDir + inputFileName + '_ML.csv')
# Out:
# Output File Location:
#
# C:/Users/Jake/Documents/GitHub/EducationDataNC/2019/Machine Learning Datasets/PublicSchools2019_ML.csv
