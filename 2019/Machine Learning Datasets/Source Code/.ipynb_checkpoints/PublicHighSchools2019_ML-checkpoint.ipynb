# %% [markdown]
# # Create Public School Machine Learning Datasets
# ** This program creates all the _ML datasets in the NCEA repository.**
# * This notebook reads each School Dataset file located at \EducationDataNC\ *schoolYear* \School Datasets\ as input data.
# * Different school years are processed by changing the *schoolYear* parameter.
# * Different input / output files are processed / created by changing the *inputFileName* paramter in the cell below.
# * While a single program is used to create all the _ML datasets, one program copy per dataset is maintained in the repositiory so the dataset specific tranformation reports may be reviewed.
#
# **Datasets ending in ML are preprocessed for Machine Learning and go through the following transformations: **
# 1. Missing student body racial compositions are imputed using district averages.
# 2. Columns that have the same value in every single row are deleted.
# 3. Columns that have a unique value in every single row (all values are different) are deleted.
# 4. Empty columns (all values are NA or NULL) are deleted.
# 5. Numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# 6. Remaining numeric, non-race columns with missing values are imputed / populated with 0.  In many cases, schools are not reporting values when they are zero. However, mean imputation or some other more sophisticated strategy might be considered here.
# 7. Categorical / text based columns with > *uniqueThreshold* unique values are deleted.
# 8. All remaining categorical / text based columns are one-hot encoded.  In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# 9. Duplicated or highly similar columns with > 95% correlation are delelted.

# %%
#import required Libraries
import pandas as pd
import numpy as np
import os
import string

#**********************************************************************************
# Set the following variables before running this code!!!
#**********************************************************************************
#All raw data files are processed for the year below
schoolYear = 2019

#Location where copies of the raw data files will be read in from csv files.
dataDir = 'D:/BenepactLLC/Belk/NC_Report_Card_Data/2020/June 2020/' + str(schoolYear) + '/School Datasets/'

#Name of the file to be processed
#inputFileName = 'PublicSchools2019'
inputFileName = 'PublicHighSchools2019'
#inputFileName = 'PublicMiddleSchools2019'
#inputFileName = 'PublicElementarySchools2019'

#Input file being transformed for machine learning 
inputFile = dataDir + inputFileName + '.csv'

#Location where the new school datasets will be created.
outputDir = 'D:/BenepactLLC/Belk/NC_Report_Card_Data/2020/June 2020/' + str(schoolYear) + '/Machine Learning Datasets/'

#Missing Data Threshold (Per Column)
missingThreshold = 0.60

#Unique Value Threshold (Per Column)
#Delete Columns >  uniqueThreshold unique values prior to one-hot encoding. 
#(each unique value becomes a new column during one-hot encoding)
uniqueThreshold = 200

#Read in the School Data File
schoolData = pd.read_csv(inputFile, low_memory=False, dtype={'agency_code': object})
print('*********Start: Beginning Column and Row Counts********************************************')
schoolData.info(verbose=False)

#Select only public schools as charter schools are missing data for many columns.
schoolData = schoolData[(schoolData['designation_type_loc'] == 'P')] #& (schoolData['avg_student_num'] > 0)] -rcd_admin missing

print('\r\n*********After: Selecting Only Public School Campuses**********************************')
schoolData.info(verbose=False)

#Save primary key
agency_code = schoolData['agency_code']
#Convert zip code to string
schoolData['zip_loc'] = schoolData['zip_loc'].astype('object')
# Out:
# *********Start: Beginning Column and Row Counts********************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 716 entries, 0 to 715
# Columns: 4649 entries, agency_code to welcome_url
# dtypes: float64(4611), object(38)
# memory usage: 25.4+ MB
#
# *********After: Selecting Only Public School Campuses**********************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 644 entries, 2 to 715
# Columns: 4649 entries, agency_code to welcome_url
# dtypes: float64(4611), object(38)
# memory usage: 22.8+ MB

# %%
schoolData.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 644 entries, 2 to 715
# Data columns (total 4649 columns):
#  #    Column                                         Dtype
# ---   ------                                         -----
#  0    agency_code                                    object
#  1    category_code_loc                              object
#  2    agency_level_loc                               object
#  3    lea_code_loc                                   object
#  4    designation_type_loc                           object
#  5    name_loc                                       object
#  6    county_loc                                     object
#  7    street_addr_loc                                object
#  8    stree_addr2_loc                                object
#  9    city_loc                                       object
#  10   state_loc                                      object
#  11   zip_loc                                        object
#  12   phone_loc                                      object
#  13   grade_span_loc                                 object
#  14   school_type_loc                                object
#  15   calendar_type_loc                              object
#  16   url_loc                                        object
#  17   super_name_loc                                 object
#  18   title_i_loc                                    object
#  19   esea_loc                                       float64
#  20   stem_loc                                       object
#  21   purple_star_loc                                object
#  22   lea                                            float64
#  23   lea_name                                       object
#  24   school                                         float64
#  25   school_name                                    object
#  26   indian_pct                                     float64
#  27   asian_pct                                      float64
#  28   hispanic_pct                                   float64
#  29   black_pct                                      float64
#  30   white_pct                                      float64
#  31   pacific_island_pct                             float64
#  32   two_or_more_pct                                float64
#  33   minority_pct                                   float64
#  34   indian_male_pct                                float64
#  35   asian_male_pct                                 float64
#  36   hispanic_male_pct                              float64
#  37   black_male_pct                                 float64
#  38   white_male_pct                                 float64
#  39   pacific_island_male_pct                        float64
#  40   two_or_more_male_pct                           float64
#  41   minority_male_pct                              float64
#  42   indian_female_pct                              float64
#  43   asian_female_pct                               float64
#  44   hispanic_female_pct                            float64
#  45   black_female_pct                               float64
#  46   white_female_pct                               float64
#  47   minority_female_pct                            float64
#  48   pacific_island_female_pct                      float64
#  49   two_or_more_female_pct                         float64
#  50   pct_ma_03_aapart                               float64
#  51   pct_ma_04_aapart                               float64
#  52   pct_ma_05_aapart                               float64
#  53   pct_ma_06_aapart                               float64
#  54   pct_ma_07_aapart                               float64
#  55   pct_ma_08_aapart                               float64
#  56   pct_ma_gs_aapart                               float64
#  57   pct_ma_hs_aapart                               float64
#  58   pct_rd_03_aapart                               float64
#  59   pct_rd_04_aapart                               float64
#  60   pct_rd_05_aapart                               float64
#  61   pct_rd_06_aapart                               float64
#  62   pct_rd_07_aapart                               float64
#  63   pct_rd_08_aapart                               float64
#  64   pct_rd_gs_aapart                               float64
#  65   pct_rd_hs_aapart                               float64
#  66   pct_sc_05_aapart                               float64
#  67   pct_sc_08_aapart                               float64
#  68   pct_sc_gs_aapart                               float64
#  69   pct_sc_hs_aapart                               float64
#  70   pct_acall_aig_act                              float64
#  71   pct_acall_all_act                              float64
#  72   pct_acall_am7_act                              float64
#  73   pct_acall_as7_act                              float64
#  74   pct_acall_bl7_act                              float64
#  75   pct_acall_eds_act                              float64
#  76   pct_acall_els_act                              float64
#  77   pct_acall_fcs_act                              float64
#  78   pct_acall_fem_act                              float64
#  79   pct_acall_hi7_act                              float64
#  80   pct_acall_hms_act                              float64
#  81   pct_acall_male_act                             float64
#  82   pct_acall_mig_act                              float64
#  83   pct_acall_mil_act                              float64
#  84   pct_acall_mu7_act                              float64
#  85   pct_acall_neds_act                             float64
#  86   pct_acall_nswd_act                             float64
#  87   pct_acall_swd_act                              float64
#  88   pct_acall_wh7_act                              float64
#  89   pct_acco_aig_act                               float64
#  90   pct_acco_all_act                               float64
#  91   pct_acco_am7_act                               float64
#  92   pct_acco_as7_act                               float64
#  93   pct_acco_bl7_act                               float64
#  94   pct_acco_eds_act                               float64
#  95   pct_acco_els_act                               float64
#  96   pct_acco_fem_act                               float64
#  97   pct_acco_hi7_act                               float64
#  98   pct_acco_hms_act                               float64
#  99   pct_acco_male_act                              float64
#  100  pct_acco_mil_act                               float64
#  101  pct_acco_mu7_act                               float64
#  102  pct_acco_neds_act                              float64
#  103  pct_acco_nswd_act                              float64
#  104  pct_acco_swd_act                               float64
#  105  pct_acco_wh7_act                               float64
#  106  pct_acen_aig_act                               float64
#  107  pct_acen_all_act                               float64
#  108  pct_acen_am7_act                               float64
#  109  pct_acen_as7_act                               float64
#  110  pct_acen_bl7_act                               float64
#  111  pct_acen_eds_act                               float64
#  112  pct_acen_els_act                               float64
#  113  pct_acen_fem_act                               float64
#  114  pct_acen_hi7_act                               float64
#  115  pct_acen_hms_act                               float64
#  116  pct_acen_male_act                              float64
#  117  pct_acen_mil_act                               float64
#  118  pct_acen_mu7_act                               float64
#  119  pct_acen_neds_act                              float64
#  120  pct_acen_nswd_act                              float64
#  121  pct_acen_swd_act                               float64
#  122  pct_acen_wh7_act                               float64
#  123  pct_acma_aig_act                               float64
#  124  pct_acma_all_act                               float64
#  125  pct_acma_am7_act                               float64
#  126  pct_acma_as7_act                               float64
#  127  pct_acma_bl7_act                               float64
#  128  pct_acma_eds_act                               float64
#  129  pct_acma_els_act                               float64
#  130  pct_acma_fem_act                               float64
#  131  pct_acma_hi7_act                               float64
#  132  pct_acma_hms_act                               float64
#  133  pct_acma_male_act                              float64
#  134  pct_acma_mil_act                               float64
#  135  pct_acma_mu7_act                               float64
#  136  pct_acma_neds_act                              float64
#  137  pct_acma_nswd_act                              float64
#  138  pct_acma_swd_act                               float64
#  139  pct_acma_wh7_act                               float64
#  140  pct_acrd_aig_act                               float64
#  141  pct_acrd_all_act                               float64
#  142  pct_acrd_am7_act                               float64
#  143  pct_acrd_as7_act                               float64
#  144  pct_acrd_bl7_act                               float64
#  145  pct_acrd_eds_act                               float64
#  146  pct_acrd_els_act                               float64
#  147  pct_acrd_fem_act                               float64
#  148  pct_acrd_hi7_act                               float64
#  149  pct_acrd_hms_act                               float64
#  150  pct_acrd_male_act                              float64
#  151  pct_acrd_mil_act                               float64
#  152  pct_acrd_mu7_act                               float64
#  153  pct_acrd_neds_act                              float64
#  154  pct_acrd_nswd_act                              float64
#  155  pct_acrd_swd_act                               float64
#  156  pct_acrd_wh7_act                               float64
#  157  pct_acsc_aig_act                               float64
#  158  pct_acsc_all_act                               float64
#  159  pct_acsc_am7_act                               float64
#  160  pct_acsc_as7_act                               float64
#  161  pct_acsc_bl7_act                               float64
#  162  pct_acsc_eds_act                               float64
#  163  pct_acsc_els_act                               float64
#  164  pct_acsc_fem_act                               float64
#  165  pct_acsc_hi7_act                               float64
#  166  pct_acsc_hms_act                               float64
#  167  pct_acsc_male_act                              float64
#  168  pct_acsc_mil_act                               float64
#  169  pct_acsc_mu7_act                               float64
#  170  pct_acsc_neds_act                              float64
#  171  pct_acsc_nswd_act                              float64
#  172  pct_acsc_swd_act                               float64
#  173  pct_acsc_wh7_act                               float64
#  174  pct_acwr_aig_act                               float64
#  175  pct_acwr_all_act                               float64
#  176  pct_acwr_am7_act                               float64
#  177  pct_acwr_as7_act                               float64
#  178  pct_acwr_bl7_act                               float64
#  179  pct_acwr_eds_act                               float64
#  180  pct_acwr_els_act                               float64
#  181  pct_acwr_fem_act                               float64
#  182  pct_acwr_hi7_act                               float64
#  183  pct_acwr_hms_act                               float64
#  184  pct_acwr_male_act                              float64
#  185  pct_acwr_mil_act                               float64
#  186  pct_acwr_mu7_act                               float64
#  187  pct_acwr_neds_act                              float64
#  188  pct_acwr_nswd_act                              float64
#  189  pct_acwr_swd_act                               float64
#  190  pct_acwr_wh7_act                               float64
#  191  pct_aig_awa                                    float64
#  192  pct_all_awa                                    float64
#  193  pct_am7_awa                                    float64
#  194  pct_as7_awa                                    float64
#  195  pct_bl7_awa                                    float64
#  196  pct_eds_awa                                    float64
#  197  pct_els_awa                                    float64
#  198  pct_fem_awa                                    float64
#  199  pct_hi7_awa                                    float64
#  200  pct_hms_awa                                    float64
#  201  pct_male_awa                                   float64
#  202  pct_mig_awa                                    float64
#  203  pct_mil_awa                                    float64
#  204  pct_mu7_awa                                    float64
#  205  pct_neds_awa                                   float64
#  206  pct_nswd_awa                                   float64
#  207  pct_swd_awa                                    float64
#  208  pct_wh7_awa                                    float64
#  209  pct_ext_aig_cgr                                float64
#  210  pct_ext_all_cgr                                float64
#  211  pct_ext_am7_cgr                                float64
#  212  pct_ext_as7_cgr                                float64
#  213  pct_ext_bl7_cgr                                float64
#  214  pct_ext_eds_cgr                                float64
#  215  pct_ext_els_cgr                                float64
#  216  pct_ext_fem_cgr                                float64
#  217  pct_ext_hi7_cgr                                float64
#  218  pct_ext_hms_cgr                                float64
#  219  pct_ext_male_cgr                               float64
#  220  pct_ext_mig_cgr                                float64
#  221  pct_ext_mu7_cgr                                float64
#  222  pct_ext_neds_cgr                               float64
#  223  pct_ext_nswd_cgr                               float64
#  224  pct_ext_swd_cgr                                float64
#  225  pct_ext_wh7_cgr                                float64
#  226  pct_std_aig_cgr                                float64
#  227  pct_std_all_cgr                                float64
#  228  pct_std_am7_cgr                                float64
#  229  pct_std_as7_cgr                                float64
#  230  pct_std_bl7_cgr                                float64
#  231  pct_std_eds_cgr                                float64
#  232  pct_std_els_cgr                                float64
#  233  pct_std_fcs_cgr                                float64
#  234  pct_std_fem_cgr                                float64
#  235  pct_std_hi7_cgr                                float64
#  236  pct_std_hms_cgr                                float64
#  237  pct_std_male_cgr                               float64
#  238  pct_std_mig_cgr                                float64
#  239  pct_std_mu7_cgr                                float64
#  240  pct_std_neds_cgr                               float64
#  241  pct_std_nswd_cgr                               float64
#  242  pct_std_swd_cgr                                float64
#  243  pct_std_wh7_cgr                                float64
#  244  pct_eds                                        float64
#  245  eg_index_all_aig_eg                            float64
#  246  eg_index_all_all_eg                            float64
#  247  eg_index_all_am7_eg                            float64
#  248  eg_index_all_as7_eg                            float64
#  249  eg_index_all_bl7_eg                            float64
#  250  eg_index_all_eds_eg                            float64
#  251  eg_index_all_els_eg                            float64
#  252  eg_index_all_hi7_eg                            float64
#  253  eg_index_all_mu7_eg                            float64
#  254  eg_index_all_swd_eg                            float64
#  255  eg_index_all_wh7_eg                            float64
#  256  eg_index_ma_all_eg                             float64
#  257  eg_index_rd_all_eg                             float64
#  258  eg_score_all_aig_eg                            float64
#  259  eg_score_all_all_eg                            float64
#  260  eg_score_all_am7_eg                            float64
#  261  eg_score_all_as7_eg                            float64
#  262  eg_score_all_bl7_eg                            float64
#  263  eg_score_all_eds_eg                            float64
#  264  eg_score_all_els_eg                            float64
#  265  eg_score_all_hi7_eg                            float64
#  266  eg_score_all_mu7_eg                            float64
#  267  eg_score_all_swd_eg                            float64
#  268  eg_score_all_wh7_eg                            float64
#  269  eg_score_ma_all_eg                             float64
#  270  eg_score_rd_all_eg                             float64
#  271  den_aig_elp                                    float64
#  272  den_all_elp                                    float64
#  273  den_as7_elp                                    float64
#  274  den_bl7_elp                                    float64
#  275  den_eds_elp                                    float64
#  276  den_els_elp                                    float64
#  277  den_fem_elp                                    float64
#  278  den_hi7_elp                                    float64
#  279  den_hms_elp                                    float64
#  280  den_male_elp                                   float64
#  281  den_mig_elp                                    float64
#  282  den_mil_elp                                    float64
#  283  den_neds_elp                                   float64
#  284  den_nswd_elp                                   float64
#  285  den_swd_elp                                    float64
#  286  den_wh7_elp                                    float64
#  287  pct_aig_elp                                    float64
#  288  pct_all_elp                                    float64
#  289  pct_as7_elp                                    float64
#  290  pct_bl7_elp                                    float64
#  291  pct_eds_elp                                    float64
#  292  pct_els_elp                                    float64
#  293  pct_fem_elp                                    float64
#  294  pct_hi7_elp                                    float64
#  295  pct_hms_elp                                    float64
#  296  pct_male_elp                                   float64
#  297  pct_mig_elp                                    float64
#  298  pct_mil_elp                                    float64
#  299  pct_neds_elp                                   float64
#  300  pct_nswd_elp                                   float64
#  301  pct_swd_elp                                    float64
#  302  pct_wh7_elp                                    float64
#  303  csi_lp_esea_desig                              object
#  304  csi_lg_esea_desig                              object
#  305  tsi_cu_esea_desig                              object
#  306  tsi_at_esea_desig                              object
#  307  grad_project_gp                                object
#  308  pct_prof_6gr_irm                               float64
#  309  pct_prof_9gr_irm                               float64
#  310  lp_school_lowperf                              object
#  311  rlp_school_lowperf                             object
#  312  clpc_school_lowperf                            object
#  313  pct_met_4_year_graduation_rate_ltg             float64
#  314  pct_met_el_progress_ltg                        float64
#  315  pct_met_math_grade_11_ltg                      float64
#  316  pct_met_math_grades_3-8_ltg                    float64
#  317  pct_met_reading_grade_10_ltg                   float64
#  318  pct_met_reading_grades_3-8_ltg                 float64
#  319  pct_met_total_targets_ltg                      float64
#  320  target_assign_4_year_graduation_rate_ltg       float64
#  321  target_assign_el_progress_ltg                  float64
#  322  target_assign_math_grade_11_ltg                float64
#  323  target_assign_math_grades_3-8_ltg              float64
#  324  target_assign_reading_grade_10_ltg             float64
#  325  target_assign_reading_grades_3-8_ltg           float64
#  326  target_assign_total_targets_ltg                float64
#  327  target_met_4_year_graduation_rate_ltg          float64
#  328  target_met_el_progress_ltg                     float64
#  329  target_met_math_grade_11_ltg                   float64
#  330  target_met_math_grades_3-8_ltg                 float64
#  331  target_met_reading_grade_10_ltg                float64
#  332  target_met_reading_grades_3-8_ltg              float64
#  333  target_met_total_targets_ltg                   float64
#  334  target_list_ltg_detail                         object
#  335  subgroup_list_ltg_detail                       object
#  336  pct_aig_mcr                                    float64
#  337  pct_all_mcr                                    float64
#  338  pct_am7_mcr                                    float64
#  339  pct_as7_mcr                                    float64
#  340  pct_bl7_mcr                                    float64
#  341  pct_eds_mcr                                    float64
#  342  pct_els_mcr                                    float64
#  343  pct_fem_mcr                                    float64
#  344  pct_hi7_mcr                                    float64
#  345  pct_hms_mcr                                    float64
#  346  pct_male_mcr                                   float64
#  347  pct_mig_mcr                                    float64
#  348  pct_mil_mcr                                    float64
#  349  pct_mu7_mcr                                    float64
#  350  pct_neds_mcr                                   float64
#  351  pct_nswd_mcr                                   float64
#  352  pct_swd_mcr                                    float64
#  353  pct_wh7_mcr                                    float64
#  354  pct_met_act_workkeys_part                      float64
#  355  pct_met_biology_part                           float64
#  356  pct_met_english_ii_part                        float64
#  357  pct_met_high_school_math_part                  float64
#  358  pct_met_math_grades_3-8_part                   float64
#  359  pct_met_reading_grades_3-8_part                float64
#  360  pct_met_science_grades_5&8_part                float64
#  361  pct_met_the_act_part                           float64
#  362  pct_met_total_targets_part                     float64
#  363  target_assign_act_workkeys_part                float64
#  364  target_assign_biology_part                     float64
#  365  target_assign_english_ii_part                  float64
#  366  target_assign_high_school_math_part            float64
#  367  target_assign_math_grades_3-8_part             float64
#  368  target_assign_reading_grades_3-8_part          float64
#  369  target_assign_science_grades_5&8_part          float64
#  370  target_assign_the_act_part                     float64
#  371  target_assign_total_targets_part               float64
#  372  target_met_act_workkeys_part                   float64
#  373  target_met_biology_part                        float64
#  374  target_met_english_ii_part                     float64
#  375  target_met_high_school_math_part               float64
#  376  target_met_math_grades_3-8_part                float64
#  377  target_met_reading_grades_3-8_part             float64
#  378  target_met_science_grades_5&8_part             float64
#  379  target_met_the_act_part                        float64
#  380  target_met_total_targets_part                  float64
#  381  pct_act_workkeys_all_part_det                  float64
#  382  pct_act_workkeys_am7_part_det                  float64
#  383  pct_act_workkeys_as7_part_det                  float64
#  384  pct_act_workkeys_bl7_part_det                  float64
#  385  pct_act_workkeys_eds_part_det                  float64
#  386  pct_act_workkeys_hi7_part_det                  float64
#  387  pct_act_workkeys_wh7_part_det                  float64
#  388  pct_biology_all_part_det                       float64
#  389  pct_biology_am7_part_det                       float64
#  390  pct_biology_as7_part_det                       float64
#  391  pct_biology_bl7_part_det                       float64
#  392  pct_biology_eds_part_det                       float64
#  393  pct_biology_els_part_det                       float64
#  394  pct_biology_hi7_part_det                       float64
#  395  pct_biology_mu7_part_det                       float64
#  396  pct_biology_swd_part_det                       float64
#  397  pct_biology_wh7_part_det                       float64
#  398  pct_english_ii_all_part_det                    float64
#  399  pct_english_ii_am7_part_det                    float64
#  400  pct_english_ii_as7_part_det                    float64
#  401  pct_english_ii_bl7_part_det                    float64
#  402  pct_english_ii_eds_part_det                    float64
#  403  pct_english_ii_els_part_det                    float64
#  404  pct_english_ii_hi7_part_det                    float64
#  405  pct_english_ii_mu7_part_det                    float64
#  406  pct_english_ii_swd_part_det                    float64
#  407  pct_english_ii_wh7_part_det                    float64
#  408  pct_high_school_math_all_part_det              float64
#  409  pct_high_school_math_am7_part_det              float64
#  410  pct_high_school_math_as7_part_det              float64
#  411  pct_high_school_math_bl7_part_det              float64
#  412  pct_high_school_math_eds_part_det              float64
#  413  pct_high_school_math_els_part_det              float64
#  414  pct_high_school_math_hi7_part_det              float64
#  415  pct_high_school_math_mu7_part_det              float64
#  416  pct_high_school_math_swd_part_det              float64
#  417  pct_high_school_math_wh7_part_det              float64
#  418  pct_math_grades_3-8_all_part_det               float64
#  419  pct_math_grades_3-8_am7_part_det               float64
#  420  pct_math_grades_3-8_as7_part_det               float64
#  421  pct_math_grades_3-8_bl7_part_det               float64
#  422  pct_math_grades_3-8_eds_part_det               float64
#  423  pct_math_grades_3-8_els_part_det               float64
#  424  pct_math_grades_3-8_hi7_part_det               float64
#  425  pct_math_grades_3-8_mu7_part_det               float64
#  426  pct_math_grades_3-8_swd_part_det               float64
#  427  pct_math_grades_3-8_wh7_part_det               float64
#  428  pct_reading_grades_3-8_all_part_det            float64
#  429  pct_reading_grades_3-8_am7_part_det            float64
#  430  pct_reading_grades_3-8_as7_part_det            float64
#  431  pct_reading_grades_3-8_bl7_part_det            float64
#  432  pct_reading_grades_3-8_eds_part_det            float64
#  433  pct_reading_grades_3-8_els_part_det            float64
#  434  pct_reading_grades_3-8_hi7_part_det            float64
#  435  pct_reading_grades_3-8_mu7_part_det            float64
#  436  pct_reading_grades_3-8_swd_part_det            float64
#  437  pct_reading_grades_3-8_wh7_part_det            float64
#  438  pct_science_grades_5&8_all_part_det            float64
#  439  pct_science_grades_5&8_am7_part_det            float64
#  440  pct_science_grades_5&8_as7_part_det            float64
#  441  pct_science_grades_5&8_bl7_part_det            float64
#  442  pct_science_grades_5&8_eds_part_det            float64
#  443  pct_science_grades_5&8_els_part_det            float64
#  444  pct_science_grades_5&8_hi7_part_det            float64
#  445  pct_science_grades_5&8_mu7_part_det            float64
#  446  pct_science_grades_5&8_swd_part_det            float64
#  447  pct_science_grades_5&8_wh7_part_det            float64
#  448  pct_the_act_all_part_det                       float64
#  449  pct_the_act_am7_part_det                       float64
#  450  pct_the_act_as7_part_det                       float64
#  451  pct_the_act_bl7_part_det                       float64
#  452  pct_the_act_eds_part_det                       float64
#  453  pct_the_act_els_part_det                       float64
#  454  pct_the_act_hi7_part_det                       float64
#  455  pct_the_act_mu7_part_det                       float64
#  456  pct_the_act_swd_part_det                       float64
#  457  pct_the_act_wh7_part_det                       float64
#  458  pct_ccr_bi_eoc_aig_pc                          float64
#  459  pct_ccr_bi_eoc_all_pc                          float64
#  460  pct_ccr_bi_eoc_am7_pc                          float64
#  461  pct_ccr_bi_eoc_as7_pc                          float64
#  462  pct_ccr_bi_eoc_bl7_pc                          float64
#  463  pct_ccr_bi_eoc_eds_pc                          float64
#  464  pct_ccr_bi_eoc_els_pc                          float64
#  465  pct_ccr_bi_eoc_fcs_pc                          float64
#  466  pct_ccr_bi_eoc_fem_pc                          float64
#  467  pct_ccr_bi_eoc_hi7_pc                          float64
#  468  pct_ccr_bi_eoc_hms_pc                          float64
#  469  pct_ccr_bi_eoc_male_pc                         float64
#  470  pct_ccr_bi_eoc_mig_pc                          float64
#  471  pct_ccr_bi_eoc_mil_pc                          float64
#  472  pct_ccr_bi_eoc_mu7_pc                          float64
#  473  pct_ccr_bi_eoc_neds_pc                         float64
#  474  pct_ccr_bi_eoc_nswd_pc                         float64
#  475  pct_ccr_bi_eoc_swd_pc                          float64
#  476  pct_ccr_bi_eoc_wh7_pc                          float64
#  477  pct_ccr_e2_eoc_aig_pc                          float64
#  478  pct_ccr_e2_eoc_all_pc                          float64
#  479  pct_ccr_e2_eoc_am7_pc                          float64
#  480  pct_ccr_e2_eoc_as7_pc                          float64
#  481  pct_ccr_e2_eoc_bl7_pc                          float64
#  482  pct_ccr_e2_eoc_eds_pc                          float64
#  483  pct_ccr_e2_eoc_els_pc                          float64
#  484  pct_ccr_e2_eoc_fem_pc                          float64
#  485  pct_ccr_e2_eoc_hi7_pc                          float64
#  486  pct_ccr_e2_eoc_hms_pc                          float64
#  487  pct_ccr_e2_eoc_male_pc                         float64
#  488  pct_ccr_e2_eoc_mig_pc                          float64
#  489  pct_ccr_e2_eoc_mil_pc                          float64
#  490  pct_ccr_e2_eoc_mu7_pc                          float64
#  491  pct_ccr_e2_eoc_neds_pc                         float64
#  492  pct_ccr_e2_eoc_nswd_pc                         float64
#  493  pct_ccr_e2_eoc_swd_pc                          float64
#  494  pct_ccr_e2_eoc_wh7_pc                          float64
#  495  pct_ccr_eoc_eoc_aig_pc                         float64
#  496  pct_ccr_eoc_eoc_all_pc                         float64
#  497  pct_ccr_eoc_eoc_am7_pc                         float64
#  498  pct_ccr_eoc_eoc_as7_pc                         float64
#  499  pct_ccr_eoc_eoc_bl7_pc                         float64
#  500  pct_ccr_eoc_eoc_eds_pc                         float64
#  501  pct_ccr_eoc_eoc_els_pc                         float64
#  502  pct_ccr_eoc_eoc_fcs_pc                         float64
#  503  pct_ccr_eoc_eoc_fem_pc                         float64
#  504  pct_ccr_eoc_eoc_hi7_pc                         float64
#  505  pct_ccr_eoc_eoc_hms_pc                         float64
#  506  pct_ccr_eoc_eoc_male_pc                        float64
#  507  pct_ccr_eoc_eoc_mig_pc                         float64
#  508  pct_ccr_eoc_eoc_mil_pc                         float64
#  509  pct_ccr_eoc_eoc_mu7_pc                         float64
#  510  pct_ccr_eoc_eoc_neds_pc                        float64
#  511  pct_ccr_eoc_eoc_nswd_pc                        float64
#  512  pct_ccr_eoc_eoc_swd_pc                         float64
#  513  pct_ccr_eoc_eoc_wh7_pc                         float64
#  514  pct_ccr_eog_03_aig_pc                          float64
#  515  pct_ccr_eog_03_all_pc                          float64
#  516  pct_ccr_eog_03_am7_pc                          float64
#  517  pct_ccr_eog_03_as7_pc                          float64
#  518  pct_ccr_eog_03_bl7_pc                          float64
#  519  pct_ccr_eog_03_eds_pc                          float64
#  520  pct_ccr_eog_03_els_pc                          float64
#  521  pct_ccr_eog_03_fcs_pc                          float64
#  522  pct_ccr_eog_03_fem_pc                          float64
#  523  pct_ccr_eog_03_hi7_pc                          float64
#  524  pct_ccr_eog_03_hms_pc                          float64
#  525  pct_ccr_eog_03_male_pc                         float64
#  526  pct_ccr_eog_03_mig_pc                          float64
#  527  pct_ccr_eog_03_mil_pc                          float64
#  528  pct_ccr_eog_03_mu7_pc                          float64
#  529  pct_ccr_eog_03_neds_pc                         float64
#  530  pct_ccr_eog_03_nswd_pc                         float64
#  531  pct_ccr_eog_03_swd_pc                          float64
#  532  pct_ccr_eog_03_wh7_pc                          float64
#  533  pct_ccr_eog_04_aig_pc                          float64
#  534  pct_ccr_eog_04_all_pc                          float64
#  535  pct_ccr_eog_04_am7_pc                          float64
#  536  pct_ccr_eog_04_as7_pc                          float64
#  537  pct_ccr_eog_04_bl7_pc                          float64
#  538  pct_ccr_eog_04_eds_pc                          float64
#  539  pct_ccr_eog_04_els_pc                          float64
#  540  pct_ccr_eog_04_fcs_pc                          float64
#  541  pct_ccr_eog_04_fem_pc                          float64
#  542  pct_ccr_eog_04_hi7_pc                          float64
#  543  pct_ccr_eog_04_hms_pc                          float64
#  544  pct_ccr_eog_04_male_pc                         float64
#  545  pct_ccr_eog_04_mig_pc                          float64
#  546  pct_ccr_eog_04_mil_pc                          float64
#  547  pct_ccr_eog_04_mu7_pc                          float64
#  548  pct_ccr_eog_04_neds_pc                         float64
#  549  pct_ccr_eog_04_nswd_pc                         float64
#  550  pct_ccr_eog_04_swd_pc                          float64
#  551  pct_ccr_eog_04_wh7_pc                          float64
#  552  pct_ccr_eog_05_aig_pc                          float64
#  553  pct_ccr_eog_05_all_pc                          float64
#  554  pct_ccr_eog_05_am7_pc                          float64
#  555  pct_ccr_eog_05_as7_pc                          float64
#  556  pct_ccr_eog_05_bl7_pc                          float64
#  557  pct_ccr_eog_05_eds_pc                          float64
#  558  pct_ccr_eog_05_els_pc                          float64
#  559  pct_ccr_eog_05_fcs_pc                          float64
#  560  pct_ccr_eog_05_fem_pc                          float64
#  561  pct_ccr_eog_05_hi7_pc                          float64
#  562  pct_ccr_eog_05_hms_pc                          float64
#  563  pct_ccr_eog_05_male_pc                         float64
#  564  pct_ccr_eog_05_mig_pc                          float64
#  565  pct_ccr_eog_05_mil_pc                          float64
#  566  pct_ccr_eog_05_mu7_pc                          float64
#  567  pct_ccr_eog_05_neds_pc                         float64
#  568  pct_ccr_eog_05_nswd_pc                         float64
#  569  pct_ccr_eog_05_swd_pc                          float64
#  570  pct_ccr_eog_05_wh7_pc                          float64
#  571  pct_ccr_eog_06_aig_pc                          float64
#  572  pct_ccr_eog_06_all_pc                          float64
#  573  pct_ccr_eog_06_am7_pc                          float64
#  574  pct_ccr_eog_06_as7_pc                          float64
#  575  pct_ccr_eog_06_bl7_pc                          float64
#  576  pct_ccr_eog_06_eds_pc                          float64
#  577  pct_ccr_eog_06_els_pc                          float64
#  578  pct_ccr_eog_06_fcs_pc                          float64
#  579  pct_ccr_eog_06_fem_pc                          float64
#  580  pct_ccr_eog_06_hi7_pc                          float64
#  581  pct_ccr_eog_06_hms_pc                          float64
#  582  pct_ccr_eog_06_male_pc                         float64
#  583  pct_ccr_eog_06_mig_pc                          float64
#  584  pct_ccr_eog_06_mil_pc                          float64
#  585  pct_ccr_eog_06_mu7_pc                          float64
#  586  pct_ccr_eog_06_neds_pc                         float64
#  587  pct_ccr_eog_06_nswd_pc                         float64
#  588  pct_ccr_eog_06_swd_pc                          float64
#  589  pct_ccr_eog_06_wh7_pc                          float64
#  590  pct_ccr_eog_07_aig_pc                          float64
#  591  pct_ccr_eog_07_all_pc                          float64
#  592  pct_ccr_eog_07_am7_pc                          float64
#  593  pct_ccr_eog_07_as7_pc                          float64
#  594  pct_ccr_eog_07_bl7_pc                          float64
#  595  pct_ccr_eog_07_eds_pc                          float64
#  596  pct_ccr_eog_07_els_pc                          float64
#  597  pct_ccr_eog_07_fcs_pc                          float64
#  598  pct_ccr_eog_07_fem_pc                          float64
#  599  pct_ccr_eog_07_hi7_pc                          float64
#  600  pct_ccr_eog_07_hms_pc                          float64
#  601  pct_ccr_eog_07_male_pc                         float64
#  602  pct_ccr_eog_07_mig_pc                          float64
#  603  pct_ccr_eog_07_mil_pc                          float64
#  604  pct_ccr_eog_07_mu7_pc                          float64
#  605  pct_ccr_eog_07_neds_pc                         float64
#  606  pct_ccr_eog_07_nswd_pc                         float64
#  607  pct_ccr_eog_07_swd_pc                          float64
#  608  pct_ccr_eog_07_wh7_pc                          float64
#  609  pct_ccr_eog_08_aig_pc                          float64
#  610  pct_ccr_eog_08_all_pc                          float64
#  611  pct_ccr_eog_08_am7_pc                          float64
#  612  pct_ccr_eog_08_as7_pc                          float64
#  613  pct_ccr_eog_08_bl7_pc                          float64
#  614  pct_ccr_eog_08_eds_pc                          float64
#  615  pct_ccr_eog_08_els_pc                          float64
#  616  pct_ccr_eog_08_fcs_pc                          float64
#  617  pct_ccr_eog_08_fem_pc                          float64
#  618  pct_ccr_eog_08_hi7_pc                          float64
#  619  pct_ccr_eog_08_hms_pc                          float64
#  620  pct_ccr_eog_08_male_pc                         float64
#  621  pct_ccr_eog_08_mig_pc                          float64
#  622  pct_ccr_eog_08_mil_pc                          float64
#  623  pct_ccr_eog_08_mu7_pc                          float64
#  624  pct_ccr_eog_08_neds_pc                         float64
#  625  pct_ccr_eog_08_nswd_pc                         float64
#  626  pct_ccr_eog_08_swd_pc                          float64
#  627  pct_ccr_eog_08_wh7_pc                          float64
#  628  pct_ccr_eog_all_aig_pc                         float64
#  629  pct_ccr_eog_all_all_pc                         float64
#  630  pct_ccr_eog_all_am7_pc                         float64
#  631  pct_ccr_eog_all_as7_pc                         float64
#  632  pct_ccr_eog_all_bl7_pc                         float64
#  633  pct_ccr_eog_all_eds_pc                         float64
#  634  pct_ccr_eog_all_els_pc                         float64
#  635  pct_ccr_eog_all_fcs_pc                         float64
#  636  pct_ccr_eog_all_fem_pc                         float64
#  637  pct_ccr_eog_all_hi7_pc                         float64
#  638  pct_ccr_eog_all_hms_pc                         float64
#  639  pct_ccr_eog_all_male_pc                        float64
#  640  pct_ccr_eog_all_mig_pc                         float64
#  641  pct_ccr_eog_all_mil_pc                         float64
#  642  pct_ccr_eog_all_mu7_pc                         float64
#  643  pct_ccr_eog_all_neds_pc                        float64
#  644  pct_ccr_eog_all_nswd_pc                        float64
#  645  pct_ccr_eog_all_swd_pc                         float64
#  646  pct_ccr_eog_all_wh7_pc                         float64
#  647  pct_ccr_m1_eoc_aig_pc                          float64
#  648  pct_ccr_m1_eoc_all_pc                          float64
#  649  pct_ccr_m1_eoc_am7_pc                          float64
#  650  pct_ccr_m1_eoc_as7_pc                          float64
#  651  pct_ccr_m1_eoc_bl7_pc                          float64
#  652  pct_ccr_m1_eoc_eds_pc                          float64
#  653  pct_ccr_m1_eoc_els_pc                          float64
#  654  pct_ccr_m1_eoc_fem_pc                          float64
#  655  pct_ccr_m1_eoc_hi7_pc                          float64
#  656  pct_ccr_m1_eoc_hms_pc                          float64
#  657  pct_ccr_m1_eoc_male_pc                         float64
#  658  pct_ccr_m1_eoc_mig_pc                          float64
#  659  pct_ccr_m1_eoc_mil_pc                          float64
#  660  pct_ccr_m1_eoc_mu7_pc                          float64
#  661  pct_ccr_m1_eoc_neds_pc                         float64
#  662  pct_ccr_m1_eoc_nswd_pc                         float64
#  663  pct_ccr_m1_eoc_swd_pc                          float64
#  664  pct_ccr_m1_eoc_wh7_pc                          float64
#  665  pct_ccr_m3_eoc_aig_pc                          float64
#  666  pct_ccr_m3_eoc_all_pc                          float64
#  667  pct_ccr_m3_eoc_am7_pc                          float64
#  668  pct_ccr_m3_eoc_as7_pc                          float64
#  669  pct_ccr_m3_eoc_bl7_pc                          float64
#  670  pct_ccr_m3_eoc_eds_pc                          float64
#  671  pct_ccr_m3_eoc_els_pc                          float64
#  672  pct_ccr_m3_eoc_fem_pc                          float64
#  673  pct_ccr_m3_eoc_hi7_pc                          float64
#  674  pct_ccr_m3_eoc_hms_pc                          float64
#  675  pct_ccr_m3_eoc_male_pc                         float64
#  676  pct_ccr_m3_eoc_mig_pc                          float64
#  677  pct_ccr_m3_eoc_mil_pc                          float64
#  678  pct_ccr_m3_eoc_mu7_pc                          float64
#  679  pct_ccr_m3_eoc_neds_pc                         float64
#  680  pct_ccr_m3_eoc_nswd_pc                         float64
#  681  pct_ccr_m3_eoc_swd_pc                          float64
#  682  pct_ccr_m3_eoc_wh7_pc                          float64
#  683  pct_ccr_ma_03_aig_pc                           float64
#  684  pct_ccr_ma_03_all_pc                           float64
#  685  pct_ccr_ma_03_am7_pc                           float64
#  686  pct_ccr_ma_03_as7_pc                           float64
#  687  pct_ccr_ma_03_bl7_pc                           float64
#  688  pct_ccr_ma_03_eds_pc                           float64
#  689  pct_ccr_ma_03_els_pc                           float64
#  690  pct_ccr_ma_03_fem_pc                           float64
#  691  pct_ccr_ma_03_hi7_pc                           float64
#  692  pct_ccr_ma_03_hms_pc                           float64
#  693  pct_ccr_ma_03_male_pc                          float64
#  694  pct_ccr_ma_03_mig_pc                           float64
#  695  pct_ccr_ma_03_mil_pc                           float64
#  696  pct_ccr_ma_03_mu7_pc                           float64
#  697  pct_ccr_ma_03_neds_pc                          float64
#  698  pct_ccr_ma_03_nswd_pc                          float64
#  699  pct_ccr_ma_03_swd_pc                           float64
#  700  pct_ccr_ma_03_wh7_pc                           float64
#  701  pct_ccr_ma_04_aig_pc                           float64
#  702  pct_ccr_ma_04_all_pc                           float64
#  703  pct_ccr_ma_04_am7_pc                           float64
#  704  pct_ccr_ma_04_as7_pc                           float64
#  705  pct_ccr_ma_04_bl7_pc                           float64
#  706  pct_ccr_ma_04_eds_pc                           float64
#  707  pct_ccr_ma_04_els_pc                           float64
#  708  pct_ccr_ma_04_fem_pc                           float64
#  709  pct_ccr_ma_04_hi7_pc                           float64
#  710  pct_ccr_ma_04_hms_pc                           float64
#  711  pct_ccr_ma_04_male_pc                          float64
#  712  pct_ccr_ma_04_mig_pc                           float64
#  713  pct_ccr_ma_04_mil_pc                           float64
#  714  pct_ccr_ma_04_mu7_pc                           float64
#  715  pct_ccr_ma_04_neds_pc                          float64
#  716  pct_ccr_ma_04_nswd_pc                          float64
#  717  pct_ccr_ma_04_swd_pc                           float64
#  718  pct_ccr_ma_04_wh7_pc                           float64
#  719  pct_ccr_ma_05_aig_pc                           float64
#  720  pct_ccr_ma_05_all_pc                           float64
#  721  pct_ccr_ma_05_am7_pc                           float64
#  722  pct_ccr_ma_05_as7_pc                           float64
#  723  pct_ccr_ma_05_bl7_pc                           float64
#  724  pct_ccr_ma_05_eds_pc                           float64
#  725  pct_ccr_ma_05_els_pc                           float64
#  726  pct_ccr_ma_05_fem_pc                           float64
#  727  pct_ccr_ma_05_hi7_pc                           float64
#  728  pct_ccr_ma_05_hms_pc                           float64
#  729  pct_ccr_ma_05_male_pc                          float64
#  730  pct_ccr_ma_05_mig_pc                           float64
#  731  pct_ccr_ma_05_mil_pc                           float64
#  732  pct_ccr_ma_05_mu7_pc                           float64
#  733  pct_ccr_ma_05_neds_pc                          float64
#  734  pct_ccr_ma_05_nswd_pc                          float64
#  735  pct_ccr_ma_05_swd_pc                           float64
#  736  pct_ccr_ma_05_wh7_pc                           float64
#  737  pct_ccr_ma_06_aig_pc                           float64
#  738  pct_ccr_ma_06_all_pc                           float64
#  739  pct_ccr_ma_06_am7_pc                           float64
#  740  pct_ccr_ma_06_as7_pc                           float64
#  741  pct_ccr_ma_06_bl7_pc                           float64
#  742  pct_ccr_ma_06_eds_pc                           float64
#  743  pct_ccr_ma_06_els_pc                           float64
#  744  pct_ccr_ma_06_fem_pc                           float64
#  745  pct_ccr_ma_06_hi7_pc                           float64
#  746  pct_ccr_ma_06_hms_pc                           float64
#  747  pct_ccr_ma_06_male_pc                          float64
#  748  pct_ccr_ma_06_mig_pc                           float64
#  749  pct_ccr_ma_06_mil_pc                           float64
#  750  pct_ccr_ma_06_mu7_pc                           float64
#  751  pct_ccr_ma_06_neds_pc                          float64
#  752  pct_ccr_ma_06_nswd_pc                          float64
#  753  pct_ccr_ma_06_swd_pc                           float64
#  754  pct_ccr_ma_06_wh7_pc                           float64
#  755  pct_ccr_ma_07_aig_pc                           float64
#  756  pct_ccr_ma_07_all_pc                           float64
#  757  pct_ccr_ma_07_am7_pc                           float64
#  758  pct_ccr_ma_07_as7_pc                           float64
#  759  pct_ccr_ma_07_bl7_pc                           float64
#  760  pct_ccr_ma_07_eds_pc                           float64
#  761  pct_ccr_ma_07_els_pc                           float64
#  762  pct_ccr_ma_07_fem_pc                           float64
#  763  pct_ccr_ma_07_hi7_pc                           float64
#  764  pct_ccr_ma_07_hms_pc                           float64
#  765  pct_ccr_ma_07_male_pc                          float64
#  766  pct_ccr_ma_07_mig_pc                           float64
#  767  pct_ccr_ma_07_mil_pc                           float64
#  768  pct_ccr_ma_07_mu7_pc                           float64
#  769  pct_ccr_ma_07_neds_pc                          float64
#  770  pct_ccr_ma_07_nswd_pc                          float64
#  771  pct_ccr_ma_07_swd_pc                           float64
#  772  pct_ccr_ma_07_wh7_pc                           float64
#  773  pct_ccr_ma_08_aig_pc                           float64
#  774  pct_ccr_ma_08_all_pc                           float64
#  775  pct_ccr_ma_08_am7_pc                           float64
#  776  pct_ccr_ma_08_as7_pc                           float64
#  777  pct_ccr_ma_08_bl7_pc                           float64
#  778  pct_ccr_ma_08_eds_pc                           float64
#  779  pct_ccr_ma_08_els_pc                           float64
#  780  pct_ccr_ma_08_fem_pc                           float64
#  781  pct_ccr_ma_08_hi7_pc                           float64
#  782  pct_ccr_ma_08_hms_pc                           float64
# ...
#  4388 num_credentials_cte_cred                       float64
#  4389 num_enrollments_cte_cred                       float64
#  4390 cred_earned_pct_cte_cred                       float64
#  4391 career_only_cte_end_cte_enroll                 float64
#  4392 career_college_college_unc_cte_end_cte_enroll  float64
#  4393 college_college_unc_only_cte_end_cte_enroll    float64
#  4394 college_only_cte_end_cte_enroll                float64
#  4395 stu_enroll                                     float64
#  4396 cte_enroll                                     float64
#  4397 pct                                            float64
#  4398 digital_media_dlmi                             float64
#  4399 category_code_dlmi                             float64
#  4400 device_access_dlmi                             float64
#  4401 device_access_grades_dlmi                      float64
#  4402 device_home_dlmi                               float64
#  4403 device_home_grades_dlmi                        float64
#  4404 byod_dlmi                                      float64
#  4405 byod_grades_dlmi                               float64
#  4406 book_titlesper_student_dlmi                    float64
#  4407 wap_dlmi                                       float64
#  4408 wap_class_dlmi                                 float64
#  4409 media_school_dlmi                              float64
#  4410 devices_dlmi                                   float64
#  4411 ni_effect3                                     float64
#  4412 eff_effect3                                    float64
#  4413 he_effect3                                     float64
#  4414 ni_pct_effect3                                 float64
#  4415 eff_pct_effect3                                float64
#  4416 he_pct_effect3                                 float64
#  4417 poverty_eq                                     object
#  4418 number_of_teachers_eq                          float64
#  4419 beg_teacher_eq                                 float64
#  4420 pct_beg_teachers_eq                            float64
#  4421 prov_teachers_eq                               float64
#  4422 pct_prov_teachers_eq                           float64
#  4423 num_prin_eq                                    float64
#  4424 inexp_count_prin_eq                            float64
#  4425 pct_inexp_prin_eq                              float64
#  4426 adm_central_expense_funds2                     float64
#  4427 adm_employee_benefits_funds2                   float64
#  4428 adm_instructional_equip._funds2                float64
#  4429 adm_other_objects_funds2                       float64
#  4430 adm_purchased_services_funds2                  float64
#  4431 adm_salaries_funds2                            float64
#  4432 adm_supplies_&_materials_funds2                float64
#  4433 adm_total_funds2                               float64
#  4434 federal_funds_central_expense_funds2           float64
#  4435 federal_funds_employee_benefits_funds2         float64
#  4436 federal_funds_instructional_equip._funds2      float64
#  4437 federal_funds_other_objects_funds2             float64
#  4438 federal_funds_purchased_services_funds2        float64
#  4439 federal_funds_salaries_funds2                  float64
#  4440 federal_funds_supplies_&_materials_funds2      float64
#  4441 federal_funds_total_funds2                     float64
#  4442 federal_ppe_central_expense_funds2             float64
#  4443 federal_ppe_employee_benefits_funds2           float64
#  4444 federal_ppe_instructional_equip._funds2        float64
#  4445 federal_ppe_other_objects_funds2               float64
#  4446 federal_ppe_purchased_services_funds2          float64
#  4447 federal_ppe_salaries_funds2                    float64
#  4448 federal_ppe_supplies_&_materials_funds2        float64
#  4449 federal_ppe_total_funds2                       float64
#  4450 local_funds_central_expense_funds2             float64
#  4451 local_funds_employee_benefits_funds2           float64
#  4452 local_funds_instructional_equip._funds2        float64
#  4453 local_funds_other_objects_funds2               float64
#  4454 local_funds_purchased_services_funds2          float64
#  4455 local_funds_salaries_funds2                    float64
#  4456 local_funds_supplies_&_materials_funds2        float64
#  4457 local_funds_total_funds2                       float64
#  4458 local_ppe_central_expense_funds2               float64
#  4459 local_ppe_employee_benefits_funds2             float64
#  4460 local_ppe_instructional_equip._funds2          float64
#  4461 local_ppe_other_objects_funds2                 float64
#  4462 local_ppe_purchased_services_funds2            float64
#  4463 local_ppe_salaries_funds2                      float64
#  4464 local_ppe_supplies_&_materials_funds2          float64
#  4465 local_ppe_total_funds2                         float64
#  4466 state_funds_central_expense_funds2             float64
#  4467 state_funds_employee_benefits_funds2           float64
#  4468 state_funds_instructional_equip._funds2        float64
#  4469 state_funds_other_objects_funds2               float64
#  4470 state_funds_purchased_services_funds2          float64
#  4471 state_funds_salaries_funds2                    float64
#  4472 state_funds_supplies_&_materials_funds2        float64
#  4473 state_funds_total_funds2                       float64
#  4474 state_ppe_central_expense_funds2               float64
#  4475 state_ppe_employee_benefits_funds2             float64
#  4476 state_ppe_instructional_equip._funds2          float64
#  4477 state_ppe_other_objects_funds2                 float64
#  4478 state_ppe_purchased_services_funds2            float64
#  4479 state_ppe_salaries_funds2                      float64
#  4480 state_ppe_supplies_&_materials_funds2          float64
#  4481 state_ppe_total_funds2                         float64
#  4482 total_funds_central_expense_funds2             float64
#  4483 total_funds_employee_benefits_funds2           float64
#  4484 total_funds_instructional_equip._funds2        float64
#  4485 total_funds_other_objects_funds2               float64
#  4486 total_funds_purchased_services_funds2          float64
#  4487 total_funds_salaries_funds2                    float64
#  4488 total_funds_supplies_&_materials_funds2        float64
#  4489 total_funds_total_funds2                       float64
#  4490 total_ppe_central_expense_funds2               float64
#  4491 total_ppe_employee_benefits_funds2             float64
#  4492 total_ppe_instructional_equip._funds2          float64
#  4493 total_ppe_other_objects_funds2                 float64
#  4494 total_ppe_purchased_services_funds2            float64
#  4495 total_ppe_salaries_funds2                      float64
#  4496 total_ppe_supplies_&_materials_funds2          float64
#  4497 total_ppe_total_funds2                         float64
#  4498 pct_ib_pass                                    float64
#  4499 pct_ib_participation                           float64
#  4500 amount_improvement                             float64
#  4501 act_per1000_all_inc2                           float64
#  4502 act_per1000_am7_inc2                           float64
#  4503 act_per1000_as7_inc2                           float64
#  4504 act_per1000_bl7_inc2                           float64
#  4505 act_per1000_eds_inc2                           float64
#  4506 act_per1000_els_inc2                           float64
#  4507 act_per1000_fem_inc2                           float64
#  4508 act_per1000_hi7_inc2                           float64
#  4509 act_per1000_male_inc2                          float64
#  4510 act_per1000_mu7_inc2                           float64
#  4511 act_per1000_pi7_inc2                           float64
#  4512 act_per1000_swd_inc2                           float64
#  4513 act_per1000_wh7_inc2                           float64
#  4514 arr_per1000_all_inc2                           float64
#  4515 arr_per1000_am7_inc2                           float64
#  4516 arr_per1000_as7_inc2                           float64
#  4517 arr_per1000_bl7_inc2                           float64
#  4518 arr_per1000_eds_inc2                           float64
#  4519 arr_per1000_els_inc2                           float64
#  4520 arr_per1000_fem_inc2                           float64
#  4521 arr_per1000_hi7_inc2                           float64
#  4522 arr_per1000_male_inc2                          float64
#  4523 arr_per1000_mu7_inc2                           float64
#  4524 arr_per1000_pi7_inc2                           float64
#  4525 arr_per1000_swd_inc2                           float64
#  4526 arr_per1000_wh7_inc2                           float64
#  4527 bha_per1000_all_inc2                           float64
#  4528 bha_per1000_am7_inc2                           float64
#  4529 bha_per1000_as7_inc2                           float64
#  4530 bha_per1000_bl7_inc2                           float64
#  4531 bha_per1000_eds_inc2                           float64
#  4532 bha_per1000_els_inc2                           float64
#  4533 bha_per1000_fem_inc2                           float64
#  4534 bha_per1000_hi7_inc2                           float64
#  4535 bha_per1000_male_inc2                          float64
#  4536 bha_per1000_mu7_inc2                           float64
#  4537 bha_per1000_pi7_inc2                           float64
#  4538 bha_per1000_swd_inc2                           float64
#  4539 bha_per1000_wh7_inc2                           float64
#  4540 exp_per1000_all_inc2                           float64
#  4541 exp_per1000_am7_inc2                           float64
#  4542 exp_per1000_as7_inc2                           float64
#  4543 exp_per1000_bl7_inc2                           float64
#  4544 exp_per1000_eds_inc2                           float64
#  4545 exp_per1000_els_inc2                           float64
#  4546 exp_per1000_fem_inc2                           float64
#  4547 exp_per1000_hi7_inc2                           float64
#  4548 exp_per1000_male_inc2                          float64
#  4549 exp_per1000_mu7_inc2                           float64
#  4550 exp_per1000_pi7_inc2                           float64
#  4551 exp_per1000_swd_inc2                           float64
#  4552 exp_per1000_wh7_inc2                           float64
#  4553 iss_per1000_all_inc2                           float64
#  4554 iss_per1000_am7_inc2                           float64
#  4555 iss_per1000_as7_inc2                           float64
#  4556 iss_per1000_bl7_inc2                           float64
#  4557 iss_per1000_eds_inc2                           float64
#  4558 iss_per1000_els_inc2                           float64
#  4559 iss_per1000_fem_inc2                           float64
#  4560 iss_per1000_hi7_inc2                           float64
#  4561 iss_per1000_male_inc2                          float64
#  4562 iss_per1000_mu7_inc2                           float64
#  4563 iss_per1000_pi7_inc2                           float64
#  4564 iss_per1000_swd_inc2                           float64
#  4565 iss_per1000_wh7_inc2                           float64
#  4566 lts_per1000_all_inc2                           float64
#  4567 lts_per1000_am7_inc2                           float64
#  4568 lts_per1000_as7_inc2                           float64
#  4569 lts_per1000_bl7_inc2                           float64
#  4570 lts_per1000_eds_inc2                           float64
#  4571 lts_per1000_els_inc2                           float64
#  4572 lts_per1000_fem_inc2                           float64
#  4573 lts_per1000_hi7_inc2                           float64
#  4574 lts_per1000_male_inc2                          float64
#  4575 lts_per1000_mu7_inc2                           float64
#  4576 lts_per1000_pi7_inc2                           float64
#  4577 lts_per1000_swd_inc2                           float64
#  4578 lts_per1000_wh7_inc2                           float64
#  4579 rpt_per1000_all_inc2                           float64
#  4580 rpt_per1000_am7_inc2                           float64
#  4581 rpt_per1000_as7_inc2                           float64
#  4582 rpt_per1000_bl7_inc2                           float64
#  4583 rpt_per1000_eds_inc2                           float64
#  4584 rpt_per1000_els_inc2                           float64
#  4585 rpt_per1000_fem_inc2                           float64
#  4586 rpt_per1000_hi7_inc2                           float64
#  4587 rpt_per1000_male_inc2                          float64
#  4588 rpt_per1000_mu7_inc2                           float64
#  4589 rpt_per1000_pi7_inc2                           float64
#  4590 rpt_per1000_swd_inc2                           float64
#  4591 rpt_per1000_wh7_inc2                           float64
#  4592 sts_per1000_all_inc2                           float64
#  4593 sts_per1000_am7_inc2                           float64
#  4594 sts_per1000_as7_inc2                           float64
#  4595 sts_per1000_bl7_inc2                           float64
#  4596 sts_per1000_eds_inc2                           float64
#  4597 sts_per1000_els_inc2                           float64
#  4598 sts_per1000_fem_inc2                           float64
#  4599 sts_per1000_hi7_inc2                           float64
#  4600 sts_per1000_male_inc2                          float64
#  4601 sts_per1000_mu7_inc2                           float64
#  4602 sts_per1000_pi7_inc2                           float64
#  4603 sts_per1000_swd_inc2                           float64
#  4604 sts_per1000_wh7_inc2                           float64
#  4605 count_all_pk_enroll                            float64
#  4606 count_am7_pk_enroll                            float64
#  4607 count_as7_pk_enroll                            float64
#  4608 count_bl7_pk_enroll                            float64
#  4609 count_els_pk_enroll                            float64
#  4610 count_fem_pk_enroll                            float64
#  4611 count_hi7_pk_enroll                            float64
#  4612 count_male_pk_enroll                           float64
#  4613 count_mu7_pk_enroll                            float64
#  4614 count_pi7_pk_enroll                            float64
#  4615 count_swd_pk_enroll                            float64
#  4616 count_wh7_pk_enroll                            float64
#  4617 pct_all_pk_enroll                              float64
#  4618 pct_am7_pk_enroll                              float64
#  4619 pct_as7_pk_enroll                              float64
#  4620 pct_bl7_pk_enroll                              float64
#  4621 pct_els_pk_enroll                              float64
#  4622 pct_fem_pk_enroll                              float64
#  4623 pct_hi7_pk_enroll                              float64
#  4624 pct_male_pk_enroll                             float64
#  4625 pct_mu7_pk_enroll                              float64
#  4626 pct_pi7_pk_enroll                              float64
#  4627 pct_swd_pk_enroll                              float64
#  4628 pct_wh7_pk_enroll                              float64
#  4629 pct_ready_kea_a_cat_code                       float64
#  4630 pct_ready_kea_e_cat_code                       float64
#  4631 pct_ready_kea_i_cat_code                       float64
#  4632 pct_ready_kea_m_cat_code                       float64
#  4633 avg_size_00_sar                                float64
#  4634 avg_size_01_sar                                float64
#  4635 avg_size_02_sar                                float64
#  4636 avg_size_03_sar                                float64
#  4637 avg_size_04_sar                                float64
#  4638 avg_size_05_sar                                float64
#  4639 avg_size_06_sar                                float64
#  4640 avg_size_07_sar                                float64
#  4641 avg_size_08_sar                                float64
#  4642 avg_size_biology_sar                           float64
#  4643 avg_size_english_ii_sar                        float64
#  4644 avg_size_nc_math_1_sar                         float64
#  4645 avg_size_nc_math_3_sar                         float64
#  4646 avg_sat_score                                  float64
#  4647 pct_sat_participation                          float64
#  4648 welcome_url                                    object
# dtypes: float64(4610), object(39)
# memory usage: 22.8+ MB

# %% [markdown]
# # Prepare Consolidated Dataset for Machine Learning
# **Below we perform operations on the entire dataset to remove columns and update row values that could cause problems during machine learning.**

# %% [markdown]
# ## Student Body Racial Composition Features
# **Impute / update missing Student Body Racial Composition Fields using mean imputation.**
# * When there are no racial composition percentages for a particular school campus / agency_code, fill in the missing values

# %%
#Get Student Body Racial Composition Fields
raceCompositionFields = schoolData.filter(regex='indian|asian|hispanic|black|white|pacific_island|two_or_more|minority')\
                                  .filter(regex='pct').columns
    
rowsBefore = schoolData[raceCompositionFields].isnull().T.any().T.sum()

#Update missing race values with the district average when avaiable (No district averages for charter schools) 
schoolData[raceCompositionFields] = schoolData.groupby('lea_code_loc')[raceCompositionFields]\
                                              .transform(lambda x: x.fillna(x.mean()))

    #Review dataset contents after Racial Composition Imputation
print('*********After: Updating Missing Racial Compostion Values****************************')   
rowsAfter = schoolData[raceCompositionFields].isnull().T.any().T.sum()
rowsUpdated = rowsBefore - rowsAfter
print('Rows Updated / Imputed: ', rowsUpdated) 
print('\r\nTotal Rows Missing Racial Compositions By District Code') 
schoolData['lea_code_loc'][schoolData[raceCompositionFields].isnull().T.any().T].value_counts()
# Out:
# *********After: Updating Missing Racial Compostion Values****************************
# Rows Updated / Imputed:  6
#
# Total Rows Missing Racial Compositions By District Code
# 998LEA    13
# 997LEA     9
# 996LEA     4
# 298LEA     3
# 679LEA     1
# 299LEA     1
# Name: lea_code_loc, dtype: int64

# %% [markdown]
# ## Remove Columns with Problematic Data
# **Here we remove entire columns that could cause problems during machine learning.  The following operations are performed:**
# * Remove any columns that have the same value in every single row.
# * Remove any columns that have a unique value in every single row (all values are different).
# * Remove empty columns (all values are NA or NULL).

# %%
#Remove any fields that have the same value in all rows
UniqueValueCounts = schoolData.nunique(dropna=False)
SingleValueCols = UniqueValueCounts[UniqueValueCounts == 1].index
schoolData = schoolData.drop(SingleValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with the same value in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(SingleValueCols))
# Out:
# *********After: Removing columns with the same value in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 644 entries, 2 to 715
# Columns: 3644 entries, agency_code to welcome_url
# dtypes: float64(3609), object(35)
# memory usage: 17.9+ MB
#
# Columns Deleted:  1005

# %%
#Remove any fields that have unique values in every row
schoolDataRecordCt = schoolData.shape[0]
UniqueValueCounts = schoolData.apply(pd.Series.nunique)
AllUniqueValueCols = UniqueValueCounts[UniqueValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(AllUniqueValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with unique values in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(AllUniqueValueCols))
# Out:
# *********After: Removing columns with unique values in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 644 entries, 2 to 715
# Columns: 3643 entries, category_code_loc to welcome_url
# dtypes: float64(3609), object(34)
# memory usage: 17.9+ MB
#
# Columns Deleted:  1

# %%
#Remove any empty fields (null values in every row)
schoolDataRecordCt = schoolData.shape[0]
NullValueCounts = schoolData.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with null / blank values in every row.*************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with null / blank values in every row.*************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 644 entries, 2 to 715
# Columns: 3643 entries, category_code_loc to welcome_url
# dtypes: float64(3609), object(34)
# memory usage: 17.9+ MB
#
# Columns Deleted:  0

# %% [markdown]
# ## Handle Other Missing Values Types
# * Here we eliminate any numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# * All remaining non-race, numeric column missing values are populated with 0.
# * In many cases, it seems that schools are not simply not reporting values when they are zero. However, mean imputation or some other strategy might be considered.

# %%
#Isolate continuous and categorical data types
#These are indexers into the schoolData dataframe and may be used similar to the schoolData dataframe 
sD_boolean = schoolData.loc[:, (schoolData.dtypes == bool) ]
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]
sD_continuous = schoolData.loc[:, (schoolData.dtypes != bool) & (schoolData.dtypes != object)]
print ("Boolean Columns: ", sD_boolean.shape[1])
print ("Nominal Columns: ", sD_nominal.shape[1])
print ("Continuous Columns: ", sD_continuous.shape[1])
print ("Columns Accounted for: ", sD_nominal.shape[1] + sD_continuous.shape[1] + sD_boolean.shape[1])
# Out:
# Boolean Columns:  0
# Nominal Columns:  34
# Continuous Columns:  3609
# Columns Accounted for:  3643

# %%
#Eliminate continuous columns with more than missingThreshold percentage of missing values
schoolDataRecordCt = sD_continuous.shape[0]
missingValueLimit = schoolDataRecordCt * missingThreshold
NullValueCounts = sD_continuous.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts >= missingValueLimit].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with >= missingThreshold % of missing values******')
schoolData.info(verbose=False)
print('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with >= missingThreshold % of missing values******
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 644 entries, 2 to 715
# Columns: 932 entries, category_code_loc to welcome_url
# dtypes: float64(898), object(34)
# memory usage: 4.6+ MB
#
# Columns Deleted:  2711

# %% [markdown]
# ## One-Hot Encoding of Categorical Variables
# **All categorical / string variables are converted to numberic variables via one hot encoding.  Each unique row value will become a new binary / numeric column in the dataset.**
# * All remaining categorical columns are one-hot encoded.
# * In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# * Prior to one-hot encoding, columns with > *uniqueThreshold* unique values are deleted.

# %%
#Delete categorical columns with > uniqueThreshold unique values 
#(Each unique value becomes a column during one-hot encoding)
oneHotUniqueValueCounts = schoolData[sD_nominal.columns].apply(lambda x: x.nunique())
oneHotUniqueValueCols = oneHotUniqueValueCounts[oneHotUniqueValueCounts >= uniqueThreshold].index
schoolData.drop(oneHotUniqueValueCols, axis=1, inplace=True) 

#Remove categorical columns which do not add value to machine learning
#Grades columns dropped since they all have indicator fields (device_access, device_home, BYOD)
#with less unique values to one-hot encode

# _dlmi columns may or may not exist after running cleanups above.

#----MUST CHECK FOR:---- 'device_access_grades_dlmi','device_home_grades_dlmi','byod_grades_dlmi'
# to fields below, if they exist
schoolData.drop(['welcome_url'], axis=1, inplace=True) 

#Review dataset contents one hot high unique value drops
print('*********After: Removing columns with >= uniqueThreshold unique values***********')
schoolData.info(verbose=False)
print('\r\nColumns Deleted: ', len(oneHotUniqueValueCols))
print(oneHotUniqueValueCols)
print('Dropped Manually: welcome_url,device_access_grades_dlmi ,device_home_grades_dlmi ,byod_grades_dlmi ')
# Out:
# *********After: Removing columns with >= uniqueThreshold unique values***********
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 644 entries, 2 to 715
# Columns: 924 entries, category_code_loc to pct_sat_participation
# dtypes: float64(898), object(26)
# memory usage: 4.5+ MB
#
# Columns Deleted:  7
# Index(['name_loc', 'street_addr_loc', 'city_loc', 'zip_loc', 'phone_loc',
#        'url_loc', 'school_name'],
#       dtype='object')
# Dropped Manually: welcome_url,device_access_grades_dlmi ,device_home_grades_dlmi ,byod_grades_dlmi

# %%
#Isolate remaining categorical variables
begColumnCt = len(schoolData.columns)
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]

#one hot encode categorical variables
schoolData = pd.get_dummies(data=schoolData, 
                       columns=sD_nominal.columns, drop_first=True)

#Determine change in column count
endColumnCt = len(schoolData.columns)
columnsAdded = endColumnCt - begColumnCt

#Review dataset contents one hot high unique value drops
print('Columns To One-Hot Encode: ', len(sD_nominal.columns))
print('\r\n*********After: Adding New Columns Via One-Hot Encoding*************************')
schoolData.info(verbose=False)
print('\r\nNew Columns Created Via One-Hot Encoding: ', columnsAdded)
# Out:
# Columns To One-Hot Encode:  26
#
# *********After: Adding New Columns Via One-Hot Encoding*************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 644 entries, 2 to 715
# Columns: 1354 entries, lea to poverty_eq_NEITHER
# dtypes: float64(898), uint8(456)
# memory usage: 4.7 MB
#
# New Columns Created Via One-Hot Encoding:  430

# %%
#Remove any fields that have the same value in all rows after one-hot encoding
UniqueValueCounts = schoolData.nunique(dropna=False)
SingleValueCols = UniqueValueCounts[UniqueValueCounts == 1].index
schoolData = schoolData.drop(SingleValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing one-hot encoded columns with the same value in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(SingleValueCols))
# Out:
# *********After: Removing one-hot encoded columns with the same value in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 644 entries, 2 to 715
# Columns: 1354 entries, lea to poverty_eq_NEITHER
# dtypes: float64(898), uint8(456)
# memory usage: 4.7 MB
#
# Columns Deleted:  0

# %% [markdown]
# ## Impute any Remaining Missing Values as Zero

# %%
#Print out all the missing value rows
pd.set_option('display.max_rows', 1500)

print('\r\n*********The Remaining Missing Values Below will be set to Zero!*************************')

#Check for Missing values 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# *********The Remaining Missing Values Below will be set to Zero!*************************
#                                      Variable Name  Number Missing Values
# 0                                              lea                     37
# 1                                           school                     37
# 2                                       indian_pct                     31
# 3                                        asian_pct                     31
# 4                                     hispanic_pct                     31
# 5                                        black_pct                     31
# 6                                        white_pct                     31
# 7                               pacific_island_pct                     31
# 8                                  two_or_more_pct                     31
# 9                                     minority_pct                     31
# 10                                 indian_male_pct                     31
# 11                                  asian_male_pct                     31
# 12                               hispanic_male_pct                     31
# 13                                  black_male_pct                     31
# 14                                  white_male_pct                     31
# 15                         pacific_island_male_pct                     31
# 16                            two_or_more_male_pct                     31
# 17                               minority_male_pct                     31
# 18                               indian_female_pct                     31
# 19                                asian_female_pct                     31
# 20                             hispanic_female_pct                     31
# 21                                black_female_pct                     31
# 22                                white_female_pct                     31
# 23                             minority_female_pct                     31
# 24                       pacific_island_female_pct                     31
# 25                          two_or_more_female_pct                     31
# 26                               pct_acall_aig_act                    145
# 27                               pct_acall_all_act                     86
# 28                               pct_acall_as7_act                    377
# 29                               pct_acall_bl7_act                    156
# 30                               pct_acall_eds_act                     95
# 31                               pct_acall_els_act                    313
# 32                               pct_acall_fem_act                    106
# 33                               pct_acall_hi7_act                    150
# 34                              pct_acall_male_act                     91
# 35                               pct_acall_mu7_act                    233
# 36                              pct_acall_neds_act                     98
# 37                              pct_acall_nswd_act                     91
# 38                               pct_acall_swd_act                    215
# 39                               pct_acall_wh7_act                    117
# 40                                pct_acco_aig_act                    228
# 41                                pct_acco_all_act                    118
# 42                                pct_acco_bl7_act                    268
# 43                                pct_acco_eds_act                    158
# 44                                pct_acco_fem_act                    140
# 45                                pct_acco_hi7_act                    280
# 46                               pct_acco_male_act                    143
# 47                               pct_acco_neds_act                    144
# 48                               pct_acco_nswd_act                    123
# 49                                pct_acco_swd_act                    353
# 50                                pct_acco_wh7_act                    181
# 51                                pct_acen_aig_act                    228
# 52                                pct_acen_all_act                    118
# 53                                pct_acen_bl7_act                    268
# 54                                pct_acen_eds_act                    158
# 55                                pct_acen_fem_act                    140
# 56                                pct_acen_hi7_act                    280
# 57                               pct_acen_male_act                    143
# 58                               pct_acen_neds_act                    144
# 59                               pct_acen_nswd_act                    123
# 60                                pct_acen_swd_act                    352
# 61                                pct_acen_wh7_act                    181
# 62                                pct_acma_aig_act                    228
# 63                                pct_acma_all_act                    118
# 64                                pct_acma_bl7_act                    268
# 65                                pct_acma_eds_act                    158
# 66                                pct_acma_fem_act                    140
# 67                                pct_acma_hi7_act                    280
# 68                               pct_acma_male_act                    143
# 69                               pct_acma_neds_act                    144
# 70                               pct_acma_nswd_act                    123
# 71                                pct_acma_swd_act                    353
# 72                                pct_acma_wh7_act                    181
# 73                                pct_acrd_aig_act                    228
# 74                                pct_acrd_all_act                    118
# 75                                pct_acrd_bl7_act                    268
# 76                                pct_acrd_eds_act                    157
# 77                                pct_acrd_fem_act                    140
# 78                                pct_acrd_hi7_act                    280
# 79                               pct_acrd_male_act                    143
# 80                               pct_acrd_neds_act                    144
# 81                               pct_acrd_nswd_act                    123
# 82                                pct_acrd_swd_act                    352
# 83                                pct_acrd_wh7_act                    181
# 84                                pct_acsc_aig_act                    228
# 85                                pct_acsc_all_act                    118
# 86                                pct_acsc_bl7_act                    268
# 87                                pct_acsc_eds_act                    157
# 88                                pct_acsc_fem_act                    140
# 89                                pct_acsc_hi7_act                    280
# 90                               pct_acsc_male_act                    143
# 91                               pct_acsc_neds_act                    144
# 92                               pct_acsc_nswd_act                    123
# 93                                pct_acsc_swd_act                    352
# 94                                pct_acsc_wh7_act                    181
# 95                                pct_acwr_aig_act                    228
# 96                                pct_acwr_all_act                    118
# 97                                pct_acwr_bl7_act                    272
# 98                                pct_acwr_eds_act                    161
# 99                                pct_acwr_fem_act                    142
# 100                               pct_acwr_hi7_act                    280
# 101                              pct_acwr_male_act                    148
# 102                              pct_acwr_neds_act                    144
# 103                              pct_acwr_nswd_act                    123
# 104                               pct_acwr_swd_act                    365
# 105                               pct_acwr_wh7_act                    183
# 106                                    pct_aig_awa                    237
# 107                                    pct_all_awa                    122
# 108                                    pct_bl7_awa                    272
# 109                                    pct_eds_awa                    162
# 110                                    pct_fem_awa                    149
# 111                                    pct_hi7_awa                    293
# 112                                   pct_male_awa                    154
# 113                                   pct_neds_awa                    143
# 114                                   pct_nswd_awa                    127
# 115                                    pct_swd_awa                    347
# 116                                    pct_wh7_awa                    182
# 117                                pct_ext_aig_cgr                    235
# 118                                pct_ext_all_cgr                    107
# 119                                pct_ext_bl7_cgr                    257
# 120                                pct_ext_eds_cgr                    155
# 121                                pct_ext_fem_cgr                    136
# 122                                pct_ext_hi7_cgr                    290
# 123                               pct_ext_male_cgr                    134
# 124                               pct_ext_neds_cgr                    129
# 125                               pct_ext_nswd_cgr                    120
# 126                                pct_ext_swd_cgr                    258
# 127                                pct_ext_wh7_cgr                    170
# 128                                pct_std_aig_cgr                    226
# 129                                pct_std_all_cgr                     95
# 130                                pct_std_bl7_cgr                    248
# 131                                pct_std_eds_cgr                    140
# 132                                pct_std_fem_cgr                    118
# 133                                pct_std_hi7_cgr                    266
# 134                               pct_std_male_cgr                    118
# 135                               pct_std_neds_cgr                    121
# 136                               pct_std_nswd_cgr                    115
# 137                                pct_std_swd_cgr                    234
# 138                                pct_std_wh7_cgr                    146
# 139                                        pct_eds                     38
# 140                            eg_index_all_aig_eg                    216
# 141                            eg_index_all_all_eg                     83
# 142                            eg_index_all_bl7_eg                    230
# 143                            eg_index_all_eds_eg                    106
# 144                            eg_index_all_hi7_eg                    240
# 145                            eg_index_all_swd_eg                    268
# 146                            eg_index_all_wh7_eg                    161
# 147                            eg_score_all_aig_eg                    295
# 148                            eg_score_all_all_eg                    105
# 149                            eg_score_all_bl7_eg                    312
# 150                            eg_score_all_eds_eg                    159
# 151                            eg_score_all_hi7_eg                    337
# 152                            eg_score_all_swd_eg                    321
# 153                            eg_score_all_wh7_eg                    205
# 154                                    den_all_elp                    325
# 155                                    den_eds_elp                    364
# 156                                    den_els_elp                    325
# 157                                    den_hi7_elp                    344
# 158                                   den_male_elp                    377
# 159                                   den_nswd_elp                    357
# 160                                    pct_all_elp                    325
# 161                                    pct_eds_elp                    364
# 162                                    pct_els_elp                    325
# 163                                    pct_hi7_elp                    344
# 164                                   pct_male_elp                    377
# 165                                   pct_nswd_elp                    357
# 166                               pct_prof_9gr_irm                    103
# 167             pct_met_4_year_graduation_rate_ltg                    144
# 168                      pct_met_math_grade_11_ltg                    171
# 169                   pct_met_reading_grade_10_ltg                    165
# 170                      pct_met_total_targets_ltg                     88
# 171       target_assign_4_year_graduation_rate_ltg                    144
# 172                target_assign_math_grade_11_ltg                    171
# 173             target_assign_reading_grade_10_ltg                    165
# 174                target_assign_total_targets_ltg                     88
# 175          target_met_4_year_graduation_rate_ltg                    144
# 176                   target_met_math_grade_11_ltg                    171
# 177                target_met_reading_grade_10_ltg                    165
# 178                   target_met_total_targets_ltg                     88
# 179                                    pct_aig_mcr                    232
# 180                                    pct_all_mcr                     96
# 181                                    pct_bl7_mcr                    253
# 182                                    pct_eds_mcr                    143
# 183                                    pct_fem_mcr                    135
# 184                                    pct_hi7_mcr                    279
# 185                                   pct_male_mcr                    128
# 186                                   pct_neds_mcr                    127
# 187                                   pct_nswd_mcr                    118
# 188                                    pct_swd_mcr                    270
# 189                                    pct_wh7_mcr                    159
# 190                      pct_met_act_workkeys_part                    282
# 191                           pct_met_biology_part                    153
# 192                        pct_met_english_ii_part                    146
# 193                  pct_met_high_school_math_part                    153
# 194                           pct_met_the_act_part                    153
# 195                     pct_met_total_targets_part                     96
# 196                target_assign_act_workkeys_part                    282
# 197                     target_assign_biology_part                    153
# 198                  target_assign_english_ii_part                    146
# 199            target_assign_high_school_math_part                    153
# 200                     target_assign_the_act_part                    153
# 201               target_assign_total_targets_part                     96
# 202                   target_met_act_workkeys_part                    282
# 203                        target_met_biology_part                    153
# 204                     target_met_english_ii_part                    146
# 205               target_met_high_school_math_part                    153
# 206                        target_met_the_act_part                    153
# 207                  target_met_total_targets_part                     96
# 208                  pct_act_workkeys_all_part_det                    282
# 209                  pct_act_workkeys_wh7_part_det                    371
# 210                       pct_biology_all_part_det                    153
# 211                       pct_biology_eds_part_det                    266
# 212                       pct_biology_wh7_part_det                    274
# 213                    pct_english_ii_all_part_det                    146
# 214                    pct_english_ii_eds_part_det                    250
# 215                    pct_english_ii_wh7_part_det                    275
# 216              pct_high_school_math_all_part_det                    153
# 217              pct_high_school_math_eds_part_det                    266
# 218              pct_high_school_math_wh7_part_det                    274
# 219                       pct_the_act_all_part_det                    153
# 220                       pct_the_act_eds_part_det                    264
# 221                       pct_the_act_wh7_part_det                    272
# 222                          pct_ccr_bi_eoc_aig_pc                    239
# 223                          pct_ccr_bi_eoc_all_pc                    117
# 224                          pct_ccr_bi_eoc_bl7_pc                    275
# 225                          pct_ccr_bi_eoc_eds_pc                    157
# 226                          pct_ccr_bi_eoc_fem_pc                    152
# 227                          pct_ccr_bi_eoc_hi7_pc                    266
# 228                         pct_ccr_bi_eoc_male_pc                    147
# 229                         pct_ccr_bi_eoc_neds_pc                    141
# 230                         pct_ccr_bi_eoc_nswd_pc                    125
# 231                          pct_ccr_bi_eoc_swd_pc                    346
# 232                          pct_ccr_bi_eoc_wh7_pc                    178
# 233                          pct_ccr_e2_eoc_aig_pc                    225
# 234                          pct_ccr_e2_eoc_all_pc                    108
# 235                          pct_ccr_e2_eoc_bl7_pc                    256
# 236                          pct_ccr_e2_eoc_eds_pc                    136
# 237                          pct_ccr_e2_eoc_fem_pc                    132
# 238                          pct_ccr_e2_eoc_hi7_pc                    254
# 239                         pct_ccr_e2_eoc_male_pc                    132
# 240                         pct_ccr_e2_eoc_neds_pc                    134
# 241                         pct_ccr_e2_eoc_nswd_pc                    112
# 242                          pct_ccr_e2_eoc_swd_pc                    365
# 243                          pct_ccr_e2_eoc_wh7_pc                    167
# 244                         pct_ccr_eoc_eoc_aig_pc                    157
# 245                         pct_ccr_eoc_eoc_all_pc                     91
# 246                         pct_ccr_eoc_eoc_bl7_pc                    193
# 247                         pct_ccr_eoc_eoc_eds_pc                    115
# 248                         pct_ccr_eoc_eoc_fem_pc                     99
# 249                         pct_ccr_eoc_eoc_hi7_pc                    160
# 250                        pct_ccr_eoc_eoc_male_pc                    113
# 251                         pct_ccr_eoc_eoc_mu7_pc                    267
# 252                        pct_ccr_eoc_eoc_neds_pc                     96
# 253                        pct_ccr_eoc_eoc_nswd_pc                     96
# 254                         pct_ccr_eoc_eoc_swd_pc                    356
# 255                         pct_ccr_eoc_eoc_wh7_pc                    106
# 256                          pct_ccr_m1_eoc_all_pc                    248
# 257                          pct_ccr_m1_eoc_eds_pc                    311
# 258                          pct_ccr_m1_eoc_fem_pc                    260
# 259                         pct_ccr_m1_eoc_male_pc                    291
# 260                         pct_ccr_m1_eoc_neds_pc                    259
# 261                         pct_ccr_m1_eoc_nswd_pc                    235
# 262                          pct_ccr_m1_eoc_wh7_pc                    284
# 263                          pct_ccr_m3_eoc_aig_pc                    229
# 264                          pct_ccr_m3_eoc_all_pc                    169
# 265                          pct_ccr_m3_eoc_eds_pc                    246
# 266                          pct_ccr_m3_eoc_fem_pc                    181
# 267                          pct_ccr_m3_eoc_hi7_pc                    305
# 268                         pct_ccr_m3_eoc_male_pc                    198
# 269                         pct_ccr_m3_eoc_neds_pc                    172
# 270                         pct_ccr_m3_eoc_nswd_pc                    164
# 271                          pct_ccr_m3_eoc_wh7_pc                    197
# 272                          pct_glp_bi_eoc_aig_pc                    239
# 273                          pct_glp_bi_eoc_all_pc                    110
# 274                          pct_glp_bi_eoc_bl7_pc                    270
# 275                          pct_glp_bi_eoc_eds_pc                    151
# 276                          pct_glp_bi_eoc_fem_pc                    149
# 277                          pct_glp_bi_eoc_hi7_pc                    264
# 278                         pct_glp_bi_eoc_male_pc                    139
# 279                         pct_glp_bi_eoc_neds_pc                    138
# 280                         pct_glp_bi_eoc_nswd_pc                    120
# 281                          pct_glp_bi_eoc_swd_pc                    308
# 282                          pct_glp_bi_eoc_wh7_pc                    177
# 283                          pct_glp_e2_eoc_aig_pc                    225
# 284                          pct_glp_e2_eoc_all_pc                    102
# 285                          pct_glp_e2_eoc_bl7_pc                    253
# 286                          pct_glp_e2_eoc_eds_pc                    134
# 287                          pct_glp_e2_eoc_fem_pc                    130
# 288                          pct_glp_e2_eoc_hi7_pc                    252
# 289                         pct_glp_e2_eoc_male_pc                    126
# 290                         pct_glp_e2_eoc_neds_pc                    133
# 291                         pct_glp_e2_eoc_nswd_pc                    107
# 292                          pct_glp_e2_eoc_swd_pc                    312
# 293                          pct_glp_e2_eoc_wh7_pc                    166
# 294                         pct_glp_eoc_eoc_aig_pc                    157
# 295                         pct_glp_eoc_eoc_all_pc                     72
# 296                         pct_glp_eoc_eoc_bl7_pc                    174
# 297                         pct_glp_eoc_eoc_eds_pc                     94
# 298                         pct_glp_eoc_eoc_els_pc                    362
# 299                         pct_glp_eoc_eoc_fem_pc                     89
# 300                         pct_glp_eoc_eoc_hi7_pc                    152
# 301                        pct_glp_eoc_eoc_male_pc                     88
# 302                         pct_glp_eoc_eoc_mu7_pc                    261
# 303                        pct_glp_eoc_eoc_neds_pc                     88
# 304                        pct_glp_eoc_eoc_nswd_pc                     82
# 305                         pct_glp_eoc_eoc_swd_pc                    247
# 306                         pct_glp_eoc_eoc_wh7_pc                     98
# 307                          pct_glp_m1_eoc_all_pc                    132
# 308                          pct_glp_m1_eoc_bl7_pc                    306
# 309                          pct_glp_m1_eoc_eds_pc                    167
# 310                          pct_glp_m1_eoc_fem_pc                    164
# 311                          pct_glp_m1_eoc_hi7_pc                    304
# 312                         pct_glp_m1_eoc_male_pc                    180
# 313                         pct_glp_m1_eoc_neds_pc                    174
# 314                         pct_glp_m1_eoc_nswd_pc                    139
# 315                          pct_glp_m1_eoc_swd_pc                    347
# 316                          pct_glp_m1_eoc_wh7_pc                    213
# 317                          pct_glp_m3_eoc_aig_pc                    227
# 318                          pct_glp_m3_eoc_all_pc                    123
# 319                          pct_glp_m3_eoc_bl7_pc                    287
# 320                          pct_glp_m3_eoc_eds_pc                    157
# 321                          pct_glp_m3_eoc_fem_pc                    142
# 322                          pct_glp_m3_eoc_hi7_pc                    266
# 323                         pct_glp_m3_eoc_male_pc                    150
# 324                         pct_glp_m3_eoc_neds_pc                    145
# 325                         pct_glp_m3_eoc_nswd_pc                    121
# 326                          pct_glp_m3_eoc_wh7_pc                    184
# 327                           pct_l1_bi_eoc_all_pc                    196
# 328                           pct_l1_bi_eoc_bl7_pc                    293
# 329                           pct_l1_bi_eoc_eds_pc                    200
# 330                           pct_l1_bi_eoc_fem_pc                    239
# 331                           pct_l1_bi_eoc_hi7_pc                    304
# 332                          pct_l1_bi_eoc_male_pc                    222
# 333                          pct_l1_bi_eoc_neds_pc                    263
# 334                          pct_l1_bi_eoc_nswd_pc                    238
# 335                           pct_l1_bi_eoc_swd_pc                    286
# 336                           pct_l1_bi_eoc_wh7_pc                    306
# 337                           pct_l1_e2_eoc_all_pc                    196
# 338                           pct_l1_e2_eoc_bl7_pc                    283
# 339                           pct_l1_e2_eoc_eds_pc                    198
# 340                           pct_l1_e2_eoc_fem_pc                    245
# 341                           pct_l1_e2_eoc_hi7_pc                    298
# 342                          pct_l1_e2_eoc_male_pc                    189
# 343                          pct_l1_e2_eoc_neds_pc                    260
# 344                          pct_l1_e2_eoc_nswd_pc                    226
# 345                           pct_l1_e2_eoc_swd_pc                    275
# 346                           pct_l1_e2_eoc_wh7_pc                    279
# 347                           pct_l2_bi_eoc_all_pc                    134
# 348                           pct_l2_bi_eoc_bl7_pc                    277
# 349                           pct_l2_bi_eoc_eds_pc                    162
# 350                           pct_l2_bi_eoc_fem_pc                    175
# 351                           pct_l2_bi_eoc_hi7_pc                    283
# 352                          pct_l2_bi_eoc_male_pc                    178
# 353                          pct_l2_bi_eoc_neds_pc                    185
# 354                          pct_l2_bi_eoc_nswd_pc                    150
# 355                           pct_l2_bi_eoc_swd_pc                    301
# 356                           pct_l2_bi_eoc_wh7_pc                    228
# 357                           pct_l2_e2_eoc_all_pc                    132
# 358                           pct_l2_e2_eoc_bl7_pc                    265
# 359                           pct_l2_e2_eoc_eds_pc                    156
# 360                           pct_l2_e2_eoc_fem_pc                    178
# 361                           pct_l2_e2_eoc_hi7_pc                    269
# 362                          pct_l2_e2_eoc_male_pc                    160
# 363                          pct_l2_e2_eoc_neds_pc                    191
# 364                          pct_l2_e2_eoc_nswd_pc                    150
# 365                           pct_l2_e2_eoc_swd_pc                    295
# 366                           pct_l2_e2_eoc_wh7_pc                    230
# 367                          pct_l3_all_all_aig_pc                    204
# 368                          pct_l3_all_all_all_pc                     87
# 369                          pct_l3_all_all_bl7_pc                    181
# 370                          pct_l3_all_all_eds_pc                    101
# 371                          pct_l3_all_all_fem_pc                     90
# 372                          pct_l3_all_all_hi7_pc                    150
# 373                         pct_l3_all_all_male_pc                    102
# 374                          pct_l3_all_all_mu7_pc                    268
# 375                         pct_l3_all_all_neds_pc                     87
# 376                         pct_l3_all_all_nswd_pc                    102
# 377                          pct_l3_all_all_swd_pc                    324
# 378                          pct_l3_all_all_wh7_pc                     93
# 379                           pct_l3_bi_eoc_all_pc                    186
# 380                           pct_l3_bi_eoc_bl7_pc                    349
# 381                           pct_l3_bi_eoc_eds_pc                    239
# 382                           pct_l3_bi_eoc_fem_pc                    229
# 383                           pct_l3_bi_eoc_hi7_pc                    361
# 384                          pct_l3_bi_eoc_male_pc                    238
# 385                          pct_l3_bi_eoc_neds_pc                    245
# 386                          pct_l3_bi_eoc_nswd_pc                    196
# 387                           pct_l3_bi_eoc_wh7_pc                    286
# 388                           pct_l3_e2_eoc_all_pc                    151
# 389                           pct_l3_e2_eoc_bl7_pc                    313
# 390                           pct_l3_e2_eoc_eds_pc                    175
# 391                           pct_l3_e2_eoc_fem_pc                    187
# 392                           pct_l3_e2_eoc_hi7_pc                    301
# 393                          pct_l3_e2_eoc_male_pc                    188
# 394                          pct_l3_e2_eoc_neds_pc                    205
# 395                          pct_l3_e2_eoc_nswd_pc                    154
# 396                           pct_l3_e2_eoc_wh7_pc                    238
# 397                          pct_l3_eoc_eoc_aig_pc                    211
# 398                          pct_l3_eoc_eoc_all_pc                    100
# 399                          pct_l3_eoc_eoc_bl7_pc                    195
# 400                          pct_l3_eoc_eoc_eds_pc                    115
# 401                          pct_l3_eoc_eoc_fem_pc                    109
# 402                          pct_l3_eoc_eoc_hi7_pc                    167
# 403                         pct_l3_eoc_eoc_male_pc                    111
# 404                          pct_l3_eoc_eoc_mu7_pc                    279
# 405                         pct_l3_eoc_eoc_neds_pc                    103
# 406                         pct_l3_eoc_eoc_nswd_pc                    108
# 407                          pct_l3_eoc_eoc_swd_pc                    341
# 408                          pct_l3_eoc_eoc_wh7_pc                    119
# 409                           pct_l3_m1_eoc_all_pc                    137
# 410                           pct_l3_m1_eoc_bl7_pc                    309
# 411                           pct_l3_m1_eoc_eds_pc                    172
# 412                           pct_l3_m1_eoc_fem_pc                    166
# 413                           pct_l3_m1_eoc_hi7_pc                    306
# 414                          pct_l3_m1_eoc_male_pc                    186
# 415                          pct_l3_m1_eoc_neds_pc                    178
# 416                          pct_l3_m1_eoc_nswd_pc                    144
# 417                           pct_l3_m1_eoc_swd_pc                    364
# 418                           pct_l3_m1_eoc_wh7_pc                    216
# 419                           pct_l3_m3_eoc_aig_pc                    245
# 420                           pct_l3_m3_eoc_all_pc                    128
# 421                           pct_l3_m3_eoc_bl7_pc                    303
# 422                           pct_l3_m3_eoc_eds_pc                    166
# 423                           pct_l3_m3_eoc_fem_pc                    144
# 424                           pct_l3_m3_eoc_hi7_pc                    272
# 425                          pct_l3_m3_eoc_male_pc                    165
# 426                          pct_l3_m3_eoc_neds_pc                    149
# 427                          pct_l3_m3_eoc_nswd_pc                    125
# 428                           pct_l3_m3_eoc_wh7_pc                    190
# 429                          pct_l4_all_all_aig_pc                    145
# 430                          pct_l4_all_all_all_pc                     79
# 431                          pct_l4_all_all_bl7_pc                    188
# 432                          pct_l4_all_all_eds_pc                    104
# 433                          pct_l4_all_all_fem_pc                     87
# 434                          pct_l4_all_all_hi7_pc                    150
# 435                         pct_l4_all_all_male_pc                     89
# 436                          pct_l4_all_all_mu7_pc                    255
# 437                         pct_l4_all_all_neds_pc                     79
# 438                         pct_l4_all_all_nswd_pc                     85
# 439                          pct_l4_all_all_swd_pc                    383
# 440                          pct_l4_all_all_wh7_pc                     81
# 441                           pct_l4_bi_eoc_aig_pc                    241
# 442                           pct_l4_bi_eoc_all_pc                    118
# 443                           pct_l4_bi_eoc_bl7_pc                    278
# 444                           pct_l4_bi_eoc_eds_pc                    158
# 445                           pct_l4_bi_eoc_fem_pc                    153
# 446                           pct_l4_bi_eoc_hi7_pc                    267
# 447                          pct_l4_bi_eoc_male_pc                    150
# 448                          pct_l4_bi_eoc_neds_pc                    141
# 449                          pct_l4_bi_eoc_nswd_pc                    127
# 450                           pct_l4_bi_eoc_swd_pc                    370
# 451                           pct_l4_bi_eoc_wh7_pc                    179
# 452                           pct_l4_e2_eoc_aig_pc                    225
# 453                           pct_l4_e2_eoc_all_pc                    108
# 454                           pct_l4_e2_eoc_bl7_pc                    256
# 455                           pct_l4_e2_eoc_eds_pc                    136
# 456                           pct_l4_e2_eoc_fem_pc                    132
# 457                           pct_l4_e2_eoc_hi7_pc                    254
# 458                          pct_l4_e2_eoc_male_pc                    132
# 459                          pct_l4_e2_eoc_neds_pc                    134
# 460                          pct_l4_e2_eoc_nswd_pc                    112
# 461                           pct_l4_e2_eoc_wh7_pc                    167
# 462                          pct_l4_eoc_eoc_aig_pc                    157
# 463                          pct_l4_eoc_eoc_all_pc                     95
# 464                          pct_l4_eoc_eoc_bl7_pc                    197
# 465                          pct_l4_eoc_eoc_eds_pc                    117
# 466                          pct_l4_eoc_eoc_fem_pc                    101
# 467                          pct_l4_eoc_eoc_hi7_pc                    162
# 468                         pct_l4_eoc_eoc_male_pc                    114
# 469                          pct_l4_eoc_eoc_mu7_pc                    273
# 470                         pct_l4_eoc_eoc_neds_pc                     99
# 471                         pct_l4_eoc_eoc_nswd_pc                     98
# 472                          pct_l4_eoc_eoc_wh7_pc                    108
# 473                           pct_l4_m1_eoc_all_pc                    248
# 474                           pct_l4_m1_eoc_eds_pc                    316
# 475                           pct_l4_m1_eoc_fem_pc                    262
# 476                          pct_l4_m1_eoc_male_pc                    295
# 477                          pct_l4_m1_eoc_neds_pc                    263
# 478                          pct_l4_m1_eoc_nswd_pc                    237
# 479                           pct_l4_m1_eoc_wh7_pc                    286
# 480                           pct_l4_m3_eoc_aig_pc                    230
# 481                           pct_l4_m3_eoc_all_pc                    178
# 482                           pct_l4_m3_eoc_eds_pc                    263
# 483                           pct_l4_m3_eoc_fem_pc                    190
# 484                           pct_l4_m3_eoc_hi7_pc                    322
# 485                          pct_l4_m3_eoc_male_pc                    214
# 486                          pct_l4_m3_eoc_neds_pc                    177
# 487                          pct_l4_m3_eoc_nswd_pc                    174
# 488                           pct_l4_m3_eoc_wh7_pc                    202
# 489                          pct_l5_all_all_aig_pc                    162
# 490                          pct_l5_all_all_all_pc                    312
# 491                          pct_l5_all_all_fem_pc                    307
# 492                         pct_l5_all_all_male_pc                    318
# 493                         pct_l5_all_all_neds_pc                    239
# 494                         pct_l5_all_all_nswd_pc                    294
# 495                          pct_l5_all_all_wh7_pc                    237
# 496                           pct_l5_bi_eoc_aig_pc                    241
# 497                           pct_l5_bi_eoc_all_pc                    212
# 498                           pct_l5_bi_eoc_eds_pc                    315
# 499                           pct_l5_bi_eoc_fem_pc                    232
# 500                           pct_l5_bi_eoc_hi7_pc                    376
# 501                          pct_l5_bi_eoc_male_pc                    230
# 502                          pct_l5_bi_eoc_neds_pc                    200
# 503                          pct_l5_bi_eoc_nswd_pc                    211
# 504                           pct_l5_bi_eoc_wh7_pc                    221
# 505                           pct_l5_e2_eoc_aig_pc                    263
# 506                          pct_l5_e2_eoc_neds_pc                    353
# 507                           pct_l5_e2_eoc_wh7_pc                    368
# 508                          pct_l5_eoc_eoc_aig_pc                    173
# 509                          pct_l5_eoc_eoc_all_pc                    314
# 510                          pct_l5_eoc_eoc_fem_pc                    314
# 511                         pct_l5_eoc_eoc_male_pc                    326
# 512                         pct_l5_eoc_eoc_neds_pc                    245
# 513                         pct_l5_eoc_eoc_nswd_pc                    300
# 514                          pct_l5_eoc_eoc_wh7_pc                    241
# 515                           pct_l5_m3_eoc_aig_pc                    269
# 516                           pct_l5_m3_eoc_all_pc                    374
# 517                          pct_l5_m3_eoc_male_pc                    371
# 518                          pct_l5_m3_eoc_neds_pc                    338
# 519                          pct_l5_m3_eoc_nswd_pc                    367
# 520                           pct_l5_m3_eoc_wh7_pc                    347
# 521                     pct_notprof_all_all_aig_pc                    348
# 522                     pct_notprof_all_all_all_pc                     64
# 523                     pct_notprof_all_all_bl7_pc                    141
# 524                     pct_notprof_all_all_eds_pc                     71
# 525                     pct_notprof_all_all_els_pc                    295
# 526                     pct_notprof_all_all_fem_pc                     70
# 527                     pct_notprof_all_all_hi7_pc                    135
# 528                    pct_notprof_all_all_male_pc                     77
# 529                     pct_notprof_all_all_mu7_pc                    245
# 530                    pct_notprof_all_all_neds_pc                     80
# 531                    pct_notprof_all_all_nswd_pc                     83
# 532                     pct_notprof_all_all_swd_pc                    162
# 533                     pct_notprof_all_all_wh7_pc                     90
# 534                     pct_notprof_eoc_eoc_aig_pc                    352
# 535                     pct_notprof_eoc_eoc_all_pc                     74
# 536                     pct_notprof_eoc_eoc_bl7_pc                    155
# 537                     pct_notprof_eoc_eoc_eds_pc                     85
# 538                     pct_notprof_eoc_eoc_els_pc                    313
# 539                     pct_notprof_eoc_eoc_fem_pc                     89
# 540                     pct_notprof_eoc_eoc_hi7_pc                    159
# 541                    pct_notprof_eoc_eoc_male_pc                     93
# 542                     pct_notprof_eoc_eoc_mu7_pc                    265
# 543                    pct_notprof_eoc_eoc_neds_pc                    100
# 544                    pct_notprof_eoc_eoc_nswd_pc                     89
# 545                     pct_notprof_eoc_eoc_swd_pc                    185
# 546                     pct_notprof_eoc_eoc_wh7_pc                    118
# 547                      pct_notprof_m1_eoc_all_pc                    120
# 548                      pct_notprof_m1_eoc_bl7_pc                    274
# 549                      pct_notprof_m1_eoc_eds_pc                    155
# 550                      pct_notprof_m1_eoc_fem_pc                    172
# 551                      pct_notprof_m1_eoc_hi7_pc                    301
# 552                     pct_notprof_m1_eoc_male_pc                    175
# 553                     pct_notprof_m1_eoc_neds_pc                    184
# 554                     pct_notprof_m1_eoc_nswd_pc                    139
# 555                      pct_notprof_m1_eoc_swd_pc                    273
# 556                      pct_notprof_m1_eoc_wh7_pc                    223
# 557                      pct_notprof_m3_eoc_aig_pc                    341
# 558                      pct_notprof_m3_eoc_all_pc                    113
# 559                      pct_notprof_m3_eoc_bl7_pc                    270
# 560                      pct_notprof_m3_eoc_eds_pc                    145
# 561                      pct_notprof_m3_eoc_fem_pc                    144
# 562                      pct_notprof_m3_eoc_hi7_pc                    272
# 563                     pct_notprof_m3_eoc_male_pc                    154
# 564                     pct_notprof_m3_eoc_neds_pc                    156
# 565                     pct_notprof_m3_eoc_nswd_pc                    118
# 566                      pct_notprof_m3_eoc_swd_pc                    342
# 567                      pct_notprof_m3_eoc_wh7_pc                    200
# 568                             aaa_score_all_spg2                    131
# 569                             aaa_score_bl7_spg2                    305
# 570                             aaa_score_eds_spg2                    167
# 571                             aaa_score_hi7_spg2                    305
# 572                             aaa_score_swd_spg2                    297
# 573                             aaa_score_wh7_spg2                    188
# 574                             ach_score_all_spg2                    122
# 575                             ach_score_bl7_spg2                    301
# 576                             ach_score_eds_spg2                    165
# 577                             ach_score_hi7_spg2                    305
# 578                             ach_score_swd_spg2                    297
# 579                             ach_score_wh7_spg2                    181
# 580                             awa_score_all_spg2                    180
# 581                             awa_score_eds_spg2                    290
# 582                             awa_score_wh7_spg2                    286
# 583                              bi_score_all_spg2                    166
# 584                              bi_score_eds_spg2                    256
# 585                              bi_score_wh7_spg2                    279
# 586                            cgrs_score_all_spg2                    174
# 587                            cgrs_score_eds_spg2                    277
# 588                            cgrs_score_wh7_spg2                    268
# 589                              eg_score_all_spg2                    135
# 590                              eg_score_bl7_spg2                    319
# 591                              eg_score_eds_spg2                    178
# 592                              eg_score_hi7_spg2                    337
# 593                              eg_score_swd_spg2                    322
# 594                              eg_score_wh7_spg2                    211
# 595                             mcr_score_all_spg2                    178
# 596                             mcr_score_eds_spg2                    281
# 597                             mcr_score_wh7_spg2                    283
# 598                             spg_score_all_spg2                    122
# 599                             spg_score_bl7_spg2                    301
# 600                             spg_score_eds_spg2                    165
# 601                             spg_score_hi7_spg2                    305
# 602                             spg_score_swd_spg2                    297
# 603                             spg_score_wh7_spg2                    181
# 604                                     pct_all_wk                    243
# 605                                     pct_eds_wk                    288
# 606                                     pct_fem_wk                    268
# 607                                    pct_male_wk                    267
# 608                                    pct_neds_wk                    267
# 609                                    pct_nswd_wk                    246
# 610                                     pct_wh7_wk                    305
# 611                            avg_student_num_adm                     37
# 612                                 pct_ap_pass_ap                    232
# 613                        pct_ap_participation_ap                    233
# 614                         count_all_chron_absent                     54
# 615                         count_bl7_chron_absent                    129
# 616                         count_els_chron_absent                    217
# 617                         count_fem_chron_absent                     65
# 618                         count_hi7_chron_absent                    113
# 619                        count_male_chron_absent                     83
# 620                         count_mu7_chron_absent                    151
# 621                         count_swd_chron_absent                    151
# 622                         count_wh7_chron_absent                     74
# 623                           pct_all_chron_absent                     54
# 624                           pct_bl7_chron_absent                    129
# 625                           pct_els_chron_absent                    217
# 626                           pct_fem_chron_absent                     65
# 627                           pct_hi7_chron_absent                    113
# 628                          pct_male_chron_absent                     83
# 629                           pct_mu7_chron_absent                    151
# 630                           pct_swd_chron_absent                    151
# 631                           pct_wh7_chron_absent                     74
# 632                  count_2018_enroll_as7_college                    285
# 633                  count_2018_enroll_all_college                     95
# 634                  count_2018_enroll_bl7_college                    131
# 635                  count_2018_enroll_eds_college                    225
# 636                  count_2018_enroll_els_college                    287
# 637                  count_2018_enroll_fem_college                    102
# 638                  count_2018_enroll_hi7_college                    130
# 639                 count_2018_enroll_male_college                     98
# 640                  count_2018_enroll_mu7_college                    169
# 641                  count_2018_enroll_swd_college                    162
# 642                  count_2018_enroll_wh7_college                    104
# 643                  count_2018_noenro_as7_college                    285
# 644                  count_2018_noenro_all_college                     95
# 645                  count_2018_noenro_bl7_college                    131
# ...
# 682                     tot_num_ap_h_male_courses2                    258
# 683                      tot_num_ap_h_mu7_courses2                    258
# 684                    tot_num_ap_h_other_courses2                    258
# 685                      tot_num_ap_h_pi7_courses2                    258
# 686                      tot_num_ap_h_swd_courses2                    258
# 687                      tot_num_ap_h_wh7_courses2                    258
# 688                     tot_num_ccp_h_am7_courses2                    140
# 689                     tot_num_ccp_h_as7_courses2                    140
# 690                     tot_num_ccp_h_bl7_courses2                    140
# 691                     tot_num_ccp_h_els_courses2                    140
# 692                     tot_num_ccp_h_fem_courses2                    140
# 693                     tot_num_ccp_h_hi7_courses2                    140
# 694                    tot_num_ccp_h_male_courses2                    140
# 695                     tot_num_ccp_h_mu7_courses2                    140
# 696                   tot_num_ccp_h_other_courses2                    140
# 697                     tot_num_ccp_h_pi7_courses2                    140
# 698                     tot_num_ccp_h_swd_courses2                    140
# 699                     tot_num_ccp_h_wh7_courses2                    140
# 700                            year_h_am7_courses2                    139
# 701                            year_h_as7_courses2                    139
# 702                            year_h_bl7_courses2                    139
# 703                            year_h_els_courses2                    139
# 704                            year_h_fem_courses2                    139
# 705                            year_h_hi7_courses2                    139
# 706                           year_h_male_courses2                    139
# 707                            year_h_mu7_courses2                    139
# 708                          year_h_other_courses2                    139
# 709                            year_h_pi7_courses2                    139
# 710                            year_h_swd_courses2                    139
# 711                            year_h_wh7_courses2                    139
# 712                 num_concentrators_aavc_cte_con                    350
# 713                 num_concentrators_agnr_cte_con                    264
# 714                 num_concentrators_arch_cte_con                    260
# 715                  num_concentrators_bma_cte_con                    260
# 716                 num_concentrators_hlth_cte_con                    263
# 717                 num_concentrators_hosp_cte_con                    250
# 718                 num_concentrators_info_cte_con                    253
# 719                 num_concentrators_manu_cte_con                    356
# 720                 num_concentrators_stem_cte_con                    354
# 721                       num_credentials_cte_cred                    130
# 722                 career_only_cte_end_cte_enroll                    159
# 723  career_college_college_unc_cte_end_cte_enroll                    159
# 724    college_college_unc_only_cte_end_cte_enroll                    159
# 725                college_only_cte_end_cte_enroll                    159
# 726                                     stu_enroll                     61
# 727                                     cte_enroll                     61
# 728                                            pct                     61
# 729                                     ni_effect3                     34
# 730                                    eff_effect3                     34
# 731                                     he_effect3                     34
# 732                                 ni_pct_effect3                     34
# 733                                eff_pct_effect3                     34
# 734                                 he_pct_effect3                     34
# 735                          number_of_teachers_eq                     34
# 736                                 beg_teacher_eq                     34
# 737                            pct_beg_teachers_eq                     34
# 738                               prov_teachers_eq                     34
# 739                           pct_prov_teachers_eq                     34
# 740                     adm_central_expense_funds2                     37
# 741                   adm_employee_benefits_funds2                     37
# 742                adm_instructional_equip._funds2                     37
# 743                       adm_other_objects_funds2                     37
# 744                  adm_purchased_services_funds2                     37
# 745                            adm_salaries_funds2                     37
# 746                adm_supplies_&_materials_funds2                     37
# 747                               adm_total_funds2                     37
# 748           federal_funds_central_expense_funds2                     37
# 749         federal_funds_employee_benefits_funds2                     37
# 750      federal_funds_instructional_equip._funds2                     37
# 751             federal_funds_other_objects_funds2                     37
# 752        federal_funds_purchased_services_funds2                     37
# 753                  federal_funds_salaries_funds2                     37
# 754      federal_funds_supplies_&_materials_funds2                     37
# 755                     federal_funds_total_funds2                     37
# 756             federal_ppe_central_expense_funds2                     37
# 757           federal_ppe_employee_benefits_funds2                     37
# 758        federal_ppe_instructional_equip._funds2                     37
# 759               federal_ppe_other_objects_funds2                     37
# 760          federal_ppe_purchased_services_funds2                     37
# 761                    federal_ppe_salaries_funds2                     37
# 762        federal_ppe_supplies_&_materials_funds2                     37
# 763                       federal_ppe_total_funds2                     37
# 764             local_funds_central_expense_funds2                     37
# 765           local_funds_employee_benefits_funds2                     37
# 766        local_funds_instructional_equip._funds2                     37
# 767               local_funds_other_objects_funds2                     37
# 768          local_funds_purchased_services_funds2                     37
# 769                    local_funds_salaries_funds2                     37
# 770        local_funds_supplies_&_materials_funds2                     37
# 771                       local_funds_total_funds2                     37
# 772               local_ppe_central_expense_funds2                     37
# 773             local_ppe_employee_benefits_funds2                     37
# 774          local_ppe_instructional_equip._funds2                     37
# 775                 local_ppe_other_objects_funds2                     37
# 776            local_ppe_purchased_services_funds2                     37
# 777                      local_ppe_salaries_funds2                     37
# 778          local_ppe_supplies_&_materials_funds2                     37
# 779                         local_ppe_total_funds2                     37
# 780             state_funds_central_expense_funds2                     37
# 781           state_funds_employee_benefits_funds2                     37
# 782        state_funds_instructional_equip._funds2                     37
# 783               state_funds_other_objects_funds2                     37
# 784          state_funds_purchased_services_funds2                     37
# 785                    state_funds_salaries_funds2                     37
# 786        state_funds_supplies_&_materials_funds2                     37
# 787                       state_funds_total_funds2                     37
# 788               state_ppe_central_expense_funds2                     37
# 789             state_ppe_employee_benefits_funds2                     37
# 790          state_ppe_instructional_equip._funds2                     37
# 791                 state_ppe_other_objects_funds2                     37
# 792            state_ppe_purchased_services_funds2                     37
# 793                      state_ppe_salaries_funds2                     37
# 794          state_ppe_supplies_&_materials_funds2                     37
# 795                         state_ppe_total_funds2                     37
# 796             total_funds_central_expense_funds2                     37
# 797           total_funds_employee_benefits_funds2                     37
# 798        total_funds_instructional_equip._funds2                     37
# 799               total_funds_other_objects_funds2                     37
# 800          total_funds_purchased_services_funds2                     37
# 801                    total_funds_salaries_funds2                     37
# 802        total_funds_supplies_&_materials_funds2                     37
# 803                       total_funds_total_funds2                     37
# 804               total_ppe_central_expense_funds2                     37
# 805             total_ppe_employee_benefits_funds2                     37
# 806          total_ppe_instructional_equip._funds2                     37
# 807                 total_ppe_other_objects_funds2                     37
# 808            total_ppe_purchased_services_funds2                     37
# 809                      total_ppe_salaries_funds2                     37
# 810          total_ppe_supplies_&_materials_funds2                     37
# 811                         total_ppe_total_funds2                     37
# 812                           act_per1000_all_inc2                     68
# 813                           act_per1000_bl7_inc2                    163
# 814                           act_per1000_eds_inc2                     84
# 815                           act_per1000_els_inc2                    321
# 816                           act_per1000_fem_inc2                    102
# 817                           act_per1000_hi7_inc2                    188
# 818                          act_per1000_male_inc2                     82
# 819                           act_per1000_mu7_inc2                    302
# 820                           act_per1000_swd_inc2                    176
# 821                           act_per1000_wh7_inc2                    115
# 822                           arr_per1000_all_inc2                     68
# 823                           arr_per1000_bl7_inc2                    163
# 824                           arr_per1000_eds_inc2                     84
# 825                           arr_per1000_els_inc2                    321
# 826                           arr_per1000_fem_inc2                    102
# 827                           arr_per1000_hi7_inc2                    188
# 828                          arr_per1000_male_inc2                     82
# 829                           arr_per1000_mu7_inc2                    302
# 830                           arr_per1000_swd_inc2                    176
# 831                           arr_per1000_wh7_inc2                    115
# 832                           bha_per1000_all_inc2                     68
# 833                           bha_per1000_bl7_inc2                    163
# 834                           bha_per1000_eds_inc2                     84
# 835                           bha_per1000_els_inc2                    321
# 836                           bha_per1000_fem_inc2                    102
# 837                           bha_per1000_hi7_inc2                    188
# 838                          bha_per1000_male_inc2                     82
# 839                           bha_per1000_mu7_inc2                    302
# 840                           bha_per1000_swd_inc2                    176
# 841                           bha_per1000_wh7_inc2                    115
# 842                           exp_per1000_all_inc2                     68
# 843                           exp_per1000_bl7_inc2                    163
# 844                           exp_per1000_eds_inc2                     84
# 845                           exp_per1000_els_inc2                    321
# 846                           exp_per1000_fem_inc2                    102
# 847                           exp_per1000_hi7_inc2                    188
# 848                          exp_per1000_male_inc2                     82
# 849                           exp_per1000_mu7_inc2                    302
# 850                           exp_per1000_swd_inc2                    176
# 851                           exp_per1000_wh7_inc2                    115
# 852                           iss_per1000_all_inc2                     68
# 853                           iss_per1000_bl7_inc2                    163
# 854                           iss_per1000_eds_inc2                     84
# 855                           iss_per1000_els_inc2                    321
# 856                           iss_per1000_fem_inc2                    102
# 857                           iss_per1000_hi7_inc2                    188
# 858                          iss_per1000_male_inc2                     82
# 859                           iss_per1000_mu7_inc2                    302
# 860                           iss_per1000_swd_inc2                    176
# 861                           iss_per1000_wh7_inc2                    115
# 862                           lts_per1000_all_inc2                     68
# 863                           lts_per1000_bl7_inc2                    163
# 864                           lts_per1000_eds_inc2                     84
# 865                           lts_per1000_els_inc2                    321
# 866                           lts_per1000_fem_inc2                    102
# 867                           lts_per1000_hi7_inc2                    188
# 868                          lts_per1000_male_inc2                     82
# 869                           lts_per1000_mu7_inc2                    302
# 870                           lts_per1000_swd_inc2                    176
# 871                           lts_per1000_wh7_inc2                    115
# 872                           rpt_per1000_all_inc2                     68
# 873                           rpt_per1000_bl7_inc2                    163
# 874                           rpt_per1000_eds_inc2                     84
# 875                           rpt_per1000_els_inc2                    321
# 876                           rpt_per1000_fem_inc2                    102
# 877                           rpt_per1000_hi7_inc2                    188
# 878                          rpt_per1000_male_inc2                     82
# 879                           rpt_per1000_mu7_inc2                    302
# 880                           rpt_per1000_swd_inc2                    176
# 881                           rpt_per1000_wh7_inc2                    115
# 882                           sts_per1000_all_inc2                     69
# 883                           sts_per1000_bl7_inc2                    169
# 884                           sts_per1000_eds_inc2                     84
# 885                           sts_per1000_els_inc2                    321
# 886                           sts_per1000_fem_inc2                    104
# 887                           sts_per1000_hi7_inc2                    189
# 888                          sts_per1000_male_inc2                     88
# 889                           sts_per1000_mu7_inc2                    302
# 890                           sts_per1000_swd_inc2                    176
# 891                           sts_per1000_wh7_inc2                    116
# 892                           avg_size_biology_sar                     90
# 893                        avg_size_english_ii_sar                     93
# 894                         avg_size_nc_math_1_sar                     90
# 895                         avg_size_nc_math_3_sar                     93
# 896                                  avg_sat_score                    194
# 897                          pct_sat_participation                    192

# %%
#Replace all remaining NaN with 0
schoolData = schoolData.fillna(0)

#Check for Missing values after final imputation 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# Empty DataFrame
# Columns: [Variable Name, Number Missing Values]
# Index: []

# %% [markdown]
# ## Identify and Remove Highly Correlated Features
# **Find and remove any columns / features that are > 95% correlated**
# * https://stackoverflow.com/questions/39409866/correlation-heatmap
# * https://chrisalbon.com/machine_learning/feature_selection/drop_highly_correlated_features/
# * https://codeyarns.com/2015/04/20/how-to-change-font-size-in-seaborn/

# %%
# calculate the correlation matrix
corr_matrix  = schoolData.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
#Print out all the missing value rows
pd.set_option('display.max_rows', 3500)

#Get all of the correlation values > 95%
x = np.where(upper > 0.95)

#Display all field combinations with > 95% correlation
cf = pd.DataFrame()
cf['Field1'] = upper.columns[x[1]]
cf['Field2'] = upper.index[x[0]]

#Get the correlation values for every field combination. (There must be a more pythonic way to do this!)
corr = [0] * len(cf)
for i in range(0, len(cf)):
    corr[i] =  upper[cf['Field1'][i]][cf['Field2'][i]] 
    
cf['Correlation'] = corr

print ('There are ', str(len(cf['Field1'])), ' field correlations > 95%.')
cf
# Out:
# There are  1041  field correlations > 95%.
#                                              Field1  \
# 0                                   indian_male_pct
# 1                                 indian_female_pct
# 2                                    asian_male_pct
# 3                                  asian_female_pct
# 4                                 pct_acall_fem_act
# 5                                pct_acall_male_act
# 6                                pct_acall_neds_act
# 7                                pct_acall_nswd_act
# 8                                  pct_acen_all_act
# 9                                 pct_acen_nswd_act
# 10                                 pct_acma_all_act
# 11                                pct_acma_nswd_act
# 12                                 pct_acrd_all_act
# 13                                pct_acrd_nswd_act
# 14                                 pct_acsc_all_act
# 15                                pct_acsc_nswd_act
# 16                               pct_acall_neds_act
# 17                               pct_acall_nswd_act
# 18                                 pct_acen_all_act
# 19                                pct_acen_nswd_act
# 20                                 pct_acrd_all_act
# 21                                pct_acrd_nswd_act
# 22                                 pct_acsc_all_act
# 23                                pct_acsc_nswd_act
# 24                               pct_acall_neds_act
# 25                               pct_acall_nswd_act
# 26                                 pct_acrd_all_act
# 27                               pct_acall_nswd_act
# 28                                pct_acall_wh7_act
# 29                                 pct_acen_all_act
# 30                                pct_acen_neds_act
# 31                                pct_acen_nswd_act
# 32                                 pct_acrd_all_act
# 33                                pct_acrd_neds_act
# 34                                pct_acrd_nswd_act
# 35                                pct_acsc_neds_act
# 36                                 pct_acen_all_act
# 37                                pct_acen_nswd_act
# 38                                 pct_acma_all_act
# 39                                pct_acma_nswd_act
# 40                                 pct_acrd_all_act
# 41                                pct_acrd_nswd_act
# 42                                 pct_acsc_all_act
# 43                                pct_acsc_nswd_act
# 44                                 pct_acen_aig_act
# 45                                 pct_acco_fem_act
# 46                                pct_acco_nswd_act
# 47                                 pct_acen_all_act
# 48                                pct_acen_nswd_act
# 49                                pct_acco_nswd_act
# 50                                 pct_acen_fem_act
# 51                                pct_acen_male_act
# 52                                pct_acco_nswd_act
# 53                                pct_acen_neds_act
# 54                                 pct_acen_all_act
# 55                                pct_acen_nswd_act
# 56                                 pct_acen_wh7_act
# 57                                 pct_acma_aig_act
# 58                                 pct_acrd_aig_act
# 59                                 pct_acsc_aig_act
# 60                                 pct_acen_fem_act
# 61                                pct_acen_neds_act
# 62                                pct_acen_nswd_act
# 63                                 pct_acrd_all_act
# 64                                pct_acrd_nswd_act
# 65                                pct_acen_nswd_act
# 66                                 pct_acrd_fem_act
# 67                                pct_acrd_male_act
# 68                                pct_acen_nswd_act
# 69                                pct_acrd_neds_act
# 70                                 pct_acrd_all_act
# 71                                pct_acrd_nswd_act
# 72                                 pct_acrd_wh7_act
# 73                                 pct_acsc_wh7_act
# 74                                 pct_acrd_aig_act
# 75                                 pct_acsc_aig_act
# 76                                 pct_acma_fem_act
# 77                                pct_acma_neds_act
# 78                                pct_acma_nswd_act
# 79                                 pct_acsc_all_act
# 80                                pct_acsc_nswd_act
# 81                                pct_acma_nswd_act
# 82                                pct_acsc_male_act
# 83                                pct_acma_nswd_act
# 84                                pct_acsc_neds_act
# 85                                 pct_acsc_all_act
# 86                                pct_acsc_nswd_act
# 87                                 pct_acsc_wh7_act
# 88                                 pct_acsc_aig_act
# 89                                 pct_acrd_fem_act
# 90                                pct_acrd_neds_act
# 91                                pct_acrd_nswd_act
# 92                                 pct_acsc_all_act
# 93                                pct_acsc_nswd_act
# 94                                pct_acrd_nswd_act
# 95                                pct_acsc_male_act
# 96                                pct_acrd_nswd_act
# 97                                pct_acsc_neds_act
# 98                                 pct_acsc_all_act
# 99                                pct_acsc_nswd_act
# 100                                pct_acsc_wh7_act
# 101                               pct_acsc_neds_act
# 102                               pct_acsc_nswd_act
# 103                               pct_acsc_nswd_act
# 104                                pct_acwr_fem_act
# 105                               pct_acwr_neds_act
# 106                               pct_acwr_nswd_act
# 107                               pct_acwr_nswd_act
# 108                               pct_acwr_nswd_act
# 109                                     pct_aig_mcr
# 110                                    pct_neds_awa
# 111                                    pct_nswd_awa
# 112                                    pct_neds_awa
# 113                                    pct_nswd_awa
# 114                                pct_ext_neds_cgr
# 115                                pct_ext_nswd_cgr
# 116                                 pct_std_fem_cgr
# 117                                pct_std_nswd_cgr
# 118                                pct_ext_neds_cgr
# 119                                pct_ext_nswd_cgr
# 120                                pct_ext_nswd_cgr
# 121                                 pct_std_fem_cgr
# 122                                pct_std_nswd_cgr
# 123                                 pct_std_fem_cgr
# 124                                pct_std_nswd_cgr
# 125                                pct_std_nswd_cgr
# 126                                pct_std_nswd_cgr
# 127                               eg_score_bl7_spg2
# 128                               eg_score_eds_spg2
# 129                               eg_score_hi7_spg2
# 130                               eg_score_swd_spg2
# 131                               eg_score_wh7_spg2
# 132                                     den_els_elp
# 133                                     den_hi7_elp
# 134                                    den_male_elp
# 135                                    den_nswd_elp
# 136                                    den_male_elp
# 137                                     den_hi7_elp
# 138                                    den_male_elp
# 139                                    den_nswd_elp
# 140                                    den_male_elp
# 141                                    den_nswd_elp
# 142                                    den_nswd_elp
# 143                                     pct_els_elp
# 144              target_assign_reading_grade_10_ltg
# 145                      target_assign_biology_part
# 146             target_assign_high_school_math_part
# 147                      target_assign_the_act_part
# 148                      target_assign_biology_part
# 149                   target_assign_english_ii_part
# 150             target_assign_high_school_math_part
# 151                      target_assign_the_act_part
# 152                target_assign_total_targets_part
# 153                                    pct_nswd_mcr
# 154                                    pct_neds_mcr
# 155             target_assign_high_school_math_part
# 156                      target_assign_the_act_part
# 157                target_assign_total_targets_part
# 158                      target_met_english_ii_part
# 159                      target_assign_the_act_part
# 160                target_assign_total_targets_part
# 161                target_assign_total_targets_part
# 162                target_met_high_school_math_part
# 163               pct_high_school_math_all_part_det
# 164                        pct_the_act_all_part_det
# 165               pct_high_school_math_eds_part_det
# 166                        pct_the_act_eds_part_det
# 167               pct_high_school_math_wh7_part_det
# 168                        pct_the_act_wh7_part_det
# 169                        pct_the_act_all_part_det
# 170                        pct_the_act_eds_part_det
# 171                        pct_the_act_wh7_part_det
# 172                           pct_glp_bi_eoc_aig_pc
# 173                          pct_ccr_bi_eoc_nswd_pc
# 174                           pct_glp_bi_eoc_all_pc
# 175                          pct_glp_bi_eoc_nswd_pc
# 176                           pct_glp_bi_eoc_bl7_pc
# 177                           pct_glp_bi_eoc_eds_pc
# 178                           pct_glp_bi_eoc_fem_pc
# 179                           pct_glp_bi_eoc_hi7_pc
# 180                          pct_glp_bi_eoc_male_pc
# 181                          pct_ccr_bi_eoc_nswd_pc
# 182                          pct_glp_bi_eoc_neds_pc
# 183                          pct_glp_bi_eoc_nswd_pc
# 184                           pct_glp_bi_eoc_all_pc
# 185                          pct_glp_bi_eoc_nswd_pc
# 186                            pct_l4_bi_eoc_swd_pc
# 187                           pct_glp_bi_eoc_wh7_pc
# 188                           pct_glp_e2_eoc_aig_pc
# 189                            pct_l4_e2_eoc_aig_pc
# 190                           pct_ccr_e2_eoc_fem_pc
# 191                          pct_ccr_e2_eoc_nswd_pc
# 192                           pct_glp_e2_eoc_all_pc
# 193                          pct_glp_e2_eoc_nswd_pc
# 194                            pct_l4_e2_eoc_all_pc
# 195                           pct_l4_e2_eoc_nswd_pc
# 196                           pct_glp_e2_eoc_bl7_pc
# 197                            pct_l4_e2_eoc_bl7_pc
# 198                           pct_glp_e2_eoc_eds_pc
# 199                            pct_l4_e2_eoc_eds_pc
# 200                          pct_ccr_e2_eoc_nswd_pc
# 201                           pct_glp_e2_eoc_fem_pc
# 202                            pct_l4_e2_eoc_fem_pc
# 203                           pct_glp_e2_eoc_hi7_pc
# 204                            pct_l4_e2_eoc_hi7_pc
# 205                          pct_glp_e2_eoc_male_pc
# 206                           pct_l4_e2_eoc_male_pc
# 207                          pct_glp_e2_eoc_neds_pc
# 208                           pct_l4_e2_eoc_neds_pc
# 209                           pct_glp_e2_eoc_all_pc
# 210                          pct_glp_e2_eoc_nswd_pc
# 211                            pct_l4_e2_eoc_all_pc
# 212                           pct_l4_e2_eoc_nswd_pc
# 213                           pct_glp_e2_eoc_wh7_pc
# 214                            pct_l4_e2_eoc_wh7_pc
# 215                          pct_glp_eoc_eoc_aig_pc
# 216                          pct_ccr_eoc_eoc_fem_pc
# 217                         pct_ccr_eoc_eoc_male_pc
# 218                         pct_ccr_eoc_eoc_neds_pc
# 219                         pct_ccr_eoc_eoc_nswd_pc
# 220                          pct_glp_eoc_eoc_all_pc
# 221                         pct_glp_eoc_eoc_nswd_pc
# 222                           pct_l4_eoc_eoc_all_pc
# 223                          pct_glp_eoc_eoc_bl7_pc
# 224                           pct_l4_eoc_eoc_bl7_pc
# 225                          pct_glp_eoc_eoc_eds_pc
# 226                           pct_l4_all_all_eds_pc
# 227                           pct_l4_eoc_eoc_eds_pc
# 228                         pct_ccr_eoc_eoc_neds_pc
# 229                         pct_ccr_eoc_eoc_nswd_pc
# 230                          pct_glp_eoc_eoc_all_pc
# 231                          pct_glp_eoc_eoc_fem_pc
# 232                           pct_l4_eoc_eoc_fem_pc
# 233                          pct_glp_eoc_eoc_hi7_pc
# 234                           pct_l4_all_all_hi7_pc
# 235                           pct_l4_eoc_eoc_hi7_pc
# 236                         pct_glp_eoc_eoc_male_pc
# 237                          pct_l4_eoc_eoc_male_pc
# 238                          pct_glp_eoc_eoc_mu7_pc
# 239                           pct_l4_eoc_eoc_mu7_pc
# 240                         pct_ccr_eoc_eoc_nswd_pc
# 241                         pct_glp_eoc_eoc_neds_pc
# 242                          pct_l4_eoc_eoc_neds_pc
# 243                          pct_glp_eoc_eoc_all_pc
# 244                         pct_glp_eoc_eoc_nswd_pc
# 245                           pct_l4_eoc_eoc_all_pc
# 246                          pct_l4_eoc_eoc_nswd_pc
# 247                          pct_glp_eoc_eoc_wh7_pc
# 248                           pct_l4_eoc_eoc_wh7_pc
# 249                          pct_ccr_m1_eoc_nswd_pc
# 250                            pct_l4_m1_eoc_all_pc
# 251                           pct_l4_m1_eoc_nswd_pc
# 252                            pct_l4_m1_eoc_eds_pc
# 253                            pct_l4_m1_eoc_fem_pc
# 254                           pct_l4_m1_eoc_male_pc
# 255                           pct_l4_m1_eoc_neds_pc
# 256                            pct_l4_m1_eoc_all_pc
# 257                           pct_l4_m1_eoc_nswd_pc
# 258                            pct_l4_m1_eoc_wh7_pc
# 259                           pct_ccr_m3_eoc_fem_pc
# 260                          pct_ccr_m3_eoc_nswd_pc
# 261                            pct_l4_m3_eoc_eds_pc
# 262                          pct_ccr_m3_eoc_nswd_pc
# 263                            pct_l4_m3_eoc_hi7_pc
# 264                          pct_glp_bi_eoc_nswd_pc
# 265                            pct_l4_bi_eoc_bl7_pc
# 266                          pct_glp_bi_eoc_nswd_pc
# 267                            pct_l4_e2_eoc_aig_pc
# 268                          pct_glp_e2_eoc_nswd_pc
# 269                            pct_l4_e2_eoc_all_pc
# 270                           pct_l4_e2_eoc_nswd_pc
# 271                            pct_l4_e2_eoc_bl7_pc
# 272                            pct_l4_e2_eoc_eds_pc
# 273                          pct_glp_e2_eoc_nswd_pc
# 274                            pct_l4_e2_eoc_fem_pc
# 275                            pct_l4_e2_eoc_hi7_pc
# 276                           pct_l4_e2_eoc_male_pc
# 277                           pct_l4_e2_eoc_neds_pc
# 278                            pct_l4_e2_eoc_all_pc
# 279                           pct_l4_e2_eoc_nswd_pc
# 280                            pct_l4_e2_eoc_wh7_pc
# 281                          pct_glp_eoc_eoc_fem_pc
# 282                         pct_glp_eoc_eoc_neds_pc
# 283                         pct_glp_eoc_eoc_nswd_pc
# 284                           pct_l4_all_all_all_pc
# 285                           pct_l4_eoc_eoc_all_pc
# 286                          pct_l4_eoc_eoc_nswd_pc
# 287                           pct_l4_eoc_eoc_bl7_pc
# 288                           pct_l4_eoc_eoc_eds_pc
# 289                         pct_glp_eoc_eoc_neds_pc
# 290                         pct_glp_eoc_eoc_nswd_pc
# 291                           pct_l4_eoc_eoc_fem_pc
# 292                           pct_l4_eoc_eoc_hi7_pc
# 293                          pct_l4_eoc_eoc_male_pc
# 294                         pct_glp_eoc_eoc_nswd_pc
# 295                          pct_l4_eoc_eoc_neds_pc
# 296                           pct_l4_all_all_all_pc
# 297                          pct_l4_all_all_nswd_pc
# 298                           pct_l4_eoc_eoc_all_pc
# 299                          pct_l4_eoc_eoc_nswd_pc
# 300                           pct_l4_eoc_eoc_wh7_pc
# 301                          pct_glp_m1_eoc_nswd_pc
# 302                            pct_l3_m1_eoc_swd_pc
# 303                           pct_glp_m3_eoc_fem_pc
# 304                          pct_glp_m3_eoc_nswd_pc
# 305                          pct_glp_m3_eoc_nswd_pc
# 306                           pct_l3_eoc_eoc_aig_pc
# 307                           pct_l3_eoc_eoc_all_pc
# 308                           pct_l3_eoc_eoc_bl7_pc
# 309                           pct_l3_eoc_eoc_eds_pc
# 310                           pct_l3_eoc_eoc_hi7_pc
# 311                           pct_l3_eoc_eoc_mu7_pc
# 312                          pct_l3_eoc_eoc_nswd_pc
# 313                           pct_l3_m1_eoc_nswd_pc
# 314                           pct_l3_m3_eoc_nswd_pc
# 315                           pct_l4_eoc_eoc_aig_pc
# 316                           pct_l4_all_all_fem_pc
# 317                          pct_l4_all_all_neds_pc
# 318                          pct_l4_all_all_nswd_pc
# 319                           pct_l4_eoc_eoc_all_pc
# 320                          pct_l4_eoc_eoc_nswd_pc
# 321                           pct_l4_eoc_eoc_bl7_pc
# 322                           pct_l4_eoc_eoc_eds_pc
# 323                          pct_l4_all_all_nswd_pc
# 324                           pct_l4_eoc_eoc_all_pc
# 325                           pct_l4_eoc_eoc_fem_pc
# 326                          pct_l4_eoc_eoc_nswd_pc
# 327                           pct_l4_eoc_eoc_hi7_pc
# 328                          pct_l4_eoc_eoc_male_pc
# 329                           pct_l4_eoc_eoc_mu7_pc
# 330                          pct_l4_all_all_nswd_pc
# 331                          pct_l4_eoc_eoc_neds_pc
# 332                           pct_l4_eoc_eoc_all_pc
# 333                           pct_l4_eoc_eoc_fem_pc
# 334                          pct_l4_eoc_eoc_nswd_pc
# 335                           pct_l4_eoc_eoc_wh7_pc
# 336                           pct_l4_bi_eoc_nswd_pc
# 337                           pct_l4_e2_eoc_nswd_pc
# 338                           pct_l4_eoc_eoc_fem_pc
# 339                          pct_l4_eoc_eoc_neds_pc
# 340                          pct_l4_eoc_eoc_nswd_pc
# 341                          pct_l4_eoc_eoc_nswd_pc
# 342                          pct_l4_eoc_eoc_nswd_pc
# 343                           pct_l4_m1_eoc_nswd_pc
# 344                           pct_l4_m3_eoc_nswd_pc
# 345                           pct_l5_all_all_fem_pc
# 346                          pct_l5_all_all_neds_pc
# 347                          pct_l5_all_all_nswd_pc
# 348                           pct_l5_eoc_eoc_all_pc
# 349                           pct_l5_eoc_eoc_fem_pc
# 350                          pct_l5_eoc_eoc_nswd_pc
# 351                          pct_l5_all_all_nswd_pc
# 352                           pct_l5_eoc_eoc_all_pc
# 353                           pct_l5_eoc_eoc_fem_pc
# 354                          pct_l5_eoc_eoc_nswd_pc
# 355                          pct_l5_eoc_eoc_male_pc
# 356                          pct_l5_all_all_nswd_pc
# 357                          pct_l5_eoc_eoc_neds_pc
# 358                           pct_l5_eoc_eoc_all_pc
# 359                           pct_l5_eoc_eoc_fem_pc
# 360                          pct_l5_eoc_eoc_nswd_pc
# 361                           pct_l5_eoc_eoc_wh7_pc
# 362                           pct_l5_bi_eoc_nswd_pc
# 363                           pct_l5_bi_eoc_nswd_pc
# 364                           pct_l5_eoc_eoc_fem_pc
# 365                          pct_l5_eoc_eoc_nswd_pc
# 366                          pct_l5_eoc_eoc_nswd_pc
# 367                          pct_l5_eoc_eoc_nswd_pc
# 368                           pct_l5_m3_eoc_nswd_pc
# 369                      pct_notprof_eoc_eoc_aig_pc
# 370                     pct_notprof_all_all_male_pc
# 371                     pct_notprof_eoc_eoc_nswd_pc
# 372                      pct_notprof_m3_eoc_nswd_pc
# 373                              ach_score_hi7_spg2
# 374                              spg_score_hi7_spg2
# 375                              spg_score_all_spg2
# 376                              spg_score_bl7_spg2
# 377                              spg_score_eds_spg2
# 378                              spg_score_hi7_spg2
# 379                              spg_score_swd_spg2
# 380                              spg_score_wh7_spg2
# 381                              mcr_score_wh7_spg2
# 382                              mcr_score_eds_spg2
# 383                                     pct_nswd_wk
# 384                                      stu_enroll
# 385                                      cte_enroll
# 386                           number_of_teachers_eq
# 387                      adm_central_expense_funds2
# 388                    adm_employee_benefits_funds2
# 389                 adm_instructional_equip._funds2
# 390                        adm_other_objects_funds2
# 391                   adm_purchased_services_funds2
# 392                             adm_salaries_funds2
# 393                 adm_supplies_&_materials_funds2
# 394                                adm_total_funds2
# 395            state_funds_employee_benefits_funds2
# 396                     state_funds_salaries_funds2
# 397                        state_funds_total_funds2
# 398            total_funds_employee_benefits_funds2
# 399                     total_funds_salaries_funds2
# 400                        total_funds_total_funds2
# 401                          count_fem_chron_absent
# 402                         count_male_chron_absent
# 403                         count_male_chron_absent
# 404                           pct_male_chron_absent
# 405                   count_2018_enroll_fem_college
# 406                  count_2018_enroll_male_college
# 407                  count_2018_enroll_male_college
# 408                   count_2018_noenro_fem_college
# 409                  count_2018_noenro_male_college
# 410                       tot_num_ap_h_as7_courses2
# 411                       tot_num_ap_h_bl7_courses2
# 412                       tot_num_ap_h_els_courses2
# 413                       tot_num_ap_h_fem_courses2
# 414                       tot_num_ap_h_hi7_courses2
# 415                      tot_num_ap_h_male_courses2
# 416                       tot_num_ap_h_mu7_courses2
# 417                     tot_num_ap_h_other_courses2
# 418                       tot_num_ap_h_pi7_courses2
# 419                       tot_num_ap_h_swd_courses2
# 420                       tot_num_ap_h_wh7_courses2
# 421                       tot_num_ap_h_bl7_courses2
# 422                       tot_num_ap_h_els_courses2
# 423                       tot_num_ap_h_fem_courses2
# 424                       tot_num_ap_h_hi7_courses2
# 425                      tot_num_ap_h_male_courses2
# 426                       tot_num_ap_h_mu7_courses2
# 427                     tot_num_ap_h_other_courses2
# 428                       tot_num_ap_h_pi7_courses2
# 429                       tot_num_ap_h_swd_courses2
# 430                       tot_num_ap_h_wh7_courses2
# 431                       tot_num_ap_h_els_courses2
# 432                       tot_num_ap_h_fem_courses2
# 433                       tot_num_ap_h_hi7_courses2
# 434                      tot_num_ap_h_male_courses2
# 435                       tot_num_ap_h_mu7_courses2
# 436                     tot_num_ap_h_other_courses2
# 437                       tot_num_ap_h_pi7_courses2
# 438                       tot_num_ap_h_swd_courses2
# 439                       tot_num_ap_h_wh7_courses2
# 440                       tot_num_ap_h_fem_courses2
# 441                       tot_num_ap_h_hi7_courses2
# 442                      tot_num_ap_h_male_courses2
# 443                       tot_num_ap_h_mu7_courses2
# 444                     tot_num_ap_h_other_courses2
# 445                       tot_num_ap_h_pi7_courses2
# 446                       tot_num_ap_h_swd_courses2
# 447                       tot_num_ap_h_wh7_courses2
# 448                       tot_num_ap_h_hi7_courses2
# 449                      tot_num_ap_h_male_courses2
# 450                       tot_num_ap_h_mu7_courses2
# 451                     tot_num_ap_h_other_courses2
# 452                       tot_num_ap_h_pi7_courses2
# 453                       tot_num_ap_h_swd_courses2
# 454                       tot_num_ap_h_wh7_courses2
# 455                      tot_num_ap_h_male_courses2
# 456                       tot_num_ap_h_mu7_courses2
# 457                     tot_num_ap_h_other_courses2
# 458                       tot_num_ap_h_pi7_courses2
# 459                       tot_num_ap_h_swd_courses2
# 460                       tot_num_ap_h_wh7_courses2
# 461                       tot_num_ap_h_mu7_courses2
# 462                     tot_num_ap_h_other_courses2
# 463                       tot_num_ap_h_pi7_courses2
# 464                       tot_num_ap_h_swd_courses2
# 465                       tot_num_ap_h_wh7_courses2
# 466                     tot_num_ap_h_other_courses2
# 467                       tot_num_ap_h_pi7_courses2
# 468                       tot_num_ap_h_swd_courses2
# 469                       tot_num_ap_h_wh7_courses2
# 470                       tot_num_ap_h_pi7_courses2
# 471                       tot_num_ap_h_swd_courses2
# 472                       tot_num_ap_h_wh7_courses2
# 473                       tot_num_ap_h_swd_courses2
# 474                       tot_num_ap_h_wh7_courses2
# 475                       tot_num_ap_h_wh7_courses2
# 476                      tot_num_ccp_h_as7_courses2
# 477                      tot_num_ccp_h_bl7_courses2
# 478                      tot_num_ccp_h_els_courses2
# 479                      tot_num_ccp_h_fem_courses2
# 480                      tot_num_ccp_h_hi7_courses2
# 481                     tot_num_ccp_h_male_courses2
# 482                      tot_num_ccp_h_mu7_courses2
# 483                    tot_num_ccp_h_other_courses2
# 484                      tot_num_ccp_h_pi7_courses2
# 485                      tot_num_ccp_h_swd_courses2
# 486                      tot_num_ccp_h_wh7_courses2
# 487                      tot_num_ccp_h_bl7_courses2
# 488                      tot_num_ccp_h_els_courses2
# 489                      tot_num_ccp_h_fem_courses2
# 490                      tot_num_ccp_h_hi7_courses2
# 491                     tot_num_ccp_h_male_courses2
# 492                      tot_num_ccp_h_mu7_courses2
# 493                    tot_num_ccp_h_other_courses2
# 494                      tot_num_ccp_h_pi7_courses2
# 495                      tot_num_ccp_h_swd_courses2
# 496                      tot_num_ccp_h_wh7_courses2
# 497                      tot_num_ccp_h_els_courses2
# 498                      tot_num_ccp_h_fem_courses2
# 499                      tot_num_ccp_h_hi7_courses2
# 500                     tot_num_ccp_h_male_courses2
# 501                      tot_num_ccp_h_mu7_courses2
# 502                    tot_num_ccp_h_other_courses2
# 503                      tot_num_ccp_h_pi7_courses2
# 504                      tot_num_ccp_h_swd_courses2
# 505                      tot_num_ccp_h_wh7_courses2
# 506                      tot_num_ccp_h_fem_courses2
# 507                      tot_num_ccp_h_hi7_courses2
# 508                     tot_num_ccp_h_male_courses2
# 509                      tot_num_ccp_h_mu7_courses2
# 510                    tot_num_ccp_h_other_courses2
# 511                      tot_num_ccp_h_pi7_courses2
# 512                      tot_num_ccp_h_swd_courses2
# 513                      tot_num_ccp_h_wh7_courses2
# 514                      tot_num_ccp_h_hi7_courses2
# 515                     tot_num_ccp_h_male_courses2
# 516                      tot_num_ccp_h_mu7_courses2
# 517                    tot_num_ccp_h_other_courses2
# 518                      tot_num_ccp_h_pi7_courses2
# 519                      tot_num_ccp_h_swd_courses2
# 520                      tot_num_ccp_h_wh7_courses2
# 521                     tot_num_ccp_h_male_courses2
# 522                      tot_num_ccp_h_mu7_courses2
# 523                    tot_num_ccp_h_other_courses2
# 524                      tot_num_ccp_h_pi7_courses2
# 525                      tot_num_ccp_h_swd_courses2
# 526                      tot_num_ccp_h_wh7_courses2
# 527                      tot_num_ccp_h_mu7_courses2
# 528                    tot_num_ccp_h_other_courses2
# 529                      tot_num_ccp_h_pi7_courses2
# 530                      tot_num_ccp_h_swd_courses2
# 531                      tot_num_ccp_h_wh7_courses2
# 532                    tot_num_ccp_h_other_courses2
# 533                      tot_num_ccp_h_pi7_courses2
# 534                      tot_num_ccp_h_swd_courses2
# 535                      tot_num_ccp_h_wh7_courses2
# 536                      tot_num_ccp_h_pi7_courses2
# 537                      tot_num_ccp_h_swd_courses2
# 538                      tot_num_ccp_h_wh7_courses2
# 539                      tot_num_ccp_h_swd_courses2
# 540                      tot_num_ccp_h_wh7_courses2
# 541                      tot_num_ccp_h_wh7_courses2
# 542                             year_h_as7_courses2
# 543                             year_h_bl7_courses2
# 544                             year_h_els_courses2
# 545                             year_h_fem_courses2
# 546                             year_h_hi7_courses2
# 547                            year_h_male_courses2
# 548                             year_h_mu7_courses2
# 549                           year_h_other_courses2
# 550                             year_h_pi7_courses2
# 551                             year_h_swd_courses2
# 552                             year_h_wh7_courses2
# 553                             year_h_bl7_courses2
# 554                             year_h_els_courses2
# 555                             year_h_fem_courses2
# 556                             year_h_hi7_courses2
# 557                            year_h_male_courses2
# 558                             year_h_mu7_courses2
# 559                           year_h_other_courses2
# 560                             year_h_pi7_courses2
# 561                             year_h_swd_courses2
# 562                             year_h_wh7_courses2
# 563                             year_h_els_courses2
# 564                             year_h_fem_courses2
# 565                             year_h_hi7_courses2
# 566                            year_h_male_courses2
# 567                             year_h_mu7_courses2
# 568                           year_h_other_courses2
# 569                             year_h_pi7_courses2
# 570                             year_h_swd_courses2
# 571                             year_h_wh7_courses2
# 572                             year_h_fem_courses2
# 573                             year_h_hi7_courses2
# 574                            year_h_male_courses2
# 575                             year_h_mu7_courses2
# 576                           year_h_other_courses2
# 577                             year_h_pi7_courses2
# 578                             year_h_swd_courses2
# 579                             year_h_wh7_courses2
# 580                             year_h_hi7_courses2
# 581                            year_h_male_courses2
# 582                             year_h_mu7_courses2
# 583                           year_h_other_courses2
# 584                             year_h_pi7_courses2
# 585                             year_h_swd_courses2
# 586                             year_h_wh7_courses2
# 587                            year_h_male_courses2
# 588                             year_h_mu7_courses2
# 589                           year_h_other_courses2
# 590                             year_h_pi7_courses2
# 591                             year_h_swd_courses2
# 592                             year_h_wh7_courses2
# 593                             year_h_mu7_courses2
# 594                           year_h_other_courses2
# 595                             year_h_pi7_courses2
# 596                             year_h_swd_courses2
# 597                             year_h_wh7_courses2
# 598                           year_h_other_courses2
# 599                             year_h_pi7_courses2
# 600                             year_h_swd_courses2
# 601                             year_h_wh7_courses2
# 602                             year_h_pi7_courses2
# 603                             year_h_swd_courses2
# 604                             year_h_wh7_courses2
# 605                             year_h_swd_courses2
# 606                             year_h_wh7_courses2
# 607                             year_h_wh7_courses2
# 608                                      cte_enroll
# 609                           number_of_teachers_eq
# 610                      adm_central_expense_funds2
# 611                    adm_employee_benefits_funds2
# 612                 adm_instructional_equip._funds2
# 613                        adm_other_objects_funds2
# 614                   adm_purchased_services_funds2
# 615                             adm_salaries_funds2
# 616                 adm_supplies_&_materials_funds2
# 617                                adm_total_funds2
# 618            state_funds_employee_benefits_funds2
# 619                     state_funds_salaries_funds2
# 620                        state_funds_total_funds2
# 621            total_funds_employee_benefits_funds2
# 622                     total_funds_salaries_funds2
# 623                        total_funds_total_funds2
# 624                      adm_central_expense_funds2
# 625                    adm_employee_benefits_funds2
# 626                 adm_instructional_equip._funds2
# 627                        adm_other_objects_funds2
# 628                   adm_purchased_services_funds2
# 629                             adm_salaries_funds2
# 630                 adm_supplies_&_materials_funds2
# 631                                adm_total_funds2
# 632            state_funds_employee_benefits_funds2
# 633                     state_funds_salaries_funds2
# 634                        state_funds_total_funds2
# 635                      adm_central_expense_funds2
# 636                    adm_employee_benefits_funds2
# 637                 adm_instructional_equip._funds2
# 638                        adm_other_objects_funds2
# 639                   adm_purchased_services_funds2
# 640                             adm_salaries_funds2
# 641                 adm_supplies_&_materials_funds2
# 642                                adm_total_funds2
# 643            state_funds_employee_benefits_funds2
# 644                     state_funds_salaries_funds2
# 645                        state_funds_total_funds2
# 646            total_funds_employee_benefits_funds2
# 647                     total_funds_salaries_funds2
# 648                        total_funds_total_funds2
# 649                    adm_employee_benefits_funds2
# 650                 adm_instructional_equip._funds2
# 651                        adm_other_objects_funds2
# 652                   adm_purchased_services_funds2
# 653                             adm_salaries_funds2
# 654                 adm_supplies_&_materials_funds2
# 655                                adm_total_funds2
# 656            state_funds_employee_benefits_funds2
# 657                     state_funds_salaries_funds2
# 658                        state_funds_total_funds2
# 659            total_funds_employee_benefits_funds2
# 660                     total_funds_salaries_funds2
# 661                        total_funds_total_funds2
# 662                 adm_instructional_equip._funds2
# 663                        adm_other_objects_funds2
# 664                   adm_purchased_services_funds2
# 665                             adm_salaries_funds2
# 666                 adm_supplies_&_materials_funds2
# 667                                adm_total_funds2
# 668            state_funds_employee_benefits_funds2
# 669                     state_funds_salaries_funds2
# 670                        state_funds_total_funds2
# 671            total_funds_employee_benefits_funds2
# 672                     total_funds_salaries_funds2
# 673                        total_funds_total_funds2
# 674                        adm_other_objects_funds2
# 675                   adm_purchased_services_funds2
# 676                             adm_salaries_funds2
# 677                 adm_supplies_&_materials_funds2
# 678                                adm_total_funds2
# 679            state_funds_employee_benefits_funds2
# 680                     state_funds_salaries_funds2
# 681                        state_funds_total_funds2
# 682            total_funds_employee_benefits_funds2
# 683                     total_funds_salaries_funds2
# 684                        total_funds_total_funds2
# 685                   adm_purchased_services_funds2
# 686                             adm_salaries_funds2
# 687                 adm_supplies_&_materials_funds2
# 688                                adm_total_funds2
# 689            state_funds_employee_benefits_funds2
# 690                     state_funds_salaries_funds2
# 691                        state_funds_total_funds2
# 692            total_funds_employee_benefits_funds2
# 693                     total_funds_salaries_funds2
# 694                        total_funds_total_funds2
# 695                             adm_salaries_funds2
# 696                 adm_supplies_&_materials_funds2
# 697                                adm_total_funds2
# 698            state_funds_employee_benefits_funds2
# 699                     state_funds_salaries_funds2
# 700                        state_funds_total_funds2
# 701            total_funds_employee_benefits_funds2
# 702                     total_funds_salaries_funds2
# 703                        total_funds_total_funds2
# 704                 adm_supplies_&_materials_funds2
# 705                                adm_total_funds2
# 706            state_funds_employee_benefits_funds2
# 707                     state_funds_salaries_funds2
# 708                        state_funds_total_funds2
# 709            total_funds_employee_benefits_funds2
# 710                     total_funds_salaries_funds2
# 711                        total_funds_total_funds2
# 712                                adm_total_funds2
# 713            state_funds_employee_benefits_funds2
# 714                     state_funds_salaries_funds2
# 715                        state_funds_total_funds2
# 716            total_funds_employee_benefits_funds2
# 717                     total_funds_salaries_funds2
# 718                        total_funds_total_funds2
# 719            state_funds_employee_benefits_funds2
# 720                     state_funds_salaries_funds2
# 721                        state_funds_total_funds2
# 722            total_funds_employee_benefits_funds2
# 723                     total_funds_salaries_funds2
# 724                        total_funds_total_funds2
# 725                   federal_funds_salaries_funds2
# 726                local_funds_other_objects_funds2
# 727                total_funds_other_objects_funds2
# 728                      federal_funds_total_funds2
# 729                     federal_ppe_salaries_funds2
# 730                        federal_ppe_total_funds2
# 731                  local_ppe_other_objects_funds2
# 732                  total_ppe_other_objects_funds2
# 733                        federal_ppe_total_funds2
# 734              total_funds_central_expense_funds2
# 735                     local_funds_salaries_funds2
# 736                        local_funds_total_funds2
# 737                total_funds_other_objects_funds2
# 738           total_funds_purchased_services_funds2
# 739                        local_funds_total_funds2
# 740                       local_ppe_salaries_funds2
# 741                  total_ppe_other_objects_funds2
# 742                     state_funds_salaries_funds2
# 743                        state_funds_total_funds2
# 744            total_funds_employee_benefits_funds2
# 745                     total_funds_salaries_funds2
# 746                        total_funds_total_funds2
# 747                        state_funds_total_funds2
# 748            total_funds_employee_benefits_funds2
# 749                     total_funds_salaries_funds2
# 750                        total_funds_total_funds2
# 751            total_funds_employee_benefits_funds2
# 752                     total_funds_salaries_funds2
# 753                        total_funds_total_funds2
# 754              total_ppe_employee_benefits_funds2
# 755                     total_funds_salaries_funds2
# 756                        total_funds_total_funds2
# 757                        total_funds_total_funds2
# 758                            arr_per1000_bl7_inc2
# 759                            arr_per1000_fem_inc2
# 760                           arr_per1000_male_inc2
# 761                           arr_per1000_male_inc2
# 762                            exp_per1000_bl7_inc2
# 763                           exp_per1000_male_inc2
# 764                            exp_per1000_eds_inc2
# 765                            exp_per1000_els_inc2
# 766                            exp_per1000_wh7_inc2
# 767                           iss_per1000_male_inc2
# 768                            lts_per1000_fem_inc2
# 769                            rpt_per1000_eds_inc2
# 770               lea_name_Alexander County Schools
# 771                            county_loc_Alleghany
# 772               lea_name_Alleghany County Schools
# 773                                county_loc_Anson
# 774                   lea_name_Anson County Schools
# 775                                 county_loc_Ashe
# 776                    lea_name_Ashe County Schools
# 777                                county_loc_Avery
# 778                   lea_name_Avery County Schools
# 779                             county_loc_Beaufort
# 780                lea_name_Beaufort County Schools
# 781                               county_loc_Bertie
# 782                  lea_name_Bertie County Schools
# 783                               county_loc_Bladen
# 784                  lea_name_Bladen County Schools
# 785                            county_loc_Brunswick
# 786               lea_name_Brunswick County Schools
# 787                lea_name_Buncombe County Schools
# 788                 lea_name_Asheville City Schools
# 789                                county_loc_Burke
# 790                   lea_name_Burke County Schools
# 791                lea_name_Cabarrus County Schools
# 792                lea_name_Kannapolis City Schools
# 793                             county_loc_Caldwell
# 794                lea_name_Caldwell County Schools
# 795                               county_loc_Camden
# 796                  lea_name_Camden County Schools
# 797                             county_loc_Carteret
# 798                lea_name_Carteret County Schools
# 799                              county_loc_Caswell
# 800                 lea_name_Caswell County Schools
# 801                 lea_name_Catawba County Schools
# 802                   lea_name_Hickory City Schools
# 803            lea_name_Newton-Conover City Schools
# 804                 lea_name_Chatham County Schools
# 805                             county_loc_Cherokee
# 806                lea_name_Cherokee County Schools
# 807                               county_loc_Chowan
# 808          lea_name_Edenton-Chowan County Schools
# 809                                 county_loc_Clay
# 810                    lea_name_Clay County Schools
# 811                            county_loc_Cleveland
# 812               lea_name_Cleveland County Schools
# 813                lea_name_Columbus County Schools
# 814                lea_name_Whiteville City Schools
# 815                               county_loc_Craven
# 816                  lea_name_Craven County Schools
# 817              lea_name_Cumberland County Schools
# 818                            county_loc_Currituck
# 819               lea_name_Currituck County Schools
# 820                                 county_loc_Dare
# 821                    lea_name_Dare County Schools
# 822                lea_name_Davidson County Schools
# 823                 lea_name_Lexington City Schools
# 824               lea_name_Thomasville City Schools
# 825        stree_addr2_loc_Partners 1 Bldg Ste 3900
# 826                                county_loc_Davie
# 827                   lea_name_Davie County Schools
# 828                               county_loc_Duplin
# 829                  lea_name_Duplin County Schools
# 830                               county_loc_Durham
# 831                  lea_name_Durham County Schools
# 832                            county_loc_Edgecombe
# 833               lea_name_Edgecombe County Schools
# 834                              county_loc_Forsyth
# 835                 lea_name_Forsyth County Schools
# 836                             county_loc_Franklin
# 837                lea_name_Franklin County Schools
# 838                               county_loc_Gaston
# 839                  lea_name_Gaston County Schools
# 840                                county_loc_Gates
# 841                   lea_name_Gates County Schools
# 842                               county_loc_Graham
# 843                  lea_name_Graham County Schools
# 844                            county_loc_Granville
# 845               lea_name_Granville County Schools
# 846                               county_loc_Greene
# 847                  lea_name_Greene County Schools
# 848                             county_loc_Guilford
# 849                lea_name_Guilford County Schools
# 850                 lea_name_Halifax County Schools
# 851            lea_name_Roanoke Rapids City Schools
# 852                    lea_name_Weldon City Schools
# 853                              county_loc_Harnett
# 854                 lea_name_Harnett County Schools
# 855                              county_loc_Haywood
# 856                 lea_name_Haywood County Schools
# 857                            county_loc_Henderson
# 858               lea_name_Henderson County Schools
# 859                             county_loc_Hertford
# 860                lea_name_Hertford County Schools
# 861                                 county_loc_Hoke
# 862                    lea_name_Hoke County Schools
# 863                                 county_loc_Hyde
# 864                    lea_name_Hyde County Schools
# 865            lea_name_Iredell-Statesville Schools
# 866                              county_loc_Jackson
# 867                 lea_name_Jackson County Schools
# 868                             county_loc_Johnston
# 869                lea_name_Johnston County Schools
# ...
# 775                      lea_code_loc_050LEA     1.000000
# 776                      lea_code_loc_050LEA     1.000000
# 777                      lea_code_loc_060LEA     1.000000
# 778                      lea_code_loc_060LEA     1.000000
# 779                      lea_code_loc_070LEA     1.000000
# 780                      lea_code_loc_070LEA     1.000000
# 781                      lea_code_loc_080LEA     1.000000
# 782                      lea_code_loc_080LEA     1.000000
# 783                      lea_code_loc_090LEA     1.000000
# 784                      lea_code_loc_090LEA     1.000000
# 785                      lea_code_loc_100LEA     1.000000
# 786                      lea_code_loc_100LEA     1.000000
# 787                      lea_code_loc_110LEA     1.000000
# 788                      lea_code_loc_111LEA     1.000000
# 789                      lea_code_loc_120LEA     1.000000
# 790                      lea_code_loc_120LEA     1.000000
# 791                      lea_code_loc_130LEA     1.000000
# 792                      lea_code_loc_132LEA     1.000000
# 793                      lea_code_loc_140LEA     1.000000
# 794                      lea_code_loc_140LEA     1.000000
# 795                      lea_code_loc_150LEA     1.000000
# 796                      lea_code_loc_150LEA     1.000000
# 797                      lea_code_loc_160LEA     1.000000
# 798                      lea_code_loc_160LEA     1.000000
# 799                      lea_code_loc_170LEA     1.000000
# 800                      lea_code_loc_170LEA     1.000000
# 801                      lea_code_loc_180LEA     1.000000
# 802                      lea_code_loc_181LEA     1.000000
# 803                      lea_code_loc_182LEA     1.000000
# 804                      lea_code_loc_190LEA     1.000000
# 805                      lea_code_loc_200LEA     1.000000
# 806                      lea_code_loc_200LEA     1.000000
# 807                      lea_code_loc_210LEA     1.000000
# 808                      lea_code_loc_210LEA     1.000000
# 809                      lea_code_loc_220LEA     1.000000
# 810                      lea_code_loc_220LEA     1.000000
# 811                      lea_code_loc_230LEA     1.000000
# 812                      lea_code_loc_230LEA     1.000000
# 813                      lea_code_loc_240LEA     1.000000
# 814                      lea_code_loc_241LEA     1.000000
# 815                      lea_code_loc_250LEA     1.000000
# 816                      lea_code_loc_250LEA     1.000000
# 817                      lea_code_loc_260LEA     1.000000
# 818                      lea_code_loc_270LEA     1.000000
# 819                      lea_code_loc_270LEA     1.000000
# 820                      lea_code_loc_280LEA     1.000000
# 821                      lea_code_loc_280LEA     1.000000
# 822                      lea_code_loc_290LEA     1.000000
# 823                      lea_code_loc_291LEA     1.000000
# 824                      lea_code_loc_292LEA     1.000000
# 825                      lea_code_loc_299LEA     1.000000
# 826                      lea_code_loc_300LEA     1.000000
# 827                      lea_code_loc_300LEA     1.000000
# 828                      lea_code_loc_310LEA     1.000000
# 829                      lea_code_loc_310LEA     1.000000
# 830                      lea_code_loc_320LEA     1.000000
# 831                      lea_code_loc_320LEA     0.965325
# 832                      lea_code_loc_330LEA     1.000000
# 833                      lea_code_loc_330LEA     1.000000
# 834                      lea_code_loc_340LEA     1.000000
# 835                      lea_code_loc_340LEA     0.975118
# 836                      lea_code_loc_350LEA     1.000000
# 837                      lea_code_loc_350LEA     1.000000
# 838                      lea_code_loc_360LEA     1.000000
# 839                      lea_code_loc_360LEA     1.000000
# 840                      lea_code_loc_370LEA     1.000000
# 841                      lea_code_loc_370LEA     1.000000
# 842                      lea_code_loc_380LEA     1.000000
# 843                      lea_code_loc_380LEA     1.000000
# 844                      lea_code_loc_390LEA     1.000000
# 845                      lea_code_loc_390LEA     1.000000
# 846                      lea_code_loc_400LEA     1.000000
# 847                      lea_code_loc_400LEA     1.000000
# 848                      lea_code_loc_410LEA     1.000000
# 849                      lea_code_loc_410LEA     1.000000
# 850                      lea_code_loc_420LEA     1.000000
# 851                      lea_code_loc_421LEA     1.000000
# 852                      lea_code_loc_422LEA     1.000000
# 853                      lea_code_loc_430LEA     1.000000
# 854                      lea_code_loc_430LEA     1.000000
# 855                      lea_code_loc_440LEA     1.000000
# 856                      lea_code_loc_440LEA     1.000000
# 857                      lea_code_loc_450LEA     1.000000
# 858                      lea_code_loc_450LEA     1.000000
# 859                      lea_code_loc_460LEA     1.000000
# 860                      lea_code_loc_460LEA     1.000000
# 861                      lea_code_loc_470LEA     1.000000
# 862                      lea_code_loc_470LEA     1.000000
# 863                      lea_code_loc_480LEA     1.000000
# 864                      lea_code_loc_480LEA     1.000000
# 865                      lea_code_loc_490LEA     1.000000
# 866                      lea_code_loc_500LEA     1.000000
# 867                      lea_code_loc_500LEA     1.000000
# 868                      lea_code_loc_510LEA     1.000000
# 869                      lea_code_loc_510LEA     1.000000
# 870                      lea_code_loc_520LEA     1.000000
# 871                      lea_code_loc_520LEA     1.000000
# 872                      lea_code_loc_530LEA     1.000000
# 873                      lea_code_loc_530LEA     1.000000
# 874                      lea_code_loc_540LEA     1.000000
# 875                      lea_code_loc_550LEA     1.000000
# 876                      lea_code_loc_560LEA     1.000000
# 877                      lea_code_loc_560LEA     1.000000
# 878                      lea_code_loc_570LEA     1.000000
# 879                      lea_code_loc_570LEA     1.000000
# 880                      lea_code_loc_580LEA     1.000000
# 881                      lea_code_loc_580LEA     1.000000
# 882                      lea_code_loc_590LEA     1.000000
# 883                      lea_code_loc_590LEA     1.000000
# 884                      lea_code_loc_600LEA     1.000000
# 885                      lea_code_loc_600LEA     1.000000
# 886                      lea_code_loc_610LEA     1.000000
# 887                      lea_code_loc_610LEA     1.000000
# 888                      lea_code_loc_620LEA     1.000000
# 889                      lea_code_loc_630LEA     1.000000
# 890                      lea_code_loc_630LEA     1.000000
# 891                      lea_code_loc_640LEA     1.000000
# 892                      lea_code_loc_650LEA     1.000000
# 893                      lea_code_loc_660LEA     1.000000
# 894                      lea_code_loc_660LEA     1.000000
# 895                      lea_code_loc_670LEA     1.000000
# 896                      lea_code_loc_670LEA     1.000000
# 897                      lea_code_loc_680LEA     1.000000
# 898                      lea_code_loc_681LEA     1.000000
# 899                      lea_code_loc_690LEA     1.000000
# 900                      lea_code_loc_690LEA     1.000000
# 901                      lea_code_loc_700LEA     1.000000
# 902                      lea_code_loc_700LEA     1.000000
# 903                      lea_code_loc_710LEA     1.000000
# 904                      lea_code_loc_710LEA     1.000000
# 905                      lea_code_loc_720LEA     1.000000
# 906                      lea_code_loc_720LEA     1.000000
# 907                      lea_code_loc_730LEA     1.000000
# 908                      lea_code_loc_730LEA     1.000000
# 909                      lea_code_loc_740LEA     1.000000
# 910                      lea_code_loc_750LEA     1.000000
# 911                      lea_code_loc_750LEA     1.000000
# 912                      lea_code_loc_760LEA     1.000000
# 913                      lea_code_loc_761LEA     1.000000
# 914                      lea_code_loc_770LEA     1.000000
# 915                      lea_code_loc_770LEA     1.000000
# 916                      lea_code_loc_780LEA     1.000000
# 917                      lea_code_loc_790LEA     1.000000
# 918                      lea_code_loc_790LEA     1.000000
# 919                      lea_code_loc_800LEA     1.000000
# 920                      lea_code_loc_800LEA     1.000000
# 921                      lea_code_loc_810LEA     1.000000
# 922                      lea_code_loc_810LEA     1.000000
# 923                      lea_code_loc_820LEA     1.000000
# 924                      lea_code_loc_821LEA     1.000000
# 925                      lea_code_loc_830LEA     1.000000
# 926                      lea_code_loc_830LEA     1.000000
# 927                      lea_code_loc_840LEA     1.000000
# 928                      lea_code_loc_840LEA     1.000000
# 929                      lea_code_loc_850LEA     1.000000
# 930                      lea_code_loc_850LEA     1.000000
# 931                      lea_code_loc_860LEA     1.000000
# 932                      lea_code_loc_861LEA     1.000000
# 933                      lea_code_loc_862LEA     1.000000
# 934                      lea_code_loc_870LEA     1.000000
# 935                      lea_code_loc_870LEA     1.000000
# 936                      lea_code_loc_880LEA     1.000000
# 937                      lea_code_loc_880LEA     1.000000
# 938                      lea_code_loc_890LEA     1.000000
# 939                      lea_code_loc_890LEA     1.000000
# 940                      lea_code_loc_900LEA     1.000000
# 941                      lea_code_loc_900LEA     1.000000
# 942                      lea_code_loc_910LEA     1.000000
# 943                      lea_code_loc_910LEA     1.000000
# 944                      lea_code_loc_920LEA     0.984378
# 945                      lea_code_loc_920LEA     1.000000
# 946                      lea_code_loc_930LEA     1.000000
# 947                      lea_code_loc_940LEA     1.000000
# 948                      lea_code_loc_940LEA     1.000000
# 949                      lea_code_loc_950LEA     1.000000
# 950                      lea_code_loc_950LEA     1.000000
# 951                      lea_code_loc_960LEA     1.000000
# 952                      lea_code_loc_960LEA     1.000000
# 953                      lea_code_loc_970LEA     1.000000
# 954                      lea_code_loc_980LEA     1.000000
# 955                      lea_code_loc_980LEA     1.000000
# 956                      lea_code_loc_990LEA     1.000000
# 957                      lea_code_loc_990LEA     1.000000
# 958                      lea_code_loc_995LEA     1.000000
# 959                      lea_code_loc_995LEA     1.000000
# 960                      lea_code_loc_995LEA     1.000000
# 961                      lea_code_loc_998LEA     1.000000
# 962                     county_loc_Alleghany     1.000000
# 963                         county_loc_Anson     1.000000
# 964                          county_loc_Ashe     1.000000
# 965                         county_loc_Avery     1.000000
# 966                      county_loc_Beaufort     1.000000
# 967                        county_loc_Bertie     1.000000
# 968                        county_loc_Bladen     1.000000
# 969                     county_loc_Brunswick     1.000000
# 970                         county_loc_Burke     1.000000
# 971                      county_loc_Caldwell     1.000000
# 972                        county_loc_Camden     1.000000
# 973                      county_loc_Carteret     1.000000
# 974                       county_loc_Caswell     1.000000
# 975                      county_loc_Cherokee     1.000000
# 976                        county_loc_Chowan     1.000000
# 977                          county_loc_Clay     1.000000
# 978                     county_loc_Cleveland     1.000000
# 979                        county_loc_Craven     1.000000
# 980                     county_loc_Currituck     1.000000
# 981                          county_loc_Dare     1.000000
# 982                         county_loc_Davie     1.000000
# 983                        county_loc_Duplin     1.000000
# 984                        county_loc_Durham     0.965325
# 985                     county_loc_Edgecombe     1.000000
# 986                       county_loc_Forsyth     0.975118
# 987                      county_loc_Franklin     1.000000
# 988                        county_loc_Gaston     1.000000
# 989                         county_loc_Gates     1.000000
# 990                        county_loc_Graham     1.000000
# 991                     county_loc_Granville     1.000000
# 992                        county_loc_Greene     1.000000
# 993                      county_loc_Guilford     1.000000
# 994                       county_loc_Harnett     1.000000
# 995                       county_loc_Haywood     1.000000
# 996                     county_loc_Henderson     1.000000
# 997                      county_loc_Hertford     1.000000
# 998                          county_loc_Hoke     1.000000
# 999                          county_loc_Hyde     1.000000
# 1000                      county_loc_Jackson     1.000000
# 1001                     county_loc_Johnston     1.000000
# 1002                        county_loc_Jones     1.000000
# 1003                          county_loc_Lee     1.000000
# 1004                        county_loc_Macon     1.000000
# 1005                      county_loc_Madison     1.000000
# 1006                       county_loc_Martin     1.000000
# 1007                     county_loc_McDowell     1.000000
# 1008                  county_loc_Mecklenburg     1.000000
# 1009                     county_loc_Mitchell     1.000000
# 1010                        county_loc_Moore     1.000000
# 1011                  county_loc_Northampton     1.000000
# 1012                       county_loc_Onslow     1.000000
# 1013                      county_loc_Pamlico     1.000000
# 1014                   county_loc_Pasquotank     1.000000
# 1015                       county_loc_Pender     1.000000
# 1016                   county_loc_Perquimans     1.000000
# 1017                       county_loc_Person     1.000000
# 1018                         county_loc_Polk     1.000000
# 1019                     county_loc_Richmond     1.000000
# 1020                   county_loc_Rockingham     1.000000
# 1021                        county_loc_Rowan     1.000000
# 1022                   county_loc_Rutherford     1.000000
# 1023                     county_loc_Scotland     1.000000
# 1024                       county_loc_Stanly     1.000000
# 1025                       county_loc_Stokes     1.000000
# 1026                        county_loc_Swain     1.000000
# 1027                 county_loc_Transylvania     1.000000
# 1028                      county_loc_Tyrrell     1.000000
# 1029                        county_loc_Union     1.000000
# 1030                        county_loc_Vance     1.000000
# 1031                         county_loc_Wake     0.984378
# 1032                   county_loc_Washington     1.000000
# 1033                      county_loc_Watauga     1.000000
# 1034                        county_loc_Wayne     1.000000
# 1035                       county_loc_Wilson     1.000000
# 1036                       county_loc_Yadkin     1.000000
# 1037                       county_loc_Yancey     1.000000
# 1038                       county_loc_Yancey     1.000000
# 1039            stree_addr2_loc_309 Ashe Ave     1.000000
# 1040                    grade_span_loc_P1:12     1.000000

# %%
print('Dropping the following ', str(len(cf['Field2'].unique())), ' highly correlated, unique fields.')
cf['Field2'].unique()
# Out:
# Dropping the following  471  highly correlated, unique fields.
# array(['indian_pct', 'asian_pct', 'pct_acall_all_act',
#        'pct_acall_fem_act', 'pct_acall_male_act', 'pct_acall_neds_act',
#        'pct_acall_nswd_act', 'pct_acco_aig_act', 'pct_acco_all_act',
#        'pct_acco_fem_act', 'pct_acco_male_act', 'pct_acco_neds_act',
#        'pct_acco_nswd_act', 'pct_acco_wh7_act', 'pct_acen_aig_act',
#        'pct_acen_all_act', 'pct_acen_fem_act', 'pct_acen_male_act',
#        'pct_acen_neds_act', 'pct_acen_nswd_act', 'pct_acen_wh7_act',
#        'pct_acma_aig_act', 'pct_acma_all_act', 'pct_acma_fem_act',
#        'pct_acma_male_act', 'pct_acma_neds_act', 'pct_acma_nswd_act',
#        'pct_acma_wh7_act', 'pct_acrd_aig_act', 'pct_acrd_all_act',
#        'pct_acrd_fem_act', 'pct_acrd_male_act', 'pct_acrd_neds_act',
#        'pct_acrd_nswd_act', 'pct_acrd_wh7_act', 'pct_acsc_all_act',
#        'pct_acsc_neds_act', 'pct_acwr_all_act', 'pct_acwr_fem_act',
#        'pct_acwr_neds_act', 'pct_aig_awa', 'pct_all_awa', 'pct_fem_awa',
#        'pct_neds_awa', 'pct_ext_all_cgr', 'pct_ext_fem_cgr',
#        'pct_ext_neds_cgr', 'pct_ext_nswd_cgr', 'pct_std_all_cgr',
#        'pct_std_fem_cgr', 'pct_std_neds_cgr', 'eg_score_all_bl7_eg',
#        'eg_score_all_eds_eg', 'eg_score_all_hi7_eg',
#        'eg_score_all_swd_eg', 'eg_score_all_wh7_eg', 'den_all_elp',
#        'den_eds_elp', 'den_els_elp', 'den_hi7_elp', 'den_male_elp',
#        'pct_all_elp', 'target_assign_math_grade_11_ltg',
#        'target_assign_reading_grade_10_ltg',
#        'target_assign_total_targets_ltg', 'pct_all_mcr', 'pct_fem_mcr',
#        'target_assign_biology_part', 'target_assign_english_ii_part',
#        'target_assign_high_school_math_part',
#        'target_assign_the_act_part', 'target_met_biology_part',
#        'pct_biology_all_part_det', 'pct_biology_eds_part_det',
#        'pct_biology_wh7_part_det', 'pct_high_school_math_all_part_det',
#        'pct_high_school_math_eds_part_det',
#        'pct_high_school_math_wh7_part_det', 'pct_ccr_bi_eoc_aig_pc',
#        'pct_ccr_bi_eoc_all_pc', 'pct_ccr_bi_eoc_bl7_pc',
#        'pct_ccr_bi_eoc_eds_pc', 'pct_ccr_bi_eoc_fem_pc',
#        'pct_ccr_bi_eoc_hi7_pc', 'pct_ccr_bi_eoc_male_pc',
#        'pct_ccr_bi_eoc_neds_pc', 'pct_ccr_bi_eoc_nswd_pc',
#        'pct_ccr_bi_eoc_swd_pc', 'pct_ccr_bi_eoc_wh7_pc',
#        'pct_ccr_e2_eoc_aig_pc', 'pct_ccr_e2_eoc_all_pc',
#        'pct_ccr_e2_eoc_bl7_pc', 'pct_ccr_e2_eoc_eds_pc',
#        'pct_ccr_e2_eoc_fem_pc', 'pct_ccr_e2_eoc_hi7_pc',
#        'pct_ccr_e2_eoc_male_pc', 'pct_ccr_e2_eoc_neds_pc',
#        'pct_ccr_e2_eoc_nswd_pc', 'pct_ccr_e2_eoc_wh7_pc',
#        'pct_ccr_eoc_eoc_aig_pc', 'pct_ccr_eoc_eoc_all_pc',
#        'pct_ccr_eoc_eoc_bl7_pc', 'pct_ccr_eoc_eoc_eds_pc',
#        'pct_ccr_eoc_eoc_fem_pc', 'pct_ccr_eoc_eoc_hi7_pc',
#        'pct_ccr_eoc_eoc_male_pc', 'pct_ccr_eoc_eoc_mu7_pc',
#        'pct_ccr_eoc_eoc_neds_pc', 'pct_ccr_eoc_eoc_nswd_pc',
#        'pct_ccr_eoc_eoc_wh7_pc', 'pct_ccr_m1_eoc_all_pc',
#        'pct_ccr_m1_eoc_eds_pc', 'pct_ccr_m1_eoc_fem_pc',
#        'pct_ccr_m1_eoc_male_pc', 'pct_ccr_m1_eoc_neds_pc',
#        'pct_ccr_m1_eoc_nswd_pc', 'pct_ccr_m1_eoc_wh7_pc',
#        'pct_ccr_m3_eoc_all_pc', 'pct_ccr_m3_eoc_eds_pc',
#        'pct_ccr_m3_eoc_fem_pc', 'pct_ccr_m3_eoc_hi7_pc',
#        'pct_glp_bi_eoc_all_pc', 'pct_glp_bi_eoc_bl7_pc',
#        'pct_glp_bi_eoc_neds_pc', 'pct_glp_e2_eoc_aig_pc',
#        'pct_glp_e2_eoc_all_pc', 'pct_glp_e2_eoc_bl7_pc',
#        'pct_glp_e2_eoc_eds_pc', 'pct_glp_e2_eoc_fem_pc',
#        'pct_glp_e2_eoc_hi7_pc', 'pct_glp_e2_eoc_male_pc',
#        'pct_glp_e2_eoc_neds_pc', 'pct_glp_e2_eoc_nswd_pc',
#        'pct_glp_e2_eoc_wh7_pc', 'pct_glp_eoc_eoc_all_pc',
#        'pct_glp_eoc_eoc_bl7_pc', 'pct_glp_eoc_eoc_eds_pc',
#        'pct_glp_eoc_eoc_fem_pc', 'pct_glp_eoc_eoc_hi7_pc',
#        'pct_glp_eoc_eoc_male_pc', 'pct_glp_eoc_eoc_neds_pc',
#        'pct_glp_eoc_eoc_nswd_pc', 'pct_glp_eoc_eoc_wh7_pc',
#        'pct_glp_m1_eoc_all_pc', 'pct_glp_m1_eoc_swd_pc',
#        'pct_glp_m3_eoc_all_pc', 'pct_glp_m3_eoc_fem_pc',
#        'pct_l3_all_all_aig_pc', 'pct_l3_all_all_all_pc',
#        'pct_l3_all_all_bl7_pc', 'pct_l3_all_all_eds_pc',
#        'pct_l3_all_all_hi7_pc', 'pct_l3_all_all_mu7_pc',
#        'pct_l3_all_all_nswd_pc', 'pct_l3_m1_eoc_all_pc',
#        'pct_l3_m3_eoc_all_pc', 'pct_l4_all_all_aig_pc',
#        'pct_l4_all_all_all_pc', 'pct_l4_all_all_bl7_pc',
#        'pct_l4_all_all_eds_pc', 'pct_l4_all_all_fem_pc',
#        'pct_l4_all_all_hi7_pc', 'pct_l4_all_all_male_pc',
#        'pct_l4_all_all_mu7_pc', 'pct_l4_all_all_neds_pc',
#        'pct_l4_all_all_nswd_pc', 'pct_l4_all_all_wh7_pc',
#        'pct_l4_bi_eoc_all_pc', 'pct_l4_e2_eoc_all_pc',
#        'pct_l4_eoc_eoc_all_pc', 'pct_l4_eoc_eoc_fem_pc',
#        'pct_l4_eoc_eoc_neds_pc', 'pct_l4_m1_eoc_all_pc',
#        'pct_l4_m3_eoc_all_pc', 'pct_l5_all_all_all_pc',
#        'pct_l5_all_all_fem_pc', 'pct_l5_all_all_male_pc',
#        'pct_l5_all_all_neds_pc', 'pct_l5_all_all_nswd_pc',
#        'pct_l5_all_all_wh7_pc', 'pct_l5_bi_eoc_all_pc',
#        'pct_l5_bi_eoc_neds_pc', 'pct_l5_eoc_eoc_all_pc',
#        'pct_l5_eoc_eoc_fem_pc', 'pct_l5_eoc_eoc_neds_pc',
#        'pct_l5_m3_eoc_all_pc', 'pct_notprof_all_all_aig_pc',
#        'pct_notprof_all_all_all_pc', 'pct_notprof_all_all_nswd_pc',
#        'pct_notprof_m3_eoc_all_pc', 'aaa_score_hi7_spg2',
#        'ach_score_all_spg2', 'ach_score_bl7_spg2', 'ach_score_eds_spg2',
#        'ach_score_hi7_spg2', 'ach_score_swd_spg2', 'ach_score_wh7_spg2',
#        'awa_score_wh7_spg2', 'cgrs_score_eds_spg2', 'pct_all_wk',
#        'avg_student_num_adm', 'count_all_chron_absent',
#        'count_fem_chron_absent', 'pct_all_chron_absent',
#        'count_2018_enroll_all_college', 'count_2018_enroll_fem_college',
#        'count_2018_noenro_all_college', 'tot_num_ap_h_am7_courses2',
#        'tot_num_ap_h_as7_courses2', 'tot_num_ap_h_bl7_courses2',
#        'tot_num_ap_h_els_courses2', 'tot_num_ap_h_fem_courses2',
#        'tot_num_ap_h_hi7_courses2', 'tot_num_ap_h_male_courses2',
#        'tot_num_ap_h_mu7_courses2', 'tot_num_ap_h_other_courses2',
#        'tot_num_ap_h_pi7_courses2', 'tot_num_ap_h_swd_courses2',
#        'tot_num_ccp_h_am7_courses2', 'tot_num_ccp_h_as7_courses2',
#        'tot_num_ccp_h_bl7_courses2', 'tot_num_ccp_h_els_courses2',
#        'tot_num_ccp_h_fem_courses2', 'tot_num_ccp_h_hi7_courses2',
#        'tot_num_ccp_h_male_courses2', 'tot_num_ccp_h_mu7_courses2',
#        'tot_num_ccp_h_other_courses2', 'tot_num_ccp_h_pi7_courses2',
#        'tot_num_ccp_h_swd_courses2', 'year_h_am7_courses2',
#        'year_h_as7_courses2', 'year_h_bl7_courses2',
#        'year_h_els_courses2', 'year_h_fem_courses2',
#        'year_h_hi7_courses2', 'year_h_male_courses2',
#        'year_h_mu7_courses2', 'year_h_other_courses2',
#        'year_h_pi7_courses2', 'year_h_swd_courses2', 'stu_enroll',
#        'cte_enroll', 'number_of_teachers_eq',
#        'adm_central_expense_funds2', 'adm_employee_benefits_funds2',
#        'adm_instructional_equip._funds2', 'adm_other_objects_funds2',
#        'adm_purchased_services_funds2', 'adm_salaries_funds2',
#        'adm_supplies_&_materials_funds2', 'adm_total_funds2',
#        'federal_funds_employee_benefits_funds2',
#        'federal_funds_other_objects_funds2',
#        'federal_funds_salaries_funds2',
#        'federal_ppe_employee_benefits_funds2',
#        'federal_ppe_other_objects_funds2', 'federal_ppe_salaries_funds2',
#        'local_funds_central_expense_funds2',
#        'local_funds_employee_benefits_funds2',
#        'local_funds_other_objects_funds2',
#        'local_funds_purchased_services_funds2',
#        'local_funds_salaries_funds2',
#        'local_ppe_employee_benefits_funds2',
#        'local_ppe_other_objects_funds2',
#        'state_funds_employee_benefits_funds2',
#        'state_funds_salaries_funds2', 'state_funds_total_funds2',
#        'state_ppe_employee_benefits_funds2',
#        'total_funds_employee_benefits_funds2',
#        'total_funds_salaries_funds2', 'arr_per1000_all_inc2',
#        'arr_per1000_bl7_inc2', 'exp_per1000_all_inc2',
#        'exp_per1000_bl7_inc2', 'exp_per1000_els_inc2',
#        'iss_per1000_all_inc2', 'lts_per1000_bl7_inc2',
#        'rpt_per1000_all_inc2', 'lea_code_loc_020LEA',
#        'lea_code_loc_030LEA', 'lea_code_loc_040LEA',
#        'lea_code_loc_050LEA', 'lea_code_loc_060LEA',
#        'lea_code_loc_070LEA', 'lea_code_loc_080LEA',
#        'lea_code_loc_090LEA', 'lea_code_loc_100LEA',
#        'lea_code_loc_110LEA', 'lea_code_loc_111LEA',
#        'lea_code_loc_120LEA', 'lea_code_loc_130LEA',
#        'lea_code_loc_132LEA', 'lea_code_loc_140LEA',
#        'lea_code_loc_150LEA', 'lea_code_loc_160LEA',
#        'lea_code_loc_170LEA', 'lea_code_loc_180LEA',
#        'lea_code_loc_181LEA', 'lea_code_loc_182LEA',
#        'lea_code_loc_190LEA', 'lea_code_loc_200LEA',
#        'lea_code_loc_210LEA', 'lea_code_loc_220LEA',
#        'lea_code_loc_230LEA', 'lea_code_loc_240LEA',
#        'lea_code_loc_241LEA', 'lea_code_loc_250LEA',
#        'lea_code_loc_260LEA', 'lea_code_loc_270LEA',
#        'lea_code_loc_280LEA', 'lea_code_loc_290LEA',
#        'lea_code_loc_291LEA', 'lea_code_loc_292LEA',
#        'lea_code_loc_299LEA', 'lea_code_loc_300LEA',
#        'lea_code_loc_310LEA', 'lea_code_loc_320LEA',
#        'lea_code_loc_330LEA', 'lea_code_loc_340LEA',
#        'lea_code_loc_350LEA', 'lea_code_loc_360LEA',
#        'lea_code_loc_370LEA', 'lea_code_loc_380LEA',
#        'lea_code_loc_390LEA', 'lea_code_loc_400LEA',
#        'lea_code_loc_410LEA', 'lea_code_loc_420LEA',
#        'lea_code_loc_421LEA', 'lea_code_loc_422LEA',
#        'lea_code_loc_430LEA', 'lea_code_loc_440LEA',
#        'lea_code_loc_450LEA', 'lea_code_loc_460LEA',
#        'lea_code_loc_470LEA', 'lea_code_loc_480LEA',
#        'lea_code_loc_490LEA', 'lea_code_loc_500LEA',
#        'lea_code_loc_510LEA', 'lea_code_loc_520LEA',
#        'lea_code_loc_530LEA', 'lea_code_loc_540LEA',
#        'lea_code_loc_550LEA', 'lea_code_loc_560LEA',
#        'lea_code_loc_570LEA', 'lea_code_loc_580LEA',
#        'lea_code_loc_590LEA', 'lea_code_loc_600LEA',
#        'lea_code_loc_610LEA', 'lea_code_loc_620LEA',
#        'lea_code_loc_630LEA', 'lea_code_loc_640LEA',
#        'lea_code_loc_650LEA', 'lea_code_loc_660LEA',
#        'lea_code_loc_670LEA', 'lea_code_loc_680LEA',
#        'lea_code_loc_681LEA', 'lea_code_loc_690LEA',
#        'lea_code_loc_700LEA', 'lea_code_loc_710LEA',
#        'lea_code_loc_720LEA', 'lea_code_loc_730LEA',
#        'lea_code_loc_740LEA', 'lea_code_loc_750LEA',
#        'lea_code_loc_760LEA', 'lea_code_loc_761LEA',
#        'lea_code_loc_770LEA', 'lea_code_loc_780LEA',
#        'lea_code_loc_790LEA', 'lea_code_loc_800LEA',
#        'lea_code_loc_810LEA', 'lea_code_loc_820LEA',
#        'lea_code_loc_821LEA', 'lea_code_loc_830LEA',
#        'lea_code_loc_840LEA', 'lea_code_loc_850LEA',
#        'lea_code_loc_860LEA', 'lea_code_loc_861LEA',
#        'lea_code_loc_862LEA', 'lea_code_loc_870LEA',
#        'lea_code_loc_880LEA', 'lea_code_loc_890LEA',
#        'lea_code_loc_900LEA', 'lea_code_loc_910LEA',
#        'lea_code_loc_920LEA', 'lea_code_loc_930LEA',
#        'lea_code_loc_940LEA', 'lea_code_loc_950LEA',
#        'lea_code_loc_960LEA', 'lea_code_loc_970LEA',
#        'lea_code_loc_980LEA', 'lea_code_loc_990LEA',
#        'lea_code_loc_995LEA', 'lea_code_loc_998LEA',
#        'county_loc_Alleghany', 'county_loc_Anson', 'county_loc_Ashe',
#        'county_loc_Avery', 'county_loc_Beaufort', 'county_loc_Bertie',
#        'county_loc_Bladen', 'county_loc_Brunswick', 'county_loc_Burke',
#        'county_loc_Caldwell', 'county_loc_Camden', 'county_loc_Carteret',
#        'county_loc_Caswell', 'county_loc_Cherokee', 'county_loc_Chowan',
#        'county_loc_Clay', 'county_loc_Cleveland', 'county_loc_Craven',
#        'county_loc_Currituck', 'county_loc_Dare', 'county_loc_Davie',
#        'county_loc_Duplin', 'county_loc_Durham', 'county_loc_Edgecombe',
#        'county_loc_Forsyth', 'county_loc_Franklin', 'county_loc_Gaston',
#        'county_loc_Gates', 'county_loc_Graham', 'county_loc_Granville',
#        'county_loc_Greene', 'county_loc_Guilford', 'county_loc_Harnett',
#        'county_loc_Haywood', 'county_loc_Henderson',
#        'county_loc_Hertford', 'county_loc_Hoke', 'county_loc_Hyde',
#        'county_loc_Jackson', 'county_loc_Johnston', 'county_loc_Jones',
#        'county_loc_Lee', 'county_loc_Macon', 'county_loc_Madison',
#        'county_loc_Martin', 'county_loc_McDowell',
#        'county_loc_Mecklenburg', 'county_loc_Mitchell',
#        'county_loc_Moore', 'county_loc_Northampton', 'county_loc_Onslow',
#        'county_loc_Pamlico', 'county_loc_Pasquotank', 'county_loc_Pender',
#        'county_loc_Perquimans', 'county_loc_Person', 'county_loc_Polk',
#        'county_loc_Richmond', 'county_loc_Rockingham', 'county_loc_Rowan',
#        'county_loc_Rutherford', 'county_loc_Scotland',
#        'county_loc_Stanly', 'county_loc_Stokes', 'county_loc_Swain',
#        'county_loc_Transylvania', 'county_loc_Tyrrell',
#        'county_loc_Union', 'county_loc_Vance', 'county_loc_Wake',
#        'county_loc_Washington', 'county_loc_Watauga', 'county_loc_Wayne',
#        'county_loc_Wilson', 'county_loc_Yadkin', 'county_loc_Yancey',
#        'stree_addr2_loc_309 Ashe Ave', 'grade_span_loc_P1:12'],
#       dtype=object)

# %%
#Check columns before drop 
print('\r\n*********Before: Dropping Highly Correlated Fields*************************************')
schoolData.info(verbose=False)

# Drop the highly correlated features from our training data 
#schoolData = schoolData.drop(to_drop, axis=1)
schoolData = schoolData.drop(cf['Field2'], axis=1)

#Check columns after drop 
print('\r\n*********After: Dropping Highly Correlated Fields**************************************')
schoolData.info(verbose=False)
# Out:
# *********Before: Dropping Highly Correlated Fields*************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 644 entries, 2 to 715
# Columns: 1354 entries, lea to poverty_eq_NEITHER
# dtypes: float64(898), uint8(456)
# memory usage: 4.7 MB
#
# *********After: Dropping Highly Correlated Fields**************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 644 entries, 2 to 715
# Columns: 883 entries, lea to poverty_eq_NEITHER
# dtypes: float64(620), uint8(263)
# memory usage: 3.2 MB

# %%
#Restore the unit_code before saving
schoolData['agency_code'] = agency_code
#Save the final dataset to a .csv file
schoolData.to_csv(outputDir + inputFileName + '_ML.csv', sep=',', index=False)

# %%
print('*********FINAL DATASET DETAILS*********************************************************\r\n')
schoolData.info(verbose=True)
# Out:
# *********FINAL DATASET DETAILS*********************************************************
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 644 entries, 2 to 715
# Data columns (total 884 columns):
#  #   Column                                                                                                                       Dtype
# ---  ------                                                                                                                       -----
#  0   lea                                                                                                                          float64
#  1   school                                                                                                                       float64
#  2   hispanic_pct                                                                                                                 float64
#  3   black_pct                                                                                                                    float64
#  4   white_pct                                                                                                                    float64
#  5   pacific_island_pct                                                                                                           float64
#  6   two_or_more_pct                                                                                                              float64
#  7   minority_pct                                                                                                                 float64
#  8   indian_male_pct                                                                                                              float64
#  9   asian_male_pct                                                                                                               float64
#  10  hispanic_male_pct                                                                                                            float64
#  11  black_male_pct                                                                                                               float64
#  12  white_male_pct                                                                                                               float64
#  13  pacific_island_male_pct                                                                                                      float64
#  14  two_or_more_male_pct                                                                                                         float64
#  15  minority_male_pct                                                                                                            float64
#  16  indian_female_pct                                                                                                            float64
#  17  asian_female_pct                                                                                                             float64
#  18  hispanic_female_pct                                                                                                          float64
#  19  black_female_pct                                                                                                             float64
#  20  white_female_pct                                                                                                             float64
#  21  minority_female_pct                                                                                                          float64
#  22  pacific_island_female_pct                                                                                                    float64
#  23  two_or_more_female_pct                                                                                                       float64
#  24  pct_acall_aig_act                                                                                                            float64
#  25  pct_acall_as7_act                                                                                                            float64
#  26  pct_acall_bl7_act                                                                                                            float64
#  27  pct_acall_eds_act                                                                                                            float64
#  28  pct_acall_els_act                                                                                                            float64
#  29  pct_acall_hi7_act                                                                                                            float64
#  30  pct_acall_mu7_act                                                                                                            float64
#  31  pct_acall_swd_act                                                                                                            float64
#  32  pct_acall_wh7_act                                                                                                            float64
#  33  pct_acco_bl7_act                                                                                                             float64
#  34  pct_acco_eds_act                                                                                                             float64
#  35  pct_acco_hi7_act                                                                                                             float64
#  36  pct_acco_swd_act                                                                                                             float64
#  37  pct_acen_bl7_act                                                                                                             float64
#  38  pct_acen_eds_act                                                                                                             float64
#  39  pct_acen_hi7_act                                                                                                             float64
#  40  pct_acen_swd_act                                                                                                             float64
#  41  pct_acma_bl7_act                                                                                                             float64
#  42  pct_acma_eds_act                                                                                                             float64
#  43  pct_acma_hi7_act                                                                                                             float64
#  44  pct_acma_swd_act                                                                                                             float64
#  45  pct_acrd_bl7_act                                                                                                             float64
#  46  pct_acrd_eds_act                                                                                                             float64
#  47  pct_acrd_hi7_act                                                                                                             float64
#  48  pct_acrd_swd_act                                                                                                             float64
#  49  pct_acsc_aig_act                                                                                                             float64
#  50  pct_acsc_bl7_act                                                                                                             float64
#  51  pct_acsc_eds_act                                                                                                             float64
#  52  pct_acsc_fem_act                                                                                                             float64
#  53  pct_acsc_hi7_act                                                                                                             float64
#  54  pct_acsc_male_act                                                                                                            float64
#  55  pct_acsc_nswd_act                                                                                                            float64
#  56  pct_acsc_swd_act                                                                                                             float64
#  57  pct_acsc_wh7_act                                                                                                             float64
#  58  pct_acwr_aig_act                                                                                                             float64
#  59  pct_acwr_bl7_act                                                                                                             float64
#  60  pct_acwr_eds_act                                                                                                             float64
#  61  pct_acwr_hi7_act                                                                                                             float64
#  62  pct_acwr_male_act                                                                                                            float64
#  63  pct_acwr_nswd_act                                                                                                            float64
#  64  pct_acwr_swd_act                                                                                                             float64
#  65  pct_acwr_wh7_act                                                                                                             float64
#  66  pct_bl7_awa                                                                                                                  float64
#  67  pct_eds_awa                                                                                                                  float64
#  68  pct_hi7_awa                                                                                                                  float64
#  69  pct_male_awa                                                                                                                 float64
#  70  pct_nswd_awa                                                                                                                 float64
#  71  pct_swd_awa                                                                                                                  float64
#  72  pct_wh7_awa                                                                                                                  float64
#  73  pct_ext_aig_cgr                                                                                                              float64
#  74  pct_ext_bl7_cgr                                                                                                              float64
#  75  pct_ext_eds_cgr                                                                                                              float64
#  76  pct_ext_hi7_cgr                                                                                                              float64
#  77  pct_ext_male_cgr                                                                                                             float64
#  78  pct_ext_swd_cgr                                                                                                              float64
#  79  pct_ext_wh7_cgr                                                                                                              float64
#  80  pct_std_aig_cgr                                                                                                              float64
#  81  pct_std_bl7_cgr                                                                                                              float64
#  82  pct_std_eds_cgr                                                                                                              float64
#  83  pct_std_hi7_cgr                                                                                                              float64
#  84  pct_std_male_cgr                                                                                                             float64
#  85  pct_std_nswd_cgr                                                                                                             float64
#  86  pct_std_swd_cgr                                                                                                              float64
#  87  pct_std_wh7_cgr                                                                                                              float64
#  88  pct_eds                                                                                                                      float64
#  89  eg_index_all_aig_eg                                                                                                          float64
#  90  eg_index_all_all_eg                                                                                                          float64
#  91  eg_index_all_bl7_eg                                                                                                          float64
#  92  eg_index_all_eds_eg                                                                                                          float64
#  93  eg_index_all_hi7_eg                                                                                                          float64
#  94  eg_index_all_swd_eg                                                                                                          float64
#  95  eg_index_all_wh7_eg                                                                                                          float64
#  96  eg_score_all_aig_eg                                                                                                          float64
#  97  eg_score_all_all_eg                                                                                                          float64
#  98  den_nswd_elp                                                                                                                 float64
#  99  pct_eds_elp                                                                                                                  float64
#  100 pct_els_elp                                                                                                                  float64
#  101 pct_hi7_elp                                                                                                                  float64
#  102 pct_male_elp                                                                                                                 float64
#  103 pct_nswd_elp                                                                                                                 float64
#  104 pct_prof_9gr_irm                                                                                                             float64
#  105 pct_met_4_year_graduation_rate_ltg                                                                                           float64
#  106 pct_met_math_grade_11_ltg                                                                                                    float64
#  107 pct_met_reading_grade_10_ltg                                                                                                 float64
#  108 pct_met_total_targets_ltg                                                                                                    float64
#  109 target_assign_4_year_graduation_rate_ltg                                                                                     float64
#  110 target_met_4_year_graduation_rate_ltg                                                                                        float64
#  111 target_met_math_grade_11_ltg                                                                                                 float64
#  112 target_met_reading_grade_10_ltg                                                                                              float64
#  113 target_met_total_targets_ltg                                                                                                 float64
#  114 pct_aig_mcr                                                                                                                  float64
#  115 pct_bl7_mcr                                                                                                                  float64
#  116 pct_eds_mcr                                                                                                                  float64
#  117 pct_hi7_mcr                                                                                                                  float64
#  118 pct_male_mcr                                                                                                                 float64
#  119 pct_neds_mcr                                                                                                                 float64
#  120 pct_nswd_mcr                                                                                                                 float64
#  121 pct_swd_mcr                                                                                                                  float64
#  122 pct_wh7_mcr                                                                                                                  float64
#  123 pct_met_act_workkeys_part                                                                                                    float64
#  124 pct_met_biology_part                                                                                                         float64
#  125 pct_met_english_ii_part                                                                                                      float64
#  126 pct_met_high_school_math_part                                                                                                float64
#  127 pct_met_the_act_part                                                                                                         float64
#  128 pct_met_total_targets_part                                                                                                   float64
#  129 target_assign_act_workkeys_part                                                                                              float64
#  130 target_assign_total_targets_part                                                                                             float64
#  131 target_met_act_workkeys_part                                                                                                 float64
#  132 target_met_english_ii_part                                                                                                   float64
#  133 target_met_high_school_math_part                                                                                             float64
#  134 target_met_the_act_part                                                                                                      float64
#  135 target_met_total_targets_part                                                                                                float64
#  136 pct_act_workkeys_all_part_det                                                                                                float64
#  137 pct_act_workkeys_wh7_part_det                                                                                                float64
#  138 pct_english_ii_all_part_det                                                                                                  float64
#  139 pct_english_ii_eds_part_det                                                                                                  float64
#  140 pct_english_ii_wh7_part_det                                                                                                  float64
#  141 pct_the_act_all_part_det                                                                                                     float64
#  142 pct_the_act_eds_part_det                                                                                                     float64
#  143 pct_the_act_wh7_part_det                                                                                                     float64
#  144 pct_ccr_e2_eoc_swd_pc                                                                                                        float64
#  145 pct_ccr_eoc_eoc_swd_pc                                                                                                       float64
#  146 pct_ccr_m3_eoc_aig_pc                                                                                                        float64
#  147 pct_ccr_m3_eoc_male_pc                                                                                                       float64
#  148 pct_ccr_m3_eoc_neds_pc                                                                                                       float64
#  149 pct_ccr_m3_eoc_nswd_pc                                                                                                       float64
#  150 pct_ccr_m3_eoc_wh7_pc                                                                                                        float64
#  151 pct_glp_bi_eoc_aig_pc                                                                                                        float64
#  152 pct_glp_bi_eoc_eds_pc                                                                                                        float64
#  153 pct_glp_bi_eoc_fem_pc                                                                                                        float64
#  154 pct_glp_bi_eoc_hi7_pc                                                                                                        float64
#  155 pct_glp_bi_eoc_male_pc                                                                                                       float64
#  156 pct_glp_bi_eoc_nswd_pc                                                                                                       float64
#  157 pct_glp_bi_eoc_swd_pc                                                                                                        float64
#  158 pct_glp_bi_eoc_wh7_pc                                                                                                        float64
#  159 pct_glp_e2_eoc_swd_pc                                                                                                        float64
#  160 pct_glp_eoc_eoc_aig_pc                                                                                                       float64
#  161 pct_glp_eoc_eoc_els_pc                                                                                                       float64
#  162 pct_glp_eoc_eoc_mu7_pc                                                                                                       float64
#  163 pct_glp_eoc_eoc_swd_pc                                                                                                       float64
#  164 pct_glp_m1_eoc_bl7_pc                                                                                                        float64
#  165 pct_glp_m1_eoc_eds_pc                                                                                                        float64
#  166 pct_glp_m1_eoc_fem_pc                                                                                                        float64
#  167 pct_glp_m1_eoc_hi7_pc                                                                                                        float64
#  168 pct_glp_m1_eoc_male_pc                                                                                                       float64
#  169 pct_glp_m1_eoc_neds_pc                                                                                                       float64
#  170 pct_glp_m1_eoc_nswd_pc                                                                                                       float64
#  171 pct_glp_m1_eoc_wh7_pc                                                                                                        float64
#  172 pct_glp_m3_eoc_aig_pc                                                                                                        float64
#  173 pct_glp_m3_eoc_bl7_pc                                                                                                        float64
#  174 pct_glp_m3_eoc_eds_pc                                                                                                        float64
#  175 pct_glp_m3_eoc_hi7_pc                                                                                                        float64
#  176 pct_glp_m3_eoc_male_pc                                                                                                       float64
#  177 pct_glp_m3_eoc_neds_pc                                                                                                       float64
#  178 pct_glp_m3_eoc_nswd_pc                                                                                                       float64
#  179 pct_glp_m3_eoc_wh7_pc                                                                                                        float64
#  180 pct_l1_bi_eoc_all_pc                                                                                                         float64
#  181 pct_l1_bi_eoc_bl7_pc                                                                                                         float64
#  182 pct_l1_bi_eoc_eds_pc                                                                                                         float64
#  183 pct_l1_bi_eoc_fem_pc                                                                                                         float64
#  184 pct_l1_bi_eoc_hi7_pc                                                                                                         float64
#  185 pct_l1_bi_eoc_male_pc                                                                                                        float64
#  186 pct_l1_bi_eoc_neds_pc                                                                                                        float64
#  187 pct_l1_bi_eoc_nswd_pc                                                                                                        float64
#  188 pct_l1_bi_eoc_swd_pc                                                                                                         float64
#  189 pct_l1_bi_eoc_wh7_pc                                                                                                         float64
#  190 pct_l1_e2_eoc_all_pc                                                                                                         float64
#  191 pct_l1_e2_eoc_bl7_pc                                                                                                         float64
#  192 pct_l1_e2_eoc_eds_pc                                                                                                         float64
#  193 pct_l1_e2_eoc_fem_pc                                                                                                         float64
#  194 pct_l1_e2_eoc_hi7_pc                                                                                                         float64
#  195 pct_l1_e2_eoc_male_pc                                                                                                        float64
#  196 pct_l1_e2_eoc_neds_pc                                                                                                        float64
#  197 pct_l1_e2_eoc_nswd_pc                                                                                                        float64
#  198 pct_l1_e2_eoc_swd_pc                                                                                                         float64
#  199 pct_l1_e2_eoc_wh7_pc                                                                                                         float64
#  200 pct_l2_bi_eoc_all_pc                                                                                                         float64
#  201 pct_l2_bi_eoc_bl7_pc                                                                                                         float64
#  202 pct_l2_bi_eoc_eds_pc                                                                                                         float64
#  203 pct_l2_bi_eoc_fem_pc                                                                                                         float64
#  204 pct_l2_bi_eoc_hi7_pc                                                                                                         float64
#  205 pct_l2_bi_eoc_male_pc                                                                                                        float64
#  206 pct_l2_bi_eoc_neds_pc                                                                                                        float64
#  207 pct_l2_bi_eoc_nswd_pc                                                                                                        float64
#  208 pct_l2_bi_eoc_swd_pc                                                                                                         float64
#  209 pct_l2_bi_eoc_wh7_pc                                                                                                         float64
#  210 pct_l2_e2_eoc_all_pc                                                                                                         float64
#  211 pct_l2_e2_eoc_bl7_pc                                                                                                         float64
#  212 pct_l2_e2_eoc_eds_pc                                                                                                         float64
#  213 pct_l2_e2_eoc_fem_pc                                                                                                         float64
#  214 pct_l2_e2_eoc_hi7_pc                                                                                                         float64
#  215 pct_l2_e2_eoc_male_pc                                                                                                        float64
#  216 pct_l2_e2_eoc_neds_pc                                                                                                        float64
#  217 pct_l2_e2_eoc_nswd_pc                                                                                                        float64
#  218 pct_l2_e2_eoc_swd_pc                                                                                                         float64
#  219 pct_l2_e2_eoc_wh7_pc                                                                                                         float64
#  220 pct_l3_all_all_fem_pc                                                                                                        float64
#  221 pct_l3_all_all_male_pc                                                                                                       float64
#  222 pct_l3_all_all_neds_pc                                                                                                       float64
#  223 pct_l3_all_all_swd_pc                                                                                                        float64
#  224 pct_l3_all_all_wh7_pc                                                                                                        float64
#  225 pct_l3_bi_eoc_all_pc                                                                                                         float64
#  226 pct_l3_bi_eoc_bl7_pc                                                                                                         float64
#  227 pct_l3_bi_eoc_eds_pc                                                                                                         float64
#  228 pct_l3_bi_eoc_fem_pc                                                                                                         float64
#  229 pct_l3_bi_eoc_hi7_pc                                                                                                         float64
#  230 pct_l3_bi_eoc_male_pc                                                                                                        float64
#  231 pct_l3_bi_eoc_neds_pc                                                                                                        float64
#  232 pct_l3_bi_eoc_nswd_pc                                                                                                        float64
#  233 pct_l3_bi_eoc_wh7_pc                                                                                                         float64
#  234 pct_l3_e2_eoc_all_pc                                                                                                         float64
#  235 pct_l3_e2_eoc_bl7_pc                                                                                                         float64
#  236 pct_l3_e2_eoc_eds_pc                                                                                                         float64
#  237 pct_l3_e2_eoc_fem_pc                                                                                                         float64
#  238 pct_l3_e2_eoc_hi7_pc                                                                                                         float64
#  239 pct_l3_e2_eoc_male_pc                                                                                                        float64
#  240 pct_l3_e2_eoc_neds_pc                                                                                                        float64
#  241 pct_l3_e2_eoc_nswd_pc                                                                                                        float64
#  242 pct_l3_e2_eoc_wh7_pc                                                                                                         float64
#  243 pct_l3_eoc_eoc_aig_pc                                                                                                        float64
#  244 pct_l3_eoc_eoc_all_pc                                                                                                        float64
#  245 pct_l3_eoc_eoc_bl7_pc                                                                                                        float64
#  246 pct_l3_eoc_eoc_eds_pc                                                                                                        float64
#  247 pct_l3_eoc_eoc_fem_pc                                                                                                        float64
#  248 pct_l3_eoc_eoc_hi7_pc                                                                                                        float64
#  249 pct_l3_eoc_eoc_male_pc                                                                                                       float64
#  250 pct_l3_eoc_eoc_mu7_pc                                                                                                        float64
#  251 pct_l3_eoc_eoc_neds_pc                                                                                                       float64
#  252 pct_l3_eoc_eoc_nswd_pc                                                                                                       float64
#  253 pct_l3_eoc_eoc_swd_pc                                                                                                        float64
#  254 pct_l3_eoc_eoc_wh7_pc                                                                                                        float64
#  255 pct_l3_m1_eoc_bl7_pc                                                                                                         float64
#  256 pct_l3_m1_eoc_eds_pc                                                                                                         float64
#  257 pct_l3_m1_eoc_fem_pc                                                                                                         float64
#  258 pct_l3_m1_eoc_hi7_pc                                                                                                         float64
#  259 pct_l3_m1_eoc_male_pc                                                                                                        float64
#  260 pct_l3_m1_eoc_neds_pc                                                                                                        float64
#  261 pct_l3_m1_eoc_nswd_pc                                                                                                        float64
#  262 pct_l3_m1_eoc_swd_pc                                                                                                         float64
#  263 pct_l3_m1_eoc_wh7_pc                                                                                                         float64
#  264 pct_l3_m3_eoc_aig_pc                                                                                                         float64
#  265 pct_l3_m3_eoc_bl7_pc                                                                                                         float64
#  266 pct_l3_m3_eoc_eds_pc                                                                                                         float64
#  267 pct_l3_m3_eoc_fem_pc                                                                                                         float64
#  268 pct_l3_m3_eoc_hi7_pc                                                                                                         float64
#  269 pct_l3_m3_eoc_male_pc                                                                                                        float64
#  270 pct_l3_m3_eoc_neds_pc                                                                                                        float64
#  271 pct_l3_m3_eoc_nswd_pc                                                                                                        float64
#  272 pct_l3_m3_eoc_wh7_pc                                                                                                         float64
#  273 pct_l4_all_all_swd_pc                                                                                                        float64
#  274 pct_l4_bi_eoc_aig_pc                                                                                                         float64
#  275 pct_l4_bi_eoc_bl7_pc                                                                                                         float64
#  276 pct_l4_bi_eoc_eds_pc                                                                                                         float64
#  277 pct_l4_bi_eoc_fem_pc                                                                                                         float64
#  278 pct_l4_bi_eoc_hi7_pc                                                                                                         float64
#  279 pct_l4_bi_eoc_male_pc                                                                                                        float64
#  280 pct_l4_bi_eoc_neds_pc                                                                                                        float64
#  281 pct_l4_bi_eoc_nswd_pc                                                                                                        float64
#  282 pct_l4_bi_eoc_swd_pc                                                                                                         float64
#  283 pct_l4_bi_eoc_wh7_pc                                                                                                         float64
#  284 pct_l4_e2_eoc_aig_pc                                                                                                         float64
#  285 pct_l4_e2_eoc_bl7_pc                                                                                                         float64
#  286 pct_l4_e2_eoc_eds_pc                                                                                                         float64
#  287 pct_l4_e2_eoc_fem_pc                                                                                                         float64
#  288 pct_l4_e2_eoc_hi7_pc                                                                                                         float64
#  289 pct_l4_e2_eoc_male_pc                                                                                                        float64
#  290 pct_l4_e2_eoc_neds_pc                                                                                                        float64
#  291 pct_l4_e2_eoc_nswd_pc                                                                                                        float64
#  292 pct_l4_e2_eoc_wh7_pc                                                                                                         float64
#  293 pct_l4_eoc_eoc_aig_pc                                                                                                        float64
#  294 pct_l4_eoc_eoc_bl7_pc                                                                                                        float64
#  295 pct_l4_eoc_eoc_eds_pc                                                                                                        float64
#  296 pct_l4_eoc_eoc_hi7_pc                                                                                                        float64
#  297 pct_l4_eoc_eoc_male_pc                                                                                                       float64
#  298 pct_l4_eoc_eoc_mu7_pc                                                                                                        float64
#  299 pct_l4_eoc_eoc_nswd_pc                                                                                                       float64
#  300 pct_l4_eoc_eoc_wh7_pc                                                                                                        float64
#  301 pct_l4_m1_eoc_eds_pc                                                                                                         float64
#  302 pct_l4_m1_eoc_fem_pc                                                                                                         float64
#  303 pct_l4_m1_eoc_male_pc                                                                                                        float64
#  304 pct_l4_m1_eoc_neds_pc                                                                                                        float64
#  305 pct_l4_m1_eoc_nswd_pc                                                                                                        float64
#  306 pct_l4_m1_eoc_wh7_pc                                                                                                         float64
#  307 pct_l4_m3_eoc_aig_pc                                                                                                         float64
#  308 pct_l4_m3_eoc_eds_pc                                                                                                         float64
#  309 pct_l4_m3_eoc_fem_pc                                                                                                         float64
#  310 pct_l4_m3_eoc_hi7_pc                                                                                                         float64
#  311 pct_l4_m3_eoc_male_pc                                                                                                        float64
#  312 pct_l4_m3_eoc_neds_pc                                                                                                        float64
#  313 pct_l4_m3_eoc_nswd_pc                                                                                                        float64
#  314 pct_l4_m3_eoc_wh7_pc                                                                                                         float64
#  315 pct_l5_all_all_aig_pc                                                                                                        float64
#  316 pct_l5_bi_eoc_aig_pc                                                                                                         float64
#  317 pct_l5_bi_eoc_eds_pc                                                                                                         float64
#  318 pct_l5_bi_eoc_fem_pc                                                                                                         float64
#  319 pct_l5_bi_eoc_hi7_pc                                                                                                         float64
#  320 pct_l5_bi_eoc_male_pc                                                                                                        float64
#  321 pct_l5_bi_eoc_nswd_pc                                                                                                        float64
#  322 pct_l5_bi_eoc_wh7_pc                                                                                                         float64
#  323 pct_l5_e2_eoc_aig_pc                                                                                                         float64
#  324 pct_l5_e2_eoc_neds_pc                                                                                                        float64
#  325 pct_l5_e2_eoc_wh7_pc                                                                                                         float64
#  326 pct_l5_eoc_eoc_aig_pc                                                                                                        float64
#  327 pct_l5_eoc_eoc_male_pc                                                                                                       float64
#  328 pct_l5_eoc_eoc_nswd_pc                                                                                                       float64
#  329 pct_l5_eoc_eoc_wh7_pc                                                                                                        float64
#  330 pct_l5_m3_eoc_aig_pc                                                                                                         float64
#  331 pct_l5_m3_eoc_male_pc                                                                                                        float64
#  332 pct_l5_m3_eoc_neds_pc                                                                                                        float64
#  333 pct_l5_m3_eoc_nswd_pc                                                                                                        float64
#  334 pct_l5_m3_eoc_wh7_pc                                                                                                         float64
#  335 pct_notprof_all_all_bl7_pc                                                                                                   float64
#  336 pct_notprof_all_all_eds_pc                                                                                                   float64
#  337 pct_notprof_all_all_els_pc                                                                                                   float64
#  338 pct_notprof_all_all_fem_pc                                                                                                   float64
#  339 pct_notprof_all_all_hi7_pc                                                                                                   float64
#  340 pct_notprof_all_all_male_pc                                                                                                  float64
#  341 pct_notprof_all_all_mu7_pc                                                                                                   float64
#  342 pct_notprof_all_all_neds_pc                                                                                                  float64
#  343 pct_notprof_all_all_swd_pc                                                                                                   float64
# ...
#  769 lea_name_Nash-Rocky Mount Schools                                                                                            uint8
#  770 lea_name_New Hanover County Schools                                                                                          uint8
#  771 lea_name_Newton-Conover City Schools                                                                                         uint8
#  772 lea_name_Northampton County Schools                                                                                          uint8
#  773 lea_name_Onslow County Schools                                                                                               uint8
#  774 lea_name_Orange County Schools                                                                                               uint8
#  775 lea_name_Pamlico County Schools                                                                                              uint8
#  776 lea_name_Pasquotank County Schools                                                                                           uint8
#  777 lea_name_Pender County Schools                                                                                               uint8
#  778 lea_name_Perquimans County Schools                                                                                           uint8
#  779 lea_name_Person County Schools                                                                                               uint8
#  780 lea_name_Pitt County Schools                                                                                                 uint8
#  781 lea_name_Polk County Schools                                                                                                 uint8
#  782 lea_name_Randolph County Schools                                                                                             uint8
#  783 lea_name_Richmond County Schools                                                                                             uint8
#  784 lea_name_Roanoke Rapids City Schools                                                                                         uint8
#  785 lea_name_Robeson County Schools                                                                                              uint8
#  786 lea_name_Rockingham County Schools                                                                                           uint8
#  787 lea_name_Rowan-Salisbury County Schools                                                                                      uint8
#  788 lea_name_Rutherford County Schools                                                                                           uint8
#  789 lea_name_Sampson County Schools                                                                                              uint8
#  790 lea_name_Scotland County Schools                                                                                             uint8
#  791 lea_name_Stanly County Schools                                                                                               uint8
#  792 lea_name_Stokes County Schools                                                                                               uint8
#  793 lea_name_Surry County Schools                                                                                                uint8
#  794 lea_name_Swain County Schools                                                                                                uint8
#  795 lea_name_Thomasville City Schools                                                                                            uint8
#  796 lea_name_Transylvania County Schools                                                                                         uint8
#  797 lea_name_Tyrrell County Schools                                                                                              uint8
#  798 lea_name_Union County Schools                                                                                                uint8
#  799 lea_name_Vance County Schools                                                                                                uint8
#  800 lea_name_Wake County Schools                                                                                                 uint8
#  801 lea_name_Warren County Schools                                                                                               uint8
#  802 lea_name_Washington County Schools                                                                                           uint8
#  803 lea_name_Watauga County Schools                                                                                              uint8
#  804 lea_name_Wayne County Schools                                                                                                uint8
#  805 lea_name_Weldon City Schools                                                                                                 uint8
#  806 lea_name_Whiteville City Schools                                                                                             uint8
#  807 lea_name_Wilkes County Schools                                                                                               uint8
#  808 lea_name_Wilson County Schools                                                                                               uint8
#  809 lea_name_Yadkin County Schools                                                                                               uint8
#  810 lea_name_Yancey County Schools                                                                                               uint8
#  811 csi_lp_esea_desig_Y                                                                                                          uint8
#  812 csi_lg_esea_desig_Y                                                                                                          uint8
#  813 tsi_cu_esea_desig_Y                                                                                                          uint8
#  814 tsi_at_esea_desig_Y                                                                                                          uint8
#  815 grad_project_gp_Y                                                                                                            uint8
#  816 lp_school_lowperf_Y                                                                                                          uint8
#  817 rlp_school_lowperf_Y                                                                                                         uint8
#  818 target_list_ltg_detail_4 Year Graduation Rate,EL Progress,Math Grade 11,Math Grades 3-8,Reading Grade 10,Reading Grades 3-8  uint8
#  819 target_list_ltg_detail_4 Year Graduation Rate,EL Progress,Math Grade 11,Reading Grade 10                                     uint8
#  820 target_list_ltg_detail_4 Year Graduation Rate,EL Progress,Math Grades 3-8,Reading Grade 10,Reading Grades 3-8                uint8
#  821 target_list_ltg_detail_4 Year Graduation Rate,Math Grade 11                                                                  uint8
#  822 target_list_ltg_detail_4 Year Graduation Rate,Math Grade 11,Math Grades 3-8,Reading Grade 10,Reading Grades 3-8              uint8
#  823 target_list_ltg_detail_4 Year Graduation Rate,Math Grade 11,Math Grades 3-8,Reading Grades 3-8                               uint8
#  824 target_list_ltg_detail_4 Year Graduation Rate,Math Grade 11,Reading Grade 10                                                 uint8
#  825 target_list_ltg_detail_4 Year Graduation Rate,Math Grades 3-8,Reading Grades 3-8                                             uint8
#  826 target_list_ltg_detail_4 Year Graduation Rate,Reading Grade 10                                                               uint8
#  827 target_list_ltg_detail_Math Grade 11                                                                                         uint8
#  828 target_list_ltg_detail_Math Grade 11,Math Grades 3-8,Reading Grades 3-8                                                      uint8
#  829 target_list_ltg_detail_Math Grade 11,Reading Grade 10                                                                        uint8
#  830 target_list_ltg_detail_Math Grades 3-8,Reading Grade 10,Reading Grades 3-8                                                   uint8
#  831 target_list_ltg_detail_Math Grades 3-8,Reading Grades 3-8                                                                    uint8
#  832 target_list_ltg_detail_Reading Grade 10                                                                                      uint8
#  833 subgroup_list_ltg_detail_ALL,AM7,BL7,EDS                                                                                     uint8
#  834 subgroup_list_ltg_detail_ALL,AM7,BL7,EDS,ELS,HI7,MU7,SWD,WH7                                                                 uint8
#  835 subgroup_list_ltg_detail_ALL,AM7,BL7,EDS,HI7                                                                                 uint8
#  836 subgroup_list_ltg_detail_ALL,AM7,BL7,EDS,HI7,MU7,SWD,WH7                                                                     uint8
#  837 subgroup_list_ltg_detail_ALL,AM7,BL7,EDS,HI7,SWD,WH7                                                                         uint8
#  838 subgroup_list_ltg_detail_ALL,AM7,BL7,EDS,SWD                                                                                 uint8
#  839 subgroup_list_ltg_detail_ALL,AM7,BL7,EDS,SWD,WH7                                                                             uint8
#  840 subgroup_list_ltg_detail_ALL,AM7,EDS,WH7                                                                                     uint8
#  841 subgroup_list_ltg_detail_ALL,AS7,BL7,EDS,ELS,HI7,MU7,SWD,WH7                                                                 uint8
#  842 subgroup_list_ltg_detail_ALL,AS7,BL7,EDS,ELS,HI7,SWD                                                                         uint8
#  843 subgroup_list_ltg_detail_ALL,AS7,BL7,EDS,ELS,HI7,SWD,WH7                                                                     uint8
#  844 subgroup_list_ltg_detail_ALL,AS7,BL7,EDS,HI7,SWD,WH7                                                                         uint8
#  845 subgroup_list_ltg_detail_ALL,AS7,BL7,EDS,HI7,WH7                                                                             uint8
#  846 subgroup_list_ltg_detail_ALL,AS7,WH7                                                                                         uint8
#  847 subgroup_list_ltg_detail_ALL,BL7                                                                                             uint8
#  848 subgroup_list_ltg_detail_ALL,BL7,EDS                                                                                         uint8
#  849 subgroup_list_ltg_detail_ALL,BL7,EDS,ELS,HI7                                                                                 uint8
#  850 subgroup_list_ltg_detail_ALL,BL7,EDS,ELS,HI7,SWD                                                                             uint8
#  851 subgroup_list_ltg_detail_ALL,BL7,EDS,ELS,HI7,SWD,WH7                                                                         uint8
#  852 subgroup_list_ltg_detail_ALL,BL7,EDS,ELS,HI7,WH7                                                                             uint8
#  853 subgroup_list_ltg_detail_ALL,BL7,EDS,HI7                                                                                     uint8
#  854 subgroup_list_ltg_detail_ALL,BL7,EDS,HI7,MU7,SWD,WH7                                                                         uint8
#  855 subgroup_list_ltg_detail_ALL,BL7,EDS,HI7,SWD                                                                                 uint8
#  856 subgroup_list_ltg_detail_ALL,BL7,EDS,HI7,SWD,WH7                                                                             uint8
#  857 subgroup_list_ltg_detail_ALL,BL7,EDS,HI7,WH7                                                                                 uint8
#  858 subgroup_list_ltg_detail_ALL,BL7,EDS,SWD                                                                                     uint8
#  859 subgroup_list_ltg_detail_ALL,BL7,EDS,SWD,WH7                                                                                 uint8
#  860 subgroup_list_ltg_detail_ALL,BL7,EDS,WH7                                                                                     uint8
#  861 subgroup_list_ltg_detail_ALL,BL7,SWD                                                                                         uint8
#  862 subgroup_list_ltg_detail_ALL,BL7,WH7                                                                                         uint8
#  863 subgroup_list_ltg_detail_ALL,EDS                                                                                             uint8
#  864 subgroup_list_ltg_detail_ALL,EDS,ELS,HI7                                                                                     uint8
#  865 subgroup_list_ltg_detail_ALL,EDS,ELS,HI7,SWD,WH7                                                                             uint8
#  866 subgroup_list_ltg_detail_ALL,EDS,ELS,HI7,WH7                                                                                 uint8
#  867 subgroup_list_ltg_detail_ALL,EDS,HI7                                                                                         uint8
#  868 subgroup_list_ltg_detail_ALL,EDS,HI7,SWD,WH7                                                                                 uint8
#  869 subgroup_list_ltg_detail_ALL,EDS,HI7,WH7                                                                                     uint8
#  870 subgroup_list_ltg_detail_ALL,EDS,SWD                                                                                         uint8
#  871 subgroup_list_ltg_detail_ALL,EDS,SWD,WH7                                                                                     uint8
#  872 subgroup_list_ltg_detail_ALL,EDS,WH7                                                                                         uint8
#  873 subgroup_list_ltg_detail_ALL,HI7                                                                                             uint8
#  874 subgroup_list_ltg_detail_ALL,HI7,WH7                                                                                         uint8
#  875 subgroup_list_ltg_detail_ALL,SWD                                                                                             uint8
#  876 subgroup_list_ltg_detail_ALL,WH7                                                                                             uint8
#  877 dance_cat_arts_Y                                                                                                             uint8
#  878 music_cat_arts_Y                                                                                                             uint8
#  879 theatre_cat_arts_Y                                                                                                           uint8
#  880 va_cat_arts_Y                                                                                                                uint8
#  881 poverty_eq_LOW                                                                                                               uint8
#  882 poverty_eq_NEITHER                                                                                                           uint8
#  883 agency_code                                                                                                                  object
# dtypes: float64(620), object(1), uint8(263)
# memory usage: 3.2+ MB

# %%
import sklearn
import pandas as pd

print('Sklearn Version: ' + sklearn.__version__)
print('Pandas Version: ' + pd.__version__)
# Out:
# Sklearn Version: 0.22.1
# Pandas Version: 1.0.3

# %%
print('Output File Location:\r\n\r\n' + outputDir + inputFileName + '_ML.csv')
# Out:
# Output File Location:
#
# D:/BenepactLLC/Belk/NC_Report_Card_Data/2020/June 2020/2019/Machine Learning Datasets/PublicHighSchools2019_ML.csv
