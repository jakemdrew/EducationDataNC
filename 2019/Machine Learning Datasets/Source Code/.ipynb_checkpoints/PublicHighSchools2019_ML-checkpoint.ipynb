# %% [markdown]
# # Create Public School Machine Learning Datasets
# ** This program creates all the _ML datasets in the NCEA repository.**
# * This notebook reads each School Dataset file located at \EducationDataNC\ *schoolYear* \School Datasets\ as input data.
# * Different school years are processed by changing the *schoolYear* parameter.
# * Different input / output files are processed / created by changing the *inputFileName* paramter in the cell below.
# * While a single program is used to create all the _ML datasets, one program copy per dataset is maintained in the repositiory so the dataset specific tranformation reports may be reviewed.
#
# **Datasets ending in ML are preprocessed for Machine Learning and go through the following transformations: **
# 1. Missing student body racial compositions are imputed using district averages.
# 2. Columns that have the same value in every single row are deleted.
# 3. Columns that have a unique value in every single row (all values are different) are deleted.
# 4. Empty columns (all values are NA or NULL) are deleted.
# 5. Numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# 6. Remaining numeric, non-race columns with missing values are imputed / populated with 0.  In many cases, schools are not reporting values when they are zero. However, mean imputation or some other more sophisticated strategy might be considered here.
# 7. Categorical / text based columns with > *uniqueThreshold* unique values are deleted.
# 8. All remaining categorical / text based columns are one-hot encoded.  In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# 9. Duplicated or highly similar columns with > 95% correlation are delelted.

# %%
#import required Libraries
import pandas as pd
import numpy as np
import os
import string

#**********************************************************************************
# Set the following variables before running this code!!!
#**********************************************************************************
#All raw data files are processed for the year below
schoolYear = 2019

#Location where copies of the raw data files will be read in from csv files.
dataDir = 'D:/BenepactLLC/Belk/NC_Report_Card_Data/2020/June 2020/' + str(schoolYear) + '/School Datasets/'

#Name of the file to be processed
#inputFileName = 'PublicSchools2019'
inputFileName = 'PublicHighSchools2019'
#inputFileName = 'PublicMiddleSchools2019'
#inputFileName = 'PublicElementarySchools2019'

#Input file being transformed for machine learning 
inputFile = dataDir + inputFileName + '.csv'

#Location where the new school datasets will be created.
outputDir = 'D:/BenepactLLC/Belk/NC_Report_Card_Data/2020/June 2020/' + str(schoolYear) + '/Machine Learning Datasets/'

#Missing Data Threshold (Per Column)
missingThreshold = 0.60

#Unique Value Threshold (Per Column)
#Delete Columns >  uniqueThreshold unique values prior to one-hot encoding. 
#(each unique value becomes a new column during one-hot encoding)
uniqueThreshold = 200

#Read in the School Data File
schoolData = pd.read_csv(inputFile, low_memory=False, dtype={'agency_code': object})
print('*********Start: Beginning Column and Row Counts********************************************')
schoolData.info(verbose=False)

#Select only public schools as charter schools are missing data for many columns.
schoolData = schoolData[(schoolData['designation_type_loc'] == 'P')] #& (schoolData['avg_student_num'] > 0)] -rcd_admin missing

print('\r\n*********After: Selecting Only Public School Campuses**********************************')
schoolData.info(verbose=False)

#Save primary key
agency_code = schoolData['agency_code']
#Convert zip code to string
schoolData['zip_loc'] = schoolData['zip_loc'].astype('object')
# Out:
# *********Start: Beginning Column and Row Counts********************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 716 entries, 0 to 715
# Columns: 4665 entries, agency_code to welcome_url
# dtypes: float64(4618), object(47)
# memory usage: 25.5+ MB
#
# *********After: Selecting Only Public School Campuses**********************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 644 entries, 2 to 715
# Columns: 4665 entries, agency_code to welcome_url
# dtypes: float64(4618), object(47)
# memory usage: 22.9+ MB

# %%
schoolData.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 644 entries, 2 to 715
# Data columns (total 4665 columns):
#  #    Column                                         Dtype
# ---   ------                                         -----
#  0    agency_code                                    object
#  1    category_code_loc                              object
#  2    agency_level_loc                               object
#  3    lea_code_loc                                   object
#  4    designation_type_loc                           object
#  5    name_loc                                       object
#  6    county_loc                                     object
#  7    street_addr_loc                                object
#  8    stree_addr2_loc                                object
#  9    city_loc                                       object
#  10   state_loc                                      object
#  11   zip_loc                                        object
#  12   phone_loc                                      object
#  13   grade_span_loc                                 object
#  14   school_type_loc                                object
#  15   calendar_type_loc                              object
#  16   url_loc                                        object
#  17   super_name_loc                                 object
#  18   title_i_loc                                    object
#  19   esea_loc                                       float64
#  20   stem_loc                                       object
#  21   purple_star_loc                                object
#  22   lea                                            float64
#  23   lea_name                                       object
#  24   school                                         float64
#  25   school_name                                    object
#  26   indian_pct                                     float64
#  27   asian_pct                                      float64
#  28   hispanic_pct                                   float64
#  29   black_pct                                      float64
#  30   white_pct                                      float64
#  31   pacific_island_pct                             float64
#  32   two_or_more_pct                                float64
#  33   minority_pct                                   float64
#  34   indian_male_pct                                float64
#  35   asian_male_pct                                 float64
#  36   hispanic_male_pct                              float64
#  37   black_male_pct                                 float64
#  38   white_male_pct                                 float64
#  39   pacific_island_male_pct                        float64
#  40   two_or_more_male_pct                           float64
#  41   minority_male_pct                              float64
#  42   indian_female_pct                              float64
#  43   asian_female_pct                               float64
#  44   hispanic_female_pct                            float64
#  45   black_female_pct                               float64
#  46   white_female_pct                               float64
#  47   minority_female_pct                            float64
#  48   pacific_island_female_pct                      float64
#  49   two_or_more_female_pct                         float64
#  50   lea_no_attendance                              float64
#  51   lea_name_attendance                            object
#  52   school_no_attendance                           float64
#  53   school_name_attendance                         object
#  54   grade_span_attendance                          object
#  55   ada_ct_2017_attendance                         object
#  56   adm_ct_2017_attendance                         object
#  57   ada_adm_ratio_2018_attendance                  float64
#  58   ada_ct_2018_attendance                         object
#  59   adm_ct_2018_attendance                         object
#  60   ada_adm_ratio_2018.1_attendance                float64
#  61   ada_ct_2019_attendance                         object
#  62   adm_ct_2019_attendance                         object
#  63   ada_adm_ratio_2019_attendance                  float64
#  64   ada_adm_ratio_2017_thru_2019_attendance        float64
#  65   ada_adm_rank_2017_thru_2019_attendance         float64
#  66   pct_ma_03_aapart                               float64
#  67   pct_ma_04_aapart                               float64
#  68   pct_ma_05_aapart                               float64
#  69   pct_ma_06_aapart                               float64
#  70   pct_ma_07_aapart                               float64
#  71   pct_ma_08_aapart                               float64
#  72   pct_ma_gs_aapart                               float64
#  73   pct_ma_hs_aapart                               float64
#  74   pct_rd_03_aapart                               float64
#  75   pct_rd_04_aapart                               float64
#  76   pct_rd_05_aapart                               float64
#  77   pct_rd_06_aapart                               float64
#  78   pct_rd_07_aapart                               float64
#  79   pct_rd_08_aapart                               float64
#  80   pct_rd_gs_aapart                               float64
#  81   pct_rd_hs_aapart                               float64
#  82   pct_sc_05_aapart                               float64
#  83   pct_sc_08_aapart                               float64
#  84   pct_sc_gs_aapart                               float64
#  85   pct_sc_hs_aapart                               float64
#  86   pct_acall_aig_act                              float64
#  87   pct_acall_all_act                              float64
#  88   pct_acall_am7_act                              float64
#  89   pct_acall_as7_act                              float64
#  90   pct_acall_bl7_act                              float64
#  91   pct_acall_eds_act                              float64
#  92   pct_acall_els_act                              float64
#  93   pct_acall_fcs_act                              float64
#  94   pct_acall_fem_act                              float64
#  95   pct_acall_hi7_act                              float64
#  96   pct_acall_hms_act                              float64
#  97   pct_acall_male_act                             float64
#  98   pct_acall_mig_act                              float64
#  99   pct_acall_mil_act                              float64
#  100  pct_acall_mu7_act                              float64
#  101  pct_acall_neds_act                             float64
#  102  pct_acall_nswd_act                             float64
#  103  pct_acall_swd_act                              float64
#  104  pct_acall_wh7_act                              float64
#  105  pct_acco_aig_act                               float64
#  106  pct_acco_all_act                               float64
#  107  pct_acco_am7_act                               float64
#  108  pct_acco_as7_act                               float64
#  109  pct_acco_bl7_act                               float64
#  110  pct_acco_eds_act                               float64
#  111  pct_acco_els_act                               float64
#  112  pct_acco_fem_act                               float64
#  113  pct_acco_hi7_act                               float64
#  114  pct_acco_hms_act                               float64
#  115  pct_acco_male_act                              float64
#  116  pct_acco_mil_act                               float64
#  117  pct_acco_mu7_act                               float64
#  118  pct_acco_neds_act                              float64
#  119  pct_acco_nswd_act                              float64
#  120  pct_acco_swd_act                               float64
#  121  pct_acco_wh7_act                               float64
#  122  pct_acen_aig_act                               float64
#  123  pct_acen_all_act                               float64
#  124  pct_acen_am7_act                               float64
#  125  pct_acen_as7_act                               float64
#  126  pct_acen_bl7_act                               float64
#  127  pct_acen_eds_act                               float64
#  128  pct_acen_els_act                               float64
#  129  pct_acen_fem_act                               float64
#  130  pct_acen_hi7_act                               float64
#  131  pct_acen_hms_act                               float64
#  132  pct_acen_male_act                              float64
#  133  pct_acen_mil_act                               float64
#  134  pct_acen_mu7_act                               float64
#  135  pct_acen_neds_act                              float64
#  136  pct_acen_nswd_act                              float64
#  137  pct_acen_swd_act                               float64
#  138  pct_acen_wh7_act                               float64
#  139  pct_acma_aig_act                               float64
#  140  pct_acma_all_act                               float64
#  141  pct_acma_am7_act                               float64
#  142  pct_acma_as7_act                               float64
#  143  pct_acma_bl7_act                               float64
#  144  pct_acma_eds_act                               float64
#  145  pct_acma_els_act                               float64
#  146  pct_acma_fem_act                               float64
#  147  pct_acma_hi7_act                               float64
#  148  pct_acma_hms_act                               float64
#  149  pct_acma_male_act                              float64
#  150  pct_acma_mil_act                               float64
#  151  pct_acma_mu7_act                               float64
#  152  pct_acma_neds_act                              float64
#  153  pct_acma_nswd_act                              float64
#  154  pct_acma_swd_act                               float64
#  155  pct_acma_wh7_act                               float64
#  156  pct_acrd_aig_act                               float64
#  157  pct_acrd_all_act                               float64
#  158  pct_acrd_am7_act                               float64
#  159  pct_acrd_as7_act                               float64
#  160  pct_acrd_bl7_act                               float64
#  161  pct_acrd_eds_act                               float64
#  162  pct_acrd_els_act                               float64
#  163  pct_acrd_fem_act                               float64
#  164  pct_acrd_hi7_act                               float64
#  165  pct_acrd_hms_act                               float64
#  166  pct_acrd_male_act                              float64
#  167  pct_acrd_mil_act                               float64
#  168  pct_acrd_mu7_act                               float64
#  169  pct_acrd_neds_act                              float64
#  170  pct_acrd_nswd_act                              float64
#  171  pct_acrd_swd_act                               float64
#  172  pct_acrd_wh7_act                               float64
#  173  pct_acsc_aig_act                               float64
#  174  pct_acsc_all_act                               float64
#  175  pct_acsc_am7_act                               float64
#  176  pct_acsc_as7_act                               float64
#  177  pct_acsc_bl7_act                               float64
#  178  pct_acsc_eds_act                               float64
#  179  pct_acsc_els_act                               float64
#  180  pct_acsc_fem_act                               float64
#  181  pct_acsc_hi7_act                               float64
#  182  pct_acsc_hms_act                               float64
#  183  pct_acsc_male_act                              float64
#  184  pct_acsc_mil_act                               float64
#  185  pct_acsc_mu7_act                               float64
#  186  pct_acsc_neds_act                              float64
#  187  pct_acsc_nswd_act                              float64
#  188  pct_acsc_swd_act                               float64
#  189  pct_acsc_wh7_act                               float64
#  190  pct_acwr_aig_act                               float64
#  191  pct_acwr_all_act                               float64
#  192  pct_acwr_am7_act                               float64
#  193  pct_acwr_as7_act                               float64
#  194  pct_acwr_bl7_act                               float64
#  195  pct_acwr_eds_act                               float64
#  196  pct_acwr_els_act                               float64
#  197  pct_acwr_fem_act                               float64
#  198  pct_acwr_hi7_act                               float64
#  199  pct_acwr_hms_act                               float64
#  200  pct_acwr_male_act                              float64
#  201  pct_acwr_mil_act                               float64
#  202  pct_acwr_mu7_act                               float64
#  203  pct_acwr_neds_act                              float64
#  204  pct_acwr_nswd_act                              float64
#  205  pct_acwr_swd_act                               float64
#  206  pct_acwr_wh7_act                               float64
#  207  pct_aig_awa                                    float64
#  208  pct_all_awa                                    float64
#  209  pct_am7_awa                                    float64
#  210  pct_as7_awa                                    float64
#  211  pct_bl7_awa                                    float64
#  212  pct_eds_awa                                    float64
#  213  pct_els_awa                                    float64
#  214  pct_fem_awa                                    float64
#  215  pct_hi7_awa                                    float64
#  216  pct_hms_awa                                    float64
#  217  pct_male_awa                                   float64
#  218  pct_mig_awa                                    float64
#  219  pct_mil_awa                                    float64
#  220  pct_mu7_awa                                    float64
#  221  pct_neds_awa                                   float64
#  222  pct_nswd_awa                                   float64
#  223  pct_swd_awa                                    float64
#  224  pct_wh7_awa                                    float64
#  225  pct_ext_aig_cgr                                float64
#  226  pct_ext_all_cgr                                float64
#  227  pct_ext_am7_cgr                                float64
#  228  pct_ext_as7_cgr                                float64
#  229  pct_ext_bl7_cgr                                float64
#  230  pct_ext_eds_cgr                                float64
#  231  pct_ext_els_cgr                                float64
#  232  pct_ext_fem_cgr                                float64
#  233  pct_ext_hi7_cgr                                float64
#  234  pct_ext_hms_cgr                                float64
#  235  pct_ext_male_cgr                               float64
#  236  pct_ext_mig_cgr                                float64
#  237  pct_ext_mu7_cgr                                float64
#  238  pct_ext_neds_cgr                               float64
#  239  pct_ext_nswd_cgr                               float64
#  240  pct_ext_swd_cgr                                float64
#  241  pct_ext_wh7_cgr                                float64
#  242  pct_std_aig_cgr                                float64
#  243  pct_std_all_cgr                                float64
#  244  pct_std_am7_cgr                                float64
#  245  pct_std_as7_cgr                                float64
#  246  pct_std_bl7_cgr                                float64
#  247  pct_std_eds_cgr                                float64
#  248  pct_std_els_cgr                                float64
#  249  pct_std_fcs_cgr                                float64
#  250  pct_std_fem_cgr                                float64
#  251  pct_std_hi7_cgr                                float64
#  252  pct_std_hms_cgr                                float64
#  253  pct_std_male_cgr                               float64
#  254  pct_std_mig_cgr                                float64
#  255  pct_std_mu7_cgr                                float64
#  256  pct_std_neds_cgr                               float64
#  257  pct_std_nswd_cgr                               float64
#  258  pct_std_swd_cgr                                float64
#  259  pct_std_wh7_cgr                                float64
#  260  pct_eds                                        float64
#  261  eg_index_all_aig_eg                            float64
#  262  eg_index_all_all_eg                            float64
#  263  eg_index_all_am7_eg                            float64
#  264  eg_index_all_as7_eg                            float64
#  265  eg_index_all_bl7_eg                            float64
#  266  eg_index_all_eds_eg                            float64
#  267  eg_index_all_els_eg                            float64
#  268  eg_index_all_hi7_eg                            float64
#  269  eg_index_all_mu7_eg                            float64
#  270  eg_index_all_swd_eg                            float64
#  271  eg_index_all_wh7_eg                            float64
#  272  eg_index_ma_all_eg                             float64
#  273  eg_index_rd_all_eg                             float64
#  274  eg_score_all_aig_eg                            float64
#  275  eg_score_all_all_eg                            float64
#  276  eg_score_all_am7_eg                            float64
#  277  eg_score_all_as7_eg                            float64
#  278  eg_score_all_bl7_eg                            float64
#  279  eg_score_all_eds_eg                            float64
#  280  eg_score_all_els_eg                            float64
#  281  eg_score_all_hi7_eg                            float64
#  282  eg_score_all_mu7_eg                            float64
#  283  eg_score_all_swd_eg                            float64
#  284  eg_score_all_wh7_eg                            float64
#  285  eg_score_ma_all_eg                             float64
#  286  eg_score_rd_all_eg                             float64
#  287  den_aig_elp                                    float64
#  288  den_all_elp                                    float64
#  289  den_as7_elp                                    float64
#  290  den_bl7_elp                                    float64
#  291  den_eds_elp                                    float64
#  292  den_els_elp                                    float64
#  293  den_fem_elp                                    float64
#  294  den_hi7_elp                                    float64
#  295  den_hms_elp                                    float64
#  296  den_male_elp                                   float64
#  297  den_mig_elp                                    float64
#  298  den_mil_elp                                    float64
#  299  den_neds_elp                                   float64
#  300  den_nswd_elp                                   float64
#  301  den_swd_elp                                    float64
#  302  den_wh7_elp                                    float64
#  303  pct_aig_elp                                    float64
#  304  pct_all_elp                                    float64
#  305  pct_as7_elp                                    float64
#  306  pct_bl7_elp                                    float64
#  307  pct_eds_elp                                    float64
#  308  pct_els_elp                                    float64
#  309  pct_fem_elp                                    float64
#  310  pct_hi7_elp                                    float64
#  311  pct_hms_elp                                    float64
#  312  pct_male_elp                                   float64
#  313  pct_mig_elp                                    float64
#  314  pct_mil_elp                                    float64
#  315  pct_neds_elp                                   float64
#  316  pct_nswd_elp                                   float64
#  317  pct_swd_elp                                    float64
#  318  pct_wh7_elp                                    float64
#  319  csi_lp_esea_desig                              object
#  320  csi_lg_esea_desig                              object
#  321  tsi_cu_esea_desig                              object
#  322  tsi_at_esea_desig                              object
#  323  grad_project_gp                                object
#  324  pct_prof_6gr_irm                               float64
#  325  pct_prof_9gr_irm                               float64
#  326  lp_school_lowperf                              object
#  327  rlp_school_lowperf                             object
#  328  clpc_school_lowperf                            object
#  329  pct_met_4_year_graduation_rate_ltg             float64
#  330  pct_met_el_progress_ltg                        float64
#  331  pct_met_math_grade_11_ltg                      float64
#  332  pct_met_math_grades_3-8_ltg                    float64
#  333  pct_met_reading_grade_10_ltg                   float64
#  334  pct_met_reading_grades_3-8_ltg                 float64
#  335  pct_met_total_targets_ltg                      float64
#  336  target_assign_4_year_graduation_rate_ltg       float64
#  337  target_assign_el_progress_ltg                  float64
#  338  target_assign_math_grade_11_ltg                float64
#  339  target_assign_math_grades_3-8_ltg              float64
#  340  target_assign_reading_grade_10_ltg             float64
#  341  target_assign_reading_grades_3-8_ltg           float64
#  342  target_assign_total_targets_ltg                float64
#  343  target_met_4_year_graduation_rate_ltg          float64
#  344  target_met_el_progress_ltg                     float64
#  345  target_met_math_grade_11_ltg                   float64
#  346  target_met_math_grades_3-8_ltg                 float64
#  347  target_met_reading_grade_10_ltg                float64
#  348  target_met_reading_grades_3-8_ltg              float64
#  349  target_met_total_targets_ltg                   float64
#  350  target_list_ltg_detail                         object
#  351  subgroup_list_ltg_detail                       object
#  352  pct_aig_mcr                                    float64
#  353  pct_all_mcr                                    float64
#  354  pct_am7_mcr                                    float64
#  355  pct_as7_mcr                                    float64
#  356  pct_bl7_mcr                                    float64
#  357  pct_eds_mcr                                    float64
#  358  pct_els_mcr                                    float64
#  359  pct_fem_mcr                                    float64
#  360  pct_hi7_mcr                                    float64
#  361  pct_hms_mcr                                    float64
#  362  pct_male_mcr                                   float64
#  363  pct_mig_mcr                                    float64
#  364  pct_mil_mcr                                    float64
#  365  pct_mu7_mcr                                    float64
#  366  pct_neds_mcr                                   float64
#  367  pct_nswd_mcr                                   float64
#  368  pct_swd_mcr                                    float64
#  369  pct_wh7_mcr                                    float64
#  370  pct_met_act_workkeys_part                      float64
#  371  pct_met_biology_part                           float64
#  372  pct_met_english_ii_part                        float64
#  373  pct_met_high_school_math_part                  float64
#  374  pct_met_math_grades_3-8_part                   float64
#  375  pct_met_reading_grades_3-8_part                float64
#  376  pct_met_science_grades_5&8_part                float64
#  377  pct_met_the_act_part                           float64
#  378  pct_met_total_targets_part                     float64
#  379  target_assign_act_workkeys_part                float64
#  380  target_assign_biology_part                     float64
#  381  target_assign_english_ii_part                  float64
#  382  target_assign_high_school_math_part            float64
#  383  target_assign_math_grades_3-8_part             float64
#  384  target_assign_reading_grades_3-8_part          float64
#  385  target_assign_science_grades_5&8_part          float64
#  386  target_assign_the_act_part                     float64
#  387  target_assign_total_targets_part               float64
#  388  target_met_act_workkeys_part                   float64
#  389  target_met_biology_part                        float64
#  390  target_met_english_ii_part                     float64
#  391  target_met_high_school_math_part               float64
#  392  target_met_math_grades_3-8_part                float64
#  393  target_met_reading_grades_3-8_part             float64
#  394  target_met_science_grades_5&8_part             float64
#  395  target_met_the_act_part                        float64
#  396  target_met_total_targets_part                  float64
#  397  pct_act_workkeys_all_part_det                  float64
#  398  pct_act_workkeys_am7_part_det                  float64
#  399  pct_act_workkeys_as7_part_det                  float64
#  400  pct_act_workkeys_bl7_part_det                  float64
#  401  pct_act_workkeys_eds_part_det                  float64
#  402  pct_act_workkeys_hi7_part_det                  float64
#  403  pct_act_workkeys_wh7_part_det                  float64
#  404  pct_biology_all_part_det                       float64
#  405  pct_biology_am7_part_det                       float64
#  406  pct_biology_as7_part_det                       float64
#  407  pct_biology_bl7_part_det                       float64
#  408  pct_biology_eds_part_det                       float64
#  409  pct_biology_els_part_det                       float64
#  410  pct_biology_hi7_part_det                       float64
#  411  pct_biology_mu7_part_det                       float64
#  412  pct_biology_swd_part_det                       float64
#  413  pct_biology_wh7_part_det                       float64
#  414  pct_english_ii_all_part_det                    float64
#  415  pct_english_ii_am7_part_det                    float64
#  416  pct_english_ii_as7_part_det                    float64
#  417  pct_english_ii_bl7_part_det                    float64
#  418  pct_english_ii_eds_part_det                    float64
#  419  pct_english_ii_els_part_det                    float64
#  420  pct_english_ii_hi7_part_det                    float64
#  421  pct_english_ii_mu7_part_det                    float64
#  422  pct_english_ii_swd_part_det                    float64
#  423  pct_english_ii_wh7_part_det                    float64
#  424  pct_high_school_math_all_part_det              float64
#  425  pct_high_school_math_am7_part_det              float64
#  426  pct_high_school_math_as7_part_det              float64
#  427  pct_high_school_math_bl7_part_det              float64
#  428  pct_high_school_math_eds_part_det              float64
#  429  pct_high_school_math_els_part_det              float64
#  430  pct_high_school_math_hi7_part_det              float64
#  431  pct_high_school_math_mu7_part_det              float64
#  432  pct_high_school_math_swd_part_det              float64
#  433  pct_high_school_math_wh7_part_det              float64
#  434  pct_math_grades_3-8_all_part_det               float64
#  435  pct_math_grades_3-8_am7_part_det               float64
#  436  pct_math_grades_3-8_as7_part_det               float64
#  437  pct_math_grades_3-8_bl7_part_det               float64
#  438  pct_math_grades_3-8_eds_part_det               float64
#  439  pct_math_grades_3-8_els_part_det               float64
#  440  pct_math_grades_3-8_hi7_part_det               float64
#  441  pct_math_grades_3-8_mu7_part_det               float64
#  442  pct_math_grades_3-8_swd_part_det               float64
#  443  pct_math_grades_3-8_wh7_part_det               float64
#  444  pct_reading_grades_3-8_all_part_det            float64
#  445  pct_reading_grades_3-8_am7_part_det            float64
#  446  pct_reading_grades_3-8_as7_part_det            float64
#  447  pct_reading_grades_3-8_bl7_part_det            float64
#  448  pct_reading_grades_3-8_eds_part_det            float64
#  449  pct_reading_grades_3-8_els_part_det            float64
#  450  pct_reading_grades_3-8_hi7_part_det            float64
#  451  pct_reading_grades_3-8_mu7_part_det            float64
#  452  pct_reading_grades_3-8_swd_part_det            float64
#  453  pct_reading_grades_3-8_wh7_part_det            float64
#  454  pct_science_grades_5&8_all_part_det            float64
#  455  pct_science_grades_5&8_am7_part_det            float64
#  456  pct_science_grades_5&8_as7_part_det            float64
#  457  pct_science_grades_5&8_bl7_part_det            float64
#  458  pct_science_grades_5&8_eds_part_det            float64
#  459  pct_science_grades_5&8_els_part_det            float64
#  460  pct_science_grades_5&8_hi7_part_det            float64
#  461  pct_science_grades_5&8_mu7_part_det            float64
#  462  pct_science_grades_5&8_swd_part_det            float64
#  463  pct_science_grades_5&8_wh7_part_det            float64
#  464  pct_the_act_all_part_det                       float64
#  465  pct_the_act_am7_part_det                       float64
#  466  pct_the_act_as7_part_det                       float64
#  467  pct_the_act_bl7_part_det                       float64
#  468  pct_the_act_eds_part_det                       float64
#  469  pct_the_act_els_part_det                       float64
#  470  pct_the_act_hi7_part_det                       float64
#  471  pct_the_act_mu7_part_det                       float64
#  472  pct_the_act_swd_part_det                       float64
#  473  pct_the_act_wh7_part_det                       float64
#  474  pct_ccr_bi_eoc_aig_pc                          float64
#  475  pct_ccr_bi_eoc_all_pc                          float64
#  476  pct_ccr_bi_eoc_am7_pc                          float64
#  477  pct_ccr_bi_eoc_as7_pc                          float64
#  478  pct_ccr_bi_eoc_bl7_pc                          float64
#  479  pct_ccr_bi_eoc_eds_pc                          float64
#  480  pct_ccr_bi_eoc_els_pc                          float64
#  481  pct_ccr_bi_eoc_fcs_pc                          float64
#  482  pct_ccr_bi_eoc_fem_pc                          float64
#  483  pct_ccr_bi_eoc_hi7_pc                          float64
#  484  pct_ccr_bi_eoc_hms_pc                          float64
#  485  pct_ccr_bi_eoc_male_pc                         float64
#  486  pct_ccr_bi_eoc_mig_pc                          float64
#  487  pct_ccr_bi_eoc_mil_pc                          float64
#  488  pct_ccr_bi_eoc_mu7_pc                          float64
#  489  pct_ccr_bi_eoc_neds_pc                         float64
#  490  pct_ccr_bi_eoc_nswd_pc                         float64
#  491  pct_ccr_bi_eoc_swd_pc                          float64
#  492  pct_ccr_bi_eoc_wh7_pc                          float64
#  493  pct_ccr_e2_eoc_aig_pc                          float64
#  494  pct_ccr_e2_eoc_all_pc                          float64
#  495  pct_ccr_e2_eoc_am7_pc                          float64
#  496  pct_ccr_e2_eoc_as7_pc                          float64
#  497  pct_ccr_e2_eoc_bl7_pc                          float64
#  498  pct_ccr_e2_eoc_eds_pc                          float64
#  499  pct_ccr_e2_eoc_els_pc                          float64
#  500  pct_ccr_e2_eoc_fem_pc                          float64
#  501  pct_ccr_e2_eoc_hi7_pc                          float64
#  502  pct_ccr_e2_eoc_hms_pc                          float64
#  503  pct_ccr_e2_eoc_male_pc                         float64
#  504  pct_ccr_e2_eoc_mig_pc                          float64
#  505  pct_ccr_e2_eoc_mil_pc                          float64
#  506  pct_ccr_e2_eoc_mu7_pc                          float64
#  507  pct_ccr_e2_eoc_neds_pc                         float64
#  508  pct_ccr_e2_eoc_nswd_pc                         float64
#  509  pct_ccr_e2_eoc_swd_pc                          float64
#  510  pct_ccr_e2_eoc_wh7_pc                          float64
#  511  pct_ccr_eoc_eoc_aig_pc                         float64
#  512  pct_ccr_eoc_eoc_all_pc                         float64
#  513  pct_ccr_eoc_eoc_am7_pc                         float64
#  514  pct_ccr_eoc_eoc_as7_pc                         float64
#  515  pct_ccr_eoc_eoc_bl7_pc                         float64
#  516  pct_ccr_eoc_eoc_eds_pc                         float64
#  517  pct_ccr_eoc_eoc_els_pc                         float64
#  518  pct_ccr_eoc_eoc_fcs_pc                         float64
#  519  pct_ccr_eoc_eoc_fem_pc                         float64
#  520  pct_ccr_eoc_eoc_hi7_pc                         float64
#  521  pct_ccr_eoc_eoc_hms_pc                         float64
#  522  pct_ccr_eoc_eoc_male_pc                        float64
#  523  pct_ccr_eoc_eoc_mig_pc                         float64
#  524  pct_ccr_eoc_eoc_mil_pc                         float64
#  525  pct_ccr_eoc_eoc_mu7_pc                         float64
#  526  pct_ccr_eoc_eoc_neds_pc                        float64
#  527  pct_ccr_eoc_eoc_nswd_pc                        float64
#  528  pct_ccr_eoc_eoc_swd_pc                         float64
#  529  pct_ccr_eoc_eoc_wh7_pc                         float64
#  530  pct_ccr_eog_03_aig_pc                          float64
#  531  pct_ccr_eog_03_all_pc                          float64
#  532  pct_ccr_eog_03_am7_pc                          float64
#  533  pct_ccr_eog_03_as7_pc                          float64
#  534  pct_ccr_eog_03_bl7_pc                          float64
#  535  pct_ccr_eog_03_eds_pc                          float64
#  536  pct_ccr_eog_03_els_pc                          float64
#  537  pct_ccr_eog_03_fcs_pc                          float64
#  538  pct_ccr_eog_03_fem_pc                          float64
#  539  pct_ccr_eog_03_hi7_pc                          float64
#  540  pct_ccr_eog_03_hms_pc                          float64
#  541  pct_ccr_eog_03_male_pc                         float64
#  542  pct_ccr_eog_03_mig_pc                          float64
#  543  pct_ccr_eog_03_mil_pc                          float64
#  544  pct_ccr_eog_03_mu7_pc                          float64
#  545  pct_ccr_eog_03_neds_pc                         float64
#  546  pct_ccr_eog_03_nswd_pc                         float64
#  547  pct_ccr_eog_03_swd_pc                          float64
#  548  pct_ccr_eog_03_wh7_pc                          float64
#  549  pct_ccr_eog_04_aig_pc                          float64
#  550  pct_ccr_eog_04_all_pc                          float64
#  551  pct_ccr_eog_04_am7_pc                          float64
#  552  pct_ccr_eog_04_as7_pc                          float64
#  553  pct_ccr_eog_04_bl7_pc                          float64
#  554  pct_ccr_eog_04_eds_pc                          float64
#  555  pct_ccr_eog_04_els_pc                          float64
#  556  pct_ccr_eog_04_fcs_pc                          float64
#  557  pct_ccr_eog_04_fem_pc                          float64
#  558  pct_ccr_eog_04_hi7_pc                          float64
#  559  pct_ccr_eog_04_hms_pc                          float64
#  560  pct_ccr_eog_04_male_pc                         float64
#  561  pct_ccr_eog_04_mig_pc                          float64
#  562  pct_ccr_eog_04_mil_pc                          float64
#  563  pct_ccr_eog_04_mu7_pc                          float64
#  564  pct_ccr_eog_04_neds_pc                         float64
#  565  pct_ccr_eog_04_nswd_pc                         float64
#  566  pct_ccr_eog_04_swd_pc                          float64
#  567  pct_ccr_eog_04_wh7_pc                          float64
#  568  pct_ccr_eog_05_aig_pc                          float64
#  569  pct_ccr_eog_05_all_pc                          float64
#  570  pct_ccr_eog_05_am7_pc                          float64
#  571  pct_ccr_eog_05_as7_pc                          float64
#  572  pct_ccr_eog_05_bl7_pc                          float64
#  573  pct_ccr_eog_05_eds_pc                          float64
#  574  pct_ccr_eog_05_els_pc                          float64
#  575  pct_ccr_eog_05_fcs_pc                          float64
#  576  pct_ccr_eog_05_fem_pc                          float64
#  577  pct_ccr_eog_05_hi7_pc                          float64
#  578  pct_ccr_eog_05_hms_pc                          float64
#  579  pct_ccr_eog_05_male_pc                         float64
#  580  pct_ccr_eog_05_mig_pc                          float64
#  581  pct_ccr_eog_05_mil_pc                          float64
#  582  pct_ccr_eog_05_mu7_pc                          float64
#  583  pct_ccr_eog_05_neds_pc                         float64
#  584  pct_ccr_eog_05_nswd_pc                         float64
#  585  pct_ccr_eog_05_swd_pc                          float64
#  586  pct_ccr_eog_05_wh7_pc                          float64
#  587  pct_ccr_eog_06_aig_pc                          float64
#  588  pct_ccr_eog_06_all_pc                          float64
#  589  pct_ccr_eog_06_am7_pc                          float64
#  590  pct_ccr_eog_06_as7_pc                          float64
#  591  pct_ccr_eog_06_bl7_pc                          float64
#  592  pct_ccr_eog_06_eds_pc                          float64
#  593  pct_ccr_eog_06_els_pc                          float64
#  594  pct_ccr_eog_06_fcs_pc                          float64
#  595  pct_ccr_eog_06_fem_pc                          float64
#  596  pct_ccr_eog_06_hi7_pc                          float64
#  597  pct_ccr_eog_06_hms_pc                          float64
#  598  pct_ccr_eog_06_male_pc                         float64
#  599  pct_ccr_eog_06_mig_pc                          float64
#  600  pct_ccr_eog_06_mil_pc                          float64
#  601  pct_ccr_eog_06_mu7_pc                          float64
#  602  pct_ccr_eog_06_neds_pc                         float64
#  603  pct_ccr_eog_06_nswd_pc                         float64
#  604  pct_ccr_eog_06_swd_pc                          float64
#  605  pct_ccr_eog_06_wh7_pc                          float64
#  606  pct_ccr_eog_07_aig_pc                          float64
#  607  pct_ccr_eog_07_all_pc                          float64
#  608  pct_ccr_eog_07_am7_pc                          float64
#  609  pct_ccr_eog_07_as7_pc                          float64
#  610  pct_ccr_eog_07_bl7_pc                          float64
#  611  pct_ccr_eog_07_eds_pc                          float64
#  612  pct_ccr_eog_07_els_pc                          float64
#  613  pct_ccr_eog_07_fcs_pc                          float64
#  614  pct_ccr_eog_07_fem_pc                          float64
#  615  pct_ccr_eog_07_hi7_pc                          float64
#  616  pct_ccr_eog_07_hms_pc                          float64
#  617  pct_ccr_eog_07_male_pc                         float64
#  618  pct_ccr_eog_07_mig_pc                          float64
#  619  pct_ccr_eog_07_mil_pc                          float64
#  620  pct_ccr_eog_07_mu7_pc                          float64
#  621  pct_ccr_eog_07_neds_pc                         float64
#  622  pct_ccr_eog_07_nswd_pc                         float64
#  623  pct_ccr_eog_07_swd_pc                          float64
#  624  pct_ccr_eog_07_wh7_pc                          float64
#  625  pct_ccr_eog_08_aig_pc                          float64
#  626  pct_ccr_eog_08_all_pc                          float64
#  627  pct_ccr_eog_08_am7_pc                          float64
#  628  pct_ccr_eog_08_as7_pc                          float64
#  629  pct_ccr_eog_08_bl7_pc                          float64
#  630  pct_ccr_eog_08_eds_pc                          float64
#  631  pct_ccr_eog_08_els_pc                          float64
#  632  pct_ccr_eog_08_fcs_pc                          float64
#  633  pct_ccr_eog_08_fem_pc                          float64
#  634  pct_ccr_eog_08_hi7_pc                          float64
#  635  pct_ccr_eog_08_hms_pc                          float64
#  636  pct_ccr_eog_08_male_pc                         float64
#  637  pct_ccr_eog_08_mig_pc                          float64
#  638  pct_ccr_eog_08_mil_pc                          float64
#  639  pct_ccr_eog_08_mu7_pc                          float64
#  640  pct_ccr_eog_08_neds_pc                         float64
#  641  pct_ccr_eog_08_nswd_pc                         float64
#  642  pct_ccr_eog_08_swd_pc                          float64
#  643  pct_ccr_eog_08_wh7_pc                          float64
#  644  pct_ccr_eog_all_aig_pc                         float64
#  645  pct_ccr_eog_all_all_pc                         float64
#  646  pct_ccr_eog_all_am7_pc                         float64
#  647  pct_ccr_eog_all_as7_pc                         float64
#  648  pct_ccr_eog_all_bl7_pc                         float64
#  649  pct_ccr_eog_all_eds_pc                         float64
#  650  pct_ccr_eog_all_els_pc                         float64
#  651  pct_ccr_eog_all_fcs_pc                         float64
#  652  pct_ccr_eog_all_fem_pc                         float64
#  653  pct_ccr_eog_all_hi7_pc                         float64
#  654  pct_ccr_eog_all_hms_pc                         float64
#  655  pct_ccr_eog_all_male_pc                        float64
#  656  pct_ccr_eog_all_mig_pc                         float64
#  657  pct_ccr_eog_all_mil_pc                         float64
#  658  pct_ccr_eog_all_mu7_pc                         float64
#  659  pct_ccr_eog_all_neds_pc                        float64
#  660  pct_ccr_eog_all_nswd_pc                        float64
#  661  pct_ccr_eog_all_swd_pc                         float64
#  662  pct_ccr_eog_all_wh7_pc                         float64
#  663  pct_ccr_m1_eoc_aig_pc                          float64
#  664  pct_ccr_m1_eoc_all_pc                          float64
#  665  pct_ccr_m1_eoc_am7_pc                          float64
#  666  pct_ccr_m1_eoc_as7_pc                          float64
#  667  pct_ccr_m1_eoc_bl7_pc                          float64
#  668  pct_ccr_m1_eoc_eds_pc                          float64
#  669  pct_ccr_m1_eoc_els_pc                          float64
#  670  pct_ccr_m1_eoc_fem_pc                          float64
#  671  pct_ccr_m1_eoc_hi7_pc                          float64
#  672  pct_ccr_m1_eoc_hms_pc                          float64
#  673  pct_ccr_m1_eoc_male_pc                         float64
#  674  pct_ccr_m1_eoc_mig_pc                          float64
#  675  pct_ccr_m1_eoc_mil_pc                          float64
#  676  pct_ccr_m1_eoc_mu7_pc                          float64
#  677  pct_ccr_m1_eoc_neds_pc                         float64
#  678  pct_ccr_m1_eoc_nswd_pc                         float64
#  679  pct_ccr_m1_eoc_swd_pc                          float64
#  680  pct_ccr_m1_eoc_wh7_pc                          float64
#  681  pct_ccr_m3_eoc_aig_pc                          float64
#  682  pct_ccr_m3_eoc_all_pc                          float64
#  683  pct_ccr_m3_eoc_am7_pc                          float64
#  684  pct_ccr_m3_eoc_as7_pc                          float64
#  685  pct_ccr_m3_eoc_bl7_pc                          float64
#  686  pct_ccr_m3_eoc_eds_pc                          float64
#  687  pct_ccr_m3_eoc_els_pc                          float64
#  688  pct_ccr_m3_eoc_fem_pc                          float64
#  689  pct_ccr_m3_eoc_hi7_pc                          float64
#  690  pct_ccr_m3_eoc_hms_pc                          float64
#  691  pct_ccr_m3_eoc_male_pc                         float64
#  692  pct_ccr_m3_eoc_mig_pc                          float64
#  693  pct_ccr_m3_eoc_mil_pc                          float64
#  694  pct_ccr_m3_eoc_mu7_pc                          float64
#  695  pct_ccr_m3_eoc_neds_pc                         float64
#  696  pct_ccr_m3_eoc_nswd_pc                         float64
#  697  pct_ccr_m3_eoc_swd_pc                          float64
#  698  pct_ccr_m3_eoc_wh7_pc                          float64
#  699  pct_ccr_ma_03_aig_pc                           float64
#  700  pct_ccr_ma_03_all_pc                           float64
#  701  pct_ccr_ma_03_am7_pc                           float64
#  702  pct_ccr_ma_03_as7_pc                           float64
#  703  pct_ccr_ma_03_bl7_pc                           float64
#  704  pct_ccr_ma_03_eds_pc                           float64
#  705  pct_ccr_ma_03_els_pc                           float64
#  706  pct_ccr_ma_03_fem_pc                           float64
#  707  pct_ccr_ma_03_hi7_pc                           float64
#  708  pct_ccr_ma_03_hms_pc                           float64
#  709  pct_ccr_ma_03_male_pc                          float64
#  710  pct_ccr_ma_03_mig_pc                           float64
#  711  pct_ccr_ma_03_mil_pc                           float64
#  712  pct_ccr_ma_03_mu7_pc                           float64
#  713  pct_ccr_ma_03_neds_pc                          float64
#  714  pct_ccr_ma_03_nswd_pc                          float64
#  715  pct_ccr_ma_03_swd_pc                           float64
#  716  pct_ccr_ma_03_wh7_pc                           float64
#  717  pct_ccr_ma_04_aig_pc                           float64
#  718  pct_ccr_ma_04_all_pc                           float64
#  719  pct_ccr_ma_04_am7_pc                           float64
#  720  pct_ccr_ma_04_as7_pc                           float64
#  721  pct_ccr_ma_04_bl7_pc                           float64
#  722  pct_ccr_ma_04_eds_pc                           float64
#  723  pct_ccr_ma_04_els_pc                           float64
#  724  pct_ccr_ma_04_fem_pc                           float64
#  725  pct_ccr_ma_04_hi7_pc                           float64
#  726  pct_ccr_ma_04_hms_pc                           float64
#  727  pct_ccr_ma_04_male_pc                          float64
#  728  pct_ccr_ma_04_mig_pc                           float64
#  729  pct_ccr_ma_04_mil_pc                           float64
#  730  pct_ccr_ma_04_mu7_pc                           float64
#  731  pct_ccr_ma_04_neds_pc                          float64
#  732  pct_ccr_ma_04_nswd_pc                          float64
#  733  pct_ccr_ma_04_swd_pc                           float64
#  734  pct_ccr_ma_04_wh7_pc                           float64
#  735  pct_ccr_ma_05_aig_pc                           float64
#  736  pct_ccr_ma_05_all_pc                           float64
#  737  pct_ccr_ma_05_am7_pc                           float64
#  738  pct_ccr_ma_05_as7_pc                           float64
#  739  pct_ccr_ma_05_bl7_pc                           float64
#  740  pct_ccr_ma_05_eds_pc                           float64
#  741  pct_ccr_ma_05_els_pc                           float64
#  742  pct_ccr_ma_05_fem_pc                           float64
#  743  pct_ccr_ma_05_hi7_pc                           float64
#  744  pct_ccr_ma_05_hms_pc                           float64
#  745  pct_ccr_ma_05_male_pc                          float64
#  746  pct_ccr_ma_05_mig_pc                           float64
#  747  pct_ccr_ma_05_mil_pc                           float64
#  748  pct_ccr_ma_05_mu7_pc                           float64
#  749  pct_ccr_ma_05_neds_pc                          float64
#  750  pct_ccr_ma_05_nswd_pc                          float64
#  751  pct_ccr_ma_05_swd_pc                           float64
#  752  pct_ccr_ma_05_wh7_pc                           float64
#  753  pct_ccr_ma_06_aig_pc                           float64
#  754  pct_ccr_ma_06_all_pc                           float64
#  755  pct_ccr_ma_06_am7_pc                           float64
#  756  pct_ccr_ma_06_as7_pc                           float64
#  757  pct_ccr_ma_06_bl7_pc                           float64
#  758  pct_ccr_ma_06_eds_pc                           float64
#  759  pct_ccr_ma_06_els_pc                           float64
#  760  pct_ccr_ma_06_fem_pc                           float64
#  761  pct_ccr_ma_06_hi7_pc                           float64
#  762  pct_ccr_ma_06_hms_pc                           float64
#  763  pct_ccr_ma_06_male_pc                          float64
#  764  pct_ccr_ma_06_mig_pc                           float64
#  765  pct_ccr_ma_06_mil_pc                           float64
#  766  pct_ccr_ma_06_mu7_pc                           float64
#  767  pct_ccr_ma_06_neds_pc                          float64
#  768  pct_ccr_ma_06_nswd_pc                          float64
#  769  pct_ccr_ma_06_swd_pc                           float64
#  770  pct_ccr_ma_06_wh7_pc                           float64
#  771  pct_ccr_ma_07_aig_pc                           float64
#  772  pct_ccr_ma_07_all_pc                           float64
#  773  pct_ccr_ma_07_am7_pc                           float64
#  774  pct_ccr_ma_07_as7_pc                           float64
#  775  pct_ccr_ma_07_bl7_pc                           float64
#  776  pct_ccr_ma_07_eds_pc                           float64
#  777  pct_ccr_ma_07_els_pc                           float64
#  778  pct_ccr_ma_07_fem_pc                           float64
#  779  pct_ccr_ma_07_hi7_pc                           float64
#  780  pct_ccr_ma_07_hms_pc                           float64
#  781  pct_ccr_ma_07_male_pc                          float64
#  782  pct_ccr_ma_07_mig_pc                           float64
# ...
#  4404 num_credentials_cte_cred                       float64
#  4405 num_enrollments_cte_cred                       float64
#  4406 cred_earned_pct_cte_cred                       float64
#  4407 career_only_cte_end_cte_enroll                 float64
#  4408 career_college_college_unc_cte_end_cte_enroll  float64
#  4409 college_college_unc_only_cte_end_cte_enroll    float64
#  4410 college_only_cte_end_cte_enroll                float64
#  4411 stu_enroll                                     float64
#  4412 cte_enroll                                     float64
#  4413 pct                                            float64
#  4414 digital_media_dlmi                             float64
#  4415 category_code_dlmi                             float64
#  4416 device_access_dlmi                             float64
#  4417 device_access_grades_dlmi                      float64
#  4418 device_home_dlmi                               float64
#  4419 device_home_grades_dlmi                        float64
#  4420 byod_dlmi                                      float64
#  4421 byod_grades_dlmi                               float64
#  4422 book_titlesper_student_dlmi                    float64
#  4423 wap_dlmi                                       float64
#  4424 wap_class_dlmi                                 float64
#  4425 media_school_dlmi                              float64
#  4426 devices_dlmi                                   float64
#  4427 ni_effect3                                     float64
#  4428 eff_effect3                                    float64
#  4429 he_effect3                                     float64
#  4430 ni_pct_effect3                                 float64
#  4431 eff_pct_effect3                                float64
#  4432 he_pct_effect3                                 float64
#  4433 poverty_eq                                     object
#  4434 number_of_teachers_eq                          float64
#  4435 beg_teacher_eq                                 float64
#  4436 pct_beg_teachers_eq                            float64
#  4437 prov_teachers_eq                               float64
#  4438 pct_prov_teachers_eq                           float64
#  4439 num_prin_eq                                    float64
#  4440 inexp_count_prin_eq                            float64
#  4441 pct_inexp_prin_eq                              float64
#  4442 adm_central_expense_funds2                     float64
#  4443 adm_employee_benefits_funds2                   float64
#  4444 adm_instructional_equip._funds2                float64
#  4445 adm_other_objects_funds2                       float64
#  4446 adm_purchased_services_funds2                  float64
#  4447 adm_salaries_funds2                            float64
#  4448 adm_supplies_&_materials_funds2                float64
#  4449 adm_total_funds2                               float64
#  4450 federal_funds_central_expense_funds2           float64
#  4451 federal_funds_employee_benefits_funds2         float64
#  4452 federal_funds_instructional_equip._funds2      float64
#  4453 federal_funds_other_objects_funds2             float64
#  4454 federal_funds_purchased_services_funds2        float64
#  4455 federal_funds_salaries_funds2                  float64
#  4456 federal_funds_supplies_&_materials_funds2      float64
#  4457 federal_funds_total_funds2                     float64
#  4458 federal_ppe_central_expense_funds2             float64
#  4459 federal_ppe_employee_benefits_funds2           float64
#  4460 federal_ppe_instructional_equip._funds2        float64
#  4461 federal_ppe_other_objects_funds2               float64
#  4462 federal_ppe_purchased_services_funds2          float64
#  4463 federal_ppe_salaries_funds2                    float64
#  4464 federal_ppe_supplies_&_materials_funds2        float64
#  4465 federal_ppe_total_funds2                       float64
#  4466 local_funds_central_expense_funds2             float64
#  4467 local_funds_employee_benefits_funds2           float64
#  4468 local_funds_instructional_equip._funds2        float64
#  4469 local_funds_other_objects_funds2               float64
#  4470 local_funds_purchased_services_funds2          float64
#  4471 local_funds_salaries_funds2                    float64
#  4472 local_funds_supplies_&_materials_funds2        float64
#  4473 local_funds_total_funds2                       float64
#  4474 local_ppe_central_expense_funds2               float64
#  4475 local_ppe_employee_benefits_funds2             float64
#  4476 local_ppe_instructional_equip._funds2          float64
#  4477 local_ppe_other_objects_funds2                 float64
#  4478 local_ppe_purchased_services_funds2            float64
#  4479 local_ppe_salaries_funds2                      float64
#  4480 local_ppe_supplies_&_materials_funds2          float64
#  4481 local_ppe_total_funds2                         float64
#  4482 state_funds_central_expense_funds2             float64
#  4483 state_funds_employee_benefits_funds2           float64
#  4484 state_funds_instructional_equip._funds2        float64
#  4485 state_funds_other_objects_funds2               float64
#  4486 state_funds_purchased_services_funds2          float64
#  4487 state_funds_salaries_funds2                    float64
#  4488 state_funds_supplies_&_materials_funds2        float64
#  4489 state_funds_total_funds2                       float64
#  4490 state_ppe_central_expense_funds2               float64
#  4491 state_ppe_employee_benefits_funds2             float64
#  4492 state_ppe_instructional_equip._funds2          float64
#  4493 state_ppe_other_objects_funds2                 float64
#  4494 state_ppe_purchased_services_funds2            float64
#  4495 state_ppe_salaries_funds2                      float64
#  4496 state_ppe_supplies_&_materials_funds2          float64
#  4497 state_ppe_total_funds2                         float64
#  4498 total_funds_central_expense_funds2             float64
#  4499 total_funds_employee_benefits_funds2           float64
#  4500 total_funds_instructional_equip._funds2        float64
#  4501 total_funds_other_objects_funds2               float64
#  4502 total_funds_purchased_services_funds2          float64
#  4503 total_funds_salaries_funds2                    float64
#  4504 total_funds_supplies_&_materials_funds2        float64
#  4505 total_funds_total_funds2                       float64
#  4506 total_ppe_central_expense_funds2               float64
#  4507 total_ppe_employee_benefits_funds2             float64
#  4508 total_ppe_instructional_equip._funds2          float64
#  4509 total_ppe_other_objects_funds2                 float64
#  4510 total_ppe_purchased_services_funds2            float64
#  4511 total_ppe_salaries_funds2                      float64
#  4512 total_ppe_supplies_&_materials_funds2          float64
#  4513 total_ppe_total_funds2                         float64
#  4514 pct_ib_pass                                    float64
#  4515 pct_ib_participation                           float64
#  4516 amount_improvement                             float64
#  4517 act_per1000_all_inc2                           float64
#  4518 act_per1000_am7_inc2                           float64
#  4519 act_per1000_as7_inc2                           float64
#  4520 act_per1000_bl7_inc2                           float64
#  4521 act_per1000_eds_inc2                           float64
#  4522 act_per1000_els_inc2                           float64
#  4523 act_per1000_fem_inc2                           float64
#  4524 act_per1000_hi7_inc2                           float64
#  4525 act_per1000_male_inc2                          float64
#  4526 act_per1000_mu7_inc2                           float64
#  4527 act_per1000_pi7_inc2                           float64
#  4528 act_per1000_swd_inc2                           float64
#  4529 act_per1000_wh7_inc2                           float64
#  4530 arr_per1000_all_inc2                           float64
#  4531 arr_per1000_am7_inc2                           float64
#  4532 arr_per1000_as7_inc2                           float64
#  4533 arr_per1000_bl7_inc2                           float64
#  4534 arr_per1000_eds_inc2                           float64
#  4535 arr_per1000_els_inc2                           float64
#  4536 arr_per1000_fem_inc2                           float64
#  4537 arr_per1000_hi7_inc2                           float64
#  4538 arr_per1000_male_inc2                          float64
#  4539 arr_per1000_mu7_inc2                           float64
#  4540 arr_per1000_pi7_inc2                           float64
#  4541 arr_per1000_swd_inc2                           float64
#  4542 arr_per1000_wh7_inc2                           float64
#  4543 bha_per1000_all_inc2                           float64
#  4544 bha_per1000_am7_inc2                           float64
#  4545 bha_per1000_as7_inc2                           float64
#  4546 bha_per1000_bl7_inc2                           float64
#  4547 bha_per1000_eds_inc2                           float64
#  4548 bha_per1000_els_inc2                           float64
#  4549 bha_per1000_fem_inc2                           float64
#  4550 bha_per1000_hi7_inc2                           float64
#  4551 bha_per1000_male_inc2                          float64
#  4552 bha_per1000_mu7_inc2                           float64
#  4553 bha_per1000_pi7_inc2                           float64
#  4554 bha_per1000_swd_inc2                           float64
#  4555 bha_per1000_wh7_inc2                           float64
#  4556 exp_per1000_all_inc2                           float64
#  4557 exp_per1000_am7_inc2                           float64
#  4558 exp_per1000_as7_inc2                           float64
#  4559 exp_per1000_bl7_inc2                           float64
#  4560 exp_per1000_eds_inc2                           float64
#  4561 exp_per1000_els_inc2                           float64
#  4562 exp_per1000_fem_inc2                           float64
#  4563 exp_per1000_hi7_inc2                           float64
#  4564 exp_per1000_male_inc2                          float64
#  4565 exp_per1000_mu7_inc2                           float64
#  4566 exp_per1000_pi7_inc2                           float64
#  4567 exp_per1000_swd_inc2                           float64
#  4568 exp_per1000_wh7_inc2                           float64
#  4569 iss_per1000_all_inc2                           float64
#  4570 iss_per1000_am7_inc2                           float64
#  4571 iss_per1000_as7_inc2                           float64
#  4572 iss_per1000_bl7_inc2                           float64
#  4573 iss_per1000_eds_inc2                           float64
#  4574 iss_per1000_els_inc2                           float64
#  4575 iss_per1000_fem_inc2                           float64
#  4576 iss_per1000_hi7_inc2                           float64
#  4577 iss_per1000_male_inc2                          float64
#  4578 iss_per1000_mu7_inc2                           float64
#  4579 iss_per1000_pi7_inc2                           float64
#  4580 iss_per1000_swd_inc2                           float64
#  4581 iss_per1000_wh7_inc2                           float64
#  4582 lts_per1000_all_inc2                           float64
#  4583 lts_per1000_am7_inc2                           float64
#  4584 lts_per1000_as7_inc2                           float64
#  4585 lts_per1000_bl7_inc2                           float64
#  4586 lts_per1000_eds_inc2                           float64
#  4587 lts_per1000_els_inc2                           float64
#  4588 lts_per1000_fem_inc2                           float64
#  4589 lts_per1000_hi7_inc2                           float64
#  4590 lts_per1000_male_inc2                          float64
#  4591 lts_per1000_mu7_inc2                           float64
#  4592 lts_per1000_pi7_inc2                           float64
#  4593 lts_per1000_swd_inc2                           float64
#  4594 lts_per1000_wh7_inc2                           float64
#  4595 rpt_per1000_all_inc2                           float64
#  4596 rpt_per1000_am7_inc2                           float64
#  4597 rpt_per1000_as7_inc2                           float64
#  4598 rpt_per1000_bl7_inc2                           float64
#  4599 rpt_per1000_eds_inc2                           float64
#  4600 rpt_per1000_els_inc2                           float64
#  4601 rpt_per1000_fem_inc2                           float64
#  4602 rpt_per1000_hi7_inc2                           float64
#  4603 rpt_per1000_male_inc2                          float64
#  4604 rpt_per1000_mu7_inc2                           float64
#  4605 rpt_per1000_pi7_inc2                           float64
#  4606 rpt_per1000_swd_inc2                           float64
#  4607 rpt_per1000_wh7_inc2                           float64
#  4608 sts_per1000_all_inc2                           float64
#  4609 sts_per1000_am7_inc2                           float64
#  4610 sts_per1000_as7_inc2                           float64
#  4611 sts_per1000_bl7_inc2                           float64
#  4612 sts_per1000_eds_inc2                           float64
#  4613 sts_per1000_els_inc2                           float64
#  4614 sts_per1000_fem_inc2                           float64
#  4615 sts_per1000_hi7_inc2                           float64
#  4616 sts_per1000_male_inc2                          float64
#  4617 sts_per1000_mu7_inc2                           float64
#  4618 sts_per1000_pi7_inc2                           float64
#  4619 sts_per1000_swd_inc2                           float64
#  4620 sts_per1000_wh7_inc2                           float64
#  4621 count_all_pk_enroll                            float64
#  4622 count_am7_pk_enroll                            float64
#  4623 count_as7_pk_enroll                            float64
#  4624 count_bl7_pk_enroll                            float64
#  4625 count_els_pk_enroll                            float64
#  4626 count_fem_pk_enroll                            float64
#  4627 count_hi7_pk_enroll                            float64
#  4628 count_male_pk_enroll                           float64
#  4629 count_mu7_pk_enroll                            float64
#  4630 count_pi7_pk_enroll                            float64
#  4631 count_swd_pk_enroll                            float64
#  4632 count_wh7_pk_enroll                            float64
#  4633 pct_all_pk_enroll                              float64
#  4634 pct_am7_pk_enroll                              float64
#  4635 pct_as7_pk_enroll                              float64
#  4636 pct_bl7_pk_enroll                              float64
#  4637 pct_els_pk_enroll                              float64
#  4638 pct_fem_pk_enroll                              float64
#  4639 pct_hi7_pk_enroll                              float64
#  4640 pct_male_pk_enroll                             float64
#  4641 pct_mu7_pk_enroll                              float64
#  4642 pct_pi7_pk_enroll                              float64
#  4643 pct_swd_pk_enroll                              float64
#  4644 pct_wh7_pk_enroll                              float64
#  4645 pct_ready_kea_a_cat_code                       float64
#  4646 pct_ready_kea_e_cat_code                       float64
#  4647 pct_ready_kea_i_cat_code                       float64
#  4648 pct_ready_kea_m_cat_code                       float64
#  4649 avg_size_00_sar                                float64
#  4650 avg_size_01_sar                                float64
#  4651 avg_size_02_sar                                float64
#  4652 avg_size_03_sar                                float64
#  4653 avg_size_04_sar                                float64
#  4654 avg_size_05_sar                                float64
#  4655 avg_size_06_sar                                float64
#  4656 avg_size_07_sar                                float64
#  4657 avg_size_08_sar                                float64
#  4658 avg_size_biology_sar                           float64
#  4659 avg_size_english_ii_sar                        float64
#  4660 avg_size_nc_math_1_sar                         float64
#  4661 avg_size_nc_math_3_sar                         float64
#  4662 avg_sat_score                                  float64
#  4663 pct_sat_participation                          float64
#  4664 welcome_url                                    object
# dtypes: float64(4617), object(48)
# memory usage: 22.9+ MB

# %% [markdown]
# # Prepare Consolidated Dataset for Machine Learning
# **Below we perform operations on the entire dataset to remove columns and update row values that could cause problems during machine learning.**

# %% [markdown]
# ## Student Body Racial Composition Features
# **Impute / update missing Student Body Racial Composition Fields using mean imputation.**
# * When there are no racial composition percentages for a particular school campus / agency_code, fill in the missing values

# %%
#Get Student Body Racial Composition Fields
raceCompositionFields = schoolData.filter(regex='indian|asian|hispanic|black|white|pacific_island|two_or_more|minority')\
                                  .filter(regex='pct').columns
    
rowsBefore = schoolData[raceCompositionFields].isnull().T.any().T.sum()

#Update missing race values with the district average when avaiable (No district averages for charter schools) 
schoolData[raceCompositionFields] = schoolData.groupby('lea_code_loc')[raceCompositionFields]\
                                              .transform(lambda x: x.fillna(x.mean()))

    #Review dataset contents after Racial Composition Imputation
print('*********After: Updating Missing Racial Compostion Values****************************')   
rowsAfter = schoolData[raceCompositionFields].isnull().T.any().T.sum()
rowsUpdated = rowsBefore - rowsAfter
print('Rows Updated / Imputed: ', rowsUpdated) 
print('\r\nTotal Rows Missing Racial Compositions By District Code') 
schoolData['lea_code_loc'][schoolData[raceCompositionFields].isnull().T.any().T].value_counts()
# Out:
# *********After: Updating Missing Racial Compostion Values****************************
# Rows Updated / Imputed:  6
#
# Total Rows Missing Racial Compositions By District Code
# 998LEA    13
# 997LEA     9
# 996LEA     4
# 298LEA     3
# 299LEA     1
# 679LEA     1
# Name: lea_code_loc, dtype: int64

# %% [markdown]
# ## Remove Columns with Problematic Data
# **Here we remove entire columns that could cause problems during machine learning.  The following operations are performed:**
# * Remove any columns that have the same value in every single row.
# * Remove any columns that have a unique value in every single row (all values are different).
# * Remove empty columns (all values are NA or NULL).

# %%
#Remove any fields that have the same value in all rows
UniqueValueCounts = schoolData.nunique(dropna=False)
SingleValueCols = UniqueValueCounts[UniqueValueCounts == 1].index
schoolData = schoolData.drop(SingleValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with the same value in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(SingleValueCols))
# Out:
# *********After: Removing columns with the same value in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 644 entries, 2 to 715
# Columns: 3660 entries, agency_code to welcome_url
# dtypes: float64(3616), object(44)
# memory usage: 18.0+ MB
#
# Columns Deleted:  1005

# %%
#Remove any fields that have unique values in every row
schoolDataRecordCt = schoolData.shape[0]
UniqueValueCounts = schoolData.apply(pd.Series.nunique)
AllUniqueValueCols = UniqueValueCounts[UniqueValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(AllUniqueValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with unique values in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(AllUniqueValueCols))
# Out:
# *********After: Removing columns with unique values in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 644 entries, 2 to 715
# Columns: 3659 entries, category_code_loc to welcome_url
# dtypes: float64(3616), object(43)
# memory usage: 18.0+ MB
#
# Columns Deleted:  1

# %%
#Remove any empty fields (null values in every row)
schoolDataRecordCt = schoolData.shape[0]
NullValueCounts = schoolData.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with null / blank values in every row.*************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with null / blank values in every row.*************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 644 entries, 2 to 715
# Columns: 3659 entries, category_code_loc to welcome_url
# dtypes: float64(3616), object(43)
# memory usage: 18.0+ MB
#
# Columns Deleted:  0

# %% [markdown]
# ## Handle Other Missing Values Types
# * Here we eliminate any numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# * All remaining non-race, numeric column missing values are populated with 0.
# * In many cases, it seems that schools are not simply not reporting values when they are zero. However, mean imputation or some other strategy might be considered.

# %%
#Isolate continuous and categorical data types
#These are indexers into the schoolData dataframe and may be used similar to the schoolData dataframe 
sD_boolean = schoolData.loc[:, (schoolData.dtypes == bool) ]
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]
sD_continuous = schoolData.loc[:, (schoolData.dtypes != bool) & (schoolData.dtypes != object)]
print ("Boolean Columns: ", sD_boolean.shape[1])
print ("Nominal Columns: ", sD_nominal.shape[1])
print ("Continuous Columns: ", sD_continuous.shape[1])
print ("Columns Accounted for: ", sD_nominal.shape[1] + sD_continuous.shape[1] + sD_boolean.shape[1])
# Out:
# Boolean Columns:  0
# Nominal Columns:  43
# Continuous Columns:  3616
# Columns Accounted for:  3659

# %%
#Eliminate continuous columns with more than missingThreshold percentage of missing values
schoolDataRecordCt = sD_continuous.shape[0]
missingValueLimit = schoolDataRecordCt * missingThreshold
NullValueCounts = sD_continuous.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts >= missingValueLimit].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with >= missingThreshold % of missing values******')
schoolData.info(verbose=False)
print('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with >= missingThreshold % of missing values******
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 644 entries, 2 to 715
# Columns: 948 entries, category_code_loc to welcome_url
# dtypes: float64(905), object(43)
# memory usage: 4.7+ MB
#
# Columns Deleted:  2711

# %% [markdown]
# ## One-Hot Encoding of Categorical Variables
# **All categorical / string variables are converted to numberic variables via one hot encoding.  Each unique row value will become a new binary / numeric column in the dataset.**
# * All remaining categorical columns are one-hot encoded.
# * In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# * Prior to one-hot encoding, columns with > *uniqueThreshold* unique values are deleted.

# %%
#Delete categorical columns with > uniqueThreshold unique values 
#(Each unique value becomes a column during one-hot encoding)
oneHotUniqueValueCounts = schoolData[sD_nominal.columns].apply(lambda x: x.nunique())
oneHotUniqueValueCols = oneHotUniqueValueCounts[oneHotUniqueValueCounts >= uniqueThreshold].index
schoolData.drop(oneHotUniqueValueCols, axis=1, inplace=True) 

#Remove categorical columns which do not add value to machine learning
#Grades columns dropped since they all have indicator fields (device_access, device_home, BYOD)
#with less unique values to one-hot encode

# _dlmi columns may or may not exist after running cleanups above.

#----MUST CHECK FOR:---- 'device_access_grades_dlmi','device_home_grades_dlmi','byod_grades_dlmi'
# to fields below, if they exist
schoolData.drop(['welcome_url'], axis=1, inplace=True) 

#Review dataset contents one hot high unique value drops
print('*********After: Removing columns with >= uniqueThreshold unique values***********')
schoolData.info(verbose=False)
print('\r\nColumns Deleted: ', len(oneHotUniqueValueCols))
print(oneHotUniqueValueCols)
print('Dropped Manually: welcome_url,device_access_grades_dlmi ,device_home_grades_dlmi ,byod_grades_dlmi ')
# Out:
# *********After: Removing columns with >= uniqueThreshold unique values***********
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 644 entries, 2 to 715
# Columns: 933 entries, category_code_loc to pct_sat_participation
# dtypes: float64(905), object(28)
# memory usage: 4.6+ MB
#
# Columns Deleted:  14
# Index(['name_loc', 'street_addr_loc', 'city_loc', 'zip_loc', 'phone_loc',
#        'url_loc', 'school_name', 'school_name_attendance',
#        'ada_ct_2017_attendance', 'adm_ct_2017_attendance',
#        'ada_ct_2018_attendance', 'adm_ct_2018_attendance',
#        'ada_ct_2019_attendance', 'adm_ct_2019_attendance'],
#       dtype='object')
# Dropped Manually: welcome_url,device_access_grades_dlmi ,device_home_grades_dlmi ,byod_grades_dlmi

# %%
#Isolate remaining categorical variables
begColumnCt = len(schoolData.columns)
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]

#one hot encode categorical variables
schoolData = pd.get_dummies(data=schoolData, 
                       columns=sD_nominal.columns, drop_first=True)

#Determine change in column count
endColumnCt = len(schoolData.columns)
columnsAdded = endColumnCt - begColumnCt

#Review dataset contents one hot high unique value drops
print('Columns To One-Hot Encode: ', len(sD_nominal.columns))
print('\r\n*********After: Adding New Columns Via One-Hot Encoding*************************')
schoolData.info(verbose=False)
print('\r\nNew Columns Created Via One-Hot Encoding: ', columnsAdded)
# Out:
# Columns To One-Hot Encode:  28
#
# *********After: Adding New Columns Via One-Hot Encoding*************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 644 entries, 2 to 715
# Columns: 1502 entries, lea to poverty_eq_NEITHER
# dtypes: float64(905), uint8(597)
# memory usage: 4.8 MB
#
# New Columns Created Via One-Hot Encoding:  569

# %%
#Remove any fields that have the same value in all rows after one-hot encoding
UniqueValueCounts = schoolData.nunique(dropna=False)
SingleValueCols = UniqueValueCounts[UniqueValueCounts == 1].index
schoolData = schoolData.drop(SingleValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing one-hot encoded columns with the same value in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(SingleValueCols))
# Out:
# *********After: Removing one-hot encoded columns with the same value in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 644 entries, 2 to 715
# Columns: 1502 entries, lea to poverty_eq_NEITHER
# dtypes: float64(905), uint8(597)
# memory usage: 4.8 MB
#
# Columns Deleted:  0

# %% [markdown]
# ## Impute any Remaining Missing Values as Zero

# %%
#Print out all the missing value rows
pd.set_option('display.max_rows', 1500)

print('\r\n*********The Remaining Missing Values Below will be set to Zero!*************************')

#Check for Missing values 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# *********The Remaining Missing Values Below will be set to Zero!*************************
#                                      Variable Name  Number Missing Values
# 0                                              lea                     37
# 1                                           school                     37
# 2                                       indian_pct                     31
# 3                                        asian_pct                     31
# 4                                     hispanic_pct                     31
# 5                                        black_pct                     31
# 6                                        white_pct                     31
# 7                               pacific_island_pct                     31
# 8                                  two_or_more_pct                     31
# 9                                     minority_pct                     31
# 10                                 indian_male_pct                     31
# 11                                  asian_male_pct                     31
# 12                               hispanic_male_pct                     31
# 13                                  black_male_pct                     31
# 14                                  white_male_pct                     31
# 15                         pacific_island_male_pct                     31
# 16                            two_or_more_male_pct                     31
# 17                               minority_male_pct                     31
# 18                               indian_female_pct                     31
# 19                                asian_female_pct                     31
# 20                             hispanic_female_pct                     31
# 21                                black_female_pct                     31
# 22                                white_female_pct                     31
# 23                             minority_female_pct                     31
# 24                       pacific_island_female_pct                     31
# 25                          two_or_more_female_pct                     31
# 26                               lea_no_attendance                     39
# 27                            school_no_attendance                     39
# 28                   ada_adm_ratio_2018_attendance                     61
# 29                 ada_adm_ratio_2018.1_attendance                     48
# 30                   ada_adm_ratio_2019_attendance                     39
# 31         ada_adm_ratio_2017_thru_2019_attendance                     61
# 32          ada_adm_rank_2017_thru_2019_attendance                     61
# 33                               pct_acall_aig_act                    145
# 34                               pct_acall_all_act                     86
# 35                               pct_acall_as7_act                    377
# 36                               pct_acall_bl7_act                    156
# 37                               pct_acall_eds_act                     95
# 38                               pct_acall_els_act                    313
# 39                               pct_acall_fem_act                    106
# 40                               pct_acall_hi7_act                    150
# 41                              pct_acall_male_act                     91
# 42                               pct_acall_mu7_act                    233
# 43                              pct_acall_neds_act                     98
# 44                              pct_acall_nswd_act                     91
# 45                               pct_acall_swd_act                    215
# 46                               pct_acall_wh7_act                    117
# 47                                pct_acco_aig_act                    228
# 48                                pct_acco_all_act                    118
# 49                                pct_acco_bl7_act                    268
# 50                                pct_acco_eds_act                    158
# 51                                pct_acco_fem_act                    140
# 52                                pct_acco_hi7_act                    280
# 53                               pct_acco_male_act                    143
# 54                               pct_acco_neds_act                    144
# 55                               pct_acco_nswd_act                    123
# 56                                pct_acco_swd_act                    353
# 57                                pct_acco_wh7_act                    181
# 58                                pct_acen_aig_act                    228
# 59                                pct_acen_all_act                    118
# 60                                pct_acen_bl7_act                    268
# 61                                pct_acen_eds_act                    158
# 62                                pct_acen_fem_act                    140
# 63                                pct_acen_hi7_act                    280
# 64                               pct_acen_male_act                    143
# 65                               pct_acen_neds_act                    144
# 66                               pct_acen_nswd_act                    123
# 67                                pct_acen_swd_act                    352
# 68                                pct_acen_wh7_act                    181
# 69                                pct_acma_aig_act                    228
# 70                                pct_acma_all_act                    118
# 71                                pct_acma_bl7_act                    268
# 72                                pct_acma_eds_act                    158
# 73                                pct_acma_fem_act                    140
# 74                                pct_acma_hi7_act                    280
# 75                               pct_acma_male_act                    143
# 76                               pct_acma_neds_act                    144
# 77                               pct_acma_nswd_act                    123
# 78                                pct_acma_swd_act                    353
# 79                                pct_acma_wh7_act                    181
# 80                                pct_acrd_aig_act                    228
# 81                                pct_acrd_all_act                    118
# 82                                pct_acrd_bl7_act                    268
# 83                                pct_acrd_eds_act                    157
# 84                                pct_acrd_fem_act                    140
# 85                                pct_acrd_hi7_act                    280
# 86                               pct_acrd_male_act                    143
# 87                               pct_acrd_neds_act                    144
# 88                               pct_acrd_nswd_act                    123
# 89                                pct_acrd_swd_act                    352
# 90                                pct_acrd_wh7_act                    181
# 91                                pct_acsc_aig_act                    228
# 92                                pct_acsc_all_act                    118
# 93                                pct_acsc_bl7_act                    268
# 94                                pct_acsc_eds_act                    157
# 95                                pct_acsc_fem_act                    140
# 96                                pct_acsc_hi7_act                    280
# 97                               pct_acsc_male_act                    143
# 98                               pct_acsc_neds_act                    144
# 99                               pct_acsc_nswd_act                    123
# 100                               pct_acsc_swd_act                    352
# 101                               pct_acsc_wh7_act                    181
# 102                               pct_acwr_aig_act                    228
# 103                               pct_acwr_all_act                    118
# 104                               pct_acwr_bl7_act                    272
# 105                               pct_acwr_eds_act                    161
# 106                               pct_acwr_fem_act                    142
# 107                               pct_acwr_hi7_act                    280
# 108                              pct_acwr_male_act                    148
# 109                              pct_acwr_neds_act                    144
# 110                              pct_acwr_nswd_act                    123
# 111                               pct_acwr_swd_act                    365
# 112                               pct_acwr_wh7_act                    183
# 113                                    pct_aig_awa                    237
# 114                                    pct_all_awa                    122
# 115                                    pct_bl7_awa                    272
# 116                                    pct_eds_awa                    162
# 117                                    pct_fem_awa                    149
# 118                                    pct_hi7_awa                    293
# 119                                   pct_male_awa                    154
# 120                                   pct_neds_awa                    143
# 121                                   pct_nswd_awa                    127
# 122                                    pct_swd_awa                    347
# 123                                    pct_wh7_awa                    182
# 124                                pct_ext_aig_cgr                    235
# 125                                pct_ext_all_cgr                    107
# 126                                pct_ext_bl7_cgr                    257
# 127                                pct_ext_eds_cgr                    155
# 128                                pct_ext_fem_cgr                    136
# 129                                pct_ext_hi7_cgr                    290
# 130                               pct_ext_male_cgr                    134
# 131                               pct_ext_neds_cgr                    129
# 132                               pct_ext_nswd_cgr                    120
# 133                                pct_ext_swd_cgr                    258
# 134                                pct_ext_wh7_cgr                    170
# 135                                pct_std_aig_cgr                    226
# 136                                pct_std_all_cgr                     95
# 137                                pct_std_bl7_cgr                    248
# 138                                pct_std_eds_cgr                    140
# 139                                pct_std_fem_cgr                    118
# 140                                pct_std_hi7_cgr                    266
# 141                               pct_std_male_cgr                    118
# 142                               pct_std_neds_cgr                    121
# 143                               pct_std_nswd_cgr                    115
# 144                                pct_std_swd_cgr                    234
# 145                                pct_std_wh7_cgr                    146
# 146                                        pct_eds                     38
# 147                            eg_index_all_aig_eg                    216
# 148                            eg_index_all_all_eg                     83
# 149                            eg_index_all_bl7_eg                    230
# 150                            eg_index_all_eds_eg                    106
# 151                            eg_index_all_hi7_eg                    240
# 152                            eg_index_all_swd_eg                    268
# 153                            eg_index_all_wh7_eg                    161
# 154                            eg_score_all_aig_eg                    295
# 155                            eg_score_all_all_eg                    105
# 156                            eg_score_all_bl7_eg                    312
# 157                            eg_score_all_eds_eg                    159
# 158                            eg_score_all_hi7_eg                    337
# 159                            eg_score_all_swd_eg                    321
# 160                            eg_score_all_wh7_eg                    205
# 161                                    den_all_elp                    325
# 162                                    den_eds_elp                    364
# 163                                    den_els_elp                    325
# 164                                    den_hi7_elp                    344
# 165                                   den_male_elp                    377
# 166                                   den_nswd_elp                    357
# 167                                    pct_all_elp                    325
# 168                                    pct_eds_elp                    364
# 169                                    pct_els_elp                    325
# 170                                    pct_hi7_elp                    344
# 171                                   pct_male_elp                    377
# 172                                   pct_nswd_elp                    357
# 173                               pct_prof_9gr_irm                    103
# 174             pct_met_4_year_graduation_rate_ltg                    144
# 175                      pct_met_math_grade_11_ltg                    171
# 176                   pct_met_reading_grade_10_ltg                    165
# 177                      pct_met_total_targets_ltg                     88
# 178       target_assign_4_year_graduation_rate_ltg                    144
# 179                target_assign_math_grade_11_ltg                    171
# 180             target_assign_reading_grade_10_ltg                    165
# 181                target_assign_total_targets_ltg                     88
# 182          target_met_4_year_graduation_rate_ltg                    144
# 183                   target_met_math_grade_11_ltg                    171
# 184                target_met_reading_grade_10_ltg                    165
# 185                   target_met_total_targets_ltg                     88
# 186                                    pct_aig_mcr                    232
# 187                                    pct_all_mcr                     96
# 188                                    pct_bl7_mcr                    253
# 189                                    pct_eds_mcr                    143
# 190                                    pct_fem_mcr                    135
# 191                                    pct_hi7_mcr                    279
# 192                                   pct_male_mcr                    128
# 193                                   pct_neds_mcr                    127
# 194                                   pct_nswd_mcr                    118
# 195                                    pct_swd_mcr                    270
# 196                                    pct_wh7_mcr                    159
# 197                      pct_met_act_workkeys_part                    282
# 198                           pct_met_biology_part                    153
# 199                        pct_met_english_ii_part                    146
# 200                  pct_met_high_school_math_part                    153
# 201                           pct_met_the_act_part                    153
# 202                     pct_met_total_targets_part                     96
# 203                target_assign_act_workkeys_part                    282
# 204                     target_assign_biology_part                    153
# 205                  target_assign_english_ii_part                    146
# 206            target_assign_high_school_math_part                    153
# 207                     target_assign_the_act_part                    153
# 208               target_assign_total_targets_part                     96
# 209                   target_met_act_workkeys_part                    282
# 210                        target_met_biology_part                    153
# 211                     target_met_english_ii_part                    146
# 212               target_met_high_school_math_part                    153
# 213                        target_met_the_act_part                    153
# 214                  target_met_total_targets_part                     96
# 215                  pct_act_workkeys_all_part_det                    282
# 216                  pct_act_workkeys_wh7_part_det                    371
# 217                       pct_biology_all_part_det                    153
# 218                       pct_biology_eds_part_det                    266
# 219                       pct_biology_wh7_part_det                    274
# 220                    pct_english_ii_all_part_det                    146
# 221                    pct_english_ii_eds_part_det                    250
# 222                    pct_english_ii_wh7_part_det                    275
# 223              pct_high_school_math_all_part_det                    153
# 224              pct_high_school_math_eds_part_det                    266
# 225              pct_high_school_math_wh7_part_det                    274
# 226                       pct_the_act_all_part_det                    153
# 227                       pct_the_act_eds_part_det                    264
# 228                       pct_the_act_wh7_part_det                    272
# 229                          pct_ccr_bi_eoc_aig_pc                    239
# 230                          pct_ccr_bi_eoc_all_pc                    117
# 231                          pct_ccr_bi_eoc_bl7_pc                    275
# 232                          pct_ccr_bi_eoc_eds_pc                    157
# 233                          pct_ccr_bi_eoc_fem_pc                    152
# 234                          pct_ccr_bi_eoc_hi7_pc                    266
# 235                         pct_ccr_bi_eoc_male_pc                    147
# 236                         pct_ccr_bi_eoc_neds_pc                    141
# 237                         pct_ccr_bi_eoc_nswd_pc                    125
# 238                          pct_ccr_bi_eoc_swd_pc                    346
# 239                          pct_ccr_bi_eoc_wh7_pc                    178
# 240                          pct_ccr_e2_eoc_aig_pc                    225
# 241                          pct_ccr_e2_eoc_all_pc                    108
# 242                          pct_ccr_e2_eoc_bl7_pc                    256
# 243                          pct_ccr_e2_eoc_eds_pc                    136
# 244                          pct_ccr_e2_eoc_fem_pc                    132
# 245                          pct_ccr_e2_eoc_hi7_pc                    254
# 246                         pct_ccr_e2_eoc_male_pc                    132
# 247                         pct_ccr_e2_eoc_neds_pc                    134
# 248                         pct_ccr_e2_eoc_nswd_pc                    112
# 249                          pct_ccr_e2_eoc_swd_pc                    365
# 250                          pct_ccr_e2_eoc_wh7_pc                    167
# 251                         pct_ccr_eoc_eoc_aig_pc                    157
# 252                         pct_ccr_eoc_eoc_all_pc                     91
# 253                         pct_ccr_eoc_eoc_bl7_pc                    193
# 254                         pct_ccr_eoc_eoc_eds_pc                    115
# 255                         pct_ccr_eoc_eoc_fem_pc                     99
# 256                         pct_ccr_eoc_eoc_hi7_pc                    160
# 257                        pct_ccr_eoc_eoc_male_pc                    113
# 258                         pct_ccr_eoc_eoc_mu7_pc                    267
# 259                        pct_ccr_eoc_eoc_neds_pc                     96
# 260                        pct_ccr_eoc_eoc_nswd_pc                     96
# 261                         pct_ccr_eoc_eoc_swd_pc                    356
# 262                         pct_ccr_eoc_eoc_wh7_pc                    106
# 263                          pct_ccr_m1_eoc_all_pc                    248
# 264                          pct_ccr_m1_eoc_eds_pc                    311
# 265                          pct_ccr_m1_eoc_fem_pc                    260
# 266                         pct_ccr_m1_eoc_male_pc                    291
# 267                         pct_ccr_m1_eoc_neds_pc                    259
# 268                         pct_ccr_m1_eoc_nswd_pc                    235
# 269                          pct_ccr_m1_eoc_wh7_pc                    284
# 270                          pct_ccr_m3_eoc_aig_pc                    229
# 271                          pct_ccr_m3_eoc_all_pc                    169
# 272                          pct_ccr_m3_eoc_eds_pc                    246
# 273                          pct_ccr_m3_eoc_fem_pc                    181
# 274                          pct_ccr_m3_eoc_hi7_pc                    305
# 275                         pct_ccr_m3_eoc_male_pc                    198
# 276                         pct_ccr_m3_eoc_neds_pc                    172
# 277                         pct_ccr_m3_eoc_nswd_pc                    164
# 278                          pct_ccr_m3_eoc_wh7_pc                    197
# 279                          pct_glp_bi_eoc_aig_pc                    239
# 280                          pct_glp_bi_eoc_all_pc                    110
# 281                          pct_glp_bi_eoc_bl7_pc                    270
# 282                          pct_glp_bi_eoc_eds_pc                    151
# 283                          pct_glp_bi_eoc_fem_pc                    149
# 284                          pct_glp_bi_eoc_hi7_pc                    264
# 285                         pct_glp_bi_eoc_male_pc                    139
# 286                         pct_glp_bi_eoc_neds_pc                    138
# 287                         pct_glp_bi_eoc_nswd_pc                    120
# 288                          pct_glp_bi_eoc_swd_pc                    308
# 289                          pct_glp_bi_eoc_wh7_pc                    177
# 290                          pct_glp_e2_eoc_aig_pc                    225
# 291                          pct_glp_e2_eoc_all_pc                    102
# 292                          pct_glp_e2_eoc_bl7_pc                    253
# 293                          pct_glp_e2_eoc_eds_pc                    134
# 294                          pct_glp_e2_eoc_fem_pc                    130
# 295                          pct_glp_e2_eoc_hi7_pc                    252
# 296                         pct_glp_e2_eoc_male_pc                    126
# 297                         pct_glp_e2_eoc_neds_pc                    133
# 298                         pct_glp_e2_eoc_nswd_pc                    107
# 299                          pct_glp_e2_eoc_swd_pc                    312
# 300                          pct_glp_e2_eoc_wh7_pc                    166
# 301                         pct_glp_eoc_eoc_aig_pc                    157
# 302                         pct_glp_eoc_eoc_all_pc                     72
# 303                         pct_glp_eoc_eoc_bl7_pc                    174
# 304                         pct_glp_eoc_eoc_eds_pc                     94
# 305                         pct_glp_eoc_eoc_els_pc                    362
# 306                         pct_glp_eoc_eoc_fem_pc                     89
# 307                         pct_glp_eoc_eoc_hi7_pc                    152
# 308                        pct_glp_eoc_eoc_male_pc                     88
# 309                         pct_glp_eoc_eoc_mu7_pc                    261
# 310                        pct_glp_eoc_eoc_neds_pc                     88
# 311                        pct_glp_eoc_eoc_nswd_pc                     82
# 312                         pct_glp_eoc_eoc_swd_pc                    247
# 313                         pct_glp_eoc_eoc_wh7_pc                     98
# 314                          pct_glp_m1_eoc_all_pc                    132
# 315                          pct_glp_m1_eoc_bl7_pc                    306
# 316                          pct_glp_m1_eoc_eds_pc                    167
# 317                          pct_glp_m1_eoc_fem_pc                    164
# 318                          pct_glp_m1_eoc_hi7_pc                    304
# 319                         pct_glp_m1_eoc_male_pc                    180
# 320                         pct_glp_m1_eoc_neds_pc                    174
# 321                         pct_glp_m1_eoc_nswd_pc                    139
# 322                          pct_glp_m1_eoc_swd_pc                    347
# 323                          pct_glp_m1_eoc_wh7_pc                    213
# 324                          pct_glp_m3_eoc_aig_pc                    227
# 325                          pct_glp_m3_eoc_all_pc                    123
# 326                          pct_glp_m3_eoc_bl7_pc                    287
# 327                          pct_glp_m3_eoc_eds_pc                    157
# 328                          pct_glp_m3_eoc_fem_pc                    142
# 329                          pct_glp_m3_eoc_hi7_pc                    266
# 330                         pct_glp_m3_eoc_male_pc                    150
# 331                         pct_glp_m3_eoc_neds_pc                    145
# 332                         pct_glp_m3_eoc_nswd_pc                    121
# 333                          pct_glp_m3_eoc_wh7_pc                    184
# 334                           pct_l1_bi_eoc_all_pc                    196
# 335                           pct_l1_bi_eoc_bl7_pc                    293
# 336                           pct_l1_bi_eoc_eds_pc                    200
# 337                           pct_l1_bi_eoc_fem_pc                    239
# 338                           pct_l1_bi_eoc_hi7_pc                    304
# 339                          pct_l1_bi_eoc_male_pc                    222
# 340                          pct_l1_bi_eoc_neds_pc                    263
# 341                          pct_l1_bi_eoc_nswd_pc                    238
# 342                           pct_l1_bi_eoc_swd_pc                    286
# 343                           pct_l1_bi_eoc_wh7_pc                    306
# 344                           pct_l1_e2_eoc_all_pc                    196
# 345                           pct_l1_e2_eoc_bl7_pc                    283
# 346                           pct_l1_e2_eoc_eds_pc                    198
# 347                           pct_l1_e2_eoc_fem_pc                    245
# 348                           pct_l1_e2_eoc_hi7_pc                    298
# 349                          pct_l1_e2_eoc_male_pc                    189
# 350                          pct_l1_e2_eoc_neds_pc                    260
# 351                          pct_l1_e2_eoc_nswd_pc                    226
# 352                           pct_l1_e2_eoc_swd_pc                    275
# 353                           pct_l1_e2_eoc_wh7_pc                    279
# 354                           pct_l2_bi_eoc_all_pc                    134
# 355                           pct_l2_bi_eoc_bl7_pc                    277
# 356                           pct_l2_bi_eoc_eds_pc                    162
# 357                           pct_l2_bi_eoc_fem_pc                    175
# 358                           pct_l2_bi_eoc_hi7_pc                    283
# 359                          pct_l2_bi_eoc_male_pc                    178
# 360                          pct_l2_bi_eoc_neds_pc                    185
# 361                          pct_l2_bi_eoc_nswd_pc                    150
# 362                           pct_l2_bi_eoc_swd_pc                    301
# 363                           pct_l2_bi_eoc_wh7_pc                    228
# 364                           pct_l2_e2_eoc_all_pc                    132
# 365                           pct_l2_e2_eoc_bl7_pc                    265
# 366                           pct_l2_e2_eoc_eds_pc                    156
# 367                           pct_l2_e2_eoc_fem_pc                    178
# 368                           pct_l2_e2_eoc_hi7_pc                    269
# 369                          pct_l2_e2_eoc_male_pc                    160
# 370                          pct_l2_e2_eoc_neds_pc                    191
# 371                          pct_l2_e2_eoc_nswd_pc                    150
# 372                           pct_l2_e2_eoc_swd_pc                    295
# 373                           pct_l2_e2_eoc_wh7_pc                    230
# 374                          pct_l3_all_all_aig_pc                    204
# 375                          pct_l3_all_all_all_pc                     87
# 376                          pct_l3_all_all_bl7_pc                    181
# 377                          pct_l3_all_all_eds_pc                    101
# 378                          pct_l3_all_all_fem_pc                     90
# 379                          pct_l3_all_all_hi7_pc                    150
# 380                         pct_l3_all_all_male_pc                    102
# 381                          pct_l3_all_all_mu7_pc                    268
# 382                         pct_l3_all_all_neds_pc                     87
# 383                         pct_l3_all_all_nswd_pc                    102
# 384                          pct_l3_all_all_swd_pc                    324
# 385                          pct_l3_all_all_wh7_pc                     93
# 386                           pct_l3_bi_eoc_all_pc                    186
# 387                           pct_l3_bi_eoc_bl7_pc                    349
# 388                           pct_l3_bi_eoc_eds_pc                    239
# 389                           pct_l3_bi_eoc_fem_pc                    229
# 390                           pct_l3_bi_eoc_hi7_pc                    361
# 391                          pct_l3_bi_eoc_male_pc                    238
# 392                          pct_l3_bi_eoc_neds_pc                    245
# 393                          pct_l3_bi_eoc_nswd_pc                    196
# 394                           pct_l3_bi_eoc_wh7_pc                    286
# 395                           pct_l3_e2_eoc_all_pc                    151
# 396                           pct_l3_e2_eoc_bl7_pc                    313
# 397                           pct_l3_e2_eoc_eds_pc                    175
# 398                           pct_l3_e2_eoc_fem_pc                    187
# 399                           pct_l3_e2_eoc_hi7_pc                    301
# 400                          pct_l3_e2_eoc_male_pc                    188
# 401                          pct_l3_e2_eoc_neds_pc                    205
# 402                          pct_l3_e2_eoc_nswd_pc                    154
# 403                           pct_l3_e2_eoc_wh7_pc                    238
# 404                          pct_l3_eoc_eoc_aig_pc                    211
# 405                          pct_l3_eoc_eoc_all_pc                    100
# 406                          pct_l3_eoc_eoc_bl7_pc                    195
# 407                          pct_l3_eoc_eoc_eds_pc                    115
# 408                          pct_l3_eoc_eoc_fem_pc                    109
# 409                          pct_l3_eoc_eoc_hi7_pc                    167
# 410                         pct_l3_eoc_eoc_male_pc                    111
# 411                          pct_l3_eoc_eoc_mu7_pc                    279
# 412                         pct_l3_eoc_eoc_neds_pc                    103
# 413                         pct_l3_eoc_eoc_nswd_pc                    108
# 414                          pct_l3_eoc_eoc_swd_pc                    341
# 415                          pct_l3_eoc_eoc_wh7_pc                    119
# 416                           pct_l3_m1_eoc_all_pc                    137
# 417                           pct_l3_m1_eoc_bl7_pc                    309
# 418                           pct_l3_m1_eoc_eds_pc                    172
# 419                           pct_l3_m1_eoc_fem_pc                    166
# 420                           pct_l3_m1_eoc_hi7_pc                    306
# 421                          pct_l3_m1_eoc_male_pc                    186
# 422                          pct_l3_m1_eoc_neds_pc                    178
# 423                          pct_l3_m1_eoc_nswd_pc                    144
# 424                           pct_l3_m1_eoc_swd_pc                    364
# 425                           pct_l3_m1_eoc_wh7_pc                    216
# 426                           pct_l3_m3_eoc_aig_pc                    245
# 427                           pct_l3_m3_eoc_all_pc                    128
# 428                           pct_l3_m3_eoc_bl7_pc                    303
# 429                           pct_l3_m3_eoc_eds_pc                    166
# 430                           pct_l3_m3_eoc_fem_pc                    144
# 431                           pct_l3_m3_eoc_hi7_pc                    272
# 432                          pct_l3_m3_eoc_male_pc                    165
# 433                          pct_l3_m3_eoc_neds_pc                    149
# 434                          pct_l3_m3_eoc_nswd_pc                    125
# 435                           pct_l3_m3_eoc_wh7_pc                    190
# 436                          pct_l4_all_all_aig_pc                    145
# 437                          pct_l4_all_all_all_pc                     79
# 438                          pct_l4_all_all_bl7_pc                    188
# 439                          pct_l4_all_all_eds_pc                    104
# 440                          pct_l4_all_all_fem_pc                     87
# 441                          pct_l4_all_all_hi7_pc                    150
# 442                         pct_l4_all_all_male_pc                     89
# 443                          pct_l4_all_all_mu7_pc                    255
# 444                         pct_l4_all_all_neds_pc                     79
# 445                         pct_l4_all_all_nswd_pc                     85
# 446                          pct_l4_all_all_swd_pc                    383
# 447                          pct_l4_all_all_wh7_pc                     81
# 448                           pct_l4_bi_eoc_aig_pc                    241
# 449                           pct_l4_bi_eoc_all_pc                    118
# 450                           pct_l4_bi_eoc_bl7_pc                    278
# 451                           pct_l4_bi_eoc_eds_pc                    158
# 452                           pct_l4_bi_eoc_fem_pc                    153
# 453                           pct_l4_bi_eoc_hi7_pc                    267
# 454                          pct_l4_bi_eoc_male_pc                    150
# 455                          pct_l4_bi_eoc_neds_pc                    141
# 456                          pct_l4_bi_eoc_nswd_pc                    127
# 457                           pct_l4_bi_eoc_swd_pc                    370
# 458                           pct_l4_bi_eoc_wh7_pc                    179
# 459                           pct_l4_e2_eoc_aig_pc                    225
# 460                           pct_l4_e2_eoc_all_pc                    108
# 461                           pct_l4_e2_eoc_bl7_pc                    256
# 462                           pct_l4_e2_eoc_eds_pc                    136
# 463                           pct_l4_e2_eoc_fem_pc                    132
# 464                           pct_l4_e2_eoc_hi7_pc                    254
# 465                          pct_l4_e2_eoc_male_pc                    132
# 466                          pct_l4_e2_eoc_neds_pc                    134
# 467                          pct_l4_e2_eoc_nswd_pc                    112
# 468                           pct_l4_e2_eoc_wh7_pc                    167
# 469                          pct_l4_eoc_eoc_aig_pc                    157
# 470                          pct_l4_eoc_eoc_all_pc                     95
# 471                          pct_l4_eoc_eoc_bl7_pc                    197
# 472                          pct_l4_eoc_eoc_eds_pc                    117
# 473                          pct_l4_eoc_eoc_fem_pc                    101
# 474                          pct_l4_eoc_eoc_hi7_pc                    162
# 475                         pct_l4_eoc_eoc_male_pc                    114
# 476                          pct_l4_eoc_eoc_mu7_pc                    273
# 477                         pct_l4_eoc_eoc_neds_pc                     99
# 478                         pct_l4_eoc_eoc_nswd_pc                     98
# 479                          pct_l4_eoc_eoc_wh7_pc                    108
# 480                           pct_l4_m1_eoc_all_pc                    248
# 481                           pct_l4_m1_eoc_eds_pc                    316
# 482                           pct_l4_m1_eoc_fem_pc                    262
# 483                          pct_l4_m1_eoc_male_pc                    295
# 484                          pct_l4_m1_eoc_neds_pc                    263
# 485                          pct_l4_m1_eoc_nswd_pc                    237
# 486                           pct_l4_m1_eoc_wh7_pc                    286
# 487                           pct_l4_m3_eoc_aig_pc                    230
# 488                           pct_l4_m3_eoc_all_pc                    178
# 489                           pct_l4_m3_eoc_eds_pc                    263
# 490                           pct_l4_m3_eoc_fem_pc                    190
# 491                           pct_l4_m3_eoc_hi7_pc                    322
# 492                          pct_l4_m3_eoc_male_pc                    214
# 493                          pct_l4_m3_eoc_neds_pc                    177
# 494                          pct_l4_m3_eoc_nswd_pc                    174
# 495                           pct_l4_m3_eoc_wh7_pc                    202
# 496                          pct_l5_all_all_aig_pc                    162
# 497                          pct_l5_all_all_all_pc                    312
# 498                          pct_l5_all_all_fem_pc                    307
# 499                         pct_l5_all_all_male_pc                    318
# 500                         pct_l5_all_all_neds_pc                    239
# 501                         pct_l5_all_all_nswd_pc                    294
# 502                          pct_l5_all_all_wh7_pc                    237
# 503                           pct_l5_bi_eoc_aig_pc                    241
# 504                           pct_l5_bi_eoc_all_pc                    212
# 505                           pct_l5_bi_eoc_eds_pc                    315
# 506                           pct_l5_bi_eoc_fem_pc                    232
# 507                           pct_l5_bi_eoc_hi7_pc                    376
# 508                          pct_l5_bi_eoc_male_pc                    230
# 509                          pct_l5_bi_eoc_neds_pc                    200
# 510                          pct_l5_bi_eoc_nswd_pc                    211
# 511                           pct_l5_bi_eoc_wh7_pc                    221
# 512                           pct_l5_e2_eoc_aig_pc                    263
# 513                          pct_l5_e2_eoc_neds_pc                    353
# 514                           pct_l5_e2_eoc_wh7_pc                    368
# 515                          pct_l5_eoc_eoc_aig_pc                    173
# 516                          pct_l5_eoc_eoc_all_pc                    314
# 517                          pct_l5_eoc_eoc_fem_pc                    314
# 518                         pct_l5_eoc_eoc_male_pc                    326
# 519                         pct_l5_eoc_eoc_neds_pc                    245
# 520                         pct_l5_eoc_eoc_nswd_pc                    300
# 521                          pct_l5_eoc_eoc_wh7_pc                    241
# 522                           pct_l5_m3_eoc_aig_pc                    269
# 523                           pct_l5_m3_eoc_all_pc                    374
# 524                          pct_l5_m3_eoc_male_pc                    371
# 525                          pct_l5_m3_eoc_neds_pc                    338
# 526                          pct_l5_m3_eoc_nswd_pc                    367
# 527                           pct_l5_m3_eoc_wh7_pc                    347
# 528                     pct_notprof_all_all_aig_pc                    348
# 529                     pct_notprof_all_all_all_pc                     64
# 530                     pct_notprof_all_all_bl7_pc                    141
# 531                     pct_notprof_all_all_eds_pc                     71
# 532                     pct_notprof_all_all_els_pc                    295
# 533                     pct_notprof_all_all_fem_pc                     70
# 534                     pct_notprof_all_all_hi7_pc                    135
# 535                    pct_notprof_all_all_male_pc                     77
# 536                     pct_notprof_all_all_mu7_pc                    245
# 537                    pct_notprof_all_all_neds_pc                     80
# 538                    pct_notprof_all_all_nswd_pc                     83
# 539                     pct_notprof_all_all_swd_pc                    162
# 540                     pct_notprof_all_all_wh7_pc                     90
# 541                     pct_notprof_eoc_eoc_aig_pc                    352
# 542                     pct_notprof_eoc_eoc_all_pc                     74
# 543                     pct_notprof_eoc_eoc_bl7_pc                    155
# 544                     pct_notprof_eoc_eoc_eds_pc                     85
# 545                     pct_notprof_eoc_eoc_els_pc                    313
# 546                     pct_notprof_eoc_eoc_fem_pc                     89
# 547                     pct_notprof_eoc_eoc_hi7_pc                    159
# 548                    pct_notprof_eoc_eoc_male_pc                     93
# 549                     pct_notprof_eoc_eoc_mu7_pc                    265
# 550                    pct_notprof_eoc_eoc_neds_pc                    100
# 551                    pct_notprof_eoc_eoc_nswd_pc                     89
# 552                     pct_notprof_eoc_eoc_swd_pc                    185
# 553                     pct_notprof_eoc_eoc_wh7_pc                    118
# 554                      pct_notprof_m1_eoc_all_pc                    120
# 555                      pct_notprof_m1_eoc_bl7_pc                    274
# 556                      pct_notprof_m1_eoc_eds_pc                    155
# 557                      pct_notprof_m1_eoc_fem_pc                    172
# 558                      pct_notprof_m1_eoc_hi7_pc                    301
# 559                     pct_notprof_m1_eoc_male_pc                    175
# 560                     pct_notprof_m1_eoc_neds_pc                    184
# 561                     pct_notprof_m1_eoc_nswd_pc                    139
# 562                      pct_notprof_m1_eoc_swd_pc                    273
# 563                      pct_notprof_m1_eoc_wh7_pc                    223
# 564                      pct_notprof_m3_eoc_aig_pc                    341
# 565                      pct_notprof_m3_eoc_all_pc                    113
# 566                      pct_notprof_m3_eoc_bl7_pc                    270
# 567                      pct_notprof_m3_eoc_eds_pc                    145
# 568                      pct_notprof_m3_eoc_fem_pc                    144
# 569                      pct_notprof_m3_eoc_hi7_pc                    272
# 570                     pct_notprof_m3_eoc_male_pc                    154
# 571                     pct_notprof_m3_eoc_neds_pc                    156
# 572                     pct_notprof_m3_eoc_nswd_pc                    118
# 573                      pct_notprof_m3_eoc_swd_pc                    342
# 574                      pct_notprof_m3_eoc_wh7_pc                    200
# 575                             aaa_score_all_spg2                    131
# 576                             aaa_score_bl7_spg2                    305
# 577                             aaa_score_eds_spg2                    167
# 578                             aaa_score_hi7_spg2                    305
# 579                             aaa_score_swd_spg2                    297
# 580                             aaa_score_wh7_spg2                    188
# 581                             ach_score_all_spg2                    122
# 582                             ach_score_bl7_spg2                    301
# 583                             ach_score_eds_spg2                    165
# 584                             ach_score_hi7_spg2                    305
# 585                             ach_score_swd_spg2                    297
# 586                             ach_score_wh7_spg2                    181
# 587                             awa_score_all_spg2                    180
# 588                             awa_score_eds_spg2                    290
# 589                             awa_score_wh7_spg2                    286
# 590                              bi_score_all_spg2                    166
# 591                              bi_score_eds_spg2                    256
# 592                              bi_score_wh7_spg2                    279
# 593                            cgrs_score_all_spg2                    174
# 594                            cgrs_score_eds_spg2                    277
# 595                            cgrs_score_wh7_spg2                    268
# 596                              eg_score_all_spg2                    135
# 597                              eg_score_bl7_spg2                    319
# 598                              eg_score_eds_spg2                    178
# 599                              eg_score_hi7_spg2                    337
# 600                              eg_score_swd_spg2                    322
# 601                              eg_score_wh7_spg2                    211
# 602                             mcr_score_all_spg2                    178
# 603                             mcr_score_eds_spg2                    281
# 604                             mcr_score_wh7_spg2                    283
# 605                             spg_score_all_spg2                    122
# 606                             spg_score_bl7_spg2                    301
# 607                             spg_score_eds_spg2                    165
# 608                             spg_score_hi7_spg2                    305
# 609                             spg_score_swd_spg2                    297
# 610                             spg_score_wh7_spg2                    181
# 611                                     pct_all_wk                    243
# 612                                     pct_eds_wk                    288
# 613                                     pct_fem_wk                    268
# 614                                    pct_male_wk                    267
# 615                                    pct_neds_wk                    267
# 616                                    pct_nswd_wk                    246
# 617                                     pct_wh7_wk                    305
# 618                            avg_student_num_adm                     37
# 619                                 pct_ap_pass_ap                    232
# 620                        pct_ap_participation_ap                    233
# 621                         count_all_chron_absent                     54
# 622                         count_bl7_chron_absent                    129
# 623                         count_els_chron_absent                    217
# 624                         count_fem_chron_absent                     65
# 625                         count_hi7_chron_absent                    113
# 626                        count_male_chron_absent                     83
# 627                         count_mu7_chron_absent                    151
# 628                         count_swd_chron_absent                    151
# 629                         count_wh7_chron_absent                     74
# 630                           pct_all_chron_absent                     54
# 631                           pct_bl7_chron_absent                    129
# 632                           pct_els_chron_absent                    217
# 633                           pct_fem_chron_absent                     65
# 634                           pct_hi7_chron_absent                    113
# 635                          pct_male_chron_absent                     83
# 636                           pct_mu7_chron_absent                    151
# 637                           pct_swd_chron_absent                    151
# 638                           pct_wh7_chron_absent                     74
# 639                  count_2018_enroll_as7_college                    285
# 640                  count_2018_enroll_all_college                     95
# 641                  count_2018_enroll_bl7_college                    131
# 642                  count_2018_enroll_eds_college                    225
# 643                  count_2018_enroll_els_college                    287
# 644                  count_2018_enroll_fem_college                    102
# 645                  count_2018_enroll_hi7_college                    130
# ...
# 689                     tot_num_ap_h_male_courses2                    258
# 690                      tot_num_ap_h_mu7_courses2                    258
# 691                    tot_num_ap_h_other_courses2                    258
# 692                      tot_num_ap_h_pi7_courses2                    258
# 693                      tot_num_ap_h_swd_courses2                    258
# 694                      tot_num_ap_h_wh7_courses2                    258
# 695                     tot_num_ccp_h_am7_courses2                    140
# 696                     tot_num_ccp_h_as7_courses2                    140
# 697                     tot_num_ccp_h_bl7_courses2                    140
# 698                     tot_num_ccp_h_els_courses2                    140
# 699                     tot_num_ccp_h_fem_courses2                    140
# 700                     tot_num_ccp_h_hi7_courses2                    140
# 701                    tot_num_ccp_h_male_courses2                    140
# 702                     tot_num_ccp_h_mu7_courses2                    140
# 703                   tot_num_ccp_h_other_courses2                    140
# 704                     tot_num_ccp_h_pi7_courses2                    140
# 705                     tot_num_ccp_h_swd_courses2                    140
# 706                     tot_num_ccp_h_wh7_courses2                    140
# 707                            year_h_am7_courses2                    139
# 708                            year_h_as7_courses2                    139
# 709                            year_h_bl7_courses2                    139
# 710                            year_h_els_courses2                    139
# 711                            year_h_fem_courses2                    139
# 712                            year_h_hi7_courses2                    139
# 713                           year_h_male_courses2                    139
# 714                            year_h_mu7_courses2                    139
# 715                          year_h_other_courses2                    139
# 716                            year_h_pi7_courses2                    139
# 717                            year_h_swd_courses2                    139
# 718                            year_h_wh7_courses2                    139
# 719                 num_concentrators_aavc_cte_con                    350
# 720                 num_concentrators_agnr_cte_con                    264
# 721                 num_concentrators_arch_cte_con                    260
# 722                  num_concentrators_bma_cte_con                    260
# 723                 num_concentrators_hlth_cte_con                    263
# 724                 num_concentrators_hosp_cte_con                    250
# 725                 num_concentrators_info_cte_con                    253
# 726                 num_concentrators_manu_cte_con                    356
# 727                 num_concentrators_stem_cte_con                    354
# 728                       num_credentials_cte_cred                    130
# 729                 career_only_cte_end_cte_enroll                    159
# 730  career_college_college_unc_cte_end_cte_enroll                    159
# 731    college_college_unc_only_cte_end_cte_enroll                    159
# 732                college_only_cte_end_cte_enroll                    159
# 733                                     stu_enroll                     61
# 734                                     cte_enroll                     61
# 735                                            pct                     61
# 736                                     ni_effect3                     34
# 737                                    eff_effect3                     34
# 738                                     he_effect3                     34
# 739                                 ni_pct_effect3                     34
# 740                                eff_pct_effect3                     34
# 741                                 he_pct_effect3                     34
# 742                          number_of_teachers_eq                     34
# 743                                 beg_teacher_eq                     34
# 744                            pct_beg_teachers_eq                     34
# 745                               prov_teachers_eq                     34
# 746                           pct_prov_teachers_eq                     34
# 747                     adm_central_expense_funds2                     37
# 748                   adm_employee_benefits_funds2                     37
# 749                adm_instructional_equip._funds2                     37
# 750                       adm_other_objects_funds2                     37
# 751                  adm_purchased_services_funds2                     37
# 752                            adm_salaries_funds2                     37
# 753                adm_supplies_&_materials_funds2                     37
# 754                               adm_total_funds2                     37
# 755           federal_funds_central_expense_funds2                     37
# 756         federal_funds_employee_benefits_funds2                     37
# 757      federal_funds_instructional_equip._funds2                     37
# 758             federal_funds_other_objects_funds2                     37
# 759        federal_funds_purchased_services_funds2                     37
# 760                  federal_funds_salaries_funds2                     37
# 761      federal_funds_supplies_&_materials_funds2                     37
# 762                     federal_funds_total_funds2                     37
# 763             federal_ppe_central_expense_funds2                     37
# 764           federal_ppe_employee_benefits_funds2                     37
# 765        federal_ppe_instructional_equip._funds2                     37
# 766               federal_ppe_other_objects_funds2                     37
# 767          federal_ppe_purchased_services_funds2                     37
# 768                    federal_ppe_salaries_funds2                     37
# 769        federal_ppe_supplies_&_materials_funds2                     37
# 770                       federal_ppe_total_funds2                     37
# 771             local_funds_central_expense_funds2                     37
# 772           local_funds_employee_benefits_funds2                     37
# 773        local_funds_instructional_equip._funds2                     37
# 774               local_funds_other_objects_funds2                     37
# 775          local_funds_purchased_services_funds2                     37
# 776                    local_funds_salaries_funds2                     37
# 777        local_funds_supplies_&_materials_funds2                     37
# 778                       local_funds_total_funds2                     37
# 779               local_ppe_central_expense_funds2                     37
# 780             local_ppe_employee_benefits_funds2                     37
# 781          local_ppe_instructional_equip._funds2                     37
# 782                 local_ppe_other_objects_funds2                     37
# 783            local_ppe_purchased_services_funds2                     37
# 784                      local_ppe_salaries_funds2                     37
# 785          local_ppe_supplies_&_materials_funds2                     37
# 786                         local_ppe_total_funds2                     37
# 787             state_funds_central_expense_funds2                     37
# 788           state_funds_employee_benefits_funds2                     37
# 789        state_funds_instructional_equip._funds2                     37
# 790               state_funds_other_objects_funds2                     37
# 791          state_funds_purchased_services_funds2                     37
# 792                    state_funds_salaries_funds2                     37
# 793        state_funds_supplies_&_materials_funds2                     37
# 794                       state_funds_total_funds2                     37
# 795               state_ppe_central_expense_funds2                     37
# 796             state_ppe_employee_benefits_funds2                     37
# 797          state_ppe_instructional_equip._funds2                     37
# 798                 state_ppe_other_objects_funds2                     37
# 799            state_ppe_purchased_services_funds2                     37
# 800                      state_ppe_salaries_funds2                     37
# 801          state_ppe_supplies_&_materials_funds2                     37
# 802                         state_ppe_total_funds2                     37
# 803             total_funds_central_expense_funds2                     37
# 804           total_funds_employee_benefits_funds2                     37
# 805        total_funds_instructional_equip._funds2                     37
# 806               total_funds_other_objects_funds2                     37
# 807          total_funds_purchased_services_funds2                     37
# 808                    total_funds_salaries_funds2                     37
# 809        total_funds_supplies_&_materials_funds2                     37
# 810                       total_funds_total_funds2                     37
# 811               total_ppe_central_expense_funds2                     37
# 812             total_ppe_employee_benefits_funds2                     37
# 813          total_ppe_instructional_equip._funds2                     37
# 814                 total_ppe_other_objects_funds2                     37
# 815            total_ppe_purchased_services_funds2                     37
# 816                      total_ppe_salaries_funds2                     37
# 817          total_ppe_supplies_&_materials_funds2                     37
# 818                         total_ppe_total_funds2                     37
# 819                           act_per1000_all_inc2                     68
# 820                           act_per1000_bl7_inc2                    163
# 821                           act_per1000_eds_inc2                     84
# 822                           act_per1000_els_inc2                    321
# 823                           act_per1000_fem_inc2                    102
# 824                           act_per1000_hi7_inc2                    188
# 825                          act_per1000_male_inc2                     82
# 826                           act_per1000_mu7_inc2                    302
# 827                           act_per1000_swd_inc2                    176
# 828                           act_per1000_wh7_inc2                    115
# 829                           arr_per1000_all_inc2                     68
# 830                           arr_per1000_bl7_inc2                    163
# 831                           arr_per1000_eds_inc2                     84
# 832                           arr_per1000_els_inc2                    321
# 833                           arr_per1000_fem_inc2                    102
# 834                           arr_per1000_hi7_inc2                    188
# 835                          arr_per1000_male_inc2                     82
# 836                           arr_per1000_mu7_inc2                    302
# 837                           arr_per1000_swd_inc2                    176
# 838                           arr_per1000_wh7_inc2                    115
# 839                           bha_per1000_all_inc2                     68
# 840                           bha_per1000_bl7_inc2                    163
# 841                           bha_per1000_eds_inc2                     84
# 842                           bha_per1000_els_inc2                    321
# 843                           bha_per1000_fem_inc2                    102
# 844                           bha_per1000_hi7_inc2                    188
# 845                          bha_per1000_male_inc2                     82
# 846                           bha_per1000_mu7_inc2                    302
# 847                           bha_per1000_swd_inc2                    176
# 848                           bha_per1000_wh7_inc2                    115
# 849                           exp_per1000_all_inc2                     68
# 850                           exp_per1000_bl7_inc2                    163
# 851                           exp_per1000_eds_inc2                     84
# 852                           exp_per1000_els_inc2                    321
# 853                           exp_per1000_fem_inc2                    102
# 854                           exp_per1000_hi7_inc2                    188
# 855                          exp_per1000_male_inc2                     82
# 856                           exp_per1000_mu7_inc2                    302
# 857                           exp_per1000_swd_inc2                    176
# 858                           exp_per1000_wh7_inc2                    115
# 859                           iss_per1000_all_inc2                     68
# 860                           iss_per1000_bl7_inc2                    163
# 861                           iss_per1000_eds_inc2                     84
# 862                           iss_per1000_els_inc2                    321
# 863                           iss_per1000_fem_inc2                    102
# 864                           iss_per1000_hi7_inc2                    188
# 865                          iss_per1000_male_inc2                     82
# 866                           iss_per1000_mu7_inc2                    302
# 867                           iss_per1000_swd_inc2                    176
# 868                           iss_per1000_wh7_inc2                    115
# 869                           lts_per1000_all_inc2                     68
# 870                           lts_per1000_bl7_inc2                    163
# 871                           lts_per1000_eds_inc2                     84
# 872                           lts_per1000_els_inc2                    321
# 873                           lts_per1000_fem_inc2                    102
# 874                           lts_per1000_hi7_inc2                    188
# 875                          lts_per1000_male_inc2                     82
# 876                           lts_per1000_mu7_inc2                    302
# 877                           lts_per1000_swd_inc2                    176
# 878                           lts_per1000_wh7_inc2                    115
# 879                           rpt_per1000_all_inc2                     68
# 880                           rpt_per1000_bl7_inc2                    163
# 881                           rpt_per1000_eds_inc2                     84
# 882                           rpt_per1000_els_inc2                    321
# 883                           rpt_per1000_fem_inc2                    102
# 884                           rpt_per1000_hi7_inc2                    188
# 885                          rpt_per1000_male_inc2                     82
# 886                           rpt_per1000_mu7_inc2                    302
# 887                           rpt_per1000_swd_inc2                    176
# 888                           rpt_per1000_wh7_inc2                    115
# 889                           sts_per1000_all_inc2                     69
# 890                           sts_per1000_bl7_inc2                    169
# 891                           sts_per1000_eds_inc2                     84
# 892                           sts_per1000_els_inc2                    321
# 893                           sts_per1000_fem_inc2                    104
# 894                           sts_per1000_hi7_inc2                    189
# 895                          sts_per1000_male_inc2                     88
# 896                           sts_per1000_mu7_inc2                    302
# 897                           sts_per1000_swd_inc2                    176
# 898                           sts_per1000_wh7_inc2                    116
# 899                           avg_size_biology_sar                     90
# 900                        avg_size_english_ii_sar                     93
# 901                         avg_size_nc_math_1_sar                     90
# 902                         avg_size_nc_math_3_sar                     93
# 903                                  avg_sat_score                    194
# 904                          pct_sat_participation                    192

# %%
#Replace all remaining NaN with 0
schoolData = schoolData.fillna(0)

#Check for Missing values after final imputation 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# Empty DataFrame
# Columns: [Variable Name, Number Missing Values]
# Index: []

# %% [markdown]
# ## Identify and Remove Highly Correlated Features
# **Find and remove any columns / features that are > 95% correlated**
# * https://stackoverflow.com/questions/39409866/correlation-heatmap
# * https://chrisalbon.com/machine_learning/feature_selection/drop_highly_correlated_features/
# * https://codeyarns.com/2015/04/20/how-to-change-font-size-in-seaborn/

# %%
# calculate the correlation matrix
corr_matrix  = schoolData.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
#Print out all the missing value rows
pd.set_option('display.max_rows', 3500)

#Get all of the correlation values > 95%
x = np.where(upper > 0.95)

#Display all field combinations with > 95% correlation
cf = pd.DataFrame()
cf['Field1'] = upper.columns[x[1]]
cf['Field2'] = upper.index[x[0]]

#Get the correlation values for every field combination. (There must be a more pythonic way to do this!)
corr = [0] * len(cf)
for i in range(0, len(cf)):
    corr[i] =  upper[cf['Field1'][i]][cf['Field2'][i]] 
    
cf['Correlation'] = corr

print ('There are ', str(len(cf['Field1'])), ' field correlations > 95%.')
cf
# Out:
# There are  1343  field correlations > 95%.
#                                                  Field1  \
# 0                                     lea_no_attendance
# 1                                  school_no_attendance
# 2                                       indian_male_pct
# 3                                     indian_female_pct
# 4                                        asian_male_pct
# 5                                      asian_female_pct
# 6               ada_adm_ratio_2017_thru_2019_attendance
# 7                                     pct_acall_fem_act
# 8                                    pct_acall_male_act
# 9                                    pct_acall_neds_act
# 10                                   pct_acall_nswd_act
# 11                                     pct_acen_all_act
# 12                                    pct_acen_nswd_act
# 13                                     pct_acma_all_act
# 14                                    pct_acma_nswd_act
# 15                                     pct_acrd_all_act
# 16                                    pct_acrd_nswd_act
# 17                                     pct_acsc_all_act
# 18                                    pct_acsc_nswd_act
# 19                                   pct_acall_neds_act
# 20                                   pct_acall_nswd_act
# 21                                     pct_acen_all_act
# 22                                    pct_acen_nswd_act
# 23                                     pct_acrd_all_act
# 24                                    pct_acrd_nswd_act
# 25                                     pct_acsc_all_act
# 26                                    pct_acsc_nswd_act
# 27                                   pct_acall_neds_act
# 28                                   pct_acall_nswd_act
# 29                                     pct_acrd_all_act
# 30                                   pct_acall_nswd_act
# 31                                    pct_acall_wh7_act
# 32                                     pct_acen_all_act
# 33                                    pct_acen_neds_act
# 34                                    pct_acen_nswd_act
# 35                                     pct_acrd_all_act
# 36                                    pct_acrd_neds_act
# 37                                    pct_acrd_nswd_act
# 38                                    pct_acsc_neds_act
# 39                                     pct_acen_all_act
# 40                                    pct_acen_nswd_act
# 41                                     pct_acma_all_act
# 42                                    pct_acma_nswd_act
# 43                                     pct_acrd_all_act
# 44                                    pct_acrd_nswd_act
# 45                                     pct_acsc_all_act
# 46                                    pct_acsc_nswd_act
# 47                                     pct_acen_aig_act
# 48                                     pct_acco_fem_act
# 49                                    pct_acco_nswd_act
# 50                                     pct_acen_all_act
# 51                                    pct_acen_nswd_act
# 52                                    pct_acco_nswd_act
# 53                                     pct_acen_fem_act
# 54                                    pct_acen_male_act
# 55                                    pct_acco_nswd_act
# 56                                    pct_acen_neds_act
# 57                                     pct_acen_all_act
# 58                                    pct_acen_nswd_act
# 59                                     pct_acen_wh7_act
# 60                                     pct_acma_aig_act
# 61                                     pct_acrd_aig_act
# 62                                     pct_acsc_aig_act
# 63                                     pct_acen_fem_act
# 64                                    pct_acen_neds_act
# 65                                    pct_acen_nswd_act
# 66                                     pct_acrd_all_act
# 67                                    pct_acrd_nswd_act
# 68                                    pct_acen_nswd_act
# 69                                     pct_acrd_fem_act
# 70                                    pct_acrd_male_act
# 71                                    pct_acen_nswd_act
# 72                                    pct_acrd_neds_act
# 73                                     pct_acrd_all_act
# 74                                    pct_acrd_nswd_act
# 75                                     pct_acrd_wh7_act
# 76                                     pct_acsc_wh7_act
# 77                                     pct_acrd_aig_act
# 78                                     pct_acsc_aig_act
# 79                                     pct_acma_fem_act
# 80                                    pct_acma_neds_act
# 81                                    pct_acma_nswd_act
# 82                                     pct_acsc_all_act
# 83                                    pct_acsc_nswd_act
# 84                                    pct_acma_nswd_act
# 85                                    pct_acsc_male_act
# 86                                    pct_acma_nswd_act
# 87                                    pct_acsc_neds_act
# 88                                     pct_acsc_all_act
# 89                                    pct_acsc_nswd_act
# 90                                     pct_acsc_wh7_act
# 91                                     pct_acsc_aig_act
# 92                                     pct_acrd_fem_act
# 93                                    pct_acrd_neds_act
# 94                                    pct_acrd_nswd_act
# 95                                     pct_acsc_all_act
# 96                                    pct_acsc_nswd_act
# 97                                    pct_acrd_nswd_act
# 98                                    pct_acsc_male_act
# 99                                    pct_acrd_nswd_act
# 100                                   pct_acsc_neds_act
# 101                                    pct_acsc_all_act
# 102                                   pct_acsc_nswd_act
# 103                                    pct_acsc_wh7_act
# 104                                   pct_acsc_neds_act
# 105                                   pct_acsc_nswd_act
# 106                                   pct_acsc_nswd_act
# 107                                    pct_acwr_fem_act
# 108                                   pct_acwr_neds_act
# 109                                   pct_acwr_nswd_act
# 110                                   pct_acwr_nswd_act
# 111                                   pct_acwr_nswd_act
# 112                                         pct_aig_mcr
# 113                                        pct_neds_awa
# 114                                        pct_nswd_awa
# 115                                        pct_neds_awa
# 116                                        pct_nswd_awa
# 117                                    pct_ext_neds_cgr
# 118                                    pct_ext_nswd_cgr
# 119                                     pct_std_fem_cgr
# 120                                    pct_std_nswd_cgr
# 121                                    pct_ext_neds_cgr
# 122                                    pct_ext_nswd_cgr
# 123                                    pct_ext_nswd_cgr
# 124                                     pct_std_fem_cgr
# 125                                    pct_std_nswd_cgr
# 126                                     pct_std_fem_cgr
# 127                                    pct_std_nswd_cgr
# 128                                    pct_std_nswd_cgr
# 129                                    pct_std_nswd_cgr
# 130                                   eg_score_bl7_spg2
# 131                                   eg_score_eds_spg2
# 132                                   eg_score_hi7_spg2
# 133                                   eg_score_swd_spg2
# 134                                   eg_score_wh7_spg2
# 135                                         den_els_elp
# 136                                         den_hi7_elp
# 137                                        den_male_elp
# 138                                        den_nswd_elp
# 139                                        den_male_elp
# 140                                         den_hi7_elp
# 141                                        den_male_elp
# 142                                        den_nswd_elp
# 143                                        den_male_elp
# 144                                        den_nswd_elp
# 145                                        den_nswd_elp
# 146                                         pct_els_elp
# 147                  target_assign_reading_grade_10_ltg
# 148                          target_assign_biology_part
# 149                 target_assign_high_school_math_part
# 150                          target_assign_the_act_part
# 151                          target_assign_biology_part
# 152                       target_assign_english_ii_part
# 153                 target_assign_high_school_math_part
# 154                          target_assign_the_act_part
# 155                    target_assign_total_targets_part
# 156                                        pct_nswd_mcr
# 157                                        pct_neds_mcr
# 158                 target_assign_high_school_math_part
# 159                          target_assign_the_act_part
# 160                    target_assign_total_targets_part
# 161                          target_met_english_ii_part
# 162                          target_assign_the_act_part
# 163                    target_assign_total_targets_part
# 164                    target_assign_total_targets_part
# 165                    target_met_high_school_math_part
# 166                   pct_high_school_math_all_part_det
# 167                            pct_the_act_all_part_det
# 168                   pct_high_school_math_eds_part_det
# 169                            pct_the_act_eds_part_det
# 170                   pct_high_school_math_wh7_part_det
# 171                            pct_the_act_wh7_part_det
# 172                            pct_the_act_all_part_det
# 173                            pct_the_act_eds_part_det
# 174                            pct_the_act_wh7_part_det
# 175                               pct_glp_bi_eoc_aig_pc
# 176                              pct_ccr_bi_eoc_nswd_pc
# 177                               pct_glp_bi_eoc_all_pc
# 178                              pct_glp_bi_eoc_nswd_pc
# 179                               pct_glp_bi_eoc_bl7_pc
# 180                               pct_glp_bi_eoc_eds_pc
# 181                               pct_glp_bi_eoc_fem_pc
# 182                               pct_glp_bi_eoc_hi7_pc
# 183                              pct_glp_bi_eoc_male_pc
# 184                              pct_ccr_bi_eoc_nswd_pc
# 185                              pct_glp_bi_eoc_neds_pc
# 186                              pct_glp_bi_eoc_nswd_pc
# 187                               pct_glp_bi_eoc_all_pc
# 188                              pct_glp_bi_eoc_nswd_pc
# 189                                pct_l4_bi_eoc_swd_pc
# 190                               pct_glp_bi_eoc_wh7_pc
# 191                               pct_glp_e2_eoc_aig_pc
# 192                                pct_l4_e2_eoc_aig_pc
# 193                               pct_ccr_e2_eoc_fem_pc
# 194                              pct_ccr_e2_eoc_nswd_pc
# 195                               pct_glp_e2_eoc_all_pc
# 196                              pct_glp_e2_eoc_nswd_pc
# 197                                pct_l4_e2_eoc_all_pc
# 198                               pct_l4_e2_eoc_nswd_pc
# 199                               pct_glp_e2_eoc_bl7_pc
# 200                                pct_l4_e2_eoc_bl7_pc
# 201                               pct_glp_e2_eoc_eds_pc
# 202                                pct_l4_e2_eoc_eds_pc
# 203                              pct_ccr_e2_eoc_nswd_pc
# 204                               pct_glp_e2_eoc_fem_pc
# 205                                pct_l4_e2_eoc_fem_pc
# 206                               pct_glp_e2_eoc_hi7_pc
# 207                                pct_l4_e2_eoc_hi7_pc
# 208                              pct_glp_e2_eoc_male_pc
# 209                               pct_l4_e2_eoc_male_pc
# 210                              pct_glp_e2_eoc_neds_pc
# 211                               pct_l4_e2_eoc_neds_pc
# 212                               pct_glp_e2_eoc_all_pc
# 213                              pct_glp_e2_eoc_nswd_pc
# 214                                pct_l4_e2_eoc_all_pc
# 215                               pct_l4_e2_eoc_nswd_pc
# 216                               pct_glp_e2_eoc_wh7_pc
# 217                                pct_l4_e2_eoc_wh7_pc
# 218                              pct_glp_eoc_eoc_aig_pc
# 219                              pct_ccr_eoc_eoc_fem_pc
# 220                             pct_ccr_eoc_eoc_male_pc
# 221                             pct_ccr_eoc_eoc_neds_pc
# 222                             pct_ccr_eoc_eoc_nswd_pc
# 223                              pct_glp_eoc_eoc_all_pc
# 224                             pct_glp_eoc_eoc_nswd_pc
# 225                               pct_l4_eoc_eoc_all_pc
# 226                              pct_glp_eoc_eoc_bl7_pc
# 227                               pct_l4_eoc_eoc_bl7_pc
# 228                              pct_glp_eoc_eoc_eds_pc
# 229                               pct_l4_all_all_eds_pc
# 230                               pct_l4_eoc_eoc_eds_pc
# 231                             pct_ccr_eoc_eoc_neds_pc
# 232                             pct_ccr_eoc_eoc_nswd_pc
# 233                              pct_glp_eoc_eoc_all_pc
# 234                              pct_glp_eoc_eoc_fem_pc
# 235                               pct_l4_eoc_eoc_fem_pc
# 236                              pct_glp_eoc_eoc_hi7_pc
# 237                               pct_l4_all_all_hi7_pc
# 238                               pct_l4_eoc_eoc_hi7_pc
# 239                             pct_glp_eoc_eoc_male_pc
# 240                              pct_l4_eoc_eoc_male_pc
# 241                              pct_glp_eoc_eoc_mu7_pc
# 242                               pct_l4_eoc_eoc_mu7_pc
# 243                             pct_ccr_eoc_eoc_nswd_pc
# 244                             pct_glp_eoc_eoc_neds_pc
# 245                              pct_l4_eoc_eoc_neds_pc
# 246                              pct_glp_eoc_eoc_all_pc
# 247                             pct_glp_eoc_eoc_nswd_pc
# 248                               pct_l4_eoc_eoc_all_pc
# 249                              pct_l4_eoc_eoc_nswd_pc
# 250                              pct_glp_eoc_eoc_wh7_pc
# 251                               pct_l4_eoc_eoc_wh7_pc
# 252                              pct_ccr_m1_eoc_nswd_pc
# 253                                pct_l4_m1_eoc_all_pc
# 254                               pct_l4_m1_eoc_nswd_pc
# 255                                pct_l4_m1_eoc_eds_pc
# 256                                pct_l4_m1_eoc_fem_pc
# 257                               pct_l4_m1_eoc_male_pc
# 258                               pct_l4_m1_eoc_neds_pc
# 259                                pct_l4_m1_eoc_all_pc
# 260                               pct_l4_m1_eoc_nswd_pc
# 261                                pct_l4_m1_eoc_wh7_pc
# 262                               pct_ccr_m3_eoc_fem_pc
# 263                              pct_ccr_m3_eoc_nswd_pc
# 264                                pct_l4_m3_eoc_eds_pc
# 265                              pct_ccr_m3_eoc_nswd_pc
# 266                                pct_l4_m3_eoc_hi7_pc
# 267                              pct_glp_bi_eoc_nswd_pc
# 268                                pct_l4_bi_eoc_bl7_pc
# 269                              pct_glp_bi_eoc_nswd_pc
# 270                                pct_l4_e2_eoc_aig_pc
# 271                              pct_glp_e2_eoc_nswd_pc
# 272                                pct_l4_e2_eoc_all_pc
# 273                               pct_l4_e2_eoc_nswd_pc
# 274                                pct_l4_e2_eoc_bl7_pc
# 275                                pct_l4_e2_eoc_eds_pc
# 276                              pct_glp_e2_eoc_nswd_pc
# 277                                pct_l4_e2_eoc_fem_pc
# 278                                pct_l4_e2_eoc_hi7_pc
# 279                               pct_l4_e2_eoc_male_pc
# 280                               pct_l4_e2_eoc_neds_pc
# 281                                pct_l4_e2_eoc_all_pc
# 282                               pct_l4_e2_eoc_nswd_pc
# 283                                pct_l4_e2_eoc_wh7_pc
# 284                              pct_glp_eoc_eoc_fem_pc
# 285                             pct_glp_eoc_eoc_neds_pc
# 286                             pct_glp_eoc_eoc_nswd_pc
# 287                               pct_l4_all_all_all_pc
# 288                               pct_l4_eoc_eoc_all_pc
# 289                              pct_l4_eoc_eoc_nswd_pc
# 290                               pct_l4_eoc_eoc_bl7_pc
# 291                               pct_l4_eoc_eoc_eds_pc
# 292                             pct_glp_eoc_eoc_neds_pc
# 293                             pct_glp_eoc_eoc_nswd_pc
# 294                               pct_l4_eoc_eoc_fem_pc
# 295                               pct_l4_eoc_eoc_hi7_pc
# 296                              pct_l4_eoc_eoc_male_pc
# 297                             pct_glp_eoc_eoc_nswd_pc
# 298                              pct_l4_eoc_eoc_neds_pc
# 299                               pct_l4_all_all_all_pc
# 300                              pct_l4_all_all_nswd_pc
# 301                               pct_l4_eoc_eoc_all_pc
# 302                              pct_l4_eoc_eoc_nswd_pc
# 303                               pct_l4_eoc_eoc_wh7_pc
# 304                              pct_glp_m1_eoc_nswd_pc
# 305                                pct_l3_m1_eoc_swd_pc
# 306                               pct_glp_m3_eoc_fem_pc
# 307                              pct_glp_m3_eoc_nswd_pc
# 308                              pct_glp_m3_eoc_nswd_pc
# 309                               pct_l3_eoc_eoc_aig_pc
# 310                               pct_l3_eoc_eoc_all_pc
# 311                               pct_l3_eoc_eoc_bl7_pc
# 312                               pct_l3_eoc_eoc_eds_pc
# 313                               pct_l3_eoc_eoc_hi7_pc
# 314                               pct_l3_eoc_eoc_mu7_pc
# 315                              pct_l3_eoc_eoc_nswd_pc
# 316                               pct_l3_m1_eoc_nswd_pc
# 317                               pct_l3_m3_eoc_nswd_pc
# 318                               pct_l4_eoc_eoc_aig_pc
# 319                               pct_l4_all_all_fem_pc
# 320                              pct_l4_all_all_neds_pc
# 321                              pct_l4_all_all_nswd_pc
# 322                               pct_l4_eoc_eoc_all_pc
# 323                              pct_l4_eoc_eoc_nswd_pc
# 324                               pct_l4_eoc_eoc_bl7_pc
# 325                               pct_l4_eoc_eoc_eds_pc
# 326                              pct_l4_all_all_nswd_pc
# 327                               pct_l4_eoc_eoc_all_pc
# 328                               pct_l4_eoc_eoc_fem_pc
# 329                              pct_l4_eoc_eoc_nswd_pc
# 330                               pct_l4_eoc_eoc_hi7_pc
# 331                              pct_l4_eoc_eoc_male_pc
# 332                               pct_l4_eoc_eoc_mu7_pc
# 333                              pct_l4_all_all_nswd_pc
# 334                              pct_l4_eoc_eoc_neds_pc
# 335                               pct_l4_eoc_eoc_all_pc
# 336                               pct_l4_eoc_eoc_fem_pc
# 337                              pct_l4_eoc_eoc_nswd_pc
# 338                               pct_l4_eoc_eoc_wh7_pc
# 339                               pct_l4_bi_eoc_nswd_pc
# 340                               pct_l4_e2_eoc_nswd_pc
# 341                               pct_l4_eoc_eoc_fem_pc
# 342                              pct_l4_eoc_eoc_neds_pc
# 343                              pct_l4_eoc_eoc_nswd_pc
# 344                              pct_l4_eoc_eoc_nswd_pc
# 345                              pct_l4_eoc_eoc_nswd_pc
# 346                               pct_l4_m1_eoc_nswd_pc
# 347                               pct_l4_m3_eoc_nswd_pc
# 348                               pct_l5_all_all_fem_pc
# 349                              pct_l5_all_all_neds_pc
# 350                              pct_l5_all_all_nswd_pc
# 351                               pct_l5_eoc_eoc_all_pc
# 352                               pct_l5_eoc_eoc_fem_pc
# 353                              pct_l5_eoc_eoc_nswd_pc
# 354                              pct_l5_all_all_nswd_pc
# 355                               pct_l5_eoc_eoc_all_pc
# 356                               pct_l5_eoc_eoc_fem_pc
# 357                              pct_l5_eoc_eoc_nswd_pc
# 358                              pct_l5_eoc_eoc_male_pc
# 359                              pct_l5_all_all_nswd_pc
# 360                              pct_l5_eoc_eoc_neds_pc
# 361                               pct_l5_eoc_eoc_all_pc
# 362                               pct_l5_eoc_eoc_fem_pc
# 363                              pct_l5_eoc_eoc_nswd_pc
# 364                               pct_l5_eoc_eoc_wh7_pc
# 365                               pct_l5_bi_eoc_nswd_pc
# 366                               pct_l5_bi_eoc_nswd_pc
# 367                               pct_l5_eoc_eoc_fem_pc
# 368                              pct_l5_eoc_eoc_nswd_pc
# 369                              pct_l5_eoc_eoc_nswd_pc
# 370                              pct_l5_eoc_eoc_nswd_pc
# 371                               pct_l5_m3_eoc_nswd_pc
# 372                          pct_notprof_eoc_eoc_aig_pc
# 373                         pct_notprof_all_all_male_pc
# 374                         pct_notprof_eoc_eoc_nswd_pc
# 375                          pct_notprof_m3_eoc_nswd_pc
# 376                                  ach_score_hi7_spg2
# 377                                  spg_score_hi7_spg2
# 378                                  spg_score_all_spg2
# 379                                  spg_score_bl7_spg2
# 380                                  spg_score_eds_spg2
# 381                                  spg_score_hi7_spg2
# 382                                  spg_score_swd_spg2
# 383                                  spg_score_wh7_spg2
# 384                                  mcr_score_wh7_spg2
# 385                                  mcr_score_eds_spg2
# 386                                         pct_nswd_wk
# 387                                          stu_enroll
# 388                                          cte_enroll
# 389                               number_of_teachers_eq
# 390                          adm_central_expense_funds2
# 391                        adm_employee_benefits_funds2
# 392                     adm_instructional_equip._funds2
# 393                            adm_other_objects_funds2
# 394                       adm_purchased_services_funds2
# 395                                 adm_salaries_funds2
# 396                     adm_supplies_&_materials_funds2
# 397                                    adm_total_funds2
# 398                state_funds_employee_benefits_funds2
# 399                         state_funds_salaries_funds2
# 400                            state_funds_total_funds2
# 401                total_funds_employee_benefits_funds2
# 402                         total_funds_salaries_funds2
# 403                            total_funds_total_funds2
# 404                              count_fem_chron_absent
# 405                             count_male_chron_absent
# 406                             count_male_chron_absent
# 407                               pct_male_chron_absent
# 408                       count_2018_enroll_fem_college
# 409                      count_2018_enroll_male_college
# 410                      count_2018_enroll_male_college
# 411                       count_2018_noenro_fem_college
# 412                      count_2018_noenro_male_college
# 413                           tot_num_ap_h_as7_courses2
# 414                           tot_num_ap_h_bl7_courses2
# 415                           tot_num_ap_h_els_courses2
# 416                           tot_num_ap_h_fem_courses2
# 417                           tot_num_ap_h_hi7_courses2
# 418                          tot_num_ap_h_male_courses2
# 419                           tot_num_ap_h_mu7_courses2
# 420                         tot_num_ap_h_other_courses2
# 421                           tot_num_ap_h_pi7_courses2
# 422                           tot_num_ap_h_swd_courses2
# 423                           tot_num_ap_h_wh7_courses2
# 424                           tot_num_ap_h_bl7_courses2
# 425                           tot_num_ap_h_els_courses2
# 426                           tot_num_ap_h_fem_courses2
# 427                           tot_num_ap_h_hi7_courses2
# 428                          tot_num_ap_h_male_courses2
# 429                           tot_num_ap_h_mu7_courses2
# 430                         tot_num_ap_h_other_courses2
# 431                           tot_num_ap_h_pi7_courses2
# 432                           tot_num_ap_h_swd_courses2
# 433                           tot_num_ap_h_wh7_courses2
# 434                           tot_num_ap_h_els_courses2
# 435                           tot_num_ap_h_fem_courses2
# 436                           tot_num_ap_h_hi7_courses2
# 437                          tot_num_ap_h_male_courses2
# 438                           tot_num_ap_h_mu7_courses2
# 439                         tot_num_ap_h_other_courses2
# 440                           tot_num_ap_h_pi7_courses2
# 441                           tot_num_ap_h_swd_courses2
# 442                           tot_num_ap_h_wh7_courses2
# 443                           tot_num_ap_h_fem_courses2
# 444                           tot_num_ap_h_hi7_courses2
# 445                          tot_num_ap_h_male_courses2
# 446                           tot_num_ap_h_mu7_courses2
# 447                         tot_num_ap_h_other_courses2
# 448                           tot_num_ap_h_pi7_courses2
# 449                           tot_num_ap_h_swd_courses2
# 450                           tot_num_ap_h_wh7_courses2
# 451                           tot_num_ap_h_hi7_courses2
# 452                          tot_num_ap_h_male_courses2
# 453                           tot_num_ap_h_mu7_courses2
# 454                         tot_num_ap_h_other_courses2
# 455                           tot_num_ap_h_pi7_courses2
# 456                           tot_num_ap_h_swd_courses2
# 457                           tot_num_ap_h_wh7_courses2
# 458                          tot_num_ap_h_male_courses2
# 459                           tot_num_ap_h_mu7_courses2
# 460                         tot_num_ap_h_other_courses2
# 461                           tot_num_ap_h_pi7_courses2
# 462                           tot_num_ap_h_swd_courses2
# 463                           tot_num_ap_h_wh7_courses2
# 464                           tot_num_ap_h_mu7_courses2
# 465                         tot_num_ap_h_other_courses2
# 466                           tot_num_ap_h_pi7_courses2
# 467                           tot_num_ap_h_swd_courses2
# 468                           tot_num_ap_h_wh7_courses2
# 469                         tot_num_ap_h_other_courses2
# 470                           tot_num_ap_h_pi7_courses2
# 471                           tot_num_ap_h_swd_courses2
# 472                           tot_num_ap_h_wh7_courses2
# 473                           tot_num_ap_h_pi7_courses2
# 474                           tot_num_ap_h_swd_courses2
# 475                           tot_num_ap_h_wh7_courses2
# 476                           tot_num_ap_h_swd_courses2
# 477                           tot_num_ap_h_wh7_courses2
# 478                           tot_num_ap_h_wh7_courses2
# 479                          tot_num_ccp_h_as7_courses2
# 480                          tot_num_ccp_h_bl7_courses2
# 481                          tot_num_ccp_h_els_courses2
# 482                          tot_num_ccp_h_fem_courses2
# 483                          tot_num_ccp_h_hi7_courses2
# 484                         tot_num_ccp_h_male_courses2
# 485                          tot_num_ccp_h_mu7_courses2
# 486                        tot_num_ccp_h_other_courses2
# 487                          tot_num_ccp_h_pi7_courses2
# 488                          tot_num_ccp_h_swd_courses2
# 489                          tot_num_ccp_h_wh7_courses2
# 490                          tot_num_ccp_h_bl7_courses2
# 491                          tot_num_ccp_h_els_courses2
# 492                          tot_num_ccp_h_fem_courses2
# 493                          tot_num_ccp_h_hi7_courses2
# 494                         tot_num_ccp_h_male_courses2
# 495                          tot_num_ccp_h_mu7_courses2
# 496                        tot_num_ccp_h_other_courses2
# 497                          tot_num_ccp_h_pi7_courses2
# 498                          tot_num_ccp_h_swd_courses2
# 499                          tot_num_ccp_h_wh7_courses2
# 500                          tot_num_ccp_h_els_courses2
# 501                          tot_num_ccp_h_fem_courses2
# 502                          tot_num_ccp_h_hi7_courses2
# 503                         tot_num_ccp_h_male_courses2
# 504                          tot_num_ccp_h_mu7_courses2
# 505                        tot_num_ccp_h_other_courses2
# 506                          tot_num_ccp_h_pi7_courses2
# 507                          tot_num_ccp_h_swd_courses2
# 508                          tot_num_ccp_h_wh7_courses2
# 509                          tot_num_ccp_h_fem_courses2
# 510                          tot_num_ccp_h_hi7_courses2
# 511                         tot_num_ccp_h_male_courses2
# 512                          tot_num_ccp_h_mu7_courses2
# 513                        tot_num_ccp_h_other_courses2
# 514                          tot_num_ccp_h_pi7_courses2
# 515                          tot_num_ccp_h_swd_courses2
# 516                          tot_num_ccp_h_wh7_courses2
# 517                          tot_num_ccp_h_hi7_courses2
# 518                         tot_num_ccp_h_male_courses2
# 519                          tot_num_ccp_h_mu7_courses2
# 520                        tot_num_ccp_h_other_courses2
# 521                          tot_num_ccp_h_pi7_courses2
# 522                          tot_num_ccp_h_swd_courses2
# 523                          tot_num_ccp_h_wh7_courses2
# 524                         tot_num_ccp_h_male_courses2
# 525                          tot_num_ccp_h_mu7_courses2
# 526                        tot_num_ccp_h_other_courses2
# 527                          tot_num_ccp_h_pi7_courses2
# 528                          tot_num_ccp_h_swd_courses2
# 529                          tot_num_ccp_h_wh7_courses2
# 530                          tot_num_ccp_h_mu7_courses2
# 531                        tot_num_ccp_h_other_courses2
# 532                          tot_num_ccp_h_pi7_courses2
# 533                          tot_num_ccp_h_swd_courses2
# 534                          tot_num_ccp_h_wh7_courses2
# 535                        tot_num_ccp_h_other_courses2
# 536                          tot_num_ccp_h_pi7_courses2
# 537                          tot_num_ccp_h_swd_courses2
# 538                          tot_num_ccp_h_wh7_courses2
# 539                          tot_num_ccp_h_pi7_courses2
# 540                          tot_num_ccp_h_swd_courses2
# 541                          tot_num_ccp_h_wh7_courses2
# 542                          tot_num_ccp_h_swd_courses2
# 543                          tot_num_ccp_h_wh7_courses2
# 544                          tot_num_ccp_h_wh7_courses2
# 545                                 year_h_as7_courses2
# 546                                 year_h_bl7_courses2
# 547                                 year_h_els_courses2
# 548                                 year_h_fem_courses2
# 549                                 year_h_hi7_courses2
# 550                                year_h_male_courses2
# 551                                 year_h_mu7_courses2
# 552                               year_h_other_courses2
# 553                                 year_h_pi7_courses2
# 554                                 year_h_swd_courses2
# 555                                 year_h_wh7_courses2
# 556                                 year_h_bl7_courses2
# 557                                 year_h_els_courses2
# 558                                 year_h_fem_courses2
# 559                                 year_h_hi7_courses2
# 560                                year_h_male_courses2
# 561                                 year_h_mu7_courses2
# 562                               year_h_other_courses2
# 563                                 year_h_pi7_courses2
# 564                                 year_h_swd_courses2
# 565                                 year_h_wh7_courses2
# 566                                 year_h_els_courses2
# 567                                 year_h_fem_courses2
# 568                                 year_h_hi7_courses2
# 569                                year_h_male_courses2
# 570                                 year_h_mu7_courses2
# 571                               year_h_other_courses2
# 572                                 year_h_pi7_courses2
# 573                                 year_h_swd_courses2
# 574                                 year_h_wh7_courses2
# 575                                 year_h_fem_courses2
# 576                                 year_h_hi7_courses2
# 577                                year_h_male_courses2
# 578                                 year_h_mu7_courses2
# 579                               year_h_other_courses2
# 580                                 year_h_pi7_courses2
# 581                                 year_h_swd_courses2
# 582                                 year_h_wh7_courses2
# 583                                 year_h_hi7_courses2
# 584                                year_h_male_courses2
# 585                                 year_h_mu7_courses2
# 586                               year_h_other_courses2
# 587                                 year_h_pi7_courses2
# 588                                 year_h_swd_courses2
# 589                                 year_h_wh7_courses2
# 590                                year_h_male_courses2
# 591                                 year_h_mu7_courses2
# 592                               year_h_other_courses2
# 593                                 year_h_pi7_courses2
# 594                                 year_h_swd_courses2
# 595                                 year_h_wh7_courses2
# 596                                 year_h_mu7_courses2
# 597                               year_h_other_courses2
# 598                                 year_h_pi7_courses2
# 599                                 year_h_swd_courses2
# 600                                 year_h_wh7_courses2
# 601                               year_h_other_courses2
# 602                                 year_h_pi7_courses2
# 603                                 year_h_swd_courses2
# 604                                 year_h_wh7_courses2
# 605                                 year_h_pi7_courses2
# 606                                 year_h_swd_courses2
# 607                                 year_h_wh7_courses2
# 608                                 year_h_swd_courses2
# 609                                 year_h_wh7_courses2
# 610                                 year_h_wh7_courses2
# 611                                          cte_enroll
# 612                               number_of_teachers_eq
# 613                          adm_central_expense_funds2
# 614                        adm_employee_benefits_funds2
# 615                     adm_instructional_equip._funds2
# 616                            adm_other_objects_funds2
# 617                       adm_purchased_services_funds2
# 618                                 adm_salaries_funds2
# 619                     adm_supplies_&_materials_funds2
# 620                                    adm_total_funds2
# 621                state_funds_employee_benefits_funds2
# 622                         state_funds_salaries_funds2
# 623                            state_funds_total_funds2
# 624                total_funds_employee_benefits_funds2
# 625                         total_funds_salaries_funds2
# 626                            total_funds_total_funds2
# 627                          adm_central_expense_funds2
# 628                        adm_employee_benefits_funds2
# 629                     adm_instructional_equip._funds2
# 630                            adm_other_objects_funds2
# 631                       adm_purchased_services_funds2
# 632                                 adm_salaries_funds2
# 633                     adm_supplies_&_materials_funds2
# 634                                    adm_total_funds2
# 635                state_funds_employee_benefits_funds2
# 636                         state_funds_salaries_funds2
# 637                            state_funds_total_funds2
# 638                          adm_central_expense_funds2
# 639                        adm_employee_benefits_funds2
# 640                     adm_instructional_equip._funds2
# 641                            adm_other_objects_funds2
# 642                       adm_purchased_services_funds2
# 643                                 adm_salaries_funds2
# 644                     adm_supplies_&_materials_funds2
# 645                                    adm_total_funds2
# 646                state_funds_employee_benefits_funds2
# 647                         state_funds_salaries_funds2
# 648                            state_funds_total_funds2
# 649                total_funds_employee_benefits_funds2
# 650                         total_funds_salaries_funds2
# 651                            total_funds_total_funds2
# 652                        adm_employee_benefits_funds2
# 653                     adm_instructional_equip._funds2
# 654                            adm_other_objects_funds2
# 655                       adm_purchased_services_funds2
# 656                                 adm_salaries_funds2
# 657                     adm_supplies_&_materials_funds2
# 658                                    adm_total_funds2
# 659                state_funds_employee_benefits_funds2
# 660                         state_funds_salaries_funds2
# 661                            state_funds_total_funds2
# 662                total_funds_employee_benefits_funds2
# 663                         total_funds_salaries_funds2
# 664                            total_funds_total_funds2
# 665                     adm_instructional_equip._funds2
# 666                            adm_other_objects_funds2
# 667                       adm_purchased_services_funds2
# 668                                 adm_salaries_funds2
# 669                     adm_supplies_&_materials_funds2
# 670                                    adm_total_funds2
# 671                state_funds_employee_benefits_funds2
# 672                         state_funds_salaries_funds2
# 673                            state_funds_total_funds2
# 674                total_funds_employee_benefits_funds2
# 675                         total_funds_salaries_funds2
# 676                            total_funds_total_funds2
# 677                            adm_other_objects_funds2
# 678                       adm_purchased_services_funds2
# 679                                 adm_salaries_funds2
# 680                     adm_supplies_&_materials_funds2
# 681                                    adm_total_funds2
# 682                state_funds_employee_benefits_funds2
# 683                         state_funds_salaries_funds2
# 684                            state_funds_total_funds2
# 685                total_funds_employee_benefits_funds2
# 686                         total_funds_salaries_funds2
# 687                            total_funds_total_funds2
# 688                       adm_purchased_services_funds2
# 689                                 adm_salaries_funds2
# 690                     adm_supplies_&_materials_funds2
# 691                                    adm_total_funds2
# 692                state_funds_employee_benefits_funds2
# 693                         state_funds_salaries_funds2
# 694                            state_funds_total_funds2
# 695                total_funds_employee_benefits_funds2
# 696                         total_funds_salaries_funds2
# 697                            total_funds_total_funds2
# 698                                 adm_salaries_funds2
# 699                     adm_supplies_&_materials_funds2
# 700                                    adm_total_funds2
# 701                state_funds_employee_benefits_funds2
# 702                         state_funds_salaries_funds2
# 703                            state_funds_total_funds2
# 704                total_funds_employee_benefits_funds2
# 705                         total_funds_salaries_funds2
# 706                            total_funds_total_funds2
# 707                     adm_supplies_&_materials_funds2
# 708                                    adm_total_funds2
# 709                state_funds_employee_benefits_funds2
# 710                         state_funds_salaries_funds2
# 711                            state_funds_total_funds2
# 712                total_funds_employee_benefits_funds2
# 713                         total_funds_salaries_funds2
# 714                            total_funds_total_funds2
# 715                                    adm_total_funds2
# 716                state_funds_employee_benefits_funds2
# 717                         state_funds_salaries_funds2
# 718                            state_funds_total_funds2
# 719                total_funds_employee_benefits_funds2
# 720                         total_funds_salaries_funds2
# 721                            total_funds_total_funds2
# 722                state_funds_employee_benefits_funds2
# 723                         state_funds_salaries_funds2
# 724                            state_funds_total_funds2
# 725                total_funds_employee_benefits_funds2
# 726                         total_funds_salaries_funds2
# 727                            total_funds_total_funds2
# 728                       federal_funds_salaries_funds2
# 729                    local_funds_other_objects_funds2
# 730                    total_funds_other_objects_funds2
# 731                          federal_funds_total_funds2
# 732                         federal_ppe_salaries_funds2
# 733                            federal_ppe_total_funds2
# 734                      local_ppe_other_objects_funds2
# 735                      total_ppe_other_objects_funds2
# 736                            federal_ppe_total_funds2
# 737                  total_funds_central_expense_funds2
# 738                         local_funds_salaries_funds2
# 739                            local_funds_total_funds2
# 740                    total_funds_other_objects_funds2
# 741               total_funds_purchased_services_funds2
# 742                            local_funds_total_funds2
# 743                           local_ppe_salaries_funds2
# 744                      total_ppe_other_objects_funds2
# 745                         state_funds_salaries_funds2
# 746                            state_funds_total_funds2
# 747                total_funds_employee_benefits_funds2
# 748                         total_funds_salaries_funds2
# 749                            total_funds_total_funds2
# 750                            state_funds_total_funds2
# 751                total_funds_employee_benefits_funds2
# 752                         total_funds_salaries_funds2
# 753                            total_funds_total_funds2
# 754                total_funds_employee_benefits_funds2
# 755                         total_funds_salaries_funds2
# 756                            total_funds_total_funds2
# 757                  total_ppe_employee_benefits_funds2
# 758                         total_funds_salaries_funds2
# 759                            total_funds_total_funds2
# 760                            total_funds_total_funds2
# 761                                arr_per1000_bl7_inc2
# 762                                arr_per1000_fem_inc2
# 763                               arr_per1000_male_inc2
# 764                               arr_per1000_male_inc2
# 765                                exp_per1000_bl7_inc2
# 766                               exp_per1000_male_inc2
# 767                                exp_per1000_eds_inc2
# 768                                exp_per1000_els_inc2
# 769                                exp_per1000_wh7_inc2
# 770                               iss_per1000_male_inc2
# 771                                lts_per1000_fem_inc2
# 772                                rpt_per1000_eds_inc2
# 773                   lea_name_Alexander County Schools
# 774        lea_name_attendance_Alexander County Schools
# 775                                county_loc_Alleghany
# 776                   lea_name_Alleghany County Schools
# 777        lea_name_attendance_Alleghany County Schools
# 778                                    county_loc_Anson
# 779                       lea_name_Anson County Schools
# 780            lea_name_attendance_Anson County Schools
# 781                                     county_loc_Ashe
# 782                        lea_name_Ashe County Schools
# 783                                    county_loc_Avery
# 784                       lea_name_Avery County Schools
# 785            lea_name_attendance_Avery County Schools
# 786                                 county_loc_Beaufort
# 787                    lea_name_Beaufort County Schools
# 788         lea_name_attendance_Beaufort County Schools
# 789                                   county_loc_Bertie
# 790                      lea_name_Bertie County Schools
# 791           lea_name_attendance_Bertie County Schools
# 792                                   county_loc_Bladen
# 793                      lea_name_Bladen County Schools
# 794           lea_name_attendance_Bladen County Schools
# 795                                county_loc_Brunswick
# 796                   lea_name_Brunswick County Schools
# 797        lea_name_attendance_Brunswick County Schools
# 798                    lea_name_Buncombe County Schools
# 799         lea_name_attendance_Buncombe County Schools
# 800                     lea_name_Asheville City Schools
# 801          lea_name_attendance_Asheville City Schools
# 802                                    county_loc_Burke
# 803                       lea_name_Burke County Schools
# 804            lea_name_attendance_Burke County Schools
# 805                    lea_name_Cabarrus County Schools
# 806         lea_name_attendance_Cabarrus County Schools
# 807                    lea_name_Kannapolis City Schools
# 808         lea_name_attendance_Kannapolis City Schools
# 809                                 county_loc_Caldwell
# 810                    lea_name_Caldwell County Schools
# ...
# 1105                           county_loc_Cleveland     1.000000
# 1106                           county_loc_Cleveland     1.000000
# 1107                              county_loc_Craven     1.000000
# 1108                              county_loc_Craven     1.000000
# 1109                           county_loc_Currituck     1.000000
# 1110                           county_loc_Currituck     1.000000
# 1111                                county_loc_Dare     1.000000
# 1112                                county_loc_Dare     1.000000
# 1113                               county_loc_Davie     1.000000
# 1114                               county_loc_Davie     1.000000
# 1115                              county_loc_Duplin     1.000000
# 1116                              county_loc_Duplin     1.000000
# 1117                              county_loc_Durham     0.965325
# 1118                              county_loc_Durham     0.965325
# 1119                           county_loc_Edgecombe     1.000000
# 1120                           county_loc_Edgecombe     1.000000
# 1121                             county_loc_Forsyth     0.975118
# 1122                             county_loc_Forsyth     0.975118
# 1123                            county_loc_Franklin     1.000000
# 1124                            county_loc_Franklin     1.000000
# 1125                              county_loc_Gaston     1.000000
# 1126                              county_loc_Gaston     1.000000
# 1127                               county_loc_Gates     1.000000
# 1128                               county_loc_Gates     1.000000
# 1129                              county_loc_Graham     1.000000
# 1130                              county_loc_Graham     1.000000
# 1131                           county_loc_Granville     1.000000
# 1132                           county_loc_Granville     1.000000
# 1133                              county_loc_Greene     1.000000
# 1134                              county_loc_Greene     1.000000
# 1135                            county_loc_Guilford     1.000000
# 1136                            county_loc_Guilford     1.000000
# 1137                             county_loc_Harnett     1.000000
# 1138                             county_loc_Harnett     1.000000
# 1139                             county_loc_Haywood     1.000000
# 1140                             county_loc_Haywood     1.000000
# 1141                           county_loc_Henderson     1.000000
# 1142                           county_loc_Henderson     1.000000
# 1143                            county_loc_Hertford     1.000000
# 1144                            county_loc_Hertford     1.000000
# 1145                                county_loc_Hoke     1.000000
# 1146                                county_loc_Hoke     1.000000
# 1147                                county_loc_Hyde     1.000000
# 1148                                county_loc_Hyde     1.000000
# 1149                             county_loc_Jackson     1.000000
# 1150                             county_loc_Jackson     1.000000
# 1151                            county_loc_Johnston     1.000000
# 1152                            county_loc_Johnston     1.000000
# 1153                               county_loc_Jones     1.000000
# 1154                               county_loc_Jones     1.000000
# 1155                                 county_loc_Lee     1.000000
# 1156                                 county_loc_Lee     1.000000
# 1157                               county_loc_Macon     1.000000
# 1158                               county_loc_Macon     1.000000
# 1159                             county_loc_Madison     1.000000
# 1160                             county_loc_Madison     1.000000
# 1161                              county_loc_Martin     1.000000
# 1162                              county_loc_Martin     1.000000
# 1163                            county_loc_McDowell     1.000000
# 1164                            county_loc_McDowell     1.000000
# 1165                         county_loc_Mecklenburg     1.000000
# 1166                         county_loc_Mecklenburg     1.000000
# 1167                            county_loc_Mitchell     1.000000
# 1168                            county_loc_Mitchell     1.000000
# 1169                               county_loc_Moore     1.000000
# 1170                               county_loc_Moore     1.000000
# 1171                         county_loc_Northampton     1.000000
# 1172                         county_loc_Northampton     1.000000
# 1173                              county_loc_Onslow     1.000000
# 1174                              county_loc_Onslow     1.000000
# 1175                             county_loc_Pamlico     1.000000
# 1176                             county_loc_Pamlico     1.000000
# 1177                          county_loc_Pasquotank     1.000000
# 1178                          county_loc_Pasquotank     1.000000
# 1179                              county_loc_Pender     1.000000
# 1180                              county_loc_Pender     1.000000
# 1181                          county_loc_Perquimans     1.000000
# 1182                          county_loc_Perquimans     1.000000
# 1183                              county_loc_Person     1.000000
# 1184                              county_loc_Person     1.000000
# 1185                                county_loc_Polk     1.000000
# 1186                                county_loc_Polk     1.000000
# 1187                            county_loc_Richmond     1.000000
# 1188                            county_loc_Richmond     1.000000
# 1189                          county_loc_Rockingham     1.000000
# 1190                          county_loc_Rockingham     1.000000
# 1191                               county_loc_Rowan     1.000000
# 1192                               county_loc_Rowan     1.000000
# 1193                          county_loc_Rutherford     1.000000
# 1194                          county_loc_Rutherford     1.000000
# 1195                            county_loc_Scotland     1.000000
# 1196                            county_loc_Scotland     1.000000
# 1197                              county_loc_Stanly     1.000000
# 1198                              county_loc_Stokes     1.000000
# 1199                              county_loc_Stokes     1.000000
# 1200                               county_loc_Swain     1.000000
# 1201                               county_loc_Swain     1.000000
# 1202                        county_loc_Transylvania     1.000000
# 1203                        county_loc_Transylvania     1.000000
# 1204                             county_loc_Tyrrell     1.000000
# 1205                             county_loc_Tyrrell     1.000000
# 1206                               county_loc_Union     1.000000
# 1207                               county_loc_Union     1.000000
# 1208                               county_loc_Vance     1.000000
# 1209                               county_loc_Vance     1.000000
# 1210                                county_loc_Wake     0.984378
# 1211                                county_loc_Wake     0.984378
# 1212                          county_loc_Washington     1.000000
# 1213                          county_loc_Washington     1.000000
# 1214                             county_loc_Watauga     1.000000
# 1215                             county_loc_Watauga     1.000000
# 1216                               county_loc_Wayne     1.000000
# 1217                               county_loc_Wayne     1.000000
# 1218                              county_loc_Wilson     1.000000
# 1219                              county_loc_Wilson     1.000000
# 1220                              county_loc_Yadkin     1.000000
# 1221                              county_loc_Yadkin     1.000000
# 1222                              county_loc_Yancey     1.000000
# 1223                              county_loc_Yancey     1.000000
# 1224                              county_loc_Yancey     1.000000
# 1225                   stree_addr2_loc_309 Ashe Ave     1.000000
# 1226                               grade_span_loc_9     1.000000
# 1227                           grade_span_loc_P0:13     1.000000
# 1228                           grade_span_loc_P1:12     1.000000
# 1229                           grade_span_loc_P1:12     1.000000
# 1230              lea_name_Alexander County Schools     1.000000
# 1231              lea_name_Alleghany County Schools     1.000000
# 1232                  lea_name_Anson County Schools     1.000000
# 1233                 lea_name_Asheboro City Schools     1.000000
# 1234                lea_name_Asheville City Schools     1.000000
# 1235                  lea_name_Avery County Schools     1.000000
# 1236               lea_name_Beaufort County Schools     1.000000
# 1237                 lea_name_Bertie County Schools     1.000000
# 1238                 lea_name_Bladen County Schools     1.000000
# 1239              lea_name_Brunswick County Schools     1.000000
# 1240               lea_name_Buncombe County Schools     1.000000
# 1241                  lea_name_Burke County Schools     1.000000
# 1242               lea_name_Cabarrus County Schools     1.000000
# 1243               lea_name_Caldwell County Schools     1.000000
# 1244                 lea_name_Camden County Schools     1.000000
# 1245               lea_name_Carteret County Schools     1.000000
# 1246                lea_name_Caswell County Schools     1.000000
# 1247                lea_name_Catawba County Schools     1.000000
# 1248     lea_name_Chapel-Hill/Carrboro City Schools     1.000000
# 1249  lea_name_Charlotte-Mecklenburg County Schools     1.000000
# 1250                lea_name_Chatham County Schools     1.000000
# 1251               lea_name_Cherokee County Schools     1.000000
# 1252                   lea_name_Clay County Schools     1.000000
# 1253              lea_name_Cleveland County Schools     1.000000
# 1254                  lea_name_Clinton City Schools     1.000000
# 1255               lea_name_Columbus County Schools     1.000000
# 1256                 lea_name_Craven County Schools     1.000000
# 1257             lea_name_Cumberland County Schools     1.000000
# 1258              lea_name_Currituck County Schools     1.000000
# 1259                   lea_name_Dare County Schools     1.000000
# 1260               lea_name_Davidson County Schools     1.000000
# 1261                  lea_name_Davie County Schools     1.000000
# 1262                 lea_name_Duplin County Schools     1.000000
# 1263                 lea_name_Durham County Schools     1.000000
# 1264         lea_name_Edenton-Chowan County Schools     1.000000
# 1265              lea_name_Edgecombe County Schools     1.000000
# 1266                    lea_name_Elkin City Schools     1.000000
# 1267                lea_name_Forsyth County Schools     1.000000
# 1268               lea_name_Franklin County Schools     1.000000
# 1269                 lea_name_Gaston County Schools     1.000000
# 1270                  lea_name_Gates County Schools     1.000000
# 1271                 lea_name_Graham County Schools     1.000000
# 1272              lea_name_Granville County Schools     1.000000
# 1273                 lea_name_Greene County Schools     1.000000
# 1274               lea_name_Guilford County Schools     1.000000
# 1275                lea_name_Halifax County Schools     1.000000
# 1276                lea_name_Harnett County Schools     1.000000
# 1277                lea_name_Haywood County Schools     1.000000
# 1278              lea_name_Henderson County Schools     1.000000
# 1279               lea_name_Hertford County Schools     1.000000
# 1280                  lea_name_Hickory City Schools     1.000000
# 1281                   lea_name_Hoke County Schools     1.000000
# 1282                   lea_name_Hyde County Schools     1.000000
# 1283           lea_name_Iredell-Statesville Schools     1.000000
# 1284                lea_name_Jackson County Schools     1.000000
# 1285               lea_name_Johnston County Schools     1.000000
# 1286                  lea_name_Jones County Schools     1.000000
# 1287               lea_name_Kannapolis City Schools     1.000000
# 1288                    lea_name_Lee County Schools     1.000000
# 1289                 lea_name_Lenoir County Schools     1.000000
# 1290                lea_name_Lexington City Schools     1.000000
# 1291                lea_name_Lincoln County Schools     1.000000
# 1292                  lea_name_Macon County Schools     1.000000
# 1293                lea_name_Madison County Schools     1.000000
# 1294                 lea_name_Martin County Schools     1.000000
# 1295               lea_name_McDowell County Schools     1.000000
# 1296               lea_name_Mitchell County Schools     1.000000
# 1297             lea_name_Montgomery County Schools     1.000000
# 1298                  lea_name_Moore County Schools     1.000000
# 1299              lea_name_Mooresville City Schools     1.000000
# 1300               lea_name_Mount Airy City Schools     1.000000
# 1301              lea_name_Nash-Rocky Mount Schools     1.000000
# 1302            lea_name_New Hanover County Schools     1.000000
# 1303           lea_name_Newton-Conover City Schools     1.000000
# 1304            lea_name_Northampton County Schools     1.000000
# 1305                 lea_name_Onslow County Schools     1.000000
# 1306                 lea_name_Orange County Schools     1.000000
# 1307                lea_name_Pamlico County Schools     1.000000
# 1308             lea_name_Pasquotank County Schools     1.000000
# 1309                 lea_name_Pender County Schools     1.000000
# 1310             lea_name_Perquimans County Schools     1.000000
# 1311                 lea_name_Person County Schools     1.000000
# 1312                   lea_name_Pitt County Schools     1.000000
# 1313                   lea_name_Polk County Schools     1.000000
# 1314               lea_name_Randolph County Schools     1.000000
# 1315               lea_name_Richmond County Schools     1.000000
# 1316           lea_name_Roanoke Rapids City Schools     1.000000
# 1317                lea_name_Robeson County Schools     1.000000
# 1318             lea_name_Rockingham County Schools     1.000000
# 1319        lea_name_Rowan-Salisbury County Schools     1.000000
# 1320             lea_name_Rutherford County Schools     1.000000
# 1321                lea_name_Sampson County Schools     1.000000
# 1322               lea_name_Scotland County Schools     1.000000
# 1323                 lea_name_Stokes County Schools     1.000000
# 1324                  lea_name_Surry County Schools     1.000000
# 1325                  lea_name_Swain County Schools     1.000000
# 1326              lea_name_Thomasville City Schools     1.000000
# 1327           lea_name_Transylvania County Schools     1.000000
# 1328                lea_name_Tyrrell County Schools     1.000000
# 1329                  lea_name_Union County Schools     1.000000
# 1330                  lea_name_Vance County Schools     1.000000
# 1331                   lea_name_Wake County Schools     1.000000
# 1332                 lea_name_Warren County Schools     1.000000
# 1333             lea_name_Washington County Schools     1.000000
# 1334                lea_name_Watauga County Schools     1.000000
# 1335                  lea_name_Wayne County Schools     1.000000
# 1336                   lea_name_Weldon City Schools     1.000000
# 1337               lea_name_Whiteville City Schools     1.000000
# 1338                 lea_name_Wilkes County Schools     1.000000
# 1339                 lea_name_Wilson County Schools     1.000000
# 1340                 lea_name_Yadkin County Schools     1.000000
# 1341                 lea_name_Yancey County Schools     1.000000
# 1342                    grade_span_attendance_PK-13     1.000000

# %%
print('Dropping the following ', str(len(cf['Field2'].unique())), ' highly correlated, unique fields.')
cf['Field2'].unique()
# Out:
# Dropping the following  589  highly correlated, unique fields.
# array(['lea', 'school', 'indian_pct', 'asian_pct',
#        'ada_adm_ratio_2018_attendance', 'pct_acall_all_act',
#        'pct_acall_fem_act', 'pct_acall_male_act', 'pct_acall_neds_act',
#        'pct_acall_nswd_act', 'pct_acco_aig_act', 'pct_acco_all_act',
#        'pct_acco_fem_act', 'pct_acco_male_act', 'pct_acco_neds_act',
#        'pct_acco_nswd_act', 'pct_acco_wh7_act', 'pct_acen_aig_act',
#        'pct_acen_all_act', 'pct_acen_fem_act', 'pct_acen_male_act',
#        'pct_acen_neds_act', 'pct_acen_nswd_act', 'pct_acen_wh7_act',
#        'pct_acma_aig_act', 'pct_acma_all_act', 'pct_acma_fem_act',
#        'pct_acma_male_act', 'pct_acma_neds_act', 'pct_acma_nswd_act',
#        'pct_acma_wh7_act', 'pct_acrd_aig_act', 'pct_acrd_all_act',
#        'pct_acrd_fem_act', 'pct_acrd_male_act', 'pct_acrd_neds_act',
#        'pct_acrd_nswd_act', 'pct_acrd_wh7_act', 'pct_acsc_all_act',
#        'pct_acsc_neds_act', 'pct_acwr_all_act', 'pct_acwr_fem_act',
#        'pct_acwr_neds_act', 'pct_aig_awa', 'pct_all_awa', 'pct_fem_awa',
#        'pct_neds_awa', 'pct_ext_all_cgr', 'pct_ext_fem_cgr',
#        'pct_ext_neds_cgr', 'pct_ext_nswd_cgr', 'pct_std_all_cgr',
#        'pct_std_fem_cgr', 'pct_std_neds_cgr', 'eg_score_all_bl7_eg',
#        'eg_score_all_eds_eg', 'eg_score_all_hi7_eg',
#        'eg_score_all_swd_eg', 'eg_score_all_wh7_eg', 'den_all_elp',
#        'den_eds_elp', 'den_els_elp', 'den_hi7_elp', 'den_male_elp',
#        'pct_all_elp', 'target_assign_math_grade_11_ltg',
#        'target_assign_reading_grade_10_ltg',
#        'target_assign_total_targets_ltg', 'pct_all_mcr', 'pct_fem_mcr',
#        'target_assign_biology_part', 'target_assign_english_ii_part',
#        'target_assign_high_school_math_part',
#        'target_assign_the_act_part', 'target_met_biology_part',
#        'pct_biology_all_part_det', 'pct_biology_eds_part_det',
#        'pct_biology_wh7_part_det', 'pct_high_school_math_all_part_det',
#        'pct_high_school_math_eds_part_det',
#        'pct_high_school_math_wh7_part_det', 'pct_ccr_bi_eoc_aig_pc',
#        'pct_ccr_bi_eoc_all_pc', 'pct_ccr_bi_eoc_bl7_pc',
#        'pct_ccr_bi_eoc_eds_pc', 'pct_ccr_bi_eoc_fem_pc',
#        'pct_ccr_bi_eoc_hi7_pc', 'pct_ccr_bi_eoc_male_pc',
#        'pct_ccr_bi_eoc_neds_pc', 'pct_ccr_bi_eoc_nswd_pc',
#        'pct_ccr_bi_eoc_swd_pc', 'pct_ccr_bi_eoc_wh7_pc',
#        'pct_ccr_e2_eoc_aig_pc', 'pct_ccr_e2_eoc_all_pc',
#        'pct_ccr_e2_eoc_bl7_pc', 'pct_ccr_e2_eoc_eds_pc',
#        'pct_ccr_e2_eoc_fem_pc', 'pct_ccr_e2_eoc_hi7_pc',
#        'pct_ccr_e2_eoc_male_pc', 'pct_ccr_e2_eoc_neds_pc',
#        'pct_ccr_e2_eoc_nswd_pc', 'pct_ccr_e2_eoc_wh7_pc',
#        'pct_ccr_eoc_eoc_aig_pc', 'pct_ccr_eoc_eoc_all_pc',
#        'pct_ccr_eoc_eoc_bl7_pc', 'pct_ccr_eoc_eoc_eds_pc',
#        'pct_ccr_eoc_eoc_fem_pc', 'pct_ccr_eoc_eoc_hi7_pc',
#        'pct_ccr_eoc_eoc_male_pc', 'pct_ccr_eoc_eoc_mu7_pc',
#        'pct_ccr_eoc_eoc_neds_pc', 'pct_ccr_eoc_eoc_nswd_pc',
#        'pct_ccr_eoc_eoc_wh7_pc', 'pct_ccr_m1_eoc_all_pc',
#        'pct_ccr_m1_eoc_eds_pc', 'pct_ccr_m1_eoc_fem_pc',
#        'pct_ccr_m1_eoc_male_pc', 'pct_ccr_m1_eoc_neds_pc',
#        'pct_ccr_m1_eoc_nswd_pc', 'pct_ccr_m1_eoc_wh7_pc',
#        'pct_ccr_m3_eoc_all_pc', 'pct_ccr_m3_eoc_eds_pc',
#        'pct_ccr_m3_eoc_fem_pc', 'pct_ccr_m3_eoc_hi7_pc',
#        'pct_glp_bi_eoc_all_pc', 'pct_glp_bi_eoc_bl7_pc',
#        'pct_glp_bi_eoc_neds_pc', 'pct_glp_e2_eoc_aig_pc',
#        'pct_glp_e2_eoc_all_pc', 'pct_glp_e2_eoc_bl7_pc',
#        'pct_glp_e2_eoc_eds_pc', 'pct_glp_e2_eoc_fem_pc',
#        'pct_glp_e2_eoc_hi7_pc', 'pct_glp_e2_eoc_male_pc',
#        'pct_glp_e2_eoc_neds_pc', 'pct_glp_e2_eoc_nswd_pc',
#        'pct_glp_e2_eoc_wh7_pc', 'pct_glp_eoc_eoc_all_pc',
#        'pct_glp_eoc_eoc_bl7_pc', 'pct_glp_eoc_eoc_eds_pc',
#        'pct_glp_eoc_eoc_fem_pc', 'pct_glp_eoc_eoc_hi7_pc',
#        'pct_glp_eoc_eoc_male_pc', 'pct_glp_eoc_eoc_neds_pc',
#        'pct_glp_eoc_eoc_nswd_pc', 'pct_glp_eoc_eoc_wh7_pc',
#        'pct_glp_m1_eoc_all_pc', 'pct_glp_m1_eoc_swd_pc',
#        'pct_glp_m3_eoc_all_pc', 'pct_glp_m3_eoc_fem_pc',
#        'pct_l3_all_all_aig_pc', 'pct_l3_all_all_all_pc',
#        'pct_l3_all_all_bl7_pc', 'pct_l3_all_all_eds_pc',
#        'pct_l3_all_all_hi7_pc', 'pct_l3_all_all_mu7_pc',
#        'pct_l3_all_all_nswd_pc', 'pct_l3_m1_eoc_all_pc',
#        'pct_l3_m3_eoc_all_pc', 'pct_l4_all_all_aig_pc',
#        'pct_l4_all_all_all_pc', 'pct_l4_all_all_bl7_pc',
#        'pct_l4_all_all_eds_pc', 'pct_l4_all_all_fem_pc',
#        'pct_l4_all_all_hi7_pc', 'pct_l4_all_all_male_pc',
#        'pct_l4_all_all_mu7_pc', 'pct_l4_all_all_neds_pc',
#        'pct_l4_all_all_nswd_pc', 'pct_l4_all_all_wh7_pc',
#        'pct_l4_bi_eoc_all_pc', 'pct_l4_e2_eoc_all_pc',
#        'pct_l4_eoc_eoc_all_pc', 'pct_l4_eoc_eoc_fem_pc',
#        'pct_l4_eoc_eoc_neds_pc', 'pct_l4_m1_eoc_all_pc',
#        'pct_l4_m3_eoc_all_pc', 'pct_l5_all_all_all_pc',
#        'pct_l5_all_all_fem_pc', 'pct_l5_all_all_male_pc',
#        'pct_l5_all_all_neds_pc', 'pct_l5_all_all_nswd_pc',
#        'pct_l5_all_all_wh7_pc', 'pct_l5_bi_eoc_all_pc',
#        'pct_l5_bi_eoc_neds_pc', 'pct_l5_eoc_eoc_all_pc',
#        'pct_l5_eoc_eoc_fem_pc', 'pct_l5_eoc_eoc_neds_pc',
#        'pct_l5_m3_eoc_all_pc', 'pct_notprof_all_all_aig_pc',
#        'pct_notprof_all_all_all_pc', 'pct_notprof_all_all_nswd_pc',
#        'pct_notprof_m3_eoc_all_pc', 'aaa_score_hi7_spg2',
#        'ach_score_all_spg2', 'ach_score_bl7_spg2', 'ach_score_eds_spg2',
#        'ach_score_hi7_spg2', 'ach_score_swd_spg2', 'ach_score_wh7_spg2',
#        'awa_score_wh7_spg2', 'cgrs_score_eds_spg2', 'pct_all_wk',
#        'avg_student_num_adm', 'count_all_chron_absent',
#        'count_fem_chron_absent', 'pct_all_chron_absent',
#        'count_2018_enroll_all_college', 'count_2018_enroll_fem_college',
#        'count_2018_noenro_all_college', 'tot_num_ap_h_am7_courses2',
#        'tot_num_ap_h_as7_courses2', 'tot_num_ap_h_bl7_courses2',
#        'tot_num_ap_h_els_courses2', 'tot_num_ap_h_fem_courses2',
#        'tot_num_ap_h_hi7_courses2', 'tot_num_ap_h_male_courses2',
#        'tot_num_ap_h_mu7_courses2', 'tot_num_ap_h_other_courses2',
#        'tot_num_ap_h_pi7_courses2', 'tot_num_ap_h_swd_courses2',
#        'tot_num_ccp_h_am7_courses2', 'tot_num_ccp_h_as7_courses2',
#        'tot_num_ccp_h_bl7_courses2', 'tot_num_ccp_h_els_courses2',
#        'tot_num_ccp_h_fem_courses2', 'tot_num_ccp_h_hi7_courses2',
#        'tot_num_ccp_h_male_courses2', 'tot_num_ccp_h_mu7_courses2',
#        'tot_num_ccp_h_other_courses2', 'tot_num_ccp_h_pi7_courses2',
#        'tot_num_ccp_h_swd_courses2', 'year_h_am7_courses2',
#        'year_h_as7_courses2', 'year_h_bl7_courses2',
#        'year_h_els_courses2', 'year_h_fem_courses2',
#        'year_h_hi7_courses2', 'year_h_male_courses2',
#        'year_h_mu7_courses2', 'year_h_other_courses2',
#        'year_h_pi7_courses2', 'year_h_swd_courses2', 'stu_enroll',
#        'cte_enroll', 'number_of_teachers_eq',
#        'adm_central_expense_funds2', 'adm_employee_benefits_funds2',
#        'adm_instructional_equip._funds2', 'adm_other_objects_funds2',
#        'adm_purchased_services_funds2', 'adm_salaries_funds2',
#        'adm_supplies_&_materials_funds2', 'adm_total_funds2',
#        'federal_funds_employee_benefits_funds2',
#        'federal_funds_other_objects_funds2',
#        'federal_funds_salaries_funds2',
#        'federal_ppe_employee_benefits_funds2',
#        'federal_ppe_other_objects_funds2', 'federal_ppe_salaries_funds2',
#        'local_funds_central_expense_funds2',
#        'local_funds_employee_benefits_funds2',
#        'local_funds_other_objects_funds2',
#        'local_funds_purchased_services_funds2',
#        'local_funds_salaries_funds2',
#        'local_ppe_employee_benefits_funds2',
#        'local_ppe_other_objects_funds2',
#        'state_funds_employee_benefits_funds2',
#        'state_funds_salaries_funds2', 'state_funds_total_funds2',
#        'state_ppe_employee_benefits_funds2',
#        'total_funds_employee_benefits_funds2',
#        'total_funds_salaries_funds2', 'arr_per1000_all_inc2',
#        'arr_per1000_bl7_inc2', 'exp_per1000_all_inc2',
#        'exp_per1000_bl7_inc2', 'exp_per1000_els_inc2',
#        'iss_per1000_all_inc2', 'lts_per1000_bl7_inc2',
#        'rpt_per1000_all_inc2', 'lea_code_loc_020LEA',
#        'lea_code_loc_030LEA', 'lea_code_loc_040LEA',
#        'lea_code_loc_050LEA', 'lea_code_loc_060LEA',
#        'lea_code_loc_070LEA', 'lea_code_loc_080LEA',
#        'lea_code_loc_090LEA', 'lea_code_loc_100LEA',
#        'lea_code_loc_110LEA', 'lea_code_loc_111LEA',
#        'lea_code_loc_120LEA', 'lea_code_loc_130LEA',
#        'lea_code_loc_132LEA', 'lea_code_loc_140LEA',
#        'lea_code_loc_150LEA', 'lea_code_loc_160LEA',
#        'lea_code_loc_170LEA', 'lea_code_loc_180LEA',
#        'lea_code_loc_181LEA', 'lea_code_loc_182LEA',
#        'lea_code_loc_190LEA', 'lea_code_loc_200LEA',
#        'lea_code_loc_210LEA', 'lea_code_loc_220LEA',
#        'lea_code_loc_230LEA', 'lea_code_loc_240LEA',
#        'lea_code_loc_241LEA', 'lea_code_loc_250LEA',
#        'lea_code_loc_260LEA', 'lea_code_loc_270LEA',
#        'lea_code_loc_280LEA', 'lea_code_loc_290LEA',
#        'lea_code_loc_291LEA', 'lea_code_loc_292LEA',
#        'lea_code_loc_299LEA', 'lea_code_loc_300LEA',
#        'lea_code_loc_310LEA', 'lea_code_loc_320LEA',
#        'lea_code_loc_330LEA', 'lea_code_loc_340LEA',
#        'lea_code_loc_350LEA', 'lea_code_loc_360LEA',
#        'lea_code_loc_370LEA', 'lea_code_loc_380LEA',
#        'lea_code_loc_390LEA', 'lea_code_loc_400LEA',
#        'lea_code_loc_410LEA', 'lea_code_loc_420LEA',
#        'lea_code_loc_421LEA', 'lea_code_loc_422LEA',
#        'lea_code_loc_430LEA', 'lea_code_loc_440LEA',
#        'lea_code_loc_450LEA', 'lea_code_loc_460LEA',
#        'lea_code_loc_470LEA', 'lea_code_loc_480LEA',
#        'lea_code_loc_490LEA', 'lea_code_loc_500LEA',
#        'lea_code_loc_510LEA', 'lea_code_loc_520LEA',
#        'lea_code_loc_530LEA', 'lea_code_loc_540LEA',
#        'lea_code_loc_550LEA', 'lea_code_loc_560LEA',
#        'lea_code_loc_570LEA', 'lea_code_loc_580LEA',
#        'lea_code_loc_590LEA', 'lea_code_loc_600LEA',
#        'lea_code_loc_610LEA', 'lea_code_loc_620LEA',
#        'lea_code_loc_630LEA', 'lea_code_loc_640LEA',
#        'lea_code_loc_650LEA', 'lea_code_loc_660LEA',
#        'lea_code_loc_670LEA', 'lea_code_loc_680LEA',
#        'lea_code_loc_681LEA', 'lea_code_loc_690LEA',
#        'lea_code_loc_700LEA', 'lea_code_loc_710LEA',
#        'lea_code_loc_720LEA', 'lea_code_loc_730LEA',
#        'lea_code_loc_740LEA', 'lea_code_loc_750LEA',
#        'lea_code_loc_760LEA', 'lea_code_loc_761LEA',
#        'lea_code_loc_770LEA', 'lea_code_loc_780LEA',
#        'lea_code_loc_790LEA', 'lea_code_loc_800LEA',
#        'lea_code_loc_810LEA', 'lea_code_loc_820LEA',
#        'lea_code_loc_821LEA', 'lea_code_loc_830LEA',
#        'lea_code_loc_840LEA', 'lea_code_loc_850LEA',
#        'lea_code_loc_860LEA', 'lea_code_loc_861LEA',
#        'lea_code_loc_862LEA', 'lea_code_loc_870LEA',
#        'lea_code_loc_880LEA', 'lea_code_loc_890LEA',
#        'lea_code_loc_900LEA', 'lea_code_loc_910LEA',
#        'lea_code_loc_920LEA', 'lea_code_loc_930LEA',
#        'lea_code_loc_940LEA', 'lea_code_loc_950LEA',
#        'lea_code_loc_960LEA', 'lea_code_loc_970LEA',
#        'lea_code_loc_980LEA', 'lea_code_loc_990LEA',
#        'lea_code_loc_995LEA', 'lea_code_loc_998LEA',
#        'county_loc_Alleghany', 'county_loc_Anson', 'county_loc_Ashe',
#        'county_loc_Avery', 'county_loc_Beaufort', 'county_loc_Bertie',
#        'county_loc_Bladen', 'county_loc_Brunswick', 'county_loc_Burke',
#        'county_loc_Caldwell', 'county_loc_Camden', 'county_loc_Carteret',
#        'county_loc_Caswell', 'county_loc_Cherokee', 'county_loc_Chowan',
#        'county_loc_Clay', 'county_loc_Cleveland', 'county_loc_Craven',
#        'county_loc_Currituck', 'county_loc_Dare', 'county_loc_Davie',
#        'county_loc_Duplin', 'county_loc_Durham', 'county_loc_Edgecombe',
#        'county_loc_Forsyth', 'county_loc_Franklin', 'county_loc_Gaston',
#        'county_loc_Gates', 'county_loc_Graham', 'county_loc_Granville',
#        'county_loc_Greene', 'county_loc_Guilford', 'county_loc_Harnett',
#        'county_loc_Haywood', 'county_loc_Henderson',
#        'county_loc_Hertford', 'county_loc_Hoke', 'county_loc_Hyde',
#        'county_loc_Jackson', 'county_loc_Johnston', 'county_loc_Jones',
#        'county_loc_Lee', 'county_loc_Macon', 'county_loc_Madison',
#        'county_loc_Martin', 'county_loc_McDowell',
#        'county_loc_Mecklenburg', 'county_loc_Mitchell',
#        'county_loc_Moore', 'county_loc_Northampton', 'county_loc_Onslow',
#        'county_loc_Pamlico', 'county_loc_Pasquotank', 'county_loc_Pender',
#        'county_loc_Perquimans', 'county_loc_Person', 'county_loc_Polk',
#        'county_loc_Richmond', 'county_loc_Rockingham', 'county_loc_Rowan',
#        'county_loc_Rutherford', 'county_loc_Scotland',
#        'county_loc_Stanly', 'county_loc_Stokes', 'county_loc_Swain',
#        'county_loc_Transylvania', 'county_loc_Tyrrell',
#        'county_loc_Union', 'county_loc_Vance', 'county_loc_Wake',
#        'county_loc_Washington', 'county_loc_Watauga', 'county_loc_Wayne',
#        'county_loc_Wilson', 'county_loc_Yadkin', 'county_loc_Yancey',
#        'stree_addr2_loc_309 Ashe Ave', 'grade_span_loc_9',
#        'grade_span_loc_P0:13', 'grade_span_loc_P1:12',
#        'lea_name_Alexander County Schools',
#        'lea_name_Alleghany County Schools',
#        'lea_name_Anson County Schools', 'lea_name_Asheboro City Schools',
#        'lea_name_Asheville City Schools', 'lea_name_Avery County Schools',
#        'lea_name_Beaufort County Schools',
#        'lea_name_Bertie County Schools', 'lea_name_Bladen County Schools',
#        'lea_name_Brunswick County Schools',
#        'lea_name_Buncombe County Schools',
#        'lea_name_Burke County Schools',
#        'lea_name_Cabarrus County Schools',
#        'lea_name_Caldwell County Schools',
#        'lea_name_Camden County Schools',
#        'lea_name_Carteret County Schools',
#        'lea_name_Caswell County Schools',
#        'lea_name_Catawba County Schools',
#        'lea_name_Chapel-Hill/Carrboro City Schools',
#        'lea_name_Charlotte-Mecklenburg County Schools',
#        'lea_name_Chatham County Schools',
#        'lea_name_Cherokee County Schools', 'lea_name_Clay County Schools',
#        'lea_name_Cleveland County Schools',
#        'lea_name_Clinton City Schools',
#        'lea_name_Columbus County Schools',
#        'lea_name_Craven County Schools',
#        'lea_name_Cumberland County Schools',
#        'lea_name_Currituck County Schools',
#        'lea_name_Dare County Schools', 'lea_name_Davidson County Schools',
#        'lea_name_Davie County Schools', 'lea_name_Duplin County Schools',
#        'lea_name_Durham County Schools',
#        'lea_name_Edenton-Chowan County Schools',
#        'lea_name_Edgecombe County Schools', 'lea_name_Elkin City Schools',
#        'lea_name_Forsyth County Schools',
#        'lea_name_Franklin County Schools',
#        'lea_name_Gaston County Schools', 'lea_name_Gates County Schools',
#        'lea_name_Graham County Schools',
#        'lea_name_Granville County Schools',
#        'lea_name_Greene County Schools',
#        'lea_name_Guilford County Schools',
#        'lea_name_Halifax County Schools',
#        'lea_name_Harnett County Schools',
#        'lea_name_Haywood County Schools',
#        'lea_name_Henderson County Schools',
#        'lea_name_Hertford County Schools',
#        'lea_name_Hickory City Schools', 'lea_name_Hoke County Schools',
#        'lea_name_Hyde County Schools',
#        'lea_name_Iredell-Statesville Schools',
#        'lea_name_Jackson County Schools',
#        'lea_name_Johnston County Schools',
#        'lea_name_Jones County Schools',
#        'lea_name_Kannapolis City Schools', 'lea_name_Lee County Schools',
#        'lea_name_Lenoir County Schools',
#        'lea_name_Lexington City Schools',
#        'lea_name_Lincoln County Schools', 'lea_name_Macon County Schools',
#        'lea_name_Madison County Schools',
#        'lea_name_Martin County Schools',
#        'lea_name_McDowell County Schools',
#        'lea_name_Mitchell County Schools',
#        'lea_name_Montgomery County Schools',
#        'lea_name_Moore County Schools',
#        'lea_name_Mooresville City Schools',
#        'lea_name_Mount Airy City Schools',
#        'lea_name_Nash-Rocky Mount Schools',
#        'lea_name_New Hanover County Schools',
#        'lea_name_Newton-Conover City Schools',
#        'lea_name_Northampton County Schools',
#        'lea_name_Onslow County Schools', 'lea_name_Orange County Schools',
#        'lea_name_Pamlico County Schools',
#        'lea_name_Pasquotank County Schools',
#        'lea_name_Pender County Schools',
#        'lea_name_Perquimans County Schools',
#        'lea_name_Person County Schools', 'lea_name_Pitt County Schools',
#        'lea_name_Polk County Schools', 'lea_name_Randolph County Schools',
#        'lea_name_Richmond County Schools',
#        'lea_name_Roanoke Rapids City Schools',
#        'lea_name_Robeson County Schools',
#        'lea_name_Rockingham County Schools',
#        'lea_name_Rowan-Salisbury County Schools',
#        'lea_name_Rutherford County Schools',
#        'lea_name_Sampson County Schools',
#        'lea_name_Scotland County Schools',
#        'lea_name_Stokes County Schools', 'lea_name_Surry County Schools',
#        'lea_name_Swain County Schools',
#        'lea_name_Thomasville City Schools',
#        'lea_name_Transylvania County Schools',
#        'lea_name_Tyrrell County Schools', 'lea_name_Union County Schools',
#        'lea_name_Vance County Schools', 'lea_name_Wake County Schools',
#        'lea_name_Warren County Schools',
#        'lea_name_Washington County Schools',
#        'lea_name_Watauga County Schools', 'lea_name_Wayne County Schools',
#        'lea_name_Weldon City Schools', 'lea_name_Whiteville City Schools',
#        'lea_name_Wilkes County Schools', 'lea_name_Wilson County Schools',
#        'lea_name_Yadkin County Schools', 'lea_name_Yancey County Schools',
#        'grade_span_attendance_PK-13'], dtype=object)

# %%
#Check columns before drop 
print('\r\n*********Before: Dropping Highly Correlated Fields*************************************')
schoolData.info(verbose=False)

# Drop the highly correlated features from our training data 
#schoolData = schoolData.drop(to_drop, axis=1)
schoolData = schoolData.drop(cf['Field2'], axis=1)

#Check columns after drop 
print('\r\n*********After: Dropping Highly Correlated Fields**************************************')
schoolData.info(verbose=False)
# Out:
# *********Before: Dropping Highly Correlated Fields*************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 644 entries, 2 to 715
# Columns: 1502 entries, lea to poverty_eq_NEITHER
# dtypes: float64(905), uint8(597)
# memory usage: 4.8 MB
#
# *********After: Dropping Highly Correlated Fields**************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 644 entries, 2 to 715
# Columns: 913 entries, hispanic_pct to poverty_eq_NEITHER
# dtypes: float64(624), uint8(289)
# memory usage: 3.2 MB

# %%
#Restore the unit_code before saving
schoolData['agency_code'] = agency_code
#Save the final dataset to a .csv file
schoolData.to_csv(outputDir + inputFileName + '_ML.csv', sep=',', index=False)

# %%
print('*********FINAL DATASET DETAILS*********************************************************\r\n')
schoolData.info(verbose=True)
# Out:
# *********FINAL DATASET DETAILS*********************************************************
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 644 entries, 2 to 715
# Data columns (total 914 columns):
#  #   Column                                                                                                                       Dtype
# ---  ------                                                                                                                       -----
#  0   hispanic_pct                                                                                                                 float64
#  1   black_pct                                                                                                                    float64
#  2   white_pct                                                                                                                    float64
#  3   pacific_island_pct                                                                                                           float64
#  4   two_or_more_pct                                                                                                              float64
#  5   minority_pct                                                                                                                 float64
#  6   indian_male_pct                                                                                                              float64
#  7   asian_male_pct                                                                                                               float64
#  8   hispanic_male_pct                                                                                                            float64
#  9   black_male_pct                                                                                                               float64
#  10  white_male_pct                                                                                                               float64
#  11  pacific_island_male_pct                                                                                                      float64
#  12  two_or_more_male_pct                                                                                                         float64
#  13  minority_male_pct                                                                                                            float64
#  14  indian_female_pct                                                                                                            float64
#  15  asian_female_pct                                                                                                             float64
#  16  hispanic_female_pct                                                                                                          float64
#  17  black_female_pct                                                                                                             float64
#  18  white_female_pct                                                                                                             float64
#  19  minority_female_pct                                                                                                          float64
#  20  pacific_island_female_pct                                                                                                    float64
#  21  two_or_more_female_pct                                                                                                       float64
#  22  lea_no_attendance                                                                                                            float64
#  23  school_no_attendance                                                                                                         float64
#  24  ada_adm_ratio_2018.1_attendance                                                                                              float64
#  25  ada_adm_ratio_2019_attendance                                                                                                float64
#  26  ada_adm_ratio_2017_thru_2019_attendance                                                                                      float64
#  27  ada_adm_rank_2017_thru_2019_attendance                                                                                       float64
#  28  pct_acall_aig_act                                                                                                            float64
#  29  pct_acall_as7_act                                                                                                            float64
#  30  pct_acall_bl7_act                                                                                                            float64
#  31  pct_acall_eds_act                                                                                                            float64
#  32  pct_acall_els_act                                                                                                            float64
#  33  pct_acall_hi7_act                                                                                                            float64
#  34  pct_acall_mu7_act                                                                                                            float64
#  35  pct_acall_swd_act                                                                                                            float64
#  36  pct_acall_wh7_act                                                                                                            float64
#  37  pct_acco_bl7_act                                                                                                             float64
#  38  pct_acco_eds_act                                                                                                             float64
#  39  pct_acco_hi7_act                                                                                                             float64
#  40  pct_acco_swd_act                                                                                                             float64
#  41  pct_acen_bl7_act                                                                                                             float64
#  42  pct_acen_eds_act                                                                                                             float64
#  43  pct_acen_hi7_act                                                                                                             float64
#  44  pct_acen_swd_act                                                                                                             float64
#  45  pct_acma_bl7_act                                                                                                             float64
#  46  pct_acma_eds_act                                                                                                             float64
#  47  pct_acma_hi7_act                                                                                                             float64
#  48  pct_acma_swd_act                                                                                                             float64
#  49  pct_acrd_bl7_act                                                                                                             float64
#  50  pct_acrd_eds_act                                                                                                             float64
#  51  pct_acrd_hi7_act                                                                                                             float64
#  52  pct_acrd_swd_act                                                                                                             float64
#  53  pct_acsc_aig_act                                                                                                             float64
#  54  pct_acsc_bl7_act                                                                                                             float64
#  55  pct_acsc_eds_act                                                                                                             float64
#  56  pct_acsc_fem_act                                                                                                             float64
#  57  pct_acsc_hi7_act                                                                                                             float64
#  58  pct_acsc_male_act                                                                                                            float64
#  59  pct_acsc_nswd_act                                                                                                            float64
#  60  pct_acsc_swd_act                                                                                                             float64
#  61  pct_acsc_wh7_act                                                                                                             float64
#  62  pct_acwr_aig_act                                                                                                             float64
#  63  pct_acwr_bl7_act                                                                                                             float64
#  64  pct_acwr_eds_act                                                                                                             float64
#  65  pct_acwr_hi7_act                                                                                                             float64
#  66  pct_acwr_male_act                                                                                                            float64
#  67  pct_acwr_nswd_act                                                                                                            float64
#  68  pct_acwr_swd_act                                                                                                             float64
#  69  pct_acwr_wh7_act                                                                                                             float64
#  70  pct_bl7_awa                                                                                                                  float64
#  71  pct_eds_awa                                                                                                                  float64
#  72  pct_hi7_awa                                                                                                                  float64
#  73  pct_male_awa                                                                                                                 float64
#  74  pct_nswd_awa                                                                                                                 float64
#  75  pct_swd_awa                                                                                                                  float64
#  76  pct_wh7_awa                                                                                                                  float64
#  77  pct_ext_aig_cgr                                                                                                              float64
#  78  pct_ext_bl7_cgr                                                                                                              float64
#  79  pct_ext_eds_cgr                                                                                                              float64
#  80  pct_ext_hi7_cgr                                                                                                              float64
#  81  pct_ext_male_cgr                                                                                                             float64
#  82  pct_ext_swd_cgr                                                                                                              float64
#  83  pct_ext_wh7_cgr                                                                                                              float64
#  84  pct_std_aig_cgr                                                                                                              float64
#  85  pct_std_bl7_cgr                                                                                                              float64
#  86  pct_std_eds_cgr                                                                                                              float64
#  87  pct_std_hi7_cgr                                                                                                              float64
#  88  pct_std_male_cgr                                                                                                             float64
#  89  pct_std_nswd_cgr                                                                                                             float64
#  90  pct_std_swd_cgr                                                                                                              float64
#  91  pct_std_wh7_cgr                                                                                                              float64
#  92  pct_eds                                                                                                                      float64
#  93  eg_index_all_aig_eg                                                                                                          float64
#  94  eg_index_all_all_eg                                                                                                          float64
#  95  eg_index_all_bl7_eg                                                                                                          float64
#  96  eg_index_all_eds_eg                                                                                                          float64
#  97  eg_index_all_hi7_eg                                                                                                          float64
#  98  eg_index_all_swd_eg                                                                                                          float64
#  99  eg_index_all_wh7_eg                                                                                                          float64
#  100 eg_score_all_aig_eg                                                                                                          float64
#  101 eg_score_all_all_eg                                                                                                          float64
#  102 den_nswd_elp                                                                                                                 float64
#  103 pct_eds_elp                                                                                                                  float64
#  104 pct_els_elp                                                                                                                  float64
#  105 pct_hi7_elp                                                                                                                  float64
#  106 pct_male_elp                                                                                                                 float64
#  107 pct_nswd_elp                                                                                                                 float64
#  108 pct_prof_9gr_irm                                                                                                             float64
#  109 pct_met_4_year_graduation_rate_ltg                                                                                           float64
#  110 pct_met_math_grade_11_ltg                                                                                                    float64
#  111 pct_met_reading_grade_10_ltg                                                                                                 float64
#  112 pct_met_total_targets_ltg                                                                                                    float64
#  113 target_assign_4_year_graduation_rate_ltg                                                                                     float64
#  114 target_met_4_year_graduation_rate_ltg                                                                                        float64
#  115 target_met_math_grade_11_ltg                                                                                                 float64
#  116 target_met_reading_grade_10_ltg                                                                                              float64
#  117 target_met_total_targets_ltg                                                                                                 float64
#  118 pct_aig_mcr                                                                                                                  float64
#  119 pct_bl7_mcr                                                                                                                  float64
#  120 pct_eds_mcr                                                                                                                  float64
#  121 pct_hi7_mcr                                                                                                                  float64
#  122 pct_male_mcr                                                                                                                 float64
#  123 pct_neds_mcr                                                                                                                 float64
#  124 pct_nswd_mcr                                                                                                                 float64
#  125 pct_swd_mcr                                                                                                                  float64
#  126 pct_wh7_mcr                                                                                                                  float64
#  127 pct_met_act_workkeys_part                                                                                                    float64
#  128 pct_met_biology_part                                                                                                         float64
#  129 pct_met_english_ii_part                                                                                                      float64
#  130 pct_met_high_school_math_part                                                                                                float64
#  131 pct_met_the_act_part                                                                                                         float64
#  132 pct_met_total_targets_part                                                                                                   float64
#  133 target_assign_act_workkeys_part                                                                                              float64
#  134 target_assign_total_targets_part                                                                                             float64
#  135 target_met_act_workkeys_part                                                                                                 float64
#  136 target_met_english_ii_part                                                                                                   float64
#  137 target_met_high_school_math_part                                                                                             float64
#  138 target_met_the_act_part                                                                                                      float64
#  139 target_met_total_targets_part                                                                                                float64
#  140 pct_act_workkeys_all_part_det                                                                                                float64
#  141 pct_act_workkeys_wh7_part_det                                                                                                float64
#  142 pct_english_ii_all_part_det                                                                                                  float64
#  143 pct_english_ii_eds_part_det                                                                                                  float64
#  144 pct_english_ii_wh7_part_det                                                                                                  float64
#  145 pct_the_act_all_part_det                                                                                                     float64
#  146 pct_the_act_eds_part_det                                                                                                     float64
#  147 pct_the_act_wh7_part_det                                                                                                     float64
#  148 pct_ccr_e2_eoc_swd_pc                                                                                                        float64
#  149 pct_ccr_eoc_eoc_swd_pc                                                                                                       float64
#  150 pct_ccr_m3_eoc_aig_pc                                                                                                        float64
#  151 pct_ccr_m3_eoc_male_pc                                                                                                       float64
#  152 pct_ccr_m3_eoc_neds_pc                                                                                                       float64
#  153 pct_ccr_m3_eoc_nswd_pc                                                                                                       float64
#  154 pct_ccr_m3_eoc_wh7_pc                                                                                                        float64
#  155 pct_glp_bi_eoc_aig_pc                                                                                                        float64
#  156 pct_glp_bi_eoc_eds_pc                                                                                                        float64
#  157 pct_glp_bi_eoc_fem_pc                                                                                                        float64
#  158 pct_glp_bi_eoc_hi7_pc                                                                                                        float64
#  159 pct_glp_bi_eoc_male_pc                                                                                                       float64
#  160 pct_glp_bi_eoc_nswd_pc                                                                                                       float64
#  161 pct_glp_bi_eoc_swd_pc                                                                                                        float64
#  162 pct_glp_bi_eoc_wh7_pc                                                                                                        float64
#  163 pct_glp_e2_eoc_swd_pc                                                                                                        float64
#  164 pct_glp_eoc_eoc_aig_pc                                                                                                       float64
#  165 pct_glp_eoc_eoc_els_pc                                                                                                       float64
#  166 pct_glp_eoc_eoc_mu7_pc                                                                                                       float64
#  167 pct_glp_eoc_eoc_swd_pc                                                                                                       float64
#  168 pct_glp_m1_eoc_bl7_pc                                                                                                        float64
#  169 pct_glp_m1_eoc_eds_pc                                                                                                        float64
#  170 pct_glp_m1_eoc_fem_pc                                                                                                        float64
#  171 pct_glp_m1_eoc_hi7_pc                                                                                                        float64
#  172 pct_glp_m1_eoc_male_pc                                                                                                       float64
#  173 pct_glp_m1_eoc_neds_pc                                                                                                       float64
#  174 pct_glp_m1_eoc_nswd_pc                                                                                                       float64
#  175 pct_glp_m1_eoc_wh7_pc                                                                                                        float64
#  176 pct_glp_m3_eoc_aig_pc                                                                                                        float64
#  177 pct_glp_m3_eoc_bl7_pc                                                                                                        float64
#  178 pct_glp_m3_eoc_eds_pc                                                                                                        float64
#  179 pct_glp_m3_eoc_hi7_pc                                                                                                        float64
#  180 pct_glp_m3_eoc_male_pc                                                                                                       float64
#  181 pct_glp_m3_eoc_neds_pc                                                                                                       float64
#  182 pct_glp_m3_eoc_nswd_pc                                                                                                       float64
#  183 pct_glp_m3_eoc_wh7_pc                                                                                                        float64
#  184 pct_l1_bi_eoc_all_pc                                                                                                         float64
#  185 pct_l1_bi_eoc_bl7_pc                                                                                                         float64
#  186 pct_l1_bi_eoc_eds_pc                                                                                                         float64
#  187 pct_l1_bi_eoc_fem_pc                                                                                                         float64
#  188 pct_l1_bi_eoc_hi7_pc                                                                                                         float64
#  189 pct_l1_bi_eoc_male_pc                                                                                                        float64
#  190 pct_l1_bi_eoc_neds_pc                                                                                                        float64
#  191 pct_l1_bi_eoc_nswd_pc                                                                                                        float64
#  192 pct_l1_bi_eoc_swd_pc                                                                                                         float64
#  193 pct_l1_bi_eoc_wh7_pc                                                                                                         float64
#  194 pct_l1_e2_eoc_all_pc                                                                                                         float64
#  195 pct_l1_e2_eoc_bl7_pc                                                                                                         float64
#  196 pct_l1_e2_eoc_eds_pc                                                                                                         float64
#  197 pct_l1_e2_eoc_fem_pc                                                                                                         float64
#  198 pct_l1_e2_eoc_hi7_pc                                                                                                         float64
#  199 pct_l1_e2_eoc_male_pc                                                                                                        float64
#  200 pct_l1_e2_eoc_neds_pc                                                                                                        float64
#  201 pct_l1_e2_eoc_nswd_pc                                                                                                        float64
#  202 pct_l1_e2_eoc_swd_pc                                                                                                         float64
#  203 pct_l1_e2_eoc_wh7_pc                                                                                                         float64
#  204 pct_l2_bi_eoc_all_pc                                                                                                         float64
#  205 pct_l2_bi_eoc_bl7_pc                                                                                                         float64
#  206 pct_l2_bi_eoc_eds_pc                                                                                                         float64
#  207 pct_l2_bi_eoc_fem_pc                                                                                                         float64
#  208 pct_l2_bi_eoc_hi7_pc                                                                                                         float64
#  209 pct_l2_bi_eoc_male_pc                                                                                                        float64
#  210 pct_l2_bi_eoc_neds_pc                                                                                                        float64
#  211 pct_l2_bi_eoc_nswd_pc                                                                                                        float64
#  212 pct_l2_bi_eoc_swd_pc                                                                                                         float64
#  213 pct_l2_bi_eoc_wh7_pc                                                                                                         float64
#  214 pct_l2_e2_eoc_all_pc                                                                                                         float64
#  215 pct_l2_e2_eoc_bl7_pc                                                                                                         float64
#  216 pct_l2_e2_eoc_eds_pc                                                                                                         float64
#  217 pct_l2_e2_eoc_fem_pc                                                                                                         float64
#  218 pct_l2_e2_eoc_hi7_pc                                                                                                         float64
#  219 pct_l2_e2_eoc_male_pc                                                                                                        float64
#  220 pct_l2_e2_eoc_neds_pc                                                                                                        float64
#  221 pct_l2_e2_eoc_nswd_pc                                                                                                        float64
#  222 pct_l2_e2_eoc_swd_pc                                                                                                         float64
#  223 pct_l2_e2_eoc_wh7_pc                                                                                                         float64
#  224 pct_l3_all_all_fem_pc                                                                                                        float64
#  225 pct_l3_all_all_male_pc                                                                                                       float64
#  226 pct_l3_all_all_neds_pc                                                                                                       float64
#  227 pct_l3_all_all_swd_pc                                                                                                        float64
#  228 pct_l3_all_all_wh7_pc                                                                                                        float64
#  229 pct_l3_bi_eoc_all_pc                                                                                                         float64
#  230 pct_l3_bi_eoc_bl7_pc                                                                                                         float64
#  231 pct_l3_bi_eoc_eds_pc                                                                                                         float64
#  232 pct_l3_bi_eoc_fem_pc                                                                                                         float64
#  233 pct_l3_bi_eoc_hi7_pc                                                                                                         float64
#  234 pct_l3_bi_eoc_male_pc                                                                                                        float64
#  235 pct_l3_bi_eoc_neds_pc                                                                                                        float64
#  236 pct_l3_bi_eoc_nswd_pc                                                                                                        float64
#  237 pct_l3_bi_eoc_wh7_pc                                                                                                         float64
#  238 pct_l3_e2_eoc_all_pc                                                                                                         float64
#  239 pct_l3_e2_eoc_bl7_pc                                                                                                         float64
#  240 pct_l3_e2_eoc_eds_pc                                                                                                         float64
#  241 pct_l3_e2_eoc_fem_pc                                                                                                         float64
#  242 pct_l3_e2_eoc_hi7_pc                                                                                                         float64
#  243 pct_l3_e2_eoc_male_pc                                                                                                        float64
#  244 pct_l3_e2_eoc_neds_pc                                                                                                        float64
#  245 pct_l3_e2_eoc_nswd_pc                                                                                                        float64
#  246 pct_l3_e2_eoc_wh7_pc                                                                                                         float64
#  247 pct_l3_eoc_eoc_aig_pc                                                                                                        float64
#  248 pct_l3_eoc_eoc_all_pc                                                                                                        float64
#  249 pct_l3_eoc_eoc_bl7_pc                                                                                                        float64
#  250 pct_l3_eoc_eoc_eds_pc                                                                                                        float64
#  251 pct_l3_eoc_eoc_fem_pc                                                                                                        float64
#  252 pct_l3_eoc_eoc_hi7_pc                                                                                                        float64
#  253 pct_l3_eoc_eoc_male_pc                                                                                                       float64
#  254 pct_l3_eoc_eoc_mu7_pc                                                                                                        float64
#  255 pct_l3_eoc_eoc_neds_pc                                                                                                       float64
#  256 pct_l3_eoc_eoc_nswd_pc                                                                                                       float64
#  257 pct_l3_eoc_eoc_swd_pc                                                                                                        float64
#  258 pct_l3_eoc_eoc_wh7_pc                                                                                                        float64
#  259 pct_l3_m1_eoc_bl7_pc                                                                                                         float64
#  260 pct_l3_m1_eoc_eds_pc                                                                                                         float64
#  261 pct_l3_m1_eoc_fem_pc                                                                                                         float64
#  262 pct_l3_m1_eoc_hi7_pc                                                                                                         float64
#  263 pct_l3_m1_eoc_male_pc                                                                                                        float64
#  264 pct_l3_m1_eoc_neds_pc                                                                                                        float64
#  265 pct_l3_m1_eoc_nswd_pc                                                                                                        float64
#  266 pct_l3_m1_eoc_swd_pc                                                                                                         float64
#  267 pct_l3_m1_eoc_wh7_pc                                                                                                         float64
#  268 pct_l3_m3_eoc_aig_pc                                                                                                         float64
#  269 pct_l3_m3_eoc_bl7_pc                                                                                                         float64
#  270 pct_l3_m3_eoc_eds_pc                                                                                                         float64
#  271 pct_l3_m3_eoc_fem_pc                                                                                                         float64
#  272 pct_l3_m3_eoc_hi7_pc                                                                                                         float64
#  273 pct_l3_m3_eoc_male_pc                                                                                                        float64
#  274 pct_l3_m3_eoc_neds_pc                                                                                                        float64
#  275 pct_l3_m3_eoc_nswd_pc                                                                                                        float64
#  276 pct_l3_m3_eoc_wh7_pc                                                                                                         float64
#  277 pct_l4_all_all_swd_pc                                                                                                        float64
#  278 pct_l4_bi_eoc_aig_pc                                                                                                         float64
#  279 pct_l4_bi_eoc_bl7_pc                                                                                                         float64
#  280 pct_l4_bi_eoc_eds_pc                                                                                                         float64
#  281 pct_l4_bi_eoc_fem_pc                                                                                                         float64
#  282 pct_l4_bi_eoc_hi7_pc                                                                                                         float64
#  283 pct_l4_bi_eoc_male_pc                                                                                                        float64
#  284 pct_l4_bi_eoc_neds_pc                                                                                                        float64
#  285 pct_l4_bi_eoc_nswd_pc                                                                                                        float64
#  286 pct_l4_bi_eoc_swd_pc                                                                                                         float64
#  287 pct_l4_bi_eoc_wh7_pc                                                                                                         float64
#  288 pct_l4_e2_eoc_aig_pc                                                                                                         float64
#  289 pct_l4_e2_eoc_bl7_pc                                                                                                         float64
#  290 pct_l4_e2_eoc_eds_pc                                                                                                         float64
#  291 pct_l4_e2_eoc_fem_pc                                                                                                         float64
#  292 pct_l4_e2_eoc_hi7_pc                                                                                                         float64
#  293 pct_l4_e2_eoc_male_pc                                                                                                        float64
#  294 pct_l4_e2_eoc_neds_pc                                                                                                        float64
#  295 pct_l4_e2_eoc_nswd_pc                                                                                                        float64
#  296 pct_l4_e2_eoc_wh7_pc                                                                                                         float64
#  297 pct_l4_eoc_eoc_aig_pc                                                                                                        float64
#  298 pct_l4_eoc_eoc_bl7_pc                                                                                                        float64
#  299 pct_l4_eoc_eoc_eds_pc                                                                                                        float64
#  300 pct_l4_eoc_eoc_hi7_pc                                                                                                        float64
#  301 pct_l4_eoc_eoc_male_pc                                                                                                       float64
#  302 pct_l4_eoc_eoc_mu7_pc                                                                                                        float64
#  303 pct_l4_eoc_eoc_nswd_pc                                                                                                       float64
#  304 pct_l4_eoc_eoc_wh7_pc                                                                                                        float64
#  305 pct_l4_m1_eoc_eds_pc                                                                                                         float64
#  306 pct_l4_m1_eoc_fem_pc                                                                                                         float64
#  307 pct_l4_m1_eoc_male_pc                                                                                                        float64
#  308 pct_l4_m1_eoc_neds_pc                                                                                                        float64
#  309 pct_l4_m1_eoc_nswd_pc                                                                                                        float64
#  310 pct_l4_m1_eoc_wh7_pc                                                                                                         float64
#  311 pct_l4_m3_eoc_aig_pc                                                                                                         float64
#  312 pct_l4_m3_eoc_eds_pc                                                                                                         float64
#  313 pct_l4_m3_eoc_fem_pc                                                                                                         float64
#  314 pct_l4_m3_eoc_hi7_pc                                                                                                         float64
#  315 pct_l4_m3_eoc_male_pc                                                                                                        float64
#  316 pct_l4_m3_eoc_neds_pc                                                                                                        float64
#  317 pct_l4_m3_eoc_nswd_pc                                                                                                        float64
#  318 pct_l4_m3_eoc_wh7_pc                                                                                                         float64
#  319 pct_l5_all_all_aig_pc                                                                                                        float64
#  320 pct_l5_bi_eoc_aig_pc                                                                                                         float64
#  321 pct_l5_bi_eoc_eds_pc                                                                                                         float64
#  322 pct_l5_bi_eoc_fem_pc                                                                                                         float64
#  323 pct_l5_bi_eoc_hi7_pc                                                                                                         float64
#  324 pct_l5_bi_eoc_male_pc                                                                                                        float64
#  325 pct_l5_bi_eoc_nswd_pc                                                                                                        float64
#  326 pct_l5_bi_eoc_wh7_pc                                                                                                         float64
#  327 pct_l5_e2_eoc_aig_pc                                                                                                         float64
#  328 pct_l5_e2_eoc_neds_pc                                                                                                        float64
#  329 pct_l5_e2_eoc_wh7_pc                                                                                                         float64
#  330 pct_l5_eoc_eoc_aig_pc                                                                                                        float64
#  331 pct_l5_eoc_eoc_male_pc                                                                                                       float64
#  332 pct_l5_eoc_eoc_nswd_pc                                                                                                       float64
#  333 pct_l5_eoc_eoc_wh7_pc                                                                                                        float64
#  334 pct_l5_m3_eoc_aig_pc                                                                                                         float64
#  335 pct_l5_m3_eoc_male_pc                                                                                                        float64
#  336 pct_l5_m3_eoc_neds_pc                                                                                                        float64
#  337 pct_l5_m3_eoc_nswd_pc                                                                                                        float64
#  338 pct_l5_m3_eoc_wh7_pc                                                                                                         float64
#  339 pct_notprof_all_all_bl7_pc                                                                                                   float64
#  340 pct_notprof_all_all_eds_pc                                                                                                   float64
#  341 pct_notprof_all_all_els_pc                                                                                                   float64
#  342 pct_notprof_all_all_fem_pc                                                                                                   float64
#  343 pct_notprof_all_all_hi7_pc                                                                                                   float64
# ...
#  799 lea_name_attendance_Transylvania County Schools                                                                              uint8
#  800 lea_name_attendance_Tyrrell County Schools                                                                                   uint8
#  801 lea_name_attendance_Union County Public Schools                                                                              uint8
#  802 lea_name_attendance_Vance County Schools                                                                                     uint8
#  803 lea_name_attendance_Wake County Schools                                                                                      uint8
#  804 lea_name_attendance_Warren County Schools                                                                                    uint8
#  805 lea_name_attendance_Washington County Schools                                                                                uint8
#  806 lea_name_attendance_Watauga County Schools                                                                                   uint8
#  807 lea_name_attendance_Wayne County Public Schools                                                                              uint8
#  808 lea_name_attendance_Weldon City Schools                                                                                      uint8
#  809 lea_name_attendance_Whiteville City Schools                                                                                  uint8
#  810 lea_name_attendance_Wilkes County Schools                                                                                    uint8
#  811 lea_name_attendance_Wilson County Schools                                                                                    uint8
#  812 lea_name_attendance_Winston Salem/Forsyth County Schools                                                                     uint8
#  813 lea_name_attendance_Yadkin County Schools                                                                                    uint8
#  814 lea_name_attendance_Yancey County Schools                                                                                    uint8
#  815 grade_span_attendance_03-12                                                                                                  uint8
#  816 grade_span_attendance_04-12                                                                                                  uint8
#  817 grade_span_attendance_05-12                                                                                                  uint8
#  818 grade_span_attendance_06-08                                                                                                  uint8
#  819 grade_span_attendance_06-10                                                                                                  uint8
#  820 grade_span_attendance_06-12                                                                                                  uint8
#  821 grade_span_attendance_06-13                                                                                                  uint8
#  822 grade_span_attendance_07-11                                                                                                  uint8
#  823 grade_span_attendance_07-12                                                                                                  uint8
#  824 grade_span_attendance_07-13                                                                                                  uint8
#  825 grade_span_attendance_08-12                                                                                                  uint8
#  826 grade_span_attendance_08-13                                                                                                  uint8
#  827 grade_span_attendance_09-09                                                                                                  uint8
#  828 grade_span_attendance_09-10                                                                                                  uint8
#  829 grade_span_attendance_09-11                                                                                                  uint8
#  830 grade_span_attendance_09-12                                                                                                  uint8
#  831 grade_span_attendance_09-13                                                                                                  uint8
#  832 grade_span_attendance_09-99                                                                                                  uint8
#  833 grade_span_attendance_0K-11                                                                                                  uint8
#  834 grade_span_attendance_0K-12                                                                                                  uint8
#  835 grade_span_attendance_10-12                                                                                                  uint8
#  836 grade_span_attendance_10-13                                                                                                  uint8
#  837 grade_span_attendance_11-12                                                                                                  uint8
#  838 grade_span_attendance_11-13                                                                                                  uint8
#  839 grade_span_attendance_PK-11                                                                                                  uint8
#  840 grade_span_attendance_PK-12                                                                                                  uint8
#  841 csi_lp_esea_desig_Y                                                                                                          uint8
#  842 csi_lg_esea_desig_Y                                                                                                          uint8
#  843 tsi_cu_esea_desig_Y                                                                                                          uint8
#  844 tsi_at_esea_desig_Y                                                                                                          uint8
#  845 grad_project_gp_Y                                                                                                            uint8
#  846 lp_school_lowperf_Y                                                                                                          uint8
#  847 rlp_school_lowperf_Y                                                                                                         uint8
#  848 target_list_ltg_detail_4 Year Graduation Rate,EL Progress,Math Grade 11,Math Grades 3-8,Reading Grade 10,Reading Grades 3-8  uint8
#  849 target_list_ltg_detail_4 Year Graduation Rate,EL Progress,Math Grade 11,Reading Grade 10                                     uint8
#  850 target_list_ltg_detail_4 Year Graduation Rate,EL Progress,Math Grades 3-8,Reading Grade 10,Reading Grades 3-8                uint8
#  851 target_list_ltg_detail_4 Year Graduation Rate,Math Grade 11                                                                  uint8
#  852 target_list_ltg_detail_4 Year Graduation Rate,Math Grade 11,Math Grades 3-8,Reading Grade 10,Reading Grades 3-8              uint8
#  853 target_list_ltg_detail_4 Year Graduation Rate,Math Grade 11,Math Grades 3-8,Reading Grades 3-8                               uint8
#  854 target_list_ltg_detail_4 Year Graduation Rate,Math Grade 11,Reading Grade 10                                                 uint8
#  855 target_list_ltg_detail_4 Year Graduation Rate,Math Grades 3-8,Reading Grades 3-8                                             uint8
#  856 target_list_ltg_detail_4 Year Graduation Rate,Reading Grade 10                                                               uint8
#  857 target_list_ltg_detail_Math Grade 11                                                                                         uint8
#  858 target_list_ltg_detail_Math Grade 11,Math Grades 3-8,Reading Grades 3-8                                                      uint8
#  859 target_list_ltg_detail_Math Grade 11,Reading Grade 10                                                                        uint8
#  860 target_list_ltg_detail_Math Grades 3-8,Reading Grade 10,Reading Grades 3-8                                                   uint8
#  861 target_list_ltg_detail_Math Grades 3-8,Reading Grades 3-8                                                                    uint8
#  862 target_list_ltg_detail_Reading Grade 10                                                                                      uint8
#  863 subgroup_list_ltg_detail_ALL,AM7,BL7,EDS                                                                                     uint8
#  864 subgroup_list_ltg_detail_ALL,AM7,BL7,EDS,ELS,HI7,MU7,SWD,WH7                                                                 uint8
#  865 subgroup_list_ltg_detail_ALL,AM7,BL7,EDS,HI7                                                                                 uint8
#  866 subgroup_list_ltg_detail_ALL,AM7,BL7,EDS,HI7,MU7,SWD,WH7                                                                     uint8
#  867 subgroup_list_ltg_detail_ALL,AM7,BL7,EDS,HI7,SWD,WH7                                                                         uint8
#  868 subgroup_list_ltg_detail_ALL,AM7,BL7,EDS,SWD                                                                                 uint8
#  869 subgroup_list_ltg_detail_ALL,AM7,BL7,EDS,SWD,WH7                                                                             uint8
#  870 subgroup_list_ltg_detail_ALL,AM7,EDS,WH7                                                                                     uint8
#  871 subgroup_list_ltg_detail_ALL,AS7,BL7,EDS,ELS,HI7,MU7,SWD,WH7                                                                 uint8
#  872 subgroup_list_ltg_detail_ALL,AS7,BL7,EDS,ELS,HI7,SWD                                                                         uint8
#  873 subgroup_list_ltg_detail_ALL,AS7,BL7,EDS,ELS,HI7,SWD,WH7                                                                     uint8
#  874 subgroup_list_ltg_detail_ALL,AS7,BL7,EDS,HI7,SWD,WH7                                                                         uint8
#  875 subgroup_list_ltg_detail_ALL,AS7,BL7,EDS,HI7,WH7                                                                             uint8
#  876 subgroup_list_ltg_detail_ALL,AS7,WH7                                                                                         uint8
#  877 subgroup_list_ltg_detail_ALL,BL7                                                                                             uint8
#  878 subgroup_list_ltg_detail_ALL,BL7,EDS                                                                                         uint8
#  879 subgroup_list_ltg_detail_ALL,BL7,EDS,ELS,HI7                                                                                 uint8
#  880 subgroup_list_ltg_detail_ALL,BL7,EDS,ELS,HI7,SWD                                                                             uint8
#  881 subgroup_list_ltg_detail_ALL,BL7,EDS,ELS,HI7,SWD,WH7                                                                         uint8
#  882 subgroup_list_ltg_detail_ALL,BL7,EDS,ELS,HI7,WH7                                                                             uint8
#  883 subgroup_list_ltg_detail_ALL,BL7,EDS,HI7                                                                                     uint8
#  884 subgroup_list_ltg_detail_ALL,BL7,EDS,HI7,MU7,SWD,WH7                                                                         uint8
#  885 subgroup_list_ltg_detail_ALL,BL7,EDS,HI7,SWD                                                                                 uint8
#  886 subgroup_list_ltg_detail_ALL,BL7,EDS,HI7,SWD,WH7                                                                             uint8
#  887 subgroup_list_ltg_detail_ALL,BL7,EDS,HI7,WH7                                                                                 uint8
#  888 subgroup_list_ltg_detail_ALL,BL7,EDS,SWD                                                                                     uint8
#  889 subgroup_list_ltg_detail_ALL,BL7,EDS,SWD,WH7                                                                                 uint8
#  890 subgroup_list_ltg_detail_ALL,BL7,EDS,WH7                                                                                     uint8
#  891 subgroup_list_ltg_detail_ALL,BL7,SWD                                                                                         uint8
#  892 subgroup_list_ltg_detail_ALL,BL7,WH7                                                                                         uint8
#  893 subgroup_list_ltg_detail_ALL,EDS                                                                                             uint8
#  894 subgroup_list_ltg_detail_ALL,EDS,ELS,HI7                                                                                     uint8
#  895 subgroup_list_ltg_detail_ALL,EDS,ELS,HI7,SWD,WH7                                                                             uint8
#  896 subgroup_list_ltg_detail_ALL,EDS,ELS,HI7,WH7                                                                                 uint8
#  897 subgroup_list_ltg_detail_ALL,EDS,HI7                                                                                         uint8
#  898 subgroup_list_ltg_detail_ALL,EDS,HI7,SWD,WH7                                                                                 uint8
#  899 subgroup_list_ltg_detail_ALL,EDS,HI7,WH7                                                                                     uint8
#  900 subgroup_list_ltg_detail_ALL,EDS,SWD                                                                                         uint8
#  901 subgroup_list_ltg_detail_ALL,EDS,SWD,WH7                                                                                     uint8
#  902 subgroup_list_ltg_detail_ALL,EDS,WH7                                                                                         uint8
#  903 subgroup_list_ltg_detail_ALL,HI7                                                                                             uint8
#  904 subgroup_list_ltg_detail_ALL,HI7,WH7                                                                                         uint8
#  905 subgroup_list_ltg_detail_ALL,SWD                                                                                             uint8
#  906 subgroup_list_ltg_detail_ALL,WH7                                                                                             uint8
#  907 dance_cat_arts_Y                                                                                                             uint8
#  908 music_cat_arts_Y                                                                                                             uint8
#  909 theatre_cat_arts_Y                                                                                                           uint8
#  910 va_cat_arts_Y                                                                                                                uint8
#  911 poverty_eq_LOW                                                                                                               uint8
#  912 poverty_eq_NEITHER                                                                                                           uint8
#  913 agency_code                                                                                                                  object
# dtypes: float64(624), object(1), uint8(289)
# memory usage: 3.3+ MB

# %%
import sklearn
import pandas as pd

print('Sklearn Version: ' + sklearn.__version__)
print('Pandas Version: ' + pd.__version__)
# Out:
# Sklearn Version: 0.22.1
# Pandas Version: 1.0.3

# %%
print('Output File Location:\r\n\r\n' + outputDir + inputFileName + '_ML.csv')
# Out:
# Output File Location:
#
# D:/BenepactLLC/Belk/NC_Report_Card_Data/2020/June 2020/2019/Machine Learning Datasets/PublicHighSchools2019_ML.csv
