# %% [markdown]
# # Create Public School Machine Learning Datasets
# ** This program creates all the _ML datasets in the NCEA repository.**
# * This notebook reads each School Dataset file located at \EducationDataNC\ *schoolYear* \School Datasets\ as input data.
# * Different school years are processed by changing the *schoolYear* parameter.
# * Different input / output files are processed / created by changing the *inputFileName* paramter in the cell below.
# * While a single program is used to create all the _ML datasets, one program copy per dataset is maintained in the repositiory so the dataset specific tranformation reports may be reviewed.
#
# **Datasets ending in ML are preprocessed for Machine Learning and go through the following transformations: **
# 1. Missing student body racial compositions are imputed using district averages.
# 2. Columns that have the same value in every single row are deleted.
# 3. Columns that have a unique value in every single row (all values are different) are deleted.
# 4. Empty columns (all values are NA or NULL) are deleted.
# 5. Numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# 6. Remaining numeric, non-race columns with missing values are imputed / populated with 0.  In many cases, schools are not reporting values when they are zero. However, mean imputation or some other more sophisticated strategy might be considered here.
# 7. Categorical / text based columns with > *uniqueThreshold* unique values are deleted.
# 8. All remaining categorical / text based columns are one-hot encoded.  In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# 9. Duplicated or highly similar columns with > 95% correlation are delelted.

# %%
#import required Libraries
import pandas as pd
import numpy as np
import os
import string

#**********************************************************************************
# Set the following variables before running this code!!!
#**********************************************************************************
#All raw data files are processed for the year below
schoolYear = 2019

#Location where copies of the raw data files will be read in from csv files.
dataDir = 'C:/Users/Jake/Documents/GitHub/EducationDataNC/' + str(schoolYear) + '/School Datasets/'

#Name of the file to be processed
#inputFileName = 'PublicSchools2019'
#inputFileName = 'PublicHighSchools2019'
inputFileName = 'PublicMiddleSchools2019'
#inputFileName = 'PublicElementarySchools2019'

#Input file being transformed for machine learning 
inputFile = dataDir + inputFileName + '.csv'

#Location where the new school datasets will be created.
outputDir = 'C:/Users/Jake/Documents/GitHub/EducationDataNC/' + str(schoolYear) + '/Machine Learning Datasets/'

#Missing Data Threshold (Per Column)
missingThreshold = 0.60

#Unique Value Threshold (Per Column)
#Delete Columns >  uniqueThreshold unique values prior to one-hot encoding. 
#(each unique value becomes a new column during one-hot encoding)
uniqueThreshold = 200

#Read in the School Data File
schoolData = pd.read_csv(inputFile, low_memory=False, dtype={'agency_code': object})
print('*********Start: Beginning Column and Row Counts********************************************')
schoolData.info(verbose=False)

#Select only public schools as charter schools are missing data for many columns.
schoolData = schoolData[(schoolData['designation_type'] == 'P')] #& (schoolData['avg_student_num'] > 0)] -rcd_admin missing

print('\r\n*********After: Selecting Only Public School Campuses**********************************')
schoolData.info(verbose=False)

#Save primary key
agency_code = schoolData['agency_code']
#Convert zip code to string
schoolData['zip'] = schoolData['zip'].astype('object')
# Out:
# *********Start: Beginning Column and Row Counts********************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 839 entries, 0 to 838
# Columns: 1485 entries, agency_code to welcome_url
# dtypes: float64(1436), int64(1), object(48)
# memory usage: 9.5+ MB
#
# *********After: Selecting Only Public School Campuses**********************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 684 entries, 2 to 838
# Columns: 1485 entries, agency_code to welcome_url
# dtypes: float64(1436), int64(1), object(48)
# memory usage: 7.8+ MB

# %% [markdown]
# # Prepare Consolidated Dataset for Machine Learning
# **Below we perform operations on the entire dataset to remove columns and update row values that could cause problems during machine learning.**

# %% [markdown]
# ## Student Body Racial Composition Features
# **Impute / update missing Student Body Racial Composition Fields using mean imputation.**
# * When there are no racial composition percentages for a particular school campus / agency_code, fill in the missing values

# %%
#Get Student Body Racial Composition Fields
raceCompositionFields = schoolData.filter(regex='Indian|Asian|Hispanic|Black|White|PacificIsland|TwoOrMore|Minority')\
                                  .filter(regex='Pct').columns
    
rowsBefore = schoolData[raceCompositionFields].isnull().T.any().T.sum()

#Update missing race values with the district average when avaiable (No district averages for charter schools) 
schoolData[raceCompositionFields] = schoolData.groupby('lea_code')[raceCompositionFields]\
                                              .transform(lambda x: x.fillna(x.mean()))

    #Review dataset contents after Racial Composition Imputation
print('*********After: Updating Missing Racial Compostion Values****************************')   
rowsAfter = schoolData[raceCompositionFields].isnull().T.any().T.sum()
rowsUpdated = rowsBefore - rowsAfter
print('Rows Updated / Imputed: ', rowsUpdated) 
print('\r\nTotal Rows Missing Racial Compositions By District Code') 
schoolData['lea_code'][schoolData[raceCompositionFields].isnull().T.any().T].value_counts()
# Out:
# *********After: Updating Missing Racial Compostion Values****************************
# Rows Updated / Imputed:  5
#
# Total Rows Missing Racial Compositions By District Code
# 010LEA    8
# 070LEA    7
# 090LEA    4
# 060LEA    3
# 030LEA    3
# 020LEA    2
# 040LEA    2
# 080LEA    1
# 050LEA    1
# Name: lea_code, dtype: int64

# %% [markdown]
# ## Remove Columns with Problematic Data
# **Here we remove entire columns that could cause problems during machine learning.  The following operations are performed:**
# * Remove any columns that have the same value in every single row.
# * Remove any columns that have a unique value in every single row (all values are different).
# * Remove empty columns (all values are NA or NULL).

# %%
#Remove any fields that have the same value in all rows
UniqueValueCounts = schoolData.nunique(dropna=False)
SingleValueCols = UniqueValueCounts[UniqueValueCounts == 1].index
schoolData = schoolData.drop(SingleValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with the same value in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(SingleValueCols))
# Out:
# *********After: Removing columns with the same value in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 684 entries, 2 to 838
# Columns: 623 entries, agency_code to welcome_url
# dtypes: float64(580), object(43)
# memory usage: 3.3+ MB
#
# Columns Deleted:  862

# %%
#Remove any fields that have unique values in every row
schoolDataRecordCt = schoolData.shape[0]
UniqueValueCounts = schoolData.apply(pd.Series.nunique)
AllUniqueValueCols = UniqueValueCounts[UniqueValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(AllUniqueValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with unique values in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(AllUniqueValueCols))
# Out:
# *********After: Removing columns with unique values in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 684 entries, 2 to 838
# Columns: 623 entries, agency_code to welcome_url
# dtypes: float64(580), object(43)
# memory usage: 3.3+ MB
#
# Columns Deleted:  0

# %%
#Remove any empty fields (null values in every row)
schoolDataRecordCt = schoolData.shape[0]
NullValueCounts = schoolData.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with null / blank values in every row.*************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with null / blank values in every row.*************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 684 entries, 2 to 838
# Columns: 623 entries, agency_code to welcome_url
# dtypes: float64(580), object(43)
# memory usage: 3.3+ MB
#
# Columns Deleted:  0

# %% [markdown]
# ## Handle Other Missing Values Types
# * Here we eliminate any numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# * All remaining non-race, numeric column missing values are populated with 0.
# * In many cases, it seems that schools are not simply not reporting values when they are zero. However, mean imputation or some other strategy might be considered.

# %%
#Isolate continuous and categorical data types
#These are indexers into the schoolData dataframe and may be used similar to the schoolData dataframe 
sD_boolean = schoolData.loc[:, (schoolData.dtypes == bool) ]
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]
sD_continuous = schoolData.loc[:, (schoolData.dtypes != bool) & (schoolData.dtypes != object)]
print ("Boolean Columns: ", sD_boolean.shape[1])
print ("Nominal Columns: ", sD_nominal.shape[1])
print ("Continuous Columns: ", sD_continuous.shape[1])
print ("Columns Accounted for: ", sD_nominal.shape[1] + sD_continuous.shape[1] + sD_boolean.shape[1])
# Out:
# Boolean Columns:  0
# Nominal Columns:  43
# Continuous Columns:  580
# Columns Accounted for:  623

# %%
#Eliminate continuous columns with more than missingThreshold percentage of missing values
schoolDataRecordCt = sD_continuous.shape[0]
missingValueLimit = schoolDataRecordCt * missingThreshold
NullValueCounts = sD_continuous.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts >= missingValueLimit].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with >= missingThreshold % of missing values******')
schoolData.info(verbose=False)
print('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with >= missingThreshold % of missing values******
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 684 entries, 2 to 838
# Columns: 261 entries, agency_code to welcome_url
# dtypes: float64(218), object(43)
# memory usage: 1.4+ MB
#
# Columns Deleted:  362

# %% [markdown]
# ## One-Hot Encoding of Categorical Variables
# **All categorical / string variables are converted to numberic variables via one hot encoding.  Each unique row value will become a new binary / numeric column in the dataset.**
# * All remaining categorical columns are one-hot encoded.
# * In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# * Prior to one-hot encoding, columns with > *uniqueThreshold* unique values are deleted.

# %%
#Delete categorical columns with > uniqueThreshold unique values 
#(Each unique value becomes a column during one-hot encoding)
oneHotUniqueValueCounts = schoolData[sD_nominal.columns].apply(lambda x: x.nunique())
oneHotUniqueValueCols = oneHotUniqueValueCounts[oneHotUniqueValueCounts >= uniqueThreshold].index
schoolData.drop(oneHotUniqueValueCols, axis=1, inplace=True) 

#Remove categorical columns which do not add value to machine learning
#Grades columns dropped since they all have indicator fields (device_access, device_home, BYOD)
#with less unique values to one-hot encode
schoolData.drop(['welcome_url','device_access_grades',
                 'device_home_grades','byod_grades'], axis=1, inplace=True) 

#Review dataset contents one hot high unique value drops
print('*********After: Removing columns with >= uniqueThreshold unique values***********')
schoolData.info(verbose=False)
print('\r\nColumns Deleted: ', len(oneHotUniqueValueCols))
print(oneHotUniqueValueCols)
print('Dropped Manually: welcome_url,device_access_grades,device_home_grades,byod_grades')
# Out:
# *********After: Removing columns with >= uniqueThreshold unique values***********
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 684 entries, 2 to 838
# Columns: 249 entries, category_code to sts_per1000_WH7
# dtypes: float64(218), object(31)
# memory usage: 1.3+ MB
#
# Columns Deleted:  8
# Index(['agency_code', 'name', 'street_addr', 'city', 'zip', 'phone', 'url',
#        'School Name'],
#       dtype='object')
# Dropped Manually: welcome_url,device_access_grades,device_home_grades,byod_grades

# %%
#Isolate remaining categorical variables
begColumnCt = len(schoolData.columns)
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]

#one hot encode categorical variables
schoolData = pd.get_dummies(data=schoolData, 
                       columns=sD_nominal.columns, drop_first=True)

#Determine change in column count
endColumnCt = len(schoolData.columns)
columnsAdded = endColumnCt - begColumnCt

#Review dataset contents one hot high unique value drops
print('Columns To One-Hot Encode: ', len(sD_nominal.columns))
print('\r\n*********After: Adding New Columns Via One-Hot Encoding*************************')
schoolData.info(verbose=False)
print('\r\nNew Columns Created Via One-Hot Encoding: ', columnsAdded)
# Out:
# Columns To One-Hot Encode:  31
#
# *********After: Adding New Columns Via One-Hot Encoding*************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 684 entries, 2 to 838
# Columns: 753 entries, IndianPct to devices_4.07
# dtypes: float64(218), uint8(535)
# memory usage: 1.5 MB
#
# New Columns Created Via One-Hot Encoding:  504

# %%
#Remove any fields that have the same value in all rows after one-hot encoding
UniqueValueCounts = schoolData.nunique(dropna=False)
SingleValueCols = UniqueValueCounts[UniqueValueCounts == 1].index
schoolData = schoolData.drop(SingleValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing one-hot encoded columns with the same value in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(SingleValueCols))
# Out:
# *********After: Removing one-hot encoded columns with the same value in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 684 entries, 2 to 838
# Columns: 753 entries, IndianPct to devices_4.07
# dtypes: float64(218), uint8(535)
# memory usage: 1.5 MB
#
# Columns Deleted:  0

# %% [markdown]
# ## Impute any Remaining Missing Values as Zero

# %%
#Print out all the missing value rows
pd.set_option('display.max_rows', 1000)

print('\r\n*********The Remaining Missing Values Below will be set to Zero!*************************')

#Check for Missing values 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# *********The Remaining Missing Values Below will be set to Zero!*************************
#                            Variable Name  Number Missing Values
# 0                              IndianPct                     31
# 1                               AsianPct                     31
# 2                            HispanicPct                     31
# 3                               BlackPct                     31
# 4                               WhitePct                     31
# 5                       PacificIslandPct                     31
# 6                           TwoOrMorePct                     31
# 7                            MinorityPct                     31
# 8                          IndianMalePct                     31
# 9                           AsianMalePct                     31
# 10                       HispanicMalePct                     31
# 11                          BlackMalePct                     31
# 12                          WhiteMalePct                     31
# 13                  PacificIslandMalePct                     31
# 14                      TwoOrMoreMalePct                     31
# 15                       MinorityMalePct                     31
# 16                       IndianFemalePct                     31
# 17                        AsianFemalePct                     31
# 18                     HispanicFemalePct                     31
# 19                        BlackFemalePct                     31
# 20                        WhiteFemalePct                     31
# 21                     MinorityFemalePct                     31
# 22                PacificIslandFemalePct                     31
# 23                    TwoOrMoreFemalePct                     31
# 24                               pct_eds                      7
# 25                      eg_index_ALL_AIG                    147
# 26                      eg_index_ALL_ALL                     38
# 27                      eg_index_ALL_BL7                    158
# 28                      eg_index_ALL_EDS                     50
# 29                      eg_index_ALL_ELS                    194
# 30                      eg_index_ALL_HI7                    137
# 31                      eg_index_ALL_MU7                    280
# 32                      eg_index_ALL_SWD                    113
# 33                      eg_index_ALL_WH7                    100
# 34                       eg_index_MA_ALL                     51
# 35                       eg_index_RD_ALL                     66
# 36                      eg_score_ALL_AIG                    174
# 37                      eg_score_ALL_ALL                     56
# 38                      eg_score_ALL_BL7                    189
# 39                      eg_score_ALL_EDS                     71
# 40                      eg_score_ALL_ELS                    258
# 41                      eg_score_ALL_HI7                    164
# 42                      eg_score_ALL_MU7                    382
# 43                      eg_score_ALL_SWD                    145
# 44                      eg_score_ALL_WH7                    117
# 45                       eg_score_MA_ALL                     76
# 46                       eg_score_RD_ALL                     81
# 47                           pct_ALL_ELP                    251
# 48                           pct_EDS_ELP                    299
# 49                           pct_ELS_ELP                    251
# 50                           pct_HI7_ELP                    289
# 51                          pct_MALE_ELP                    339
# 52                          pct_NSWD_ELP                    309
# 53                      pct_prof_6gr_irm                    100
# 54           pct_met_Math Grades 3-8_LTG                     59
# 55        pct_met_Reading Grades 3-8_LTG                     59
# 56             pct_met_Total Targets_LTG                     34
# 57          pct_met_Math Grades 3-8_PART                     47
# 58       pct_met_Reading Grades 3-8_PART                     47
# 59       pct_met_Science Grades 5&8_PART                     84
# 60            pct_met_Total Targets_PART                     39
# 61      pct_Math Grades 3-8_ALL_PART_DET                     47
# 62      pct_Math Grades 3-8_BL7_PART_DET                    201
# 63      pct_Math Grades 3-8_EDS_PART_DET                     65
# 64      pct_Math Grades 3-8_ELS_PART_DET                    292
# 65      pct_Math Grades 3-8_HI7_PART_DET                    181
# 66      pct_Math Grades 3-8_SWD_PART_DET                    138
# 67      pct_Math Grades 3-8_WH7_PART_DET                    132
# 68   pct_Reading Grades 3-8_ALL_PART_DET                     47
# 69   pct_Reading Grades 3-8_BL7_PART_DET                    201
# 70   pct_Reading Grades 3-8_EDS_PART_DET                     65
# 71   pct_Reading Grades 3-8_ELS_PART_DET                    292
# 72   pct_Reading Grades 3-8_HI7_PART_DET                    181
# 73   pct_Reading Grades 3-8_SWD_PART_DET                    138
# 74   pct_Reading Grades 3-8_WH7_PART_DET                    132
# 75   pct_Science Grades 5&8_ALL_PART_DET                     84
# 76   pct_Science Grades 5&8_BL7_PART_DET                    335
# 77   pct_Science Grades 5&8_EDS_PART_DET                    127
# 78   pct_Science Grades 5&8_HI7_PART_DET                    396
# 79   pct_Science Grades 5&8_WH7_PART_DET                    225
# 80                              ma_score                     98
# 81                              rd_score                     98
# 82                              sc_score                     99
# 83                              m1_score                    171
# 84                             ach_score                     94
# 85                              eg_score                     97
# 86                             spg_score                     94
# 87                          ma_spg_score                     98
# 88                          rd_spg_score                     98
# 89                           ma_eg_score                    101
# 90                           rd_eg_score                    101
# 91                    aaa_score_ALL_SPG2                     79
# 92                    aaa_score_BL7_SPG2                    177
# 93                    aaa_score_EDS_SPG2                     82
# 94                    aaa_score_ELS_SPG2                    205
# 95                    aaa_score_HI7_SPG2                    128
# 96                    aaa_score_MU7_SPG2                    282
# 97                    aaa_score_SWD_SPG2                    102
# 98                    aaa_score_WH7_SPG2                    109
# 99                    ach_score_ALL_SPG2                     79
# 100                   ach_score_BL7_SPG2                    177
# 101                   ach_score_EDS_SPG2                     82
# 102                   ach_score_ELS_SPG2                    205
# 103                   ach_score_HI7_SPG2                    128
# 104                   ach_score_MU7_SPG2                    282
# 105                   ach_score_SWD_SPG2                    102
# 106                   ach_score_WH7_SPG2                    109
# 107                    eg_score_ALL_SPG2                     82
# 108                    eg_score_BL7_SPG2                    196
# 109                    eg_score_EDS_SPG2                     88
# 110                    eg_score_ELS_SPG2                    258
# 111                    eg_score_HI7_SPG2                    166
# 112                    eg_score_MU7_SPG2                    382
# 113                    eg_score_SWD_SPG2                    147
# 114                    eg_score_WH7_SPG2                    121
# 115                  scgs_score_ALL_SPG2                     94
# 116                  scgs_score_BL7_SPG2                    344
# 117                  scgs_score_EDS_SPG2                    141
# 118                  scgs_score_WH7_SPG2                    228
# 119                   spg_score_ALL_SPG2                     79
# 120                   spg_score_BL7_SPG2                    177
# 121                   spg_score_EDS_SPG2                     82
# 122                   spg_score_ELS_SPG2                    205
# 123                   spg_score_HI7_SPG2                    128
# 124                   spg_score_MU7_SPG2                    282
# 125                   spg_score_SWD_SPG2                    102
# 126                   spg_score_WH7_SPG2                    109
# 127                           stu_enroll                     44
# 128                           cte_enroll                     44
# 129                   cte_enrollment_pct                     44
# 130               Book_TitlesPer_Student                     45
# 131                                  wap                      6
# 132                            wap_class                      6
# 133                         media_school                     40
# 134                                crime                     21
# 135                           short_term                     21
# 136                            long_term                     21
# 137                            expulsion                     21
# 138                      act_per1000_ALL                     18
# 139                      act_per1000_BL7                    109
# 140                      act_per1000_EDS                     22
# 141                      act_per1000_ELS                    234
# 142                      act_per1000_FEM                     43
# 143                      act_per1000_HI7                     98
# 144                     act_per1000_MALE                     29
# 145                      act_per1000_MU7                    218
# 146                      act_per1000_SWD                     40
# 147                      act_per1000_WH7                     62
# 148                      arr_per1000_ALL                     18
# 149                      arr_per1000_BL7                    109
# 150                      arr_per1000_EDS                     22
# 151                      arr_per1000_ELS                    234
# 152                      arr_per1000_FEM                     43
# 153                      arr_per1000_HI7                     98
# 154                     arr_per1000_MALE                     29
# 155                      arr_per1000_MU7                    218
# 156                      arr_per1000_SWD                     40
# 157                      arr_per1000_WH7                     62
# 158                      bha_per1000_ALL                     18
# 159                      bha_per1000_BL7                    109
# 160                      bha_per1000_EDS                     22
# 161                      bha_per1000_ELS                    234
# 162                      bha_per1000_FEM                     43
# 163                      bha_per1000_HI7                     98
# 164                     bha_per1000_MALE                     29
# 165                      bha_per1000_MU7                    218
# 166                      bha_per1000_SWD                     40
# 167                      bha_per1000_WH7                     62
# 168                      exp_per1000_ALL                     18
# 169                      exp_per1000_BL7                    109
# 170                      exp_per1000_EDS                     22
# 171                      exp_per1000_ELS                    234
# 172                      exp_per1000_FEM                     43
# 173                      exp_per1000_HI7                     98
# 174                     exp_per1000_MALE                     29
# 175                      exp_per1000_MU7                    218
# 176                      exp_per1000_SWD                     40
# 177                      exp_per1000_WH7                     62
# 178                      iss_per1000_ALL                     18
# 179                      iss_per1000_BL7                    110
# 180                      iss_per1000_EDS                     22
# 181                      iss_per1000_ELS                    234
# 182                      iss_per1000_FEM                     43
# 183                      iss_per1000_HI7                     98
# 184                     iss_per1000_MALE                     29
# 185                      iss_per1000_MU7                    218
# 186                      iss_per1000_SWD                     40
# 187                      iss_per1000_WH7                     62
# 188                      lts_per1000_ALL                     18
# 189                      lts_per1000_BL7                    109
# 190                      lts_per1000_EDS                     22
# 191                      lts_per1000_ELS                    234
# 192                      lts_per1000_FEM                     43
# 193                      lts_per1000_HI7                     98
# 194                     lts_per1000_MALE                     29
# 195                      lts_per1000_MU7                    218
# 196                      lts_per1000_SWD                     40
# 197                      lts_per1000_WH7                     62
# 198                      rpt_per1000_ALL                     18
# 199                      rpt_per1000_BL7                    109
# 200                      rpt_per1000_EDS                     22
# 201                      rpt_per1000_ELS                    234
# 202                      rpt_per1000_FEM                     43
# 203                      rpt_per1000_HI7                     98
# 204                     rpt_per1000_MALE                     29
# 205                      rpt_per1000_MU7                    218
# 206                      rpt_per1000_SWD                     40
# 207                      rpt_per1000_WH7                     62
# 208                      sts_per1000_ALL                     19
# 209                      sts_per1000_BL7                    114
# 210                      sts_per1000_EDS                     22
# 211                      sts_per1000_ELS                    234
# 212                      sts_per1000_FEM                     44
# 213                      sts_per1000_HI7                     99
# 214                     sts_per1000_MALE                     34
# 215                      sts_per1000_MU7                    218
# 216                      sts_per1000_SWD                     40
# 217                      sts_per1000_WH7                     63

# %%
#Replace all remaining NaN with 0
schoolData = schoolData.fillna(0)

#Check for Missing values after final imputation 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# Empty DataFrame
# Columns: [Variable Name, Number Missing Values]
# Index: []

# %% [markdown]
# ## Identify and Remove Highly Correlated Features
# **Find and remove any columns / features that are > 95% correlated**
# * https://stackoverflow.com/questions/39409866/correlation-heatmap
# * https://chrisalbon.com/machine_learning/feature_selection/drop_highly_correlated_features/
# * https://codeyarns.com/2015/04/20/how-to-change-font-size-in-seaborn/

# %%
# calculate the correlation matrix
corr_matrix  = schoolData.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
#Get all of the correlation values > 95%
x = np.where(upper > 0.95)

#Display all field combinations with > 95% correlation
cf = pd.DataFrame()
cf['Field1'] = upper.columns[x[1]]
cf['Field2'] = upper.index[x[0]]

#Get the correlation values for every field combination. (There must be a more pythonic way to do this!)
corr = [0] * len(cf)
for i in range(0, len(cf)):
    corr[i] =  upper[cf['Field1'][i]][cf['Field2'][i]] 
    
cf['Correlation'] = corr

print ('There are ', str(len(cf['Field1'])), ' field correlations > 95%.')
cf
# Out:
# There are  175  field correlations > 95%.
#                                   Field1  \
# 0                          IndianMalePct
# 1                        IndianFemalePct
# 2                           BlackMalePct
# 3                           WhiteMalePct
# 4                         WhiteFemalePct
# 5                        IndianFemalePct
# 6                        eg_index_MA_ALL
# 7                        eg_index_RD_ALL
# 8                        eg_index_RD_ALL
# 9                      eg_score_BL7_SPG2
# 10                     eg_score_ELS_SPG2
# 11                     eg_score_HI7_SPG2
# 12                     eg_score_MU7_SPG2
# 13                     eg_score_SWD_SPG2
# 14                     eg_score_WH7_SPG2
# 15                       eg_score_RD_ALL
# 16                     eg_score_ALL_SPG2
# 17                     eg_score_ALL_SPG2
# 18                           pct_ELS_ELP
# 19       pct_met_Reading Grades 3-8_PART
# 20   pct_Science Grades 5&8_ALL_PART_DET
# 21   pct_Reading Grades 3-8_ALL_PART_DET
# 22   pct_Reading Grades 3-8_BL7_PART_DET
# 23   pct_Reading Grades 3-8_EDS_PART_DET
# 24   pct_Reading Grades 3-8_ELS_PART_DET
# 25   pct_Reading Grades 3-8_HI7_PART_DET
# 26   pct_Reading Grades 3-8_SWD_PART_DET
# 27   pct_Reading Grades 3-8_WH7_PART_DET
# 28                   scgs_score_WH7_SPG2
# 29                              rd_score
# 30                             ach_score
# 31                          ma_spg_score
# 32                             ach_score
# 33                             spg_score
# 34                          ma_spg_score
# 35                          rd_spg_score
# 36                          rd_spg_score
# 37                             spg_score
# 38                          ma_spg_score
# 39                          rd_spg_score
# 40                           ma_eg_score
# 41                          ma_spg_score
# 42                          rd_spg_score
# 43                          rd_spg_score
# 44                    ach_score_ALL_SPG2
# 45                    spg_score_ALL_SPG2
# 46                    ach_score_BL7_SPG2
# 47                    spg_score_BL7_SPG2
# 48                    ach_score_EDS_SPG2
# 49                    spg_score_EDS_SPG2
# 50                    ach_score_ELS_SPG2
# 51                    spg_score_ELS_SPG2
# 52                    ach_score_HI7_SPG2
# 53                    spg_score_HI7_SPG2
# 54                    ach_score_MU7_SPG2
# 55                    spg_score_MU7_SPG2
# 56                    ach_score_SWD_SPG2
# 57                    ach_score_WH7_SPG2
# 58                    spg_score_WH7_SPG2
# 59                    spg_score_ALL_SPG2
# 60                    spg_score_BL7_SPG2
# 61                    spg_score_EDS_SPG2
# 62                    spg_score_ELS_SPG2
# 63                    spg_score_HI7_SPG2
# 64                    spg_score_MU7_SPG2
# 65                    spg_score_WH7_SPG2
# 66                     eg_score_EDS_SPG2
# 67                    spg_score_EDS_SPG2
# 68                       arr_per1000_BL7
# 69                       arr_per1000_EDS
# 70                      arr_per1000_MALE
# 71                       arr_per1000_SWD
# 72                       arr_per1000_FEM
# 73                      arr_per1000_MALE
# 74                       arr_per1000_FEM
# 75                      iss_per1000_MALE
# 76                       rpt_per1000_EDS
# 77                      county_Alexander
# 78                      county_Alleghany
# 79                          county_Anson
# 80                           county_Ashe
# 81                          county_Avery
# 82                       county_Beaufort
# 83                         county_Bertie
# 84                         county_Bladen
# 85                      county_Brunswick
# 86                          county_Burke
# 87                       county_Cabarrus
# 88                       county_Caldwell
# 89                         county_Camden
# 90                       county_Carteret
# 91                        county_Caswell
# 92                        county_Chatham
# 93                       county_Cherokee
# 94                         county_Chowan
# 95                           county_Clay
# 96                      county_Cleveland
# 97                         county_Craven
# 98                     county_Cumberland
# 99                      county_Currituck
# 100                          county_Dare
# 101                         county_Davie
# 102                        county_Duplin
# 103                        county_Durham
# 104                     county_Edgecombe
# 105                       county_Forsyth
# 106                      county_Franklin
# 107                        county_Gaston
# 108                         county_Gates
# 109                        county_Graham
# 110                     county_Granville
# 111                        county_Greene
# 112                      county_Guilford
# 113                       county_Harnett
# 114                       county_Haywood
# 115                     county_Henderson
# 116                      county_Hertford
# 117                          county_Hoke
# 118                          county_Hyde
# 119                       county_Jackson
# 120                      county_Johnston
# 121                         county_Jones
# 122                           county_Lee
# 123                        county_Lenoir
# 124                       county_Lincoln
# 125                         county_Macon
# 126                       county_Madison
# 127                        county_Martin
# 128                      county_McDowell
# 129                   county_Mecklenburg
# 130                      county_Mitchell
# 131                    county_Montgomery
# 132                         county_Moore
# 133                          county_Nash
# 134                   county_New Hanover
# 135                   county_Northampton
# 136                        county_Onslow
# 137                       county_Pamlico
# 138                    county_Pasquotank
# 139                        county_Pender
# 140                    county_Perquimans
# 141                        county_Person
# 142                          county_Pitt
# 143                          county_Polk
# 144                      county_Richmond
# 145                       county_Robeson
# 146                    county_Rockingham
# 147                         county_Rowan
# 148                    county_Rutherford
# 149                      county_Scotland
# 150                        county_Stanly
# 151                        county_Stokes
# 152                         county_Swain
# 153                  county_Transylvania
# 154                       county_Tyrrell
# 155                         county_Union
# 156                         county_Vance
# 157                          county_Wake
# 158                        county_Warren
# 159                    county_Washington
# 160                       county_Watauga
# 161                         county_Wayne
# 162                        county_Wilkes
# 163                        county_Wilson
# 164                        county_Yadkin
# 165                        county_Yancey
# 166                     digital_media_26
# 167            subgroup_list_ALL,BL7,SWD
# 168                         devices_0.27
# 169               school_type_CTE School
# 170                         devices_0.03
# 171                         devices_0.41
# 172                         devices_1.47
# 173                         devices_0.27
# 174                         devices_2.53
#
#                                         Field2  Correlation
# 0                                    IndianPct     0.990073
# 1                                    IndianPct     0.989317
# 2                                     BlackPct     0.965909
# 3                                     WhitePct     0.966424
# 4                                     WhitePct     0.958470
# 5                                IndianMalePct     0.959007
# 6                             eg_index_ALL_ALL     0.994951
# 7                             eg_index_ALL_ALL     0.988252
# 8                              eg_index_MA_ALL     0.991166
# 9                             eg_score_ALL_BL7     0.982740
# 10                            eg_score_ALL_ELS     1.000000
# 11                            eg_score_ALL_HI7     0.991271
# 12                            eg_score_ALL_MU7     1.000000
# 13                            eg_score_ALL_SWD     0.991790
# 14                            eg_score_ALL_WH7     0.989181
# 15                             eg_score_MA_ALL     0.983617
# 16                             eg_score_MA_ALL     0.958508
# 17                             eg_score_RD_ALL     0.965403
# 18                                 pct_ALL_ELP     1.000000
# 19                pct_met_Math Grades 3-8_PART     0.987796
# 20             pct_met_Science Grades 5&8_PART     0.967923
# 21            pct_Math Grades 3-8_ALL_PART_DET     0.999880
# 22            pct_Math Grades 3-8_BL7_PART_DET     0.999982
# 23            pct_Math Grades 3-8_EDS_PART_DET     0.999935
# 24            pct_Math Grades 3-8_ELS_PART_DET     1.000000
# 25            pct_Math Grades 3-8_HI7_PART_DET     0.999985
# 26            pct_Math Grades 3-8_SWD_PART_DET     0.999983
# 27            pct_Math Grades 3-8_WH7_PART_DET     0.999992
# 28         pct_Science Grades 5&8_WH7_PART_DET     0.979459
# 29                                    ma_score     0.959225
# 30                                    ma_score     0.954908
# 31                                    ma_score     0.986470
# 32                                    rd_score     0.967114
# 33                                    rd_score     0.957951
# 34                                    rd_score     0.962369
# 35                                    rd_score     0.990093
# 36                                    sc_score     0.956700
# 37                                   ach_score     0.990614
# 38                                   ach_score     0.955044
# 39                                   ach_score     0.956505
# 40                                    eg_score     0.956447
# 41                                   spg_score     0.958463
# 42                                   spg_score     0.964424
# 43                                ma_spg_score     0.961117
# 44                          aaa_score_ALL_SPG2     0.996453
# 45                          aaa_score_ALL_SPG2     0.984595
# 46                          aaa_score_BL7_SPG2     0.995409
# 47                          aaa_score_BL7_SPG2     0.981771
# 48                          aaa_score_EDS_SPG2     0.995074
# 49                          aaa_score_EDS_SPG2     0.980361
# 50                          aaa_score_ELS_SPG2     0.996686
# 51                          aaa_score_ELS_SPG2     0.986602
# 52                          aaa_score_HI7_SPG2     0.996974
# 53                          aaa_score_HI7_SPG2     0.989141
# 54                          aaa_score_MU7_SPG2     0.999942
# 55                          aaa_score_MU7_SPG2     0.996477
# 56                          aaa_score_SWD_SPG2     0.984708
# 57                          aaa_score_WH7_SPG2     0.998292
# 58                          aaa_score_WH7_SPG2     0.992793
# 59                          ach_score_ALL_SPG2     0.991244
# 60                          ach_score_BL7_SPG2     0.989746
# 61                          ach_score_EDS_SPG2     0.988835
# 62                          ach_score_ELS_SPG2     0.986244
# 63                          ach_score_HI7_SPG2     0.992161
# 64                          ach_score_MU7_SPG2     0.996490
# 65                          ach_score_WH7_SPG2     0.995325
# 66                           eg_score_ALL_SPG2     0.957151
# 67                          spg_score_ALL_SPG2     0.960673
# 68                             arr_per1000_ALL     0.979862
# 69                             arr_per1000_ALL     0.954029
# 70                             arr_per1000_ALL     0.984967
# 71                             arr_per1000_ALL     0.962685
# 72                             arr_per1000_BL7     0.955296
# 73                             arr_per1000_BL7     0.988488
# 74                             arr_per1000_EDS     0.976413
# 75                             iss_per1000_ALL     0.958132
# 76                             rpt_per1000_ALL     0.963636
# 77                             lea_code_020LEA     1.000000
# 78                             lea_code_030LEA     1.000000
# 79                             lea_code_040LEA     1.000000
# 80                             lea_code_050LEA     1.000000
# 81                             lea_code_060LEA     1.000000
# 82                             lea_code_070LEA     1.000000
# 83                             lea_code_080LEA     1.000000
# 84                             lea_code_090LEA     1.000000
# 85                             lea_code_100LEA     1.000000
# 86                             lea_code_120LEA     1.000000
# 87                             lea_code_130LEA     0.952755
# 88                             lea_code_140LEA     1.000000
# 89                             lea_code_150LEA     1.000000
# 90                             lea_code_160LEA     1.000000
# 91                             lea_code_170LEA     1.000000
# 92                             lea_code_190LEA     1.000000
# 93                             lea_code_200LEA     1.000000
# 94                             lea_code_210LEA     1.000000
# 95                             lea_code_220LEA     1.000000
# 96                             lea_code_230LEA     1.000000
# 97                             lea_code_250LEA     1.000000
# 98                             lea_code_260LEA     1.000000
# 99                             lea_code_270LEA     1.000000
# 100                            lea_code_280LEA     1.000000
# 101                            lea_code_300LEA     1.000000
# 102                            lea_code_310LEA     1.000000
# 103                            lea_code_320LEA     1.000000
# 104                            lea_code_330LEA     1.000000
# 105                            lea_code_340LEA     1.000000
# 106                            lea_code_350LEA     1.000000
# 107                            lea_code_360LEA     1.000000
# 108                            lea_code_370LEA     1.000000
# 109                            lea_code_380LEA     1.000000
# 110                            lea_code_390LEA     1.000000
# 111                            lea_code_400LEA     1.000000
# 112                            lea_code_410LEA     1.000000
# 113                            lea_code_430LEA     1.000000
# 114                            lea_code_440LEA     1.000000
# 115                            lea_code_450LEA     1.000000
# 116                            lea_code_460LEA     1.000000
# 117                            lea_code_470LEA     1.000000
# 118                            lea_code_480LEA     1.000000
# 119                            lea_code_500LEA     1.000000
# 120                            lea_code_510LEA     1.000000
# 121                            lea_code_520LEA     1.000000
# 122                            lea_code_530LEA     1.000000
# 123                            lea_code_540LEA     1.000000
# 124                            lea_code_550LEA     1.000000
# 125                            lea_code_560LEA     1.000000
# 126                            lea_code_570LEA     1.000000
# 127                            lea_code_580LEA     1.000000
# 128                            lea_code_590LEA     1.000000
# 129                            lea_code_600LEA     1.000000
# 130                            lea_code_610LEA     1.000000
# 131                            lea_code_620LEA     1.000000
# 132                            lea_code_630LEA     1.000000
# 133                            lea_code_640LEA     1.000000
# 134                            lea_code_650LEA     1.000000
# 135                            lea_code_660LEA     1.000000
# 136                            lea_code_670LEA     1.000000
# 137                            lea_code_690LEA     1.000000
# 138                            lea_code_700LEA     1.000000
# 139                            lea_code_710LEA     1.000000
# 140                            lea_code_720LEA     1.000000
# 141                            lea_code_730LEA     1.000000
# 142                            lea_code_740LEA     1.000000
# 143                            lea_code_750LEA     1.000000
# 144                            lea_code_770LEA     1.000000
# 145                            lea_code_780LEA     1.000000
# 146                            lea_code_790LEA     1.000000
# 147                            lea_code_800LEA     1.000000
# 148                            lea_code_810LEA     1.000000
# 149                            lea_code_830LEA     1.000000
# 150                            lea_code_840LEA     1.000000
# 151                            lea_code_850LEA     1.000000
# 152                            lea_code_870LEA     1.000000
# 153                            lea_code_880LEA     1.000000
# 154                            lea_code_890LEA     1.000000
# 155                            lea_code_900LEA     1.000000
# 156                            lea_code_910LEA     1.000000
# 157                            lea_code_920LEA     1.000000
# 158                            lea_code_930LEA     1.000000
# 159                            lea_code_940LEA     1.000000
# 160                            lea_code_950LEA     1.000000
# 161                            lea_code_960LEA     1.000000
# 162                            lea_code_970LEA     1.000000
# 163                            lea_code_980LEA     1.000000
# 164                            lea_code_990LEA     1.000000
# 165                            lea_code_995LEA     1.000000
# 166                           grade_span_KG:07     1.000000
# 167                           grade_span_KG:13     1.000000
# 168                           grade_span_KG:13     1.000000
# 169                              grade_span_NG     1.000000
# 170                           grade_span_P0:13     1.000000
# 171              subgroup_list_ALL,AM7,BL7,EDS     1.000000
# 172  subgroup_list_ALL,AM7,BL7,EDS,MU7,SWD,WH7     1.000000
# 173                  subgroup_list_ALL,BL7,SWD     1.000000
# 174                           digital_media_97     1.000000

# %%
#The old way
#print('Dropping the following ', str(len(to_drop)), ' highly correlated fields.')
#to_drop

# Comparing highly correlated unique field names in field 1 vs field 2 list above will allow you to 
# remove the least amount of fields possible.  
#len(cf['Field1'].unique())
#len(cf['Field2'].unique())

print('Dropping the following ', str(len(cf['Field2'].unique())), ' highly correlated, unique fields.')
cf['Field2'].unique()
# Out:
# Dropping the following  151  highly correlated, unique fields.
# array(['IndianPct', 'BlackPct', 'WhitePct', 'IndianMalePct',
#        'eg_index_ALL_ALL', 'eg_index_MA_ALL', 'eg_score_ALL_BL7',
#        'eg_score_ALL_ELS', 'eg_score_ALL_HI7', 'eg_score_ALL_MU7',
#        'eg_score_ALL_SWD', 'eg_score_ALL_WH7', 'eg_score_MA_ALL',
#        'eg_score_RD_ALL', 'pct_ALL_ELP', 'pct_met_Math Grades 3-8_PART',
#        'pct_met_Science Grades 5&8_PART',
#        'pct_Math Grades 3-8_ALL_PART_DET',
#        'pct_Math Grades 3-8_BL7_PART_DET',
#        'pct_Math Grades 3-8_EDS_PART_DET',
#        'pct_Math Grades 3-8_ELS_PART_DET',
#        'pct_Math Grades 3-8_HI7_PART_DET',
#        'pct_Math Grades 3-8_SWD_PART_DET',
#        'pct_Math Grades 3-8_WH7_PART_DET',
#        'pct_Science Grades 5&8_WH7_PART_DET', 'ma_score', 'rd_score',
#        'sc_score', 'ach_score', 'eg_score', 'spg_score', 'ma_spg_score',
#        'aaa_score_ALL_SPG2', 'aaa_score_BL7_SPG2', 'aaa_score_EDS_SPG2',
#        'aaa_score_ELS_SPG2', 'aaa_score_HI7_SPG2', 'aaa_score_MU7_SPG2',
#        'aaa_score_SWD_SPG2', 'aaa_score_WH7_SPG2', 'ach_score_ALL_SPG2',
#        'ach_score_BL7_SPG2', 'ach_score_EDS_SPG2', 'ach_score_ELS_SPG2',
#        'ach_score_HI7_SPG2', 'ach_score_MU7_SPG2', 'ach_score_WH7_SPG2',
#        'eg_score_ALL_SPG2', 'spg_score_ALL_SPG2', 'arr_per1000_ALL',
#        'arr_per1000_BL7', 'arr_per1000_EDS', 'iss_per1000_ALL',
#        'rpt_per1000_ALL', 'lea_code_020LEA', 'lea_code_030LEA',
#        'lea_code_040LEA', 'lea_code_050LEA', 'lea_code_060LEA',
#        'lea_code_070LEA', 'lea_code_080LEA', 'lea_code_090LEA',
#        'lea_code_100LEA', 'lea_code_120LEA', 'lea_code_130LEA',
#        'lea_code_140LEA', 'lea_code_150LEA', 'lea_code_160LEA',
#        'lea_code_170LEA', 'lea_code_190LEA', 'lea_code_200LEA',
#        'lea_code_210LEA', 'lea_code_220LEA', 'lea_code_230LEA',
#        'lea_code_250LEA', 'lea_code_260LEA', 'lea_code_270LEA',
#        'lea_code_280LEA', 'lea_code_300LEA', 'lea_code_310LEA',
#        'lea_code_320LEA', 'lea_code_330LEA', 'lea_code_340LEA',
#        'lea_code_350LEA', 'lea_code_360LEA', 'lea_code_370LEA',
#        'lea_code_380LEA', 'lea_code_390LEA', 'lea_code_400LEA',
#        'lea_code_410LEA', 'lea_code_430LEA', 'lea_code_440LEA',
#        'lea_code_450LEA', 'lea_code_460LEA', 'lea_code_470LEA',
#        'lea_code_480LEA', 'lea_code_500LEA', 'lea_code_510LEA',
#        'lea_code_520LEA', 'lea_code_530LEA', 'lea_code_540LEA',
#        'lea_code_550LEA', 'lea_code_560LEA', 'lea_code_570LEA',
#        'lea_code_580LEA', 'lea_code_590LEA', 'lea_code_600LEA',
#        'lea_code_610LEA', 'lea_code_620LEA', 'lea_code_630LEA',
#        'lea_code_640LEA', 'lea_code_650LEA', 'lea_code_660LEA',
#        'lea_code_670LEA', 'lea_code_690LEA', 'lea_code_700LEA',
#        'lea_code_710LEA', 'lea_code_720LEA', 'lea_code_730LEA',
#        'lea_code_740LEA', 'lea_code_750LEA', 'lea_code_770LEA',
#        'lea_code_780LEA', 'lea_code_790LEA', 'lea_code_800LEA',
#        'lea_code_810LEA', 'lea_code_830LEA', 'lea_code_840LEA',
#        'lea_code_850LEA', 'lea_code_870LEA', 'lea_code_880LEA',
#        'lea_code_890LEA', 'lea_code_900LEA', 'lea_code_910LEA',
#        'lea_code_920LEA', 'lea_code_930LEA', 'lea_code_940LEA',
#        'lea_code_950LEA', 'lea_code_960LEA', 'lea_code_970LEA',
#        'lea_code_980LEA', 'lea_code_990LEA', 'lea_code_995LEA',
#        'grade_span_KG:07', 'grade_span_KG:13', 'grade_span_NG',
#        'grade_span_P0:13', 'subgroup_list_ALL,AM7,BL7,EDS',
#        'subgroup_list_ALL,AM7,BL7,EDS,MU7,SWD,WH7',
#        'subgroup_list_ALL,BL7,SWD', 'digital_media_97'], dtype=object)

# %%
#Check columns before drop 
print('\r\n*********Before: Dropping Highly Correlated Fields*************************************')
schoolData.info(verbose=False)

# Drop the highly correlated features from our training data 
#schoolData = schoolData.drop(to_drop, axis=1)
schoolData = schoolData.drop(cf['Field2'], axis=1)

#Check columns after drop 
print('\r\n*********After: Dropping Highly Correlated Fields**************************************')
schoolData.info(verbose=False)
# Out:
# *********Before: Dropping Highly Correlated Fields*************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 684 entries, 2 to 838
# Columns: 753 entries, IndianPct to devices_4.07
# dtypes: float64(218), uint8(535)
# memory usage: 1.5 MB
#
# *********After: Dropping Highly Correlated Fields**************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 684 entries, 2 to 838
# Columns: 602 entries, AsianPct to devices_4.07
# dtypes: float64(164), uint8(438)
# memory usage: 1.1 MB

# %%
#Restore the unit_code before saving
schoolData['agency_code'] = agency_code
#Save the final dataset to a .csv file
schoolData.to_csv(outputDir + inputFileName + '_ML.csv', sep=',', index=False)

# %%
print('*********FINAL DATASET DETAILS*********************************************************\r\n')
schoolData.info(verbose=True)
# Out:
# *********FINAL DATASET DETAILS*********************************************************
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 684 entries, 2 to 838
# Data columns (total 603 columns):
# AsianPct                                                                                                            float64
# HispanicPct                                                                                                         float64
# PacificIslandPct                                                                                                    float64
# TwoOrMorePct                                                                                                        float64
# MinorityPct                                                                                                         float64
# AsianMalePct                                                                                                        float64
# HispanicMalePct                                                                                                     float64
# BlackMalePct                                                                                                        float64
# WhiteMalePct                                                                                                        float64
# PacificIslandMalePct                                                                                                float64
# TwoOrMoreMalePct                                                                                                    float64
# MinorityMalePct                                                                                                     float64
# IndianFemalePct                                                                                                     float64
# AsianFemalePct                                                                                                      float64
# HispanicFemalePct                                                                                                   float64
# BlackFemalePct                                                                                                      float64
# WhiteFemalePct                                                                                                      float64
# MinorityFemalePct                                                                                                   float64
# PacificIslandFemalePct                                                                                              float64
# TwoOrMoreFemalePct                                                                                                  float64
# pct_eds                                                                                                             float64
# eg_index_ALL_AIG                                                                                                    float64
# eg_index_ALL_BL7                                                                                                    float64
# eg_index_ALL_EDS                                                                                                    float64
# eg_index_ALL_ELS                                                                                                    float64
# eg_index_ALL_HI7                                                                                                    float64
# eg_index_ALL_MU7                                                                                                    float64
# eg_index_ALL_SWD                                                                                                    float64
# eg_index_ALL_WH7                                                                                                    float64
# eg_index_RD_ALL                                                                                                     float64
# eg_score_ALL_AIG                                                                                                    float64
# eg_score_ALL_ALL                                                                                                    float64
# eg_score_ALL_EDS                                                                                                    float64
# pct_EDS_ELP                                                                                                         float64
# pct_ELS_ELP                                                                                                         float64
# pct_HI7_ELP                                                                                                         float64
# pct_MALE_ELP                                                                                                        float64
# pct_NSWD_ELP                                                                                                        float64
# pct_prof_6gr_irm                                                                                                    float64
# pct_met_Math Grades 3-8_LTG                                                                                         float64
# pct_met_Reading Grades 3-8_LTG                                                                                      float64
# pct_met_Total Targets_LTG                                                                                           float64
# pct_met_Reading Grades 3-8_PART                                                                                     float64
# pct_met_Total Targets_PART                                                                                          float64
# pct_Reading Grades 3-8_ALL_PART_DET                                                                                 float64
# pct_Reading Grades 3-8_BL7_PART_DET                                                                                 float64
# pct_Reading Grades 3-8_EDS_PART_DET                                                                                 float64
# pct_Reading Grades 3-8_ELS_PART_DET                                                                                 float64
# pct_Reading Grades 3-8_HI7_PART_DET                                                                                 float64
# pct_Reading Grades 3-8_SWD_PART_DET                                                                                 float64
# pct_Reading Grades 3-8_WH7_PART_DET                                                                                 float64
# pct_Science Grades 5&8_ALL_PART_DET                                                                                 float64
# pct_Science Grades 5&8_BL7_PART_DET                                                                                 float64
# pct_Science Grades 5&8_EDS_PART_DET                                                                                 float64
# pct_Science Grades 5&8_HI7_PART_DET                                                                                 float64
# m1_score                                                                                                            float64
# rd_spg_score                                                                                                        float64
# ma_eg_score                                                                                                         float64
# rd_eg_score                                                                                                         float64
# ach_score_SWD_SPG2                                                                                                  float64
# eg_score_BL7_SPG2                                                                                                   float64
# eg_score_EDS_SPG2                                                                                                   float64
# eg_score_ELS_SPG2                                                                                                   float64
# eg_score_HI7_SPG2                                                                                                   float64
# eg_score_MU7_SPG2                                                                                                   float64
# eg_score_SWD_SPG2                                                                                                   float64
# eg_score_WH7_SPG2                                                                                                   float64
# scgs_score_ALL_SPG2                                                                                                 float64
# scgs_score_BL7_SPG2                                                                                                 float64
# scgs_score_EDS_SPG2                                                                                                 float64
# scgs_score_WH7_SPG2                                                                                                 float64
# spg_score_BL7_SPG2                                                                                                  float64
# spg_score_EDS_SPG2                                                                                                  float64
# spg_score_ELS_SPG2                                                                                                  float64
# spg_score_HI7_SPG2                                                                                                  float64
# spg_score_MU7_SPG2                                                                                                  float64
# spg_score_SWD_SPG2                                                                                                  float64
# spg_score_WH7_SPG2                                                                                                  float64
# stu_enroll                                                                                                          float64
# cte_enroll                                                                                                          float64
# cte_enrollment_pct                                                                                                  float64
# Book_TitlesPer_Student                                                                                              float64
# wap                                                                                                                 float64
# wap_class                                                                                                           float64
# media_school                                                                                                        float64
# crime                                                                                                               float64
# short_term                                                                                                          float64
# long_term                                                                                                           float64
# expulsion                                                                                                           float64
# act_per1000_ALL                                                                                                     float64
# act_per1000_BL7                                                                                                     float64
# act_per1000_EDS                                                                                                     float64
# act_per1000_ELS                                                                                                     float64
# act_per1000_FEM                                                                                                     float64
# act_per1000_HI7                                                                                                     float64
# act_per1000_MALE                                                                                                    float64
# act_per1000_MU7                                                                                                     float64
# act_per1000_SWD                                                                                                     float64
# act_per1000_WH7                                                                                                     float64
# arr_per1000_ELS                                                                                                     float64
# arr_per1000_FEM                                                                                                     float64
# arr_per1000_HI7                                                                                                     float64
# arr_per1000_MALE                                                                                                    float64
# arr_per1000_MU7                                                                                                     float64
# arr_per1000_SWD                                                                                                     float64
# arr_per1000_WH7                                                                                                     float64
# bha_per1000_ALL                                                                                                     float64
# bha_per1000_BL7                                                                                                     float64
# bha_per1000_EDS                                                                                                     float64
# bha_per1000_ELS                                                                                                     float64
# bha_per1000_FEM                                                                                                     float64
# bha_per1000_HI7                                                                                                     float64
# bha_per1000_MALE                                                                                                    float64
# bha_per1000_MU7                                                                                                     float64
# bha_per1000_SWD                                                                                                     float64
# bha_per1000_WH7                                                                                                     float64
# exp_per1000_ALL                                                                                                     float64
# exp_per1000_BL7                                                                                                     float64
# exp_per1000_EDS                                                                                                     float64
# exp_per1000_ELS                                                                                                     float64
# exp_per1000_FEM                                                                                                     float64
# exp_per1000_HI7                                                                                                     float64
# exp_per1000_MALE                                                                                                    float64
# exp_per1000_MU7                                                                                                     float64
# exp_per1000_SWD                                                                                                     float64
# exp_per1000_WH7                                                                                                     float64
# iss_per1000_BL7                                                                                                     float64
# iss_per1000_EDS                                                                                                     float64
# iss_per1000_ELS                                                                                                     float64
# iss_per1000_FEM                                                                                                     float64
# iss_per1000_HI7                                                                                                     float64
# iss_per1000_MALE                                                                                                    float64
# iss_per1000_MU7                                                                                                     float64
# iss_per1000_SWD                                                                                                     float64
# iss_per1000_WH7                                                                                                     float64
# lts_per1000_ALL                                                                                                     float64
# lts_per1000_BL7                                                                                                     float64
# lts_per1000_EDS                                                                                                     float64
# lts_per1000_ELS                                                                                                     float64
# lts_per1000_FEM                                                                                                     float64
# lts_per1000_HI7                                                                                                     float64
# lts_per1000_MALE                                                                                                    float64
# lts_per1000_MU7                                                                                                     float64
# lts_per1000_SWD                                                                                                     float64
# lts_per1000_WH7                                                                                                     float64
# rpt_per1000_BL7                                                                                                     float64
# rpt_per1000_EDS                                                                                                     float64
# rpt_per1000_ELS                                                                                                     float64
# rpt_per1000_FEM                                                                                                     float64
# rpt_per1000_HI7                                                                                                     float64
# rpt_per1000_MALE                                                                                                    float64
# rpt_per1000_MU7                                                                                                     float64
# rpt_per1000_SWD                                                                                                     float64
# rpt_per1000_WH7                                                                                                     float64
# sts_per1000_ALL                                                                                                     float64
# sts_per1000_BL7                                                                                                     float64
# sts_per1000_EDS                                                                                                     float64
# sts_per1000_ELS                                                                                                     float64
# sts_per1000_FEM                                                                                                     float64
# sts_per1000_HI7                                                                                                     float64
# sts_per1000_MALE                                                                                                    float64
# sts_per1000_MU7                                                                                                     float64
# sts_per1000_SWD                                                                                                     float64
# sts_per1000_WH7                                                                                                     float64
# category_code_I                                                                                                     uint8
# category_code_M                                                                                                     uint8
# category_code_T                                                                                                     uint8
# lea_code_110LEA                                                                                                     uint8
# lea_code_111LEA                                                                                                     uint8
# lea_code_132LEA                                                                                                     uint8
# lea_code_180LEA                                                                                                     uint8
# lea_code_181LEA                                                                                                     uint8
# lea_code_182LEA                                                                                                     uint8
# lea_code_240LEA                                                                                                     uint8
# lea_code_241LEA                                                                                                     uint8
# lea_code_290LEA                                                                                                     uint8
# lea_code_291LEA                                                                                                     uint8
# lea_code_292LEA                                                                                                     uint8
# lea_code_420LEA                                                                                                     uint8
# lea_code_421LEA                                                                                                     uint8
# lea_code_422LEA                                                                                                     uint8
# lea_code_490LEA                                                                                                     uint8
# lea_code_491LEA                                                                                                     uint8
# lea_code_680LEA                                                                                                     uint8
# lea_code_681LEA                                                                                                     uint8
# lea_code_760LEA                                                                                                     uint8
# lea_code_761LEA                                                                                                     uint8
# lea_code_820LEA                                                                                                     uint8
# lea_code_821LEA                                                                                                     uint8
# lea_code_860LEA                                                                                                     uint8
# lea_code_861LEA                                                                                                     uint8
# lea_code_862LEA                                                                                                     uint8
# county_Alexander                                                                                                    uint8
# county_Alleghany                                                                                                    uint8
# county_Anson                                                                                                        uint8
# county_Ashe                                                                                                         uint8
# county_Avery                                                                                                        uint8
# county_Beaufort                                                                                                     uint8
# county_Bertie                                                                                                       uint8
# county_Bladen                                                                                                       uint8
# county_Brunswick                                                                                                    uint8
# county_Buncombe                                                                                                     uint8
# county_Burke                                                                                                        uint8
# county_Cabarrus                                                                                                     uint8
# county_Caldwell                                                                                                     uint8
# county_Camden                                                                                                       uint8
# county_Carteret                                                                                                     uint8
# county_Caswell                                                                                                      uint8
# county_Catawba                                                                                                      uint8
# county_Chatham                                                                                                      uint8
# county_Cherokee                                                                                                     uint8
# county_Chowan                                                                                                       uint8
# county_Clay                                                                                                         uint8
# county_Cleveland                                                                                                    uint8
# county_Columbus                                                                                                     uint8
# county_Craven                                                                                                       uint8
# county_Cumberland                                                                                                   uint8
# county_Currituck                                                                                                    uint8
# county_Dare                                                                                                         uint8
# county_Davidson                                                                                                     uint8
# county_Davie                                                                                                        uint8
# county_Duplin                                                                                                       uint8
# county_Durham                                                                                                       uint8
# county_Edgecombe                                                                                                    uint8
# county_Forsyth                                                                                                      uint8
# county_Franklin                                                                                                     uint8
# county_Gaston                                                                                                       uint8
# county_Gates                                                                                                        uint8
# county_Graham                                                                                                       uint8
# county_Granville                                                                                                    uint8
# county_Greene                                                                                                       uint8
# county_Guilford                                                                                                     uint8
# county_Halifax                                                                                                      uint8
# county_Harnett                                                                                                      uint8
# county_Haywood                                                                                                      uint8
# county_Henderson                                                                                                    uint8
# county_Hertford                                                                                                     uint8
# county_Hoke                                                                                                         uint8
# county_Hyde                                                                                                         uint8
# county_Iredell                                                                                                      uint8
# county_Jackson                                                                                                      uint8
# county_Johnston                                                                                                     uint8
# county_Jones                                                                                                        uint8
# county_Lee                                                                                                          uint8
# county_Lenoir                                                                                                       uint8
# county_Lincoln                                                                                                      uint8
# county_Macon                                                                                                        uint8
# county_Madison                                                                                                      uint8
# county_Martin                                                                                                       uint8
# county_McDowell                                                                                                     uint8
# county_Mecklenburg                                                                                                  uint8
# county_Mitchell                                                                                                     uint8
# county_Montgomery                                                                                                   uint8
# county_Moore                                                                                                        uint8
# county_Nash                                                                                                         uint8
# county_New Hanover                                                                                                  uint8
# county_Northampton                                                                                                  uint8
# county_Onslow                                                                                                       uint8
# county_Orange                                                                                                       uint8
# county_Pamlico                                                                                                      uint8
# county_Pasquotank                                                                                                   uint8
# county_Pender                                                                                                       uint8
# county_Perquimans                                                                                                   uint8
# county_Person                                                                                                       uint8
# county_Pitt                                                                                                         uint8
# county_Polk                                                                                                         uint8
# county_Randolph                                                                                                     uint8
# county_Richmond                                                                                                     uint8
# county_Robeson                                                                                                      uint8
# county_Rockingham                                                                                                   uint8
# county_Rowan                                                                                                        uint8
# county_Rutherford                                                                                                   uint8
# county_Sampson                                                                                                      uint8
# county_Scotland                                                                                                     uint8
# county_Stanly                                                                                                       uint8
# county_Stokes                                                                                                       uint8
# county_Surry                                                                                                        uint8
# county_Swain                                                                                                        uint8
# county_Transylvania                                                                                                 uint8
# county_Tyrrell                                                                                                      uint8
# county_Union                                                                                                        uint8
# county_Vance                                                                                                        uint8
# county_Wake                                                                                                         uint8
# county_Warren                                                                                                       uint8
# county_Washington                                                                                                   uint8
# county_Watauga                                                                                                      uint8
# county_Wayne                                                                                                        uint8
# county_Wilkes                                                                                                       uint8
# county_Wilson                                                                                                       uint8
# county_Yadkin                                                                                                       uint8
# county_Yancey                                                                                                       uint8
# stree_addr2_Haigler-Overcash Education Center                                                                       uint8
# grade_span_04:08:00                                                                                                 uint8
# grade_span_04:09:00                                                                                                 uint8
# grade_span_05:06:00                                                                                                 uint8
# grade_span_05:08:00                                                                                                 uint8
# grade_span_06:07:00                                                                                                 uint8
# grade_span_06:08:00                                                                                                 uint8
# grade_span_06:09:00                                                                                                 uint8
# grade_span_06:10:00                                                                                                 uint8
# grade_span_06:12:00                                                                                                 uint8
# grade_span_06:13:00                                                                                                 uint8
# grade_span_07:08:00                                                                                                 uint8
# grade_span_07:12:00                                                                                                 uint8
# grade_span_07:13:00                                                                                                 uint8
# grade_span_6                                                                                                        uint8
# grade_span_KG:08                                                                                                    uint8
# grade_span_KG:12                                                                                                    uint8
# grade_span_P0:08                                                                                                    uint8
# grade_span_P0:12                                                                                                    uint8
# grade_span_P1:12                                                                                                    uint8
# grade_span_P2:07                                                                                                    uint8
# grade_span_P2:08                                                                                                    uint8
# grade_span_P2:12                                                                                                    uint8
# grade_span_P2:13                                                                                                    uint8
# grade_span_P3:08                                                                                                    uint8
# grade_span_P3:12                                                                                                    uint8
# grade_span_PK:08                                                                                                    uint8
# grade_span_PK:09                                                                                                    uint8
# grade_span_PK:12                                                                                                    uint8
# school_type_CTE School                                                                                              uint8
# school_type_EC School                                                                                               uint8
# school_type_Regular School                                                                                          uint8
# calendar_type_Traditional                                                                                           uint8
# calendar_type_Year Round                                                                                            uint8
# csi_lp_Y                                                                                                            uint8
# csi_lg_Y                                                                                                            uint8
# tsi_cu_Y                                                                                                            uint8
# tsi_at_Y                                                                                                            uint8
# grad_project_Y                                                                                                      uint8
# lp_school_Y                                                                                                         uint8
# rlp_school_Y                                                                                                        uint8
# target_list_4 Year Graduation Rate,EL Progress,Math Grade 11,Math Grades 3-8,Reading Grade 10,Reading Grades 3-8    uint8
# target_list_4 Year Graduation Rate,EL Progress,Math Grades 3-8,Reading Grade 10,Reading Grades 3-8                  uint8
# target_list_4 Year Graduation Rate,Math Grade 11                                                                    uint8
# target_list_4 Year Graduation Rate,Math Grade 11,Math Grades 3-8,Reading Grade 10,Reading Grades 3-8                uint8
# target_list_4 Year Graduation Rate,Math Grade 11,Math Grades 3-8,Reading Grades 3-8                                 uint8
# target_list_4 Year Graduation Rate,Math Grade 11,Reading Grade 10                                                   uint8
# target_list_4 Year Graduation Rate,Math Grades 3-8,Reading Grades 3-8                                               uint8
# target_list_EL Progress,Math Grades 3-8,Reading Grades 3-8                                                          uint8
# target_list_Math Grade 11,Math Grades 3-8,Reading Grades 3-8                                                        uint8
# target_list_Math Grades 3-8,Reading Grade 10,Reading Grades 3-8                                                     uint8
# target_list_Math Grades 3-8,Reading Grades 3-8                                                                      uint8
# target_list_Reading Grade 10                                                                                        uint8
# subgroup_list_ALL,AM7,BL7,EDS,ELS,HI7,MU7,SWD                                                                       uint8
# subgroup_list_ALL,AM7,BL7,EDS,ELS,HI7,MU7,SWD,WH7                                                                   uint8
# subgroup_list_ALL,AM7,BL7,EDS,ELS,HI7,SWD                                                                           uint8
# subgroup_list_ALL,AM7,BL7,EDS,ELS,HI7,SWD,WH7                                                                       uint8
# subgroup_list_ALL,AM7,BL7,EDS,HI7,SWD,WH7                                                                           uint8
# subgroup_list_ALL,AM7,BL7,EDS,SWD                                                                                   uint8
# subgroup_list_ALL,AM7,BL7,EDS,SWD,WH7                                                                               uint8
# subgroup_list_ALL,AM7,BL7,EDS,WH7                                                                                   uint8
# subgroup_list_ALL,AM7,EDS,SWD                                                                                       uint8
# subgroup_list_ALL,AM7,EDS,SWD,WH7                                                                                   uint8
# subgroup_list_ALL,AS7,BL7,EDS,ELS,HI7                                                                               uint8
# subgroup_list_ALL,AS7,BL7,EDS,ELS,HI7,MU7,SWD,WH7                                                                   uint8
# subgroup_list_ALL,AS7,BL7,EDS,ELS,HI7,SWD                                                                           uint8
# subgroup_list_ALL,AS7,BL7,EDS,ELS,HI7,SWD,WH7                                                                       uint8
# subgroup_list_ALL,AS7,BL7,EDS,ELS,HI7,WH7                                                                           uint8
# subgroup_list_ALL,AS7,BL7,EDS,ELS,MU7,SWD,WH7                                                                       uint8
# subgroup_list_ALL,AS7,BL7,EDS,HI7,MU7,SWD,WH7                                                                       uint8
# subgroup_list_ALL,AS7,BL7,EDS,HI7,MU7,WH7                                                                           uint8
# subgroup_list_ALL,AS7,BL7,EDS,HI7,SWD,WH7                                                                           uint8
# subgroup_list_ALL,AS7,BL7,HI7,MU7,SWD,WH7                                                                           uint8
# subgroup_list_ALL,AS7,EDS,ELS,HI7,MU7,SWD,WH7                                                                       uint8
# subgroup_list_ALL,AS7,EDS,ELS,HI7,SWD,WH7                                                                           uint8
# subgroup_list_ALL,AS7,EDS,HI7,SWD,WH7                                                                               uint8
# subgroup_list_ALL,AS7,WH7                                                                                           uint8
# subgroup_list_ALL,BL7,EDS                                                                                           uint8
# subgroup_list_ALL,BL7,EDS,ELS,HI7                                                                                   uint8
# subgroup_list_ALL,BL7,EDS,ELS,HI7,MU7,SWD,WH7                                                                       uint8
# subgroup_list_ALL,BL7,EDS,ELS,HI7,SWD                                                                               uint8
# subgroup_list_ALL,BL7,EDS,ELS,HI7,SWD,WH7                                                                           uint8
# subgroup_list_ALL,BL7,EDS,ELS,HI7,WH7                                                                               uint8
# subgroup_list_ALL,BL7,EDS,HI7,MU7,SWD,WH7                                                                           uint8
# subgroup_list_ALL,BL7,EDS,HI7,SWD                                                                                   uint8
# subgroup_list_ALL,BL7,EDS,HI7,SWD,WH7                                                                               uint8
# subgroup_list_ALL,BL7,EDS,HI7,WH7                                                                                   uint8
# subgroup_list_ALL,BL7,EDS,MU7,SWD,WH7                                                                               uint8
# subgroup_list_ALL,BL7,EDS,SWD                                                                                       uint8
# subgroup_list_ALL,BL7,EDS,SWD,WH7                                                                                   uint8
# subgroup_list_ALL,BL7,EDS,WH7                                                                                       uint8
# subgroup_list_ALL,EDS                                                                                               uint8
# subgroup_list_ALL,EDS,ELS,HI7                                                                                       uint8
# subgroup_list_ALL,EDS,ELS,HI7,MU7,SWD,WH7                                                                           uint8
# subgroup_list_ALL,EDS,ELS,HI7,SWD,WH7                                                                               uint8
# subgroup_list_ALL,EDS,ELS,HI7,WH7                                                                                   uint8
# subgroup_list_ALL,EDS,HI7,MU7,SWD,WH7                                                                               uint8
# subgroup_list_ALL,EDS,HI7,SWD,WH7                                                                                   uint8
# ...
# devices_0.37                                                                                                        uint8
# devices_0.38                                                                                                        uint8
# devices_0.39                                                                                                        uint8
# devices_0.4                                                                                                         uint8
# devices_0.41                                                                                                        uint8
# devices_0.42                                                                                                        uint8
# devices_0.43                                                                                                        uint8
# devices_0.44                                                                                                        uint8
# devices_0.45                                                                                                        uint8
# devices_0.46                                                                                                        uint8
# devices_0.47                                                                                                        uint8
# devices_0.48                                                                                                        uint8
# devices_0.49                                                                                                        uint8
# devices_0.5                                                                                                         uint8
# devices_0.51                                                                                                        uint8
# devices_0.52                                                                                                        uint8
# devices_0.53                                                                                                        uint8
# devices_0.54                                                                                                        uint8
# devices_0.55                                                                                                        uint8
# devices_0.56                                                                                                        uint8
# devices_0.57                                                                                                        uint8
# devices_0.58                                                                                                        uint8
# devices_0.59                                                                                                        uint8
# devices_0.6                                                                                                         uint8
# devices_0.61                                                                                                        uint8
# devices_0.62                                                                                                        uint8
# devices_0.63                                                                                                        uint8
# devices_0.64                                                                                                        uint8
# devices_0.65                                                                                                        uint8
# devices_0.66                                                                                                        uint8
# devices_0.67                                                                                                        uint8
# devices_0.68                                                                                                        uint8
# devices_0.69                                                                                                        uint8
# devices_0.7                                                                                                         uint8
# devices_0.71                                                                                                        uint8
# devices_0.72                                                                                                        uint8
# devices_0.73                                                                                                        uint8
# devices_0.74                                                                                                        uint8
# devices_0.75                                                                                                        uint8
# devices_0.76                                                                                                        uint8
# devices_0.77                                                                                                        uint8
# devices_0.78                                                                                                        uint8
# devices_0.79                                                                                                        uint8
# devices_0.8                                                                                                         uint8
# devices_0.81                                                                                                        uint8
# devices_0.82                                                                                                        uint8
# devices_0.83                                                                                                        uint8
# devices_0.84                                                                                                        uint8
# devices_0.85                                                                                                        uint8
# devices_0.86                                                                                                        uint8
# devices_0.87                                                                                                        uint8
# devices_0.88                                                                                                        uint8
# devices_0.89                                                                                                        uint8
# devices_0.9                                                                                                         uint8
# devices_0.91                                                                                                        uint8
# devices_0.92                                                                                                        uint8
# devices_0.93                                                                                                        uint8
# devices_0.94                                                                                                        uint8
# devices_0.95                                                                                                        uint8
# devices_0.96                                                                                                        uint8
# devices_0.97                                                                                                        uint8
# devices_0.98                                                                                                        uint8
# devices_0.99                                                                                                        uint8
# devices_1                                                                                                           uint8
# devices_1.01                                                                                                        uint8
# devices_1.02                                                                                                        uint8
# devices_1.03                                                                                                        uint8
# devices_1.04                                                                                                        uint8
# devices_1.05                                                                                                        uint8
# devices_1.06                                                                                                        uint8
# devices_1.07                                                                                                        uint8
# devices_1.09                                                                                                        uint8
# devices_1.1                                                                                                         uint8
# devices_1.11                                                                                                        uint8
# devices_1.12                                                                                                        uint8
# devices_1.13                                                                                                        uint8
# devices_1.14                                                                                                        uint8
# devices_1.17                                                                                                        uint8
# devices_1.18                                                                                                        uint8
# devices_1.19                                                                                                        uint8
# devices_1.2                                                                                                         uint8
# devices_1.21                                                                                                        uint8
# devices_1.22                                                                                                        uint8
# devices_1.24                                                                                                        uint8
# devices_1.26                                                                                                        uint8
# devices_1.28                                                                                                        uint8
# devices_1.3                                                                                                         uint8
# devices_1.31                                                                                                        uint8
# devices_1.33                                                                                                        uint8
# devices_1.34                                                                                                        uint8
# devices_1.35                                                                                                        uint8
# devices_1.36                                                                                                        uint8
# devices_1.38                                                                                                        uint8
# devices_1.39                                                                                                        uint8
# devices_1.4                                                                                                         uint8
# devices_1.41                                                                                                        uint8
# devices_1.42                                                                                                        uint8
# devices_1.43                                                                                                        uint8
# devices_1.44                                                                                                        uint8
# devices_1.46                                                                                                        uint8
# devices_1.47                                                                                                        uint8
# devices_1.5                                                                                                         uint8
# devices_1.54                                                                                                        uint8
# devices_1.56                                                                                                        uint8
# devices_1.57                                                                                                        uint8
# devices_1.58                                                                                                        uint8
# devices_1.6                                                                                                         uint8
# devices_1.61                                                                                                        uint8
# devices_1.62                                                                                                        uint8
# devices_1.63                                                                                                        uint8
# devices_1.65                                                                                                        uint8
# devices_1.66                                                                                                        uint8
# devices_1.68                                                                                                        uint8
# devices_1.73                                                                                                        uint8
# devices_1.78                                                                                                        uint8
# devices_1.79                                                                                                        uint8
# devices_1.82                                                                                                        uint8
# devices_1.83                                                                                                        uint8
# devices_1.87                                                                                                        uint8
# devices_1.93                                                                                                        uint8
# devices_1.96                                                                                                        uint8
# devices_2.02                                                                                                        uint8
# devices_2.1                                                                                                         uint8
# devices_2.19                                                                                                        uint8
# devices_2.37                                                                                                        uint8
# devices_2.52                                                                                                        uint8
# devices_2.53                                                                                                        uint8
# devices_3.05                                                                                                        uint8
# devices_4.07                                                                                                        uint8
# agency_code                                                                                                         object
# dtypes: float64(164), object(1), uint8(438)
# memory usage: 1.2+ MB

# %%
import sklearn
import pandas as pd

print('Sklearn Version: ' + sklearn.__version__)
print('Pandas Version: ' + pd.__version__)
# Out:
# Sklearn Version: 0.21.2
# Pandas Version: 0.23.4

# %%
print('Output File Location:\r\n\r\n' + outputDir + inputFileName + '_ML.csv')
# Out:
# Output File Location:
#
# C:/Users/Jake/Documents/GitHub/EducationDataNC/2019/Machine Learning Datasets/PublicMiddleSchools2019_ML.csv
