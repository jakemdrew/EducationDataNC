# %% [markdown]
# # Create 2017-2018 School Datasets¶
# ### This program uses all flattened raw datasets to create the school dataset files within the NCEA repository.
#
# 1. This notebook reads raw dataset .csv files directly from the \EducationDataNC\2017\Raw Datasets folder.
# 2. Each raw dataset is transformed to contain only one record per public school campus or unique agency_code.
# 3. Many raw datasets have more than one record per campus, per year. In these instances, table pivots are used to create new columns from row level entries and reduce each dataset to one record per school. This adds many new colums the flattened dataset. (see the code below for more details)
# 4. School datasets merge all flattened files into one dataset with one record per agency_code.

# %%
#import required Libraries
import pandas as pd
import numpy as np
import os
import string

#**********************************************************************************
# Set the following variables before running this code!!!
#**********************************************************************************

#'C:/Users/Jake/Documents/GitHub/EducationDataNC/2018/
dirPath = 'D:/BenepactLLC/Belk/NC_Report_Card_Data/2019/April 2019/2018/'

#Location where copies of the raw data files will be read in from csv files.
# 'C:/Users/Jake/Documents/GitHub/EducationDataNC/2018/Raw Datasets/'
dataDir = dirPath + 'Raw Datasets/'

#Location where the new school datasets will be created.
# 'C:/Users/Jake/Documents/GitHub/EducationDataNC/2018/School Datasets/'
outputDir = dirPath + 'School Datasets/'

#All raw data files are processed for the year below
schoolYear = 2018

# %% [markdown]
# # Read in the Raw Data Files
# ### This section reads raw data files directly from the \\Raw Datasets folder.
#
# * The file input location is specified at the dataDir parameter.
# * The file output location is specified at the outputDir parameter.
# * The schoolYear parameter is used to specify the correct school year to process.

# %% [markdown]
# # A List of All Files Processed

# %%
#Use wildcards to find files in a directory
import glob
#Use ntpath.basename to get a filename from a filepath
import ntpath

#Get and display a list of all .csv file names for 2018 download
rcdFiles = glob.glob(dataDir + 'rcd*.csv')

rcdFileNames = [ntpath.basename(x)[:-4] for x in rcdFiles]

print('A List of File Names and Record Counts for Processing:\n')

#Create dataframes for each file
for fileName in rcdFileNames:
    print(fileName + ', ' + str(len(eval(fileName).index)) )
    #create one ataframe for each .csv file in rcdFileNames  
    exec(fileName + ' = pd.read_csv("' + dataDir + '" + "' + fileName + '" + ".csv", low_memory=False, dtype={"agency_code": object})')
# Out:
# A List of File Names and Record Counts for Processing:
#
# rcd_161, 644
# rcd_acc_aapart, 53
# rcd_acc_act, 742
# rcd_acc_awa, 688
# rcd_acc_cgr, 738
# rcd_acc_eds, 2761
# rcd_acc_elp, 1809
# rcd_acc_essa_desig, 2645
# rcd_acc_gp, 658
# rcd_acc_irm, 1276
# rcd_acc_lowperf, 2760
# rcd_acc_ltg, 2461
# rcd_acc_ltg_detail, 2631
# rcd_acc_mcr, 717
# rcd_acc_part, 2527
# rcd_acc_part_detail, 2527
# rcd_acc_pc, 2697
# rcd_acc_rta, 1576
# rcd_acc_spg1, 2584
# rcd_acc_spg2, 2538
# rcd_acc_wk, 517
# rcd_adm, 3197
# rcd_ap, 563
# rcd_arts, 2509
# rcd_att, 3115
# rcd_charter, 241
# rcd_chronic_absent, 2719
# rcd_college, 690
# rcd_courses1, 773
# rcd_courses2, 636
# rcd_cte_concentrators, 492
# rcd_cte_credentials, 436
# rcd_cte_endorsement, 537
# rcd_cte_enrollment, 1184
# rcd_dlmi, 2723
# rcd_effectiveness, 2724
# rcd_esea_att, 2700
# rcd_experience, 2758
# rcd_funds, 292
# rcd_hqt, 2697
# rcd_ib, 51
# rcd_improvement, 19
# rcd_inc1, 3097
# rcd_inc2, 2792
# rcd_licenses, 3121
# rcd_location, 2643
# rcd_naep, 2
# rcd_nbpts, 3124
# rcd_pk_enroll, 988
# rcd_prin_demo, 116
# rcd_readiness, 1323
# rcd_sar, 2630
# rcd_sat, 613
# rcd_welcome, 1311

# %% [markdown]
# # Merge all datasets to one master dataset with one record per school
# * **Starting with the location table we left outer join on agency_code, merging data from each reshaped table into one master record.**
# * **The report below ensures that merges by location result in one unique record per public school campus.**
# * **This report also shows changes to the final dataset's column and row counts as each flattened raw dataset is merged into the final Public School Datasets.**

# %%
#Make a copy of a variable (by value) using copy() or deepcopy()
import copy 

#Remove state and district level location records before performing campus level merges
rcd_location = rcd_location[(rcd_location['agency_code'] != 'NC-SEA') & 
                            (rcd_location['agency_code'].str.contains("LEA") == False)]

#Do not merge file: rcd_acc_pc
mergeFileNames = copy.deepcopy(rcdFileNames)
mergeFileNames.remove('rcd_acc_pc')

print('*********************************Start: RCD Location Data*********************************')
rcd_location.info(verbose=False)

for fileName in mergeFileNames:
    rcd_location = rcd_location.merge(eval(fileName),how='left',on='agency_code', suffixes=('', '_Drop'))
    print('*********************************After: ' + fileName + '**************************')
    rcd_location.info(verbose=False)
    

#Rename final merged rcd file! 
PublicSchools = rcd_location

#Delete all of the duplicate / overlapping columns 
#i.e. When two tables have columns with identical names, the column from the table inside the merge() is deleted.
dropCols = [x for x in PublicSchools.columns if x.endswith('_Drop')]
PublicSchools = PublicSchools.drop(dropCols, axis=1)

print('*********************************After: Deleting Duplicated Columns*********')
PublicSchools.info(verbose=False)
# Out:
# *********************************Start: RCD Location Data*********************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2757
# Columns: 21 entries, agency_code to stem
# dtypes: float64(3), object(18)
# memory usage: 454.3+ KB
# *********************************After: rcd_161**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 56 entries, agency_code to NOINFO_WH7_CCC_PCT
# dtypes: float64(38), object(18)
# memory usage: 1.1+ MB
# *********************************After: rcd_acc_aapart**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 76 entries, agency_code to SC_HS_AAPART_PCT
# dtypes: float64(58), object(18)
# memory usage: 1.6+ MB
# *********************************After: rcd_acc_act**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 188 entries, agency_code to ACWR_WH7_ACT_PCT
# dtypes: float64(170), object(18)
# memory usage: 3.8+ MB
# *********************************After: rcd_acc_awa**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 204 entries, agency_code to WH7_AWA_PCT
# dtypes: float64(186), object(18)
# memory usage: 4.1+ MB
# *********************************After: rcd_acc_cgr**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 234 entries, agency_code to STD_WH7_CGR_PCT
# dtypes: float64(216), object(18)
# memory usage: 4.7+ MB
# *********************************After: rcd_acc_eds**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 235 entries, agency_code to pct_eds
# dtypes: float64(217), object(18)
# memory usage: 4.8+ MB
# *********************************After: rcd_acc_elp**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 251 entries, agency_code to WH7_ELP_PCT
# dtypes: float64(233), object(18)
# memory usage: 5.1+ MB
# *********************************After: rcd_acc_essa_desig**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 255 entries, agency_code to tsi_at
# dtypes: float64(233), object(22)
# memory usage: 5.2+ MB
# *********************************After: rcd_acc_gp**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 256 entries, agency_code to grad_project
# dtypes: float64(233), object(23)
# memory usage: 5.2+ MB
# *********************************After: rcd_acc_irm**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 258 entries, agency_code to 9gr_irm_pct_prof
# dtypes: float64(235), object(23)
# memory usage: 5.2+ MB
# *********************************After: rcd_acc_lowperf**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 261 entries, agency_code to clpc_school
# dtypes: float64(235), object(26)
# memory usage: 5.3+ MB
# *********************************After: rcd_acc_ltg**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 268 entries, agency_code to Total Targets_LTG_PCT_MET
# dtypes: float64(242), object(26)
# memory usage: 5.4+ MB
# *********************************After: rcd_acc_ltg_detail**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 270 entries, agency_code to subgroup_list
# dtypes: float64(242), object(28)
# memory usage: 5.5+ MB
# *********************************After: rcd_acc_mcr**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 286 entries, agency_code to WH7_MCR_PCT
# dtypes: float64(258), object(28)
# memory usage: 5.8+ MB
# *********************************After: rcd_acc_part**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 295 entries, agency_code to Total Targets_PART_PCT_MET
# dtypes: float64(267), object(28)
# memory usage: 6.0+ MB
# *********************************After: rcd_acc_part_detail**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 375 entries, agency_code to The ACT_WH7_PART_DET_PCT
# dtypes: float64(347), object(28)
# memory usage: 7.6+ MB
# *********************************After: rcd_acc_rta**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 384 entries, agency_code to retained_RTA_PCT
# dtypes: float64(356), object(28)
# memory usage: 7.8+ MB
# *********************************After: rcd_acc_spg1**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 420 entries, agency_code to rd_eg_score
# dtypes: float64(384), object(36)
# memory usage: 8.5+ MB
# *********************************After: rcd_acc_spg2**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 517 entries, agency_code to ('spg_score', 'WH7')_SPG2_PCT
# dtypes: float64(481), object(36)
# memory usage: 10.4+ MB
# *********************************After: rcd_acc_wk**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 533 entries, agency_code to WH7_WK_PCT
# dtypes: float64(497), object(36)
# memory usage: 10.8+ MB
# *********************************After: rcd_adm**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 534 entries, agency_code to avg_student_num
# dtypes: float64(498), object(36)
# memory usage: 10.8+ MB
# *********************************After: rcd_ap**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 536 entries, agency_code to pct_ap_participation
# dtypes: float64(500), object(36)
# memory usage: 10.8+ MB
# *********************************After: rcd_arts**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 540 entries, agency_code to va_cat
# dtypes: float64(500), object(40)
# memory usage: 10.9+ MB
# *********************************After: rcd_att**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 541 entries, agency_code to pct_att
# dtypes: float64(501), object(40)
# memory usage: 10.9+ MB
# *********************************After: rcd_charter**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 1201 entries, agency_code to NC-SEA_WH7_CHARTER_PCT
# dtypes: float64(1161), object(40)
# memory usage: 24.2+ MB
# *********************************After: rcd_chronic_absent**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 1213 entries, agency_code to WH7_CHRON_ABSENT_PCT
# dtypes: float64(1173), object(40)
# memory usage: 24.5+ MB
# *********************************After: rcd_college**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 1225 entries, agency_code to ENROLL_WH7_COLLEGE_PCT
# dtypes: float64(1185), object(40)
# memory usage: 24.7+ MB
# *********************************After: rcd_courses1**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 1229 entries, agency_code to pct_univ_coll_crs
# dtypes: float64(1189), object(40)
# memory usage: 24.8+ MB
# *********************************After: rcd_courses2**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 1312 entries, agency_code to pct_ib_H_WH7_COURSES2
# dtypes: float64(1272), object(40)
# memory usage: 26.5+ MB
# *********************************After: rcd_cte_concentrators**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 1327 entries, agency_code to TRAN_CTE_CONCENTRATORS
# dtypes: float64(1287), object(40)
# memory usage: 26.8+ MB
# *********************************After: rcd_cte_credentials**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 1330 entries, agency_code to cred_earned_pct
# dtypes: float64(1290), object(40)
# memory usage: 26.8+ MB
# *********************************After: rcd_cte_endorsement**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 1334 entries, agency_code to college_only
# dtypes: float64(1294), object(40)
# memory usage: 26.9+ MB
# *********************************After: rcd_cte_enrollment**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 1337 entries, agency_code to cte_enrollment_pct
# dtypes: float64(1297), object(40)
# memory usage: 27.0+ MB
# *********************************After: rcd_dlmi**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 1350 entries, agency_code to category_code_Drop
# dtypes: float64(1302), object(48)
# memory usage: 27.2+ MB
# *********************************After: rcd_effectiveness**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 1416 entries, agency_code to pct_rating_TS_Meets Expected Growth
# dtypes: float64(1368), object(48)
# memory usage: 28.6+ MB
# *********************************After: rcd_esea_att**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 1417 entries, agency_code to esea_att
# dtypes: float64(1368), object(49)
# memory usage: 28.6+ MB
# *********************************After: rcd_experience**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 1429 entries, agency_code to total_class_teach_TeacherExp
# dtypes: float64(1380), object(49)
# memory usage: 28.8+ MB
# *********************************After: rcd_funds**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 1441 entries, agency_code to federal_perpupil
# dtypes: float64(1391), object(50)
# memory usage: 29.1+ MB
# *********************************After: rcd_hqt**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 1447 entries, agency_code to T_HIGHQUAL_CLASS_PCT
# dtypes: float64(1397), object(50)
# memory usage: 29.2+ MB
# *********************************After: rcd_ib**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 1449 entries, agency_code to pct_ib_participation
# dtypes: float64(1399), object(50)
# memory usage: 29.2+ MB
# *********************************After: rcd_improvement**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 1452 entries, agency_code to  Whole School Reform_Improve_Amt
# dtypes: float64(1402), object(50)
# memory usage: 29.3+ MB
# *********************************After: rcd_inc1**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 1456 entries, agency_code to expulsion
# dtypes: float64(1406), object(50)
# memory usage: 29.4+ MB
# *********************************After: rcd_inc2**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 1560 entries, agency_code to sts_per1000_WH7
# dtypes: float64(1510), object(50)
# memory usage: 31.5+ MB
# *********************************After: rcd_licenses**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 1562 entries, agency_code to pct_lateral_entry
# dtypes: float64(1512), object(50)
# memory usage: 31.5+ MB
# *********************************After: rcd_location**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 3123 entries, agency_code to pct_lateral_entry_Drop
# dtypes: float64(3024), object(99)
# memory usage: 63.0+ MB
# *********************************After: rcd_naep**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 3330 entries, agency_code to 8_RD_WH7_Below_Basic_NAEP
# dtypes: float64(3231), object(99)
# memory usage: 67.2+ MB
# *********************************After: rcd_nbpts**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 3331 entries, agency_code to nbpts_num
# dtypes: float64(3232), object(99)
# memory usage: 67.2+ MB
# *********************************After: rcd_pk_enroll**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 3343 entries, agency_code to WH7_PK_ENROLL_PCT
# dtypes: float64(3244), object(99)
# memory usage: 67.4+ MB
# *********************************After: rcd_prin_demo**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 3348 entries, agency_code to WH7_PCT_PRIN_DEMO
# dtypes: float64(3249), object(99)
# memory usage: 67.5+ MB
# *********************************After: rcd_readiness**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 3349 entries, agency_code to pct_ready_kea
# dtypes: float64(3250), object(99)
# memory usage: 67.6+ MB
# *********************************After: rcd_sar**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 3361 entries, agency_code to Math I_SAR_AVG_SIZE
# dtypes: float64(3262), object(99)
# memory usage: 67.8+ MB
# *********************************After: rcd_sat**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 3363 entries, agency_code to pct_sat_participation
# dtypes: float64(3264), object(99)
# memory usage: 67.8+ MB
# *********************************After: rcd_welcome**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 3364 entries, agency_code to welcome_url
# dtypes: float64(3264), object(100)
# memory usage: 67.9+ MB
# *********************************After: Deleting Duplicated Columns*********
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 1801 entries, agency_code to welcome_url
# dtypes: float64(1752), object(49)
# memory usage: 36.3+ MB

# %%
#Save the master file to disk
PublicSchools.to_csv(outputDir + 'PublicSchools' + str(schoolYear) + '.csv', sep=',', index=False)

print('*********************************All Public Schools****************************')
PublicSchools.info(verbose=False)

#Filter regular public high schools
HighSchools = PublicSchools[((PublicSchools.category_code == 'H') | 
                             (PublicSchools.category_code == 'T') | 
                             (PublicSchools.category_code == 'A')) 
                            ]

#Save the file to disk
HighSchools.to_csv(outputDir + 'PublicHighSchools' + str(schoolYear) + '.csv', sep=',', index=False)

print('*********************************Regular Public High Schools*******************')
HighSchools.info(verbose=False)

#Filter regular public middle schools
MiddleSchools = PublicSchools[((PublicSchools.category_code == 'M') | 
                               (PublicSchools.category_code == 'T') | 
                               (PublicSchools.category_code == 'A') |
                               (PublicSchools.category_code == 'I'))
                             ]

#Save the file to disk
MiddleSchools.to_csv(outputDir + 'PublicMiddleSchools' + str(schoolYear) + '.csv', sep=',', index=False)

print('*********************************Regular Public Middle Schools******************')
MiddleSchools.info(verbose=False)


#Filter regular elementary high schools
ElementarySchools = PublicSchools[((PublicSchools.category_code == 'E') | 
                                   (PublicSchools.category_code == 'I') | 
                                   (PublicSchools.category_code == 'A')) 
                                 ]

#Save the file to disk
ElementarySchools.to_csv(outputDir + 'PublicElementarySchools' + str(schoolYear) + '.csv', sep=',', index=False)

print('*********************************Regular Public Elementary Schools**************')
ElementarySchools.info(verbose=False)
# Out:
# *********************************All Public Schools****************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 1801 entries, agency_code to welcome_url
# dtypes: float64(1752), object(49)
# memory usage: 36.3+ MB
# *********************************Regular Public High Schools*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 679 entries, 0 to 2640
# Columns: 1801 entries, agency_code to welcome_url
# dtypes: float64(1752), object(49)
# memory usage: 9.3+ MB
# *********************************Regular Public Middle Schools******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 806 entries, 0 to 2640
# Columns: 1801 entries, agency_code to welcome_url
# dtypes: float64(1752), object(49)
# memory usage: 11.1+ MB
# *********************************Regular Public Elementary Schools**************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1575 entries, 0 to 2641
# Columns: 1801 entries, agency_code to welcome_url
# dtypes: float64(1752), object(49)
# memory usage: 21.7+ MB

# %% [markdown]
# # Data Columns Available in Each Public School Dataset

# %%
PublicSchools.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Data columns (total 1801 columns):
# agency_code                                    object
# category_code                                  object
# agency_level                                   object
# lea_code                                       object
# designation_type                               object
# name                                           object
# county                                         object
# street_addr                                    object
# stree_addr2                                    float64
# city                                           object
# state                                          object
# zip                                            float64
# phone                                          object
# grade_span                                     object
# school_type                                    object
# calendar_type                                  object
# url                                            object
# super_name                                     object
# title_I                                        object
# esea                                           float64
# stem                                           object
# COMP1Y_ALL_CCC_PCT                             float64
# COMP1Y_AM7_CCC_PCT                             float64
# COMP1Y_AS7_CCC_PCT                             float64
# COMP1Y_BL7_CCC_PCT                             float64
# COMP1Y_EDS_CCC_PCT                             float64
# COMP1Y_FEM_CCC_PCT                             float64
# COMP1Y_HI7_CCC_PCT                             float64
# COMP1Y_MALE_CCC_PCT                            float64
# COMP1Y_MU7_CCC_PCT                             float64
# COMP1Y_SWD_CCC_PCT                             float64
# COMP1Y_WH7_CCC_PCT                             float64
# NOCOMP1Y_ALL_CCC_PCT                           float64
# NOCOMP1Y_AM7_CCC_PCT                           float64
# NOCOMP1Y_AS7_CCC_PCT                           float64
# NOCOMP1Y_BL7_CCC_PCT                           float64
# NOCOMP1Y_EDS_CCC_PCT                           float64
# NOCOMP1Y_ELS_CCC_PCT                           float64
# NOCOMP1Y_FEM_CCC_PCT                           float64
# NOCOMP1Y_HI7_CCC_PCT                           float64
# NOCOMP1Y_MALE_CCC_PCT                          float64
# NOCOMP1Y_MU7_CCC_PCT                           float64
# NOCOMP1Y_SWD_CCC_PCT                           float64
# NOCOMP1Y_WH7_CCC_PCT                           float64
# NOINFO_ALL_CCC_PCT                             float64
# NOINFO_AM7_CCC_PCT                             float64
# NOINFO_AS7_CCC_PCT                             float64
# NOINFO_BL7_CCC_PCT                             float64
# NOINFO_EDS_CCC_PCT                             float64
# NOINFO_ELS_CCC_PCT                             float64
# NOINFO_FEM_CCC_PCT                             float64
# NOINFO_HI7_CCC_PCT                             float64
# NOINFO_MALE_CCC_PCT                            float64
# NOINFO_MU7_CCC_PCT                             float64
# NOINFO_SWD_CCC_PCT                             float64
# NOINFO_WH7_CCC_PCT                             float64
# MA_03_AAPART_PCT                               float64
# MA_04_AAPART_PCT                               float64
# MA_05_AAPART_PCT                               float64
# MA_06_AAPART_PCT                               float64
# MA_07_AAPART_PCT                               float64
# MA_08_AAPART_PCT                               float64
# MA_GS_AAPART_PCT                               float64
# MA_HS_AAPART_PCT                               float64
# RD_03_AAPART_PCT                               float64
# RD_04_AAPART_PCT                               float64
# RD_05_AAPART_PCT                               float64
# RD_06_AAPART_PCT                               float64
# RD_07_AAPART_PCT                               float64
# RD_08_AAPART_PCT                               float64
# RD_GS_AAPART_PCT                               float64
# RD_HS_AAPART_PCT                               float64
# SC_05_AAPART_PCT                               float64
# SC_08_AAPART_PCT                               float64
# SC_GS_AAPART_PCT                               float64
# SC_HS_AAPART_PCT                               float64
# ACALL_AIG_ACT_PCT                              float64
# ACALL_ALL_ACT_PCT                              float64
# ACALL_AM7_ACT_PCT                              float64
# ACALL_AS7_ACT_PCT                              float64
# ACALL_BL7_ACT_PCT                              float64
# ACALL_EDS_ACT_PCT                              float64
# ACALL_ELS_ACT_PCT                              float64
# ACALL_FCS_ACT_PCT                              float64
# ACALL_FEM_ACT_PCT                              float64
# ACALL_HI7_ACT_PCT                              float64
# ACALL_HMS_ACT_PCT                              float64
# ACALL_MALE_ACT_PCT                             float64
# ACALL_MIL_ACT_PCT                              float64
# ACALL_MU7_ACT_PCT                              float64
# ACALL_SWD_ACT_PCT                              float64
# ACALL_WH7_ACT_PCT                              float64
# ACCO_AIG_ACT_PCT                               float64
# ACCO_ALL_ACT_PCT                               float64
# ACCO_AM7_ACT_PCT                               float64
# ACCO_AS7_ACT_PCT                               float64
# ACCO_BL7_ACT_PCT                               float64
# ACCO_EDS_ACT_PCT                               float64
# ACCO_ELS_ACT_PCT                               float64
# ACCO_FCS_ACT_PCT                               float64
# ACCO_FEM_ACT_PCT                               float64
# ACCO_HI7_ACT_PCT                               float64
# ACCO_HMS_ACT_PCT                               float64
# ACCO_MALE_ACT_PCT                              float64
# ACCO_MIL_ACT_PCT                               float64
# ACCO_MU7_ACT_PCT                               float64
# ACCO_SWD_ACT_PCT                               float64
# ACCO_WH7_ACT_PCT                               float64
# ACEN_AIG_ACT_PCT                               float64
# ACEN_ALL_ACT_PCT                               float64
# ACEN_AM7_ACT_PCT                               float64
# ACEN_AS7_ACT_PCT                               float64
# ACEN_BL7_ACT_PCT                               float64
# ACEN_EDS_ACT_PCT                               float64
# ACEN_ELS_ACT_PCT                               float64
# ACEN_FCS_ACT_PCT                               float64
# ACEN_FEM_ACT_PCT                               float64
# ACEN_HI7_ACT_PCT                               float64
# ACEN_HMS_ACT_PCT                               float64
# ACEN_MALE_ACT_PCT                              float64
# ACEN_MIL_ACT_PCT                               float64
# ACEN_MU7_ACT_PCT                               float64
# ACEN_SWD_ACT_PCT                               float64
# ACEN_WH7_ACT_PCT                               float64
# ACMA_AIG_ACT_PCT                               float64
# ACMA_ALL_ACT_PCT                               float64
# ACMA_AM7_ACT_PCT                               float64
# ACMA_AS7_ACT_PCT                               float64
# ACMA_BL7_ACT_PCT                               float64
# ACMA_EDS_ACT_PCT                               float64
# ACMA_ELS_ACT_PCT                               float64
# ACMA_FCS_ACT_PCT                               float64
# ACMA_FEM_ACT_PCT                               float64
# ACMA_HI7_ACT_PCT                               float64
# ACMA_HMS_ACT_PCT                               float64
# ACMA_MALE_ACT_PCT                              float64
# ACMA_MIL_ACT_PCT                               float64
# ACMA_MU7_ACT_PCT                               float64
# ACMA_SWD_ACT_PCT                               float64
# ACMA_WH7_ACT_PCT                               float64
# ACRD_AIG_ACT_PCT                               float64
# ACRD_ALL_ACT_PCT                               float64
# ACRD_AM7_ACT_PCT                               float64
# ACRD_AS7_ACT_PCT                               float64
# ACRD_BL7_ACT_PCT                               float64
# ACRD_EDS_ACT_PCT                               float64
# ACRD_ELS_ACT_PCT                               float64
# ACRD_FCS_ACT_PCT                               float64
# ACRD_FEM_ACT_PCT                               float64
# ACRD_HI7_ACT_PCT                               float64
# ACRD_HMS_ACT_PCT                               float64
# ACRD_MALE_ACT_PCT                              float64
# ACRD_MIL_ACT_PCT                               float64
# ACRD_MU7_ACT_PCT                               float64
# ACRD_SWD_ACT_PCT                               float64
# ACRD_WH7_ACT_PCT                               float64
# ACSC_AIG_ACT_PCT                               float64
# ACSC_ALL_ACT_PCT                               float64
# ACSC_AM7_ACT_PCT                               float64
# ACSC_AS7_ACT_PCT                               float64
# ACSC_BL7_ACT_PCT                               float64
# ACSC_EDS_ACT_PCT                               float64
# ACSC_ELS_ACT_PCT                               float64
# ACSC_FCS_ACT_PCT                               float64
# ACSC_FEM_ACT_PCT                               float64
# ACSC_HI7_ACT_PCT                               float64
# ACSC_HMS_ACT_PCT                               float64
# ACSC_MALE_ACT_PCT                              float64
# ACSC_MIL_ACT_PCT                               float64
# ACSC_MU7_ACT_PCT                               float64
# ACSC_SWD_ACT_PCT                               float64
# ACSC_WH7_ACT_PCT                               float64
# ACWR_AIG_ACT_PCT                               float64
# ACWR_ALL_ACT_PCT                               float64
# ACWR_AM7_ACT_PCT                               float64
# ACWR_AS7_ACT_PCT                               float64
# ACWR_BL7_ACT_PCT                               float64
# ACWR_EDS_ACT_PCT                               float64
# ACWR_ELS_ACT_PCT                               float64
# ACWR_FCS_ACT_PCT                               float64
# ACWR_FEM_ACT_PCT                               float64
# ACWR_HI7_ACT_PCT                               float64
# ACWR_HMS_ACT_PCT                               float64
# ACWR_MALE_ACT_PCT                              float64
# ACWR_MIL_ACT_PCT                               float64
# ACWR_MU7_ACT_PCT                               float64
# ACWR_SWD_ACT_PCT                               float64
# ACWR_WH7_ACT_PCT                               float64
# AIG_AWA_PCT                                    float64
# ALL_AWA_PCT                                    float64
# AM7_AWA_PCT                                    float64
# AS7_AWA_PCT                                    float64
# BL7_AWA_PCT                                    float64
# EDS_AWA_PCT                                    float64
# ELS_AWA_PCT                                    float64
# FCS_AWA_PCT                                    float64
# FEM_AWA_PCT                                    float64
# HI7_AWA_PCT                                    float64
# HMS_AWA_PCT                                    float64
# MALE_AWA_PCT                                   float64
# MIL_AWA_PCT                                    float64
# MU7_AWA_PCT                                    float64
# SWD_AWA_PCT                                    float64
# WH7_AWA_PCT                                    float64
# EXT_AIG_CGR_PCT                                float64
# EXT_ALL_CGR_PCT                                float64
# EXT_AM7_CGR_PCT                                float64
# EXT_AS7_CGR_PCT                                float64
# EXT_BL7_CGR_PCT                                float64
# EXT_EDS_CGR_PCT                                float64
# EXT_ELS_CGR_PCT                                float64
# EXT_FEM_CGR_PCT                                float64
# EXT_HI7_CGR_PCT                                float64
# EXT_MALE_CGR_PCT                               float64
# EXT_MIG_CGR_PCT                                float64
# EXT_MU7_CGR_PCT                                float64
# EXT_SWD_CGR_PCT                                float64
# EXT_WH7_CGR_PCT                                float64
# STD_AIG_CGR_PCT                                float64
# STD_ALL_CGR_PCT                                float64
# STD_AM7_CGR_PCT                                float64
# STD_AS7_CGR_PCT                                float64
# STD_BL7_CGR_PCT                                float64
# STD_EDS_CGR_PCT                                float64
# STD_ELS_CGR_PCT                                float64
# STD_FCS_CGR_PCT                                float64
# STD_FEM_CGR_PCT                                float64
# STD_HI7_CGR_PCT                                float64
# STD_HMS_CGR_PCT                                float64
# STD_MALE_CGR_PCT                               float64
# STD_MIG_CGR_PCT                                float64
# STD_MU7_CGR_PCT                                float64
# STD_SWD_CGR_PCT                                float64
# STD_WH7_CGR_PCT                                float64
# pct_eds                                        float64
# AIG_ELP_PCT                                    float64
# ALL_ELP_PCT                                    float64
# AM7_ELP_PCT                                    float64
# AS7_ELP_PCT                                    float64
# BL7_ELP_PCT                                    float64
# EDS_ELP_PCT                                    float64
# ELS_ELP_PCT                                    float64
# FCS_ELP_PCT                                    float64
# FEM_ELP_PCT                                    float64
# HI7_ELP_PCT                                    float64
# HMS_ELP_PCT                                    float64
# MALE_ELP_PCT                                   float64
# MIL_ELP_PCT                                    float64
# MU7_ELP_PCT                                    float64
# SWD_ELP_PCT                                    float64
# WH7_ELP_PCT                                    float64
# csi_lp                                         object
# csi_lg                                         object
# tsi_cu                                         object
# tsi_at                                         object
# grad_project                                   object
# 6gr_irm_pct_prof                               float64
# 9gr_irm_pct_prof                               float64
# lp_school                                      object
# rlp_school                                     object
# clpc_school                                    object
# 4 Year Graduation Rate_LTG_PCT_MET             float64
# EL Progress_LTG_PCT_MET                        float64
# Math Grade 11_LTG_PCT_MET                      float64
# Math Grades 3-8_LTG_PCT_MET                    float64
# Reading Grade 10_LTG_PCT_MET                   float64
# Reading Grades 3-8_LTG_PCT_MET                 float64
# Total Targets_LTG_PCT_MET                      float64
# target_list                                    object
# subgroup_list                                  object
# AIG_MCR_PCT                                    float64
# ALL_MCR_PCT                                    float64
# AM7_MCR_PCT                                    float64
# AS7_MCR_PCT                                    float64
# BL7_MCR_PCT                                    float64
# EDS_MCR_PCT                                    float64
# ELS_MCR_PCT                                    float64
# FCS_MCR_PCT                                    float64
# FEM_MCR_PCT                                    float64
# HI7_MCR_PCT                                    float64
# HMS_MCR_PCT                                    float64
# MALE_MCR_PCT                                   float64
# MIL_MCR_PCT                                    float64
# MU7_MCR_PCT                                    float64
# SWD_MCR_PCT                                    float64
# WH7_MCR_PCT                                    float64
# ACT WorkKeys_PART_PCT_MET                      float64
# Biology_PART_PCT_MET                           float64
# English II_PART_PCT_MET                        float64
# High School Math_PART_PCT_MET                  float64
# Math Grades 3-8_PART_PCT_MET                   float64
# Reading Grades 3-8_PART_PCT_MET                float64
# Science Grades 5&8_PART_PCT_MET                float64
# The ACT_PART_PCT_MET                           float64
# Total Targets_PART_PCT_MET                     float64
# ACT WorkKeys_ALL_PART_DET_PCT                  float64
# ACT WorkKeys_AM7_PART_DET_PCT                  float64
# ACT WorkKeys_AS7_PART_DET_PCT                  float64
# ACT WorkKeys_BL7_PART_DET_PCT                  float64
# ACT WorkKeys_EDS_PART_DET_PCT                  float64
# ACT WorkKeys_ELS_PART_DET_PCT                  float64
# ACT WorkKeys_HI7_PART_DET_PCT                  float64
# ACT WorkKeys_MU7_PART_DET_PCT                  float64
# ACT WorkKeys_SWD_PART_DET_PCT                  float64
# ACT WorkKeys_WH7_PART_DET_PCT                  float64
# Biology_ALL_PART_DET_PCT                       float64
# Biology_AM7_PART_DET_PCT                       float64
# Biology_AS7_PART_DET_PCT                       float64
# Biology_BL7_PART_DET_PCT                       float64
# Biology_EDS_PART_DET_PCT                       float64
# Biology_ELS_PART_DET_PCT                       float64
# Biology_HI7_PART_DET_PCT                       float64
# Biology_MU7_PART_DET_PCT                       float64
# Biology_SWD_PART_DET_PCT                       float64
# Biology_WH7_PART_DET_PCT                       float64
# English II_ALL_PART_DET_PCT                    float64
# English II_AM7_PART_DET_PCT                    float64
# English II_AS7_PART_DET_PCT                    float64
# English II_BL7_PART_DET_PCT                    float64
# English II_EDS_PART_DET_PCT                    float64
# English II_ELS_PART_DET_PCT                    float64
# English II_HI7_PART_DET_PCT                    float64
# English II_MU7_PART_DET_PCT                    float64
# English II_SWD_PART_DET_PCT                    float64
# English II_WH7_PART_DET_PCT                    float64
# High School Math_ALL_PART_DET_PCT              float64
# High School Math_AM7_PART_DET_PCT              float64
# High School Math_AS7_PART_DET_PCT              float64
# High School Math_BL7_PART_DET_PCT              float64
# High School Math_EDS_PART_DET_PCT              float64
# High School Math_ELS_PART_DET_PCT              float64
# High School Math_HI7_PART_DET_PCT              float64
# High School Math_MU7_PART_DET_PCT              float64
# High School Math_SWD_PART_DET_PCT              float64
# High School Math_WH7_PART_DET_PCT              float64
# Math Grades 3-8_ALL_PART_DET_PCT               float64
# Math Grades 3-8_AM7_PART_DET_PCT               float64
# Math Grades 3-8_AS7_PART_DET_PCT               float64
# Math Grades 3-8_BL7_PART_DET_PCT               float64
# Math Grades 3-8_EDS_PART_DET_PCT               float64
# Math Grades 3-8_ELS_PART_DET_PCT               float64
# Math Grades 3-8_HI7_PART_DET_PCT               float64
# Math Grades 3-8_MU7_PART_DET_PCT               float64
# Math Grades 3-8_SWD_PART_DET_PCT               float64
# Math Grades 3-8_WH7_PART_DET_PCT               float64
# Reading Grades 3-8_ALL_PART_DET_PCT            float64
# Reading Grades 3-8_AM7_PART_DET_PCT            float64
# Reading Grades 3-8_AS7_PART_DET_PCT            float64
# Reading Grades 3-8_BL7_PART_DET_PCT            float64
# Reading Grades 3-8_EDS_PART_DET_PCT            float64
# Reading Grades 3-8_ELS_PART_DET_PCT            float64
# Reading Grades 3-8_HI7_PART_DET_PCT            float64
# Reading Grades 3-8_MU7_PART_DET_PCT            float64
# Reading Grades 3-8_SWD_PART_DET_PCT            float64
# Reading Grades 3-8_WH7_PART_DET_PCT            float64
# Science Grades 5&8_ALL_PART_DET_PCT            float64
# Science Grades 5&8_AM7_PART_DET_PCT            float64
# Science Grades 5&8_AS7_PART_DET_PCT            float64
# Science Grades 5&8_BL7_PART_DET_PCT            float64
# Science Grades 5&8_EDS_PART_DET_PCT            float64
# Science Grades 5&8_ELS_PART_DET_PCT            float64
# Science Grades 5&8_HI7_PART_DET_PCT            float64
# Science Grades 5&8_MU7_PART_DET_PCT            float64
# Science Grades 5&8_SWD_PART_DET_PCT            float64
# Science Grades 5&8_WH7_PART_DET_PCT            float64
# The ACT_ALL_PART_DET_PCT                       float64
# The ACT_AM7_PART_DET_PCT                       float64
# The ACT_AS7_PART_DET_PCT                       float64
# The ACT_BL7_PART_DET_PCT                       float64
# The ACT_EDS_PART_DET_PCT                       float64
# The ACT_ELS_PART_DET_PCT                       float64
# The ACT_HI7_PART_DET_PCT                       float64
# The ACT_MU7_PART_DET_PCT                       float64
# The ACT_SWD_PART_DET_PCT                       float64
# The ACT_WH7_PART_DET_PCT                       float64
# gce_all_RTA_PCT                                float64
# gce_prm_RTA_PCT                                float64
# gce_rpf_RTA_PCT                                float64
# gce_swd_RTA_PCT                                float64
# passed_eog_RTA_PCT                             float64
# passed_laa_RTA_PCT                             float64
# passed_rta_RTA_PCT                             float64
# promoted_RTA_PCT                               float64
# retained_RTA_PCT                               float64
# asm_option                                     object
# subgroup                                       object
# ma_score                                       float64
# ma_score_masking                               float64
# ma_grade                                       object
# rd_score                                       float64
# rd_score_masking                               float64
# rd_grade                                       object
# sc_score                                       float64
# sc_score_masking                               float64
# m1_score                                       float64
# m1_score_masking                               float64
# e2_score                                       float64
# e2_score_masking                               float64
# bi_score                                       float64
# bi_score_masking                               float64
# act_score                                      float64
# act_score_masking                              float64
# wk_score                                       float64
# wk_score_masking                               float64
# mcr_score                                      float64
# mcr_score_masking                              float64
# cgrs_score                                     float64
# cgrs_score_masking                             float64
# ach_score                                      float64
# ach_score_masking                              float64
# eg_status                                      object
# eg_score                                       float64
# spg_score                                      float64
# spg_grade                                      object
# ma_spg_score                                   float64
# rd_spg_score                                   float64
# ma_eg_status                                   object
# rd_eg_status                                   object
# ma_eg_score                                    float64
# rd_eg_score                                    float64
# ('aaa_score', 'ALL')_SPG2_PCT                  float64
# ('aaa_score', 'AM7')_SPG2_PCT                  float64
# ('aaa_score', 'AS7')_SPG2_PCT                  float64
# ('aaa_score', 'BL7')_SPG2_PCT                  float64
# ('aaa_score', 'EDS')_SPG2_PCT                  float64
# ('aaa_score', 'ELS')_SPG2_PCT                  float64
# ('aaa_score', 'HI7')_SPG2_PCT                  float64
# ('aaa_score', 'MU7')_SPG2_PCT                  float64
# ('aaa_score', 'SWD')_SPG2_PCT                  float64
# ('aaa_score', 'WH7')_SPG2_PCT                  float64
# ('ach_score', 'ALL')_SPG2_PCT                  float64
# ('ach_score', 'AM7')_SPG2_PCT                  float64
# ('ach_score', 'AS7')_SPG2_PCT                  float64
# ('ach_score', 'BL7')_SPG2_PCT                  float64
# ('ach_score', 'EDS')_SPG2_PCT                  float64
# ('ach_score', 'ELS')_SPG2_PCT                  float64
# ('ach_score', 'HI7')_SPG2_PCT                  float64
# ('ach_score', 'MU7')_SPG2_PCT                  float64
# ('ach_score', 'SWD')_SPG2_PCT                  float64
# ('ach_score', 'WH7')_SPG2_PCT                  float64
# ('awa_score', 'ALL')_SPG2_PCT                  float64
# ('awa_score', 'AM7')_SPG2_PCT                  float64
# ('awa_score', 'AS7')_SPG2_PCT                  float64
# ('awa_score', 'BL7')_SPG2_PCT                  float64
# ('awa_score', 'EDS')_SPG2_PCT                  float64
# ('awa_score', 'ELS')_SPG2_PCT                  float64
# ('awa_score', 'HI7')_SPG2_PCT                  float64
# ('awa_score', 'MU7')_SPG2_PCT                  float64
# ('awa_score', 'SWD')_SPG2_PCT                  float64
# ('awa_score', 'WH7')_SPG2_PCT                  float64
# ('bi_score', 'ALL')_SPG2_PCT                   float64
# ('bi_score', 'AM7')_SPG2_PCT                   float64
# ('bi_score', 'AS7')_SPG2_PCT                   float64
# ('bi_score', 'BL7')_SPG2_PCT                   float64
# ('bi_score', 'EDS')_SPG2_PCT                   float64
# ('bi_score', 'ELS')_SPG2_PCT                   float64
# ('bi_score', 'HI7')_SPG2_PCT                   float64
# ('bi_score', 'MU7')_SPG2_PCT                   float64
# ('bi_score', 'SWD')_SPG2_PCT                   float64
# ('bi_score', 'WH7')_SPG2_PCT                   float64
# ('cgrs_score', 'ALL')_SPG2_PCT                 float64
# ('cgrs_score', 'AM7')_SPG2_PCT                 float64
# ('cgrs_score', 'AS7')_SPG2_PCT                 float64
# ('cgrs_score', 'BL7')_SPG2_PCT                 float64
# ('cgrs_score', 'EDS')_SPG2_PCT                 float64
# ('cgrs_score', 'ELS')_SPG2_PCT                 float64
# ('cgrs_score', 'HI7')_SPG2_PCT                 float64
# ('cgrs_score', 'MU7')_SPG2_PCT                 float64
# ('cgrs_score', 'SWD')_SPG2_PCT                 float64
# ('cgrs_score', 'WH7')_SPG2_PCT                 float64
# ('eg_score', 'ALL')_SPG2_PCT                   float64
# ('eg_score', 'AM7')_SPG2_PCT                   float64
# ('eg_score', 'AS7')_SPG2_PCT                   float64
# ('eg_score', 'BL7')_SPG2_PCT                   float64
# ('eg_score', 'EDS')_SPG2_PCT                   float64
# ('eg_score', 'ELS')_SPG2_PCT                   float64
# ('eg_score', 'HI7')_SPG2_PCT                   float64
# ('eg_score', 'MU7')_SPG2_PCT                   float64
# ('eg_score', 'SWD')_SPG2_PCT                   float64
# ('eg_score', 'WH7')_SPG2_PCT                   float64
# ('elp_score', 'ALL')_SPG2_PCT                  float64
# ('elp_score', 'AS7')_SPG2_PCT                  float64
# ('elp_score', 'BL7')_SPG2_PCT                  float64
# ('elp_score', 'EDS')_SPG2_PCT                  float64
# ('elp_score', 'ELS')_SPG2_PCT                  float64
# ('elp_score', 'HI7')_SPG2_PCT                  float64
# ('elp_score', 'SWD')_SPG2_PCT                  float64
# ('mcr_score', 'ALL')_SPG2_PCT                  float64
# ('mcr_score', 'AM7')_SPG2_PCT                  float64
# ('mcr_score', 'AS7')_SPG2_PCT                  float64
# ('mcr_score', 'BL7')_SPG2_PCT                  float64
# ('mcr_score', 'EDS')_SPG2_PCT                  float64
# ('mcr_score', 'ELS')_SPG2_PCT                  float64
# ('mcr_score', 'HI7')_SPG2_PCT                  float64
# ('mcr_score', 'MU7')_SPG2_PCT                  float64
# ('mcr_score', 'SWD')_SPG2_PCT                  float64
# ('mcr_score', 'WH7')_SPG2_PCT                  float64
# ('scgs_score', 'ALL')_SPG2_PCT                 float64
# ('scgs_score', 'AM7')_SPG2_PCT                 float64
# ('scgs_score', 'AS7')_SPG2_PCT                 float64
# ('scgs_score', 'BL7')_SPG2_PCT                 float64
# ('scgs_score', 'EDS')_SPG2_PCT                 float64
# ('scgs_score', 'ELS')_SPG2_PCT                 float64
# ('scgs_score', 'HI7')_SPG2_PCT                 float64
# ('scgs_score', 'MU7')_SPG2_PCT                 float64
# ('scgs_score', 'SWD')_SPG2_PCT                 float64
# ('scgs_score', 'WH7')_SPG2_PCT                 float64
# ('spg_score', 'ALL')_SPG2_PCT                  float64
# ('spg_score', 'AM7')_SPG2_PCT                  float64
# ('spg_score', 'AS7')_SPG2_PCT                  float64
# ('spg_score', 'BL7')_SPG2_PCT                  float64
# ('spg_score', 'EDS')_SPG2_PCT                  float64
# ('spg_score', 'ELS')_SPG2_PCT                  float64
# ('spg_score', 'HI7')_SPG2_PCT                  float64
# ('spg_score', 'MU7')_SPG2_PCT                  float64
# ('spg_score', 'SWD')_SPG2_PCT                  float64
# ('spg_score', 'WH7')_SPG2_PCT                  float64
# AIG_WK_PCT                                     float64
# ALL_WK_PCT                                     float64
# AM7_WK_PCT                                     float64
# AS7_WK_PCT                                     float64
# BL7_WK_PCT                                     float64
# EDS_WK_PCT                                     float64
# ELS_WK_PCT                                     float64
# FCS_WK_PCT                                     float64
# FEM_WK_PCT                                     float64
# HI7_WK_PCT                                     float64
# HMS_WK_PCT                                     float64
# MALE_WK_PCT                                    float64
# MIL_WK_PCT                                     float64
# MU7_WK_PCT                                     float64
# SWD_WK_PCT                                     float64
# WH7_WK_PCT                                     float64
# avg_student_num                                float64
# pct_ap_pass                                    float64
# pct_ap_participation                           float64
# dance_cat                                      object
# music_cat                                      object
# theatre_cat                                    object
# va_cat                                         object
# pct_att                                        float64
# 010LEA_AM7_CHARTER_PCT                         float64
# 010LEA_AS7_CHARTER_PCT                         float64
# 010LEA_BL7_CHARTER_PCT                         float64
# 010LEA_EDS_CHARTER_PCT                         float64
# 010LEA_ELS_CHARTER_PCT                         float64
# 010LEA_HI7_CHARTER_PCT                         float64
# 010LEA_MU7_CHARTER_PCT                         float64
# 010LEA_PI7_CHARTER_PCT                         float64
# 010LEA_SWD_CHARTER_PCT                         float64
# 010LEA_WH7_CHARTER_PCT                         float64
# 060LEA_AM7_CHARTER_PCT                         float64
# 060LEA_AS7_CHARTER_PCT                         float64
# 060LEA_BL7_CHARTER_PCT                         float64
# 060LEA_EDS_CHARTER_PCT                         float64
# 060LEA_ELS_CHARTER_PCT                         float64
# 060LEA_HI7_CHARTER_PCT                         float64
# 060LEA_MU7_CHARTER_PCT                         float64
# 060LEA_PI7_CHARTER_PCT                         float64
# 060LEA_SWD_CHARTER_PCT                         float64
# 060LEA_WH7_CHARTER_PCT                         float64
# 070LEA_AM7_CHARTER_PCT                         float64
# 070LEA_AS7_CHARTER_PCT                         float64
# 070LEA_BL7_CHARTER_PCT                         float64
# 070LEA_EDS_CHARTER_PCT                         float64
# 070LEA_ELS_CHARTER_PCT                         float64
# 070LEA_HI7_CHARTER_PCT                         float64
# 070LEA_MU7_CHARTER_PCT                         float64
# 070LEA_PI7_CHARTER_PCT                         float64
# 070LEA_SWD_CHARTER_PCT                         float64
# 070LEA_WH7_CHARTER_PCT                         float64
# 080LEA_AM7_CHARTER_PCT                         float64
# 080LEA_AS7_CHARTER_PCT                         float64
# 080LEA_BL7_CHARTER_PCT                         float64
# 080LEA_EDS_CHARTER_PCT                         float64
# 080LEA_ELS_CHARTER_PCT                         float64
# 080LEA_HI7_CHARTER_PCT                         float64
# 080LEA_MU7_CHARTER_PCT                         float64
# 080LEA_PI7_CHARTER_PCT                         float64
# 080LEA_SWD_CHARTER_PCT                         float64
# 080LEA_WH7_CHARTER_PCT                         float64
# 090LEA_AM7_CHARTER_PCT                         float64
# 090LEA_AS7_CHARTER_PCT                         float64
# 090LEA_BL7_CHARTER_PCT                         float64
# 090LEA_EDS_CHARTER_PCT                         float64
# 090LEA_ELS_CHARTER_PCT                         float64
# 090LEA_HI7_CHARTER_PCT                         float64
# 090LEA_MU7_CHARTER_PCT                         float64
# 090LEA_PI7_CHARTER_PCT                         float64
# 090LEA_SWD_CHARTER_PCT                         float64
# 090LEA_WH7_CHARTER_PCT                         float64
# 100LEA_AM7_CHARTER_PCT                         float64
# 100LEA_AS7_CHARTER_PCT                         float64
# 100LEA_BL7_CHARTER_PCT                         float64
# 100LEA_EDS_CHARTER_PCT                         float64
# 100LEA_ELS_CHARTER_PCT                         float64
# 100LEA_HI7_CHARTER_PCT                         float64
# 100LEA_MU7_CHARTER_PCT                         float64
# 100LEA_PI7_CHARTER_PCT                         float64
# 100LEA_SWD_CHARTER_PCT                         float64
# 100LEA_WH7_CHARTER_PCT                         float64
# 110LEA_AM7_CHARTER_PCT                         float64
# 110LEA_AS7_CHARTER_PCT                         float64
# 110LEA_BL7_CHARTER_PCT                         float64
# 110LEA_EDS_CHARTER_PCT                         float64
# 110LEA_ELS_CHARTER_PCT                         float64
# 110LEA_HI7_CHARTER_PCT                         float64
# 110LEA_MU7_CHARTER_PCT                         float64
# 110LEA_PI7_CHARTER_PCT                         float64
# 110LEA_SWD_CHARTER_PCT                         float64
# 110LEA_WH7_CHARTER_PCT                         float64
# 111LEA_AM7_CHARTER_PCT                         float64
# 111LEA_AS7_CHARTER_PCT                         float64
# 111LEA_BL7_CHARTER_PCT                         float64
# 111LEA_EDS_CHARTER_PCT                         float64
# 111LEA_ELS_CHARTER_PCT                         float64
# 111LEA_HI7_CHARTER_PCT                         float64
# 111LEA_MU7_CHARTER_PCT                         float64
# 111LEA_PI7_CHARTER_PCT                         float64
# 111LEA_SWD_CHARTER_PCT                         float64
# 111LEA_WH7_CHARTER_PCT                         float64
# 120LEA_AM7_CHARTER_PCT                         float64
# 120LEA_AS7_CHARTER_PCT                         float64
# 120LEA_BL7_CHARTER_PCT                         float64
# 120LEA_EDS_CHARTER_PCT                         float64
# 120LEA_ELS_CHARTER_PCT                         float64
# 120LEA_HI7_CHARTER_PCT                         float64
# 120LEA_MU7_CHARTER_PCT                         float64
# 120LEA_PI7_CHARTER_PCT                         float64
# 120LEA_SWD_CHARTER_PCT                         float64
# 120LEA_WH7_CHARTER_PCT                         float64
# 130LEA_AM7_CHARTER_PCT                         float64
# 130LEA_AS7_CHARTER_PCT                         float64
# 130LEA_BL7_CHARTER_PCT                         float64
# 130LEA_EDS_CHARTER_PCT                         float64
# 130LEA_ELS_CHARTER_PCT                         float64
# 130LEA_HI7_CHARTER_PCT                         float64
# 130LEA_MU7_CHARTER_PCT                         float64
# 130LEA_PI7_CHARTER_PCT                         float64
# 130LEA_SWD_CHARTER_PCT                         float64
# 130LEA_WH7_CHARTER_PCT                         float64
# 160LEA_AM7_CHARTER_PCT                         float64
# 160LEA_AS7_CHARTER_PCT                         float64
# 160LEA_BL7_CHARTER_PCT                         float64
# 160LEA_EDS_CHARTER_PCT                         float64
# 160LEA_ELS_CHARTER_PCT                         float64
# 160LEA_HI7_CHARTER_PCT                         float64
# 160LEA_MU7_CHARTER_PCT                         float64
# 160LEA_PI7_CHARTER_PCT                         float64
# 160LEA_SWD_CHARTER_PCT                         float64
# 160LEA_WH7_CHARTER_PCT                         float64
# 190LEA_AM7_CHARTER_PCT                         float64
# 190LEA_AS7_CHARTER_PCT                         float64
# 190LEA_BL7_CHARTER_PCT                         float64
# 190LEA_EDS_CHARTER_PCT                         float64
# 190LEA_ELS_CHARTER_PCT                         float64
# 190LEA_HI7_CHARTER_PCT                         float64
# 190LEA_MU7_CHARTER_PCT                         float64
# 190LEA_PI7_CHARTER_PCT                         float64
# 190LEA_SWD_CHARTER_PCT                         float64
# 190LEA_WH7_CHARTER_PCT                         float64
# 200LEA_AM7_CHARTER_PCT                         float64
# 200LEA_AS7_CHARTER_PCT                         float64
# 200LEA_BL7_CHARTER_PCT                         float64
# 200LEA_EDS_CHARTER_PCT                         float64
# 200LEA_ELS_CHARTER_PCT                         float64
# 200LEA_HI7_CHARTER_PCT                         float64
# 200LEA_MU7_CHARTER_PCT                         float64
# 200LEA_PI7_CHARTER_PCT                         float64
# 200LEA_SWD_CHARTER_PCT                         float64
# 200LEA_WH7_CHARTER_PCT                         float64
# 230LEA_AM7_CHARTER_PCT                         float64
# 230LEA_AS7_CHARTER_PCT                         float64
# 230LEA_BL7_CHARTER_PCT                         float64
# 230LEA_EDS_CHARTER_PCT                         float64
# 230LEA_ELS_CHARTER_PCT                         float64
# 230LEA_HI7_CHARTER_PCT                         float64
# 230LEA_MU7_CHARTER_PCT                         float64
# 230LEA_PI7_CHARTER_PCT                         float64
# 230LEA_SWD_CHARTER_PCT                         float64
# 230LEA_WH7_CHARTER_PCT                         float64
# 240LEA_AM7_CHARTER_PCT                         float64
# 240LEA_AS7_CHARTER_PCT                         float64
# 240LEA_BL7_CHARTER_PCT                         float64
# 240LEA_EDS_CHARTER_PCT                         float64
# 240LEA_ELS_CHARTER_PCT                         float64
# 240LEA_HI7_CHARTER_PCT                         float64
# 240LEA_MU7_CHARTER_PCT                         float64
# 240LEA_PI7_CHARTER_PCT                         float64
# 240LEA_SWD_CHARTER_PCT                         float64
# 240LEA_WH7_CHARTER_PCT                         float64
# 241LEA_AM7_CHARTER_PCT                         float64
# 241LEA_AS7_CHARTER_PCT                         float64
# 241LEA_BL7_CHARTER_PCT                         float64
# 241LEA_EDS_CHARTER_PCT                         float64
# 241LEA_ELS_CHARTER_PCT                         float64
# 241LEA_HI7_CHARTER_PCT                         float64
# 241LEA_MU7_CHARTER_PCT                         float64
# 241LEA_PI7_CHARTER_PCT                         float64
# 241LEA_SWD_CHARTER_PCT                         float64
# 241LEA_WH7_CHARTER_PCT                         float64
# 260LEA_AM7_CHARTER_PCT                         float64
# 260LEA_AS7_CHARTER_PCT                         float64
# 260LEA_BL7_CHARTER_PCT                         float64
# 260LEA_EDS_CHARTER_PCT                         float64
# 260LEA_ELS_CHARTER_PCT                         float64
# 260LEA_HI7_CHARTER_PCT                         float64
# 260LEA_MU7_CHARTER_PCT                         float64
# 260LEA_PI7_CHARTER_PCT                         float64
# 260LEA_SWD_CHARTER_PCT                         float64
# 260LEA_WH7_CHARTER_PCT                         float64
# 270LEA_AM7_CHARTER_PCT                         float64
# 270LEA_AS7_CHARTER_PCT                         float64
# 270LEA_BL7_CHARTER_PCT                         float64
# 270LEA_EDS_CHARTER_PCT                         float64
# 270LEA_ELS_CHARTER_PCT                         float64
# 270LEA_HI7_CHARTER_PCT                         float64
# 270LEA_MU7_CHARTER_PCT                         float64
# 270LEA_PI7_CHARTER_PCT                         float64
# 270LEA_SWD_CHARTER_PCT                         float64
# 270LEA_WH7_CHARTER_PCT                         float64
# 320LEA_AM7_CHARTER_PCT                         float64
# 320LEA_AS7_CHARTER_PCT                         float64
# 320LEA_BL7_CHARTER_PCT                         float64
# 320LEA_EDS_CHARTER_PCT                         float64
# 320LEA_ELS_CHARTER_PCT                         float64
# 320LEA_HI7_CHARTER_PCT                         float64
# 320LEA_MU7_CHARTER_PCT                         float64
# 320LEA_PI7_CHARTER_PCT                         float64
# 320LEA_SWD_CHARTER_PCT                         float64
# 320LEA_WH7_CHARTER_PCT                         float64
# 330LEA_AM7_CHARTER_PCT                         float64
# 330LEA_AS7_CHARTER_PCT                         float64
# 330LEA_BL7_CHARTER_PCT                         float64
# 330LEA_EDS_CHARTER_PCT                         float64
# 330LEA_ELS_CHARTER_PCT                         float64
# 330LEA_HI7_CHARTER_PCT                         float64
# 330LEA_MU7_CHARTER_PCT                         float64
# 330LEA_PI7_CHARTER_PCT                         float64
# 330LEA_SWD_CHARTER_PCT                         float64
# 330LEA_WH7_CHARTER_PCT                         float64
# 340LEA_AM7_CHARTER_PCT                         float64
# 340LEA_AS7_CHARTER_PCT                         float64
# 340LEA_BL7_CHARTER_PCT                         float64
# 340LEA_EDS_CHARTER_PCT                         float64
# 340LEA_ELS_CHARTER_PCT                         float64
# 340LEA_HI7_CHARTER_PCT                         float64
# 340LEA_MU7_CHARTER_PCT                         float64
# 340LEA_PI7_CHARTER_PCT                         float64
# 340LEA_SWD_CHARTER_PCT                         float64
# 340LEA_WH7_CHARTER_PCT                         float64
# 350LEA_AM7_CHARTER_PCT                         float64
# 350LEA_AS7_CHARTER_PCT                         float64
# 350LEA_BL7_CHARTER_PCT                         float64
# 350LEA_EDS_CHARTER_PCT                         float64
# 350LEA_ELS_CHARTER_PCT                         float64
# 350LEA_HI7_CHARTER_PCT                         float64
# 350LEA_MU7_CHARTER_PCT                         float64
# 350LEA_PI7_CHARTER_PCT                         float64
# 350LEA_SWD_CHARTER_PCT                         float64
# 350LEA_WH7_CHARTER_PCT                         float64
# 360LEA_AM7_CHARTER_PCT                         float64
# 360LEA_AS7_CHARTER_PCT                         float64
# 360LEA_BL7_CHARTER_PCT                         float64
# 360LEA_EDS_CHARTER_PCT                         float64
# 360LEA_ELS_CHARTER_PCT                         float64
# 360LEA_HI7_CHARTER_PCT                         float64
# 360LEA_MU7_CHARTER_PCT                         float64
# 360LEA_PI7_CHARTER_PCT                         float64
# 360LEA_SWD_CHARTER_PCT                         float64
# 360LEA_WH7_CHARTER_PCT                         float64
# 390LEA_AM7_CHARTER_PCT                         float64
# 390LEA_AS7_CHARTER_PCT                         float64
# 390LEA_BL7_CHARTER_PCT                         float64
# 390LEA_EDS_CHARTER_PCT                         float64
# 390LEA_ELS_CHARTER_PCT                         float64
# 390LEA_HI7_CHARTER_PCT                         float64
# 390LEA_MU7_CHARTER_PCT                         float64
# 390LEA_PI7_CHARTER_PCT                         float64
# 390LEA_SWD_CHARTER_PCT                         float64
# 390LEA_WH7_CHARTER_PCT                         float64
# 410LEA_AM7_CHARTER_PCT                         float64
# 410LEA_AS7_CHARTER_PCT                         float64
# 410LEA_BL7_CHARTER_PCT                         float64
# 410LEA_EDS_CHARTER_PCT                         float64
# 410LEA_ELS_CHARTER_PCT                         float64
# 410LEA_HI7_CHARTER_PCT                         float64
# 410LEA_MU7_CHARTER_PCT                         float64
# 410LEA_PI7_CHARTER_PCT                         float64
# 410LEA_SWD_CHARTER_PCT                         float64
# 410LEA_WH7_CHARTER_PCT                         float64
# 420LEA_AM7_CHARTER_PCT                         float64
# 420LEA_AS7_CHARTER_PCT                         float64
# 420LEA_BL7_CHARTER_PCT                         float64
# 420LEA_EDS_CHARTER_PCT                         float64
# 420LEA_ELS_CHARTER_PCT                         float64
# 420LEA_HI7_CHARTER_PCT                         float64
# 420LEA_MU7_CHARTER_PCT                         float64
# 420LEA_PI7_CHARTER_PCT                         float64
# 420LEA_SWD_CHARTER_PCT                         float64
# 420LEA_WH7_CHARTER_PCT                         float64
# 430LEA_AM7_CHARTER_PCT                         float64
# 430LEA_AS7_CHARTER_PCT                         float64
# 430LEA_BL7_CHARTER_PCT                         float64
# 430LEA_EDS_CHARTER_PCT                         float64
# 430LEA_ELS_CHARTER_PCT                         float64
# 430LEA_HI7_CHARTER_PCT                         float64
# 430LEA_MU7_CHARTER_PCT                         float64
# 430LEA_PI7_CHARTER_PCT                         float64
# 430LEA_SWD_CHARTER_PCT                         float64
# 430LEA_WH7_CHARTER_PCT                         float64
# 440LEA_AM7_CHARTER_PCT                         float64
# 440LEA_AS7_CHARTER_PCT                         float64
# 440LEA_BL7_CHARTER_PCT                         float64
# 440LEA_EDS_CHARTER_PCT                         float64
# 440LEA_ELS_CHARTER_PCT                         float64
# 440LEA_HI7_CHARTER_PCT                         float64
# 440LEA_MU7_CHARTER_PCT                         float64
# 440LEA_PI7_CHARTER_PCT                         float64
# 440LEA_SWD_CHARTER_PCT                         float64
# 440LEA_WH7_CHARTER_PCT                         float64
# 450LEA_AM7_CHARTER_PCT                         float64
# 450LEA_AS7_CHARTER_PCT                         float64
# 450LEA_BL7_CHARTER_PCT                         float64
# 450LEA_EDS_CHARTER_PCT                         float64
# 450LEA_ELS_CHARTER_PCT                         float64
# 450LEA_HI7_CHARTER_PCT                         float64
# 450LEA_MU7_CHARTER_PCT                         float64
# 450LEA_PI7_CHARTER_PCT                         float64
# 450LEA_SWD_CHARTER_PCT                         float64
# 450LEA_WH7_CHARTER_PCT                         float64
# 490LEA_AM7_CHARTER_PCT                         float64
# 490LEA_AS7_CHARTER_PCT                         float64
# 490LEA_BL7_CHARTER_PCT                         float64
# 490LEA_EDS_CHARTER_PCT                         float64
# 490LEA_ELS_CHARTER_PCT                         float64
# 490LEA_HI7_CHARTER_PCT                         float64
# 490LEA_MU7_CHARTER_PCT                         float64
# 490LEA_PI7_CHARTER_PCT                         float64
# 490LEA_SWD_CHARTER_PCT                         float64
# 490LEA_WH7_CHARTER_PCT                         float64
# 500LEA_AM7_CHARTER_PCT                         float64
# 500LEA_AS7_CHARTER_PCT                         float64
# 500LEA_BL7_CHARTER_PCT                         float64
# 500LEA_EDS_CHARTER_PCT                         float64
# 500LEA_ELS_CHARTER_PCT                         float64
# 500LEA_HI7_CHARTER_PCT                         float64
# 500LEA_MU7_CHARTER_PCT                         float64
# 500LEA_PI7_CHARTER_PCT                         float64
# 500LEA_SWD_CHARTER_PCT                         float64
# 500LEA_WH7_CHARTER_PCT                         float64
# 510LEA_AM7_CHARTER_PCT                         float64
# 510LEA_AS7_CHARTER_PCT                         float64
# 510LEA_BL7_CHARTER_PCT                         float64
# 510LEA_EDS_CHARTER_PCT                         float64
# 510LEA_ELS_CHARTER_PCT                         float64
# 510LEA_HI7_CHARTER_PCT                         float64
# 510LEA_MU7_CHARTER_PCT                         float64
# 510LEA_PI7_CHARTER_PCT                         float64
# 510LEA_SWD_CHARTER_PCT                         float64
# 510LEA_WH7_CHARTER_PCT                         float64
# 540LEA_AM7_CHARTER_PCT                         float64
# 540LEA_AS7_CHARTER_PCT                         float64
# 540LEA_BL7_CHARTER_PCT                         float64
# 540LEA_EDS_CHARTER_PCT                         float64
# 540LEA_ELS_CHARTER_PCT                         float64
# 540LEA_HI7_CHARTER_PCT                         float64
# 540LEA_MU7_CHARTER_PCT                         float64
# 540LEA_PI7_CHARTER_PCT                         float64
# 540LEA_SWD_CHARTER_PCT                         float64
# 540LEA_WH7_CHARTER_PCT                         float64
# ...
# iss_per1000_FEM                                float64
# iss_per1000_HI7                                float64
# iss_per1000_MALE                               float64
# iss_per1000_MU7                                float64
# iss_per1000_PI7                                float64
# iss_per1000_SWD                                float64
# iss_per1000_WH7                                float64
# lts_per1000_ALL                                float64
# lts_per1000_AM7                                float64
# lts_per1000_AS7                                float64
# lts_per1000_BL7                                float64
# lts_per1000_EDS                                float64
# lts_per1000_ELS                                float64
# lts_per1000_FEM                                float64
# lts_per1000_HI7                                float64
# lts_per1000_MALE                               float64
# lts_per1000_MU7                                float64
# lts_per1000_PI7                                float64
# lts_per1000_SWD                                float64
# lts_per1000_WH7                                float64
# rplw_per1000_ALL                               float64
# rplw_per1000_AM7                               float64
# rplw_per1000_AS7                               float64
# rplw_per1000_BL7                               float64
# rplw_per1000_EDS                               float64
# rplw_per1000_ELS                               float64
# rplw_per1000_FEM                               float64
# rplw_per1000_HI7                               float64
# rplw_per1000_MALE                              float64
# rplw_per1000_MU7                               float64
# rplw_per1000_PI7                               float64
# rplw_per1000_SWD                               float64
# rplw_per1000_WH7                               float64
# sts_per1000_ALL                                float64
# sts_per1000_AM7                                float64
# sts_per1000_AS7                                float64
# sts_per1000_BL7                                float64
# sts_per1000_EDS                                float64
# sts_per1000_ELS                                float64
# sts_per1000_FEM                                float64
# sts_per1000_HI7                                float64
# sts_per1000_MALE                               float64
# sts_per1000_MU7                                float64
# sts_per1000_PI7                                float64
# sts_per1000_SWD                                float64
# sts_per1000_WH7                                float64
# pct_fully_licensed                             float64
# pct_lateral_entry                              float64
# 4_M_AIAN_At_Advanced_NAEP                      float64
# 4_M_AIAN_At_Basic_NAEP                         float64
# 4_M_AIAN_At_proficient_NAEP                    float64
# 4_M_AIAN_Below_Basic_NAEP                      float64
# 4_M_ALL_At_Advanced_NAEP                       float64
# 4_M_ALL_At_Basic_NAEP                          float64
# 4_M_ALL_At_proficient_NAEP                     float64
# 4_M_ALL_Below_Basic_NAEP                       float64
# 4_M_ASPI_At_Advanced_NAEP                      float64
# 4_M_ASPI_At_Basic_NAEP                         float64
# 4_M_ASPI_At_proficient_NAEP                    float64
# 4_M_ASPI_Below_Basic_NAEP                      float64
# 4_M_BL7_At_Advanced_NAEP                       float64
# 4_M_BL7_At_Basic_NAEP                          float64
# 4_M_BL7_At_proficient_NAEP                     float64
# 4_M_BL7_Below_Basic_NAEP                       float64
# 4_M_EDS_At_Advanced_NAEP                       float64
# 4_M_EDS_At_Basic_NAEP                          float64
# 4_M_EDS_At_proficient_NAEP                     float64
# 4_M_EDS_Below_Basic_NAEP                       float64
# 4_M_ELS_At_Advanced_NAEP                       float64
# 4_M_ELS_At_Basic_NAEP                          float64
# 4_M_ELS_At_proficient_NAEP                     float64
# 4_M_ELS_Below_Basic_NAEP                       float64
# 4_M_FEM_At_Advanced_NAEP                       float64
# 4_M_FEM_At_Basic_NAEP                          float64
# 4_M_FEM_At_proficient_NAEP                     float64
# 4_M_FEM_Below_Basic_NAEP                       float64
# 4_M_HI7_At_Advanced_NAEP                       float64
# 4_M_HI7_At_Basic_NAEP                          float64
# 4_M_HI7_At_proficient_NAEP                     float64
# 4_M_HI7_Below_Basic_NAEP                       float64
# 4_M_MALE_At_Advanced_NAEP                      float64
# 4_M_MALE_At_Basic_NAEP                         float64
# 4_M_MALE_At_proficient_NAEP                    float64
# 4_M_MALE_Below_Basic_NAEP                      float64
# 4_M_MU7_At_Advanced_NAEP                       float64
# 4_M_MU7_At_Basic_NAEP                          float64
# 4_M_MU7_At_proficient_NAEP                     float64
# 4_M_MU7_Below_Basic_NAEP                       float64
# 4_M_NOT_EDS_At_Advanced_NAEP                   float64
# 4_M_NOT_EDS_At_Basic_NAEP                      float64
# 4_M_NOT_EDS_At_proficient_NAEP                 float64
# 4_M_NOT_EDS_Below_Basic_NAEP                   float64
# 4_M_SWD_At_Advanced_NAEP                       float64
# 4_M_SWD_At_Basic_NAEP                          float64
# 4_M_SWD_At_proficient_NAEP                     float64
# 4_M_SWD_Below_Basic_NAEP                       float64
# 4_M_WH7_At_Advanced_NAEP                       float64
# 4_M_WH7_At_Basic_NAEP                          float64
# 4_M_WH7_At_proficient_NAEP                     float64
# 4_M_WH7_Below_Basic_NAEP                       float64
# 4_RD_AIAN_At_Advanced_NAEP                     float64
# 4_RD_AIAN_At_Basic_NAEP                        float64
# 4_RD_AIAN_At_proficient_NAEP                   float64
# 4_RD_AIAN_Below_Basic_NAEP                     float64
# 4_RD_ALL_At_Advanced_NAEP                      float64
# 4_RD_ALL_At_Basic_NAEP                         float64
# 4_RD_ALL_At_proficient_NAEP                    float64
# 4_RD_ALL_Below_Basic_NAEP                      float64
# 4_RD_ASPI_At_Advanced_NAEP                     float64
# 4_RD_ASPI_At_Basic_NAEP                        float64
# 4_RD_ASPI_At_proficient_NAEP                   float64
# 4_RD_ASPI_Below_Basic_NAEP                     float64
# 4_RD_BL7_At_Advanced_NAEP                      float64
# 4_RD_BL7_At_Basic_NAEP                         float64
# 4_RD_BL7_At_proficient_NAEP                    float64
# 4_RD_BL7_Below_Basic_NAEP                      float64
# 4_RD_EDS_At_Advanced_NAEP                      float64
# 4_RD_EDS_At_Basic_NAEP                         float64
# 4_RD_EDS_At_proficient_NAEP                    float64
# 4_RD_EDS_Below_Basic_NAEP                      float64
# 4_RD_ELS_At_Advanced_NAEP                      float64
# 4_RD_ELS_At_Basic_NAEP                         float64
# 4_RD_ELS_At_proficient_NAEP                    float64
# 4_RD_ELS_Below_Basic_NAEP                      float64
# 4_RD_FEM_At_Advanced_NAEP                      float64
# 4_RD_FEM_At_Basic_NAEP                         float64
# 4_RD_FEM_At_proficient_NAEP                    float64
# 4_RD_FEM_Below_Basic_NAEP                      float64
# 4_RD_HI7_At_Advanced_NAEP                      float64
# 4_RD_HI7_At_Basic_NAEP                         float64
# 4_RD_HI7_At_proficient_NAEP                    float64
# 4_RD_HI7_Below_Basic_NAEP                      float64
# 4_RD_MALE_At_Advanced_NAEP                     float64
# 4_RD_MALE_At_Basic_NAEP                        float64
# 4_RD_MALE_At_proficient_NAEP                   float64
# 4_RD_MALE_Below_Basic_NAEP                     float64
# 4_RD_MU7_At_Advanced_NAEP                      float64
# 4_RD_MU7_At_Basic_NAEP                         float64
# 4_RD_MU7_At_proficient_NAEP                    float64
# 4_RD_MU7_Below_Basic_NAEP                      float64
# 4_RD_NOT_EDS_At_Advanced_NAEP                  float64
# 4_RD_NOT_EDS_At_Basic_NAEP                     float64
# 4_RD_NOT_EDS_At_proficient_NAEP                float64
# 4_RD_NOT_EDS_Below_Basic_NAEP                  float64
# 4_RD_SWD_At_Advanced_NAEP                      float64
# 4_RD_SWD_At_Basic_NAEP                         float64
# 4_RD_SWD_At_proficient_NAEP                    float64
# 4_RD_SWD_Below_Basic_NAEP                      float64
# 4_RD_WH7_At_Advanced_NAEP                      float64
# 4_RD_WH7_At_Basic_NAEP                         float64
# 4_RD_WH7_At_proficient_NAEP                    float64
# 4_RD_WH7_Below_Basic_NAEP                      float64
# 8_M_AIAN_At_Advanced_NAEP                      float64
# 8_M_AIAN_At_Basic_NAEP                         float64
# 8_M_AIAN_At_proficient_NAEP                    float64
# 8_M_AIAN_Below_Basic_NAEP                      float64
# 8_M_ALL_At_Advanced_NAEP                       float64
# 8_M_ALL_At_Basic_NAEP                          float64
# 8_M_ALL_At_proficient_NAEP                     float64
# 8_M_ALL_Below_Basic_NAEP                       float64
# 8_M_ASPI_At_Advanced_NAEP                      float64
# 8_M_ASPI_At_Basic_NAEP                         float64
# 8_M_ASPI_At_proficient_NAEP                    float64
# 8_M_ASPI_Below_Basic_NAEP                      float64
# 8_M_BL7_At_Advanced_NAEP                       float64
# 8_M_BL7_At_Basic_NAEP                          float64
# 8_M_BL7_At_proficient_NAEP                     float64
# 8_M_BL7_Below_Basic_NAEP                       float64
# 8_M_EDS_At_Advanced_NAEP                       float64
# 8_M_EDS_At_Basic_NAEP                          float64
# 8_M_EDS_At_proficient_NAEP                     float64
# 8_M_EDS_Below_Basic_NAEP                       float64
# 8_M_ELS_At_Advanced_NAEP                       float64
# 8_M_ELS_At_Basic_NAEP                          float64
# 8_M_ELS_At_proficient_NAEP                     float64
# 8_M_ELS_Below_Basic_NAEP                       float64
# 8_M_FEM_At_Advanced_NAEP                       float64
# 8_M_FEM_At_Basic_NAEP                          float64
# 8_M_FEM_At_proficient_NAEP                     float64
# 8_M_FEM_Below_Basic_NAEP                       float64
# 8_M_HI7_At_Advanced_NAEP                       float64
# 8_M_HI7_At_Basic_NAEP                          float64
# 8_M_HI7_At_proficient_NAEP                     float64
# 8_M_HI7_Below_Basic_NAEP                       float64
# 8_M_MALE_At_Advanced_NAEP                      float64
# 8_M_MALE_At_Basic_NAEP                         float64
# 8_M_MALE_At_proficient_NAEP                    float64
# 8_M_MALE_Below_Basic_NAEP                      float64
# 8_M_MU7_At_Advanced_NAEP                       float64
# 8_M_MU7_At_Basic_NAEP                          float64
# 8_M_MU7_At_proficient_NAEP                     float64
# 8_M_MU7_Below_Basic_NAEP                       float64
# 8_M_NOT_EDS_At_Advanced_NAEP                   float64
# 8_M_NOT_EDS_At_Basic_NAEP                      float64
# 8_M_NOT_EDS_At_proficient_NAEP                 float64
# 8_M_NOT_EDS_Below_Basic_NAEP                   float64
# 8_M_SWD_At_Advanced_NAEP                       float64
# 8_M_SWD_At_Basic_NAEP                          float64
# 8_M_SWD_At_proficient_NAEP                     float64
# 8_M_SWD_Below_Basic_NAEP                       float64
# 8_M_WH7_At_Advanced_NAEP                       float64
# 8_M_WH7_At_Basic_NAEP                          float64
# 8_M_WH7_At_proficient_NAEP                     float64
# 8_M_WH7_Below_Basic_NAEP                       float64
# 8_RD_AIAN_At_Advanced_NAEP                     float64
# 8_RD_AIAN_At_Basic_NAEP                        float64
# 8_RD_AIAN_At_proficient_NAEP                   float64
# 8_RD_AIAN_Below_Basic_NAEP                     float64
# 8_RD_ALL_At_Advanced_NAEP                      float64
# 8_RD_ALL_At_Basic_NAEP                         float64
# 8_RD_ALL_At_proficient_NAEP                    float64
# 8_RD_ALL_Below_Basic_NAEP                      float64
# 8_RD_ASPI_At_Advanced_NAEP                     float64
# 8_RD_ASPI_At_Basic_NAEP                        float64
# 8_RD_ASPI_At_proficient_NAEP                   float64
# 8_RD_ASPI_Below_Basic_NAEP                     float64
# 8_RD_BL7_At_Advanced_NAEP                      float64
# 8_RD_BL7_At_Basic_NAEP                         float64
# 8_RD_BL7_At_proficient_NAEP                    float64
# 8_RD_BL7_Below_Basic_NAEP                      float64
# 8_RD_EDS_At_Advanced_NAEP                      float64
# 8_RD_EDS_At_Basic_NAEP                         float64
# 8_RD_EDS_At_proficient_NAEP                    float64
# 8_RD_EDS_Below_Basic_NAEP                      float64
# 8_RD_ELS_At_Basic_NAEP                         float64
# 8_RD_ELS_At_proficient_NAEP                    float64
# 8_RD_ELS_Below_Basic_NAEP                      float64
# 8_RD_FEM_At_Advanced_NAEP                      float64
# 8_RD_FEM_At_Basic_NAEP                         float64
# 8_RD_FEM_At_proficient_NAEP                    float64
# 8_RD_FEM_Below_Basic_NAEP                      float64
# 8_RD_HI7_At_Advanced_NAEP                      float64
# 8_RD_HI7_At_Basic_NAEP                         float64
# 8_RD_HI7_At_proficient_NAEP                    float64
# 8_RD_HI7_Below_Basic_NAEP                      float64
# 8_RD_MALE_At_Advanced_NAEP                     float64
# 8_RD_MALE_At_Basic_NAEP                        float64
# 8_RD_MALE_At_proficient_NAEP                   float64
# 8_RD_MALE_Below_Basic_NAEP                     float64
# 8_RD_MU7_At_Advanced_NAEP                      float64
# 8_RD_MU7_At_Basic_NAEP                         float64
# 8_RD_MU7_At_proficient_NAEP                    float64
# 8_RD_MU7_Below_Basic_NAEP                      float64
# 8_RD_NOT_EDS_At_Advanced_NAEP                  float64
# 8_RD_NOT_EDS_At_Basic_NAEP                     float64
# 8_RD_NOT_EDS_At_proficient_NAEP                float64
# 8_RD_NOT_EDS_Below_Basic_NAEP                  float64
# 8_RD_SWD_At_Advanced_NAEP                      float64
# 8_RD_SWD_At_Basic_NAEP                         float64
# 8_RD_SWD_At_proficient_NAEP                    float64
# 8_RD_SWD_Below_Basic_NAEP                      float64
# 8_RD_WH7_At_Advanced_NAEP                      float64
# 8_RD_WH7_At_Basic_NAEP                         float64
# 8_RD_WH7_At_proficient_NAEP                    float64
# 8_RD_WH7_Below_Basic_NAEP                      float64
# nbpts_num                                      float64
# ALL_PK_ENROLL_PCT                              float64
# AM7_PK_ENROLL_PCT                              float64
# AS7_PK_ENROLL_PCT                              float64
# BL7_PK_ENROLL_PCT                              float64
# ELS_PK_ENROLL_PCT                              float64
# FEM_PK_ENROLL_PCT                              float64
# HI7_PK_ENROLL_PCT                              float64
# MALE_PK_ENROLL_PCT                             float64
# MU7_PK_ENROLL_PCT                              float64
# PI7_PK_ENROLL_PCT                              float64
# SWD_PK_ENROLL_PCT                              float64
# WH7_PK_ENROLL_PCT                              float64
# BL7_PCT_PRIN_DEMO                              float64
# FEM_PCT_PRIN_DEMO                              float64
# MALE_PCT_PRIN_DEMO                             float64
# OTHER_PCT_PRIN_DEMO                            float64
# WH7_PCT_PRIN_DEMO                              float64
# pct_ready_kea                                  float64
# 00_SAR_AVG_SIZE                                float64
# 01_SAR_AVG_SIZE                                float64
# 02_SAR_AVG_SIZE                                float64
# 03_SAR_AVG_SIZE                                float64
# 04_SAR_AVG_SIZE                                float64
# 05_SAR_AVG_SIZE                                float64
# 06_SAR_AVG_SIZE                                float64
# 07_SAR_AVG_SIZE                                float64
# 08_SAR_AVG_SIZE                                float64
# Biology_SAR_AVG_SIZE                           float64
# English II_SAR_AVG_SIZE                        float64
# Math I_SAR_AVG_SIZE                            float64
# avg_sat_score                                  float64
# pct_sat_participation                          float64
# welcome_url                                    object
# dtypes: float64(1752), object(49)
# memory usage: 36.3+ MB
