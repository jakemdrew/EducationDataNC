# %% [markdown]
# # Create 2017-2018 School Datasets
# ### This program uses all flattened raw datasets to create the school dataset files within the NCEA repository.
#
# 1. This notebook reads raw dataset .csv files directly from the \EducationDataNC\2017\Raw Datasets folder.
# 2. Each raw dataset is transformed to contain only one record per public school campus or unique agency_code.
# 3. Many raw datasets have more than one record per campus, per year. In these instances, table pivots are used to create new columns from row level entries and reduce each dataset to one record per school. This adds many new colums the flattened dataset. (see the code below for more details)
# 4. School datasets merge all flattened files into one dataset with one record per agency_code.

# %%
#import required Libraries
import pandas as pd
import numpy as np
import os
import string

#**********************************************************************************
# Set the following variables before running this code!!!
#**********************************************************************************

#'C:/Users/Jake/Documents/GitHub/EducationDataNC/2018/
dirPath = 'D:/BenepactLLC/Belk/NC_Report_Card_Data/2020/June 2020/2018/'

#Location where copies of the raw data files will be read in from csv files.
# 'C:/Users/Jake/Documents/GitHub/EducationDataNC/2018/Raw Datasets/'
dataDir = dirPath + 'Raw Datasets/Flattened Datasets/'

#Location where the new school datasets will be created.
# 'C:/Users/Jake/Documents/GitHub/EducationDataNC/2018/School Datasets/'
outputDir = dirPath + 'School Datasets/'

#All raw data files are processed for the year below
schoolYear = 2018

# %% [markdown]
# # Read in the Raw Data Files
# ### This section reads raw data files directly from the \\Raw Datasets folder.
#
# * The file input location is specified at the dataDir parameter.
# * The file output location is specified at the outputDir parameter.
# * The schoolYear parameter is used to specify the correct school year to process.

# %% [markdown]
# # A List of All Files Processed

# %%
#Use wildcards to find files in a directory
import glob
#Use ntpath.basename to get a filename from a filepath
import ntpath

#Get and display a list of all .csv file names for 2018 download
rcdFiles = glob.glob(dataDir + '*.csv')

rcdFileNames = [ntpath.basename(x)[:-4] for x in rcdFiles]

print('A List of File Names and Record Counts for Processing:\n')

#Create dataframes for each file
for fileName in rcdFileNames:
    #create one ataframe for each .csv file in rcdFileNames  
    exec(fileName + ' = pd.read_csv("' + dataDir + '" + "' + fileName + '" + ".csv", low_memory=False, dtype={"agency_code": object})')  
    print(fileName + ', ' + str(len(eval(fileName).index)) )
# Out:
# A List of File Names and Record Counts for Processing:
#
# ec_pupils_pct, 2494
# ratio, 2609
# rcd_acc_aapart, 53
# rcd_acc_act, 742
# rcd_acc_awa, 688
# rcd_acc_cgr, 738
# rcd_acc_eds, 2761
# rcd_acc_elp, 1809
# rcd_acc_essa_desig, 2645
# rcd_acc_gp, 658
# rcd_acc_irm, 1276
# rcd_acc_lowperf, 2760
# rcd_acc_ltg, 2461
# rcd_acc_ltg_detail, 2631
# rcd_acc_mcr, 717
# rcd_acc_part, 2527
# rcd_acc_part_detail, 2527
# rcd_acc_pc, 2697
# rcd_acc_rta, 1576
# rcd_acc_spg2, 2538
# rcd_acc_wk, 517
# rcd_adm, 3197
# rcd_ap, 563
# rcd_arts, 2509
# rcd_att, 3115
# rcd_charter, 241
# rcd_chronic_absent, 2719
# rcd_college, 690
# rcd_courses2, 652
# rcd_cte_concentrators, 492
# rcd_cte_credentials, 436
# rcd_cte_endorsement, 537
# rcd_cte_enrollment, 1184
# rcd_dlmi, 2723
# rcd_effectiveness, 2777
# rcd_experience, 2758
# rcd_funds, 292
# rcd_ib, 51
# rcd_improvement, 19
# rcd_inc2, 2792
# rcd_licenses, 3121
# rcd_location, 2759
# rcd_nbpts, 3124
# rcd_pk_enroll, 988
# rcd_readiness, 1323
# rcd_sar, 2630
# rcd_sat, 613
# rcd_welcome, 1311

# %% [markdown]
# # Merge all datasets to one master dataset with one record per school
# * **Starting with the location table we left outer join on agency_code, merging data from each reshaped table into one master record.**
# * **The report below ensures that merges by location result in one unique record per public school campus.**
# * **This report also shows changes to the final dataset's column and row counts as each flattened raw dataset is merged into the final Public School Datasets.**

# %%
#Make a copy of a variable (by value) using copy() or deepcopy()
import copy 

#Remove state and district level location records before performing campus level merges
rcd_location = rcd_location[(rcd_location['agency_code'] != 'NC-SEA') & 
                            (rcd_location['agency_code'].str.contains("LEA") == False)]

#Do not merge file: rcd_acc_pc
mergeFileNames = copy.deepcopy(rcdFileNames)
mergeFileNames.remove('rcd_location')
#mergeFileNames.remove('rcd_acc_pc')

#Funds are only provided at the district level and require special handling
mergeFileNames.remove('rcd_funds')


print('*********************************Start: RCD Location Data*********************************')
rcd_location.info(verbose=False)

for fileName in mergeFileNames:
    rcd_location = rcd_location.merge(eval(fileName),how='left',on='agency_code', suffixes=('', '_Drop'))
    print('*********************************After: ' + fileName + '**************************')
    rcd_location.info(verbose=False)
    

#Rename final merged rcd file! 
PublicSchools = rcd_location

#Delete all of the duplicate / overlapping columns 
#i.e. When two tables have columns with identical names, the column from the table inside the merge() is deleted.
dropCols = [x for x in PublicSchools.columns if x.endswith('_Drop')]
PublicSchools = PublicSchools.drop(dropCols, axis=1)

#Delete any masking columns that were missed. 
dropCols = [x for x in PublicSchools.columns if x.endswith('_masking')]
PublicSchools = PublicSchools.drop(dropCols, axis=1)

print('*********************************After: Deleting Duplicated Columns*********')
PublicSchools.info(verbose=False)
# Out:
# *********************************Start: RCD Location Data*********************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2757
# Columns: 21 entries, agency_code to stem
# dtypes: float64(3), object(18)
# memory usage: 454.3+ KB
# *********************************After: ec_pupils_pct**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 49 entries, agency_code to two_or_more_female_pct
# dtypes: float64(29), object(20)
# memory usage: 1.0+ MB
# *********************************After: ratio**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 65 entries, agency_code to ada_adm_rank_2017_thru_2019_attendance
# dtypes: float64(36), object(29)
# memory usage: 1.3+ MB
# *********************************After: rcd_acc_aapart**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 85 entries, agency_code to pct_SC_HS_AAPART
# dtypes: float64(56), object(29)
# memory usage: 1.7+ MB
# *********************************After: rcd_acc_act**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 197 entries, agency_code to pct_ACWR_WH7_ACT
# dtypes: float64(168), object(29)
# memory usage: 4.0+ MB
# *********************************After: rcd_acc_awa**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 213 entries, agency_code to pct_WH7_AWA
# dtypes: float64(184), object(29)
# memory usage: 4.3+ MB
# *********************************After: rcd_acc_cgr**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 243 entries, agency_code to pct_STD_WH7_CGR
# dtypes: float64(214), object(29)
# memory usage: 4.9+ MB
# *********************************After: rcd_acc_eds**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 244 entries, agency_code to pct_eds
# dtypes: float64(215), object(29)
# memory usage: 4.9+ MB
# *********************************After: rcd_acc_elp**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 260 entries, agency_code to pct_WH7_ELP
# dtypes: float64(231), object(29)
# memory usage: 5.3+ MB
# *********************************After: rcd_acc_essa_desig**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 264 entries, agency_code to tsi_at
# dtypes: float64(231), object(33)
# memory usage: 5.3+ MB
# *********************************After: rcd_acc_gp**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 265 entries, agency_code to grad_project
# dtypes: float64(231), object(34)
# memory usage: 5.4+ MB
# *********************************After: rcd_acc_irm**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 267 entries, agency_code to pct_prof_9gr_irm
# dtypes: float64(233), object(34)
# memory usage: 5.4+ MB
# *********************************After: rcd_acc_lowperf**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 270 entries, agency_code to clpc_school
# dtypes: float64(233), object(37)
# memory usage: 5.5+ MB
# *********************************After: rcd_acc_ltg**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 277 entries, agency_code to pct_met_Total Targets_LTG
# dtypes: float64(240), object(37)
# memory usage: 5.6+ MB
# *********************************After: rcd_acc_ltg_detail**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 279 entries, agency_code to subgroup_list
# dtypes: float64(240), object(39)
# memory usage: 5.6+ MB
# *********************************After: rcd_acc_mcr**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 295 entries, agency_code to pct_WH7_MCR
# dtypes: float64(256), object(39)
# memory usage: 6.0+ MB
# *********************************After: rcd_acc_part**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 304 entries, agency_code to pct_met_Total Targets_PART
# dtypes: float64(265), object(39)
# memory usage: 6.2+ MB
# *********************************After: rcd_acc_part_detail**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 384 entries, agency_code to pct_The ACT_WH7_PART_DET
# dtypes: float64(345), object(39)
# memory usage: 7.8+ MB
# *********************************After: rcd_acc_pc**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 3799 entries, agency_code to pct_L5_SC_ALL_WH7_PC
# dtypes: float64(3760), object(39)
# memory usage: 76.6+ MB
# *********************************After: rcd_acc_rta**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 3808 entries, agency_code to pct_retained_RTA
# dtypes: float64(3769), object(39)
# memory usage: 76.8+ MB
# *********************************After: rcd_acc_spg2**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 3905 entries, agency_code to spg_score_WH7_SPG2
# dtypes: float64(3866), object(39)
# memory usage: 78.8+ MB
# *********************************After: rcd_acc_wk**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 3921 entries, agency_code to pct_WH7_WK
# dtypes: float64(3882), object(39)
# memory usage: 79.1+ MB
# *********************************After: rcd_adm**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 3922 entries, agency_code to avg_student_num
# dtypes: float64(3883), object(39)
# memory usage: 79.1+ MB
# *********************************After: rcd_ap**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 3924 entries, agency_code to pct_ap_participation
# dtypes: float64(3885), object(39)
# memory usage: 79.1+ MB
# *********************************After: rcd_arts**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 3928 entries, agency_code to va_cat
# dtypes: float64(3885), object(43)
# memory usage: 79.2+ MB
# *********************************After: rcd_att**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 3929 entries, agency_code to pct_att
# dtypes: float64(3886), object(43)
# memory usage: 79.2+ MB
# *********************************After: rcd_charter**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 3939 entries, agency_code to pct_enrolled_WH7_CHARTER
# dtypes: float64(3896), object(43)
# memory usage: 79.4+ MB
# *********************************After: rcd_chronic_absent**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 3951 entries, agency_code to pct_WH7_CHRON_ABSENT
# dtypes: float64(3908), object(43)
# memory usage: 79.7+ MB
# *********************************After: rcd_college**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 3963 entries, agency_code to pct_enrolled_ENROLL_WH7_COLLEGE
# dtypes: float64(3920), object(43)
# memory usage: 79.9+ MB
# *********************************After: rcd_courses2**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 4190 entries, agency_code to year_T_WH7_COURSES2
# dtypes: float64(4147), object(43)
# memory usage: 84.5+ MB
# *********************************After: rcd_cte_concentrators**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 4205 entries, agency_code to num_concentrators_TRAN
# dtypes: float64(4162), object(43)
# memory usage: 84.8+ MB
# *********************************After: rcd_cte_credentials**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 4208 entries, agency_code to cred_earned_pct
# dtypes: float64(4165), object(43)
# memory usage: 84.9+ MB
# *********************************After: rcd_cte_endorsement**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 4212 entries, agency_code to college_only
# dtypes: float64(4169), object(43)
# memory usage: 85.0+ MB
# *********************************After: rcd_cte_enrollment**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 4215 entries, agency_code to cte_enrollment_pct
# dtypes: float64(4172), object(43)
# memory usage: 85.0+ MB
# *********************************After: rcd_dlmi**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 4228 entries, agency_code to category_code_Drop
# dtypes: float64(4177), object(51)
# memory usage: 85.3+ MB
# *********************************After: rcd_effectiveness**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 4294 entries, agency_code to pct_rating_TS_MeetsExpectedGrowth
# dtypes: float64(4243), object(51)
# memory usage: 86.6+ MB
# *********************************After: rcd_experience**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 4306 entries, agency_code to total_class_teach_TeacherExp
# dtypes: float64(4255), object(51)
# memory usage: 86.8+ MB
# *********************************After: rcd_ib**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 4308 entries, agency_code to pct_ib_participation
# dtypes: float64(4257), object(51)
# memory usage: 86.9+ MB
# *********************************After: rcd_improvement**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 4311 entries, agency_code to amount_ Whole School Reform_Improve_Amt
# dtypes: float64(4260), object(51)
# memory usage: 86.9+ MB
# *********************************After: rcd_inc2**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 4415 entries, agency_code to sts_per1000_WH7
# dtypes: float64(4364), object(51)
# memory usage: 89.0+ MB
# *********************************After: rcd_licenses**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 4417 entries, agency_code to pct_lateral_entry
# dtypes: float64(4366), object(51)
# memory usage: 89.1+ MB
# *********************************After: rcd_nbpts**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 4418 entries, agency_code to nbpts_num
# dtypes: float64(4367), object(51)
# memory usage: 89.1+ MB
# *********************************After: rcd_pk_enroll**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 4442 entries, agency_code to pct_WH7_PK_ENROLL
# dtypes: float64(4391), object(51)
# memory usage: 89.6+ MB
# *********************************After: rcd_readiness**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 4443 entries, agency_code to pct_ready_kea
# dtypes: float64(4392), object(51)
# memory usage: 89.6+ MB
# *********************************After: rcd_sar**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 4455 entries, agency_code to avg_size_Math I_SAR
# dtypes: float64(4404), object(51)
# memory usage: 89.9+ MB
# *********************************After: rcd_sat**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 4457 entries, agency_code to pct_sat_participation
# dtypes: float64(4406), object(51)
# memory usage: 89.9+ MB
# *********************************After: rcd_welcome**************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 4458 entries, agency_code to welcome_url
# dtypes: float64(4406), object(52)
# memory usage: 89.9+ MB
# *********************************After: Deleting Duplicated Columns*********
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 4457 entries, agency_code to welcome_url
# dtypes: float64(4406), object(51)
# memory usage: 89.9+ MB

# %% [markdown]
# ## Process District Level Funds Data
# * **Funds are only provided at the district level and require special handling**
# * **Funds are also reported for charter schools by agency code**
# * **Must join file by agency_code for charter schools and lea_code for all other schools**

# %%
#Give rcd_funds columns names to indicate they are district level values.
rcd_funds.rename(columns={'total_expense' : 'lea_total_expense' ,
                          'pct_salary' : 'lea_pct_salary' ,
                          'pct_benefits' : 'lea_pct_benefits' ,
                          'pct_services' : 'lea_pct_services' ,
                          'pct_supplies' : 'lea_pct_supplies' ,
                          'pct_instruct_equip' : 'lea_pct_instruct_equip' ,
                          'pct_building' : 'lea_pct_building' ,
                          'pct_other' : 'lea_pct_other' ,
                          'local_perpupil' : 'lea_local_perpupil' ,
                          'state_perpupil' : 'lea_state_perpupil' ,
                          'federal_perpupil' : 'lea_federal_perpupil'}, inplace=True)

# %%
rcd_funds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292 entries, 0 to 291
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   agency_code             292 non-null    object
#  1   category_code           174 non-null    object
#  2   lea_total_expense       290 non-null    float64
#  3   lea_pct_salary          290 non-null    float64
#  4   lea_pct_benefits        290 non-null    float64
#  5   lea_pct_services        290 non-null    float64
#  6   lea_pct_supplies        290 non-null    float64
#  7   lea_pct_instruct_equip  290 non-null    float64
#  8   lea_pct_building        290 non-null    float64
#  9   lea_pct_other           0 non-null      float64
#  10  lea_local_perpupil      290 non-null    float64
#  11  lea_state_perpupil      290 non-null    float64
#  12  lea_federal_perpupil    290 non-null    float64
# dtypes: float64(11), object(2)
# memory usage: 29.8+ KB

# %%
#Create a new lookup table and field "agency_lea_code" using agency code for charter schools and lea_code for everyone else 
lea_lookup = pd.DataFrame( rcd_location[['agency_code','lea_code']] )
lea_lookup['agency_lea_code'] = np.where(lea_lookup['lea_code']=='CH', lea_lookup['agency_code'], lea_lookup['lea_code'])
lea_lookup = lea_lookup[['agency_lea_code','lea_code']].drop_duplicates()

#Create a new field "agency_lea_code" on PublicSchools table
PublicSchools['agency_lea_code'] = np.where(PublicSchools['lea_code']=='CH', 
                                            PublicSchools['agency_code'], PublicSchools['lea_code'])

#Merge agency_lea_code to the funds table.
rcd_funds = rcd_funds.merge(lea_lookup, left_on='agency_code', 
                            right_on='agency_lea_code', suffixes=('', '_Drop'))

#Merge PublicSchools and rcd_funds
PublicSchools = PublicSchools.merge(rcd_funds, how='left',on='agency_lea_code', suffixes=('', '_Drop'))

#Delete all of the duplicate / overlapping columns 
#i.e. When two tables have columns with identical names, the column from the table inside the merge() is deleted.
dropCols = [x for x in PublicSchools.columns if x.endswith('_Drop')]
PublicSchools = PublicSchools.drop(dropCols, axis=1)

print('*********************************After: rcd_funds **************************')
PublicSchools.info(verbose=False)
# Out:
# *********************************After: rcd_funds **************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2643 entries, 0 to 2642
# Columns: 4469 entries, agency_code to lea_federal_perpupil
# dtypes: float64(4417), object(52)
# memory usage: 90.1+ MB

# %% [markdown]
# ## Save Final Versions of the School Datasets

# %%
# Remove any National or State Level Records
PublicSchools = PublicSchools[(PublicSchools.agency_code != 'NATION') & (PublicSchools.agency_code != 'NC-SEA')]

# %%
#Save the master file to disk
PublicSchools.to_csv(outputDir + 'PublicSchools' + str(schoolYear) + '.csv', sep=',', index=False)

print('*********************************All Public Schools****************************')
PublicSchools.info(verbose=False)

#Filter regular public high schools
HighSchools = PublicSchools[((PublicSchools.category_code == 'H') | 
                             (PublicSchools.category_code == 'T') | 
                             (PublicSchools.category_code == 'A')) 
                            ]

#Save the file to disk
HighSchools.to_csv(outputDir + 'PublicHighSchools' + str(schoolYear) + '.csv', sep=',', index=False)

print('*********************************Regular Public High Schools*******************')
HighSchools.info(verbose=False)

#Filter regular public middle schools
MiddleSchools = PublicSchools[((PublicSchools.category_code == 'M') | 
                               (PublicSchools.category_code == 'T') | 
                               (PublicSchools.category_code == 'A') |
                               (PublicSchools.category_code == 'I'))
                             ]

#Save the file to disk
MiddleSchools.to_csv(outputDir + 'PublicMiddleSchools' + str(schoolYear) + '.csv', sep=',', index=False)

print('*********************************Regular Public Middle Schools******************')
MiddleSchools.info(verbose=False)


#Filter regular elementary high schools
ElementarySchools = PublicSchools[((PublicSchools.category_code == 'E') | 
                                   (PublicSchools.category_code == 'I') | 
                                   (PublicSchools.category_code == 'A')) 
                                 ]

#Save the file to disk
ElementarySchools.to_csv(outputDir + 'PublicElementarySchools' + str(schoolYear) + '.csv', sep=',', index=False)

print('*********************************Regular Public Elementary Schools**************')
ElementarySchools.info(verbose=False)
# Out:
# *********************************All Public Schools****************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2642 entries, 0 to 2641
# Columns: 4469 entries, agency_code to lea_federal_perpupil
# dtypes: float64(4417), object(52)
# memory usage: 90.1+ MB
# *********************************Regular Public High Schools*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 679 entries, 0 to 2640
# Columns: 4469 entries, agency_code to lea_federal_perpupil
# dtypes: float64(4417), object(52)
# memory usage: 23.2+ MB
# *********************************Regular Public Middle Schools******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 806 entries, 0 to 2640
# Columns: 4469 entries, agency_code to lea_federal_perpupil
# dtypes: float64(4417), object(52)
# memory usage: 27.5+ MB
# *********************************Regular Public Elementary Schools**************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1575 entries, 0 to 2641
# Columns: 4469 entries, agency_code to lea_federal_perpupil
# dtypes: float64(4417), object(52)
# memory usage: 53.7+ MB

# %% [markdown]
# # Data Columns Available in the Public School Dataset

# %%
PublicSchools.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2642 entries, 0 to 2641
# Data columns (total 4469 columns):
#  #    Column                                   Dtype
# ---   ------                                   -----
#  0    agency_code                              object
#  1    category_code                            object
#  2    agency_level                             object
#  3    lea_code                                 object
#  4    designation_type                         object
#  5    name                                     object
#  6    county                                   object
#  7    street_addr                              object
#  8    stree_addr2                              float64
#  9    city                                     object
#  10   state                                    object
#  11   zip                                      float64
#  12   phone                                    object
#  13   grade_span                               object
#  14   school_type                              object
#  15   calendar_type                            object
#  16   url                                      object
#  17   super_name                               object
#  18   title_I                                  object
#  19   esea                                     float64
#  20   stem                                     object
#  21   lea                                      float64
#  22   lea_name                                 object
#  23   school                                   float64
#  24   school_name                              object
#  25   indian_pct                               float64
#  26   asian_pct                                float64
#  27   hispanic_pct                             float64
#  28   black_pct                                float64
#  29   white_pct                                float64
#  30   pacific_island_pct                       float64
#  31   two_or_more_pct                          float64
#  32   minority_pct                             float64
#  33   indian_male_pct                          float64
#  34   asian_male_pct                           float64
#  35   hispanic_male_pct                        float64
#  36   black_male_pct                           float64
#  37   white_male_pct                           float64
#  38   pacific_island_male_pct                  float64
#  39   two_or_more_male_pct                     float64
#  40   minority_male_pct                        float64
#  41   indian_female_pct                        float64
#  42   asian_female_pct                         float64
#  43   hispanic_female_pct                      float64
#  44   black_female_pct                         float64
#  45   white_female_pct                         float64
#  46   minority_female_pct                      float64
#  47   pacific_island_female_pct                float64
#  48   two_or_more_female_pct                   float64
#  49   lea_no_attendance                        float64
#  50   lea_name_attendance                      object
#  51   school_no_attendance                     float64
#  52   school_name_attendance                   object
#  53   grade_span_attendance                    object
#  54   ada_ct_2017_attendance                   object
#  55   adm_ct_2017_attendance                   object
#  56   ada_adm_ratio_2018_attendance            float64
#  57   ada_ct_2018_attendance                   object
#  58   adm_ct_2018_attendance                   object
#  59   ada_adm_ratio_2018.1_attendance          float64
#  60   ada_ct_2019_attendance                   object
#  61   adm_ct_2019_attendance                   object
#  62   ada_adm_ratio_2019_attendance            float64
#  63   ada_adm_ratio_2017_thru_2019_attendance  float64
#  64   ada_adm_rank_2017_thru_2019_attendance   float64
#  65   pct_MA_03_AAPART                         float64
#  66   pct_MA_04_AAPART                         float64
#  67   pct_MA_05_AAPART                         float64
#  68   pct_MA_06_AAPART                         float64
#  69   pct_MA_07_AAPART                         float64
#  70   pct_MA_08_AAPART                         float64
#  71   pct_MA_GS_AAPART                         float64
#  72   pct_MA_HS_AAPART                         float64
#  73   pct_RD_03_AAPART                         float64
#  74   pct_RD_04_AAPART                         float64
#  75   pct_RD_05_AAPART                         float64
#  76   pct_RD_06_AAPART                         float64
#  77   pct_RD_07_AAPART                         float64
#  78   pct_RD_08_AAPART                         float64
#  79   pct_RD_GS_AAPART                         float64
#  80   pct_RD_HS_AAPART                         float64
#  81   pct_SC_05_AAPART                         float64
#  82   pct_SC_08_AAPART                         float64
#  83   pct_SC_GS_AAPART                         float64
#  84   pct_SC_HS_AAPART                         float64
#  85   pct_ACALL_AIG_ACT                        float64
#  86   pct_ACALL_ALL_ACT                        float64
#  87   pct_ACALL_AM7_ACT                        float64
#  88   pct_ACALL_AS7_ACT                        float64
#  89   pct_ACALL_BL7_ACT                        float64
#  90   pct_ACALL_EDS_ACT                        float64
#  91   pct_ACALL_ELS_ACT                        float64
#  92   pct_ACALL_FCS_ACT                        float64
#  93   pct_ACALL_FEM_ACT                        float64
#  94   pct_ACALL_HI7_ACT                        float64
#  95   pct_ACALL_HMS_ACT                        float64
#  96   pct_ACALL_MALE_ACT                       float64
#  97   pct_ACALL_MIL_ACT                        float64
#  98   pct_ACALL_MU7_ACT                        float64
#  99   pct_ACALL_SWD_ACT                        float64
#  100  pct_ACALL_WH7_ACT                        float64
#  101  pct_ACCO_AIG_ACT                         float64
#  102  pct_ACCO_ALL_ACT                         float64
#  103  pct_ACCO_AM7_ACT                         float64
#  104  pct_ACCO_AS7_ACT                         float64
#  105  pct_ACCO_BL7_ACT                         float64
#  106  pct_ACCO_EDS_ACT                         float64
#  107  pct_ACCO_ELS_ACT                         float64
#  108  pct_ACCO_FCS_ACT                         float64
#  109  pct_ACCO_FEM_ACT                         float64
#  110  pct_ACCO_HI7_ACT                         float64
#  111  pct_ACCO_HMS_ACT                         float64
#  112  pct_ACCO_MALE_ACT                        float64
#  113  pct_ACCO_MIL_ACT                         float64
#  114  pct_ACCO_MU7_ACT                         float64
#  115  pct_ACCO_SWD_ACT                         float64
#  116  pct_ACCO_WH7_ACT                         float64
#  117  pct_ACEN_AIG_ACT                         float64
#  118  pct_ACEN_ALL_ACT                         float64
#  119  pct_ACEN_AM7_ACT                         float64
#  120  pct_ACEN_AS7_ACT                         float64
#  121  pct_ACEN_BL7_ACT                         float64
#  122  pct_ACEN_EDS_ACT                         float64
#  123  pct_ACEN_ELS_ACT                         float64
#  124  pct_ACEN_FCS_ACT                         float64
#  125  pct_ACEN_FEM_ACT                         float64
#  126  pct_ACEN_HI7_ACT                         float64
#  127  pct_ACEN_HMS_ACT                         float64
#  128  pct_ACEN_MALE_ACT                        float64
#  129  pct_ACEN_MIL_ACT                         float64
#  130  pct_ACEN_MU7_ACT                         float64
#  131  pct_ACEN_SWD_ACT                         float64
#  132  pct_ACEN_WH7_ACT                         float64
#  133  pct_ACMA_AIG_ACT                         float64
#  134  pct_ACMA_ALL_ACT                         float64
#  135  pct_ACMA_AM7_ACT                         float64
#  136  pct_ACMA_AS7_ACT                         float64
#  137  pct_ACMA_BL7_ACT                         float64
#  138  pct_ACMA_EDS_ACT                         float64
#  139  pct_ACMA_ELS_ACT                         float64
#  140  pct_ACMA_FCS_ACT                         float64
#  141  pct_ACMA_FEM_ACT                         float64
#  142  pct_ACMA_HI7_ACT                         float64
#  143  pct_ACMA_HMS_ACT                         float64
#  144  pct_ACMA_MALE_ACT                        float64
#  145  pct_ACMA_MIL_ACT                         float64
#  146  pct_ACMA_MU7_ACT                         float64
#  147  pct_ACMA_SWD_ACT                         float64
#  148  pct_ACMA_WH7_ACT                         float64
#  149  pct_ACRD_AIG_ACT                         float64
#  150  pct_ACRD_ALL_ACT                         float64
#  151  pct_ACRD_AM7_ACT                         float64
#  152  pct_ACRD_AS7_ACT                         float64
#  153  pct_ACRD_BL7_ACT                         float64
#  154  pct_ACRD_EDS_ACT                         float64
#  155  pct_ACRD_ELS_ACT                         float64
#  156  pct_ACRD_FCS_ACT                         float64
#  157  pct_ACRD_FEM_ACT                         float64
#  158  pct_ACRD_HI7_ACT                         float64
#  159  pct_ACRD_HMS_ACT                         float64
#  160  pct_ACRD_MALE_ACT                        float64
#  161  pct_ACRD_MIL_ACT                         float64
#  162  pct_ACRD_MU7_ACT                         float64
#  163  pct_ACRD_SWD_ACT                         float64
#  164  pct_ACRD_WH7_ACT                         float64
#  165  pct_ACSC_AIG_ACT                         float64
#  166  pct_ACSC_ALL_ACT                         float64
#  167  pct_ACSC_AM7_ACT                         float64
#  168  pct_ACSC_AS7_ACT                         float64
#  169  pct_ACSC_BL7_ACT                         float64
#  170  pct_ACSC_EDS_ACT                         float64
#  171  pct_ACSC_ELS_ACT                         float64
#  172  pct_ACSC_FCS_ACT                         float64
#  173  pct_ACSC_FEM_ACT                         float64
#  174  pct_ACSC_HI7_ACT                         float64
#  175  pct_ACSC_HMS_ACT                         float64
#  176  pct_ACSC_MALE_ACT                        float64
#  177  pct_ACSC_MIL_ACT                         float64
#  178  pct_ACSC_MU7_ACT                         float64
#  179  pct_ACSC_SWD_ACT                         float64
#  180  pct_ACSC_WH7_ACT                         float64
#  181  pct_ACWR_AIG_ACT                         float64
#  182  pct_ACWR_ALL_ACT                         float64
#  183  pct_ACWR_AM7_ACT                         float64
#  184  pct_ACWR_AS7_ACT                         float64
#  185  pct_ACWR_BL7_ACT                         float64
#  186  pct_ACWR_EDS_ACT                         float64
#  187  pct_ACWR_ELS_ACT                         float64
#  188  pct_ACWR_FCS_ACT                         float64
#  189  pct_ACWR_FEM_ACT                         float64
#  190  pct_ACWR_HI7_ACT                         float64
#  191  pct_ACWR_HMS_ACT                         float64
#  192  pct_ACWR_MALE_ACT                        float64
#  193  pct_ACWR_MIL_ACT                         float64
#  194  pct_ACWR_MU7_ACT                         float64
#  195  pct_ACWR_SWD_ACT                         float64
#  196  pct_ACWR_WH7_ACT                         float64
#  197  pct_AIG_AWA                              float64
#  198  pct_ALL_AWA                              float64
#  199  pct_AM7_AWA                              float64
#  200  pct_AS7_AWA                              float64
#  201  pct_BL7_AWA                              float64
#  202  pct_EDS_AWA                              float64
#  203  pct_ELS_AWA                              float64
#  204  pct_FCS_AWA                              float64
#  205  pct_FEM_AWA                              float64
#  206  pct_HI7_AWA                              float64
#  207  pct_HMS_AWA                              float64
#  208  pct_MALE_AWA                             float64
#  209  pct_MIL_AWA                              float64
#  210  pct_MU7_AWA                              float64
#  211  pct_SWD_AWA                              float64
#  212  pct_WH7_AWA                              float64
#  213  pct_EXT_AIG_CGR                          float64
#  214  pct_EXT_ALL_CGR                          float64
#  215  pct_EXT_AM7_CGR                          float64
#  216  pct_EXT_AS7_CGR                          float64
#  217  pct_EXT_BL7_CGR                          float64
#  218  pct_EXT_EDS_CGR                          float64
#  219  pct_EXT_ELS_CGR                          float64
#  220  pct_EXT_FEM_CGR                          float64
#  221  pct_EXT_HI7_CGR                          float64
#  222  pct_EXT_MALE_CGR                         float64
#  223  pct_EXT_MIG_CGR                          float64
#  224  pct_EXT_MU7_CGR                          float64
#  225  pct_EXT_SWD_CGR                          float64
#  226  pct_EXT_WH7_CGR                          float64
#  227  pct_STD_AIG_CGR                          float64
#  228  pct_STD_ALL_CGR                          float64
#  229  pct_STD_AM7_CGR                          float64
#  230  pct_STD_AS7_CGR                          float64
#  231  pct_STD_BL7_CGR                          float64
#  232  pct_STD_EDS_CGR                          float64
#  233  pct_STD_ELS_CGR                          float64
#  234  pct_STD_FCS_CGR                          float64
#  235  pct_STD_FEM_CGR                          float64
#  236  pct_STD_HI7_CGR                          float64
#  237  pct_STD_HMS_CGR                          float64
#  238  pct_STD_MALE_CGR                         float64
#  239  pct_STD_MIG_CGR                          float64
#  240  pct_STD_MU7_CGR                          float64
#  241  pct_STD_SWD_CGR                          float64
#  242  pct_STD_WH7_CGR                          float64
#  243  pct_eds                                  float64
#  244  pct_AIG_ELP                              float64
#  245  pct_ALL_ELP                              float64
#  246  pct_AM7_ELP                              float64
#  247  pct_AS7_ELP                              float64
#  248  pct_BL7_ELP                              float64
#  249  pct_EDS_ELP                              float64
#  250  pct_ELS_ELP                              float64
#  251  pct_FCS_ELP                              float64
#  252  pct_FEM_ELP                              float64
#  253  pct_HI7_ELP                              float64
#  254  pct_HMS_ELP                              float64
#  255  pct_MALE_ELP                             float64
#  256  pct_MIL_ELP                              float64
#  257  pct_MU7_ELP                              float64
#  258  pct_SWD_ELP                              float64
#  259  pct_WH7_ELP                              float64
#  260  csi_lp                                   object
#  261  csi_lg                                   object
#  262  tsi_cu                                   object
#  263  tsi_at                                   object
#  264  grad_project                             object
#  265  pct_prof_6gr_irm                         float64
#  266  pct_prof_9gr_irm                         float64
#  267  lp_school                                object
#  268  rlp_school                               object
#  269  clpc_school                              object
#  270  pct_met_4 Year Graduation Rate_LTG       float64
#  271  pct_met_EL Progress_LTG                  float64
#  272  pct_met_Math Grade 11_LTG                float64
#  273  pct_met_Math Grades 3-8_LTG              float64
#  274  pct_met_Reading Grade 10_LTG             float64
#  275  pct_met_Reading Grades 3-8_LTG           float64
#  276  pct_met_Total Targets_LTG                float64
#  277  target_list                              object
#  278  subgroup_list                            object
#  279  pct_AIG_MCR                              float64
#  280  pct_ALL_MCR                              float64
#  281  pct_AM7_MCR                              float64
#  282  pct_AS7_MCR                              float64
#  283  pct_BL7_MCR                              float64
#  284  pct_EDS_MCR                              float64
#  285  pct_ELS_MCR                              float64
#  286  pct_FCS_MCR                              float64
#  287  pct_FEM_MCR                              float64
#  288  pct_HI7_MCR                              float64
#  289  pct_HMS_MCR                              float64
#  290  pct_MALE_MCR                             float64
#  291  pct_MIL_MCR                              float64
#  292  pct_MU7_MCR                              float64
#  293  pct_SWD_MCR                              float64
#  294  pct_WH7_MCR                              float64
#  295  pct_met_ACT WorkKeys_PART                float64
#  296  pct_met_Biology_PART                     float64
#  297  pct_met_English II_PART                  float64
#  298  pct_met_High School Math_PART            float64
#  299  pct_met_Math Grades 3-8_PART             float64
#  300  pct_met_Reading Grades 3-8_PART          float64
#  301  pct_met_Science Grades 5&8_PART          float64
#  302  pct_met_The ACT_PART                     float64
#  303  pct_met_Total Targets_PART               float64
#  304  pct_ACT WorkKeys_ALL_PART_DET            float64
#  305  pct_ACT WorkKeys_AM7_PART_DET            float64
#  306  pct_ACT WorkKeys_AS7_PART_DET            float64
#  307  pct_ACT WorkKeys_BL7_PART_DET            float64
#  308  pct_ACT WorkKeys_EDS_PART_DET            float64
#  309  pct_ACT WorkKeys_ELS_PART_DET            float64
#  310  pct_ACT WorkKeys_HI7_PART_DET            float64
#  311  pct_ACT WorkKeys_MU7_PART_DET            float64
#  312  pct_ACT WorkKeys_SWD_PART_DET            float64
#  313  pct_ACT WorkKeys_WH7_PART_DET            float64
#  314  pct_Biology_ALL_PART_DET                 float64
#  315  pct_Biology_AM7_PART_DET                 float64
#  316  pct_Biology_AS7_PART_DET                 float64
#  317  pct_Biology_BL7_PART_DET                 float64
#  318  pct_Biology_EDS_PART_DET                 float64
#  319  pct_Biology_ELS_PART_DET                 float64
#  320  pct_Biology_HI7_PART_DET                 float64
#  321  pct_Biology_MU7_PART_DET                 float64
#  322  pct_Biology_SWD_PART_DET                 float64
#  323  pct_Biology_WH7_PART_DET                 float64
#  324  pct_English II_ALL_PART_DET              float64
#  325  pct_English II_AM7_PART_DET              float64
#  326  pct_English II_AS7_PART_DET              float64
#  327  pct_English II_BL7_PART_DET              float64
#  328  pct_English II_EDS_PART_DET              float64
#  329  pct_English II_ELS_PART_DET              float64
#  330  pct_English II_HI7_PART_DET              float64
#  331  pct_English II_MU7_PART_DET              float64
#  332  pct_English II_SWD_PART_DET              float64
#  333  pct_English II_WH7_PART_DET              float64
#  334  pct_High School Math_ALL_PART_DET        float64
#  335  pct_High School Math_AM7_PART_DET        float64
#  336  pct_High School Math_AS7_PART_DET        float64
#  337  pct_High School Math_BL7_PART_DET        float64
#  338  pct_High School Math_EDS_PART_DET        float64
#  339  pct_High School Math_ELS_PART_DET        float64
#  340  pct_High School Math_HI7_PART_DET        float64
#  341  pct_High School Math_MU7_PART_DET        float64
#  342  pct_High School Math_SWD_PART_DET        float64
#  343  pct_High School Math_WH7_PART_DET        float64
#  344  pct_Math Grades 3-8_ALL_PART_DET         float64
#  345  pct_Math Grades 3-8_AM7_PART_DET         float64
#  346  pct_Math Grades 3-8_AS7_PART_DET         float64
#  347  pct_Math Grades 3-8_BL7_PART_DET         float64
#  348  pct_Math Grades 3-8_EDS_PART_DET         float64
#  349  pct_Math Grades 3-8_ELS_PART_DET         float64
#  350  pct_Math Grades 3-8_HI7_PART_DET         float64
#  351  pct_Math Grades 3-8_MU7_PART_DET         float64
#  352  pct_Math Grades 3-8_SWD_PART_DET         float64
#  353  pct_Math Grades 3-8_WH7_PART_DET         float64
#  354  pct_Reading Grades 3-8_ALL_PART_DET      float64
#  355  pct_Reading Grades 3-8_AM7_PART_DET      float64
#  356  pct_Reading Grades 3-8_AS7_PART_DET      float64
#  357  pct_Reading Grades 3-8_BL7_PART_DET      float64
#  358  pct_Reading Grades 3-8_EDS_PART_DET      float64
#  359  pct_Reading Grades 3-8_ELS_PART_DET      float64
#  360  pct_Reading Grades 3-8_HI7_PART_DET      float64
#  361  pct_Reading Grades 3-8_MU7_PART_DET      float64
#  362  pct_Reading Grades 3-8_SWD_PART_DET      float64
#  363  pct_Reading Grades 3-8_WH7_PART_DET      float64
#  364  pct_Science Grades 5&8_ALL_PART_DET      float64
#  365  pct_Science Grades 5&8_AM7_PART_DET      float64
#  366  pct_Science Grades 5&8_AS7_PART_DET      float64
#  367  pct_Science Grades 5&8_BL7_PART_DET      float64
#  368  pct_Science Grades 5&8_EDS_PART_DET      float64
#  369  pct_Science Grades 5&8_ELS_PART_DET      float64
#  370  pct_Science Grades 5&8_HI7_PART_DET      float64
#  371  pct_Science Grades 5&8_MU7_PART_DET      float64
#  372  pct_Science Grades 5&8_SWD_PART_DET      float64
#  373  pct_Science Grades 5&8_WH7_PART_DET      float64
#  374  pct_The ACT_ALL_PART_DET                 float64
#  375  pct_The ACT_AM7_PART_DET                 float64
#  376  pct_The ACT_AS7_PART_DET                 float64
#  377  pct_The ACT_BL7_PART_DET                 float64
#  378  pct_The ACT_EDS_PART_DET                 float64
#  379  pct_The ACT_ELS_PART_DET                 float64
#  380  pct_The ACT_HI7_PART_DET                 float64
#  381  pct_The ACT_MU7_PART_DET                 float64
#  382  pct_The ACT_SWD_PART_DET                 float64
#  383  pct_The ACT_WH7_PART_DET                 float64
#  384  pct_CCR_BI_EOC_AIG_PC                    float64
#  385  pct_CCR_BI_EOC_ALL_PC                    float64
#  386  pct_CCR_BI_EOC_AM7_PC                    float64
#  387  pct_CCR_BI_EOC_AS7_PC                    float64
#  388  pct_CCR_BI_EOC_BL7_PC                    float64
#  389  pct_CCR_BI_EOC_EDS_PC                    float64
#  390  pct_CCR_BI_EOC_ELS_PC                    float64
#  391  pct_CCR_BI_EOC_FCS_PC                    float64
#  392  pct_CCR_BI_EOC_FEM_PC                    float64
#  393  pct_CCR_BI_EOC_HI7_PC                    float64
#  394  pct_CCR_BI_EOC_HMS_PC                    float64
#  395  pct_CCR_BI_EOC_MALE_PC                   float64
#  396  pct_CCR_BI_EOC_MIG_PC                    float64
#  397  pct_CCR_BI_EOC_MIL_PC                    float64
#  398  pct_CCR_BI_EOC_MU7_PC                    float64
#  399  pct_CCR_BI_EOC_SWD_PC                    float64
#  400  pct_CCR_BI_EOC_WH7_PC                    float64
#  401  pct_CCR_E2_EOC_AIG_PC                    float64
#  402  pct_CCR_E2_EOC_ALL_PC                    float64
#  403  pct_CCR_E2_EOC_AM7_PC                    float64
#  404  pct_CCR_E2_EOC_AS7_PC                    float64
#  405  pct_CCR_E2_EOC_BL7_PC                    float64
#  406  pct_CCR_E2_EOC_EDS_PC                    float64
#  407  pct_CCR_E2_EOC_ELS_PC                    float64
#  408  pct_CCR_E2_EOC_FCS_PC                    float64
#  409  pct_CCR_E2_EOC_FEM_PC                    float64
#  410  pct_CCR_E2_EOC_HI7_PC                    float64
#  411  pct_CCR_E2_EOC_HMS_PC                    float64
#  412  pct_CCR_E2_EOC_MALE_PC                   float64
#  413  pct_CCR_E2_EOC_MIG_PC                    float64
#  414  pct_CCR_E2_EOC_MIL_PC                    float64
#  415  pct_CCR_E2_EOC_MU7_PC                    float64
#  416  pct_CCR_E2_EOC_SWD_PC                    float64
#  417  pct_CCR_E2_EOC_WH7_PC                    float64
#  418  pct_CCR_EOC_EOC_AIG_PC                   float64
#  419  pct_CCR_EOC_EOC_ALL_PC                   float64
#  420  pct_CCR_EOC_EOC_AM7_PC                   float64
#  421  pct_CCR_EOC_EOC_AS7_PC                   float64
#  422  pct_CCR_EOC_EOC_BL7_PC                   float64
#  423  pct_CCR_EOC_EOC_EDS_PC                   float64
#  424  pct_CCR_EOC_EOC_ELS_PC                   float64
#  425  pct_CCR_EOC_EOC_FCS_PC                   float64
#  426  pct_CCR_EOC_EOC_FEM_PC                   float64
#  427  pct_CCR_EOC_EOC_HI7_PC                   float64
#  428  pct_CCR_EOC_EOC_HMS_PC                   float64
#  429  pct_CCR_EOC_EOC_MALE_PC                  float64
#  430  pct_CCR_EOC_EOC_MIG_PC                   float64
#  431  pct_CCR_EOC_EOC_MIL_PC                   float64
#  432  pct_CCR_EOC_EOC_MU7_PC                   float64
#  433  pct_CCR_EOC_EOC_SWD_PC                   float64
#  434  pct_CCR_EOC_EOC_WH7_PC                   float64
#  435  pct_CCR_EOG_03_AIG_PC                    float64
#  436  pct_CCR_EOG_03_ALL_PC                    float64
#  437  pct_CCR_EOG_03_AM7_PC                    float64
#  438  pct_CCR_EOG_03_AS7_PC                    float64
#  439  pct_CCR_EOG_03_BL7_PC                    float64
#  440  pct_CCR_EOG_03_EDS_PC                    float64
#  441  pct_CCR_EOG_03_ELS_PC                    float64
#  442  pct_CCR_EOG_03_FCS_PC                    float64
#  443  pct_CCR_EOG_03_FEM_PC                    float64
#  444  pct_CCR_EOG_03_HI7_PC                    float64
#  445  pct_CCR_EOG_03_HMS_PC                    float64
#  446  pct_CCR_EOG_03_MALE_PC                   float64
#  447  pct_CCR_EOG_03_MIG_PC                    float64
#  448  pct_CCR_EOG_03_MIL_PC                    float64
#  449  pct_CCR_EOG_03_MU7_PC                    float64
#  450  pct_CCR_EOG_03_SWD_PC                    float64
#  451  pct_CCR_EOG_03_WH7_PC                    float64
#  452  pct_CCR_EOG_04_AIG_PC                    float64
#  453  pct_CCR_EOG_04_ALL_PC                    float64
#  454  pct_CCR_EOG_04_AM7_PC                    float64
#  455  pct_CCR_EOG_04_AS7_PC                    float64
#  456  pct_CCR_EOG_04_BL7_PC                    float64
#  457  pct_CCR_EOG_04_EDS_PC                    float64
#  458  pct_CCR_EOG_04_ELS_PC                    float64
#  459  pct_CCR_EOG_04_FCS_PC                    float64
#  460  pct_CCR_EOG_04_FEM_PC                    float64
#  461  pct_CCR_EOG_04_HI7_PC                    float64
#  462  pct_CCR_EOG_04_HMS_PC                    float64
#  463  pct_CCR_EOG_04_MALE_PC                   float64
#  464  pct_CCR_EOG_04_MIG_PC                    float64
#  465  pct_CCR_EOG_04_MIL_PC                    float64
#  466  pct_CCR_EOG_04_MU7_PC                    float64
#  467  pct_CCR_EOG_04_SWD_PC                    float64
#  468  pct_CCR_EOG_04_WH7_PC                    float64
#  469  pct_CCR_EOG_05_AIG_PC                    float64
#  470  pct_CCR_EOG_05_ALL_PC                    float64
#  471  pct_CCR_EOG_05_AM7_PC                    float64
#  472  pct_CCR_EOG_05_AS7_PC                    float64
#  473  pct_CCR_EOG_05_BL7_PC                    float64
#  474  pct_CCR_EOG_05_EDS_PC                    float64
#  475  pct_CCR_EOG_05_ELS_PC                    float64
#  476  pct_CCR_EOG_05_FCS_PC                    float64
#  477  pct_CCR_EOG_05_FEM_PC                    float64
#  478  pct_CCR_EOG_05_HI7_PC                    float64
#  479  pct_CCR_EOG_05_HMS_PC                    float64
#  480  pct_CCR_EOG_05_MALE_PC                   float64
#  481  pct_CCR_EOG_05_MIG_PC                    float64
#  482  pct_CCR_EOG_05_MIL_PC                    float64
#  483  pct_CCR_EOG_05_MU7_PC                    float64
#  484  pct_CCR_EOG_05_SWD_PC                    float64
#  485  pct_CCR_EOG_05_WH7_PC                    float64
#  486  pct_CCR_EOG_06_AIG_PC                    float64
#  487  pct_CCR_EOG_06_ALL_PC                    float64
#  488  pct_CCR_EOG_06_AM7_PC                    float64
#  489  pct_CCR_EOG_06_AS7_PC                    float64
#  490  pct_CCR_EOG_06_BL7_PC                    float64
#  491  pct_CCR_EOG_06_EDS_PC                    float64
#  492  pct_CCR_EOG_06_ELS_PC                    float64
#  493  pct_CCR_EOG_06_FCS_PC                    float64
#  494  pct_CCR_EOG_06_FEM_PC                    float64
#  495  pct_CCR_EOG_06_HI7_PC                    float64
#  496  pct_CCR_EOG_06_HMS_PC                    float64
#  497  pct_CCR_EOG_06_MALE_PC                   float64
#  498  pct_CCR_EOG_06_MIG_PC                    float64
#  499  pct_CCR_EOG_06_MIL_PC                    float64
#  500  pct_CCR_EOG_06_MU7_PC                    float64
#  501  pct_CCR_EOG_06_SWD_PC                    float64
#  502  pct_CCR_EOG_06_WH7_PC                    float64
#  503  pct_CCR_EOG_07_AIG_PC                    float64
#  504  pct_CCR_EOG_07_ALL_PC                    float64
#  505  pct_CCR_EOG_07_AM7_PC                    float64
#  506  pct_CCR_EOG_07_AS7_PC                    float64
#  507  pct_CCR_EOG_07_BL7_PC                    float64
#  508  pct_CCR_EOG_07_EDS_PC                    float64
#  509  pct_CCR_EOG_07_ELS_PC                    float64
#  510  pct_CCR_EOG_07_FCS_PC                    float64
#  511  pct_CCR_EOG_07_FEM_PC                    float64
#  512  pct_CCR_EOG_07_HI7_PC                    float64
#  513  pct_CCR_EOG_07_HMS_PC                    float64
#  514  pct_CCR_EOG_07_MALE_PC                   float64
#  515  pct_CCR_EOG_07_MIG_PC                    float64
#  516  pct_CCR_EOG_07_MIL_PC                    float64
#  517  pct_CCR_EOG_07_MU7_PC                    float64
#  518  pct_CCR_EOG_07_SWD_PC                    float64
#  519  pct_CCR_EOG_07_WH7_PC                    float64
#  520  pct_CCR_EOG_08_AIG_PC                    float64
#  521  pct_CCR_EOG_08_ALL_PC                    float64
#  522  pct_CCR_EOG_08_AM7_PC                    float64
#  523  pct_CCR_EOG_08_AS7_PC                    float64
#  524  pct_CCR_EOG_08_BL7_PC                    float64
#  525  pct_CCR_EOG_08_EDS_PC                    float64
#  526  pct_CCR_EOG_08_ELS_PC                    float64
#  527  pct_CCR_EOG_08_FCS_PC                    float64
#  528  pct_CCR_EOG_08_FEM_PC                    float64
#  529  pct_CCR_EOG_08_HI7_PC                    float64
#  530  pct_CCR_EOG_08_HMS_PC                    float64
#  531  pct_CCR_EOG_08_MALE_PC                   float64
#  532  pct_CCR_EOG_08_MIG_PC                    float64
#  533  pct_CCR_EOG_08_MIL_PC                    float64
#  534  pct_CCR_EOG_08_MU7_PC                    float64
#  535  pct_CCR_EOG_08_SWD_PC                    float64
#  536  pct_CCR_EOG_08_WH7_PC                    float64
#  537  pct_CCR_EOG_ALL_AIG_PC                   float64
#  538  pct_CCR_EOG_ALL_ALL_PC                   float64
#  539  pct_CCR_EOG_ALL_AM7_PC                   float64
#  540  pct_CCR_EOG_ALL_AS7_PC                   float64
#  541  pct_CCR_EOG_ALL_BL7_PC                   float64
#  542  pct_CCR_EOG_ALL_EDS_PC                   float64
#  543  pct_CCR_EOG_ALL_ELS_PC                   float64
#  544  pct_CCR_EOG_ALL_FCS_PC                   float64
#  545  pct_CCR_EOG_ALL_FEM_PC                   float64
#  546  pct_CCR_EOG_ALL_HI7_PC                   float64
#  547  pct_CCR_EOG_ALL_HMS_PC                   float64
#  548  pct_CCR_EOG_ALL_MALE_PC                  float64
#  549  pct_CCR_EOG_ALL_MIG_PC                   float64
#  550  pct_CCR_EOG_ALL_MIL_PC                   float64
#  551  pct_CCR_EOG_ALL_MU7_PC                   float64
#  552  pct_CCR_EOG_ALL_SWD_PC                   float64
#  553  pct_CCR_EOG_ALL_WH7_PC                   float64
#  554  pct_CCR_M1_EOC_AIG_PC                    float64
#  555  pct_CCR_M1_EOC_ALL_PC                    float64
#  556  pct_CCR_M1_EOC_AM7_PC                    float64
#  557  pct_CCR_M1_EOC_AS7_PC                    float64
#  558  pct_CCR_M1_EOC_BL7_PC                    float64
#  559  pct_CCR_M1_EOC_EDS_PC                    float64
#  560  pct_CCR_M1_EOC_ELS_PC                    float64
#  561  pct_CCR_M1_EOC_FCS_PC                    float64
#  562  pct_CCR_M1_EOC_FEM_PC                    float64
#  563  pct_CCR_M1_EOC_HI7_PC                    float64
#  564  pct_CCR_M1_EOC_HMS_PC                    float64
#  565  pct_CCR_M1_EOC_MALE_PC                   float64
#  566  pct_CCR_M1_EOC_MIG_PC                    float64
#  567  pct_CCR_M1_EOC_MIL_PC                    float64
#  568  pct_CCR_M1_EOC_MU7_PC                    float64
#  569  pct_CCR_M1_EOC_SWD_PC                    float64
#  570  pct_CCR_M1_EOC_WH7_PC                    float64
#  571  pct_CCR_MA_03_AIG_PC                     float64
#  572  pct_CCR_MA_03_ALL_PC                     float64
#  573  pct_CCR_MA_03_AM7_PC                     float64
#  574  pct_CCR_MA_03_AS7_PC                     float64
#  575  pct_CCR_MA_03_BL7_PC                     float64
#  576  pct_CCR_MA_03_EDS_PC                     float64
#  577  pct_CCR_MA_03_ELS_PC                     float64
#  578  pct_CCR_MA_03_FCS_PC                     float64
#  579  pct_CCR_MA_03_FEM_PC                     float64
#  580  pct_CCR_MA_03_HI7_PC                     float64
#  581  pct_CCR_MA_03_HMS_PC                     float64
#  582  pct_CCR_MA_03_MALE_PC                    float64
#  583  pct_CCR_MA_03_MIG_PC                     float64
#  584  pct_CCR_MA_03_MIL_PC                     float64
#  585  pct_CCR_MA_03_MU7_PC                     float64
#  586  pct_CCR_MA_03_SWD_PC                     float64
#  587  pct_CCR_MA_03_WH7_PC                     float64
#  588  pct_CCR_MA_04_AIG_PC                     float64
#  589  pct_CCR_MA_04_ALL_PC                     float64
#  590  pct_CCR_MA_04_AM7_PC                     float64
#  591  pct_CCR_MA_04_AS7_PC                     float64
#  592  pct_CCR_MA_04_BL7_PC                     float64
#  593  pct_CCR_MA_04_EDS_PC                     float64
#  594  pct_CCR_MA_04_ELS_PC                     float64
#  595  pct_CCR_MA_04_FCS_PC                     float64
#  596  pct_CCR_MA_04_FEM_PC                     float64
#  597  pct_CCR_MA_04_HI7_PC                     float64
#  598  pct_CCR_MA_04_HMS_PC                     float64
#  599  pct_CCR_MA_04_MALE_PC                    float64
#  600  pct_CCR_MA_04_MIG_PC                     float64
#  601  pct_CCR_MA_04_MIL_PC                     float64
#  602  pct_CCR_MA_04_MU7_PC                     float64
#  603  pct_CCR_MA_04_SWD_PC                     float64
#  604  pct_CCR_MA_04_WH7_PC                     float64
#  605  pct_CCR_MA_05_AIG_PC                     float64
#  606  pct_CCR_MA_05_ALL_PC                     float64
#  607  pct_CCR_MA_05_AM7_PC                     float64
#  608  pct_CCR_MA_05_AS7_PC                     float64
#  609  pct_CCR_MA_05_BL7_PC                     float64
#  610  pct_CCR_MA_05_EDS_PC                     float64
#  611  pct_CCR_MA_05_ELS_PC                     float64
#  612  pct_CCR_MA_05_FCS_PC                     float64
#  613  pct_CCR_MA_05_FEM_PC                     float64
#  614  pct_CCR_MA_05_HI7_PC                     float64
#  615  pct_CCR_MA_05_HMS_PC                     float64
#  616  pct_CCR_MA_05_MALE_PC                    float64
#  617  pct_CCR_MA_05_MIG_PC                     float64
#  618  pct_CCR_MA_05_MIL_PC                     float64
#  619  pct_CCR_MA_05_MU7_PC                     float64
#  620  pct_CCR_MA_05_SWD_PC                     float64
#  621  pct_CCR_MA_05_WH7_PC                     float64
#  622  pct_CCR_MA_06_AIG_PC                     float64
#  623  pct_CCR_MA_06_ALL_PC                     float64
#  624  pct_CCR_MA_06_AM7_PC                     float64
#  625  pct_CCR_MA_06_AS7_PC                     float64
#  626  pct_CCR_MA_06_BL7_PC                     float64
#  627  pct_CCR_MA_06_EDS_PC                     float64
#  628  pct_CCR_MA_06_ELS_PC                     float64
#  629  pct_CCR_MA_06_FCS_PC                     float64
#  630  pct_CCR_MA_06_FEM_PC                     float64
#  631  pct_CCR_MA_06_HI7_PC                     float64
#  632  pct_CCR_MA_06_HMS_PC                     float64
#  633  pct_CCR_MA_06_MALE_PC                    float64
#  634  pct_CCR_MA_06_MIG_PC                     float64
#  635  pct_CCR_MA_06_MIL_PC                     float64
#  636  pct_CCR_MA_06_MU7_PC                     float64
#  637  pct_CCR_MA_06_SWD_PC                     float64
#  638  pct_CCR_MA_06_WH7_PC                     float64
#  639  pct_CCR_MA_07_AIG_PC                     float64
#  640  pct_CCR_MA_07_ALL_PC                     float64
#  641  pct_CCR_MA_07_AM7_PC                     float64
#  642  pct_CCR_MA_07_AS7_PC                     float64
#  643  pct_CCR_MA_07_BL7_PC                     float64
#  644  pct_CCR_MA_07_EDS_PC                     float64
#  645  pct_CCR_MA_07_ELS_PC                     float64
#  646  pct_CCR_MA_07_FCS_PC                     float64
#  647  pct_CCR_MA_07_FEM_PC                     float64
#  648  pct_CCR_MA_07_HI7_PC                     float64
#  649  pct_CCR_MA_07_HMS_PC                     float64
#  650  pct_CCR_MA_07_MALE_PC                    float64
#  651  pct_CCR_MA_07_MIG_PC                     float64
#  652  pct_CCR_MA_07_MIL_PC                     float64
#  653  pct_CCR_MA_07_MU7_PC                     float64
#  654  pct_CCR_MA_07_SWD_PC                     float64
#  655  pct_CCR_MA_07_WH7_PC                     float64
#  656  pct_CCR_MA_08_AIG_PC                     float64
#  657  pct_CCR_MA_08_ALL_PC                     float64
#  658  pct_CCR_MA_08_AM7_PC                     float64
#  659  pct_CCR_MA_08_AS7_PC                     float64
#  660  pct_CCR_MA_08_BL7_PC                     float64
#  661  pct_CCR_MA_08_EDS_PC                     float64
#  662  pct_CCR_MA_08_ELS_PC                     float64
#  663  pct_CCR_MA_08_FCS_PC                     float64
#  664  pct_CCR_MA_08_FEM_PC                     float64
#  665  pct_CCR_MA_08_HI7_PC                     float64
#  666  pct_CCR_MA_08_HMS_PC                     float64
#  667  pct_CCR_MA_08_MALE_PC                    float64
#  668  pct_CCR_MA_08_MIG_PC                     float64
#  669  pct_CCR_MA_08_MIL_PC                     float64
#  670  pct_CCR_MA_08_MU7_PC                     float64
#  671  pct_CCR_MA_08_SWD_PC                     float64
#  672  pct_CCR_MA_08_WH7_PC                     float64
#  673  pct_CCR_MA_ALL_AIG_PC                    float64
#  674  pct_CCR_MA_ALL_ALL_PC                    float64
#  675  pct_CCR_MA_ALL_AM7_PC                    float64
#  676  pct_CCR_MA_ALL_AS7_PC                    float64
#  677  pct_CCR_MA_ALL_BL7_PC                    float64
#  678  pct_CCR_MA_ALL_EDS_PC                    float64
#  679  pct_CCR_MA_ALL_ELS_PC                    float64
#  680  pct_CCR_MA_ALL_FCS_PC                    float64
#  681  pct_CCR_MA_ALL_FEM_PC                    float64
#  682  pct_CCR_MA_ALL_HI7_PC                    float64
#  683  pct_CCR_MA_ALL_HMS_PC                    float64
#  684  pct_CCR_MA_ALL_MALE_PC                   float64
#  685  pct_CCR_MA_ALL_MIG_PC                    float64
#  686  pct_CCR_MA_ALL_MIL_PC                    float64
#  687  pct_CCR_MA_ALL_MU7_PC                    float64
#  688  pct_CCR_MA_ALL_SWD_PC                    float64
#  689  pct_CCR_MA_ALL_WH7_PC                    float64
#  690  pct_CCR_RD_03_AIG_PC                     float64
#  691  pct_CCR_RD_03_ALL_PC                     float64
#  692  pct_CCR_RD_03_AM7_PC                     float64
#  693  pct_CCR_RD_03_AS7_PC                     float64
#  694  pct_CCR_RD_03_BL7_PC                     float64
#  695  pct_CCR_RD_03_EDS_PC                     float64
#  696  pct_CCR_RD_03_ELS_PC                     float64
#  697  pct_CCR_RD_03_FCS_PC                     float64
#  698  pct_CCR_RD_03_FEM_PC                     float64
#  699  pct_CCR_RD_03_HI7_PC                     float64
#  700  pct_CCR_RD_03_HMS_PC                     float64
#  701  pct_CCR_RD_03_MALE_PC                    float64
#  702  pct_CCR_RD_03_MIG_PC                     float64
#  703  pct_CCR_RD_03_MIL_PC                     float64
#  704  pct_CCR_RD_03_MU7_PC                     float64
#  705  pct_CCR_RD_03_SWD_PC                     float64
#  706  pct_CCR_RD_03_WH7_PC                     float64
#  707  pct_CCR_RD_04_AIG_PC                     float64
#  708  pct_CCR_RD_04_ALL_PC                     float64
#  709  pct_CCR_RD_04_AM7_PC                     float64
#  710  pct_CCR_RD_04_AS7_PC                     float64
#  711  pct_CCR_RD_04_BL7_PC                     float64
#  712  pct_CCR_RD_04_EDS_PC                     float64
#  713  pct_CCR_RD_04_ELS_PC                     float64
#  714  pct_CCR_RD_04_FCS_PC                     float64
#  715  pct_CCR_RD_04_FEM_PC                     float64
#  716  pct_CCR_RD_04_HI7_PC                     float64
#  717  pct_CCR_RD_04_HMS_PC                     float64
#  718  pct_CCR_RD_04_MALE_PC                    float64
#  719  pct_CCR_RD_04_MIG_PC                     float64
#  720  pct_CCR_RD_04_MIL_PC                     float64
#  721  pct_CCR_RD_04_MU7_PC                     float64
#  722  pct_CCR_RD_04_SWD_PC                     float64
#  723  pct_CCR_RD_04_WH7_PC                     float64
#  724  pct_CCR_RD_05_AIG_PC                     float64
#  725  pct_CCR_RD_05_ALL_PC                     float64
#  726  pct_CCR_RD_05_AM7_PC                     float64
#  727  pct_CCR_RD_05_AS7_PC                     float64
#  728  pct_CCR_RD_05_BL7_PC                     float64
#  729  pct_CCR_RD_05_EDS_PC                     float64
#  730  pct_CCR_RD_05_ELS_PC                     float64
#  731  pct_CCR_RD_05_FCS_PC                     float64
#  732  pct_CCR_RD_05_FEM_PC                     float64
#  733  pct_CCR_RD_05_HI7_PC                     float64
#  734  pct_CCR_RD_05_HMS_PC                     float64
#  735  pct_CCR_RD_05_MALE_PC                    float64
#  736  pct_CCR_RD_05_MIG_PC                     float64
#  737  pct_CCR_RD_05_MIL_PC                     float64
#  738  pct_CCR_RD_05_MU7_PC                     float64
#  739  pct_CCR_RD_05_SWD_PC                     float64
#  740  pct_CCR_RD_05_WH7_PC                     float64
#  741  pct_CCR_RD_06_AIG_PC                     float64
#  742  pct_CCR_RD_06_ALL_PC                     float64
#  743  pct_CCR_RD_06_AM7_PC                     float64
#  744  pct_CCR_RD_06_AS7_PC                     float64
#  745  pct_CCR_RD_06_BL7_PC                     float64
#  746  pct_CCR_RD_06_EDS_PC                     float64
#  747  pct_CCR_RD_06_ELS_PC                     float64
#  748  pct_CCR_RD_06_FCS_PC                     float64
#  749  pct_CCR_RD_06_FEM_PC                     float64
#  750  pct_CCR_RD_06_HI7_PC                     float64
#  751  pct_CCR_RD_06_HMS_PC                     float64
#  752  pct_CCR_RD_06_MALE_PC                    float64
#  753  pct_CCR_RD_06_MIG_PC                     float64
#  754  pct_CCR_RD_06_MIL_PC                     float64
#  755  pct_CCR_RD_06_MU7_PC                     float64
#  756  pct_CCR_RD_06_SWD_PC                     float64
#  757  pct_CCR_RD_06_WH7_PC                     float64
#  758  pct_CCR_RD_07_AIG_PC                     float64
#  759  pct_CCR_RD_07_ALL_PC                     float64
#  760  pct_CCR_RD_07_AM7_PC                     float64
#  761  pct_CCR_RD_07_AS7_PC                     float64
#  762  pct_CCR_RD_07_BL7_PC                     float64
#  763  pct_CCR_RD_07_EDS_PC                     float64
#  764  pct_CCR_RD_07_ELS_PC                     float64
#  765  pct_CCR_RD_07_FCS_PC                     float64
#  766  pct_CCR_RD_07_FEM_PC                     float64
#  767  pct_CCR_RD_07_HI7_PC                     float64
#  768  pct_CCR_RD_07_HMS_PC                     float64
#  769  pct_CCR_RD_07_MALE_PC                    float64
#  770  pct_CCR_RD_07_MIG_PC                     float64
#  771  pct_CCR_RD_07_MIL_PC                     float64
#  772  pct_CCR_RD_07_MU7_PC                     float64
#  773  pct_CCR_RD_07_SWD_PC                     float64
#  774  pct_CCR_RD_07_WH7_PC                     float64
#  775  pct_CCR_RD_08_AIG_PC                     float64
#  776  pct_CCR_RD_08_ALL_PC                     float64
#  777  pct_CCR_RD_08_AM7_PC                     float64
#  778  pct_CCR_RD_08_AS7_PC                     float64
#  779  pct_CCR_RD_08_BL7_PC                     float64
#  780  pct_CCR_RD_08_EDS_PC                     float64
#  781  pct_CCR_RD_08_ELS_PC                     float64
#  782  pct_CCR_RD_08_FCS_PC                     float64
#  783  pct_CCR_RD_08_FEM_PC                     float64
#  784  pct_CCR_RD_08_HI7_PC                     float64
#  785  pct_CCR_RD_08_HMS_PC                     float64
#  786  pct_CCR_RD_08_MALE_PC                    float64
#  787  pct_CCR_RD_08_MIG_PC                     float64
#  788  pct_CCR_RD_08_MIL_PC                     float64
#  789  pct_CCR_RD_08_MU7_PC                     float64
#  790  pct_CCR_RD_08_SWD_PC                     float64
#  791  pct_CCR_RD_08_WH7_PC                     float64
#  792  pct_CCR_RD_ALL_AIG_PC                    float64
#  793  pct_CCR_RD_ALL_ALL_PC                    float64
#  794  pct_CCR_RD_ALL_AM7_PC                    float64
#  795  pct_CCR_RD_ALL_AS7_PC                    float64
#  796  pct_CCR_RD_ALL_BL7_PC                    float64
#  797  pct_CCR_RD_ALL_EDS_PC                    float64
#  798  pct_CCR_RD_ALL_ELS_PC                    float64
#  799  pct_CCR_RD_ALL_FCS_PC                    float64
#  800  pct_CCR_RD_ALL_FEM_PC                    float64
#  801  pct_CCR_RD_ALL_HI7_PC                    float64
#  802  pct_CCR_RD_ALL_HMS_PC                    float64
#  803  pct_CCR_RD_ALL_MALE_PC                   float64
#  804  pct_CCR_RD_ALL_MIG_PC                    float64
#  805  pct_CCR_RD_ALL_MIL_PC                    float64
#  806  pct_CCR_RD_ALL_MU7_PC                    float64
#  807  pct_CCR_RD_ALL_SWD_PC                    float64
#  808  pct_CCR_RD_ALL_WH7_PC                    float64
#  809  pct_CCR_SC_05_AIG_PC                     float64
#  810  pct_CCR_SC_05_ALL_PC                     float64
#  811  pct_CCR_SC_05_AM7_PC                     float64
#  812  pct_CCR_SC_05_AS7_PC                     float64
#  813  pct_CCR_SC_05_BL7_PC                     float64
#  814  pct_CCR_SC_05_EDS_PC                     float64
#  815  pct_CCR_SC_05_ELS_PC                     float64
#  816  pct_CCR_SC_05_FCS_PC                     float64
#  817  pct_CCR_SC_05_FEM_PC                     float64
#  818  pct_CCR_SC_05_HI7_PC                     float64
#  819  pct_CCR_SC_05_HMS_PC                     float64
#  820  pct_CCR_SC_05_MALE_PC                    float64
#  821  pct_CCR_SC_05_MIG_PC                     float64
#  822  pct_CCR_SC_05_MIL_PC                     float64
#  823  pct_CCR_SC_05_MU7_PC                     float64
#  824  pct_CCR_SC_05_SWD_PC                     float64
#  825  pct_CCR_SC_05_WH7_PC                     float64
#  826  pct_CCR_SC_08_AIG_PC                     float64
#  827  pct_CCR_SC_08_ALL_PC                     float64
#  828  pct_CCR_SC_08_AM7_PC                     float64
#  829  pct_CCR_SC_08_AS7_PC                     float64
#  830  pct_CCR_SC_08_BL7_PC                     float64
#  831  pct_CCR_SC_08_EDS_PC                     float64
#  832  pct_CCR_SC_08_ELS_PC                     float64
#  833  pct_CCR_SC_08_FCS_PC                     float64
#  834  pct_CCR_SC_08_FEM_PC                     float64
#  835  pct_CCR_SC_08_HI7_PC                     float64
#  836  pct_CCR_SC_08_HMS_PC                     float64
#  837  pct_CCR_SC_08_MALE_PC                    float64
#  838  pct_CCR_SC_08_MIG_PC                     float64
#  839  pct_CCR_SC_08_MIL_PC                     float64
#  840  pct_CCR_SC_08_MU7_PC                     float64
#  841  pct_CCR_SC_08_SWD_PC                     float64
#  842  pct_CCR_SC_08_WH7_PC                     float64
#  843  pct_CCR_SC_ALL_AIG_PC                    float64
#  844  pct_CCR_SC_ALL_ALL_PC                    float64
#  845  pct_CCR_SC_ALL_AM7_PC                    float64
#  846  pct_CCR_SC_ALL_AS7_PC                    float64
#  847  pct_CCR_SC_ALL_BL7_PC                    float64
#  848  pct_CCR_SC_ALL_EDS_PC                    float64
#  849  pct_CCR_SC_ALL_ELS_PC                    float64
#  850  pct_CCR_SC_ALL_FCS_PC                    float64
#  851  pct_CCR_SC_ALL_FEM_PC                    float64
#  852  pct_CCR_SC_ALL_HI7_PC                    float64
#  853  pct_CCR_SC_ALL_HMS_PC                    float64
#  854  pct_CCR_SC_ALL_MALE_PC                   float64
#  855  pct_CCR_SC_ALL_MIG_PC                    float64
#  856  pct_CCR_SC_ALL_MIL_PC                    float64
#  857  pct_CCR_SC_ALL_MU7_PC                    float64
#  858  pct_CCR_SC_ALL_SWD_PC                    float64
#  859  pct_CCR_SC_ALL_WH7_PC                    float64
#  860  pct_GLP_BI_EOC_AIG_PC                    float64
#  861  pct_GLP_BI_EOC_ALL_PC                    float64
#  862  pct_GLP_BI_EOC_AM7_PC                    float64
#  863  pct_GLP_BI_EOC_AS7_PC                    float64
#  864  pct_GLP_BI_EOC_BL7_PC                    float64
#  865  pct_GLP_BI_EOC_EDS_PC                    float64
#  866  pct_GLP_BI_EOC_ELS_PC                    float64
#  867  pct_GLP_BI_EOC_FCS_PC                    float64
# ...
#  4180 year_T_BL7_COURSES2                      float64
#  4181 year_T_ELS_COURSES2                      float64
#  4182 year_T_FEM_COURSES2                      float64
#  4183 year_T_HI7_COURSES2                      float64
#  4184 year_T_MALE_COURSES2                     float64
#  4185 year_T_MU7_COURSES2                      float64
#  4186 year_T_Other_COURSES2                    float64
#  4187 year_T_PI7_COURSES2                      float64
#  4188 year_T_SWD_COURSES2                      float64
#  4189 year_T_WH7_COURSES2                      float64
#  4190 num_concentrators_AAVC                   float64
#  4191 num_concentrators_AGNR                   float64
#  4192 num_concentrators_ARCH                   float64
#  4193 num_concentrators_BMA                    float64
#  4194 num_concentrators_EDUC                   float64
#  4195 num_concentrators_FINA                   float64
#  4196 num_concentrators_HLTH                   float64
#  4197 num_concentrators_HOSP                   float64
#  4198 num_concentrators_HUMA                   float64
#  4199 num_concentrators_INFO                   float64
#  4200 num_concentrators_LAW                    float64
#  4201 num_concentrators_MANU                   float64
#  4202 num_concentrators_MRKT                   float64
#  4203 num_concentrators_STEM                   float64
#  4204 num_concentrators_TRAN                   float64
#  4205 num_credentials                          float64
#  4206 num_enrollments                          float64
#  4207 cred_earned_pct                          float64
#  4208 career_only                              float64
#  4209 career_college_college_unc               float64
#  4210 college_college_unc_only                 float64
#  4211 college_only                             float64
#  4212 stu_enroll                               float64
#  4213 cte_enroll                               float64
#  4214 cte_enrollment_pct                       float64
#  4215 digital_media                            object
#  4216 device_access                            object
#  4217 device_access_grades                     object
#  4218 device_home                              object
#  4219 device_home_grades                       object
#  4220 BYOD                                     object
#  4221 byod_grades                              object
#  4222 Book_TitlesPer_Student                   float64
#  4223 wap                                      float64
#  4224 wap_class                                float64
#  4225 media_school                             float64
#  4226 devices                                  float64
#  4227 pct_rating_P1_Accomplished               float64
#  4228 pct_rating_P1_Developing                 float64
#  4229 pct_rating_P1_Distinguished              float64
#  4230 pct_rating_P1_NotDemostrated             float64
#  4231 pct_rating_P1_Proficient                 float64
#  4232 pct_rating_P2_Accomplished               float64
#  4233 pct_rating_P2_Developing                 float64
#  4234 pct_rating_P2_Distinguished              float64
#  4235 pct_rating_P2_NotDemostrated             float64
#  4236 pct_rating_P2_Proficient                 float64
#  4237 pct_rating_P3_Accomplished               float64
#  4238 pct_rating_P3_Developing                 float64
#  4239 pct_rating_P3_Distinguished              float64
#  4240 pct_rating_P3_NotDemostrated             float64
#  4241 pct_rating_P3_Proficient                 float64
#  4242 pct_rating_P4_Accomplished               float64
#  4243 pct_rating_P4_Developing                 float64
#  4244 pct_rating_P4_Distinguished              float64
#  4245 pct_rating_P4_NotDemostrated             float64
#  4246 pct_rating_P4_Proficient                 float64
#  4247 pct_rating_P5_Accomplished               float64
#  4248 pct_rating_P5_Developing                 float64
#  4249 pct_rating_P5_Distinguished              float64
#  4250 pct_rating_P5_NotDemostrated             float64
#  4251 pct_rating_P5_Proficient                 float64
#  4252 pct_rating_P6_Accomplished               float64
#  4253 pct_rating_P6_Developing                 float64
#  4254 pct_rating_P6_Distinguished              float64
#  4255 pct_rating_P6_NotDemostrated             float64
#  4256 pct_rating_P6_Proficient                 float64
#  4257 pct_rating_P7_Accomplished               float64
#  4258 pct_rating_P7_Developing                 float64
#  4259 pct_rating_P7_Distinguished              float64
#  4260 pct_rating_P7_NotDemostrated             float64
#  4261 pct_rating_P7_Proficient                 float64
#  4262 pct_rating_PS_DoesNotMeetExpectedGrowth  float64
#  4263 pct_rating_PS_ExceedsExpectedGrowth      float64
#  4264 pct_rating_PS_MeetsExpectedGrowth        float64
#  4265 pct_rating_T1_Accomplished               float64
#  4266 pct_rating_T1_Developing                 float64
#  4267 pct_rating_T1_Distinguished              float64
#  4268 pct_rating_T1_NotDemostrated             float64
#  4269 pct_rating_T1_Proficient                 float64
#  4270 pct_rating_T2_Accomplished               float64
#  4271 pct_rating_T2_Developing                 float64
#  4272 pct_rating_T2_Distinguished              float64
#  4273 pct_rating_T2_NotDemostrated             float64
#  4274 pct_rating_T2_Proficient                 float64
#  4275 pct_rating_T3_Accomplished               float64
#  4276 pct_rating_T3_Developing                 float64
#  4277 pct_rating_T3_Distinguished              float64
#  4278 pct_rating_T3_NotDemostrated             float64
#  4279 pct_rating_T3_Proficient                 float64
#  4280 pct_rating_T4_Accomplished               float64
#  4281 pct_rating_T4_Developing                 float64
#  4282 pct_rating_T4_Distinguished              float64
#  4283 pct_rating_T4_NotDemostrated             float64
#  4284 pct_rating_T4_Proficient                 float64
#  4285 pct_rating_T5_Accomplished               float64
#  4286 pct_rating_T5_Developing                 float64
#  4287 pct_rating_T5_Distinguished              float64
#  4288 pct_rating_T5_NotDemostrated             float64
#  4289 pct_rating_T5_Proficient                 float64
#  4290 pct_rating_TS_DoesNotMeetExpectedGrowth  float64
#  4291 pct_rating_TS_ExceedsExpectedGrowth      float64
#  4292 pct_rating_TS_MeetsExpectedGrowth        float64
#  4293 avg_class_teach_TeacherExp               float64
#  4294 pct_adv_degree_PrincipalExp              float64
#  4295 pct_adv_degree_TeacherExp                float64
#  4296 pct_experience_0_PrincipalExp            float64
#  4297 pct_experience_0_TeacherExp              float64
#  4298 pct_experience_10_PrincipalExp           float64
#  4299 pct_experience_10_TeacherExp             float64
#  4300 pct_experience_4_PrincipalExp            float64
#  4301 pct_experience_4_TeacherExp              float64
#  4302 pct_turnover_PrincipalExp                float64
#  4303 pct_turnover_TeacherExp                  float64
#  4304 total_class_teach_TeacherExp             float64
#  4305 pct_ib_pass                              float64
#  4306 pct_ib_participation                     float64
#  4307 amount_ Transformation_Improve_Amt       float64
#  4308 amount_ Turnaround_Improve_Amt           float64
#  4309 amount_ Whole School Reform_Improve_Amt  float64
#  4310 arre_per1000_ALL                         float64
#  4311 arre_per1000_AM7                         float64
#  4312 arre_per1000_AS7                         float64
#  4313 arre_per1000_BL7                         float64
#  4314 arre_per1000_EDS                         float64
#  4315 arre_per1000_ELS                         float64
#  4316 arre_per1000_FEM                         float64
#  4317 arre_per1000_HI7                         float64
#  4318 arre_per1000_MALE                        float64
#  4319 arre_per1000_MU7                         float64
#  4320 arre_per1000_PI7                         float64
#  4321 arre_per1000_SWD                         float64
#  4322 arre_per1000_WH7                         float64
#  4323 blhr_per1000_ALL                         float64
#  4324 blhr_per1000_AM7                         float64
#  4325 blhr_per1000_AS7                         float64
#  4326 blhr_per1000_BL7                         float64
#  4327 blhr_per1000_EDS                         float64
#  4328 blhr_per1000_ELS                         float64
#  4329 blhr_per1000_FEM                         float64
#  4330 blhr_per1000_HI7                         float64
#  4331 blhr_per1000_MALE                        float64
#  4332 blhr_per1000_MU7                         float64
#  4333 blhr_per1000_PI7                         float64
#  4334 blhr_per1000_SWD                         float64
#  4335 blhr_per1000_WH7                         float64
#  4336 crime_per1000_ALL                        float64
#  4337 crime_per1000_AM7                        float64
#  4338 crime_per1000_AS7                        float64
#  4339 crime_per1000_BL7                        float64
#  4340 crime_per1000_EDS                        float64
#  4341 crime_per1000_ELS                        float64
#  4342 crime_per1000_FEM                        float64
#  4343 crime_per1000_HI7                        float64
#  4344 crime_per1000_MALE                       float64
#  4345 crime_per1000_MU7                        float64
#  4346 crime_per1000_PI7                        float64
#  4347 crime_per1000_SWD                        float64
#  4348 crime_per1000_WH7                        float64
#  4349 exp_per1000_ALL                          float64
#  4350 exp_per1000_AM7                          float64
#  4351 exp_per1000_AS7                          float64
#  4352 exp_per1000_BL7                          float64
#  4353 exp_per1000_EDS                          float64
#  4354 exp_per1000_ELS                          float64
#  4355 exp_per1000_FEM                          float64
#  4356 exp_per1000_HI7                          float64
#  4357 exp_per1000_MALE                         float64
#  4358 exp_per1000_MU7                          float64
#  4359 exp_per1000_PI7                          float64
#  4360 exp_per1000_SWD                          float64
#  4361 exp_per1000_WH7                          float64
#  4362 iss_per1000_ALL                          float64
#  4363 iss_per1000_AM7                          float64
#  4364 iss_per1000_AS7                          float64
#  4365 iss_per1000_BL7                          float64
#  4366 iss_per1000_EDS                          float64
#  4367 iss_per1000_ELS                          float64
#  4368 iss_per1000_FEM                          float64
#  4369 iss_per1000_HI7                          float64
#  4370 iss_per1000_MALE                         float64
#  4371 iss_per1000_MU7                          float64
#  4372 iss_per1000_PI7                          float64
#  4373 iss_per1000_SWD                          float64
#  4374 iss_per1000_WH7                          float64
#  4375 lts_per1000_ALL                          float64
#  4376 lts_per1000_AM7                          float64
#  4377 lts_per1000_AS7                          float64
#  4378 lts_per1000_BL7                          float64
#  4379 lts_per1000_EDS                          float64
#  4380 lts_per1000_ELS                          float64
#  4381 lts_per1000_FEM                          float64
#  4382 lts_per1000_HI7                          float64
#  4383 lts_per1000_MALE                         float64
#  4384 lts_per1000_MU7                          float64
#  4385 lts_per1000_PI7                          float64
#  4386 lts_per1000_SWD                          float64
#  4387 lts_per1000_WH7                          float64
#  4388 rplw_per1000_ALL                         float64
#  4389 rplw_per1000_AM7                         float64
#  4390 rplw_per1000_AS7                         float64
#  4391 rplw_per1000_BL7                         float64
#  4392 rplw_per1000_EDS                         float64
#  4393 rplw_per1000_ELS                         float64
#  4394 rplw_per1000_FEM                         float64
#  4395 rplw_per1000_HI7                         float64
#  4396 rplw_per1000_MALE                        float64
#  4397 rplw_per1000_MU7                         float64
#  4398 rplw_per1000_PI7                         float64
#  4399 rplw_per1000_SWD                         float64
#  4400 rplw_per1000_WH7                         float64
#  4401 sts_per1000_ALL                          float64
#  4402 sts_per1000_AM7                          float64
#  4403 sts_per1000_AS7                          float64
#  4404 sts_per1000_BL7                          float64
#  4405 sts_per1000_EDS                          float64
#  4406 sts_per1000_ELS                          float64
#  4407 sts_per1000_FEM                          float64
#  4408 sts_per1000_HI7                          float64
#  4409 sts_per1000_MALE                         float64
#  4410 sts_per1000_MU7                          float64
#  4411 sts_per1000_PI7                          float64
#  4412 sts_per1000_SWD                          float64
#  4413 sts_per1000_WH7                          float64
#  4414 pct_fully_licensed                       float64
#  4415 pct_lateral_entry                        float64
#  4416 nbpts_num                                float64
#  4417 count_ALL_PK_ENROLL                      float64
#  4418 count_AM7_PK_ENROLL                      float64
#  4419 count_AS7_PK_ENROLL                      float64
#  4420 count_BL7_PK_ENROLL                      float64
#  4421 count_ELS_PK_ENROLL                      float64
#  4422 count_FEM_PK_ENROLL                      float64
#  4423 count_HI7_PK_ENROLL                      float64
#  4424 count_MALE_PK_ENROLL                     float64
#  4425 count_MU7_PK_ENROLL                      float64
#  4426 count_PI7_PK_ENROLL                      float64
#  4427 count_SWD_PK_ENROLL                      float64
#  4428 count_WH7_PK_ENROLL                      float64
#  4429 pct_ALL_PK_ENROLL                        float64
#  4430 pct_AM7_PK_ENROLL                        float64
#  4431 pct_AS7_PK_ENROLL                        float64
#  4432 pct_BL7_PK_ENROLL                        float64
#  4433 pct_ELS_PK_ENROLL                        float64
#  4434 pct_FEM_PK_ENROLL                        float64
#  4435 pct_HI7_PK_ENROLL                        float64
#  4436 pct_MALE_PK_ENROLL                       float64
#  4437 pct_MU7_PK_ENROLL                        float64
#  4438 pct_PI7_PK_ENROLL                        float64
#  4439 pct_SWD_PK_ENROLL                        float64
#  4440 pct_WH7_PK_ENROLL                        float64
#  4441 pct_ready_kea                            float64
#  4442 avg_size_00_SAR                          float64
#  4443 avg_size_01_SAR                          float64
#  4444 avg_size_02_SAR                          float64
#  4445 avg_size_03_SAR                          float64
#  4446 avg_size_04_SAR                          float64
#  4447 avg_size_05_SAR                          float64
#  4448 avg_size_06_SAR                          float64
#  4449 avg_size_07_SAR                          float64
#  4450 avg_size_08_SAR                          float64
#  4451 avg_size_Biology_SAR                     float64
#  4452 avg_size_English II_SAR                  float64
#  4453 avg_size_Math I_SAR                      float64
#  4454 avg_sat_score                            float64
#  4455 pct_sat_participation                    float64
#  4456 welcome_url                              object
#  4457 agency_lea_code                          object
#  4458 lea_total_expense                        float64
#  4459 lea_pct_salary                           float64
#  4460 lea_pct_benefits                         float64
#  4461 lea_pct_services                         float64
#  4462 lea_pct_supplies                         float64
#  4463 lea_pct_instruct_equip                   float64
#  4464 lea_pct_building                         float64
#  4465 lea_pct_other                            float64
#  4466 lea_local_perpupil                       float64
#  4467 lea_state_perpupil                       float64
#  4468 lea_federal_perpupil                     float64
# dtypes: float64(4417), object(52)
# memory usage: 90.1+ MB
