# %% [markdown]
# # Create Public School Machine Learning Datasets
# ** This program creates all the _ML datasets in the NCEA repository.**
# * This notebook reads each School Dataset file located at \EducationDataNC\ *schoolYear* \School Datasets\ as input data.
# * Different school years are processed by changing the *schoolYear* parameter.
# * Different input / output files are processed / created by changing the *inputFileName* paramter in the cell below.
# * While a single program is used to create all the _ML datasets, one program copy per dataset is maintained in the repositiory so the dataset specific tranformation reports may be reviewed.
#
# **Datasets ending in ML are preprocessed for Machine Learning and go through the following transformations: **
# 1. Missing student body racial compositions are imputed using district averages.
# 2. Columns that have the same value in every single row are deleted.
# 3. Columns that have a unique value in every single row (all values are different) are deleted.
# 4. Empty columns (all values are NA or NULL) are deleted.
# 5. Numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# 6. Remaining numeric, non-race columns with missing values are imputed / populated with 0.  In many cases, schools are not reporting values when they are zero. However, mean imputation or some other more sophisticated strategy might be considered here.
# 7. Categorical / text based columns with > *uniqueThreshold* unique values are deleted.
# 8. All remaining categorical / text based columns are one-hot encoded.  In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# 9. Duplicated or highly similar columns with > 95% correlation are delelted.

# %%
#import required Libraries
import pandas as pd
import numpy as np
import os
import string

#**********************************************************************************
# Set the following variables before running this code!!!
#**********************************************************************************
#All raw data files are processed for the year below
schoolYear = 2018
rootDir = 'D:/BenepactLLC/Belk/NC_Report_Card_Data/2020/June 2020/'

#Location where copies of the raw data files will be read in from csv files.
dataDir = rootDir + str(schoolYear) + '/School Datasets/'

#Name of the file to be processed
#inputFileName = 'PublicSchools2018'
#inputFileName = 'PublicHighSchools2018'
#inputFileName = 'PublicMiddleSchools2018'
inputFileName = 'PublicElementarySchools2018'

#Input file being transformed for machine learning 
inputFile = dataDir + inputFileName + '.csv'

#Location where the new school datasets will be created.
outputDir = rootDir + str(schoolYear) + '/Machine Learning Datasets/'

#Missing Data Threshold (Per Column)
missingThreshold = 0.60

#Unique Value Threshold (Per Column)
#Delete Columns >  uniqueThreshold unique values prior to one-hot encoding. 
#(each unique value becomes a new column during one-hot encoding)
uniqueThreshold = 200

#Read in the School Data File
schoolData = pd.read_csv(inputFile, low_memory=False, dtype={'agency_code': object})
print('*********Start: Beginning Column and Row Counts********************************************')
schoolData.info(verbose=False)

#Select only public schools as charter schools are missing data for many columns.
schoolData = schoolData[(schoolData['designation_type'] == 'P') & (schoolData['avg_student_num'] > 0)]

print('\r\n*********After: Selecting Only Public School Campuses**********************************')
schoolData.info(verbose=False)

#Save primary key
agency_code = schoolData['agency_code']
#Convert zip code to string
schoolData['zip'] = schoolData['zip'].astype('object')
# Out:
# *********Start: Beginning Column and Row Counts********************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1575 entries, 0 to 1574
# Columns: 4469 entries, agency_code to lea_federal_perpupil
# dtypes: float64(4417), object(52)
# memory usage: 53.7+ MB
#
# *********After: Selecting Only Public School Campuses**********************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1422 entries, 2 to 1574
# Columns: 4469 entries, agency_code to lea_federal_perpupil
# dtypes: float64(4417), object(52)
# memory usage: 48.5+ MB

# %% [markdown]
# # Prepare Consolidated Dataset for Machine Learning
# **Below we perform operations on the entire dataset to remove columns and update row values that could cause problems during machine learning.**

# %% [markdown]
# ## Student Body Racial Composition Features
# **Impute / update missing Student Body Racial Composition Fields using mean imputation.**
# * When there are no racial composition percentages for a particular school campus / agency_code, fill in the missing values

# %%
#Get Student Body Racial Composition Fields
raceCompositionFields = schoolData.filter(regex='Indian|Asian|Hispanic|Black|White|PacificIsland|TwoOrMore|Minority')\
                                  .filter(regex='Pct').columns
    
rowsBefore = schoolData[raceCompositionFields].isnull().T.any().T.sum()

#Update missing race values with the district average when avaiable (No district averages for charter schools) 
schoolData[raceCompositionFields] = schoolData.groupby('lea_code')[raceCompositionFields]\
                                              .transform(lambda x: x.fillna(x.mean()))

    #Review dataset contents after Racial Composition Imputation
print('*********After: Updating Missing Racial Compostion Values****************************')   
rowsAfter = schoolData[raceCompositionFields].isnull().T.any().T.sum()
rowsUpdated = rowsBefore - rowsAfter
print('Rows Updated / Imputed: ', rowsUpdated) 
print('\r\nTotal Rows Missing Racial Compositions By District Code') 
schoolData['lea_code'][schoolData[raceCompositionFields].isnull().T.any().T].value_counts()
# Out:
# *********After: Updating Missing Racial Compostion Values****************************
# Rows Updated / Imputed:  0
#
# Total Rows Missing Racial Compositions By District Code
# Series([], Name: lea_code, dtype: int64)

# %% [markdown]
# ## Remove Columns with Problematic Data
# **Here we remove entire columns that could cause problems during machine learning.  The following operations are performed:**
# * Remove any columns that have the same value in every single row.
# * Remove any columns that have a unique value in every single row (all values are different).
# * Remove empty columns (all values are NA or NULL).

# %%
#Remove any fields that have the same value in all rows
UniqueValueCounts = schoolData.nunique(dropna=False)
SingleValueCols = UniqueValueCounts[UniqueValueCounts == 1].index
schoolData = schoolData.drop(SingleValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with the same value in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(SingleValueCols))
# Out:
# *********After: Removing columns with the same value in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1422 entries, 2 to 1574
# Columns: 3612 entries, agency_code to lea_federal_perpupil
# dtypes: float64(3564), object(48)
# memory usage: 39.2+ MB
#
# Columns Deleted:  857

# %%
#Remove any fields that have unique values in every row
schoolDataRecordCt = schoolData.shape[0]
UniqueValueCounts = schoolData.apply(pd.Series.nunique)
AllUniqueValueCols = UniqueValueCounts[UniqueValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(AllUniqueValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with unique values in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(AllUniqueValueCols))
# Out:
# *********After: Removing columns with unique values in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1422 entries, 2 to 1574
# Columns: 3610 entries, category_code to lea_federal_perpupil
# dtypes: float64(3564), object(46)
# memory usage: 39.2+ MB
#
# Columns Deleted:  2

# %%
#Remove any empty fields (null values in every row)
schoolDataRecordCt = schoolData.shape[0]
NullValueCounts = schoolData.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with null / blank values in every row.*************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with null / blank values in every row.*************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1422 entries, 2 to 1574
# Columns: 3610 entries, category_code to lea_federal_perpupil
# dtypes: float64(3564), object(46)
# memory usage: 39.2+ MB
#
# Columns Deleted:  0

# %% [markdown]
# ## Handle Other Missing Values Types
# * Here we eliminate any numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# * All remaining non-race, numeric column missing values are populated with 0.
# * In many cases, it seems that schools are not simply not reporting values when they are zero. However, mean imputation or some other strategy might be considered.

# %%
#Isolate continuous and categorical data types
#These are indexers into the schoolData dataframe and may be used similar to the schoolData dataframe 
sD_boolean = schoolData.loc[:, (schoolData.dtypes == bool) ]
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]
sD_continuous = schoolData.loc[:, (schoolData.dtypes != bool) & (schoolData.dtypes != object)]
print ("Boolean Columns: ", sD_boolean.shape[1])
print ("Nominal Columns: ", sD_nominal.shape[1])
print ("Continuous Columns: ", sD_continuous.shape[1])
print ("Columns Accounted for: ", sD_nominal.shape[1] + sD_continuous.shape[1] + sD_boolean.shape[1])
# Out:
# Boolean Columns:  0
# Nominal Columns:  46
# Continuous Columns:  3564
# Columns Accounted for:  3610

# %%
#Eliminate continuous columns with more than missingThreshold percentage of missing values
schoolDataRecordCt = sD_continuous.shape[0]
missingValueLimit = schoolDataRecordCt * missingThreshold
NullValueCounts = sD_continuous.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts >= missingValueLimit].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with >= missingThreshold % of missing values******')
schoolData.info(verbose=False)
print('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with >= missingThreshold % of missing values******
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1422 entries, 2 to 1574
# Columns: 1172 entries, category_code to lea_federal_perpupil
# dtypes: float64(1126), object(46)
# memory usage: 12.7+ MB
#
# Columns Deleted:  2438

# %% [markdown]
# ## One-Hot Encoding of Categorical Variables
# **All categorical / string variables are converted to numberic variables via one hot encoding.  Each unique row value will become a new binary / numeric column in the dataset.**
# * All remaining categorical columns are one-hot encoded.
# * In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# * Prior to one-hot encoding, columns with > *uniqueThreshold* unique values are deleted.

# %%
#Delete categorical columns with > uniqueThreshold unique values 
#(Each unique value becomes a column during one-hot encoding)
oneHotUniqueValueCounts = schoolData[sD_nominal.columns].apply(lambda x: x.nunique())
oneHotUniqueValueCols = oneHotUniqueValueCounts[oneHotUniqueValueCounts >= uniqueThreshold].index
schoolData.drop(oneHotUniqueValueCols, axis=1, inplace=True) 

#Remove categorical columns which do not add value to machine learning
#Grades columns dropped since they all have indicator fields (device_access, device_home, BYOD)
#with less unique values to one-hot encode
schoolData.drop(['welcome_url','device_access_grades',
                 'device_home_grades','byod_grades'], axis=1, inplace=True) 

#Review dataset contents one hot high unique value drops
print('*********After: Removing columns with >= uniqueThreshold unique values***********')
schoolData.info(verbose=False)
print('\r\nColumns Deleted: ', len(oneHotUniqueValueCols))
print(oneHotUniqueValueCols)
print('Dropped Manually: welcome_url,device_access_grades,device_home_grades,byod_grades')
# Out:
# *********After: Removing columns with >= uniqueThreshold unique values***********
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1422 entries, 2 to 1574
# Columns: 1155 entries, category_code to lea_federal_perpupil
# dtypes: float64(1126), object(29)
# memory usage: 12.5+ MB
#
# Columns Deleted:  13
# Index(['street_addr', 'city', 'zip', 'phone', 'url', 'school_name',
#        'school_name_attendance', 'ada_ct_2017_attendance',
#        'adm_ct_2017_attendance', 'ada_ct_2018_attendance',
#        'adm_ct_2018_attendance', 'ada_ct_2019_attendance',
#        'adm_ct_2019_attendance'],
#       dtype='object')
# Dropped Manually: welcome_url,device_access_grades,device_home_grades,byod_grades

# %%
#Isolate remaining categorical variables
begColumnCt = len(schoolData.columns)
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]

#one hot encode categorical variables
schoolData = pd.get_dummies(data=schoolData, 
                       columns=sD_nominal.columns, drop_first=True)

#Determine change in column count
endColumnCt = len(schoolData.columns)
columnsAdded = endColumnCt - begColumnCt

#Review dataset contents one hot high unique value drops
print('Columns To One-Hot Encode: ', len(sD_nominal.columns))
print('\r\n*********After: Adding New Columns Via One-Hot Encoding*************************')
schoolData.info(verbose=False)
print('\r\nNew Columns Created Via One-Hot Encoding: ', columnsAdded)
# Out:
# Columns To One-Hot Encode:  29
#
# *********After: Adding New Columns Via One-Hot Encoding*************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1422 entries, 2 to 1574
# Columns: 1880 entries, lea to agency_lea_code_995LEA
# dtypes: float64(1126), uint8(754)
# memory usage: 13.2 MB
#
# New Columns Created Via One-Hot Encoding:  725

# %%
#Remove any fields that have the same value in all rows after one-hot encoding
UniqueValueCounts = schoolData.nunique(dropna=False)
SingleValueCols = UniqueValueCounts[UniqueValueCounts == 1].index
schoolData = schoolData.drop(SingleValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing one-hot encoded columns with the same value in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(SingleValueCols))
# Out:
# *********After: Removing one-hot encoded columns with the same value in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1422 entries, 2 to 1574
# Columns: 1880 entries, lea to agency_lea_code_995LEA
# dtypes: float64(1126), uint8(754)
# memory usage: 13.2 MB
#
# Columns Deleted:  0

# %% [markdown]
# ## Impute any Remaining Missing Values as Zero

# %%
#Print out all the missing value rows
pd.set_option('display.max_rows', 1000)

print('\r\n*********The Remaining Missing Values Below will be set to Zero!*************************')

#Check for Missing values 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# *********The Remaining Missing Values Below will be set to Zero!*************************
#                                 Variable Name  Number Missing Values
# 28              ada_adm_ratio_2018_attendance                      8
# 30              ada_adm_ratio_2019_attendance                     15
# 31    ada_adm_ratio_2017_thru_2019_attendance                     23
# 32     ada_adm_rank_2017_thru_2019_attendance                     23
# 33                                    pct_eds                      1
# ...                                       ...                    ...
# 1112                          avg_size_01_SAR                    250
# 1113                          avg_size_02_SAR                    254
# 1114                          avg_size_03_SAR                    254
# 1115                          avg_size_04_SAR                    202
# 1116                          avg_size_05_SAR                    254
#
# [1072 rows x 2 columns]

# %%
#Replace all remaining NaN with 0
schoolData = schoolData.fillna(0)

#Check for Missing values after final imputation 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# Empty DataFrame
# Columns: [Variable Name, Number Missing Values]
# Index: []

# %% [markdown]
# ## Identify and Remove Highly Correlated Features
# **Find and remove any columns / features that are > 95% correlated**
# * https://stackoverflow.com/questions/39409866/correlation-heatmap
# * https://chrisalbon.com/machine_learning/feature_selection/drop_highly_correlated_features/
# * https://codeyarns.com/2015/04/20/how-to-change-font-size-in-seaborn/

# %%
# calculate the correlation matrix
corr_matrix  = schoolData.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
#Get all of the correlation values > 95%
x = np.where(upper > 0.95)

#Display all field combinations with > 95% correlation
cf = pd.DataFrame()
cf['Field1'] = upper.columns[x[1]]
cf['Field2'] = upper.index[x[0]]

#Get the correlation values for every field combination. (There must be a more pythonic way to do this!)
corr = [0] * len(cf)
for i in range(0, len(cf)):
    corr[i] =  upper[cf['Field1'][i]][cf['Field2'][i]] 
    
cf['Correlation'] = corr

print ('There are ', str(len(cf['Field1'])), ' field correlations > 95%.')
cf
# Out:
# There are  1675  field correlations > 95%.
#                       Field1  \
# 0          lea_no_attendance
# 1       school_no_attendance
# 2            indian_male_pct
# 3          indian_female_pct
# 4             asian_male_pct
# ...                      ...
# 1670  agency_lea_code_970LEA
# 1671  agency_lea_code_980LEA
# 1672  agency_lea_code_340LEA
# 1673  agency_lea_code_990LEA
# 1674  agency_lea_code_995LEA
#
#                                                  Field2  Correlation
# 0                                                   lea     1.000000
# 1                                                school     1.000000
# 2                                            indian_pct     0.996935
# 3                                            indian_pct     0.996759
# 4                                             asian_pct     0.990799
# ...                                                 ...          ...
# 1670          lea_name_attendance_Wilkes County Schools     1.000000
# 1671          lea_name_attendance_Wilson County Schools     1.000000
# 1672  lea_name_attendance_Winston Salem/Forsyth Coun...     1.000000
# 1673          lea_name_attendance_Yadkin County Schools     1.000000
# 1674          lea_name_attendance_Yancey County Schools     1.000000
#
# [1675 rows x 3 columns]

# %%
#The old way
#print('Dropping the following ', str(len(to_drop)), ' highly correlated fields.')
#to_drop

# Comparing highly correlated unique field names in field 1 vs field 2 list above will allow you to 
# remove the least amount of fields possible.  
#len(cf['Field1'].unique())
#len(cf['Field2'].unique())

print('Dropping the following ', str(len(cf['Field2'].unique())), ' highly correlated, unique fields.')
cf['Field2'].unique()
# Out:
# Dropping the following  748  highly correlated, unique fields.
# array(['lea', 'school', 'indian_pct', 'asian_pct', 'hispanic_pct',
#        'black_pct', 'white_pct', 'minority_pct', 'indian_male_pct',
#        'asian_male_pct', 'white_male_pct', 'minority_male_pct',
#        'ada_adm_ratio_2018.1_attendance', 'pct_ALL_ELP',
#        'pct_met_Math Grades 3-8_PART', 'pct_met_Reading Grades 3-8_PART',
#        'pct_met_Science Grades 5&8_PART', 'pct_met_Total Targets_PART',
#        'pct_Math Grades 3-8_ALL_PART_DET',
#        'pct_Math Grades 3-8_BL7_PART_DET',
#        'pct_Math Grades 3-8_EDS_PART_DET',
#        'pct_Math Grades 3-8_HI7_PART_DET',
#        'pct_Math Grades 3-8_SWD_PART_DET',
#        'pct_Math Grades 3-8_WH7_PART_DET',
#        'pct_Science Grades 5&8_WH7_PART_DET', 'pct_CCR_EOG_03_ALL_PC',
#        'pct_CCR_EOG_03_BL7_PC', 'pct_CCR_EOG_03_EDS_PC',
#        'pct_CCR_EOG_03_ELS_PC', 'pct_CCR_EOG_03_FEM_PC',
#        'pct_CCR_EOG_03_HI7_PC', 'pct_CCR_EOG_03_MALE_PC',
#        'pct_CCR_EOG_03_WH7_PC', 'pct_CCR_EOG_04_AIG_PC',
#        'pct_CCR_EOG_04_ALL_PC', 'pct_CCR_EOG_04_BL7_PC',
#        'pct_CCR_EOG_04_EDS_PC', 'pct_CCR_EOG_04_ELS_PC',
#        'pct_CCR_EOG_04_FEM_PC', 'pct_CCR_EOG_04_HI7_PC',
#        'pct_CCR_EOG_04_MALE_PC', 'pct_CCR_EOG_04_WH7_PC',
#        'pct_CCR_EOG_05_AIG_PC', 'pct_CCR_EOG_05_ALL_PC',
#        'pct_CCR_EOG_05_BL7_PC', 'pct_CCR_EOG_05_EDS_PC',
#        'pct_CCR_EOG_05_ELS_PC', 'pct_CCR_EOG_05_FEM_PC',
#        'pct_CCR_EOG_05_HI7_PC', 'pct_CCR_EOG_05_MALE_PC',
#        'pct_CCR_EOG_05_MU7_PC', 'pct_CCR_EOG_05_WH7_PC',
#        'pct_CCR_EOG_ALL_AIG_PC', 'pct_CCR_EOG_ALL_ALL_PC',
#        'pct_CCR_EOG_ALL_BL7_PC', 'pct_CCR_EOG_ALL_EDS_PC',
#        'pct_CCR_EOG_ALL_ELS_PC', 'pct_CCR_EOG_ALL_FEM_PC',
#        'pct_CCR_EOG_ALL_HI7_PC', 'pct_CCR_EOG_ALL_MALE_PC',
#        'pct_CCR_EOG_ALL_MU7_PC', 'pct_CCR_EOG_ALL_SWD_PC',
#        'pct_CCR_EOG_ALL_WH7_PC', 'pct_CCR_MA_03_ALL_PC',
#        'pct_CCR_MA_03_BL7_PC', 'pct_CCR_MA_03_FEM_PC',
#        'pct_CCR_MA_03_HI7_PC', 'pct_CCR_MA_03_MALE_PC',
#        'pct_CCR_MA_03_WH7_PC', 'pct_CCR_MA_04_ALL_PC',
#        'pct_CCR_MA_04_BL7_PC', 'pct_CCR_MA_04_EDS_PC',
#        'pct_CCR_MA_04_FEM_PC', 'pct_CCR_MA_04_HI7_PC',
#        'pct_CCR_MA_04_MALE_PC', 'pct_CCR_MA_04_SWD_PC',
#        'pct_CCR_MA_04_WH7_PC', 'pct_CCR_MA_05_AIG_PC',
#        'pct_CCR_MA_05_ALL_PC', 'pct_CCR_MA_05_BL7_PC',
#        'pct_CCR_MA_05_EDS_PC', 'pct_CCR_MA_05_FEM_PC',
#        'pct_CCR_MA_05_HI7_PC', 'pct_CCR_MA_05_MALE_PC',
#        'pct_CCR_MA_05_WH7_PC', 'pct_CCR_MA_ALL_AIG_PC',
#        'pct_CCR_MA_ALL_ALL_PC', 'pct_CCR_MA_ALL_BL7_PC',
#        'pct_CCR_MA_ALL_EDS_PC', 'pct_CCR_MA_ALL_ELS_PC',
#        'pct_CCR_MA_ALL_FEM_PC', 'pct_CCR_MA_ALL_HI7_PC',
#        'pct_CCR_MA_ALL_MALE_PC', 'pct_CCR_MA_ALL_MU7_PC',
#        'pct_CCR_MA_ALL_WH7_PC', 'pct_CCR_RD_03_ALL_PC',
#        'pct_CCR_RD_03_BL7_PC', 'pct_CCR_RD_03_FEM_PC',
#        'pct_CCR_RD_03_HI7_PC', 'pct_CCR_RD_03_MALE_PC',
#        'pct_CCR_RD_03_WH7_PC', 'pct_CCR_RD_04_ALL_PC',
#        'pct_CCR_RD_04_BL7_PC', 'pct_CCR_RD_04_EDS_PC',
#        'pct_CCR_RD_04_FEM_PC', 'pct_CCR_RD_04_HI7_PC',
#        'pct_CCR_RD_04_MALE_PC', 'pct_CCR_RD_04_SWD_PC',
#        'pct_CCR_RD_04_WH7_PC', 'pct_CCR_RD_05_AIG_PC',
#        'pct_CCR_RD_05_ALL_PC', 'pct_CCR_RD_05_BL7_PC',
#        'pct_CCR_RD_05_EDS_PC', 'pct_CCR_RD_05_FEM_PC',
#        'pct_CCR_RD_05_HI7_PC', 'pct_CCR_RD_05_MALE_PC',
#        'pct_CCR_RD_05_WH7_PC', 'pct_CCR_RD_ALL_AIG_PC',
#        'pct_CCR_RD_ALL_ALL_PC', 'pct_CCR_RD_ALL_BL7_PC',
#        'pct_CCR_RD_ALL_EDS_PC', 'pct_CCR_RD_ALL_ELS_PC',
#        'pct_CCR_RD_ALL_FEM_PC', 'pct_CCR_RD_ALL_HI7_PC',
#        'pct_CCR_RD_ALL_MALE_PC', 'pct_CCR_RD_ALL_MU7_PC',
#        'pct_CCR_RD_ALL_WH7_PC', 'pct_CCR_SC_05_AIG_PC',
#        'pct_CCR_SC_05_ALL_PC', 'pct_CCR_SC_05_BL7_PC',
#        'pct_CCR_SC_05_EDS_PC', 'pct_CCR_SC_05_FEM_PC',
#        'pct_CCR_SC_05_HI7_PC', 'pct_CCR_SC_05_MALE_PC',
#        'pct_CCR_SC_05_SWD_PC', 'pct_CCR_SC_05_WH7_PC',
#        'pct_CCR_SC_ALL_AIG_PC', 'pct_CCR_SC_ALL_ALL_PC',
#        'pct_CCR_SC_ALL_BL7_PC', 'pct_CCR_SC_ALL_EDS_PC',
#        'pct_CCR_SC_ALL_FEM_PC', 'pct_CCR_SC_ALL_HI7_PC',
#        'pct_CCR_SC_ALL_MALE_PC', 'pct_CCR_SC_ALL_WH7_PC',
#        'pct_GLP_EOG_03_ALL_PC', 'pct_GLP_EOG_04_ALL_PC',
#        'pct_GLP_EOG_04_BL7_PC', 'pct_GLP_EOG_05_ALL_PC',
#        'pct_GLP_EOG_05_BL7_PC', 'pct_GLP_EOG_05_EDS_PC',
#        'pct_GLP_EOG_05_ELS_PC', 'pct_GLP_EOG_05_MALE_PC',
#        'pct_GLP_EOG_ALL_ALL_PC', 'pct_GLP_EOG_ALL_BL7_PC',
#        'pct_GLP_EOG_ALL_EDS_PC', 'pct_GLP_EOG_ALL_FEM_PC',
#        'pct_GLP_EOG_ALL_MALE_PC', 'pct_GLP_MA_03_WH7_PC',
#        'pct_GLP_MA_04_WH7_PC', 'pct_GLP_MA_05_AIG_PC',
#        'pct_GLP_MA_05_BL7_PC', 'pct_GLP_MA_05_WH7_PC',
#        'pct_GLP_MA_ALL_AIG_PC', 'pct_GLP_MA_ALL_ALL_PC',
#        'pct_GLP_MA_ALL_FEM_PC', 'pct_GLP_MA_ALL_MALE_PC',
#        'pct_GLP_MA_ALL_MU7_PC', 'pct_GLP_MA_ALL_WH7_PC',
#        'pct_GLP_RD_03_ALL_PC', 'pct_GLP_RD_04_ALL_PC',
#        'pct_GLP_RD_04_BL7_PC', 'pct_GLP_RD_04_WH7_PC',
#        'pct_GLP_RD_05_AIG_PC', 'pct_GLP_RD_05_ALL_PC',
#        'pct_GLP_RD_05_WH7_PC', 'pct_GLP_RD_ALL_ALL_PC',
#        'pct_GLP_RD_ALL_FEM_PC', 'pct_GLP_RD_ALL_MALE_PC',
#        'pct_GLP_SC_05_AIG_PC', 'pct_GLP_SC_05_ALL_PC',
#        'pct_GLP_SC_05_BL7_PC', 'pct_GLP_SC_05_EDS_PC',
#        'pct_GLP_SC_05_FEM_PC', 'pct_GLP_SC_05_HI7_PC',
#        'pct_GLP_SC_05_MALE_PC', 'pct_GLP_SC_05_SWD_PC',
#        'pct_GLP_SC_05_WH7_PC', 'pct_GLP_SC_ALL_BL7_PC',
#        'pct_GLP_SC_ALL_HI7_PC', 'pct_L1_ALL_ALL_ALL_PC',
#        'pct_L1_ALL_ALL_BL7_PC', 'pct_L1_ALL_ALL_EDS_PC',
#        'pct_L1_ALL_ALL_ELS_PC', 'pct_L1_ALL_ALL_FEM_PC',
#        'pct_L1_ALL_ALL_MALE_PC', 'pct_L1_ALL_ALL_MU7_PC',
#        'pct_L1_ALL_ALL_SWD_PC', 'pct_L1_ALL_ALL_WH7_PC',
#        'pct_L1_EOG_05_ALL_PC', 'pct_L1_EOG_ALL_ALL_PC',
#        'pct_L1_EOG_ALL_MALE_PC', 'pct_L1_MA_ALL_ALL_PC',
#        'pct_L1_RD_ALL_ALL_PC', 'pct_L1_SC_05_FEM_PC',
#        'pct_L1_SC_05_HI7_PC', 'pct_L1_SC_05_WH7_PC',
#        'pct_L2_ALL_ALL_ALL_PC', 'pct_L2_ALL_ALL_BL7_PC',
#        'pct_L2_ALL_ALL_EDS_PC', 'pct_L2_ALL_ALL_ELS_PC',
#        'pct_L2_ALL_ALL_FEM_PC', 'pct_L2_ALL_ALL_HI7_PC',
#        'pct_L2_ALL_ALL_MALE_PC', 'pct_L2_ALL_ALL_MU7_PC',
#        'pct_L2_ALL_ALL_SWD_PC', 'pct_L2_ALL_ALL_WH7_PC',
#        'pct_L2_EOG_ALL_ALL_PC', 'pct_L2_SC_05_BL7_PC',
#        'pct_L2_SC_05_EDS_PC', 'pct_L2_SC_05_FEM_PC',
#        'pct_L2_SC_05_HI7_PC', 'pct_L2_SC_05_WH7_PC',
#        'pct_L3_ALL_ALL_ALL_PC', 'pct_L3_ALL_ALL_BL7_PC',
#        'pct_L3_ALL_ALL_EDS_PC', 'pct_L3_ALL_ALL_ELS_PC',
#        'pct_L3_ALL_ALL_FEM_PC', 'pct_L3_ALL_ALL_HI7_PC',
#        'pct_L3_ALL_ALL_MALE_PC', 'pct_L3_ALL_ALL_MU7_PC',
#        'pct_L3_ALL_ALL_SWD_PC', 'pct_L3_ALL_ALL_WH7_PC',
#        'pct_L3_SC_05_BL7_PC', 'pct_L3_SC_05_EDS_PC',
#        'pct_L3_SC_05_HI7_PC', 'pct_L3_SC_05_MALE_PC',
#        'pct_L3_SC_05_WH7_PC', 'pct_L4_ALL_ALL_AIG_PC',
#        'pct_L4_ALL_ALL_ALL_PC', 'pct_L4_ALL_ALL_BL7_PC',
#        'pct_L4_ALL_ALL_EDS_PC', 'pct_L4_ALL_ALL_ELS_PC',
#        'pct_L4_ALL_ALL_FEM_PC', 'pct_L4_ALL_ALL_HI7_PC',
#        'pct_L4_ALL_ALL_MALE_PC', 'pct_L4_ALL_ALL_MU7_PC',
#        'pct_L4_ALL_ALL_SWD_PC', 'pct_L4_ALL_ALL_WH7_PC',
#        'pct_L4_EOG_ALL_ALL_PC', 'pct_L4_MA_ALL_ALL_PC',
#        'pct_L4_RD_ALL_ALL_PC', 'pct_L4_SC_05_AIG_PC',
#        'pct_L4_SC_05_ALL_PC', 'pct_L4_SC_05_BL7_PC',
#        'pct_L4_SC_05_EDS_PC', 'pct_L4_SC_05_FEM_PC',
#        'pct_L4_SC_05_HI7_PC', 'pct_L4_SC_05_MALE_PC',
#        'pct_L4_SC_05_SWD_PC', 'pct_L4_SC_05_WH7_PC',
#        'pct_L5_ALL_ALL_AIG_PC', 'pct_L5_ALL_ALL_ALL_PC',
#        'pct_L5_ALL_ALL_EDS_PC', 'pct_L5_ALL_ALL_ELS_PC',
#        'pct_L5_ALL_ALL_FEM_PC', 'pct_L5_ALL_ALL_HI7_PC',
#        'pct_L5_ALL_ALL_MALE_PC', 'pct_L5_ALL_ALL_MU7_PC',
#        'pct_L5_ALL_ALL_WH7_PC', 'pct_L5_EOG_03_ALL_PC',
#        'pct_L5_EOG_04_ALL_PC', 'pct_L5_EOG_04_MALE_PC',
#        'pct_L5_EOG_05_ALL_PC', 'pct_L5_EOG_ALL_ALL_PC',
#        'pct_L5_EOG_ALL_FEM_PC', 'pct_L5_EOG_ALL_MALE_PC',
#        'pct_L5_MA_ALL_ALL_PC', 'pct_L5_SC_05_AIG_PC',
#        'pct_L5_SC_05_ALL_PC', 'pct_L5_SC_05_EDS_PC',
#        'pct_L5_SC_05_FEM_PC', 'pct_L5_SC_05_MALE_PC',
#        'pct_L5_SC_05_WH7_PC', 'aaa_score_ALL_SPG2', 'aaa_score_BL7_SPG2',
#        'aaa_score_EDS_SPG2', 'aaa_score_ELS_SPG2', 'aaa_score_HI7_SPG2',
#        'aaa_score_SWD_SPG2', 'aaa_score_WH7_SPG2', 'ach_score_ELS_SPG2',
#        'pct_ALL_CHRON_ABSENT', 'arre_per1000_ALL', 'arre_per1000_BL7',
#        'arre_per1000_EDS', 'arre_per1000_MALE', 'arre_per1000_SWD',
#        'arre_per1000_WH7', 'crime_per1000_ALL', 'crime_per1000_BL7',
#        'crime_per1000_ELS', 'crime_per1000_MALE', 'crime_per1000_MU7',
#        'crime_per1000_SWD', 'iss_per1000_ALL', 'iss_per1000_EDS',
#        'rplw_per1000_ALL', 'rplw_per1000_MALE', 'count_ALL_PK_ENROLL',
#        'pct_ALL_PK_ENROLL', 'lea_code_020LEA', 'lea_code_030LEA',
#        'lea_code_040LEA', 'lea_code_050LEA', 'lea_code_060LEA',
#        'lea_code_070LEA', 'lea_code_080LEA', 'lea_code_090LEA',
#        'lea_code_100LEA', 'lea_code_110LEA', 'lea_code_111LEA',
#        'lea_code_120LEA', 'lea_code_130LEA', 'lea_code_132LEA',
#        'lea_code_140LEA', 'lea_code_150LEA', 'lea_code_160LEA',
#        'lea_code_170LEA', 'lea_code_180LEA', 'lea_code_181LEA',
#        'lea_code_182LEA', 'lea_code_190LEA', 'lea_code_200LEA',
#        'lea_code_210LEA', 'lea_code_220LEA', 'lea_code_230LEA',
#        'lea_code_240LEA', 'lea_code_241LEA', 'lea_code_250LEA',
#        'lea_code_260LEA', 'lea_code_270LEA', 'lea_code_280LEA',
#        'lea_code_290LEA', 'lea_code_291LEA', 'lea_code_292LEA',
#        'lea_code_300LEA', 'lea_code_310LEA', 'lea_code_320LEA',
#        'lea_code_330LEA', 'lea_code_340LEA', 'lea_code_350LEA',
#        'lea_code_360LEA', 'lea_code_370LEA', 'lea_code_380LEA',
#        'lea_code_390LEA', 'lea_code_400LEA', 'lea_code_410LEA',
#        'lea_code_420LEA', 'lea_code_421LEA', 'lea_code_422LEA',
#        'lea_code_430LEA', 'lea_code_440LEA', 'lea_code_450LEA',
#        'lea_code_460LEA', 'lea_code_470LEA', 'lea_code_480LEA',
#        'lea_code_490LEA', 'lea_code_491LEA', 'lea_code_500LEA',
#        'lea_code_510LEA', 'lea_code_520LEA', 'lea_code_530LEA',
#        'lea_code_540LEA', 'lea_code_550LEA', 'lea_code_560LEA',
#        'lea_code_570LEA', 'lea_code_580LEA', 'lea_code_590LEA',
#        'lea_code_600LEA', 'lea_code_610LEA', 'lea_code_620LEA',
#        'lea_code_630LEA', 'lea_code_640LEA', 'lea_code_650LEA',
#        'lea_code_660LEA', 'lea_code_670LEA', 'lea_code_680LEA',
#        'lea_code_681LEA', 'lea_code_690LEA', 'lea_code_700LEA',
#        'lea_code_710LEA', 'lea_code_720LEA', 'lea_code_730LEA',
#        'lea_code_740LEA', 'lea_code_750LEA', 'lea_code_760LEA',
#        'lea_code_761LEA', 'lea_code_770LEA', 'lea_code_780LEA',
#        'lea_code_790LEA', 'lea_code_800LEA', 'lea_code_810LEA',
#        'lea_code_820LEA', 'lea_code_821LEA', 'lea_code_830LEA',
#        'lea_code_840LEA', 'lea_code_850LEA', 'lea_code_860LEA',
#        'lea_code_861LEA', 'lea_code_862LEA', 'lea_code_870LEA',
#        'lea_code_880LEA', 'lea_code_890LEA', 'lea_code_900LEA',
#        'lea_code_910LEA', 'lea_code_920LEA', 'lea_code_930LEA',
#        'lea_code_940LEA', 'lea_code_950LEA', 'lea_code_960LEA',
#        'lea_code_970LEA', 'lea_code_980LEA', 'lea_code_990LEA',
#        'lea_code_995LEA', 'county_Alexander', 'county_Alleghany',
#        'county_Anson', 'county_Ashe', 'county_Avery', 'county_Beaufort',
#        'county_Bertie', 'county_Bladen', 'county_Brunswick',
#        'county_Burke', 'county_Caldwell', 'county_Camden',
#        'county_Carteret', 'county_Caswell', 'county_Chatham',
#        'county_Cherokee', 'county_Chowan', 'county_Clay',
#        'county_Cleveland', 'county_Craven', 'county_Cumberland',
#        'county_Currituck', 'county_Dare', 'county_Davie', 'county_Duplin',
#        'county_Durham', 'county_Edgecombe', 'county_Forsyth',
#        'county_Franklin', 'county_Gaston', 'county_Gates',
#        'county_Graham', 'county_Granville', 'county_Greene',
#        'county_Guilford', 'county_Harnett', 'county_Haywood',
#        'county_Henderson', 'county_Hertford', 'county_Hoke',
#        'county_Hyde', 'county_Jackson', 'county_Johnston', 'county_Jones',
#        'county_Lee', 'county_Lenoir', 'county_Lincoln', 'county_Macon',
#        'county_Madison', 'county_Martin', 'county_McDowell',
#        'county_Mecklenburg', 'county_Mitchell', 'county_Montgomery',
#        'county_Moore', 'county_Nash', 'county_New Hanover',
#        'county_Northampton', 'county_Onslow', 'county_Pamlico',
#        'county_Pasquotank', 'county_Pender', 'county_Perquimans',
#        'county_Person', 'county_Pitt', 'county_Polk', 'county_Richmond',
#        'county_Robeson', 'county_Rockingham', 'county_Rowan',
#        'county_Rutherford', 'county_Scotland', 'county_Stanly',
#        'county_Stokes', 'county_Swain', 'county_Transylvania',
#        'county_Tyrrell', 'county_Union', 'county_Vance', 'county_Wake',
#        'county_Warren', 'county_Washington', 'county_Watauga',
#        'county_Wayne', 'county_Wilkes', 'county_Wilson', 'county_Yadkin',
#        'county_Yancey', 'grade_span_02:03', 'grade_span_02:04',
#        'grade_span_04:08', 'grade_span_KG:01', 'grade_span_KG:13',
#        'grade_span_PK:01', 'grade_span_PK:09', 'grade_span_PK:KG',
#        'lea_name_Alexander County Schools',
#        'lea_name_Alleghany County Schools',
#        'lea_name_Anson County Schools', 'lea_name_Ashe County Schools',
#        'lea_name_Asheboro City Schools',
#        'lea_name_Asheville City Schools', 'lea_name_Avery County Schools',
#        'lea_name_Beaufort County Schools',
#        'lea_name_Bertie County Schools', 'lea_name_Bladen County Schools',
#        'lea_name_Brunswick County Schools',
#        'lea_name_Buncombe County Schools',
#        'lea_name_Burke County Schools',
#        'lea_name_Cabarrus County Schools',
#        'lea_name_Caldwell County Schools',
#        'lea_name_Camden County Schools',
#        'lea_name_Carteret County Schools',
#        'lea_name_Caswell County Schools',
#        'lea_name_Catawba County Schools',
#        'lea_name_Chapel-Hill/Carrboro City Schools',
#        'lea_name_Charlotte-Mecklenburg County Schools',
#        'lea_name_Chatham County Schools',
#        'lea_name_Cherokee County Schools', 'lea_name_Clay County Schools',
#        'lea_name_Cleveland County Schools',
#        'lea_name_Clinton City Schools',
#        'lea_name_Columbus County Schools',
#        'lea_name_Craven County Schools',
#        'lea_name_Cumberland County Schools',
#        'lea_name_Currituck County Schools',
#        'lea_name_Dare County Schools', 'lea_name_Davidson County Schools',
#        'lea_name_Davie County Schools', 'lea_name_Duplin County Schools',
#        'lea_name_Durham County Schools',
#        'lea_name_Edenton-Chowan County Schools',
#        'lea_name_Edgecombe County Schools', 'lea_name_Elkin City Schools',
#        'lea_name_Forsyth County Schools',
#        'lea_name_Franklin County Schools',
#        'lea_name_Gaston County Schools', 'lea_name_Gates County Schools',
#        'lea_name_Graham County Schools',
#        'lea_name_Granville County Schools',
#        'lea_name_Greene County Schools',
#        'lea_name_Guilford County Schools',
#        'lea_name_Halifax County Schools',
#        'lea_name_Harnett County Schools',
#        'lea_name_Haywood County Schools',
#        'lea_name_Henderson County Schools',
#        'lea_name_Hertford County Schools',
#        'lea_name_Hickory City Schools', 'lea_name_Hoke County Schools',
#        'lea_name_Hyde County Schools',
#        'lea_name_Iredell-Statesville Schools',
#        'lea_name_Jackson County Schools',
#        'lea_name_Johnston County Schools',
#        'lea_name_Jones County Schools',
#        'lea_name_Kannapolis City Schools', 'lea_name_Lee County Schools',
#        'lea_name_Lenoir County Schools',
#        'lea_name_Lexington City Schools',
#        'lea_name_Lincoln County Schools', 'lea_name_Macon County Schools',
#        'lea_name_Madison County Schools',
#        'lea_name_Martin County Schools',
#        'lea_name_McDowell County Schools',
#        'lea_name_Mitchell County Schools',
#        'lea_name_Montgomery County Schools',
#        'lea_name_Moore County Schools',
#        'lea_name_Mooresville City Schools',
#        'lea_name_Mount Airy City Schools',
#        'lea_name_Nash-Rocky Mount Schools',
#        'lea_name_New Hanover County Schools',
#        'lea_name_Newton-Conover City Schools',
#        'lea_name_Northampton County Schools',
#        'lea_name_Onslow County Schools', 'lea_name_Orange County Schools',
#        'lea_name_Pamlico County Schools',
#        'lea_name_Pasquotank County Schools',
#        'lea_name_Pender County Schools',
#        'lea_name_Perquimans County Schools',
#        'lea_name_Person County Schools', 'lea_name_Pitt County Schools',
#        'lea_name_Polk County Schools', 'lea_name_Randolph County Schools',
#        'lea_name_Richmond County Schools',
#        'lea_name_Roanoke Rapids City Schools',
#        'lea_name_Robeson County Schools',
#        'lea_name_Rockingham County Schools',
#        'lea_name_Rowan-Salisbury County Schools',
#        'lea_name_Rutherford County Schools',
#        'lea_name_Sampson County Schools',
#        'lea_name_Scotland County Schools',
#        'lea_name_Stanly County Schools', 'lea_name_Stokes County Schools',
#        'lea_name_Surry County Schools', 'lea_name_Swain County Schools',
#        'lea_name_Thomasville City Schools',
#        'lea_name_Transylvania County Schools',
#        'lea_name_Tyrrell County Schools', 'lea_name_Union County Schools',
#        'lea_name_Vance County Schools', 'lea_name_Wake County Schools',
#        'lea_name_Warren County Schools',
#        'lea_name_Washington County Schools',
#        'lea_name_Watauga County Schools', 'lea_name_Wayne County Schools',
#        'lea_name_Weldon City Schools', 'lea_name_Whiteville City Schools',
#        'lea_name_Wilkes County Schools', 'lea_name_Wilson County Schools',
#        'lea_name_Yadkin County Schools', 'lea_name_Yancey County Schools',
#        'lea_name_attendance_Alexander County Schools',
#        'lea_name_attendance_Alleghany County Schools',
#        'lea_name_attendance_Anson County Schools',
#        'lea_name_attendance_Ashe County Schools',
#        'lea_name_attendance_Asheboro City Schools',
#        'lea_name_attendance_Asheville City Schools',
#        'lea_name_attendance_Avery County Schools',
#        'lea_name_attendance_Beaufort County Schools',
#        'lea_name_attendance_Bertie County Schools',
#        'lea_name_attendance_Bladen County Schools',
#        'lea_name_attendance_Brunswick County Schools',
#        'lea_name_attendance_Buncombe County Schools',
#        'lea_name_attendance_Burke County Schools',
#        'lea_name_attendance_Cabarrus County Schools',
#        'lea_name_attendance_Caldwell County Schools',
#        'lea_name_attendance_Camden County Schools',
#        'lea_name_attendance_Carteret County Public Schools',
#        'lea_name_attendance_Caswell County Schools',
#        'lea_name_attendance_Catawba County Schools',
#        'lea_name_attendance_Chapel Hill-Carrboro City Schools',
#        'lea_name_attendance_Charlotte-Mecklenburg Schools',
#        'lea_name_attendance_Chatham County Schools',
#        'lea_name_attendance_Cherokee County Schools',
#        'lea_name_attendance_Clay County Schools',
#        'lea_name_attendance_Cleveland County Schools',
#        'lea_name_attendance_Clinton City Schools',
#        'lea_name_attendance_Columbus County Schools',
#        'lea_name_attendance_Craven County Schools',
#        'lea_name_attendance_Cumberland County Schools',
#        'lea_name_attendance_Currituck County Schools',
#        'lea_name_attendance_Dare County Schools',
#        'lea_name_attendance_Davidson County Schools',
#        'lea_name_attendance_Davie County Schools',
#        'lea_name_attendance_Duplin County Schools',
#        'lea_name_attendance_Durham Public Schools',
#        'lea_name_attendance_Edenton-Chowan Schools',
#        'lea_name_attendance_Edgecombe County Public Schools',
#        'lea_name_attendance_Elizabeth City-Pasquotank Public Schools',
#        'lea_name_attendance_Elkin City Schools',
#        'lea_name_attendance_Franklin County Schools',
#        'lea_name_attendance_Gaston County Schools',
#        'lea_name_attendance_Gates County Schools',
#        'lea_name_attendance_Graham County Schools',
#        'lea_name_attendance_Granville County Schools',
#        'lea_name_attendance_Greene County Schools',
#        'lea_name_attendance_Guilford County Schools',
#        'lea_name_attendance_Halifax County Schools',
#        'lea_name_attendance_Harnett County Schools',
#        'lea_name_attendance_Haywood County Schools',
#        'lea_name_attendance_Henderson County Schools',
#        'lea_name_attendance_Hertford County Schools',
#        'lea_name_attendance_Hickory City Schools',
#        'lea_name_attendance_Hoke County Schools',
#        'lea_name_attendance_Hyde County Schools',
#        'lea_name_attendance_Iredell-Statesville Schools',
#        'lea_name_attendance_Jackson County Public Schools',
#        'lea_name_attendance_Johnston County Schools',
#        'lea_name_attendance_Jones County Schools',
#        'lea_name_attendance_Kannapolis City Schools',
#        'lea_name_attendance_Lee County Schools',
#        'lea_name_attendance_Lenoir County Public Schools',
#        'lea_name_attendance_Lexington City Schools',
#        'lea_name_attendance_Lincoln County Schools',
#        'lea_name_attendance_Macon County Schools',
#        'lea_name_attendance_Madison County Schools',
#        'lea_name_attendance_Martin County Schools',
#        'lea_name_attendance_McDowell County Schools',
#        'lea_name_attendance_Mitchell County Schools',
#        'lea_name_attendance_Montgomery County Schools',
#        'lea_name_attendance_Moore County Schools',
#        'lea_name_attendance_Mooresville Graded School District',
#        'lea_name_attendance_Mount Airy City Schools',
#        'lea_name_attendance_Nash-Rocky Mount Schools',
#        'lea_name_attendance_New Hanover County Schools',
#        'lea_name_attendance_Newton Conover City Schools',
#        'lea_name_attendance_Northampton County Schools',
#        'lea_name_attendance_Onslow County Schools',
#        'lea_name_attendance_Orange County Schools',
#        'lea_name_attendance_Pamlico County Schools',
#        'lea_name_attendance_Pender County Schools',
#        'lea_name_attendance_Perquimans County Schools',
#        'lea_name_attendance_Person County Schools',
#        'lea_name_attendance_Pitt County Schools',
#        'lea_name_attendance_Polk County Schools',
#        'lea_name_attendance_Public Schools of Robeson County',
#        'lea_name_attendance_Randolph County School System',
#        'lea_name_attendance_Richmond County Schools',
#        'lea_name_attendance_Roanoke Rapids City Schools',
#        'lea_name_attendance_Rockingham County Schools',
#        'lea_name_attendance_Rowan-Salisbury Schools',
#        'lea_name_attendance_Rutherford County Schools',
#        'lea_name_attendance_Sampson County Schools',
#        'lea_name_attendance_Scotland County Schools',
#        'lea_name_attendance_Stanly County Schools',
#        'lea_name_attendance_Stokes County Schools',
#        'lea_name_attendance_Surry County Schools',
#        'lea_name_attendance_Swain County Schools',
#        'lea_name_attendance_Thomasville City Schools',
#        'lea_name_attendance_Transylvania County Schools',
#        'lea_name_attendance_Tyrrell County Schools',
#        'lea_name_attendance_Union County Public Schools',
#        'lea_name_attendance_Vance County Schools',
#        'lea_name_attendance_Wake County Schools',
#        'lea_name_attendance_Warren County Schools',
#        'lea_name_attendance_Washington County Schools',
#        'lea_name_attendance_Watauga County Schools',
#        'lea_name_attendance_Wayne County Public Schools',
#        'lea_name_attendance_Weldon City Schools',
#        'lea_name_attendance_Whiteville City Schools',
#        'lea_name_attendance_Wilkes County Schools',
#        'lea_name_attendance_Wilson County Schools',
#        'lea_name_attendance_Winston Salem/Forsyth County Schools',
#        'lea_name_attendance_Yadkin County Schools',
#        'lea_name_attendance_Yancey County Schools'], dtype=object)

# %%
#Check columns before drop 
print('\r\n*********Before: Dropping Highly Correlated Fields*************************************')
schoolData.info(verbose=False)

# Drop the highly correlated features from our training data 
#schoolData = schoolData.drop(to_drop, axis=1)
schoolData = schoolData.drop(cf['Field2'], axis=1)

#Check columns after drop 
print('\r\n*********After: Dropping Highly Correlated Fields**************************************')
schoolData.info(verbose=False)
# Out:
# *********Before: Dropping Highly Correlated Fields*************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1422 entries, 2 to 1574
# Columns: 1880 entries, lea to agency_lea_code_995LEA
# dtypes: float64(1126), uint8(754)
# memory usage: 13.2 MB
#
# *********After: Dropping Highly Correlated Fields**************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1422 entries, 2 to 1574
# Columns: 1132 entries, pacific_island_pct to agency_lea_code_995LEA
# dtypes: float64(816), uint8(316)
# memory usage: 9.3 MB

# %%
#Restore the unit_code before saving
schoolData['agency_code'] = agency_code
#Save the final dataset to a .csv file
schoolData.to_csv(outputDir + inputFileName + '_ML.csv', sep=',', index=False)

# %%
print('*********FINAL DATASET DETAILS*********************************************************\r\n')
schoolData.info(verbose=True)
# Out:
# *********FINAL DATASET DETAILS*********************************************************
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1422 entries, 2 to 1574
# Data columns (total 1133 columns):
#  #    Column                                                                 Dtype
# ---   ------                                                                 -----
#  0    pacific_island_pct                                                     float64
#  1    two_or_more_pct                                                        float64
#  2    hispanic_male_pct                                                      float64
#  3    black_male_pct                                                         float64
#  4    pacific_island_male_pct                                                float64
#  5    two_or_more_male_pct                                                   float64
#  6    indian_female_pct                                                      float64
#  7    asian_female_pct                                                       float64
#  8    hispanic_female_pct                                                    float64
#  9    black_female_pct                                                       float64
#  10   white_female_pct                                                       float64
#  11   minority_female_pct                                                    float64
#  12   pacific_island_female_pct                                              float64
#  13   two_or_more_female_pct                                                 float64
#  14   lea_no_attendance                                                      float64
#  15   school_no_attendance                                                   float64
#  16   ada_adm_ratio_2018_attendance                                          float64
#  17   ada_adm_ratio_2019_attendance                                          float64
#  18   ada_adm_ratio_2017_thru_2019_attendance                                float64
#  19   ada_adm_rank_2017_thru_2019_attendance                                 float64
#  20   pct_eds                                                                float64
#  21   pct_EDS_ELP                                                            float64
#  22   pct_ELS_ELP                                                            float64
#  23   pct_FEM_ELP                                                            float64
#  24   pct_HI7_ELP                                                            float64
#  25   pct_MALE_ELP                                                           float64
#  26   pct_met_Math Grades 3-8_LTG                                            float64
#  27   pct_met_Reading Grades 3-8_LTG                                         float64
#  28   pct_met_Total Targets_LTG                                              float64
#  29   pct_Reading Grades 3-8_ALL_PART_DET                                    float64
#  30   pct_Reading Grades 3-8_BL7_PART_DET                                    float64
#  31   pct_Reading Grades 3-8_EDS_PART_DET                                    float64
#  32   pct_Reading Grades 3-8_HI7_PART_DET                                    float64
#  33   pct_Reading Grades 3-8_SWD_PART_DET                                    float64
#  34   pct_Reading Grades 3-8_WH7_PART_DET                                    float64
#  35   pct_Science Grades 5&8_ALL_PART_DET                                    float64
#  36   pct_Science Grades 5&8_EDS_PART_DET                                    float64
#  37   pct_CCR_EOG_03_SWD_PC                                                  float64
#  38   pct_CCR_EOG_04_SWD_PC                                                  float64
#  39   pct_CCR_EOG_05_SWD_PC                                                  float64
#  40   pct_CCR_MA_03_EDS_PC                                                   float64
#  41   pct_CCR_MA_03_SWD_PC                                                   float64
#  42   pct_CCR_MA_05_SWD_PC                                                   float64
#  43   pct_CCR_MA_ALL_SWD_PC                                                  float64
#  44   pct_CCR_RD_03_EDS_PC                                                   float64
#  45   pct_CCR_RD_03_SWD_PC                                                   float64
#  46   pct_CCR_RD_ALL_SWD_PC                                                  float64
#  47   pct_CCR_SC_ALL_SWD_PC                                                  float64
#  48   pct_GLP_EOG_03_BL7_PC                                                  float64
#  49   pct_GLP_EOG_03_EDS_PC                                                  float64
#  50   pct_GLP_EOG_03_ELS_PC                                                  float64
#  51   pct_GLP_EOG_03_FEM_PC                                                  float64
#  52   pct_GLP_EOG_03_HI7_PC                                                  float64
#  53   pct_GLP_EOG_03_MALE_PC                                                 float64
#  54   pct_GLP_EOG_03_SWD_PC                                                  float64
#  55   pct_GLP_EOG_03_WH7_PC                                                  float64
#  56   pct_GLP_EOG_04_AIG_PC                                                  float64
#  57   pct_GLP_EOG_04_EDS_PC                                                  float64
#  58   pct_GLP_EOG_04_ELS_PC                                                  float64
#  59   pct_GLP_EOG_04_FEM_PC                                                  float64
#  60   pct_GLP_EOG_04_HI7_PC                                                  float64
#  61   pct_GLP_EOG_04_MALE_PC                                                 float64
#  62   pct_GLP_EOG_04_SWD_PC                                                  float64
#  63   pct_GLP_EOG_04_WH7_PC                                                  float64
#  64   pct_GLP_EOG_05_AIG_PC                                                  float64
#  65   pct_GLP_EOG_05_FEM_PC                                                  float64
#  66   pct_GLP_EOG_05_HI7_PC                                                  float64
#  67   pct_GLP_EOG_05_MU7_PC                                                  float64
#  68   pct_GLP_EOG_05_SWD_PC                                                  float64
#  69   pct_GLP_EOG_05_WH7_PC                                                  float64
#  70   pct_GLP_EOG_ALL_AIG_PC                                                 float64
#  71   pct_GLP_EOG_ALL_ELS_PC                                                 float64
#  72   pct_GLP_EOG_ALL_HI7_PC                                                 float64
#  73   pct_GLP_EOG_ALL_MU7_PC                                                 float64
#  74   pct_GLP_EOG_ALL_SWD_PC                                                 float64
#  75   pct_GLP_EOG_ALL_WH7_PC                                                 float64
#  76   pct_GLP_MA_03_ALL_PC                                                   float64
#  77   pct_GLP_MA_03_BL7_PC                                                   float64
#  78   pct_GLP_MA_03_EDS_PC                                                   float64
#  79   pct_GLP_MA_03_FEM_PC                                                   float64
#  80   pct_GLP_MA_03_HI7_PC                                                   float64
#  81   pct_GLP_MA_03_MALE_PC                                                  float64
#  82   pct_GLP_MA_03_SWD_PC                                                   float64
#  83   pct_GLP_MA_04_ALL_PC                                                   float64
#  84   pct_GLP_MA_04_BL7_PC                                                   float64
#  85   pct_GLP_MA_04_EDS_PC                                                   float64
#  86   pct_GLP_MA_04_FEM_PC                                                   float64
#  87   pct_GLP_MA_04_HI7_PC                                                   float64
#  88   pct_GLP_MA_04_MALE_PC                                                  float64
#  89   pct_GLP_MA_04_SWD_PC                                                   float64
#  90   pct_GLP_MA_05_ALL_PC                                                   float64
#  91   pct_GLP_MA_05_EDS_PC                                                   float64
#  92   pct_GLP_MA_05_FEM_PC                                                   float64
#  93   pct_GLP_MA_05_HI7_PC                                                   float64
#  94   pct_GLP_MA_05_MALE_PC                                                  float64
#  95   pct_GLP_MA_05_SWD_PC                                                   float64
#  96   pct_GLP_MA_ALL_BL7_PC                                                  float64
#  97   pct_GLP_MA_ALL_EDS_PC                                                  float64
#  98   pct_GLP_MA_ALL_ELS_PC                                                  float64
#  99   pct_GLP_MA_ALL_HI7_PC                                                  float64
#  100  pct_GLP_MA_ALL_SWD_PC                                                  float64
#  101  pct_GLP_RD_03_BL7_PC                                                   float64
#  102  pct_GLP_RD_03_EDS_PC                                                   float64
#  103  pct_GLP_RD_03_FEM_PC                                                   float64
#  104  pct_GLP_RD_03_HI7_PC                                                   float64
#  105  pct_GLP_RD_03_MALE_PC                                                  float64
#  106  pct_GLP_RD_03_SWD_PC                                                   float64
#  107  pct_GLP_RD_03_WH7_PC                                                   float64
#  108  pct_GLP_RD_04_EDS_PC                                                   float64
#  109  pct_GLP_RD_04_FEM_PC                                                   float64
#  110  pct_GLP_RD_04_HI7_PC                                                   float64
#  111  pct_GLP_RD_04_MALE_PC                                                  float64
#  112  pct_GLP_RD_04_SWD_PC                                                   float64
#  113  pct_GLP_RD_05_BL7_PC                                                   float64
#  114  pct_GLP_RD_05_EDS_PC                                                   float64
#  115  pct_GLP_RD_05_FEM_PC                                                   float64
#  116  pct_GLP_RD_05_HI7_PC                                                   float64
#  117  pct_GLP_RD_05_MALE_PC                                                  float64
#  118  pct_GLP_RD_05_SWD_PC                                                   float64
#  119  pct_GLP_RD_ALL_AIG_PC                                                  float64
#  120  pct_GLP_RD_ALL_BL7_PC                                                  float64
#  121  pct_GLP_RD_ALL_EDS_PC                                                  float64
#  122  pct_GLP_RD_ALL_ELS_PC                                                  float64
#  123  pct_GLP_RD_ALL_HI7_PC                                                  float64
#  124  pct_GLP_RD_ALL_MU7_PC                                                  float64
#  125  pct_GLP_RD_ALL_SWD_PC                                                  float64
#  126  pct_GLP_RD_ALL_WH7_PC                                                  float64
#  127  pct_GLP_SC_ALL_AIG_PC                                                  float64
#  128  pct_GLP_SC_ALL_ALL_PC                                                  float64
#  129  pct_GLP_SC_ALL_EDS_PC                                                  float64
#  130  pct_GLP_SC_ALL_FEM_PC                                                  float64
#  131  pct_GLP_SC_ALL_MALE_PC                                                 float64
#  132  pct_GLP_SC_ALL_SWD_PC                                                  float64
#  133  pct_GLP_SC_ALL_WH7_PC                                                  float64
#  134  pct_L1_ALL_ALL_HI7_PC                                                  float64
#  135  pct_L1_EOG_03_ALL_PC                                                   float64
#  136  pct_L1_EOG_03_BL7_PC                                                   float64
#  137  pct_L1_EOG_03_EDS_PC                                                   float64
#  138  pct_L1_EOG_03_ELS_PC                                                   float64
#  139  pct_L1_EOG_03_FEM_PC                                                   float64
#  140  pct_L1_EOG_03_HI7_PC                                                   float64
#  141  pct_L1_EOG_03_MALE_PC                                                  float64
#  142  pct_L1_EOG_03_SWD_PC                                                   float64
#  143  pct_L1_EOG_03_WH7_PC                                                   float64
#  144  pct_L1_EOG_04_ALL_PC                                                   float64
#  145  pct_L1_EOG_04_BL7_PC                                                   float64
#  146  pct_L1_EOG_04_EDS_PC                                                   float64
#  147  pct_L1_EOG_04_ELS_PC                                                   float64
#  148  pct_L1_EOG_04_FEM_PC                                                   float64
#  149  pct_L1_EOG_04_HI7_PC                                                   float64
#  150  pct_L1_EOG_04_MALE_PC                                                  float64
#  151  pct_L1_EOG_04_SWD_PC                                                   float64
#  152  pct_L1_EOG_04_WH7_PC                                                   float64
#  153  pct_L1_EOG_05_BL7_PC                                                   float64
#  154  pct_L1_EOG_05_EDS_PC                                                   float64
#  155  pct_L1_EOG_05_ELS_PC                                                   float64
#  156  pct_L1_EOG_05_FEM_PC                                                   float64
#  157  pct_L1_EOG_05_HI7_PC                                                   float64
#  158  pct_L1_EOG_05_MALE_PC                                                  float64
#  159  pct_L1_EOG_05_SWD_PC                                                   float64
#  160  pct_L1_EOG_05_WH7_PC                                                   float64
#  161  pct_L1_EOG_ALL_BL7_PC                                                  float64
#  162  pct_L1_EOG_ALL_EDS_PC                                                  float64
#  163  pct_L1_EOG_ALL_ELS_PC                                                  float64
#  164  pct_L1_EOG_ALL_FEM_PC                                                  float64
#  165  pct_L1_EOG_ALL_HI7_PC                                                  float64
#  166  pct_L1_EOG_ALL_MU7_PC                                                  float64
#  167  pct_L1_EOG_ALL_SWD_PC                                                  float64
#  168  pct_L1_EOG_ALL_WH7_PC                                                  float64
#  169  pct_L1_MA_03_ALL_PC                                                    float64
#  170  pct_L1_MA_03_BL7_PC                                                    float64
#  171  pct_L1_MA_03_EDS_PC                                                    float64
#  172  pct_L1_MA_03_FEM_PC                                                    float64
#  173  pct_L1_MA_03_HI7_PC                                                    float64
#  174  pct_L1_MA_03_MALE_PC                                                   float64
#  175  pct_L1_MA_03_SWD_PC                                                    float64
#  176  pct_L1_MA_03_WH7_PC                                                    float64
#  177  pct_L1_MA_04_ALL_PC                                                    float64
#  178  pct_L1_MA_04_BL7_PC                                                    float64
#  179  pct_L1_MA_04_EDS_PC                                                    float64
#  180  pct_L1_MA_04_FEM_PC                                                    float64
#  181  pct_L1_MA_04_HI7_PC                                                    float64
#  182  pct_L1_MA_04_MALE_PC                                                   float64
#  183  pct_L1_MA_04_SWD_PC                                                    float64
#  184  pct_L1_MA_04_WH7_PC                                                    float64
#  185  pct_L1_MA_05_ALL_PC                                                    float64
#  186  pct_L1_MA_05_BL7_PC                                                    float64
#  187  pct_L1_MA_05_EDS_PC                                                    float64
#  188  pct_L1_MA_05_FEM_PC                                                    float64
#  189  pct_L1_MA_05_HI7_PC                                                    float64
#  190  pct_L1_MA_05_MALE_PC                                                   float64
#  191  pct_L1_MA_05_SWD_PC                                                    float64
#  192  pct_L1_MA_05_WH7_PC                                                    float64
#  193  pct_L1_MA_ALL_BL7_PC                                                   float64
#  194  pct_L1_MA_ALL_EDS_PC                                                   float64
#  195  pct_L1_MA_ALL_ELS_PC                                                   float64
#  196  pct_L1_MA_ALL_FEM_PC                                                   float64
#  197  pct_L1_MA_ALL_HI7_PC                                                   float64
#  198  pct_L1_MA_ALL_MALE_PC                                                  float64
#  199  pct_L1_MA_ALL_MU7_PC                                                   float64
#  200  pct_L1_MA_ALL_SWD_PC                                                   float64
#  201  pct_L1_MA_ALL_WH7_PC                                                   float64
#  202  pct_L1_RD_03_ALL_PC                                                    float64
#  203  pct_L1_RD_03_BL7_PC                                                    float64
#  204  pct_L1_RD_03_EDS_PC                                                    float64
#  205  pct_L1_RD_03_FEM_PC                                                    float64
#  206  pct_L1_RD_03_HI7_PC                                                    float64
#  207  pct_L1_RD_03_MALE_PC                                                   float64
#  208  pct_L1_RD_03_SWD_PC                                                    float64
#  209  pct_L1_RD_03_WH7_PC                                                    float64
#  210  pct_L1_RD_04_ALL_PC                                                    float64
#  211  pct_L1_RD_04_BL7_PC                                                    float64
#  212  pct_L1_RD_04_EDS_PC                                                    float64
#  213  pct_L1_RD_04_FEM_PC                                                    float64
#  214  pct_L1_RD_04_HI7_PC                                                    float64
#  215  pct_L1_RD_04_MALE_PC                                                   float64
#  216  pct_L1_RD_04_SWD_PC                                                    float64
#  217  pct_L1_RD_04_WH7_PC                                                    float64
#  218  pct_L1_RD_05_ALL_PC                                                    float64
#  219  pct_L1_RD_05_BL7_PC                                                    float64
#  220  pct_L1_RD_05_EDS_PC                                                    float64
#  221  pct_L1_RD_05_FEM_PC                                                    float64
#  222  pct_L1_RD_05_HI7_PC                                                    float64
#  223  pct_L1_RD_05_MALE_PC                                                   float64
#  224  pct_L1_RD_05_SWD_PC                                                    float64
#  225  pct_L1_RD_05_WH7_PC                                                    float64
#  226  pct_L1_RD_ALL_BL7_PC                                                   float64
#  227  pct_L1_RD_ALL_EDS_PC                                                   float64
#  228  pct_L1_RD_ALL_ELS_PC                                                   float64
#  229  pct_L1_RD_ALL_FEM_PC                                                   float64
#  230  pct_L1_RD_ALL_HI7_PC                                                   float64
#  231  pct_L1_RD_ALL_MALE_PC                                                  float64
#  232  pct_L1_RD_ALL_MU7_PC                                                   float64
#  233  pct_L1_RD_ALL_SWD_PC                                                   float64
#  234  pct_L1_RD_ALL_WH7_PC                                                   float64
#  235  pct_L1_SC_05_ALL_PC                                                    float64
#  236  pct_L1_SC_05_BL7_PC                                                    float64
#  237  pct_L1_SC_05_EDS_PC                                                    float64
#  238  pct_L1_SC_05_MALE_PC                                                   float64
#  239  pct_L1_SC_05_SWD_PC                                                    float64
#  240  pct_L1_SC_ALL_ALL_PC                                                   float64
#  241  pct_L1_SC_ALL_BL7_PC                                                   float64
#  242  pct_L1_SC_ALL_EDS_PC                                                   float64
#  243  pct_L1_SC_ALL_FEM_PC                                                   float64
#  244  pct_L1_SC_ALL_HI7_PC                                                   float64
#  245  pct_L1_SC_ALL_MALE_PC                                                  float64
#  246  pct_L1_SC_ALL_SWD_PC                                                   float64
#  247  pct_L1_SC_ALL_WH7_PC                                                   float64
#  248  pct_L2_EOG_03_ALL_PC                                                   float64
#  249  pct_L2_EOG_03_BL7_PC                                                   float64
#  250  pct_L2_EOG_03_EDS_PC                                                   float64
#  251  pct_L2_EOG_03_ELS_PC                                                   float64
#  252  pct_L2_EOG_03_FEM_PC                                                   float64
#  253  pct_L2_EOG_03_HI7_PC                                                   float64
#  254  pct_L2_EOG_03_MALE_PC                                                  float64
#  255  pct_L2_EOG_03_SWD_PC                                                   float64
#  256  pct_L2_EOG_03_WH7_PC                                                   float64
#  257  pct_L2_EOG_04_ALL_PC                                                   float64
#  258  pct_L2_EOG_04_BL7_PC                                                   float64
#  259  pct_L2_EOG_04_EDS_PC                                                   float64
#  260  pct_L2_EOG_04_ELS_PC                                                   float64
#  261  pct_L2_EOG_04_FEM_PC                                                   float64
#  262  pct_L2_EOG_04_HI7_PC                                                   float64
#  263  pct_L2_EOG_04_MALE_PC                                                  float64
#  264  pct_L2_EOG_04_SWD_PC                                                   float64
#  265  pct_L2_EOG_04_WH7_PC                                                   float64
#  266  pct_L2_EOG_05_ALL_PC                                                   float64
#  267  pct_L2_EOG_05_BL7_PC                                                   float64
#  268  pct_L2_EOG_05_EDS_PC                                                   float64
#  269  pct_L2_EOG_05_ELS_PC                                                   float64
#  270  pct_L2_EOG_05_FEM_PC                                                   float64
#  271  pct_L2_EOG_05_HI7_PC                                                   float64
#  272  pct_L2_EOG_05_MALE_PC                                                  float64
#  273  pct_L2_EOG_05_SWD_PC                                                   float64
#  274  pct_L2_EOG_05_WH7_PC                                                   float64
#  275  pct_L2_EOG_ALL_BL7_PC                                                  float64
#  276  pct_L2_EOG_ALL_EDS_PC                                                  float64
#  277  pct_L2_EOG_ALL_ELS_PC                                                  float64
#  278  pct_L2_EOG_ALL_FEM_PC                                                  float64
#  279  pct_L2_EOG_ALL_HI7_PC                                                  float64
#  280  pct_L2_EOG_ALL_MALE_PC                                                 float64
#  281  pct_L2_EOG_ALL_MU7_PC                                                  float64
#  282  pct_L2_EOG_ALL_SWD_PC                                                  float64
#  283  pct_L2_EOG_ALL_WH7_PC                                                  float64
#  284  pct_L2_MA_03_ALL_PC                                                    float64
#  285  pct_L2_MA_03_BL7_PC                                                    float64
#  286  pct_L2_MA_03_EDS_PC                                                    float64
#  287  pct_L2_MA_03_FEM_PC                                                    float64
#  288  pct_L2_MA_03_HI7_PC                                                    float64
#  289  pct_L2_MA_03_MALE_PC                                                   float64
#  290  pct_L2_MA_03_SWD_PC                                                    float64
#  291  pct_L2_MA_03_WH7_PC                                                    float64
#  292  pct_L2_MA_04_ALL_PC                                                    float64
#  293  pct_L2_MA_04_BL7_PC                                                    float64
#  294  pct_L2_MA_04_EDS_PC                                                    float64
#  295  pct_L2_MA_04_FEM_PC                                                    float64
#  296  pct_L2_MA_04_HI7_PC                                                    float64
#  297  pct_L2_MA_04_MALE_PC                                                   float64
#  298  pct_L2_MA_04_SWD_PC                                                    float64
#  299  pct_L2_MA_04_WH7_PC                                                    float64
#  300  pct_L2_MA_05_ALL_PC                                                    float64
#  301  pct_L2_MA_05_BL7_PC                                                    float64
#  302  pct_L2_MA_05_EDS_PC                                                    float64
#  303  pct_L2_MA_05_FEM_PC                                                    float64
#  304  pct_L2_MA_05_HI7_PC                                                    float64
#  305  pct_L2_MA_05_MALE_PC                                                   float64
#  306  pct_L2_MA_05_SWD_PC                                                    float64
#  307  pct_L2_MA_05_WH7_PC                                                    float64
#  308  pct_L2_MA_ALL_ALL_PC                                                   float64
#  309  pct_L2_MA_ALL_BL7_PC                                                   float64
#  310  pct_L2_MA_ALL_EDS_PC                                                   float64
#  311  pct_L2_MA_ALL_ELS_PC                                                   float64
#  312  pct_L2_MA_ALL_FEM_PC                                                   float64
#  313  pct_L2_MA_ALL_HI7_PC                                                   float64
#  314  pct_L2_MA_ALL_MALE_PC                                                  float64
#  315  pct_L2_MA_ALL_MU7_PC                                                   float64
#  316  pct_L2_MA_ALL_SWD_PC                                                   float64
#  317  pct_L2_MA_ALL_WH7_PC                                                   float64
#  318  pct_L2_RD_03_ALL_PC                                                    float64
#  319  pct_L2_RD_03_BL7_PC                                                    float64
#  320  pct_L2_RD_03_EDS_PC                                                    float64
#  321  pct_L2_RD_03_FEM_PC                                                    float64
#  322  pct_L2_RD_03_HI7_PC                                                    float64
#  323  pct_L2_RD_03_MALE_PC                                                   float64
#  324  pct_L2_RD_03_SWD_PC                                                    float64
#  325  pct_L2_RD_03_WH7_PC                                                    float64
#  326  pct_L2_RD_04_ALL_PC                                                    float64
#  327  pct_L2_RD_04_BL7_PC                                                    float64
#  328  pct_L2_RD_04_EDS_PC                                                    float64
#  329  pct_L2_RD_04_FEM_PC                                                    float64
#  330  pct_L2_RD_04_HI7_PC                                                    float64
#  331  pct_L2_RD_04_MALE_PC                                                   float64
#  332  pct_L2_RD_04_SWD_PC                                                    float64
#  333  pct_L2_RD_04_WH7_PC                                                    float64
#  334  pct_L2_RD_05_ALL_PC                                                    float64
#  335  pct_L2_RD_05_BL7_PC                                                    float64
#  336  pct_L2_RD_05_EDS_PC                                                    float64
#  337  pct_L2_RD_05_FEM_PC                                                    float64
#  338  pct_L2_RD_05_HI7_PC                                                    float64
#  339  pct_L2_RD_05_MALE_PC                                                   float64
#  340  pct_L2_RD_05_SWD_PC                                                    float64
#  341  pct_L2_RD_05_WH7_PC                                                    float64
#  342  pct_L2_RD_ALL_ALL_PC                                                   float64
#  343  pct_L2_RD_ALL_BL7_PC                                                   float64
#  344  pct_L2_RD_ALL_EDS_PC                                                   float64
#  345  pct_L2_RD_ALL_ELS_PC                                                   float64
#  346  pct_L2_RD_ALL_FEM_PC                                                   float64
#  347  pct_L2_RD_ALL_HI7_PC                                                   float64
#  348  pct_L2_RD_ALL_MALE_PC                                                  float64
#  349  pct_L2_RD_ALL_MU7_PC                                                   float64
#  350  pct_L2_RD_ALL_SWD_PC                                                   float64
#  351  pct_L2_RD_ALL_WH7_PC                                                   float64
#  352  pct_L2_SC_05_ALL_PC                                                    float64
#  353  pct_L2_SC_05_MALE_PC                                                   float64
#  354  pct_L2_SC_05_SWD_PC                                                    float64
#  355  pct_L2_SC_ALL_ALL_PC                                                   float64
#  356  pct_L2_SC_ALL_BL7_PC                                                   float64
#  357  pct_L2_SC_ALL_EDS_PC                                                   float64
#  358  pct_L2_SC_ALL_FEM_PC                                                   float64
#  359  pct_L2_SC_ALL_HI7_PC                                                   float64
#  360  pct_L2_SC_ALL_MALE_PC                                                  float64
#  361  pct_L2_SC_ALL_SWD_PC                                                   float64
#  362  pct_L2_SC_ALL_WH7_PC                                                   float64
#  363  pct_L3_EOG_03_ALL_PC                                                   float64
#  364  pct_L3_EOG_03_BL7_PC                                                   float64
#  365  pct_L3_EOG_03_EDS_PC                                                   float64
#  366  pct_L3_EOG_03_ELS_PC                                                   float64
#  367  pct_L3_EOG_03_FEM_PC                                                   float64
#  368  pct_L3_EOG_03_HI7_PC                                                   float64
#  369  pct_L3_EOG_03_MALE_PC                                                  float64
#  370  pct_L3_EOG_03_SWD_PC                                                   float64
#  371  pct_L3_EOG_03_WH7_PC                                                   float64
#  372  pct_L3_EOG_04_ALL_PC                                                   float64
#  373  pct_L3_EOG_04_BL7_PC                                                   float64
#  374  pct_L3_EOG_04_EDS_PC                                                   float64
#  375  pct_L3_EOG_04_ELS_PC                                                   float64
#  376  pct_L3_EOG_04_FEM_PC                                                   float64
#  377  pct_L3_EOG_04_HI7_PC                                                   float64
#  378  pct_L3_EOG_04_MALE_PC                                                  float64
#  379  pct_L3_EOG_04_SWD_PC                                                   float64
#  380  pct_L3_EOG_04_WH7_PC                                                   float64
#  381  pct_L3_EOG_05_ALL_PC                                                   float64
#  382  pct_L3_EOG_05_BL7_PC                                                   float64
#  383  pct_L3_EOG_05_EDS_PC                                                   float64
#  384  pct_L3_EOG_05_ELS_PC                                                   float64
#  385  pct_L3_EOG_05_FEM_PC                                                   float64
#  386  pct_L3_EOG_05_HI7_PC                                                   float64
#  387  pct_L3_EOG_05_MALE_PC                                                  float64
#  388  pct_L3_EOG_05_SWD_PC                                                   float64
#  389  pct_L3_EOG_05_WH7_PC                                                   float64
#  390  pct_L3_EOG_ALL_ALL_PC                                                  float64
#  391  pct_L3_EOG_ALL_BL7_PC                                                  float64
#  392  pct_L3_EOG_ALL_EDS_PC                                                  float64
#  393  pct_L3_EOG_ALL_ELS_PC                                                  float64
#  394  pct_L3_EOG_ALL_FEM_PC                                                  float64
#  395  pct_L3_EOG_ALL_HI7_PC                                                  float64
#  396  pct_L3_EOG_ALL_MALE_PC                                                 float64
#  397  pct_L3_EOG_ALL_MU7_PC                                                  float64
#  398  pct_L3_EOG_ALL_SWD_PC                                                  float64
#  399  pct_L3_EOG_ALL_WH7_PC                                                  float64
#  400  pct_L3_MA_03_ALL_PC                                                    float64
#  401  pct_L3_MA_03_BL7_PC                                                    float64
#  402  pct_L3_MA_03_EDS_PC                                                    float64
#  403  pct_L3_MA_03_FEM_PC                                                    float64
#  404  pct_L3_MA_03_HI7_PC                                                    float64
#  405  pct_L3_MA_03_MALE_PC                                                   float64
#  406  pct_L3_MA_03_WH7_PC                                                    float64
#  407  pct_L3_MA_04_ALL_PC                                                    float64
#  408  pct_L3_MA_04_BL7_PC                                                    float64
#  409  pct_L3_MA_04_EDS_PC                                                    float64
#  410  pct_L3_MA_04_FEM_PC                                                    float64
#  411  pct_L3_MA_04_MALE_PC                                                   float64
#  412  pct_L3_MA_04_WH7_PC                                                    float64
#  413  pct_L3_MA_05_ALL_PC                                                    float64
#  414  pct_L3_MA_05_EDS_PC                                                    float64
#  415  pct_L3_MA_05_FEM_PC                                                    float64
#  416  pct_L3_MA_05_MALE_PC                                                   float64
#  417  pct_L3_MA_05_WH7_PC                                                    float64
#  418  pct_L3_MA_ALL_ALL_PC                                                   float64
#  419  pct_L3_MA_ALL_BL7_PC                                                   float64
#  420  pct_L3_MA_ALL_EDS_PC                                                   float64
#  421  pct_L3_MA_ALL_ELS_PC                                                   float64
#  422  pct_L3_MA_ALL_FEM_PC                                                   float64
#  423  pct_L3_MA_ALL_HI7_PC                                                   float64
#  424  pct_L3_MA_ALL_MALE_PC                                                  float64
#  425  pct_L3_MA_ALL_SWD_PC                                                   float64
#  426  pct_L3_MA_ALL_WH7_PC                                                   float64
#  427  pct_L3_RD_03_ALL_PC                                                    float64
#  428  pct_L3_RD_03_BL7_PC                                                    float64
#  429  pct_L3_RD_03_EDS_PC                                                    float64
#  430  pct_L3_RD_03_FEM_PC                                                    float64
#  431  pct_L3_RD_03_HI7_PC                                                    float64
#  432  pct_L3_RD_03_MALE_PC                                                   float64
#  433  pct_L3_RD_03_WH7_PC                                                    float64
#  434  pct_L3_RD_04_ALL_PC                                                    float64
#  435  pct_L3_RD_04_BL7_PC                                                    float64
#  436  pct_L3_RD_04_EDS_PC                                                    float64
#  437  pct_L3_RD_04_FEM_PC                                                    float64
#  438  pct_L3_RD_04_HI7_PC                                                    float64
#  439  pct_L3_RD_04_MALE_PC                                                   float64
#  440  pct_L3_RD_04_WH7_PC                                                    float64
#  441  pct_L3_RD_05_ALL_PC                                                    float64
#  442  pct_L3_RD_05_BL7_PC                                                    float64
#  443  pct_L3_RD_05_EDS_PC                                                    float64
#  444  pct_L3_RD_05_FEM_PC                                                    float64
#  445  pct_L3_RD_05_HI7_PC                                                    float64
#  446  pct_L3_RD_05_MALE_PC                                                   float64
#  447  pct_L3_RD_05_WH7_PC                                                    float64
#  448  pct_L3_RD_ALL_ALL_PC                                                   float64
#  449  pct_L3_RD_ALL_BL7_PC                                                   float64
#  450  pct_L3_RD_ALL_EDS_PC                                                   float64
#  451  pct_L3_RD_ALL_ELS_PC                                                   float64
#  452  pct_L3_RD_ALL_FEM_PC                                                   float64
#  453  pct_L3_RD_ALL_HI7_PC                                                   float64
#  454  pct_L3_RD_ALL_MALE_PC                                                  float64
#  455  pct_L3_RD_ALL_MU7_PC                                                   float64
#  456  pct_L3_RD_ALL_SWD_PC                                                   float64
#  457  pct_L3_RD_ALL_WH7_PC                                                   float64
#  458  pct_L3_SC_05_ALL_PC                                                    float64
#  459  pct_L3_SC_05_FEM_PC                                                    float64
#  460  pct_L3_SC_ALL_ALL_PC                                                   float64
#  461  pct_L3_SC_ALL_BL7_PC                                                   float64
#  462  pct_L3_SC_ALL_EDS_PC                                                   float64
#  463  pct_L3_SC_ALL_FEM_PC                                                   float64
#  464  pct_L3_SC_ALL_HI7_PC                                                   float64
#  465  pct_L3_SC_ALL_MALE_PC                                                  float64
#  466  pct_L3_SC_ALL_WH7_PC                                                   float64
#  467  pct_L4_EOG_03_ALL_PC                                                   float64
#  468  pct_L4_EOG_03_BL7_PC                                                   float64
#  469  pct_L4_EOG_03_EDS_PC                                                   float64
#  470  pct_L4_EOG_03_ELS_PC                                                   float64
#  471  pct_L4_EOG_03_FEM_PC                                                   float64
#  472  pct_L4_EOG_03_HI7_PC                                                   float64
#  473  pct_L4_EOG_03_MALE_PC                                                  float64
#  474  pct_L4_EOG_03_SWD_PC                                                   float64
#  475  pct_L4_EOG_03_WH7_PC                                                   float64
#  476  pct_L4_EOG_04_AIG_PC                                                   float64
#  477  pct_L4_EOG_04_ALL_PC                                                   float64
#  478  pct_L4_EOG_04_BL7_PC                                                   float64
#  479  pct_L4_EOG_04_EDS_PC                                                   float64
#  480  pct_L4_EOG_04_ELS_PC                                                   float64
#  481  pct_L4_EOG_04_FEM_PC                                                   float64
#  482  pct_L4_EOG_04_HI7_PC                                                   float64
#  483  pct_L4_EOG_04_MALE_PC                                                  float64
#  484  pct_L4_EOG_04_SWD_PC                                                   float64
#  485  pct_L4_EOG_04_WH7_PC                                                   float64
#  486  pct_L4_EOG_05_AIG_PC                                                   float64
#  487  pct_L4_EOG_05_ALL_PC                                                   float64
#  488  pct_L4_EOG_05_BL7_PC                                                   float64
#  489  pct_L4_EOG_05_EDS_PC                                                   float64
#  490  pct_L4_EOG_05_ELS_PC                                                   float64
#  491  pct_L4_EOG_05_FEM_PC                                                   float64
#  492  pct_L4_EOG_05_HI7_PC                                                   float64
#  493  pct_L4_EOG_05_MALE_PC                                                  float64
#  494  pct_L4_EOG_05_MU7_PC                                                   float64
#  495  pct_L4_EOG_05_SWD_PC                                                   float64
#  496  pct_L4_EOG_05_WH7_PC                                                   float64
#  497  pct_L4_EOG_ALL_AIG_PC                                                  float64
#  498  pct_L4_EOG_ALL_BL7_PC                                                  float64
#  499  pct_L4_EOG_ALL_EDS_PC                                                  float64
#  500  pct_L4_EOG_ALL_ELS_PC                                                  float64
#  501  pct_L4_EOG_ALL_FEM_PC                                                  float64
#  502  pct_L4_EOG_ALL_HI7_PC                                                  float64
#  503  pct_L4_EOG_ALL_MALE_PC                                                 float64
#  504  pct_L4_EOG_ALL_MU7_PC                                                  float64
#  505  pct_L4_EOG_ALL_SWD_PC                                                  float64
#  506  pct_L4_EOG_ALL_WH7_PC                                                  float64
#  507  pct_L4_MA_03_ALL_PC                                                    float64
#  508  pct_L4_MA_03_BL7_PC                                                    float64
#  509  pct_L4_MA_03_EDS_PC                                                    float64
#  510  pct_L4_MA_03_FEM_PC                                                    float64
#  511  pct_L4_MA_03_HI7_PC                                                    float64
#  512  pct_L4_MA_03_MALE_PC                                                   float64
#  513  pct_L4_MA_03_SWD_PC                                                    float64
#  514  pct_L4_MA_03_WH7_PC                                                    float64
#  515  pct_L4_MA_04_ALL_PC                                                    float64
#  516  pct_L4_MA_04_BL7_PC                                                    float64
#  517  pct_L4_MA_04_EDS_PC                                                    float64
#  518  pct_L4_MA_04_FEM_PC                                                    float64
#  519  pct_L4_MA_04_HI7_PC                                                    float64
#  520  pct_L4_MA_04_MALE_PC                                                   float64
#  521  pct_L4_MA_04_SWD_PC                                                    float64
#  522  pct_L4_MA_04_WH7_PC                                                    float64
#  523  pct_L4_MA_05_AIG_PC                                                    float64
#  524  pct_L4_MA_05_ALL_PC                                                    float64
#  525  pct_L4_MA_05_BL7_PC                                                    float64
#  526  pct_L4_MA_05_EDS_PC                                                    float64
#  527  pct_L4_MA_05_FEM_PC                                                    float64
#  528  pct_L4_MA_05_HI7_PC                                                    float64
#  529  pct_L4_MA_05_MALE_PC                                                   float64
#  530  pct_L4_MA_05_WH7_PC                                                    float64
#  531  pct_L4_MA_ALL_AIG_PC                                                   float64
#  532  pct_L4_MA_ALL_BL7_PC                                                   float64
#  533  pct_L4_MA_ALL_EDS_PC                                                   float64
#  534  pct_L4_MA_ALL_ELS_PC                                                   float64
#  535  pct_L4_MA_ALL_FEM_PC                                                   float64
#  536  pct_L4_MA_ALL_HI7_PC                                                   float64
#  537  pct_L4_MA_ALL_MALE_PC                                                  float64
#  538  pct_L4_MA_ALL_MU7_PC                                                   float64
#  539  pct_L4_MA_ALL_SWD_PC                                                   float64
#  540  pct_L4_MA_ALL_WH7_PC                                                   float64
#  541  pct_L4_RD_03_ALL_PC                                                    float64
#  542  pct_L4_RD_03_BL7_PC                                                    float64
#  543  pct_L4_RD_03_EDS_PC                                                    float64
#  544  pct_L4_RD_03_FEM_PC                                                    float64
#  545  pct_L4_RD_03_HI7_PC                                                    float64
#  546  pct_L4_RD_03_MALE_PC                                                   float64
#  547  pct_L4_RD_03_WH7_PC                                                    float64
#  548  pct_L4_RD_04_ALL_PC                                                    float64
#  549  pct_L4_RD_04_BL7_PC                                                    float64
#  550  pct_L4_RD_04_EDS_PC                                                    float64
#  551  pct_L4_RD_04_FEM_PC                                                    float64
#  552  pct_L4_RD_04_HI7_PC                                                    float64
#  553  pct_L4_RD_04_MALE_PC                                                   float64
#  554  pct_L4_RD_04_SWD_PC                                                    float64
#  555  pct_L4_RD_04_WH7_PC                                                    float64
#  556  pct_L4_RD_05_AIG_PC                                                    float64
#  557  pct_L4_RD_05_ALL_PC                                                    float64
#  558  pct_L4_RD_05_BL7_PC                                                    float64
#  559  pct_L4_RD_05_EDS_PC                                                    float64
# ...
#  946  subgroup_list_ALL,BL7,EDS                                              uint8
#  947  subgroup_list_ALL,BL7,EDS,ELS,HI7                                      uint8
#  948  subgroup_list_ALL,BL7,EDS,ELS,HI7,MU7,SWD,WH7                          uint8
#  949  subgroup_list_ALL,BL7,EDS,ELS,HI7,MU7,WH7                              uint8
#  950  subgroup_list_ALL,BL7,EDS,ELS,HI7,SWD                                  uint8
#  951  subgroup_list_ALL,BL7,EDS,ELS,HI7,SWD,WH7                              uint8
#  952  subgroup_list_ALL,BL7,EDS,ELS,HI7,WH7                                  uint8
#  953  subgroup_list_ALL,BL7,EDS,HI7                                          uint8
#  954  subgroup_list_ALL,BL7,EDS,HI7,MU7,SWD,WH7                              uint8
#  955  subgroup_list_ALL,BL7,EDS,HI7,SWD                                      uint8
#  956  subgroup_list_ALL,BL7,EDS,HI7,SWD,WH7                                  uint8
#  957  subgroup_list_ALL,BL7,EDS,HI7,WH7                                      uint8
#  958  subgroup_list_ALL,BL7,EDS,SWD                                          uint8
#  959  subgroup_list_ALL,BL7,EDS,SWD,WH7                                      uint8
#  960  subgroup_list_ALL,BL7,EDS,WH7                                          uint8
#  961  subgroup_list_ALL,BL7,SWD                                              uint8
#  962  subgroup_list_ALL,EDS                                                  uint8
#  963  subgroup_list_ALL,EDS,ELS,HI7                                          uint8
#  964  subgroup_list_ALL,EDS,ELS,HI7,SWD,WH7                                  uint8
#  965  subgroup_list_ALL,EDS,ELS,HI7,WH7                                      uint8
#  966  subgroup_list_ALL,EDS,HI7,SWD,WH7                                      uint8
#  967  subgroup_list_ALL,EDS,HI7,WH7                                          uint8
#  968  subgroup_list_ALL,EDS,SWD                                              uint8
#  969  subgroup_list_ALL,EDS,SWD,WH7                                          uint8
#  970  subgroup_list_ALL,EDS,WH7                                              uint8
#  971  subgroup_list_ALL,HI7,SWD,WH7                                          uint8
#  972  subgroup_list_ALL,SWD                                                  uint8
#  973  subgroup_list_ALL,SWD,WH7                                              uint8
#  974  subgroup_list_ALL,WH7                                                  uint8
#  975  dance_cat_Y                                                            uint8
#  976  music_cat_Y                                                            uint8
#  977  theatre_cat_Y                                                          uint8
#  978  va_cat_Y                                                               uint8
#  979  digital_media_0                                                        uint8
#  980  digital_media_1                                                        uint8
#  981  digital_media_10                                                       uint8
#  982  digital_media_11                                                       uint8
#  983  digital_media_12                                                       uint8
#  984  digital_media_13                                                       uint8
#  985  digital_media_14                                                       uint8
#  986  digital_media_15                                                       uint8
#  987  digital_media_16                                                       uint8
#  988  digital_media_17                                                       uint8
#  989  digital_media_2                                                        uint8
#  990  digital_media_20                                                       uint8
#  991  digital_media_22                                                       uint8
#  992  digital_media_23                                                       uint8
#  993  digital_media_25                                                       uint8
#  994  digital_media_27                                                       uint8
#  995  digital_media_28                                                       uint8
#  996  digital_media_3                                                        uint8
#  997  digital_media_30                                                       uint8
#  998  digital_media_31                                                       uint8
#  999  digital_media_32                                                       uint8
#  1000 digital_media_33                                                       uint8
#  1001 digital_media_35                                                       uint8
#  1002 digital_media_38                                                       uint8
#  1003 digital_media_4                                                        uint8
#  1004 digital_media_5                                                        uint8
#  1005 digital_media_54                                                       uint8
#  1006 digital_media_58                                                       uint8
#  1007 digital_media_6                                                        uint8
#  1008 digital_media_7                                                        uint8
#  1009 digital_media_8                                                        uint8
#  1010 digital_media_9                                                        uint8
#  1011 digital_media_97                                                       uint8
#  1012 digital_media_99                                                       uint8
#  1013 device_access_Yes                                                      uint8
#  1014 device_home_Yes                                                        uint8
#  1015 BYOD_Neither                                                           uint8
#  1016 BYOD_Staff                                                             uint8
#  1017 BYOD_Students                                                          uint8
#  1018 agency_lea_code_020LEA                                                 uint8
#  1019 agency_lea_code_030LEA                                                 uint8
#  1020 agency_lea_code_040LEA                                                 uint8
#  1021 agency_lea_code_050LEA                                                 uint8
#  1022 agency_lea_code_060LEA                                                 uint8
#  1023 agency_lea_code_070LEA                                                 uint8
#  1024 agency_lea_code_080LEA                                                 uint8
#  1025 agency_lea_code_090LEA                                                 uint8
#  1026 agency_lea_code_100LEA                                                 uint8
#  1027 agency_lea_code_110LEA                                                 uint8
#  1028 agency_lea_code_111LEA                                                 uint8
#  1029 agency_lea_code_120LEA                                                 uint8
#  1030 agency_lea_code_130LEA                                                 uint8
#  1031 agency_lea_code_132LEA                                                 uint8
#  1032 agency_lea_code_140LEA                                                 uint8
#  1033 agency_lea_code_150LEA                                                 uint8
#  1034 agency_lea_code_160LEA                                                 uint8
#  1035 agency_lea_code_170LEA                                                 uint8
#  1036 agency_lea_code_180LEA                                                 uint8
#  1037 agency_lea_code_181LEA                                                 uint8
#  1038 agency_lea_code_182LEA                                                 uint8
#  1039 agency_lea_code_190LEA                                                 uint8
#  1040 agency_lea_code_200LEA                                                 uint8
#  1041 agency_lea_code_210LEA                                                 uint8
#  1042 agency_lea_code_220LEA                                                 uint8
#  1043 agency_lea_code_230LEA                                                 uint8
#  1044 agency_lea_code_240LEA                                                 uint8
#  1045 agency_lea_code_241LEA                                                 uint8
#  1046 agency_lea_code_250LEA                                                 uint8
#  1047 agency_lea_code_260LEA                                                 uint8
#  1048 agency_lea_code_270LEA                                                 uint8
#  1049 agency_lea_code_280LEA                                                 uint8
#  1050 agency_lea_code_290LEA                                                 uint8
#  1051 agency_lea_code_291LEA                                                 uint8
#  1052 agency_lea_code_292LEA                                                 uint8
#  1053 agency_lea_code_300LEA                                                 uint8
#  1054 agency_lea_code_310LEA                                                 uint8
#  1055 agency_lea_code_320LEA                                                 uint8
#  1056 agency_lea_code_330LEA                                                 uint8
#  1057 agency_lea_code_340LEA                                                 uint8
#  1058 agency_lea_code_350LEA                                                 uint8
#  1059 agency_lea_code_360LEA                                                 uint8
#  1060 agency_lea_code_370LEA                                                 uint8
#  1061 agency_lea_code_380LEA                                                 uint8
#  1062 agency_lea_code_390LEA                                                 uint8
#  1063 agency_lea_code_400LEA                                                 uint8
#  1064 agency_lea_code_410LEA                                                 uint8
#  1065 agency_lea_code_420LEA                                                 uint8
#  1066 agency_lea_code_421LEA                                                 uint8
#  1067 agency_lea_code_422LEA                                                 uint8
#  1068 agency_lea_code_430LEA                                                 uint8
#  1069 agency_lea_code_440LEA                                                 uint8
#  1070 agency_lea_code_450LEA                                                 uint8
#  1071 agency_lea_code_460LEA                                                 uint8
#  1072 agency_lea_code_470LEA                                                 uint8
#  1073 agency_lea_code_480LEA                                                 uint8
#  1074 agency_lea_code_490LEA                                                 uint8
#  1075 agency_lea_code_491LEA                                                 uint8
#  1076 agency_lea_code_500LEA                                                 uint8
#  1077 agency_lea_code_510LEA                                                 uint8
#  1078 agency_lea_code_520LEA                                                 uint8
#  1079 agency_lea_code_530LEA                                                 uint8
#  1080 agency_lea_code_540LEA                                                 uint8
#  1081 agency_lea_code_550LEA                                                 uint8
#  1082 agency_lea_code_560LEA                                                 uint8
#  1083 agency_lea_code_570LEA                                                 uint8
#  1084 agency_lea_code_580LEA                                                 uint8
#  1085 agency_lea_code_590LEA                                                 uint8
#  1086 agency_lea_code_600LEA                                                 uint8
#  1087 agency_lea_code_610LEA                                                 uint8
#  1088 agency_lea_code_620LEA                                                 uint8
#  1089 agency_lea_code_630LEA                                                 uint8
#  1090 agency_lea_code_640LEA                                                 uint8
#  1091 agency_lea_code_650LEA                                                 uint8
#  1092 agency_lea_code_660LEA                                                 uint8
#  1093 agency_lea_code_670LEA                                                 uint8
#  1094 agency_lea_code_680LEA                                                 uint8
#  1095 agency_lea_code_681LEA                                                 uint8
#  1096 agency_lea_code_690LEA                                                 uint8
#  1097 agency_lea_code_700LEA                                                 uint8
#  1098 agency_lea_code_710LEA                                                 uint8
#  1099 agency_lea_code_720LEA                                                 uint8
#  1100 agency_lea_code_730LEA                                                 uint8
#  1101 agency_lea_code_740LEA                                                 uint8
#  1102 agency_lea_code_750LEA                                                 uint8
#  1103 agency_lea_code_760LEA                                                 uint8
#  1104 agency_lea_code_761LEA                                                 uint8
#  1105 agency_lea_code_770LEA                                                 uint8
#  1106 agency_lea_code_780LEA                                                 uint8
#  1107 agency_lea_code_790LEA                                                 uint8
#  1108 agency_lea_code_800LEA                                                 uint8
#  1109 agency_lea_code_810LEA                                                 uint8
#  1110 agency_lea_code_820LEA                                                 uint8
#  1111 agency_lea_code_821LEA                                                 uint8
#  1112 agency_lea_code_830LEA                                                 uint8
#  1113 agency_lea_code_840LEA                                                 uint8
#  1114 agency_lea_code_850LEA                                                 uint8
#  1115 agency_lea_code_860LEA                                                 uint8
#  1116 agency_lea_code_861LEA                                                 uint8
#  1117 agency_lea_code_862LEA                                                 uint8
#  1118 agency_lea_code_870LEA                                                 uint8
#  1119 agency_lea_code_880LEA                                                 uint8
#  1120 agency_lea_code_890LEA                                                 uint8
#  1121 agency_lea_code_900LEA                                                 uint8
#  1122 agency_lea_code_910LEA                                                 uint8
#  1123 agency_lea_code_920LEA                                                 uint8
#  1124 agency_lea_code_930LEA                                                 uint8
#  1125 agency_lea_code_940LEA                                                 uint8
#  1126 agency_lea_code_950LEA                                                 uint8
#  1127 agency_lea_code_960LEA                                                 uint8
#  1128 agency_lea_code_970LEA                                                 uint8
#  1129 agency_lea_code_980LEA                                                 uint8
#  1130 agency_lea_code_990LEA                                                 uint8
#  1131 agency_lea_code_995LEA                                                 uint8
#  1132 agency_code                                                            object
# dtypes: float64(816), object(1), uint8(316)
# memory usage: 9.3+ MB

# %%
import sklearn
import pandas as pd

print('Sklearn Version: ' + sklearn.__version__)
print('Pandas Version: ' + pd.__version__)
# Out:
# Sklearn Version: 0.22.1
# Pandas Version: 1.0.3

# %%
print('Output File Location:\r\n\r\n' + outputDir + inputFileName + '_ML.csv')
# Out:
# Output File Location:
#
# D:/BenepactLLC/Belk/NC_Report_Card_Data/2020/June 2020/2018/Machine Learning Datasets/PublicElementarySchools2018_ML.csv
