# %% [markdown]
# # Create Public School Machine Learning Datasets
# ** This program creates all the _ML datasets in the NCEA repository.**
# * This notebook reads each School Dataset file located at \EducationDataNC\ *schoolYear* \School Datasets\ as input data.
# * Different school years are processed by changing the *schoolYear* parameter.
# * Different input / output files are processed / created by changing the *inputFileName* paramter in the cell below.
# * While a single program is used to create all the _ML datasets, one program copy per dataset is maintained in the repositiory so the dataset specific tranformation reports may be reviewed.
#
# **Datasets ending in ML are preprocessed for Machine Learning and go through the following transformations: **
# 1. Missing student body racial compositions are imputed using district averages.
# 2. Columns that have the same value in every single row are deleted.
# 3. Columns that have a unique value in every single row (all values are different) are deleted.
# 4. Empty columns (all values are NA or NULL) are deleted.
# 5. Numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# 6. Remaining numeric, non-race columns with missing values are imputed / populated with 0.  In many cases, schools are not reporting values when they are zero. However, mean imputation or some other more sophisticated strategy might be considered here.
# 7. Categorical / text based columns with > *uniqueThreshold* unique values are deleted.
# 8. All remaining categorical / text based columns are one-hot encoded.  In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# 9. Duplicated or highly similar columns with > 95% correlation are delelted.

# %%
#import required Libraries
import pandas as pd
import numpy as np
import os
import string

#**********************************************************************************
# Set the following variables before running this code!!!
#**********************************************************************************
#All raw data files are processed for the year below
schoolYear = 2018

#Location where copies of the raw data files will be read in from csv files.
dataDir = 'C:/Users/Jake/Documents/GitHub/EducationDataNC/' + str(schoolYear) + '/School Datasets/'

#Name of the file to be processed
#inputFileName = 'PublicSchools2018'
#inputFileName = 'PublicHighSchools2018'
#inputFileName = 'PublicMiddleSchools2018'
inputFileName = 'PublicElementarySchools2018'

#Input file being transformed for machine learning 
inputFile = dataDir + inputFileName + '.csv'

#Location where the new school datasets will be created.
outputDir = 'C:/Users/Jake/Documents/GitHub/EducationDataNC/' + str(schoolYear) + '/Machine Learning Datasets/'

#Missing Data Threshold (Per Column)
missingThreshold = 0.60

#Unique Value Threshold (Per Column)
#Delete Columns >  uniqueThreshold unique values prior to one-hot encoding. 
#(each unique value becomes a new column during one-hot encoding)
uniqueThreshold = 200

#Read in the School Data File
schoolData = pd.read_csv(inputFile, low_memory=False, dtype={'agency_code': object})
print('*********Start: Beginning Column and Row Counts********************************************')
schoolData.info(verbose=False)

#Select only public schools as charter schools are missing data for many columns.
schoolData = schoolData[(schoolData['designation_type'] == 'P') & (schoolData['avg_student_num'] > 0)]

print('\r\n*********After: Selecting Only Public School Campuses**********************************')
schoolData.info(verbose=False)

#Save primary key
agency_code = schoolData['agency_code']
#Convert zip code to string
schoolData['zip'] = schoolData['zip'].astype('object')
# Out:
# *********Start: Beginning Column and Row Counts********************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1575 entries, 0 to 1574
# Columns: 5243 entries, agency_code to lea_federal_perpupil
# dtypes: float64(5192), object(51)
# memory usage: 63.0+ MB
#
# *********After: Selecting Only Public School Campuses**********************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1422 entries, 2 to 1574
# Columns: 5243 entries, agency_code to lea_federal_perpupil
# dtypes: float64(5192), object(51)
# memory usage: 56.9+ MB

# %% [markdown]
# # Prepare Consolidated Dataset for Machine Learning
# **Below we perform operations on the entire dataset to remove columns and update row values that could cause problems during machine learning.**

# %% [markdown]
# ## Student Body Racial Composition Features
# **Impute / update missing Student Body Racial Composition Fields using mean imputation.**
# * When there are no racial composition percentages for a particular school campus / agency_code, fill in the missing values

# %%
#Get Student Body Racial Composition Fields
raceCompositionFields = schoolData.filter(regex='Indian|Asian|Hispanic|Black|White|PacificIsland|TwoOrMore|Minority')\
                                  .filter(regex='Pct').columns
    
rowsBefore = schoolData[raceCompositionFields].isnull().T.any().T.sum()

#Update missing race values with the district average when avaiable (No district averages for charter schools) 
schoolData[raceCompositionFields] = schoolData.groupby('lea_code')[raceCompositionFields]\
                                              .transform(lambda x: x.fillna(x.mean()))

    #Review dataset contents after Racial Composition Imputation
print('*********After: Updating Missing Racial Compostion Values****************************')   
rowsAfter = schoolData[raceCompositionFields].isnull().T.any().T.sum()
rowsUpdated = rowsBefore - rowsAfter
print('Rows Updated / Imputed: ', rowsUpdated) 
print('\r\nTotal Rows Missing Racial Compositions By District Code') 
schoolData['lea_code'][schoolData[raceCompositionFields].isnull().T.any().T].value_counts()
# Out:
# *********After: Updating Missing Racial Compostion Values****************************
# Rows Updated / Imputed:  2
#
# Total Rows Missing Racial Compositions By District Code
# Series([], Name: lea_code, dtype: int64)

# %% [markdown]
# ## Remove Columns with Problematic Data
# **Here we remove entire columns that could cause problems during machine learning.  The following operations are performed:**
# * Remove any columns that have the same value in every single row.
# * Remove any columns that have a unique value in every single row (all values are different).
# * Remove empty columns (all values are NA or NULL).

# %%
#Remove any fields that have the same value in all rows
UniqueValueCounts = schoolData.nunique(dropna=False)
SingleValueCols = UniqueValueCounts[UniqueValueCounts == 1].index
schoolData = schoolData.drop(SingleValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with the same value in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(SingleValueCols))
# Out:
# *********After: Removing columns with the same value in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1422 entries, 2 to 1574
# Columns: 3620 entries, agency_code to lea_federal_perpupil
# dtypes: float64(3573), object(47)
# memory usage: 39.3+ MB
#
# Columns Deleted:  1623

# %%
#Remove any fields that have unique values in every row
schoolDataRecordCt = schoolData.shape[0]
UniqueValueCounts = schoolData.apply(pd.Series.nunique)
AllUniqueValueCols = UniqueValueCounts[UniqueValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(AllUniqueValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with unique values in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(AllUniqueValueCols))
# Out:
# *********After: Removing columns with unique values in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1422 entries, 2 to 1574
# Columns: 3618 entries, category_code to lea_federal_perpupil
# dtypes: float64(3573), object(45)
# memory usage: 39.3+ MB
#
# Columns Deleted:  2

# %%
#Remove any empty fields (null values in every row)
schoolDataRecordCt = schoolData.shape[0]
NullValueCounts = schoolData.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with null / blank values in every row.*************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with null / blank values in every row.*************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1422 entries, 2 to 1574
# Columns: 3618 entries, category_code to lea_federal_perpupil
# dtypes: float64(3573), object(45)
# memory usage: 39.3+ MB
#
# Columns Deleted:  0

# %% [markdown]
# ## Handle Other Missing Values Types
# * Here we eliminate any numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# * All remaining non-race, numeric column missing values are populated with 0.
# * In many cases, it seems that schools are not simply not reporting values when they are zero. However, mean imputation or some other strategy might be considered.

# %%
#Isolate continuous and categorical data types
#These are indexers into the schoolData dataframe and may be used similar to the schoolData dataframe 
sD_boolean = schoolData.loc[:, (schoolData.dtypes == bool) ]
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]
sD_continuous = schoolData.loc[:, (schoolData.dtypes != bool) & (schoolData.dtypes != object)]
print ("Boolean Columns: ", sD_boolean.shape[1])
print ("Nominal Columns: ", sD_nominal.shape[1])
print ("Continuous Columns: ", sD_continuous.shape[1])
print ("Columns Accounted for: ", sD_nominal.shape[1] + sD_continuous.shape[1] + sD_boolean.shape[1])
# Out:
# Boolean Columns:  0
# Nominal Columns:  45
# Continuous Columns:  3573
# Columns Accounted for:  3618

# %%
#Eliminate continuous columns with more than missingThreshold percentage of missing values
schoolDataRecordCt = sD_continuous.shape[0]
missingValueLimit = schoolDataRecordCt * missingThreshold
NullValueCounts = sD_continuous.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts >= missingValueLimit].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with >= missingThreshold % of missing values******')
schoolData.info(verbose=False)
print('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with >= missingThreshold % of missing values******
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1422 entries, 2 to 1574
# Columns: 1179 entries, category_code to lea_federal_perpupil
# dtypes: float64(1134), object(45)
# memory usage: 12.8+ MB
#
# Columns Deleted:  2439

# %% [markdown]
# ## One-Hot Encoding of Categorical Variables
# **All categorical / string variables are converted to numberic variables via one hot encoding.  Each unique row value will become a new binary / numeric column in the dataset.**
# * All remaining categorical columns are one-hot encoded.
# * In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# * Prior to one-hot encoding, columns with > *uniqueThreshold* unique values are deleted.

# %%
#Delete categorical columns with > uniqueThreshold unique values 
#(Each unique value becomes a column during one-hot encoding)
oneHotUniqueValueCounts = schoolData[sD_nominal.columns].apply(lambda x: x.nunique())
oneHotUniqueValueCols = oneHotUniqueValueCounts[oneHotUniqueValueCounts >= uniqueThreshold].index
schoolData.drop(oneHotUniqueValueCols, axis=1, inplace=True) 

#Remove categorical columns which do not add value to machine learning
#Grades columns dropped since they all have indicator fields (device_access, device_home, BYOD)
#with less unique values to one-hot encode
schoolData.drop(['welcome_url','device_access_grades',
                 'device_home_grades','byod_grades'], axis=1, inplace=True) 

#Review dataset contents one hot high unique value drops
print('*********After: Removing columns with >= uniqueThreshold unique values***********')
schoolData.info(verbose=False)
print('\r\nColumns Deleted: ', len(oneHotUniqueValueCols))
print(oneHotUniqueValueCols)
print('Dropped Manually: welcome_url,device_access_grades,device_home_grades,byod_grades')
# Out:
# *********After: Removing columns with >= uniqueThreshold unique values***********
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1422 entries, 2 to 1574
# Columns: 1169 entries, category_code to lea_federal_perpupil
# dtypes: float64(1134), object(35)
# memory usage: 12.7+ MB
#
# Columns Deleted:  6
# Index(['street_addr', 'city', 'zip', 'phone', 'url', 'School Name'], dtype='object')
# Dropped Manually: welcome_url,device_access_grades,device_home_grades,byod_grades

# %%
#Isolate remaining categorical variables
begColumnCt = len(schoolData.columns)
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]

#one hot encode categorical variables
schoolData = pd.get_dummies(data=schoolData, 
                       columns=sD_nominal.columns, drop_first=True)

#Determine change in column count
endColumnCt = len(schoolData.columns)
columnsAdded = endColumnCt - begColumnCt

#Review dataset contents one hot high unique value drops
print('Columns To One-Hot Encode: ', len(sD_nominal.columns))
print('\r\n*********After: Adding New Columns Via One-Hot Encoding*************************')
schoolData.info(verbose=False)
print('\r\nNew Columns Created Via One-Hot Encoding: ', columnsAdded)
# Out:
# Columns To One-Hot Encode:  35
#
# *********After: Adding New Columns Via One-Hot Encoding*************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1422 entries, 2 to 1574
# Columns: 1637 entries, IndianPct to agency_lea_code_995LEA
# dtypes: float64(1134), uint8(503)
# memory usage: 13.0 MB
#
# New Columns Created Via One-Hot Encoding:  468

# %%
#Remove any fields that have the same value in all rows after one-hot encoding
UniqueValueCounts = schoolData.nunique(dropna=False)
SingleValueCols = UniqueValueCounts[UniqueValueCounts == 1].index
schoolData = schoolData.drop(SingleValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing one-hot encoded columns with the same value in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(SingleValueCols))
# Out:
# *********After: Removing one-hot encoded columns with the same value in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1422 entries, 2 to 1574
# Columns: 1637 entries, IndianPct to agency_lea_code_995LEA
# dtypes: float64(1134), uint8(503)
# memory usage: 13.0 MB
#
# Columns Deleted:  0

# %% [markdown]
# ## Impute any Remaining Missing Values as Zero

# %%
#Print out all the missing value rows
pd.set_option('display.max_rows', 1000)

print('\r\n*********The Remaining Missing Values Below will be set to Zero!*************************')

#Check for Missing values 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# *********The Remaining Missing Values Below will be set to Zero!*************************
#         Variable Name  Number Missing Values
# 24            pct_eds                      1
# 25        pct_ALL_ELP                    391
# 26        pct_EDS_ELP                    560
# 27        pct_ELS_ELP                    391
# 28        pct_FEM_ELP                    682
# ...               ...                    ...
# 1120  avg_size_01_SAR                    250
# 1121  avg_size_02_SAR                    254
# 1122  avg_size_03_SAR                    254
# 1123  avg_size_04_SAR                    202
# 1124  avg_size_05_SAR                    254
#
# [1085 rows x 2 columns]

# %%
#Replace all remaining NaN with 0
schoolData = schoolData.fillna(0)

#Check for Missing values after final imputation 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# Empty DataFrame
# Columns: [Variable Name, Number Missing Values]
# Index: []

# %% [markdown]
# ## Identify and Remove Highly Correlated Features
# **Find and remove any columns / features that are > 95% correlated**
# * https://stackoverflow.com/questions/39409866/correlation-heatmap
# * https://chrisalbon.com/machine_learning/feature_selection/drop_highly_correlated_features/
# * https://codeyarns.com/2015/04/20/how-to-change-font-size-in-seaborn/

# %%
# calculate the correlation matrix
corr_matrix  = schoolData.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
#Get all of the correlation values > 95%
x = np.where(upper > 0.95)

#Display all field combinations with > 95% correlation
cf = pd.DataFrame()
cf['Field1'] = upper.columns[x[1]]
cf['Field2'] = upper.index[x[0]]

#Get the correlation values for every field combination. (There must be a more pythonic way to do this!)
corr = [0] * len(cf)
for i in range(0, len(cf)):
    corr[i] =  upper[cf['Field1'][i]][cf['Field2'][i]] 
    
cf['Correlation'] = corr

print ('There are ', str(len(cf['Field1'])), ' field correlations > 95%.')
cf
# Out:
# There are  938  field correlations > 95%.
#                                   Field1                               Field2  \
# 0                          IndianMalePct                            IndianPct
# 1                        IndianFemalePct                            IndianPct
# 2                           AsianMalePct                             AsianPct
# 3                         AsianFemalePct                             AsianPct
# 4                        HispanicMalePct                          HispanicPct
# 5                      HispanicFemalePct                          HispanicPct
# 6                           BlackMalePct                             BlackPct
# 7                         BlackFemalePct                             BlackPct
# 8                            MinorityPct                             WhitePct
# 9                           WhiteMalePct                             WhitePct
# 10                       MinorityMalePct                             WhitePct
# 11                        WhiteFemalePct                             WhitePct
# 12                     MinorityFemalePct                             WhitePct
# 13                          WhiteMalePct                          MinorityPct
# 14                       MinorityMalePct                          MinorityPct
# 15                        WhiteFemalePct                          MinorityPct
# 16                     MinorityFemalePct                          MinorityPct
# 17                       IndianFemalePct                        IndianMalePct
# 18                        AsianFemalePct                         AsianMalePct
# 19                       MinorityMalePct                         WhiteMalePct
# 20                     MinorityFemalePct                         WhiteMalePct
# 21                        WhiteFemalePct                      MinorityMalePct
# 22                           pct_ELS_ELP                          pct_ALL_ELP
# 23       pct_met_Reading Grades 3-8_PART         pct_met_Math Grades 3-8_PART
# 24            pct_met_Total Targets_PART         pct_met_Math Grades 3-8_PART
# 25      pct_Math Grades 3-8_ALL_PART_DET         pct_met_Math Grades 3-8_PART
# 26   pct_Reading Grades 3-8_ALL_PART_DET         pct_met_Math Grades 3-8_PART
# 27            pct_met_Total Targets_PART      pct_met_Reading Grades 3-8_PART
# 28      pct_Math Grades 3-8_ALL_PART_DET      pct_met_Reading Grades 3-8_PART
# 29   pct_Reading Grades 3-8_ALL_PART_DET      pct_met_Reading Grades 3-8_PART
# 30   pct_Science Grades 5&8_ALL_PART_DET      pct_met_Science Grades 5&8_PART
# 31      pct_Math Grades 3-8_ALL_PART_DET           pct_met_Total Targets_PART
# 32   pct_Reading Grades 3-8_ALL_PART_DET           pct_met_Total Targets_PART
# 33   pct_Reading Grades 3-8_ALL_PART_DET     pct_Math Grades 3-8_ALL_PART_DET
# 34   pct_Reading Grades 3-8_BL7_PART_DET     pct_Math Grades 3-8_BL7_PART_DET
# 35   pct_Reading Grades 3-8_EDS_PART_DET     pct_Math Grades 3-8_EDS_PART_DET
# 36   pct_Reading Grades 3-8_HI7_PART_DET     pct_Math Grades 3-8_HI7_PART_DET
# 37   pct_Reading Grades 3-8_SWD_PART_DET     pct_Math Grades 3-8_SWD_PART_DET
# 38   pct_Reading Grades 3-8_WH7_PART_DET     pct_Math Grades 3-8_WH7_PART_DET
# 39                   scgs_score_WH7_SPG2  pct_Science Grades 5&8_WH7_PART_DET
# 40                 pct_CCR_EOG_03_FEM_PC                pct_CCR_EOG_03_ALL_PC
# 41                pct_CCR_EOG_03_MALE_PC                pct_CCR_EOG_03_ALL_PC
# 42                  pct_CCR_MA_03_ALL_PC                pct_CCR_EOG_03_ALL_PC
# 43                  pct_CCR_RD_03_ALL_PC                pct_CCR_EOG_03_ALL_PC
# 44                 pct_GLP_EOG_03_ALL_PC                pct_CCR_EOG_03_ALL_PC
# 45                  pct_GLP_RD_03_ALL_PC                pct_CCR_EOG_03_ALL_PC
# 46                 pct_GLP_EOG_03_BL7_PC                pct_CCR_EOG_03_BL7_PC
# 47                  pct_L4_EOG_03_BL7_PC                pct_CCR_EOG_03_BL7_PC
# 48                 pct_GLP_EOG_03_EDS_PC                pct_CCR_EOG_03_EDS_PC
# 49                 pct_GLP_EOG_03_ELS_PC                pct_CCR_EOG_03_ELS_PC
# 50                  pct_L4_EOG_03_ELS_PC                pct_CCR_EOG_03_ELS_PC
# 51                 pct_GLP_EOG_03_FEM_PC                pct_CCR_EOG_03_FEM_PC
# 52                 pct_GLP_EOG_03_HI7_PC                pct_CCR_EOG_03_HI7_PC
# 53                pct_GLP_EOG_03_MALE_PC               pct_CCR_EOG_03_MALE_PC
# 54                 pct_GLP_EOG_03_WH7_PC                pct_CCR_EOG_03_WH7_PC
# 55                 pct_GLP_EOG_04_AIG_PC                pct_CCR_EOG_04_AIG_PC
# 56                 pct_CCR_EOG_04_FEM_PC                pct_CCR_EOG_04_ALL_PC
# 57                pct_CCR_EOG_04_MALE_PC                pct_CCR_EOG_04_ALL_PC
# 58                  pct_CCR_MA_04_ALL_PC                pct_CCR_EOG_04_ALL_PC
# 59                  pct_CCR_RD_04_ALL_PC                pct_CCR_EOG_04_ALL_PC
# 60                 pct_GLP_EOG_04_ALL_PC                pct_CCR_EOG_04_ALL_PC
# 61                  pct_GLP_MA_04_ALL_PC                pct_CCR_EOG_04_ALL_PC
# 62                 pct_GLP_EOG_04_BL7_PC                pct_CCR_EOG_04_BL7_PC
# 63                  pct_L4_EOG_04_BL7_PC                pct_CCR_EOG_04_BL7_PC
# 64                 pct_GLP_EOG_04_EDS_PC                pct_CCR_EOG_04_EDS_PC
# 65                  pct_L4_EOG_04_EDS_PC                pct_CCR_EOG_04_EDS_PC
# 66                 pct_GLP_EOG_04_ELS_PC                pct_CCR_EOG_04_ELS_PC
# 67                  pct_L4_EOG_04_ELS_PC                pct_CCR_EOG_04_ELS_PC
# 68                 pct_GLP_EOG_04_FEM_PC                pct_CCR_EOG_04_FEM_PC
# 69                 pct_GLP_EOG_04_HI7_PC                pct_CCR_EOG_04_HI7_PC
# 70                  pct_L4_EOG_04_HI7_PC                pct_CCR_EOG_04_HI7_PC
# 71                pct_GLP_EOG_04_MALE_PC               pct_CCR_EOG_04_MALE_PC
# 72                 pct_GLP_EOG_04_WH7_PC                pct_CCR_EOG_04_WH7_PC
# 73                 pct_GLP_EOG_05_AIG_PC                pct_CCR_EOG_05_AIG_PC
# 74                 pct_CCR_EOG_05_FEM_PC                pct_CCR_EOG_05_ALL_PC
# 75                pct_CCR_EOG_05_MALE_PC                pct_CCR_EOG_05_ALL_PC
# 76                  pct_CCR_MA_05_ALL_PC                pct_CCR_EOG_05_ALL_PC
# 77                  pct_CCR_SC_05_ALL_PC                pct_CCR_EOG_05_ALL_PC
# 78                 pct_CCR_SC_ALL_ALL_PC                pct_CCR_EOG_05_ALL_PC
# 79                 pct_GLP_EOG_05_ALL_PC                pct_CCR_EOG_05_ALL_PC
# 80                 pct_GLP_EOG_05_FEM_PC                pct_CCR_EOG_05_ALL_PC
# 81                pct_GLP_EOG_05_MALE_PC                pct_CCR_EOG_05_ALL_PC
# 82                  pct_GLP_MA_05_ALL_PC                pct_CCR_EOG_05_ALL_PC
# 83                  pct_GLP_RD_05_ALL_PC                pct_CCR_EOG_05_ALL_PC
# 84                 pct_GLP_EOG_05_BL7_PC                pct_CCR_EOG_05_BL7_PC
# 85                  pct_L4_EOG_05_BL7_PC                pct_CCR_EOG_05_BL7_PC
# 86                 pct_GLP_EOG_05_EDS_PC                pct_CCR_EOG_05_EDS_PC
# 87                  pct_L4_EOG_05_EDS_PC                pct_CCR_EOG_05_EDS_PC
# 88                 pct_GLP_EOG_05_ELS_PC                pct_CCR_EOG_05_ELS_PC
# 89                  pct_L4_EOG_05_ELS_PC                pct_CCR_EOG_05_ELS_PC
# 90                 pct_GLP_EOG_05_FEM_PC                pct_CCR_EOG_05_FEM_PC
# 91                 pct_GLP_EOG_05_HI7_PC                pct_CCR_EOG_05_HI7_PC
# 92                  pct_CCR_MA_05_ALL_PC               pct_CCR_EOG_05_MALE_PC
# 93                 pct_GLP_EOG_05_ALL_PC               pct_CCR_EOG_05_MALE_PC
# 94                pct_GLP_EOG_05_MALE_PC               pct_CCR_EOG_05_MALE_PC
# 95                  pct_GLP_MA_05_ALL_PC               pct_CCR_EOG_05_MALE_PC
# 96                 pct_GLP_EOG_05_MU7_PC                pct_CCR_EOG_05_MU7_PC
# 97                 pct_GLP_EOG_05_WH7_PC                pct_CCR_EOG_05_WH7_PC
# 98                pct_GLP_EOG_ALL_AIG_PC               pct_CCR_EOG_ALL_AIG_PC
# 99                pct_CCR_EOG_ALL_FEM_PC               pct_CCR_EOG_ALL_ALL_PC
# 100              pct_CCR_EOG_ALL_MALE_PC               pct_CCR_EOG_ALL_ALL_PC
# 101                pct_CCR_MA_ALL_ALL_PC               pct_CCR_EOG_ALL_ALL_PC
# 102                pct_CCR_MA_ALL_FEM_PC               pct_CCR_EOG_ALL_ALL_PC
# 103               pct_CCR_MA_ALL_MALE_PC               pct_CCR_EOG_ALL_ALL_PC
# 104                pct_CCR_RD_ALL_ALL_PC               pct_CCR_EOG_ALL_ALL_PC
# 105                pct_CCR_RD_ALL_FEM_PC               pct_CCR_EOG_ALL_ALL_PC
# 106               pct_GLP_EOG_ALL_ALL_PC               pct_CCR_EOG_ALL_ALL_PC
# 107               pct_GLP_EOG_ALL_FEM_PC               pct_CCR_EOG_ALL_ALL_PC
# 108              pct_GLP_EOG_ALL_MALE_PC               pct_CCR_EOG_ALL_ALL_PC
# 109                pct_GLP_MA_ALL_ALL_PC               pct_CCR_EOG_ALL_ALL_PC
# 110               pct_GLP_MA_ALL_MALE_PC               pct_CCR_EOG_ALL_ALL_PC
# 111                pct_GLP_RD_ALL_ALL_PC               pct_CCR_EOG_ALL_ALL_PC
# 112                   aaa_score_ALL_SPG2               pct_CCR_EOG_ALL_ALL_PC
# 113                   ach_score_ALL_SPG2               pct_CCR_EOG_ALL_ALL_PC
# 114               pct_GLP_EOG_ALL_BL7_PC               pct_CCR_EOG_ALL_BL7_PC
# 115                pct_L4_ALL_ALL_BL7_PC               pct_CCR_EOG_ALL_BL7_PC
# 116                pct_L4_EOG_ALL_BL7_PC               pct_CCR_EOG_ALL_BL7_PC
# 117                pct_CCR_MA_ALL_EDS_PC               pct_CCR_EOG_ALL_EDS_PC
# 118               pct_GLP_EOG_ALL_EDS_PC               pct_CCR_EOG_ALL_EDS_PC
# 119                pct_L4_ALL_ALL_EDS_PC               pct_CCR_EOG_ALL_EDS_PC
# 120                pct_L4_EOG_ALL_EDS_PC               pct_CCR_EOG_ALL_EDS_PC
# 121               pct_GLP_EOG_ALL_ELS_PC               pct_CCR_EOG_ALL_ELS_PC
# 122                pct_L4_ALL_ALL_ELS_PC               pct_CCR_EOG_ALL_ELS_PC
# 123                pct_L4_EOG_ALL_ELS_PC               pct_CCR_EOG_ALL_ELS_PC
# 124                pct_CCR_MA_ALL_ALL_PC               pct_CCR_EOG_ALL_FEM_PC
# 125                pct_CCR_MA_ALL_FEM_PC               pct_CCR_EOG_ALL_FEM_PC
# 126                pct_CCR_RD_ALL_ALL_PC               pct_CCR_EOG_ALL_FEM_PC
# 127                pct_CCR_RD_ALL_FEM_PC               pct_CCR_EOG_ALL_FEM_PC
# 128               pct_GLP_EOG_ALL_ALL_PC               pct_CCR_EOG_ALL_FEM_PC
# 129               pct_GLP_EOG_ALL_FEM_PC               pct_CCR_EOG_ALL_FEM_PC
# 130                pct_GLP_MA_ALL_ALL_PC               pct_CCR_EOG_ALL_FEM_PC
# 131                pct_GLP_MA_ALL_FEM_PC               pct_CCR_EOG_ALL_FEM_PC
# 132                pct_GLP_RD_ALL_ALL_PC               pct_CCR_EOG_ALL_FEM_PC
# 133                pct_GLP_RD_ALL_FEM_PC               pct_CCR_EOG_ALL_FEM_PC
# 134                   aaa_score_ALL_SPG2               pct_CCR_EOG_ALL_FEM_PC
# 135               pct_GLP_EOG_ALL_HI7_PC               pct_CCR_EOG_ALL_HI7_PC
# 136                pct_CCR_MA_ALL_ALL_PC              pct_CCR_EOG_ALL_MALE_PC
# 137               pct_CCR_MA_ALL_MALE_PC              pct_CCR_EOG_ALL_MALE_PC
# 138                pct_CCR_RD_ALL_ALL_PC              pct_CCR_EOG_ALL_MALE_PC
# 139               pct_CCR_RD_ALL_MALE_PC              pct_CCR_EOG_ALL_MALE_PC
# 140               pct_GLP_EOG_ALL_ALL_PC              pct_CCR_EOG_ALL_MALE_PC
# 141              pct_GLP_EOG_ALL_MALE_PC              pct_CCR_EOG_ALL_MALE_PC
# 142                pct_GLP_MA_ALL_ALL_PC              pct_CCR_EOG_ALL_MALE_PC
# 143               pct_GLP_MA_ALL_MALE_PC              pct_CCR_EOG_ALL_MALE_PC
# 144               pct_GLP_RD_ALL_MALE_PC              pct_CCR_EOG_ALL_MALE_PC
# 145               pct_GLP_EOG_ALL_MU7_PC               pct_CCR_EOG_ALL_MU7_PC
# 146               pct_GLP_EOG_ALL_SWD_PC               pct_CCR_EOG_ALL_SWD_PC
# 147               pct_GLP_EOG_ALL_WH7_PC               pct_CCR_EOG_ALL_WH7_PC
# 148                pct_GLP_EOG_03_ALL_PC                 pct_CCR_MA_03_ALL_PC
# 149                 pct_GLP_MA_03_ALL_PC                 pct_CCR_MA_03_ALL_PC
# 150                 pct_GLP_MA_03_BL7_PC                 pct_CCR_MA_03_BL7_PC
# 151                  pct_L4_MA_03_BL7_PC                 pct_CCR_MA_03_BL7_PC
# 152                 pct_GLP_MA_03_FEM_PC                 pct_CCR_MA_03_FEM_PC
# 153                 pct_GLP_MA_03_HI7_PC                 pct_CCR_MA_03_HI7_PC
# 154                pct_GLP_MA_03_MALE_PC                pct_CCR_MA_03_MALE_PC
# 155                 pct_GLP_MA_03_WH7_PC                 pct_CCR_MA_03_WH7_PC
# 156                pct_GLP_EOG_04_ALL_PC                 pct_CCR_MA_04_ALL_PC
# 157                 pct_GLP_MA_04_ALL_PC                 pct_CCR_MA_04_ALL_PC
# 158                 pct_GLP_MA_04_BL7_PC                 pct_CCR_MA_04_BL7_PC
# 159                  pct_L4_MA_04_BL7_PC                 pct_CCR_MA_04_BL7_PC
# 160                 pct_GLP_MA_04_EDS_PC                 pct_CCR_MA_04_EDS_PC
# 161                 pct_GLP_MA_04_FEM_PC                 pct_CCR_MA_04_FEM_PC
# 162                 pct_GLP_MA_04_HI7_PC                 pct_CCR_MA_04_HI7_PC
# 163                  pct_L4_MA_04_HI7_PC                 pct_CCR_MA_04_HI7_PC
# 164                pct_GLP_MA_04_MALE_PC                pct_CCR_MA_04_MALE_PC
# 165                 pct_GLP_MA_04_SWD_PC                 pct_CCR_MA_04_SWD_PC
# 166                 pct_CCR_RD_04_WH7_PC                 pct_CCR_MA_04_WH7_PC
# 167                 pct_GLP_MA_04_WH7_PC                 pct_CCR_MA_04_WH7_PC
# 168                 pct_GLP_RD_04_WH7_PC                 pct_CCR_MA_04_WH7_PC
# 169                 pct_CCR_RD_05_AIG_PC                 pct_CCR_MA_05_AIG_PC
# 170                 pct_CCR_SC_05_AIG_PC                 pct_CCR_MA_05_AIG_PC
# 171                pct_CCR_SC_ALL_AIG_PC                 pct_CCR_MA_05_AIG_PC
# 172                 pct_GLP_MA_05_AIG_PC                 pct_CCR_MA_05_AIG_PC
# 173                 pct_GLP_RD_05_AIG_PC                 pct_CCR_MA_05_AIG_PC
# 174                 pct_GLP_SC_05_AIG_PC                 pct_CCR_MA_05_AIG_PC
# 175                pct_GLP_SC_ALL_AIG_PC                 pct_CCR_MA_05_AIG_PC
# 176                  pct_L4_RD_05_AIG_PC                 pct_CCR_MA_05_AIG_PC
# 177                 pct_GLP_MA_05_ALL_PC                 pct_CCR_MA_05_ALL_PC
# 178                 pct_GLP_MA_05_BL7_PC                 pct_CCR_MA_05_BL7_PC
# 179                  pct_L4_MA_05_BL7_PC                 pct_CCR_MA_05_BL7_PC
# 180                 pct_GLP_MA_05_EDS_PC                 pct_CCR_MA_05_EDS_PC
# 181                 pct_GLP_MA_05_FEM_PC                 pct_CCR_MA_05_FEM_PC
# 182                 pct_GLP_MA_05_HI7_PC                 pct_CCR_MA_05_HI7_PC
# 183                pct_GLP_MA_05_MALE_PC                pct_CCR_MA_05_MALE_PC
# 184                 pct_CCR_SC_05_WH7_PC                 pct_CCR_MA_05_WH7_PC
# 185                 pct_GLP_MA_05_WH7_PC                 pct_CCR_MA_05_WH7_PC
# 186                 pct_GLP_RD_05_WH7_PC                 pct_CCR_MA_05_WH7_PC
# 187                 pct_GLP_SC_05_WH7_PC                 pct_CCR_MA_05_WH7_PC
# 188                pct_CCR_RD_ALL_AIG_PC                pct_CCR_MA_ALL_AIG_PC
# 189                pct_GLP_MA_ALL_AIG_PC                pct_CCR_MA_ALL_AIG_PC
# 190                pct_GLP_RD_ALL_AIG_PC                pct_CCR_MA_ALL_AIG_PC
# 191                pct_CCR_MA_ALL_FEM_PC                pct_CCR_MA_ALL_ALL_PC
# 192               pct_CCR_MA_ALL_MALE_PC                pct_CCR_MA_ALL_ALL_PC
# 193               pct_GLP_EOG_ALL_ALL_PC                pct_CCR_MA_ALL_ALL_PC
# 194               pct_GLP_EOG_ALL_FEM_PC                pct_CCR_MA_ALL_ALL_PC
# 195              pct_GLP_EOG_ALL_MALE_PC                pct_CCR_MA_ALL_ALL_PC
# 196                pct_GLP_MA_ALL_ALL_PC                pct_CCR_MA_ALL_ALL_PC
# 197                pct_GLP_MA_ALL_FEM_PC                pct_CCR_MA_ALL_ALL_PC
# 198               pct_GLP_MA_ALL_MALE_PC                pct_CCR_MA_ALL_ALL_PC
# 199                   aaa_score_ALL_SPG2                pct_CCR_MA_ALL_ALL_PC
# 200                   ach_score_ALL_SPG2                pct_CCR_MA_ALL_ALL_PC
# 201                pct_GLP_MA_ALL_BL7_PC                pct_CCR_MA_ALL_BL7_PC
# 202                 pct_L4_MA_ALL_BL7_PC                pct_CCR_MA_ALL_BL7_PC
# 203                pct_GLP_MA_ALL_EDS_PC                pct_CCR_MA_ALL_EDS_PC
# 204                pct_GLP_MA_ALL_ELS_PC                pct_CCR_MA_ALL_ELS_PC
# 205               pct_GLP_EOG_ALL_FEM_PC                pct_CCR_MA_ALL_FEM_PC
# 206                pct_GLP_MA_ALL_ALL_PC                pct_CCR_MA_ALL_FEM_PC
# 207                pct_GLP_MA_ALL_FEM_PC                pct_CCR_MA_ALL_FEM_PC
# 208                pct_GLP_MA_ALL_HI7_PC                pct_CCR_MA_ALL_HI7_PC
# 209               pct_GLP_EOG_ALL_ALL_PC               pct_CCR_MA_ALL_MALE_PC
# 210              pct_GLP_EOG_ALL_MALE_PC               pct_CCR_MA_ALL_MALE_PC
# 211                pct_GLP_MA_ALL_ALL_PC               pct_CCR_MA_ALL_MALE_PC
# 212               pct_GLP_MA_ALL_MALE_PC               pct_CCR_MA_ALL_MALE_PC
# 213                   aaa_score_ALL_SPG2               pct_CCR_MA_ALL_MALE_PC
# 214                pct_GLP_MA_ALL_MU7_PC                pct_CCR_MA_ALL_MU7_PC
# 215                pct_GLP_MA_ALL_WH7_PC                pct_CCR_MA_ALL_WH7_PC
# 216                 pct_GLP_RD_03_ALL_PC                 pct_CCR_RD_03_ALL_PC
# 217                 pct_GLP_RD_03_BL7_PC                 pct_CCR_RD_03_BL7_PC
# 218                  pct_L4_RD_03_BL7_PC                 pct_CCR_RD_03_BL7_PC
# 219                 pct_GLP_RD_03_FEM_PC                 pct_CCR_RD_03_FEM_PC
# 220                 pct_GLP_RD_03_HI7_PC                 pct_CCR_RD_03_HI7_PC
# 221                  pct_L4_RD_03_HI7_PC                 pct_CCR_RD_03_HI7_PC
# 222                pct_GLP_RD_03_MALE_PC                pct_CCR_RD_03_MALE_PC
# 223                 pct_GLP_RD_03_WH7_PC                 pct_CCR_RD_03_WH7_PC
# 224                 pct_GLP_RD_04_ALL_PC                 pct_CCR_RD_04_ALL_PC
# 225                  pct_L4_RD_04_ALL_PC                 pct_CCR_RD_04_ALL_PC
# 226                 pct_GLP_RD_04_BL7_PC                 pct_CCR_RD_04_BL7_PC
# 227                  pct_L4_RD_04_BL7_PC                 pct_CCR_RD_04_BL7_PC
# 228                  pct_L4_RD_04_EDS_PC                 pct_CCR_RD_04_EDS_PC
# 229                 pct_GLP_RD_04_FEM_PC                 pct_CCR_RD_04_FEM_PC
# 230                  pct_L4_RD_04_FEM_PC                 pct_CCR_RD_04_FEM_PC
# 231                 pct_GLP_RD_04_HI7_PC                 pct_CCR_RD_04_HI7_PC
# 232                  pct_L4_RD_04_HI7_PC                 pct_CCR_RD_04_HI7_PC
# 233                pct_GLP_RD_04_MALE_PC                pct_CCR_RD_04_MALE_PC
# 234                 pct_L4_RD_04_MALE_PC                pct_CCR_RD_04_MALE_PC
# 235                  pct_L4_RD_04_SWD_PC                 pct_CCR_RD_04_SWD_PC
# 236                 pct_GLP_MA_04_WH7_PC                 pct_CCR_RD_04_WH7_PC
# 237                 pct_GLP_RD_04_WH7_PC                 pct_CCR_RD_04_WH7_PC
# 238                  pct_L4_RD_04_WH7_PC                 pct_CCR_RD_04_WH7_PC
# 239                 pct_CCR_SC_05_AIG_PC                 pct_CCR_RD_05_AIG_PC
# 240                pct_CCR_SC_ALL_AIG_PC                 pct_CCR_RD_05_AIG_PC
# 241                 pct_GLP_MA_05_AIG_PC                 pct_CCR_RD_05_AIG_PC
# 242                 pct_GLP_RD_05_AIG_PC                 pct_CCR_RD_05_AIG_PC
# 243                 pct_GLP_SC_05_AIG_PC                 pct_CCR_RD_05_AIG_PC
# 244                pct_GLP_SC_ALL_AIG_PC                 pct_CCR_RD_05_AIG_PC
# 245                  pct_L4_RD_05_AIG_PC                 pct_CCR_RD_05_AIG_PC
# 246                 pct_GLP_RD_05_ALL_PC                 pct_CCR_RD_05_ALL_PC
# 247                  pct_L4_RD_05_ALL_PC                 pct_CCR_RD_05_ALL_PC
# 248                  pct_L4_RD_05_BL7_PC                 pct_CCR_RD_05_BL7_PC
# 249                  pct_L4_RD_05_EDS_PC                 pct_CCR_RD_05_EDS_PC
# 250                 pct_GLP_RD_05_FEM_PC                 pct_CCR_RD_05_FEM_PC
# 251                  pct_L4_RD_05_FEM_PC                 pct_CCR_RD_05_FEM_PC
# 252                 pct_GLP_RD_05_HI7_PC                 pct_CCR_RD_05_HI7_PC
# 253                  pct_L4_RD_05_HI7_PC                 pct_CCR_RD_05_HI7_PC
# 254                pct_GLP_RD_05_MALE_PC                pct_CCR_RD_05_MALE_PC
# 255                 pct_L4_RD_05_MALE_PC                pct_CCR_RD_05_MALE_PC
# 256                 pct_GLP_RD_05_WH7_PC                 pct_CCR_RD_05_WH7_PC
# 257                  pct_L4_RD_05_WH7_PC                 pct_CCR_RD_05_WH7_PC
# 258                pct_GLP_MA_ALL_AIG_PC                pct_CCR_RD_ALL_AIG_PC
# 259                pct_GLP_RD_ALL_AIG_PC                pct_CCR_RD_ALL_AIG_PC
# 260                pct_CCR_RD_ALL_FEM_PC                pct_CCR_RD_ALL_ALL_PC
# 261               pct_CCR_RD_ALL_MALE_PC                pct_CCR_RD_ALL_ALL_PC
# 262                pct_GLP_RD_ALL_ALL_PC                pct_CCR_RD_ALL_ALL_PC
# 263               pct_GLP_RD_ALL_MALE_PC                pct_CCR_RD_ALL_ALL_PC
# 264                 pct_L4_RD_ALL_ALL_PC                pct_CCR_RD_ALL_ALL_PC
# 265                pct_GLP_RD_ALL_BL7_PC                pct_CCR_RD_ALL_BL7_PC
# 266                 pct_L4_RD_ALL_BL7_PC                pct_CCR_RD_ALL_BL7_PC
# 267                pct_GLP_RD_ALL_EDS_PC                pct_CCR_RD_ALL_EDS_PC
# 268                 pct_L4_RD_ALL_EDS_PC                pct_CCR_RD_ALL_EDS_PC
# 269                 pct_L4_RD_ALL_ELS_PC                pct_CCR_RD_ALL_ELS_PC
# 270                pct_GLP_RD_ALL_ALL_PC                pct_CCR_RD_ALL_FEM_PC
# 271                pct_GLP_RD_ALL_FEM_PC                pct_CCR_RD_ALL_FEM_PC
# 272                 pct_L4_RD_ALL_FEM_PC                pct_CCR_RD_ALL_FEM_PC
# 273                pct_GLP_RD_ALL_HI7_PC                pct_CCR_RD_ALL_HI7_PC
# 274                 pct_L4_RD_ALL_HI7_PC                pct_CCR_RD_ALL_HI7_PC
# 275                pct_GLP_RD_ALL_ALL_PC               pct_CCR_RD_ALL_MALE_PC
# 276               pct_GLP_RD_ALL_MALE_PC               pct_CCR_RD_ALL_MALE_PC
# 277                pct_L4_RD_ALL_MALE_PC               pct_CCR_RD_ALL_MALE_PC
# 278                pct_GLP_RD_ALL_MU7_PC                pct_CCR_RD_ALL_MU7_PC
# 279                 pct_L4_RD_ALL_MU7_PC                pct_CCR_RD_ALL_MU7_PC
# 280                pct_GLP_RD_ALL_WH7_PC                pct_CCR_RD_ALL_WH7_PC
# 281                pct_CCR_SC_ALL_AIG_PC                 pct_CCR_SC_05_AIG_PC
# 282                 pct_GLP_MA_05_AIG_PC                 pct_CCR_SC_05_AIG_PC
# 283                 pct_GLP_RD_05_AIG_PC                 pct_CCR_SC_05_AIG_PC
# 284                 pct_GLP_SC_05_AIG_PC                 pct_CCR_SC_05_AIG_PC
# 285                pct_GLP_SC_ALL_AIG_PC                 pct_CCR_SC_05_AIG_PC
# 286                  pct_L4_RD_05_AIG_PC                 pct_CCR_SC_05_AIG_PC
# 287                pct_CCR_SC_ALL_ALL_PC                 pct_CCR_SC_05_ALL_PC
# 288                 pct_GLP_SC_05_ALL_PC                 pct_CCR_SC_05_ALL_PC
# 289                pct_GLP_SC_ALL_ALL_PC                 pct_CCR_SC_05_ALL_PC
# 290                pct_CCR_SC_ALL_BL7_PC                 pct_CCR_SC_05_BL7_PC
# 291                 pct_GLP_SC_05_BL7_PC                 pct_CCR_SC_05_BL7_PC
# 292                pct_GLP_SC_ALL_BL7_PC                 pct_CCR_SC_05_BL7_PC
# 293                  pct_L4_SC_05_BL7_PC                 pct_CCR_SC_05_BL7_PC
# 294                 pct_L4_SC_ALL_BL7_PC                 pct_CCR_SC_05_BL7_PC
# 295                pct_CCR_SC_ALL_EDS_PC                 pct_CCR_SC_05_EDS_PC
# 296                 pct_GLP_SC_05_EDS_PC                 pct_CCR_SC_05_EDS_PC
# 297                pct_CCR_SC_ALL_FEM_PC                 pct_CCR_SC_05_FEM_PC
# 298                 pct_GLP_SC_05_FEM_PC                 pct_CCR_SC_05_FEM_PC
# 299                pct_CCR_SC_ALL_HI7_PC                 pct_CCR_SC_05_HI7_PC
# 300                 pct_GLP_SC_05_HI7_PC                 pct_CCR_SC_05_HI7_PC
# 301                pct_GLP_SC_ALL_HI7_PC                 pct_CCR_SC_05_HI7_PC
# 302                  pct_L4_SC_05_HI7_PC                 pct_CCR_SC_05_HI7_PC
# 303               pct_CCR_SC_ALL_MALE_PC                pct_CCR_SC_05_MALE_PC
# 304                pct_GLP_SC_05_MALE_PC                pct_CCR_SC_05_MALE_PC
# 305                pct_CCR_SC_ALL_SWD_PC                 pct_CCR_SC_05_SWD_PC
# 306                pct_CCR_SC_ALL_WH7_PC                 pct_CCR_SC_05_WH7_PC
# 307                 pct_GLP_MA_05_WH7_PC                 pct_CCR_SC_05_WH7_PC
# 308                 pct_GLP_RD_05_WH7_PC                 pct_CCR_SC_05_WH7_PC
# 309                 pct_GLP_SC_05_WH7_PC                 pct_CCR_SC_05_WH7_PC
# 310                pct_GLP_SC_ALL_WH7_PC                 pct_CCR_SC_05_WH7_PC
# 311                 pct_GLP_MA_05_AIG_PC                pct_CCR_SC_ALL_AIG_PC
# 312                 pct_GLP_RD_05_AIG_PC                pct_CCR_SC_ALL_AIG_PC
# 313                 pct_GLP_SC_05_AIG_PC                pct_CCR_SC_ALL_AIG_PC
# 314                pct_GLP_SC_ALL_AIG_PC                pct_CCR_SC_ALL_AIG_PC
# 315                 pct_GLP_SC_05_ALL_PC                pct_CCR_SC_ALL_ALL_PC
# 316                pct_GLP_SC_ALL_ALL_PC                pct_CCR_SC_ALL_ALL_PC
# 317                 pct_GLP_SC_05_BL7_PC                pct_CCR_SC_ALL_BL7_PC
# 318                pct_GLP_SC_ALL_BL7_PC                pct_CCR_SC_ALL_BL7_PC
# 319                  pct_L4_SC_05_BL7_PC                pct_CCR_SC_ALL_BL7_PC
# 320                 pct_L4_SC_ALL_BL7_PC                pct_CCR_SC_ALL_BL7_PC
# 321                pct_GLP_SC_ALL_EDS_PC                pct_CCR_SC_ALL_EDS_PC
# 322                 pct_GLP_SC_05_FEM_PC                pct_CCR_SC_ALL_FEM_PC
# 323                pct_GLP_SC_ALL_FEM_PC                pct_CCR_SC_ALL_FEM_PC
# 324                 pct_GLP_SC_05_HI7_PC                pct_CCR_SC_ALL_HI7_PC
# 325                pct_GLP_SC_ALL_HI7_PC                pct_CCR_SC_ALL_HI7_PC
# 326                 pct_L4_SC_ALL_HI7_PC                pct_CCR_SC_ALL_HI7_PC
# 327               pct_GLP_SC_ALL_MALE_PC               pct_CCR_SC_ALL_MALE_PC
# 328                 pct_GLP_MA_05_WH7_PC                pct_CCR_SC_ALL_WH7_PC
# 329                 pct_GLP_RD_05_WH7_PC                pct_CCR_SC_ALL_WH7_PC
# 330                 pct_GLP_SC_05_WH7_PC                pct_CCR_SC_ALL_WH7_PC
# 331                pct_GLP_SC_ALL_WH7_PC                pct_CCR_SC_ALL_WH7_PC
# 332                pct_GLP_EOG_03_FEM_PC                pct_GLP_EOG_03_ALL_PC
# 333               pct_GLP_EOG_03_MALE_PC                pct_GLP_EOG_03_ALL_PC
# 334                 pct_GLP_MA_03_ALL_PC                pct_GLP_EOG_03_ALL_PC
# 335                 pct_GLP_RD_03_ALL_PC                pct_GLP_EOG_03_ALL_PC
# 336                pct_GLP_EOG_04_FEM_PC                pct_GLP_EOG_04_ALL_PC
# 337               pct_GLP_EOG_04_MALE_PC                pct_GLP_EOG_04_ALL_PC
# 338                 pct_GLP_MA_04_ALL_PC                pct_GLP_EOG_04_ALL_PC
# 339                 pct_GLP_RD_04_ALL_PC                pct_GLP_EOG_04_ALL_PC
# 340                 pct_L4_EOG_04_ALL_PC                pct_GLP_EOG_04_ALL_PC
# 341                 pct_L4_EOG_04_BL7_PC                pct_GLP_EOG_04_BL7_PC
# 342                pct_GLP_EOG_05_FEM_PC                pct_GLP_EOG_05_ALL_PC
# 343               pct_GLP_EOG_05_MALE_PC                pct_GLP_EOG_05_ALL_PC
# 344                 pct_GLP_MA_05_ALL_PC                pct_GLP_EOG_05_ALL_PC
# 345                 pct_GLP_RD_05_ALL_PC                pct_GLP_EOG_05_ALL_PC
# 346                 pct_GLP_SC_05_ALL_PC                pct_GLP_EOG_05_ALL_PC
# 347                pct_GLP_SC_ALL_ALL_PC                pct_GLP_EOG_05_ALL_PC
# 348                 pct_L4_EOG_05_ALL_PC                pct_GLP_EOG_05_ALL_PC
# 349                 pct_L4_EOG_05_BL7_PC                pct_GLP_EOG_05_BL7_PC
# 350                 pct_L4_EOG_05_EDS_PC                pct_GLP_EOG_05_EDS_PC
# 351                 pct_L4_EOG_05_ELS_PC                pct_GLP_EOG_05_ELS_PC
# 352                 pct_GLP_MA_05_ALL_PC               pct_GLP_EOG_05_MALE_PC
# 353                 pct_GLP_RD_05_ALL_PC               pct_GLP_EOG_05_MALE_PC
# 354               pct_GLP_EOG_ALL_FEM_PC               pct_GLP_EOG_ALL_ALL_PC
# 355              pct_GLP_EOG_ALL_MALE_PC               pct_GLP_EOG_ALL_ALL_PC
# 356                pct_GLP_MA_ALL_ALL_PC               pct_GLP_EOG_ALL_ALL_PC
# 357                pct_GLP_MA_ALL_FEM_PC               pct_GLP_EOG_ALL_ALL_PC
# 358               pct_GLP_MA_ALL_MALE_PC               pct_GLP_EOG_ALL_ALL_PC
# 359                pct_GLP_RD_ALL_ALL_PC               pct_GLP_EOG_ALL_ALL_PC
# 360                pct_GLP_RD_ALL_FEM_PC               pct_GLP_EOG_ALL_ALL_PC
# 361               pct_GLP_RD_ALL_MALE_PC               pct_GLP_EOG_ALL_ALL_PC
# 362                pct_L4_EOG_ALL_ALL_PC               pct_GLP_EOG_ALL_ALL_PC
# 363                   aaa_score_ALL_SPG2               pct_GLP_EOG_ALL_ALL_PC
# 364                   ach_score_ALL_SPG2               pct_GLP_EOG_ALL_ALL_PC
# 365                pct_L4_ALL_ALL_BL7_PC               pct_GLP_EOG_ALL_BL7_PC
# 366                pct_L4_EOG_ALL_BL7_PC               pct_GLP_EOG_ALL_BL7_PC
# 367                pct_GLP_MA_ALL_EDS_PC               pct_GLP_EOG_ALL_EDS_PC
# 368                pct_L4_EOG_ALL_EDS_PC               pct_GLP_EOG_ALL_EDS_PC
# 369                pct_GLP_MA_ALL_ALL_PC               pct_GLP_EOG_ALL_FEM_PC
# 370                pct_GLP_MA_ALL_FEM_PC               pct_GLP_EOG_ALL_FEM_PC
# 371                pct_GLP_RD_ALL_ALL_PC               pct_GLP_EOG_ALL_FEM_PC
# 372                pct_GLP_RD_ALL_FEM_PC               pct_GLP_EOG_ALL_FEM_PC
# 373                   aaa_score_ALL_SPG2               pct_GLP_EOG_ALL_FEM_PC
# 374                   ach_score_ALL_SPG2               pct_GLP_EOG_ALL_FEM_PC
# 375                pct_GLP_MA_ALL_ALL_PC              pct_GLP_EOG_ALL_MALE_PC
# 376               pct_GLP_MA_ALL_MALE_PC              pct_GLP_EOG_ALL_MALE_PC
# 377                pct_GLP_RD_ALL_ALL_PC              pct_GLP_EOG_ALL_MALE_PC
# 378               pct_GLP_RD_ALL_MALE_PC              pct_GLP_EOG_ALL_MALE_PC
# 379                   aaa_score_ALL_SPG2              pct_GLP_EOG_ALL_MALE_PC
# 380                 pct_GLP_RD_03_WH7_PC                 pct_GLP_MA_03_WH7_PC
# 381                 pct_GLP_RD_04_WH7_PC                 pct_GLP_MA_04_WH7_PC
# 382                 pct_GLP_RD_05_AIG_PC                 pct_GLP_MA_05_AIG_PC
# 383                 pct_GLP_SC_05_AIG_PC                 pct_GLP_MA_05_AIG_PC
# 384                pct_GLP_SC_ALL_AIG_PC                 pct_GLP_MA_05_AIG_PC
# 385                  pct_L4_RD_05_AIG_PC                 pct_GLP_MA_05_AIG_PC
# 386                  pct_L4_MA_05_BL7_PC                 pct_GLP_MA_05_BL7_PC
# 387                 pct_GLP_RD_05_WH7_PC                 pct_GLP_MA_05_WH7_PC
# 388                 pct_GLP_SC_05_WH7_PC                 pct_GLP_MA_05_WH7_PC
# 389                pct_GLP_SC_ALL_WH7_PC                 pct_GLP_MA_05_WH7_PC
# 390                pct_GLP_RD_ALL_AIG_PC                pct_GLP_MA_ALL_AIG_PC
# 391                pct_GLP_MA_ALL_FEM_PC                pct_GLP_MA_ALL_ALL_PC
# 392               pct_GLP_MA_ALL_MALE_PC                pct_GLP_MA_ALL_ALL_PC
# 393                   aaa_score_ALL_SPG2                pct_GLP_MA_ALL_ALL_PC
# 394                   ach_score_ALL_SPG2                pct_GLP_MA_ALL_ALL_PC
# 395                   aaa_score_ALL_SPG2                pct_GLP_MA_ALL_FEM_PC
# 396                   aaa_score_ALL_SPG2               pct_GLP_MA_ALL_MALE_PC
# 397                pct_GLP_RD_ALL_MU7_PC                pct_GLP_MA_ALL_MU7_PC
# 398                pct_GLP_RD_ALL_WH7_PC                pct_GLP_MA_ALL_WH7_PC
# 399                   pct_passed_eog_RTA                 pct_GLP_RD_03_ALL_PC
# 400                  pct_L4_RD_04_ALL_PC                 pct_GLP_RD_04_ALL_PC
# 401                  pct_L4_RD_04_BL7_PC                 pct_GLP_RD_04_BL7_PC
# 402                  pct_L4_RD_04_WH7_PC                 pct_GLP_RD_04_WH7_PC
# 403                 pct_GLP_SC_05_AIG_PC                 pct_GLP_RD_05_AIG_PC
# 404                pct_GLP_SC_ALL_AIG_PC                 pct_GLP_RD_05_AIG_PC
# 405                  pct_L4_RD_05_AIG_PC                 pct_GLP_RD_05_AIG_PC
# 406                  pct_L4_RD_05_ALL_PC                 pct_GLP_RD_05_ALL_PC
# 407                 pct_GLP_SC_05_WH7_PC                 pct_GLP_RD_05_WH7_PC
# 408                pct_GLP_SC_ALL_WH7_PC                 pct_GLP_RD_05_WH7_PC
# 409                  pct_L4_RD_05_WH7_PC                 pct_GLP_RD_05_WH7_PC
# 410                pct_GLP_RD_ALL_FEM_PC                pct_GLP_RD_ALL_ALL_PC
# 411               pct_GLP_RD_ALL_MALE_PC                pct_GLP_RD_ALL_ALL_PC
# 412                 pct_L4_RD_ALL_ALL_PC                pct_GLP_RD_ALL_ALL_PC
# 413                 pct_L4_RD_ALL_FEM_PC                pct_GLP_RD_ALL_FEM_PC
# 414                pct_L4_RD_ALL_MALE_PC               pct_GLP_RD_ALL_MALE_PC
# 415                pct_GLP_SC_ALL_AIG_PC                 pct_GLP_SC_05_AIG_PC
# 416                  pct_L4_RD_05_AIG_PC                 pct_GLP_SC_05_AIG_PC
# 417                pct_GLP_SC_ALL_ALL_PC                 pct_GLP_SC_05_ALL_PC
# 418                pct_GLP_SC_ALL_BL7_PC                 pct_GLP_SC_05_BL7_PC
# 419                  pct_L4_SC_05_BL7_PC                 pct_GLP_SC_05_BL7_PC
# 420                 pct_L4_SC_ALL_BL7_PC                 pct_GLP_SC_05_BL7_PC
# 421                pct_GLP_SC_ALL_EDS_PC                 pct_GLP_SC_05_EDS_PC
# 422                pct_GLP_SC_ALL_FEM_PC                 pct_GLP_SC_05_FEM_PC
# 423                pct_GLP_SC_ALL_HI7_PC                 pct_GLP_SC_05_HI7_PC
# 424                  pct_L4_SC_05_HI7_PC                 pct_GLP_SC_05_HI7_PC
# 425               pct_GLP_SC_ALL_MALE_PC                pct_GLP_SC_05_MALE_PC
# 426                pct_GLP_SC_ALL_SWD_PC                 pct_GLP_SC_05_SWD_PC
# 427                pct_GLP_SC_ALL_WH7_PC                 pct_GLP_SC_05_WH7_PC
# 428                 pct_L4_SC_ALL_BL7_PC                pct_GLP_SC_ALL_BL7_PC
# 429                 pct_L4_SC_ALL_HI7_PC                pct_GLP_SC_ALL_HI7_PC
# 430               pct_L1_ALL_ALL_MALE_PC                pct_L1_ALL_ALL_ALL_PC
# 431                pct_L1_EOG_ALL_ALL_PC                pct_L1_ALL_ALL_ALL_PC
# 432               pct_L1_EOG_ALL_MALE_PC                pct_L1_ALL_ALL_ALL_PC
# 433                pct_L1_EOG_ALL_BL7_PC                pct_L1_ALL_ALL_BL7_PC
# 434                pct_L1_EOG_ALL_EDS_PC                pct_L1_ALL_ALL_EDS_PC
# 435                pct_L1_EOG_ALL_ELS_PC                pct_L1_ALL_ALL_ELS_PC
# 436                pct_L1_EOG_ALL_FEM_PC                pct_L1_ALL_ALL_FEM_PC
# 437                pct_L1_EOG_ALL_ALL_PC               pct_L1_ALL_ALL_MALE_PC
# 438               pct_L1_EOG_ALL_MALE_PC               pct_L1_ALL_ALL_MALE_PC
# 439                pct_L1_EOG_ALL_MU7_PC                pct_L1_ALL_ALL_MU7_PC
# 440                pct_L1_EOG_ALL_SWD_PC                pct_L1_ALL_ALL_SWD_PC
# 441                pct_L1_EOG_ALL_WH7_PC                pct_L1_ALL_ALL_WH7_PC
# 442                pct_L1_EOG_05_MALE_PC                 pct_L1_EOG_05_ALL_PC
# 443               pct_L1_EOG_ALL_MALE_PC                pct_L1_EOG_ALL_ALL_PC
# 444                 pct_L1_MA_ALL_ALL_PC                pct_L1_EOG_ALL_ALL_PC
# 445                 pct_L1_RD_ALL_ALL_PC                pct_L1_EOG_ALL_ALL_PC
# 446                pct_L1_MA_ALL_MALE_PC               pct_L1_EOG_ALL_MALE_PC
# 447                pct_L1_MA_ALL_MALE_PC                 pct_L1_MA_ALL_ALL_PC
# 448                pct_L1_RD_ALL_MALE_PC                 pct_L1_RD_ALL_ALL_PC
# 449                 pct_L1_SC_ALL_FEM_PC                  pct_L1_SC_05_FEM_PC
# 450                 pct_L1_SC_ALL_HI7_PC                  pct_L1_SC_05_HI7_PC
# 451                 pct_L1_SC_ALL_WH7_PC                  pct_L1_SC_05_WH7_PC
# 452                pct_L2_EOG_ALL_ALL_PC                pct_L2_ALL_ALL_ALL_PC
# 453                pct_L2_EOG_ALL_BL7_PC                pct_L2_ALL_ALL_BL7_PC
# 454                pct_L2_EOG_ALL_EDS_PC                pct_L2_ALL_ALL_EDS_PC
# 455                pct_L2_EOG_ALL_ELS_PC                pct_L2_ALL_ALL_ELS_PC
# 456                pct_L2_EOG_ALL_FEM_PC                pct_L2_ALL_ALL_FEM_PC
# 457                pct_L2_EOG_ALL_HI7_PC                pct_L2_ALL_ALL_HI7_PC
# 458               pct_L2_EOG_ALL_MALE_PC               pct_L2_ALL_ALL_MALE_PC
# 459                pct_L2_EOG_ALL_MU7_PC                pct_L2_ALL_ALL_MU7_PC
# 460                pct_L2_EOG_ALL_SWD_PC                pct_L2_ALL_ALL_SWD_PC
# 461                pct_L2_EOG_ALL_WH7_PC                pct_L2_ALL_ALL_WH7_PC
# 462               pct_L2_EOG_ALL_MALE_PC                pct_L2_EOG_ALL_ALL_PC
# 463                 pct_L2_SC_ALL_BL7_PC                  pct_L2_SC_05_BL7_PC
# 464                 pct_L2_SC_ALL_EDS_PC                  pct_L2_SC_05_EDS_PC
# 465                 pct_L2_SC_ALL_FEM_PC                  pct_L2_SC_05_FEM_PC
# 466                 pct_L2_SC_ALL_HI7_PC                  pct_L2_SC_05_HI7_PC
# 467                 pct_L2_SC_ALL_WH7_PC                  pct_L2_SC_05_WH7_PC
# 468                pct_L3_EOG_ALL_ALL_PC                pct_L3_ALL_ALL_ALL_PC
# 469                pct_L3_EOG_ALL_BL7_PC                pct_L3_ALL_ALL_BL7_PC
# 470                pct_L3_EOG_ALL_EDS_PC                pct_L3_ALL_ALL_EDS_PC
# 471                pct_L3_EOG_ALL_ELS_PC                pct_L3_ALL_ALL_ELS_PC
# 472                pct_L3_EOG_ALL_FEM_PC                pct_L3_ALL_ALL_FEM_PC
# 473                pct_L3_EOG_ALL_HI7_PC                pct_L3_ALL_ALL_HI7_PC
# 474               pct_L3_EOG_ALL_MALE_PC               pct_L3_ALL_ALL_MALE_PC
# 475                pct_L3_EOG_ALL_MU7_PC                pct_L3_ALL_ALL_MU7_PC
# 476                pct_L3_EOG_ALL_SWD_PC                pct_L3_ALL_ALL_SWD_PC
# 477                pct_L3_EOG_ALL_WH7_PC                pct_L3_ALL_ALL_WH7_PC
# 478                 pct_L3_SC_ALL_BL7_PC                  pct_L3_SC_05_BL7_PC
# 479                 pct_L3_SC_ALL_EDS_PC                  pct_L3_SC_05_EDS_PC
# 480                 pct_L3_SC_ALL_HI7_PC                  pct_L3_SC_05_HI7_PC
# 481                pct_L3_SC_ALL_MALE_PC                 pct_L3_SC_05_MALE_PC
# 482                 pct_L3_SC_ALL_WH7_PC                  pct_L3_SC_05_WH7_PC
# 483                pct_L4_EOG_ALL_AIG_PC                pct_L4_ALL_ALL_AIG_PC
# 484                pct_L4_ALL_ALL_FEM_PC                pct_L4_ALL_ALL_ALL_PC
# 485               pct_L4_ALL_ALL_MALE_PC                pct_L4_ALL_ALL_ALL_PC
# 486                pct_L4_EOG_ALL_ALL_PC                pct_L4_ALL_ALL_ALL_PC
# 487                pct_L4_EOG_ALL_FEM_PC                pct_L4_ALL_ALL_ALL_PC
# 488               pct_L4_EOG_ALL_MALE_PC                pct_L4_ALL_ALL_ALL_PC
# 489                pct_L4_EOG_ALL_BL7_PC                pct_L4_ALL_ALL_BL7_PC
# 490                pct_L4_EOG_ALL_EDS_PC                pct_L4_ALL_ALL_EDS_PC
# 491                pct_L4_EOG_ALL_ELS_PC                pct_L4_ALL_ALL_ELS_PC
# 492                pct_L4_EOG_ALL_ALL_PC                pct_L4_ALL_ALL_FEM_PC
# 493                pct_L4_EOG_ALL_FEM_PC                pct_L4_ALL_ALL_FEM_PC
# 494                pct_L4_EOG_ALL_HI7_PC                pct_L4_ALL_ALL_HI7_PC
# 495                pct_L4_EOG_ALL_ALL_PC               pct_L4_ALL_ALL_MALE_PC
# 496               pct_L4_EOG_ALL_MALE_PC               pct_L4_ALL_ALL_MALE_PC
# 497                pct_L4_EOG_ALL_MU7_PC                pct_L4_ALL_ALL_MU7_PC
# 498                pct_L4_EOG_ALL_SWD_PC                pct_L4_ALL_ALL_SWD_PC
# 499                pct_L4_EOG_ALL_WH7_PC                pct_L4_ALL_ALL_WH7_PC
# 500                pct_L4_EOG_ALL_FEM_PC                pct_L4_EOG_ALL_ALL_PC
# 501               pct_L4_EOG_ALL_MALE_PC                pct_L4_EOG_ALL_ALL_PC
# 502                 pct_L4_MA_ALL_FEM_PC                 pct_L4_MA_ALL_ALL_PC
# 503                pct_L4_MA_ALL_MALE_PC                 pct_L4_MA_ALL_ALL_PC
# 504                 pct_L4_RD_ALL_FEM_PC                 pct_L4_RD_ALL_ALL_PC
# 505                pct_L4_RD_ALL_MALE_PC                 pct_L4_RD_ALL_ALL_PC
# 506                 pct_L4_SC_ALL_AIG_PC                  pct_L4_SC_05_AIG_PC
# 507                 pct_L4_SC_ALL_ALL_PC                  pct_L4_SC_05_ALL_PC
# 508                 pct_L4_SC_ALL_BL7_PC                  pct_L4_SC_05_BL7_PC
# 509                 pct_L4_SC_ALL_EDS_PC                  pct_L4_SC_05_EDS_PC
# 510                 pct_L4_SC_ALL_FEM_PC                  pct_L4_SC_05_FEM_PC
# 511                 pct_L4_SC_ALL_HI7_PC                  pct_L4_SC_05_HI7_PC
# 512                pct_L4_SC_ALL_MALE_PC                 pct_L4_SC_05_MALE_PC
# 513                 pct_L4_SC_ALL_SWD_PC                  pct_L4_SC_05_SWD_PC
# 514                 pct_L4_SC_ALL_WH7_PC                  pct_L4_SC_05_WH7_PC
# 515                pct_L5_EOG_ALL_AIG_PC                pct_L5_ALL_ALL_AIG_PC
# 516                pct_L5_ALL_ALL_FEM_PC                pct_L5_ALL_ALL_ALL_PC
# 517               pct_L5_ALL_ALL_MALE_PC                pct_L5_ALL_ALL_ALL_PC
# 518                pct_L5_EOG_ALL_ALL_PC                pct_L5_ALL_ALL_ALL_PC
# 519                pct_L5_EOG_ALL_FEM_PC                pct_L5_ALL_ALL_ALL_PC
# 520               pct_L5_EOG_ALL_MALE_PC                pct_L5_ALL_ALL_ALL_PC
# 521                 pct_L5_MA_ALL_ALL_PC                pct_L5_ALL_ALL_ALL_PC
# 522                pct_L5_MA_ALL_MALE_PC                pct_L5_ALL_ALL_ALL_PC
# 523                pct_L5_EOG_ALL_EDS_PC                pct_L5_ALL_ALL_EDS_PC
# 524                pct_L5_EOG_ALL_ELS_PC                pct_L5_ALL_ALL_ELS_PC
# 525                pct_L5_EOG_ALL_ALL_PC                pct_L5_ALL_ALL_FEM_PC
# 526                pct_L5_EOG_ALL_FEM_PC                pct_L5_ALL_ALL_FEM_PC
# 527                 pct_L5_MA_ALL_FEM_PC                pct_L5_ALL_ALL_FEM_PC
# 528                pct_L5_EOG_ALL_HI7_PC                pct_L5_ALL_ALL_HI7_PC
# 529                pct_L5_EOG_ALL_ALL_PC               pct_L5_ALL_ALL_MALE_PC
# 530               pct_L5_EOG_ALL_MALE_PC               pct_L5_ALL_ALL_MALE_PC
# 531                 pct_L5_MA_ALL_ALL_PC               pct_L5_ALL_ALL_MALE_PC
# 532                pct_L5_MA_ALL_MALE_PC               pct_L5_ALL_ALL_MALE_PC
# 533                pct_L5_EOG_ALL_MU7_PC                pct_L5_ALL_ALL_MU7_PC
# 534                pct_L5_EOG_ALL_WH7_PC                pct_L5_ALL_ALL_WH7_PC
# 535                  pct_L5_MA_03_ALL_PC                 pct_L5_EOG_03_ALL_PC
# 536                  pct_L5_MA_04_ALL_PC                 pct_L5_EOG_04_ALL_PC
# 537                 pct_L5_MA_04_MALE_PC                pct_L5_EOG_04_MALE_PC
# 538                pct_L5_EOG_05_MALE_PC                 pct_L5_EOG_05_ALL_PC
# 539                pct_L5_EOG_ALL_FEM_PC                pct_L5_EOG_ALL_ALL_PC
# 540               pct_L5_EOG_ALL_MALE_PC                pct_L5_EOG_ALL_ALL_PC
# 541                 pct_L5_MA_ALL_ALL_PC                pct_L5_EOG_ALL_ALL_PC
# 542                pct_L5_MA_ALL_MALE_PC                pct_L5_EOG_ALL_ALL_PC
# 543                 pct_L5_MA_ALL_ALL_PC                pct_L5_EOG_ALL_FEM_PC
# 544                 pct_L5_MA_ALL_FEM_PC                pct_L5_EOG_ALL_FEM_PC
# 545                 pct_L5_MA_ALL_ALL_PC               pct_L5_EOG_ALL_MALE_PC
# 546                pct_L5_MA_ALL_MALE_PC               pct_L5_EOG_ALL_MALE_PC
# 547                 pct_L5_MA_ALL_FEM_PC                 pct_L5_MA_ALL_ALL_PC
# 548                pct_L5_MA_ALL_MALE_PC                 pct_L5_MA_ALL_ALL_PC
# 549                 pct_L5_SC_ALL_AIG_PC                  pct_L5_SC_05_AIG_PC
# 550                 pct_L5_SC_ALL_ALL_PC                  pct_L5_SC_05_ALL_PC
# 551                 pct_L5_SC_ALL_EDS_PC                  pct_L5_SC_05_EDS_PC
# 552                 pct_L5_SC_ALL_FEM_PC                  pct_L5_SC_05_FEM_PC
# 553                pct_L5_SC_ALL_MALE_PC                 pct_L5_SC_05_MALE_PC
# 554                 pct_L5_SC_ALL_WH7_PC                  pct_L5_SC_05_WH7_PC
# 555                            ach_score                             ma_score
# 556                            spg_score                             ma_score
# 557                         ma_spg_score                             ma_score
# 558                            ach_score                             rd_score
# 559                            spg_score                             rd_score
# 560                         rd_spg_score                             rd_score
# 561                            spg_score                            ach_score
# 562                         ma_spg_score                            ach_score
# 563                         rd_spg_score                            ach_score
# 564                         ma_spg_score                            spg_score
# 565                         rd_spg_score                            spg_score
# 566                         rd_spg_score                         ma_spg_score
# 567                   ach_score_ALL_SPG2                   aaa_score_ALL_SPG2
# 568                   ach_score_BL7_SPG2                   aaa_score_BL7_SPG2
# 569                   ach_score_EDS_SPG2                   aaa_score_EDS_SPG2
# 570                   ach_score_ELS_SPG2                   aaa_score_ELS_SPG2
# 571                   ach_score_HI7_SPG2                   aaa_score_HI7_SPG2
# 572                   ach_score_SWD_SPG2                   aaa_score_SWD_SPG2
# 573                   ach_score_WH7_SPG2                   aaa_score_WH7_SPG2
# 574                   spg_score_ELS_SPG2                   ach_score_ELS_SPG2
# 575                pct_MALE_CHRON_ABSENT                 pct_ALL_CHRON_ABSENT
# 576                    crime_per1000_ALL                                crime
# 577                   crime_per1000_MALE                                crime
# 578                    crime_per1000_MU7                                crime
# 579                    crime_per1000_SWD                                crime
# 580                     rplw_per1000_ALL                                crime
# 581                    rplw_per1000_MALE                                crime
# 582                     rplw_per1000_SWD                                crime
# 583                     arre_per1000_BL7                     arre_per1000_ALL
# 584                     arre_per1000_EDS                     arre_per1000_ALL
# 585                    arre_per1000_MALE                     arre_per1000_ALL
# 586                     arre_per1000_SWD                     arre_per1000_ALL
# 587                     arre_per1000_WH7                     arre_per1000_ALL
# 588                    crime_per1000_ELS                     arre_per1000_ALL
# 589                     grade_span_KG:13                     arre_per1000_ALL
# 590            subgroup_list_ALL,BL7,SWD                     arre_per1000_ALL
# ...
# 96      0.983764
# 97      0.986965
# 98      0.995588
# 99      0.980650
# 100     0.986894
# 101     0.979139
# 102     0.959279
# 103     0.964729
# 104     0.968418
# 105     0.950807
# 106     0.985516
# 107     0.963360
# 108     0.974218
# 109     0.964979
# 110     0.953890
# 111     0.963363
# 112     0.963296
# 113     0.956225
# 114     0.972362
# 115     0.963569
# 116     0.969140
# 117     0.954010
# 118     0.978634
# 119     0.956652
# 120     0.970111
# 121     0.963819
# 122     0.951369
# 123     0.953391
# 124     0.967219
# 125     0.975699
# 126     0.954260
# 127     0.967575
# 128     0.966340
# 129     0.980978
# 130     0.954460
# 131     0.957887
# 132     0.951869
# 133     0.958271
# 134     0.956144
# 135     0.964770
# 136     0.965642
# 137     0.975094
# 138     0.955697
# 139     0.962506
# 140     0.972627
# 141     0.983638
# 142     0.951478
# 143     0.961388
# 144     0.957269
# 145     0.971106
# 146     0.953880
# 147     0.979984
# 148     0.953573
# 149     0.965080
# 150     0.964278
# 151     0.957987
# 152     0.952879
# 153     0.968053
# 154     0.959567
# 155     0.976545
# 156     0.955158
# 157     0.983738
# 158     0.976467
# 159     0.960643
# 160     0.970455
# 161     0.978121
# 162     0.980828
# 163     0.952960
# 164     0.976639
# 165     0.951797
# 166     0.950441
# 167     0.988256
# 168     0.952162
# 169     0.992724
# 170     0.997751
# 171     0.966581
# 172     0.999172
# 173     0.997540
# 174     0.997949
# 175     0.967237
# 176     0.951002
# 177     0.986804
# 178     0.978391
# 179     0.959940
# 180     0.977636
# 181     0.981632
# 182     0.986662
# 183     0.984217
# 184     0.956449
# 185     0.991538
# 186     0.961700
# 187     0.954573
# 188     0.990597
# 189     0.998481
# 190     0.996117
# 191     0.981268
# 192     0.984426
# 193     0.965928
# 194     0.953954
# 195     0.953303
# 196     0.984036
# 197     0.965031
# 198     0.971370
# 199     0.962355
# 200     0.952710
# 201     0.973380
# 202     0.957007
# 203     0.974264
# 204     0.972979
# 205     0.959576
# 206     0.964974
# 207     0.978510
# 208     0.972937
# 209     0.950189
# 210     0.958035
# 211     0.967026
# 212     0.981224
# 213     0.950168
# 214     0.980744
# 215     0.982864
# 216     0.972290
# 217     0.964079
# 218     0.968988
# 219     0.962099
# 220     0.963958
# 221     0.959129
# 222     0.963027
# 223     0.979200
# 224     0.965708
# 225     0.970834
# 226     0.961739
# 227     0.986602
# 228     0.980711
# 229     0.955324
# 230     0.960737
# 231     0.956791
# 232     0.987016
# 233     0.954377
# 234     0.967072
# 235     0.950490
# 236     0.953133
# 237     0.976697
# 238     0.972849
# 239     0.992868
# 240     0.961890
# 241     0.992961
# 242     0.995345
# 243     0.992685
# 244     0.962150
# 245     0.952200
# 246     0.966965
# 247     0.964912
# 248     0.977446
# 249     0.970383
# 250     0.957557
# 251     0.953200
# 252     0.952095
# 253     0.976222
# 254     0.957100
# 255     0.958899
# 256     0.976876
# 257     0.960917
# 258     0.991009
# 259     0.994010
# 260     0.974578
# 261     0.978942
# 262     0.977644
# 263     0.959062
# 264     0.966597
# 265     0.956375
# 266     0.977330
# 267     0.958372
# 268     0.973603
# 269     0.977896
# 270     0.954889
# 271     0.971178
# 272     0.953205
# 273     0.951303
# 274     0.964714
# 275     0.955344
# 276     0.971223
# 277     0.961647
# 278     0.969630
# 279     0.964794
# 280     0.975287
# 281     0.968725
# 282     0.998295
# 283     0.997655
# 284     0.998613
# 285     0.967875
# 286     0.951915
# 287     0.982829
# 288     0.977995
# 289     0.959570
# 290     0.990524
# 291     0.975121
# 292     0.962561
# 293     0.973214
# 294     0.965286
# 295     0.975709
# 296     0.965617
# 297     0.980050
# 298     0.971329
# 299     0.977546
# 300     0.977837
# 301     0.955679
# 302     0.963991
# 303     0.975578
# 304     0.975441
# 305     0.966964
# 306     0.987196
# 307     0.964221
# 308     0.961940
# 309     0.986748
# 310     0.974968
# 311     0.967068
# 312     0.966503
# 313     0.967377
# 314     0.998659
# 315     0.962529
# 316     0.977836
# 317     0.966300
# 318     0.973873
# 319     0.963371
# 320     0.973708
# 321     0.966271
# 322     0.951844
# 323     0.970680
# 324     0.955577
# 325     0.977582
# 326     0.963872
# 327     0.975167
# 328     0.954107
# 329     0.952003
# 330     0.975377
# 331     0.987259
# 332     0.964406
# 333     0.957571
# 334     0.970250
# 335     0.967252
# 336     0.954540
# 337     0.952548
# 338     0.969840
# 339     0.965997
# 340     0.954127
# 341     0.955265
# 342     0.960633
# 343     0.967545
# 344     0.963471
# 345     0.955601
# 346     0.953992
# 347     0.953192
# 348     0.951014
# 349     0.954940
# 350     0.957434
# 351     0.951411
# 352     0.959115
# 353     0.951676
# 354     0.977988
# 355     0.987351
# 356     0.977468
# 357     0.954699
# 358     0.962665
# 359     0.972039
# 360     0.950429
# 361     0.951967
# 362     0.956302
# 363     0.964734
# 364     0.959215
# 365     0.952965
# 366     0.958663
# 367     0.952952
# 368     0.965615
# 369     0.967650
# 370     0.973379
# 371     0.958933
# 372     0.969565
# 373     0.958287
# 374     0.953946
# 375     0.963659
# 376     0.970466
# 377     0.960262
# 378     0.964574
# 379     0.951301
# 380     0.960285
# 381     0.965275
# 382     0.998351
# 383     0.999285
# 384     0.968522
# 385     0.953433
# 386     0.950447
# 387     0.967838
# 388     0.968443
# 389     0.958174
# 390     0.997957
# 391     0.978076
# 392     0.981865
# 393     0.962745
# 394     0.954724
# 395     0.953611
# 396     0.954861
# 397     0.953895
# 398     0.954717
# 399     0.965716
# 400     0.957250
# 401     0.952040
# 402     0.962923
# 403     0.998455
# 404     0.967743
# 405     0.953793
# 406     0.954589
# 407     0.967184
# 408     0.956888
# 409     0.957028
# 410     0.969561
# 411     0.977739
# 412     0.969556
# 413     0.950293
# 414     0.957153
# 415     0.969224
# 416     0.954369
# 417     0.980767
# 418     0.987189
# 419     0.960274
# 420     0.953020
# 421     0.972952
# 422     0.975683
# 423     0.977217
# 424     0.953239
# 425     0.969595
# 426     0.960611
# 427     0.988502
# 428     0.958992
# 429     0.952530
# 430     0.968929
# 431     0.982446
# 432     0.963782
# 433     0.994908
# 434     0.990077
# 435     0.971961
# 436     0.993523
# 437     0.974176
# 438     0.993253
# 439     0.982844
# 440     0.984333
# 441     0.995364
# 442     0.956507
# 443     0.980973
# 444     0.963331
# 445     0.960453
# 446     0.950995
# 447     0.968136
# 448     0.967782
# 449     0.978786
# 450     0.981630
# 451     0.955631
# 452     0.980664
# 453     0.988142
# 454     0.977883
# 455     0.994555
# 456     0.980999
# 457     0.970640
# 458     0.982254
# 459     0.992953
# 460     0.950253
# 461     0.978743
# 462     0.950352
# 463     0.981556
# 464     0.960381
# 465     0.978201
# 466     0.979188
# 467     0.980525
# 468     0.980371
# 469     0.992200
# 470     0.984601
# 471     0.985237
# 472     0.983706
# 473     0.993921
# 474     0.985965
# 475     0.996539
# 476     0.997626
# 477     0.975601
# 478     0.963516
# 479     0.963551
# 480     0.975966
# 481     0.956025
# 482     0.980238
# 483     0.989528
# 484     0.969311
# 485     0.971105
# 486     0.983350
# 487     0.951990
# 488     0.953773
# 489     0.994069
# 490     0.985167
# 491     0.998034
# 492     0.951346
# 493     0.981685
# 494     0.992158
# 495     0.955860
# 496     0.983347
# 497     0.998690
# 498     0.997669
# 499     0.985899
# 500     0.963090
# 501     0.971149
# 502     0.950029
# 503     0.952016
# 504     0.952249
# 505     0.959861
# 506     0.969291
# 507     0.982780
# 508     0.990518
# 509     0.977250
# 510     0.980040
# 511     0.979265
# 512     0.969918
# 513     0.961754
# 514     0.988382
# 515     0.996083
# 516     0.971291
# 517     0.975395
# 518     0.998108
# 519     0.970481
# 520     0.973584
# 521     0.973948
# 522     0.954499
# 523     0.997429
# 524     0.995811
# 525     0.969713
# 526     0.998960
# 527     0.967089
# 528     0.998377
# 529     0.973545
# 530     0.998187
# 531     0.955019
# 532     0.968227
# 533     0.999318
# 534     0.998045
# 535     0.966418
# 536     0.974632
# 537     0.953000
# 538     0.954307
# 539     0.970660
# 540     0.975231
# 541     0.974117
# 542     0.954699
# 543     0.950220
# 544     0.967779
# 545     0.955462
# 546     0.968713
# 547     0.971558
# 548     0.979493
# 549     0.973069
# 550     0.977909
# 551     0.971825
# 552     0.980126
# 553     0.979565
# 554     0.981307
# 555     0.972246
# 556     0.960820
# 557     0.987096
# 558     0.971790
# 559     0.954894
# 560     0.988745
# 561     0.988757
# 562     0.962711
# 563     0.967340
# 564     0.972755
# 565     0.970338
# 566     0.954082
# 567     0.996219
# 568     0.998220
# 569     0.993358
# 570     0.992758
# 571     0.997348
# 572     0.997532
# 573     0.999053
# 574     0.958637
# 575     0.974825
# 576     0.995383
# 577     0.982422
# 578     0.995952
# 579     0.993651
# 580     0.990233
# 581     0.960770
# 582     0.973800
# 583     1.000000
# 584     1.000000
# 585     1.000000
# 586     1.000000
# 587     1.000000
# 588     0.997755
# 589     1.000000
# 590     1.000000
# 591     1.000000
# 592     1.000000
# 593     1.000000
# 594     1.000000
# 595     0.997755
# 596     1.000000
# 597     1.000000
# 598     1.000000
# 599     1.000000
# 600     1.000000
# 601     0.997755
# 602     1.000000
# 603     1.000000
# 604     1.000000
# 605     1.000000
# 606     0.997755
# 607     1.000000
# 608     1.000000
# 609     1.000000
# 610     0.997755
# 611     1.000000
# 612     1.000000
# 613     0.997755
# 614     1.000000
# 615     1.000000
# 616     0.994147
# 617     0.988808
# 618     0.993202
# 619     0.986937
# 620     0.962013
# 621     0.967530
# 622     0.968706
# 623     0.984836
# 624     0.950861
# 625     0.997755
# 626     0.997755
# 627     0.974854
# 628     0.982398
# 629     0.977122
# 630     0.960749
# 631     0.954474
# 632     0.990476
# 633     0.989051
# 634     0.959925
# 635     0.974272
# 636     0.985699
# 637     0.958663
# 638     0.972738
# 639     0.977636
# 640     0.951749
# 641     0.988431
# 642     0.983946
# 643     0.972060
# 644     1.000000
# 645     0.974423
# 646     0.979899
# 647     1.000000
# 648     1.000000
# 649     1.000000
# 650     1.000000
# 651     1.000000
# 652     1.000000
# 653     1.000000
# 654     1.000000
# 655     1.000000
# 656     1.000000
# 657     1.000000
# 658     1.000000
# 659     1.000000
# 660     1.000000
# 661     1.000000
# 662     1.000000
# 663     1.000000
# 664     1.000000
# 665     1.000000
# 666     1.000000
# 667     1.000000
# 668     1.000000
# 669     1.000000
# 670     1.000000
# 671     1.000000
# 672     1.000000
# 673     1.000000
# 674     1.000000
# 675     1.000000
# 676     1.000000
# 677     1.000000
# 678     1.000000
# 679     1.000000
# 680     1.000000
# 681     1.000000
# 682     1.000000
# 683     1.000000
# 684     1.000000
# 685     1.000000
# 686     1.000000
# 687     1.000000
# 688     1.000000
# 689     1.000000
# 690     1.000000
# 691     1.000000
# 692     1.000000
# 693     1.000000
# 694     1.000000
# 695     1.000000
# 696     1.000000
# 697     1.000000
# 698     1.000000
# 699     1.000000
# 700     1.000000
# 701     1.000000
# 702     1.000000
# 703     1.000000
# 704     1.000000
# 705     1.000000
# 706     1.000000
# 707     1.000000
# 708     1.000000
# 709     1.000000
# 710     1.000000
# 711     1.000000
# 712     1.000000
# 713     1.000000
# 714     1.000000
# 715     1.000000
# 716     1.000000
# 717     1.000000
# 718     1.000000
# 719     1.000000
# 720     1.000000
# 721     1.000000
# 722     1.000000
# 723     1.000000
# 724     1.000000
# 725     1.000000
# 726     1.000000
# 727     1.000000
# 728     1.000000
# 729     1.000000
# 730     1.000000
# 731     1.000000
# 732     1.000000
# 733     1.000000
# 734     1.000000
# 735     1.000000
# 736     1.000000
# 737     1.000000
# 738     1.000000
# 739     1.000000
# 740     1.000000
# 741     1.000000
# 742     1.000000
# 743     1.000000
# 744     1.000000
# 745     1.000000
# 746     1.000000
# 747     1.000000
# 748     1.000000
# 749     1.000000
# 750     1.000000
# 751     1.000000
# 752     1.000000
# 753     1.000000
# 754     1.000000
# 755     1.000000
# 756     1.000000
# 757     1.000000
# 758     1.000000
# 759     1.000000
# 760     1.000000
# 761     1.000000
# 762     1.000000
# 763     1.000000
# 764     1.000000
# 765     1.000000
# 766     1.000000
# 767     1.000000
# 768     1.000000
# 769     1.000000
# 770     1.000000
# 771     1.000000
# 772     1.000000
# 773     1.000000
# 774     1.000000
# 775     1.000000
# 776     1.000000
# 777     1.000000
# 778     1.000000
# 779     1.000000
# 780     1.000000
# 781     1.000000
# 782     1.000000
# 783     1.000000
# 784     1.000000
# 785     1.000000
# 786     1.000000
# 787     1.000000
# 788     1.000000
# 789     1.000000
# 790     1.000000
# 791     1.000000
# 792     1.000000
# 793     1.000000
# 794     1.000000
# 795     1.000000
# 796     1.000000
# 797     1.000000
# 798     1.000000
# 799     1.000000
# 800     1.000000
# 801     1.000000
# 802     1.000000
# 803     1.000000
# 804     1.000000
# 805     1.000000
# 806     1.000000
# 807     1.000000
# 808     1.000000
# 809     1.000000
# 810     1.000000
# 811     1.000000
# 812     1.000000
# 813     1.000000
# 814     1.000000
# 815     1.000000
# 816     1.000000
# 817     1.000000
# 818     1.000000
# 819     1.000000
# 820     1.000000
# 821     1.000000
# 822     1.000000
# 823     1.000000
# 824     1.000000
# 825     1.000000
# 826     1.000000
# 827     1.000000
# 828     1.000000
# 829     1.000000
# 830     1.000000
# 831     1.000000
# 832     1.000000
# 833     1.000000
# 834     1.000000
# 835     1.000000
# 836     1.000000
# 837     1.000000
# 838     1.000000
# 839     1.000000
# 840     1.000000
# 841     1.000000
# 842     1.000000
# 843     1.000000
# 844     1.000000
# 845     1.000000
# 846     1.000000
# 847     1.000000
# 848     1.000000
# 849     1.000000
# 850     1.000000
# 851     1.000000
# 852     1.000000
# 853     1.000000
# 854     1.000000
# 855     1.000000
# 856     1.000000
# 857     1.000000
# 858     1.000000
# 859     1.000000
# 860     1.000000
# 861     1.000000
# 862     1.000000
# 863     1.000000
# 864     1.000000
# 865     1.000000
# 866     1.000000
# 867     1.000000
# 868     1.000000
# 869     1.000000
# 870     1.000000
# 871     1.000000
# 872     1.000000
# 873     1.000000
# 874     1.000000
# 875     1.000000
# 876     1.000000
# 877     1.000000
# 878     1.000000
# 879     1.000000
# 880     1.000000
# 881     1.000000
# 882     1.000000
# 883     1.000000
# 884     1.000000
# 885     1.000000
# 886     1.000000
# 887     1.000000
# 888     1.000000
# 889     1.000000
# 890     1.000000
# 891     1.000000
# 892     1.000000
# 893     1.000000
# 894     1.000000
# 895     1.000000
# 896     1.000000
# 897     1.000000
# 898     1.000000
# 899     1.000000
# 900     1.000000
# 901     1.000000
# 902     1.000000
# 903     1.000000
# 904     1.000000
# 905     1.000000
# 906     1.000000
# 907     1.000000
# 908     1.000000
# 909     1.000000
# 910     1.000000
# 911     1.000000
# 912     1.000000
# 913     1.000000
# 914     1.000000
# 915     1.000000
# 916     1.000000
# 917     1.000000
# 918     1.000000
# 919     1.000000
# 920     1.000000
# 921     1.000000
# 922     1.000000
# 923     1.000000
# 924     1.000000
# 925     1.000000
# 926     1.000000
# 927     1.000000
# 928     1.000000
# 929     1.000000
# 930     1.000000
# 931     1.000000
# 932     1.000000
# 933     1.000000
# 934     1.000000
# 935     1.000000
# 936     1.000000
# 937     1.000000

# %%
#The old way
#print('Dropping the following ', str(len(to_drop)), ' highly correlated fields.')
#to_drop

# Comparing highly correlated unique field names in field 1 vs field 2 list above will allow you to 
# remove the least amount of fields possible.  
#len(cf['Field1'].unique())
#len(cf['Field2'].unique())

print('Dropping the following ', str(len(cf['Field2'].unique())), ' highly correlated, unique fields.')
cf['Field2'].unique()
# Out:
# Dropping the following  516  highly correlated, unique fields.
# array(['IndianPct', 'AsianPct', 'HispanicPct', 'BlackPct', 'WhitePct',
#        'MinorityPct', 'IndianMalePct', 'AsianMalePct', 'WhiteMalePct',
#        'MinorityMalePct', 'pct_ALL_ELP', 'pct_met_Math Grades 3-8_PART',
#        'pct_met_Reading Grades 3-8_PART',
#        'pct_met_Science Grades 5&8_PART', 'pct_met_Total Targets_PART',
#        'pct_Math Grades 3-8_ALL_PART_DET',
#        'pct_Math Grades 3-8_BL7_PART_DET',
#        'pct_Math Grades 3-8_EDS_PART_DET',
#        'pct_Math Grades 3-8_HI7_PART_DET',
#        'pct_Math Grades 3-8_SWD_PART_DET',
#        'pct_Math Grades 3-8_WH7_PART_DET',
#        'pct_Science Grades 5&8_WH7_PART_DET', 'pct_CCR_EOG_03_ALL_PC',
#        'pct_CCR_EOG_03_BL7_PC', 'pct_CCR_EOG_03_EDS_PC',
#        'pct_CCR_EOG_03_ELS_PC', 'pct_CCR_EOG_03_FEM_PC',
#        'pct_CCR_EOG_03_HI7_PC', 'pct_CCR_EOG_03_MALE_PC',
#        'pct_CCR_EOG_03_WH7_PC', 'pct_CCR_EOG_04_AIG_PC',
#        'pct_CCR_EOG_04_ALL_PC', 'pct_CCR_EOG_04_BL7_PC',
#        'pct_CCR_EOG_04_EDS_PC', 'pct_CCR_EOG_04_ELS_PC',
#        'pct_CCR_EOG_04_FEM_PC', 'pct_CCR_EOG_04_HI7_PC',
#        'pct_CCR_EOG_04_MALE_PC', 'pct_CCR_EOG_04_WH7_PC',
#        'pct_CCR_EOG_05_AIG_PC', 'pct_CCR_EOG_05_ALL_PC',
#        'pct_CCR_EOG_05_BL7_PC', 'pct_CCR_EOG_05_EDS_PC',
#        'pct_CCR_EOG_05_ELS_PC', 'pct_CCR_EOG_05_FEM_PC',
#        'pct_CCR_EOG_05_HI7_PC', 'pct_CCR_EOG_05_MALE_PC',
#        'pct_CCR_EOG_05_MU7_PC', 'pct_CCR_EOG_05_WH7_PC',
#        'pct_CCR_EOG_ALL_AIG_PC', 'pct_CCR_EOG_ALL_ALL_PC',
#        'pct_CCR_EOG_ALL_BL7_PC', 'pct_CCR_EOG_ALL_EDS_PC',
#        'pct_CCR_EOG_ALL_ELS_PC', 'pct_CCR_EOG_ALL_FEM_PC',
#        'pct_CCR_EOG_ALL_HI7_PC', 'pct_CCR_EOG_ALL_MALE_PC',
#        'pct_CCR_EOG_ALL_MU7_PC', 'pct_CCR_EOG_ALL_SWD_PC',
#        'pct_CCR_EOG_ALL_WH7_PC', 'pct_CCR_MA_03_ALL_PC',
#        'pct_CCR_MA_03_BL7_PC', 'pct_CCR_MA_03_FEM_PC',
#        'pct_CCR_MA_03_HI7_PC', 'pct_CCR_MA_03_MALE_PC',
#        'pct_CCR_MA_03_WH7_PC', 'pct_CCR_MA_04_ALL_PC',
#        'pct_CCR_MA_04_BL7_PC', 'pct_CCR_MA_04_EDS_PC',
#        'pct_CCR_MA_04_FEM_PC', 'pct_CCR_MA_04_HI7_PC',
#        'pct_CCR_MA_04_MALE_PC', 'pct_CCR_MA_04_SWD_PC',
#        'pct_CCR_MA_04_WH7_PC', 'pct_CCR_MA_05_AIG_PC',
#        'pct_CCR_MA_05_ALL_PC', 'pct_CCR_MA_05_BL7_PC',
#        'pct_CCR_MA_05_EDS_PC', 'pct_CCR_MA_05_FEM_PC',
#        'pct_CCR_MA_05_HI7_PC', 'pct_CCR_MA_05_MALE_PC',
#        'pct_CCR_MA_05_WH7_PC', 'pct_CCR_MA_ALL_AIG_PC',
#        'pct_CCR_MA_ALL_ALL_PC', 'pct_CCR_MA_ALL_BL7_PC',
#        'pct_CCR_MA_ALL_EDS_PC', 'pct_CCR_MA_ALL_ELS_PC',
#        'pct_CCR_MA_ALL_FEM_PC', 'pct_CCR_MA_ALL_HI7_PC',
#        'pct_CCR_MA_ALL_MALE_PC', 'pct_CCR_MA_ALL_MU7_PC',
#        'pct_CCR_MA_ALL_WH7_PC', 'pct_CCR_RD_03_ALL_PC',
#        'pct_CCR_RD_03_BL7_PC', 'pct_CCR_RD_03_FEM_PC',
#        'pct_CCR_RD_03_HI7_PC', 'pct_CCR_RD_03_MALE_PC',
#        'pct_CCR_RD_03_WH7_PC', 'pct_CCR_RD_04_ALL_PC',
#        'pct_CCR_RD_04_BL7_PC', 'pct_CCR_RD_04_EDS_PC',
#        'pct_CCR_RD_04_FEM_PC', 'pct_CCR_RD_04_HI7_PC',
#        'pct_CCR_RD_04_MALE_PC', 'pct_CCR_RD_04_SWD_PC',
#        'pct_CCR_RD_04_WH7_PC', 'pct_CCR_RD_05_AIG_PC',
#        'pct_CCR_RD_05_ALL_PC', 'pct_CCR_RD_05_BL7_PC',
#        'pct_CCR_RD_05_EDS_PC', 'pct_CCR_RD_05_FEM_PC',
#        'pct_CCR_RD_05_HI7_PC', 'pct_CCR_RD_05_MALE_PC',
#        'pct_CCR_RD_05_WH7_PC', 'pct_CCR_RD_ALL_AIG_PC',
#        'pct_CCR_RD_ALL_ALL_PC', 'pct_CCR_RD_ALL_BL7_PC',
#        'pct_CCR_RD_ALL_EDS_PC', 'pct_CCR_RD_ALL_ELS_PC',
#        'pct_CCR_RD_ALL_FEM_PC', 'pct_CCR_RD_ALL_HI7_PC',
#        'pct_CCR_RD_ALL_MALE_PC', 'pct_CCR_RD_ALL_MU7_PC',
#        'pct_CCR_RD_ALL_WH7_PC', 'pct_CCR_SC_05_AIG_PC',
#        'pct_CCR_SC_05_ALL_PC', 'pct_CCR_SC_05_BL7_PC',
#        'pct_CCR_SC_05_EDS_PC', 'pct_CCR_SC_05_FEM_PC',
#        'pct_CCR_SC_05_HI7_PC', 'pct_CCR_SC_05_MALE_PC',
#        'pct_CCR_SC_05_SWD_PC', 'pct_CCR_SC_05_WH7_PC',
#        'pct_CCR_SC_ALL_AIG_PC', 'pct_CCR_SC_ALL_ALL_PC',
#        'pct_CCR_SC_ALL_BL7_PC', 'pct_CCR_SC_ALL_EDS_PC',
#        'pct_CCR_SC_ALL_FEM_PC', 'pct_CCR_SC_ALL_HI7_PC',
#        'pct_CCR_SC_ALL_MALE_PC', 'pct_CCR_SC_ALL_WH7_PC',
#        'pct_GLP_EOG_03_ALL_PC', 'pct_GLP_EOG_04_ALL_PC',
#        'pct_GLP_EOG_04_BL7_PC', 'pct_GLP_EOG_05_ALL_PC',
#        'pct_GLP_EOG_05_BL7_PC', 'pct_GLP_EOG_05_EDS_PC',
#        'pct_GLP_EOG_05_ELS_PC', 'pct_GLP_EOG_05_MALE_PC',
#        'pct_GLP_EOG_ALL_ALL_PC', 'pct_GLP_EOG_ALL_BL7_PC',
#        'pct_GLP_EOG_ALL_EDS_PC', 'pct_GLP_EOG_ALL_FEM_PC',
#        'pct_GLP_EOG_ALL_MALE_PC', 'pct_GLP_MA_03_WH7_PC',
#        'pct_GLP_MA_04_WH7_PC', 'pct_GLP_MA_05_AIG_PC',
#        'pct_GLP_MA_05_BL7_PC', 'pct_GLP_MA_05_WH7_PC',
#        'pct_GLP_MA_ALL_AIG_PC', 'pct_GLP_MA_ALL_ALL_PC',
#        'pct_GLP_MA_ALL_FEM_PC', 'pct_GLP_MA_ALL_MALE_PC',
#        'pct_GLP_MA_ALL_MU7_PC', 'pct_GLP_MA_ALL_WH7_PC',
#        'pct_GLP_RD_03_ALL_PC', 'pct_GLP_RD_04_ALL_PC',
#        'pct_GLP_RD_04_BL7_PC', 'pct_GLP_RD_04_WH7_PC',
#        'pct_GLP_RD_05_AIG_PC', 'pct_GLP_RD_05_ALL_PC',
#        'pct_GLP_RD_05_WH7_PC', 'pct_GLP_RD_ALL_ALL_PC',
#        'pct_GLP_RD_ALL_FEM_PC', 'pct_GLP_RD_ALL_MALE_PC',
#        'pct_GLP_SC_05_AIG_PC', 'pct_GLP_SC_05_ALL_PC',
#        'pct_GLP_SC_05_BL7_PC', 'pct_GLP_SC_05_EDS_PC',
#        'pct_GLP_SC_05_FEM_PC', 'pct_GLP_SC_05_HI7_PC',
#        'pct_GLP_SC_05_MALE_PC', 'pct_GLP_SC_05_SWD_PC',
#        'pct_GLP_SC_05_WH7_PC', 'pct_GLP_SC_ALL_BL7_PC',
#        'pct_GLP_SC_ALL_HI7_PC', 'pct_L1_ALL_ALL_ALL_PC',
#        'pct_L1_ALL_ALL_BL7_PC', 'pct_L1_ALL_ALL_EDS_PC',
#        'pct_L1_ALL_ALL_ELS_PC', 'pct_L1_ALL_ALL_FEM_PC',
#        'pct_L1_ALL_ALL_MALE_PC', 'pct_L1_ALL_ALL_MU7_PC',
#        'pct_L1_ALL_ALL_SWD_PC', 'pct_L1_ALL_ALL_WH7_PC',
#        'pct_L1_EOG_05_ALL_PC', 'pct_L1_EOG_ALL_ALL_PC',
#        'pct_L1_EOG_ALL_MALE_PC', 'pct_L1_MA_ALL_ALL_PC',
#        'pct_L1_RD_ALL_ALL_PC', 'pct_L1_SC_05_FEM_PC',
#        'pct_L1_SC_05_HI7_PC', 'pct_L1_SC_05_WH7_PC',
#        'pct_L2_ALL_ALL_ALL_PC', 'pct_L2_ALL_ALL_BL7_PC',
#        'pct_L2_ALL_ALL_EDS_PC', 'pct_L2_ALL_ALL_ELS_PC',
#        'pct_L2_ALL_ALL_FEM_PC', 'pct_L2_ALL_ALL_HI7_PC',
#        'pct_L2_ALL_ALL_MALE_PC', 'pct_L2_ALL_ALL_MU7_PC',
#        'pct_L2_ALL_ALL_SWD_PC', 'pct_L2_ALL_ALL_WH7_PC',
#        'pct_L2_EOG_ALL_ALL_PC', 'pct_L2_SC_05_BL7_PC',
#        'pct_L2_SC_05_EDS_PC', 'pct_L2_SC_05_FEM_PC',
#        'pct_L2_SC_05_HI7_PC', 'pct_L2_SC_05_WH7_PC',
#        'pct_L3_ALL_ALL_ALL_PC', 'pct_L3_ALL_ALL_BL7_PC',
#        'pct_L3_ALL_ALL_EDS_PC', 'pct_L3_ALL_ALL_ELS_PC',
#        'pct_L3_ALL_ALL_FEM_PC', 'pct_L3_ALL_ALL_HI7_PC',
#        'pct_L3_ALL_ALL_MALE_PC', 'pct_L3_ALL_ALL_MU7_PC',
#        'pct_L3_ALL_ALL_SWD_PC', 'pct_L3_ALL_ALL_WH7_PC',
#        'pct_L3_SC_05_BL7_PC', 'pct_L3_SC_05_EDS_PC',
#        'pct_L3_SC_05_HI7_PC', 'pct_L3_SC_05_MALE_PC',
#        'pct_L3_SC_05_WH7_PC', 'pct_L4_ALL_ALL_AIG_PC',
#        'pct_L4_ALL_ALL_ALL_PC', 'pct_L4_ALL_ALL_BL7_PC',
#        'pct_L4_ALL_ALL_EDS_PC', 'pct_L4_ALL_ALL_ELS_PC',
#        'pct_L4_ALL_ALL_FEM_PC', 'pct_L4_ALL_ALL_HI7_PC',
#        'pct_L4_ALL_ALL_MALE_PC', 'pct_L4_ALL_ALL_MU7_PC',
#        'pct_L4_ALL_ALL_SWD_PC', 'pct_L4_ALL_ALL_WH7_PC',
#        'pct_L4_EOG_ALL_ALL_PC', 'pct_L4_MA_ALL_ALL_PC',
#        'pct_L4_RD_ALL_ALL_PC', 'pct_L4_SC_05_AIG_PC',
#        'pct_L4_SC_05_ALL_PC', 'pct_L4_SC_05_BL7_PC',
#        'pct_L4_SC_05_EDS_PC', 'pct_L4_SC_05_FEM_PC',
#        'pct_L4_SC_05_HI7_PC', 'pct_L4_SC_05_MALE_PC',
#        'pct_L4_SC_05_SWD_PC', 'pct_L4_SC_05_WH7_PC',
#        'pct_L5_ALL_ALL_AIG_PC', 'pct_L5_ALL_ALL_ALL_PC',
#        'pct_L5_ALL_ALL_EDS_PC', 'pct_L5_ALL_ALL_ELS_PC',
#        'pct_L5_ALL_ALL_FEM_PC', 'pct_L5_ALL_ALL_HI7_PC',
#        'pct_L5_ALL_ALL_MALE_PC', 'pct_L5_ALL_ALL_MU7_PC',
#        'pct_L5_ALL_ALL_WH7_PC', 'pct_L5_EOG_03_ALL_PC',
#        'pct_L5_EOG_04_ALL_PC', 'pct_L5_EOG_04_MALE_PC',
#        'pct_L5_EOG_05_ALL_PC', 'pct_L5_EOG_ALL_ALL_PC',
#        'pct_L5_EOG_ALL_FEM_PC', 'pct_L5_EOG_ALL_MALE_PC',
#        'pct_L5_MA_ALL_ALL_PC', 'pct_L5_SC_05_AIG_PC',
#        'pct_L5_SC_05_ALL_PC', 'pct_L5_SC_05_EDS_PC',
#        'pct_L5_SC_05_FEM_PC', 'pct_L5_SC_05_MALE_PC',
#        'pct_L5_SC_05_WH7_PC', 'ma_score', 'rd_score', 'ach_score',
#        'spg_score', 'ma_spg_score', 'aaa_score_ALL_SPG2',
#        'aaa_score_BL7_SPG2', 'aaa_score_EDS_SPG2', 'aaa_score_ELS_SPG2',
#        'aaa_score_HI7_SPG2', 'aaa_score_SWD_SPG2', 'aaa_score_WH7_SPG2',
#        'ach_score_ELS_SPG2', 'pct_ALL_CHRON_ABSENT', 'crime',
#        'arre_per1000_ALL', 'arre_per1000_BL7', 'arre_per1000_EDS',
#        'arre_per1000_MALE', 'arre_per1000_SWD', 'arre_per1000_WH7',
#        'crime_per1000_ALL', 'crime_per1000_BL7', 'crime_per1000_ELS',
#        'crime_per1000_MALE', 'crime_per1000_MU7', 'crime_per1000_SWD',
#        'iss_per1000_ALL', 'iss_per1000_EDS', 'rplw_per1000_ALL',
#        'rplw_per1000_MALE', 'pct_ALL_PK_ENROLL', 'count_ALL_PK_ENROLL',
#        'lea_code_020LEA', 'lea_code_030LEA', 'lea_code_040LEA',
#        'lea_code_050LEA', 'lea_code_060LEA', 'lea_code_070LEA',
#        'lea_code_080LEA', 'lea_code_090LEA', 'lea_code_100LEA',
#        'lea_code_110LEA', 'lea_code_111LEA', 'lea_code_120LEA',
#        'lea_code_130LEA', 'lea_code_132LEA', 'lea_code_140LEA',
#        'lea_code_150LEA', 'lea_code_160LEA', 'lea_code_170LEA',
#        'lea_code_180LEA', 'lea_code_181LEA', 'lea_code_182LEA',
#        'lea_code_190LEA', 'lea_code_200LEA', 'lea_code_210LEA',
#        'lea_code_220LEA', 'lea_code_230LEA', 'lea_code_240LEA',
#        'lea_code_241LEA', 'lea_code_250LEA', 'lea_code_260LEA',
#        'lea_code_270LEA', 'lea_code_280LEA', 'lea_code_290LEA',
#        'lea_code_291LEA', 'lea_code_292LEA', 'lea_code_300LEA',
#        'lea_code_310LEA', 'lea_code_320LEA', 'lea_code_330LEA',
#        'lea_code_340LEA', 'lea_code_350LEA', 'lea_code_360LEA',
#        'lea_code_370LEA', 'lea_code_380LEA', 'lea_code_390LEA',
#        'lea_code_400LEA', 'lea_code_410LEA', 'lea_code_420LEA',
#        'lea_code_421LEA', 'lea_code_422LEA', 'lea_code_430LEA',
#        'lea_code_440LEA', 'lea_code_450LEA', 'lea_code_460LEA',
#        'lea_code_470LEA', 'lea_code_480LEA', 'lea_code_490LEA',
#        'lea_code_491LEA', 'lea_code_500LEA', 'lea_code_510LEA',
#        'lea_code_520LEA', 'lea_code_530LEA', 'lea_code_540LEA',
#        'lea_code_550LEA', 'lea_code_560LEA', 'lea_code_570LEA',
#        'lea_code_580LEA', 'lea_code_590LEA', 'lea_code_600LEA',
#        'lea_code_610LEA', 'lea_code_620LEA', 'lea_code_630LEA',
#        'lea_code_640LEA', 'lea_code_650LEA', 'lea_code_660LEA',
#        'lea_code_670LEA', 'lea_code_680LEA', 'lea_code_681LEA',
#        'lea_code_690LEA', 'lea_code_700LEA', 'lea_code_710LEA',
#        'lea_code_720LEA', 'lea_code_730LEA', 'lea_code_740LEA',
#        'lea_code_750LEA', 'lea_code_760LEA', 'lea_code_761LEA',
#        'lea_code_770LEA', 'lea_code_780LEA', 'lea_code_790LEA',
#        'lea_code_800LEA', 'lea_code_810LEA', 'lea_code_820LEA',
#        'lea_code_821LEA', 'lea_code_830LEA', 'lea_code_840LEA',
#        'lea_code_850LEA', 'lea_code_860LEA', 'lea_code_861LEA',
#        'lea_code_862LEA', 'lea_code_870LEA', 'lea_code_880LEA',
#        'lea_code_890LEA', 'lea_code_900LEA', 'lea_code_910LEA',
#        'lea_code_920LEA', 'lea_code_930LEA', 'lea_code_940LEA',
#        'lea_code_950LEA', 'lea_code_960LEA', 'lea_code_970LEA',
#        'lea_code_980LEA', 'lea_code_990LEA', 'lea_code_995LEA',
#        'county_Alexander', 'county_Alleghany', 'county_Anson',
#        'county_Ashe', 'county_Avery', 'county_Beaufort', 'county_Bertie',
#        'county_Bladen', 'county_Brunswick', 'county_Burke',
#        'county_Caldwell', 'county_Camden', 'county_Carteret',
#        'county_Caswell', 'county_Chatham', 'county_Cherokee',
#        'county_Chowan', 'county_Clay', 'county_Cleveland',
#        'county_Craven', 'county_Cumberland', 'county_Currituck',
#        'county_Dare', 'county_Davie', 'county_Duplin', 'county_Durham',
#        'county_Edgecombe', 'county_Forsyth', 'county_Franklin',
#        'county_Gaston', 'county_Gates', 'county_Graham',
#        'county_Granville', 'county_Greene', 'county_Guilford',
#        'county_Harnett', 'county_Haywood', 'county_Henderson',
#        'county_Hertford', 'county_Hoke', 'county_Hyde', 'county_Jackson',
#        'county_Johnston', 'county_Jones', 'county_Lee', 'county_Lenoir',
#        'county_Lincoln', 'county_Macon', 'county_Madison',
#        'county_Martin', 'county_McDowell', 'county_Mecklenburg',
#        'county_Mitchell', 'county_Montgomery', 'county_Moore',
#        'county_Nash', 'county_New Hanover', 'county_Northampton',
#        'county_Onslow', 'county_Pamlico', 'county_Pasquotank',
#        'county_Pender', 'county_Perquimans', 'county_Person',
#        'county_Pitt', 'county_Polk', 'county_Richmond', 'county_Robeson',
#        'county_Rockingham', 'county_Rowan', 'county_Rutherford',
#        'county_Scotland', 'county_Stanly', 'county_Stokes',
#        'county_Swain', 'county_Transylvania', 'county_Tyrrell',
#        'county_Union', 'county_Vance', 'county_Wake', 'county_Warren',
#        'county_Washington', 'county_Watauga', 'county_Wayne',
#        'county_Wilkes', 'county_Wilson', 'county_Yadkin', 'county_Yancey',
#        'grade_span_KG:13'], dtype=object)

# %%
#Check columns before drop 
print('\r\n*********Before: Dropping Highly Correlated Fields*************************************')
schoolData.info(verbose=False)

# Drop the highly correlated features from our training data 
#schoolData = schoolData.drop(to_drop, axis=1)
schoolData = schoolData.drop(cf['Field2'], axis=1)

#Check columns after drop 
print('\r\n*********After: Dropping Highly Correlated Fields**************************************')
schoolData.info(verbose=False)
# Out:
# *********Before: Dropping Highly Correlated Fields*************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1422 entries, 2 to 1574
# Columns: 1637 entries, IndianPct to agency_lea_code_995LEA
# dtypes: float64(1134), uint8(503)
# memory usage: 13.0 MB
#
# *********After: Dropping Highly Correlated Fields**************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1422 entries, 2 to 1574
# Columns: 1121 entries, PacificIslandPct to agency_lea_code_995LEA
# dtypes: float64(821), uint8(300)
# memory usage: 9.3 MB

# %%
#Restore the unit_code before saving
schoolData['agency_code'] = agency_code
#Save the final dataset to a .csv file
schoolData.to_csv(outputDir + inputFileName + '_ML.csv', sep=',', index=False)

# %%
print('*********FINAL DATASET DETAILS*********************************************************\r\n')
schoolData.info(verbose=True)
# Out:
# *********FINAL DATASET DETAILS*********************************************************
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1422 entries, 2 to 1574
# Data columns (total 1122 columns):
#  #    Column                                                                 Dtype
# ---   ------                                                                 -----
#  0    PacificIslandPct                                                       float64
#  1    TwoOrMorePct                                                           float64
#  2    HispanicMalePct                                                        float64
#  3    BlackMalePct                                                           float64
#  4    PacificIslandMalePct                                                   float64
#  5    TwoOrMoreMalePct                                                       float64
#  6    IndianFemalePct                                                        float64
#  7    AsianFemalePct                                                         float64
#  8    HispanicFemalePct                                                      float64
#  9    BlackFemalePct                                                         float64
#  10   WhiteFemalePct                                                         float64
#  11   MinorityFemalePct                                                      float64
#  12   PacificIslandFemalePct                                                 float64
#  13   TwoOrMoreFemalePct                                                     float64
#  14   pct_eds                                                                float64
#  15   pct_EDS_ELP                                                            float64
#  16   pct_ELS_ELP                                                            float64
#  17   pct_FEM_ELP                                                            float64
#  18   pct_HI7_ELP                                                            float64
#  19   pct_MALE_ELP                                                           float64
#  20   pct_met_Math Grades 3-8_LTG                                            float64
#  21   pct_met_Reading Grades 3-8_LTG                                         float64
#  22   pct_met_Total Targets_LTG                                              float64
#  23   pct_Reading Grades 3-8_ALL_PART_DET                                    float64
#  24   pct_Reading Grades 3-8_BL7_PART_DET                                    float64
#  25   pct_Reading Grades 3-8_EDS_PART_DET                                    float64
#  26   pct_Reading Grades 3-8_HI7_PART_DET                                    float64
#  27   pct_Reading Grades 3-8_SWD_PART_DET                                    float64
#  28   pct_Reading Grades 3-8_WH7_PART_DET                                    float64
#  29   pct_Science Grades 5&8_ALL_PART_DET                                    float64
#  30   pct_Science Grades 5&8_EDS_PART_DET                                    float64
#  31   pct_CCR_EOG_03_SWD_PC                                                  float64
#  32   pct_CCR_EOG_04_SWD_PC                                                  float64
#  33   pct_CCR_EOG_05_SWD_PC                                                  float64
#  34   pct_CCR_MA_03_EDS_PC                                                   float64
#  35   pct_CCR_MA_03_SWD_PC                                                   float64
#  36   pct_CCR_MA_05_SWD_PC                                                   float64
#  37   pct_CCR_MA_ALL_SWD_PC                                                  float64
#  38   pct_CCR_RD_03_EDS_PC                                                   float64
#  39   pct_CCR_RD_03_SWD_PC                                                   float64
#  40   pct_CCR_RD_ALL_SWD_PC                                                  float64
#  41   pct_CCR_SC_ALL_SWD_PC                                                  float64
#  42   pct_GLP_EOG_03_BL7_PC                                                  float64
#  43   pct_GLP_EOG_03_EDS_PC                                                  float64
#  44   pct_GLP_EOG_03_ELS_PC                                                  float64
#  45   pct_GLP_EOG_03_FEM_PC                                                  float64
#  46   pct_GLP_EOG_03_HI7_PC                                                  float64
#  47   pct_GLP_EOG_03_MALE_PC                                                 float64
#  48   pct_GLP_EOG_03_SWD_PC                                                  float64
#  49   pct_GLP_EOG_03_WH7_PC                                                  float64
#  50   pct_GLP_EOG_04_AIG_PC                                                  float64
#  51   pct_GLP_EOG_04_EDS_PC                                                  float64
#  52   pct_GLP_EOG_04_ELS_PC                                                  float64
#  53   pct_GLP_EOG_04_FEM_PC                                                  float64
#  54   pct_GLP_EOG_04_HI7_PC                                                  float64
#  55   pct_GLP_EOG_04_MALE_PC                                                 float64
#  56   pct_GLP_EOG_04_SWD_PC                                                  float64
#  57   pct_GLP_EOG_04_WH7_PC                                                  float64
#  58   pct_GLP_EOG_05_AIG_PC                                                  float64
#  59   pct_GLP_EOG_05_FEM_PC                                                  float64
#  60   pct_GLP_EOG_05_HI7_PC                                                  float64
#  61   pct_GLP_EOG_05_MU7_PC                                                  float64
#  62   pct_GLP_EOG_05_SWD_PC                                                  float64
#  63   pct_GLP_EOG_05_WH7_PC                                                  float64
#  64   pct_GLP_EOG_ALL_AIG_PC                                                 float64
#  65   pct_GLP_EOG_ALL_ELS_PC                                                 float64
#  66   pct_GLP_EOG_ALL_HI7_PC                                                 float64
#  67   pct_GLP_EOG_ALL_MU7_PC                                                 float64
#  68   pct_GLP_EOG_ALL_SWD_PC                                                 float64
#  69   pct_GLP_EOG_ALL_WH7_PC                                                 float64
#  70   pct_GLP_MA_03_ALL_PC                                                   float64
#  71   pct_GLP_MA_03_BL7_PC                                                   float64
#  72   pct_GLP_MA_03_EDS_PC                                                   float64
#  73   pct_GLP_MA_03_FEM_PC                                                   float64
#  74   pct_GLP_MA_03_HI7_PC                                                   float64
#  75   pct_GLP_MA_03_MALE_PC                                                  float64
#  76   pct_GLP_MA_03_SWD_PC                                                   float64
#  77   pct_GLP_MA_04_ALL_PC                                                   float64
#  78   pct_GLP_MA_04_BL7_PC                                                   float64
#  79   pct_GLP_MA_04_EDS_PC                                                   float64
#  80   pct_GLP_MA_04_FEM_PC                                                   float64
#  81   pct_GLP_MA_04_HI7_PC                                                   float64
#  82   pct_GLP_MA_04_MALE_PC                                                  float64
#  83   pct_GLP_MA_04_SWD_PC                                                   float64
#  84   pct_GLP_MA_05_ALL_PC                                                   float64
#  85   pct_GLP_MA_05_EDS_PC                                                   float64
#  86   pct_GLP_MA_05_FEM_PC                                                   float64
#  87   pct_GLP_MA_05_HI7_PC                                                   float64
#  88   pct_GLP_MA_05_MALE_PC                                                  float64
#  89   pct_GLP_MA_05_SWD_PC                                                   float64
#  90   pct_GLP_MA_ALL_BL7_PC                                                  float64
#  91   pct_GLP_MA_ALL_EDS_PC                                                  float64
#  92   pct_GLP_MA_ALL_ELS_PC                                                  float64
#  93   pct_GLP_MA_ALL_HI7_PC                                                  float64
#  94   pct_GLP_MA_ALL_SWD_PC                                                  float64
#  95   pct_GLP_RD_03_BL7_PC                                                   float64
#  96   pct_GLP_RD_03_EDS_PC                                                   float64
#  97   pct_GLP_RD_03_FEM_PC                                                   float64
#  98   pct_GLP_RD_03_HI7_PC                                                   float64
#  99   pct_GLP_RD_03_MALE_PC                                                  float64
#  100  pct_GLP_RD_03_SWD_PC                                                   float64
#  101  pct_GLP_RD_03_WH7_PC                                                   float64
#  102  pct_GLP_RD_04_EDS_PC                                                   float64
#  103  pct_GLP_RD_04_FEM_PC                                                   float64
#  104  pct_GLP_RD_04_HI7_PC                                                   float64
#  105  pct_GLP_RD_04_MALE_PC                                                  float64
#  106  pct_GLP_RD_04_SWD_PC                                                   float64
#  107  pct_GLP_RD_05_BL7_PC                                                   float64
#  108  pct_GLP_RD_05_EDS_PC                                                   float64
#  109  pct_GLP_RD_05_FEM_PC                                                   float64
#  110  pct_GLP_RD_05_HI7_PC                                                   float64
#  111  pct_GLP_RD_05_MALE_PC                                                  float64
#  112  pct_GLP_RD_05_SWD_PC                                                   float64
#  113  pct_GLP_RD_ALL_AIG_PC                                                  float64
#  114  pct_GLP_RD_ALL_BL7_PC                                                  float64
#  115  pct_GLP_RD_ALL_EDS_PC                                                  float64
#  116  pct_GLP_RD_ALL_ELS_PC                                                  float64
#  117  pct_GLP_RD_ALL_HI7_PC                                                  float64
#  118  pct_GLP_RD_ALL_MU7_PC                                                  float64
#  119  pct_GLP_RD_ALL_SWD_PC                                                  float64
#  120  pct_GLP_RD_ALL_WH7_PC                                                  float64
#  121  pct_GLP_SC_ALL_AIG_PC                                                  float64
#  122  pct_GLP_SC_ALL_ALL_PC                                                  float64
#  123  pct_GLP_SC_ALL_EDS_PC                                                  float64
#  124  pct_GLP_SC_ALL_FEM_PC                                                  float64
#  125  pct_GLP_SC_ALL_MALE_PC                                                 float64
#  126  pct_GLP_SC_ALL_SWD_PC                                                  float64
#  127  pct_GLP_SC_ALL_WH7_PC                                                  float64
#  128  pct_L1_ALL_ALL_HI7_PC                                                  float64
#  129  pct_L1_EOG_03_ALL_PC                                                   float64
#  130  pct_L1_EOG_03_BL7_PC                                                   float64
#  131  pct_L1_EOG_03_EDS_PC                                                   float64
#  132  pct_L1_EOG_03_ELS_PC                                                   float64
#  133  pct_L1_EOG_03_FEM_PC                                                   float64
#  134  pct_L1_EOG_03_HI7_PC                                                   float64
#  135  pct_L1_EOG_03_MALE_PC                                                  float64
#  136  pct_L1_EOG_03_SWD_PC                                                   float64
#  137  pct_L1_EOG_03_WH7_PC                                                   float64
#  138  pct_L1_EOG_04_ALL_PC                                                   float64
#  139  pct_L1_EOG_04_BL7_PC                                                   float64
#  140  pct_L1_EOG_04_EDS_PC                                                   float64
#  141  pct_L1_EOG_04_ELS_PC                                                   float64
#  142  pct_L1_EOG_04_FEM_PC                                                   float64
#  143  pct_L1_EOG_04_HI7_PC                                                   float64
#  144  pct_L1_EOG_04_MALE_PC                                                  float64
#  145  pct_L1_EOG_04_SWD_PC                                                   float64
#  146  pct_L1_EOG_04_WH7_PC                                                   float64
#  147  pct_L1_EOG_05_BL7_PC                                                   float64
#  148  pct_L1_EOG_05_EDS_PC                                                   float64
#  149  pct_L1_EOG_05_ELS_PC                                                   float64
#  150  pct_L1_EOG_05_FEM_PC                                                   float64
#  151  pct_L1_EOG_05_HI7_PC                                                   float64
#  152  pct_L1_EOG_05_MALE_PC                                                  float64
#  153  pct_L1_EOG_05_SWD_PC                                                   float64
#  154  pct_L1_EOG_05_WH7_PC                                                   float64
#  155  pct_L1_EOG_ALL_BL7_PC                                                  float64
#  156  pct_L1_EOG_ALL_EDS_PC                                                  float64
#  157  pct_L1_EOG_ALL_ELS_PC                                                  float64
#  158  pct_L1_EOG_ALL_FEM_PC                                                  float64
#  159  pct_L1_EOG_ALL_HI7_PC                                                  float64
#  160  pct_L1_EOG_ALL_MU7_PC                                                  float64
#  161  pct_L1_EOG_ALL_SWD_PC                                                  float64
#  162  pct_L1_EOG_ALL_WH7_PC                                                  float64
#  163  pct_L1_MA_03_ALL_PC                                                    float64
#  164  pct_L1_MA_03_BL7_PC                                                    float64
#  165  pct_L1_MA_03_EDS_PC                                                    float64
#  166  pct_L1_MA_03_FEM_PC                                                    float64
#  167  pct_L1_MA_03_HI7_PC                                                    float64
#  168  pct_L1_MA_03_MALE_PC                                                   float64
#  169  pct_L1_MA_03_SWD_PC                                                    float64
#  170  pct_L1_MA_03_WH7_PC                                                    float64
#  171  pct_L1_MA_04_ALL_PC                                                    float64
#  172  pct_L1_MA_04_BL7_PC                                                    float64
#  173  pct_L1_MA_04_EDS_PC                                                    float64
#  174  pct_L1_MA_04_FEM_PC                                                    float64
#  175  pct_L1_MA_04_HI7_PC                                                    float64
#  176  pct_L1_MA_04_MALE_PC                                                   float64
#  177  pct_L1_MA_04_SWD_PC                                                    float64
#  178  pct_L1_MA_04_WH7_PC                                                    float64
#  179  pct_L1_MA_05_ALL_PC                                                    float64
#  180  pct_L1_MA_05_BL7_PC                                                    float64
#  181  pct_L1_MA_05_EDS_PC                                                    float64
#  182  pct_L1_MA_05_FEM_PC                                                    float64
#  183  pct_L1_MA_05_HI7_PC                                                    float64
#  184  pct_L1_MA_05_MALE_PC                                                   float64
#  185  pct_L1_MA_05_SWD_PC                                                    float64
#  186  pct_L1_MA_05_WH7_PC                                                    float64
#  187  pct_L1_MA_ALL_BL7_PC                                                   float64
#  188  pct_L1_MA_ALL_EDS_PC                                                   float64
#  189  pct_L1_MA_ALL_ELS_PC                                                   float64
#  190  pct_L1_MA_ALL_FEM_PC                                                   float64
#  191  pct_L1_MA_ALL_HI7_PC                                                   float64
#  192  pct_L1_MA_ALL_MALE_PC                                                  float64
#  193  pct_L1_MA_ALL_MU7_PC                                                   float64
#  194  pct_L1_MA_ALL_SWD_PC                                                   float64
#  195  pct_L1_MA_ALL_WH7_PC                                                   float64
#  196  pct_L1_RD_03_ALL_PC                                                    float64
#  197  pct_L1_RD_03_BL7_PC                                                    float64
#  198  pct_L1_RD_03_EDS_PC                                                    float64
#  199  pct_L1_RD_03_FEM_PC                                                    float64
#  200  pct_L1_RD_03_HI7_PC                                                    float64
#  201  pct_L1_RD_03_MALE_PC                                                   float64
#  202  pct_L1_RD_03_SWD_PC                                                    float64
#  203  pct_L1_RD_03_WH7_PC                                                    float64
#  204  pct_L1_RD_04_ALL_PC                                                    float64
#  205  pct_L1_RD_04_BL7_PC                                                    float64
#  206  pct_L1_RD_04_EDS_PC                                                    float64
#  207  pct_L1_RD_04_FEM_PC                                                    float64
#  208  pct_L1_RD_04_HI7_PC                                                    float64
#  209  pct_L1_RD_04_MALE_PC                                                   float64
#  210  pct_L1_RD_04_SWD_PC                                                    float64
#  211  pct_L1_RD_04_WH7_PC                                                    float64
#  212  pct_L1_RD_05_ALL_PC                                                    float64
#  213  pct_L1_RD_05_BL7_PC                                                    float64
#  214  pct_L1_RD_05_EDS_PC                                                    float64
#  215  pct_L1_RD_05_FEM_PC                                                    float64
#  216  pct_L1_RD_05_HI7_PC                                                    float64
#  217  pct_L1_RD_05_MALE_PC                                                   float64
#  218  pct_L1_RD_05_SWD_PC                                                    float64
#  219  pct_L1_RD_05_WH7_PC                                                    float64
#  220  pct_L1_RD_ALL_BL7_PC                                                   float64
#  221  pct_L1_RD_ALL_EDS_PC                                                   float64
#  222  pct_L1_RD_ALL_ELS_PC                                                   float64
#  223  pct_L1_RD_ALL_FEM_PC                                                   float64
#  224  pct_L1_RD_ALL_HI7_PC                                                   float64
#  225  pct_L1_RD_ALL_MALE_PC                                                  float64
#  226  pct_L1_RD_ALL_MU7_PC                                                   float64
#  227  pct_L1_RD_ALL_SWD_PC                                                   float64
#  228  pct_L1_RD_ALL_WH7_PC                                                   float64
#  229  pct_L1_SC_05_ALL_PC                                                    float64
#  230  pct_L1_SC_05_BL7_PC                                                    float64
#  231  pct_L1_SC_05_EDS_PC                                                    float64
#  232  pct_L1_SC_05_MALE_PC                                                   float64
#  233  pct_L1_SC_05_SWD_PC                                                    float64
#  234  pct_L1_SC_ALL_ALL_PC                                                   float64
#  235  pct_L1_SC_ALL_BL7_PC                                                   float64
#  236  pct_L1_SC_ALL_EDS_PC                                                   float64
#  237  pct_L1_SC_ALL_FEM_PC                                                   float64
#  238  pct_L1_SC_ALL_HI7_PC                                                   float64
#  239  pct_L1_SC_ALL_MALE_PC                                                  float64
#  240  pct_L1_SC_ALL_SWD_PC                                                   float64
#  241  pct_L1_SC_ALL_WH7_PC                                                   float64
#  242  pct_L2_EOG_03_ALL_PC                                                   float64
#  243  pct_L2_EOG_03_BL7_PC                                                   float64
#  244  pct_L2_EOG_03_EDS_PC                                                   float64
#  245  pct_L2_EOG_03_ELS_PC                                                   float64
#  246  pct_L2_EOG_03_FEM_PC                                                   float64
#  247  pct_L2_EOG_03_HI7_PC                                                   float64
#  248  pct_L2_EOG_03_MALE_PC                                                  float64
#  249  pct_L2_EOG_03_SWD_PC                                                   float64
#  250  pct_L2_EOG_03_WH7_PC                                                   float64
#  251  pct_L2_EOG_04_ALL_PC                                                   float64
#  252  pct_L2_EOG_04_BL7_PC                                                   float64
#  253  pct_L2_EOG_04_EDS_PC                                                   float64
#  254  pct_L2_EOG_04_ELS_PC                                                   float64
#  255  pct_L2_EOG_04_FEM_PC                                                   float64
#  256  pct_L2_EOG_04_HI7_PC                                                   float64
#  257  pct_L2_EOG_04_MALE_PC                                                  float64
#  258  pct_L2_EOG_04_SWD_PC                                                   float64
#  259  pct_L2_EOG_04_WH7_PC                                                   float64
#  260  pct_L2_EOG_05_ALL_PC                                                   float64
#  261  pct_L2_EOG_05_BL7_PC                                                   float64
#  262  pct_L2_EOG_05_EDS_PC                                                   float64
#  263  pct_L2_EOG_05_ELS_PC                                                   float64
#  264  pct_L2_EOG_05_FEM_PC                                                   float64
#  265  pct_L2_EOG_05_HI7_PC                                                   float64
#  266  pct_L2_EOG_05_MALE_PC                                                  float64
#  267  pct_L2_EOG_05_SWD_PC                                                   float64
#  268  pct_L2_EOG_05_WH7_PC                                                   float64
#  269  pct_L2_EOG_ALL_BL7_PC                                                  float64
#  270  pct_L2_EOG_ALL_EDS_PC                                                  float64
#  271  pct_L2_EOG_ALL_ELS_PC                                                  float64
#  272  pct_L2_EOG_ALL_FEM_PC                                                  float64
#  273  pct_L2_EOG_ALL_HI7_PC                                                  float64
#  274  pct_L2_EOG_ALL_MALE_PC                                                 float64
#  275  pct_L2_EOG_ALL_MU7_PC                                                  float64
#  276  pct_L2_EOG_ALL_SWD_PC                                                  float64
#  277  pct_L2_EOG_ALL_WH7_PC                                                  float64
#  278  pct_L2_MA_03_ALL_PC                                                    float64
#  279  pct_L2_MA_03_BL7_PC                                                    float64
#  280  pct_L2_MA_03_EDS_PC                                                    float64
#  281  pct_L2_MA_03_FEM_PC                                                    float64
#  282  pct_L2_MA_03_HI7_PC                                                    float64
#  283  pct_L2_MA_03_MALE_PC                                                   float64
#  284  pct_L2_MA_03_SWD_PC                                                    float64
#  285  pct_L2_MA_03_WH7_PC                                                    float64
#  286  pct_L2_MA_04_ALL_PC                                                    float64
#  287  pct_L2_MA_04_BL7_PC                                                    float64
#  288  pct_L2_MA_04_EDS_PC                                                    float64
#  289  pct_L2_MA_04_FEM_PC                                                    float64
#  290  pct_L2_MA_04_HI7_PC                                                    float64
#  291  pct_L2_MA_04_MALE_PC                                                   float64
#  292  pct_L2_MA_04_SWD_PC                                                    float64
#  293  pct_L2_MA_04_WH7_PC                                                    float64
#  294  pct_L2_MA_05_ALL_PC                                                    float64
#  295  pct_L2_MA_05_BL7_PC                                                    float64
#  296  pct_L2_MA_05_EDS_PC                                                    float64
#  297  pct_L2_MA_05_FEM_PC                                                    float64
#  298  pct_L2_MA_05_HI7_PC                                                    float64
#  299  pct_L2_MA_05_MALE_PC                                                   float64
#  300  pct_L2_MA_05_SWD_PC                                                    float64
#  301  pct_L2_MA_05_WH7_PC                                                    float64
#  302  pct_L2_MA_ALL_ALL_PC                                                   float64
#  303  pct_L2_MA_ALL_BL7_PC                                                   float64
#  304  pct_L2_MA_ALL_EDS_PC                                                   float64
#  305  pct_L2_MA_ALL_ELS_PC                                                   float64
#  306  pct_L2_MA_ALL_FEM_PC                                                   float64
#  307  pct_L2_MA_ALL_HI7_PC                                                   float64
#  308  pct_L2_MA_ALL_MALE_PC                                                  float64
#  309  pct_L2_MA_ALL_MU7_PC                                                   float64
#  310  pct_L2_MA_ALL_SWD_PC                                                   float64
#  311  pct_L2_MA_ALL_WH7_PC                                                   float64
#  312  pct_L2_RD_03_ALL_PC                                                    float64
#  313  pct_L2_RD_03_BL7_PC                                                    float64
#  314  pct_L2_RD_03_EDS_PC                                                    float64
#  315  pct_L2_RD_03_FEM_PC                                                    float64
#  316  pct_L2_RD_03_HI7_PC                                                    float64
#  317  pct_L2_RD_03_MALE_PC                                                   float64
#  318  pct_L2_RD_03_SWD_PC                                                    float64
#  319  pct_L2_RD_03_WH7_PC                                                    float64
#  320  pct_L2_RD_04_ALL_PC                                                    float64
#  321  pct_L2_RD_04_BL7_PC                                                    float64
#  322  pct_L2_RD_04_EDS_PC                                                    float64
#  323  pct_L2_RD_04_FEM_PC                                                    float64
#  324  pct_L2_RD_04_HI7_PC                                                    float64
#  325  pct_L2_RD_04_MALE_PC                                                   float64
#  326  pct_L2_RD_04_SWD_PC                                                    float64
#  327  pct_L2_RD_04_WH7_PC                                                    float64
#  328  pct_L2_RD_05_ALL_PC                                                    float64
#  329  pct_L2_RD_05_BL7_PC                                                    float64
#  330  pct_L2_RD_05_EDS_PC                                                    float64
#  331  pct_L2_RD_05_FEM_PC                                                    float64
#  332  pct_L2_RD_05_HI7_PC                                                    float64
#  333  pct_L2_RD_05_MALE_PC                                                   float64
#  334  pct_L2_RD_05_SWD_PC                                                    float64
#  335  pct_L2_RD_05_WH7_PC                                                    float64
#  336  pct_L2_RD_ALL_ALL_PC                                                   float64
#  337  pct_L2_RD_ALL_BL7_PC                                                   float64
#  338  pct_L2_RD_ALL_EDS_PC                                                   float64
#  339  pct_L2_RD_ALL_ELS_PC                                                   float64
#  340  pct_L2_RD_ALL_FEM_PC                                                   float64
#  341  pct_L2_RD_ALL_HI7_PC                                                   float64
#  342  pct_L2_RD_ALL_MALE_PC                                                  float64
#  343  pct_L2_RD_ALL_MU7_PC                                                   float64
#  344  pct_L2_RD_ALL_SWD_PC                                                   float64
#  345  pct_L2_RD_ALL_WH7_PC                                                   float64
#  346  pct_L2_SC_05_ALL_PC                                                    float64
#  347  pct_L2_SC_05_MALE_PC                                                   float64
#  348  pct_L2_SC_05_SWD_PC                                                    float64
#  349  pct_L2_SC_ALL_ALL_PC                                                   float64
#  350  pct_L2_SC_ALL_BL7_PC                                                   float64
#  351  pct_L2_SC_ALL_EDS_PC                                                   float64
#  352  pct_L2_SC_ALL_FEM_PC                                                   float64
#  353  pct_L2_SC_ALL_HI7_PC                                                   float64
#  354  pct_L2_SC_ALL_MALE_PC                                                  float64
#  355  pct_L2_SC_ALL_SWD_PC                                                   float64
#  356  pct_L2_SC_ALL_WH7_PC                                                   float64
#  357  pct_L3_EOG_03_ALL_PC                                                   float64
#  358  pct_L3_EOG_03_BL7_PC                                                   float64
#  359  pct_L3_EOG_03_EDS_PC                                                   float64
#  360  pct_L3_EOG_03_ELS_PC                                                   float64
#  361  pct_L3_EOG_03_FEM_PC                                                   float64
#  362  pct_L3_EOG_03_HI7_PC                                                   float64
#  363  pct_L3_EOG_03_MALE_PC                                                  float64
#  364  pct_L3_EOG_03_SWD_PC                                                   float64
#  365  pct_L3_EOG_03_WH7_PC                                                   float64
#  366  pct_L3_EOG_04_ALL_PC                                                   float64
#  367  pct_L3_EOG_04_BL7_PC                                                   float64
#  368  pct_L3_EOG_04_EDS_PC                                                   float64
#  369  pct_L3_EOG_04_ELS_PC                                                   float64
#  370  pct_L3_EOG_04_FEM_PC                                                   float64
#  371  pct_L3_EOG_04_HI7_PC                                                   float64
#  372  pct_L3_EOG_04_MALE_PC                                                  float64
#  373  pct_L3_EOG_04_SWD_PC                                                   float64
#  374  pct_L3_EOG_04_WH7_PC                                                   float64
#  375  pct_L3_EOG_05_ALL_PC                                                   float64
#  376  pct_L3_EOG_05_BL7_PC                                                   float64
#  377  pct_L3_EOG_05_EDS_PC                                                   float64
#  378  pct_L3_EOG_05_ELS_PC                                                   float64
#  379  pct_L3_EOG_05_FEM_PC                                                   float64
#  380  pct_L3_EOG_05_HI7_PC                                                   float64
#  381  pct_L3_EOG_05_MALE_PC                                                  float64
#  382  pct_L3_EOG_05_SWD_PC                                                   float64
#  383  pct_L3_EOG_05_WH7_PC                                                   float64
#  384  pct_L3_EOG_ALL_ALL_PC                                                  float64
#  385  pct_L3_EOG_ALL_BL7_PC                                                  float64
#  386  pct_L3_EOG_ALL_EDS_PC                                                  float64
#  387  pct_L3_EOG_ALL_ELS_PC                                                  float64
#  388  pct_L3_EOG_ALL_FEM_PC                                                  float64
#  389  pct_L3_EOG_ALL_HI7_PC                                                  float64
#  390  pct_L3_EOG_ALL_MALE_PC                                                 float64
#  391  pct_L3_EOG_ALL_MU7_PC                                                  float64
#  392  pct_L3_EOG_ALL_SWD_PC                                                  float64
#  393  pct_L3_EOG_ALL_WH7_PC                                                  float64
#  394  pct_L3_MA_03_ALL_PC                                                    float64
#  395  pct_L3_MA_03_BL7_PC                                                    float64
#  396  pct_L3_MA_03_EDS_PC                                                    float64
#  397  pct_L3_MA_03_FEM_PC                                                    float64
#  398  pct_L3_MA_03_HI7_PC                                                    float64
#  399  pct_L3_MA_03_MALE_PC                                                   float64
#  400  pct_L3_MA_03_WH7_PC                                                    float64
#  401  pct_L3_MA_04_ALL_PC                                                    float64
#  402  pct_L3_MA_04_BL7_PC                                                    float64
#  403  pct_L3_MA_04_EDS_PC                                                    float64
#  404  pct_L3_MA_04_FEM_PC                                                    float64
#  405  pct_L3_MA_04_MALE_PC                                                   float64
#  406  pct_L3_MA_04_WH7_PC                                                    float64
#  407  pct_L3_MA_05_ALL_PC                                                    float64
#  408  pct_L3_MA_05_EDS_PC                                                    float64
#  409  pct_L3_MA_05_FEM_PC                                                    float64
#  410  pct_L3_MA_05_MALE_PC                                                   float64
#  411  pct_L3_MA_05_WH7_PC                                                    float64
#  412  pct_L3_MA_ALL_ALL_PC                                                   float64
#  413  pct_L3_MA_ALL_BL7_PC                                                   float64
#  414  pct_L3_MA_ALL_EDS_PC                                                   float64
#  415  pct_L3_MA_ALL_ELS_PC                                                   float64
#  416  pct_L3_MA_ALL_FEM_PC                                                   float64
#  417  pct_L3_MA_ALL_HI7_PC                                                   float64
#  418  pct_L3_MA_ALL_MALE_PC                                                  float64
#  419  pct_L3_MA_ALL_SWD_PC                                                   float64
#  420  pct_L3_MA_ALL_WH7_PC                                                   float64
#  421  pct_L3_RD_03_ALL_PC                                                    float64
#  422  pct_L3_RD_03_BL7_PC                                                    float64
#  423  pct_L3_RD_03_EDS_PC                                                    float64
#  424  pct_L3_RD_03_FEM_PC                                                    float64
#  425  pct_L3_RD_03_HI7_PC                                                    float64
#  426  pct_L3_RD_03_MALE_PC                                                   float64
#  427  pct_L3_RD_03_WH7_PC                                                    float64
#  428  pct_L3_RD_04_ALL_PC                                                    float64
#  429  pct_L3_RD_04_BL7_PC                                                    float64
#  430  pct_L3_RD_04_EDS_PC                                                    float64
#  431  pct_L3_RD_04_FEM_PC                                                    float64
#  432  pct_L3_RD_04_HI7_PC                                                    float64
#  433  pct_L3_RD_04_MALE_PC                                                   float64
#  434  pct_L3_RD_04_WH7_PC                                                    float64
#  435  pct_L3_RD_05_ALL_PC                                                    float64
#  436  pct_L3_RD_05_BL7_PC                                                    float64
#  437  pct_L3_RD_05_EDS_PC                                                    float64
#  438  pct_L3_RD_05_FEM_PC                                                    float64
#  439  pct_L3_RD_05_HI7_PC                                                    float64
#  440  pct_L3_RD_05_MALE_PC                                                   float64
#  441  pct_L3_RD_05_WH7_PC                                                    float64
#  442  pct_L3_RD_ALL_ALL_PC                                                   float64
#  443  pct_L3_RD_ALL_BL7_PC                                                   float64
#  444  pct_L3_RD_ALL_EDS_PC                                                   float64
#  445  pct_L3_RD_ALL_ELS_PC                                                   float64
#  446  pct_L3_RD_ALL_FEM_PC                                                   float64
#  447  pct_L3_RD_ALL_HI7_PC                                                   float64
#  448  pct_L3_RD_ALL_MALE_PC                                                  float64
#  449  pct_L3_RD_ALL_MU7_PC                                                   float64
#  450  pct_L3_RD_ALL_SWD_PC                                                   float64
#  451  pct_L3_RD_ALL_WH7_PC                                                   float64
#  452  pct_L3_SC_05_ALL_PC                                                    float64
#  453  pct_L3_SC_05_FEM_PC                                                    float64
#  454  pct_L3_SC_ALL_ALL_PC                                                   float64
#  455  pct_L3_SC_ALL_BL7_PC                                                   float64
#  456  pct_L3_SC_ALL_EDS_PC                                                   float64
#  457  pct_L3_SC_ALL_FEM_PC                                                   float64
#  458  pct_L3_SC_ALL_HI7_PC                                                   float64
#  459  pct_L3_SC_ALL_MALE_PC                                                  float64
#  460  pct_L3_SC_ALL_WH7_PC                                                   float64
#  461  pct_L4_EOG_03_ALL_PC                                                   float64
#  462  pct_L4_EOG_03_BL7_PC                                                   float64
#  463  pct_L4_EOG_03_EDS_PC                                                   float64
#  464  pct_L4_EOG_03_ELS_PC                                                   float64
#  465  pct_L4_EOG_03_FEM_PC                                                   float64
#  466  pct_L4_EOG_03_HI7_PC                                                   float64
#  467  pct_L4_EOG_03_MALE_PC                                                  float64
#  468  pct_L4_EOG_03_SWD_PC                                                   float64
#  469  pct_L4_EOG_03_WH7_PC                                                   float64
#  470  pct_L4_EOG_04_AIG_PC                                                   float64
#  471  pct_L4_EOG_04_ALL_PC                                                   float64
#  472  pct_L4_EOG_04_BL7_PC                                                   float64
#  473  pct_L4_EOG_04_EDS_PC                                                   float64
#  474  pct_L4_EOG_04_ELS_PC                                                   float64
#  475  pct_L4_EOG_04_FEM_PC                                                   float64
#  476  pct_L4_EOG_04_HI7_PC                                                   float64
#  477  pct_L4_EOG_04_MALE_PC                                                  float64
#  478  pct_L4_EOG_04_SWD_PC                                                   float64
#  479  pct_L4_EOG_04_WH7_PC                                                   float64
#  480  pct_L4_EOG_05_AIG_PC                                                   float64
#  481  pct_L4_EOG_05_ALL_PC                                                   float64
#  482  pct_L4_EOG_05_BL7_PC                                                   float64
#  483  pct_L4_EOG_05_EDS_PC                                                   float64
#  484  pct_L4_EOG_05_ELS_PC                                                   float64
#  485  pct_L4_EOG_05_FEM_PC                                                   float64
#  486  pct_L4_EOG_05_HI7_PC                                                   float64
#  487  pct_L4_EOG_05_MALE_PC                                                  float64
#  488  pct_L4_EOG_05_MU7_PC                                                   float64
#  489  pct_L4_EOG_05_SWD_PC                                                   float64
#  490  pct_L4_EOG_05_WH7_PC                                                   float64
#  491  pct_L4_EOG_ALL_AIG_PC                                                  float64
#  492  pct_L4_EOG_ALL_BL7_PC                                                  float64
#  493  pct_L4_EOG_ALL_EDS_PC                                                  float64
#  494  pct_L4_EOG_ALL_ELS_PC                                                  float64
#  495  pct_L4_EOG_ALL_FEM_PC                                                  float64
#  496  pct_L4_EOG_ALL_HI7_PC                                                  float64
#  497  pct_L4_EOG_ALL_MALE_PC                                                 float64
#  498  pct_L4_EOG_ALL_MU7_PC                                                  float64
#  499  pct_L4_EOG_ALL_SWD_PC                                                  float64
#  500  pct_L4_EOG_ALL_WH7_PC                                                  float64
#  501  pct_L4_MA_03_ALL_PC                                                    float64
#  502  pct_L4_MA_03_BL7_PC                                                    float64
#  503  pct_L4_MA_03_EDS_PC                                                    float64
#  504  pct_L4_MA_03_FEM_PC                                                    float64
#  505  pct_L4_MA_03_HI7_PC                                                    float64
#  506  pct_L4_MA_03_MALE_PC                                                   float64
#  507  pct_L4_MA_03_SWD_PC                                                    float64
#  508  pct_L4_MA_03_WH7_PC                                                    float64
#  509  pct_L4_MA_04_ALL_PC                                                    float64
#  510  pct_L4_MA_04_BL7_PC                                                    float64
#  511  pct_L4_MA_04_EDS_PC                                                    float64
#  512  pct_L4_MA_04_FEM_PC                                                    float64
#  513  pct_L4_MA_04_HI7_PC                                                    float64
#  514  pct_L4_MA_04_MALE_PC                                                   float64
#  515  pct_L4_MA_04_SWD_PC                                                    float64
#  516  pct_L4_MA_04_WH7_PC                                                    float64
#  517  pct_L4_MA_05_AIG_PC                                                    float64
#  518  pct_L4_MA_05_ALL_PC                                                    float64
#  519  pct_L4_MA_05_BL7_PC                                                    float64
#  520  pct_L4_MA_05_EDS_PC                                                    float64
#  521  pct_L4_MA_05_FEM_PC                                                    float64
#  522  pct_L4_MA_05_HI7_PC                                                    float64
#  523  pct_L4_MA_05_MALE_PC                                                   float64
#  524  pct_L4_MA_05_WH7_PC                                                    float64
#  525  pct_L4_MA_ALL_AIG_PC                                                   float64
#  526  pct_L4_MA_ALL_BL7_PC                                                   float64
#  527  pct_L4_MA_ALL_EDS_PC                                                   float64
#  528  pct_L4_MA_ALL_ELS_PC                                                   float64
#  529  pct_L4_MA_ALL_FEM_PC                                                   float64
#  530  pct_L4_MA_ALL_HI7_PC                                                   float64
#  531  pct_L4_MA_ALL_MALE_PC                                                  float64
#  532  pct_L4_MA_ALL_MU7_PC                                                   float64
#  533  pct_L4_MA_ALL_SWD_PC                                                   float64
#  534  pct_L4_MA_ALL_WH7_PC                                                   float64
#  535  pct_L4_RD_03_ALL_PC                                                    float64
#  536  pct_L4_RD_03_BL7_PC                                                    float64
#  537  pct_L4_RD_03_EDS_PC                                                    float64
#  538  pct_L4_RD_03_FEM_PC                                                    float64
#  539  pct_L4_RD_03_HI7_PC                                                    float64
#  540  pct_L4_RD_03_MALE_PC                                                   float64
#  541  pct_L4_RD_03_WH7_PC                                                    float64
#  542  pct_L4_RD_04_ALL_PC                                                    float64
#  543  pct_L4_RD_04_BL7_PC                                                    float64
#  544  pct_L4_RD_04_EDS_PC                                                    float64
#  545  pct_L4_RD_04_FEM_PC                                                    float64
#  546  pct_L4_RD_04_HI7_PC                                                    float64
#  547  pct_L4_RD_04_MALE_PC                                                   float64
#  548  pct_L4_RD_04_SWD_PC                                                    float64
#  549  pct_L4_RD_04_WH7_PC                                                    float64
#  550  pct_L4_RD_05_AIG_PC                                                    float64
#  551  pct_L4_RD_05_ALL_PC                                                    float64
#  552  pct_L4_RD_05_BL7_PC                                                    float64
#  553  pct_L4_RD_05_EDS_PC                                                    float64
#  554  pct_L4_RD_05_FEM_PC                                                    float64
#  555  pct_L4_RD_05_HI7_PC                                                    float64
#  556  pct_L4_RD_05_MALE_PC                                                   float64
#  557  pct_L4_RD_05_WH7_PC                                                    float64
#  558  pct_L4_RD_ALL_AIG_PC                                                   float64
#  559  pct_L4_RD_ALL_BL7_PC                                                   float64
# ...
#  935  subgroup_list_ALL,EDS,HI7,SWD,WH7                                      uint8
#  936  subgroup_list_ALL,EDS,HI7,WH7                                          uint8
#  937  subgroup_list_ALL,EDS,SWD                                              uint8
#  938  subgroup_list_ALL,EDS,SWD,WH7                                          uint8
#  939  subgroup_list_ALL,EDS,WH7                                              uint8
#  940  subgroup_list_ALL,HI7,SWD,WH7                                          uint8
#  941  subgroup_list_ALL,SWD                                                  uint8
#  942  subgroup_list_ALL,SWD,WH7                                              uint8
#  943  subgroup_list_ALL,WH7                                                  uint8
#  944  ma_grade_B                                                             uint8
#  945  ma_grade_C                                                             uint8
#  946  ma_grade_D                                                             uint8
#  947  ma_grade_F                                                             uint8
#  948  rd_grade_B                                                             uint8
#  949  rd_grade_C                                                             uint8
#  950  rd_grade_D                                                             uint8
#  951  rd_grade_F                                                             uint8
#  952  eg_status_Met                                                          uint8
#  953  eg_status_NotMet                                                       uint8
#  954  spg_grade_A+NG                                                         uint8
#  955  spg_grade_B                                                            uint8
#  956  spg_grade_C                                                            uint8
#  957  spg_grade_D                                                            uint8
#  958  spg_grade_F                                                            uint8
#  959  ma_eg_status_Met                                                       uint8
#  960  ma_eg_status_NotMet                                                    uint8
#  961  rd_eg_status_Met                                                       uint8
#  962  rd_eg_status_NotMet                                                    uint8
#  963  dance_cat_Y                                                            uint8
#  964  music_cat_Y                                                            uint8
#  965  theatre_cat_Y                                                          uint8
#  966  va_cat_Y                                                               uint8
#  967  digital_media_0                                                        uint8
#  968  digital_media_1                                                        uint8
#  969  digital_media_10                                                       uint8
#  970  digital_media_11                                                       uint8
#  971  digital_media_12                                                       uint8
#  972  digital_media_13                                                       uint8
#  973  digital_media_14                                                       uint8
#  974  digital_media_15                                                       uint8
#  975  digital_media_16                                                       uint8
#  976  digital_media_17                                                       uint8
#  977  digital_media_2                                                        uint8
#  978  digital_media_20                                                       uint8
#  979  digital_media_22                                                       uint8
#  980  digital_media_23                                                       uint8
#  981  digital_media_25                                                       uint8
#  982  digital_media_27                                                       uint8
#  983  digital_media_28                                                       uint8
#  984  digital_media_3                                                        uint8
#  985  digital_media_30                                                       uint8
#  986  digital_media_31                                                       uint8
#  987  digital_media_32                                                       uint8
#  988  digital_media_33                                                       uint8
#  989  digital_media_35                                                       uint8
#  990  digital_media_38                                                       uint8
#  991  digital_media_4                                                        uint8
#  992  digital_media_5                                                        uint8
#  993  digital_media_54                                                       uint8
#  994  digital_media_58                                                       uint8
#  995  digital_media_6                                                        uint8
#  996  digital_media_7                                                        uint8
#  997  digital_media_8                                                        uint8
#  998  digital_media_9                                                        uint8
#  999  digital_media_97                                                       uint8
#  1000 digital_media_99                                                       uint8
#  1001 device_access_Yes                                                      uint8
#  1002 device_home_Yes                                                        uint8
#  1003 BYOD_Neither                                                           uint8
#  1004 BYOD_Staff                                                             uint8
#  1005 BYOD_Students                                                          uint8
#  1006 esea_att_Met                                                           uint8
#  1007 agency_lea_code_020LEA                                                 uint8
#  1008 agency_lea_code_030LEA                                                 uint8
#  1009 agency_lea_code_040LEA                                                 uint8
#  1010 agency_lea_code_050LEA                                                 uint8
#  1011 agency_lea_code_060LEA                                                 uint8
#  1012 agency_lea_code_070LEA                                                 uint8
#  1013 agency_lea_code_080LEA                                                 uint8
#  1014 agency_lea_code_090LEA                                                 uint8
#  1015 agency_lea_code_100LEA                                                 uint8
#  1016 agency_lea_code_110LEA                                                 uint8
#  1017 agency_lea_code_111LEA                                                 uint8
#  1018 agency_lea_code_120LEA                                                 uint8
#  1019 agency_lea_code_130LEA                                                 uint8
#  1020 agency_lea_code_132LEA                                                 uint8
#  1021 agency_lea_code_140LEA                                                 uint8
#  1022 agency_lea_code_150LEA                                                 uint8
#  1023 agency_lea_code_160LEA                                                 uint8
#  1024 agency_lea_code_170LEA                                                 uint8
#  1025 agency_lea_code_180LEA                                                 uint8
#  1026 agency_lea_code_181LEA                                                 uint8
#  1027 agency_lea_code_182LEA                                                 uint8
#  1028 agency_lea_code_190LEA                                                 uint8
#  1029 agency_lea_code_200LEA                                                 uint8
#  1030 agency_lea_code_210LEA                                                 uint8
#  1031 agency_lea_code_220LEA                                                 uint8
#  1032 agency_lea_code_230LEA                                                 uint8
#  1033 agency_lea_code_240LEA                                                 uint8
#  1034 agency_lea_code_241LEA                                                 uint8
#  1035 agency_lea_code_250LEA                                                 uint8
#  1036 agency_lea_code_260LEA                                                 uint8
#  1037 agency_lea_code_270LEA                                                 uint8
#  1038 agency_lea_code_280LEA                                                 uint8
#  1039 agency_lea_code_290LEA                                                 uint8
#  1040 agency_lea_code_291LEA                                                 uint8
#  1041 agency_lea_code_292LEA                                                 uint8
#  1042 agency_lea_code_300LEA                                                 uint8
#  1043 agency_lea_code_310LEA                                                 uint8
#  1044 agency_lea_code_320LEA                                                 uint8
#  1045 agency_lea_code_330LEA                                                 uint8
#  1046 agency_lea_code_340LEA                                                 uint8
#  1047 agency_lea_code_350LEA                                                 uint8
#  1048 agency_lea_code_360LEA                                                 uint8
#  1049 agency_lea_code_370LEA                                                 uint8
#  1050 agency_lea_code_380LEA                                                 uint8
#  1051 agency_lea_code_390LEA                                                 uint8
#  1052 agency_lea_code_400LEA                                                 uint8
#  1053 agency_lea_code_410LEA                                                 uint8
#  1054 agency_lea_code_420LEA                                                 uint8
#  1055 agency_lea_code_421LEA                                                 uint8
#  1056 agency_lea_code_422LEA                                                 uint8
#  1057 agency_lea_code_430LEA                                                 uint8
#  1058 agency_lea_code_440LEA                                                 uint8
#  1059 agency_lea_code_450LEA                                                 uint8
#  1060 agency_lea_code_460LEA                                                 uint8
#  1061 agency_lea_code_470LEA                                                 uint8
#  1062 agency_lea_code_480LEA                                                 uint8
#  1063 agency_lea_code_490LEA                                                 uint8
#  1064 agency_lea_code_491LEA                                                 uint8
#  1065 agency_lea_code_500LEA                                                 uint8
#  1066 agency_lea_code_510LEA                                                 uint8
#  1067 agency_lea_code_520LEA                                                 uint8
#  1068 agency_lea_code_530LEA                                                 uint8
#  1069 agency_lea_code_540LEA                                                 uint8
#  1070 agency_lea_code_550LEA                                                 uint8
#  1071 agency_lea_code_560LEA                                                 uint8
#  1072 agency_lea_code_570LEA                                                 uint8
#  1073 agency_lea_code_580LEA                                                 uint8
#  1074 agency_lea_code_590LEA                                                 uint8
#  1075 agency_lea_code_600LEA                                                 uint8
#  1076 agency_lea_code_610LEA                                                 uint8
#  1077 agency_lea_code_620LEA                                                 uint8
#  1078 agency_lea_code_630LEA                                                 uint8
#  1079 agency_lea_code_640LEA                                                 uint8
#  1080 agency_lea_code_650LEA                                                 uint8
#  1081 agency_lea_code_660LEA                                                 uint8
#  1082 agency_lea_code_670LEA                                                 uint8
#  1083 agency_lea_code_680LEA                                                 uint8
#  1084 agency_lea_code_681LEA                                                 uint8
#  1085 agency_lea_code_690LEA                                                 uint8
#  1086 agency_lea_code_700LEA                                                 uint8
#  1087 agency_lea_code_710LEA                                                 uint8
#  1088 agency_lea_code_720LEA                                                 uint8
#  1089 agency_lea_code_730LEA                                                 uint8
#  1090 agency_lea_code_740LEA                                                 uint8
#  1091 agency_lea_code_750LEA                                                 uint8
#  1092 agency_lea_code_760LEA                                                 uint8
#  1093 agency_lea_code_761LEA                                                 uint8
#  1094 agency_lea_code_770LEA                                                 uint8
#  1095 agency_lea_code_780LEA                                                 uint8
#  1096 agency_lea_code_790LEA                                                 uint8
#  1097 agency_lea_code_800LEA                                                 uint8
#  1098 agency_lea_code_810LEA                                                 uint8
#  1099 agency_lea_code_820LEA                                                 uint8
#  1100 agency_lea_code_821LEA                                                 uint8
#  1101 agency_lea_code_830LEA                                                 uint8
#  1102 agency_lea_code_840LEA                                                 uint8
#  1103 agency_lea_code_850LEA                                                 uint8
#  1104 agency_lea_code_860LEA                                                 uint8
#  1105 agency_lea_code_861LEA                                                 uint8
#  1106 agency_lea_code_862LEA                                                 uint8
#  1107 agency_lea_code_870LEA                                                 uint8
#  1108 agency_lea_code_880LEA                                                 uint8
#  1109 agency_lea_code_890LEA                                                 uint8
#  1110 agency_lea_code_900LEA                                                 uint8
#  1111 agency_lea_code_910LEA                                                 uint8
#  1112 agency_lea_code_920LEA                                                 uint8
#  1113 agency_lea_code_930LEA                                                 uint8
#  1114 agency_lea_code_940LEA                                                 uint8
#  1115 agency_lea_code_950LEA                                                 uint8
#  1116 agency_lea_code_960LEA                                                 uint8
#  1117 agency_lea_code_970LEA                                                 uint8
#  1118 agency_lea_code_980LEA                                                 uint8
#  1119 agency_lea_code_990LEA                                                 uint8
#  1120 agency_lea_code_995LEA                                                 uint8
#  1121 agency_code                                                            object
# dtypes: float64(821), object(1), uint8(300)
# memory usage: 9.3+ MB

# %%
import sklearn
import pandas as pd

print('Sklearn Version: ' + sklearn.__version__)
print('Pandas Version: ' + pd.__version__)
# Out:
# Sklearn Version: 0.22.1
# Pandas Version: 1.0.3

# %%
print('Output File Location:\r\n\r\n' + outputDir + inputFileName + '_ML.csv')
# Out:
# Output File Location:
#
# C:/Users/Jake/Documents/GitHub/EducationDataNC/2018/Machine Learning Datasets/PublicElementarySchools2018_ML.csv
