# %% [markdown]
# # Create Public School Machine Learning Datasets
# ** This program creates all the _ML datasets in the NCEA repository.**
# * This notebook reads each School Dataset file located at \EducationDataNC\ *schoolYear* \School Datasets\ as input data.
# * Different school years are processed by changing the *schoolYear* parameter.
# * Different input / output files are processed / created by changing the *inputFileName* paramter in the cell below.
# * While a single program is used to create all the _ML datasets, one program copy per dataset is maintained in the repositiory so the dataset specific tranformation reports may be reviewed.
#
# **Datasets ending in ML are preprocessed for Machine Learning and go through the following transformations: **
# 1. Missing student body racial compositions are imputed using district averages.
# 2. Columns that have the same value in every single row are deleted.
# 3. Columns that have a unique value in every single row (all values are different) are deleted.
# 4. Empty columns (all values are NA or NULL) are deleted.
# 5. Numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# 6. Remaining numeric, non-race columns with missing values are imputed / populated with 0.  In many cases, schools are not reporting values when they are zero. However, mean imputation or some other more sophisticated strategy might be considered here.
# 7. Categorical / text based columns with > *uniqueThreshold* unique values are deleted.
# 8. All remaining categorical / text based columns are one-hot encoded.  In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# 9. Duplicated or highly similar columns with > 95% correlation are delelted.

# %%
#import required Libraries
import pandas as pd
import numpy as np
import os
import string

#**********************************************************************************
# Set the following variables before running this code!!!
#**********************************************************************************
#All raw data files are processed for the year below
schoolYear = 2018

#Location where copies of the raw data files will be read in from csv files.
dataDir = 'C:/Users/Jake/Documents/GitHub/EducationDataNC/' + str(schoolYear) + '/School Datasets/'

#Name of the file to be processed
#inputFileName = 'PublicSchools2018'
#inputFileName = 'PublicHighSchools2018'
inputFileName = 'PublicMiddleSchools2018'
#inputFileName = 'PublicElementarySchools2018'

#Input file being transformed for machine learning 
inputFile = dataDir + inputFileName + '.csv'

#Location where the new school datasets will be created.
outputDir = 'C:/Users/Jake/Documents/GitHub/EducationDataNC/' + str(schoolYear) + '/Machine Learning Datasets/'

#Missing Data Threshold (Per Column)
missingThreshold = 0.60

#Unique Value Threshold (Per Column)
#Delete Columns >  uniqueThreshold unique values prior to one-hot encoding. 
#(each unique value becomes a new column during one-hot encoding)
uniqueThreshold = 200

#Read in the School Data File
schoolData = pd.read_csv(inputFile, low_memory=False, dtype={'agency_code': object})
print('*********Start: Beginning Column and Row Counts********************************************')
schoolData.info(verbose=False)

#Select only public schools as charter schools are missing data for many columns.
schoolData = schoolData[(schoolData['designation_type'] == 'P') & (schoolData['avg_student_num'] > 0)]

print('\r\n*********After: Selecting Only Public School Campuses**********************************')
schoolData.info(verbose=False)

#Save primary key
agency_code = schoolData['agency_code']
#Convert zip code to string
schoolData['zip'] = schoolData['zip'].astype('object')
# Out:
# *********Start: Beginning Column and Row Counts********************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 806 entries, 0 to 805
# Columns: 5243 entries, agency_code to lea_federal_perpupil
# dtypes: float64(5192), object(51)
# memory usage: 32.2+ MB
#
# *********After: Selecting Only Public School Campuses**********************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 660 entries, 2 to 805
# Columns: 5243 entries, agency_code to lea_federal_perpupil
# dtypes: float64(5192), object(51)
# memory usage: 26.4+ MB

# %% [markdown]
# # Prepare Consolidated Dataset for Machine Learning
# **Below we perform operations on the entire dataset to remove columns and update row values that could cause problems during machine learning.**

# %% [markdown]
# ## Student Body Racial Composition Features
# **Impute / update missing Student Body Racial Composition Fields using mean imputation.**
# * When there are no racial composition percentages for a particular school campus / agency_code, fill in the missing values

# %%
#Get Student Body Racial Composition Fields
raceCompositionFields = schoolData.filter(regex='Indian|Asian|Hispanic|Black|White|PacificIsland|TwoOrMore|Minority')\
                                  .filter(regex='Pct').columns
    
rowsBefore = schoolData[raceCompositionFields].isnull().T.any().T.sum()

#Update missing race values with the district average when avaiable (No district averages for charter schools) 
schoolData[raceCompositionFields] = schoolData.groupby('lea_code')[raceCompositionFields]\
                                              .transform(lambda x: x.fillna(x.mean()))

    #Review dataset contents after Racial Composition Imputation
print('*********After: Updating Missing Racial Compostion Values****************************')   
rowsAfter = schoolData[raceCompositionFields].isnull().T.any().T.sum()
rowsUpdated = rowsBefore - rowsAfter
print('Rows Updated / Imputed: ', rowsUpdated) 
print('\r\nTotal Rows Missing Racial Compositions By District Code') 
schoolData['lea_code'][schoolData[raceCompositionFields].isnull().T.any().T].value_counts()
# Out:
# *********After: Updating Missing Racial Compostion Values****************************
# Rows Updated / Imputed:  3
#
# Total Rows Missing Racial Compositions By District Code
# Series([], Name: lea_code, dtype: int64)

# %% [markdown]
# ## Remove Columns with Problematic Data
# **Here we remove entire columns that could cause problems during machine learning.  The following operations are performed:**
# * Remove any columns that have the same value in every single row.
# * Remove any columns that have a unique value in every single row (all values are different).
# * Remove empty columns (all values are NA or NULL).

# %%
#Remove any fields that have the same value in all rows
UniqueValueCounts = schoolData.nunique(dropna=False)
SingleValueCols = UniqueValueCounts[UniqueValueCounts == 1].index
schoolData = schoolData.drop(SingleValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with the same value in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(SingleValueCols))
# Out:
# *********After: Removing columns with the same value in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 660 entries, 2 to 805
# Columns: 3805 entries, agency_code to lea_federal_perpupil
# dtypes: float64(3758), object(47)
# memory usage: 19.2+ MB
#
# Columns Deleted:  1438

# %%
#Remove any fields that have unique values in every row
schoolDataRecordCt = schoolData.shape[0]
UniqueValueCounts = schoolData.apply(pd.Series.nunique)
AllUniqueValueCols = UniqueValueCounts[UniqueValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(AllUniqueValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with unique values in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(AllUniqueValueCols))
# Out:
# *********After: Removing columns with unique values in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 660 entries, 2 to 805
# Columns: 3803 entries, category_code to lea_federal_perpupil
# dtypes: float64(3758), object(45)
# memory usage: 19.2+ MB
#
# Columns Deleted:  2

# %%
#Remove any empty fields (null values in every row)
schoolDataRecordCt = schoolData.shape[0]
NullValueCounts = schoolData.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with null / blank values in every row.*************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with null / blank values in every row.*************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 660 entries, 2 to 805
# Columns: 3803 entries, category_code to lea_federal_perpupil
# dtypes: float64(3758), object(45)
# memory usage: 19.2+ MB
#
# Columns Deleted:  0

# %% [markdown]
# ## Handle Other Missing Values Types
# * Here we eliminate any numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# * All remaining non-race, numeric column missing values are populated with 0.
# * In many cases, it seems that schools are not simply not reporting values when they are zero. However, mean imputation or some other strategy might be considered.

# %%
#Isolate continuous and categorical data types
#These are indexers into the schoolData dataframe and may be used similar to the schoolData dataframe 
sD_boolean = schoolData.loc[:, (schoolData.dtypes == bool) ]
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]
sD_continuous = schoolData.loc[:, (schoolData.dtypes != bool) & (schoolData.dtypes != object)]
print ("Boolean Columns: ", sD_boolean.shape[1])
print ("Nominal Columns: ", sD_nominal.shape[1])
print ("Continuous Columns: ", sD_continuous.shape[1])
print ("Columns Accounted for: ", sD_nominal.shape[1] + sD_continuous.shape[1] + sD_boolean.shape[1])
# Out:
# Boolean Columns:  0
# Nominal Columns:  45
# Continuous Columns:  3758
# Columns Accounted for:  3803

# %%
#Eliminate continuous columns with more than missingThreshold percentage of missing values
schoolDataRecordCt = sD_continuous.shape[0]
missingValueLimit = schoolDataRecordCt * missingThreshold
NullValueCounts = sD_continuous.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts >= missingValueLimit].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with >= missingThreshold % of missing values******')
schoolData.info(verbose=False)
print('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with >= missingThreshold % of missing values******
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 660 entries, 2 to 805
# Columns: 1260 entries, category_code to lea_federal_perpupil
# dtypes: float64(1215), object(45)
# memory usage: 6.3+ MB
#
# Columns Deleted:  2543

# %% [markdown]
# ## One-Hot Encoding of Categorical Variables
# **All categorical / string variables are converted to numberic variables via one hot encoding.  Each unique row value will become a new binary / numeric column in the dataset.**
# * All remaining categorical columns are one-hot encoded.
# * In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# * Prior to one-hot encoding, columns with > *uniqueThreshold* unique values are deleted.

# %%
#Delete categorical columns with > uniqueThreshold unique values 
#(Each unique value becomes a column during one-hot encoding)
oneHotUniqueValueCounts = schoolData[sD_nominal.columns].apply(lambda x: x.nunique())
oneHotUniqueValueCols = oneHotUniqueValueCounts[oneHotUniqueValueCounts >= uniqueThreshold].index
schoolData.drop(oneHotUniqueValueCols, axis=1, inplace=True) 

#Remove categorical columns which do not add value to machine learning
#Grades columns dropped since they all have indicator fields (device_access, device_home, BYOD)
#with less unique values to one-hot encode
schoolData.drop(['welcome_url','device_access_grades',
                 'device_home_grades','byod_grades'], axis=1, inplace=True) 

#Review dataset contents one hot high unique value drops
print('*********After: Removing columns with >= uniqueThreshold unique values***********')
schoolData.info(verbose=False)
print('\r\nColumns Deleted: ', len(oneHotUniqueValueCols))
print(oneHotUniqueValueCols)
print('Dropped Manually: welcome_url,device_access_grades,device_home_grades,byod_grades')
# Out:
# *********After: Removing columns with >= uniqueThreshold unique values***********
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 660 entries, 2 to 805
# Columns: 1250 entries, category_code to lea_federal_perpupil
# dtypes: float64(1215), object(35)
# memory usage: 6.3+ MB
#
# Columns Deleted:  6
# Index(['street_addr', 'city', 'zip', 'phone', 'url', 'School Name'], dtype='object')
# Dropped Manually: welcome_url,device_access_grades,device_home_grades,byod_grades

# %%
#Isolate remaining categorical variables
begColumnCt = len(schoolData.columns)
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]

#one hot encode categorical variables
schoolData = pd.get_dummies(data=schoolData, 
                       columns=sD_nominal.columns, drop_first=True)

#Determine change in column count
endColumnCt = len(schoolData.columns)
columnsAdded = endColumnCt - begColumnCt

#Review dataset contents one hot high unique value drops
print('Columns To One-Hot Encode: ', len(sD_nominal.columns))
print('\r\n*********After: Adding New Columns Via One-Hot Encoding*************************')
schoolData.info(verbose=False)
print('\r\nNew Columns Created Via One-Hot Encoding: ', columnsAdded)
# Out:
# Columns To One-Hot Encode:  35
#
# *********After: Adding New Columns Via One-Hot Encoding*************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 660 entries, 2 to 805
# Columns: 1702 entries, IndianPct to agency_lea_code_995LEA
# dtypes: float64(1215), uint8(487)
# memory usage: 6.4 MB
#
# New Columns Created Via One-Hot Encoding:  452

# %%
#Remove any fields that have the same value in all rows after one-hot encoding
UniqueValueCounts = schoolData.nunique(dropna=False)
SingleValueCols = UniqueValueCounts[UniqueValueCounts == 1].index
schoolData = schoolData.drop(SingleValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing one-hot encoded columns with the same value in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(SingleValueCols))
# Out:
# *********After: Removing one-hot encoded columns with the same value in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 660 entries, 2 to 805
# Columns: 1702 entries, IndianPct to agency_lea_code_995LEA
# dtypes: float64(1215), uint8(487)
# memory usage: 6.4 MB
#
# Columns Deleted:  0

# %% [markdown]
# ## Impute any Remaining Missing Values as Zero

# %%
#Print out all the missing value rows
pd.set_option('display.max_rows', 1000)

print('\r\n*********The Remaining Missing Values Below will be set to Zero!*************************')

#Check for Missing values 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# *********The Remaining Missing Values Below will be set to Zero!*************************
#             Variable Name  Number Missing Values
# 24                pct_eds                      1
# 25            pct_ALL_ELP                    277
# 26            pct_EDS_ELP                    331
# 27            pct_ELS_ELP                    277
# 28            pct_HI7_ELP                    313
# ...                   ...                    ...
# 1201            nbpts_num                      1
# 1202      avg_size_06_SAR                    134
# 1203      avg_size_07_SAR                    119
# 1204      avg_size_08_SAR                    123
# 1205  avg_size_Math I_SAR                    122
#
# [1173 rows x 2 columns]

# %%
#Replace all remaining NaN with 0
schoolData = schoolData.fillna(0)

#Check for Missing values after final imputation 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# Empty DataFrame
# Columns: [Variable Name, Number Missing Values]
# Index: []

# %% [markdown]
# ## Identify and Remove Highly Correlated Features
# **Find and remove any columns / features that are > 95% correlated**
# * https://stackoverflow.com/questions/39409866/correlation-heatmap
# * https://chrisalbon.com/machine_learning/feature_selection/drop_highly_correlated_features/
# * https://codeyarns.com/2015/04/20/how-to-change-font-size-in-seaborn/

# %%
# calculate the correlation matrix
corr_matrix  = schoolData.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
#Get all of the correlation values > 95%
x = np.where(upper > 0.95)

#Display all field combinations with > 95% correlation
cf = pd.DataFrame()
cf['Field1'] = upper.columns[x[1]]
cf['Field2'] = upper.index[x[0]]

#Get the correlation values for every field combination. (There must be a more pythonic way to do this!)
corr = [0] * len(cf)
for i in range(0, len(cf)):
    corr[i] =  upper[cf['Field1'][i]][cf['Field2'][i]] 
    
cf['Correlation'] = corr

print ('There are ', str(len(cf['Field1'])), ' field correlations > 95%.')
cf
# Out:
# There are  788  field correlations > 95%.
#                                   Field1                               Field2  \
# 0                          IndianMalePct                            IndianPct
# 1                        IndianFemalePct                            IndianPct
# 2                           AsianMalePct                             AsianPct
# 3                         AsianFemalePct                             AsianPct
# 4                        HispanicMalePct                          HispanicPct
# 5                      HispanicFemalePct                          HispanicPct
# 6                            MinorityPct                             WhitePct
# 7                           WhiteMalePct                             WhitePct
# 8                         WhiteFemalePct                             WhitePct
# 9                           WhiteMalePct                          MinorityPct
# 10                        WhiteFemalePct                          MinorityPct
# 11                       IndianFemalePct                        IndianMalePct
# 12                           pct_ELS_ELP                          pct_ALL_ELP
# 13                  pct_CCR_RD_06_ALL_PC                     pct_prof_6gr_irm
# 14       pct_met_Reading Grades 3-8_PART         pct_met_Math Grades 3-8_PART
# 15   pct_Science Grades 5&8_ALL_PART_DET      pct_met_Science Grades 5&8_PART
# 16   pct_Reading Grades 3-8_ALL_PART_DET     pct_Math Grades 3-8_ALL_PART_DET
# 17   pct_Reading Grades 3-8_BL7_PART_DET     pct_Math Grades 3-8_BL7_PART_DET
# 18   pct_Reading Grades 3-8_EDS_PART_DET     pct_Math Grades 3-8_EDS_PART_DET
# 19   pct_Reading Grades 3-8_ELS_PART_DET     pct_Math Grades 3-8_ELS_PART_DET
# 20   pct_Reading Grades 3-8_HI7_PART_DET     pct_Math Grades 3-8_HI7_PART_DET
# 21   pct_Reading Grades 3-8_SWD_PART_DET     pct_Math Grades 3-8_SWD_PART_DET
# 22   pct_Reading Grades 3-8_WH7_PART_DET     pct_Math Grades 3-8_WH7_PART_DET
# 23                   scgs_score_WH7_SPG2  pct_Science Grades 5&8_WH7_PART_DET
# 24                 pct_GLP_EOG_06_AIG_PC                pct_CCR_EOG_06_AIG_PC
# 25                  pct_CCR_MA_06_ALL_PC                pct_CCR_EOG_06_ALL_PC
# 26                 pct_GLP_EOG_06_ALL_PC                pct_CCR_EOG_06_ALL_PC
# 27                 pct_GLP_EOG_06_BL7_PC                pct_CCR_EOG_06_BL7_PC
# 28                 pct_GLP_EOG_06_EDS_PC                pct_CCR_EOG_06_EDS_PC
# 29                  pct_L4_EOG_06_EDS_PC                pct_CCR_EOG_06_EDS_PC
# 30                 pct_GLP_EOG_06_ELS_PC                pct_CCR_EOG_06_ELS_PC
# 31                  pct_CCR_MA_06_ALL_PC                pct_CCR_EOG_06_FEM_PC
# 32                  pct_CCR_RD_06_ALL_PC                pct_CCR_EOG_06_FEM_PC
# 33                 pct_GLP_EOG_06_FEM_PC                pct_CCR_EOG_06_FEM_PC
# 34                 pct_GLP_EOG_06_HI7_PC                pct_CCR_EOG_06_HI7_PC
# 35                pct_GLP_EOG_06_MALE_PC               pct_CCR_EOG_06_MALE_PC
# 36                 pct_GLP_EOG_06_MU7_PC                pct_CCR_EOG_06_MU7_PC
# 37                  pct_L4_EOG_06_SWD_PC                pct_CCR_EOG_06_SWD_PC
# 38                 pct_GLP_EOG_06_WH7_PC                pct_CCR_EOG_06_WH7_PC
# 39                 pct_GLP_EOG_07_AIG_PC                pct_CCR_EOG_07_AIG_PC
# 40                 pct_CCR_EOG_07_FEM_PC                pct_CCR_EOG_07_ALL_PC
# 41                pct_CCR_EOG_07_MALE_PC                pct_CCR_EOG_07_ALL_PC
# 42                  pct_CCR_MA_07_ALL_PC                pct_CCR_EOG_07_ALL_PC
# 43                  pct_CCR_RD_07_ALL_PC                pct_CCR_EOG_07_ALL_PC
# 44                 pct_GLP_EOG_07_ALL_PC                pct_CCR_EOG_07_ALL_PC
# 45                  pct_GLP_MA_07_ALL_PC                pct_CCR_EOG_07_ALL_PC
# 46                 pct_GLP_EOG_07_BL7_PC                pct_CCR_EOG_07_BL7_PC
# 47                 pct_GLP_EOG_07_EDS_PC                pct_CCR_EOG_07_EDS_PC
# 48                 pct_GLP_EOG_07_ELS_PC                pct_CCR_EOG_07_ELS_PC
# 49                  pct_CCR_MA_07_ALL_PC                pct_CCR_EOG_07_FEM_PC
# 50                 pct_GLP_EOG_07_ALL_PC                pct_CCR_EOG_07_FEM_PC
# 51                 pct_GLP_EOG_07_FEM_PC                pct_CCR_EOG_07_FEM_PC
# 52                  pct_GLP_MA_07_ALL_PC                pct_CCR_EOG_07_FEM_PC
# 53                 pct_GLP_EOG_07_HI7_PC                pct_CCR_EOG_07_HI7_PC
# 54                  pct_L4_EOG_07_HI7_PC                pct_CCR_EOG_07_HI7_PC
# 55                pct_GLP_EOG_07_MALE_PC               pct_CCR_EOG_07_MALE_PC
# 56                 pct_GLP_EOG_07_MU7_PC                pct_CCR_EOG_07_MU7_PC
# 57                 pct_GLP_EOG_07_WH7_PC                pct_CCR_EOG_07_WH7_PC
# 58                 pct_GLP_EOG_08_AIG_PC                pct_CCR_EOG_08_AIG_PC
# 59                 pct_CCR_EOG_08_FEM_PC                pct_CCR_EOG_08_ALL_PC
# 60                  pct_CCR_RD_08_ALL_PC                pct_CCR_EOG_08_ALL_PC
# 61                 pct_GLP_EOG_08_ALL_PC                pct_CCR_EOG_08_ALL_PC
# 62                  pct_GLP_MA_08_ALL_PC                pct_CCR_EOG_08_ALL_PC
# 63                  pct_GLP_RD_08_ALL_PC                pct_CCR_EOG_08_ALL_PC
# 64                 pct_GLP_EOG_08_BL7_PC                pct_CCR_EOG_08_BL7_PC
# 65                  pct_L4_EOG_08_BL7_PC                pct_CCR_EOG_08_BL7_PC
# 66                 pct_GLP_EOG_08_EDS_PC                pct_CCR_EOG_08_EDS_PC
# 67                  pct_L4_EOG_08_EDS_PC                pct_CCR_EOG_08_EDS_PC
# 68                 pct_GLP_EOG_08_ELS_PC                pct_CCR_EOG_08_ELS_PC
# 69                 pct_GLP_EOG_08_FEM_PC                pct_CCR_EOG_08_FEM_PC
# 70                 pct_GLP_EOG_08_HI7_PC                pct_CCR_EOG_08_HI7_PC
# 71                  pct_L4_EOG_08_HI7_PC                pct_CCR_EOG_08_HI7_PC
# 72                pct_GLP_EOG_08_MALE_PC               pct_CCR_EOG_08_MALE_PC
# 73                 pct_GLP_EOG_08_MU7_PC                pct_CCR_EOG_08_MU7_PC
# 74                  pct_L4_EOG_08_SWD_PC                pct_CCR_EOG_08_SWD_PC
# 75                 pct_GLP_EOG_08_WH7_PC                pct_CCR_EOG_08_WH7_PC
# 76                pct_GLP_EOG_ALL_AIG_PC               pct_CCR_EOG_ALL_AIG_PC
# 77                pct_CCR_EOG_ALL_FEM_PC               pct_CCR_EOG_ALL_ALL_PC
# 78               pct_CCR_EOG_ALL_MALE_PC               pct_CCR_EOG_ALL_ALL_PC
# 79                 pct_CCR_MA_ALL_ALL_PC               pct_CCR_EOG_ALL_ALL_PC
# 80                 pct_CCR_RD_ALL_ALL_PC               pct_CCR_EOG_ALL_ALL_PC
# 81                pct_GLP_EOG_ALL_ALL_PC               pct_CCR_EOG_ALL_ALL_PC
# 82               pct_GLP_EOG_ALL_MALE_PC               pct_CCR_EOG_ALL_ALL_PC
# 83                 pct_GLP_MA_ALL_ALL_PC               pct_CCR_EOG_ALL_ALL_PC
# 84                 pct_GLP_RD_ALL_ALL_PC               pct_CCR_EOG_ALL_ALL_PC
# 85                pct_GLP_EOG_ALL_AS7_PC               pct_CCR_EOG_ALL_AS7_PC
# 86                pct_GLP_EOG_ALL_BL7_PC               pct_CCR_EOG_ALL_BL7_PC
# 87                 pct_CCR_MA_ALL_EDS_PC               pct_CCR_EOG_ALL_EDS_PC
# 88                 pct_CCR_RD_ALL_EDS_PC               pct_CCR_EOG_ALL_EDS_PC
# 89                pct_GLP_EOG_ALL_EDS_PC               pct_CCR_EOG_ALL_EDS_PC
# 90                 pct_L4_EOG_ALL_EDS_PC               pct_CCR_EOG_ALL_EDS_PC
# 91                pct_GLP_EOG_ALL_ELS_PC               pct_CCR_EOG_ALL_ELS_PC
# 92                 pct_CCR_MA_ALL_ALL_PC               pct_CCR_EOG_ALL_FEM_PC
# 93                 pct_CCR_MA_ALL_FEM_PC               pct_CCR_EOG_ALL_FEM_PC
# 94                 pct_CCR_RD_ALL_ALL_PC               pct_CCR_EOG_ALL_FEM_PC
# 95                 pct_CCR_RD_ALL_FEM_PC               pct_CCR_EOG_ALL_FEM_PC
# 96                pct_GLP_EOG_ALL_ALL_PC               pct_CCR_EOG_ALL_FEM_PC
# 97                pct_GLP_EOG_ALL_FEM_PC               pct_CCR_EOG_ALL_FEM_PC
# 98                 pct_GLP_MA_ALL_ALL_PC               pct_CCR_EOG_ALL_FEM_PC
# 99                 pct_GLP_MA_ALL_FEM_PC               pct_CCR_EOG_ALL_FEM_PC
# 100                pct_GLP_RD_ALL_FEM_PC               pct_CCR_EOG_ALL_FEM_PC
# 101               pct_GLP_EOG_ALL_HI7_PC               pct_CCR_EOG_ALL_HI7_PC
# 102               pct_CCR_MA_ALL_MALE_PC              pct_CCR_EOG_ALL_MALE_PC
# 103               pct_CCR_RD_ALL_MALE_PC              pct_CCR_EOG_ALL_MALE_PC
# 104               pct_GLP_EOG_ALL_ALL_PC              pct_CCR_EOG_ALL_MALE_PC
# 105              pct_GLP_EOG_ALL_MALE_PC              pct_CCR_EOG_ALL_MALE_PC
# 106               pct_GLP_MA_ALL_MALE_PC              pct_CCR_EOG_ALL_MALE_PC
# 107               pct_GLP_EOG_ALL_MU7_PC               pct_CCR_EOG_ALL_MU7_PC
# 108                pct_L4_EOG_ALL_SWD_PC               pct_CCR_EOG_ALL_SWD_PC
# 109               pct_GLP_EOG_ALL_WH7_PC               pct_CCR_EOG_ALL_WH7_PC
# 110                 pct_CCR_RD_06_AIG_PC                 pct_CCR_MA_06_AIG_PC
# 111                 pct_GLP_MA_06_AIG_PC                 pct_CCR_MA_06_AIG_PC
# 112                 pct_GLP_RD_06_AIG_PC                 pct_CCR_MA_06_AIG_PC
# 113                 pct_GLP_MA_06_ALL_PC                 pct_CCR_MA_06_ALL_PC
# 114                 pct_GLP_MA_06_BL7_PC                 pct_CCR_MA_06_BL7_PC
# 115                 pct_GLP_MA_06_EDS_PC                 pct_CCR_MA_06_EDS_PC
# 116                 pct_GLP_MA_06_ELS_PC                 pct_CCR_MA_06_ELS_PC
# 117                 pct_GLP_MA_06_FEM_PC                 pct_CCR_MA_06_FEM_PC
# 118                 pct_GLP_MA_06_HI7_PC                 pct_CCR_MA_06_HI7_PC
# 119                pct_GLP_MA_06_MALE_PC                pct_CCR_MA_06_MALE_PC
# 120                  pct_L4_MA_06_SWD_PC                 pct_CCR_MA_06_SWD_PC
# 121                 pct_GLP_MA_06_WH7_PC                 pct_CCR_MA_06_WH7_PC
# 122                 pct_CCR_RD_07_AIG_PC                 pct_CCR_MA_07_AIG_PC
# 123                 pct_GLP_MA_07_AIG_PC                 pct_CCR_MA_07_AIG_PC
# 124                 pct_GLP_RD_07_AIG_PC                 pct_CCR_MA_07_AIG_PC
# 125                pct_GLP_EOG_07_ALL_PC                 pct_CCR_MA_07_ALL_PC
# 126                 pct_GLP_MA_07_ALL_PC                 pct_CCR_MA_07_ALL_PC
# 127                 pct_GLP_MA_07_BL7_PC                 pct_CCR_MA_07_BL7_PC
# 128                 pct_GLP_MA_07_EDS_PC                 pct_CCR_MA_07_EDS_PC
# 129                 pct_GLP_MA_07_ELS_PC                 pct_CCR_MA_07_ELS_PC
# 130                 pct_GLP_MA_07_FEM_PC                 pct_CCR_MA_07_FEM_PC
# 131                 pct_GLP_MA_07_HI7_PC                 pct_CCR_MA_07_HI7_PC
# 132                pct_GLP_MA_07_MALE_PC                pct_CCR_MA_07_MALE_PC
# 133                 pct_GLP_MA_07_WH7_PC                 pct_CCR_MA_07_WH7_PC
# 134                 pct_CCR_RD_08_AIG_PC                 pct_CCR_MA_08_AIG_PC
# 135                 pct_CCR_SC_08_AIG_PC                 pct_CCR_MA_08_AIG_PC
# 136                 pct_GLP_MA_08_AIG_PC                 pct_CCR_MA_08_AIG_PC
# 137                 pct_GLP_RD_08_AIG_PC                 pct_CCR_MA_08_AIG_PC
# 138                 pct_GLP_SC_08_AIG_PC                 pct_CCR_MA_08_AIG_PC
# 139                 pct_GLP_MA_08_ALL_PC                 pct_CCR_MA_08_ALL_PC
# 140                 pct_GLP_MA_08_BL7_PC                 pct_CCR_MA_08_BL7_PC
# 141                 pct_GLP_MA_08_EDS_PC                 pct_CCR_MA_08_EDS_PC
# 142                  pct_L4_MA_08_EDS_PC                 pct_CCR_MA_08_EDS_PC
# 143                 pct_GLP_MA_08_FEM_PC                 pct_CCR_MA_08_FEM_PC
# 144                 pct_GLP_MA_08_HI7_PC                 pct_CCR_MA_08_HI7_PC
# 145                  pct_L4_MA_08_HI7_PC                 pct_CCR_MA_08_HI7_PC
# 146                pct_GLP_MA_08_MALE_PC                pct_CCR_MA_08_MALE_PC
# 147                 pct_GLP_MA_08_WH7_PC                 pct_CCR_MA_08_WH7_PC
# 148                pct_CCR_RD_ALL_AIG_PC                pct_CCR_MA_ALL_AIG_PC
# 149                pct_GLP_MA_ALL_AIG_PC                pct_CCR_MA_ALL_AIG_PC
# 150                pct_GLP_RD_ALL_AIG_PC                pct_CCR_MA_ALL_AIG_PC
# 151                pct_CCR_MA_ALL_FEM_PC                pct_CCR_MA_ALL_ALL_PC
# 152               pct_CCR_MA_ALL_MALE_PC                pct_CCR_MA_ALL_ALL_PC
# 153               pct_GLP_EOG_ALL_ALL_PC                pct_CCR_MA_ALL_ALL_PC
# 154                pct_GLP_MA_ALL_ALL_PC                pct_CCR_MA_ALL_ALL_PC
# 155                pct_GLP_MA_ALL_FEM_PC                pct_CCR_MA_ALL_ALL_PC
# 156               pct_GLP_MA_ALL_MALE_PC                pct_CCR_MA_ALL_ALL_PC
# 157                pct_GLP_MA_ALL_BL7_PC                pct_CCR_MA_ALL_BL7_PC
# 158                pct_GLP_MA_ALL_EDS_PC                pct_CCR_MA_ALL_EDS_PC
# 159                pct_GLP_MA_ALL_ELS_PC                pct_CCR_MA_ALL_ELS_PC
# 160               pct_GLP_EOG_ALL_FEM_PC                pct_CCR_MA_ALL_FEM_PC
# 161                pct_GLP_MA_ALL_ALL_PC                pct_CCR_MA_ALL_FEM_PC
# 162                pct_GLP_MA_ALL_FEM_PC                pct_CCR_MA_ALL_FEM_PC
# 163                pct_GLP_MA_ALL_HI7_PC                pct_CCR_MA_ALL_HI7_PC
# 164                pct_GLP_MA_ALL_ALL_PC               pct_CCR_MA_ALL_MALE_PC
# 165               pct_GLP_MA_ALL_MALE_PC               pct_CCR_MA_ALL_MALE_PC
# 166                pct_GLP_MA_ALL_MU7_PC                pct_CCR_MA_ALL_MU7_PC
# 167                 pct_L4_MA_ALL_SWD_PC                pct_CCR_MA_ALL_SWD_PC
# 168                pct_GLP_MA_ALL_WH7_PC                pct_CCR_MA_ALL_WH7_PC
# 169                 pct_GLP_MA_06_AIG_PC                 pct_CCR_RD_06_AIG_PC
# 170                 pct_GLP_RD_06_AIG_PC                 pct_CCR_RD_06_AIG_PC
# 171                 pct_GLP_RD_06_ALL_PC                 pct_CCR_RD_06_ALL_PC
# 172                 pct_GLP_RD_06_BL7_PC                 pct_CCR_RD_06_BL7_PC
# 173                  pct_L4_RD_06_BL7_PC                 pct_CCR_RD_06_BL7_PC
# 174                 pct_GLP_RD_06_EDS_PC                 pct_CCR_RD_06_EDS_PC
# 175                  pct_L4_RD_06_EDS_PC                 pct_CCR_RD_06_EDS_PC
# 176                 pct_GLP_RD_06_ELS_PC                 pct_CCR_RD_06_ELS_PC
# 177                  pct_L4_RD_06_ELS_PC                 pct_CCR_RD_06_ELS_PC
# 178                 pct_GLP_RD_06_FEM_PC                 pct_CCR_RD_06_FEM_PC
# 179                 pct_GLP_RD_06_HI7_PC                 pct_CCR_RD_06_HI7_PC
# 180                  pct_L4_RD_06_HI7_PC                 pct_CCR_RD_06_HI7_PC
# 181                pct_GLP_RD_06_MALE_PC                pct_CCR_RD_06_MALE_PC
# 182                 pct_GLP_MA_06_WH7_PC                 pct_CCR_RD_06_WH7_PC
# 183                 pct_GLP_RD_06_WH7_PC                 pct_CCR_RD_06_WH7_PC
# 184                 pct_GLP_MA_07_AIG_PC                 pct_CCR_RD_07_AIG_PC
# 185                 pct_GLP_RD_07_AIG_PC                 pct_CCR_RD_07_AIG_PC
# 186                pct_GLP_EOG_07_ALL_PC                 pct_CCR_RD_07_ALL_PC
# 187                 pct_GLP_RD_07_ALL_PC                 pct_CCR_RD_07_ALL_PC
# 188                 pct_GLP_RD_07_BL7_PC                 pct_CCR_RD_07_BL7_PC
# 189                  pct_L4_RD_07_BL7_PC                 pct_CCR_RD_07_BL7_PC
# 190                 pct_GLP_RD_07_EDS_PC                 pct_CCR_RD_07_EDS_PC
# 191                  pct_L4_RD_07_EDS_PC                 pct_CCR_RD_07_EDS_PC
# 192                 pct_GLP_RD_07_ELS_PC                 pct_CCR_RD_07_ELS_PC
# 193                  pct_L4_RD_07_ELS_PC                 pct_CCR_RD_07_ELS_PC
# 194                 pct_GLP_RD_07_FEM_PC                 pct_CCR_RD_07_FEM_PC
# 195                 pct_GLP_RD_07_HI7_PC                 pct_CCR_RD_07_HI7_PC
# 196                  pct_L4_RD_07_HI7_PC                 pct_CCR_RD_07_HI7_PC
# 197                pct_GLP_RD_07_MALE_PC                pct_CCR_RD_07_MALE_PC
# 198                 pct_L4_RD_07_MALE_PC                pct_CCR_RD_07_MALE_PC
# 199                 pct_GLP_MA_07_WH7_PC                 pct_CCR_RD_07_WH7_PC
# 200                 pct_GLP_RD_07_WH7_PC                 pct_CCR_RD_07_WH7_PC
# 201                 pct_CCR_SC_08_AIG_PC                 pct_CCR_RD_08_AIG_PC
# 202                 pct_GLP_MA_08_AIG_PC                 pct_CCR_RD_08_AIG_PC
# 203                 pct_GLP_RD_08_AIG_PC                 pct_CCR_RD_08_AIG_PC
# 204                 pct_GLP_SC_08_AIG_PC                 pct_CCR_RD_08_AIG_PC
# 205                 pct_GLP_RD_08_ALL_PC                 pct_CCR_RD_08_ALL_PC
# 206                  pct_L4_RD_08_ALL_PC                 pct_CCR_RD_08_ALL_PC
# 207                 pct_GLP_RD_08_BL7_PC                 pct_CCR_RD_08_BL7_PC
# 208                  pct_L4_RD_08_BL7_PC                 pct_CCR_RD_08_BL7_PC
# 209                 pct_GLP_RD_08_EDS_PC                 pct_CCR_RD_08_EDS_PC
# 210                  pct_L4_RD_08_EDS_PC                 pct_CCR_RD_08_EDS_PC
# 211                 pct_GLP_RD_08_FEM_PC                 pct_CCR_RD_08_FEM_PC
# 212                  pct_L4_RD_08_FEM_PC                 pct_CCR_RD_08_FEM_PC
# 213                  pct_L4_RD_08_HI7_PC                 pct_CCR_RD_08_HI7_PC
# 214                pct_GLP_RD_08_MALE_PC                pct_CCR_RD_08_MALE_PC
# 215                 pct_L4_RD_08_MALE_PC                pct_CCR_RD_08_MALE_PC
# 216                 pct_GLP_MA_08_WH7_PC                 pct_CCR_RD_08_WH7_PC
# 217                 pct_GLP_RD_08_WH7_PC                 pct_CCR_RD_08_WH7_PC
# 218                pct_GLP_MA_ALL_AIG_PC                pct_CCR_RD_ALL_AIG_PC
# 219                pct_GLP_RD_ALL_AIG_PC                pct_CCR_RD_ALL_AIG_PC
# 220                pct_CCR_RD_ALL_FEM_PC                pct_CCR_RD_ALL_ALL_PC
# 221               pct_CCR_RD_ALL_MALE_PC                pct_CCR_RD_ALL_ALL_PC
# 222               pct_GLP_EOG_ALL_ALL_PC                pct_CCR_RD_ALL_ALL_PC
# 223                pct_GLP_RD_ALL_ALL_PC                pct_CCR_RD_ALL_ALL_PC
# 224                 pct_L4_RD_ALL_ALL_PC                pct_CCR_RD_ALL_ALL_PC
# 225                pct_GLP_RD_ALL_BL7_PC                pct_CCR_RD_ALL_BL7_PC
# 226                 pct_L4_RD_ALL_BL7_PC                pct_CCR_RD_ALL_BL7_PC
# 227                pct_GLP_RD_ALL_EDS_PC                pct_CCR_RD_ALL_EDS_PC
# 228                 pct_L4_RD_ALL_EDS_PC                pct_CCR_RD_ALL_EDS_PC
# 229                 pct_L4_RD_ALL_ELS_PC                pct_CCR_RD_ALL_ELS_PC
# 230               pct_GLP_EOG_ALL_FEM_PC                pct_CCR_RD_ALL_FEM_PC
# 231                pct_GLP_RD_ALL_FEM_PC                pct_CCR_RD_ALL_FEM_PC
# 232                pct_GLP_RD_ALL_HI7_PC                pct_CCR_RD_ALL_HI7_PC
# 233                 pct_L4_RD_ALL_HI7_PC                pct_CCR_RD_ALL_HI7_PC
# 234               pct_GLP_RD_ALL_MALE_PC               pct_CCR_RD_ALL_MALE_PC
# 235                pct_L4_RD_ALL_MALE_PC               pct_CCR_RD_ALL_MALE_PC
# 236                pct_GLP_RD_ALL_MU7_PC                pct_CCR_RD_ALL_MU7_PC
# 237                pct_GLP_RD_ALL_WH7_PC                pct_CCR_RD_ALL_WH7_PC
# 238                 pct_GLP_MA_08_AIG_PC                 pct_CCR_SC_08_AIG_PC
# 239                 pct_GLP_RD_08_AIG_PC                 pct_CCR_SC_08_AIG_PC
# 240                 pct_GLP_SC_08_AIG_PC                 pct_CCR_SC_08_AIG_PC
# 241                 pct_GLP_SC_08_ALL_PC                 pct_CCR_SC_08_ALL_PC
# 242                pct_CCR_SC_ALL_BL7_PC                 pct_CCR_SC_08_BL7_PC
# 243                 pct_GLP_SC_08_BL7_PC                 pct_CCR_SC_08_BL7_PC
# 244                  pct_L4_SC_08_BL7_PC                 pct_CCR_SC_08_BL7_PC
# 245                 pct_GLP_SC_08_EDS_PC                 pct_CCR_SC_08_EDS_PC
# 246                 pct_GLP_SC_08_ELS_PC                 pct_CCR_SC_08_ELS_PC
# 247                  pct_L4_SC_08_ELS_PC                 pct_CCR_SC_08_ELS_PC
# 248                 pct_GLP_RD_08_FEM_PC                 pct_CCR_SC_08_FEM_PC
# 249                 pct_GLP_SC_08_FEM_PC                 pct_CCR_SC_08_FEM_PC
# 250                 pct_GLP_SC_08_HI7_PC                 pct_CCR_SC_08_HI7_PC
# 251                pct_GLP_SC_08_MALE_PC                pct_CCR_SC_08_MALE_PC
# 252                 pct_GLP_SC_08_SWD_PC                 pct_CCR_SC_08_SWD_PC
# 253                  pct_L4_SC_08_SWD_PC                 pct_CCR_SC_08_SWD_PC
# 254                 pct_GLP_RD_08_WH7_PC                 pct_CCR_SC_08_WH7_PC
# 255                 pct_GLP_SC_08_WH7_PC                 pct_CCR_SC_08_WH7_PC
# 256                pct_GLP_SC_ALL_AIG_PC                pct_CCR_SC_ALL_AIG_PC
# 257               pct_CCR_SC_ALL_MALE_PC                pct_CCR_SC_ALL_ALL_PC
# 258                pct_GLP_SC_ALL_ALL_PC                pct_CCR_SC_ALL_ALL_PC
# 259                pct_GLP_SC_ALL_BL7_PC                pct_CCR_SC_ALL_BL7_PC
# 260                 pct_L4_SC_ALL_BL7_PC                pct_CCR_SC_ALL_BL7_PC
# 261                pct_GLP_SC_ALL_EDS_PC                pct_CCR_SC_ALL_EDS_PC
# 262                pct_GLP_SC_ALL_ELS_PC                pct_CCR_SC_ALL_ELS_PC
# 263                 pct_L4_SC_ALL_ELS_PC                pct_CCR_SC_ALL_ELS_PC
# 264                pct_GLP_SC_ALL_FEM_PC                pct_CCR_SC_ALL_FEM_PC
# 265                pct_GLP_SC_ALL_HI7_PC                pct_CCR_SC_ALL_HI7_PC
# 266               pct_GLP_SC_ALL_MALE_PC               pct_CCR_SC_ALL_MALE_PC
# 267                 pct_L4_SC_ALL_SWD_PC                pct_CCR_SC_ALL_SWD_PC
# 268                pct_GLP_SC_ALL_WH7_PC                pct_CCR_SC_ALL_WH7_PC
# 269                 pct_GLP_MA_06_ALL_PC                pct_GLP_EOG_06_ALL_PC
# 270                 pct_L4_EOG_06_EDS_PC                pct_GLP_EOG_06_EDS_PC
# 271                 pct_GLP_RD_06_ALL_PC                pct_GLP_EOG_06_FEM_PC
# 272                pct_GLP_EOG_07_FEM_PC                pct_GLP_EOG_07_ALL_PC
# 273               pct_GLP_EOG_07_MALE_PC                pct_GLP_EOG_07_ALL_PC
# 274                 pct_GLP_MA_07_ALL_PC                pct_GLP_EOG_07_ALL_PC
# 275                 pct_GLP_RD_07_ALL_PC                pct_GLP_EOG_07_ALL_PC
# 276                 pct_GLP_MA_07_ALL_PC                pct_GLP_EOG_07_FEM_PC
# 277                 pct_GLP_RD_07_ALL_PC                pct_GLP_EOG_07_FEM_PC
# 278                 pct_L4_EOG_07_HI7_PC                pct_GLP_EOG_07_HI7_PC
# 279                 pct_GLP_RD_08_ALL_PC                pct_GLP_EOG_08_ALL_PC
# 280                 pct_L4_EOG_08_ALL_PC                pct_GLP_EOG_08_ALL_PC
# 281                 pct_L4_EOG_08_BL7_PC                pct_GLP_EOG_08_BL7_PC
# 282                 pct_L4_EOG_08_EDS_PC                pct_GLP_EOG_08_EDS_PC
# 283                 pct_L4_EOG_08_HI7_PC                pct_GLP_EOG_08_HI7_PC
# 284               pct_GLP_EOG_ALL_FEM_PC               pct_GLP_EOG_ALL_ALL_PC
# 285              pct_GLP_EOG_ALL_MALE_PC               pct_GLP_EOG_ALL_ALL_PC
# 286                pct_GLP_MA_ALL_ALL_PC               pct_GLP_EOG_ALL_ALL_PC
# 287                pct_GLP_RD_ALL_ALL_PC               pct_GLP_EOG_ALL_ALL_PC
# 288                pct_GLP_MA_ALL_EDS_PC               pct_GLP_EOG_ALL_EDS_PC
# 289                pct_GLP_RD_ALL_EDS_PC               pct_GLP_EOG_ALL_EDS_PC
# 290                pct_L4_EOG_ALL_EDS_PC               pct_GLP_EOG_ALL_EDS_PC
# 291                pct_GLP_MA_ALL_FEM_PC               pct_GLP_EOG_ALL_FEM_PC
# 292                pct_GLP_RD_ALL_ALL_PC               pct_GLP_EOG_ALL_FEM_PC
# 293                pct_GLP_RD_ALL_FEM_PC               pct_GLP_EOG_ALL_FEM_PC
# 294               pct_GLP_MA_ALL_MALE_PC              pct_GLP_EOG_ALL_MALE_PC
# 295               pct_GLP_RD_ALL_MALE_PC              pct_GLP_EOG_ALL_MALE_PC
# 296                 pct_GLP_RD_06_AIG_PC                 pct_GLP_MA_06_AIG_PC
# 297                 pct_GLP_RD_06_WH7_PC                 pct_GLP_MA_06_WH7_PC
# 298                 pct_GLP_RD_07_AIG_PC                 pct_GLP_MA_07_AIG_PC
# 299                 pct_GLP_RD_07_WH7_PC                 pct_GLP_MA_07_WH7_PC
# 300                 pct_GLP_RD_08_AIG_PC                 pct_GLP_MA_08_AIG_PC
# 301                 pct_GLP_SC_08_AIG_PC                 pct_GLP_MA_08_AIG_PC
# 302                 pct_GLP_RD_08_WH7_PC                 pct_GLP_MA_08_WH7_PC
# 303                pct_GLP_RD_ALL_AIG_PC                pct_GLP_MA_ALL_AIG_PC
# 304                pct_GLP_MA_ALL_FEM_PC                pct_GLP_MA_ALL_ALL_PC
# 305               pct_GLP_MA_ALL_MALE_PC                pct_GLP_MA_ALL_ALL_PC
# 306                  pct_L4_RD_06_ALL_PC                 pct_GLP_RD_06_ALL_PC
# 307                 pct_L4_RD_06_MALE_PC                pct_GLP_RD_06_MALE_PC
# 308                  pct_L4_RD_07_ALL_PC                 pct_GLP_RD_07_ALL_PC
# 309                  pct_L4_RD_07_BL7_PC                 pct_GLP_RD_07_BL7_PC
# 310                  pct_L4_RD_07_EDS_PC                 pct_GLP_RD_07_EDS_PC
# 311                  pct_L4_RD_07_ELS_PC                 pct_GLP_RD_07_ELS_PC
# 312                  pct_L4_RD_07_FEM_PC                 pct_GLP_RD_07_FEM_PC
# 313                  pct_L4_RD_07_HI7_PC                 pct_GLP_RD_07_HI7_PC
# 314                 pct_L4_RD_07_MALE_PC                pct_GLP_RD_07_MALE_PC
# 315                  pct_L4_RD_07_WH7_PC                 pct_GLP_RD_07_WH7_PC
# 316                 pct_GLP_SC_08_AIG_PC                 pct_GLP_RD_08_AIG_PC
# 317                  pct_L4_RD_08_ALL_PC                 pct_GLP_RD_08_ALL_PC
# 318                  pct_L4_RD_08_FEM_PC                 pct_GLP_RD_08_FEM_PC
# 319                 pct_L4_RD_08_MALE_PC                pct_GLP_RD_08_MALE_PC
# 320                 pct_GLP_SC_08_WH7_PC                 pct_GLP_RD_08_WH7_PC
# 321                  pct_L4_RD_08_WH7_PC                 pct_GLP_RD_08_WH7_PC
# 322               pct_GLP_RD_ALL_MALE_PC                pct_GLP_RD_ALL_ALL_PC
# 323                 pct_L4_RD_ALL_ALL_PC                pct_GLP_RD_ALL_ALL_PC
# 324                 pct_L4_RD_ALL_BL7_PC                pct_GLP_RD_ALL_BL7_PC
# 325                 pct_L4_RD_ALL_EDS_PC                pct_GLP_RD_ALL_EDS_PC
# 326                 pct_L4_RD_ALL_FEM_PC                pct_GLP_RD_ALL_FEM_PC
# 327                pct_L4_RD_ALL_MALE_PC               pct_GLP_RD_ALL_MALE_PC
# 328                pct_GLP_SC_ALL_BL7_PC                 pct_GLP_SC_08_BL7_PC
# 329                  pct_L4_SC_08_BL7_PC                 pct_GLP_SC_08_BL7_PC
# 330                  pct_L4_SC_08_ELS_PC                 pct_GLP_SC_08_ELS_PC
# 331               pct_GLP_SC_ALL_MALE_PC                pct_GLP_SC_ALL_ALL_PC
# 332                  scgs_score_ALL_SPG2                pct_GLP_SC_ALL_FEM_PC
# 333               pct_L1_ALL_ALL_MALE_PC                pct_L1_ALL_ALL_ALL_PC
# 334                pct_L1_EOG_ALL_HMS_PC                pct_L1_ALL_ALL_HMS_PC
# 335                pct_L1_EOG_ALL_ALL_PC               pct_L1_ALL_ALL_MALE_PC
# 336               pct_L1_EOG_ALL_MALE_PC               pct_L1_ALL_ALL_MALE_PC
# 337               pct_L1_EOG_ALL_MALE_PC                pct_L1_EOG_ALL_ALL_PC
# 338                  pct_L1_RD_08_ELS_PC                  pct_L1_MA_08_ELS_PC
# 339                pct_L2_EOG_ALL_AS7_PC                pct_L2_ALL_ALL_AS7_PC
# 340                pct_L2_EOG_ALL_BL7_PC                pct_L2_ALL_ALL_BL7_PC
# 341                pct_L2_EOG_ALL_ELS_PC                pct_L2_ALL_ALL_ELS_PC
# 342               pct_L2_EOG_ALL_MALE_PC                pct_L2_EOG_ALL_ALL_PC
# 343                pct_L3_EOG_ALL_BL7_PC                pct_L3_ALL_ALL_BL7_PC
# 344                pct_L3_EOG_ALL_ELS_PC                pct_L3_ALL_ALL_ELS_PC
# 345                pct_L3_EOG_ALL_MU7_PC                pct_L3_ALL_ALL_MU7_PC
# 346                pct_L3_EOG_ALL_SWD_PC                pct_L3_ALL_ALL_SWD_PC
# 347                pct_L4_EOG_ALL_AIG_PC                pct_L4_ALL_ALL_AIG_PC
# 348                pct_L4_ALL_ALL_FEM_PC                pct_L4_ALL_ALL_ALL_PC
# 349               pct_L4_ALL_ALL_MALE_PC                pct_L4_ALL_ALL_ALL_PC
# 350                pct_L4_EOG_ALL_AS7_PC                pct_L4_ALL_ALL_AS7_PC
# 351                pct_L4_EOG_ALL_BL7_PC                pct_L4_ALL_ALL_BL7_PC
# 352                pct_L4_EOG_ALL_EDS_PC                pct_L4_ALL_ALL_EDS_PC
# 353                pct_L4_EOG_ALL_ELS_PC                pct_L4_ALL_ALL_ELS_PC
# 354                pct_L4_EOG_ALL_FEM_PC                pct_L4_ALL_ALL_FEM_PC
# 355                pct_L4_EOG_ALL_HI7_PC                pct_L4_ALL_ALL_HI7_PC
# 356                pct_L4_EOG_ALL_MU7_PC                pct_L4_ALL_ALL_MU7_PC
# 357                  pct_L4_RD_07_ALL_PC                 pct_L4_EOG_07_ALL_PC
# 358               pct_L4_EOG_ALL_MALE_PC                pct_L4_EOG_ALL_ALL_PC
# 359                 pct_L4_RD_ALL_ALL_PC                pct_L4_EOG_ALL_ALL_PC
# 360                 pct_L4_RD_ALL_EDS_PC                pct_L4_EOG_ALL_EDS_PC
# 361                 pct_L4_RD_ALL_FEM_PC                pct_L4_EOG_ALL_FEM_PC
# 362                pct_L4_MA_ALL_MALE_PC                 pct_L4_MA_ALL_ALL_PC
# 363                pct_L4_RD_ALL_MALE_PC                 pct_L4_RD_ALL_ALL_PC
# 364                 pct_L4_SC_ALL_BL7_PC                  pct_L4_SC_08_BL7_PC
# 365                pct_L5_EOG_ALL_AIG_PC                pct_L5_ALL_ALL_AIG_PC
# 366                pct_L5_ALL_ALL_FEM_PC                pct_L5_ALL_ALL_ALL_PC
# 367               pct_L5_ALL_ALL_MALE_PC                pct_L5_ALL_ALL_ALL_PC
# 368                pct_L5_EOG_ALL_ALL_PC                pct_L5_ALL_ALL_ALL_PC
# 369                pct_L5_EOG_ALL_FEM_PC                pct_L5_ALL_ALL_ALL_PC
# 370               pct_L5_EOG_ALL_MALE_PC                pct_L5_ALL_ALL_ALL_PC
# 371                 pct_L5_MA_ALL_ALL_PC                pct_L5_ALL_ALL_ALL_PC
# 372                 pct_L5_MA_ALL_FEM_PC                pct_L5_ALL_ALL_ALL_PC
# 373                pct_L5_MA_ALL_MALE_PC                pct_L5_ALL_ALL_ALL_PC
# 374                 pct_L5_RD_ALL_ALL_PC                pct_L5_ALL_ALL_ALL_PC
# 375                pct_L5_EOG_ALL_AS7_PC                pct_L5_ALL_ALL_AS7_PC
# 376                pct_L5_EOG_ALL_EDS_PC                pct_L5_ALL_ALL_EDS_PC
# 377                pct_L5_EOG_ALL_ALL_PC                pct_L5_ALL_ALL_FEM_PC
# 378                pct_L5_EOG_ALL_FEM_PC                pct_L5_ALL_ALL_FEM_PC
# 379                 pct_L5_MA_ALL_ALL_PC                pct_L5_ALL_ALL_FEM_PC
# 380                 pct_L5_MA_ALL_FEM_PC                pct_L5_ALL_ALL_FEM_PC
# 381                 pct_L5_RD_ALL_FEM_PC                pct_L5_ALL_ALL_FEM_PC
# 382                pct_L5_EOG_ALL_HI7_PC                pct_L5_ALL_ALL_HI7_PC
# 383                pct_L5_EOG_ALL_ALL_PC               pct_L5_ALL_ALL_MALE_PC
# 384               pct_L5_EOG_ALL_MALE_PC               pct_L5_ALL_ALL_MALE_PC
# 385                 pct_L5_MA_ALL_ALL_PC               pct_L5_ALL_ALL_MALE_PC
# 386                pct_L5_MA_ALL_MALE_PC               pct_L5_ALL_ALL_MALE_PC
# 387                pct_L5_EOG_ALL_MU7_PC                pct_L5_ALL_ALL_MU7_PC
# 388                pct_L5_EOG_ALL_WH7_PC                pct_L5_ALL_ALL_WH7_PC
# 389                 pct_L5_MA_ALL_WH7_PC                pct_L5_ALL_ALL_WH7_PC
# 390                 pct_L5_EOG_06_FEM_PC                 pct_L5_EOG_06_ALL_PC
# 391                pct_L5_EOG_06_MALE_PC                 pct_L5_EOG_06_ALL_PC
# 392                  pct_L5_MA_06_ALL_PC                 pct_L5_EOG_06_ALL_PC
# 393                 pct_L5_MA_06_MALE_PC                pct_L5_EOG_06_MALE_PC
# 394                  pct_L5_MA_06_WH7_PC                 pct_L5_EOG_06_WH7_PC
# 395                 pct_L5_EOG_07_FEM_PC                 pct_L5_EOG_07_ALL_PC
# 396                  pct_L5_MA_07_ALL_PC                 pct_L5_EOG_07_ALL_PC
# 397                  pct_L5_MA_07_ALL_PC                 pct_L5_EOG_07_FEM_PC
# 398                 pct_L5_MA_07_MALE_PC                pct_L5_EOG_07_MALE_PC
# 399                  pct_L5_MA_07_WH7_PC                 pct_L5_EOG_07_WH7_PC
# 400                 pct_L5_EOG_08_FEM_PC                 pct_L5_EOG_08_ALL_PC
# 401                pct_L5_EOG_08_MALE_PC                 pct_L5_EOG_08_ALL_PC
# 402                pct_L5_EOG_ALL_FEM_PC                pct_L5_EOG_ALL_ALL_PC
# 403               pct_L5_EOG_ALL_MALE_PC                pct_L5_EOG_ALL_ALL_PC
# 404                 pct_L5_MA_ALL_ALL_PC                pct_L5_EOG_ALL_ALL_PC
# 405                 pct_L5_MA_ALL_FEM_PC                pct_L5_EOG_ALL_ALL_PC
# 406                 pct_L5_RD_ALL_ALL_PC                pct_L5_EOG_ALL_ALL_PC
# 407                 pct_L5_MA_ALL_ALL_PC                pct_L5_EOG_ALL_FEM_PC
# 408                 pct_L5_MA_ALL_FEM_PC                pct_L5_EOG_ALL_FEM_PC
# 409                 pct_L5_RD_ALL_FEM_PC                pct_L5_EOG_ALL_FEM_PC
# 410                 pct_L5_MA_ALL_ALL_PC               pct_L5_EOG_ALL_MALE_PC
# 411                pct_L5_MA_ALL_MALE_PC               pct_L5_EOG_ALL_MALE_PC
# 412                 pct_L5_MA_ALL_WH7_PC                pct_L5_EOG_ALL_WH7_PC
# 413                  pct_L5_MA_07_FEM_PC                  pct_L5_MA_07_ALL_PC
# 414                 pct_L5_MA_07_MALE_PC                  pct_L5_MA_07_ALL_PC
# 415                  pct_L5_MA_08_FEM_PC                  pct_L5_MA_08_ALL_PC
# 416                 pct_L5_MA_08_MALE_PC                  pct_L5_MA_08_ALL_PC
# 417                 pct_L5_MA_ALL_FEM_PC                 pct_L5_MA_ALL_ALL_PC
# 418                pct_L5_MA_ALL_MALE_PC                 pct_L5_MA_ALL_ALL_PC
# 419                 pct_L5_RD_ALL_FEM_PC                 pct_L5_RD_ALL_ALL_PC
# 420                pct_L5_RD_ALL_MALE_PC                 pct_L5_RD_ALL_ALL_PC
# 421                 pct_L5_SC_ALL_ALL_PC                  pct_L5_SC_08_ALL_PC
# 422                 pct_L5_SC_ALL_BL7_PC                  pct_L5_SC_08_BL7_PC
# 423                 pct_L5_SC_ALL_FEM_PC                  pct_L5_SC_08_FEM_PC
# 424                 pct_L5_SC_ALL_HI7_PC                  pct_L5_SC_08_HI7_PC
# 425                pct_L5_SC_ALL_MALE_PC                 pct_L5_SC_08_MALE_PC
# 426                 pct_L5_SC_ALL_FEM_PC                 pct_L5_SC_ALL_ALL_PC
# 427                pct_L5_SC_ALL_MALE_PC                 pct_L5_SC_ALL_ALL_PC
# 428                             rd_score                             ma_score
# 429                         ma_spg_score                             ma_score
# 430                            ach_score                             rd_score
# 431                         ma_spg_score                             rd_score
# 432                         rd_spg_score                             rd_score
# 433                         rd_spg_score                             sc_score
# 434                            spg_score                            ach_score
# 435                         ma_spg_score                            spg_score
# 436                         rd_spg_score                            spg_score
# 437                         rd_spg_score                         ma_spg_score
# 438                   ach_score_ALL_SPG2                   aaa_score_ALL_SPG2
# 439                   spg_score_ALL_SPG2                   aaa_score_ALL_SPG2
# 440                   ach_score_BL7_SPG2                   aaa_score_BL7_SPG2
# 441                   spg_score_BL7_SPG2                   aaa_score_BL7_SPG2
# 442                   ach_score_EDS_SPG2                   aaa_score_EDS_SPG2
# 443                   spg_score_EDS_SPG2                   aaa_score_EDS_SPG2
# 444                   ach_score_ELS_SPG2                   aaa_score_ELS_SPG2
# 445                   spg_score_ELS_SPG2                   aaa_score_ELS_SPG2
# 446                   ach_score_HI7_SPG2                   aaa_score_HI7_SPG2
# 447                   spg_score_HI7_SPG2                   aaa_score_HI7_SPG2
# 448                   ach_score_MU7_SPG2                   aaa_score_MU7_SPG2
# 449                   spg_score_MU7_SPG2                   aaa_score_MU7_SPG2
# 450                   ach_score_SWD_SPG2                   aaa_score_SWD_SPG2
# 451                   ach_score_WH7_SPG2                   aaa_score_WH7_SPG2
# 452                   spg_score_WH7_SPG2                   aaa_score_WH7_SPG2
# 453                   spg_score_ALL_SPG2                   ach_score_ALL_SPG2
# 454                   spg_score_BL7_SPG2                   ach_score_BL7_SPG2
# 455                   spg_score_EDS_SPG2                   ach_score_EDS_SPG2
# 456                   spg_score_ELS_SPG2                   ach_score_ELS_SPG2
# 457                   spg_score_HI7_SPG2                   ach_score_HI7_SPG2
# 458                   spg_score_MU7_SPG2                   ach_score_MU7_SPG2
# 459                   spg_score_WH7_SPG2                   ach_score_WH7_SPG2
# 460           avg_class_teach_TeacherExp                      avg_student_num
# 461                pct_MALE_CHRON_ABSENT                 pct_ALL_CHRON_ABSENT
# 462                      category_code_M                 highqual_class_pct_M
# 463                     arre_per1000_BL7                     arre_per1000_ALL
# 464                     arre_per1000_EDS                     arre_per1000_ALL
# 465                     arre_per1000_SWD                     arre_per1000_ALL
# 466                    crime_per1000_ELS                     arre_per1000_ALL
# 467                     grade_span_KG:13                     arre_per1000_ALL
# 468            subgroup_list_ALL,BL7,SWD                     arre_per1000_ALL
# 469                     arre_per1000_EDS                     arre_per1000_BL7
# 470                     arre_per1000_SWD                     arre_per1000_BL7
# 471                    crime_per1000_ELS                     arre_per1000_BL7
# 472                     grade_span_KG:13                     arre_per1000_BL7
# 473            subgroup_list_ALL,BL7,SWD                     arre_per1000_BL7
# 474                     arre_per1000_SWD                     arre_per1000_EDS
# 475                    crime_per1000_ELS                     arre_per1000_EDS
# 476                     grade_span_KG:13                     arre_per1000_EDS
# 477            subgroup_list_ALL,BL7,SWD                     arre_per1000_EDS
# 478                     arre_per1000_HI7                     arre_per1000_ELS
# 479                     arre_per1000_SWD                    arre_per1000_MALE
# 480                     grade_span_KG:13                    crime_per1000_ELS
# 481            subgroup_list_ALL,BL7,SWD                    crime_per1000_ELS
# 482                      exp_per1000_BL7                      exp_per1000_ALL
# 483                      exp_per1000_EDS                      exp_per1000_ALL
# 484                     exp_per1000_MALE                      exp_per1000_ALL
# 485                      exp_per1000_EDS                      exp_per1000_BL7
# 486                     exp_per1000_MALE                      exp_per1000_BL7
# 487                     exp_per1000_MALE                      exp_per1000_EDS
# 488                     iss_per1000_MALE                      iss_per1000_ALL
# 489                     lts_per1000_MALE                      lts_per1000_ALL
# 490                     county_Alexander                      lea_code_020LEA
# 491               agency_lea_code_020LEA                      lea_code_020LEA
# 492                     county_Alleghany                      lea_code_030LEA
# 493               agency_lea_code_030LEA                      lea_code_030LEA
# 494                         county_Anson                      lea_code_040LEA
# 495               agency_lea_code_040LEA                      lea_code_040LEA
# 496                          county_Ashe                      lea_code_050LEA
# 497               agency_lea_code_050LEA                      lea_code_050LEA
# 498                         county_Avery                      lea_code_060LEA
# 499               agency_lea_code_060LEA                      lea_code_060LEA
# 500                      county_Beaufort                      lea_code_070LEA
# 501               agency_lea_code_070LEA                      lea_code_070LEA
# 502                        county_Bertie                      lea_code_080LEA
# 503               agency_lea_code_080LEA                      lea_code_080LEA
# 504                        county_Bladen                      lea_code_090LEA
# 505               agency_lea_code_090LEA                      lea_code_090LEA
# 506                     county_Brunswick                      lea_code_100LEA
# 507               agency_lea_code_100LEA                      lea_code_100LEA
# 508               agency_lea_code_110LEA                      lea_code_110LEA
# 509               agency_lea_code_111LEA                      lea_code_111LEA
# 510                         county_Burke                      lea_code_120LEA
# 511               agency_lea_code_120LEA                      lea_code_120LEA
# 512                      county_Cabarrus                      lea_code_130LEA
# 513               agency_lea_code_130LEA                      lea_code_130LEA
# 514               agency_lea_code_132LEA                      lea_code_132LEA
# 515                      county_Caldwell                      lea_code_140LEA
# 516               agency_lea_code_140LEA                      lea_code_140LEA
# 517                        county_Camden                      lea_code_150LEA
# 518               agency_lea_code_150LEA                      lea_code_150LEA
# 519                      county_Carteret                      lea_code_160LEA
# 520               agency_lea_code_160LEA                      lea_code_160LEA
# 521                       county_Caswell                      lea_code_170LEA
# 522               agency_lea_code_170LEA                      lea_code_170LEA
# 523               agency_lea_code_180LEA                      lea_code_180LEA
# 524               agency_lea_code_181LEA                      lea_code_181LEA
# 525               agency_lea_code_182LEA                      lea_code_182LEA
# 526                       county_Chatham                      lea_code_190LEA
# 527               agency_lea_code_190LEA                      lea_code_190LEA
# 528                      county_Cherokee                      lea_code_200LEA
# 529               agency_lea_code_200LEA                      lea_code_200LEA
# 530                        county_Chowan                      lea_code_210LEA
# 531               agency_lea_code_210LEA                      lea_code_210LEA
# 532                          county_Clay                      lea_code_220LEA
# 533               agency_lea_code_220LEA                      lea_code_220LEA
# 534                     county_Cleveland                      lea_code_230LEA
# 535               agency_lea_code_230LEA                      lea_code_230LEA
# 536               agency_lea_code_240LEA                      lea_code_240LEA
# 537               agency_lea_code_241LEA                      lea_code_241LEA
# 538                        county_Craven                      lea_code_250LEA
# 539               agency_lea_code_250LEA                      lea_code_250LEA
# 540                    county_Cumberland                      lea_code_260LEA
# 541               agency_lea_code_260LEA                      lea_code_260LEA
# 542                     county_Currituck                      lea_code_270LEA
# 543    subgroup_list_ALL,EDS,MU7,SWD,WH7                      lea_code_270LEA
# 544               agency_lea_code_270LEA                      lea_code_270LEA
# 545                          county_Dare                      lea_code_280LEA
# 546               agency_lea_code_280LEA                      lea_code_280LEA
# 547               agency_lea_code_290LEA                      lea_code_290LEA
# 548               agency_lea_code_291LEA                      lea_code_291LEA
# 549               agency_lea_code_292LEA                      lea_code_292LEA
# 550                         county_Davie                      lea_code_300LEA
# 551               agency_lea_code_300LEA                      lea_code_300LEA
# 552                        county_Duplin                      lea_code_310LEA
# 553               agency_lea_code_310LEA                      lea_code_310LEA
# 554                        county_Durham                      lea_code_320LEA
# 555               agency_lea_code_320LEA                      lea_code_320LEA
# 556                     county_Edgecombe                      lea_code_330LEA
# 557               agency_lea_code_330LEA                      lea_code_330LEA
# 558                       county_Forsyth                      lea_code_340LEA
# 559               agency_lea_code_340LEA                      lea_code_340LEA
# 560                      county_Franklin                      lea_code_350LEA
# 561               agency_lea_code_350LEA                      lea_code_350LEA
# 562                        county_Gaston                      lea_code_360LEA
# 563               agency_lea_code_360LEA                      lea_code_360LEA
# 564                         county_Gates                      lea_code_370LEA
# 565               agency_lea_code_370LEA                      lea_code_370LEA
# 566                        county_Graham                      lea_code_380LEA
# 567               agency_lea_code_380LEA                      lea_code_380LEA
# 568                     county_Granville                      lea_code_390LEA
# 569               agency_lea_code_390LEA                      lea_code_390LEA
# 570                        county_Greene                      lea_code_400LEA
# 571               agency_lea_code_400LEA                      lea_code_400LEA
# 572                      county_Guilford                      lea_code_410LEA
# 573               agency_lea_code_410LEA                      lea_code_410LEA
# 574               agency_lea_code_420LEA                      lea_code_420LEA
# 575               agency_lea_code_421LEA                      lea_code_421LEA
# 576               agency_lea_code_422LEA                      lea_code_422LEA
# 577                       county_Harnett                      lea_code_430LEA
# 578               agency_lea_code_430LEA                      lea_code_430LEA
# 579                       county_Haywood                      lea_code_440LEA
# 580               agency_lea_code_440LEA                      lea_code_440LEA
# 581                     county_Henderson                      lea_code_450LEA
# 582               agency_lea_code_450LEA                      lea_code_450LEA
# 583                      county_Hertford                      lea_code_460LEA
# 584               agency_lea_code_460LEA                      lea_code_460LEA
# 585                          county_Hoke                      lea_code_470LEA
# 586               agency_lea_code_470LEA                      lea_code_470LEA
# 587                          county_Hyde                      lea_code_480LEA
# 588               agency_lea_code_480LEA                      lea_code_480LEA
# 589                       county_Iredell                      lea_code_490LEA
# 590               agency_lea_code_490LEA                      lea_code_490LEA
# ...
# 776               agency_lea_code_910LEA                         county_Vance
# 777               agency_lea_code_920LEA                          county_Wake
# 778               agency_lea_code_930LEA                        county_Warren
# 779               agency_lea_code_940LEA                    county_Washington
# 780               agency_lea_code_950LEA                       county_Watauga
# 781               agency_lea_code_960LEA                         county_Wayne
# 782               agency_lea_code_970LEA                        county_Wilkes
# 783               agency_lea_code_980LEA                        county_Wilson
# 784               agency_lea_code_990LEA                        county_Yadkin
# 785               agency_lea_code_995LEA                        county_Yancey
# 786            subgroup_list_ALL,BL7,SWD                     grade_span_KG:13
# 787               agency_lea_code_270LEA    subgroup_list_ALL,EDS,MU7,SWD,WH7
#
#      Correlation
# 0       0.994008
# 1       0.993680
# 2       0.966715
# 3       0.962805
# 4       0.953730
# 5       0.952985
# 6       1.000000
# 7       0.966763
# 8       0.960895
# 9       0.966763
# 10      0.960895
# 11      0.975456
# 12      1.000000
# 13      0.958225
# 14      0.993967
# 15      0.965325
# 16      0.999987
# 17      0.999992
# 18      0.999995
# 19      1.000000
# 20      0.999999
# 21      0.999990
# 22      0.999995
# 23      0.958643
# 24      0.997118
# 25      0.954705
# 26      0.985437
# 27      0.974440
# 28      0.976720
# 29      0.951042
# 30      0.970505
# 31      0.952277
# 32      0.950663
# 33      0.983286
# 34      0.970946
# 35      0.984278
# 36      0.977924
# 37      0.954429
# 38      0.987666
# 39      0.996283
# 40      0.959463
# 41      0.959856
# 42      0.972551
# 43      0.967849
# 44      0.986476
# 45      0.971440
# 46      0.973398
# 47      0.976355
# 48      0.968434
# 49      0.952335
# 50      0.953321
# 51      0.985411
# 52      0.957958
# 53      0.975742
# 54      0.952977
# 55      0.982404
# 56      0.980121
# 57      0.985845
# 58      0.995542
# 59      0.954179
# 60      0.959169
# 61      0.987580
# 62      0.955709
# 63      0.953889
# 64      0.976897
# 65      0.954731
# 66      0.982671
# 67      0.961053
# 68      0.968806
# 69      0.985479
# 70      0.978493
# 71      0.954373
# 72      0.986558
# 73      0.986119
# 74      0.953940
# 75      0.988692
# 76      0.993970
# 77      0.965992
# 78      0.974924
# 79      0.971080
# 80      0.973772
# 81      0.987773
# 82      0.960925
# 83      0.965133
# 84      0.956148
# 85      0.991633
# 86      0.976973
# 87      0.957493
# 88      0.962326
# 89      0.983388
# 90      0.961469
# 91      0.968862
# 92      0.952924
# 93      0.970477
# 94      0.955993
# 95      0.974804
# 96      0.955110
# 97      0.985224
# 98      0.952772
# 99      0.965870
# 100     0.954715
# 101     0.974132
# 102     0.964644
# 103     0.965081
# 104     0.963626
# 105     0.985150
# 106     0.958236
# 107     0.980936
# 108     0.955615
# 109     0.983085
# 110     0.992133
# 111     0.996944
# 112     0.989240
# 113     0.984385
# 114     0.972742
# 115     0.977051
# 116     0.975572
# 117     0.982277
# 118     0.978108
# 119     0.984114
# 120     0.951455
# 121     0.987230
# 122     0.993356
# 123     0.997425
# 124     0.992513
# 125     0.953018
# 126     0.986332
# 127     0.971220
# 128     0.974626
# 129     0.975101
# 130     0.985737
# 131     0.979581
# 132     0.981146
# 133     0.987768
# 134     0.987129
# 135     0.987397
# 136     0.995374
# 137     0.988662
# 138     0.985919
# 139     0.987432
# 140     0.972251
# 141     0.977028
# 142     0.954546
# 143     0.983902
# 144     0.974913
# 145     0.953965
# 146     0.983017
# 147     0.987599
# 148     0.988774
# 149     0.994081
# 150     0.985482
# 151     0.973262
# 152     0.973459
# 153     0.952280
# 154     0.986508
# 155     0.956832
# 156     0.959796
# 157     0.978605
# 158     0.979679
# 159     0.972139
# 160     0.951869
# 161     0.962633
# 162     0.986095
# 163     0.976762
# 164     0.957398
# 165     0.983321
# 166     0.975415
# 167     0.952052
# 168     0.983579
# 169     0.995624
# 170     0.997437
# 171     0.980396
# 172     0.966278
# 173     0.963567
# 174     0.968516
# 175     0.955740
# 176     0.953441
# 177     0.973951
# 178     0.975233
# 179     0.965966
# 180     0.961732
# 181     0.977230
# 182     0.959193
# 183     0.986174
# 184     0.996664
# 185     0.998040
# 186     0.964677
# 187     0.980849
# 188     0.970527
# 189     0.972152
# 190     0.969020
# 191     0.973976
# 192     0.969386
# 193     0.977611
# 194     0.979699
# 195     0.975949
# 196     0.975604
# 197     0.977351
# 198     0.951109
# 199     0.956047
# 200     0.985137
# 201     0.989623
# 202     0.989464
# 203     0.992923
# 204     0.987808
# 205     0.977270
# 206     0.960925
# 207     0.954782
# 208     0.968669
# 209     0.958539
# 210     0.972250
# 211     0.973019
# 212     0.951067
# 213     0.968745
# 214     0.970530
# 215     0.963870
# 216     0.952726
# 217     0.979559
# 218     0.991220
# 219     0.993691
# 220     0.958062
# 221     0.963078
# 222     0.959772
# 223     0.980589
# 224     0.951697
# 225     0.967229
# 226     0.968841
# 227     0.970157
# 228     0.965140
# 229     0.964872
# 230     0.964200
# 231     0.980178
# 232     0.963558
# 233     0.953496
# 234     0.977333
# 235     0.954689
# 236     0.971578
# 237     0.977807
# 238     0.995450
# 239     0.998495
# 240     0.999443
# 241     0.985467
# 242     0.958193
# 243     0.981133
# 244     0.955776
# 245     0.979990
# 246     0.977244
# 247     0.958689
# 248     0.951371
# 249     0.983477
# 250     0.983511
# 251     0.985239
# 252     0.955832
# 253     0.958503
# 254     0.961321
# 255     0.991759
# 256     0.999127
# 257     0.960425
# 258     0.981612
# 259     0.978813
# 260     0.954154
# 261     0.975859
# 262     0.973098
# 263     0.957886
# 264     0.979191
# 265     0.978088
# 266     0.981684
# 267     0.954581
# 268     0.989755
# 269     0.953581
# 270     0.954492
# 271     0.953939
# 272     0.957925
# 273     0.963560
# 274     0.971876
# 275     0.965598
# 276     0.954289
# 277     0.952000
# 278     0.950683
# 279     0.953888
# 280     0.950796
# 281     0.955071
# 282     0.966241
# 283     0.954403
# 284     0.955197
# 285     0.974017
# 286     0.966370
# 287     0.967018
# 288     0.956119
# 289     0.960644
# 290     0.967460
# 291     0.968834
# 292     0.953356
# 293     0.970970
# 294     0.952969
# 295     0.950503
# 296     0.994966
# 297     0.957100
# 298     0.997325
# 299     0.950278
# 300     0.995367
# 301     0.994808
# 302     0.954028
# 303     0.994180
# 304     0.966211
# 305     0.967645
# 306     0.956846
# 307     0.951099
# 308     0.955353
# 309     0.958483
# 310     0.955751
# 311     0.963267
# 312     0.951305
# 313     0.958869
# 314     0.951774
# 315     0.951873
# 316     0.997833
# 317     0.962799
# 318     0.950682
# 319     0.956196
# 320     0.950385
# 321     0.952772
# 322     0.959530
# 323     0.964123
# 324     0.955765
# 325     0.959345
# 326     0.958554
# 327     0.962832
# 328     0.955347
# 329     0.952821
# 330     0.953490
# 331     0.954915
# 332     0.953442
# 333     0.970039
# 334     0.961023
# 335     0.957973
# 336     0.962450
# 337     0.988171
# 338     0.954987
# 339     0.999214
# 340     0.952324
# 341     0.969915
# 342     0.951225
# 343     0.960236
# 344     0.952020
# 345     0.950931
# 346     0.960025
# 347     0.962039
# 348     0.958937
# 349     0.963408
# 350     0.993534
# 351     0.981694
# 352     0.955348
# 353     0.975793
# 354     0.950900
# 355     0.965782
# 356     0.985233
# 357     0.956282
# 358     0.964738
# 359     0.953673
# 360     0.951992
# 361     0.957150
# 362     0.954462
# 363     0.953703
# 364     0.950003
# 365     0.989587
# 366     0.983984
# 367     0.979547
# 368     0.995948
# 369     0.981052
# 370     0.976446
# 371     0.969503
# 372     0.954685
# 373     0.950711
# 374     0.952219
# 375     0.978302
# 376     0.993341
# 377     0.979950
# 378     0.996929
# 379     0.958680
# 380     0.965999
# 381     0.955358
# 382     0.993326
# 383     0.973594
# 384     0.995057
# 385     0.951338
# 386     0.963114
# 387     0.995904
# 388     0.995226
# 389     0.955563
# 390     0.955086
# 391     0.952689
# 392     0.962351
# 393     0.953269
# 394     0.952450
# 395     0.961082
# 396     0.972864
# 397     0.950202
# 398     0.965564
# 399     0.962154
# 400     0.961892
# 401     0.956914
# 402     0.981638
# 403     0.977633
# 404     0.969860
# 405     0.953743
# 406     0.956392
# 407     0.959299
# 408     0.965423
# 409     0.956723
# 410     0.952509
# 411     0.964776
# 412     0.955455
# 413     0.958202
# 414     0.952041
# 415     0.955438
# 416     0.950661
# 417     0.983216
# 418     0.979024
# 419     0.958655
# 420     0.950476
# 421     0.951879
# 422     0.975667
# 423     0.952044
# 424     0.970721
# 425     0.953533
# 426     0.960415
# 427     0.967552
# 428     0.958288
# 429     0.985737
# 430     0.959545
# 431     0.960904
# 432     0.989557
# 433     0.954199
# 434     0.989921
# 435     0.950344
# 436     0.955479
# 437     0.959156
# 438     0.994815
# 439     0.980341
# 440     0.994518
# 441     0.977660
# 442     0.993469
# 443     0.975557
# 444     0.998127
# 445     0.981653
# 446     0.997489
# 447     0.986728
# 448     0.999982
# 449     0.996034
# 450     0.973714
# 451     0.991865
# 452     0.985181
# 453     0.989419
# 454     0.986657
# 455     0.986248
# 456     0.984089
# 457     0.990918
# 458     0.996018
# 459     0.994305
# 460     0.953711
# 461     0.987649
# 462     0.958632
# 463     0.997494
# 464     0.988306
# 465     0.967010
# 466     0.974591
# 467     0.982406
# 468     0.982406
# 469     0.987860
# 470     0.981102
# 471     0.964228
# 472     0.970575
# 473     0.970575
# 474     0.969258
# 475     0.965432
# 476     0.973702
# 477     0.973702
# 478     1.000000
# 479     0.962051
# 480     0.987426
# 481     0.987426
# 482     1.000000
# 483     1.000000
# 484     1.000000
# 485     1.000000
# 486     1.000000
# 487     1.000000
# 488     0.961220
# 489     0.955726
# 490     1.000000
# 491     1.000000
# 492     1.000000
# 493     1.000000
# 494     1.000000
# 495     1.000000
# 496     1.000000
# 497     1.000000
# 498     1.000000
# 499     1.000000
# 500     1.000000
# 501     1.000000
# 502     1.000000
# 503     1.000000
# 504     1.000000
# 505     1.000000
# 506     1.000000
# 507     1.000000
# 508     1.000000
# 509     1.000000
# 510     1.000000
# 511     1.000000
# 512     0.952729
# 513     1.000000
# 514     1.000000
# 515     1.000000
# 516     1.000000
# 517     1.000000
# 518     1.000000
# 519     1.000000
# 520     1.000000
# 521     1.000000
# 522     1.000000
# 523     1.000000
# 524     1.000000
# 525     1.000000
# 526     1.000000
# 527     1.000000
# 528     1.000000
# 529     1.000000
# 530     1.000000
# 531     1.000000
# 532     1.000000
# 533     1.000000
# 534     1.000000
# 535     1.000000
# 536     1.000000
# 537     1.000000
# 538     1.000000
# 539     1.000000
# 540     1.000000
# 541     1.000000
# 542     1.000000
# 543     1.000000
# 544     1.000000
# 545     1.000000
# 546     1.000000
# 547     1.000000
# 548     1.000000
# 549     1.000000
# 550     1.000000
# 551     1.000000
# 552     1.000000
# 553     1.000000
# 554     1.000000
# 555     1.000000
# 556     1.000000
# 557     1.000000
# 558     1.000000
# 559     1.000000
# 560     1.000000
# 561     1.000000
# 562     1.000000
# 563     1.000000
# 564     1.000000
# 565     1.000000
# 566     1.000000
# 567     1.000000
# 568     1.000000
# 569     1.000000
# 570     1.000000
# 571     1.000000
# 572     1.000000
# 573     1.000000
# 574     1.000000
# 575     1.000000
# 576     1.000000
# 577     1.000000
# 578     1.000000
# 579     1.000000
# 580     1.000000
# 581     1.000000
# 582     1.000000
# 583     1.000000
# 584     1.000000
# 585     1.000000
# 586     1.000000
# 587     1.000000
# 588     1.000000
# 589     0.956689
# 590     1.000000
# 591     1.000000
# 592     1.000000
# 593     1.000000
# 594     1.000000
# 595     1.000000
# 596     1.000000
# 597     1.000000
# 598     1.000000
# 599     1.000000
# 600     1.000000
# 601     1.000000
# 602     1.000000
# 603     1.000000
# 604     1.000000
# 605     1.000000
# 606     1.000000
# 607     1.000000
# 608     1.000000
# 609     1.000000
# 610     1.000000
# 611     1.000000
# 612     1.000000
# 613     1.000000
# 614     1.000000
# 615     1.000000
# 616     1.000000
# 617     1.000000
# 618     1.000000
# 619     1.000000
# 620     1.000000
# 621     1.000000
# 622     1.000000
# 623     1.000000
# 624     1.000000
# 625     1.000000
# 626     1.000000
# 627     1.000000
# 628     1.000000
# 629     1.000000
# 630     1.000000
# 631     1.000000
# 632     1.000000
# 633     1.000000
# 634     1.000000
# 635     1.000000
# 636     1.000000
# 637     1.000000
# 638     1.000000
# 639     1.000000
# 640     1.000000
# 641     1.000000
# 642     1.000000
# 643     1.000000
# 644     1.000000
# 645     1.000000
# 646     1.000000
# 647     1.000000
# 648     1.000000
# 649     1.000000
# 650     1.000000
# 651     1.000000
# 652     1.000000
# 653     1.000000
# 654     1.000000
# 655     1.000000
# 656     1.000000
# 657     1.000000
# 658     1.000000
# 659     1.000000
# 660     1.000000
# 661     1.000000
# 662     1.000000
# 663     1.000000
# 664     1.000000
# 665     1.000000
# 666     1.000000
# 667     1.000000
# 668     1.000000
# 669     1.000000
# 670     1.000000
# 671     1.000000
# 672     1.000000
# 673     1.000000
# 674     1.000000
# 675     1.000000
# 676     1.000000
# 677     1.000000
# 678     1.000000
# 679     1.000000
# 680     1.000000
# 681     1.000000
# 682     1.000000
# 683     1.000000
# 684     1.000000
# 685     1.000000
# 686     1.000000
# 687     1.000000
# 688     1.000000
# 689     1.000000
# 690     1.000000
# 691     1.000000
# 692     1.000000
# 693     1.000000
# 694     1.000000
# 695     1.000000
# 696     1.000000
# 697     1.000000
# 698     1.000000
# 699     1.000000
# 700     1.000000
# 701     1.000000
# 702     1.000000
# 703     1.000000
# 704     1.000000
# 705     0.952729
# 706     1.000000
# 707     1.000000
# 708     1.000000
# 709     1.000000
# 710     1.000000
# 711     1.000000
# 712     1.000000
# 713     1.000000
# 714     1.000000
# 715     1.000000
# 716     1.000000
# 717     1.000000
# 718     1.000000
# 719     1.000000
# 720     1.000000
# 721     1.000000
# 722     1.000000
# 723     1.000000
# 724     1.000000
# 725     1.000000
# 726     1.000000
# 727     1.000000
# 728     1.000000
# 729     1.000000
# 730     1.000000
# 731     1.000000
# 732     1.000000
# 733     1.000000
# 734     1.000000
# 735     1.000000
# 736     1.000000
# 737     1.000000
# 738     0.956689
# 739     1.000000
# 740     1.000000
# 741     1.000000
# 742     1.000000
# 743     1.000000
# 744     1.000000
# 745     1.000000
# 746     1.000000
# 747     1.000000
# 748     1.000000
# 749     1.000000
# 750     1.000000
# 751     1.000000
# 752     1.000000
# 753     1.000000
# 754     1.000000
# 755     1.000000
# 756     1.000000
# 757     1.000000
# 758     1.000000
# 759     1.000000
# 760     1.000000
# 761     1.000000
# 762     1.000000
# 763     1.000000
# 764     1.000000
# 765     1.000000
# 766     1.000000
# 767     1.000000
# 768     1.000000
# 769     1.000000
# 770     1.000000
# 771     1.000000
# 772     1.000000
# 773     1.000000
# 774     1.000000
# 775     1.000000
# 776     1.000000
# 777     1.000000
# 778     1.000000
# 779     1.000000
# 780     1.000000
# 781     1.000000
# 782     1.000000
# 783     1.000000
# 784     1.000000
# 785     1.000000
# 786     1.000000
# 787     1.000000

# %%
#The old way
#print('Dropping the following ', str(len(to_drop)), ' highly correlated fields.')
#to_drop

# Comparing highly correlated unique field names in field 1 vs field 2 list above will allow you to 
# remove the least amount of fields possible.  
#len(cf['Field1'].unique())
#len(cf['Field2'].unique())

print('Dropping the following ', str(len(cf['Field2'].unique())), ' highly correlated, unique fields.')
cf['Field2'].unique()
# Out:
# Dropping the following  503  highly correlated, unique fields.
# array(['IndianPct', 'AsianPct', 'HispanicPct', 'WhitePct', 'MinorityPct',
#        'IndianMalePct', 'pct_ALL_ELP', 'pct_prof_6gr_irm',
#        'pct_met_Math Grades 3-8_PART', 'pct_met_Science Grades 5&8_PART',
#        'pct_Math Grades 3-8_ALL_PART_DET',
#        'pct_Math Grades 3-8_BL7_PART_DET',
#        'pct_Math Grades 3-8_EDS_PART_DET',
#        'pct_Math Grades 3-8_ELS_PART_DET',
#        'pct_Math Grades 3-8_HI7_PART_DET',
#        'pct_Math Grades 3-8_SWD_PART_DET',
#        'pct_Math Grades 3-8_WH7_PART_DET',
#        'pct_Science Grades 5&8_WH7_PART_DET', 'pct_CCR_EOG_06_AIG_PC',
#        'pct_CCR_EOG_06_ALL_PC', 'pct_CCR_EOG_06_BL7_PC',
#        'pct_CCR_EOG_06_EDS_PC', 'pct_CCR_EOG_06_ELS_PC',
#        'pct_CCR_EOG_06_FEM_PC', 'pct_CCR_EOG_06_HI7_PC',
#        'pct_CCR_EOG_06_MALE_PC', 'pct_CCR_EOG_06_MU7_PC',
#        'pct_CCR_EOG_06_SWD_PC', 'pct_CCR_EOG_06_WH7_PC',
#        'pct_CCR_EOG_07_AIG_PC', 'pct_CCR_EOG_07_ALL_PC',
#        'pct_CCR_EOG_07_BL7_PC', 'pct_CCR_EOG_07_EDS_PC',
#        'pct_CCR_EOG_07_ELS_PC', 'pct_CCR_EOG_07_FEM_PC',
#        'pct_CCR_EOG_07_HI7_PC', 'pct_CCR_EOG_07_MALE_PC',
#        'pct_CCR_EOG_07_MU7_PC', 'pct_CCR_EOG_07_WH7_PC',
#        'pct_CCR_EOG_08_AIG_PC', 'pct_CCR_EOG_08_ALL_PC',
#        'pct_CCR_EOG_08_BL7_PC', 'pct_CCR_EOG_08_EDS_PC',
#        'pct_CCR_EOG_08_ELS_PC', 'pct_CCR_EOG_08_FEM_PC',
#        'pct_CCR_EOG_08_HI7_PC', 'pct_CCR_EOG_08_MALE_PC',
#        'pct_CCR_EOG_08_MU7_PC', 'pct_CCR_EOG_08_SWD_PC',
#        'pct_CCR_EOG_08_WH7_PC', 'pct_CCR_EOG_ALL_AIG_PC',
#        'pct_CCR_EOG_ALL_ALL_PC', 'pct_CCR_EOG_ALL_AS7_PC',
#        'pct_CCR_EOG_ALL_BL7_PC', 'pct_CCR_EOG_ALL_EDS_PC',
#        'pct_CCR_EOG_ALL_ELS_PC', 'pct_CCR_EOG_ALL_FEM_PC',
#        'pct_CCR_EOG_ALL_HI7_PC', 'pct_CCR_EOG_ALL_MALE_PC',
#        'pct_CCR_EOG_ALL_MU7_PC', 'pct_CCR_EOG_ALL_SWD_PC',
#        'pct_CCR_EOG_ALL_WH7_PC', 'pct_CCR_MA_06_AIG_PC',
#        'pct_CCR_MA_06_ALL_PC', 'pct_CCR_MA_06_BL7_PC',
#        'pct_CCR_MA_06_EDS_PC', 'pct_CCR_MA_06_ELS_PC',
#        'pct_CCR_MA_06_FEM_PC', 'pct_CCR_MA_06_HI7_PC',
#        'pct_CCR_MA_06_MALE_PC', 'pct_CCR_MA_06_SWD_PC',
#        'pct_CCR_MA_06_WH7_PC', 'pct_CCR_MA_07_AIG_PC',
#        'pct_CCR_MA_07_ALL_PC', 'pct_CCR_MA_07_BL7_PC',
#        'pct_CCR_MA_07_EDS_PC', 'pct_CCR_MA_07_ELS_PC',
#        'pct_CCR_MA_07_FEM_PC', 'pct_CCR_MA_07_HI7_PC',
#        'pct_CCR_MA_07_MALE_PC', 'pct_CCR_MA_07_WH7_PC',
#        'pct_CCR_MA_08_AIG_PC', 'pct_CCR_MA_08_ALL_PC',
#        'pct_CCR_MA_08_BL7_PC', 'pct_CCR_MA_08_EDS_PC',
#        'pct_CCR_MA_08_FEM_PC', 'pct_CCR_MA_08_HI7_PC',
#        'pct_CCR_MA_08_MALE_PC', 'pct_CCR_MA_08_WH7_PC',
#        'pct_CCR_MA_ALL_AIG_PC', 'pct_CCR_MA_ALL_ALL_PC',
#        'pct_CCR_MA_ALL_BL7_PC', 'pct_CCR_MA_ALL_EDS_PC',
#        'pct_CCR_MA_ALL_ELS_PC', 'pct_CCR_MA_ALL_FEM_PC',
#        'pct_CCR_MA_ALL_HI7_PC', 'pct_CCR_MA_ALL_MALE_PC',
#        'pct_CCR_MA_ALL_MU7_PC', 'pct_CCR_MA_ALL_SWD_PC',
#        'pct_CCR_MA_ALL_WH7_PC', 'pct_CCR_RD_06_AIG_PC',
#        'pct_CCR_RD_06_ALL_PC', 'pct_CCR_RD_06_BL7_PC',
#        'pct_CCR_RD_06_EDS_PC', 'pct_CCR_RD_06_ELS_PC',
#        'pct_CCR_RD_06_FEM_PC', 'pct_CCR_RD_06_HI7_PC',
#        'pct_CCR_RD_06_MALE_PC', 'pct_CCR_RD_06_WH7_PC',
#        'pct_CCR_RD_07_AIG_PC', 'pct_CCR_RD_07_ALL_PC',
#        'pct_CCR_RD_07_BL7_PC', 'pct_CCR_RD_07_EDS_PC',
#        'pct_CCR_RD_07_ELS_PC', 'pct_CCR_RD_07_FEM_PC',
#        'pct_CCR_RD_07_HI7_PC', 'pct_CCR_RD_07_MALE_PC',
#        'pct_CCR_RD_07_WH7_PC', 'pct_CCR_RD_08_AIG_PC',
#        'pct_CCR_RD_08_ALL_PC', 'pct_CCR_RD_08_BL7_PC',
#        'pct_CCR_RD_08_EDS_PC', 'pct_CCR_RD_08_FEM_PC',
#        'pct_CCR_RD_08_HI7_PC', 'pct_CCR_RD_08_MALE_PC',
#        'pct_CCR_RD_08_WH7_PC', 'pct_CCR_RD_ALL_AIG_PC',
#        'pct_CCR_RD_ALL_ALL_PC', 'pct_CCR_RD_ALL_BL7_PC',
#        'pct_CCR_RD_ALL_EDS_PC', 'pct_CCR_RD_ALL_ELS_PC',
#        'pct_CCR_RD_ALL_FEM_PC', 'pct_CCR_RD_ALL_HI7_PC',
#        'pct_CCR_RD_ALL_MALE_PC', 'pct_CCR_RD_ALL_MU7_PC',
#        'pct_CCR_RD_ALL_WH7_PC', 'pct_CCR_SC_08_AIG_PC',
#        'pct_CCR_SC_08_ALL_PC', 'pct_CCR_SC_08_BL7_PC',
#        'pct_CCR_SC_08_EDS_PC', 'pct_CCR_SC_08_ELS_PC',
#        'pct_CCR_SC_08_FEM_PC', 'pct_CCR_SC_08_HI7_PC',
#        'pct_CCR_SC_08_MALE_PC', 'pct_CCR_SC_08_SWD_PC',
#        'pct_CCR_SC_08_WH7_PC', 'pct_CCR_SC_ALL_AIG_PC',
#        'pct_CCR_SC_ALL_ALL_PC', 'pct_CCR_SC_ALL_BL7_PC',
#        'pct_CCR_SC_ALL_EDS_PC', 'pct_CCR_SC_ALL_ELS_PC',
#        'pct_CCR_SC_ALL_FEM_PC', 'pct_CCR_SC_ALL_HI7_PC',
#        'pct_CCR_SC_ALL_MALE_PC', 'pct_CCR_SC_ALL_SWD_PC',
#        'pct_CCR_SC_ALL_WH7_PC', 'pct_GLP_EOG_06_ALL_PC',
#        'pct_GLP_EOG_06_EDS_PC', 'pct_GLP_EOG_06_FEM_PC',
#        'pct_GLP_EOG_07_ALL_PC', 'pct_GLP_EOG_07_FEM_PC',
#        'pct_GLP_EOG_07_HI7_PC', 'pct_GLP_EOG_08_ALL_PC',
#        'pct_GLP_EOG_08_BL7_PC', 'pct_GLP_EOG_08_EDS_PC',
#        'pct_GLP_EOG_08_HI7_PC', 'pct_GLP_EOG_ALL_ALL_PC',
#        'pct_GLP_EOG_ALL_EDS_PC', 'pct_GLP_EOG_ALL_FEM_PC',
#        'pct_GLP_EOG_ALL_MALE_PC', 'pct_GLP_MA_06_AIG_PC',
#        'pct_GLP_MA_06_WH7_PC', 'pct_GLP_MA_07_AIG_PC',
#        'pct_GLP_MA_07_WH7_PC', 'pct_GLP_MA_08_AIG_PC',
#        'pct_GLP_MA_08_WH7_PC', 'pct_GLP_MA_ALL_AIG_PC',
#        'pct_GLP_MA_ALL_ALL_PC', 'pct_GLP_RD_06_ALL_PC',
#        'pct_GLP_RD_06_MALE_PC', 'pct_GLP_RD_07_ALL_PC',
#        'pct_GLP_RD_07_BL7_PC', 'pct_GLP_RD_07_EDS_PC',
#        'pct_GLP_RD_07_ELS_PC', 'pct_GLP_RD_07_FEM_PC',
#        'pct_GLP_RD_07_HI7_PC', 'pct_GLP_RD_07_MALE_PC',
#        'pct_GLP_RD_07_WH7_PC', 'pct_GLP_RD_08_AIG_PC',
#        'pct_GLP_RD_08_ALL_PC', 'pct_GLP_RD_08_FEM_PC',
#        'pct_GLP_RD_08_MALE_PC', 'pct_GLP_RD_08_WH7_PC',
#        'pct_GLP_RD_ALL_ALL_PC', 'pct_GLP_RD_ALL_BL7_PC',
#        'pct_GLP_RD_ALL_EDS_PC', 'pct_GLP_RD_ALL_FEM_PC',
#        'pct_GLP_RD_ALL_MALE_PC', 'pct_GLP_SC_08_BL7_PC',
#        'pct_GLP_SC_08_ELS_PC', 'pct_GLP_SC_ALL_ALL_PC',
#        'pct_GLP_SC_ALL_FEM_PC', 'pct_L1_ALL_ALL_ALL_PC',
#        'pct_L1_ALL_ALL_HMS_PC', 'pct_L1_ALL_ALL_MALE_PC',
#        'pct_L1_EOG_ALL_ALL_PC', 'pct_L1_MA_08_ELS_PC',
#        'pct_L2_ALL_ALL_AS7_PC', 'pct_L2_ALL_ALL_BL7_PC',
#        'pct_L2_ALL_ALL_ELS_PC', 'pct_L2_EOG_ALL_ALL_PC',
#        'pct_L3_ALL_ALL_BL7_PC', 'pct_L3_ALL_ALL_ELS_PC',
#        'pct_L3_ALL_ALL_MU7_PC', 'pct_L3_ALL_ALL_SWD_PC',
#        'pct_L4_ALL_ALL_AIG_PC', 'pct_L4_ALL_ALL_ALL_PC',
#        'pct_L4_ALL_ALL_AS7_PC', 'pct_L4_ALL_ALL_BL7_PC',
#        'pct_L4_ALL_ALL_EDS_PC', 'pct_L4_ALL_ALL_ELS_PC',
#        'pct_L4_ALL_ALL_FEM_PC', 'pct_L4_ALL_ALL_HI7_PC',
#        'pct_L4_ALL_ALL_MU7_PC', 'pct_L4_EOG_07_ALL_PC',
#        'pct_L4_EOG_ALL_ALL_PC', 'pct_L4_EOG_ALL_EDS_PC',
#        'pct_L4_EOG_ALL_FEM_PC', 'pct_L4_MA_ALL_ALL_PC',
#        'pct_L4_RD_ALL_ALL_PC', 'pct_L4_SC_08_BL7_PC',
#        'pct_L5_ALL_ALL_AIG_PC', 'pct_L5_ALL_ALL_ALL_PC',
#        'pct_L5_ALL_ALL_AS7_PC', 'pct_L5_ALL_ALL_EDS_PC',
#        'pct_L5_ALL_ALL_FEM_PC', 'pct_L5_ALL_ALL_HI7_PC',
#        'pct_L5_ALL_ALL_MALE_PC', 'pct_L5_ALL_ALL_MU7_PC',
#        'pct_L5_ALL_ALL_WH7_PC', 'pct_L5_EOG_06_ALL_PC',
#        'pct_L5_EOG_06_MALE_PC', 'pct_L5_EOG_06_WH7_PC',
#        'pct_L5_EOG_07_ALL_PC', 'pct_L5_EOG_07_FEM_PC',
#        'pct_L5_EOG_07_MALE_PC', 'pct_L5_EOG_07_WH7_PC',
#        'pct_L5_EOG_08_ALL_PC', 'pct_L5_EOG_ALL_ALL_PC',
#        'pct_L5_EOG_ALL_FEM_PC', 'pct_L5_EOG_ALL_MALE_PC',
#        'pct_L5_EOG_ALL_WH7_PC', 'pct_L5_MA_07_ALL_PC',
#        'pct_L5_MA_08_ALL_PC', 'pct_L5_MA_ALL_ALL_PC',
#        'pct_L5_RD_ALL_ALL_PC', 'pct_L5_SC_08_ALL_PC',
#        'pct_L5_SC_08_BL7_PC', 'pct_L5_SC_08_FEM_PC',
#        'pct_L5_SC_08_HI7_PC', 'pct_L5_SC_08_MALE_PC',
#        'pct_L5_SC_ALL_ALL_PC', 'ma_score', 'rd_score', 'sc_score',
#        'ach_score', 'spg_score', 'ma_spg_score', 'aaa_score_ALL_SPG2',
#        'aaa_score_BL7_SPG2', 'aaa_score_EDS_SPG2', 'aaa_score_ELS_SPG2',
#        'aaa_score_HI7_SPG2', 'aaa_score_MU7_SPG2', 'aaa_score_SWD_SPG2',
#        'aaa_score_WH7_SPG2', 'ach_score_ALL_SPG2', 'ach_score_BL7_SPG2',
#        'ach_score_EDS_SPG2', 'ach_score_ELS_SPG2', 'ach_score_HI7_SPG2',
#        'ach_score_MU7_SPG2', 'ach_score_WH7_SPG2', 'avg_student_num',
#        'pct_ALL_CHRON_ABSENT', 'highqual_class_pct_M', 'arre_per1000_ALL',
#        'arre_per1000_BL7', 'arre_per1000_EDS', 'arre_per1000_ELS',
#        'arre_per1000_MALE', 'crime_per1000_ELS', 'exp_per1000_ALL',
#        'exp_per1000_BL7', 'exp_per1000_EDS', 'iss_per1000_ALL',
#        'lts_per1000_ALL', 'lea_code_020LEA', 'lea_code_030LEA',
#        'lea_code_040LEA', 'lea_code_050LEA', 'lea_code_060LEA',
#        'lea_code_070LEA', 'lea_code_080LEA', 'lea_code_090LEA',
#        'lea_code_100LEA', 'lea_code_110LEA', 'lea_code_111LEA',
#        'lea_code_120LEA', 'lea_code_130LEA', 'lea_code_132LEA',
#        'lea_code_140LEA', 'lea_code_150LEA', 'lea_code_160LEA',
#        'lea_code_170LEA', 'lea_code_180LEA', 'lea_code_181LEA',
#        'lea_code_182LEA', 'lea_code_190LEA', 'lea_code_200LEA',
#        'lea_code_210LEA', 'lea_code_220LEA', 'lea_code_230LEA',
#        'lea_code_240LEA', 'lea_code_241LEA', 'lea_code_250LEA',
#        'lea_code_260LEA', 'lea_code_270LEA', 'lea_code_280LEA',
#        'lea_code_290LEA', 'lea_code_291LEA', 'lea_code_292LEA',
#        'lea_code_300LEA', 'lea_code_310LEA', 'lea_code_320LEA',
#        'lea_code_330LEA', 'lea_code_340LEA', 'lea_code_350LEA',
#        'lea_code_360LEA', 'lea_code_370LEA', 'lea_code_380LEA',
#        'lea_code_390LEA', 'lea_code_400LEA', 'lea_code_410LEA',
#        'lea_code_420LEA', 'lea_code_421LEA', 'lea_code_422LEA',
#        'lea_code_430LEA', 'lea_code_440LEA', 'lea_code_450LEA',
#        'lea_code_460LEA', 'lea_code_470LEA', 'lea_code_480LEA',
#        'lea_code_490LEA', 'lea_code_491LEA', 'lea_code_500LEA',
#        'lea_code_510LEA', 'lea_code_520LEA', 'lea_code_530LEA',
#        'lea_code_540LEA', 'lea_code_550LEA', 'lea_code_560LEA',
#        'lea_code_570LEA', 'lea_code_580LEA', 'lea_code_590LEA',
#        'lea_code_600LEA', 'lea_code_610LEA', 'lea_code_620LEA',
#        'lea_code_630LEA', 'lea_code_640LEA', 'lea_code_650LEA',
#        'lea_code_660LEA', 'lea_code_670LEA', 'lea_code_680LEA',
#        'lea_code_681LEA', 'lea_code_690LEA', 'lea_code_700LEA',
#        'lea_code_710LEA', 'lea_code_720LEA', 'lea_code_730LEA',
#        'lea_code_740LEA', 'lea_code_750LEA', 'lea_code_760LEA',
#        'lea_code_761LEA', 'lea_code_770LEA', 'lea_code_780LEA',
#        'lea_code_790LEA', 'lea_code_800LEA', 'lea_code_810LEA',
#        'lea_code_820LEA', 'lea_code_821LEA', 'lea_code_830LEA',
#        'lea_code_840LEA', 'lea_code_850LEA', 'lea_code_860LEA',
#        'lea_code_861LEA', 'lea_code_862LEA', 'lea_code_870LEA',
#        'lea_code_880LEA', 'lea_code_890LEA', 'lea_code_900LEA',
#        'lea_code_910LEA', 'lea_code_920LEA', 'lea_code_930LEA',
#        'lea_code_940LEA', 'lea_code_950LEA', 'lea_code_960LEA',
#        'lea_code_970LEA', 'lea_code_980LEA', 'lea_code_990LEA',
#        'lea_code_995LEA', 'county_Alexander', 'county_Alleghany',
#        'county_Anson', 'county_Ashe', 'county_Avery', 'county_Beaufort',
#        'county_Bertie', 'county_Bladen', 'county_Brunswick',
#        'county_Burke', 'county_Cabarrus', 'county_Caldwell',
#        'county_Camden', 'county_Carteret', 'county_Caswell',
#        'county_Chatham', 'county_Cherokee', 'county_Chowan',
#        'county_Clay', 'county_Cleveland', 'county_Craven',
#        'county_Cumberland', 'county_Currituck', 'county_Dare',
#        'county_Davie', 'county_Duplin', 'county_Durham',
#        'county_Edgecombe', 'county_Forsyth', 'county_Franklin',
#        'county_Gaston', 'county_Gates', 'county_Graham',
#        'county_Granville', 'county_Greene', 'county_Guilford',
#        'county_Harnett', 'county_Haywood', 'county_Henderson',
#        'county_Hertford', 'county_Hoke', 'county_Hyde', 'county_Iredell',
#        'county_Jackson', 'county_Johnston', 'county_Jones', 'county_Lee',
#        'county_Lenoir', 'county_Lincoln', 'county_Macon',
#        'county_Madison', 'county_Martin', 'county_McDowell',
#        'county_Mecklenburg', 'county_Mitchell', 'county_Montgomery',
#        'county_Moore', 'county_Nash', 'county_New Hanover',
#        'county_Northampton', 'county_Onslow', 'county_Pamlico',
#        'county_Pasquotank', 'county_Pender', 'county_Perquimans',
#        'county_Person', 'county_Pitt', 'county_Polk', 'county_Richmond',
#        'county_Robeson', 'county_Rockingham', 'county_Rowan',
#        'county_Rutherford', 'county_Scotland', 'county_Stanly',
#        'county_Stokes', 'county_Swain', 'county_Transylvania',
#        'county_Tyrrell', 'county_Union', 'county_Vance', 'county_Wake',
#        'county_Warren', 'county_Washington', 'county_Watauga',
#        'county_Wayne', 'county_Wilkes', 'county_Wilson', 'county_Yadkin',
#        'county_Yancey', 'grade_span_KG:13',
#        'subgroup_list_ALL,EDS,MU7,SWD,WH7'], dtype=object)

# %%
#Check columns before drop 
print('\r\n*********Before: Dropping Highly Correlated Fields*************************************')
schoolData.info(verbose=False)

# Drop the highly correlated features from our training data 
#schoolData = schoolData.drop(to_drop, axis=1)
schoolData = schoolData.drop(cf['Field2'], axis=1)

#Check columns after drop 
print('\r\n*********After: Dropping Highly Correlated Fields**************************************')
schoolData.info(verbose=False)
# Out:
# *********Before: Dropping Highly Correlated Fields*************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 660 entries, 2 to 805
# Columns: 1702 entries, IndianPct to agency_lea_code_995LEA
# dtypes: float64(1215), uint8(487)
# memory usage: 6.4 MB
#
# *********After: Dropping Highly Correlated Fields**************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 660 entries, 2 to 805
# Columns: 1199 entries, BlackPct to agency_lea_code_995LEA
# dtypes: float64(918), uint8(281)
# memory usage: 4.8 MB

# %%
#Restore the unit_code before saving
schoolData['agency_code'] = agency_code
#Save the final dataset to a .csv file
schoolData.to_csv(outputDir + inputFileName + '_ML.csv', sep=',', index=False)

# %%
print('*********FINAL DATASET DETAILS*********************************************************\r\n')
schoolData.info(verbose=True)
# Out:
# *********FINAL DATASET DETAILS*********************************************************
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 660 entries, 2 to 805
# Data columns (total 1200 columns):
#  #    Column                                                                                                            Dtype
# ---   ------                                                                                                            -----
#  0    BlackPct                                                                                                          float64
#  1    PacificIslandPct                                                                                                  float64
#  2    TwoOrMorePct                                                                                                      float64
#  3    AsianMalePct                                                                                                      float64
#  4    HispanicMalePct                                                                                                   float64
#  5    BlackMalePct                                                                                                      float64
#  6    WhiteMalePct                                                                                                      float64
#  7    PacificIslandMalePct                                                                                              float64
#  8    TwoOrMoreMalePct                                                                                                  float64
#  9    MinorityMalePct                                                                                                   float64
#  10   IndianFemalePct                                                                                                   float64
#  11   AsianFemalePct                                                                                                    float64
#  12   HispanicFemalePct                                                                                                 float64
#  13   BlackFemalePct                                                                                                    float64
#  14   WhiteFemalePct                                                                                                    float64
#  15   MinorityFemalePct                                                                                                 float64
#  16   PacificIslandFemalePct                                                                                            float64
#  17   TwoOrMoreFemalePct                                                                                                float64
#  18   pct_eds                                                                                                           float64
#  19   pct_EDS_ELP                                                                                                       float64
#  20   pct_ELS_ELP                                                                                                       float64
#  21   pct_HI7_ELP                                                                                                       float64
#  22   pct_MALE_ELP                                                                                                      float64
#  23   pct_met_Math Grades 3-8_LTG                                                                                       float64
#  24   pct_met_Reading Grades 3-8_LTG                                                                                    float64
#  25   pct_met_Total Targets_LTG                                                                                         float64
#  26   pct_met_Reading Grades 3-8_PART                                                                                   float64
#  27   pct_met_Total Targets_PART                                                                                        float64
#  28   pct_Reading Grades 3-8_ALL_PART_DET                                                                               float64
#  29   pct_Reading Grades 3-8_BL7_PART_DET                                                                               float64
#  30   pct_Reading Grades 3-8_EDS_PART_DET                                                                               float64
#  31   pct_Reading Grades 3-8_ELS_PART_DET                                                                               float64
#  32   pct_Reading Grades 3-8_HI7_PART_DET                                                                               float64
#  33   pct_Reading Grades 3-8_SWD_PART_DET                                                                               float64
#  34   pct_Reading Grades 3-8_WH7_PART_DET                                                                               float64
#  35   pct_Science Grades 5&8_ALL_PART_DET                                                                               float64
#  36   pct_Science Grades 5&8_BL7_PART_DET                                                                               float64
#  37   pct_Science Grades 5&8_EDS_PART_DET                                                                               float64
#  38   pct_CCR_EOG_07_SWD_PC                                                                                             float64
#  39   pct_CCR_MA_07_SWD_PC                                                                                              float64
#  40   pct_CCR_RD_06_SWD_PC                                                                                              float64
#  41   pct_CCR_RD_07_SWD_PC                                                                                              float64
#  42   pct_CCR_RD_08_SWD_PC                                                                                              float64
#  43   pct_CCR_RD_ALL_SWD_PC                                                                                             float64
#  44   pct_GLP_EOG_06_AIG_PC                                                                                             float64
#  45   pct_GLP_EOG_06_BL7_PC                                                                                             float64
#  46   pct_GLP_EOG_06_ELS_PC                                                                                             float64
#  47   pct_GLP_EOG_06_HI7_PC                                                                                             float64
#  48   pct_GLP_EOG_06_MALE_PC                                                                                            float64
#  49   pct_GLP_EOG_06_MU7_PC                                                                                             float64
#  50   pct_GLP_EOG_06_SWD_PC                                                                                             float64
#  51   pct_GLP_EOG_06_WH7_PC                                                                                             float64
#  52   pct_GLP_EOG_07_AIG_PC                                                                                             float64
#  53   pct_GLP_EOG_07_BL7_PC                                                                                             float64
#  54   pct_GLP_EOG_07_EDS_PC                                                                                             float64
#  55   pct_GLP_EOG_07_ELS_PC                                                                                             float64
#  56   pct_GLP_EOG_07_MALE_PC                                                                                            float64
#  57   pct_GLP_EOG_07_MU7_PC                                                                                             float64
#  58   pct_GLP_EOG_07_SWD_PC                                                                                             float64
#  59   pct_GLP_EOG_07_WH7_PC                                                                                             float64
#  60   pct_GLP_EOG_08_AIG_PC                                                                                             float64
#  61   pct_GLP_EOG_08_ELS_PC                                                                                             float64
#  62   pct_GLP_EOG_08_FEM_PC                                                                                             float64
#  63   pct_GLP_EOG_08_MALE_PC                                                                                            float64
#  64   pct_GLP_EOG_08_MU7_PC                                                                                             float64
#  65   pct_GLP_EOG_08_SWD_PC                                                                                             float64
#  66   pct_GLP_EOG_08_WH7_PC                                                                                             float64
#  67   pct_GLP_EOG_ALL_AIG_PC                                                                                            float64
#  68   pct_GLP_EOG_ALL_AS7_PC                                                                                            float64
#  69   pct_GLP_EOG_ALL_BL7_PC                                                                                            float64
#  70   pct_GLP_EOG_ALL_ELS_PC                                                                                            float64
#  71   pct_GLP_EOG_ALL_HI7_PC                                                                                            float64
#  72   pct_GLP_EOG_ALL_MU7_PC                                                                                            float64
#  73   pct_GLP_EOG_ALL_SWD_PC                                                                                            float64
#  74   pct_GLP_EOG_ALL_WH7_PC                                                                                            float64
#  75   pct_GLP_MA_06_ALL_PC                                                                                              float64
#  76   pct_GLP_MA_06_BL7_PC                                                                                              float64
#  77   pct_GLP_MA_06_EDS_PC                                                                                              float64
#  78   pct_GLP_MA_06_ELS_PC                                                                                              float64
#  79   pct_GLP_MA_06_FEM_PC                                                                                              float64
#  80   pct_GLP_MA_06_HI7_PC                                                                                              float64
#  81   pct_GLP_MA_06_MALE_PC                                                                                             float64
#  82   pct_GLP_MA_06_SWD_PC                                                                                              float64
#  83   pct_GLP_MA_07_ALL_PC                                                                                              float64
#  84   pct_GLP_MA_07_BL7_PC                                                                                              float64
#  85   pct_GLP_MA_07_EDS_PC                                                                                              float64
#  86   pct_GLP_MA_07_ELS_PC                                                                                              float64
#  87   pct_GLP_MA_07_FEM_PC                                                                                              float64
#  88   pct_GLP_MA_07_HI7_PC                                                                                              float64
#  89   pct_GLP_MA_07_MALE_PC                                                                                             float64
#  90   pct_GLP_MA_07_SWD_PC                                                                                              float64
#  91   pct_GLP_MA_08_ALL_PC                                                                                              float64
#  92   pct_GLP_MA_08_BL7_PC                                                                                              float64
#  93   pct_GLP_MA_08_EDS_PC                                                                                              float64
#  94   pct_GLP_MA_08_FEM_PC                                                                                              float64
#  95   pct_GLP_MA_08_HI7_PC                                                                                              float64
#  96   pct_GLP_MA_08_MALE_PC                                                                                             float64
#  97   pct_GLP_MA_08_SWD_PC                                                                                              float64
#  98   pct_GLP_MA_ALL_BL7_PC                                                                                             float64
#  99   pct_GLP_MA_ALL_EDS_PC                                                                                             float64
#  100  pct_GLP_MA_ALL_ELS_PC                                                                                             float64
#  101  pct_GLP_MA_ALL_FEM_PC                                                                                             float64
#  102  pct_GLP_MA_ALL_HI7_PC                                                                                             float64
#  103  pct_GLP_MA_ALL_MALE_PC                                                                                            float64
#  104  pct_GLP_MA_ALL_MU7_PC                                                                                             float64
#  105  pct_GLP_MA_ALL_SWD_PC                                                                                             float64
#  106  pct_GLP_MA_ALL_WH7_PC                                                                                             float64
#  107  pct_GLP_RD_06_AIG_PC                                                                                              float64
#  108  pct_GLP_RD_06_BL7_PC                                                                                              float64
#  109  pct_GLP_RD_06_EDS_PC                                                                                              float64
#  110  pct_GLP_RD_06_ELS_PC                                                                                              float64
#  111  pct_GLP_RD_06_FEM_PC                                                                                              float64
#  112  pct_GLP_RD_06_HI7_PC                                                                                              float64
#  113  pct_GLP_RD_06_SWD_PC                                                                                              float64
#  114  pct_GLP_RD_06_WH7_PC                                                                                              float64
#  115  pct_GLP_RD_07_AIG_PC                                                                                              float64
#  116  pct_GLP_RD_07_SWD_PC                                                                                              float64
#  117  pct_GLP_RD_08_BL7_PC                                                                                              float64
#  118  pct_GLP_RD_08_EDS_PC                                                                                              float64
#  119  pct_GLP_RD_08_HI7_PC                                                                                              float64
#  120  pct_GLP_RD_08_SWD_PC                                                                                              float64
#  121  pct_GLP_RD_ALL_AIG_PC                                                                                             float64
#  122  pct_GLP_RD_ALL_ELS_PC                                                                                             float64
#  123  pct_GLP_RD_ALL_HI7_PC                                                                                             float64
#  124  pct_GLP_RD_ALL_MU7_PC                                                                                             float64
#  125  pct_GLP_RD_ALL_SWD_PC                                                                                             float64
#  126  pct_GLP_RD_ALL_WH7_PC                                                                                             float64
#  127  pct_GLP_SC_08_AIG_PC                                                                                              float64
#  128  pct_GLP_SC_08_ALL_PC                                                                                              float64
#  129  pct_GLP_SC_08_EDS_PC                                                                                              float64
#  130  pct_GLP_SC_08_FEM_PC                                                                                              float64
#  131  pct_GLP_SC_08_HI7_PC                                                                                              float64
#  132  pct_GLP_SC_08_MALE_PC                                                                                             float64
#  133  pct_GLP_SC_08_SWD_PC                                                                                              float64
#  134  pct_GLP_SC_08_WH7_PC                                                                                              float64
#  135  pct_GLP_SC_ALL_AIG_PC                                                                                             float64
#  136  pct_GLP_SC_ALL_BL7_PC                                                                                             float64
#  137  pct_GLP_SC_ALL_EDS_PC                                                                                             float64
#  138  pct_GLP_SC_ALL_ELS_PC                                                                                             float64
#  139  pct_GLP_SC_ALL_HI7_PC                                                                                             float64
#  140  pct_GLP_SC_ALL_MALE_PC                                                                                            float64
#  141  pct_GLP_SC_ALL_SWD_PC                                                                                             float64
#  142  pct_GLP_SC_ALL_WH7_PC                                                                                             float64
#  143  pct_L1_ALL_ALL_BL7_PC                                                                                             float64
#  144  pct_L1_ALL_ALL_EDS_PC                                                                                             float64
#  145  pct_L1_ALL_ALL_ELS_PC                                                                                             float64
#  146  pct_L1_ALL_ALL_FEM_PC                                                                                             float64
#  147  pct_L1_ALL_ALL_HI7_PC                                                                                             float64
#  148  pct_L1_ALL_ALL_MU7_PC                                                                                             float64
#  149  pct_L1_ALL_ALL_SWD_PC                                                                                             float64
#  150  pct_L1_ALL_ALL_WH7_PC                                                                                             float64
#  151  pct_L1_EOG_06_ALL_PC                                                                                              float64
#  152  pct_L1_EOG_06_BL7_PC                                                                                              float64
#  153  pct_L1_EOG_06_EDS_PC                                                                                              float64
#  154  pct_L1_EOG_06_ELS_PC                                                                                              float64
#  155  pct_L1_EOG_06_FEM_PC                                                                                              float64
#  156  pct_L1_EOG_06_HI7_PC                                                                                              float64
#  157  pct_L1_EOG_06_MALE_PC                                                                                             float64
#  158  pct_L1_EOG_06_MU7_PC                                                                                              float64
#  159  pct_L1_EOG_06_SWD_PC                                                                                              float64
#  160  pct_L1_EOG_06_WH7_PC                                                                                              float64
#  161  pct_L1_EOG_07_ALL_PC                                                                                              float64
#  162  pct_L1_EOG_07_BL7_PC                                                                                              float64
#  163  pct_L1_EOG_07_EDS_PC                                                                                              float64
#  164  pct_L1_EOG_07_ELS_PC                                                                                              float64
#  165  pct_L1_EOG_07_FEM_PC                                                                                              float64
#  166  pct_L1_EOG_07_HI7_PC                                                                                              float64
#  167  pct_L1_EOG_07_MALE_PC                                                                                             float64
#  168  pct_L1_EOG_07_MU7_PC                                                                                              float64
#  169  pct_L1_EOG_07_SWD_PC                                                                                              float64
#  170  pct_L1_EOG_07_WH7_PC                                                                                              float64
#  171  pct_L1_EOG_08_ALL_PC                                                                                              float64
#  172  pct_L1_EOG_08_BL7_PC                                                                                              float64
#  173  pct_L1_EOG_08_EDS_PC                                                                                              float64
#  174  pct_L1_EOG_08_ELS_PC                                                                                              float64
#  175  pct_L1_EOG_08_FEM_PC                                                                                              float64
#  176  pct_L1_EOG_08_HI7_PC                                                                                              float64
#  177  pct_L1_EOG_08_MALE_PC                                                                                             float64
#  178  pct_L1_EOG_08_MU7_PC                                                                                              float64
#  179  pct_L1_EOG_08_SWD_PC                                                                                              float64
#  180  pct_L1_EOG_08_WH7_PC                                                                                              float64
#  181  pct_L1_EOG_ALL_BL7_PC                                                                                             float64
#  182  pct_L1_EOG_ALL_EDS_PC                                                                                             float64
#  183  pct_L1_EOG_ALL_ELS_PC                                                                                             float64
#  184  pct_L1_EOG_ALL_FEM_PC                                                                                             float64
#  185  pct_L1_EOG_ALL_HI7_PC                                                                                             float64
#  186  pct_L1_EOG_ALL_HMS_PC                                                                                             float64
#  187  pct_L1_EOG_ALL_MALE_PC                                                                                            float64
#  188  pct_L1_EOG_ALL_MU7_PC                                                                                             float64
#  189  pct_L1_EOG_ALL_SWD_PC                                                                                             float64
#  190  pct_L1_EOG_ALL_WH7_PC                                                                                             float64
#  191  pct_L1_MA_06_ALL_PC                                                                                               float64
#  192  pct_L1_MA_06_BL7_PC                                                                                               float64
#  193  pct_L1_MA_06_EDS_PC                                                                                               float64
#  194  pct_L1_MA_06_ELS_PC                                                                                               float64
#  195  pct_L1_MA_06_FEM_PC                                                                                               float64
#  196  pct_L1_MA_06_HI7_PC                                                                                               float64
#  197  pct_L1_MA_06_MALE_PC                                                                                              float64
#  198  pct_L1_MA_06_SWD_PC                                                                                               float64
#  199  pct_L1_MA_06_WH7_PC                                                                                               float64
#  200  pct_L1_MA_07_ALL_PC                                                                                               float64
#  201  pct_L1_MA_07_BL7_PC                                                                                               float64
#  202  pct_L1_MA_07_EDS_PC                                                                                               float64
#  203  pct_L1_MA_07_ELS_PC                                                                                               float64
#  204  pct_L1_MA_07_FEM_PC                                                                                               float64
#  205  pct_L1_MA_07_HI7_PC                                                                                               float64
#  206  pct_L1_MA_07_MALE_PC                                                                                              float64
#  207  pct_L1_MA_07_SWD_PC                                                                                               float64
#  208  pct_L1_MA_07_WH7_PC                                                                                               float64
#  209  pct_L1_MA_08_ALL_PC                                                                                               float64
#  210  pct_L1_MA_08_BL7_PC                                                                                               float64
#  211  pct_L1_MA_08_EDS_PC                                                                                               float64
#  212  pct_L1_MA_08_FEM_PC                                                                                               float64
#  213  pct_L1_MA_08_HI7_PC                                                                                               float64
#  214  pct_L1_MA_08_MALE_PC                                                                                              float64
#  215  pct_L1_MA_08_SWD_PC                                                                                               float64
#  216  pct_L1_MA_08_WH7_PC                                                                                               float64
#  217  pct_L1_MA_ALL_ALL_PC                                                                                              float64
#  218  pct_L1_MA_ALL_BL7_PC                                                                                              float64
#  219  pct_L1_MA_ALL_EDS_PC                                                                                              float64
#  220  pct_L1_MA_ALL_ELS_PC                                                                                              float64
#  221  pct_L1_MA_ALL_FEM_PC                                                                                              float64
#  222  pct_L1_MA_ALL_HI7_PC                                                                                              float64
#  223  pct_L1_MA_ALL_MALE_PC                                                                                             float64
#  224  pct_L1_MA_ALL_MU7_PC                                                                                              float64
#  225  pct_L1_MA_ALL_SWD_PC                                                                                              float64
#  226  pct_L1_MA_ALL_WH7_PC                                                                                              float64
#  227  pct_L1_RD_06_ALL_PC                                                                                               float64
#  228  pct_L1_RD_06_BL7_PC                                                                                               float64
#  229  pct_L1_RD_06_EDS_PC                                                                                               float64
#  230  pct_L1_RD_06_ELS_PC                                                                                               float64
#  231  pct_L1_RD_06_FEM_PC                                                                                               float64
#  232  pct_L1_RD_06_HI7_PC                                                                                               float64
#  233  pct_L1_RD_06_MALE_PC                                                                                              float64
#  234  pct_L1_RD_06_SWD_PC                                                                                               float64
#  235  pct_L1_RD_06_WH7_PC                                                                                               float64
#  236  pct_L1_RD_07_ALL_PC                                                                                               float64
#  237  pct_L1_RD_07_BL7_PC                                                                                               float64
#  238  pct_L1_RD_07_EDS_PC                                                                                               float64
#  239  pct_L1_RD_07_ELS_PC                                                                                               float64
#  240  pct_L1_RD_07_FEM_PC                                                                                               float64
#  241  pct_L1_RD_07_HI7_PC                                                                                               float64
#  242  pct_L1_RD_07_MALE_PC                                                                                              float64
#  243  pct_L1_RD_07_SWD_PC                                                                                               float64
#  244  pct_L1_RD_07_WH7_PC                                                                                               float64
#  245  pct_L1_RD_08_ALL_PC                                                                                               float64
#  246  pct_L1_RD_08_BL7_PC                                                                                               float64
#  247  pct_L1_RD_08_EDS_PC                                                                                               float64
#  248  pct_L1_RD_08_ELS_PC                                                                                               float64
#  249  pct_L1_RD_08_FEM_PC                                                                                               float64
#  250  pct_L1_RD_08_HI7_PC                                                                                               float64
#  251  pct_L1_RD_08_MALE_PC                                                                                              float64
#  252  pct_L1_RD_08_SWD_PC                                                                                               float64
#  253  pct_L1_RD_08_WH7_PC                                                                                               float64
#  254  pct_L1_RD_ALL_ALL_PC                                                                                              float64
#  255  pct_L1_RD_ALL_BL7_PC                                                                                              float64
#  256  pct_L1_RD_ALL_EDS_PC                                                                                              float64
#  257  pct_L1_RD_ALL_ELS_PC                                                                                              float64
#  258  pct_L1_RD_ALL_FEM_PC                                                                                              float64
#  259  pct_L1_RD_ALL_HI7_PC                                                                                              float64
#  260  pct_L1_RD_ALL_MALE_PC                                                                                             float64
#  261  pct_L1_RD_ALL_MU7_PC                                                                                              float64
#  262  pct_L1_RD_ALL_SWD_PC                                                                                              float64
#  263  pct_L1_RD_ALL_WH7_PC                                                                                              float64
#  264  pct_L1_SC_08_ALL_PC                                                                                               float64
#  265  pct_L1_SC_08_BL7_PC                                                                                               float64
#  266  pct_L1_SC_08_EDS_PC                                                                                               float64
#  267  pct_L1_SC_08_ELS_PC                                                                                               float64
#  268  pct_L1_SC_08_FEM_PC                                                                                               float64
#  269  pct_L1_SC_08_HI7_PC                                                                                               float64
#  270  pct_L1_SC_08_MALE_PC                                                                                              float64
#  271  pct_L1_SC_08_SWD_PC                                                                                               float64
#  272  pct_L1_SC_08_WH7_PC                                                                                               float64
#  273  pct_L1_SC_ALL_ALL_PC                                                                                              float64
#  274  pct_L1_SC_ALL_BL7_PC                                                                                              float64
#  275  pct_L1_SC_ALL_EDS_PC                                                                                              float64
#  276  pct_L1_SC_ALL_ELS_PC                                                                                              float64
#  277  pct_L1_SC_ALL_FEM_PC                                                                                              float64
#  278  pct_L1_SC_ALL_HI7_PC                                                                                              float64
#  279  pct_L1_SC_ALL_MALE_PC                                                                                             float64
#  280  pct_L1_SC_ALL_SWD_PC                                                                                              float64
#  281  pct_L1_SC_ALL_WH7_PC                                                                                              float64
#  282  pct_L2_ALL_ALL_ALL_PC                                                                                             float64
#  283  pct_L2_ALL_ALL_EDS_PC                                                                                             float64
#  284  pct_L2_ALL_ALL_FEM_PC                                                                                             float64
#  285  pct_L2_ALL_ALL_HI7_PC                                                                                             float64
#  286  pct_L2_ALL_ALL_HMS_PC                                                                                             float64
#  287  pct_L2_ALL_ALL_MALE_PC                                                                                            float64
#  288  pct_L2_ALL_ALL_MU7_PC                                                                                             float64
#  289  pct_L2_ALL_ALL_SWD_PC                                                                                             float64
#  290  pct_L2_ALL_ALL_WH7_PC                                                                                             float64
#  291  pct_L2_EOG_06_ALL_PC                                                                                              float64
#  292  pct_L2_EOG_06_BL7_PC                                                                                              float64
#  293  pct_L2_EOG_06_EDS_PC                                                                                              float64
#  294  pct_L2_EOG_06_ELS_PC                                                                                              float64
#  295  pct_L2_EOG_06_FEM_PC                                                                                              float64
#  296  pct_L2_EOG_06_HI7_PC                                                                                              float64
#  297  pct_L2_EOG_06_MALE_PC                                                                                             float64
#  298  pct_L2_EOG_06_MU7_PC                                                                                              float64
#  299  pct_L2_EOG_06_SWD_PC                                                                                              float64
#  300  pct_L2_EOG_06_WH7_PC                                                                                              float64
#  301  pct_L2_EOG_07_ALL_PC                                                                                              float64
#  302  pct_L2_EOG_07_BL7_PC                                                                                              float64
#  303  pct_L2_EOG_07_EDS_PC                                                                                              float64
#  304  pct_L2_EOG_07_ELS_PC                                                                                              float64
#  305  pct_L2_EOG_07_FEM_PC                                                                                              float64
#  306  pct_L2_EOG_07_HI7_PC                                                                                              float64
#  307  pct_L2_EOG_07_MALE_PC                                                                                             float64
#  308  pct_L2_EOG_07_MU7_PC                                                                                              float64
#  309  pct_L2_EOG_07_SWD_PC                                                                                              float64
#  310  pct_L2_EOG_07_WH7_PC                                                                                              float64
#  311  pct_L2_EOG_08_ALL_PC                                                                                              float64
#  312  pct_L2_EOG_08_BL7_PC                                                                                              float64
#  313  pct_L2_EOG_08_EDS_PC                                                                                              float64
#  314  pct_L2_EOG_08_ELS_PC                                                                                              float64
#  315  pct_L2_EOG_08_FEM_PC                                                                                              float64
#  316  pct_L2_EOG_08_HI7_PC                                                                                              float64
#  317  pct_L2_EOG_08_MALE_PC                                                                                             float64
#  318  pct_L2_EOG_08_MU7_PC                                                                                              float64
#  319  pct_L2_EOG_08_SWD_PC                                                                                              float64
#  320  pct_L2_EOG_08_WH7_PC                                                                                              float64
#  321  pct_L2_EOG_ALL_AS7_PC                                                                                             float64
#  322  pct_L2_EOG_ALL_BL7_PC                                                                                             float64
#  323  pct_L2_EOG_ALL_EDS_PC                                                                                             float64
#  324  pct_L2_EOG_ALL_ELS_PC                                                                                             float64
#  325  pct_L2_EOG_ALL_FEM_PC                                                                                             float64
#  326  pct_L2_EOG_ALL_HI7_PC                                                                                             float64
#  327  pct_L2_EOG_ALL_MALE_PC                                                                                            float64
#  328  pct_L2_EOG_ALL_MU7_PC                                                                                             float64
#  329  pct_L2_EOG_ALL_SWD_PC                                                                                             float64
#  330  pct_L2_EOG_ALL_WH7_PC                                                                                             float64
#  331  pct_L2_MA_06_ALL_PC                                                                                               float64
#  332  pct_L2_MA_06_BL7_PC                                                                                               float64
#  333  pct_L2_MA_06_EDS_PC                                                                                               float64
#  334  pct_L2_MA_06_ELS_PC                                                                                               float64
#  335  pct_L2_MA_06_FEM_PC                                                                                               float64
#  336  pct_L2_MA_06_HI7_PC                                                                                               float64
#  337  pct_L2_MA_06_MALE_PC                                                                                              float64
#  338  pct_L2_MA_06_SWD_PC                                                                                               float64
#  339  pct_L2_MA_06_WH7_PC                                                                                               float64
#  340  pct_L2_MA_07_ALL_PC                                                                                               float64
#  341  pct_L2_MA_07_BL7_PC                                                                                               float64
#  342  pct_L2_MA_07_EDS_PC                                                                                               float64
#  343  pct_L2_MA_07_ELS_PC                                                                                               float64
#  344  pct_L2_MA_07_FEM_PC                                                                                               float64
#  345  pct_L2_MA_07_HI7_PC                                                                                               float64
#  346  pct_L2_MA_07_MALE_PC                                                                                              float64
#  347  pct_L2_MA_07_SWD_PC                                                                                               float64
#  348  pct_L2_MA_07_WH7_PC                                                                                               float64
#  349  pct_L2_MA_08_ALL_PC                                                                                               float64
#  350  pct_L2_MA_08_BL7_PC                                                                                               float64
#  351  pct_L2_MA_08_EDS_PC                                                                                               float64
#  352  pct_L2_MA_08_ELS_PC                                                                                               float64
#  353  pct_L2_MA_08_FEM_PC                                                                                               float64
#  354  pct_L2_MA_08_HI7_PC                                                                                               float64
#  355  pct_L2_MA_08_MALE_PC                                                                                              float64
#  356  pct_L2_MA_08_SWD_PC                                                                                               float64
#  357  pct_L2_MA_08_WH7_PC                                                                                               float64
#  358  pct_L2_MA_ALL_ALL_PC                                                                                              float64
#  359  pct_L2_MA_ALL_BL7_PC                                                                                              float64
#  360  pct_L2_MA_ALL_EDS_PC                                                                                              float64
#  361  pct_L2_MA_ALL_ELS_PC                                                                                              float64
#  362  pct_L2_MA_ALL_FEM_PC                                                                                              float64
#  363  pct_L2_MA_ALL_HI7_PC                                                                                              float64
#  364  pct_L2_MA_ALL_MALE_PC                                                                                             float64
#  365  pct_L2_MA_ALL_MU7_PC                                                                                              float64
#  366  pct_L2_MA_ALL_SWD_PC                                                                                              float64
#  367  pct_L2_MA_ALL_WH7_PC                                                                                              float64
#  368  pct_L2_RD_06_ALL_PC                                                                                               float64
#  369  pct_L2_RD_06_BL7_PC                                                                                               float64
#  370  pct_L2_RD_06_EDS_PC                                                                                               float64
# ...
#  1076 digital_media_9                                                                                                   uint8
#  1077 digital_media_95                                                                                                  uint8
#  1078 device_access_Yes                                                                                                 uint8
#  1079 device_home_Yes                                                                                                   uint8
#  1080 BYOD_Both                                                                                                         uint8
#  1081 BYOD_Neither                                                                                                      uint8
#  1082 BYOD_Staff                                                                                                        uint8
#  1083 BYOD_Students                                                                                                     uint8
#  1084 esea_att_Met                                                                                                      uint8
#  1085 agency_lea_code_020LEA                                                                                            uint8
#  1086 agency_lea_code_030LEA                                                                                            uint8
#  1087 agency_lea_code_040LEA                                                                                            uint8
#  1088 agency_lea_code_050LEA                                                                                            uint8
#  1089 agency_lea_code_060LEA                                                                                            uint8
#  1090 agency_lea_code_070LEA                                                                                            uint8
#  1091 agency_lea_code_080LEA                                                                                            uint8
#  1092 agency_lea_code_090LEA                                                                                            uint8
#  1093 agency_lea_code_100LEA                                                                                            uint8
#  1094 agency_lea_code_110LEA                                                                                            uint8
#  1095 agency_lea_code_111LEA                                                                                            uint8
#  1096 agency_lea_code_120LEA                                                                                            uint8
#  1097 agency_lea_code_130LEA                                                                                            uint8
#  1098 agency_lea_code_132LEA                                                                                            uint8
#  1099 agency_lea_code_140LEA                                                                                            uint8
#  1100 agency_lea_code_150LEA                                                                                            uint8
#  1101 agency_lea_code_160LEA                                                                                            uint8
#  1102 agency_lea_code_170LEA                                                                                            uint8
#  1103 agency_lea_code_180LEA                                                                                            uint8
#  1104 agency_lea_code_181LEA                                                                                            uint8
#  1105 agency_lea_code_182LEA                                                                                            uint8
#  1106 agency_lea_code_190LEA                                                                                            uint8
#  1107 agency_lea_code_200LEA                                                                                            uint8
#  1108 agency_lea_code_210LEA                                                                                            uint8
#  1109 agency_lea_code_220LEA                                                                                            uint8
#  1110 agency_lea_code_230LEA                                                                                            uint8
#  1111 agency_lea_code_240LEA                                                                                            uint8
#  1112 agency_lea_code_241LEA                                                                                            uint8
#  1113 agency_lea_code_250LEA                                                                                            uint8
#  1114 agency_lea_code_260LEA                                                                                            uint8
#  1115 agency_lea_code_270LEA                                                                                            uint8
#  1116 agency_lea_code_280LEA                                                                                            uint8
#  1117 agency_lea_code_290LEA                                                                                            uint8
#  1118 agency_lea_code_291LEA                                                                                            uint8
#  1119 agency_lea_code_292LEA                                                                                            uint8
#  1120 agency_lea_code_300LEA                                                                                            uint8
#  1121 agency_lea_code_310LEA                                                                                            uint8
#  1122 agency_lea_code_320LEA                                                                                            uint8
#  1123 agency_lea_code_330LEA                                                                                            uint8
#  1124 agency_lea_code_340LEA                                                                                            uint8
#  1125 agency_lea_code_350LEA                                                                                            uint8
#  1126 agency_lea_code_360LEA                                                                                            uint8
#  1127 agency_lea_code_370LEA                                                                                            uint8
#  1128 agency_lea_code_380LEA                                                                                            uint8
#  1129 agency_lea_code_390LEA                                                                                            uint8
#  1130 agency_lea_code_400LEA                                                                                            uint8
#  1131 agency_lea_code_410LEA                                                                                            uint8
#  1132 agency_lea_code_420LEA                                                                                            uint8
#  1133 agency_lea_code_421LEA                                                                                            uint8
#  1134 agency_lea_code_422LEA                                                                                            uint8
#  1135 agency_lea_code_430LEA                                                                                            uint8
#  1136 agency_lea_code_440LEA                                                                                            uint8
#  1137 agency_lea_code_450LEA                                                                                            uint8
#  1138 agency_lea_code_460LEA                                                                                            uint8
#  1139 agency_lea_code_470LEA                                                                                            uint8
#  1140 agency_lea_code_480LEA                                                                                            uint8
#  1141 agency_lea_code_490LEA                                                                                            uint8
#  1142 agency_lea_code_491LEA                                                                                            uint8
#  1143 agency_lea_code_500LEA                                                                                            uint8
#  1144 agency_lea_code_510LEA                                                                                            uint8
#  1145 agency_lea_code_520LEA                                                                                            uint8
#  1146 agency_lea_code_530LEA                                                                                            uint8
#  1147 agency_lea_code_540LEA                                                                                            uint8
#  1148 agency_lea_code_550LEA                                                                                            uint8
#  1149 agency_lea_code_560LEA                                                                                            uint8
#  1150 agency_lea_code_570LEA                                                                                            uint8
#  1151 agency_lea_code_580LEA                                                                                            uint8
#  1152 agency_lea_code_590LEA                                                                                            uint8
#  1153 agency_lea_code_600LEA                                                                                            uint8
#  1154 agency_lea_code_610LEA                                                                                            uint8
#  1155 agency_lea_code_620LEA                                                                                            uint8
#  1156 agency_lea_code_630LEA                                                                                            uint8
#  1157 agency_lea_code_640LEA                                                                                            uint8
#  1158 agency_lea_code_650LEA                                                                                            uint8
#  1159 agency_lea_code_660LEA                                                                                            uint8
#  1160 agency_lea_code_670LEA                                                                                            uint8
#  1161 agency_lea_code_680LEA                                                                                            uint8
#  1162 agency_lea_code_681LEA                                                                                            uint8
#  1163 agency_lea_code_690LEA                                                                                            uint8
#  1164 agency_lea_code_700LEA                                                                                            uint8
#  1165 agency_lea_code_710LEA                                                                                            uint8
#  1166 agency_lea_code_720LEA                                                                                            uint8
#  1167 agency_lea_code_730LEA                                                                                            uint8
#  1168 agency_lea_code_740LEA                                                                                            uint8
#  1169 agency_lea_code_750LEA                                                                                            uint8
#  1170 agency_lea_code_760LEA                                                                                            uint8
#  1171 agency_lea_code_761LEA                                                                                            uint8
#  1172 agency_lea_code_770LEA                                                                                            uint8
#  1173 agency_lea_code_780LEA                                                                                            uint8
#  1174 agency_lea_code_790LEA                                                                                            uint8
#  1175 agency_lea_code_800LEA                                                                                            uint8
#  1176 agency_lea_code_810LEA                                                                                            uint8
#  1177 agency_lea_code_820LEA                                                                                            uint8
#  1178 agency_lea_code_821LEA                                                                                            uint8
#  1179 agency_lea_code_830LEA                                                                                            uint8
#  1180 agency_lea_code_840LEA                                                                                            uint8
#  1181 agency_lea_code_850LEA                                                                                            uint8
#  1182 agency_lea_code_860LEA                                                                                            uint8
#  1183 agency_lea_code_861LEA                                                                                            uint8
#  1184 agency_lea_code_862LEA                                                                                            uint8
#  1185 agency_lea_code_870LEA                                                                                            uint8
#  1186 agency_lea_code_880LEA                                                                                            uint8
#  1187 agency_lea_code_890LEA                                                                                            uint8
#  1188 agency_lea_code_900LEA                                                                                            uint8
#  1189 agency_lea_code_910LEA                                                                                            uint8
#  1190 agency_lea_code_920LEA                                                                                            uint8
#  1191 agency_lea_code_930LEA                                                                                            uint8
#  1192 agency_lea_code_940LEA                                                                                            uint8
#  1193 agency_lea_code_950LEA                                                                                            uint8
#  1194 agency_lea_code_960LEA                                                                                            uint8
#  1195 agency_lea_code_970LEA                                                                                            uint8
#  1196 agency_lea_code_980LEA                                                                                            uint8
#  1197 agency_lea_code_990LEA                                                                                            uint8
#  1198 agency_lea_code_995LEA                                                                                            uint8
#  1199 agency_code                                                                                                       object
# dtypes: float64(918), object(1), uint8(281)
# memory usage: 4.8+ MB

# %%
import sklearn
import pandas as pd

print('Sklearn Version: ' + sklearn.__version__)
print('Pandas Version: ' + pd.__version__)
# Out:
# Sklearn Version: 0.22.1
# Pandas Version: 1.0.3

# %%
print('Output File Location:\r\n\r\n' + outputDir + inputFileName + '_ML.csv')
# Out:
# Output File Location:
#
# C:/Users/Jake/Documents/GitHub/EducationDataNC/2018/Machine Learning Datasets/PublicMiddleSchools2018_ML.csv
