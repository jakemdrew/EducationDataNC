# %% [markdown]
# # Create Public School Machine Learning Datasets
# ** This program creates all the _ML datasets in the NCEA repository.**
# * This notebook reads each School Dataset file located at \EducationDataNC\ *schoolYear* \School Datasets\ as input data.
# * Different school years are processed by changing the *schoolYear* parameter.
# * Different input / output files are processed / created by changing the *inputFileName* paramter in the cell below.
# * While a single program is used to create all the _ML datasets, one program copy per dataset is maintained in the repositiory so the dataset specific tranformation reports may be reviewed.
#
# **Datasets ending in ML are preprocessed for Machine Learning and go through the following transformations: **
# 1. Missing student body racial compositions are imputed using district averages.
# 2. Columns that have the same value in every single row are deleted.
# 3. Columns that have a unique value in every single row (all values are different) are deleted.
# 4. Empty columns (all values are NA or NULL) are deleted.
# 5. Numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# 6. Remaining numeric, non-race columns with missing values are imputed / populated with 0.  In many cases, schools are not reporting values when they are zero. However, mean imputation or some other more sophisticated strategy might be considered here.
# 7. Categorical / text based columns with > *uniqueThreshold* unique values are deleted.
# 8. All remaining categorical / text based columns are one-hot encoded.  In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# 9. Duplicated or highly similar columns with > 95% correlation are delelted.

# %%
#import required Libraries
import pandas as pd
import numpy as np
import os
import string

#**********************************************************************************
# Set the following variables before running this code!!!
#**********************************************************************************
#All raw data files are processed for the year below
schoolYear = 2018
rootDir = 'D:/BenepactLLC/Belk/NC_Report_Card_Data/2020/June 2020/'
#Location where copies of the raw data files will be read in from csv files.
dataDir = rootDir + str(schoolYear) + '/School Datasets/'

#Name of the file to be processed
inputFileName = 'PublicSchools2018'
#inputFileName = 'PublicHighSchools2018'
#inputFileName = 'PublicMiddleSchools2018'
#inputFileName = 'PublicElementarySchools2018'

#Input file being transformed for machine learning 
inputFile = dataDir + inputFileName + '.csv'

#Location where the new school datasets will be created.
outputDir = rootDir + str(schoolYear) + '/Machine Learning Datasets/'

#Missing Data Threshold (Per Column)
missingThreshold = 0.60

#Unique Value Threshold (Per Column)
#Delete Columns >  uniqueThreshold unique values prior to one-hot encoding. 
#(each unique value becomes a new column during one-hot encoding)
uniqueThreshold = 200

#Read in the School Data File
schoolData = pd.read_csv(inputFile, low_memory=False, dtype={'agency_code': object})
print('*********Start: Beginning Column and Row Counts********************************************')
schoolData.info(verbose=False)

#Select only public schools as charter schools are missing data for many columns.
schoolData = schoolData[(schoolData['designation_type'] == 'P') & (schoolData['avg_student_num'] > 0)]

print('\r\n*********After: Selecting Only Public School Campuses**********************************')
schoolData.info(verbose=False)

#Save primary key
agency_code = schoolData['agency_code']
#Convert zip code to string
schoolData['zip'] = schoolData['zip'].astype('object')
# Out:
# *********Start: Beginning Column and Row Counts********************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2642 entries, 0 to 2641
# Columns: 5246 entries, agency_code to lea_federal_perpupil
# dtypes: float64(5194), object(52)
# memory usage: 105.7+ MB
#
# *********After: Selecting Only Public School Campuses**********************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2460 entries, 2 to 2641
# Columns: 5246 entries, agency_code to lea_federal_perpupil
# dtypes: float64(5194), object(52)
# memory usage: 98.5+ MB

# %% [markdown]
# # Prepare Consolidated Dataset for Machine Learning
# **Below we perform operations on the entire dataset to remove columns and update row values that could cause problems during machine learning.**

# %% [markdown]
# ## Student Body Racial Composition Features
# **Impute / update missing Student Body Racial Composition Fields using mean imputation.**
# * When there are no racial composition percentages for a particular school campus / agency_code, fill in the missing values

# %%
#Get Student Body Racial Composition Fields
raceCompositionFields = schoolData.filter(regex='Indian|Asian|Hispanic|Black|White|PacificIsland|TwoOrMore|Minority')\
                                  .filter(regex='Pct').columns
    
rowsBefore = schoolData[raceCompositionFields].isnull().T.any().T.sum()

#Update missing race values with the district average when avaiable (No district averages for charter schools) 
schoolData[raceCompositionFields] = schoolData.groupby('lea_code')[raceCompositionFields]\
                                              .transform(lambda x: x.fillna(x.mean()))

    #Review dataset contents after Racial Composition Imputation
print('*********After: Updating Missing Racial Compostion Values****************************')   
rowsAfter = schoolData[raceCompositionFields].isnull().T.any().T.sum()
rowsUpdated = rowsBefore - rowsAfter
print('Rows Updated / Imputed: ', rowsUpdated) 
print('\r\nTotal Rows Missing Racial Compositions By District Code') 
schoolData['lea_code'][schoolData[raceCompositionFields].isnull().T.any().T].value_counts()
# Out:
# *********After: Updating Missing Racial Compostion Values****************************
# Rows Updated / Imputed:  0
#
# Total Rows Missing Racial Compositions By District Code
# Series([], Name: lea_code, dtype: int64)

# %% [markdown]
# ## Remove Columns with Problematic Data
# **Here we remove entire columns that could cause problems during machine learning.  The following operations are performed:**
# * Remove any columns that have the same value in every single row.
# * Remove any columns that have a unique value in every single row (all values are different).
# * Remove empty columns (all values are NA or NULL).

# %%
#Remove any fields that have the same value in all rows
UniqueValueCounts = schoolData.nunique(dropna=False)
SingleValueCols = UniqueValueCounts[UniqueValueCounts == 1].index
schoolData = schoolData.drop(SingleValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with the same value in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(SingleValueCols))
# Out:
# *********After: Removing columns with the same value in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2460 entries, 2 to 2641
# Columns: 4160 entries, agency_code to lea_federal_perpupil
# dtypes: float64(4112), object(48)
# memory usage: 78.1+ MB
#
# Columns Deleted:  1086

# %%
#Remove any fields that have unique values in every row
schoolDataRecordCt = schoolData.shape[0]
UniqueValueCounts = schoolData.apply(pd.Series.nunique)
AllUniqueValueCols = UniqueValueCounts[UniqueValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(AllUniqueValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with unique values in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(AllUniqueValueCols))
# Out:
# *********After: Removing columns with unique values in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2460 entries, 2 to 2641
# Columns: 4158 entries, category_code to lea_federal_perpupil
# dtypes: float64(4112), object(46)
# memory usage: 78.1+ MB
#
# Columns Deleted:  2

# %%
#Remove any empty fields (null values in every row)
schoolDataRecordCt = schoolData.shape[0]
NullValueCounts = schoolData.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with null / blank values in every row.*************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with null / blank values in every row.*************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2460 entries, 2 to 2641
# Columns: 4158 entries, category_code to lea_federal_perpupil
# dtypes: float64(4112), object(46)
# memory usage: 78.1+ MB
#
# Columns Deleted:  0

# %% [markdown]
# ## Handle Other Missing Values Types
# * Here we eliminate any numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# * All remaining non-race, numeric column missing values are populated with 0.
# * In many cases, it seems that schools are not simply not reporting values when they are zero. However, mean imputation or some other strategy might be considered.

# %%
#Isolate continuous and categorical data types
#These are indexers into the schoolData dataframe and may be used similar to the schoolData dataframe 
sD_boolean = schoolData.loc[:, (schoolData.dtypes == bool) ]
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]
sD_continuous = schoolData.loc[:, (schoolData.dtypes != bool) & (schoolData.dtypes != object)]
print ("Boolean Columns: ", sD_boolean.shape[1])
print ("Nominal Columns: ", sD_nominal.shape[1])
print ("Continuous Columns: ", sD_continuous.shape[1])
print ("Columns Accounted for: ", sD_nominal.shape[1] + sD_continuous.shape[1] + sD_boolean.shape[1])
# Out:
# Boolean Columns:  0
# Nominal Columns:  46
# Continuous Columns:  4112
# Columns Accounted for:  4158

# %%
#Eliminate continuous columns with more than missingThreshold percentage of missing values
schoolDataRecordCt = sD_continuous.shape[0]
missingValueLimit = schoolDataRecordCt * missingThreshold
NullValueCounts = sD_continuous.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts >= missingValueLimit].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with >= missingThreshold % of missing values******')
schoolData.info(verbose=False)
print('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with >= missingThreshold % of missing values******
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2460 entries, 2 to 2641
# Columns: 950 entries, category_code to lea_federal_perpupil
# dtypes: float64(904), object(46)
# memory usage: 17.8+ MB
#
# Columns Deleted:  3208

# %% [markdown]
# ## One-Hot Encoding of Categorical Variables
# **All categorical / string variables are converted to numberic variables via one hot encoding.  Each unique row value will become a new binary / numeric column in the dataset.**
# * All remaining categorical columns are one-hot encoded.
# * In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# * Prior to one-hot encoding, columns with > *uniqueThreshold* unique values are deleted.

# %%
#Delete categorical columns with > uniqueThreshold unique values 
#(Each unique value becomes a column during one-hot encoding)
oneHotUniqueValueCounts = schoolData[sD_nominal.columns].apply(lambda x: x.nunique())
oneHotUniqueValueCols = oneHotUniqueValueCounts[oneHotUniqueValueCounts >= uniqueThreshold].index
schoolData.drop(oneHotUniqueValueCols, axis=1, inplace=True) 

#Remove categorical columns which do not add value to machine learning
#Grades columns dropped since they all have indicator fields (device_access, device_home, BYOD)
#with less unique values to one-hot encode
schoolData.drop(['welcome_url','device_access_grades',
                 'device_home_grades','byod_grades'], axis=1, inplace=True) 

#Review dataset contents one hot high unique value drops
print('*********After: Removing columns with >= uniqueThreshold unique values***********')
schoolData.info(verbose=False)
print('\r\nColumns Deleted: ', len(oneHotUniqueValueCols))
print(oneHotUniqueValueCols)
print('Dropped Manually: welcome_url,device_access_grades,device_home_grades,byod_grades')
# Out:
# *********After: Removing columns with >= uniqueThreshold unique values***********
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2460 entries, 2 to 2641
# Columns: 940 entries, category_code to lea_federal_perpupil
# dtypes: float64(904), object(36)
# memory usage: 17.7+ MB
#
# Columns Deleted:  6
# Index(['street_addr', 'city', 'zip', 'phone', 'url', 'school_name'], dtype='object')
# Dropped Manually: welcome_url,device_access_grades,device_home_grades,byod_grades

# %%
#Isolate remaining categorical variables
begColumnCt = len(schoolData.columns)
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]

#one hot encode categorical variables
schoolData = pd.get_dummies(data=schoolData, 
                       columns=sD_nominal.columns, drop_first=True)

#Determine change in column count
endColumnCt = len(schoolData.columns)
columnsAdded = endColumnCt - begColumnCt

#Review dataset contents one hot high unique value drops
print('Columns To One-Hot Encode: ', len(sD_nominal.columns))
print('\r\n*********After: Adding New Columns Via One-Hot Encoding*************************')
schoolData.info(verbose=False)
print('\r\nNew Columns Created Via One-Hot Encoding: ', columnsAdded)
# Out:
# Columns To One-Hot Encode:  36
#
# *********After: Adding New Columns Via One-Hot Encoding*************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2460 entries, 2 to 2641
# Columns: 1585 entries, lea to agency_lea_code_995LEA
# dtypes: float64(904), uint8(681)
# memory usage: 18.6 MB
#
# New Columns Created Via One-Hot Encoding:  645

# %%
#Remove any fields that have the same value in all rows after one-hot encoding
UniqueValueCounts = schoolData.nunique(dropna=False)
SingleValueCols = UniqueValueCounts[UniqueValueCounts == 1].index
schoolData = schoolData.drop(SingleValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing one-hot encoded columns with the same value in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(SingleValueCols))
# Out:
# *********After: Removing one-hot encoded columns with the same value in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2460 entries, 2 to 2641
# Columns: 1585 entries, lea to agency_lea_code_995LEA
# dtypes: float64(904), uint8(681)
# memory usage: 18.6 MB
#
# Columns Deleted:  0

# %% [markdown]
# ## Impute any Remaining Missing Values as Zero

# %%
#Print out all the missing value rows
pd.set_option('display.max_rows', 1000)

print('\r\n*********The Remaining Missing Values Below will be set to Zero!*************************')

#Check for Missing values 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# *********The Remaining Missing Values Below will be set to Zero!*************************
#                                    Variable Name  Number Missing Values
# 26                                       pct_eds                      1
# 27                                   pct_ALL_ELP                    818
# 28                                   pct_EDS_ELP                   1072
# 29                                   pct_ELS_ELP                    818
# 30                                   pct_FEM_ELP                   1345
# 31                                   pct_HI7_ELP                    977
# 32                                  pct_MALE_ELP                   1154
# 33                   pct_met_Math Grades 3-8_LTG                    632
# 34                pct_met_Reading Grades 3-8_LTG                    632
# 35                     pct_met_Total Targets_LTG                    146
# 36                  pct_met_Math Grades 3-8_PART                    599
# 37               pct_met_Reading Grades 3-8_PART                    599
# 38               pct_met_Science Grades 5&8_PART                    755
# 39                    pct_met_Total Targets_PART                    106
# 40              pct_Math Grades 3-8_ALL_PART_DET                    599
# 41              pct_Math Grades 3-8_BL7_PART_DET                   1188
# 42              pct_Math Grades 3-8_EDS_PART_DET                    648
# 43              pct_Math Grades 3-8_HI7_PART_DET                   1260
# 44              pct_Math Grades 3-8_SWD_PART_DET                   1206
# 45              pct_Math Grades 3-8_WH7_PART_DET                    894
# 46           pct_Reading Grades 3-8_ALL_PART_DET                    599
# 47           pct_Reading Grades 3-8_BL7_PART_DET                   1188
# 48           pct_Reading Grades 3-8_EDS_PART_DET                    648
# 49           pct_Reading Grades 3-8_HI7_PART_DET                   1260
# 50           pct_Reading Grades 3-8_SWD_PART_DET                   1206
# 51           pct_Reading Grades 3-8_WH7_PART_DET                    894
# 52           pct_Science Grades 5&8_ALL_PART_DET                    755
# 53           pct_Science Grades 5&8_EDS_PART_DET                   1131
# 54           pct_Science Grades 5&8_WH7_PART_DET                   1323
# 55                         pct_CCR_EOG_03_ALL_PC                   1136
# 56                         pct_CCR_EOG_03_BL7_PC                   1460
# 57                         pct_CCR_EOG_03_EDS_PC                   1149
# 58                         pct_CCR_EOG_03_FEM_PC                   1143
# 59                         pct_CCR_EOG_03_HI7_PC                   1426
# 60                        pct_CCR_EOG_03_MALE_PC                   1142
# 61                         pct_CCR_EOG_03_SWD_PC                   1439
# 62                         pct_CCR_EOG_03_WH7_PC                   1276
# 63                         pct_CCR_EOG_04_ALL_PC                   1134
# 64                         pct_CCR_EOG_04_BL7_PC                   1467
# 65                         pct_CCR_EOG_04_EDS_PC                   1154
# 66                         pct_CCR_EOG_04_FEM_PC                   1143
# 67                         pct_CCR_EOG_04_HI7_PC                   1410
# 68                        pct_CCR_EOG_04_MALE_PC                   1145
# 69                         pct_CCR_EOG_04_WH7_PC                   1270
# 70                         pct_CCR_EOG_05_AIG_PC                   1384
# 71                         pct_CCR_EOG_05_ALL_PC                   1155
# 72                         pct_CCR_EOG_05_BL7_PC                   1441
# 73                         pct_CCR_EOG_05_EDS_PC                   1173
# 74                         pct_CCR_EOG_05_FEM_PC                   1170
# 75                         pct_CCR_EOG_05_HI7_PC                   1367
# 76                        pct_CCR_EOG_05_MALE_PC                   1165
# 77                         pct_CCR_EOG_05_SWD_PC                   1438
# 78                         pct_CCR_EOG_05_WH7_PC                   1282
# 79                        pct_CCR_EOG_ALL_AIG_PC                    746
# 80                        pct_CCR_EOG_ALL_ALL_PC                    586
# 81                        pct_CCR_EOG_ALL_BL7_PC                    803
# 82                        pct_CCR_EOG_ALL_EDS_PC                    596
# 83                        pct_CCR_EOG_ALL_ELS_PC                    832
# 84                        pct_CCR_EOG_ALL_FEM_PC                    601
# 85                        pct_CCR_EOG_ALL_HI7_PC                    679
# 86                       pct_CCR_EOG_ALL_MALE_PC                    587
# 87                        pct_CCR_EOG_ALL_MU7_PC                    886
# 88                        pct_CCR_EOG_ALL_SWD_PC                    765
# 89                        pct_CCR_EOG_ALL_WH7_PC                    635
# 90                          pct_CCR_MA_03_ALL_PC                   1140
# 91                          pct_CCR_MA_03_EDS_PC                   1182
# 92                          pct_CCR_MA_03_FEM_PC                   1164
# 93                         pct_CCR_MA_03_MALE_PC                   1165
# 94                          pct_CCR_MA_03_WH7_PC                   1370
# 95                          pct_CCR_MA_04_ALL_PC                   1143
# 96                          pct_CCR_MA_04_EDS_PC                   1197
# 97                          pct_CCR_MA_04_FEM_PC                   1173
# 98                         pct_CCR_MA_04_MALE_PC                   1164
# 99                          pct_CCR_MA_04_WH7_PC                   1374
# 100                         pct_CCR_MA_05_ALL_PC                   1168
# 101                         pct_CCR_MA_05_EDS_PC                   1214
# 102                         pct_CCR_MA_05_FEM_PC                   1195
# 103                        pct_CCR_MA_05_MALE_PC                   1190
# 104                         pct_CCR_MA_05_WH7_PC                   1394
# 105                        pct_CCR_MA_ALL_AIG_PC                    958
# 106                        pct_CCR_MA_ALL_ALL_PC                    606
# 107                        pct_CCR_MA_ALL_BL7_PC                    938
# 108                        pct_CCR_MA_ALL_EDS_PC                    622
# 109                        pct_CCR_MA_ALL_ELS_PC                   1033
# 110                        pct_CCR_MA_ALL_FEM_PC                    624
# 111                        pct_CCR_MA_ALL_HI7_PC                    811
# 112                       pct_CCR_MA_ALL_MALE_PC                    612
# 113                        pct_CCR_MA_ALL_MU7_PC                   1332
# 114                        pct_CCR_MA_ALL_SWD_PC                    935
# 115                        pct_CCR_MA_ALL_WH7_PC                    720
# 116                         pct_CCR_RD_03_ALL_PC                   1141
# 117                         pct_CCR_RD_03_EDS_PC                   1185
# 118                         pct_CCR_RD_03_FEM_PC                   1164
# 119                        pct_CCR_RD_03_MALE_PC                   1173
# 120                         pct_CCR_RD_03_WH7_PC                   1370
# 121                         pct_CCR_RD_04_ALL_PC                   1139
# 122                         pct_CCR_RD_04_EDS_PC                   1189
# 123                         pct_CCR_RD_04_FEM_PC                   1168
# 124                        pct_CCR_RD_04_MALE_PC                   1163
# 125                         pct_CCR_RD_04_WH7_PC                   1375
# 126                         pct_CCR_RD_05_ALL_PC                   1169
# 127                         pct_CCR_RD_05_EDS_PC                   1214
# 128                         pct_CCR_RD_05_FEM_PC                   1197
# 129                        pct_CCR_RD_05_MALE_PC                   1192
# 130                         pct_CCR_RD_05_WH7_PC                   1394
# 131                        pct_CCR_RD_ALL_AIG_PC                    958
# 132                        pct_CCR_RD_ALL_ALL_PC                    589
# 133                        pct_CCR_RD_ALL_BL7_PC                    919
# 134                        pct_CCR_RD_ALL_EDS_PC                    602
# 135                        pct_CCR_RD_ALL_ELS_PC                   1054
# 136                        pct_CCR_RD_ALL_FEM_PC                    614
# 137                        pct_CCR_RD_ALL_HI7_PC                    811
# 138                       pct_CCR_RD_ALL_MALE_PC                    593
# 139                        pct_CCR_RD_ALL_MU7_PC                   1328
# 140                        pct_CCR_RD_ALL_SWD_PC                    929
# 141                        pct_CCR_RD_ALL_WH7_PC                    713
# 142                         pct_CCR_SC_05_ALL_PC                   1169
# 143                         pct_CCR_SC_05_EDS_PC                   1211
# 144                         pct_CCR_SC_05_FEM_PC                   1194
# 145                        pct_CCR_SC_05_MALE_PC                   1186
# 146                         pct_CCR_SC_05_WH7_PC                   1394
# 147                        pct_CCR_SC_ALL_AIG_PC                   1370
# 148                        pct_CCR_SC_ALL_ALL_PC                    686
# 149                        pct_CCR_SC_ALL_BL7_PC                   1240
# 150                        pct_CCR_SC_ALL_EDS_PC                    741
# 151                        pct_CCR_SC_ALL_FEM_PC                    732
# 152                        pct_CCR_SC_ALL_HI7_PC                   1285
# 153                       pct_CCR_SC_ALL_MALE_PC                    706
# 154                        pct_CCR_SC_ALL_SWD_PC                   1291
# 155                        pct_CCR_SC_ALL_WH7_PC                    954
# 156                        pct_GLP_EOG_03_ALL_PC                   1132
# 157                        pct_GLP_EOG_03_BL7_PC                   1449
# 158                        pct_GLP_EOG_03_EDS_PC                   1147
# 159                        pct_GLP_EOG_03_FEM_PC                   1141
# 160                        pct_GLP_EOG_03_HI7_PC                   1419
# 161                       pct_GLP_EOG_03_MALE_PC                   1138
# 162                        pct_GLP_EOG_03_SWD_PC                   1349
# 163                        pct_GLP_EOG_03_WH7_PC                   1274
# 164                        pct_GLP_EOG_04_ALL_PC                   1131
# 165                        pct_GLP_EOG_04_BL7_PC                   1461
# 166                        pct_GLP_EOG_04_EDS_PC                   1151
# 167                        pct_GLP_EOG_04_FEM_PC                   1141
# 168                        pct_GLP_EOG_04_HI7_PC                   1403
# 169                       pct_GLP_EOG_04_MALE_PC                   1142
# 170                        pct_GLP_EOG_04_SWD_PC                   1409
# 171                        pct_GLP_EOG_04_WH7_PC                   1270
# 172                        pct_GLP_EOG_05_AIG_PC                   1384
# 173                        pct_GLP_EOG_05_ALL_PC                   1148
# 174                        pct_GLP_EOG_05_BL7_PC                   1429
# 175                        pct_GLP_EOG_05_EDS_PC                   1168
# 176                        pct_GLP_EOG_05_FEM_PC                   1168
# 177                        pct_GLP_EOG_05_HI7_PC                   1359
# 178                       pct_GLP_EOG_05_MALE_PC                   1159
# 179                        pct_GLP_EOG_05_SWD_PC                   1340
# 180                        pct_GLP_EOG_05_WH7_PC                   1280
# 181                       pct_GLP_EOG_ALL_AIG_PC                    746
# 182                       pct_GLP_EOG_ALL_ALL_PC                    570
# 183                       pct_GLP_EOG_ALL_BL7_PC                    795
# 184                       pct_GLP_EOG_ALL_EDS_PC                    583
# 185                       pct_GLP_EOG_ALL_ELS_PC                    823
# 186                       pct_GLP_EOG_ALL_FEM_PC                    589
# 187                       pct_GLP_EOG_ALL_HI7_PC                    674
# 188                      pct_GLP_EOG_ALL_MALE_PC                    574
# 189                       pct_GLP_EOG_ALL_MU7_PC                    877
# 190                       pct_GLP_EOG_ALL_SWD_PC                    659
# 191                       pct_GLP_EOG_ALL_WH7_PC                    625
# 192                         pct_GLP_MA_03_ALL_PC                   1139
# 193                         pct_GLP_MA_03_EDS_PC                   1179
# 194                         pct_GLP_MA_03_FEM_PC                   1162
# 195                        pct_GLP_MA_03_MALE_PC                   1161
# 196                         pct_GLP_MA_03_WH7_PC                   1370
# 197                         pct_GLP_MA_04_ALL_PC                   1140
# 198                         pct_GLP_MA_04_EDS_PC                   1193
# 199                         pct_GLP_MA_04_FEM_PC                   1169
# 200                        pct_GLP_MA_04_MALE_PC                   1162
# 201                         pct_GLP_MA_04_WH7_PC                   1374
# 202                         pct_GLP_MA_05_ALL_PC                   1166
# 203                         pct_GLP_MA_05_EDS_PC                   1210
# 204                         pct_GLP_MA_05_FEM_PC                   1192
# 205                        pct_GLP_MA_05_MALE_PC                   1187
# 206                         pct_GLP_MA_05_WH7_PC                   1394
# 207                        pct_GLP_MA_ALL_AIG_PC                    958
# 208                        pct_GLP_MA_ALL_ALL_PC                    589
# 209                        pct_GLP_MA_ALL_BL7_PC                    915
# 210                        pct_GLP_MA_ALL_EDS_PC                    609
# 211                        pct_GLP_MA_ALL_ELS_PC                   1026
# 212                        pct_GLP_MA_ALL_FEM_PC                    616
# 213                        pct_GLP_MA_ALL_HI7_PC                    810
# 214                       pct_GLP_MA_ALL_MALE_PC                    596
# 215                        pct_GLP_MA_ALL_MU7_PC                   1327
# 216                        pct_GLP_MA_ALL_SWD_PC                    778
# 217                        pct_GLP_MA_ALL_WH7_PC                    711
# 218                         pct_GLP_RD_03_ALL_PC                   1140
# 219                         pct_GLP_RD_03_EDS_PC                   1181
# 220                         pct_GLP_RD_03_FEM_PC                   1164
# 221                        pct_GLP_RD_03_MALE_PC                   1163
# 222                         pct_GLP_RD_03_WH7_PC                   1370
# 223                         pct_GLP_RD_04_ALL_PC                   1139
# 224                         pct_GLP_RD_04_EDS_PC                   1187
# 225                         pct_GLP_RD_04_FEM_PC                   1166
# 226                        pct_GLP_RD_04_MALE_PC                   1161
# 227                         pct_GLP_RD_04_WH7_PC                   1375
# 228                         pct_GLP_RD_05_ALL_PC                   1166
# 229                         pct_GLP_RD_05_EDS_PC                   1206
# 230                         pct_GLP_RD_05_FEM_PC                   1192
# 231                        pct_GLP_RD_05_MALE_PC                   1186
# 232                         pct_GLP_RD_05_WH7_PC                   1394
# 233                        pct_GLP_RD_ALL_AIG_PC                    958
# 234                        pct_GLP_RD_ALL_ALL_PC                    577
# 235                        pct_GLP_RD_ALL_BL7_PC                    905
# 236                        pct_GLP_RD_ALL_EDS_PC                    589
# 237                        pct_GLP_RD_ALL_ELS_PC                   1027
# 238                        pct_GLP_RD_ALL_FEM_PC                    609
# 239                        pct_GLP_RD_ALL_HI7_PC                    807
# 240                       pct_GLP_RD_ALL_MALE_PC                    585
# 241                        pct_GLP_RD_ALL_MU7_PC                   1326
# 242                        pct_GLP_RD_ALL_SWD_PC                    763
# 243                        pct_GLP_RD_ALL_WH7_PC                    708
# 244                         pct_GLP_SC_05_ALL_PC                   1166
# 245                         pct_GLP_SC_05_EDS_PC                   1208
# 246                         pct_GLP_SC_05_FEM_PC                   1193
# 247                        pct_GLP_SC_05_MALE_PC                   1186
# 248                         pct_GLP_SC_05_WH7_PC                   1394
# 249                        pct_GLP_SC_ALL_AIG_PC                   1370
# 250                        pct_GLP_SC_ALL_ALL_PC                    677
# 251                        pct_GLP_SC_ALL_BL7_PC                   1231
# 252                        pct_GLP_SC_ALL_EDS_PC                    731
# 253                        pct_GLP_SC_ALL_FEM_PC                    730
# 254                        pct_GLP_SC_ALL_HI7_PC                   1281
# 255                       pct_GLP_SC_ALL_MALE_PC                    701
# 256                        pct_GLP_SC_ALL_SWD_PC                   1247
# 257                        pct_GLP_SC_ALL_WH7_PC                    954
# 258                        pct_L1_ALL_ALL_ALL_PC                    185
# 259                        pct_L1_ALL_ALL_BL7_PC                    400
# 260                        pct_L1_ALL_ALL_EDS_PC                    136
# 261                        pct_L1_ALL_ALL_ELS_PC                    502
# 262                        pct_L1_ALL_ALL_FEM_PC                    226
# 263                        pct_L1_ALL_ALL_HI7_PC                    324
# 264                       pct_L1_ALL_ALL_MALE_PC                    181
# 265                        pct_L1_ALL_ALL_MU7_PC                    712
# 266                        pct_L1_ALL_ALL_SWD_PC                    181
# 267                        pct_L1_ALL_ALL_WH7_PC                    414
# 268                         pct_L1_EOG_03_ALL_PC                   1200
# 269                         pct_L1_EOG_03_EDS_PC                   1164
# 270                         pct_L1_EOG_03_FEM_PC                   1250
# 271                         pct_L1_EOG_03_HI7_PC                   1468
# 272                        pct_L1_EOG_03_MALE_PC                   1203
# 273                         pct_L1_EOG_03_SWD_PC                   1276
# 274                         pct_L1_EOG_04_ALL_PC                   1177
# 275                         pct_L1_EOG_04_BL7_PC                   1472
# 276                         pct_L1_EOG_04_EDS_PC                   1165
# 277                         pct_L1_EOG_04_FEM_PC                   1216
# 278                         pct_L1_EOG_04_HI7_PC                   1444
# 279                        pct_L1_EOG_04_MALE_PC                   1186
# 280                         pct_L1_EOG_04_SWD_PC                   1278
# 281                         pct_L1_EOG_04_WH7_PC                   1422
# 282                         pct_L1_EOG_05_ALL_PC                   1204
# 283                         pct_L1_EOG_05_BL7_PC                   1457
# 284                         pct_L1_EOG_05_EDS_PC                   1189
# 285                         pct_L1_EOG_05_FEM_PC                   1270
# 286                         pct_L1_EOG_05_HI7_PC                   1430
# 287                        pct_L1_EOG_05_MALE_PC                   1216
# 288                         pct_L1_EOG_05_SWD_PC                   1230
# 289                         pct_L1_EOG_05_WH7_PC                   1472
# 290                        pct_L1_EOG_ALL_ALL_PC                    611
# 291                        pct_L1_EOG_ALL_BL7_PC                    798
# 292                        pct_L1_EOG_ALL_EDS_PC                    574
# 293                        pct_L1_EOG_ALL_ELS_PC                    834
# 294                        pct_L1_EOG_ALL_FEM_PC                    651
# 295                        pct_L1_EOG_ALL_HI7_PC                    728
# 296                       pct_L1_EOG_ALL_MALE_PC                    603
# 297                        pct_L1_EOG_ALL_MU7_PC                   1040
# 298                        pct_L1_EOG_ALL_SWD_PC                    584
# 299                        pct_L1_EOG_ALL_WH7_PC                    799
# 300                          pct_L1_MA_03_ALL_PC                   1301
# 301                          pct_L1_MA_03_EDS_PC                   1260
# 302                          pct_L1_MA_03_FEM_PC                   1386
# 303                         pct_L1_MA_03_MALE_PC                   1327
# 304                          pct_L1_MA_04_ALL_PC                   1215
# 305                          pct_L1_MA_04_EDS_PC                   1210
# 306                          pct_L1_MA_04_FEM_PC                   1272
# 307                         pct_L1_MA_04_MALE_PC                   1248
# 308                          pct_L1_MA_05_ALL_PC                   1257
# 309                          pct_L1_MA_05_EDS_PC                   1235
# 310                          pct_L1_MA_05_FEM_PC                   1320
# 311                         pct_L1_MA_05_MALE_PC                   1289
# 312                         pct_L1_MA_ALL_ALL_PC                    642
# 313                         pct_L1_MA_ALL_BL7_PC                    917
# 314                         pct_L1_MA_ALL_EDS_PC                    603
# 315                         pct_L1_MA_ALL_ELS_PC                   1068
# 316                         pct_L1_MA_ALL_FEM_PC                    710
# 317                         pct_L1_MA_ALL_HI7_PC                    878
# 318                        pct_L1_MA_ALL_MALE_PC                    656
# 319                         pct_L1_MA_ALL_MU7_PC                   1426
# 320                         pct_L1_MA_ALL_SWD_PC                    642
# 321                         pct_L1_MA_ALL_WH7_PC                    920
# 322                          pct_L1_RD_03_ALL_PC                   1175
# 323                          pct_L1_RD_03_EDS_PC                   1185
# 324                          pct_L1_RD_03_FEM_PC                   1242
# 325                         pct_L1_RD_03_MALE_PC                   1197
# 326                          pct_L1_RD_04_ALL_PC                   1173
# 327                          pct_L1_RD_04_EDS_PC                   1194
# 328                          pct_L1_RD_04_FEM_PC                   1245
# 329                         pct_L1_RD_04_MALE_PC                   1190
# 330                          pct_L1_RD_05_ALL_PC                   1195
# 331                          pct_L1_RD_05_EDS_PC                   1213
# 332                          pct_L1_RD_05_FEM_PC                   1258
# 333                         pct_L1_RD_05_MALE_PC                   1211
# 334                         pct_L1_RD_ALL_ALL_PC                    603
# 335                         pct_L1_RD_ALL_BL7_PC                    911
# 336                         pct_L1_RD_ALL_EDS_PC                    591
# 337                         pct_L1_RD_ALL_ELS_PC                   1027
# 338                         pct_L1_RD_ALL_FEM_PC                    678
# 339                         pct_L1_RD_ALL_HI7_PC                    836
# 340                        pct_L1_RD_ALL_MALE_PC                    603
# 341                         pct_L1_RD_ALL_MU7_PC                   1412
# 342                         pct_L1_RD_ALL_SWD_PC                    640
# 343                         pct_L1_RD_ALL_WH7_PC                    860
# 344                          pct_L1_SC_05_ALL_PC                   1357
# 345                          pct_L1_SC_05_EDS_PC                   1300
# 346                          pct_L1_SC_05_FEM_PC                   1434
# 347                         pct_L1_SC_05_MALE_PC                   1388
# 348                         pct_L1_SC_ALL_ALL_PC                    897
# 349                         pct_L1_SC_ALL_BL7_PC                   1285
# 350                         pct_L1_SC_ALL_EDS_PC                    837
# 351                         pct_L1_SC_ALL_FEM_PC                   1035
# 352                         pct_L1_SC_ALL_HI7_PC                   1394
# 353                        pct_L1_SC_ALL_MALE_PC                    935
# 354                         pct_L1_SC_ALL_SWD_PC                   1233
# 355                        pct_L2_ALL_ALL_ALL_PC                     89
# 356                        pct_L2_ALL_ALL_BL7_PC                    364
# 357                        pct_L2_ALL_ALL_EDS_PC                     95
# 358                        pct_L2_ALL_ALL_ELS_PC                    496
# 359                        pct_L2_ALL_ALL_FEM_PC                    108
# 360                        pct_L2_ALL_ALL_HI7_PC                    236
# 361                       pct_L2_ALL_ALL_MALE_PC                    110
# 362                        pct_L2_ALL_ALL_MU7_PC                    600
# 363                        pct_L2_ALL_ALL_SWD_PC                    210
# 364                        pct_L2_ALL_ALL_WH7_PC                    219
# 365                         pct_L2_EOG_03_ALL_PC                   1136
# 366                         pct_L2_EOG_03_BL7_PC                   1452
# 367                         pct_L2_EOG_03_EDS_PC                   1151
# 368                         pct_L2_EOG_03_FEM_PC                   1162
# 369                         pct_L2_EOG_03_HI7_PC                   1448
# 370                        pct_L2_EOG_03_MALE_PC                   1149
# 371                         pct_L2_EOG_03_SWD_PC                   1323
# 372                         pct_L2_EOG_03_WH7_PC                   1321
# 373                         pct_L2_EOG_04_ALL_PC                   1144
# 374                         pct_L2_EOG_04_BL7_PC                   1468
# 375                         pct_L2_EOG_04_EDS_PC                   1158
# 376                         pct_L2_EOG_04_FEM_PC                   1164
# 377                         pct_L2_EOG_04_HI7_PC                   1436
# 378                        pct_L2_EOG_04_MALE_PC                   1168
# 379                         pct_L2_EOG_04_SWD_PC                   1358
# 380                         pct_L2_EOG_04_WH7_PC                   1331
# 381                         pct_L2_EOG_05_ALL_PC                   1156
# 382                         pct_L2_EOG_05_BL7_PC                   1431
# 383                         pct_L2_EOG_05_EDS_PC                   1174
# 384                         pct_L2_EOG_05_FEM_PC                   1187
# 385                         pct_L2_EOG_05_HI7_PC                   1394
# 386                        pct_L2_EOG_05_MALE_PC                   1176
# 387                         pct_L2_EOG_05_SWD_PC                   1276
# 388                         pct_L2_EOG_05_WH7_PC                   1335
# 389                        pct_L2_EOG_ALL_ALL_PC                    569
# 390                        pct_L2_EOG_ALL_BL7_PC                    784
# 391                        pct_L2_EOG_ALL_EDS_PC                    571
# 392                        pct_L2_EOG_ALL_ELS_PC                    825
# 393                        pct_L2_EOG_ALL_FEM_PC                    586
# 394                        pct_L2_EOG_ALL_HI7_PC                    678
# 395                       pct_L2_EOG_ALL_MALE_PC                    571
# 396                        pct_L2_EOG_ALL_MU7_PC                    936
# 397                        pct_L2_EOG_ALL_SWD_PC                    607
# 398                        pct_L2_EOG_ALL_WH7_PC                    663
# 399                          pct_L2_MA_03_ALL_PC                   1168
# 400                          pct_L2_MA_03_EDS_PC                   1200
# 401                          pct_L2_MA_03_FEM_PC                   1215
# 402                         pct_L2_MA_03_MALE_PC                   1221
# 403                          pct_L2_MA_04_ALL_PC                   1155
# 404                          pct_L2_MA_04_EDS_PC                   1198
# 405                          pct_L2_MA_04_FEM_PC                   1197
# 406                         pct_L2_MA_04_MALE_PC                   1200
# 407                          pct_L2_MA_04_WH7_PC                   1440
# 408                          pct_L2_MA_05_ALL_PC                   1187
# 409                          pct_L2_MA_05_EDS_PC                   1225
# 410                          pct_L2_MA_05_FEM_PC                   1240
# 411                         pct_L2_MA_05_MALE_PC                   1229
# 412                          pct_L2_MA_05_WH7_PC                   1473
# 413                         pct_L2_MA_ALL_ALL_PC                    586
# 414                         pct_L2_MA_ALL_BL7_PC                    904
# 415                         pct_L2_MA_ALL_EDS_PC                    593
# 416                         pct_L2_MA_ALL_ELS_PC                   1046
# 417                         pct_L2_MA_ALL_FEM_PC                    627
# 418                         pct_L2_MA_ALL_HI7_PC                    838
# 419                        pct_L2_MA_ALL_MALE_PC                    597
# 420                         pct_L2_MA_ALL_MU7_PC                   1375
# 421                         pct_L2_MA_ALL_SWD_PC                    689
# 422                         pct_L2_MA_ALL_WH7_PC                    765
# 423                          pct_L2_RD_03_ALL_PC                   1144
# 424                          pct_L2_RD_03_EDS_PC                   1190
# 425                          pct_L2_RD_03_FEM_PC                   1190
# 426                         pct_L2_RD_03_MALE_PC                   1174
# 427                          pct_L2_RD_03_WH7_PC                   1412
# 428                          pct_L2_RD_04_ALL_PC                   1169
# 429                          pct_L2_RD_04_EDS_PC                   1207
# 430                          pct_L2_RD_04_FEM_PC                   1217
# 431                         pct_L2_RD_04_MALE_PC                   1212
# 432                          pct_L2_RD_04_WH7_PC                   1475
# 433                          pct_L2_RD_05_ALL_PC                   1176
# 434                          pct_L2_RD_05_EDS_PC                   1218
# 435                          pct_L2_RD_05_FEM_PC                   1219
# 436                         pct_L2_RD_05_MALE_PC                   1210
# 437                          pct_L2_RD_05_WH7_PC                   1447
# 438                         pct_L2_RD_ALL_ALL_PC                    575
# 439                         pct_L2_RD_ALL_BL7_PC                    907
# 440                         pct_L2_RD_ALL_EDS_PC                    584
# 441                         pct_L2_RD_ALL_ELS_PC                   1034
# 442                         pct_L2_RD_ALL_FEM_PC                    618
# 443                         pct_L2_RD_ALL_HI7_PC                    827
# 444                        pct_L2_RD_ALL_MALE_PC                    587
# 445                         pct_L2_RD_ALL_MU7_PC                   1400
# 446                         pct_L2_RD_ALL_SWD_PC                    730
# 447                         pct_L2_RD_ALL_WH7_PC                    750
# 448                          pct_L2_SC_05_ALL_PC                   1232
# 449                          pct_L2_SC_05_EDS_PC                   1240
# 450                          pct_L2_SC_05_FEM_PC                   1280
# 451                         pct_L2_SC_05_MALE_PC                   1297
# 452                         pct_L2_SC_ALL_ALL_PC                    801
# 453                         pct_L2_SC_ALL_BL7_PC                   1277
# 454                         pct_L2_SC_ALL_EDS_PC                    794
# 455                         pct_L2_SC_ALL_FEM_PC                    893
# 456                         pct_L2_SC_ALL_HI7_PC                   1395
# 457                        pct_L2_SC_ALL_MALE_PC                    894
# 458                         pct_L2_SC_ALL_SWD_PC                   1286
# 459                         pct_L2_SC_ALL_WH7_PC                   1342
# 460                        pct_L3_ALL_ALL_ALL_PC                    147
# 461                        pct_L3_ALL_ALL_BL7_PC                    499
# 462                        pct_L3_ALL_ALL_EDS_PC                    153
# 463                        pct_L3_ALL_ALL_ELS_PC                    796
# 464                        pct_L3_ALL_ALL_FEM_PC                    153
# 465                        pct_L3_ALL_ALL_HI7_PC                    348
# 466                       pct_L3_ALL_ALL_MALE_PC                    194
# 467                        pct_L3_ALL_ALL_MU7_PC                    857
# 468                        pct_L3_ALL_ALL_SWD_PC                   1043
# 469                        pct_L3_ALL_ALL_WH7_PC                    314
# 470                         pct_L3_EOG_03_ALL_PC                   1158
# 471                         pct_L3_EOG_03_EDS_PC                   1197
# 472                         pct_L3_EOG_03_FEM_PC                   1194
# 473                        pct_L3_EOG_03_MALE_PC                   1220
# 474                         pct_L3_EOG_03_WH7_PC                   1380
# 475                         pct_L3_EOG_04_ALL_PC                   1197
# 476                         pct_L3_EOG_04_EDS_PC                   1253
# 477                         pct_L3_EOG_04_FEM_PC                   1276
# 478                        pct_L3_EOG_04_MALE_PC                   1276
# 479                         pct_L3_EOG_04_WH7_PC                   1433
# 480                         pct_L3_EOG_05_ALL_PC                   1195
# 481                         pct_L3_EOG_05_EDS_PC                   1237
# 482                         pct_L3_EOG_05_FEM_PC                   1243
# 483                        pct_L3_EOG_05_MALE_PC                   1268
# 484                         pct_L3_EOG_05_WH7_PC                   1420
# 485                        pct_L3_EOG_ALL_ALL_PC                    619
# 486                        pct_L3_EOG_ALL_BL7_PC                    893
# 487                        pct_L3_EOG_ALL_EDS_PC                    627
# 488                        pct_L3_EOG_ALL_ELS_PC                   1011
# 489                        pct_L3_EOG_ALL_FEM_PC                    634
# 490                        pct_L3_EOG_ALL_HI7_PC                    781
# 491                       pct_L3_EOG_ALL_MALE_PC                    645
# 492                        pct_L3_EOG_ALL_MU7_PC                   1149
# 493                        pct_L3_EOG_ALL_SWD_PC                   1282
# 494                        pct_L3_EOG_ALL_WH7_PC                    741
# 495                          pct_L3_MA_03_ALL_PC                   1202
# 496                          pct_L3_MA_03_EDS_PC                   1264
# 497                          pct_L3_MA_03_FEM_PC                   1275
# 498                         pct_L3_MA_03_MALE_PC                   1313
# 499                          pct_L3_MA_04_ALL_PC                   1475
# 500                         pct_L3_MA_ALL_ALL_PC                    749
# 501                         pct_L3_MA_ALL_BL7_PC                   1200
# 502                         pct_L3_MA_ALL_EDS_PC                    801
# 503                         pct_L3_MA_ALL_ELS_PC                   1371
# 504                         pct_L3_MA_ALL_FEM_PC                    823
# 505                         pct_L3_MA_ALL_HI7_PC                   1082
# 506                        pct_L3_MA_ALL_MALE_PC                    843
# 507                         pct_L3_MA_ALL_WH7_PC                   1027
# 508                          pct_L3_RD_03_ALL_PC                   1213
# 509                          pct_L3_RD_03_EDS_PC                   1322
# 510                          pct_L3_RD_03_FEM_PC                   1315
# 511                         pct_L3_RD_03_MALE_PC                   1340
# 512                          pct_L3_RD_04_ALL_PC                   1187
# 513                          pct_L3_RD_04_EDS_PC                   1274
# 514                          pct_L3_RD_04_FEM_PC                   1279
# 515                         pct_L3_RD_04_MALE_PC                   1271
# 516                          pct_L3_RD_05_ALL_PC                   1210
# 517                          pct_L3_RD_05_EDS_PC                   1327
# 518                          pct_L3_RD_05_FEM_PC                   1265
# 519                         pct_L3_RD_05_MALE_PC                   1306
# 520                         pct_L3_RD_ALL_ALL_PC                    610
# 521                         pct_L3_RD_ALL_BL7_PC                   1025
# 522                         pct_L3_RD_ALL_EDS_PC                    639
# 523                         pct_L3_RD_ALL_ELS_PC                   1222
# 524                         pct_L3_RD_ALL_FEM_PC                    636
# 525                         pct_L3_RD_ALL_HI7_PC                    928
# 526                        pct_L3_RD_ALL_MALE_PC                    648
# 527                         pct_L3_RD_ALL_SWD_PC                   1415
# 528                         pct_L3_RD_ALL_WH7_PC                    789
# 529                          pct_L3_SC_05_ALL_PC                   1308
# 530                          pct_L3_SC_05_EDS_PC                   1352
# 531                          pct_L3_SC_05_FEM_PC                   1379
# 532                         pct_L3_SC_05_MALE_PC                   1443
# 533                         pct_L3_SC_ALL_ALL_PC                    896
# 534                         pct_L3_SC_ALL_BL7_PC                   1390
# 535                         pct_L3_SC_ALL_EDS_PC                    918
# 536                         pct_L3_SC_ALL_FEM_PC                   1006
# 537                        pct_L3_SC_ALL_MALE_PC                   1058
# 538                         pct_L3_SC_ALL_WH7_PC                   1408
# 539                        pct_L4_ALL_ALL_AIG_PC                    277
# 540                        pct_L4_ALL_ALL_ALL_PC                     86
# 541                        pct_L4_ALL_ALL_AS7_PC                   1443
# 542                        pct_L4_ALL_ALL_BL7_PC                    369
# 543                        pct_L4_ALL_ALL_EDS_PC                    109
# 544                        pct_L4_ALL_ALL_ELS_PC                    540
# 545                        pct_L4_ALL_ALL_FEM_PC                    105
# 546                        pct_L4_ALL_ALL_HI7_PC                    223
# 547                       pct_L4_ALL_ALL_MALE_PC                     94
# 548                        pct_L4_ALL_ALL_MU7_PC                    531
# 549                        pct_L4_ALL_ALL_SWD_PC                    521
# 550                        pct_L4_ALL_ALL_WH7_PC                    150
# 551                         pct_L4_EOG_03_ALL_PC                   1136
# 552                         pct_L4_EOG_03_BL7_PC                   1464
# 553                         pct_L4_EOG_03_EDS_PC                   1150
# 554                         pct_L4_EOG_03_FEM_PC                   1143
# 555                         pct_L4_EOG_03_HI7_PC                   1431
# 556                        pct_L4_EOG_03_MALE_PC                   1142
# 557                         pct_L4_EOG_03_WH7_PC                   1276
# 558                         pct_L4_EOG_04_ALL_PC                   1134
# 559                         pct_L4_EOG_04_BL7_PC                   1468
# 560                         pct_L4_EOG_04_EDS_PC                   1154
# 561                         pct_L4_EOG_04_FEM_PC                   1144
# 562                         pct_L4_EOG_04_HI7_PC                   1410
# 563                        pct_L4_EOG_04_MALE_PC                   1146
# 564                         pct_L4_EOG_04_WH7_PC                   1270
# 565                         pct_L4_EOG_05_AIG_PC                   1384
# 566                         pct_L4_EOG_05_ALL_PC                   1155
# 567                         pct_L4_EOG_05_BL7_PC                   1444
# 568                         pct_L4_EOG_05_EDS_PC                   1173
# 569                         pct_L4_EOG_05_FEM_PC                   1170
# 570                         pct_L4_EOG_05_HI7_PC                   1368
# 571                        pct_L4_EOG_05_MALE_PC                   1165
# 572                         pct_L4_EOG_05_WH7_PC                   1283
# 573                        pct_L4_EOG_ALL_AIG_PC                    746
# 574                        pct_L4_EOG_ALL_ALL_PC                    588
# 575                        pct_L4_EOG_ALL_BL7_PC                    804
# 576                        pct_L4_EOG_ALL_EDS_PC                    599
# 577                        pct_L4_EOG_ALL_ELS_PC                    835
# 578                        pct_L4_EOG_ALL_FEM_PC                    604
# 579                        pct_L4_EOG_ALL_HI7_PC                    682
# 580                       pct_L4_EOG_ALL_MALE_PC                    588
# 581                        pct_L4_EOG_ALL_MU7_PC                    890
# 582                        pct_L4_EOG_ALL_SWD_PC                    832
# 583                        pct_L4_EOG_ALL_WH7_PC                    638
# 584                          pct_L4_MA_03_ALL_PC                   1140
# 585                          pct_L4_MA_03_EDS_PC                   1187
# 586                          pct_L4_MA_03_FEM_PC                   1164
# 587                         pct_L4_MA_03_MALE_PC                   1166
# 588                          pct_L4_MA_03_WH7_PC                   1370
# 589                          pct_L4_MA_04_ALL_PC                   1144
# 590                          pct_L4_MA_04_EDS_PC                   1199
# 591                          pct_L4_MA_04_FEM_PC                   1175
# 592                         pct_L4_MA_04_MALE_PC                   1167
# 593                          pct_L4_MA_04_WH7_PC                   1376
# 594                          pct_L4_MA_05_ALL_PC                   1170
# 595                          pct_L4_MA_05_EDS_PC                   1220
# 596                          pct_L4_MA_05_FEM_PC                   1198
# 597                         pct_L4_MA_05_MALE_PC                   1195
# 598                          pct_L4_MA_05_WH7_PC                   1398
# 599                         pct_L4_MA_ALL_AIG_PC                    977
# 600                         pct_L4_MA_ALL_ALL_PC                    607
# 601                         pct_L4_MA_ALL_BL7_PC                    946
# 602                         pct_L4_MA_ALL_EDS_PC                    625
# 603                         pct_L4_MA_ALL_ELS_PC                   1040
# 604                         pct_L4_MA_ALL_FEM_PC                    625
# 605                         pct_L4_MA_ALL_HI7_PC                    814
# 606                        pct_L4_MA_ALL_MALE_PC                    613
# 607                         pct_L4_MA_ALL_MU7_PC                   1342
# 608                         pct_L4_MA_ALL_SWD_PC                   1035
# 609                         pct_L4_MA_ALL_WH7_PC                    723
# 610                          pct_L4_RD_03_ALL_PC                   1143
# 611                          pct_L4_RD_03_EDS_PC                   1191
# 612                          pct_L4_RD_03_FEM_PC                   1165
# 613                         pct_L4_RD_03_MALE_PC                   1177
# 614                          pct_L4_RD_03_WH7_PC                   1371
# 615                          pct_L4_RD_04_ALL_PC                   1140
# 616                          pct_L4_RD_04_EDS_PC                   1190
# 617                          pct_L4_RD_04_FEM_PC                   1168
# 618                         pct_L4_RD_04_MALE_PC                   1164
# 619                          pct_L4_RD_04_WH7_PC                   1375
# 620                          pct_L4_RD_05_ALL_PC                   1171
# 621                          pct_L4_RD_05_EDS_PC                   1223
# 622                          pct_L4_RD_05_FEM_PC                   1199
# 623                         pct_L4_RD_05_MALE_PC                   1194
# 624                          pct_L4_RD_05_WH7_PC                   1394
# 625                         pct_L4_RD_ALL_AIG_PC                    958
# 626                         pct_L4_RD_ALL_ALL_PC                    592
# 627                         pct_L4_RD_ALL_BL7_PC                    922
# 628                         pct_L4_RD_ALL_EDS_PC                    603
# 629                         pct_L4_RD_ALL_ELS_PC                   1062
# 630                         pct_L4_RD_ALL_FEM_PC                    618
# 631                         pct_L4_RD_ALL_HI7_PC                    816
# 632                        pct_L4_RD_ALL_MALE_PC                    599
# 633                         pct_L4_RD_ALL_MU7_PC                   1330
# 634                         pct_L4_RD_ALL_SWD_PC                   1062
# 635                         pct_L4_RD_ALL_WH7_PC                    714
# 636                          pct_L4_SC_05_ALL_PC                   1169
# 637                          pct_L4_SC_05_EDS_PC                   1212
# 638                          pct_L4_SC_05_FEM_PC                   1195
# 639                         pct_L4_SC_05_MALE_PC                   1186
# 640                          pct_L4_SC_05_WH7_PC                   1394
# 641                         pct_L4_SC_ALL_AIG_PC                   1390
# 642                         pct_L4_SC_ALL_ALL_PC                    687
# 643                         pct_L4_SC_ALL_BL7_PC                   1242
# 644                         pct_L4_SC_ALL_EDS_PC                    743
# 645                         pct_L4_SC_ALL_FEM_PC                    733
# 646                         pct_L4_SC_ALL_HI7_PC                   1285
# 647                        pct_L4_SC_ALL_MALE_PC                    706
# 648                         pct_L4_SC_ALL_SWD_PC                   1334
# 649                         pct_L4_SC_ALL_WH7_PC                    955
# 650                        pct_L5_ALL_ALL_AIG_PC                    291
# 651                        pct_L5_ALL_ALL_ALL_PC                    515
# 652                        pct_L5_ALL_ALL_EDS_PC                   1055
# 653                        pct_L5_ALL_ALL_FEM_PC                    558
# 654                        pct_L5_ALL_ALL_HI7_PC                    919
# 655                       pct_L5_ALL_ALL_MALE_PC                    507
# 656                        pct_L5_ALL_ALL_MU7_PC                   1037
# 657                        pct_L5_ALL_ALL_WH7_PC                    335
# 658                         pct_L5_EOG_03_ALL_PC                   1329
# 659                         pct_L5_EOG_03_FEM_PC                   1369
# 660                        pct_L5_EOG_03_MALE_PC                   1357
# 661                         pct_L5_EOG_03_WH7_PC                   1343
# 662                         pct_L5_EOG_04_ALL_PC                   1445
# 663                        pct_L5_EOG_04_MALE_PC                   1467
# 664                         pct_L5_EOG_04_WH7_PC                   1403
# 665                         pct_L5_EOG_05_AIG_PC                   1388
# 666                         pct_L5_EOG_05_ALL_PC                   1358
# 667                         pct_L5_EOG_05_FEM_PC                   1446
# 668                        pct_L5_EOG_05_MALE_PC                   1351
# 669                         pct_L5_EOG_05_WH7_PC                   1358
# 670                        pct_L5_EOG_ALL_AIG_PC                    748
# 671                        pct_L5_EOG_ALL_ALL_PC                    865
# 672                        pct_L5_EOG_ALL_EDS_PC                   1250
# 673                        pct_L5_EOG_ALL_FEM_PC                    905
# 674                        pct_L5_EOG_ALL_HI7_PC                   1149
# 675                       pct_L5_EOG_ALL_MALE_PC                    859
# 676                        pct_L5_EOG_ALL_MU7_PC                   1259
# 677                        pct_L5_EOG_ALL_WH7_PC                    755
# 678                          pct_L5_MA_03_ALL_PC                   1311
# 679                          pct_L5_MA_03_FEM_PC                   1381
# 680                         pct_L5_MA_03_MALE_PC                   1340
# 681                          pct_L5_MA_03_WH7_PC                   1425
# 682                          pct_L5_MA_04_ALL_PC                   1329
# 683                          pct_L5_MA_04_FEM_PC                   1432
# 684                         pct_L5_MA_04_MALE_PC                   1345
# 685                          pct_L5_MA_04_WH7_PC                   1436
# 686                          pct_L5_MA_05_ALL_PC                   1313
# 687                          pct_L5_MA_05_FEM_PC                   1398
# 688                         pct_L5_MA_05_MALE_PC                   1342
# 689                          pct_L5_MA_05_WH7_PC                   1438
# 690                         pct_L5_MA_ALL_AIG_PC                    961
# 691                         pct_L5_MA_ALL_ALL_PC                    822
# 692                         pct_L5_MA_ALL_EDS_PC                   1150
# 693                         pct_L5_MA_ALL_FEM_PC                    871
# 694                         pct_L5_MA_ALL_HI7_PC                   1107
# 695                        pct_L5_MA_ALL_MALE_PC                    839
# 696                         pct_L5_MA_ALL_WH7_PC                    817
# 697                          pct_L5_RD_03_ALL_PC                   1405
# 698                          pct_L5_RD_03_FEM_PC                   1448
# 699                          pct_L5_RD_03_WH7_PC                   1446
# 700                         pct_L5_RD_ALL_AIG_PC                    965
# 701                         pct_L5_RD_ALL_ALL_PC                   1115
# 702                         pct_L5_RD_ALL_FEM_PC                   1075
# 703                        pct_L5_RD_ALL_MALE_PC                   1216
# 704                         pct_L5_RD_ALL_WH7_PC                    886
# 705                          pct_L5_SC_05_ALL_PC                   1393
# 706                         pct_L5_SC_05_MALE_PC                   1378
# 707                          pct_L5_SC_05_WH7_PC                   1474
# 708                         pct_L5_SC_ALL_AIG_PC                   1375
# 709                         pct_L5_SC_ALL_ALL_PC                    940
# 710                         pct_L5_SC_ALL_EDS_PC                   1260
# 711                         pct_L5_SC_ALL_FEM_PC                   1071
# 712                        pct_L5_SC_ALL_MALE_PC                    926
# 713                         pct_L5_SC_ALL_WH7_PC                   1035
# 714                           pct_passed_eog_RTA                   1171
# 715                             pct_promoted_RTA                   1137
# 716                                     ma_score                    637
# 717                                     rd_score                    637
# 718                                     sc_score                    722
# 719                                    ach_score                    153
# 720                                     eg_score                    165
# 721                                    spg_score                    153
# 722                                 ma_spg_score                    637
# 723                                 rd_spg_score                    637
# 724                                  ma_eg_score                    661
# 725                                  rd_eg_score                    640
# 726                           aaa_score_ALL_SPG2                    141
# 727                           aaa_score_BL7_SPG2                    685
# 728                           aaa_score_EDS_SPG2                    187
# 729                           aaa_score_ELS_SPG2                   1113
# 730                           aaa_score_HI7_SPG2                    623
# 731                           aaa_score_SWD_SPG2                    438
# 732                           aaa_score_WH7_SPG2                    372
# 733                           ach_score_ALL_SPG2                    132
# 734                           ach_score_BL7_SPG2                    681
# 735                           ach_score_EDS_SPG2                    184
# 736                           ach_score_ELS_SPG2                   1113
# 737                           ach_score_HI7_SPG2                    622
# 738                           ach_score_SWD_SPG2                    437
# 739                           ach_score_WH7_SPG2                    363
# 740                            eg_score_ALL_SPG2                    155
# 741                            eg_score_BL7_SPG2                    819
# 742                            eg_score_EDS_SPG2                    225
# 743                            eg_score_ELS_SPG2                   1325
# 744                            eg_score_HI7_SPG2                    837
# 745                            eg_score_SWD_SPG2                    742
# 746                            eg_score_WH7_SPG2                    480
# 747                          scgs_score_ALL_SPG2                    772
# 748                          scgs_score_EDS_SPG2                   1170
# 749                          scgs_score_WH7_SPG2                   1335
# 750                           spg_score_ALL_SPG2                     94
# 751                           spg_score_BL7_SPG2                    646
# 752                           spg_score_EDS_SPG2                    146
# 753                           spg_score_ELS_SPG2                   1088
# 754                           spg_score_HI7_SPG2                    585
# 755                           spg_score_SWD_SPG2                    399
# 756                           spg_score_WH7_SPG2                    327
# 759                         pct_ALL_CHRON_ABSENT                     25
# 760                         pct_BL7_CHRON_ABSENT                    292
# 761                         pct_ELS_CHRON_ABSENT                    616
# 762                         pct_FEM_CHRON_ABSENT                     36
# 763                         pct_HI7_CHRON_ABSENT                    182
# 764                        pct_MALE_CHRON_ABSENT                     48
# 765                         pct_MU7_CHRON_ABSENT                    347
# 766                         pct_SWD_CHRON_ABSENT                    149
# 767                         pct_WH7_CHRON_ABSENT                     62
# 768                                   stu_enroll                   1337
# 769                                   cte_enroll                   1337
# 770                           cte_enrollment_pct                   1337
# 771                       Book_TitlesPer_Student                    155
# 772                                          wap                     26
# 773                                    wap_class                     26
# 774                                 media_school                    140
# 775                                      devices                      5
# 776                   pct_rating_T1_Accomplished                     56
# 777                  pct_rating_T1_Distinguished                    573
# 778                     pct_rating_T1_Proficient                    130
# 779                   pct_rating_T2_Accomplished                     80
# 780                  pct_rating_T2_Distinguished                   1059
# 781                     pct_rating_T2_Proficient                    211
# 782                   pct_rating_T3_Accomplished                    115
# 783                  pct_rating_T3_Distinguished                   1167
# 784                     pct_rating_T3_Proficient                    162
# 785                   pct_rating_T4_Accomplished                     62
# 786                  pct_rating_T4_Distinguished                    905
# 787                     pct_rating_T4_Proficient                    144
# 788                   pct_rating_T5_Accomplished                    111
# 789                  pct_rating_T5_Distinguished                   1167
# 790                     pct_rating_T5_Proficient                    150
# 791  pct_rating_TS_Does Not Meet Expected Growth                     80
# 792        pct_rating_TS_Exceeds Expected Growth                     80
# 793          pct_rating_TS_Meets Expected Growth                     80
# 794                   avg_class_teach_TeacherExp                      3
# 795                    pct_adv_degree_TeacherExp                      3
# 796                  pct_experience_0_TeacherExp                      3
# 797                 pct_experience_10_TeacherExp                      3
# 798                  pct_experience_4_TeacherExp                      3
# 799                      pct_turnover_TeacherExp                     29
# 800                         highqual_class_pct_E                   1175
# 801                                        crime                     27
# 802                                   short_term                     27
# 803                                    long_term                     27
# 804                                    expulsion                     27
# 805                             arre_per1000_ALL                     64
# 806                             arre_per1000_BL7                    276
# 809                             arre_per1000_FEM                    162
# 810                             arre_per1000_HI7                    352
# 811                            arre_per1000_MALE                     78
# 812                             arre_per1000_MU7                    454
# 813                             arre_per1000_SWD                     26
# 814                             arre_per1000_WH7                    138
# 815                             blhr_per1000_ALL                     64
# 816                             blhr_per1000_BL7                    276
# 819                             blhr_per1000_FEM                    162
# 820                             blhr_per1000_HI7                    352
# 821                            blhr_per1000_MALE                     78
# 822                             blhr_per1000_MU7                    454
# 823                             blhr_per1000_SWD                     26
# 824                             blhr_per1000_WH7                    138
# 825                            crime_per1000_ALL                     64
# 826                            crime_per1000_BL7                    276
# 829                            crime_per1000_FEM                    162
# 830                            crime_per1000_HI7                    352
# 831                           crime_per1000_MALE                     78
# 832                            crime_per1000_MU7                    454
# 833                            crime_per1000_SWD                     26
# 834                            crime_per1000_WH7                    138
# 835                              exp_per1000_ALL                     65
# 836                              exp_per1000_BL7                    396
# 837                              exp_per1000_EDS                      9
# 838                              exp_per1000_ELS                    542
# 839                              exp_per1000_FEM                    172
# 840                              exp_per1000_HI7                    443
# 841                             exp_per1000_MALE                     84
# 842                              exp_per1000_MU7                    737
# 843                              exp_per1000_SWD                    145
# 844                              exp_per1000_WH7                    202
# 845                              iss_per1000_ALL                     65
# 846                              iss_per1000_BL7                    397
# 847                              iss_per1000_EDS                      9
# 848                              iss_per1000_ELS                    542
# 849                              iss_per1000_FEM                    172
# 850                              iss_per1000_HI7                    443
# 851                             iss_per1000_MALE                     84
# 852                              iss_per1000_MU7                    738
# 853                              iss_per1000_SWD                    145
# 854                              iss_per1000_WH7                    202
# 855                              lts_per1000_ALL                     65
# 856                              lts_per1000_BL7                    396
# 857                              lts_per1000_EDS                      9
# 858                              lts_per1000_ELS                    542
# 859                              lts_per1000_FEM                    172
# 860                              lts_per1000_HI7                    443
# 861                             lts_per1000_MALE                     84
# 862                              lts_per1000_MU7                    737
# 863                              lts_per1000_SWD                    145
# 864                              lts_per1000_WH7                    202
# 865                             rplw_per1000_ALL                     64
# 866                             rplw_per1000_BL7                    276
# 868                             rplw_per1000_FEM                    162
# 869                             rplw_per1000_HI7                    352
# 870                            rplw_per1000_MALE                     78
# 871                             rplw_per1000_MU7                    454
# 872                             rplw_per1000_SWD                     26
# 873                             rplw_per1000_WH7                    138
# 874                              sts_per1000_ALL                     65
# 875                              sts_per1000_BL7                    401
# 876                              sts_per1000_EDS                      9
# 877                              sts_per1000_ELS                    542
# 878                              sts_per1000_FEM                    174
# 879                              sts_per1000_HI7                    445
# 880                             sts_per1000_MALE                     89
# 881                              sts_per1000_MU7                    737
# 882                              sts_per1000_SWD                    149
# 883                              sts_per1000_WH7                    202
# 884                           pct_fully_licensed                      3
# 885                            pct_lateral_entry                      3
# 886                                    nbpts_num                      2
# 887                                pct_ready_kea                   1142
# 888                              avg_size_00_SAR                   1286
# 889                              avg_size_01_SAR                   1288
# 890                              avg_size_02_SAR                   1292
# 891                              avg_size_03_SAR                   1292
# 892                              avg_size_04_SAR                   1240
# 893                              avg_size_05_SAR                   1260
# 894                          avg_size_Math I_SAR                   1438

# %%
#Replace all remaining NaN with 0
schoolData = schoolData.fillna(0)

#Check for Missing values after final imputation 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# Empty DataFrame
# Columns: [Variable Name, Number Missing Values]
# Index: []

# %% [markdown]
# ## Identify and Remove Highly Correlated Features
# **Find and remove any columns / features that are > 95% correlated**
# * https://stackoverflow.com/questions/39409866/correlation-heatmap
# * https://chrisalbon.com/machine_learning/feature_selection/drop_highly_correlated_features/
# * https://codeyarns.com/2015/04/20/how-to-change-font-size-in-seaborn/

# %%
# calculate the correlation matrix
corr_matrix  = schoolData.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
#Get all of the correlation values > 95%
x = np.where(upper > 0.95)

#Display all field combinations with > 95% correlation
cf = pd.DataFrame()
cf['Field1'] = upper.columns[x[1]]
cf['Field2'] = upper.index[x[0]]

#Get the correlation values for every field combination. (There must be a more pythonic way to do this!)
corr = [0] * len(cf)
for i in range(0, len(cf)):
    corr[i] =  upper[cf['Field1'][i]][cf['Field2'][i]] 
    
cf['Correlation'] = corr

print ('There are ', str(len(cf['Field1'])), ' field correlations > 95%.')
cf
# Out:
# There are  1827  field correlations > 95%.
#                       Field1                            Field2  Correlation
# 0            indian_male_pct                        indian_pct     0.994686
# 1          indian_female_pct                        indian_pct     0.994488
# 2             asian_male_pct                         asian_pct     0.986677
# 3           asian_female_pct                         asian_pct     0.984804
# 4          hispanic_male_pct                      hispanic_pct     0.975855
# ...                      ...                               ...          ...
# 1822  agency_lea_code_241LEA  lea_name_Whiteville City Schools     1.000000
# 1823  agency_lea_code_970LEA    lea_name_Wilkes County Schools     1.000000
# 1824  agency_lea_code_980LEA    lea_name_Wilson County Schools     1.000000
# 1825  agency_lea_code_990LEA    lea_name_Yadkin County Schools     1.000000
# 1826  agency_lea_code_995LEA    lea_name_Yancey County Schools     1.000000
#
# [1827 rows x 3 columns]

# %%
#The old way
#print('Dropping the following ', str(len(to_drop)), ' highly correlated fields.')
#to_drop

# Comparing highly correlated unique field names in field 1 vs field 2 list above will allow you to 
# remove the least amount of fields possible.  
#len(cf['Field1'].unique())
#len(cf['Field2'].unique())

print('Dropping the following ', str(len(cf['Field2'].unique())), ' highly correlated, unique fields.')
cf['Field2'].unique()
# Out:
# Dropping the following  618  highly correlated, unique fields.
# array(['indian_pct', 'asian_pct', 'hispanic_pct', 'black_pct',
#        'white_pct', 'minority_pct', 'indian_male_pct', 'white_male_pct',
#        'minority_male_pct', 'pct_ALL_ELP', 'pct_met_Math Grades 3-8_PART',
#        'pct_met_Reading Grades 3-8_PART',
#        'pct_met_Science Grades 5&8_PART',
#        'pct_Math Grades 3-8_ALL_PART_DET',
#        'pct_Math Grades 3-8_BL7_PART_DET',
#        'pct_Math Grades 3-8_EDS_PART_DET',
#        'pct_Math Grades 3-8_HI7_PART_DET',
#        'pct_Math Grades 3-8_SWD_PART_DET',
#        'pct_Math Grades 3-8_WH7_PART_DET',
#        'pct_Science Grades 5&8_WH7_PART_DET', 'pct_CCR_EOG_03_ALL_PC',
#        'pct_CCR_EOG_03_BL7_PC', 'pct_CCR_EOG_03_EDS_PC',
#        'pct_CCR_EOG_03_FEM_PC', 'pct_CCR_EOG_03_HI7_PC',
#        'pct_CCR_EOG_03_MALE_PC', 'pct_CCR_EOG_03_SWD_PC',
#        'pct_CCR_EOG_03_WH7_PC', 'pct_CCR_EOG_04_ALL_PC',
#        'pct_CCR_EOG_04_BL7_PC', 'pct_CCR_EOG_04_EDS_PC',
#        'pct_CCR_EOG_04_FEM_PC', 'pct_CCR_EOG_04_HI7_PC',
#        'pct_CCR_EOG_04_MALE_PC', 'pct_CCR_EOG_04_WH7_PC',
#        'pct_CCR_EOG_05_AIG_PC', 'pct_CCR_EOG_05_ALL_PC',
#        'pct_CCR_EOG_05_BL7_PC', 'pct_CCR_EOG_05_EDS_PC',
#        'pct_CCR_EOG_05_FEM_PC', 'pct_CCR_EOG_05_HI7_PC',
#        'pct_CCR_EOG_05_MALE_PC', 'pct_CCR_EOG_05_SWD_PC',
#        'pct_CCR_EOG_05_WH7_PC', 'pct_CCR_EOG_ALL_AIG_PC',
#        'pct_CCR_EOG_ALL_ALL_PC', 'pct_CCR_EOG_ALL_BL7_PC',
#        'pct_CCR_EOG_ALL_EDS_PC', 'pct_CCR_EOG_ALL_ELS_PC',
#        'pct_CCR_EOG_ALL_FEM_PC', 'pct_CCR_EOG_ALL_HI7_PC',
#        'pct_CCR_EOG_ALL_MALE_PC', 'pct_CCR_EOG_ALL_MU7_PC',
#        'pct_CCR_EOG_ALL_SWD_PC', 'pct_CCR_EOG_ALL_WH7_PC',
#        'pct_CCR_MA_03_ALL_PC', 'pct_CCR_MA_03_EDS_PC',
#        'pct_CCR_MA_03_FEM_PC', 'pct_CCR_MA_03_MALE_PC',
#        'pct_CCR_MA_03_WH7_PC', 'pct_CCR_MA_04_ALL_PC',
#        'pct_CCR_MA_04_EDS_PC', 'pct_CCR_MA_04_FEM_PC',
#        'pct_CCR_MA_04_MALE_PC', 'pct_CCR_MA_04_WH7_PC',
#        'pct_CCR_MA_05_ALL_PC', 'pct_CCR_MA_05_EDS_PC',
#        'pct_CCR_MA_05_FEM_PC', 'pct_CCR_MA_05_MALE_PC',
#        'pct_CCR_MA_05_WH7_PC', 'pct_CCR_MA_ALL_AIG_PC',
#        'pct_CCR_MA_ALL_ALL_PC', 'pct_CCR_MA_ALL_BL7_PC',
#        'pct_CCR_MA_ALL_EDS_PC', 'pct_CCR_MA_ALL_ELS_PC',
#        'pct_CCR_MA_ALL_FEM_PC', 'pct_CCR_MA_ALL_HI7_PC',
#        'pct_CCR_MA_ALL_MALE_PC', 'pct_CCR_MA_ALL_MU7_PC',
#        'pct_CCR_MA_ALL_SWD_PC', 'pct_CCR_MA_ALL_WH7_PC',
#        'pct_CCR_RD_03_ALL_PC', 'pct_CCR_RD_03_EDS_PC',
#        'pct_CCR_RD_03_FEM_PC', 'pct_CCR_RD_03_MALE_PC',
#        'pct_CCR_RD_03_WH7_PC', 'pct_CCR_RD_04_ALL_PC',
#        'pct_CCR_RD_04_EDS_PC', 'pct_CCR_RD_04_FEM_PC',
#        'pct_CCR_RD_04_MALE_PC', 'pct_CCR_RD_04_WH7_PC',
#        'pct_CCR_RD_05_ALL_PC', 'pct_CCR_RD_05_EDS_PC',
#        'pct_CCR_RD_05_FEM_PC', 'pct_CCR_RD_05_MALE_PC',
#        'pct_CCR_RD_05_WH7_PC', 'pct_CCR_RD_ALL_AIG_PC',
#        'pct_CCR_RD_ALL_ALL_PC', 'pct_CCR_RD_ALL_BL7_PC',
#        'pct_CCR_RD_ALL_EDS_PC', 'pct_CCR_RD_ALL_ELS_PC',
#        'pct_CCR_RD_ALL_FEM_PC', 'pct_CCR_RD_ALL_HI7_PC',
#        'pct_CCR_RD_ALL_MALE_PC', 'pct_CCR_RD_ALL_MU7_PC',
#        'pct_CCR_RD_ALL_WH7_PC', 'pct_CCR_SC_05_ALL_PC',
#        'pct_CCR_SC_05_EDS_PC', 'pct_CCR_SC_05_FEM_PC',
#        'pct_CCR_SC_05_MALE_PC', 'pct_CCR_SC_05_WH7_PC',
#        'pct_CCR_SC_ALL_AIG_PC', 'pct_CCR_SC_ALL_ALL_PC',
#        'pct_CCR_SC_ALL_BL7_PC', 'pct_CCR_SC_ALL_EDS_PC',
#        'pct_CCR_SC_ALL_FEM_PC', 'pct_CCR_SC_ALL_HI7_PC',
#        'pct_CCR_SC_ALL_MALE_PC', 'pct_CCR_SC_ALL_SWD_PC',
#        'pct_CCR_SC_ALL_WH7_PC', 'pct_GLP_EOG_03_ALL_PC',
#        'pct_GLP_EOG_03_BL7_PC', 'pct_GLP_EOG_03_EDS_PC',
#        'pct_GLP_EOG_03_FEM_PC', 'pct_GLP_EOG_03_HI7_PC',
#        'pct_GLP_EOG_03_MALE_PC', 'pct_GLP_EOG_03_WH7_PC',
#        'pct_GLP_EOG_04_ALL_PC', 'pct_GLP_EOG_04_BL7_PC',
#        'pct_GLP_EOG_04_EDS_PC', 'pct_GLP_EOG_04_FEM_PC',
#        'pct_GLP_EOG_04_HI7_PC', 'pct_GLP_EOG_04_MALE_PC',
#        'pct_GLP_EOG_04_WH7_PC', 'pct_GLP_EOG_05_ALL_PC',
#        'pct_GLP_EOG_05_BL7_PC', 'pct_GLP_EOG_05_EDS_PC',
#        'pct_GLP_EOG_05_FEM_PC', 'pct_GLP_EOG_05_HI7_PC',
#        'pct_GLP_EOG_05_MALE_PC', 'pct_GLP_EOG_05_WH7_PC',
#        'pct_GLP_EOG_ALL_ALL_PC', 'pct_GLP_EOG_ALL_BL7_PC',
#        'pct_GLP_EOG_ALL_EDS_PC', 'pct_GLP_EOG_ALL_ELS_PC',
#        'pct_GLP_EOG_ALL_FEM_PC', 'pct_GLP_EOG_ALL_HI7_PC',
#        'pct_GLP_EOG_ALL_MALE_PC', 'pct_GLP_EOG_ALL_WH7_PC',
#        'pct_GLP_MA_03_ALL_PC', 'pct_GLP_MA_03_EDS_PC',
#        'pct_GLP_MA_03_FEM_PC', 'pct_GLP_MA_03_MALE_PC',
#        'pct_GLP_MA_03_WH7_PC', 'pct_GLP_MA_04_ALL_PC',
#        'pct_GLP_MA_04_EDS_PC', 'pct_GLP_MA_04_FEM_PC',
#        'pct_GLP_MA_04_MALE_PC', 'pct_GLP_MA_04_WH7_PC',
#        'pct_GLP_MA_05_ALL_PC', 'pct_GLP_MA_05_EDS_PC',
#        'pct_GLP_MA_05_FEM_PC', 'pct_GLP_MA_05_MALE_PC',
#        'pct_GLP_MA_05_WH7_PC', 'pct_GLP_MA_ALL_AIG_PC',
#        'pct_GLP_MA_ALL_ALL_PC', 'pct_GLP_MA_ALL_BL7_PC',
#        'pct_GLP_MA_ALL_EDS_PC', 'pct_GLP_MA_ALL_FEM_PC',
#        'pct_GLP_MA_ALL_MALE_PC', 'pct_GLP_MA_ALL_MU7_PC',
#        'pct_GLP_MA_ALL_WH7_PC', 'pct_GLP_RD_03_ALL_PC',
#        'pct_GLP_RD_03_EDS_PC', 'pct_GLP_RD_03_FEM_PC',
#        'pct_GLP_RD_03_MALE_PC', 'pct_GLP_RD_03_WH7_PC',
#        'pct_GLP_RD_04_ALL_PC', 'pct_GLP_RD_04_EDS_PC',
#        'pct_GLP_RD_04_FEM_PC', 'pct_GLP_RD_04_MALE_PC',
#        'pct_GLP_RD_04_WH7_PC', 'pct_GLP_RD_05_ALL_PC',
#        'pct_GLP_RD_05_EDS_PC', 'pct_GLP_RD_05_FEM_PC',
#        'pct_GLP_RD_05_MALE_PC', 'pct_GLP_RD_05_WH7_PC',
#        'pct_GLP_RD_ALL_ALL_PC', 'pct_GLP_RD_ALL_BL7_PC',
#        'pct_GLP_RD_ALL_EDS_PC', 'pct_GLP_RD_ALL_FEM_PC',
#        'pct_GLP_RD_ALL_HI7_PC', 'pct_GLP_RD_ALL_MALE_PC',
#        'pct_GLP_RD_ALL_MU7_PC', 'pct_GLP_RD_ALL_WH7_PC',
#        'pct_GLP_SC_05_ALL_PC', 'pct_GLP_SC_05_EDS_PC',
#        'pct_GLP_SC_05_FEM_PC', 'pct_GLP_SC_05_MALE_PC',
#        'pct_GLP_SC_05_WH7_PC', 'pct_GLP_SC_ALL_ALL_PC',
#        'pct_GLP_SC_ALL_BL7_PC', 'pct_GLP_SC_ALL_EDS_PC',
#        'pct_GLP_SC_ALL_FEM_PC', 'pct_GLP_SC_ALL_HI7_PC',
#        'pct_L1_ALL_ALL_ALL_PC', 'pct_L1_EOG_03_ALL_PC',
#        'pct_L1_EOG_03_EDS_PC', 'pct_L1_EOG_03_FEM_PC',
#        'pct_L1_EOG_03_MALE_PC', 'pct_L1_EOG_04_ALL_PC',
#        'pct_L1_EOG_04_EDS_PC', 'pct_L1_EOG_04_FEM_PC',
#        'pct_L1_EOG_04_MALE_PC', 'pct_L1_EOG_05_ALL_PC',
#        'pct_L1_EOG_05_FEM_PC', 'pct_L1_EOG_ALL_ALL_PC',
#        'pct_L1_MA_03_ALL_PC', 'pct_L1_MA_04_ALL_PC',
#        'pct_L1_MA_05_ALL_PC', 'pct_L1_MA_ALL_ALL_PC',
#        'pct_L1_RD_03_ALL_PC', 'pct_L1_RD_04_ALL_PC',
#        'pct_L1_RD_05_ALL_PC', 'pct_L1_RD_ALL_ALL_PC',
#        'pct_L1_SC_05_ALL_PC', 'pct_L2_EOG_03_ALL_PC',
#        'pct_L2_EOG_04_ALL_PC', 'pct_L2_EOG_ALL_ALL_PC',
#        'pct_L2_EOG_ALL_FEM_PC', 'pct_L2_EOG_ALL_MALE_PC',
#        'pct_L2_MA_ALL_ALL_PC', 'pct_L2_RD_ALL_ALL_PC',
#        'pct_L3_EOG_04_ALL_PC', 'pct_L3_EOG_ALL_ALL_PC',
#        'pct_L4_ALL_ALL_ALL_PC', 'pct_L4_EOG_03_ALL_PC',
#        'pct_L4_EOG_03_FEM_PC', 'pct_L4_EOG_03_MALE_PC',
#        'pct_L4_EOG_04_ALL_PC', 'pct_L4_EOG_04_FEM_PC',
#        'pct_L4_EOG_04_MALE_PC', 'pct_L4_EOG_05_ALL_PC',
#        'pct_L4_EOG_05_FEM_PC', 'pct_L4_EOG_05_MALE_PC',
#        'pct_L4_EOG_ALL_ALL_PC', 'pct_L4_EOG_ALL_EDS_PC',
#        'pct_L4_EOG_ALL_FEM_PC', 'pct_L4_EOG_ALL_MALE_PC',
#        'pct_L4_MA_03_ALL_PC', 'pct_L4_MA_05_ALL_PC',
#        'pct_L4_MA_ALL_ALL_PC', 'pct_L4_RD_03_ALL_PC',
#        'pct_L4_RD_04_ALL_PC', 'pct_L4_RD_05_ALL_PC',
#        'pct_L4_RD_ALL_ALL_PC', 'pct_L4_SC_05_ALL_PC',
#        'pct_L4_SC_ALL_ALL_PC', 'pct_L5_ALL_ALL_ALL_PC',
#        'pct_L5_EOG_03_ALL_PC', 'pct_L5_EOG_03_FEM_PC',
#        'pct_L5_EOG_03_MALE_PC', 'pct_L5_EOG_04_ALL_PC',
#        'pct_L5_EOG_04_MALE_PC', 'pct_L5_EOG_05_ALL_PC',
#        'pct_L5_EOG_ALL_ALL_PC', 'pct_L5_EOG_ALL_FEM_PC',
#        'pct_L5_EOG_ALL_MALE_PC', 'pct_L5_EOG_ALL_WH7_PC',
#        'pct_L5_MA_03_ALL_PC', 'pct_L5_MA_04_ALL_PC',
#        'pct_L5_MA_05_ALL_PC', 'pct_L5_MA_ALL_ALL_PC',
#        'pct_L5_RD_ALL_ALL_PC', 'pct_L5_SC_05_ALL_PC',
#        'pct_L5_SC_ALL_ALL_PC', 'ma_score', 'rd_score', 'ach_score',
#        'ma_spg_score', 'aaa_score_BL7_SPG2', 'aaa_score_ELS_SPG2',
#        'aaa_score_HI7_SPG2', 'aaa_score_WH7_SPG2', 'ach_score_BL7_SPG2',
#        'ach_score_ELS_SPG2', 'ach_score_HI7_SPG2', 'avg_student_num',
#        'pct_ALL_CHRON_ABSENT', 'stu_enroll', 'highqual_class_pct_E',
#        'crime', 'arre_per1000_ALL', 'arre_per1000_BL7',
#        'crime_per1000_ALL', 'crime_per1000_ELS', 'crime_per1000_MU7',
#        'exp_per1000_ALL', 'exp_per1000_BL7', 'iss_per1000_ALL',
#        'avg_size_01_SAR', 'lea_code_020LEA', 'lea_code_030LEA',
#        'lea_code_040LEA', 'lea_code_050LEA', 'lea_code_060LEA',
#        'lea_code_070LEA', 'lea_code_080LEA', 'lea_code_090LEA',
#        'lea_code_100LEA', 'lea_code_110LEA', 'lea_code_111LEA',
#        'lea_code_120LEA', 'lea_code_130LEA', 'lea_code_132LEA',
#        'lea_code_140LEA', 'lea_code_150LEA', 'lea_code_160LEA',
#        'lea_code_170LEA', 'lea_code_180LEA', 'lea_code_181LEA',
#        'lea_code_182LEA', 'lea_code_190LEA', 'lea_code_200LEA',
#        'lea_code_210LEA', 'lea_code_220LEA', 'lea_code_230LEA',
#        'lea_code_240LEA', 'lea_code_241LEA', 'lea_code_250LEA',
#        'lea_code_260LEA', 'lea_code_270LEA', 'lea_code_280LEA',
#        'lea_code_290LEA', 'lea_code_291LEA', 'lea_code_292LEA',
#        'lea_code_300LEA', 'lea_code_310LEA', 'lea_code_320LEA',
#        'lea_code_330LEA', 'lea_code_340LEA', 'lea_code_350LEA',
#        'lea_code_360LEA', 'lea_code_370LEA', 'lea_code_380LEA',
#        'lea_code_390LEA', 'lea_code_400LEA', 'lea_code_410LEA',
#        'lea_code_420LEA', 'lea_code_421LEA', 'lea_code_422LEA',
#        'lea_code_430LEA', 'lea_code_440LEA', 'lea_code_450LEA',
#        'lea_code_460LEA', 'lea_code_470LEA', 'lea_code_480LEA',
#        'lea_code_490LEA', 'lea_code_491LEA', 'lea_code_500LEA',
#        'lea_code_510LEA', 'lea_code_520LEA', 'lea_code_530LEA',
#        'lea_code_540LEA', 'lea_code_550LEA', 'lea_code_560LEA',
#        'lea_code_570LEA', 'lea_code_580LEA', 'lea_code_590LEA',
#        'lea_code_600LEA', 'lea_code_610LEA', 'lea_code_620LEA',
#        'lea_code_630LEA', 'lea_code_640LEA', 'lea_code_650LEA',
#        'lea_code_660LEA', 'lea_code_670LEA', 'lea_code_680LEA',
#        'lea_code_681LEA', 'lea_code_690LEA', 'lea_code_700LEA',
#        'lea_code_710LEA', 'lea_code_720LEA', 'lea_code_730LEA',
#        'lea_code_740LEA', 'lea_code_750LEA', 'lea_code_760LEA',
#        'lea_code_761LEA', 'lea_code_770LEA', 'lea_code_780LEA',
#        'lea_code_790LEA', 'lea_code_800LEA', 'lea_code_810LEA',
#        'lea_code_820LEA', 'lea_code_821LEA', 'lea_code_830LEA',
#        'lea_code_840LEA', 'lea_code_850LEA', 'lea_code_860LEA',
#        'lea_code_861LEA', 'lea_code_862LEA', 'lea_code_870LEA',
#        'lea_code_880LEA', 'lea_code_890LEA', 'lea_code_900LEA',
#        'lea_code_910LEA', 'lea_code_920LEA', 'lea_code_930LEA',
#        'lea_code_940LEA', 'lea_code_950LEA', 'lea_code_960LEA',
#        'lea_code_970LEA', 'lea_code_980LEA', 'lea_code_990LEA',
#        'lea_code_995LEA', 'county_Alexander', 'county_Alleghany',
#        'county_Anson', 'county_Ashe', 'county_Avery', 'county_Beaufort',
#        'county_Bertie', 'county_Bladen', 'county_Brunswick',
#        'county_Burke', 'county_Caldwell', 'county_Camden',
#        'county_Carteret', 'county_Caswell', 'county_Chatham',
#        'county_Cherokee', 'county_Chowan', 'county_Clay',
#        'county_Cleveland', 'county_Craven', 'county_Cumberland',
#        'county_Currituck', 'county_Dare', 'county_Davie', 'county_Duplin',
#        'county_Durham', 'county_Edgecombe', 'county_Forsyth',
#        'county_Franklin', 'county_Gaston', 'county_Gates',
#        'county_Graham', 'county_Granville', 'county_Greene',
#        'county_Guilford', 'county_Harnett', 'county_Haywood',
#        'county_Henderson', 'county_Hertford', 'county_Hoke',
#        'county_Hyde', 'county_Jackson', 'county_Johnston', 'county_Jones',
#        'county_Lee', 'county_Lenoir', 'county_Lincoln', 'county_Macon',
#        'county_Madison', 'county_Martin', 'county_McDowell',
#        'county_Mecklenburg', 'county_Mitchell', 'county_Montgomery',
#        'county_Moore', 'county_Nash', 'county_New Hanover',
#        'county_Northampton', 'county_Onslow', 'county_Pamlico',
#        'county_Pasquotank', 'county_Pender', 'county_Perquimans',
#        'county_Person', 'county_Pitt', 'county_Polk', 'county_Richmond',
#        'county_Robeson', 'county_Rockingham', 'county_Rowan',
#        'county_Rutherford', 'county_Scotland', 'county_Stanly',
#        'county_Stokes', 'county_Swain', 'county_Transylvania',
#        'county_Tyrrell', 'county_Union', 'county_Vance', 'county_Wake',
#        'county_Warren', 'county_Washington', 'county_Watauga',
#        'county_Wayne', 'county_Wilkes', 'county_Wilson', 'county_Yadkin',
#        'county_Yancey', 'grade_span_KG:13',
#        'lea_name_Alexander County Schools',
#        'lea_name_Alleghany County Schools',
#        'lea_name_Anson County Schools', 'lea_name_Ashe County Schools',
#        'lea_name_Asheboro City Schools',
#        'lea_name_Asheville City Schools', 'lea_name_Avery County Schools',
#        'lea_name_Beaufort County Schools',
#        'lea_name_Bertie County Schools', 'lea_name_Bladen County Schools',
#        'lea_name_Brunswick County Schools',
#        'lea_name_Buncombe County Schools',
#        'lea_name_Burke County Schools',
#        'lea_name_Cabarrus County Schools',
#        'lea_name_Caldwell County Schools',
#        'lea_name_Camden County Schools',
#        'lea_name_Carteret County Schools',
#        'lea_name_Caswell County Schools',
#        'lea_name_Catawba County Schools',
#        'lea_name_Chapel-Hill/Carrboro City Schools',
#        'lea_name_Charlotte-Mecklenburg County Schools',
#        'lea_name_Chatham County Schools',
#        'lea_name_Cherokee County Schools', 'lea_name_Clay County Schools',
#        'lea_name_Cleveland County Schools',
#        'lea_name_Clinton City Schools',
#        'lea_name_Columbus County Schools',
#        'lea_name_Craven County Schools',
#        'lea_name_Cumberland County Schools',
#        'lea_name_Currituck County Schools',
#        'lea_name_Dare County Schools', 'lea_name_Davidson County Schools',
#        'lea_name_Davie County Schools', 'lea_name_Duplin County Schools',
#        'lea_name_Durham County Schools',
#        'lea_name_Edenton-Chowan County Schools',
#        'lea_name_Edgecombe County Schools', 'lea_name_Elkin City Schools',
#        'lea_name_Forsyth County Schools',
#        'lea_name_Franklin County Schools',
#        'lea_name_Gaston County Schools', 'lea_name_Gates County Schools',
#        'lea_name_Graham County Schools',
#        'lea_name_Granville County Schools',
#        'lea_name_Greene County Schools',
#        'lea_name_Guilford County Schools',
#        'lea_name_Halifax County Schools',
#        'lea_name_Harnett County Schools',
#        'lea_name_Haywood County Schools',
#        'lea_name_Henderson County Schools',
#        'lea_name_Hertford County Schools',
#        'lea_name_Hickory City Schools', 'lea_name_Hoke County Schools',
#        'lea_name_Hyde County Schools',
#        'lea_name_Iredell-Statesville Schools',
#        'lea_name_Jackson County Schools',
#        'lea_name_Johnston County Schools',
#        'lea_name_Jones County Schools',
#        'lea_name_Kannapolis City Schools', 'lea_name_Lee County Schools',
#        'lea_name_Lenoir County Schools',
#        'lea_name_Lexington City Schools',
#        'lea_name_Lincoln County Schools', 'lea_name_Macon County Schools',
#        'lea_name_Madison County Schools',
#        'lea_name_Martin County Schools',
#        'lea_name_McDowell County Schools',
#        'lea_name_Mitchell County Schools',
#        'lea_name_Montgomery County Schools',
#        'lea_name_Moore County Schools',
#        'lea_name_Mooresville City Schools',
#        'lea_name_Mount Airy City Schools',
#        'lea_name_Nash-Rocky Mount Schools',
#        'lea_name_New Hanover County Schools',
#        'lea_name_Newton-Conover City Schools',
#        'lea_name_Northampton County Schools',
#        'lea_name_Onslow County Schools', 'lea_name_Orange County Schools',
#        'lea_name_Pamlico County Schools',
#        'lea_name_Pasquotank County Schools',
#        'lea_name_Pender County Schools',
#        'lea_name_Perquimans County Schools',
#        'lea_name_Person County Schools', 'lea_name_Pitt County Schools',
#        'lea_name_Polk County Schools', 'lea_name_Randolph County Schools',
#        'lea_name_Richmond County Schools',
#        'lea_name_Roanoke Rapids City Schools',
#        'lea_name_Robeson County Schools',
#        'lea_name_Rockingham County Schools',
#        'lea_name_Rowan-Salisbury County Schools',
#        'lea_name_Rutherford County Schools',
#        'lea_name_Sampson County Schools',
#        'lea_name_Scotland County Schools',
#        'lea_name_Stanly County Schools', 'lea_name_Stokes County Schools',
#        'lea_name_Surry County Schools', 'lea_name_Swain County Schools',
#        'lea_name_Thomasville City Schools',
#        'lea_name_Transylvania County Schools',
#        'lea_name_Tyrrell County Schools', 'lea_name_Union County Schools',
#        'lea_name_Vance County Schools', 'lea_name_Wake County Schools',
#        'lea_name_Warren County Schools',
#        'lea_name_Washington County Schools',
#        'lea_name_Watauga County Schools', 'lea_name_Wayne County Schools',
#        'lea_name_Weldon City Schools', 'lea_name_Whiteville City Schools',
#        'lea_name_Wilkes County Schools', 'lea_name_Wilson County Schools',
#        'lea_name_Yadkin County Schools', 'lea_name_Yancey County Schools'],
#       dtype=object)

# %%
#Check columns before drop 
print('\r\n*********Before: Dropping Highly Correlated Fields*************************************')
schoolData.info(verbose=False)

# Drop the highly correlated features from our training data 
#schoolData = schoolData.drop(to_drop, axis=1)
schoolData = schoolData.drop(cf['Field2'], axis=1)

#Check columns after drop 
print('\r\n*********After: Dropping Highly Correlated Fields**************************************')
schoolData.info(verbose=False)
# Out:
# *********Before: Dropping Highly Correlated Fields*************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2460 entries, 2 to 2641
# Columns: 1585 entries, lea to agency_lea_code_995LEA
# dtypes: float64(904), uint8(681)
# memory usage: 18.6 MB
#
# *********After: Dropping Highly Correlated Fields**************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2460 entries, 2 to 2641
# Columns: 967 entries, lea to agency_lea_code_995LEA
# dtypes: float64(603), uint8(364)
# memory usage: 12.2 MB

# %%
#Restore the unit_code before saving
schoolData['agency_code'] = agency_code
#Save the final dataset to a .csv file
schoolData.to_csv(outputDir + inputFileName + '_ML.csv', sep=',', index=False)

# %%
print('*********FINAL DATASET DETAILS*********************************************************\r\n')
schoolData.info(verbose=True)
# Out:
# *********FINAL DATASET DETAILS*********************************************************
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2460 entries, 2 to 2641
# Data columns (total 968 columns):
#  #   Column                                                                                                            Dtype
# ---  ------                                                                                                            -----
#  0   lea                                                                                                               float64
#  1   school                                                                                                            float64
#  2   pacific_island_pct                                                                                                float64
#  3   two_or_more_pct                                                                                                   float64
#  4   asian_male_pct                                                                                                    float64
#  5   hispanic_male_pct                                                                                                 float64
#  6   black_male_pct                                                                                                    float64
#  7   pacific_island_male_pct                                                                                           float64
#  8   two_or_more_male_pct                                                                                              float64
#  9   indian_female_pct                                                                                                 float64
#  10  asian_female_pct                                                                                                  float64
#  11  hispanic_female_pct                                                                                               float64
#  12  black_female_pct                                                                                                  float64
#  13  white_female_pct                                                                                                  float64
#  14  minority_female_pct                                                                                               float64
#  15  pacific_island_female_pct                                                                                         float64
#  16  two_or_more_female_pct                                                                                            float64
#  17  pct_eds                                                                                                           float64
#  18  pct_EDS_ELP                                                                                                       float64
#  19  pct_ELS_ELP                                                                                                       float64
#  20  pct_FEM_ELP                                                                                                       float64
#  21  pct_HI7_ELP                                                                                                       float64
#  22  pct_MALE_ELP                                                                                                      float64
#  23  pct_met_Math Grades 3-8_LTG                                                                                       float64
#  24  pct_met_Reading Grades 3-8_LTG                                                                                    float64
#  25  pct_met_Total Targets_LTG                                                                                         float64
#  26  pct_met_Total Targets_PART                                                                                        float64
#  27  pct_Reading Grades 3-8_ALL_PART_DET                                                                               float64
#  28  pct_Reading Grades 3-8_BL7_PART_DET                                                                               float64
#  29  pct_Reading Grades 3-8_EDS_PART_DET                                                                               float64
#  30  pct_Reading Grades 3-8_HI7_PART_DET                                                                               float64
#  31  pct_Reading Grades 3-8_SWD_PART_DET                                                                               float64
#  32  pct_Reading Grades 3-8_WH7_PART_DET                                                                               float64
#  33  pct_Science Grades 5&8_ALL_PART_DET                                                                               float64
#  34  pct_Science Grades 5&8_EDS_PART_DET                                                                               float64
#  35  pct_CCR_RD_ALL_SWD_PC                                                                                             float64
#  36  pct_GLP_EOG_03_SWD_PC                                                                                             float64
#  37  pct_GLP_EOG_04_SWD_PC                                                                                             float64
#  38  pct_GLP_EOG_05_AIG_PC                                                                                             float64
#  39  pct_GLP_EOG_05_SWD_PC                                                                                             float64
#  40  pct_GLP_EOG_ALL_AIG_PC                                                                                            float64
#  41  pct_GLP_EOG_ALL_MU7_PC                                                                                            float64
#  42  pct_GLP_EOG_ALL_SWD_PC                                                                                            float64
#  43  pct_GLP_MA_ALL_ELS_PC                                                                                             float64
#  44  pct_GLP_MA_ALL_HI7_PC                                                                                             float64
#  45  pct_GLP_MA_ALL_SWD_PC                                                                                             float64
#  46  pct_GLP_RD_ALL_AIG_PC                                                                                             float64
#  47  pct_GLP_RD_ALL_ELS_PC                                                                                             float64
#  48  pct_GLP_RD_ALL_SWD_PC                                                                                             float64
#  49  pct_GLP_SC_ALL_AIG_PC                                                                                             float64
#  50  pct_GLP_SC_ALL_MALE_PC                                                                                            float64
#  51  pct_GLP_SC_ALL_SWD_PC                                                                                             float64
#  52  pct_GLP_SC_ALL_WH7_PC                                                                                             float64
#  53  pct_L1_ALL_ALL_BL7_PC                                                                                             float64
#  54  pct_L1_ALL_ALL_EDS_PC                                                                                             float64
#  55  pct_L1_ALL_ALL_ELS_PC                                                                                             float64
#  56  pct_L1_ALL_ALL_FEM_PC                                                                                             float64
#  57  pct_L1_ALL_ALL_HI7_PC                                                                                             float64
#  58  pct_L1_ALL_ALL_MALE_PC                                                                                            float64
#  59  pct_L1_ALL_ALL_MU7_PC                                                                                             float64
#  60  pct_L1_ALL_ALL_SWD_PC                                                                                             float64
#  61  pct_L1_ALL_ALL_WH7_PC                                                                                             float64
#  62  pct_L1_EOG_03_HI7_PC                                                                                              float64
#  63  pct_L1_EOG_03_SWD_PC                                                                                              float64
#  64  pct_L1_EOG_04_BL7_PC                                                                                              float64
#  65  pct_L1_EOG_04_HI7_PC                                                                                              float64
#  66  pct_L1_EOG_04_SWD_PC                                                                                              float64
#  67  pct_L1_EOG_04_WH7_PC                                                                                              float64
#  68  pct_L1_EOG_05_BL7_PC                                                                                              float64
#  69  pct_L1_EOG_05_EDS_PC                                                                                              float64
#  70  pct_L1_EOG_05_HI7_PC                                                                                              float64
#  71  pct_L1_EOG_05_MALE_PC                                                                                             float64
#  72  pct_L1_EOG_05_SWD_PC                                                                                              float64
#  73  pct_L1_EOG_05_WH7_PC                                                                                              float64
#  74  pct_L1_EOG_ALL_BL7_PC                                                                                             float64
#  75  pct_L1_EOG_ALL_EDS_PC                                                                                             float64
#  76  pct_L1_EOG_ALL_ELS_PC                                                                                             float64
#  77  pct_L1_EOG_ALL_FEM_PC                                                                                             float64
#  78  pct_L1_EOG_ALL_HI7_PC                                                                                             float64
#  79  pct_L1_EOG_ALL_MALE_PC                                                                                            float64
#  80  pct_L1_EOG_ALL_MU7_PC                                                                                             float64
#  81  pct_L1_EOG_ALL_SWD_PC                                                                                             float64
#  82  pct_L1_EOG_ALL_WH7_PC                                                                                             float64
#  83  pct_L1_MA_03_EDS_PC                                                                                               float64
#  84  pct_L1_MA_03_FEM_PC                                                                                               float64
#  85  pct_L1_MA_03_MALE_PC                                                                                              float64
#  86  pct_L1_MA_04_EDS_PC                                                                                               float64
#  87  pct_L1_MA_04_FEM_PC                                                                                               float64
#  88  pct_L1_MA_04_MALE_PC                                                                                              float64
#  89  pct_L1_MA_05_EDS_PC                                                                                               float64
#  90  pct_L1_MA_05_FEM_PC                                                                                               float64
#  91  pct_L1_MA_05_MALE_PC                                                                                              float64
#  92  pct_L1_MA_ALL_BL7_PC                                                                                              float64
#  93  pct_L1_MA_ALL_EDS_PC                                                                                              float64
#  94  pct_L1_MA_ALL_ELS_PC                                                                                              float64
#  95  pct_L1_MA_ALL_FEM_PC                                                                                              float64
#  96  pct_L1_MA_ALL_HI7_PC                                                                                              float64
#  97  pct_L1_MA_ALL_MALE_PC                                                                                             float64
#  98  pct_L1_MA_ALL_MU7_PC                                                                                              float64
#  99  pct_L1_MA_ALL_SWD_PC                                                                                              float64
#  100 pct_L1_MA_ALL_WH7_PC                                                                                              float64
#  101 pct_L1_RD_03_EDS_PC                                                                                               float64
#  102 pct_L1_RD_03_FEM_PC                                                                                               float64
#  103 pct_L1_RD_03_MALE_PC                                                                                              float64
#  104 pct_L1_RD_04_EDS_PC                                                                                               float64
#  105 pct_L1_RD_04_FEM_PC                                                                                               float64
#  106 pct_L1_RD_04_MALE_PC                                                                                              float64
#  107 pct_L1_RD_05_EDS_PC                                                                                               float64
#  108 pct_L1_RD_05_FEM_PC                                                                                               float64
#  109 pct_L1_RD_05_MALE_PC                                                                                              float64
#  110 pct_L1_RD_ALL_BL7_PC                                                                                              float64
#  111 pct_L1_RD_ALL_EDS_PC                                                                                              float64
#  112 pct_L1_RD_ALL_ELS_PC                                                                                              float64
#  113 pct_L1_RD_ALL_FEM_PC                                                                                              float64
#  114 pct_L1_RD_ALL_HI7_PC                                                                                              float64
#  115 pct_L1_RD_ALL_MALE_PC                                                                                             float64
#  116 pct_L1_RD_ALL_MU7_PC                                                                                              float64
#  117 pct_L1_RD_ALL_SWD_PC                                                                                              float64
#  118 pct_L1_RD_ALL_WH7_PC                                                                                              float64
#  119 pct_L1_SC_05_EDS_PC                                                                                               float64
#  120 pct_L1_SC_05_FEM_PC                                                                                               float64
#  121 pct_L1_SC_05_MALE_PC                                                                                              float64
#  122 pct_L1_SC_ALL_ALL_PC                                                                                              float64
#  123 pct_L1_SC_ALL_BL7_PC                                                                                              float64
#  124 pct_L1_SC_ALL_EDS_PC                                                                                              float64
#  125 pct_L1_SC_ALL_FEM_PC                                                                                              float64
#  126 pct_L1_SC_ALL_HI7_PC                                                                                              float64
#  127 pct_L1_SC_ALL_MALE_PC                                                                                             float64
#  128 pct_L1_SC_ALL_SWD_PC                                                                                              float64
#  129 pct_L2_ALL_ALL_ALL_PC                                                                                             float64
#  130 pct_L2_ALL_ALL_BL7_PC                                                                                             float64
#  131 pct_L2_ALL_ALL_EDS_PC                                                                                             float64
#  132 pct_L2_ALL_ALL_ELS_PC                                                                                             float64
#  133 pct_L2_ALL_ALL_FEM_PC                                                                                             float64
#  134 pct_L2_ALL_ALL_HI7_PC                                                                                             float64
#  135 pct_L2_ALL_ALL_MALE_PC                                                                                            float64
#  136 pct_L2_ALL_ALL_MU7_PC                                                                                             float64
#  137 pct_L2_ALL_ALL_SWD_PC                                                                                             float64
#  138 pct_L2_ALL_ALL_WH7_PC                                                                                             float64
#  139 pct_L2_EOG_03_BL7_PC                                                                                              float64
#  140 pct_L2_EOG_03_EDS_PC                                                                                              float64
#  141 pct_L2_EOG_03_FEM_PC                                                                                              float64
#  142 pct_L2_EOG_03_HI7_PC                                                                                              float64
#  143 pct_L2_EOG_03_MALE_PC                                                                                             float64
#  144 pct_L2_EOG_03_SWD_PC                                                                                              float64
#  145 pct_L2_EOG_03_WH7_PC                                                                                              float64
#  146 pct_L2_EOG_04_BL7_PC                                                                                              float64
#  147 pct_L2_EOG_04_EDS_PC                                                                                              float64
#  148 pct_L2_EOG_04_FEM_PC                                                                                              float64
#  149 pct_L2_EOG_04_HI7_PC                                                                                              float64
#  150 pct_L2_EOG_04_MALE_PC                                                                                             float64
#  151 pct_L2_EOG_04_SWD_PC                                                                                              float64
#  152 pct_L2_EOG_04_WH7_PC                                                                                              float64
#  153 pct_L2_EOG_05_ALL_PC                                                                                              float64
#  154 pct_L2_EOG_05_BL7_PC                                                                                              float64
#  155 pct_L2_EOG_05_EDS_PC                                                                                              float64
#  156 pct_L2_EOG_05_FEM_PC                                                                                              float64
#  157 pct_L2_EOG_05_HI7_PC                                                                                              float64
#  158 pct_L2_EOG_05_MALE_PC                                                                                             float64
#  159 pct_L2_EOG_05_SWD_PC                                                                                              float64
#  160 pct_L2_EOG_05_WH7_PC                                                                                              float64
#  161 pct_L2_EOG_ALL_BL7_PC                                                                                             float64
#  162 pct_L2_EOG_ALL_EDS_PC                                                                                             float64
#  163 pct_L2_EOG_ALL_ELS_PC                                                                                             float64
#  164 pct_L2_EOG_ALL_HI7_PC                                                                                             float64
#  165 pct_L2_EOG_ALL_MU7_PC                                                                                             float64
#  166 pct_L2_EOG_ALL_SWD_PC                                                                                             float64
#  167 pct_L2_EOG_ALL_WH7_PC                                                                                             float64
#  168 pct_L2_MA_03_ALL_PC                                                                                               float64
#  169 pct_L2_MA_03_EDS_PC                                                                                               float64
#  170 pct_L2_MA_03_FEM_PC                                                                                               float64
#  171 pct_L2_MA_03_MALE_PC                                                                                              float64
#  172 pct_L2_MA_04_ALL_PC                                                                                               float64
#  173 pct_L2_MA_04_EDS_PC                                                                                               float64
#  174 pct_L2_MA_04_FEM_PC                                                                                               float64
#  175 pct_L2_MA_04_MALE_PC                                                                                              float64
#  176 pct_L2_MA_04_WH7_PC                                                                                               float64
#  177 pct_L2_MA_05_ALL_PC                                                                                               float64
#  178 pct_L2_MA_05_EDS_PC                                                                                               float64
#  179 pct_L2_MA_05_FEM_PC                                                                                               float64
#  180 pct_L2_MA_05_MALE_PC                                                                                              float64
#  181 pct_L2_MA_05_WH7_PC                                                                                               float64
#  182 pct_L2_MA_ALL_BL7_PC                                                                                              float64
#  183 pct_L2_MA_ALL_EDS_PC                                                                                              float64
#  184 pct_L2_MA_ALL_ELS_PC                                                                                              float64
#  185 pct_L2_MA_ALL_FEM_PC                                                                                              float64
#  186 pct_L2_MA_ALL_HI7_PC                                                                                              float64
#  187 pct_L2_MA_ALL_MALE_PC                                                                                             float64
#  188 pct_L2_MA_ALL_MU7_PC                                                                                              float64
#  189 pct_L2_MA_ALL_SWD_PC                                                                                              float64
#  190 pct_L2_MA_ALL_WH7_PC                                                                                              float64
#  191 pct_L2_RD_03_ALL_PC                                                                                               float64
#  192 pct_L2_RD_03_EDS_PC                                                                                               float64
#  193 pct_L2_RD_03_FEM_PC                                                                                               float64
#  194 pct_L2_RD_03_MALE_PC                                                                                              float64
#  195 pct_L2_RD_03_WH7_PC                                                                                               float64
#  196 pct_L2_RD_04_ALL_PC                                                                                               float64
#  197 pct_L2_RD_04_EDS_PC                                                                                               float64
#  198 pct_L2_RD_04_FEM_PC                                                                                               float64
#  199 pct_L2_RD_04_MALE_PC                                                                                              float64
#  200 pct_L2_RD_04_WH7_PC                                                                                               float64
#  201 pct_L2_RD_05_ALL_PC                                                                                               float64
#  202 pct_L2_RD_05_EDS_PC                                                                                               float64
#  203 pct_L2_RD_05_FEM_PC                                                                                               float64
#  204 pct_L2_RD_05_MALE_PC                                                                                              float64
#  205 pct_L2_RD_05_WH7_PC                                                                                               float64
#  206 pct_L2_RD_ALL_BL7_PC                                                                                              float64
#  207 pct_L2_RD_ALL_EDS_PC                                                                                              float64
#  208 pct_L2_RD_ALL_ELS_PC                                                                                              float64
#  209 pct_L2_RD_ALL_FEM_PC                                                                                              float64
#  210 pct_L2_RD_ALL_HI7_PC                                                                                              float64
#  211 pct_L2_RD_ALL_MALE_PC                                                                                             float64
#  212 pct_L2_RD_ALL_MU7_PC                                                                                              float64
#  213 pct_L2_RD_ALL_SWD_PC                                                                                              float64
#  214 pct_L2_RD_ALL_WH7_PC                                                                                              float64
#  215 pct_L2_SC_05_ALL_PC                                                                                               float64
#  216 pct_L2_SC_05_EDS_PC                                                                                               float64
#  217 pct_L2_SC_05_FEM_PC                                                                                               float64
#  218 pct_L2_SC_05_MALE_PC                                                                                              float64
#  219 pct_L2_SC_ALL_ALL_PC                                                                                              float64
#  220 pct_L2_SC_ALL_BL7_PC                                                                                              float64
#  221 pct_L2_SC_ALL_EDS_PC                                                                                              float64
#  222 pct_L2_SC_ALL_FEM_PC                                                                                              float64
#  223 pct_L2_SC_ALL_HI7_PC                                                                                              float64
#  224 pct_L2_SC_ALL_MALE_PC                                                                                             float64
#  225 pct_L2_SC_ALL_SWD_PC                                                                                              float64
#  226 pct_L2_SC_ALL_WH7_PC                                                                                              float64
#  227 pct_L3_ALL_ALL_ALL_PC                                                                                             float64
#  228 pct_L3_ALL_ALL_BL7_PC                                                                                             float64
#  229 pct_L3_ALL_ALL_EDS_PC                                                                                             float64
#  230 pct_L3_ALL_ALL_ELS_PC                                                                                             float64
#  231 pct_L3_ALL_ALL_FEM_PC                                                                                             float64
#  232 pct_L3_ALL_ALL_HI7_PC                                                                                             float64
#  233 pct_L3_ALL_ALL_MALE_PC                                                                                            float64
#  234 pct_L3_ALL_ALL_MU7_PC                                                                                             float64
#  235 pct_L3_ALL_ALL_SWD_PC                                                                                             float64
#  236 pct_L3_ALL_ALL_WH7_PC                                                                                             float64
#  237 pct_L3_EOG_03_ALL_PC                                                                                              float64
#  238 pct_L3_EOG_03_EDS_PC                                                                                              float64
#  239 pct_L3_EOG_03_FEM_PC                                                                                              float64
#  240 pct_L3_EOG_03_MALE_PC                                                                                             float64
#  241 pct_L3_EOG_03_WH7_PC                                                                                              float64
#  242 pct_L3_EOG_04_EDS_PC                                                                                              float64
#  243 pct_L3_EOG_04_FEM_PC                                                                                              float64
#  244 pct_L3_EOG_04_MALE_PC                                                                                             float64
#  245 pct_L3_EOG_04_WH7_PC                                                                                              float64
#  246 pct_L3_EOG_05_ALL_PC                                                                                              float64
#  247 pct_L3_EOG_05_EDS_PC                                                                                              float64
#  248 pct_L3_EOG_05_FEM_PC                                                                                              float64
#  249 pct_L3_EOG_05_MALE_PC                                                                                             float64
#  250 pct_L3_EOG_05_WH7_PC                                                                                              float64
#  251 pct_L3_EOG_ALL_BL7_PC                                                                                             float64
#  252 pct_L3_EOG_ALL_EDS_PC                                                                                             float64
#  253 pct_L3_EOG_ALL_ELS_PC                                                                                             float64
#  254 pct_L3_EOG_ALL_FEM_PC                                                                                             float64
#  255 pct_L3_EOG_ALL_HI7_PC                                                                                             float64
#  256 pct_L3_EOG_ALL_MALE_PC                                                                                            float64
#  257 pct_L3_EOG_ALL_MU7_PC                                                                                             float64
#  258 pct_L3_EOG_ALL_SWD_PC                                                                                             float64
#  259 pct_L3_EOG_ALL_WH7_PC                                                                                             float64
#  260 pct_L3_MA_03_ALL_PC                                                                                               float64
#  261 pct_L3_MA_03_EDS_PC                                                                                               float64
#  262 pct_L3_MA_03_FEM_PC                                                                                               float64
#  263 pct_L3_MA_03_MALE_PC                                                                                              float64
#  264 pct_L3_MA_04_ALL_PC                                                                                               float64
#  265 pct_L3_MA_ALL_ALL_PC                                                                                              float64
#  266 pct_L3_MA_ALL_BL7_PC                                                                                              float64
#  267 pct_L3_MA_ALL_EDS_PC                                                                                              float64
#  268 pct_L3_MA_ALL_ELS_PC                                                                                              float64
#  269 pct_L3_MA_ALL_FEM_PC                                                                                              float64
#  270 pct_L3_MA_ALL_HI7_PC                                                                                              float64
#  271 pct_L3_MA_ALL_MALE_PC                                                                                             float64
#  272 pct_L3_MA_ALL_WH7_PC                                                                                              float64
#  273 pct_L3_RD_03_ALL_PC                                                                                               float64
#  274 pct_L3_RD_03_EDS_PC                                                                                               float64
#  275 pct_L3_RD_03_FEM_PC                                                                                               float64
#  276 pct_L3_RD_03_MALE_PC                                                                                              float64
#  277 pct_L3_RD_04_ALL_PC                                                                                               float64
#  278 pct_L3_RD_04_EDS_PC                                                                                               float64
#  279 pct_L3_RD_04_FEM_PC                                                                                               float64
#  280 pct_L3_RD_04_MALE_PC                                                                                              float64
#  281 pct_L3_RD_05_ALL_PC                                                                                               float64
#  282 pct_L3_RD_05_EDS_PC                                                                                               float64
#  283 pct_L3_RD_05_FEM_PC                                                                                               float64
#  284 pct_L3_RD_05_MALE_PC                                                                                              float64
#  285 pct_L3_RD_ALL_ALL_PC                                                                                              float64
#  286 pct_L3_RD_ALL_BL7_PC                                                                                              float64
#  287 pct_L3_RD_ALL_EDS_PC                                                                                              float64
#  288 pct_L3_RD_ALL_ELS_PC                                                                                              float64
#  289 pct_L3_RD_ALL_FEM_PC                                                                                              float64
#  290 pct_L3_RD_ALL_HI7_PC                                                                                              float64
#  291 pct_L3_RD_ALL_MALE_PC                                                                                             float64
#  292 pct_L3_RD_ALL_SWD_PC                                                                                              float64
#  293 pct_L3_RD_ALL_WH7_PC                                                                                              float64
#  294 pct_L3_SC_05_ALL_PC                                                                                               float64
#  295 pct_L3_SC_05_EDS_PC                                                                                               float64
#  296 pct_L3_SC_05_FEM_PC                                                                                               float64
#  297 pct_L3_SC_05_MALE_PC                                                                                              float64
#  298 pct_L3_SC_ALL_ALL_PC                                                                                              float64
#  299 pct_L3_SC_ALL_BL7_PC                                                                                              float64
#  300 pct_L3_SC_ALL_EDS_PC                                                                                              float64
#  301 pct_L3_SC_ALL_FEM_PC                                                                                              float64
#  302 pct_L3_SC_ALL_MALE_PC                                                                                             float64
#  303 pct_L3_SC_ALL_WH7_PC                                                                                              float64
#  304 pct_L4_ALL_ALL_AIG_PC                                                                                             float64
#  305 pct_L4_ALL_ALL_AS7_PC                                                                                             float64
#  306 pct_L4_ALL_ALL_BL7_PC                                                                                             float64
#  307 pct_L4_ALL_ALL_EDS_PC                                                                                             float64
#  308 pct_L4_ALL_ALL_ELS_PC                                                                                             float64
#  309 pct_L4_ALL_ALL_FEM_PC                                                                                             float64
#  310 pct_L4_ALL_ALL_HI7_PC                                                                                             float64
#  311 pct_L4_ALL_ALL_MALE_PC                                                                                            float64
#  312 pct_L4_ALL_ALL_MU7_PC                                                                                             float64
#  313 pct_L4_ALL_ALL_SWD_PC                                                                                             float64
#  314 pct_L4_ALL_ALL_WH7_PC                                                                                             float64
#  315 pct_L4_EOG_03_BL7_PC                                                                                              float64
#  316 pct_L4_EOG_03_EDS_PC                                                                                              float64
#  317 pct_L4_EOG_03_HI7_PC                                                                                              float64
#  318 pct_L4_EOG_03_WH7_PC                                                                                              float64
#  319 pct_L4_EOG_04_BL7_PC                                                                                              float64
#  320 pct_L4_EOG_04_EDS_PC                                                                                              float64
#  321 pct_L4_EOG_04_HI7_PC                                                                                              float64
#  322 pct_L4_EOG_04_WH7_PC                                                                                              float64
#  323 pct_L4_EOG_05_AIG_PC                                                                                              float64
#  324 pct_L4_EOG_05_BL7_PC                                                                                              float64
#  325 pct_L4_EOG_05_EDS_PC                                                                                              float64
#  326 pct_L4_EOG_05_HI7_PC                                                                                              float64
#  327 pct_L4_EOG_05_WH7_PC                                                                                              float64
#  328 pct_L4_EOG_ALL_AIG_PC                                                                                             float64
#  329 pct_L4_EOG_ALL_BL7_PC                                                                                             float64
#  330 pct_L4_EOG_ALL_ELS_PC                                                                                             float64
#  331 pct_L4_EOG_ALL_HI7_PC                                                                                             float64
#  332 pct_L4_EOG_ALL_MU7_PC                                                                                             float64
#  333 pct_L4_EOG_ALL_SWD_PC                                                                                             float64
#  334 pct_L4_EOG_ALL_WH7_PC                                                                                             float64
#  335 pct_L4_MA_03_EDS_PC                                                                                               float64
#  336 pct_L4_MA_03_FEM_PC                                                                                               float64
#  337 pct_L4_MA_03_MALE_PC                                                                                              float64
#  338 pct_L4_MA_03_WH7_PC                                                                                               float64
#  339 pct_L4_MA_04_ALL_PC                                                                                               float64
#  340 pct_L4_MA_04_EDS_PC                                                                                               float64
#  341 pct_L4_MA_04_FEM_PC                                                                                               float64
#  342 pct_L4_MA_04_MALE_PC                                                                                              float64
#  343 pct_L4_MA_04_WH7_PC                                                                                               float64
#  344 pct_L4_MA_05_EDS_PC                                                                                               float64
#  345 pct_L4_MA_05_FEM_PC                                                                                               float64
#  346 pct_L4_MA_05_MALE_PC                                                                                              float64
#  347 pct_L4_MA_05_WH7_PC                                                                                               float64
#  348 pct_L4_MA_ALL_AIG_PC                                                                                              float64
#  349 pct_L4_MA_ALL_BL7_PC                                                                                              float64
#  350 pct_L4_MA_ALL_EDS_PC                                                                                              float64
#  351 pct_L4_MA_ALL_ELS_PC                                                                                              float64
#  352 pct_L4_MA_ALL_FEM_PC                                                                                              float64
#  353 pct_L4_MA_ALL_HI7_PC                                                                                              float64
#  354 pct_L4_MA_ALL_MALE_PC                                                                                             float64
#  355 pct_L4_MA_ALL_MU7_PC                                                                                              float64
#  356 pct_L4_MA_ALL_SWD_PC                                                                                              float64
#  357 pct_L4_MA_ALL_WH7_PC                                                                                              float64
#  358 pct_L4_RD_03_EDS_PC                                                                                               float64
#  359 pct_L4_RD_03_FEM_PC                                                                                               float64
#  360 pct_L4_RD_03_MALE_PC                                                                                              float64
#  361 pct_L4_RD_03_WH7_PC                                                                                               float64
#  362 pct_L4_RD_04_EDS_PC                                                                                               float64
#  363 pct_L4_RD_04_FEM_PC                                                                                               float64
#  364 pct_L4_RD_04_MALE_PC                                                                                              float64
#  365 pct_L4_RD_04_WH7_PC                                                                                               float64
#  366 pct_L4_RD_05_EDS_PC                                                                                               float64
#  367 pct_L4_RD_05_FEM_PC                                                                                               float64
#  368 pct_L4_RD_05_MALE_PC                                                                                              float64
#  369 pct_L4_RD_05_WH7_PC                                                                                               float64
#  370 pct_L4_RD_ALL_AIG_PC                                                                                              float64
#  371 pct_L4_RD_ALL_BL7_PC                                                                                              float64
#  372 pct_L4_RD_ALL_EDS_PC                                                                                              float64
#  373 pct_L4_RD_ALL_ELS_PC                                                                                              float64
# ...
#  843 digital_media_95                                                                                                  uint8
#  844 digital_media_97                                                                                                  uint8
#  845 digital_media_99                                                                                                  uint8
#  846 device_access_Yes                                                                                                 uint8
#  847 device_home_Yes                                                                                                   uint8
#  848 BYOD_Both                                                                                                         uint8
#  849 BYOD_Neither                                                                                                      uint8
#  850 BYOD_Staff                                                                                                        uint8
#  851 BYOD_Students                                                                                                     uint8
#  852 esea_att_Met                                                                                                      uint8
#  853 agency_lea_code_020LEA                                                                                            uint8
#  854 agency_lea_code_030LEA                                                                                            uint8
#  855 agency_lea_code_040LEA                                                                                            uint8
#  856 agency_lea_code_050LEA                                                                                            uint8
#  857 agency_lea_code_060LEA                                                                                            uint8
#  858 agency_lea_code_070LEA                                                                                            uint8
#  859 agency_lea_code_080LEA                                                                                            uint8
#  860 agency_lea_code_090LEA                                                                                            uint8
#  861 agency_lea_code_100LEA                                                                                            uint8
#  862 agency_lea_code_110LEA                                                                                            uint8
#  863 agency_lea_code_111LEA                                                                                            uint8
#  864 agency_lea_code_120LEA                                                                                            uint8
#  865 agency_lea_code_130LEA                                                                                            uint8
#  866 agency_lea_code_132LEA                                                                                            uint8
#  867 agency_lea_code_140LEA                                                                                            uint8
#  868 agency_lea_code_150LEA                                                                                            uint8
#  869 agency_lea_code_160LEA                                                                                            uint8
#  870 agency_lea_code_170LEA                                                                                            uint8
#  871 agency_lea_code_180LEA                                                                                            uint8
#  872 agency_lea_code_181LEA                                                                                            uint8
#  873 agency_lea_code_182LEA                                                                                            uint8
#  874 agency_lea_code_190LEA                                                                                            uint8
#  875 agency_lea_code_200LEA                                                                                            uint8
#  876 agency_lea_code_210LEA                                                                                            uint8
#  877 agency_lea_code_220LEA                                                                                            uint8
#  878 agency_lea_code_230LEA                                                                                            uint8
#  879 agency_lea_code_240LEA                                                                                            uint8
#  880 agency_lea_code_241LEA                                                                                            uint8
#  881 agency_lea_code_250LEA                                                                                            uint8
#  882 agency_lea_code_260LEA                                                                                            uint8
#  883 agency_lea_code_270LEA                                                                                            uint8
#  884 agency_lea_code_280LEA                                                                                            uint8
#  885 agency_lea_code_290LEA                                                                                            uint8
#  886 agency_lea_code_291LEA                                                                                            uint8
#  887 agency_lea_code_292LEA                                                                                            uint8
#  888 agency_lea_code_300LEA                                                                                            uint8
#  889 agency_lea_code_310LEA                                                                                            uint8
#  890 agency_lea_code_320LEA                                                                                            uint8
#  891 agency_lea_code_330LEA                                                                                            uint8
#  892 agency_lea_code_340LEA                                                                                            uint8
#  893 agency_lea_code_350LEA                                                                                            uint8
#  894 agency_lea_code_360LEA                                                                                            uint8
#  895 agency_lea_code_370LEA                                                                                            uint8
#  896 agency_lea_code_380LEA                                                                                            uint8
#  897 agency_lea_code_390LEA                                                                                            uint8
#  898 agency_lea_code_400LEA                                                                                            uint8
#  899 agency_lea_code_410LEA                                                                                            uint8
#  900 agency_lea_code_420LEA                                                                                            uint8
#  901 agency_lea_code_421LEA                                                                                            uint8
#  902 agency_lea_code_422LEA                                                                                            uint8
#  903 agency_lea_code_430LEA                                                                                            uint8
#  904 agency_lea_code_440LEA                                                                                            uint8
#  905 agency_lea_code_450LEA                                                                                            uint8
#  906 agency_lea_code_460LEA                                                                                            uint8
#  907 agency_lea_code_470LEA                                                                                            uint8
#  908 agency_lea_code_480LEA                                                                                            uint8
#  909 agency_lea_code_490LEA                                                                                            uint8
#  910 agency_lea_code_491LEA                                                                                            uint8
#  911 agency_lea_code_500LEA                                                                                            uint8
#  912 agency_lea_code_510LEA                                                                                            uint8
#  913 agency_lea_code_520LEA                                                                                            uint8
#  914 agency_lea_code_530LEA                                                                                            uint8
#  915 agency_lea_code_540LEA                                                                                            uint8
#  916 agency_lea_code_550LEA                                                                                            uint8
#  917 agency_lea_code_560LEA                                                                                            uint8
#  918 agency_lea_code_570LEA                                                                                            uint8
#  919 agency_lea_code_580LEA                                                                                            uint8
#  920 agency_lea_code_590LEA                                                                                            uint8
#  921 agency_lea_code_600LEA                                                                                            uint8
#  922 agency_lea_code_610LEA                                                                                            uint8
#  923 agency_lea_code_620LEA                                                                                            uint8
#  924 agency_lea_code_630LEA                                                                                            uint8
#  925 agency_lea_code_640LEA                                                                                            uint8
#  926 agency_lea_code_650LEA                                                                                            uint8
#  927 agency_lea_code_660LEA                                                                                            uint8
#  928 agency_lea_code_670LEA                                                                                            uint8
#  929 agency_lea_code_680LEA                                                                                            uint8
#  930 agency_lea_code_681LEA                                                                                            uint8
#  931 agency_lea_code_690LEA                                                                                            uint8
#  932 agency_lea_code_700LEA                                                                                            uint8
#  933 agency_lea_code_710LEA                                                                                            uint8
#  934 agency_lea_code_720LEA                                                                                            uint8
#  935 agency_lea_code_730LEA                                                                                            uint8
#  936 agency_lea_code_740LEA                                                                                            uint8
#  937 agency_lea_code_750LEA                                                                                            uint8
#  938 agency_lea_code_760LEA                                                                                            uint8
#  939 agency_lea_code_761LEA                                                                                            uint8
#  940 agency_lea_code_770LEA                                                                                            uint8
#  941 agency_lea_code_780LEA                                                                                            uint8
#  942 agency_lea_code_790LEA                                                                                            uint8
#  943 agency_lea_code_800LEA                                                                                            uint8
#  944 agency_lea_code_810LEA                                                                                            uint8
#  945 agency_lea_code_820LEA                                                                                            uint8
#  946 agency_lea_code_821LEA                                                                                            uint8
#  947 agency_lea_code_830LEA                                                                                            uint8
#  948 agency_lea_code_840LEA                                                                                            uint8
#  949 agency_lea_code_850LEA                                                                                            uint8
#  950 agency_lea_code_860LEA                                                                                            uint8
#  951 agency_lea_code_861LEA                                                                                            uint8
#  952 agency_lea_code_862LEA                                                                                            uint8
#  953 agency_lea_code_870LEA                                                                                            uint8
#  954 agency_lea_code_880LEA                                                                                            uint8
#  955 agency_lea_code_890LEA                                                                                            uint8
#  956 agency_lea_code_900LEA                                                                                            uint8
#  957 agency_lea_code_910LEA                                                                                            uint8
#  958 agency_lea_code_920LEA                                                                                            uint8
#  959 agency_lea_code_930LEA                                                                                            uint8
#  960 agency_lea_code_940LEA                                                                                            uint8
#  961 agency_lea_code_950LEA                                                                                            uint8
#  962 agency_lea_code_960LEA                                                                                            uint8
#  963 agency_lea_code_970LEA                                                                                            uint8
#  964 agency_lea_code_980LEA                                                                                            uint8
#  965 agency_lea_code_990LEA                                                                                            uint8
#  966 agency_lea_code_995LEA                                                                                            uint8
#  967 agency_code                                                                                                       object
# dtypes: float64(603), object(1), uint8(364)
# memory usage: 12.2+ MB

# %%
import sklearn
import pandas as pd

print('Sklearn Version: ' + sklearn.__version__)
print('Pandas Version: ' + pd.__version__)
# Out:
# Sklearn Version: 0.22.1
# Pandas Version: 1.0.3

# %%
print('Output File Location:\r\n\r\n' + outputDir + inputFileName + '_ML.csv')
# Out:
# Output File Location:
#
# D:/BenepactLLC/Belk/NC_Report_Card_Data/2020/June 2020/2018/Machine Learning Datasets/PublicSchools2018_ML.csv
