# %% [markdown]
# # Create Public School Machine Learning Datasets
# ** This program creates all the _ML datasets in the NCEA repository.**
# * This notebook reads each School Dataset file located at \EducationDataNC\ *schoolYear* \School Datasets\ as input data.
# * Different school years are processed by changing the *schoolYear* parameter.
# * Different input / output files are processed / created by changing the *inputFileName* paramter in the cell below.
# * While a single program is used to create all the _ML datasets, one program copy per dataset is maintained in the repositiory so the dataset specific tranformation reports may be reviewed.
#
# **Datasets ending in ML are preprocessed for Machine Learning and go through the following transformations: **
# 1. Missing student body racial compositions are imputed using district averages.
# 2. Columns that have the same value in every single row are deleted.
# 3. Columns that have a unique value in every single row (all values are different) are deleted.
# 4. Empty columns (all values are NA or NULL) are deleted.
# 5. Numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# 6. Remaining numeric, non-race columns with missing values are imputed / populated with 0.  In many cases, schools are not reporting values when they are zero. However, mean imputation or some other more sophisticated strategy might be considered here.
# 7. Categorical / text based columns with > *uniqueThreshold* unique values are deleted.
# 8. All remaining categorical / text based columns are one-hot encoded.  In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# 9. Duplicated or highly similar columns with > 95% correlation are delelted.

# %%
#import required Libraries
import pandas as pd
import numpy as np
import os
import string

#**********************************************************************************
# Set the following variables before running this code!!!
#**********************************************************************************
#All raw data files are processed for the year below
schoolYear = 2018
rootDir = 'D:/BenepactLLC/Belk/NC_Report_Card_Data/2020/June 2020/'

#Location where copies of the raw data files will be read in from csv files.
dataDir = rootDir + str(schoolYear) + '/School Datasets/'

#Name of the file to be processed
#inputFileName = 'PublicSchools2018'
inputFileName = 'PublicHighSchools2018'
#inputFileName = 'PublicMiddleSchools2018'
#inputFileName = 'PublicElementarySchools2018'

#Input file being transformed for machine learning 
inputFile = dataDir + inputFileName + '.csv'

#Location where the new school datasets will be created.
outputDir = rootDir + str(schoolYear) + '/Machine Learning Datasets/'

#Missing Data Threshold (Per Column)
missingThreshold = 0.60

#Unique Value Threshold (Per Column)
#Delete Columns >  uniqueThreshold unique values prior to one-hot encoding. 
#(each unique value becomes a new column during one-hot encoding)
uniqueThreshold = 200

#Read in the School Data File
schoolData = pd.read_csv(inputFile, low_memory=False, dtype={'agency_code': object})
print('*********Start: Beginning Column and Row Counts********************************************')
schoolData.info(verbose=False)

#Select only public schools as charter schools are missing data for many columns.
schoolData = schoolData[(schoolData['designation_type'] == 'P') & (schoolData['avg_student_num'] > 0)]

print('\r\n*********After: Selecting Only Public School Campuses**********************************')
schoolData.info(verbose=False)

#Save primary key
agency_code = schoolData['agency_code']
#Convert zip code to string
schoolData['zip'] = schoolData['zip'].astype('object')
# Out:
# *********Start: Beginning Column and Row Counts********************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 679 entries, 0 to 678
# Columns: 4475 entries, agency_code to lea_federal_perpupil
# dtypes: float64(4423), object(52)
# memory usage: 23.2+ MB
#
# *********After: Selecting Only Public School Campuses**********************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 603 entries, 2 to 678
# Columns: 4475 entries, agency_code to lea_federal_perpupil
# dtypes: float64(4423), object(52)
# memory usage: 20.6+ MB

# %% [markdown]
# # Prepare Consolidated Dataset for Machine Learning
# **Below we perform operations on the entire dataset to remove columns and update row values that could cause problems during machine learning.**

# %% [markdown]
# ## Student Body Racial Composition Features
# **Impute / update missing Student Body Racial Composition Fields using mean imputation.**
# * When there are no racial composition percentages for a particular school campus / agency_code, fill in the missing values

# %%
#Get Student Body Racial Composition Fields
raceCompositionFields = schoolData.filter(regex='Indian|Asian|Hispanic|Black|White|PacificIsland|TwoOrMore|Minority')\
                                  .filter(regex='Pct').columns
    
rowsBefore = schoolData[raceCompositionFields].isnull().T.any().T.sum()

#Update missing race values with the district average when avaiable (No district averages for charter schools) 
schoolData[raceCompositionFields] = schoolData.groupby('lea_code')[raceCompositionFields]\
                                              .transform(lambda x: x.fillna(x.mean()))

    #Review dataset contents after Racial Composition Imputation
print('*********After: Updating Missing Racial Compostion Values****************************')   
rowsAfter = schoolData[raceCompositionFields].isnull().T.any().T.sum()
rowsUpdated = rowsBefore - rowsAfter
print('Rows Updated / Imputed: ', rowsUpdated) 
print('\r\nTotal Rows Missing Racial Compositions By District Code') 
schoolData['lea_code'][schoolData[raceCompositionFields].isnull().T.any().T].value_counts()
# Out:
# *********After: Updating Missing Racial Compostion Values****************************
# Rows Updated / Imputed:  0
#
# Total Rows Missing Racial Compositions By District Code
# Series([], Name: lea_code, dtype: int64)

# %% [markdown]
# ## Remove Columns with Problematic Data
# **Here we remove entire columns that could cause problems during machine learning.  The following operations are performed:**
# * Remove any columns that have the same value in every single row.
# * Remove any columns that have a unique value in every single row (all values are different).
# * Remove empty columns (all values are NA or NULL).

# %%
#Remove any fields that have the same value in all rows
UniqueValueCounts = schoolData.nunique(dropna=False)
SingleValueCols = UniqueValueCounts[UniqueValueCounts == 1].index
schoolData = schoolData.drop(SingleValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with the same value in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(SingleValueCols))
# Out:
# *********After: Removing columns with the same value in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 603 entries, 2 to 678
# Columns: 3204 entries, agency_code to lea_federal_perpupil
# dtypes: float64(3156), object(48)
# memory usage: 14.7+ MB
#
# Columns Deleted:  1271

# %%
#Remove any fields that have unique values in every row
schoolDataRecordCt = schoolData.shape[0]
UniqueValueCounts = schoolData.apply(pd.Series.nunique)
AllUniqueValueCols = UniqueValueCounts[UniqueValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(AllUniqueValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with unique values in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(AllUniqueValueCols))
# Out:
# *********After: Removing columns with unique values in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 603 entries, 2 to 678
# Columns: 3202 entries, category_code to lea_federal_perpupil
# dtypes: float64(3156), object(46)
# memory usage: 14.7+ MB
#
# Columns Deleted:  2

# %%
#Remove any empty fields (null values in every row)
schoolDataRecordCt = schoolData.shape[0]
NullValueCounts = schoolData.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with null / blank values in every row.*************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with null / blank values in every row.*************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 603 entries, 2 to 678
# Columns: 3202 entries, category_code to lea_federal_perpupil
# dtypes: float64(3156), object(46)
# memory usage: 14.7+ MB
#
# Columns Deleted:  0

# %% [markdown]
# ## Handle Other Missing Values Types
# * Here we eliminate any numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# * All remaining non-race, numeric column missing values are populated with 0.
# * In many cases, it seems that schools are not simply not reporting values when they are zero. However, mean imputation or some other strategy might be considered.

# %%
#Isolate continuous and categorical data types
#These are indexers into the schoolData dataframe and may be used similar to the schoolData dataframe 
sD_boolean = schoolData.loc[:, (schoolData.dtypes == bool) ]
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]
sD_continuous = schoolData.loc[:, (schoolData.dtypes != bool) & (schoolData.dtypes != object)]
print ("Boolean Columns: ", sD_boolean.shape[1])
print ("Nominal Columns: ", sD_nominal.shape[1])
print ("Continuous Columns: ", sD_continuous.shape[1])
print ("Columns Accounted for: ", sD_nominal.shape[1] + sD_continuous.shape[1] + sD_boolean.shape[1])
# Out:
# Boolean Columns:  0
# Nominal Columns:  46
# Continuous Columns:  3156
# Columns Accounted for:  3202

# %%
#Eliminate continuous columns with more than missingThreshold percentage of missing values
schoolDataRecordCt = sD_continuous.shape[0]
missingValueLimit = schoolDataRecordCt * missingThreshold
NullValueCounts = sD_continuous.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts >= missingValueLimit].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with >= missingThreshold % of missing values******')
schoolData.info(verbose=False)
print('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with >= missingThreshold % of missing values******
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 603 entries, 2 to 678
# Columns: 761 entries, category_code to lea_federal_perpupil
# dtypes: float64(715), object(46)
# memory usage: 3.5+ MB
#
# Columns Deleted:  2441

# %% [markdown]
# ## One-Hot Encoding of Categorical Variables
# **All categorical / string variables are converted to numberic variables via one hot encoding.  Each unique row value will become a new binary / numeric column in the dataset.**
# * All remaining categorical columns are one-hot encoded.
# * In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# * Prior to one-hot encoding, columns with > *uniqueThreshold* unique values are deleted.

# %%
#Delete categorical columns with > uniqueThreshold unique values 
#(Each unique value becomes a column during one-hot encoding)
oneHotUniqueValueCounts = schoolData[sD_nominal.columns].apply(lambda x: x.nunique())
oneHotUniqueValueCols = oneHotUniqueValueCounts[oneHotUniqueValueCounts >= uniqueThreshold].index
schoolData.drop(oneHotUniqueValueCols, axis=1, inplace=True) 

#Remove categorical columns which do not add value to machine learning
#Grades columns dropped since they all have indicator fields (device_access, device_home, BYOD)
#with less unique values to one-hot encode
schoolData.drop(['welcome_url','device_access_grades',
                 'device_home_grades','byod_grades'], axis=1, inplace=True) 

#Review dataset contents one hot high unique value drops
print('*********After: Removing columns with >= uniqueThreshold unique values***********')
schoolData.info(verbose=False)
print('\r\nColumns Deleted: ', len(oneHotUniqueValueCols))
print(oneHotUniqueValueCols)
print('Dropped Manually: welcome_url,device_access_grades,device_home_grades,byod_grades')
# Out:
# *********After: Removing columns with >= uniqueThreshold unique values***********
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 603 entries, 2 to 678
# Columns: 744 entries, category_code to lea_federal_perpupil
# dtypes: float64(715), object(29)
# memory usage: 3.4+ MB
#
# Columns Deleted:  13
# Index(['street_addr', 'city', 'zip', 'phone', 'url', 'school_name',
#        'school_name_attendance', 'ada_ct_2017_attendance',
#        'adm_ct_2017_attendance', 'ada_ct_2018_attendance',
#        'adm_ct_2018_attendance', 'ada_ct_2019_attendance',
#        'adm_ct_2019_attendance'],
#       dtype='object')
# Dropped Manually: welcome_url,device_access_grades,device_home_grades,byod_grades

# %%
#Isolate remaining categorical variables
begColumnCt = len(schoolData.columns)
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]

#one hot encode categorical variables
schoolData = pd.get_dummies(data=schoolData, 
                       columns=sD_nominal.columns, drop_first=True)

#Determine change in column count
endColumnCt = len(schoolData.columns)
columnsAdded = endColumnCt - begColumnCt

#Review dataset contents one hot high unique value drops
print('Columns To One-Hot Encode: ', len(sD_nominal.columns))
print('\r\n*********After: Adding New Columns Via One-Hot Encoding*************************')
schoolData.info(verbose=False)
print('\r\nNew Columns Created Via One-Hot Encoding: ', columnsAdded)
# Out:
# Columns To One-Hot Encode:  29
#
# *********After: Adding New Columns Via One-Hot Encoding*************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 603 entries, 2 to 678
# Columns: 1417 entries, lea to agency_lea_code_995LEA
# dtypes: float64(715), uint8(702)
# memory usage: 3.7 MB
#
# New Columns Created Via One-Hot Encoding:  673

# %%
#Remove any fields that have the same value in all rows after one-hot encoding
UniqueValueCounts = schoolData.nunique(dropna=False)
SingleValueCols = UniqueValueCounts[UniqueValueCounts == 1].index
schoolData = schoolData.drop(SingleValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing one-hot encoded columns with the same value in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(SingleValueCols))
# Out:
# *********After: Removing one-hot encoded columns with the same value in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 603 entries, 2 to 678
# Columns: 1417 entries, lea to agency_lea_code_995LEA
# dtypes: float64(715), uint8(702)
# memory usage: 3.7 MB
#
# Columns Deleted:  0

# %% [markdown]
# ## Impute any Remaining Missing Values as Zero

# %%
#Print out all the missing value rows
pd.set_option('display.max_rows', 1000)

print('\r\n*********The Remaining Missing Values Below will be set to Zero!*************************')

#Check for Missing values 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# *********The Remaining Missing Values Below will be set to Zero!*************************
#                                Variable Name  Number Missing Values
# 28             ada_adm_ratio_2018_attendance                     13
# 30             ada_adm_ratio_2019_attendance                      8
# 31   ada_adm_ratio_2017_thru_2019_attendance                     21
# 32    ada_adm_rank_2017_thru_2019_attendance                     21
# 33                         pct_ACALL_AIG_ACT                    116
# 34                         pct_ACALL_ALL_ACT                     47
# 35                         pct_ACALL_AS7_ACT                    335
# 36                         pct_ACALL_BL7_ACT                    112
# 37                         pct_ACALL_EDS_ACT                     60
# 38                         pct_ACALL_ELS_ACT                    240
# 39                         pct_ACALL_FEM_ACT                     65
# 40                         pct_ACALL_HI7_ACT                    111
# 41                        pct_ACALL_MALE_ACT                     57
# 42                         pct_ACALL_MU7_ACT                    186
# 43                         pct_ACALL_SWD_ACT                    166
# 44                         pct_ACALL_WH7_ACT                     78
# 45                          pct_ACCO_AIG_ACT                    196
# 46                          pct_ACCO_ALL_ACT                     77
# 47                          pct_ACCO_BL7_ACT                    226
# 48                          pct_ACCO_EDS_ACT                    121
# 49                          pct_ACCO_FEM_ACT                    102
# 50                          pct_ACCO_HI7_ACT                    241
# 51                         pct_ACCO_MALE_ACT                    107
# 52                          pct_ACCO_SWD_ACT                    294
# 53                          pct_ACCO_WH7_ACT                    142
# 54                          pct_ACEN_AIG_ACT                    196
# 55                          pct_ACEN_ALL_ACT                     77
# 56                          pct_ACEN_BL7_ACT                    225
# 57                          pct_ACEN_EDS_ACT                    121
# 58                          pct_ACEN_FEM_ACT                    102
# 59                          pct_ACEN_HI7_ACT                    241
# 60                         pct_ACEN_MALE_ACT                    106
# 61                          pct_ACEN_SWD_ACT                    292
# 62                          pct_ACEN_WH7_ACT                    142
# 63                          pct_ACMA_AIG_ACT                    196
# 64                          pct_ACMA_ALL_ACT                     77
# 65                          pct_ACMA_BL7_ACT                    225
# 66                          pct_ACMA_EDS_ACT                    121
# 67                          pct_ACMA_FEM_ACT                    102
# 68                          pct_ACMA_HI7_ACT                    241
# 69                         pct_ACMA_MALE_ACT                    106
# 70                          pct_ACMA_SWD_ACT                    292
# 71                          pct_ACMA_WH7_ACT                    142
# 72                          pct_ACRD_AIG_ACT                    196
# 73                          pct_ACRD_ALL_ACT                     77
# 74                          pct_ACRD_BL7_ACT                    225
# 75                          pct_ACRD_EDS_ACT                    121
# 76                          pct_ACRD_FEM_ACT                    102
# 77                          pct_ACRD_HI7_ACT                    241
# 78                         pct_ACRD_MALE_ACT                    106
# 79                          pct_ACRD_SWD_ACT                    292
# 80                          pct_ACRD_WH7_ACT                    142
# 81                          pct_ACSC_AIG_ACT                    196
# 82                          pct_ACSC_ALL_ACT                     77
# 83                          pct_ACSC_BL7_ACT                    226
# 84                          pct_ACSC_EDS_ACT                    121
# 85                          pct_ACSC_FEM_ACT                    102
# 86                          pct_ACSC_HI7_ACT                    241
# 87                         pct_ACSC_MALE_ACT                    107
# 88                          pct_ACSC_SWD_ACT                    294
# 89                          pct_ACSC_WH7_ACT                    142
# 90                          pct_ACWR_AIG_ACT                    196
# 91                          pct_ACWR_ALL_ACT                     78
# 92                          pct_ACWR_BL7_ACT                    227
# 93                          pct_ACWR_EDS_ACT                    122
# 94                          pct_ACWR_FEM_ACT                    102
# 95                          pct_ACWR_HI7_ACT                    244
# 96                         pct_ACWR_MALE_ACT                    110
# 97                          pct_ACWR_SWD_ACT                    316
# 98                          pct_ACWR_WH7_ACT                    143
# 99                               pct_AIG_AWA                    197
# 100                              pct_ALL_AWA                     82
# 101                              pct_BL7_AWA                    230
# 102                              pct_EDS_AWA                    143
# 103                              pct_FEM_AWA                    105
# 104                              pct_HI7_AWA                    266
# 105                             pct_MALE_AWA                    113
# 106                              pct_SWD_AWA                    308
# 107                              pct_WH7_AWA                    145
# 108                          pct_EXT_AIG_CGR                    196
# 109                          pct_EXT_ALL_CGR                     56
# 110                          pct_EXT_BL7_CGR                    217
# 111                          pct_EXT_EDS_CGR                    106
# 112                          pct_EXT_FEM_CGR                     95
# 113                          pct_EXT_HI7_CGR                    260
# 114                         pct_EXT_MALE_CGR                     80
# 115                          pct_EXT_SWD_CGR                    242
# 116                          pct_EXT_WH7_CGR                    123
# 117                          pct_STD_AIG_CGR                    189
# 118                          pct_STD_ALL_CGR                     55
# 119                          pct_STD_BL7_CGR                    200
# 120                          pct_STD_EDS_CGR                     93
# 121                          pct_STD_FEM_CGR                     75
# 122                          pct_STD_HI7_CGR                    237
# 123                         pct_STD_MALE_CGR                     76
# 124                          pct_STD_SWD_CGR                    201
# 125                          pct_STD_WH7_CGR                    109
# 126                                  pct_eds                      1
# 127                              pct_ALL_ELP                    295
# 128                              pct_EDS_ELP                    338
# 129                              pct_ELS_ELP                    295
# 130                              pct_HI7_ELP                    313
# 131                             pct_MALE_ELP                    350
# 132                         pct_prof_9gr_irm                     65
# 133       pct_met_4 Year Graduation Rate_LTG                    135
# 134                pct_met_Math Grade 11_LTG                    149
# 135             pct_met_Reading Grade 10_LTG                    138
# 136                pct_met_Total Targets_LTG                     86
# 137                              pct_AIG_MCR                    190
# 138                              pct_ALL_MCR                     56
# 139                              pct_BL7_MCR                    217
# 140                              pct_EDS_MCR                    119
# 141                              pct_FEM_MCR                     91
# 142                              pct_HI7_MCR                    253
# 143                             pct_MALE_MCR                     87
# 144                              pct_SWD_MCR                    238
# 145                              pct_WH7_MCR                    124
# 146                pct_met_ACT WorkKeys_PART                    241
# 147                     pct_met_Biology_PART                    111
# 148                  pct_met_English II_PART                    111
# 149            pct_met_High School Math_PART                    111
# 150                     pct_met_The ACT_PART                    112
# 151               pct_met_Total Targets_PART                     62
# 152            pct_ACT WorkKeys_ALL_PART_DET                    241
# 153            pct_ACT WorkKeys_WH7_PART_DET                    335
# 154                 pct_Biology_ALL_PART_DET                    111
# 155                 pct_Biology_BL7_PART_DET                    354
# 156                 pct_Biology_EDS_PART_DET                    234
# 157                 pct_Biology_WH7_PART_DET                    235
# 158              pct_English II_ALL_PART_DET                    111
# 159              pct_English II_BL7_PART_DET                    338
# 160              pct_English II_EDS_PART_DET                    218
# 161              pct_English II_WH7_PART_DET                    230
# 162        pct_High School Math_ALL_PART_DET                    111
# 163        pct_High School Math_BL7_PART_DET                    354
# 164        pct_High School Math_EDS_PART_DET                    234
# 165        pct_High School Math_WH7_PART_DET                    235
# 166                 pct_The ACT_ALL_PART_DET                    112
# 167                 pct_The ACT_BL7_PART_DET                    355
# 168                 pct_The ACT_EDS_PART_DET                    235
# 169                 pct_The ACT_WH7_PART_DET                    238
# 170                    pct_CCR_BI_EOC_AIG_PC                    203
# 171                    pct_CCR_BI_EOC_ALL_PC                     79
# 172                    pct_CCR_BI_EOC_BL7_PC                    224
# 173                    pct_CCR_BI_EOC_EDS_PC                    123
# 174                    pct_CCR_BI_EOC_FEM_PC                    104
# 175                    pct_CCR_BI_EOC_HI7_PC                    238
# 176                   pct_CCR_BI_EOC_MALE_PC                     99
# 177                    pct_CCR_BI_EOC_SWD_PC                    291
# 178                    pct_CCR_BI_EOC_WH7_PC                    136
# 179                    pct_CCR_E2_EOC_AIG_PC                    190
# 180                    pct_CCR_E2_EOC_ALL_PC                     73
# 181                    pct_CCR_E2_EOC_BL7_PC                    213
# 182                    pct_CCR_E2_EOC_EDS_PC                    104
# 183                    pct_CCR_E2_EOC_FEM_PC                    102
# 184                    pct_CCR_E2_EOC_HI7_PC                    219
# 185                   pct_CCR_E2_EOC_MALE_PC                     98
# 186                    pct_CCR_E2_EOC_SWD_PC                    329
# 187                    pct_CCR_E2_EOC_WH7_PC                    128
# 188                   pct_CCR_EOC_EOC_AIG_PC                    123
# 189                   pct_CCR_EOC_EOC_ALL_PC                     55
# 190                   pct_CCR_EOC_EOC_BL7_PC                    147
# 191                   pct_CCR_EOC_EOC_EDS_PC                     76
# 192                   pct_CCR_EOC_EOC_ELS_PC                    298
# 193                   pct_CCR_EOC_EOC_FEM_PC                     77
# 194                   pct_CCR_EOC_EOC_HI7_PC                    129
# 195                  pct_CCR_EOC_EOC_MALE_PC                     67
# 196                   pct_CCR_EOC_EOC_MU7_PC                    247
# 197                   pct_CCR_EOC_EOC_SWD_PC                    256
# 198                   pct_CCR_EOC_EOC_WH7_PC                     77
# 199                    pct_CCR_M1_EOC_AIG_PC                    199
# 200                    pct_CCR_M1_EOC_ALL_PC                     94
# 201                    pct_CCR_M1_EOC_BL7_PC                    228
# 202                    pct_CCR_M1_EOC_EDS_PC                    121
# 203                    pct_CCR_M1_EOC_FEM_PC                    112
# 204                    pct_CCR_M1_EOC_HI7_PC                    215
# 205                   pct_CCR_M1_EOC_MALE_PC                    109
# 206                    pct_CCR_M1_EOC_SWD_PC                    348
# 207                    pct_CCR_M1_EOC_WH7_PC                    139
# 208                    pct_GLP_BI_EOC_AIG_PC                    203
# 209                    pct_GLP_BI_EOC_ALL_PC                     73
# 210                    pct_GLP_BI_EOC_BL7_PC                    217
# 211                    pct_GLP_BI_EOC_EDS_PC                    118
# 212                    pct_GLP_BI_EOC_FEM_PC                    101
# 213                    pct_GLP_BI_EOC_HI7_PC                    237
# 214                   pct_GLP_BI_EOC_MALE_PC                     96
# 215                    pct_GLP_BI_EOC_SWD_PC                    268
# 216                    pct_GLP_BI_EOC_WH7_PC                    136
# 217                    pct_GLP_E2_EOC_AIG_PC                    190
# 218                    pct_GLP_E2_EOC_ALL_PC                     66
# 219                    pct_GLP_E2_EOC_BL7_PC                    206
# 220                    pct_GLP_E2_EOC_EDS_PC                     97
# 221                    pct_GLP_E2_EOC_FEM_PC                    100
# 222                    pct_GLP_E2_EOC_HI7_PC                    219
# 223                   pct_GLP_E2_EOC_MALE_PC                     88
# 224                    pct_GLP_E2_EOC_SWD_PC                    276
# 225                    pct_GLP_E2_EOC_WH7_PC                    128
# 226                   pct_GLP_EOC_EOC_AIG_PC                    123
# 227                   pct_GLP_EOC_EOC_ALL_PC                     47
# 228                   pct_GLP_EOC_EOC_BL7_PC                    138
# 229                   pct_GLP_EOC_EOC_EDS_PC                     63
# 230                   pct_GLP_EOC_EOC_ELS_PC                    276
# 231                   pct_GLP_EOC_EOC_FEM_PC                     66
# 232                   pct_GLP_EOC_EOC_HI7_PC                    127
# 233                  pct_GLP_EOC_EOC_MALE_PC                     53
# 234                   pct_GLP_EOC_EOC_MU7_PC                    246
# 235                   pct_GLP_EOC_EOC_SWD_PC                    208
# 236                   pct_GLP_EOC_EOC_WH7_PC                     71
# 237                    pct_GLP_M1_EOC_AIG_PC                    199
# 238                    pct_GLP_M1_EOC_ALL_PC                     84
# 239                    pct_GLP_M1_EOC_BL7_PC                    218
# 240                    pct_GLP_M1_EOC_EDS_PC                    110
# 241                    pct_GLP_M1_EOC_FEM_PC                    105
# 242                    pct_GLP_M1_EOC_HI7_PC                    215
# 243                   pct_GLP_M1_EOC_MALE_PC                    100
# 244                    pct_GLP_M1_EOC_SWD_PC                    280
# 245                    pct_GLP_M1_EOC_WH7_PC                    137
# 246                    pct_L1_ALL_ALL_ALL_PC                     97
# 247                    pct_L1_ALL_ALL_BL7_PC                    148
# 248                    pct_L1_ALL_ALL_EDS_PC                     88
# 249                    pct_L1_ALL_ALL_ELS_PC                    243
# 250                    pct_L1_ALL_ALL_FEM_PC                    113
# 251                    pct_L1_ALL_ALL_HI7_PC                    160
# 252                   pct_L1_ALL_ALL_MALE_PC                    101
# 253                    pct_L1_ALL_ALL_MU7_PC                    259
# 254                    pct_L1_ALL_ALL_SWD_PC                    132
# 255                    pct_L1_ALL_ALL_WH7_PC                    155
# 256                     pct_L1_BI_EOC_ALL_PC                    149
# 257                     pct_L1_BI_EOC_BL7_PC                    234
# 258                     pct_L1_BI_EOC_EDS_PC                    159
# 259                     pct_L1_BI_EOC_FEM_PC                    176
# 260                     pct_L1_BI_EOC_HI7_PC                    267
# 261                    pct_L1_BI_EOC_MALE_PC                    174
# 262                     pct_L1_BI_EOC_SWD_PC                    241
# 263                     pct_L1_BI_EOC_WH7_PC                    259
# 264                     pct_L1_E2_EOC_ALL_PC                    154
# 265                     pct_L1_E2_EOC_BL7_PC                    244
# 266                     pct_L1_E2_EOC_EDS_PC                    163
# 267                     pct_L1_E2_EOC_FEM_PC                    214
# 268                     pct_L1_E2_EOC_HI7_PC                    264
# 269                    pct_L1_E2_EOC_MALE_PC                    169
# 270                     pct_L1_E2_EOC_SWD_PC                    238
# 271                     pct_L1_E2_EOC_WH7_PC                    243
# 272                    pct_L1_EOC_EOC_ALL_PC                    106
# 273                    pct_L1_EOC_EOC_BL7_PC                    166
# 274                    pct_L1_EOC_EOC_EDS_PC                    105
# 275                    pct_L1_EOC_EOC_ELS_PC                    266
# 276                    pct_L1_EOC_EOC_FEM_PC                    139
# 277                    pct_L1_EOC_EOC_HI7_PC                    188
# 278                   pct_L1_EOC_EOC_MALE_PC                    114
# 279                    pct_L1_EOC_EOC_MU7_PC                    280
# 280                    pct_L1_EOC_EOC_SWD_PC                    159
# 281                    pct_L1_EOC_EOC_WH7_PC                    183
# 282                     pct_L1_M1_EOC_ALL_PC                    130
# 283                     pct_L1_M1_EOC_BL7_PC                    231
# 284                     pct_L1_M1_EOC_EDS_PC                    140
# 285                     pct_L1_M1_EOC_FEM_PC                    169
# 286                     pct_L1_M1_EOC_HI7_PC                    247
# 287                    pct_L1_M1_EOC_MALE_PC                    146
# 288                     pct_L1_M1_EOC_SWD_PC                    231
# 289                     pct_L1_M1_EOC_WH7_PC                    222
# 290                    pct_L2_ALL_ALL_ALL_PC                     44
# 291                    pct_L2_ALL_ALL_BL7_PC                    129
# 292                    pct_L2_ALL_ALL_EDS_PC                     52
# 293                    pct_L2_ALL_ALL_ELS_PC                    247
# 294                    pct_L2_ALL_ALL_FEM_PC                     59
# 295                    pct_L2_ALL_ALL_HI7_PC                    122
# 296                   pct_L2_ALL_ALL_MALE_PC                     64
# 297                    pct_L2_ALL_ALL_MU7_PC                    249
# 298                    pct_L2_ALL_ALL_SWD_PC                    146
# 299                    pct_L2_ALL_ALL_WH7_PC                     96
# 300                     pct_L2_BI_EOC_ALL_PC                     92
# 301                     pct_L2_BI_EOC_BL7_PC                    222
# 302                     pct_L2_BI_EOC_EDS_PC                    126
# 303                     pct_L2_BI_EOC_FEM_PC                    125
# 304                     pct_L2_BI_EOC_HI7_PC                    248
# 305                    pct_L2_BI_EOC_MALE_PC                    126
# 306                     pct_L2_BI_EOC_SWD_PC                    250
# 307                     pct_L2_BI_EOC_WH7_PC                    179
# 308                     pct_L2_E2_EOC_ALL_PC                     94
# 309                     pct_L2_E2_EOC_BL7_PC                    217
# 310                     pct_L2_E2_EOC_EDS_PC                    123
# 311                     pct_L2_E2_EOC_FEM_PC                    138
# 312                     pct_L2_E2_EOC_HI7_PC                    238
# 313                    pct_L2_E2_EOC_MALE_PC                    124
# 314                     pct_L2_E2_EOC_SWD_PC                    251
# 315                     pct_L2_E2_EOC_WH7_PC                    178
# 316                    pct_L2_EOC_EOC_ALL_PC                     52
# 317                    pct_L2_EOC_EOC_BL7_PC                    145
# 318                    pct_L2_EOC_EOC_EDS_PC                     70
# 319                    pct_L2_EOC_EOC_ELS_PC                    269
# 320                    pct_L2_EOC_EOC_FEM_PC                     85
# 321                    pct_L2_EOC_EOC_HI7_PC                    150
# 322                   pct_L2_EOC_EOC_MALE_PC                     77
# 323                    pct_L2_EOC_EOC_MU7_PC                    270
# 324                    pct_L2_EOC_EOC_SWD_PC                    174
# 325                    pct_L2_EOC_EOC_WH7_PC                    119
# 326                     pct_L2_M1_EOC_ALL_PC                    120
# 327                     pct_L2_M1_EOC_BL7_PC                    226
# 328                     pct_L2_M1_EOC_EDS_PC                    142
# 329                     pct_L2_M1_EOC_FEM_PC                    162
# 330                     pct_L2_M1_EOC_HI7_PC                    252
# 331                    pct_L2_M1_EOC_MALE_PC                    144
# 332                     pct_L2_M1_EOC_SWD_PC                    252
# 333                     pct_L2_M1_EOC_WH7_PC                    206
# 334                    pct_L3_ALL_ALL_ALL_PC                     82
# 335                    pct_L3_ALL_ALL_BL7_PC                    184
# 336                    pct_L3_ALL_ALL_EDS_PC                     87
# 337                    pct_L3_ALL_ALL_FEM_PC                     80
# 338                    pct_L3_ALL_ALL_HI7_PC                    142
# 339                   pct_L3_ALL_ALL_MALE_PC                    105
# 340                    pct_L3_ALL_ALL_MU7_PC                    303
# 341                    pct_L3_ALL_ALL_SWD_PC                    338
# 342                    pct_L3_ALL_ALL_WH7_PC                    129
# 343                     pct_L3_BI_EOC_ALL_PC                    202
# 344                     pct_L3_BI_EOC_BL7_PC                    348
# 345                     pct_L3_BI_EOC_EDS_PC                    249
# 346                     pct_L3_BI_EOC_FEM_PC                    217
# 347                     pct_L3_BI_EOC_HI7_PC                    358
# 348                    pct_L3_BI_EOC_MALE_PC                    252
# 349                     pct_L3_BI_EOC_WH7_PC                    264
# 350                     pct_L3_E2_EOC_ALL_PC                     97
# 351                     pct_L3_E2_EOC_BL7_PC                    243
# 352                     pct_L3_E2_EOC_EDS_PC                    131
# 353                     pct_L3_E2_EOC_FEM_PC                    139
# 354                     pct_L3_E2_EOC_HI7_PC                    250
# 355                    pct_L3_E2_EOC_MALE_PC                    131
# 356                     pct_L3_E2_EOC_WH7_PC                    189
# 357                    pct_L3_EOC_EOC_ALL_PC                     89
# 358                    pct_L3_EOC_EOC_BL7_PC                    190
# 359                    pct_L3_EOC_EOC_EDS_PC                     98
# 360                    pct_L3_EOC_EOC_FEM_PC                     95
# 361                    pct_L3_EOC_EOC_HI7_PC                    161
# 362                   pct_L3_EOC_EOC_MALE_PC                    116
# 363                    pct_L3_EOC_EOC_MU7_PC                    315
# 364                    pct_L3_EOC_EOC_SWD_PC                    351
# 365                    pct_L3_EOC_EOC_WH7_PC                    146
# 366                     pct_L3_M1_EOC_ALL_PC                    120
# 367                     pct_L3_M1_EOC_BL7_PC                    262
# 368                     pct_L3_M1_EOC_EDS_PC                    149
# 369                     pct_L3_M1_EOC_FEM_PC                    128
# 370                     pct_L3_M1_EOC_HI7_PC                    254
# 371                    pct_L3_M1_EOC_MALE_PC                    169
# 372                     pct_L3_M1_EOC_WH7_PC                    195
# 373                    pct_L4_ALL_ALL_AIG_PC                    114
# 374                    pct_L4_ALL_ALL_ALL_PC                     44
# 375                    pct_L4_ALL_ALL_BL7_PC                    140
# 376                    pct_L4_ALL_ALL_EDS_PC                     64
# 377                    pct_L4_ALL_ALL_ELS_PC                    286
# 378                    pct_L4_ALL_ALL_FEM_PC                     63
# 379                    pct_L4_ALL_ALL_HI7_PC                    114
# 380                   pct_L4_ALL_ALL_MALE_PC                     51
# 381                    pct_L4_ALL_ALL_MU7_PC                    230
# 382                    pct_L4_ALL_ALL_SWD_PC                    258
# 383                    pct_L4_ALL_ALL_WH7_PC                     57
# 384                     pct_L4_BI_EOC_AIG_PC                    205
# 385                     pct_L4_BI_EOC_ALL_PC                     81
# 386                     pct_L4_BI_EOC_BL7_PC                    225
# 387                     pct_L4_BI_EOC_EDS_PC                    126
# 388                     pct_L4_BI_EOC_FEM_PC                    107
# 389                     pct_L4_BI_EOC_HI7_PC                    240
# 390                    pct_L4_BI_EOC_MALE_PC                    102
# 391                     pct_L4_BI_EOC_SWD_PC                    317
# 392                     pct_L4_BI_EOC_WH7_PC                    137
# 393                     pct_L4_E2_EOC_AIG_PC                    190
# 394                     pct_L4_E2_EOC_ALL_PC                     72
# 395                     pct_L4_E2_EOC_BL7_PC                    214
# 396                     pct_L4_E2_EOC_EDS_PC                    105
# 397                     pct_L4_E2_EOC_FEM_PC                    102
# 398                     pct_L4_E2_EOC_HI7_PC                    219
# 399                    pct_L4_E2_EOC_MALE_PC                     98
# 400                     pct_L4_E2_EOC_SWD_PC                    360
# 401                     pct_L4_E2_EOC_WH7_PC                    129
# 402                    pct_L4_EOC_EOC_AIG_PC                    123
# 403                    pct_L4_EOC_EOC_ALL_PC                     56
# 404                    pct_L4_EOC_EOC_BL7_PC                    147
# 405                    pct_L4_EOC_EOC_EDS_PC                     77
# 406                    pct_L4_EOC_EOC_ELS_PC                    305
# 407                    pct_L4_EOC_EOC_FEM_PC                     77
# 408                    pct_L4_EOC_EOC_HI7_PC                    129
# 409                   pct_L4_EOC_EOC_MALE_PC                     69
# 410                    pct_L4_EOC_EOC_MU7_PC                    247
# 411                    pct_L4_EOC_EOC_SWD_PC                    279
# 412                    pct_L4_EOC_EOC_WH7_PC                     79
# 413                     pct_L4_M1_EOC_AIG_PC                    199
# 414                     pct_L4_M1_EOC_ALL_PC                     94
# 415                     pct_L4_M1_EOC_BL7_PC                    229
# 416                     pct_L4_M1_EOC_EDS_PC                    122
# 417                     pct_L4_M1_EOC_FEM_PC                    113
# 418                     pct_L4_M1_EOC_HI7_PC                    215
# 419                    pct_L4_M1_EOC_MALE_PC                    110
# 420                     pct_L4_M1_EOC_WH7_PC                    142
# 421                    pct_L5_ALL_ALL_AIG_PC                    126
# 422                    pct_L5_ALL_ALL_ALL_PC                    231
# 423                    pct_L5_ALL_ALL_FEM_PC                    235
# 424                    pct_L5_ALL_ALL_HI7_PC                    355
# 425                   pct_L5_ALL_ALL_MALE_PC                    228
# 426                    pct_L5_ALL_ALL_WH7_PC                    156
# 427                     pct_L5_BI_EOC_AIG_PC                    205
# 428                     pct_L5_BI_EOC_ALL_PC                    167
# 429                     pct_L5_BI_EOC_EDS_PC                    288
# 430                     pct_L5_BI_EOC_FEM_PC                    189
# 431                     pct_L5_BI_EOC_HI7_PC                    347
# 432                    pct_L5_BI_EOC_MALE_PC                    181
# 433                     pct_L5_BI_EOC_WH7_PC                    165
# 434                     pct_L5_E2_EOC_AIG_PC                    261
# 435                    pct_L5_EOC_EOC_AIG_PC                    134
# 436                    pct_L5_EOC_EOC_ALL_PC                    235
# 437                    pct_L5_EOC_EOC_FEM_PC                    243
# 438                   pct_L5_EOC_EOC_MALE_PC                    239
# 439                    pct_L5_EOC_EOC_WH7_PC                    163
# 440                     pct_L5_M1_EOC_AIG_PC                    210
# 441                     pct_L5_M1_EOC_ALL_PC                    274
# 442                     pct_L5_M1_EOC_FEM_PC                    291
# 443                    pct_L5_M1_EOC_MALE_PC                    275
# 444                     pct_L5_M1_EOC_WH7_PC                    240
# 445                       aaa_score_ALL_SPG2                     92
# 446                       aaa_score_BL7_SPG2                    261
# 447                       aaa_score_EDS_SPG2                    131
# 448                       aaa_score_HI7_SPG2                    262
# 449                       aaa_score_SWD_SPG2                    260
# 450                       aaa_score_WH7_SPG2                    157
# 451                       ach_score_ALL_SPG2                     83
# 452                       ach_score_BL7_SPG2                    257
# 453                       ach_score_EDS_SPG2                    128
# 454                       ach_score_HI7_SPG2                    261
# 455                       ach_score_SWD_SPG2                    259
# 456                       ach_score_WH7_SPG2                    148
# 457                       awa_score_ALL_SPG2                    137
# 458                       awa_score_EDS_SPG2                    252
# 459                       awa_score_WH7_SPG2                    247
# 460                        bi_score_ALL_SPG2                    124
# 461                        bi_score_BL7_SPG2                    358
# 462                        bi_score_EDS_SPG2                    225
# 463                        bi_score_WH7_SPG2                    236
# 464                      cgrs_score_ALL_SPG2                    128
# 465                      cgrs_score_BL7_SPG2                    341
# 466                      cgrs_score_EDS_SPG2                    233
# 467                      cgrs_score_WH7_SPG2                    230
# 468                        eg_score_ALL_SPG2                    104
# 469                        eg_score_BL7_SPG2                    283
# 470                        eg_score_EDS_SPG2                    151
# 471                        eg_score_HI7_SPG2                    304
# 472                        eg_score_SWD_SPG2                    282
# 473                        eg_score_WH7_SPG2                    186
# 474                       mcr_score_ALL_SPG2                    136
# 475                       mcr_score_BL7_SPG2                    354
# 476                       mcr_score_EDS_SPG2                    243
# 477                       mcr_score_WH7_SPG2                    242
# 478                       spg_score_ALL_SPG2                     83
# 479                       spg_score_BL7_SPG2                    257
# 480                       spg_score_EDS_SPG2                    128
# 481                       spg_score_HI7_SPG2                    261
# 482                       spg_score_SWD_SPG2                    259
# 483                       spg_score_WH7_SPG2                    148
# 484                               pct_AIG_WK                    359
# 485                               pct_ALL_WK                    203
# 486                               pct_BL7_WK                    350
# 487                               pct_EDS_WK                    243
# 488                               pct_FEM_WK                    224
# 489                              pct_MALE_WK                    226
# 490                               pct_WH7_WK                    259
# 492                              pct_ap_pass                    205
# 493                     pct_ap_participation                    262
# 495                     pct_ALL_CHRON_ABSENT                     17
# 496                     pct_AS7_CHRON_ABSENT                    360
# 497                     pct_BL7_CHRON_ABSENT                     84
# 498                     pct_ELS_CHRON_ABSENT                    187
# 499                     pct_FEM_CHRON_ABSENT                     25
# 500                     pct_HI7_CHRON_ABSENT                     72
# 501                    pct_MALE_CHRON_ABSENT                     37
# 502                     pct_MU7_CHRON_ABSENT                    116
# 503                     pct_SWD_CHRON_ABSENT                    108
# 504                     pct_WH7_CHRON_ABSENT                     28
# 505          pct_enrolled_ENROLL_ALL_COLLEGE                     76
# 506          pct_enrolled_ENROLL_BL7_COLLEGE                    221
# 507          pct_enrolled_ENROLL_EDS_COLLEGE                    196
# 508          pct_enrolled_ENROLL_FEM_COLLEGE                     87
# 509          pct_enrolled_ENROLL_HI7_COLLEGE                    357
# 510         pct_enrolled_ENROLL_MALE_COLLEGE                     89
# 511          pct_enrolled_ENROLL_WH7_COLLEGE                    132
# 512                    pct_ap_H_AS7_COURSES2                    310
# 513                    pct_ap_H_BL7_COURSES2                    274
# 514                    pct_ap_H_FEM_COURSES2                    235
# 515                    pct_ap_H_HI7_COURSES2                    248
# 516                   pct_ap_H_MALE_COURSES2                    235
# 517                    pct_ap_H_MU7_COURSES2                    280
# 518                    pct_ap_H_WH7_COURSES2                    237
# 519                   pct_ccp_H_AM7_COURSES2                    249
# 520                   pct_ccp_H_AS7_COURSES2                    164
# 521                   pct_ccp_H_BL7_COURSES2                    108
# 522                   pct_ccp_H_ELS_COURSES2                    177
# 523                   pct_ccp_H_FEM_COURSES2                    100
# 524                   pct_ccp_H_HI7_COURSES2                    101
# 525                  pct_ccp_H_MALE_COURSES2                    100
# 526                   pct_ccp_H_MU7_COURSES2                    104
# 527                   pct_ccp_H_SWD_COURSES2                    125
# 528                   pct_ccp_H_WH7_COURSES2                     99
# 529                tot_num_ap_H_AM7_COURSES2                    235
# 530                tot_num_ap_H_AS7_COURSES2                    235
# 531                tot_num_ap_H_BL7_COURSES2                    235
# 532                tot_num_ap_H_ELS_COURSES2                    235
# 533                tot_num_ap_H_FEM_COURSES2                    235
# 534                tot_num_ap_H_HI7_COURSES2                    235
# 535               tot_num_ap_H_MALE_COURSES2                    235
# 536                tot_num_ap_H_MU7_COURSES2                    235
# 537              tot_num_ap_H_Other_COURSES2                    235
# 538                tot_num_ap_H_PI7_COURSES2                    235
# 539                tot_num_ap_H_SWD_COURSES2                    235
# 540                tot_num_ap_H_WH7_COURSES2                    235
# 541               tot_num_ccp_H_AM7_COURSES2                     99
# 542               tot_num_ccp_H_AS7_COURSES2                     99
# 543               tot_num_ccp_H_BL7_COURSES2                     99
# 544               tot_num_ccp_H_ELS_COURSES2                     99
# 545               tot_num_ccp_H_FEM_COURSES2                     99
# 546               tot_num_ccp_H_HI7_COURSES2                     99
# 547              tot_num_ccp_H_MALE_COURSES2                     99
# 548               tot_num_ccp_H_MU7_COURSES2                     99
# 549             tot_num_ccp_H_Other_COURSES2                     99
# 550               tot_num_ccp_H_PI7_COURSES2                     99
# 551               tot_num_ccp_H_SWD_COURSES2                     99
# 552               tot_num_ccp_H_WH7_COURSES2                     99
# 553                      year_H_AM7_COURSES2                     99
# 554                      year_H_AS7_COURSES2                     99
# 555                      year_H_BL7_COURSES2                     99
# 556                      year_H_ELS_COURSES2                     99
# 557                      year_H_FEM_COURSES2                     99
# 558                      year_H_HI7_COURSES2                     99
# 559                     year_H_MALE_COURSES2                     99
# 560                      year_H_MU7_COURSES2                     99
# 561                    year_H_Other_COURSES2                     99
# 562                      year_H_PI7_COURSES2                     99
# 563                      year_H_SWD_COURSES2                     99
# 564                      year_H_WH7_COURSES2                     99
# 565                   num_concentrators_AAVC                    135
# 566                   num_concentrators_AGNR                    135
# 567                   num_concentrators_ARCH                    135
# 568                    num_concentrators_BMA                    135
# 569                   num_concentrators_EDUC                    135
# 570                   num_concentrators_FINA                    135
# 571                   num_concentrators_HLTH                    135
# 572                   num_concentrators_HOSP                    135
# 573                   num_concentrators_HUMA                    135
# 574                   num_concentrators_INFO                    135
# 575                    num_concentrators_LAW                    135
# 576                   num_concentrators_MANU                    135
# 577                   num_concentrators_MRKT                    135
# 578                   num_concentrators_STEM                    135
# 579                   num_concentrators_TRAN                    135
# 580                          num_credentials                    168
# 581                          num_enrollments                    168
# 582                          cred_earned_pct                    168
# 583                              career_only                    104
# 584               career_college_college_unc                    104
# 585                 college_college_unc_only                    104
# 586                             college_only                    104
# 587                               stu_enroll                     28
# 588                               cte_enroll                     28
# 589                       cte_enrollment_pct                     28
# 590                   Book_TitlesPer_Student                    144
# 591                                      wap                     23
# 592                                wap_class                     23
# 593                             media_school                    130
# 594                                  devices                      3
# 595               pct_rating_T1_Accomplished                     15
# 596              pct_rating_T1_Distinguished                    152
# 597                 pct_rating_T1_Proficient                     54
# 598               pct_rating_T2_Accomplished                     43
# 599              pct_rating_T2_Distinguished                    334
# 600                 pct_rating_T2_Proficient                     85
# 601               pct_rating_T3_Accomplished                     51
# 602              pct_rating_T3_Distinguished                    340
# 603                 pct_rating_T3_Proficient                     77
# 604               pct_rating_T4_Accomplished                     18
# 605              pct_rating_T4_Distinguished                    231
# 606                 pct_rating_T4_Proficient                     57
# 607               pct_rating_T5_Accomplished                     56
# 608              pct_rating_T5_Distinguished                    348
# 609                 pct_rating_T5_Proficient                     72
# 610  pct_rating_TS_DoesNotMeetExpectedGrowth                    143
# 611      pct_rating_TS_ExceedsExpectedGrowth                    121
# 612        pct_rating_TS_MeetsExpectedGrowth                     49
# 613               avg_class_teach_TeacherExp                      2
# 614                pct_adv_degree_TeacherExp                      2
# 615              pct_experience_0_TeacherExp                      2
# 616             pct_experience_10_TeacherExp                      2
# 617              pct_experience_4_TeacherExp                      2
# 618                  pct_turnover_TeacherExp                     15
# 619                         arre_per1000_ALL                     35
# 620                         arre_per1000_BL7                     90
# 623                         arre_per1000_FEM                     56
# 624                         arre_per1000_HI7                    101
# 625                        arre_per1000_MALE                     47
# 626                         arre_per1000_MU7                    127
# 627                         arre_per1000_SWD                     25
# 628                         arre_per1000_WH7                     54
# 629                         blhr_per1000_ALL                     35
# 630                         blhr_per1000_BL7                     90
# 633                         blhr_per1000_FEM                     56
# 634                         blhr_per1000_HI7                    101
# 635                        blhr_per1000_MALE                     47
# 636                         blhr_per1000_MU7                    127
# 637                         blhr_per1000_SWD                     25
# 638                         blhr_per1000_WH7                     54
# 639                        crime_per1000_ALL                     35
# 640                        crime_per1000_BL7                     90
# 643                        crime_per1000_FEM                     56
# 644                        crime_per1000_HI7                    101
# 645                       crime_per1000_MALE                     47
# 646                        crime_per1000_MU7                    127
# 647                        crime_per1000_SWD                     25
# 648                        crime_per1000_WH7                     54
# 649                          exp_per1000_ALL                     35
# 650                          exp_per1000_BL7                    123
# 651                          exp_per1000_EDS                      7
# 652                          exp_per1000_ELS                    180
# 653                          exp_per1000_FEM                     63
# 654                          exp_per1000_HI7                    150
# 655                         exp_per1000_MALE                     50
# 656                          exp_per1000_MU7                    230
# 657                          exp_per1000_SWD                    123
# 658                          exp_per1000_WH7                     78
# 659                          iss_per1000_ALL                     35
# 660                          iss_per1000_BL7                    124
# 661                          iss_per1000_EDS                      7
# 662                          iss_per1000_ELS                    180
# 663                          iss_per1000_FEM                     63
# 664                          iss_per1000_HI7                    150
# 665                         iss_per1000_MALE                     50
# 666                          iss_per1000_MU7                    230
# 667                          iss_per1000_SWD                    123
# 668                          iss_per1000_WH7                     78
# 669                          lts_per1000_ALL                     35
# 670                          lts_per1000_BL7                    123
# 671                          lts_per1000_EDS                      7
# 672                          lts_per1000_ELS                    180
# 673                          lts_per1000_FEM                     63
# 674                          lts_per1000_HI7                    150
# 675                         lts_per1000_MALE                     50
# 676                          lts_per1000_MU7                    230
# 677                          lts_per1000_SWD                    123
# 678                          lts_per1000_WH7                     78
# 679                         rplw_per1000_ALL                     35
# 680                         rplw_per1000_BL7                     90
# 682                         rplw_per1000_FEM                     56
# 683                         rplw_per1000_HI7                    101
# 684                        rplw_per1000_MALE                     47
# 685                         rplw_per1000_MU7                    127
# 686                         rplw_per1000_SWD                     25
# 687                         rplw_per1000_WH7                     54
# 688                          sts_per1000_ALL                     35
# 689                          sts_per1000_BL7                    128
# 690                          sts_per1000_EDS                      7
# 691                          sts_per1000_ELS                    180
# 692                          sts_per1000_FEM                     65
# 693                          sts_per1000_HI7                    152
# 694                         sts_per1000_MALE                     55
# 695                          sts_per1000_MU7                    230
# 696                          sts_per1000_SWD                    125
# 697                          sts_per1000_WH7                     78
# 698                       pct_fully_licensed                      2
# 699                        pct_lateral_entry                      2
# 700                                nbpts_num                      1
# 701                     avg_size_Biology_SAR                     48
# 702                  avg_size_English II_SAR                     54
# 703                      avg_size_Math I_SAR                     58
# 704                            avg_sat_score                    146
# 705                    pct_sat_participation                    146

# %%
#Replace all remaining NaN with 0
schoolData = schoolData.fillna(0)

#Check for Missing values after final imputation 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# Empty DataFrame
# Columns: [Variable Name, Number Missing Values]
# Index: []

# %% [markdown]
# ## Identify and Remove Highly Correlated Features
# **Find and remove any columns / features that are > 95% correlated**
# * https://stackoverflow.com/questions/39409866/correlation-heatmap
# * https://chrisalbon.com/machine_learning/feature_selection/drop_highly_correlated_features/
# * https://codeyarns.com/2015/04/20/how-to-change-font-size-in-seaborn/

# %%
# calculate the correlation matrix
corr_matrix  = schoolData.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
#Get all of the correlation values > 95%
x = np.where(upper > 0.95)

#Display all field combinations with > 95% correlation
cf = pd.DataFrame()
cf['Field1'] = upper.columns[x[1]]
cf['Field2'] = upper.index[x[0]]

#Get the correlation values for every field combination. (There must be a more pythonic way to do this!)
corr = [0] * len(cf)
for i in range(0, len(cf)):
    corr[i] =  upper[cf['Field1'][i]][cf['Field2'][i]] 
    
cf['Correlation'] = corr

print ('There are ', str(len(cf['Field1'])), ' field correlations > 95%.')
cf
# Out:
# There are  1494  field correlations > 95%.
#                       Field1  \
# 0          lea_no_attendance
# 1       school_no_attendance
# 2            indian_male_pct
# 3          indian_female_pct
# 4             asian_male_pct
# ...                      ...
# 1489  agency_lea_code_980LEA
# 1490  agency_lea_code_340LEA
# 1491  agency_lea_code_990LEA
# 1492  agency_lea_code_995LEA
# 1493  agency_lea_code_870LEA
#
#                                                  Field2  Correlation
# 0                                                   lea     1.000000
# 1                                                school     1.000000
# 2                                            indian_pct     0.988499
# 3                                            indian_pct     0.988881
# 4                                             asian_pct     0.962782
# ...                                                 ...          ...
# 1489          lea_name_attendance_Wilson County Schools     1.000000
# 1490  lea_name_attendance_Winston Salem/Forsyth Coun...     1.000000
# 1491          lea_name_attendance_Yadkin County Schools     1.000000
# 1492          lea_name_attendance_Yancey County Schools     1.000000
# 1493                      subgroup_list_ALL,AM7,EDS,WH7     1.000000
#
# [1494 rows x 3 columns]

# %%
#The old way
#print('Dropping the following ', str(len(to_drop)), ' highly correlated fields.')
#to_drop

# Comparing highly correlated unique field names in field 1 vs field 2 list above will allow you to 
# remove the least amount of fields possible.  
#len(cf['Field1'].unique())
#len(cf['Field2'].unique())

print('Dropping the following ', str(len(cf['Field2'].unique())), ' highly correlated, unique fields.')
cf['Field2'].unique()
# Out:
# Dropping the following  611  highly correlated, unique fields.
# array(['lea', 'school', 'indian_pct', 'asian_pct', 'white_pct',
#        'indian_male_pct', 'ada_adm_ratio_2018.1_attendance',
#        'pct_ACALL_ALL_ACT', 'pct_ACALL_FEM_ACT', 'pct_ACALL_MALE_ACT',
#        'pct_ACCO_AIG_ACT', 'pct_ACCO_ALL_ACT', 'pct_ACCO_FEM_ACT',
#        'pct_ACCO_MALE_ACT', 'pct_ACCO_WH7_ACT', 'pct_ACEN_AIG_ACT',
#        'pct_ACEN_ALL_ACT', 'pct_ACEN_BL7_ACT', 'pct_ACEN_FEM_ACT',
#        'pct_ACEN_MALE_ACT', 'pct_ACEN_WH7_ACT', 'pct_ACMA_AIG_ACT',
#        'pct_ACMA_ALL_ACT', 'pct_ACMA_WH7_ACT', 'pct_ACRD_AIG_ACT',
#        'pct_ACRD_WH7_ACT', 'pct_ACWR_ALL_ACT', 'pct_AIG_AWA',
#        'pct_STD_ALL_CGR', 'pct_ALL_ELP', 'pct_Biology_ALL_PART_DET',
#        'pct_Biology_BL7_PART_DET', 'pct_Biology_EDS_PART_DET',
#        'pct_Biology_WH7_PART_DET', 'pct_High School Math_ALL_PART_DET',
#        'pct_High School Math_BL7_PART_DET',
#        'pct_High School Math_EDS_PART_DET',
#        'pct_High School Math_WH7_PART_DET', 'pct_CCR_BI_EOC_AIG_PC',
#        'pct_CCR_BI_EOC_ALL_PC', 'pct_CCR_BI_EOC_BL7_PC',
#        'pct_CCR_BI_EOC_EDS_PC', 'pct_CCR_BI_EOC_FEM_PC',
#        'pct_CCR_BI_EOC_HI7_PC', 'pct_CCR_BI_EOC_MALE_PC',
#        'pct_CCR_BI_EOC_WH7_PC', 'pct_CCR_E2_EOC_AIG_PC',
#        'pct_CCR_E2_EOC_ALL_PC', 'pct_CCR_E2_EOC_BL7_PC',
#        'pct_CCR_E2_EOC_EDS_PC', 'pct_CCR_E2_EOC_FEM_PC',
#        'pct_CCR_E2_EOC_HI7_PC', 'pct_CCR_E2_EOC_MALE_PC',
#        'pct_CCR_E2_EOC_WH7_PC', 'pct_CCR_EOC_EOC_AIG_PC',
#        'pct_CCR_EOC_EOC_ALL_PC', 'pct_CCR_EOC_EOC_BL7_PC',
#        'pct_CCR_EOC_EOC_EDS_PC', 'pct_CCR_EOC_EOC_ELS_PC',
#        'pct_CCR_EOC_EOC_FEM_PC', 'pct_CCR_EOC_EOC_HI7_PC',
#        'pct_CCR_EOC_EOC_MALE_PC', 'pct_CCR_EOC_EOC_MU7_PC',
#        'pct_CCR_EOC_EOC_SWD_PC', 'pct_CCR_EOC_EOC_WH7_PC',
#        'pct_CCR_M1_EOC_AIG_PC', 'pct_CCR_M1_EOC_ALL_PC',
#        'pct_CCR_M1_EOC_BL7_PC', 'pct_CCR_M1_EOC_EDS_PC',
#        'pct_CCR_M1_EOC_FEM_PC', 'pct_CCR_M1_EOC_HI7_PC',
#        'pct_CCR_M1_EOC_MALE_PC', 'pct_CCR_M1_EOC_WH7_PC',
#        'pct_GLP_BI_EOC_HI7_PC', 'pct_GLP_E2_EOC_AIG_PC',
#        'pct_GLP_E2_EOC_ALL_PC', 'pct_GLP_E2_EOC_BL7_PC',
#        'pct_GLP_E2_EOC_EDS_PC', 'pct_GLP_E2_EOC_FEM_PC',
#        'pct_GLP_E2_EOC_HI7_PC', 'pct_GLP_E2_EOC_MALE_PC',
#        'pct_GLP_E2_EOC_WH7_PC', 'pct_GLP_EOC_EOC_ALL_PC',
#        'pct_GLP_EOC_EOC_BL7_PC', 'pct_GLP_EOC_EOC_EDS_PC',
#        'pct_GLP_EOC_EOC_ELS_PC', 'pct_GLP_EOC_EOC_FEM_PC',
#        'pct_GLP_EOC_EOC_HI7_PC', 'pct_GLP_EOC_EOC_MALE_PC',
#        'pct_GLP_EOC_EOC_MU7_PC', 'pct_GLP_EOC_EOC_WH7_PC',
#        'pct_GLP_M1_EOC_ALL_PC', 'pct_GLP_M1_EOC_BL7_PC',
#        'pct_GLP_M1_EOC_EDS_PC', 'pct_GLP_M1_EOC_FEM_PC',
#        'pct_GLP_M1_EOC_HI7_PC', 'pct_L1_ALL_ALL_ALL_PC',
#        'pct_L1_ALL_ALL_EDS_PC', 'pct_L3_ALL_ALL_MU7_PC',
#        'pct_L4_ALL_ALL_AIG_PC', 'pct_L4_ALL_ALL_ALL_PC',
#        'pct_L4_ALL_ALL_BL7_PC', 'pct_L4_ALL_ALL_EDS_PC',
#        'pct_L4_ALL_ALL_FEM_PC', 'pct_L4_ALL_ALL_HI7_PC',
#        'pct_L4_ALL_ALL_MALE_PC', 'pct_L4_ALL_ALL_MU7_PC',
#        'pct_L4_ALL_ALL_WH7_PC', 'pct_L4_EOC_EOC_ALL_PC',
#        'pct_L4_M1_EOC_ALL_PC', 'pct_L5_ALL_ALL_AIG_PC',
#        'pct_L5_ALL_ALL_ALL_PC', 'pct_L5_ALL_ALL_FEM_PC',
#        'pct_L5_ALL_ALL_MALE_PC', 'pct_L5_ALL_ALL_WH7_PC',
#        'pct_L5_EOC_EOC_ALL_PC', 'pct_L5_M1_EOC_ALL_PC',
#        'aaa_score_HI7_SPG2', 'ach_score_ALL_SPG2', 'ach_score_BL7_SPG2',
#        'ach_score_EDS_SPG2', 'ach_score_HI7_SPG2', 'ach_score_SWD_SPG2',
#        'ach_score_WH7_SPG2', 'awa_score_WH7_SPG2', 'avg_student_num',
#        'pct_ALL_CHRON_ABSENT', 'tot_num_ap_H_AM7_COURSES2',
#        'tot_num_ap_H_AS7_COURSES2', 'tot_num_ap_H_BL7_COURSES2',
#        'tot_num_ap_H_ELS_COURSES2', 'tot_num_ap_H_FEM_COURSES2',
#        'tot_num_ap_H_HI7_COURSES2', 'tot_num_ap_H_MALE_COURSES2',
#        'tot_num_ap_H_MU7_COURSES2', 'tot_num_ap_H_Other_COURSES2',
#        'tot_num_ap_H_PI7_COURSES2', 'tot_num_ap_H_SWD_COURSES2',
#        'tot_num_ccp_H_AM7_COURSES2', 'tot_num_ccp_H_AS7_COURSES2',
#        'tot_num_ccp_H_BL7_COURSES2', 'tot_num_ccp_H_ELS_COURSES2',
#        'tot_num_ccp_H_FEM_COURSES2', 'tot_num_ccp_H_HI7_COURSES2',
#        'tot_num_ccp_H_MALE_COURSES2', 'tot_num_ccp_H_MU7_COURSES2',
#        'tot_num_ccp_H_Other_COURSES2', 'tot_num_ccp_H_PI7_COURSES2',
#        'tot_num_ccp_H_SWD_COURSES2', 'tot_num_ccp_H_WH7_COURSES2',
#        'year_H_AM7_COURSES2', 'year_H_AS7_COURSES2',
#        'year_H_BL7_COURSES2', 'year_H_ELS_COURSES2',
#        'year_H_FEM_COURSES2', 'year_H_HI7_COURSES2',
#        'year_H_MALE_COURSES2', 'year_H_MU7_COURSES2',
#        'year_H_Other_COURSES2', 'year_H_PI7_COURSES2',
#        'year_H_SWD_COURSES2', 'year_H_WH7_COURSES2', 'num_enrollments',
#        'stu_enroll', 'cte_enroll', 'arre_per1000_ALL', 'arre_per1000_BL7',
#        'blhr_per1000_ALL', 'crime_per1000_ELS', 'exp_per1000_ALL',
#        'exp_per1000_BL7', 'iss_per1000_ALL', 'lea_code_020LEA',
#        'lea_code_030LEA', 'lea_code_040LEA', 'lea_code_050LEA',
#        'lea_code_060LEA', 'lea_code_070LEA', 'lea_code_080LEA',
#        'lea_code_090LEA', 'lea_code_100LEA', 'lea_code_110LEA',
#        'lea_code_111LEA', 'lea_code_120LEA', 'lea_code_130LEA',
#        'lea_code_132LEA', 'lea_code_140LEA', 'lea_code_150LEA',
#        'lea_code_160LEA', 'lea_code_170LEA', 'lea_code_180LEA',
#        'lea_code_181LEA', 'lea_code_182LEA', 'lea_code_190LEA',
#        'lea_code_200LEA', 'lea_code_210LEA', 'lea_code_220LEA',
#        'lea_code_230LEA', 'lea_code_240LEA', 'lea_code_241LEA',
#        'lea_code_250LEA', 'lea_code_260LEA', 'lea_code_270LEA',
#        'lea_code_280LEA', 'lea_code_290LEA', 'lea_code_291LEA',
#        'lea_code_292LEA', 'lea_code_300LEA', 'lea_code_310LEA',
#        'lea_code_320LEA', 'lea_code_330LEA', 'lea_code_340LEA',
#        'lea_code_350LEA', 'lea_code_360LEA', 'lea_code_370LEA',
#        'lea_code_380LEA', 'lea_code_390LEA', 'lea_code_400LEA',
#        'lea_code_410LEA', 'lea_code_420LEA', 'lea_code_421LEA',
#        'lea_code_422LEA', 'lea_code_430LEA', 'lea_code_440LEA',
#        'lea_code_450LEA', 'lea_code_460LEA', 'lea_code_470LEA',
#        'lea_code_480LEA', 'lea_code_490LEA', 'lea_code_491LEA',
#        'lea_code_500LEA', 'lea_code_510LEA', 'lea_code_520LEA',
#        'lea_code_530LEA', 'lea_code_540LEA', 'lea_code_550LEA',
#        'lea_code_560LEA', 'lea_code_570LEA', 'lea_code_580LEA',
#        'lea_code_590LEA', 'lea_code_600LEA', 'lea_code_610LEA',
#        'lea_code_620LEA', 'lea_code_630LEA', 'lea_code_640LEA',
#        'lea_code_650LEA', 'lea_code_660LEA', 'lea_code_670LEA',
#        'lea_code_680LEA', 'lea_code_681LEA', 'lea_code_690LEA',
#        'lea_code_700LEA', 'lea_code_710LEA', 'lea_code_720LEA',
#        'lea_code_730LEA', 'lea_code_740LEA', 'lea_code_750LEA',
#        'lea_code_760LEA', 'lea_code_761LEA', 'lea_code_770LEA',
#        'lea_code_780LEA', 'lea_code_790LEA', 'lea_code_800LEA',
#        'lea_code_810LEA', 'lea_code_820LEA', 'lea_code_821LEA',
#        'lea_code_830LEA', 'lea_code_840LEA', 'lea_code_850LEA',
#        'lea_code_860LEA', 'lea_code_861LEA', 'lea_code_862LEA',
#        'lea_code_870LEA', 'lea_code_880LEA', 'lea_code_890LEA',
#        'lea_code_900LEA', 'lea_code_910LEA', 'lea_code_920LEA',
#        'lea_code_930LEA', 'lea_code_940LEA', 'lea_code_950LEA',
#        'lea_code_960LEA', 'lea_code_970LEA', 'lea_code_980LEA',
#        'lea_code_990LEA', 'lea_code_995LEA', 'county_Alexander',
#        'county_Alleghany', 'county_Anson', 'county_Ashe', 'county_Avery',
#        'county_Beaufort', 'county_Bertie', 'county_Bladen',
#        'county_Brunswick', 'county_Burke', 'county_Cabarrus',
#        'county_Caldwell', 'county_Camden', 'county_Carteret',
#        'county_Caswell', 'county_Chatham', 'county_Cherokee',
#        'county_Chowan', 'county_Clay', 'county_Cleveland',
#        'county_Craven', 'county_Cumberland', 'county_Currituck',
#        'county_Dare', 'county_Davie', 'county_Duplin', 'county_Durham',
#        'county_Edgecombe', 'county_Forsyth', 'county_Franklin',
#        'county_Gaston', 'county_Gates', 'county_Graham',
#        'county_Granville', 'county_Greene', 'county_Guilford',
#        'county_Harnett', 'county_Haywood', 'county_Henderson',
#        'county_Hertford', 'county_Hoke', 'county_Hyde', 'county_Iredell',
#        'county_Jackson', 'county_Johnston', 'county_Jones', 'county_Lee',
#        'county_Lenoir', 'county_Lincoln', 'county_Macon',
#        'county_Madison', 'county_Martin', 'county_McDowell',
#        'county_Mecklenburg', 'county_Mitchell', 'county_Montgomery',
#        'county_Moore', 'county_Nash', 'county_New Hanover',
#        'county_Northampton', 'county_Onslow', 'county_Pamlico',
#        'county_Pasquotank', 'county_Pender', 'county_Perquimans',
#        'county_Person', 'county_Pitt', 'county_Polk', 'county_Richmond',
#        'county_Robeson', 'county_Rockingham', 'county_Rowan',
#        'county_Rutherford', 'county_Scotland', 'county_Stanly',
#        'county_Stokes', 'county_Swain', 'county_Transylvania',
#        'county_Tyrrell', 'county_Union', 'county_Vance', 'county_Wake',
#        'county_Warren', 'county_Washington', 'county_Watauga',
#        'county_Wayne', 'county_Wilkes', 'county_Wilson', 'county_Yadkin',
#        'county_Yancey', 'grade_span_06:10', 'grade_span_06:13',
#        'grade_span_07:10', 'grade_span_07:13', 'grade_span_10:12',
#        'grade_span_KG:13', 'lea_name_Alexander County Schools',
#        'lea_name_Alleghany County Schools',
#        'lea_name_Anson County Schools', 'lea_name_Ashe County Schools',
#        'lea_name_Asheboro City Schools',
#        'lea_name_Asheville City Schools', 'lea_name_Avery County Schools',
#        'lea_name_Beaufort County Schools',
#        'lea_name_Bertie County Schools', 'lea_name_Bladen County Schools',
#        'lea_name_Brunswick County Schools',
#        'lea_name_Buncombe County Schools',
#        'lea_name_Burke County Schools',
#        'lea_name_Cabarrus County Schools',
#        'lea_name_Caldwell County Schools',
#        'lea_name_Camden County Schools',
#        'lea_name_Carteret County Schools',
#        'lea_name_Caswell County Schools',
#        'lea_name_Catawba County Schools',
#        'lea_name_Chapel-Hill/Carrboro City Schools',
#        'lea_name_Charlotte-Mecklenburg County Schools',
#        'lea_name_Chatham County Schools',
#        'lea_name_Cherokee County Schools', 'lea_name_Clay County Schools',
#        'lea_name_Cleveland County Schools',
#        'lea_name_Clinton City Schools',
#        'lea_name_Columbus County Schools',
#        'lea_name_Craven County Schools',
#        'lea_name_Cumberland County Schools',
#        'lea_name_Currituck County Schools',
#        'lea_name_Dare County Schools', 'lea_name_Davidson County Schools',
#        'lea_name_Davie County Schools', 'lea_name_Duplin County Schools',
#        'lea_name_Durham County Schools',
#        'lea_name_Edenton-Chowan County Schools',
#        'lea_name_Edgecombe County Schools', 'lea_name_Elkin City Schools',
#        'lea_name_Forsyth County Schools',
#        'lea_name_Franklin County Schools',
#        'lea_name_Gaston County Schools', 'lea_name_Gates County Schools',
#        'lea_name_Graham County Schools',
#        'lea_name_Granville County Schools',
#        'lea_name_Greene County Schools',
#        'lea_name_Guilford County Schools',
#        'lea_name_Halifax County Schools',
#        'lea_name_Harnett County Schools',
#        'lea_name_Haywood County Schools',
#        'lea_name_Henderson County Schools',
#        'lea_name_Hertford County Schools',
#        'lea_name_Hickory City Schools', 'lea_name_Hoke County Schools',
#        'lea_name_Hyde County Schools',
#        'lea_name_Iredell-Statesville Schools',
#        'lea_name_Jackson County Schools',
#        'lea_name_Johnston County Schools',
#        'lea_name_Jones County Schools',
#        'lea_name_Kannapolis City Schools', 'lea_name_Lee County Schools',
#        'lea_name_Lenoir County Schools',
#        'lea_name_Lexington City Schools',
#        'lea_name_Lincoln County Schools', 'lea_name_Macon County Schools',
#        'lea_name_Madison County Schools',
#        'lea_name_Martin County Schools',
#        'lea_name_McDowell County Schools',
#        'lea_name_Mitchell County Schools',
#        'lea_name_Montgomery County Schools',
#        'lea_name_Moore County Schools',
#        'lea_name_Mooresville City Schools',
#        'lea_name_Mount Airy City Schools',
#        'lea_name_Nash-Rocky Mount Schools',
#        'lea_name_New Hanover County Schools',
#        'lea_name_Newton-Conover City Schools',
#        'lea_name_Northampton County Schools',
#        'lea_name_Onslow County Schools', 'lea_name_Orange County Schools',
#        'lea_name_Pamlico County Schools',
#        'lea_name_Pasquotank County Schools',
#        'lea_name_Pender County Schools',
#        'lea_name_Perquimans County Schools',
#        'lea_name_Person County Schools', 'lea_name_Pitt County Schools',
#        'lea_name_Polk County Schools', 'lea_name_Randolph County Schools',
#        'lea_name_Richmond County Schools',
#        'lea_name_Roanoke Rapids City Schools',
#        'lea_name_Robeson County Schools',
#        'lea_name_Rockingham County Schools',
#        'lea_name_Rowan-Salisbury County Schools',
#        'lea_name_Rutherford County Schools',
#        'lea_name_Sampson County Schools',
#        'lea_name_Scotland County Schools',
#        'lea_name_Stanly County Schools', 'lea_name_Stokes County Schools',
#        'lea_name_Surry County Schools', 'lea_name_Swain County Schools',
#        'lea_name_Thomasville City Schools',
#        'lea_name_Transylvania County Schools',
#        'lea_name_Tyrrell County Schools', 'lea_name_Union County Schools',
#        'lea_name_Vance County Schools', 'lea_name_Wake County Schools',
#        'lea_name_Warren County Schools',
#        'lea_name_Washington County Schools',
#        'lea_name_Watauga County Schools', 'lea_name_Wayne County Schools',
#        'lea_name_Weldon City Schools', 'lea_name_Whiteville City Schools',
#        'lea_name_Wilkes County Schools', 'lea_name_Wilson County Schools',
#        'lea_name_Yadkin County Schools', 'lea_name_Yancey County Schools',
#        'lea_name_attendance_Alexander County Schools',
#        'lea_name_attendance_Alleghany County Schools',
#        'lea_name_attendance_Anson County Schools',
#        'lea_name_attendance_Ashe County Schools',
#        'lea_name_attendance_Asheboro City Schools',
#        'lea_name_attendance_Asheville City Schools',
#        'lea_name_attendance_Avery County Schools',
#        'lea_name_attendance_Beaufort County Schools',
#        'lea_name_attendance_Bertie County Schools',
#        'lea_name_attendance_Bladen County Schools',
#        'lea_name_attendance_Brunswick County Schools',
#        'lea_name_attendance_Buncombe County Schools',
#        'lea_name_attendance_Burke County Schools',
#        'lea_name_attendance_Cabarrus County Schools',
#        'lea_name_attendance_Caldwell County Schools',
#        'lea_name_attendance_Camden County Schools',
#        'lea_name_attendance_Carteret County Public Schools',
#        'lea_name_attendance_Caswell County Schools',
#        'lea_name_attendance_Catawba County Schools',
#        'lea_name_attendance_Chapel Hill-Carrboro City Schools',
#        'lea_name_attendance_Charlotte-Mecklenburg Schools',
#        'lea_name_attendance_Chatham County Schools',
#        'lea_name_attendance_Cherokee County Schools',
#        'lea_name_attendance_Clay County Schools',
#        'lea_name_attendance_Cleveland County Schools',
#        'lea_name_attendance_Clinton City Schools',
#        'lea_name_attendance_Columbus County Schools',
#        'lea_name_attendance_Craven County Schools',
#        'lea_name_attendance_Cumberland County Schools',
#        'lea_name_attendance_Currituck County Schools',
#        'lea_name_attendance_Dare County Schools',
#        'lea_name_attendance_Davidson County Schools',
#        'lea_name_attendance_Davie County Schools',
#        'lea_name_attendance_Duplin County Schools',
#        'lea_name_attendance_Durham Public Schools',
#        'lea_name_attendance_Edenton-Chowan Schools',
#        'lea_name_attendance_Edgecombe County Public Schools',
#        'lea_name_attendance_Elizabeth City-Pasquotank Public Schools',
#        'lea_name_attendance_Elkin City Schools',
#        'lea_name_attendance_Franklin County Schools',
#        'lea_name_attendance_Gaston County Schools',
#        'lea_name_attendance_Gates County Schools',
#        'lea_name_attendance_Graham County Schools',
#        'lea_name_attendance_Granville County Schools',
#        'lea_name_attendance_Greene County Schools',
#        'lea_name_attendance_Guilford County Schools',
#        'lea_name_attendance_Halifax County Schools',
#        'lea_name_attendance_Harnett County Schools',
#        'lea_name_attendance_Haywood County Schools',
#        'lea_name_attendance_Henderson County Schools',
#        'lea_name_attendance_Hertford County Schools',
#        'lea_name_attendance_Hickory City Schools',
#        'lea_name_attendance_Hoke County Schools',
#        'lea_name_attendance_Hyde County Schools',
#        'lea_name_attendance_Iredell-Statesville Schools',
#        'lea_name_attendance_Jackson County Public Schools',
#        'lea_name_attendance_Johnston County Schools',
#        'lea_name_attendance_Jones County Schools',
#        'lea_name_attendance_Kannapolis City Schools',
#        'lea_name_attendance_Lee County Schools',
#        'lea_name_attendance_Lenoir County Public Schools',
#        'lea_name_attendance_Lexington City Schools',
#        'lea_name_attendance_Lincoln County Schools',
#        'lea_name_attendance_Macon County Schools',
#        'lea_name_attendance_Madison County Schools',
#        'lea_name_attendance_Martin County Schools',
#        'lea_name_attendance_McDowell County Schools',
#        'lea_name_attendance_Mitchell County Schools',
#        'lea_name_attendance_Montgomery County Schools',
#        'lea_name_attendance_Moore County Schools',
#        'lea_name_attendance_Mooresville Graded School District',
#        'lea_name_attendance_Mount Airy City Schools',
#        'lea_name_attendance_Nash-Rocky Mount Schools',
#        'lea_name_attendance_New Hanover County Schools',
#        'lea_name_attendance_Newton Conover City Schools',
#        'lea_name_attendance_Northampton County Schools',
#        'lea_name_attendance_Onslow County Schools',
#        'lea_name_attendance_Orange County Schools',
#        'lea_name_attendance_Pamlico County Schools',
#        'lea_name_attendance_Pender County Schools',
#        'lea_name_attendance_Perquimans County Schools',
#        'lea_name_attendance_Person County Schools',
#        'lea_name_attendance_Pitt County Schools',
#        'lea_name_attendance_Polk County Schools',
#        'lea_name_attendance_Public Schools of Robeson County',
#        'lea_name_attendance_Randolph County School System',
#        'lea_name_attendance_Richmond County Schools',
#        'lea_name_attendance_Roanoke Rapids City Schools',
#        'lea_name_attendance_Rockingham County Schools',
#        'lea_name_attendance_Rowan-Salisbury Schools',
#        'lea_name_attendance_Rutherford County Schools',
#        'lea_name_attendance_Sampson County Schools',
#        'lea_name_attendance_Scotland County Schools',
#        'lea_name_attendance_Stanly County Schools',
#        'lea_name_attendance_Stokes County Schools',
#        'lea_name_attendance_Surry County Schools',
#        'lea_name_attendance_Swain County Schools',
#        'lea_name_attendance_Thomasville City Schools',
#        'lea_name_attendance_Transylvania County Schools',
#        'lea_name_attendance_Tyrrell County Schools',
#        'lea_name_attendance_Union County Public Schools',
#        'lea_name_attendance_Vance County Schools',
#        'lea_name_attendance_Wake County Schools',
#        'lea_name_attendance_Warren County Schools',
#        'lea_name_attendance_Washington County Schools',
#        'lea_name_attendance_Watauga County Schools',
#        'lea_name_attendance_Wayne County Public Schools',
#        'lea_name_attendance_Weldon City Schools',
#        'lea_name_attendance_Whiteville City Schools',
#        'lea_name_attendance_Wilkes County Schools',
#        'lea_name_attendance_Wilson County Schools',
#        'lea_name_attendance_Winston Salem/Forsyth County Schools',
#        'lea_name_attendance_Yadkin County Schools',
#        'lea_name_attendance_Yancey County Schools',
#        'subgroup_list_ALL,AM7,EDS,WH7'], dtype=object)

# %%
#Check columns before drop 
print('\r\n*********Before: Dropping Highly Correlated Fields*************************************')
schoolData.info(verbose=False)

# Drop the highly correlated features from our training data 
#schoolData = schoolData.drop(to_drop, axis=1)
schoolData = schoolData.drop(cf['Field2'], axis=1)

#Check columns after drop 
print('\r\n*********After: Dropping Highly Correlated Fields**************************************')
schoolData.info(verbose=False)
# Out:
# *********Before: Dropping Highly Correlated Fields*************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 603 entries, 2 to 678
# Columns: 1417 entries, lea to agency_lea_code_995LEA
# dtypes: float64(715), uint8(702)
# memory usage: 3.7 MB
#
# *********After: Dropping Highly Correlated Fields**************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 603 entries, 2 to 678
# Columns: 806 entries, hispanic_pct to agency_lea_code_995LEA
# dtypes: float64(543), uint8(263)
# memory usage: 2.7 MB

# %%
#Restore the unit_code before saving
schoolData['agency_code'] = agency_code
#Save the final dataset to a .csv file
schoolData.to_csv(outputDir + inputFileName + '_ML.csv', sep=',', index=False)

# %%
print('*********FINAL DATASET DETAILS*********************************************************\r\n')
schoolData.info(verbose=True)
# Out:
# *********FINAL DATASET DETAILS*********************************************************
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 603 entries, 2 to 678
# Data columns (total 807 columns):
#  #   Column                                                                                                            Dtype
# ---  ------                                                                                                            -----
#  0   hispanic_pct                                                                                                      float64
#  1   black_pct                                                                                                         float64
#  2   pacific_island_pct                                                                                                float64
#  3   two_or_more_pct                                                                                                   float64
#  4   minority_pct                                                                                                      float64
#  5   asian_male_pct                                                                                                    float64
#  6   hispanic_male_pct                                                                                                 float64
#  7   black_male_pct                                                                                                    float64
#  8   white_male_pct                                                                                                    float64
#  9   pacific_island_male_pct                                                                                           float64
#  10  two_or_more_male_pct                                                                                              float64
#  11  minority_male_pct                                                                                                 float64
#  12  indian_female_pct                                                                                                 float64
#  13  asian_female_pct                                                                                                  float64
#  14  hispanic_female_pct                                                                                               float64
#  15  black_female_pct                                                                                                  float64
#  16  white_female_pct                                                                                                  float64
#  17  minority_female_pct                                                                                               float64
#  18  pacific_island_female_pct                                                                                         float64
#  19  two_or_more_female_pct                                                                                            float64
#  20  lea_no_attendance                                                                                                 float64
#  21  school_no_attendance                                                                                              float64
#  22  ada_adm_ratio_2018_attendance                                                                                     float64
#  23  ada_adm_ratio_2019_attendance                                                                                     float64
#  24  ada_adm_ratio_2017_thru_2019_attendance                                                                           float64
#  25  ada_adm_rank_2017_thru_2019_attendance                                                                            float64
#  26  pct_ACALL_AIG_ACT                                                                                                 float64
#  27  pct_ACALL_AS7_ACT                                                                                                 float64
#  28  pct_ACALL_BL7_ACT                                                                                                 float64
#  29  pct_ACALL_EDS_ACT                                                                                                 float64
#  30  pct_ACALL_ELS_ACT                                                                                                 float64
#  31  pct_ACALL_HI7_ACT                                                                                                 float64
#  32  pct_ACALL_MU7_ACT                                                                                                 float64
#  33  pct_ACALL_SWD_ACT                                                                                                 float64
#  34  pct_ACALL_WH7_ACT                                                                                                 float64
#  35  pct_ACCO_BL7_ACT                                                                                                  float64
#  36  pct_ACCO_EDS_ACT                                                                                                  float64
#  37  pct_ACCO_HI7_ACT                                                                                                  float64
#  38  pct_ACCO_SWD_ACT                                                                                                  float64
#  39  pct_ACEN_EDS_ACT                                                                                                  float64
#  40  pct_ACEN_HI7_ACT                                                                                                  float64
#  41  pct_ACEN_SWD_ACT                                                                                                  float64
#  42  pct_ACMA_BL7_ACT                                                                                                  float64
#  43  pct_ACMA_EDS_ACT                                                                                                  float64
#  44  pct_ACMA_FEM_ACT                                                                                                  float64
#  45  pct_ACMA_HI7_ACT                                                                                                  float64
#  46  pct_ACMA_MALE_ACT                                                                                                 float64
#  47  pct_ACMA_SWD_ACT                                                                                                  float64
#  48  pct_ACRD_ALL_ACT                                                                                                  float64
#  49  pct_ACRD_BL7_ACT                                                                                                  float64
#  50  pct_ACRD_EDS_ACT                                                                                                  float64
#  51  pct_ACRD_FEM_ACT                                                                                                  float64
#  52  pct_ACRD_HI7_ACT                                                                                                  float64
#  53  pct_ACRD_MALE_ACT                                                                                                 float64
#  54  pct_ACRD_SWD_ACT                                                                                                  float64
#  55  pct_ACSC_AIG_ACT                                                                                                  float64
#  56  pct_ACSC_ALL_ACT                                                                                                  float64
#  57  pct_ACSC_BL7_ACT                                                                                                  float64
#  58  pct_ACSC_EDS_ACT                                                                                                  float64
#  59  pct_ACSC_FEM_ACT                                                                                                  float64
#  60  pct_ACSC_HI7_ACT                                                                                                  float64
#  61  pct_ACSC_MALE_ACT                                                                                                 float64
#  62  pct_ACSC_SWD_ACT                                                                                                  float64
#  63  pct_ACSC_WH7_ACT                                                                                                  float64
#  64  pct_ACWR_AIG_ACT                                                                                                  float64
#  65  pct_ACWR_BL7_ACT                                                                                                  float64
#  66  pct_ACWR_EDS_ACT                                                                                                  float64
#  67  pct_ACWR_FEM_ACT                                                                                                  float64
#  68  pct_ACWR_HI7_ACT                                                                                                  float64
#  69  pct_ACWR_MALE_ACT                                                                                                 float64
#  70  pct_ACWR_SWD_ACT                                                                                                  float64
#  71  pct_ACWR_WH7_ACT                                                                                                  float64
#  72  pct_ALL_AWA                                                                                                       float64
#  73  pct_BL7_AWA                                                                                                       float64
#  74  pct_EDS_AWA                                                                                                       float64
#  75  pct_FEM_AWA                                                                                                       float64
#  76  pct_HI7_AWA                                                                                                       float64
#  77  pct_MALE_AWA                                                                                                      float64
#  78  pct_SWD_AWA                                                                                                       float64
#  79  pct_WH7_AWA                                                                                                       float64
#  80  pct_EXT_AIG_CGR                                                                                                   float64
#  81  pct_EXT_ALL_CGR                                                                                                   float64
#  82  pct_EXT_BL7_CGR                                                                                                   float64
#  83  pct_EXT_EDS_CGR                                                                                                   float64
#  84  pct_EXT_FEM_CGR                                                                                                   float64
#  85  pct_EXT_HI7_CGR                                                                                                   float64
#  86  pct_EXT_MALE_CGR                                                                                                  float64
#  87  pct_EXT_SWD_CGR                                                                                                   float64
#  88  pct_EXT_WH7_CGR                                                                                                   float64
#  89  pct_STD_AIG_CGR                                                                                                   float64
#  90  pct_STD_BL7_CGR                                                                                                   float64
#  91  pct_STD_EDS_CGR                                                                                                   float64
#  92  pct_STD_FEM_CGR                                                                                                   float64
#  93  pct_STD_HI7_CGR                                                                                                   float64
#  94  pct_STD_MALE_CGR                                                                                                  float64
#  95  pct_STD_SWD_CGR                                                                                                   float64
#  96  pct_STD_WH7_CGR                                                                                                   float64
#  97  pct_eds                                                                                                           float64
#  98  pct_EDS_ELP                                                                                                       float64
#  99  pct_ELS_ELP                                                                                                       float64
#  100 pct_HI7_ELP                                                                                                       float64
#  101 pct_MALE_ELP                                                                                                      float64
#  102 pct_prof_9gr_irm                                                                                                  float64
#  103 pct_met_4 Year Graduation Rate_LTG                                                                                float64
#  104 pct_met_Math Grade 11_LTG                                                                                         float64
#  105 pct_met_Reading Grade 10_LTG                                                                                      float64
#  106 pct_met_Total Targets_LTG                                                                                         float64
#  107 pct_AIG_MCR                                                                                                       float64
#  108 pct_ALL_MCR                                                                                                       float64
#  109 pct_BL7_MCR                                                                                                       float64
#  110 pct_EDS_MCR                                                                                                       float64
#  111 pct_FEM_MCR                                                                                                       float64
#  112 pct_HI7_MCR                                                                                                       float64
#  113 pct_MALE_MCR                                                                                                      float64
#  114 pct_SWD_MCR                                                                                                       float64
#  115 pct_WH7_MCR                                                                                                       float64
#  116 pct_met_ACT WorkKeys_PART                                                                                         float64
#  117 pct_met_Biology_PART                                                                                              float64
#  118 pct_met_English II_PART                                                                                           float64
#  119 pct_met_High School Math_PART                                                                                     float64
#  120 pct_met_The ACT_PART                                                                                              float64
#  121 pct_met_Total Targets_PART                                                                                        float64
#  122 pct_ACT WorkKeys_ALL_PART_DET                                                                                     float64
#  123 pct_ACT WorkKeys_WH7_PART_DET                                                                                     float64
#  124 pct_English II_ALL_PART_DET                                                                                       float64
#  125 pct_English II_BL7_PART_DET                                                                                       float64
#  126 pct_English II_EDS_PART_DET                                                                                       float64
#  127 pct_English II_WH7_PART_DET                                                                                       float64
#  128 pct_The ACT_ALL_PART_DET                                                                                          float64
#  129 pct_The ACT_BL7_PART_DET                                                                                          float64
#  130 pct_The ACT_EDS_PART_DET                                                                                          float64
#  131 pct_The ACT_WH7_PART_DET                                                                                          float64
#  132 pct_CCR_BI_EOC_SWD_PC                                                                                             float64
#  133 pct_CCR_E2_EOC_SWD_PC                                                                                             float64
#  134 pct_CCR_M1_EOC_SWD_PC                                                                                             float64
#  135 pct_GLP_BI_EOC_AIG_PC                                                                                             float64
#  136 pct_GLP_BI_EOC_ALL_PC                                                                                             float64
#  137 pct_GLP_BI_EOC_BL7_PC                                                                                             float64
#  138 pct_GLP_BI_EOC_EDS_PC                                                                                             float64
#  139 pct_GLP_BI_EOC_FEM_PC                                                                                             float64
#  140 pct_GLP_BI_EOC_MALE_PC                                                                                            float64
#  141 pct_GLP_BI_EOC_SWD_PC                                                                                             float64
#  142 pct_GLP_BI_EOC_WH7_PC                                                                                             float64
#  143 pct_GLP_E2_EOC_SWD_PC                                                                                             float64
#  144 pct_GLP_EOC_EOC_AIG_PC                                                                                            float64
#  145 pct_GLP_EOC_EOC_SWD_PC                                                                                            float64
#  146 pct_GLP_M1_EOC_AIG_PC                                                                                             float64
#  147 pct_GLP_M1_EOC_MALE_PC                                                                                            float64
#  148 pct_GLP_M1_EOC_SWD_PC                                                                                             float64
#  149 pct_GLP_M1_EOC_WH7_PC                                                                                             float64
#  150 pct_L1_ALL_ALL_BL7_PC                                                                                             float64
#  151 pct_L1_ALL_ALL_ELS_PC                                                                                             float64
#  152 pct_L1_ALL_ALL_FEM_PC                                                                                             float64
#  153 pct_L1_ALL_ALL_HI7_PC                                                                                             float64
#  154 pct_L1_ALL_ALL_MALE_PC                                                                                            float64
#  155 pct_L1_ALL_ALL_MU7_PC                                                                                             float64
#  156 pct_L1_ALL_ALL_SWD_PC                                                                                             float64
#  157 pct_L1_ALL_ALL_WH7_PC                                                                                             float64
#  158 pct_L1_BI_EOC_ALL_PC                                                                                              float64
#  159 pct_L1_BI_EOC_BL7_PC                                                                                              float64
#  160 pct_L1_BI_EOC_EDS_PC                                                                                              float64
#  161 pct_L1_BI_EOC_FEM_PC                                                                                              float64
#  162 pct_L1_BI_EOC_HI7_PC                                                                                              float64
#  163 pct_L1_BI_EOC_MALE_PC                                                                                             float64
#  164 pct_L1_BI_EOC_SWD_PC                                                                                              float64
#  165 pct_L1_BI_EOC_WH7_PC                                                                                              float64
#  166 pct_L1_E2_EOC_ALL_PC                                                                                              float64
#  167 pct_L1_E2_EOC_BL7_PC                                                                                              float64
#  168 pct_L1_E2_EOC_EDS_PC                                                                                              float64
#  169 pct_L1_E2_EOC_FEM_PC                                                                                              float64
#  170 pct_L1_E2_EOC_HI7_PC                                                                                              float64
#  171 pct_L1_E2_EOC_MALE_PC                                                                                             float64
#  172 pct_L1_E2_EOC_SWD_PC                                                                                              float64
#  173 pct_L1_E2_EOC_WH7_PC                                                                                              float64
#  174 pct_L1_EOC_EOC_ALL_PC                                                                                             float64
#  175 pct_L1_EOC_EOC_BL7_PC                                                                                             float64
#  176 pct_L1_EOC_EOC_EDS_PC                                                                                             float64
#  177 pct_L1_EOC_EOC_ELS_PC                                                                                             float64
#  178 pct_L1_EOC_EOC_FEM_PC                                                                                             float64
#  179 pct_L1_EOC_EOC_HI7_PC                                                                                             float64
#  180 pct_L1_EOC_EOC_MALE_PC                                                                                            float64
#  181 pct_L1_EOC_EOC_MU7_PC                                                                                             float64
#  182 pct_L1_EOC_EOC_SWD_PC                                                                                             float64
#  183 pct_L1_EOC_EOC_WH7_PC                                                                                             float64
#  184 pct_L1_M1_EOC_ALL_PC                                                                                              float64
#  185 pct_L1_M1_EOC_BL7_PC                                                                                              float64
#  186 pct_L1_M1_EOC_EDS_PC                                                                                              float64
#  187 pct_L1_M1_EOC_FEM_PC                                                                                              float64
#  188 pct_L1_M1_EOC_HI7_PC                                                                                              float64
#  189 pct_L1_M1_EOC_MALE_PC                                                                                             float64
#  190 pct_L1_M1_EOC_SWD_PC                                                                                              float64
#  191 pct_L1_M1_EOC_WH7_PC                                                                                              float64
#  192 pct_L2_ALL_ALL_ALL_PC                                                                                             float64
#  193 pct_L2_ALL_ALL_BL7_PC                                                                                             float64
#  194 pct_L2_ALL_ALL_EDS_PC                                                                                             float64
#  195 pct_L2_ALL_ALL_ELS_PC                                                                                             float64
#  196 pct_L2_ALL_ALL_FEM_PC                                                                                             float64
#  197 pct_L2_ALL_ALL_HI7_PC                                                                                             float64
#  198 pct_L2_ALL_ALL_MALE_PC                                                                                            float64
#  199 pct_L2_ALL_ALL_MU7_PC                                                                                             float64
#  200 pct_L2_ALL_ALL_SWD_PC                                                                                             float64
#  201 pct_L2_ALL_ALL_WH7_PC                                                                                             float64
#  202 pct_L2_BI_EOC_ALL_PC                                                                                              float64
#  203 pct_L2_BI_EOC_BL7_PC                                                                                              float64
#  204 pct_L2_BI_EOC_EDS_PC                                                                                              float64
#  205 pct_L2_BI_EOC_FEM_PC                                                                                              float64
#  206 pct_L2_BI_EOC_HI7_PC                                                                                              float64
#  207 pct_L2_BI_EOC_MALE_PC                                                                                             float64
#  208 pct_L2_BI_EOC_SWD_PC                                                                                              float64
#  209 pct_L2_BI_EOC_WH7_PC                                                                                              float64
#  210 pct_L2_E2_EOC_ALL_PC                                                                                              float64
#  211 pct_L2_E2_EOC_BL7_PC                                                                                              float64
#  212 pct_L2_E2_EOC_EDS_PC                                                                                              float64
#  213 pct_L2_E2_EOC_FEM_PC                                                                                              float64
#  214 pct_L2_E2_EOC_HI7_PC                                                                                              float64
#  215 pct_L2_E2_EOC_MALE_PC                                                                                             float64
#  216 pct_L2_E2_EOC_SWD_PC                                                                                              float64
#  217 pct_L2_E2_EOC_WH7_PC                                                                                              float64
#  218 pct_L2_EOC_EOC_ALL_PC                                                                                             float64
#  219 pct_L2_EOC_EOC_BL7_PC                                                                                             float64
#  220 pct_L2_EOC_EOC_EDS_PC                                                                                             float64
#  221 pct_L2_EOC_EOC_ELS_PC                                                                                             float64
#  222 pct_L2_EOC_EOC_FEM_PC                                                                                             float64
#  223 pct_L2_EOC_EOC_HI7_PC                                                                                             float64
#  224 pct_L2_EOC_EOC_MALE_PC                                                                                            float64
#  225 pct_L2_EOC_EOC_MU7_PC                                                                                             float64
#  226 pct_L2_EOC_EOC_SWD_PC                                                                                             float64
#  227 pct_L2_EOC_EOC_WH7_PC                                                                                             float64
#  228 pct_L2_M1_EOC_ALL_PC                                                                                              float64
#  229 pct_L2_M1_EOC_BL7_PC                                                                                              float64
#  230 pct_L2_M1_EOC_EDS_PC                                                                                              float64
#  231 pct_L2_M1_EOC_FEM_PC                                                                                              float64
#  232 pct_L2_M1_EOC_HI7_PC                                                                                              float64
#  233 pct_L2_M1_EOC_MALE_PC                                                                                             float64
#  234 pct_L2_M1_EOC_SWD_PC                                                                                              float64
#  235 pct_L2_M1_EOC_WH7_PC                                                                                              float64
#  236 pct_L3_ALL_ALL_ALL_PC                                                                                             float64
#  237 pct_L3_ALL_ALL_BL7_PC                                                                                             float64
#  238 pct_L3_ALL_ALL_EDS_PC                                                                                             float64
#  239 pct_L3_ALL_ALL_FEM_PC                                                                                             float64
#  240 pct_L3_ALL_ALL_HI7_PC                                                                                             float64
#  241 pct_L3_ALL_ALL_MALE_PC                                                                                            float64
#  242 pct_L3_ALL_ALL_SWD_PC                                                                                             float64
#  243 pct_L3_ALL_ALL_WH7_PC                                                                                             float64
#  244 pct_L3_BI_EOC_ALL_PC                                                                                              float64
#  245 pct_L3_BI_EOC_BL7_PC                                                                                              float64
#  246 pct_L3_BI_EOC_EDS_PC                                                                                              float64
#  247 pct_L3_BI_EOC_FEM_PC                                                                                              float64
#  248 pct_L3_BI_EOC_HI7_PC                                                                                              float64
#  249 pct_L3_BI_EOC_MALE_PC                                                                                             float64
#  250 pct_L3_BI_EOC_WH7_PC                                                                                              float64
#  251 pct_L3_E2_EOC_ALL_PC                                                                                              float64
#  252 pct_L3_E2_EOC_BL7_PC                                                                                              float64
#  253 pct_L3_E2_EOC_EDS_PC                                                                                              float64
#  254 pct_L3_E2_EOC_FEM_PC                                                                                              float64
#  255 pct_L3_E2_EOC_HI7_PC                                                                                              float64
#  256 pct_L3_E2_EOC_MALE_PC                                                                                             float64
#  257 pct_L3_E2_EOC_WH7_PC                                                                                              float64
#  258 pct_L3_EOC_EOC_ALL_PC                                                                                             float64
#  259 pct_L3_EOC_EOC_BL7_PC                                                                                             float64
#  260 pct_L3_EOC_EOC_EDS_PC                                                                                             float64
#  261 pct_L3_EOC_EOC_FEM_PC                                                                                             float64
#  262 pct_L3_EOC_EOC_HI7_PC                                                                                             float64
#  263 pct_L3_EOC_EOC_MALE_PC                                                                                            float64
#  264 pct_L3_EOC_EOC_MU7_PC                                                                                             float64
#  265 pct_L3_EOC_EOC_SWD_PC                                                                                             float64
#  266 pct_L3_EOC_EOC_WH7_PC                                                                                             float64
#  267 pct_L3_M1_EOC_ALL_PC                                                                                              float64
#  268 pct_L3_M1_EOC_BL7_PC                                                                                              float64
#  269 pct_L3_M1_EOC_EDS_PC                                                                                              float64
#  270 pct_L3_M1_EOC_FEM_PC                                                                                              float64
#  271 pct_L3_M1_EOC_HI7_PC                                                                                              float64
#  272 pct_L3_M1_EOC_MALE_PC                                                                                             float64
#  273 pct_L3_M1_EOC_WH7_PC                                                                                              float64
#  274 pct_L4_ALL_ALL_ELS_PC                                                                                             float64
#  275 pct_L4_ALL_ALL_SWD_PC                                                                                             float64
#  276 pct_L4_BI_EOC_AIG_PC                                                                                              float64
#  277 pct_L4_BI_EOC_ALL_PC                                                                                              float64
#  278 pct_L4_BI_EOC_BL7_PC                                                                                              float64
#  279 pct_L4_BI_EOC_EDS_PC                                                                                              float64
#  280 pct_L4_BI_EOC_FEM_PC                                                                                              float64
#  281 pct_L4_BI_EOC_HI7_PC                                                                                              float64
#  282 pct_L4_BI_EOC_MALE_PC                                                                                             float64
#  283 pct_L4_BI_EOC_SWD_PC                                                                                              float64
#  284 pct_L4_BI_EOC_WH7_PC                                                                                              float64
#  285 pct_L4_E2_EOC_AIG_PC                                                                                              float64
#  286 pct_L4_E2_EOC_ALL_PC                                                                                              float64
#  287 pct_L4_E2_EOC_BL7_PC                                                                                              float64
#  288 pct_L4_E2_EOC_EDS_PC                                                                                              float64
#  289 pct_L4_E2_EOC_FEM_PC                                                                                              float64
#  290 pct_L4_E2_EOC_HI7_PC                                                                                              float64
#  291 pct_L4_E2_EOC_MALE_PC                                                                                             float64
#  292 pct_L4_E2_EOC_SWD_PC                                                                                              float64
#  293 pct_L4_E2_EOC_WH7_PC                                                                                              float64
#  294 pct_L4_EOC_EOC_AIG_PC                                                                                             float64
#  295 pct_L4_EOC_EOC_BL7_PC                                                                                             float64
#  296 pct_L4_EOC_EOC_EDS_PC                                                                                             float64
#  297 pct_L4_EOC_EOC_ELS_PC                                                                                             float64
#  298 pct_L4_EOC_EOC_FEM_PC                                                                                             float64
#  299 pct_L4_EOC_EOC_HI7_PC                                                                                             float64
#  300 pct_L4_EOC_EOC_MALE_PC                                                                                            float64
#  301 pct_L4_EOC_EOC_MU7_PC                                                                                             float64
#  302 pct_L4_EOC_EOC_SWD_PC                                                                                             float64
#  303 pct_L4_EOC_EOC_WH7_PC                                                                                             float64
#  304 pct_L4_M1_EOC_AIG_PC                                                                                              float64
#  305 pct_L4_M1_EOC_BL7_PC                                                                                              float64
#  306 pct_L4_M1_EOC_EDS_PC                                                                                              float64
#  307 pct_L4_M1_EOC_FEM_PC                                                                                              float64
#  308 pct_L4_M1_EOC_HI7_PC                                                                                              float64
#  309 pct_L4_M1_EOC_MALE_PC                                                                                             float64
#  310 pct_L4_M1_EOC_WH7_PC                                                                                              float64
#  311 pct_L5_ALL_ALL_HI7_PC                                                                                             float64
#  312 pct_L5_BI_EOC_AIG_PC                                                                                              float64
#  313 pct_L5_BI_EOC_ALL_PC                                                                                              float64
#  314 pct_L5_BI_EOC_EDS_PC                                                                                              float64
#  315 pct_L5_BI_EOC_FEM_PC                                                                                              float64
#  316 pct_L5_BI_EOC_HI7_PC                                                                                              float64
#  317 pct_L5_BI_EOC_MALE_PC                                                                                             float64
#  318 pct_L5_BI_EOC_WH7_PC                                                                                              float64
#  319 pct_L5_E2_EOC_AIG_PC                                                                                              float64
#  320 pct_L5_EOC_EOC_AIG_PC                                                                                             float64
#  321 pct_L5_EOC_EOC_FEM_PC                                                                                             float64
#  322 pct_L5_EOC_EOC_MALE_PC                                                                                            float64
#  323 pct_L5_EOC_EOC_WH7_PC                                                                                             float64
#  324 pct_L5_M1_EOC_AIG_PC                                                                                              float64
#  325 pct_L5_M1_EOC_FEM_PC                                                                                              float64
#  326 pct_L5_M1_EOC_MALE_PC                                                                                             float64
#  327 pct_L5_M1_EOC_WH7_PC                                                                                              float64
#  328 aaa_score_ALL_SPG2                                                                                                float64
#  329 aaa_score_BL7_SPG2                                                                                                float64
#  330 aaa_score_EDS_SPG2                                                                                                float64
#  331 aaa_score_SWD_SPG2                                                                                                float64
#  332 aaa_score_WH7_SPG2                                                                                                float64
#  333 awa_score_ALL_SPG2                                                                                                float64
#  334 awa_score_EDS_SPG2                                                                                                float64
#  335 bi_score_ALL_SPG2                                                                                                 float64
#  336 bi_score_BL7_SPG2                                                                                                 float64
#  337 bi_score_EDS_SPG2                                                                                                 float64
#  338 bi_score_WH7_SPG2                                                                                                 float64
#  339 cgrs_score_ALL_SPG2                                                                                               float64
#  340 cgrs_score_BL7_SPG2                                                                                               float64
#  341 cgrs_score_EDS_SPG2                                                                                               float64
#  342 cgrs_score_WH7_SPG2                                                                                               float64
#  343 eg_score_ALL_SPG2                                                                                                 float64
#  344 eg_score_BL7_SPG2                                                                                                 float64
#  345 eg_score_EDS_SPG2                                                                                                 float64
#  346 eg_score_HI7_SPG2                                                                                                 float64
#  347 eg_score_SWD_SPG2                                                                                                 float64
#  348 eg_score_WH7_SPG2                                                                                                 float64
#  349 mcr_score_ALL_SPG2                                                                                                float64
#  350 mcr_score_BL7_SPG2                                                                                                float64
#  351 mcr_score_EDS_SPG2                                                                                                float64
#  352 mcr_score_WH7_SPG2                                                                                                float64
#  353 spg_score_ALL_SPG2                                                                                                float64
#  354 spg_score_BL7_SPG2                                                                                                float64
#  355 spg_score_EDS_SPG2                                                                                                float64
#  356 spg_score_HI7_SPG2                                                                                                float64
#  357 spg_score_SWD_SPG2                                                                                                float64
#  358 spg_score_WH7_SPG2                                                                                                float64
#  359 pct_AIG_WK                                                                                                        float64
#  360 pct_ALL_WK                                                                                                        float64
#  361 pct_BL7_WK                                                                                                        float64
#  362 pct_EDS_WK                                                                                                        float64
#  363 pct_FEM_WK                                                                                                        float64
#  364 pct_MALE_WK                                                                                                       float64
#  365 pct_WH7_WK                                                                                                        float64
#  366 pct_ap_pass                                                                                                       float64
#  367 pct_ap_participation                                                                                              float64
#  368 pct_att                                                                                                           float64
#  369 pct_AS7_CHRON_ABSENT                                                                                              float64
#  370 pct_BL7_CHRON_ABSENT                                                                                              float64
#  371 pct_ELS_CHRON_ABSENT                                                                                              float64
#  372 pct_FEM_CHRON_ABSENT                                                                                              float64
#  373 pct_HI7_CHRON_ABSENT                                                                                              float64
# ...
#  682 digital_media_54                                                                                                  uint8
#  683 digital_media_6                                                                                                   uint8
#  684 digital_media_7                                                                                                   uint8
#  685 digital_media_8                                                                                                   uint8
#  686 digital_media_9                                                                                                   uint8
#  687 device_access_Yes                                                                                                 uint8
#  688 device_home_Yes                                                                                                   uint8
#  689 BYOD_Neither                                                                                                      uint8
#  690 BYOD_Staff                                                                                                        uint8
#  691 BYOD_Students                                                                                                     uint8
#  692 agency_lea_code_020LEA                                                                                            uint8
#  693 agency_lea_code_030LEA                                                                                            uint8
#  694 agency_lea_code_040LEA                                                                                            uint8
#  695 agency_lea_code_050LEA                                                                                            uint8
#  696 agency_lea_code_060LEA                                                                                            uint8
#  697 agency_lea_code_070LEA                                                                                            uint8
#  698 agency_lea_code_080LEA                                                                                            uint8
#  699 agency_lea_code_090LEA                                                                                            uint8
#  700 agency_lea_code_100LEA                                                                                            uint8
#  701 agency_lea_code_110LEA                                                                                            uint8
#  702 agency_lea_code_111LEA                                                                                            uint8
#  703 agency_lea_code_120LEA                                                                                            uint8
#  704 agency_lea_code_130LEA                                                                                            uint8
#  705 agency_lea_code_132LEA                                                                                            uint8
#  706 agency_lea_code_140LEA                                                                                            uint8
#  707 agency_lea_code_150LEA                                                                                            uint8
#  708 agency_lea_code_160LEA                                                                                            uint8
#  709 agency_lea_code_170LEA                                                                                            uint8
#  710 agency_lea_code_180LEA                                                                                            uint8
#  711 agency_lea_code_181LEA                                                                                            uint8
#  712 agency_lea_code_182LEA                                                                                            uint8
#  713 agency_lea_code_190LEA                                                                                            uint8
#  714 agency_lea_code_200LEA                                                                                            uint8
#  715 agency_lea_code_210LEA                                                                                            uint8
#  716 agency_lea_code_220LEA                                                                                            uint8
#  717 agency_lea_code_230LEA                                                                                            uint8
#  718 agency_lea_code_240LEA                                                                                            uint8
#  719 agency_lea_code_241LEA                                                                                            uint8
#  720 agency_lea_code_250LEA                                                                                            uint8
#  721 agency_lea_code_260LEA                                                                                            uint8
#  722 agency_lea_code_270LEA                                                                                            uint8
#  723 agency_lea_code_280LEA                                                                                            uint8
#  724 agency_lea_code_290LEA                                                                                            uint8
#  725 agency_lea_code_291LEA                                                                                            uint8
#  726 agency_lea_code_292LEA                                                                                            uint8
#  727 agency_lea_code_300LEA                                                                                            uint8
#  728 agency_lea_code_310LEA                                                                                            uint8
#  729 agency_lea_code_320LEA                                                                                            uint8
#  730 agency_lea_code_330LEA                                                                                            uint8
#  731 agency_lea_code_340LEA                                                                                            uint8
#  732 agency_lea_code_350LEA                                                                                            uint8
#  733 agency_lea_code_360LEA                                                                                            uint8
#  734 agency_lea_code_370LEA                                                                                            uint8
#  735 agency_lea_code_380LEA                                                                                            uint8
#  736 agency_lea_code_390LEA                                                                                            uint8
#  737 agency_lea_code_400LEA                                                                                            uint8
#  738 agency_lea_code_410LEA                                                                                            uint8
#  739 agency_lea_code_420LEA                                                                                            uint8
#  740 agency_lea_code_421LEA                                                                                            uint8
#  741 agency_lea_code_422LEA                                                                                            uint8
#  742 agency_lea_code_430LEA                                                                                            uint8
#  743 agency_lea_code_440LEA                                                                                            uint8
#  744 agency_lea_code_450LEA                                                                                            uint8
#  745 agency_lea_code_460LEA                                                                                            uint8
#  746 agency_lea_code_470LEA                                                                                            uint8
#  747 agency_lea_code_480LEA                                                                                            uint8
#  748 agency_lea_code_490LEA                                                                                            uint8
#  749 agency_lea_code_491LEA                                                                                            uint8
#  750 agency_lea_code_500LEA                                                                                            uint8
#  751 agency_lea_code_510LEA                                                                                            uint8
#  752 agency_lea_code_520LEA                                                                                            uint8
#  753 agency_lea_code_530LEA                                                                                            uint8
#  754 agency_lea_code_540LEA                                                                                            uint8
#  755 agency_lea_code_550LEA                                                                                            uint8
#  756 agency_lea_code_560LEA                                                                                            uint8
#  757 agency_lea_code_570LEA                                                                                            uint8
#  758 agency_lea_code_580LEA                                                                                            uint8
#  759 agency_lea_code_590LEA                                                                                            uint8
#  760 agency_lea_code_600LEA                                                                                            uint8
#  761 agency_lea_code_610LEA                                                                                            uint8
#  762 agency_lea_code_620LEA                                                                                            uint8
#  763 agency_lea_code_630LEA                                                                                            uint8
#  764 agency_lea_code_640LEA                                                                                            uint8
#  765 agency_lea_code_650LEA                                                                                            uint8
#  766 agency_lea_code_660LEA                                                                                            uint8
#  767 agency_lea_code_670LEA                                                                                            uint8
#  768 agency_lea_code_680LEA                                                                                            uint8
#  769 agency_lea_code_681LEA                                                                                            uint8
#  770 agency_lea_code_690LEA                                                                                            uint8
#  771 agency_lea_code_700LEA                                                                                            uint8
#  772 agency_lea_code_710LEA                                                                                            uint8
#  773 agency_lea_code_720LEA                                                                                            uint8
#  774 agency_lea_code_730LEA                                                                                            uint8
#  775 agency_lea_code_740LEA                                                                                            uint8
#  776 agency_lea_code_750LEA                                                                                            uint8
#  777 agency_lea_code_760LEA                                                                                            uint8
#  778 agency_lea_code_761LEA                                                                                            uint8
#  779 agency_lea_code_770LEA                                                                                            uint8
#  780 agency_lea_code_780LEA                                                                                            uint8
#  781 agency_lea_code_790LEA                                                                                            uint8
#  782 agency_lea_code_800LEA                                                                                            uint8
#  783 agency_lea_code_810LEA                                                                                            uint8
#  784 agency_lea_code_820LEA                                                                                            uint8
#  785 agency_lea_code_821LEA                                                                                            uint8
#  786 agency_lea_code_830LEA                                                                                            uint8
#  787 agency_lea_code_840LEA                                                                                            uint8
#  788 agency_lea_code_850LEA                                                                                            uint8
#  789 agency_lea_code_860LEA                                                                                            uint8
#  790 agency_lea_code_861LEA                                                                                            uint8
#  791 agency_lea_code_862LEA                                                                                            uint8
#  792 agency_lea_code_870LEA                                                                                            uint8
#  793 agency_lea_code_880LEA                                                                                            uint8
#  794 agency_lea_code_890LEA                                                                                            uint8
#  795 agency_lea_code_900LEA                                                                                            uint8
#  796 agency_lea_code_910LEA                                                                                            uint8
#  797 agency_lea_code_920LEA                                                                                            uint8
#  798 agency_lea_code_930LEA                                                                                            uint8
#  799 agency_lea_code_940LEA                                                                                            uint8
#  800 agency_lea_code_950LEA                                                                                            uint8
#  801 agency_lea_code_960LEA                                                                                            uint8
#  802 agency_lea_code_970LEA                                                                                            uint8
#  803 agency_lea_code_980LEA                                                                                            uint8
#  804 agency_lea_code_990LEA                                                                                            uint8
#  805 agency_lea_code_995LEA                                                                                            uint8
#  806 agency_code                                                                                                       object
# dtypes: float64(543), object(1), uint8(263)
# memory usage: 2.7+ MB

# %%
import sklearn
import pandas as pd

print('Sklearn Version: ' + sklearn.__version__)
print('Pandas Version: ' + pd.__version__)
# Out:
# Sklearn Version: 0.22.1
# Pandas Version: 1.0.3

# %%
print('Output File Location:\r\n\r\n' + outputDir + inputFileName + '_ML.csv')
# Out:
# Output File Location:
#
# D:/BenepactLLC/Belk/NC_Report_Card_Data/2020/June 2020/2018/Machine Learning Datasets/PublicHighSchools2018_ML.csv
