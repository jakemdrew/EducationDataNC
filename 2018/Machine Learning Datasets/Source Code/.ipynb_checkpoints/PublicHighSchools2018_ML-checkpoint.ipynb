# %% [markdown]
# # Create Public School Machine Learning Datasets
# ** This program creates all the _ML datasets in the NCEA repository.**
# * This notebook reads each School Dataset file located at \EducationDataNC\ *schoolYear* \School Datasets\ as input data.
# * Different school years are processed by changing the *schoolYear* parameter.
# * Different input / output files are processed / created by changing the *inputFileName* paramter in the cell below.
# * While a single program is used to create all the _ML datasets, one program copy per dataset is maintained in the repositiory so the dataset specific tranformation reports may be reviewed.
#
# **Datasets ending in ML are preprocessed for Machine Learning and go through the following transformations: **
# 1. Missing student body racial compositions are imputed using district averages.
# 2. Columns that have the same value in every single row are deleted.
# 3. Columns that have a unique value in every single row (all values are different) are deleted.
# 4. Empty columns (all values are NA or NULL) are deleted.
# 5. Numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# 6. Remaining numeric, non-race columns with missing values are imputed / populated with 0.  In many cases, schools are not reporting values when they are zero. However, mean imputation or some other more sophisticated strategy might be considered here.
# 7. Categorical / text based columns with > *uniqueThreshold* unique values are deleted.
# 8. All remaining categorical / text based columns are one-hot encoded.  In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# 9. Duplicated or highly similar columns with > 95% correlation are delelted.

# %%
#import required Libraries
import pandas as pd
import numpy as np
import os
import string

#**********************************************************************************
# Set the following variables before running this code!!!
#**********************************************************************************
#All raw data files are processed for the year below
schoolYear = 2018

#Location where copies of the raw data files will be read in from csv files.
dataDir = 'C:/Users/Jake/Documents/GitHub/EducationDataNC/' + str(schoolYear) + '/School Datasets/'

#Name of the file to be processed
#inputFileName = 'PublicSchools2018'
inputFileName = 'PublicHighSchools2018'
#inputFileName = 'PublicMiddleSchools2018'
#inputFileName = 'PublicElementarySchools2018'

#Input file being transformed for machine learning 
inputFile = dataDir + inputFileName + '.csv'

#Location where the new school datasets will be created.
outputDir = 'C:/Users/Jake/Documents/GitHub/EducationDataNC/' + str(schoolYear) + '/Machine Learning Datasets/'

#Missing Data Threshold (Per Column)
missingThreshold = 0.60

#Unique Value Threshold (Per Column)
#Delete Columns >  uniqueThreshold unique values prior to one-hot encoding. 
#(each unique value becomes a new column during one-hot encoding)
uniqueThreshold = 200

#Read in the School Data File
schoolData = pd.read_csv(inputFile, low_memory=False, dtype={'agency_code': object})
print('*********Start: Beginning Column and Row Counts********************************************')
schoolData.info(verbose=False)

#Select only public schools as charter schools are missing data for many columns.
schoolData = schoolData[(schoolData['designation_type'] == 'P') & (schoolData['avg_student_num'] > 0)]

print('\r\n*********After: Selecting Only Public School Campuses**********************************')
schoolData.info(verbose=False)

#Save primary key
agency_code = schoolData['agency_code']
#Convert zip code to string
schoolData['zip'] = schoolData['zip'].astype('object')
# Out:
# *********Start: Beginning Column and Row Counts********************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 679 entries, 0 to 678
# Columns: 1816 entries, agency_code to lea_federal_perpupil
# dtypes: float64(1765), object(51)
# memory usage: 9.4+ MB
#
# *********After: Selecting Only Public School Campuses**********************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 603 entries, 2 to 678
# Columns: 1816 entries, agency_code to lea_federal_perpupil
# dtypes: float64(1765), object(51)
# memory usage: 8.4+ MB

# %% [markdown]
# # Prepare Consolidated Dataset for Machine Learning
# **Below we perform operations on the entire dataset to remove columns and update row values that could cause problems during machine learning.**

# %% [markdown]
# ## Student Body Racial Composition Features
# **Impute / update missing Student Body Racial Composition Fields using mean imputation.**
# * When there are no racial composition percentages for a particular school campus / agency_code, fill in the missing values

# %%
#Get Student Body Racial Composition Fields
raceCompositionFields = schoolData.filter(regex='Indian|Asian|Hispanic|Black|White|PacificIsland|TwoOrMore|Minority')\
                                  .filter(regex='Pct').columns
    
rowsBefore = schoolData[raceCompositionFields].isnull().T.any().T.sum()

#Update missing race values with the district average when avaiable (No district averages for charter schools) 
schoolData[raceCompositionFields] = schoolData.groupby('lea_code')[raceCompositionFields]\
                                              .transform(lambda x: x.fillna(x.mean()))

    #Review dataset contents after Racial Composition Imputation
print('*********After: Updating Missing Racial Compostion Values****************************')   
rowsAfter = schoolData[raceCompositionFields].isnull().T.any().T.sum()
rowsUpdated = rowsBefore - rowsAfter
print('Rows Updated / Imputed: ', rowsUpdated) 
print('\r\nTotal Rows Missing Racial Compositions By District Code') 
schoolData['lea_code'][schoolData[raceCompositionFields].isnull().T.any().T].value_counts()
# Out:
# *********After: Updating Missing Racial Compostion Values****************************
# Rows Updated / Imputed:  2
#
# Total Rows Missing Racial Compositions By District Code
# Series([], Name: lea_code, dtype: int64)

# %% [markdown]
# ## Remove Columns with Problematic Data
# **Here we remove entire columns that could cause problems during machine learning.  The following operations are performed:**
# * Remove any columns that have the same value in every single row.
# * Remove any columns that have a unique value in every single row (all values are different).
# * Remove empty columns (all values are NA or NULL).

# %%
#Remove any fields that have the same value in all rows
UniqueValueCounts = schoolData.nunique(dropna=False)
SingleValueCols = UniqueValueCounts[UniqueValueCounts == 1].index
schoolData = schoolData.drop(SingleValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with the same value in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(SingleValueCols))
# Out:
# *********After: Removing columns with the same value in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 603 entries, 2 to 678
# Columns: 839 entries, agency_code to lea_federal_perpupil
# dtypes: float64(792), object(47)
# memory usage: 3.9+ MB
#
# Columns Deleted:  977

# %%
#Remove any fields that have unique values in every row
schoolDataRecordCt = schoolData.shape[0]
UniqueValueCounts = schoolData.apply(pd.Series.nunique)
AllUniqueValueCols = UniqueValueCounts[UniqueValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(AllUniqueValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with unique values in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(AllUniqueValueCols))
# Out:
# *********After: Removing columns with unique values in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 603 entries, 2 to 678
# Columns: 837 entries, category_code to lea_federal_perpupil
# dtypes: float64(792), object(45)
# memory usage: 3.9+ MB
#
# Columns Deleted:  2

# %%
#Remove any empty fields (null values in every row)
schoolDataRecordCt = schoolData.shape[0]
NullValueCounts = schoolData.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with null / blank values in every row.*************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with null / blank values in every row.*************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 603 entries, 2 to 678
# Columns: 837 entries, category_code to lea_federal_perpupil
# dtypes: float64(792), object(45)
# memory usage: 3.9+ MB
#
# Columns Deleted:  0

# %% [markdown]
# ## Handle Other Missing Values Types
# * Here we eliminate any numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# * All remaining non-race, numeric column missing values are populated with 0.
# * In many cases, it seems that schools are not simply not reporting values when they are zero. However, mean imputation or some other strategy might be considered.

# %%
#Isolate continuous and categorical data types
#These are indexers into the schoolData dataframe and may be used similar to the schoolData dataframe 
sD_boolean = schoolData.loc[:, (schoolData.dtypes == bool) ]
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]
sD_continuous = schoolData.loc[:, (schoolData.dtypes != bool) & (schoolData.dtypes != object)]
print ("Boolean Columns: ", sD_boolean.shape[1])
print ("Nominal Columns: ", sD_nominal.shape[1])
print ("Continuous Columns: ", sD_continuous.shape[1])
print ("Columns Accounted for: ", sD_nominal.shape[1] + sD_continuous.shape[1] + sD_boolean.shape[1])
# Out:
# Boolean Columns:  0
# Nominal Columns:  45
# Continuous Columns:  792
# Columns Accounted for:  837

# %%
#Eliminate continuous columns with more than missingThreshold percentage of missing values
schoolDataRecordCt = sD_continuous.shape[0]
missingValueLimit = schoolDataRecordCt * missingThreshold
NullValueCounts = sD_continuous.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts >= missingValueLimit].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with >= missingThreshold % of missing values******')
schoolData.info(verbose=False)
print('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with >= missingThreshold % of missing values******
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 603 entries, 2 to 678
# Columns: 477 entries, category_code to lea_federal_perpupil
# dtypes: float64(432), object(45)
# memory usage: 2.2+ MB
#
# Columns Deleted:  360

# %% [markdown]
# ## One-Hot Encoding of Categorical Variables
# **All categorical / string variables are converted to numberic variables via one hot encoding.  Each unique row value will become a new binary / numeric column in the dataset.**
# * All remaining categorical columns are one-hot encoded.
# * In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# * Prior to one-hot encoding, columns with > *uniqueThreshold* unique values are deleted.

# %%
#Delete categorical columns with > uniqueThreshold unique values 
#(Each unique value becomes a column during one-hot encoding)
oneHotUniqueValueCounts = schoolData[sD_nominal.columns].apply(lambda x: x.nunique())
oneHotUniqueValueCols = oneHotUniqueValueCounts[oneHotUniqueValueCounts >= uniqueThreshold].index
schoolData.drop(oneHotUniqueValueCols, axis=1, inplace=True) 

#Remove categorical columns which do not add value to machine learning
#Grades columns dropped since they all have indicator fields (device_access, device_home, BYOD)
#with less unique values to one-hot encode
schoolData.drop(['welcome_url','device_access_grades',
                 'device_home_grades','byod_grades'], axis=1, inplace=True) 

#Review dataset contents one hot high unique value drops
print('*********After: Removing columns with >= uniqueThreshold unique values***********')
schoolData.info(verbose=False)
print('\r\nColumns Deleted: ', len(oneHotUniqueValueCols))
print(oneHotUniqueValueCols)
print('Dropped Manually: welcome_url,device_access_grades,device_home_grades,byod_grades')
# Out:
# *********After: Removing columns with >= uniqueThreshold unique values***********
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 603 entries, 2 to 678
# Columns: 467 entries, category_code to lea_federal_perpupil
# dtypes: float64(432), object(35)
# memory usage: 2.2+ MB
#
# Columns Deleted:  6
# Index(['street_addr', 'city', 'zip', 'phone', 'url', 'School Name'], dtype='object')
# Dropped Manually: welcome_url,device_access_grades,device_home_grades,byod_grades

# %%
#Isolate remaining categorical variables
begColumnCt = len(schoolData.columns)
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]

#one hot encode categorical variables
schoolData = pd.get_dummies(data=schoolData, 
                       columns=sD_nominal.columns, drop_first=True)

#Determine change in column count
endColumnCt = len(schoolData.columns)
columnsAdded = endColumnCt - begColumnCt

#Review dataset contents one hot high unique value drops
print('Columns To One-Hot Encode: ', len(sD_nominal.columns))
print('\r\n*********After: Adding New Columns Via One-Hot Encoding*************************')
schoolData.info(verbose=False)
print('\r\nNew Columns Created Via One-Hot Encoding: ', columnsAdded)
# Out:
# Columns To One-Hot Encode:  35
#
# *********After: Adding New Columns Via One-Hot Encoding*************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 603 entries, 2 to 678
# Columns: 899 entries, IndianPct to agency_lea_code_995LEA
# dtypes: float64(432), uint8(467)
# memory usage: 2.3 MB
#
# New Columns Created Via One-Hot Encoding:  432

# %%
#Remove any fields that have the same value in all rows after one-hot encoding
UniqueValueCounts = schoolData.nunique(dropna=False)
SingleValueCols = UniqueValueCounts[UniqueValueCounts == 1].index
schoolData = schoolData.drop(SingleValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing one-hot encoded columns with the same value in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(SingleValueCols))
# Out:
# *********After: Removing one-hot encoded columns with the same value in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 603 entries, 2 to 678
# Columns: 899 entries, IndianPct to agency_lea_code_995LEA
# dtypes: float64(432), uint8(467)
# memory usage: 2.3 MB
#
# Columns Deleted:  0

# %% [markdown]
# ## Impute any Remaining Missing Values as Zero

# %%
#Print out all the missing value rows
pd.set_option('display.max_rows', 1000)

print('\r\n*********The Remaining Missing Values Below will be set to Zero!*************************')

#Check for Missing values 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# *********The Remaining Missing Values Below will be set to Zero!*************************
#                                    Variable Name  Number Missing Values
# 24                        ccc_pct_COMP1Y_ALL_161                    136
# 25                        ccc_pct_COMP1Y_BL7_161                    319
# 26                        ccc_pct_COMP1Y_EDS_161                    168
# 27                        ccc_pct_COMP1Y_FEM_161                    142
# 28                       ccc_pct_COMP1Y_MALE_161                    160
# 29                        ccc_pct_COMP1Y_WH7_161                    177
# 30                      ccc_pct_NOCOMP1Y_ALL_161                    120
# 31                      ccc_pct_NOCOMP1Y_BL7_161                    338
# 32                      ccc_pct_NOCOMP1Y_EDS_161                    192
# 33                      ccc_pct_NOCOMP1Y_FEM_161                    147
# 34                     ccc_pct_NOCOMP1Y_MALE_161                    154
# 35                      ccc_pct_NOCOMP1Y_WH7_161                    189
# 36                        ccc_pct_NOINFO_ALL_161                    116
# 37                        ccc_pct_NOINFO_BL7_161                    328
# 38                        ccc_pct_NOINFO_EDS_161                    218
# 39                        ccc_pct_NOINFO_FEM_161                    149
# 40                       ccc_pct_NOINFO_MALE_161                    165
# 41                        ccc_pct_NOINFO_WH7_161                    206
# 42                             pct_ACALL_AIG_ACT                    116
# 43                             pct_ACALL_ALL_ACT                     47
# 44                             pct_ACALL_AS7_ACT                    335
# 45                             pct_ACALL_BL7_ACT                    112
# 46                             pct_ACALL_EDS_ACT                     60
# 47                             pct_ACALL_ELS_ACT                    240
# 48                             pct_ACALL_FEM_ACT                     65
# 49                             pct_ACALL_HI7_ACT                    111
# 50                            pct_ACALL_MALE_ACT                     57
# 51                             pct_ACALL_MU7_ACT                    186
# 52                             pct_ACALL_SWD_ACT                    166
# 53                             pct_ACALL_WH7_ACT                     78
# 54                              pct_ACCO_AIG_ACT                    196
# 55                              pct_ACCO_ALL_ACT                     77
# 56                              pct_ACCO_BL7_ACT                    226
# 57                              pct_ACCO_EDS_ACT                    121
# 58                              pct_ACCO_FEM_ACT                    102
# 59                              pct_ACCO_HI7_ACT                    241
# 60                             pct_ACCO_MALE_ACT                    107
# 61                              pct_ACCO_SWD_ACT                    294
# 62                              pct_ACCO_WH7_ACT                    142
# 63                              pct_ACEN_AIG_ACT                    196
# 64                              pct_ACEN_ALL_ACT                     77
# 65                              pct_ACEN_BL7_ACT                    225
# 66                              pct_ACEN_EDS_ACT                    121
# 67                              pct_ACEN_FEM_ACT                    102
# 68                              pct_ACEN_HI7_ACT                    241
# 69                             pct_ACEN_MALE_ACT                    106
# 70                              pct_ACEN_SWD_ACT                    292
# 71                              pct_ACEN_WH7_ACT                    142
# 72                              pct_ACMA_AIG_ACT                    196
# 73                              pct_ACMA_ALL_ACT                     77
# 74                              pct_ACMA_BL7_ACT                    225
# 75                              pct_ACMA_EDS_ACT                    121
# 76                              pct_ACMA_FEM_ACT                    102
# 77                              pct_ACMA_HI7_ACT                    241
# 78                             pct_ACMA_MALE_ACT                    106
# 79                              pct_ACMA_SWD_ACT                    292
# 80                              pct_ACMA_WH7_ACT                    142
# 81                              pct_ACRD_AIG_ACT                    196
# 82                              pct_ACRD_ALL_ACT                     77
# 83                              pct_ACRD_BL7_ACT                    225
# 84                              pct_ACRD_EDS_ACT                    121
# 85                              pct_ACRD_FEM_ACT                    102
# 86                              pct_ACRD_HI7_ACT                    241
# 87                             pct_ACRD_MALE_ACT                    106
# 88                              pct_ACRD_SWD_ACT                    292
# 89                              pct_ACRD_WH7_ACT                    142
# 90                              pct_ACSC_AIG_ACT                    196
# 91                              pct_ACSC_ALL_ACT                     77
# 92                              pct_ACSC_BL7_ACT                    226
# 93                              pct_ACSC_EDS_ACT                    121
# 94                              pct_ACSC_FEM_ACT                    102
# 95                              pct_ACSC_HI7_ACT                    241
# 96                             pct_ACSC_MALE_ACT                    107
# 97                              pct_ACSC_SWD_ACT                    294
# 98                              pct_ACSC_WH7_ACT                    142
# 99                              pct_ACWR_AIG_ACT                    196
# 100                             pct_ACWR_ALL_ACT                     78
# 101                             pct_ACWR_BL7_ACT                    227
# 102                             pct_ACWR_EDS_ACT                    122
# 103                             pct_ACWR_FEM_ACT                    102
# 104                             pct_ACWR_HI7_ACT                    244
# 105                            pct_ACWR_MALE_ACT                    110
# 106                             pct_ACWR_SWD_ACT                    316
# 107                             pct_ACWR_WH7_ACT                    143
# 108                                  pct_AIG_AWA                    197
# 109                                  pct_ALL_AWA                     82
# 110                                  pct_BL7_AWA                    230
# 111                                  pct_EDS_AWA                    143
# 112                                  pct_FEM_AWA                    105
# 113                                  pct_HI7_AWA                    266
# 114                                 pct_MALE_AWA                    113
# 115                                  pct_SWD_AWA                    308
# 116                                  pct_WH7_AWA                    145
# 117                              pct_EXT_AIG_CGR                    196
# 118                              pct_EXT_ALL_CGR                     56
# 119                              pct_EXT_BL7_CGR                    217
# 120                              pct_EXT_EDS_CGR                    106
# 121                              pct_EXT_FEM_CGR                     95
# 122                              pct_EXT_HI7_CGR                    260
# 123                             pct_EXT_MALE_CGR                     80
# 124                              pct_EXT_SWD_CGR                    242
# 125                              pct_EXT_WH7_CGR                    123
# 126                              pct_STD_AIG_CGR                    189
# 127                              pct_STD_ALL_CGR                     55
# 128                              pct_STD_BL7_CGR                    200
# 129                              pct_STD_EDS_CGR                     93
# 130                              pct_STD_FEM_CGR                     75
# 131                              pct_STD_HI7_CGR                    237
# 132                             pct_STD_MALE_CGR                     76
# 133                              pct_STD_SWD_CGR                    201
# 134                              pct_STD_WH7_CGR                    109
# 135                                      pct_eds                      1
# 136                                  pct_ALL_ELP                    295
# 137                                  pct_EDS_ELP                    338
# 138                                  pct_ELS_ELP                    295
# 139                                  pct_HI7_ELP                    313
# 140                                 pct_MALE_ELP                    350
# 141                             pct_prof_9gr_irm                     65
# 142           pct_met_4 Year Graduation Rate_LTG                    135
# 143                    pct_met_Math Grade 11_LTG                    149
# 144                 pct_met_Reading Grade 10_LTG                    138
# 145                    pct_met_Total Targets_LTG                     86
# 146                                  pct_AIG_MCR                    190
# 147                                  pct_ALL_MCR                     56
# 148                                  pct_BL7_MCR                    217
# 149                                  pct_EDS_MCR                    119
# 150                                  pct_FEM_MCR                     91
# 151                                  pct_HI7_MCR                    253
# 152                                 pct_MALE_MCR                     87
# 153                                  pct_SWD_MCR                    238
# 154                                  pct_WH7_MCR                    124
# 155                    pct_met_ACT WorkKeys_PART                    241
# 156                         pct_met_Biology_PART                    111
# 157                      pct_met_English II_PART                    111
# 158                pct_met_High School Math_PART                    111
# 159                         pct_met_The ACT_PART                    112
# 160                   pct_met_Total Targets_PART                     62
# 161                pct_ACT WorkKeys_ALL_PART_DET                    241
# 162                pct_ACT WorkKeys_WH7_PART_DET                    335
# 163                     pct_Biology_ALL_PART_DET                    111
# 164                     pct_Biology_BL7_PART_DET                    354
# 165                     pct_Biology_EDS_PART_DET                    234
# 166                     pct_Biology_WH7_PART_DET                    235
# 167                  pct_English II_ALL_PART_DET                    111
# 168                  pct_English II_BL7_PART_DET                    338
# 169                  pct_English II_EDS_PART_DET                    218
# 170                  pct_English II_WH7_PART_DET                    230
# 171            pct_High School Math_ALL_PART_DET                    111
# 172            pct_High School Math_BL7_PART_DET                    354
# 173            pct_High School Math_EDS_PART_DET                    234
# 174            pct_High School Math_WH7_PART_DET                    235
# 175                     pct_The ACT_ALL_PART_DET                    112
# 176                     pct_The ACT_BL7_PART_DET                    355
# 177                     pct_The ACT_EDS_PART_DET                    235
# 178                     pct_The ACT_WH7_PART_DET                    238
# 179                                     m1_score                    107
# 180                                     e2_score                    113
# 181                                     bi_score                    112
# 182                                    act_score                    108
# 183                                     wk_score                    190
# 184                                    mcr_score                    111
# 185                                   cgrs_score                    110
# 186                                    ach_score                     94
# 187                                     eg_score                    106
# 188                                    spg_score                     94
# 189                           aaa_score_ALL_SPG2                     92
# 190                           aaa_score_BL7_SPG2                    261
# 191                           aaa_score_EDS_SPG2                    131
# 192                           aaa_score_HI7_SPG2                    262
# 193                           aaa_score_SWD_SPG2                    260
# 194                           aaa_score_WH7_SPG2                    157
# 195                           ach_score_ALL_SPG2                     83
# 196                           ach_score_BL7_SPG2                    257
# 197                           ach_score_EDS_SPG2                    128
# 198                           ach_score_HI7_SPG2                    261
# 199                           ach_score_SWD_SPG2                    259
# 200                           ach_score_WH7_SPG2                    148
# 201                           awa_score_ALL_SPG2                    137
# 202                           awa_score_EDS_SPG2                    252
# 203                           awa_score_WH7_SPG2                    247
# 204                            bi_score_ALL_SPG2                    124
# 205                            bi_score_BL7_SPG2                    358
# 206                            bi_score_EDS_SPG2                    225
# 207                            bi_score_WH7_SPG2                    236
# 208                          cgrs_score_ALL_SPG2                    128
# 209                          cgrs_score_BL7_SPG2                    341
# 210                          cgrs_score_EDS_SPG2                    233
# 211                          cgrs_score_WH7_SPG2                    230
# 212                            eg_score_ALL_SPG2                    104
# 213                            eg_score_BL7_SPG2                    283
# 214                            eg_score_EDS_SPG2                    151
# 215                            eg_score_HI7_SPG2                    304
# 216                            eg_score_SWD_SPG2                    282
# 217                            eg_score_WH7_SPG2                    186
# 218                           mcr_score_ALL_SPG2                    136
# 219                           mcr_score_BL7_SPG2                    354
# 220                           mcr_score_EDS_SPG2                    243
# 221                           mcr_score_WH7_SPG2                    242
# 222                           spg_score_ALL_SPG2                     83
# 223                           spg_score_BL7_SPG2                    257
# 224                           spg_score_EDS_SPG2                    128
# 225                           spg_score_HI7_SPG2                    261
# 226                           spg_score_SWD_SPG2                    259
# 227                           spg_score_WH7_SPG2                    148
# 228                                   pct_AIG_WK                    359
# 229                                   pct_ALL_WK                    203
# 230                                   pct_BL7_WK                    350
# 231                                   pct_EDS_WK                    243
# 232                                   pct_FEM_WK                    224
# 233                                  pct_MALE_WK                    226
# 234                                   pct_WH7_WK                    259
# 236                                  pct_ap_pass                    205
# 237                         pct_ap_participation                    262
# 239                         pct_ALL_CHRON_ABSENT                     17
# 240                         pct_AS7_CHRON_ABSENT                    360
# 241                         pct_BL7_CHRON_ABSENT                     84
# 242                         pct_ELS_CHRON_ABSENT                    187
# 243                         pct_FEM_CHRON_ABSENT                     25
# 244                         pct_HI7_CHRON_ABSENT                     72
# 245                        pct_MALE_CHRON_ABSENT                     37
# 246                         pct_MU7_CHRON_ABSENT                    116
# 247                         pct_SWD_CHRON_ABSENT                    108
# 248                         pct_WH7_CHRON_ABSENT                     28
# 249              pct_enrolled_ENROLL_ALL_COLLEGE                     76
# 250              pct_enrolled_ENROLL_BL7_COLLEGE                    221
# 251              pct_enrolled_ENROLL_EDS_COLLEGE                    196
# 252              pct_enrolled_ENROLL_FEM_COLLEGE                     87
# 253              pct_enrolled_ENROLL_HI7_COLLEGE                    357
# 254             pct_enrolled_ENROLL_MALE_COLLEGE                     89
# 255              pct_enrolled_ENROLL_WH7_COLLEGE                    132
# 256                                  pct_spc_crs                     23
# 257                                pct_ap_ib_crs                    201
# 258                                  pct_cte_crs                     49
# 259                            pct_univ_coll_crs                    153
# 260                        pct_ap_H_AS7_COURSES2                    310
# 261                        pct_ap_H_BL7_COURSES2                    274
# 262                        pct_ap_H_FEM_COURSES2                    235
# 263                        pct_ap_H_HI7_COURSES2                    248
# 264                       pct_ap_H_MALE_COURSES2                    235
# 265                        pct_ap_H_MU7_COURSES2                    280
# 266                        pct_ap_H_WH7_COURSES2                    237
# 267                       pct_ccp_H_AM7_COURSES2                    249
# 268                       pct_ccp_H_AS7_COURSES2                    164
# 269                       pct_ccp_H_BL7_COURSES2                    108
# 270                       pct_ccp_H_ELS_COURSES2                    177
# 271                       pct_ccp_H_FEM_COURSES2                    100
# 272                       pct_ccp_H_HI7_COURSES2                    101
# 273                      pct_ccp_H_MALE_COURSES2                    100
# 274                       pct_ccp_H_MU7_COURSES2                    104
# 275                       pct_ccp_H_SWD_COURSES2                    125
# 276                       pct_ccp_H_WH7_COURSES2                     99
# 277                       num_concentrators_AAVC                    135
# 278                       num_concentrators_AGNR                    135
# 279                       num_concentrators_ARCH                    135
# 280                        num_concentrators_BMA                    135
# 281                       num_concentrators_EDUC                    135
# 282                       num_concentrators_FINA                    135
# 283                       num_concentrators_HLTH                    135
# 284                       num_concentrators_HOSP                    135
# 285                       num_concentrators_HUMA                    135
# 286                       num_concentrators_INFO                    135
# 287                        num_concentrators_LAW                    135
# 288                       num_concentrators_MANU                    135
# 289                       num_concentrators_MRKT                    135
# 290                       num_concentrators_STEM                    135
# 291                       num_concentrators_TRAN                    135
# 292                              num_credentials                    168
# 293                              num_enrollments                    168
# 294                              cred_earned_pct                    168
# 295                                  career_only                    104
# 296                   career_college_college_unc                    104
# 297                     college_college_unc_only                    104
# 298                                 college_only                    104
# 299                                   stu_enroll                     28
# 300                                   cte_enroll                     28
# 301                           cte_enrollment_pct                     28
# 302                       Book_TitlesPer_Student                    144
# 303                                          wap                     23
# 304                                    wap_class                     23
# 305                                 media_school                    130
# 306                                      devices                      3
# 307                   pct_rating_T1_Accomplished                     26
# 308                  pct_rating_T1_Distinguished                    130
# 309                     pct_rating_T1_Proficient                     55
# 310                   pct_rating_T2_Accomplished                     32
# 311                  pct_rating_T2_Distinguished                    232
# 312                     pct_rating_T2_Proficient                     80
# 313                   pct_rating_T3_Accomplished                     38
# 314                  pct_rating_T3_Distinguished                    265
# 315                     pct_rating_T3_Proficient                     81
# 316                   pct_rating_T4_Accomplished                     25
# 317                  pct_rating_T4_Distinguished                    203
# 318                     pct_rating_T4_Proficient                     59
# 319                   pct_rating_T5_Accomplished                     44
# 320                  pct_rating_T5_Distinguished                    265
# 321                     pct_rating_T5_Proficient                     61
# 322  pct_rating_TS_Does Not Meet Expected Growth                     51
# 323        pct_rating_TS_Exceeds Expected Growth                     51
# 324          pct_rating_TS_Meets Expected Growth                     51
# 325                   avg_class_teach_TeacherExp                      2
# 326                    pct_adv_degree_TeacherExp                      2
# 327                  pct_experience_0_TeacherExp                      2
# 328                 pct_experience_10_TeacherExp                      2
# 329                  pct_experience_4_TeacherExp                      2
# 330                      pct_turnover_TeacherExp                     15
# 331                         highqual_class_pct_H                    121
# 332                                        crime                     13
# 333                                   short_term                     13
# 334                                    long_term                     13
# 335                                    expulsion                     13
# 336                             arre_per1000_ALL                     35
# 337                             arre_per1000_BL7                     90
# 340                             arre_per1000_FEM                     56
# 341                             arre_per1000_HI7                    101
# 342                            arre_per1000_MALE                     47
# 343                             arre_per1000_MU7                    127
# 344                             arre_per1000_SWD                     25
# 345                             arre_per1000_WH7                     54
# 346                             blhr_per1000_ALL                     35
# 347                             blhr_per1000_BL7                     90
# 350                             blhr_per1000_FEM                     56
# 351                             blhr_per1000_HI7                    101
# 352                            blhr_per1000_MALE                     47
# 353                             blhr_per1000_MU7                    127
# 354                             blhr_per1000_SWD                     25
# 355                             blhr_per1000_WH7                     54
# 356                            crime_per1000_ALL                     35
# 357                            crime_per1000_BL7                     90
# 360                            crime_per1000_FEM                     56
# 361                            crime_per1000_HI7                    101
# 362                           crime_per1000_MALE                     47
# 363                            crime_per1000_MU7                    127
# 364                            crime_per1000_SWD                     25
# 365                            crime_per1000_WH7                     54
# 366                              exp_per1000_ALL                     35
# 367                              exp_per1000_BL7                    123
# 368                              exp_per1000_EDS                      7
# 369                              exp_per1000_ELS                    180
# 370                              exp_per1000_FEM                     63
# 371                              exp_per1000_HI7                    150
# 372                             exp_per1000_MALE                     50
# 373                              exp_per1000_MU7                    230
# 374                              exp_per1000_SWD                    123
# 375                              exp_per1000_WH7                     78
# 376                              iss_per1000_ALL                     35
# 377                              iss_per1000_BL7                    124
# 378                              iss_per1000_EDS                      7
# 379                              iss_per1000_ELS                    180
# 380                              iss_per1000_FEM                     63
# 381                              iss_per1000_HI7                    150
# 382                             iss_per1000_MALE                     50
# 383                              iss_per1000_MU7                    230
# 384                              iss_per1000_SWD                    123
# 385                              iss_per1000_WH7                     78
# 386                              lts_per1000_ALL                     35
# 387                              lts_per1000_BL7                    123
# 388                              lts_per1000_EDS                      7
# 389                              lts_per1000_ELS                    180
# 390                              lts_per1000_FEM                     63
# 391                              lts_per1000_HI7                    150
# 392                             lts_per1000_MALE                     50
# 393                              lts_per1000_MU7                    230
# 394                              lts_per1000_SWD                    123
# 395                              lts_per1000_WH7                     78
# 396                             rplw_per1000_ALL                     35
# 397                             rplw_per1000_BL7                     90
# 399                             rplw_per1000_FEM                     56
# 400                             rplw_per1000_HI7                    101
# 401                            rplw_per1000_MALE                     47
# 402                             rplw_per1000_MU7                    127
# 403                             rplw_per1000_SWD                     25
# 404                             rplw_per1000_WH7                     54
# 405                              sts_per1000_ALL                     35
# 406                              sts_per1000_BL7                    128
# 407                              sts_per1000_EDS                      7
# 408                              sts_per1000_ELS                    180
# 409                              sts_per1000_FEM                     65
# 410                              sts_per1000_HI7                    152
# 411                             sts_per1000_MALE                     55
# 412                              sts_per1000_MU7                    230
# 413                              sts_per1000_SWD                    125
# 414                              sts_per1000_WH7                     78
# 415                           pct_fully_licensed                      2
# 416                            pct_lateral_entry                      2
# 417                                    nbpts_num                      1
# 418                         avg_size_Biology_SAR                     48
# 419                      avg_size_English II_SAR                     54
# 420                          avg_size_Math I_SAR                     58
# 421                                avg_sat_score                    146
# 422                        pct_sat_participation                    146

# %%
#Replace all remaining NaN with 0
schoolData = schoolData.fillna(0)

#Check for Missing values after final imputation 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# Empty DataFrame
# Columns: [Variable Name, Number Missing Values]
# Index: []

# %% [markdown]
# ## Identify and Remove Highly Correlated Features
# **Find and remove any columns / features that are > 95% correlated**
# * https://stackoverflow.com/questions/39409866/correlation-heatmap
# * https://chrisalbon.com/machine_learning/feature_selection/drop_highly_correlated_features/
# * https://codeyarns.com/2015/04/20/how-to-change-font-size-in-seaborn/

# %%
# calculate the correlation matrix
corr_matrix  = schoolData.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
#Get all of the correlation values > 95%
x = np.where(upper > 0.95)

#Display all field combinations with > 95% correlation
cf = pd.DataFrame()
cf['Field1'] = upper.columns[x[1]]
cf['Field2'] = upper.index[x[0]]

#Get the correlation values for every field combination. (There must be a more pythonic way to do this!)
corr = [0] * len(cf)
for i in range(0, len(cf)):
    corr[i] =  upper[cf['Field1'][i]][cf['Field2'][i]] 
    
cf['Correlation'] = corr

print ('There are ', str(len(cf['Field1'])), ' field correlations > 95%.')
cf
# Out:
# There are  377  field correlations > 95%.
#                                 Field1                             Field2  \
# 0                        IndianMalePct                          IndianPct
# 1                      IndianFemalePct                          IndianPct
# 2                          MinorityPct                           WhitePct
# 3                    pct_ACALL_FEM_ACT                  pct_ACALL_ALL_ACT
# 4                   pct_ACALL_MALE_ACT                  pct_ACALL_ALL_ACT
# 5                     pct_ACEN_ALL_ACT                  pct_ACALL_ALL_ACT
# 6                     pct_ACMA_ALL_ACT                  pct_ACALL_ALL_ACT
# 7                     pct_ACRD_ALL_ACT                  pct_ACALL_ALL_ACT
# 8                     pct_ACSC_ALL_ACT                  pct_ACALL_ALL_ACT
# 9                     pct_ACEN_ALL_ACT                  pct_ACALL_FEM_ACT
# 10                    pct_ACRD_ALL_ACT                  pct_ACALL_FEM_ACT
# 11                    pct_ACRD_FEM_ACT                  pct_ACALL_FEM_ACT
# 12                    pct_ACMA_ALL_ACT                 pct_ACALL_MALE_ACT
# 13                    pct_ACRD_ALL_ACT                 pct_ACALL_MALE_ACT
# 14                    pct_ACEN_AIG_ACT                   pct_ACCO_AIG_ACT
# 15                    pct_ACEN_ALL_ACT                   pct_ACCO_ALL_ACT
# 16                    pct_ACEN_FEM_ACT                   pct_ACCO_FEM_ACT
# 17                   pct_ACEN_MALE_ACT                  pct_ACCO_MALE_ACT
# 18                    pct_ACEN_WH7_ACT                   pct_ACCO_WH7_ACT
# 19                    pct_ACMA_AIG_ACT                   pct_ACEN_AIG_ACT
# 20                    pct_ACRD_AIG_ACT                   pct_ACEN_AIG_ACT
# 21                    pct_ACRD_ALL_ACT                   pct_ACEN_ALL_ACT
# 22                    pct_ACRD_BL7_ACT                   pct_ACEN_BL7_ACT
# 23                    pct_ACRD_FEM_ACT                   pct_ACEN_FEM_ACT
# 24                   pct_ACRD_MALE_ACT                  pct_ACEN_MALE_ACT
# 25                    pct_ACRD_WH7_ACT                   pct_ACEN_WH7_ACT
# 26                    pct_ACRD_AIG_ACT                   pct_ACMA_AIG_ACT
# 27                    pct_ACSC_AIG_ACT                   pct_ACMA_AIG_ACT
# 28                    pct_ACMA_FEM_ACT                   pct_ACMA_ALL_ACT
# 29                    pct_ACSC_WH7_ACT                   pct_ACMA_WH7_ACT
# 30                    pct_ACSC_AIG_ACT                   pct_ACRD_AIG_ACT
# 31                    pct_ACSC_WH7_ACT                   pct_ACRD_WH7_ACT
# 32                    pct_ACWR_FEM_ACT                   pct_ACWR_ALL_ACT
# 33                         pct_AIG_MCR                        pct_AIG_AWA
# 34                     pct_STD_FEM_CGR                    pct_STD_ALL_CGR
# 35                         pct_ELS_ELP                        pct_ALL_ELP
# 36   pct_High School Math_ALL_PART_DET           pct_Biology_ALL_PART_DET
# 37            pct_The ACT_ALL_PART_DET           pct_Biology_ALL_PART_DET
# 38   pct_High School Math_BL7_PART_DET           pct_Biology_BL7_PART_DET
# 39            pct_The ACT_BL7_PART_DET           pct_Biology_BL7_PART_DET
# 40   pct_High School Math_EDS_PART_DET           pct_Biology_EDS_PART_DET
# 41            pct_The ACT_EDS_PART_DET           pct_Biology_EDS_PART_DET
# 42   pct_High School Math_WH7_PART_DET           pct_Biology_WH7_PART_DET
# 43            pct_The ACT_WH7_PART_DET           pct_Biology_WH7_PART_DET
# 44            pct_The ACT_ALL_PART_DET  pct_High School Math_ALL_PART_DET
# 45            pct_The ACT_BL7_PART_DET  pct_High School Math_BL7_PART_DET
# 46            pct_The ACT_EDS_PART_DET  pct_High School Math_EDS_PART_DET
# 47            pct_The ACT_WH7_PART_DET  pct_High School Math_WH7_PART_DET
# 48                          cgrs_score                          mcr_score
# 49                           spg_score                          ach_score
# 50                  ach_score_HI7_SPG2                 aaa_score_HI7_SPG2
# 51                  spg_score_HI7_SPG2                 aaa_score_HI7_SPG2
# 52                  spg_score_ALL_SPG2                 ach_score_ALL_SPG2
# 53                  spg_score_BL7_SPG2                 ach_score_BL7_SPG2
# 54                  spg_score_EDS_SPG2                 ach_score_EDS_SPG2
# 55                  spg_score_HI7_SPG2                 ach_score_HI7_SPG2
# 56                  spg_score_SWD_SPG2                 ach_score_SWD_SPG2
# 57                  spg_score_WH7_SPG2                 ach_score_WH7_SPG2
# 58                  mcr_score_WH7_SPG2                 awa_score_WH7_SPG2
# 59                          stu_enroll                    avg_student_num
# 60                          cte_enroll                    avg_student_num
# 61          avg_class_teach_TeacherExp                    avg_student_num
# 62               pct_MALE_CHRON_ABSENT               pct_ALL_CHRON_ABSENT
# 63                          cte_enroll                    num_enrollments
# 64                          cte_enroll                         stu_enroll
# 65          avg_class_teach_TeacherExp                         stu_enroll
# 66          avg_class_teach_TeacherExp                         cte_enroll
# 67                    arre_per1000_BL7                   arre_per1000_ALL
# 68                    grade_span_KG:13                   arre_per1000_ALL
# 69           subgroup_list_ALL,BL7,SWD                   arre_per1000_ALL
# 70                    arre_per1000_EDS                   arre_per1000_BL7
# 71                    arre_per1000_SWD                   arre_per1000_BL7
# 72                   blhr_per1000_MALE                   blhr_per1000_ALL
# 73                    grade_span_KG:13                  crime_per1000_ELS
# 74           subgroup_list_ALL,BL7,SWD                  crime_per1000_ELS
# 75                     exp_per1000_BL7                    exp_per1000_ALL
# 76                    exp_per1000_MALE                    exp_per1000_ALL
# 77                    exp_per1000_MALE                    exp_per1000_BL7
# 78                    iss_per1000_MALE                    iss_per1000_ALL
# 79                    county_Alexander                    lea_code_020LEA
# 80              agency_lea_code_020LEA                    lea_code_020LEA
# 81                    county_Alleghany                    lea_code_030LEA
# 82              agency_lea_code_030LEA                    lea_code_030LEA
# 83                        county_Anson                    lea_code_040LEA
# 84              agency_lea_code_040LEA                    lea_code_040LEA
# 85                         county_Ashe                    lea_code_050LEA
# 86              agency_lea_code_050LEA                    lea_code_050LEA
# 87                        county_Avery                    lea_code_060LEA
# 88              agency_lea_code_060LEA                    lea_code_060LEA
# 89                     county_Beaufort                    lea_code_070LEA
# 90              agency_lea_code_070LEA                    lea_code_070LEA
# 91                       county_Bertie                    lea_code_080LEA
# 92              agency_lea_code_080LEA                    lea_code_080LEA
# 93                       county_Bladen                    lea_code_090LEA
# 94              agency_lea_code_090LEA                    lea_code_090LEA
# 95                    county_Brunswick                    lea_code_100LEA
# 96              agency_lea_code_100LEA                    lea_code_100LEA
# 97              agency_lea_code_110LEA                    lea_code_110LEA
# 98              agency_lea_code_111LEA                    lea_code_111LEA
# 99                        county_Burke                    lea_code_120LEA
# 100             agency_lea_code_120LEA                    lea_code_120LEA
# 101                    county_Cabarrus                    lea_code_130LEA
# 102             agency_lea_code_130LEA                    lea_code_130LEA
# 103             agency_lea_code_132LEA                    lea_code_132LEA
# 104                    county_Caldwell                    lea_code_140LEA
# 105             agency_lea_code_140LEA                    lea_code_140LEA
# 106                      county_Camden                    lea_code_150LEA
# 107             agency_lea_code_150LEA                    lea_code_150LEA
# 108                    county_Carteret                    lea_code_160LEA
# 109             agency_lea_code_160LEA                    lea_code_160LEA
# 110                     county_Caswell                    lea_code_170LEA
# 111             agency_lea_code_170LEA                    lea_code_170LEA
# 112             agency_lea_code_180LEA                    lea_code_180LEA
# 113             agency_lea_code_181LEA                    lea_code_181LEA
# 114             agency_lea_code_182LEA                    lea_code_182LEA
# 115                     county_Chatham                    lea_code_190LEA
# 116             agency_lea_code_190LEA                    lea_code_190LEA
# 117                    county_Cherokee                    lea_code_200LEA
# 118             agency_lea_code_200LEA                    lea_code_200LEA
# 119                      county_Chowan                    lea_code_210LEA
# 120             agency_lea_code_210LEA                    lea_code_210LEA
# 121                        county_Clay                    lea_code_220LEA
# 122             agency_lea_code_220LEA                    lea_code_220LEA
# 123                   county_Cleveland                    lea_code_230LEA
# 124             agency_lea_code_230LEA                    lea_code_230LEA
# 125             agency_lea_code_240LEA                    lea_code_240LEA
# 126             agency_lea_code_241LEA                    lea_code_241LEA
# 127                      county_Craven                    lea_code_250LEA
# 128             agency_lea_code_250LEA                    lea_code_250LEA
# 129                  county_Cumberland                    lea_code_260LEA
# 130             agency_lea_code_260LEA                    lea_code_260LEA
# 131                   county_Currituck                    lea_code_270LEA
# 132             agency_lea_code_270LEA                    lea_code_270LEA
# 133                        county_Dare                    lea_code_280LEA
# 134             agency_lea_code_280LEA                    lea_code_280LEA
# 135             agency_lea_code_290LEA                    lea_code_290LEA
# 136             agency_lea_code_291LEA                    lea_code_291LEA
# 137             agency_lea_code_292LEA                    lea_code_292LEA
# 138                       county_Davie                    lea_code_300LEA
# 139             agency_lea_code_300LEA                    lea_code_300LEA
# 140                      county_Duplin                    lea_code_310LEA
# 141             agency_lea_code_310LEA                    lea_code_310LEA
# 142                      county_Durham                    lea_code_320LEA
# 143             agency_lea_code_320LEA                    lea_code_320LEA
# 144                   county_Edgecombe                    lea_code_330LEA
# 145             agency_lea_code_330LEA                    lea_code_330LEA
# 146                     county_Forsyth                    lea_code_340LEA
# 147             agency_lea_code_340LEA                    lea_code_340LEA
# 148                    county_Franklin                    lea_code_350LEA
# 149             agency_lea_code_350LEA                    lea_code_350LEA
# 150                      county_Gaston                    lea_code_360LEA
# 151             agency_lea_code_360LEA                    lea_code_360LEA
# 152                       county_Gates                    lea_code_370LEA
# 153             agency_lea_code_370LEA                    lea_code_370LEA
# 154                      county_Graham                    lea_code_380LEA
# 155             agency_lea_code_380LEA                    lea_code_380LEA
# 156                   county_Granville                    lea_code_390LEA
# 157             agency_lea_code_390LEA                    lea_code_390LEA
# 158                      county_Greene                    lea_code_400LEA
# 159             agency_lea_code_400LEA                    lea_code_400LEA
# 160                    county_Guilford                    lea_code_410LEA
# 161             agency_lea_code_410LEA                    lea_code_410LEA
# 162             agency_lea_code_420LEA                    lea_code_420LEA
# 163             agency_lea_code_421LEA                    lea_code_421LEA
# 164             agency_lea_code_422LEA                    lea_code_422LEA
# 165                     county_Harnett                    lea_code_430LEA
# 166             agency_lea_code_430LEA                    lea_code_430LEA
# 167                     county_Haywood                    lea_code_440LEA
# 168             agency_lea_code_440LEA                    lea_code_440LEA
# 169                   county_Henderson                    lea_code_450LEA
# 170             agency_lea_code_450LEA                    lea_code_450LEA
# 171                    county_Hertford                    lea_code_460LEA
# 172             agency_lea_code_460LEA                    lea_code_460LEA
# 173                        county_Hoke                    lea_code_470LEA
# 174             agency_lea_code_470LEA                    lea_code_470LEA
# 175                        county_Hyde                    lea_code_480LEA
# 176             agency_lea_code_480LEA                    lea_code_480LEA
# 177                     county_Iredell                    lea_code_490LEA
# 178             agency_lea_code_490LEA                    lea_code_490LEA
# 179             agency_lea_code_491LEA                    lea_code_491LEA
# 180                     county_Jackson                    lea_code_500LEA
# 181             agency_lea_code_500LEA                    lea_code_500LEA
# 182                    county_Johnston                    lea_code_510LEA
# 183             agency_lea_code_510LEA                    lea_code_510LEA
# 184                       county_Jones                    lea_code_520LEA
# 185             agency_lea_code_520LEA                    lea_code_520LEA
# 186                         county_Lee                    lea_code_530LEA
# 187             agency_lea_code_530LEA                    lea_code_530LEA
# 188                      county_Lenoir                    lea_code_540LEA
# 189             agency_lea_code_540LEA                    lea_code_540LEA
# 190                     county_Lincoln                    lea_code_550LEA
# 191             agency_lea_code_550LEA                    lea_code_550LEA
# 192                       county_Macon                    lea_code_560LEA
# 193             agency_lea_code_560LEA                    lea_code_560LEA
# 194                     county_Madison                    lea_code_570LEA
# 195             agency_lea_code_570LEA                    lea_code_570LEA
# 196                      county_Martin                    lea_code_580LEA
# 197             agency_lea_code_580LEA                    lea_code_580LEA
# 198                    county_McDowell                    lea_code_590LEA
# 199             agency_lea_code_590LEA                    lea_code_590LEA
# 200                 county_Mecklenburg                    lea_code_600LEA
# 201             agency_lea_code_600LEA                    lea_code_600LEA
# 202                    county_Mitchell                    lea_code_610LEA
# 203             agency_lea_code_610LEA                    lea_code_610LEA
# 204                  county_Montgomery                    lea_code_620LEA
# 205             agency_lea_code_620LEA                    lea_code_620LEA
# 206                       county_Moore                    lea_code_630LEA
# 207             agency_lea_code_630LEA                    lea_code_630LEA
# 208                        county_Nash                    lea_code_640LEA
# 209             agency_lea_code_640LEA                    lea_code_640LEA
# 210                 county_New Hanover                    lea_code_650LEA
# 211             agency_lea_code_650LEA                    lea_code_650LEA
# 212                 county_Northampton                    lea_code_660LEA
# 213             agency_lea_code_660LEA                    lea_code_660LEA
# 214                      county_Onslow                    lea_code_670LEA
# 215             agency_lea_code_670LEA                    lea_code_670LEA
# 216             agency_lea_code_680LEA                    lea_code_680LEA
# 217             agency_lea_code_681LEA                    lea_code_681LEA
# 218                     county_Pamlico                    lea_code_690LEA
# 219             agency_lea_code_690LEA                    lea_code_690LEA
# 220                  county_Pasquotank                    lea_code_700LEA
# 221             agency_lea_code_700LEA                    lea_code_700LEA
# 222                      county_Pender                    lea_code_710LEA
# 223             agency_lea_code_710LEA                    lea_code_710LEA
# 224                  county_Perquimans                    lea_code_720LEA
# 225             agency_lea_code_720LEA                    lea_code_720LEA
# 226                      county_Person                    lea_code_730LEA
# 227             agency_lea_code_730LEA                    lea_code_730LEA
# 228                        county_Pitt                    lea_code_740LEA
# 229             agency_lea_code_740LEA                    lea_code_740LEA
# 230                        county_Polk                    lea_code_750LEA
# 231             agency_lea_code_750LEA                    lea_code_750LEA
# 232             agency_lea_code_760LEA                    lea_code_760LEA
# 233             agency_lea_code_761LEA                    lea_code_761LEA
# 234                    county_Richmond                    lea_code_770LEA
# 235             agency_lea_code_770LEA                    lea_code_770LEA
# 236                     county_Robeson                    lea_code_780LEA
# 237             agency_lea_code_780LEA                    lea_code_780LEA
# 238                  county_Rockingham                    lea_code_790LEA
# 239             agency_lea_code_790LEA                    lea_code_790LEA
# 240                       county_Rowan                    lea_code_800LEA
# 241             agency_lea_code_800LEA                    lea_code_800LEA
# 242                  county_Rutherford                    lea_code_810LEA
# 243             agency_lea_code_810LEA                    lea_code_810LEA
# 244             agency_lea_code_820LEA                    lea_code_820LEA
# 245             agency_lea_code_821LEA                    lea_code_821LEA
# 246                    county_Scotland                    lea_code_830LEA
# 247             agency_lea_code_830LEA                    lea_code_830LEA
# 248                      county_Stanly                    lea_code_840LEA
# 249             agency_lea_code_840LEA                    lea_code_840LEA
# 250                      county_Stokes                    lea_code_850LEA
# 251             agency_lea_code_850LEA                    lea_code_850LEA
# 252             agency_lea_code_860LEA                    lea_code_860LEA
# 253             agency_lea_code_861LEA                    lea_code_861LEA
# 254             agency_lea_code_862LEA                    lea_code_862LEA
# 255                       county_Swain                    lea_code_870LEA
# 256      subgroup_list_ALL,AM7,EDS,WH7                    lea_code_870LEA
# 257             agency_lea_code_870LEA                    lea_code_870LEA
# 258                county_Transylvania                    lea_code_880LEA
# 259             agency_lea_code_880LEA                    lea_code_880LEA
# 260                     county_Tyrrell                    lea_code_890LEA
# 261             agency_lea_code_890LEA                    lea_code_890LEA
# 262                       county_Union                    lea_code_900LEA
# 263             agency_lea_code_900LEA                    lea_code_900LEA
# 264                       county_Vance                    lea_code_910LEA
# 265             agency_lea_code_910LEA                    lea_code_910LEA
# 266                        county_Wake                    lea_code_920LEA
# 267             agency_lea_code_920LEA                    lea_code_920LEA
# 268                      county_Warren                    lea_code_930LEA
# 269             agency_lea_code_930LEA                    lea_code_930LEA
# 270                  county_Washington                    lea_code_940LEA
# 271             agency_lea_code_940LEA                    lea_code_940LEA
# 272                     county_Watauga                    lea_code_950LEA
# 273             agency_lea_code_950LEA                    lea_code_950LEA
# 274                       county_Wayne                    lea_code_960LEA
# 275             agency_lea_code_960LEA                    lea_code_960LEA
# 276                      county_Wilkes                    lea_code_970LEA
# 277             agency_lea_code_970LEA                    lea_code_970LEA
# 278                      county_Wilson                    lea_code_980LEA
# 279             agency_lea_code_980LEA                    lea_code_980LEA
# 280                      county_Yadkin                    lea_code_990LEA
# 281             agency_lea_code_990LEA                    lea_code_990LEA
# 282                      county_Yancey                    lea_code_995LEA
# 283             agency_lea_code_995LEA                    lea_code_995LEA
# 284             agency_lea_code_020LEA                   county_Alexander
# 285             agency_lea_code_030LEA                   county_Alleghany
# 286             agency_lea_code_040LEA                       county_Anson
# 287             agency_lea_code_050LEA                        county_Ashe
# 288             agency_lea_code_060LEA                       county_Avery
# 289             agency_lea_code_070LEA                    county_Beaufort
# 290             agency_lea_code_080LEA                      county_Bertie
# 291             agency_lea_code_090LEA                      county_Bladen
# 292             agency_lea_code_100LEA                   county_Brunswick
# 293             agency_lea_code_120LEA                       county_Burke
# 294             agency_lea_code_130LEA                    county_Cabarrus
# 295             agency_lea_code_140LEA                    county_Caldwell
# 296             agency_lea_code_150LEA                      county_Camden
# 297             agency_lea_code_160LEA                    county_Carteret
# 298             agency_lea_code_170LEA                     county_Caswell
# 299             agency_lea_code_190LEA                     county_Chatham
# 300             agency_lea_code_200LEA                    county_Cherokee
# 301             agency_lea_code_210LEA                      county_Chowan
# 302             agency_lea_code_220LEA                        county_Clay
# 303             agency_lea_code_230LEA                   county_Cleveland
# 304             agency_lea_code_250LEA                      county_Craven
# 305             agency_lea_code_260LEA                  county_Cumberland
# 306             agency_lea_code_270LEA                   county_Currituck
# 307             agency_lea_code_280LEA                        county_Dare
# 308             agency_lea_code_300LEA                       county_Davie
# 309             agency_lea_code_310LEA                      county_Duplin
# 310             agency_lea_code_320LEA                      county_Durham
# 311             agency_lea_code_330LEA                   county_Edgecombe
# 312             agency_lea_code_340LEA                     county_Forsyth
# 313             agency_lea_code_350LEA                    county_Franklin
# 314             agency_lea_code_360LEA                      county_Gaston
# 315             agency_lea_code_370LEA                       county_Gates
# 316             agency_lea_code_380LEA                      county_Graham
# 317             agency_lea_code_390LEA                   county_Granville
# 318             agency_lea_code_400LEA                      county_Greene
# 319             agency_lea_code_410LEA                    county_Guilford
# 320             agency_lea_code_430LEA                     county_Harnett
# 321             agency_lea_code_440LEA                     county_Haywood
# 322             agency_lea_code_450LEA                   county_Henderson
# 323             agency_lea_code_460LEA                    county_Hertford
# 324             agency_lea_code_470LEA                        county_Hoke
# 325             agency_lea_code_480LEA                        county_Hyde
# 326             agency_lea_code_490LEA                     county_Iredell
# 327             agency_lea_code_500LEA                     county_Jackson
# 328             agency_lea_code_510LEA                    county_Johnston
# 329             agency_lea_code_520LEA                       county_Jones
# 330             agency_lea_code_530LEA                         county_Lee
# 331             agency_lea_code_540LEA                      county_Lenoir
# 332             agency_lea_code_550LEA                     county_Lincoln
# 333             agency_lea_code_560LEA                       county_Macon
# 334             agency_lea_code_570LEA                     county_Madison
# 335             agency_lea_code_580LEA                      county_Martin
# 336             agency_lea_code_590LEA                    county_McDowell
# 337             agency_lea_code_600LEA                 county_Mecklenburg
# 338             agency_lea_code_610LEA                    county_Mitchell
# 339             agency_lea_code_620LEA                  county_Montgomery
# 340             agency_lea_code_630LEA                       county_Moore
# 341             agency_lea_code_640LEA                        county_Nash
# 342             agency_lea_code_650LEA                 county_New Hanover
# 343             agency_lea_code_660LEA                 county_Northampton
# 344             agency_lea_code_670LEA                      county_Onslow
# 345             agency_lea_code_690LEA                     county_Pamlico
# 346             agency_lea_code_700LEA                  county_Pasquotank
# 347             agency_lea_code_710LEA                      county_Pender
# 348             agency_lea_code_720LEA                  county_Perquimans
# 349             agency_lea_code_730LEA                      county_Person
# 350             agency_lea_code_740LEA                        county_Pitt
# 351             agency_lea_code_750LEA                        county_Polk
# 352             agency_lea_code_770LEA                    county_Richmond
# 353             agency_lea_code_780LEA                     county_Robeson
# 354             agency_lea_code_790LEA                  county_Rockingham
# 355             agency_lea_code_800LEA                       county_Rowan
# 356             agency_lea_code_810LEA                  county_Rutherford
# 357             agency_lea_code_830LEA                    county_Scotland
# 358             agency_lea_code_840LEA                      county_Stanly
# 359             agency_lea_code_850LEA                      county_Stokes
# 360      subgroup_list_ALL,AM7,EDS,WH7                       county_Swain
# 361             agency_lea_code_870LEA                       county_Swain
# 362             agency_lea_code_880LEA                county_Transylvania
# 363             agency_lea_code_890LEA                     county_Tyrrell
# 364             agency_lea_code_900LEA                       county_Union
# 365             agency_lea_code_910LEA                       county_Vance
# 366             agency_lea_code_920LEA                        county_Wake
# 367             agency_lea_code_930LEA                      county_Warren
# 368             agency_lea_code_940LEA                  county_Washington
# 369             agency_lea_code_950LEA                     county_Watauga
# 370             agency_lea_code_960LEA                       county_Wayne
# 371             agency_lea_code_970LEA                      county_Wilkes
# 372             agency_lea_code_980LEA                      county_Wilson
# 373             agency_lea_code_990LEA                      county_Yadkin
# 374             agency_lea_code_995LEA                      county_Yancey
# 375          subgroup_list_ALL,BL7,SWD                   grade_span_KG:13
# 376             agency_lea_code_870LEA      subgroup_list_ALL,AM7,EDS,WH7
#
#      Correlation
# 0       0.985894
# 1       0.985582
# 2       1.000000
# 3       0.978277
# 4       0.973291
# 5       0.972780
# 6       0.967270
# 7       0.980994
# 8       0.966638
# 9       0.957022
# 10      0.961878
# 11      0.950357
# 12      0.951276
# 13      0.954390
# 14      0.978491
# 15      0.959114
# 16      0.952879
# 17      0.951499
# 18      0.961441
# 19      0.968235
# 20      0.971413
# 21      0.975587
# 22      0.950063
# 23      0.967495
# 24      0.958437
# 25      0.970010
# 26      0.962489
# 27      0.956610
# 28      0.959290
# 29      0.955274
# 30      0.964170
# 31      0.957972
# 32      0.959339
# 33      0.974690
# 34      0.958145
# 35      1.000000
# 36      0.999804
# 37      0.959247
# 38      0.999896
# 39      0.980951
# 40      0.999913
# 41      0.988517
# 42      0.999979
# 43      0.982792
# 44      0.957251
# 45      0.980248
# 46      0.987972
# 47      0.982751
# 48      0.983527
# 49      0.995735
# 50      0.971599
# 51      0.966874
# 52      0.996170
# 53      0.996857
# 54      0.995799
# 55      0.997355
# 56      0.979913
# 57      0.998740
# 58      0.966465
# 59      0.997524
# 60      0.962639
# 61      0.974022
# 62      0.981912
# 63      0.986833
# 64      0.965945
# 65      0.973279
# 66      0.950475
# 67      0.970859
# 68      0.971846
# 69      0.971846
# 70      0.950795
# 71      0.977087
# 72      0.963220
# 73      0.968659
# 74      0.968659
# 75      0.965188
# 76      0.999851
# 77      0.964937
# 78      0.951452
# 79      1.000000
# 80      1.000000
# 81      1.000000
# 82      1.000000
# 83      1.000000
# 84      1.000000
# 85      1.000000
# 86      1.000000
# 87      1.000000
# 88      1.000000
# 89      1.000000
# 90      1.000000
# 91      1.000000
# 92      1.000000
# 93      1.000000
# 94      1.000000
# 95      1.000000
# 96      1.000000
# 97      1.000000
# 98      1.000000
# 99      1.000000
# 100     1.000000
# 101     0.956618
# 102     1.000000
# 103     1.000000
# 104     1.000000
# 105     1.000000
# 106     1.000000
# 107     1.000000
# 108     1.000000
# 109     1.000000
# 110     1.000000
# 111     1.000000
# 112     1.000000
# 113     1.000000
# 114     1.000000
# 115     1.000000
# 116     1.000000
# 117     1.000000
# 118     1.000000
# 119     1.000000
# 120     1.000000
# 121     1.000000
# 122     1.000000
# 123     1.000000
# 124     1.000000
# 125     1.000000
# 126     1.000000
# 127     1.000000
# 128     1.000000
# 129     1.000000
# 130     1.000000
# 131     1.000000
# 132     1.000000
# 133     1.000000
# 134     1.000000
# 135     1.000000
# 136     1.000000
# 137     1.000000
# 138     1.000000
# 139     1.000000
# 140     1.000000
# 141     1.000000
# 142     1.000000
# 143     1.000000
# 144     1.000000
# 145     1.000000
# 146     1.000000
# 147     1.000000
# 148     1.000000
# 149     1.000000
# 150     1.000000
# 151     1.000000
# 152     1.000000
# 153     1.000000
# 154     1.000000
# 155     1.000000
# 156     1.000000
# 157     1.000000
# 158     1.000000
# 159     1.000000
# 160     1.000000
# 161     1.000000
# 162     1.000000
# 163     1.000000
# 164     1.000000
# 165     1.000000
# 166     1.000000
# 167     1.000000
# 168     1.000000
# 169     1.000000
# 170     1.000000
# 171     1.000000
# 172     1.000000
# 173     1.000000
# 174     1.000000
# 175     1.000000
# 176     1.000000
# 177     0.952658
# 178     1.000000
# 179     1.000000
# 180     1.000000
# 181     1.000000
# 182     1.000000
# 183     1.000000
# 184     1.000000
# 185     1.000000
# 186     1.000000
# 187     1.000000
# 188     1.000000
# 189     1.000000
# 190     1.000000
# 191     1.000000
# 192     1.000000
# 193     1.000000
# 194     1.000000
# 195     1.000000
# 196     1.000000
# 197     1.000000
# 198     1.000000
# 199     1.000000
# 200     1.000000
# 201     1.000000
# 202     1.000000
# 203     1.000000
# 204     1.000000
# 205     1.000000
# 206     1.000000
# 207     1.000000
# 208     1.000000
# 209     1.000000
# 210     1.000000
# 211     1.000000
# 212     1.000000
# 213     1.000000
# 214     1.000000
# 215     1.000000
# 216     1.000000
# 217     1.000000
# 218     1.000000
# 219     1.000000
# 220     1.000000
# 221     1.000000
# 222     1.000000
# 223     1.000000
# 224     1.000000
# 225     1.000000
# 226     1.000000
# 227     1.000000
# 228     1.000000
# 229     1.000000
# 230     1.000000
# 231     1.000000
# 232     1.000000
# 233     1.000000
# 234     1.000000
# 235     1.000000
# 236     1.000000
# 237     1.000000
# 238     1.000000
# 239     1.000000
# 240     1.000000
# 241     1.000000
# 242     1.000000
# 243     1.000000
# 244     1.000000
# 245     1.000000
# 246     1.000000
# 247     1.000000
# 248     1.000000
# 249     1.000000
# 250     1.000000
# 251     1.000000
# 252     1.000000
# 253     1.000000
# 254     1.000000
# 255     1.000000
# 256     1.000000
# 257     1.000000
# 258     1.000000
# 259     1.000000
# 260     1.000000
# 261     1.000000
# 262     1.000000
# 263     1.000000
# 264     1.000000
# 265     1.000000
# 266     1.000000
# 267     1.000000
# 268     1.000000
# 269     1.000000
# 270     1.000000
# 271     1.000000
# 272     1.000000
# 273     1.000000
# 274     1.000000
# 275     1.000000
# 276     1.000000
# 277     1.000000
# 278     1.000000
# 279     1.000000
# 280     1.000000
# 281     1.000000
# 282     1.000000
# 283     1.000000
# 284     1.000000
# 285     1.000000
# 286     1.000000
# 287     1.000000
# 288     1.000000
# 289     1.000000
# 290     1.000000
# 291     1.000000
# 292     1.000000
# 293     1.000000
# 294     0.956618
# 295     1.000000
# 296     1.000000
# 297     1.000000
# 298     1.000000
# 299     1.000000
# 300     1.000000
# 301     1.000000
# 302     1.000000
# 303     1.000000
# 304     1.000000
# 305     1.000000
# 306     1.000000
# 307     1.000000
# 308     1.000000
# 309     1.000000
# 310     1.000000
# 311     1.000000
# 312     1.000000
# 313     1.000000
# 314     1.000000
# 315     1.000000
# 316     1.000000
# 317     1.000000
# 318     1.000000
# 319     1.000000
# 320     1.000000
# 321     1.000000
# 322     1.000000
# 323     1.000000
# 324     1.000000
# 325     1.000000
# 326     0.952658
# 327     1.000000
# 328     1.000000
# 329     1.000000
# 330     1.000000
# 331     1.000000
# 332     1.000000
# 333     1.000000
# 334     1.000000
# 335     1.000000
# 336     1.000000
# 337     1.000000
# 338     1.000000
# 339     1.000000
# 340     1.000000
# 341     1.000000
# 342     1.000000
# 343     1.000000
# 344     1.000000
# 345     1.000000
# 346     1.000000
# 347     1.000000
# 348     1.000000
# 349     1.000000
# 350     1.000000
# 351     1.000000
# 352     1.000000
# 353     1.000000
# 354     1.000000
# 355     1.000000
# 356     1.000000
# 357     1.000000
# 358     1.000000
# 359     1.000000
# 360     1.000000
# 361     1.000000
# 362     1.000000
# 363     1.000000
# 364     1.000000
# 365     1.000000
# 366     1.000000
# 367     1.000000
# 368     1.000000
# 369     1.000000
# 370     1.000000
# 371     1.000000
# 372     1.000000
# 373     1.000000
# 374     1.000000
# 375     1.000000
# 376     1.000000

# %%
#The old way
#print('Dropping the following ', str(len(to_drop)), ' highly correlated fields.')
#to_drop

# Comparing highly correlated unique field names in field 1 vs field 2 list above will allow you to 
# remove the least amount of fields possible.  
#len(cf['Field1'].unique())
#len(cf['Field2'].unique())

print('Dropping the following ', str(len(cf['Field2'].unique())), ' highly correlated, unique fields.')
cf['Field2'].unique()
# Out:
# Dropping the following  261  highly correlated, unique fields.
# array(['IndianPct', 'WhitePct', 'pct_ACALL_ALL_ACT', 'pct_ACALL_FEM_ACT',
#        'pct_ACALL_MALE_ACT', 'pct_ACCO_AIG_ACT', 'pct_ACCO_ALL_ACT',
#        'pct_ACCO_FEM_ACT', 'pct_ACCO_MALE_ACT', 'pct_ACCO_WH7_ACT',
#        'pct_ACEN_AIG_ACT', 'pct_ACEN_ALL_ACT', 'pct_ACEN_BL7_ACT',
#        'pct_ACEN_FEM_ACT', 'pct_ACEN_MALE_ACT', 'pct_ACEN_WH7_ACT',
#        'pct_ACMA_AIG_ACT', 'pct_ACMA_ALL_ACT', 'pct_ACMA_WH7_ACT',
#        'pct_ACRD_AIG_ACT', 'pct_ACRD_WH7_ACT', 'pct_ACWR_ALL_ACT',
#        'pct_AIG_AWA', 'pct_STD_ALL_CGR', 'pct_ALL_ELP',
#        'pct_Biology_ALL_PART_DET', 'pct_Biology_BL7_PART_DET',
#        'pct_Biology_EDS_PART_DET', 'pct_Biology_WH7_PART_DET',
#        'pct_High School Math_ALL_PART_DET',
#        'pct_High School Math_BL7_PART_DET',
#        'pct_High School Math_EDS_PART_DET',
#        'pct_High School Math_WH7_PART_DET', 'mcr_score', 'ach_score',
#        'aaa_score_HI7_SPG2', 'ach_score_ALL_SPG2', 'ach_score_BL7_SPG2',
#        'ach_score_EDS_SPG2', 'ach_score_HI7_SPG2', 'ach_score_SWD_SPG2',
#        'ach_score_WH7_SPG2', 'awa_score_WH7_SPG2', 'avg_student_num',
#        'pct_ALL_CHRON_ABSENT', 'num_enrollments', 'stu_enroll',
#        'cte_enroll', 'arre_per1000_ALL', 'arre_per1000_BL7',
#        'blhr_per1000_ALL', 'crime_per1000_ELS', 'exp_per1000_ALL',
#        'exp_per1000_BL7', 'iss_per1000_ALL', 'lea_code_020LEA',
#        'lea_code_030LEA', 'lea_code_040LEA', 'lea_code_050LEA',
#        'lea_code_060LEA', 'lea_code_070LEA', 'lea_code_080LEA',
#        'lea_code_090LEA', 'lea_code_100LEA', 'lea_code_110LEA',
#        'lea_code_111LEA', 'lea_code_120LEA', 'lea_code_130LEA',
#        'lea_code_132LEA', 'lea_code_140LEA', 'lea_code_150LEA',
#        'lea_code_160LEA', 'lea_code_170LEA', 'lea_code_180LEA',
#        'lea_code_181LEA', 'lea_code_182LEA', 'lea_code_190LEA',
#        'lea_code_200LEA', 'lea_code_210LEA', 'lea_code_220LEA',
#        'lea_code_230LEA', 'lea_code_240LEA', 'lea_code_241LEA',
#        'lea_code_250LEA', 'lea_code_260LEA', 'lea_code_270LEA',
#        'lea_code_280LEA', 'lea_code_290LEA', 'lea_code_291LEA',
#        'lea_code_292LEA', 'lea_code_300LEA', 'lea_code_310LEA',
#        'lea_code_320LEA', 'lea_code_330LEA', 'lea_code_340LEA',
#        'lea_code_350LEA', 'lea_code_360LEA', 'lea_code_370LEA',
#        'lea_code_380LEA', 'lea_code_390LEA', 'lea_code_400LEA',
#        'lea_code_410LEA', 'lea_code_420LEA', 'lea_code_421LEA',
#        'lea_code_422LEA', 'lea_code_430LEA', 'lea_code_440LEA',
#        'lea_code_450LEA', 'lea_code_460LEA', 'lea_code_470LEA',
#        'lea_code_480LEA', 'lea_code_490LEA', 'lea_code_491LEA',
#        'lea_code_500LEA', 'lea_code_510LEA', 'lea_code_520LEA',
#        'lea_code_530LEA', 'lea_code_540LEA', 'lea_code_550LEA',
#        'lea_code_560LEA', 'lea_code_570LEA', 'lea_code_580LEA',
#        'lea_code_590LEA', 'lea_code_600LEA', 'lea_code_610LEA',
#        'lea_code_620LEA', 'lea_code_630LEA', 'lea_code_640LEA',
#        'lea_code_650LEA', 'lea_code_660LEA', 'lea_code_670LEA',
#        'lea_code_680LEA', 'lea_code_681LEA', 'lea_code_690LEA',
#        'lea_code_700LEA', 'lea_code_710LEA', 'lea_code_720LEA',
#        'lea_code_730LEA', 'lea_code_740LEA', 'lea_code_750LEA',
#        'lea_code_760LEA', 'lea_code_761LEA', 'lea_code_770LEA',
#        'lea_code_780LEA', 'lea_code_790LEA', 'lea_code_800LEA',
#        'lea_code_810LEA', 'lea_code_820LEA', 'lea_code_821LEA',
#        'lea_code_830LEA', 'lea_code_840LEA', 'lea_code_850LEA',
#        'lea_code_860LEA', 'lea_code_861LEA', 'lea_code_862LEA',
#        'lea_code_870LEA', 'lea_code_880LEA', 'lea_code_890LEA',
#        'lea_code_900LEA', 'lea_code_910LEA', 'lea_code_920LEA',
#        'lea_code_930LEA', 'lea_code_940LEA', 'lea_code_950LEA',
#        'lea_code_960LEA', 'lea_code_970LEA', 'lea_code_980LEA',
#        'lea_code_990LEA', 'lea_code_995LEA', 'county_Alexander',
#        'county_Alleghany', 'county_Anson', 'county_Ashe', 'county_Avery',
#        'county_Beaufort', 'county_Bertie', 'county_Bladen',
#        'county_Brunswick', 'county_Burke', 'county_Cabarrus',
#        'county_Caldwell', 'county_Camden', 'county_Carteret',
#        'county_Caswell', 'county_Chatham', 'county_Cherokee',
#        'county_Chowan', 'county_Clay', 'county_Cleveland',
#        'county_Craven', 'county_Cumberland', 'county_Currituck',
#        'county_Dare', 'county_Davie', 'county_Duplin', 'county_Durham',
#        'county_Edgecombe', 'county_Forsyth', 'county_Franklin',
#        'county_Gaston', 'county_Gates', 'county_Graham',
#        'county_Granville', 'county_Greene', 'county_Guilford',
#        'county_Harnett', 'county_Haywood', 'county_Henderson',
#        'county_Hertford', 'county_Hoke', 'county_Hyde', 'county_Iredell',
#        'county_Jackson', 'county_Johnston', 'county_Jones', 'county_Lee',
#        'county_Lenoir', 'county_Lincoln', 'county_Macon',
#        'county_Madison', 'county_Martin', 'county_McDowell',
#        'county_Mecklenburg', 'county_Mitchell', 'county_Montgomery',
#        'county_Moore', 'county_Nash', 'county_New Hanover',
#        'county_Northampton', 'county_Onslow', 'county_Pamlico',
#        'county_Pasquotank', 'county_Pender', 'county_Perquimans',
#        'county_Person', 'county_Pitt', 'county_Polk', 'county_Richmond',
#        'county_Robeson', 'county_Rockingham', 'county_Rowan',
#        'county_Rutherford', 'county_Scotland', 'county_Stanly',
#        'county_Stokes', 'county_Swain', 'county_Transylvania',
#        'county_Tyrrell', 'county_Union', 'county_Vance', 'county_Wake',
#        'county_Warren', 'county_Washington', 'county_Watauga',
#        'county_Wayne', 'county_Wilkes', 'county_Wilson', 'county_Yadkin',
#        'county_Yancey', 'grade_span_KG:13',
#        'subgroup_list_ALL,AM7,EDS,WH7'], dtype=object)

# %%
#Check columns before drop 
print('\r\n*********Before: Dropping Highly Correlated Fields*************************************')
schoolData.info(verbose=False)

# Drop the highly correlated features from our training data 
#schoolData = schoolData.drop(to_drop, axis=1)
schoolData = schoolData.drop(cf['Field2'], axis=1)

#Check columns after drop 
print('\r\n*********After: Dropping Highly Correlated Fields**************************************')
schoolData.info(verbose=False)
# Out:
# *********Before: Dropping Highly Correlated Fields*************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 603 entries, 2 to 678
# Columns: 899 entries, IndianPct to agency_lea_code_995LEA
# dtypes: float64(432), uint8(467)
# memory usage: 2.3 MB
#
# *********After: Dropping Highly Correlated Fields**************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 603 entries, 2 to 678
# Columns: 638 entries, AsianPct to agency_lea_code_995LEA
# dtypes: float64(377), uint8(261)
# memory usage: 1.9 MB

# %%
#Restore the unit_code before saving
schoolData['agency_code'] = agency_code
#Save the final dataset to a .csv file
schoolData.to_csv(outputDir + inputFileName + '_ML.csv', sep=',', index=False)

# %%
print('*********FINAL DATASET DETAILS*********************************************************\r\n')
schoolData.info(verbose=True)
# Out:
# *********FINAL DATASET DETAILS*********************************************************
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 603 entries, 2 to 678
# Data columns (total 639 columns):
# AsianPct                                                                                                            float64
# HispanicPct                                                                                                         float64
# BlackPct                                                                                                            float64
# PacificIslandPct                                                                                                    float64
# TwoOrMorePct                                                                                                        float64
# MinorityPct                                                                                                         float64
# IndianMalePct                                                                                                       float64
# AsianMalePct                                                                                                        float64
# HispanicMalePct                                                                                                     float64
# BlackMalePct                                                                                                        float64
# WhiteMalePct                                                                                                        float64
# PacificIslandMalePct                                                                                                float64
# TwoOrMoreMalePct                                                                                                    float64
# MinorityMalePct                                                                                                     float64
# IndianFemalePct                                                                                                     float64
# AsianFemalePct                                                                                                      float64
# HispanicFemalePct                                                                                                   float64
# BlackFemalePct                                                                                                      float64
# WhiteFemalePct                                                                                                      float64
# MinorityFemalePct                                                                                                   float64
# PacificIslandFemalePct                                                                                              float64
# TwoOrMoreFemalePct                                                                                                  float64
# ccc_pct_COMP1Y_ALL_161                                                                                              float64
# ccc_pct_COMP1Y_BL7_161                                                                                              float64
# ccc_pct_COMP1Y_EDS_161                                                                                              float64
# ccc_pct_COMP1Y_FEM_161                                                                                              float64
# ccc_pct_COMP1Y_MALE_161                                                                                             float64
# ccc_pct_COMP1Y_WH7_161                                                                                              float64
# ccc_pct_NOCOMP1Y_ALL_161                                                                                            float64
# ccc_pct_NOCOMP1Y_BL7_161                                                                                            float64
# ccc_pct_NOCOMP1Y_EDS_161                                                                                            float64
# ccc_pct_NOCOMP1Y_FEM_161                                                                                            float64
# ccc_pct_NOCOMP1Y_MALE_161                                                                                           float64
# ccc_pct_NOCOMP1Y_WH7_161                                                                                            float64
# ccc_pct_NOINFO_ALL_161                                                                                              float64
# ccc_pct_NOINFO_BL7_161                                                                                              float64
# ccc_pct_NOINFO_EDS_161                                                                                              float64
# ccc_pct_NOINFO_FEM_161                                                                                              float64
# ccc_pct_NOINFO_MALE_161                                                                                             float64
# ccc_pct_NOINFO_WH7_161                                                                                              float64
# pct_ACALL_AIG_ACT                                                                                                   float64
# pct_ACALL_AS7_ACT                                                                                                   float64
# pct_ACALL_BL7_ACT                                                                                                   float64
# pct_ACALL_EDS_ACT                                                                                                   float64
# pct_ACALL_ELS_ACT                                                                                                   float64
# pct_ACALL_HI7_ACT                                                                                                   float64
# pct_ACALL_MU7_ACT                                                                                                   float64
# pct_ACALL_SWD_ACT                                                                                                   float64
# pct_ACALL_WH7_ACT                                                                                                   float64
# pct_ACCO_BL7_ACT                                                                                                    float64
# pct_ACCO_EDS_ACT                                                                                                    float64
# pct_ACCO_HI7_ACT                                                                                                    float64
# pct_ACCO_SWD_ACT                                                                                                    float64
# pct_ACEN_EDS_ACT                                                                                                    float64
# pct_ACEN_HI7_ACT                                                                                                    float64
# pct_ACEN_SWD_ACT                                                                                                    float64
# pct_ACMA_BL7_ACT                                                                                                    float64
# pct_ACMA_EDS_ACT                                                                                                    float64
# pct_ACMA_FEM_ACT                                                                                                    float64
# pct_ACMA_HI7_ACT                                                                                                    float64
# pct_ACMA_MALE_ACT                                                                                                   float64
# pct_ACMA_SWD_ACT                                                                                                    float64
# pct_ACRD_ALL_ACT                                                                                                    float64
# pct_ACRD_BL7_ACT                                                                                                    float64
# pct_ACRD_EDS_ACT                                                                                                    float64
# pct_ACRD_FEM_ACT                                                                                                    float64
# pct_ACRD_HI7_ACT                                                                                                    float64
# pct_ACRD_MALE_ACT                                                                                                   float64
# pct_ACRD_SWD_ACT                                                                                                    float64
# pct_ACSC_AIG_ACT                                                                                                    float64
# pct_ACSC_ALL_ACT                                                                                                    float64
# pct_ACSC_BL7_ACT                                                                                                    float64
# pct_ACSC_EDS_ACT                                                                                                    float64
# pct_ACSC_FEM_ACT                                                                                                    float64
# pct_ACSC_HI7_ACT                                                                                                    float64
# pct_ACSC_MALE_ACT                                                                                                   float64
# pct_ACSC_SWD_ACT                                                                                                    float64
# pct_ACSC_WH7_ACT                                                                                                    float64
# pct_ACWR_AIG_ACT                                                                                                    float64
# pct_ACWR_BL7_ACT                                                                                                    float64
# pct_ACWR_EDS_ACT                                                                                                    float64
# pct_ACWR_FEM_ACT                                                                                                    float64
# pct_ACWR_HI7_ACT                                                                                                    float64
# pct_ACWR_MALE_ACT                                                                                                   float64
# pct_ACWR_SWD_ACT                                                                                                    float64
# pct_ACWR_WH7_ACT                                                                                                    float64
# pct_ALL_AWA                                                                                                         float64
# pct_BL7_AWA                                                                                                         float64
# pct_EDS_AWA                                                                                                         float64
# pct_FEM_AWA                                                                                                         float64
# pct_HI7_AWA                                                                                                         float64
# pct_MALE_AWA                                                                                                        float64
# pct_SWD_AWA                                                                                                         float64
# pct_WH7_AWA                                                                                                         float64
# pct_EXT_AIG_CGR                                                                                                     float64
# pct_EXT_ALL_CGR                                                                                                     float64
# pct_EXT_BL7_CGR                                                                                                     float64
# pct_EXT_EDS_CGR                                                                                                     float64
# pct_EXT_FEM_CGR                                                                                                     float64
# pct_EXT_HI7_CGR                                                                                                     float64
# pct_EXT_MALE_CGR                                                                                                    float64
# pct_EXT_SWD_CGR                                                                                                     float64
# pct_EXT_WH7_CGR                                                                                                     float64
# pct_STD_AIG_CGR                                                                                                     float64
# pct_STD_BL7_CGR                                                                                                     float64
# pct_STD_EDS_CGR                                                                                                     float64
# pct_STD_FEM_CGR                                                                                                     float64
# pct_STD_HI7_CGR                                                                                                     float64
# pct_STD_MALE_CGR                                                                                                    float64
# pct_STD_SWD_CGR                                                                                                     float64
# pct_STD_WH7_CGR                                                                                                     float64
# pct_eds                                                                                                             float64
# pct_EDS_ELP                                                                                                         float64
# pct_ELS_ELP                                                                                                         float64
# pct_HI7_ELP                                                                                                         float64
# pct_MALE_ELP                                                                                                        float64
# pct_prof_9gr_irm                                                                                                    float64
# pct_met_4 Year Graduation Rate_LTG                                                                                  float64
# pct_met_Math Grade 11_LTG                                                                                           float64
# pct_met_Reading Grade 10_LTG                                                                                        float64
# pct_met_Total Targets_LTG                                                                                           float64
# pct_AIG_MCR                                                                                                         float64
# pct_ALL_MCR                                                                                                         float64
# pct_BL7_MCR                                                                                                         float64
# pct_EDS_MCR                                                                                                         float64
# pct_FEM_MCR                                                                                                         float64
# pct_HI7_MCR                                                                                                         float64
# pct_MALE_MCR                                                                                                        float64
# pct_SWD_MCR                                                                                                         float64
# pct_WH7_MCR                                                                                                         float64
# pct_met_ACT WorkKeys_PART                                                                                           float64
# pct_met_Biology_PART                                                                                                float64
# pct_met_English II_PART                                                                                             float64
# pct_met_High School Math_PART                                                                                       float64
# pct_met_The ACT_PART                                                                                                float64
# pct_met_Total Targets_PART                                                                                          float64
# pct_ACT WorkKeys_ALL_PART_DET                                                                                       float64
# pct_ACT WorkKeys_WH7_PART_DET                                                                                       float64
# pct_English II_ALL_PART_DET                                                                                         float64
# pct_English II_BL7_PART_DET                                                                                         float64
# pct_English II_EDS_PART_DET                                                                                         float64
# pct_English II_WH7_PART_DET                                                                                         float64
# pct_The ACT_ALL_PART_DET                                                                                            float64
# pct_The ACT_BL7_PART_DET                                                                                            float64
# pct_The ACT_EDS_PART_DET                                                                                            float64
# pct_The ACT_WH7_PART_DET                                                                                            float64
# m1_score                                                                                                            float64
# e2_score                                                                                                            float64
# bi_score                                                                                                            float64
# act_score                                                                                                           float64
# wk_score                                                                                                            float64
# cgrs_score                                                                                                          float64
# eg_score                                                                                                            float64
# spg_score                                                                                                           float64
# aaa_score_ALL_SPG2                                                                                                  float64
# aaa_score_BL7_SPG2                                                                                                  float64
# aaa_score_EDS_SPG2                                                                                                  float64
# aaa_score_SWD_SPG2                                                                                                  float64
# aaa_score_WH7_SPG2                                                                                                  float64
# awa_score_ALL_SPG2                                                                                                  float64
# awa_score_EDS_SPG2                                                                                                  float64
# bi_score_ALL_SPG2                                                                                                   float64
# bi_score_BL7_SPG2                                                                                                   float64
# bi_score_EDS_SPG2                                                                                                   float64
# bi_score_WH7_SPG2                                                                                                   float64
# cgrs_score_ALL_SPG2                                                                                                 float64
# cgrs_score_BL7_SPG2                                                                                                 float64
# cgrs_score_EDS_SPG2                                                                                                 float64
# cgrs_score_WH7_SPG2                                                                                                 float64
# eg_score_ALL_SPG2                                                                                                   float64
# eg_score_BL7_SPG2                                                                                                   float64
# eg_score_EDS_SPG2                                                                                                   float64
# eg_score_HI7_SPG2                                                                                                   float64
# eg_score_SWD_SPG2                                                                                                   float64
# eg_score_WH7_SPG2                                                                                                   float64
# mcr_score_ALL_SPG2                                                                                                  float64
# mcr_score_BL7_SPG2                                                                                                  float64
# mcr_score_EDS_SPG2                                                                                                  float64
# mcr_score_WH7_SPG2                                                                                                  float64
# spg_score_ALL_SPG2                                                                                                  float64
# spg_score_BL7_SPG2                                                                                                  float64
# spg_score_EDS_SPG2                                                                                                  float64
# spg_score_HI7_SPG2                                                                                                  float64
# spg_score_SWD_SPG2                                                                                                  float64
# spg_score_WH7_SPG2                                                                                                  float64
# pct_AIG_WK                                                                                                          float64
# pct_ALL_WK                                                                                                          float64
# pct_BL7_WK                                                                                                          float64
# pct_EDS_WK                                                                                                          float64
# pct_FEM_WK                                                                                                          float64
# pct_MALE_WK                                                                                                         float64
# pct_WH7_WK                                                                                                          float64
# pct_ap_pass                                                                                                         float64
# pct_ap_participation                                                                                                float64
# pct_att                                                                                                             float64
# pct_AS7_CHRON_ABSENT                                                                                                float64
# pct_BL7_CHRON_ABSENT                                                                                                float64
# pct_ELS_CHRON_ABSENT                                                                                                float64
# pct_FEM_CHRON_ABSENT                                                                                                float64
# pct_HI7_CHRON_ABSENT                                                                                                float64
# pct_MALE_CHRON_ABSENT                                                                                               float64
# pct_MU7_CHRON_ABSENT                                                                                                float64
# pct_SWD_CHRON_ABSENT                                                                                                float64
# pct_WH7_CHRON_ABSENT                                                                                                float64
# pct_enrolled_ENROLL_ALL_COLLEGE                                                                                     float64
# pct_enrolled_ENROLL_BL7_COLLEGE                                                                                     float64
# pct_enrolled_ENROLL_EDS_COLLEGE                                                                                     float64
# pct_enrolled_ENROLL_FEM_COLLEGE                                                                                     float64
# pct_enrolled_ENROLL_HI7_COLLEGE                                                                                     float64
# pct_enrolled_ENROLL_MALE_COLLEGE                                                                                    float64
# pct_enrolled_ENROLL_WH7_COLLEGE                                                                                     float64
# pct_spc_crs                                                                                                         float64
# pct_ap_ib_crs                                                                                                       float64
# pct_cte_crs                                                                                                         float64
# pct_univ_coll_crs                                                                                                   float64
# pct_ap_H_AS7_COURSES2                                                                                               float64
# pct_ap_H_BL7_COURSES2                                                                                               float64
# pct_ap_H_FEM_COURSES2                                                                                               float64
# pct_ap_H_HI7_COURSES2                                                                                               float64
# pct_ap_H_MALE_COURSES2                                                                                              float64
# pct_ap_H_MU7_COURSES2                                                                                               float64
# pct_ap_H_WH7_COURSES2                                                                                               float64
# pct_ccp_H_AM7_COURSES2                                                                                              float64
# pct_ccp_H_AS7_COURSES2                                                                                              float64
# pct_ccp_H_BL7_COURSES2                                                                                              float64
# pct_ccp_H_ELS_COURSES2                                                                                              float64
# pct_ccp_H_FEM_COURSES2                                                                                              float64
# pct_ccp_H_HI7_COURSES2                                                                                              float64
# pct_ccp_H_MALE_COURSES2                                                                                             float64
# pct_ccp_H_MU7_COURSES2                                                                                              float64
# pct_ccp_H_SWD_COURSES2                                                                                              float64
# pct_ccp_H_WH7_COURSES2                                                                                              float64
# num_concentrators_AAVC                                                                                              float64
# num_concentrators_AGNR                                                                                              float64
# num_concentrators_ARCH                                                                                              float64
# num_concentrators_BMA                                                                                               float64
# num_concentrators_EDUC                                                                                              float64
# num_concentrators_FINA                                                                                              float64
# num_concentrators_HLTH                                                                                              float64
# num_concentrators_HOSP                                                                                              float64
# num_concentrators_HUMA                                                                                              float64
# num_concentrators_INFO                                                                                              float64
# num_concentrators_LAW                                                                                               float64
# num_concentrators_MANU                                                                                              float64
# num_concentrators_MRKT                                                                                              float64
# num_concentrators_STEM                                                                                              float64
# num_concentrators_TRAN                                                                                              float64
# num_credentials                                                                                                     float64
# cred_earned_pct                                                                                                     float64
# career_only                                                                                                         float64
# career_college_college_unc                                                                                          float64
# college_college_unc_only                                                                                            float64
# college_only                                                                                                        float64
# cte_enrollment_pct                                                                                                  float64
# Book_TitlesPer_Student                                                                                              float64
# wap                                                                                                                 float64
# wap_class                                                                                                           float64
# media_school                                                                                                        float64
# devices                                                                                                             float64
# pct_rating_T1_Accomplished                                                                                          float64
# pct_rating_T1_Distinguished                                                                                         float64
# pct_rating_T1_Proficient                                                                                            float64
# pct_rating_T2_Accomplished                                                                                          float64
# pct_rating_T2_Distinguished                                                                                         float64
# pct_rating_T2_Proficient                                                                                            float64
# pct_rating_T3_Accomplished                                                                                          float64
# pct_rating_T3_Distinguished                                                                                         float64
# pct_rating_T3_Proficient                                                                                            float64
# pct_rating_T4_Accomplished                                                                                          float64
# pct_rating_T4_Distinguished                                                                                         float64
# pct_rating_T4_Proficient                                                                                            float64
# pct_rating_T5_Accomplished                                                                                          float64
# pct_rating_T5_Distinguished                                                                                         float64
# pct_rating_T5_Proficient                                                                                            float64
# pct_rating_TS_Does Not Meet Expected Growth                                                                         float64
# pct_rating_TS_Exceeds Expected Growth                                                                               float64
# pct_rating_TS_Meets Expected Growth                                                                                 float64
# avg_class_teach_TeacherExp                                                                                          float64
# pct_adv_degree_TeacherExp                                                                                           float64
# pct_experience_0_TeacherExp                                                                                         float64
# pct_experience_10_TeacherExp                                                                                        float64
# pct_experience_4_TeacherExp                                                                                         float64
# pct_turnover_TeacherExp                                                                                             float64
# highqual_class_pct_H                                                                                                float64
# crime                                                                                                               float64
# short_term                                                                                                          float64
# long_term                                                                                                           float64
# expulsion                                                                                                           float64
# arre_per1000_EDS                                                                                                    float64
# arre_per1000_ELS                                                                                                    float64
# arre_per1000_FEM                                                                                                    float64
# arre_per1000_HI7                                                                                                    float64
# arre_per1000_MALE                                                                                                   float64
# arre_per1000_MU7                                                                                                    float64
# arre_per1000_SWD                                                                                                    float64
# arre_per1000_WH7                                                                                                    float64
# blhr_per1000_BL7                                                                                                    float64
# blhr_per1000_EDS                                                                                                    float64
# blhr_per1000_ELS                                                                                                    float64
# blhr_per1000_FEM                                                                                                    float64
# blhr_per1000_HI7                                                                                                    float64
# blhr_per1000_MALE                                                                                                   float64
# blhr_per1000_MU7                                                                                                    float64
# blhr_per1000_SWD                                                                                                    float64
# blhr_per1000_WH7                                                                                                    float64
# crime_per1000_ALL                                                                                                   float64
# crime_per1000_BL7                                                                                                   float64
# crime_per1000_EDS                                                                                                   float64
# crime_per1000_FEM                                                                                                   float64
# crime_per1000_HI7                                                                                                   float64
# crime_per1000_MALE                                                                                                  float64
# crime_per1000_MU7                                                                                                   float64
# crime_per1000_SWD                                                                                                   float64
# crime_per1000_WH7                                                                                                   float64
# exp_per1000_EDS                                                                                                     float64
# exp_per1000_ELS                                                                                                     float64
# exp_per1000_FEM                                                                                                     float64
# exp_per1000_HI7                                                                                                     float64
# exp_per1000_MALE                                                                                                    float64
# exp_per1000_MU7                                                                                                     float64
# exp_per1000_SWD                                                                                                     float64
# exp_per1000_WH7                                                                                                     float64
# iss_per1000_BL7                                                                                                     float64
# iss_per1000_EDS                                                                                                     float64
# iss_per1000_ELS                                                                                                     float64
# iss_per1000_FEM                                                                                                     float64
# iss_per1000_HI7                                                                                                     float64
# iss_per1000_MALE                                                                                                    float64
# iss_per1000_MU7                                                                                                     float64
# iss_per1000_SWD                                                                                                     float64
# iss_per1000_WH7                                                                                                     float64
# lts_per1000_ALL                                                                                                     float64
# lts_per1000_BL7                                                                                                     float64
# lts_per1000_EDS                                                                                                     float64
# lts_per1000_ELS                                                                                                     float64
# lts_per1000_FEM                                                                                                     float64
# lts_per1000_HI7                                                                                                     float64
# lts_per1000_MALE                                                                                                    float64
# lts_per1000_MU7                                                                                                     float64
# lts_per1000_SWD                                                                                                     float64
# lts_per1000_WH7                                                                                                     float64
# rplw_per1000_ALL                                                                                                    float64
# rplw_per1000_BL7                                                                                                    float64
# rplw_per1000_EDS                                                                                                    float64
# rplw_per1000_FEM                                                                                                    float64
# rplw_per1000_HI7                                                                                                    float64
# rplw_per1000_MALE                                                                                                   float64
# rplw_per1000_MU7                                                                                                    float64
# rplw_per1000_SWD                                                                                                    float64
# rplw_per1000_WH7                                                                                                    float64
# sts_per1000_ALL                                                                                                     float64
# sts_per1000_BL7                                                                                                     float64
# sts_per1000_EDS                                                                                                     float64
# sts_per1000_ELS                                                                                                     float64
# sts_per1000_FEM                                                                                                     float64
# sts_per1000_HI7                                                                                                     float64
# sts_per1000_MALE                                                                                                    float64
# sts_per1000_MU7                                                                                                     float64
# sts_per1000_SWD                                                                                                     float64
# sts_per1000_WH7                                                                                                     float64
# pct_fully_licensed                                                                                                  float64
# pct_lateral_entry                                                                                                   float64
# nbpts_num                                                                                                           float64
# avg_size_Biology_SAR                                                                                                float64
# avg_size_English II_SAR                                                                                             float64
# avg_size_Math I_SAR                                                                                                 float64
# avg_sat_score                                                                                                       float64
# pct_sat_participation                                                                                               float64
# lea_total_expense                                                                                                   float64
# lea_pct_salary                                                                                                      float64
# lea_pct_benefits                                                                                                    float64
# lea_pct_services                                                                                                    float64
# lea_pct_supplies                                                                                                    float64
# lea_pct_instruct_equip                                                                                              float64
# lea_local_perpupil                                                                                                  float64
# lea_state_perpupil                                                                                                  float64
# lea_federal_perpupil                                                                                                float64
# category_code_H                                                                                                     uint8
# category_code_T                                                                                                     uint8
# county_Buncombe                                                                                                     uint8
# county_Catawba                                                                                                      uint8
# county_Columbus                                                                                                     uint8
# county_Davidson                                                                                                     uint8
# county_Halifax                                                                                                      uint8
# county_Orange                                                                                                       uint8
# ...
# digital_media_4                                                                                                     uint8
# digital_media_40                                                                                                    uint8
# digital_media_5                                                                                                     uint8
# digital_media_50                                                                                                    uint8
# digital_media_54                                                                                                    uint8
# digital_media_6                                                                                                     uint8
# digital_media_7                                                                                                     uint8
# digital_media_8                                                                                                     uint8
# digital_media_9                                                                                                     uint8
# device_access_Yes                                                                                                   uint8
# device_home_Yes                                                                                                     uint8
# BYOD_Neither                                                                                                        uint8
# BYOD_Staff                                                                                                          uint8
# BYOD_Students                                                                                                       uint8
# esea_att_Met                                                                                                        uint8
# agency_lea_code_020LEA                                                                                              uint8
# agency_lea_code_030LEA                                                                                              uint8
# agency_lea_code_040LEA                                                                                              uint8
# agency_lea_code_050LEA                                                                                              uint8
# agency_lea_code_060LEA                                                                                              uint8
# agency_lea_code_070LEA                                                                                              uint8
# agency_lea_code_080LEA                                                                                              uint8
# agency_lea_code_090LEA                                                                                              uint8
# agency_lea_code_100LEA                                                                                              uint8
# agency_lea_code_110LEA                                                                                              uint8
# agency_lea_code_111LEA                                                                                              uint8
# agency_lea_code_120LEA                                                                                              uint8
# agency_lea_code_130LEA                                                                                              uint8
# agency_lea_code_132LEA                                                                                              uint8
# agency_lea_code_140LEA                                                                                              uint8
# agency_lea_code_150LEA                                                                                              uint8
# agency_lea_code_160LEA                                                                                              uint8
# agency_lea_code_170LEA                                                                                              uint8
# agency_lea_code_180LEA                                                                                              uint8
# agency_lea_code_181LEA                                                                                              uint8
# agency_lea_code_182LEA                                                                                              uint8
# agency_lea_code_190LEA                                                                                              uint8
# agency_lea_code_200LEA                                                                                              uint8
# agency_lea_code_210LEA                                                                                              uint8
# agency_lea_code_220LEA                                                                                              uint8
# agency_lea_code_230LEA                                                                                              uint8
# agency_lea_code_240LEA                                                                                              uint8
# agency_lea_code_241LEA                                                                                              uint8
# agency_lea_code_250LEA                                                                                              uint8
# agency_lea_code_260LEA                                                                                              uint8
# agency_lea_code_270LEA                                                                                              uint8
# agency_lea_code_280LEA                                                                                              uint8
# agency_lea_code_290LEA                                                                                              uint8
# agency_lea_code_291LEA                                                                                              uint8
# agency_lea_code_292LEA                                                                                              uint8
# agency_lea_code_300LEA                                                                                              uint8
# agency_lea_code_310LEA                                                                                              uint8
# agency_lea_code_320LEA                                                                                              uint8
# agency_lea_code_330LEA                                                                                              uint8
# agency_lea_code_340LEA                                                                                              uint8
# agency_lea_code_350LEA                                                                                              uint8
# agency_lea_code_360LEA                                                                                              uint8
# agency_lea_code_370LEA                                                                                              uint8
# agency_lea_code_380LEA                                                                                              uint8
# agency_lea_code_390LEA                                                                                              uint8
# agency_lea_code_400LEA                                                                                              uint8
# agency_lea_code_410LEA                                                                                              uint8
# agency_lea_code_420LEA                                                                                              uint8
# agency_lea_code_421LEA                                                                                              uint8
# agency_lea_code_422LEA                                                                                              uint8
# agency_lea_code_430LEA                                                                                              uint8
# agency_lea_code_440LEA                                                                                              uint8
# agency_lea_code_450LEA                                                                                              uint8
# agency_lea_code_460LEA                                                                                              uint8
# agency_lea_code_470LEA                                                                                              uint8
# agency_lea_code_480LEA                                                                                              uint8
# agency_lea_code_490LEA                                                                                              uint8
# agency_lea_code_491LEA                                                                                              uint8
# agency_lea_code_500LEA                                                                                              uint8
# agency_lea_code_510LEA                                                                                              uint8
# agency_lea_code_520LEA                                                                                              uint8
# agency_lea_code_530LEA                                                                                              uint8
# agency_lea_code_540LEA                                                                                              uint8
# agency_lea_code_550LEA                                                                                              uint8
# agency_lea_code_560LEA                                                                                              uint8
# agency_lea_code_570LEA                                                                                              uint8
# agency_lea_code_580LEA                                                                                              uint8
# agency_lea_code_590LEA                                                                                              uint8
# agency_lea_code_600LEA                                                                                              uint8
# agency_lea_code_610LEA                                                                                              uint8
# agency_lea_code_620LEA                                                                                              uint8
# agency_lea_code_630LEA                                                                                              uint8
# agency_lea_code_640LEA                                                                                              uint8
# agency_lea_code_650LEA                                                                                              uint8
# agency_lea_code_660LEA                                                                                              uint8
# agency_lea_code_670LEA                                                                                              uint8
# agency_lea_code_680LEA                                                                                              uint8
# agency_lea_code_681LEA                                                                                              uint8
# agency_lea_code_690LEA                                                                                              uint8
# agency_lea_code_700LEA                                                                                              uint8
# agency_lea_code_710LEA                                                                                              uint8
# agency_lea_code_720LEA                                                                                              uint8
# agency_lea_code_730LEA                                                                                              uint8
# agency_lea_code_740LEA                                                                                              uint8
# agency_lea_code_750LEA                                                                                              uint8
# agency_lea_code_760LEA                                                                                              uint8
# agency_lea_code_761LEA                                                                                              uint8
# agency_lea_code_770LEA                                                                                              uint8
# agency_lea_code_780LEA                                                                                              uint8
# agency_lea_code_790LEA                                                                                              uint8
# agency_lea_code_800LEA                                                                                              uint8
# agency_lea_code_810LEA                                                                                              uint8
# agency_lea_code_820LEA                                                                                              uint8
# agency_lea_code_821LEA                                                                                              uint8
# agency_lea_code_830LEA                                                                                              uint8
# agency_lea_code_840LEA                                                                                              uint8
# agency_lea_code_850LEA                                                                                              uint8
# agency_lea_code_860LEA                                                                                              uint8
# agency_lea_code_861LEA                                                                                              uint8
# agency_lea_code_862LEA                                                                                              uint8
# agency_lea_code_870LEA                                                                                              uint8
# agency_lea_code_880LEA                                                                                              uint8
# agency_lea_code_890LEA                                                                                              uint8
# agency_lea_code_900LEA                                                                                              uint8
# agency_lea_code_910LEA                                                                                              uint8
# agency_lea_code_920LEA                                                                                              uint8
# agency_lea_code_930LEA                                                                                              uint8
# agency_lea_code_940LEA                                                                                              uint8
# agency_lea_code_950LEA                                                                                              uint8
# agency_lea_code_960LEA                                                                                              uint8
# agency_lea_code_970LEA                                                                                              uint8
# agency_lea_code_980LEA                                                                                              uint8
# agency_lea_code_990LEA                                                                                              uint8
# agency_lea_code_995LEA                                                                                              uint8
# agency_code                                                                                                         object
# dtypes: float64(377), object(1), uint8(261)
# memory usage: 1.9+ MB

# %%
import sklearn
import pandas as pd

print('Sklearn Version: ' + sklearn.__version__)
print('Pandas Version: ' + pd.__version__)
# Out:
# Sklearn Version: 0.20.3
# Pandas Version: 0.24.2

# %%
print('Output File Location:\r\n\r\n' + outputDir + inputFileName + '_ML.csv')
# Out:
# Output File Location:
#
# C:/Users/Jake/Documents/GitHub/EducationDataNC/2018/Machine Learning Datasets/PublicHighSchools2018_ML.csv
