# %% [markdown]
# # Create Public School Machine Learning Datasets
# ** This program creates all the _ML datasets in the NCEA repository.**
# * This notebook reads each School Dataset file located at \EducationDataNC\ *schoolYear* \School Datasets\ as input data.
# * Different school years are processed by changing the *schoolYear* parameter.
# * Different input / output files are processed / created by changing the *inputFileName* paramter in the cell below.
# * While a single program is used to create all the _ML datasets, one program copy per dataset is maintained in the repositiory so the dataset specific tranformation reports may be reviewed.
#
# **Datasets ending in ML are preprocessed for Machine Learning and go through the following transformations: **
# 1. Missing student body racial compositions are imputed using district averages.
# 2. Columns that have the same value in every single row are deleted.
# 3. Columns that have a unique value in every single row (all values are different) are deleted.
# 4. Empty columns (all values are NA or NULL) are deleted.
# 5. Numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# 6. Remaining numeric, non-race columns with missing values are imputed / populated with 0.  In many cases, schools are not reporting values when they are zero. However, mean imputation or some other more sophisticated strategy might be considered here.
# 7. Categorical / text based columns with > *uniqueThreshold* unique values are deleted.
# 8. All remaining categorical / text based columns are one-hot encoded.  In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# 9. Duplicated or highly similar columns with > 95% correlation are delelted.

# %%
#import required Libraries
import pandas as pd
import numpy as np
import os
import string

#**********************************************************************************
# Set the following variables before running this code!!!
#**********************************************************************************
#All raw data files are processed for the year below
schoolYear = 2018
rootDir = 'D:/BenepactLLC/Belk/NC_Report_Card_Data/2020/June 2020/'

#Location where copies of the raw data files will be read in from csv files.
dataDir = rootDir + str(schoolYear) + '/School Datasets/'

#Name of the file to be processed
#inputFileName = 'PublicSchools2018'
inputFileName = 'PublicHighSchools2018'
#inputFileName = 'PublicMiddleSchools2018'
#inputFileName = 'PublicElementarySchools2018'

#Input file being transformed for machine learning 
inputFile = dataDir + inputFileName + '.csv'

#Location where the new school datasets will be created.
outputDir = rootDir + str(schoolYear) + '/Machine Learning Datasets/'

#Missing Data Threshold (Per Column)
missingThreshold = 0.60

#Unique Value Threshold (Per Column)
#Delete Columns >  uniqueThreshold unique values prior to one-hot encoding. 
#(each unique value becomes a new column during one-hot encoding)
uniqueThreshold = 200

#Read in the School Data File
schoolData = pd.read_csv(inputFile, low_memory=False, dtype={'agency_code': object})
print('*********Start: Beginning Column and Row Counts********************************************')
schoolData.info(verbose=False)

#Select only public schools as charter schools are missing data for many columns.
schoolData = schoolData[(schoolData['designation_type'] == 'P') & (schoolData['avg_student_num'] > 0)]

print('\r\n*********After: Selecting Only Public School Campuses**********************************')
schoolData.info(verbose=False)

#Save primary key
agency_code = schoolData['agency_code']
#Convert zip code to string
schoolData['zip'] = schoolData['zip'].astype('object')
# Out:
# *********Start: Beginning Column and Row Counts********************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 679 entries, 0 to 678
# Columns: 5246 entries, agency_code to lea_federal_perpupil
# dtypes: float64(5194), object(52)
# memory usage: 27.2+ MB
#
# *********After: Selecting Only Public School Campuses**********************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 603 entries, 2 to 678
# Columns: 5246 entries, agency_code to lea_federal_perpupil
# dtypes: float64(5194), object(52)
# memory usage: 24.1+ MB

# %% [markdown]
# # Prepare Consolidated Dataset for Machine Learning
# **Below we perform operations on the entire dataset to remove columns and update row values that could cause problems during machine learning.**

# %% [markdown]
# ## Student Body Racial Composition Features
# **Impute / update missing Student Body Racial Composition Fields using mean imputation.**
# * When there are no racial composition percentages for a particular school campus / agency_code, fill in the missing values

# %%
#Get Student Body Racial Composition Fields
raceCompositionFields = schoolData.filter(regex='Indian|Asian|Hispanic|Black|White|PacificIsland|TwoOrMore|Minority')\
                                  .filter(regex='Pct').columns
    
rowsBefore = schoolData[raceCompositionFields].isnull().T.any().T.sum()

#Update missing race values with the district average when avaiable (No district averages for charter schools) 
schoolData[raceCompositionFields] = schoolData.groupby('lea_code')[raceCompositionFields]\
                                              .transform(lambda x: x.fillna(x.mean()))

    #Review dataset contents after Racial Composition Imputation
print('*********After: Updating Missing Racial Compostion Values****************************')   
rowsAfter = schoolData[raceCompositionFields].isnull().T.any().T.sum()
rowsUpdated = rowsBefore - rowsAfter
print('Rows Updated / Imputed: ', rowsUpdated) 
print('\r\nTotal Rows Missing Racial Compositions By District Code') 
schoolData['lea_code'][schoolData[raceCompositionFields].isnull().T.any().T].value_counts()
# Out:
# *********After: Updating Missing Racial Compostion Values****************************
# Rows Updated / Imputed:  0
#
# Total Rows Missing Racial Compositions By District Code
# Series([], Name: lea_code, dtype: int64)

# %% [markdown]
# ## Remove Columns with Problematic Data
# **Here we remove entire columns that could cause problems during machine learning.  The following operations are performed:**
# * Remove any columns that have the same value in every single row.
# * Remove any columns that have a unique value in every single row (all values are different).
# * Remove empty columns (all values are NA or NULL).

# %%
#Remove any fields that have the same value in all rows
UniqueValueCounts = schoolData.nunique(dropna=False)
SingleValueCols = UniqueValueCounts[UniqueValueCounts == 1].index
schoolData = schoolData.drop(SingleValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with the same value in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(SingleValueCols))
# Out:
# *********After: Removing columns with the same value in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 603 entries, 2 to 678
# Columns: 3134 entries, agency_code to lea_federal_perpupil
# dtypes: float64(3086), object(48)
# memory usage: 14.4+ MB
#
# Columns Deleted:  2112

# %%
#Remove any fields that have unique values in every row
schoolDataRecordCt = schoolData.shape[0]
UniqueValueCounts = schoolData.apply(pd.Series.nunique)
AllUniqueValueCols = UniqueValueCounts[UniqueValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(AllUniqueValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with unique values in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(AllUniqueValueCols))
# Out:
# *********After: Removing columns with unique values in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 603 entries, 2 to 678
# Columns: 3132 entries, category_code to lea_federal_perpupil
# dtypes: float64(3086), object(46)
# memory usage: 14.4+ MB
#
# Columns Deleted:  2

# %%
#Remove any empty fields (null values in every row)
schoolDataRecordCt = schoolData.shape[0]
NullValueCounts = schoolData.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with null / blank values in every row.*************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with null / blank values in every row.*************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 603 entries, 2 to 678
# Columns: 3132 entries, category_code to lea_federal_perpupil
# dtypes: float64(3086), object(46)
# memory usage: 14.4+ MB
#
# Columns Deleted:  0

# %% [markdown]
# ## Handle Other Missing Values Types
# * Here we eliminate any numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# * All remaining non-race, numeric column missing values are populated with 0.
# * In many cases, it seems that schools are not simply not reporting values when they are zero. However, mean imputation or some other strategy might be considered.

# %%
#Isolate continuous and categorical data types
#These are indexers into the schoolData dataframe and may be used similar to the schoolData dataframe 
sD_boolean = schoolData.loc[:, (schoolData.dtypes == bool) ]
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]
sD_continuous = schoolData.loc[:, (schoolData.dtypes != bool) & (schoolData.dtypes != object)]
print ("Boolean Columns: ", sD_boolean.shape[1])
print ("Nominal Columns: ", sD_nominal.shape[1])
print ("Continuous Columns: ", sD_continuous.shape[1])
print ("Columns Accounted for: ", sD_nominal.shape[1] + sD_continuous.shape[1] + sD_boolean.shape[1])
# Out:
# Boolean Columns:  0
# Nominal Columns:  46
# Continuous Columns:  3086
# Columns Accounted for:  3132

# %%
#Eliminate continuous columns with more than missingThreshold percentage of missing values
schoolDataRecordCt = sD_continuous.shape[0]
missingValueLimit = schoolDataRecordCt * missingThreshold
NullValueCounts = sD_continuous.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts >= missingValueLimit].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with >= missingThreshold % of missing values******')
schoolData.info(verbose=False)
print('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with >= missingThreshold % of missing values******
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 603 entries, 2 to 678
# Columns: 755 entries, category_code to lea_federal_perpupil
# dtypes: float64(709), object(46)
# memory usage: 3.5+ MB
#
# Columns Deleted:  2377

# %% [markdown]
# ## One-Hot Encoding of Categorical Variables
# **All categorical / string variables are converted to numberic variables via one hot encoding.  Each unique row value will become a new binary / numeric column in the dataset.**
# * All remaining categorical columns are one-hot encoded.
# * In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# * Prior to one-hot encoding, columns with > *uniqueThreshold* unique values are deleted.

# %%
#Delete categorical columns with > uniqueThreshold unique values 
#(Each unique value becomes a column during one-hot encoding)
oneHotUniqueValueCounts = schoolData[sD_nominal.columns].apply(lambda x: x.nunique())
oneHotUniqueValueCols = oneHotUniqueValueCounts[oneHotUniqueValueCounts >= uniqueThreshold].index
schoolData.drop(oneHotUniqueValueCols, axis=1, inplace=True) 

#Remove categorical columns which do not add value to machine learning
#Grades columns dropped since they all have indicator fields (device_access, device_home, BYOD)
#with less unique values to one-hot encode
schoolData.drop(['welcome_url','device_access_grades',
                 'device_home_grades','byod_grades'], axis=1, inplace=True) 

#Review dataset contents one hot high unique value drops
print('*********After: Removing columns with >= uniqueThreshold unique values***********')
schoolData.info(verbose=False)
print('\r\nColumns Deleted: ', len(oneHotUniqueValueCols))
print(oneHotUniqueValueCols)
print('Dropped Manually: welcome_url,device_access_grades,device_home_grades,byod_grades')
# Out:
# *********After: Removing columns with >= uniqueThreshold unique values***********
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 603 entries, 2 to 678
# Columns: 745 entries, category_code to lea_federal_perpupil
# dtypes: float64(709), object(36)
# memory usage: 3.4+ MB
#
# Columns Deleted:  6
# Index(['street_addr', 'city', 'zip', 'phone', 'url', 'school_name'], dtype='object')
# Dropped Manually: welcome_url,device_access_grades,device_home_grades,byod_grades

# %%
#Isolate remaining categorical variables
begColumnCt = len(schoolData.columns)
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]

#one hot encode categorical variables
schoolData = pd.get_dummies(data=schoolData, 
                       columns=sD_nominal.columns, drop_first=True)

#Determine change in column count
endColumnCt = len(schoolData.columns)
columnsAdded = endColumnCt - begColumnCt

#Review dataset contents one hot high unique value drops
print('Columns To One-Hot Encode: ', len(sD_nominal.columns))
print('\r\n*********After: Adding New Columns Via One-Hot Encoding*************************')
schoolData.info(verbose=False)
print('\r\nNew Columns Created Via One-Hot Encoding: ', columnsAdded)
# Out:
# Columns To One-Hot Encode:  36
#
# *********After: Adding New Columns Via One-Hot Encoding*************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 603 entries, 2 to 678
# Columns: 1290 entries, lea to agency_lea_code_995LEA
# dtypes: float64(709), uint8(581)
# memory usage: 3.6 MB
#
# New Columns Created Via One-Hot Encoding:  545

# %%
#Remove any fields that have the same value in all rows after one-hot encoding
UniqueValueCounts = schoolData.nunique(dropna=False)
SingleValueCols = UniqueValueCounts[UniqueValueCounts == 1].index
schoolData = schoolData.drop(SingleValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing one-hot encoded columns with the same value in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(SingleValueCols))
# Out:
# *********After: Removing one-hot encoded columns with the same value in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 603 entries, 2 to 678
# Columns: 1290 entries, lea to agency_lea_code_995LEA
# dtypes: float64(709), uint8(581)
# memory usage: 3.6 MB
#
# Columns Deleted:  0

# %% [markdown]
# ## Impute any Remaining Missing Values as Zero

# %%
#Print out all the missing value rows
pd.set_option('display.max_rows', 1000)

print('\r\n*********The Remaining Missing Values Below will be set to Zero!*************************')

#Check for Missing values 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# *********The Remaining Missing Values Below will be set to Zero!*************************
#                                Variable Name  Number Missing Values
# 26                    ccc_pct_COMP1Y_ALL_161                    136
# 27                    ccc_pct_COMP1Y_BL7_161                    319
# 28                    ccc_pct_COMP1Y_EDS_161                    168
# 29                    ccc_pct_COMP1Y_FEM_161                    142
# 30                   ccc_pct_COMP1Y_MALE_161                    160
# 31                    ccc_pct_COMP1Y_WH7_161                    177
# 32                  ccc_pct_NOCOMP1Y_ALL_161                    120
# 33                  ccc_pct_NOCOMP1Y_BL7_161                    338
# 34                  ccc_pct_NOCOMP1Y_EDS_161                    192
# 35                  ccc_pct_NOCOMP1Y_FEM_161                    147
# 36                 ccc_pct_NOCOMP1Y_MALE_161                    154
# 37                  ccc_pct_NOCOMP1Y_WH7_161                    189
# 38                    ccc_pct_NOINFO_ALL_161                    116
# 39                    ccc_pct_NOINFO_BL7_161                    328
# 40                    ccc_pct_NOINFO_EDS_161                    218
# 41                    ccc_pct_NOINFO_FEM_161                    149
# 42                   ccc_pct_NOINFO_MALE_161                    165
# 43                    ccc_pct_NOINFO_WH7_161                    206
# 44                         pct_ACALL_AIG_ACT                    116
# 45                         pct_ACALL_ALL_ACT                     47
# 46                         pct_ACALL_AS7_ACT                    335
# 47                         pct_ACALL_BL7_ACT                    112
# 48                         pct_ACALL_EDS_ACT                     60
# 49                         pct_ACALL_ELS_ACT                    240
# 50                         pct_ACALL_FEM_ACT                     65
# 51                         pct_ACALL_HI7_ACT                    111
# 52                        pct_ACALL_MALE_ACT                     57
# 53                         pct_ACALL_MU7_ACT                    186
# 54                         pct_ACALL_SWD_ACT                    166
# 55                         pct_ACALL_WH7_ACT                     78
# 56                          pct_ACCO_AIG_ACT                    196
# 57                          pct_ACCO_ALL_ACT                     77
# 58                          pct_ACCO_BL7_ACT                    226
# 59                          pct_ACCO_EDS_ACT                    121
# 60                          pct_ACCO_FEM_ACT                    102
# 61                          pct_ACCO_HI7_ACT                    241
# 62                         pct_ACCO_MALE_ACT                    107
# 63                          pct_ACCO_SWD_ACT                    294
# 64                          pct_ACCO_WH7_ACT                    142
# 65                          pct_ACEN_AIG_ACT                    196
# 66                          pct_ACEN_ALL_ACT                     77
# 67                          pct_ACEN_BL7_ACT                    225
# 68                          pct_ACEN_EDS_ACT                    121
# 69                          pct_ACEN_FEM_ACT                    102
# 70                          pct_ACEN_HI7_ACT                    241
# 71                         pct_ACEN_MALE_ACT                    106
# 72                          pct_ACEN_SWD_ACT                    292
# 73                          pct_ACEN_WH7_ACT                    142
# 74                          pct_ACMA_AIG_ACT                    196
# 75                          pct_ACMA_ALL_ACT                     77
# 76                          pct_ACMA_BL7_ACT                    225
# 77                          pct_ACMA_EDS_ACT                    121
# 78                          pct_ACMA_FEM_ACT                    102
# 79                          pct_ACMA_HI7_ACT                    241
# 80                         pct_ACMA_MALE_ACT                    106
# 81                          pct_ACMA_SWD_ACT                    292
# 82                          pct_ACMA_WH7_ACT                    142
# 83                          pct_ACRD_AIG_ACT                    196
# 84                          pct_ACRD_ALL_ACT                     77
# 85                          pct_ACRD_BL7_ACT                    225
# 86                          pct_ACRD_EDS_ACT                    121
# 87                          pct_ACRD_FEM_ACT                    102
# 88                          pct_ACRD_HI7_ACT                    241
# 89                         pct_ACRD_MALE_ACT                    106
# 90                          pct_ACRD_SWD_ACT                    292
# 91                          pct_ACRD_WH7_ACT                    142
# 92                          pct_ACSC_AIG_ACT                    196
# 93                          pct_ACSC_ALL_ACT                     77
# 94                          pct_ACSC_BL7_ACT                    226
# 95                          pct_ACSC_EDS_ACT                    121
# 96                          pct_ACSC_FEM_ACT                    102
# 97                          pct_ACSC_HI7_ACT                    241
# 98                         pct_ACSC_MALE_ACT                    107
# 99                          pct_ACSC_SWD_ACT                    294
# 100                         pct_ACSC_WH7_ACT                    142
# 101                         pct_ACWR_AIG_ACT                    196
# 102                         pct_ACWR_ALL_ACT                     78
# 103                         pct_ACWR_BL7_ACT                    227
# 104                         pct_ACWR_EDS_ACT                    122
# 105                         pct_ACWR_FEM_ACT                    102
# 106                         pct_ACWR_HI7_ACT                    244
# 107                        pct_ACWR_MALE_ACT                    110
# 108                         pct_ACWR_SWD_ACT                    316
# 109                         pct_ACWR_WH7_ACT                    143
# 110                              pct_AIG_AWA                    197
# 111                              pct_ALL_AWA                     82
# 112                              pct_BL7_AWA                    230
# 113                              pct_EDS_AWA                    143
# 114                              pct_FEM_AWA                    105
# 115                              pct_HI7_AWA                    266
# 116                             pct_MALE_AWA                    113
# 117                              pct_SWD_AWA                    308
# 118                              pct_WH7_AWA                    145
# 119                          pct_EXT_AIG_CGR                    196
# 120                          pct_EXT_ALL_CGR                     56
# 121                          pct_EXT_BL7_CGR                    217
# 122                          pct_EXT_EDS_CGR                    106
# 123                          pct_EXT_FEM_CGR                     95
# 124                          pct_EXT_HI7_CGR                    260
# 125                         pct_EXT_MALE_CGR                     80
# 126                          pct_EXT_SWD_CGR                    242
# 127                          pct_EXT_WH7_CGR                    123
# 128                          pct_STD_AIG_CGR                    189
# 129                          pct_STD_ALL_CGR                     55
# 130                          pct_STD_BL7_CGR                    200
# 131                          pct_STD_EDS_CGR                     93
# 132                          pct_STD_FEM_CGR                     75
# 133                          pct_STD_HI7_CGR                    237
# 134                         pct_STD_MALE_CGR                     76
# 135                          pct_STD_SWD_CGR                    201
# 136                          pct_STD_WH7_CGR                    109
# 137                                  pct_eds                      1
# 138                              pct_ALL_ELP                    295
# 139                              pct_EDS_ELP                    338
# 140                              pct_ELS_ELP                    295
# 141                              pct_HI7_ELP                    313
# 142                             pct_MALE_ELP                    350
# 143                         pct_prof_9gr_irm                     65
# 144       pct_met_4 Year Graduation Rate_LTG                    135
# 145                pct_met_Math Grade 11_LTG                    149
# 146             pct_met_Reading Grade 10_LTG                    138
# 147                pct_met_Total Targets_LTG                     86
# 148                              pct_AIG_MCR                    190
# 149                              pct_ALL_MCR                     56
# 150                              pct_BL7_MCR                    217
# 151                              pct_EDS_MCR                    119
# 152                              pct_FEM_MCR                     91
# 153                              pct_HI7_MCR                    253
# 154                             pct_MALE_MCR                     87
# 155                              pct_SWD_MCR                    238
# 156                              pct_WH7_MCR                    124
# 157                pct_met_ACT WorkKeys_PART                    241
# 158                     pct_met_Biology_PART                    111
# 159                  pct_met_English II_PART                    111
# 160            pct_met_High School Math_PART                    111
# 161                     pct_met_The ACT_PART                    112
# 162               pct_met_Total Targets_PART                     62
# 163            pct_ACT WorkKeys_ALL_PART_DET                    241
# 164            pct_ACT WorkKeys_WH7_PART_DET                    335
# 165                 pct_Biology_ALL_PART_DET                    111
# 166                 pct_Biology_BL7_PART_DET                    354
# 167                 pct_Biology_EDS_PART_DET                    234
# 168                 pct_Biology_WH7_PART_DET                    235
# 169              pct_English II_ALL_PART_DET                    111
# 170              pct_English II_BL7_PART_DET                    338
# 171              pct_English II_EDS_PART_DET                    218
# 172              pct_English II_WH7_PART_DET                    230
# 173        pct_High School Math_ALL_PART_DET                    111
# 174        pct_High School Math_BL7_PART_DET                    354
# 175        pct_High School Math_EDS_PART_DET                    234
# 176        pct_High School Math_WH7_PART_DET                    235
# 177                 pct_The ACT_ALL_PART_DET                    112
# 178                 pct_The ACT_BL7_PART_DET                    355
# 179                 pct_The ACT_EDS_PART_DET                    235
# 180                 pct_The ACT_WH7_PART_DET                    238
# 181                    pct_CCR_BI_EOC_AIG_PC                    203
# 182                    pct_CCR_BI_EOC_ALL_PC                     79
# 183                    pct_CCR_BI_EOC_BL7_PC                    224
# 184                    pct_CCR_BI_EOC_EDS_PC                    123
# 185                    pct_CCR_BI_EOC_FEM_PC                    104
# 186                    pct_CCR_BI_EOC_HI7_PC                    238
# 187                   pct_CCR_BI_EOC_MALE_PC                     99
# 188                    pct_CCR_BI_EOC_SWD_PC                    291
# 189                    pct_CCR_BI_EOC_WH7_PC                    136
# 190                    pct_CCR_E2_EOC_AIG_PC                    190
# 191                    pct_CCR_E2_EOC_ALL_PC                     73
# 192                    pct_CCR_E2_EOC_BL7_PC                    213
# 193                    pct_CCR_E2_EOC_EDS_PC                    104
# 194                    pct_CCR_E2_EOC_FEM_PC                    102
# 195                    pct_CCR_E2_EOC_HI7_PC                    219
# 196                   pct_CCR_E2_EOC_MALE_PC                     98
# 197                    pct_CCR_E2_EOC_SWD_PC                    329
# 198                    pct_CCR_E2_EOC_WH7_PC                    128
# 199                   pct_CCR_EOC_EOC_AIG_PC                    123
# 200                   pct_CCR_EOC_EOC_ALL_PC                     55
# 201                   pct_CCR_EOC_EOC_BL7_PC                    147
# 202                   pct_CCR_EOC_EOC_EDS_PC                     76
# 203                   pct_CCR_EOC_EOC_ELS_PC                    298
# 204                   pct_CCR_EOC_EOC_FEM_PC                     77
# 205                   pct_CCR_EOC_EOC_HI7_PC                    129
# 206                  pct_CCR_EOC_EOC_MALE_PC                     67
# 207                   pct_CCR_EOC_EOC_MU7_PC                    247
# 208                   pct_CCR_EOC_EOC_SWD_PC                    256
# 209                   pct_CCR_EOC_EOC_WH7_PC                     77
# 210                    pct_CCR_M1_EOC_AIG_PC                    199
# 211                    pct_CCR_M1_EOC_ALL_PC                     94
# 212                    pct_CCR_M1_EOC_BL7_PC                    228
# 213                    pct_CCR_M1_EOC_EDS_PC                    121
# 214                    pct_CCR_M1_EOC_FEM_PC                    112
# 215                    pct_CCR_M1_EOC_HI7_PC                    215
# 216                   pct_CCR_M1_EOC_MALE_PC                    109
# 217                    pct_CCR_M1_EOC_SWD_PC                    348
# 218                    pct_CCR_M1_EOC_WH7_PC                    139
# 219                    pct_GLP_BI_EOC_AIG_PC                    203
# 220                    pct_GLP_BI_EOC_ALL_PC                     73
# 221                    pct_GLP_BI_EOC_BL7_PC                    217
# 222                    pct_GLP_BI_EOC_EDS_PC                    118
# 223                    pct_GLP_BI_EOC_FEM_PC                    101
# 224                    pct_GLP_BI_EOC_HI7_PC                    237
# 225                   pct_GLP_BI_EOC_MALE_PC                     96
# 226                    pct_GLP_BI_EOC_SWD_PC                    268
# 227                    pct_GLP_BI_EOC_WH7_PC                    136
# 228                    pct_GLP_E2_EOC_AIG_PC                    190
# 229                    pct_GLP_E2_EOC_ALL_PC                     66
# 230                    pct_GLP_E2_EOC_BL7_PC                    206
# 231                    pct_GLP_E2_EOC_EDS_PC                     97
# 232                    pct_GLP_E2_EOC_FEM_PC                    100
# 233                    pct_GLP_E2_EOC_HI7_PC                    219
# 234                   pct_GLP_E2_EOC_MALE_PC                     88
# 235                    pct_GLP_E2_EOC_SWD_PC                    276
# 236                    pct_GLP_E2_EOC_WH7_PC                    128
# 237                   pct_GLP_EOC_EOC_AIG_PC                    123
# 238                   pct_GLP_EOC_EOC_ALL_PC                     47
# 239                   pct_GLP_EOC_EOC_BL7_PC                    138
# 240                   pct_GLP_EOC_EOC_EDS_PC                     63
# 241                   pct_GLP_EOC_EOC_ELS_PC                    276
# 242                   pct_GLP_EOC_EOC_FEM_PC                     66
# 243                   pct_GLP_EOC_EOC_HI7_PC                    127
# 244                  pct_GLP_EOC_EOC_MALE_PC                     53
# 245                   pct_GLP_EOC_EOC_MU7_PC                    246
# 246                   pct_GLP_EOC_EOC_SWD_PC                    208
# 247                   pct_GLP_EOC_EOC_WH7_PC                     71
# 248                    pct_GLP_M1_EOC_AIG_PC                    199
# 249                    pct_GLP_M1_EOC_ALL_PC                     84
# 250                    pct_GLP_M1_EOC_BL7_PC                    218
# 251                    pct_GLP_M1_EOC_EDS_PC                    110
# 252                    pct_GLP_M1_EOC_FEM_PC                    105
# 253                    pct_GLP_M1_EOC_HI7_PC                    215
# 254                   pct_GLP_M1_EOC_MALE_PC                    100
# 255                    pct_GLP_M1_EOC_SWD_PC                    280
# 256                    pct_GLP_M1_EOC_WH7_PC                    137
# 257                    pct_L1_ALL_ALL_ALL_PC                     97
# 258                    pct_L1_ALL_ALL_BL7_PC                    148
# 259                    pct_L1_ALL_ALL_EDS_PC                     88
# 260                    pct_L1_ALL_ALL_ELS_PC                    243
# 261                    pct_L1_ALL_ALL_FEM_PC                    113
# 262                    pct_L1_ALL_ALL_HI7_PC                    160
# 263                   pct_L1_ALL_ALL_MALE_PC                    101
# 264                    pct_L1_ALL_ALL_MU7_PC                    259
# 265                    pct_L1_ALL_ALL_SWD_PC                    132
# 266                    pct_L1_ALL_ALL_WH7_PC                    155
# 267                     pct_L1_BI_EOC_ALL_PC                    149
# 268                     pct_L1_BI_EOC_BL7_PC                    234
# 269                     pct_L1_BI_EOC_EDS_PC                    159
# 270                     pct_L1_BI_EOC_FEM_PC                    176
# 271                     pct_L1_BI_EOC_HI7_PC                    267
# 272                    pct_L1_BI_EOC_MALE_PC                    174
# 273                     pct_L1_BI_EOC_SWD_PC                    241
# 274                     pct_L1_BI_EOC_WH7_PC                    259
# 275                     pct_L1_E2_EOC_ALL_PC                    154
# 276                     pct_L1_E2_EOC_BL7_PC                    244
# 277                     pct_L1_E2_EOC_EDS_PC                    163
# 278                     pct_L1_E2_EOC_FEM_PC                    214
# 279                     pct_L1_E2_EOC_HI7_PC                    264
# 280                    pct_L1_E2_EOC_MALE_PC                    169
# 281                     pct_L1_E2_EOC_SWD_PC                    238
# 282                     pct_L1_E2_EOC_WH7_PC                    243
# 283                    pct_L1_EOC_EOC_ALL_PC                    106
# 284                    pct_L1_EOC_EOC_BL7_PC                    166
# 285                    pct_L1_EOC_EOC_EDS_PC                    105
# 286                    pct_L1_EOC_EOC_ELS_PC                    266
# 287                    pct_L1_EOC_EOC_FEM_PC                    139
# 288                    pct_L1_EOC_EOC_HI7_PC                    188
# 289                   pct_L1_EOC_EOC_MALE_PC                    114
# 290                    pct_L1_EOC_EOC_MU7_PC                    280
# 291                    pct_L1_EOC_EOC_SWD_PC                    159
# 292                    pct_L1_EOC_EOC_WH7_PC                    183
# 293                     pct_L1_M1_EOC_ALL_PC                    130
# 294                     pct_L1_M1_EOC_BL7_PC                    231
# 295                     pct_L1_M1_EOC_EDS_PC                    140
# 296                     pct_L1_M1_EOC_FEM_PC                    169
# 297                     pct_L1_M1_EOC_HI7_PC                    247
# 298                    pct_L1_M1_EOC_MALE_PC                    146
# 299                     pct_L1_M1_EOC_SWD_PC                    231
# 300                     pct_L1_M1_EOC_WH7_PC                    222
# 301                    pct_L2_ALL_ALL_ALL_PC                     44
# 302                    pct_L2_ALL_ALL_BL7_PC                    129
# 303                    pct_L2_ALL_ALL_EDS_PC                     52
# 304                    pct_L2_ALL_ALL_ELS_PC                    247
# 305                    pct_L2_ALL_ALL_FEM_PC                     59
# 306                    pct_L2_ALL_ALL_HI7_PC                    122
# 307                   pct_L2_ALL_ALL_MALE_PC                     64
# 308                    pct_L2_ALL_ALL_MU7_PC                    249
# 309                    pct_L2_ALL_ALL_SWD_PC                    146
# 310                    pct_L2_ALL_ALL_WH7_PC                     96
# 311                     pct_L2_BI_EOC_ALL_PC                     92
# 312                     pct_L2_BI_EOC_BL7_PC                    222
# 313                     pct_L2_BI_EOC_EDS_PC                    126
# 314                     pct_L2_BI_EOC_FEM_PC                    125
# 315                     pct_L2_BI_EOC_HI7_PC                    248
# 316                    pct_L2_BI_EOC_MALE_PC                    126
# 317                     pct_L2_BI_EOC_SWD_PC                    250
# 318                     pct_L2_BI_EOC_WH7_PC                    179
# 319                     pct_L2_E2_EOC_ALL_PC                     94
# 320                     pct_L2_E2_EOC_BL7_PC                    217
# 321                     pct_L2_E2_EOC_EDS_PC                    123
# 322                     pct_L2_E2_EOC_FEM_PC                    138
# 323                     pct_L2_E2_EOC_HI7_PC                    238
# 324                    pct_L2_E2_EOC_MALE_PC                    124
# 325                     pct_L2_E2_EOC_SWD_PC                    251
# 326                     pct_L2_E2_EOC_WH7_PC                    178
# 327                    pct_L2_EOC_EOC_ALL_PC                     52
# 328                    pct_L2_EOC_EOC_BL7_PC                    145
# 329                    pct_L2_EOC_EOC_EDS_PC                     70
# 330                    pct_L2_EOC_EOC_ELS_PC                    269
# 331                    pct_L2_EOC_EOC_FEM_PC                     85
# 332                    pct_L2_EOC_EOC_HI7_PC                    150
# 333                   pct_L2_EOC_EOC_MALE_PC                     77
# 334                    pct_L2_EOC_EOC_MU7_PC                    270
# 335                    pct_L2_EOC_EOC_SWD_PC                    174
# 336                    pct_L2_EOC_EOC_WH7_PC                    119
# 337                     pct_L2_M1_EOC_ALL_PC                    120
# 338                     pct_L2_M1_EOC_BL7_PC                    226
# 339                     pct_L2_M1_EOC_EDS_PC                    142
# 340                     pct_L2_M1_EOC_FEM_PC                    162
# 341                     pct_L2_M1_EOC_HI7_PC                    252
# 342                    pct_L2_M1_EOC_MALE_PC                    144
# 343                     pct_L2_M1_EOC_SWD_PC                    252
# 344                     pct_L2_M1_EOC_WH7_PC                    206
# 345                    pct_L3_ALL_ALL_ALL_PC                     82
# 346                    pct_L3_ALL_ALL_BL7_PC                    184
# 347                    pct_L3_ALL_ALL_EDS_PC                     87
# 348                    pct_L3_ALL_ALL_FEM_PC                     80
# 349                    pct_L3_ALL_ALL_HI7_PC                    142
# 350                   pct_L3_ALL_ALL_MALE_PC                    105
# 351                    pct_L3_ALL_ALL_MU7_PC                    303
# 352                    pct_L3_ALL_ALL_SWD_PC                    338
# 353                    pct_L3_ALL_ALL_WH7_PC                    129
# 354                     pct_L3_BI_EOC_ALL_PC                    202
# 355                     pct_L3_BI_EOC_BL7_PC                    348
# 356                     pct_L3_BI_EOC_EDS_PC                    249
# 357                     pct_L3_BI_EOC_FEM_PC                    217
# 358                     pct_L3_BI_EOC_HI7_PC                    358
# 359                    pct_L3_BI_EOC_MALE_PC                    252
# 360                     pct_L3_BI_EOC_WH7_PC                    264
# 361                     pct_L3_E2_EOC_ALL_PC                     97
# 362                     pct_L3_E2_EOC_BL7_PC                    243
# 363                     pct_L3_E2_EOC_EDS_PC                    131
# 364                     pct_L3_E2_EOC_FEM_PC                    139
# 365                     pct_L3_E2_EOC_HI7_PC                    250
# 366                    pct_L3_E2_EOC_MALE_PC                    131
# 367                     pct_L3_E2_EOC_WH7_PC                    189
# 368                    pct_L3_EOC_EOC_ALL_PC                     89
# 369                    pct_L3_EOC_EOC_BL7_PC                    190
# 370                    pct_L3_EOC_EOC_EDS_PC                     98
# 371                    pct_L3_EOC_EOC_FEM_PC                     95
# 372                    pct_L3_EOC_EOC_HI7_PC                    161
# 373                   pct_L3_EOC_EOC_MALE_PC                    116
# 374                    pct_L3_EOC_EOC_MU7_PC                    315
# 375                    pct_L3_EOC_EOC_SWD_PC                    351
# 376                    pct_L3_EOC_EOC_WH7_PC                    146
# 377                     pct_L3_M1_EOC_ALL_PC                    120
# 378                     pct_L3_M1_EOC_BL7_PC                    262
# 379                     pct_L3_M1_EOC_EDS_PC                    149
# 380                     pct_L3_M1_EOC_FEM_PC                    128
# 381                     pct_L3_M1_EOC_HI7_PC                    254
# 382                    pct_L3_M1_EOC_MALE_PC                    169
# 383                     pct_L3_M1_EOC_WH7_PC                    195
# 384                    pct_L4_ALL_ALL_AIG_PC                    114
# 385                    pct_L4_ALL_ALL_ALL_PC                     44
# 386                    pct_L4_ALL_ALL_BL7_PC                    140
# 387                    pct_L4_ALL_ALL_EDS_PC                     64
# 388                    pct_L4_ALL_ALL_ELS_PC                    286
# 389                    pct_L4_ALL_ALL_FEM_PC                     63
# 390                    pct_L4_ALL_ALL_HI7_PC                    114
# 391                   pct_L4_ALL_ALL_MALE_PC                     51
# 392                    pct_L4_ALL_ALL_MU7_PC                    230
# 393                    pct_L4_ALL_ALL_SWD_PC                    258
# 394                    pct_L4_ALL_ALL_WH7_PC                     57
# 395                     pct_L4_BI_EOC_AIG_PC                    205
# 396                     pct_L4_BI_EOC_ALL_PC                     81
# 397                     pct_L4_BI_EOC_BL7_PC                    225
# 398                     pct_L4_BI_EOC_EDS_PC                    126
# 399                     pct_L4_BI_EOC_FEM_PC                    107
# 400                     pct_L4_BI_EOC_HI7_PC                    240
# 401                    pct_L4_BI_EOC_MALE_PC                    102
# 402                     pct_L4_BI_EOC_SWD_PC                    317
# 403                     pct_L4_BI_EOC_WH7_PC                    137
# 404                     pct_L4_E2_EOC_AIG_PC                    190
# 405                     pct_L4_E2_EOC_ALL_PC                     72
# 406                     pct_L4_E2_EOC_BL7_PC                    214
# 407                     pct_L4_E2_EOC_EDS_PC                    105
# 408                     pct_L4_E2_EOC_FEM_PC                    102
# 409                     pct_L4_E2_EOC_HI7_PC                    219
# 410                    pct_L4_E2_EOC_MALE_PC                     98
# 411                     pct_L4_E2_EOC_SWD_PC                    360
# 412                     pct_L4_E2_EOC_WH7_PC                    129
# 413                    pct_L4_EOC_EOC_AIG_PC                    123
# 414                    pct_L4_EOC_EOC_ALL_PC                     56
# 415                    pct_L4_EOC_EOC_BL7_PC                    147
# 416                    pct_L4_EOC_EOC_EDS_PC                     77
# 417                    pct_L4_EOC_EOC_ELS_PC                    305
# 418                    pct_L4_EOC_EOC_FEM_PC                     77
# 419                    pct_L4_EOC_EOC_HI7_PC                    129
# 420                   pct_L4_EOC_EOC_MALE_PC                     69
# 421                    pct_L4_EOC_EOC_MU7_PC                    247
# 422                    pct_L4_EOC_EOC_SWD_PC                    279
# 423                    pct_L4_EOC_EOC_WH7_PC                     79
# 424                     pct_L4_M1_EOC_AIG_PC                    199
# 425                     pct_L4_M1_EOC_ALL_PC                     94
# 426                     pct_L4_M1_EOC_BL7_PC                    229
# 427                     pct_L4_M1_EOC_EDS_PC                    122
# 428                     pct_L4_M1_EOC_FEM_PC                    113
# 429                     pct_L4_M1_EOC_HI7_PC                    215
# 430                    pct_L4_M1_EOC_MALE_PC                    110
# 431                     pct_L4_M1_EOC_WH7_PC                    142
# 432                    pct_L5_ALL_ALL_AIG_PC                    126
# 433                    pct_L5_ALL_ALL_ALL_PC                    231
# 434                    pct_L5_ALL_ALL_FEM_PC                    235
# 435                    pct_L5_ALL_ALL_HI7_PC                    355
# 436                   pct_L5_ALL_ALL_MALE_PC                    228
# 437                    pct_L5_ALL_ALL_WH7_PC                    156
# 438                     pct_L5_BI_EOC_AIG_PC                    205
# 439                     pct_L5_BI_EOC_ALL_PC                    167
# 440                     pct_L5_BI_EOC_EDS_PC                    288
# 441                     pct_L5_BI_EOC_FEM_PC                    189
# 442                     pct_L5_BI_EOC_HI7_PC                    347
# 443                    pct_L5_BI_EOC_MALE_PC                    181
# 444                     pct_L5_BI_EOC_WH7_PC                    165
# 445                     pct_L5_E2_EOC_AIG_PC                    261
# 446                    pct_L5_EOC_EOC_AIG_PC                    134
# 447                    pct_L5_EOC_EOC_ALL_PC                    235
# 448                    pct_L5_EOC_EOC_FEM_PC                    243
# 449                   pct_L5_EOC_EOC_MALE_PC                    239
# 450                    pct_L5_EOC_EOC_WH7_PC                    163
# 451                     pct_L5_M1_EOC_AIG_PC                    210
# 452                     pct_L5_M1_EOC_ALL_PC                    274
# 453                     pct_L5_M1_EOC_FEM_PC                    291
# 454                    pct_L5_M1_EOC_MALE_PC                    275
# 455                     pct_L5_M1_EOC_WH7_PC                    240
# 456                                 m1_score                    107
# 457                                 e2_score                    113
# 458                                 bi_score                    112
# 459                                act_score                    108
# 460                                 wk_score                    190
# 461                                mcr_score                    111
# 462                               cgrs_score                    110
# 463                                ach_score                     94
# 464                                 eg_score                    106
# 465                                spg_score                     94
# 466                       aaa_score_ALL_SPG2                     92
# 467                       aaa_score_BL7_SPG2                    261
# 468                       aaa_score_EDS_SPG2                    131
# 469                       aaa_score_HI7_SPG2                    262
# 470                       aaa_score_SWD_SPG2                    260
# 471                       aaa_score_WH7_SPG2                    157
# 472                       ach_score_ALL_SPG2                     83
# 473                       ach_score_BL7_SPG2                    257
# 474                       ach_score_EDS_SPG2                    128
# 475                       ach_score_HI7_SPG2                    261
# 476                       ach_score_SWD_SPG2                    259
# 477                       ach_score_WH7_SPG2                    148
# 478                       awa_score_ALL_SPG2                    137
# 479                       awa_score_EDS_SPG2                    252
# 480                       awa_score_WH7_SPG2                    247
# 481                        bi_score_ALL_SPG2                    124
# 482                        bi_score_BL7_SPG2                    358
# 483                        bi_score_EDS_SPG2                    225
# 484                        bi_score_WH7_SPG2                    236
# 485                      cgrs_score_ALL_SPG2                    128
# 486                      cgrs_score_BL7_SPG2                    341
# 487                      cgrs_score_EDS_SPG2                    233
# 488                      cgrs_score_WH7_SPG2                    230
# 489                        eg_score_ALL_SPG2                    104
# 490                        eg_score_BL7_SPG2                    283
# 491                        eg_score_EDS_SPG2                    151
# 492                        eg_score_HI7_SPG2                    304
# 493                        eg_score_SWD_SPG2                    282
# 494                        eg_score_WH7_SPG2                    186
# 495                       mcr_score_ALL_SPG2                    136
# 496                       mcr_score_BL7_SPG2                    354
# 497                       mcr_score_EDS_SPG2                    243
# 498                       mcr_score_WH7_SPG2                    242
# 499                       spg_score_ALL_SPG2                     83
# 500                       spg_score_BL7_SPG2                    257
# 501                       spg_score_EDS_SPG2                    128
# 502                       spg_score_HI7_SPG2                    261
# 503                       spg_score_SWD_SPG2                    259
# 504                       spg_score_WH7_SPG2                    148
# 505                               pct_AIG_WK                    359
# 506                               pct_ALL_WK                    203
# 507                               pct_BL7_WK                    350
# 508                               pct_EDS_WK                    243
# 509                               pct_FEM_WK                    224
# 510                              pct_MALE_WK                    226
# 511                               pct_WH7_WK                    259
# 513                              pct_ap_pass                    205
# 514                     pct_ap_participation                    262
# 516                     pct_ALL_CHRON_ABSENT                     17
# 517                     pct_AS7_CHRON_ABSENT                    360
# 518                     pct_BL7_CHRON_ABSENT                     84
# 519                     pct_ELS_CHRON_ABSENT                    187
# 520                     pct_FEM_CHRON_ABSENT                     25
# 521                     pct_HI7_CHRON_ABSENT                     72
# 522                    pct_MALE_CHRON_ABSENT                     37
# 523                     pct_MU7_CHRON_ABSENT                    116
# 524                     pct_SWD_CHRON_ABSENT                    108
# 525                     pct_WH7_CHRON_ABSENT                     28
# 526          pct_enrolled_ENROLL_ALL_COLLEGE                     76
# 527          pct_enrolled_ENROLL_BL7_COLLEGE                    221
# 528          pct_enrolled_ENROLL_EDS_COLLEGE                    196
# 529          pct_enrolled_ENROLL_FEM_COLLEGE                     87
# 530          pct_enrolled_ENROLL_HI7_COLLEGE                    357
# 531         pct_enrolled_ENROLL_MALE_COLLEGE                     89
# 532          pct_enrolled_ENROLL_WH7_COLLEGE                    132
# 533                              pct_spc_crs                     23
# 534                            pct_ap_ib_crs                    201
# 535                              pct_cte_crs                     49
# 536                        pct_univ_coll_crs                    153
# 537                    pct_ap_H_AS7_COURSES2                    310
# 538                    pct_ap_H_BL7_COURSES2                    274
# 539                    pct_ap_H_FEM_COURSES2                    235
# 540                    pct_ap_H_HI7_COURSES2                    248
# 541                   pct_ap_H_MALE_COURSES2                    235
# 542                    pct_ap_H_MU7_COURSES2                    280
# 543                    pct_ap_H_WH7_COURSES2                    237
# 544                   pct_ccp_H_AM7_COURSES2                    249
# 545                   pct_ccp_H_AS7_COURSES2                    164
# 546                   pct_ccp_H_BL7_COURSES2                    108
# 547                   pct_ccp_H_ELS_COURSES2                    177
# 548                   pct_ccp_H_FEM_COURSES2                    100
# 549                   pct_ccp_H_HI7_COURSES2                    101
# 550                  pct_ccp_H_MALE_COURSES2                    100
# 551                   pct_ccp_H_MU7_COURSES2                    104
# 552                   pct_ccp_H_SWD_COURSES2                    125
# 553                   pct_ccp_H_WH7_COURSES2                     99
# 554                   num_concentrators_AAVC                    135
# 555                   num_concentrators_AGNR                    135
# 556                   num_concentrators_ARCH                    135
# 557                    num_concentrators_BMA                    135
# 558                   num_concentrators_EDUC                    135
# 559                   num_concentrators_FINA                    135
# 560                   num_concentrators_HLTH                    135
# 561                   num_concentrators_HOSP                    135
# 562                   num_concentrators_HUMA                    135
# 563                   num_concentrators_INFO                    135
# 564                    num_concentrators_LAW                    135
# 565                   num_concentrators_MANU                    135
# 566                   num_concentrators_MRKT                    135
# 567                   num_concentrators_STEM                    135
# 568                   num_concentrators_TRAN                    135
# 569                          num_credentials                    168
# 570                          num_enrollments                    168
# 571                          cred_earned_pct                    168
# 572                              career_only                    104
# 573               career_college_college_unc                    104
# 574                 college_college_unc_only                    104
# 575                             college_only                    104
# 576                               stu_enroll                     28
# 577                               cte_enroll                     28
# 578                       cte_enrollment_pct                     28
# 579                   Book_TitlesPer_Student                    144
# 580                                      wap                     23
# 581                                wap_class                     23
# 582                             media_school                    130
# 583                                  devices                      3
# 584               pct_rating_T1_Accomplished                     15
# 585              pct_rating_T1_Distinguished                    152
# 586                 pct_rating_T1_Proficient                     54
# 587               pct_rating_T2_Accomplished                     43
# 588              pct_rating_T2_Distinguished                    334
# 589                 pct_rating_T2_Proficient                     85
# 590               pct_rating_T3_Accomplished                     51
# 591              pct_rating_T3_Distinguished                    340
# 592                 pct_rating_T3_Proficient                     77
# 593               pct_rating_T4_Accomplished                     18
# 594              pct_rating_T4_Distinguished                    231
# 595                 pct_rating_T4_Proficient                     57
# 596               pct_rating_T5_Accomplished                     56
# 597              pct_rating_T5_Distinguished                    348
# 598                 pct_rating_T5_Proficient                     72
# 599  pct_rating_TS_DoesNotMeetExpectedGrowth                    143
# 600      pct_rating_TS_ExceedsExpectedGrowth                    121
# 601        pct_rating_TS_MeetsExpectedGrowth                     49
# 602               avg_class_teach_TeacherExp                      2
# 603                pct_adv_degree_TeacherExp                      2
# 604              pct_experience_0_TeacherExp                      2
# 605             pct_experience_10_TeacherExp                      2
# 606              pct_experience_4_TeacherExp                      2
# 607                  pct_turnover_TeacherExp                     15
# 608                     highqual_class_pct_H                    121
# 609                                    crime                     13
# 610                               short_term                     13
# 611                                long_term                     13
# 612                                expulsion                     13
# 613                         arre_per1000_ALL                     35
# 614                         arre_per1000_BL7                     90
# 617                         arre_per1000_FEM                     56
# 618                         arre_per1000_HI7                    101
# 619                        arre_per1000_MALE                     47
# 620                         arre_per1000_MU7                    127
# 621                         arre_per1000_SWD                     25
# 622                         arre_per1000_WH7                     54
# 623                         blhr_per1000_ALL                     35
# 624                         blhr_per1000_BL7                     90
# 627                         blhr_per1000_FEM                     56
# 628                         blhr_per1000_HI7                    101
# 629                        blhr_per1000_MALE                     47
# 630                         blhr_per1000_MU7                    127
# 631                         blhr_per1000_SWD                     25
# 632                         blhr_per1000_WH7                     54
# 633                        crime_per1000_ALL                     35
# 634                        crime_per1000_BL7                     90
# 637                        crime_per1000_FEM                     56
# 638                        crime_per1000_HI7                    101
# 639                       crime_per1000_MALE                     47
# 640                        crime_per1000_MU7                    127
# 641                        crime_per1000_SWD                     25
# 642                        crime_per1000_WH7                     54
# 643                          exp_per1000_ALL                     35
# 644                          exp_per1000_BL7                    123
# 645                          exp_per1000_EDS                      7
# 646                          exp_per1000_ELS                    180
# 647                          exp_per1000_FEM                     63
# 648                          exp_per1000_HI7                    150
# 649                         exp_per1000_MALE                     50
# 650                          exp_per1000_MU7                    230
# 651                          exp_per1000_SWD                    123
# 652                          exp_per1000_WH7                     78
# 653                          iss_per1000_ALL                     35
# 654                          iss_per1000_BL7                    124
# 655                          iss_per1000_EDS                      7
# 656                          iss_per1000_ELS                    180
# 657                          iss_per1000_FEM                     63
# 658                          iss_per1000_HI7                    150
# 659                         iss_per1000_MALE                     50
# 660                          iss_per1000_MU7                    230
# 661                          iss_per1000_SWD                    123
# 662                          iss_per1000_WH7                     78
# 663                          lts_per1000_ALL                     35
# 664                          lts_per1000_BL7                    123
# 665                          lts_per1000_EDS                      7
# 666                          lts_per1000_ELS                    180
# 667                          lts_per1000_FEM                     63
# 668                          lts_per1000_HI7                    150
# 669                         lts_per1000_MALE                     50
# 670                          lts_per1000_MU7                    230
# 671                          lts_per1000_SWD                    123
# 672                          lts_per1000_WH7                     78
# 673                         rplw_per1000_ALL                     35
# 674                         rplw_per1000_BL7                     90
# 676                         rplw_per1000_FEM                     56
# 677                         rplw_per1000_HI7                    101
# 678                        rplw_per1000_MALE                     47
# 679                         rplw_per1000_MU7                    127
# 680                         rplw_per1000_SWD                     25
# 681                         rplw_per1000_WH7                     54
# 682                          sts_per1000_ALL                     35
# 683                          sts_per1000_BL7                    128
# 684                          sts_per1000_EDS                      7
# 685                          sts_per1000_ELS                    180
# 686                          sts_per1000_FEM                     65
# 687                          sts_per1000_HI7                    152
# 688                         sts_per1000_MALE                     55
# 689                          sts_per1000_MU7                    230
# 690                          sts_per1000_SWD                    125
# 691                          sts_per1000_WH7                     78
# 692                       pct_fully_licensed                      2
# 693                        pct_lateral_entry                      2
# 694                                nbpts_num                      1
# 695                     avg_size_Biology_SAR                     48
# 696                  avg_size_English II_SAR                     54
# 697                      avg_size_Math I_SAR                     58
# 698                            avg_sat_score                    146
# 699                    pct_sat_participation                    146

# %%
#Replace all remaining NaN with 0
schoolData = schoolData.fillna(0)

#Check for Missing values after final imputation 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# Empty DataFrame
# Columns: [Variable Name, Number Missing Values]
# Index: []

# %% [markdown]
# ## Identify and Remove Highly Correlated Features
# **Find and remove any columns / features that are > 95% correlated**
# * https://stackoverflow.com/questions/39409866/correlation-heatmap
# * https://chrisalbon.com/machine_learning/feature_selection/drop_highly_correlated_features/
# * https://codeyarns.com/2015/04/20/how-to-change-font-size-in-seaborn/

# %%
# calculate the correlation matrix
corr_matrix  = schoolData.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
#Get all of the correlation values > 95%
x = np.where(upper > 0.95)

#Display all field combinations with > 95% correlation
cf = pd.DataFrame()
cf['Field1'] = upper.columns[x[1]]
cf['Field2'] = upper.index[x[0]]

#Get the correlation values for every field combination. (There must be a more pythonic way to do this!)
corr = [0] * len(cf)
for i in range(0, len(cf)):
    corr[i] =  upper[cf['Field1'][i]][cf['Field2'][i]] 
    
cf['Correlation'] = corr

print ('There are ', str(len(cf['Field1'])), ' field correlations > 95%.')
cf
# Out:
# There are  821  field correlations > 95%.
#                                             Field1  \
# 0                                  indian_male_pct
# 1                                indian_female_pct
# 2                                   asian_male_pct
# 3                                 asian_female_pct
# 4                                     minority_pct
# 5                                indian_female_pct
# 6                                pct_ACALL_FEM_ACT
# 7                               pct_ACALL_MALE_ACT
# 8                                 pct_ACEN_ALL_ACT
# 9                                 pct_ACMA_ALL_ACT
# 10                                pct_ACRD_ALL_ACT
# 11                                pct_ACSC_ALL_ACT
# 12                                pct_ACEN_ALL_ACT
# 13                                pct_ACRD_ALL_ACT
# 14                                pct_ACRD_FEM_ACT
# 15                                pct_ACMA_ALL_ACT
# 16                                pct_ACRD_ALL_ACT
# 17                                pct_ACEN_AIG_ACT
# 18                                pct_ACEN_ALL_ACT
# 19                                pct_ACEN_FEM_ACT
# 20                               pct_ACEN_MALE_ACT
# 21                                pct_ACEN_WH7_ACT
# 22                                pct_ACMA_AIG_ACT
# 23                                pct_ACRD_AIG_ACT
# 24                                pct_ACRD_ALL_ACT
# 25                                pct_ACRD_BL7_ACT
# 26                                pct_ACRD_FEM_ACT
# 27                               pct_ACRD_MALE_ACT
# 28                                pct_ACRD_WH7_ACT
# 29                                pct_ACRD_AIG_ACT
# 30                                pct_ACSC_AIG_ACT
# 31                                pct_ACMA_FEM_ACT
# 32                                pct_ACSC_WH7_ACT
# 33                                pct_ACSC_AIG_ACT
# 34                                pct_ACSC_WH7_ACT
# 35                                pct_ACWR_FEM_ACT
# 36                                     pct_AIG_MCR
# 37                                 pct_STD_FEM_CGR
# 38                                     pct_ELS_ELP
# 39               pct_High School Math_ALL_PART_DET
# 40                        pct_The ACT_ALL_PART_DET
# 41               pct_High School Math_BL7_PART_DET
# 42                        pct_The ACT_BL7_PART_DET
# 43               pct_High School Math_EDS_PART_DET
# 44                        pct_The ACT_EDS_PART_DET
# 45               pct_High School Math_WH7_PART_DET
# 46                        pct_The ACT_WH7_PART_DET
# 47                        pct_The ACT_ALL_PART_DET
# 48                        pct_The ACT_BL7_PART_DET
# 49                        pct_The ACT_EDS_PART_DET
# 50                        pct_The ACT_WH7_PART_DET
# 51                           pct_GLP_BI_EOC_AIG_PC
# 52                           pct_CCR_BI_EOC_FEM_PC
# 53                           pct_GLP_BI_EOC_ALL_PC
# 54                           pct_GLP_BI_EOC_BL7_PC
# 55                           pct_GLP_BI_EOC_EDS_PC
# 56                           pct_GLP_BI_EOC_FEM_PC
# 57                           pct_GLP_BI_EOC_HI7_PC
# 58                            pct_L4_BI_EOC_HI7_PC
# 59                          pct_GLP_BI_EOC_MALE_PC
# 60                           pct_GLP_BI_EOC_WH7_PC
# 61                           pct_GLP_E2_EOC_AIG_PC
# 62                            pct_L4_E2_EOC_AIG_PC
# 63                           pct_GLP_E2_EOC_ALL_PC
# 64                            pct_L4_E2_EOC_ALL_PC
# 65                           pct_GLP_E2_EOC_BL7_PC
# 66                            pct_L4_E2_EOC_BL7_PC
# 67                           pct_GLP_E2_EOC_EDS_PC
# 68                            pct_L4_E2_EOC_EDS_PC
# 69                           pct_GLP_E2_EOC_FEM_PC
# 70                            pct_L4_E2_EOC_FEM_PC
# 71                           pct_GLP_E2_EOC_HI7_PC
# 72                            pct_L4_E2_EOC_HI7_PC
# 73                          pct_GLP_E2_EOC_MALE_PC
# 74                           pct_L4_E2_EOC_MALE_PC
# 75                           pct_GLP_E2_EOC_WH7_PC
# 76                            pct_L4_E2_EOC_WH7_PC
# 77                          pct_GLP_EOC_EOC_AIG_PC
# 78                          pct_CCR_EOC_EOC_FEM_PC
# 79                         pct_CCR_EOC_EOC_MALE_PC
# 80                          pct_GLP_EOC_EOC_ALL_PC
# 81                         pct_GLP_EOC_EOC_MALE_PC
# 82                           pct_L4_EOC_EOC_ALL_PC
# 83                              aaa_score_ALL_SPG2
# 84                          pct_GLP_EOC_EOC_BL7_PC
# 85                           pct_L4_ALL_ALL_BL7_PC
# 86                           pct_L4_EOC_EOC_BL7_PC
# 87                          pct_GLP_EOC_EOC_EDS_PC
# 88                           pct_L4_ALL_ALL_EDS_PC
# 89                           pct_L4_EOC_EOC_EDS_PC
# 90                          pct_GLP_EOC_EOC_ELS_PC
# 91                           pct_L4_EOC_EOC_ELS_PC
# 92                          pct_GLP_EOC_EOC_ALL_PC
# 93                          pct_GLP_EOC_EOC_FEM_PC
# 94                           pct_L4_EOC_EOC_FEM_PC
# 95                          pct_GLP_EOC_EOC_HI7_PC
# 96                           pct_L4_ALL_ALL_HI7_PC
# 97                           pct_L4_EOC_EOC_HI7_PC
# 98                          pct_GLP_EOC_EOC_ALL_PC
# 99                         pct_GLP_EOC_EOC_MALE_PC
# 100                         pct_L4_EOC_EOC_MALE_PC
# 101                         pct_GLP_EOC_EOC_MU7_PC
# 102                          pct_L4_EOC_EOC_MU7_PC
# 103                          pct_L4_EOC_EOC_SWD_PC
# 104                         pct_GLP_EOC_EOC_WH7_PC
# 105                          pct_GLP_M1_EOC_AIG_PC
# 106                          pct_CCR_M1_EOC_FEM_PC
# 107                         pct_CCR_M1_EOC_MALE_PC
# 108                          pct_GLP_M1_EOC_ALL_PC
# 109                          pct_GLP_M1_EOC_BL7_PC
# 110                           pct_L4_M1_EOC_BL7_PC
# 111                          pct_GLP_M1_EOC_EDS_PC
# 112                           pct_L4_M1_EOC_EDS_PC
# 113                          pct_GLP_M1_EOC_ALL_PC
# 114                          pct_GLP_M1_EOC_FEM_PC
# 115                          pct_GLP_M1_EOC_HI7_PC
# 116                           pct_L4_M1_EOC_HI7_PC
# 117                         pct_GLP_M1_EOC_MALE_PC
# 118                          pct_GLP_M1_EOC_WH7_PC
# 119                           pct_L4_BI_EOC_HI7_PC
# 120                           pct_L4_E2_EOC_AIG_PC
# 121                           pct_L4_E2_EOC_ALL_PC
# 122                           pct_L4_E2_EOC_BL7_PC
# 123                           pct_L4_E2_EOC_EDS_PC
# 124                           pct_L4_E2_EOC_FEM_PC
# 125                           pct_L4_E2_EOC_HI7_PC
# 126                          pct_L4_E2_EOC_MALE_PC
# 127                           pct_L4_E2_EOC_WH7_PC
# 128                         pct_GLP_EOC_EOC_FEM_PC
# 129                        pct_GLP_EOC_EOC_MALE_PC
# 130                          pct_L4_EOC_EOC_ALL_PC
# 131                             aaa_score_ALL_SPG2
# 132                          pct_L4_EOC_EOC_BL7_PC
# 133                          pct_L4_EOC_EOC_EDS_PC
# 134                          pct_L4_EOC_EOC_ELS_PC
# 135                          pct_L4_EOC_EOC_FEM_PC
# 136                             aaa_score_ALL_SPG2
# 137                          pct_L4_EOC_EOC_HI7_PC
# 138                         pct_L4_EOC_EOC_MALE_PC
# 139                          pct_L4_EOC_EOC_MU7_PC
# 140                          pct_L4_EOC_EOC_WH7_PC
# 141                          pct_GLP_M1_EOC_FEM_PC
# 142                           pct_L4_M1_EOC_ALL_PC
# 143                           pct_L4_M1_EOC_BL7_PC
# 144                           pct_L4_M1_EOC_EDS_PC
# 145                           pct_L4_M1_EOC_FEM_PC
# 146                           pct_L4_M1_EOC_HI7_PC
# 147                         pct_L1_ALL_ALL_MALE_PC
# 148                          pct_L1_EOC_EOC_ALL_PC
# 149                         pct_L1_ALL_ALL_MALE_PC
# 150                          pct_L3_EOC_EOC_MU7_PC
# 151                          pct_L4_EOC_EOC_AIG_PC
# 152                          pct_L4_ALL_ALL_FEM_PC
# 153                         pct_L4_ALL_ALL_MALE_PC
# 154                          pct_L4_EOC_EOC_ALL_PC
# 155                          pct_L4_EOC_EOC_BL7_PC
# 156                          pct_L4_EOC_EOC_EDS_PC
# 157                          pct_L4_EOC_EOC_FEM_PC
# 158                          pct_L4_EOC_EOC_HI7_PC
# 159                         pct_L4_EOC_EOC_MALE_PC
# 160                          pct_L4_EOC_EOC_MU7_PC
# 161                          pct_L4_EOC_EOC_WH7_PC
# 162                          pct_L4_EOC_EOC_FEM_PC
# 163                         pct_L4_EOC_EOC_MALE_PC
# 164                           pct_L4_M1_EOC_FEM_PC
# 165                          pct_L5_EOC_EOC_AIG_PC
# 166                          pct_L5_ALL_ALL_FEM_PC
# 167                          pct_L5_EOC_EOC_ALL_PC
# 168                          pct_L5_EOC_EOC_FEM_PC
# 169                         pct_L5_EOC_EOC_MALE_PC
# 170                          pct_L5_EOC_EOC_WH7_PC
# 171                          pct_L5_EOC_EOC_FEM_PC
# 172                           pct_L5_M1_EOC_FEM_PC
# 173                                     cgrs_score
# 174                                      spg_score
# 175                             ach_score_HI7_SPG2
# 176                             spg_score_HI7_SPG2
# 177                             spg_score_ALL_SPG2
# 178                             spg_score_BL7_SPG2
# 179                             spg_score_EDS_SPG2
# 180                             spg_score_HI7_SPG2
# 181                             spg_score_SWD_SPG2
# 182                             spg_score_WH7_SPG2
# 183                             mcr_score_WH7_SPG2
# 184                                     stu_enroll
# 185                                     cte_enroll
# 186                     avg_class_teach_TeacherExp
# 187                          pct_MALE_CHRON_ABSENT
# 188                                     cte_enroll
# 189                                     cte_enroll
# 190                     avg_class_teach_TeacherExp
# 191                     avg_class_teach_TeacherExp
# 192                               arre_per1000_BL7
# 193                               grade_span_KG:13
# 194                      subgroup_list_ALL,BL7,SWD
# 195                               arre_per1000_EDS
# 196                               arre_per1000_SWD
# 197                              blhr_per1000_MALE
# 198                               grade_span_KG:13
# 199                      subgroup_list_ALL,BL7,SWD
# 200                                exp_per1000_BL7
# 201                               exp_per1000_MALE
# 202                               exp_per1000_MALE
# 203                               iss_per1000_MALE
# 204                               county_Alexander
# 205              lea_name_Alexander County Schools
# 206                         agency_lea_code_020LEA
# 207                               county_Alleghany
# 208              lea_name_Alleghany County Schools
# 209                         agency_lea_code_030LEA
# 210                                   county_Anson
# 211                  lea_name_Anson County Schools
# 212                         agency_lea_code_040LEA
# 213                                    county_Ashe
# 214                   lea_name_Ashe County Schools
# 215                         agency_lea_code_050LEA
# 216                                   county_Avery
# 217                  lea_name_Avery County Schools
# 218                         agency_lea_code_060LEA
# 219                                county_Beaufort
# 220               lea_name_Beaufort County Schools
# 221                         agency_lea_code_070LEA
# 222                                  county_Bertie
# 223                 lea_name_Bertie County Schools
# 224                         agency_lea_code_080LEA
# 225                                  county_Bladen
# 226                 lea_name_Bladen County Schools
# 227                         agency_lea_code_090LEA
# 228                               county_Brunswick
# 229              lea_name_Brunswick County Schools
# 230                         agency_lea_code_100LEA
# 231               lea_name_Buncombe County Schools
# 232                         agency_lea_code_110LEA
# 233                lea_name_Asheville City Schools
# 234                         agency_lea_code_111LEA
# 235                                   county_Burke
# 236                  lea_name_Burke County Schools
# 237                         agency_lea_code_120LEA
# 238                                county_Cabarrus
# 239               lea_name_Cabarrus County Schools
# 240                         agency_lea_code_130LEA
# 241               lea_name_Kannapolis City Schools
# 242                         agency_lea_code_132LEA
# 243                                county_Caldwell
# 244               lea_name_Caldwell County Schools
# 245                         agency_lea_code_140LEA
# 246                                  county_Camden
# 247                 lea_name_Camden County Schools
# 248                         agency_lea_code_150LEA
# 249                                county_Carteret
# 250               lea_name_Carteret County Schools
# 251                         agency_lea_code_160LEA
# 252                                 county_Caswell
# 253                lea_name_Caswell County Schools
# 254                         agency_lea_code_170LEA
# 255                lea_name_Catawba County Schools
# 256                         agency_lea_code_180LEA
# 257                  lea_name_Hickory City Schools
# 258                         agency_lea_code_181LEA
# 259           lea_name_Newton-Conover City Schools
# 260                         agency_lea_code_182LEA
# 261                                 county_Chatham
# 262                lea_name_Chatham County Schools
# 263                         agency_lea_code_190LEA
# 264                                county_Cherokee
# 265               lea_name_Cherokee County Schools
# 266                         agency_lea_code_200LEA
# 267                                  county_Chowan
# 268         lea_name_Edenton-Chowan County Schools
# 269                         agency_lea_code_210LEA
# 270                                    county_Clay
# 271                   lea_name_Clay County Schools
# 272                         agency_lea_code_220LEA
# 273                               county_Cleveland
# 274              lea_name_Cleveland County Schools
# 275                         agency_lea_code_230LEA
# 276               lea_name_Columbus County Schools
# 277                         agency_lea_code_240LEA
# 278               lea_name_Whiteville City Schools
# 279                         agency_lea_code_241LEA
# 280                                  county_Craven
# 281                 lea_name_Craven County Schools
# 282                         agency_lea_code_250LEA
# 283                              county_Cumberland
# 284             lea_name_Cumberland County Schools
# 285                         agency_lea_code_260LEA
# 286                               county_Currituck
# 287              lea_name_Currituck County Schools
# 288                         agency_lea_code_270LEA
# 289                                    county_Dare
# 290                   lea_name_Dare County Schools
# 291                         agency_lea_code_280LEA
# 292               lea_name_Davidson County Schools
# 293                         agency_lea_code_290LEA
# 294                lea_name_Lexington City Schools
# 295                         agency_lea_code_291LEA
# 296              lea_name_Thomasville City Schools
# 297                         agency_lea_code_292LEA
# 298                                   county_Davie
# 299                  lea_name_Davie County Schools
# 300                         agency_lea_code_300LEA
# 301                                  county_Duplin
# 302                 lea_name_Duplin County Schools
# 303                         agency_lea_code_310LEA
# 304                                  county_Durham
# 305                 lea_name_Durham County Schools
# 306                         agency_lea_code_320LEA
# 307                               county_Edgecombe
# 308              lea_name_Edgecombe County Schools
# 309                         agency_lea_code_330LEA
# 310                                 county_Forsyth
# 311                lea_name_Forsyth County Schools
# 312                         agency_lea_code_340LEA
# 313                                county_Franklin
# 314               lea_name_Franklin County Schools
# 315                         agency_lea_code_350LEA
# 316                                  county_Gaston
# 317                 lea_name_Gaston County Schools
# 318                         agency_lea_code_360LEA
# 319                                   county_Gates
# 320                  lea_name_Gates County Schools
# 321                         agency_lea_code_370LEA
# 322                                  county_Graham
# 323                 lea_name_Graham County Schools
# 324                         agency_lea_code_380LEA
# 325                               county_Granville
# 326              lea_name_Granville County Schools
# 327                         agency_lea_code_390LEA
# 328                                  county_Greene
# 329                 lea_name_Greene County Schools
# 330                         agency_lea_code_400LEA
# 331                                county_Guilford
# 332               lea_name_Guilford County Schools
# 333                         agency_lea_code_410LEA
# 334                lea_name_Halifax County Schools
# 335                         agency_lea_code_420LEA
# 336           lea_name_Roanoke Rapids City Schools
# 337                         agency_lea_code_421LEA
# 338                   lea_name_Weldon City Schools
# 339                         agency_lea_code_422LEA
# 340                                 county_Harnett
# 341                lea_name_Harnett County Schools
# 342                         agency_lea_code_430LEA
# 343                                 county_Haywood
# 344                lea_name_Haywood County Schools
# 345                         agency_lea_code_440LEA
# 346                               county_Henderson
# 347              lea_name_Henderson County Schools
# 348                         agency_lea_code_450LEA
# 349                                county_Hertford
# 350               lea_name_Hertford County Schools
# 351                         agency_lea_code_460LEA
# 352                                    county_Hoke
# 353                   lea_name_Hoke County Schools
# 354                         agency_lea_code_470LEA
# 355                                    county_Hyde
# 356                   lea_name_Hyde County Schools
# 357                         agency_lea_code_480LEA
# 358                                 county_Iredell
# 359           lea_name_Iredell-Statesville Schools
# 360                         agency_lea_code_490LEA
# 361              lea_name_Mooresville City Schools
# 362                         agency_lea_code_491LEA
# 363                                 county_Jackson
# 364                lea_name_Jackson County Schools
# 365                         agency_lea_code_500LEA
# 366                                county_Johnston
# 367               lea_name_Johnston County Schools
# 368                         agency_lea_code_510LEA
# 369                                   county_Jones
# 370                  lea_name_Jones County Schools
# 371                         agency_lea_code_520LEA
# 372                                     county_Lee
# 373                    lea_name_Lee County Schools
# 374                         agency_lea_code_530LEA
# 375                                  county_Lenoir
# 376                 lea_name_Lenoir County Schools
# 377                         agency_lea_code_540LEA
# 378                                 county_Lincoln
# 379                lea_name_Lincoln County Schools
# 380                         agency_lea_code_550LEA
# 381                                   county_Macon
# 382                  lea_name_Macon County Schools
# 383                         agency_lea_code_560LEA
# 384                                 county_Madison
# 385                lea_name_Madison County Schools
# 386                         agency_lea_code_570LEA
# 387                                  county_Martin
# 388                 lea_name_Martin County Schools
# 389                         agency_lea_code_580LEA
# 390                                county_McDowell
# 391               lea_name_McDowell County Schools
# 392                         agency_lea_code_590LEA
# 393                             county_Mecklenburg
# 394  lea_name_Charlotte-Mecklenburg County Schools
# 395                         agency_lea_code_600LEA
# 396                                county_Mitchell
# 397               lea_name_Mitchell County Schools
# 398                         agency_lea_code_610LEA
# 399                              county_Montgomery
# 400             lea_name_Montgomery County Schools
# 401                         agency_lea_code_620LEA
# 402                                   county_Moore
# 403                  lea_name_Moore County Schools
# 404                         agency_lea_code_630LEA
# 405                                    county_Nash
# 406              lea_name_Nash-Rocky Mount Schools
# 407                         agency_lea_code_640LEA
# 408                             county_New Hanover
# 409            lea_name_New Hanover County Schools
# 410                         agency_lea_code_650LEA
# 411                             county_Northampton
# 412            lea_name_Northampton County Schools
# 413                         agency_lea_code_660LEA
# 414                                  county_Onslow
# 415                 lea_name_Onslow County Schools
# 416                         agency_lea_code_670LEA
# 417                 lea_name_Orange County Schools
# 418                         agency_lea_code_680LEA
# 419     lea_name_Chapel-Hill/Carrboro City Schools
# 420                         agency_lea_code_681LEA
# 421                                 county_Pamlico
# 422                lea_name_Pamlico County Schools
# 423                         agency_lea_code_690LEA
# 424                              county_Pasquotank
# 425             lea_name_Pasquotank County Schools
# 426                         agency_lea_code_700LEA
# 427                                  county_Pender
# 428                 lea_name_Pender County Schools
# 429                         agency_lea_code_710LEA
# 430                              county_Perquimans
# 431             lea_name_Perquimans County Schools
# 432                         agency_lea_code_720LEA
# 433                                  county_Person
# 434                 lea_name_Person County Schools
# 435                         agency_lea_code_730LEA
# 436                                    county_Pitt
# 437                   lea_name_Pitt County Schools
# 438                         agency_lea_code_740LEA
# 439                                    county_Polk
# 440                   lea_name_Polk County Schools
# 441                         agency_lea_code_750LEA
# 442               lea_name_Randolph County Schools
# 443                         agency_lea_code_760LEA
# 444                 lea_name_Asheboro City Schools
# 445                         agency_lea_code_761LEA
# 446                                county_Richmond
# 447               lea_name_Richmond County Schools
# 448                         agency_lea_code_770LEA
# 449                                 county_Robeson
# 450                lea_name_Robeson County Schools
# 451                         agency_lea_code_780LEA
# 452                              county_Rockingham
# 453             lea_name_Rockingham County Schools
# 454                         agency_lea_code_790LEA
# 455                                   county_Rowan
# 456        lea_name_Rowan-Salisbury County Schools
# 457                         agency_lea_code_800LEA
# 458                              county_Rutherford
# 459             lea_name_Rutherford County Schools
# 460                         agency_lea_code_810LEA
# 461                lea_name_Sampson County Schools
# 462                         agency_lea_code_820LEA
# 463                  lea_name_Clinton City Schools
# 464                         agency_lea_code_821LEA
# 465                                county_Scotland
# 466               lea_name_Scotland County Schools
# 467                         agency_lea_code_830LEA
# 468                                  county_Stanly
# 469                 lea_name_Stanly County Schools
# 470                         agency_lea_code_840LEA
# 471                                  county_Stokes
# 472                 lea_name_Stokes County Schools
# 473                         agency_lea_code_850LEA
# 474                  lea_name_Surry County Schools
# 475                         agency_lea_code_860LEA
# 476                    lea_name_Elkin City Schools
# 477                         agency_lea_code_861LEA
# 478               lea_name_Mount Airy City Schools
# 479                         agency_lea_code_862LEA
# 480                                   county_Swain
# 481                  lea_name_Swain County Schools
# 482                  subgroup_list_ALL,AM7,EDS,WH7
# 483                         agency_lea_code_870LEA
# 484                            county_Transylvania
# 485           lea_name_Transylvania County Schools
# 486                         agency_lea_code_880LEA
# 487                                 county_Tyrrell
# 488                lea_name_Tyrrell County Schools
# 489                         agency_lea_code_890LEA
# 490                                   county_Union
# 491                  lea_name_Union County Schools
# 492                         agency_lea_code_900LEA
# 493                                   county_Vance
# 494                  lea_name_Vance County Schools
# 495                         agency_lea_code_910LEA
# 496                                    county_Wake
# 497                   lea_name_Wake County Schools
# 498                         agency_lea_code_920LEA
# 499                                  county_Warren
# 500                 lea_name_Warren County Schools
# 501                         agency_lea_code_930LEA
# 502                              county_Washington
# 503             lea_name_Washington County Schools
# 504                         agency_lea_code_940LEA
# 505                                 county_Watauga
# 506                lea_name_Watauga County Schools
# 507                         agency_lea_code_950LEA
# 508                                   county_Wayne
# 509                  lea_name_Wayne County Schools
# 510                         agency_lea_code_960LEA
# 511                                  county_Wilkes
# 512                 lea_name_Wilkes County Schools
# 513                         agency_lea_code_970LEA
# 514                                  county_Wilson
# 515                 lea_name_Wilson County Schools
# 516                         agency_lea_code_980LEA
# 517                                  county_Yadkin
# 518                 lea_name_Yadkin County Schools
# 519                         agency_lea_code_990LEA
# 520                                  county_Yancey
# 521                 lea_name_Yancey County Schools
# 522                         agency_lea_code_995LEA
# 523              lea_name_Alexander County Schools
# 524                         agency_lea_code_020LEA
# 525              lea_name_Alleghany County Schools
# 526                         agency_lea_code_030LEA
# 527                  lea_name_Anson County Schools
# 528                         agency_lea_code_040LEA
# 529                   lea_name_Ashe County Schools
# 530                         agency_lea_code_050LEA
# 531                  lea_name_Avery County Schools
# 532                         agency_lea_code_060LEA
# 533               lea_name_Beaufort County Schools
# 534                         agency_lea_code_070LEA
# 535                 lea_name_Bertie County Schools
# 536                         agency_lea_code_080LEA
# 537                 lea_name_Bladen County Schools
# 538                         agency_lea_code_090LEA
# 539              lea_name_Brunswick County Schools
# 540                         agency_lea_code_100LEA
# 541                  lea_name_Burke County Schools
# 542                         agency_lea_code_120LEA
# 543               lea_name_Cabarrus County Schools
# 544                         agency_lea_code_130LEA
# 545               lea_name_Caldwell County Schools
# 546                         agency_lea_code_140LEA
# 547                 lea_name_Camden County Schools
# 548                         agency_lea_code_150LEA
# 549               lea_name_Carteret County Schools
# 550                         agency_lea_code_160LEA
# 551                lea_name_Caswell County Schools
# 552                         agency_lea_code_170LEA
# 553                lea_name_Chatham County Schools
# 554                         agency_lea_code_190LEA
# 555               lea_name_Cherokee County Schools
# 556                         agency_lea_code_200LEA
# 557         lea_name_Edenton-Chowan County Schools
# 558                         agency_lea_code_210LEA
# 559                   lea_name_Clay County Schools
# 560                         agency_lea_code_220LEA
# 561              lea_name_Cleveland County Schools
# 562                         agency_lea_code_230LEA
# 563                 lea_name_Craven County Schools
# 564                         agency_lea_code_250LEA
# 565             lea_name_Cumberland County Schools
# 566                         agency_lea_code_260LEA
# 567              lea_name_Currituck County Schools
# 568                         agency_lea_code_270LEA
# 569                   lea_name_Dare County Schools
# 570                         agency_lea_code_280LEA
# 571                  lea_name_Davie County Schools
# 572                         agency_lea_code_300LEA
# 573                 lea_name_Duplin County Schools
# 574                         agency_lea_code_310LEA
# 575                 lea_name_Durham County Schools
# 576                         agency_lea_code_320LEA
# 577              lea_name_Edgecombe County Schools
# 578                         agency_lea_code_330LEA
# 579                lea_name_Forsyth County Schools
# 580                         agency_lea_code_340LEA
# 581               lea_name_Franklin County Schools
# 582                         agency_lea_code_350LEA
# 583                 lea_name_Gaston County Schools
# 584                         agency_lea_code_360LEA
# 585                  lea_name_Gates County Schools
# 586                         agency_lea_code_370LEA
# 587                 lea_name_Graham County Schools
# 588                         agency_lea_code_380LEA
# 589              lea_name_Granville County Schools
# 590                         agency_lea_code_390LEA
# 591                 lea_name_Greene County Schools
# 592                         agency_lea_code_400LEA
# 593               lea_name_Guilford County Schools
# 594                         agency_lea_code_410LEA
# 595                lea_name_Harnett County Schools
# 596                         agency_lea_code_430LEA
# 597                lea_name_Haywood County Schools
# 598                         agency_lea_code_440LEA
# 599              lea_name_Henderson County Schools
# 600                         agency_lea_code_450LEA
# 601               lea_name_Hertford County Schools
# 602                         agency_lea_code_460LEA
# 603                   lea_name_Hoke County Schools
# 604                         agency_lea_code_470LEA
# 605                   lea_name_Hyde County Schools
# 606                         agency_lea_code_480LEA
# 607           lea_name_Iredell-Statesville Schools
# 608                         agency_lea_code_490LEA
# 609                lea_name_Jackson County Schools
# 610                         agency_lea_code_500LEA
# 611               lea_name_Johnston County Schools
# 612                         agency_lea_code_510LEA
# 613                  lea_name_Jones County Schools
# 614                         agency_lea_code_520LEA
# 615                    lea_name_Lee County Schools
# 616                         agency_lea_code_530LEA
# 617                 lea_name_Lenoir County Schools
# 618                         agency_lea_code_540LEA
# 619                lea_name_Lincoln County Schools
# 620                         agency_lea_code_550LEA
# 621                  lea_name_Macon County Schools
# 622                         agency_lea_code_560LEA
# 623                lea_name_Madison County Schools
# 624                         agency_lea_code_570LEA
# 625                 lea_name_Martin County Schools
# 626                         agency_lea_code_580LEA
# 627               lea_name_McDowell County Schools
# 628                         agency_lea_code_590LEA
# 629  lea_name_Charlotte-Mecklenburg County Schools
# 630                         agency_lea_code_600LEA
# 631               lea_name_Mitchell County Schools
# 632                         agency_lea_code_610LEA
# 633             lea_name_Montgomery County Schools
# 634                         agency_lea_code_620LEA
# 635                  lea_name_Moore County Schools
# 636                         agency_lea_code_630LEA
# 637              lea_name_Nash-Rocky Mount Schools
# 638                         agency_lea_code_640LEA
# 639            lea_name_New Hanover County Schools
# 640                         agency_lea_code_650LEA
# 641            lea_name_Northampton County Schools
# 642                         agency_lea_code_660LEA
# 643                 lea_name_Onslow County Schools
# 644                         agency_lea_code_670LEA
# 645                lea_name_Pamlico County Schools
# 646                         agency_lea_code_690LEA
# 647             lea_name_Pasquotank County Schools
# 648                         agency_lea_code_700LEA
# 649                 lea_name_Pender County Schools
# 650                         agency_lea_code_710LEA
# 651             lea_name_Perquimans County Schools
# 652                         agency_lea_code_720LEA
# 653                 lea_name_Person County Schools
# 654                         agency_lea_code_730LEA
# 655                   lea_name_Pitt County Schools
# 656                         agency_lea_code_740LEA
# 657                   lea_name_Polk County Schools
# 658                         agency_lea_code_750LEA
# 659               lea_name_Richmond County Schools
# 660                         agency_lea_code_770LEA
# 661                lea_name_Robeson County Schools
# 662                         agency_lea_code_780LEA
# 663             lea_name_Rockingham County Schools
# 664                         agency_lea_code_790LEA
# 665        lea_name_Rowan-Salisbury County Schools
# 666                         agency_lea_code_800LEA
# 667             lea_name_Rutherford County Schools
# 668                         agency_lea_code_810LEA
# 669               lea_name_Scotland County Schools
# 670                         agency_lea_code_830LEA
# 671                 lea_name_Stanly County Schools
# 672                         agency_lea_code_840LEA
# 673                 lea_name_Stokes County Schools
# 674                         agency_lea_code_850LEA
# 675                  lea_name_Swain County Schools
# 676                  subgroup_list_ALL,AM7,EDS,WH7
# 677                         agency_lea_code_870LEA
# 678           lea_name_Transylvania County Schools
# 679                         agency_lea_code_880LEA
# 680                lea_name_Tyrrell County Schools
# 681                         agency_lea_code_890LEA
# 682                  lea_name_Union County Schools
# 683                         agency_lea_code_900LEA
# 684                  lea_name_Vance County Schools
# 685                         agency_lea_code_910LEA
# 686                   lea_name_Wake County Schools
# 687                         agency_lea_code_920LEA
# 688                 lea_name_Warren County Schools
# 689                         agency_lea_code_930LEA
# 690             lea_name_Washington County Schools
# 691                         agency_lea_code_940LEA
# 692                lea_name_Watauga County Schools
# 693                         agency_lea_code_950LEA
# 694                  lea_name_Wayne County Schools
# 695                         agency_lea_code_960LEA
# 696                 lea_name_Wilkes County Schools
# 697                         agency_lea_code_970LEA
# 698                 lea_name_Wilson County Schools
# 699                         agency_lea_code_980LEA
# 700                 lea_name_Yadkin County Schools
# 701                         agency_lea_code_990LEA
# 702                 lea_name_Yancey County Schools
# 703                         agency_lea_code_995LEA
# 704                      subgroup_list_ALL,BL7,SWD
# 705                         agency_lea_code_020LEA
# 706                         agency_lea_code_030LEA
# 707                         agency_lea_code_040LEA
# 708                         agency_lea_code_050LEA
# 709                         agency_lea_code_761LEA
# 710                         agency_lea_code_111LEA
# 711                         agency_lea_code_060LEA
# 712                         agency_lea_code_070LEA
# 713                         agency_lea_code_080LEA
# 714                         agency_lea_code_090LEA
# 715                         agency_lea_code_100LEA
# 716                         agency_lea_code_110LEA
# 717                         agency_lea_code_120LEA
# 718                         agency_lea_code_130LEA
# 719                         agency_lea_code_140LEA
# 720                         agency_lea_code_150LEA
# 721                         agency_lea_code_160LEA
# 722                         agency_lea_code_170LEA
# 723                         agency_lea_code_180LEA
# 724                         agency_lea_code_681LEA
# 725                         agency_lea_code_600LEA
# 726                         agency_lea_code_190LEA
# 727                         agency_lea_code_200LEA
# 728                         agency_lea_code_220LEA
# 729                         agency_lea_code_230LEA
# 730                         agency_lea_code_821LEA
# 731                         agency_lea_code_240LEA
# 732                         agency_lea_code_250LEA
# 733                         agency_lea_code_260LEA
# 734                         agency_lea_code_270LEA
# 735                         agency_lea_code_280LEA
# 736                         agency_lea_code_290LEA
# 737                         agency_lea_code_300LEA
# 738                         agency_lea_code_310LEA
# 739                         agency_lea_code_320LEA
# 740                         agency_lea_code_210LEA
# 741                         agency_lea_code_330LEA
# 742                         agency_lea_code_861LEA
# 743                         agency_lea_code_340LEA
# 744                         agency_lea_code_350LEA
# 745                         agency_lea_code_360LEA
# 746                         agency_lea_code_370LEA
# 747                         agency_lea_code_380LEA
# 748                         agency_lea_code_390LEA
# 749                         agency_lea_code_400LEA
# 750                         agency_lea_code_410LEA
# 751                         agency_lea_code_420LEA
# 752                         agency_lea_code_430LEA
# 753                         agency_lea_code_440LEA
# 754                         agency_lea_code_450LEA
# 755                         agency_lea_code_460LEA
# 756                         agency_lea_code_181LEA
# 757                         agency_lea_code_470LEA
# 758                         agency_lea_code_480LEA
# 759                         agency_lea_code_490LEA
# 760                         agency_lea_code_500LEA
# 761                         agency_lea_code_510LEA
# 762                         agency_lea_code_520LEA
# 763                         agency_lea_code_132LEA
# 764                         agency_lea_code_530LEA
# 765                         agency_lea_code_540LEA
# 766                         agency_lea_code_291LEA
# 767                         agency_lea_code_550LEA
# 768                         agency_lea_code_560LEA
# 769                         agency_lea_code_570LEA
# 770                         agency_lea_code_580LEA
# 771                         agency_lea_code_590LEA
# 772                         agency_lea_code_610LEA
# 773                         agency_lea_code_620LEA
# 774                         agency_lea_code_630LEA
# 775                         agency_lea_code_491LEA
# 776                         agency_lea_code_862LEA
# 777                         agency_lea_code_640LEA
# 778                         agency_lea_code_650LEA
# 779                         agency_lea_code_182LEA
# 780                         agency_lea_code_660LEA
# 781                         agency_lea_code_670LEA
# 782                         agency_lea_code_680LEA
# 783                         agency_lea_code_690LEA
# 784                         agency_lea_code_700LEA
# 785                         agency_lea_code_710LEA
# 786                         agency_lea_code_720LEA
# 787                         agency_lea_code_730LEA
# 788                         agency_lea_code_740LEA
# 789                         agency_lea_code_750LEA
# 790                         agency_lea_code_760LEA
# 791                         agency_lea_code_770LEA
# 792                         agency_lea_code_421LEA
# 793                         agency_lea_code_780LEA
# 794                         agency_lea_code_790LEA
# 795                         agency_lea_code_800LEA
# 796                         agency_lea_code_810LEA
# 797                         agency_lea_code_820LEA
# 798                         agency_lea_code_830LEA
# 799                         agency_lea_code_840LEA
# 800                         agency_lea_code_850LEA
# 801                         agency_lea_code_860LEA
# 802                  subgroup_list_ALL,AM7,EDS,WH7
# 803                         agency_lea_code_870LEA
# 804                         agency_lea_code_292LEA
# 805                         agency_lea_code_880LEA
# 806                         agency_lea_code_890LEA
# 807                         agency_lea_code_900LEA
# 808                         agency_lea_code_910LEA
# 809                         agency_lea_code_920LEA
# 810                         agency_lea_code_930LEA
# 811                         agency_lea_code_940LEA
# 812                         agency_lea_code_950LEA
# 813                         agency_lea_code_960LEA
# 814                         agency_lea_code_422LEA
# 815                         agency_lea_code_241LEA
# 816                         agency_lea_code_970LEA
# 817                         agency_lea_code_980LEA
# 818                         agency_lea_code_990LEA
# 819                         agency_lea_code_995LEA
# 820                         agency_lea_code_870LEA
#
#                                             Field2  Correlation
# 0                                       indian_pct     0.988499
# 1                                       indian_pct     0.988881
# 2                                        asian_pct     0.962782
# 3                                        asian_pct     0.959796
# 4                                        white_pct     1.000000
# 5                                  indian_male_pct     0.955019
# 6                                pct_ACALL_ALL_ACT     0.978277
# 7                                pct_ACALL_ALL_ACT     0.973291
# 8                                pct_ACALL_ALL_ACT     0.972780
# 9                                pct_ACALL_ALL_ACT     0.967270
# 10                               pct_ACALL_ALL_ACT     0.980994
# 11                               pct_ACALL_ALL_ACT     0.966638
# 12                               pct_ACALL_FEM_ACT     0.957022
# 13                               pct_ACALL_FEM_ACT     0.961878
# 14                               pct_ACALL_FEM_ACT     0.950357
# 15                              pct_ACALL_MALE_ACT     0.951276
# 16                              pct_ACALL_MALE_ACT     0.954390
# 17                                pct_ACCO_AIG_ACT     0.978491
# 18                                pct_ACCO_ALL_ACT     0.959114
# 19                                pct_ACCO_FEM_ACT     0.952879
# 20                               pct_ACCO_MALE_ACT     0.951499
# 21                                pct_ACCO_WH7_ACT     0.961441
# 22                                pct_ACEN_AIG_ACT     0.968235
# 23                                pct_ACEN_AIG_ACT     0.971413
# 24                                pct_ACEN_ALL_ACT     0.975587
# 25                                pct_ACEN_BL7_ACT     0.950063
# 26                                pct_ACEN_FEM_ACT     0.967495
# 27                               pct_ACEN_MALE_ACT     0.958437
# 28                                pct_ACEN_WH7_ACT     0.970010
# 29                                pct_ACMA_AIG_ACT     0.962489
# 30                                pct_ACMA_AIG_ACT     0.956610
# 31                                pct_ACMA_ALL_ACT     0.959290
# 32                                pct_ACMA_WH7_ACT     0.955274
# 33                                pct_ACRD_AIG_ACT     0.964170
# 34                                pct_ACRD_WH7_ACT     0.957972
# 35                                pct_ACWR_ALL_ACT     0.959339
# 36                                     pct_AIG_AWA     0.974690
# 37                                 pct_STD_ALL_CGR     0.958145
# 38                                     pct_ALL_ELP     1.000000
# 39                        pct_Biology_ALL_PART_DET     0.999804
# 40                        pct_Biology_ALL_PART_DET     0.959247
# 41                        pct_Biology_BL7_PART_DET     0.999896
# 42                        pct_Biology_BL7_PART_DET     0.980951
# 43                        pct_Biology_EDS_PART_DET     0.999913
# 44                        pct_Biology_EDS_PART_DET     0.988517
# 45                        pct_Biology_WH7_PART_DET     0.999979
# 46                        pct_Biology_WH7_PART_DET     0.982792
# 47               pct_High School Math_ALL_PART_DET     0.957251
# 48               pct_High School Math_BL7_PART_DET     0.980248
# 49               pct_High School Math_EDS_PART_DET     0.987972
# 50               pct_High School Math_WH7_PART_DET     0.982751
# 51                           pct_CCR_BI_EOC_AIG_PC     0.996801
# 52                           pct_CCR_BI_EOC_ALL_PC     0.955904
# ...
# 579                                 county_Forsyth     1.000000
# 580                                 county_Forsyth     1.000000
# 581                                county_Franklin     1.000000
# 582                                county_Franklin     1.000000
# 583                                  county_Gaston     1.000000
# 584                                  county_Gaston     1.000000
# 585                                   county_Gates     1.000000
# 586                                   county_Gates     1.000000
# 587                                  county_Graham     1.000000
# 588                                  county_Graham     1.000000
# 589                               county_Granville     1.000000
# 590                               county_Granville     1.000000
# 591                                  county_Greene     1.000000
# 592                                  county_Greene     1.000000
# 593                                county_Guilford     1.000000
# 594                                county_Guilford     1.000000
# 595                                 county_Harnett     1.000000
# 596                                 county_Harnett     1.000000
# 597                                 county_Haywood     1.000000
# 598                                 county_Haywood     1.000000
# 599                               county_Henderson     1.000000
# 600                               county_Henderson     1.000000
# 601                                county_Hertford     1.000000
# 602                                county_Hertford     1.000000
# 603                                    county_Hoke     1.000000
# 604                                    county_Hoke     1.000000
# 605                                    county_Hyde     1.000000
# 606                                    county_Hyde     1.000000
# 607                                 county_Iredell     0.952658
# 608                                 county_Iredell     0.952658
# 609                                 county_Jackson     1.000000
# 610                                 county_Jackson     1.000000
# 611                                county_Johnston     1.000000
# 612                                county_Johnston     1.000000
# 613                                   county_Jones     1.000000
# 614                                   county_Jones     1.000000
# 615                                     county_Lee     1.000000
# 616                                     county_Lee     1.000000
# 617                                  county_Lenoir     1.000000
# 618                                  county_Lenoir     1.000000
# 619                                 county_Lincoln     1.000000
# 620                                 county_Lincoln     1.000000
# 621                                   county_Macon     1.000000
# 622                                   county_Macon     1.000000
# 623                                 county_Madison     1.000000
# 624                                 county_Madison     1.000000
# 625                                  county_Martin     1.000000
# 626                                  county_Martin     1.000000
# 627                                county_McDowell     1.000000
# 628                                county_McDowell     1.000000
# 629                             county_Mecklenburg     1.000000
# 630                             county_Mecklenburg     1.000000
# 631                                county_Mitchell     1.000000
# 632                                county_Mitchell     1.000000
# 633                              county_Montgomery     1.000000
# 634                              county_Montgomery     1.000000
# 635                                   county_Moore     1.000000
# 636                                   county_Moore     1.000000
# 637                                    county_Nash     1.000000
# 638                                    county_Nash     1.000000
# 639                             county_New Hanover     1.000000
# 640                             county_New Hanover     1.000000
# 641                             county_Northampton     1.000000
# 642                             county_Northampton     1.000000
# 643                                  county_Onslow     1.000000
# 644                                  county_Onslow     1.000000
# 645                                 county_Pamlico     1.000000
# 646                                 county_Pamlico     1.000000
# 647                              county_Pasquotank     1.000000
# 648                              county_Pasquotank     1.000000
# 649                                  county_Pender     1.000000
# 650                                  county_Pender     1.000000
# 651                              county_Perquimans     1.000000
# 652                              county_Perquimans     1.000000
# 653                                  county_Person     1.000000
# 654                                  county_Person     1.000000
# 655                                    county_Pitt     1.000000
# 656                                    county_Pitt     1.000000
# 657                                    county_Polk     1.000000
# 658                                    county_Polk     1.000000
# 659                                county_Richmond     1.000000
# 660                                county_Richmond     1.000000
# 661                                 county_Robeson     1.000000
# 662                                 county_Robeson     1.000000
# 663                              county_Rockingham     1.000000
# 664                              county_Rockingham     1.000000
# 665                                   county_Rowan     1.000000
# 666                                   county_Rowan     1.000000
# 667                              county_Rutherford     1.000000
# 668                              county_Rutherford     1.000000
# 669                                county_Scotland     1.000000
# 670                                county_Scotland     1.000000
# 671                                  county_Stanly     1.000000
# 672                                  county_Stanly     1.000000
# 673                                  county_Stokes     1.000000
# 674                                  county_Stokes     1.000000
# 675                                   county_Swain     1.000000
# 676                                   county_Swain     1.000000
# 677                                   county_Swain     1.000000
# 678                            county_Transylvania     1.000000
# 679                            county_Transylvania     1.000000
# 680                                 county_Tyrrell     1.000000
# 681                                 county_Tyrrell     1.000000
# 682                                   county_Union     1.000000
# 683                                   county_Union     1.000000
# 684                                   county_Vance     1.000000
# 685                                   county_Vance     1.000000
# 686                                    county_Wake     1.000000
# 687                                    county_Wake     1.000000
# 688                                  county_Warren     1.000000
# 689                                  county_Warren     1.000000
# 690                              county_Washington     1.000000
# 691                              county_Washington     1.000000
# 692                                 county_Watauga     1.000000
# 693                                 county_Watauga     1.000000
# 694                                   county_Wayne     1.000000
# 695                                   county_Wayne     1.000000
# 696                                  county_Wilkes     1.000000
# 697                                  county_Wilkes     1.000000
# 698                                  county_Wilson     1.000000
# 699                                  county_Wilson     1.000000
# 700                                  county_Yadkin     1.000000
# 701                                  county_Yadkin     1.000000
# 702                                  county_Yancey     1.000000
# 703                                  county_Yancey     1.000000
# 704                               grade_span_KG:13     1.000000
# 705              lea_name_Alexander County Schools     1.000000
# 706              lea_name_Alleghany County Schools     1.000000
# 707                  lea_name_Anson County Schools     1.000000
# 708                   lea_name_Ashe County Schools     1.000000
# 709                 lea_name_Asheboro City Schools     1.000000
# 710                lea_name_Asheville City Schools     1.000000
# 711                  lea_name_Avery County Schools     1.000000
# 712               lea_name_Beaufort County Schools     1.000000
# 713                 lea_name_Bertie County Schools     1.000000
# 714                 lea_name_Bladen County Schools     1.000000
# 715              lea_name_Brunswick County Schools     1.000000
# 716               lea_name_Buncombe County Schools     1.000000
# 717                  lea_name_Burke County Schools     1.000000
# 718               lea_name_Cabarrus County Schools     1.000000
# 719               lea_name_Caldwell County Schools     1.000000
# 720                 lea_name_Camden County Schools     1.000000
# 721               lea_name_Carteret County Schools     1.000000
# 722                lea_name_Caswell County Schools     1.000000
# 723                lea_name_Catawba County Schools     1.000000
# 724     lea_name_Chapel-Hill/Carrboro City Schools     1.000000
# 725  lea_name_Charlotte-Mecklenburg County Schools     1.000000
# 726                lea_name_Chatham County Schools     1.000000
# 727               lea_name_Cherokee County Schools     1.000000
# 728                   lea_name_Clay County Schools     1.000000
# 729              lea_name_Cleveland County Schools     1.000000
# 730                  lea_name_Clinton City Schools     1.000000
# 731               lea_name_Columbus County Schools     1.000000
# 732                 lea_name_Craven County Schools     1.000000
# 733             lea_name_Cumberland County Schools     1.000000
# 734              lea_name_Currituck County Schools     1.000000
# 735                   lea_name_Dare County Schools     1.000000
# 736               lea_name_Davidson County Schools     1.000000
# 737                  lea_name_Davie County Schools     1.000000
# 738                 lea_name_Duplin County Schools     1.000000
# 739                 lea_name_Durham County Schools     1.000000
# 740         lea_name_Edenton-Chowan County Schools     1.000000
# 741              lea_name_Edgecombe County Schools     1.000000
# 742                    lea_name_Elkin City Schools     1.000000
# 743                lea_name_Forsyth County Schools     1.000000
# 744               lea_name_Franklin County Schools     1.000000
# 745                 lea_name_Gaston County Schools     1.000000
# 746                  lea_name_Gates County Schools     1.000000
# 747                 lea_name_Graham County Schools     1.000000
# 748              lea_name_Granville County Schools     1.000000
# 749                 lea_name_Greene County Schools     1.000000
# 750               lea_name_Guilford County Schools     1.000000
# 751                lea_name_Halifax County Schools     1.000000
# 752                lea_name_Harnett County Schools     1.000000
# 753                lea_name_Haywood County Schools     1.000000
# 754              lea_name_Henderson County Schools     1.000000
# 755               lea_name_Hertford County Schools     1.000000
# 756                  lea_name_Hickory City Schools     1.000000
# 757                   lea_name_Hoke County Schools     1.000000
# 758                   lea_name_Hyde County Schools     1.000000
# 759           lea_name_Iredell-Statesville Schools     1.000000
# 760                lea_name_Jackson County Schools     1.000000
# 761               lea_name_Johnston County Schools     1.000000
# 762                  lea_name_Jones County Schools     1.000000
# 763               lea_name_Kannapolis City Schools     1.000000
# 764                    lea_name_Lee County Schools     1.000000
# 765                 lea_name_Lenoir County Schools     1.000000
# 766                lea_name_Lexington City Schools     1.000000
# 767                lea_name_Lincoln County Schools     1.000000
# 768                  lea_name_Macon County Schools     1.000000
# 769                lea_name_Madison County Schools     1.000000
# 770                 lea_name_Martin County Schools     1.000000
# 771               lea_name_McDowell County Schools     1.000000
# 772               lea_name_Mitchell County Schools     1.000000
# 773             lea_name_Montgomery County Schools     1.000000
# 774                  lea_name_Moore County Schools     1.000000
# 775              lea_name_Mooresville City Schools     1.000000
# 776               lea_name_Mount Airy City Schools     1.000000
# 777              lea_name_Nash-Rocky Mount Schools     1.000000
# 778            lea_name_New Hanover County Schools     1.000000
# 779           lea_name_Newton-Conover City Schools     1.000000
# 780            lea_name_Northampton County Schools     1.000000
# 781                 lea_name_Onslow County Schools     1.000000
# 782                 lea_name_Orange County Schools     1.000000
# 783                lea_name_Pamlico County Schools     1.000000
# 784             lea_name_Pasquotank County Schools     1.000000
# 785                 lea_name_Pender County Schools     1.000000
# 786             lea_name_Perquimans County Schools     1.000000
# 787                 lea_name_Person County Schools     1.000000
# 788                   lea_name_Pitt County Schools     1.000000
# 789                   lea_name_Polk County Schools     1.000000
# 790               lea_name_Randolph County Schools     1.000000
# 791               lea_name_Richmond County Schools     1.000000
# 792           lea_name_Roanoke Rapids City Schools     1.000000
# 793                lea_name_Robeson County Schools     1.000000
# 794             lea_name_Rockingham County Schools     1.000000
# 795        lea_name_Rowan-Salisbury County Schools     1.000000
# 796             lea_name_Rutherford County Schools     1.000000
# 797                lea_name_Sampson County Schools     1.000000
# 798               lea_name_Scotland County Schools     1.000000
# 799                 lea_name_Stanly County Schools     1.000000
# 800                 lea_name_Stokes County Schools     1.000000
# 801                  lea_name_Surry County Schools     1.000000
# 802                  lea_name_Swain County Schools     1.000000
# 803                  lea_name_Swain County Schools     1.000000
# 804              lea_name_Thomasville City Schools     1.000000
# 805           lea_name_Transylvania County Schools     1.000000
# 806                lea_name_Tyrrell County Schools     1.000000
# 807                  lea_name_Union County Schools     1.000000
# 808                  lea_name_Vance County Schools     1.000000
# 809                   lea_name_Wake County Schools     1.000000
# 810                 lea_name_Warren County Schools     1.000000
# 811             lea_name_Washington County Schools     1.000000
# 812                lea_name_Watauga County Schools     1.000000
# 813                  lea_name_Wayne County Schools     1.000000
# 814                   lea_name_Weldon City Schools     1.000000
# 815               lea_name_Whiteville City Schools     1.000000
# 816                 lea_name_Wilkes County Schools     1.000000
# 817                 lea_name_Wilson County Schools     1.000000
# 818                 lea_name_Yadkin County Schools     1.000000
# 819                 lea_name_Yancey County Schools     1.000000
# 820                  subgroup_list_ALL,AM7,EDS,WH7     1.000000

# %%
#The old way
#print('Dropping the following ', str(len(to_drop)), ' highly correlated fields.')
#to_drop

# Comparing highly correlated unique field names in field 1 vs field 2 list above will allow you to 
# remove the least amount of fields possible.  
#len(cf['Field1'].unique())
#len(cf['Field2'].unique())

print('Dropping the following ', str(len(cf['Field2'].unique())), ' highly correlated, unique fields.')
cf['Field2'].unique()
# Out:
# Dropping the following  456  highly correlated, unique fields.
# array(['indian_pct', 'asian_pct', 'white_pct', 'indian_male_pct',
#        'pct_ACALL_ALL_ACT', 'pct_ACALL_FEM_ACT', 'pct_ACALL_MALE_ACT',
#        'pct_ACCO_AIG_ACT', 'pct_ACCO_ALL_ACT', 'pct_ACCO_FEM_ACT',
#        'pct_ACCO_MALE_ACT', 'pct_ACCO_WH7_ACT', 'pct_ACEN_AIG_ACT',
#        'pct_ACEN_ALL_ACT', 'pct_ACEN_BL7_ACT', 'pct_ACEN_FEM_ACT',
#        'pct_ACEN_MALE_ACT', 'pct_ACEN_WH7_ACT', 'pct_ACMA_AIG_ACT',
#        'pct_ACMA_ALL_ACT', 'pct_ACMA_WH7_ACT', 'pct_ACRD_AIG_ACT',
#        'pct_ACRD_WH7_ACT', 'pct_ACWR_ALL_ACT', 'pct_AIG_AWA',
#        'pct_STD_ALL_CGR', 'pct_ALL_ELP', 'pct_Biology_ALL_PART_DET',
#        'pct_Biology_BL7_PART_DET', 'pct_Biology_EDS_PART_DET',
#        'pct_Biology_WH7_PART_DET', 'pct_High School Math_ALL_PART_DET',
#        'pct_High School Math_BL7_PART_DET',
#        'pct_High School Math_EDS_PART_DET',
#        'pct_High School Math_WH7_PART_DET', 'pct_CCR_BI_EOC_AIG_PC',
#        'pct_CCR_BI_EOC_ALL_PC', 'pct_CCR_BI_EOC_BL7_PC',
#        'pct_CCR_BI_EOC_EDS_PC', 'pct_CCR_BI_EOC_FEM_PC',
#        'pct_CCR_BI_EOC_HI7_PC', 'pct_CCR_BI_EOC_MALE_PC',
#        'pct_CCR_BI_EOC_WH7_PC', 'pct_CCR_E2_EOC_AIG_PC',
#        'pct_CCR_E2_EOC_ALL_PC', 'pct_CCR_E2_EOC_BL7_PC',
#        'pct_CCR_E2_EOC_EDS_PC', 'pct_CCR_E2_EOC_FEM_PC',
#        'pct_CCR_E2_EOC_HI7_PC', 'pct_CCR_E2_EOC_MALE_PC',
#        'pct_CCR_E2_EOC_WH7_PC', 'pct_CCR_EOC_EOC_AIG_PC',
#        'pct_CCR_EOC_EOC_ALL_PC', 'pct_CCR_EOC_EOC_BL7_PC',
#        'pct_CCR_EOC_EOC_EDS_PC', 'pct_CCR_EOC_EOC_ELS_PC',
#        'pct_CCR_EOC_EOC_FEM_PC', 'pct_CCR_EOC_EOC_HI7_PC',
#        'pct_CCR_EOC_EOC_MALE_PC', 'pct_CCR_EOC_EOC_MU7_PC',
#        'pct_CCR_EOC_EOC_SWD_PC', 'pct_CCR_EOC_EOC_WH7_PC',
#        'pct_CCR_M1_EOC_AIG_PC', 'pct_CCR_M1_EOC_ALL_PC',
#        'pct_CCR_M1_EOC_BL7_PC', 'pct_CCR_M1_EOC_EDS_PC',
#        'pct_CCR_M1_EOC_FEM_PC', 'pct_CCR_M1_EOC_HI7_PC',
#        'pct_CCR_M1_EOC_MALE_PC', 'pct_CCR_M1_EOC_WH7_PC',
#        'pct_GLP_BI_EOC_HI7_PC', 'pct_GLP_E2_EOC_AIG_PC',
#        'pct_GLP_E2_EOC_ALL_PC', 'pct_GLP_E2_EOC_BL7_PC',
#        'pct_GLP_E2_EOC_EDS_PC', 'pct_GLP_E2_EOC_FEM_PC',
#        'pct_GLP_E2_EOC_HI7_PC', 'pct_GLP_E2_EOC_MALE_PC',
#        'pct_GLP_E2_EOC_WH7_PC', 'pct_GLP_EOC_EOC_ALL_PC',
#        'pct_GLP_EOC_EOC_BL7_PC', 'pct_GLP_EOC_EOC_EDS_PC',
#        'pct_GLP_EOC_EOC_ELS_PC', 'pct_GLP_EOC_EOC_FEM_PC',
#        'pct_GLP_EOC_EOC_HI7_PC', 'pct_GLP_EOC_EOC_MALE_PC',
#        'pct_GLP_EOC_EOC_MU7_PC', 'pct_GLP_EOC_EOC_WH7_PC',
#        'pct_GLP_M1_EOC_ALL_PC', 'pct_GLP_M1_EOC_BL7_PC',
#        'pct_GLP_M1_EOC_EDS_PC', 'pct_GLP_M1_EOC_FEM_PC',
#        'pct_GLP_M1_EOC_HI7_PC', 'pct_L1_ALL_ALL_ALL_PC',
#        'pct_L1_ALL_ALL_EDS_PC', 'pct_L3_ALL_ALL_MU7_PC',
#        'pct_L4_ALL_ALL_AIG_PC', 'pct_L4_ALL_ALL_ALL_PC',
#        'pct_L4_ALL_ALL_BL7_PC', 'pct_L4_ALL_ALL_EDS_PC',
#        'pct_L4_ALL_ALL_FEM_PC', 'pct_L4_ALL_ALL_HI7_PC',
#        'pct_L4_ALL_ALL_MALE_PC', 'pct_L4_ALL_ALL_MU7_PC',
#        'pct_L4_ALL_ALL_WH7_PC', 'pct_L4_EOC_EOC_ALL_PC',
#        'pct_L4_M1_EOC_ALL_PC', 'pct_L5_ALL_ALL_AIG_PC',
#        'pct_L5_ALL_ALL_ALL_PC', 'pct_L5_ALL_ALL_FEM_PC',
#        'pct_L5_ALL_ALL_MALE_PC', 'pct_L5_ALL_ALL_WH7_PC',
#        'pct_L5_EOC_EOC_ALL_PC', 'pct_L5_M1_EOC_ALL_PC', 'mcr_score',
#        'ach_score', 'aaa_score_HI7_SPG2', 'ach_score_ALL_SPG2',
#        'ach_score_BL7_SPG2', 'ach_score_EDS_SPG2', 'ach_score_HI7_SPG2',
#        'ach_score_SWD_SPG2', 'ach_score_WH7_SPG2', 'awa_score_WH7_SPG2',
#        'avg_student_num', 'pct_ALL_CHRON_ABSENT', 'num_enrollments',
#        'stu_enroll', 'cte_enroll', 'arre_per1000_ALL', 'arre_per1000_BL7',
#        'blhr_per1000_ALL', 'crime_per1000_ELS', 'exp_per1000_ALL',
#        'exp_per1000_BL7', 'iss_per1000_ALL', 'lea_code_020LEA',
#        'lea_code_030LEA', 'lea_code_040LEA', 'lea_code_050LEA',
#        'lea_code_060LEA', 'lea_code_070LEA', 'lea_code_080LEA',
#        'lea_code_090LEA', 'lea_code_100LEA', 'lea_code_110LEA',
#        'lea_code_111LEA', 'lea_code_120LEA', 'lea_code_130LEA',
#        'lea_code_132LEA', 'lea_code_140LEA', 'lea_code_150LEA',
#        'lea_code_160LEA', 'lea_code_170LEA', 'lea_code_180LEA',
#        'lea_code_181LEA', 'lea_code_182LEA', 'lea_code_190LEA',
#        'lea_code_200LEA', 'lea_code_210LEA', 'lea_code_220LEA',
#        'lea_code_230LEA', 'lea_code_240LEA', 'lea_code_241LEA',
#        'lea_code_250LEA', 'lea_code_260LEA', 'lea_code_270LEA',
#        'lea_code_280LEA', 'lea_code_290LEA', 'lea_code_291LEA',
#        'lea_code_292LEA', 'lea_code_300LEA', 'lea_code_310LEA',
#        'lea_code_320LEA', 'lea_code_330LEA', 'lea_code_340LEA',
#        'lea_code_350LEA', 'lea_code_360LEA', 'lea_code_370LEA',
#        'lea_code_380LEA', 'lea_code_390LEA', 'lea_code_400LEA',
#        'lea_code_410LEA', 'lea_code_420LEA', 'lea_code_421LEA',
#        'lea_code_422LEA', 'lea_code_430LEA', 'lea_code_440LEA',
#        'lea_code_450LEA', 'lea_code_460LEA', 'lea_code_470LEA',
#        'lea_code_480LEA', 'lea_code_490LEA', 'lea_code_491LEA',
#        'lea_code_500LEA', 'lea_code_510LEA', 'lea_code_520LEA',
#        'lea_code_530LEA', 'lea_code_540LEA', 'lea_code_550LEA',
#        'lea_code_560LEA', 'lea_code_570LEA', 'lea_code_580LEA',
#        'lea_code_590LEA', 'lea_code_600LEA', 'lea_code_610LEA',
#        'lea_code_620LEA', 'lea_code_630LEA', 'lea_code_640LEA',
#        'lea_code_650LEA', 'lea_code_660LEA', 'lea_code_670LEA',
#        'lea_code_680LEA', 'lea_code_681LEA', 'lea_code_690LEA',
#        'lea_code_700LEA', 'lea_code_710LEA', 'lea_code_720LEA',
#        'lea_code_730LEA', 'lea_code_740LEA', 'lea_code_750LEA',
#        'lea_code_760LEA', 'lea_code_761LEA', 'lea_code_770LEA',
#        'lea_code_780LEA', 'lea_code_790LEA', 'lea_code_800LEA',
#        'lea_code_810LEA', 'lea_code_820LEA', 'lea_code_821LEA',
#        'lea_code_830LEA', 'lea_code_840LEA', 'lea_code_850LEA',
#        'lea_code_860LEA', 'lea_code_861LEA', 'lea_code_862LEA',
#        'lea_code_870LEA', 'lea_code_880LEA', 'lea_code_890LEA',
#        'lea_code_900LEA', 'lea_code_910LEA', 'lea_code_920LEA',
#        'lea_code_930LEA', 'lea_code_940LEA', 'lea_code_950LEA',
#        'lea_code_960LEA', 'lea_code_970LEA', 'lea_code_980LEA',
#        'lea_code_990LEA', 'lea_code_995LEA', 'county_Alexander',
#        'county_Alleghany', 'county_Anson', 'county_Ashe', 'county_Avery',
#        'county_Beaufort', 'county_Bertie', 'county_Bladen',
#        'county_Brunswick', 'county_Burke', 'county_Cabarrus',
#        'county_Caldwell', 'county_Camden', 'county_Carteret',
#        'county_Caswell', 'county_Chatham', 'county_Cherokee',
#        'county_Chowan', 'county_Clay', 'county_Cleveland',
#        'county_Craven', 'county_Cumberland', 'county_Currituck',
#        'county_Dare', 'county_Davie', 'county_Duplin', 'county_Durham',
#        'county_Edgecombe', 'county_Forsyth', 'county_Franklin',
#        'county_Gaston', 'county_Gates', 'county_Graham',
#        'county_Granville', 'county_Greene', 'county_Guilford',
#        'county_Harnett', 'county_Haywood', 'county_Henderson',
#        'county_Hertford', 'county_Hoke', 'county_Hyde', 'county_Iredell',
#        'county_Jackson', 'county_Johnston', 'county_Jones', 'county_Lee',
#        'county_Lenoir', 'county_Lincoln', 'county_Macon',
#        'county_Madison', 'county_Martin', 'county_McDowell',
#        'county_Mecklenburg', 'county_Mitchell', 'county_Montgomery',
#        'county_Moore', 'county_Nash', 'county_New Hanover',
#        'county_Northampton', 'county_Onslow', 'county_Pamlico',
#        'county_Pasquotank', 'county_Pender', 'county_Perquimans',
#        'county_Person', 'county_Pitt', 'county_Polk', 'county_Richmond',
#        'county_Robeson', 'county_Rockingham', 'county_Rowan',
#        'county_Rutherford', 'county_Scotland', 'county_Stanly',
#        'county_Stokes', 'county_Swain', 'county_Transylvania',
#        'county_Tyrrell', 'county_Union', 'county_Vance', 'county_Wake',
#        'county_Warren', 'county_Washington', 'county_Watauga',
#        'county_Wayne', 'county_Wilkes', 'county_Wilson', 'county_Yadkin',
#        'county_Yancey', 'grade_span_KG:13',
#        'lea_name_Alexander County Schools',
#        'lea_name_Alleghany County Schools',
#        'lea_name_Anson County Schools', 'lea_name_Ashe County Schools',
#        'lea_name_Asheboro City Schools',
#        'lea_name_Asheville City Schools', 'lea_name_Avery County Schools',
#        'lea_name_Beaufort County Schools',
#        'lea_name_Bertie County Schools', 'lea_name_Bladen County Schools',
#        'lea_name_Brunswick County Schools',
#        'lea_name_Buncombe County Schools',
#        'lea_name_Burke County Schools',
#        'lea_name_Cabarrus County Schools',
#        'lea_name_Caldwell County Schools',
#        'lea_name_Camden County Schools',
#        'lea_name_Carteret County Schools',
#        'lea_name_Caswell County Schools',
#        'lea_name_Catawba County Schools',
#        'lea_name_Chapel-Hill/Carrboro City Schools',
#        'lea_name_Charlotte-Mecklenburg County Schools',
#        'lea_name_Chatham County Schools',
#        'lea_name_Cherokee County Schools', 'lea_name_Clay County Schools',
#        'lea_name_Cleveland County Schools',
#        'lea_name_Clinton City Schools',
#        'lea_name_Columbus County Schools',
#        'lea_name_Craven County Schools',
#        'lea_name_Cumberland County Schools',
#        'lea_name_Currituck County Schools',
#        'lea_name_Dare County Schools', 'lea_name_Davidson County Schools',
#        'lea_name_Davie County Schools', 'lea_name_Duplin County Schools',
#        'lea_name_Durham County Schools',
#        'lea_name_Edenton-Chowan County Schools',
#        'lea_name_Edgecombe County Schools', 'lea_name_Elkin City Schools',
#        'lea_name_Forsyth County Schools',
#        'lea_name_Franklin County Schools',
#        'lea_name_Gaston County Schools', 'lea_name_Gates County Schools',
#        'lea_name_Graham County Schools',
#        'lea_name_Granville County Schools',
#        'lea_name_Greene County Schools',
#        'lea_name_Guilford County Schools',
#        'lea_name_Halifax County Schools',
#        'lea_name_Harnett County Schools',
#        'lea_name_Haywood County Schools',
#        'lea_name_Henderson County Schools',
#        'lea_name_Hertford County Schools',
#        'lea_name_Hickory City Schools', 'lea_name_Hoke County Schools',
#        'lea_name_Hyde County Schools',
#        'lea_name_Iredell-Statesville Schools',
#        'lea_name_Jackson County Schools',
#        'lea_name_Johnston County Schools',
#        'lea_name_Jones County Schools',
#        'lea_name_Kannapolis City Schools', 'lea_name_Lee County Schools',
#        'lea_name_Lenoir County Schools',
#        'lea_name_Lexington City Schools',
#        'lea_name_Lincoln County Schools', 'lea_name_Macon County Schools',
#        'lea_name_Madison County Schools',
#        'lea_name_Martin County Schools',
#        'lea_name_McDowell County Schools',
#        'lea_name_Mitchell County Schools',
#        'lea_name_Montgomery County Schools',
#        'lea_name_Moore County Schools',
#        'lea_name_Mooresville City Schools',
#        'lea_name_Mount Airy City Schools',
#        'lea_name_Nash-Rocky Mount Schools',
#        'lea_name_New Hanover County Schools',
#        'lea_name_Newton-Conover City Schools',
#        'lea_name_Northampton County Schools',
#        'lea_name_Onslow County Schools', 'lea_name_Orange County Schools',
#        'lea_name_Pamlico County Schools',
#        'lea_name_Pasquotank County Schools',
#        'lea_name_Pender County Schools',
#        'lea_name_Perquimans County Schools',
#        'lea_name_Person County Schools', 'lea_name_Pitt County Schools',
#        'lea_name_Polk County Schools', 'lea_name_Randolph County Schools',
#        'lea_name_Richmond County Schools',
#        'lea_name_Roanoke Rapids City Schools',
#        'lea_name_Robeson County Schools',
#        'lea_name_Rockingham County Schools',
#        'lea_name_Rowan-Salisbury County Schools',
#        'lea_name_Rutherford County Schools',
#        'lea_name_Sampson County Schools',
#        'lea_name_Scotland County Schools',
#        'lea_name_Stanly County Schools', 'lea_name_Stokes County Schools',
#        'lea_name_Surry County Schools', 'lea_name_Swain County Schools',
#        'lea_name_Thomasville City Schools',
#        'lea_name_Transylvania County Schools',
#        'lea_name_Tyrrell County Schools', 'lea_name_Union County Schools',
#        'lea_name_Vance County Schools', 'lea_name_Wake County Schools',
#        'lea_name_Warren County Schools',
#        'lea_name_Washington County Schools',
#        'lea_name_Watauga County Schools', 'lea_name_Wayne County Schools',
#        'lea_name_Weldon City Schools', 'lea_name_Whiteville City Schools',
#        'lea_name_Wilkes County Schools', 'lea_name_Wilson County Schools',
#        'lea_name_Yadkin County Schools', 'lea_name_Yancey County Schools',
#        'subgroup_list_ALL,AM7,EDS,WH7'], dtype=object)

# %%
#Check columns before drop 
print('\r\n*********Before: Dropping Highly Correlated Fields*************************************')
schoolData.info(verbose=False)

# Drop the highly correlated features from our training data 
#schoolData = schoolData.drop(to_drop, axis=1)
schoolData = schoolData.drop(cf['Field2'], axis=1)

#Check columns after drop 
print('\r\n*********After: Dropping Highly Correlated Fields**************************************')
schoolData.info(verbose=False)
# Out:
# *********Before: Dropping Highly Correlated Fields*************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 603 entries, 2 to 678
# Columns: 1290 entries, lea to agency_lea_code_995LEA
# dtypes: float64(709), uint8(581)
# memory usage: 3.6 MB
#
# *********After: Dropping Highly Correlated Fields**************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 603 entries, 2 to 678
# Columns: 834 entries, lea to agency_lea_code_995LEA
# dtypes: float64(573), uint8(261)
# memory usage: 2.8 MB

# %%
#Restore the unit_code before saving
schoolData['agency_code'] = agency_code
#Save the final dataset to a .csv file
schoolData.to_csv(outputDir + inputFileName + '_ML.csv', sep=',', index=False)

# %%
print('*********FINAL DATASET DETAILS*********************************************************\r\n')
schoolData.info(verbose=True)
# Out:
# *********FINAL DATASET DETAILS*********************************************************
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 603 entries, 2 to 678
# Data columns (total 835 columns):
#  #   Column                                                                                                            Dtype
# ---  ------                                                                                                            -----
#  0   lea                                                                                                               float64
#  1   school                                                                                                            float64
#  2   hispanic_pct                                                                                                      float64
#  3   black_pct                                                                                                         float64
#  4   pacific_island_pct                                                                                                float64
#  5   two_or_more_pct                                                                                                   float64
#  6   minority_pct                                                                                                      float64
#  7   asian_male_pct                                                                                                    float64
#  8   hispanic_male_pct                                                                                                 float64
#  9   black_male_pct                                                                                                    float64
#  10  white_male_pct                                                                                                    float64
#  11  pacific_island_male_pct                                                                                           float64
#  12  two_or_more_male_pct                                                                                              float64
#  13  minority_male_pct                                                                                                 float64
#  14  indian_female_pct                                                                                                 float64
#  15  asian_female_pct                                                                                                  float64
#  16  hispanic_female_pct                                                                                               float64
#  17  black_female_pct                                                                                                  float64
#  18  white_female_pct                                                                                                  float64
#  19  minority_female_pct                                                                                               float64
#  20  pacific_island_female_pct                                                                                         float64
#  21  two_or_more_female_pct                                                                                            float64
#  22  ccc_pct_COMP1Y_ALL_161                                                                                            float64
#  23  ccc_pct_COMP1Y_BL7_161                                                                                            float64
#  24  ccc_pct_COMP1Y_EDS_161                                                                                            float64
#  25  ccc_pct_COMP1Y_FEM_161                                                                                            float64
#  26  ccc_pct_COMP1Y_MALE_161                                                                                           float64
#  27  ccc_pct_COMP1Y_WH7_161                                                                                            float64
#  28  ccc_pct_NOCOMP1Y_ALL_161                                                                                          float64
#  29  ccc_pct_NOCOMP1Y_BL7_161                                                                                          float64
#  30  ccc_pct_NOCOMP1Y_EDS_161                                                                                          float64
#  31  ccc_pct_NOCOMP1Y_FEM_161                                                                                          float64
#  32  ccc_pct_NOCOMP1Y_MALE_161                                                                                         float64
#  33  ccc_pct_NOCOMP1Y_WH7_161                                                                                          float64
#  34  ccc_pct_NOINFO_ALL_161                                                                                            float64
#  35  ccc_pct_NOINFO_BL7_161                                                                                            float64
#  36  ccc_pct_NOINFO_EDS_161                                                                                            float64
#  37  ccc_pct_NOINFO_FEM_161                                                                                            float64
#  38  ccc_pct_NOINFO_MALE_161                                                                                           float64
#  39  ccc_pct_NOINFO_WH7_161                                                                                            float64
#  40  pct_ACALL_AIG_ACT                                                                                                 float64
#  41  pct_ACALL_AS7_ACT                                                                                                 float64
#  42  pct_ACALL_BL7_ACT                                                                                                 float64
#  43  pct_ACALL_EDS_ACT                                                                                                 float64
#  44  pct_ACALL_ELS_ACT                                                                                                 float64
#  45  pct_ACALL_HI7_ACT                                                                                                 float64
#  46  pct_ACALL_MU7_ACT                                                                                                 float64
#  47  pct_ACALL_SWD_ACT                                                                                                 float64
#  48  pct_ACALL_WH7_ACT                                                                                                 float64
#  49  pct_ACCO_BL7_ACT                                                                                                  float64
#  50  pct_ACCO_EDS_ACT                                                                                                  float64
#  51  pct_ACCO_HI7_ACT                                                                                                  float64
#  52  pct_ACCO_SWD_ACT                                                                                                  float64
#  53  pct_ACEN_EDS_ACT                                                                                                  float64
#  54  pct_ACEN_HI7_ACT                                                                                                  float64
#  55  pct_ACEN_SWD_ACT                                                                                                  float64
#  56  pct_ACMA_BL7_ACT                                                                                                  float64
#  57  pct_ACMA_EDS_ACT                                                                                                  float64
#  58  pct_ACMA_FEM_ACT                                                                                                  float64
#  59  pct_ACMA_HI7_ACT                                                                                                  float64
#  60  pct_ACMA_MALE_ACT                                                                                                 float64
#  61  pct_ACMA_SWD_ACT                                                                                                  float64
#  62  pct_ACRD_ALL_ACT                                                                                                  float64
#  63  pct_ACRD_BL7_ACT                                                                                                  float64
#  64  pct_ACRD_EDS_ACT                                                                                                  float64
#  65  pct_ACRD_FEM_ACT                                                                                                  float64
#  66  pct_ACRD_HI7_ACT                                                                                                  float64
#  67  pct_ACRD_MALE_ACT                                                                                                 float64
#  68  pct_ACRD_SWD_ACT                                                                                                  float64
#  69  pct_ACSC_AIG_ACT                                                                                                  float64
#  70  pct_ACSC_ALL_ACT                                                                                                  float64
#  71  pct_ACSC_BL7_ACT                                                                                                  float64
#  72  pct_ACSC_EDS_ACT                                                                                                  float64
#  73  pct_ACSC_FEM_ACT                                                                                                  float64
#  74  pct_ACSC_HI7_ACT                                                                                                  float64
#  75  pct_ACSC_MALE_ACT                                                                                                 float64
#  76  pct_ACSC_SWD_ACT                                                                                                  float64
#  77  pct_ACSC_WH7_ACT                                                                                                  float64
#  78  pct_ACWR_AIG_ACT                                                                                                  float64
#  79  pct_ACWR_BL7_ACT                                                                                                  float64
#  80  pct_ACWR_EDS_ACT                                                                                                  float64
#  81  pct_ACWR_FEM_ACT                                                                                                  float64
#  82  pct_ACWR_HI7_ACT                                                                                                  float64
#  83  pct_ACWR_MALE_ACT                                                                                                 float64
#  84  pct_ACWR_SWD_ACT                                                                                                  float64
#  85  pct_ACWR_WH7_ACT                                                                                                  float64
#  86  pct_ALL_AWA                                                                                                       float64
#  87  pct_BL7_AWA                                                                                                       float64
#  88  pct_EDS_AWA                                                                                                       float64
#  89  pct_FEM_AWA                                                                                                       float64
#  90  pct_HI7_AWA                                                                                                       float64
#  91  pct_MALE_AWA                                                                                                      float64
#  92  pct_SWD_AWA                                                                                                       float64
#  93  pct_WH7_AWA                                                                                                       float64
#  94  pct_EXT_AIG_CGR                                                                                                   float64
#  95  pct_EXT_ALL_CGR                                                                                                   float64
#  96  pct_EXT_BL7_CGR                                                                                                   float64
#  97  pct_EXT_EDS_CGR                                                                                                   float64
#  98  pct_EXT_FEM_CGR                                                                                                   float64
#  99  pct_EXT_HI7_CGR                                                                                                   float64
#  100 pct_EXT_MALE_CGR                                                                                                  float64
#  101 pct_EXT_SWD_CGR                                                                                                   float64
#  102 pct_EXT_WH7_CGR                                                                                                   float64
#  103 pct_STD_AIG_CGR                                                                                                   float64
#  104 pct_STD_BL7_CGR                                                                                                   float64
#  105 pct_STD_EDS_CGR                                                                                                   float64
#  106 pct_STD_FEM_CGR                                                                                                   float64
#  107 pct_STD_HI7_CGR                                                                                                   float64
#  108 pct_STD_MALE_CGR                                                                                                  float64
#  109 pct_STD_SWD_CGR                                                                                                   float64
#  110 pct_STD_WH7_CGR                                                                                                   float64
#  111 pct_eds                                                                                                           float64
#  112 pct_EDS_ELP                                                                                                       float64
#  113 pct_ELS_ELP                                                                                                       float64
#  114 pct_HI7_ELP                                                                                                       float64
#  115 pct_MALE_ELP                                                                                                      float64
#  116 pct_prof_9gr_irm                                                                                                  float64
#  117 pct_met_4 Year Graduation Rate_LTG                                                                                float64
#  118 pct_met_Math Grade 11_LTG                                                                                         float64
#  119 pct_met_Reading Grade 10_LTG                                                                                      float64
#  120 pct_met_Total Targets_LTG                                                                                         float64
#  121 pct_AIG_MCR                                                                                                       float64
#  122 pct_ALL_MCR                                                                                                       float64
#  123 pct_BL7_MCR                                                                                                       float64
#  124 pct_EDS_MCR                                                                                                       float64
#  125 pct_FEM_MCR                                                                                                       float64
#  126 pct_HI7_MCR                                                                                                       float64
#  127 pct_MALE_MCR                                                                                                      float64
#  128 pct_SWD_MCR                                                                                                       float64
#  129 pct_WH7_MCR                                                                                                       float64
#  130 pct_met_ACT WorkKeys_PART                                                                                         float64
#  131 pct_met_Biology_PART                                                                                              float64
#  132 pct_met_English II_PART                                                                                           float64
#  133 pct_met_High School Math_PART                                                                                     float64
#  134 pct_met_The ACT_PART                                                                                              float64
#  135 pct_met_Total Targets_PART                                                                                        float64
#  136 pct_ACT WorkKeys_ALL_PART_DET                                                                                     float64
#  137 pct_ACT WorkKeys_WH7_PART_DET                                                                                     float64
#  138 pct_English II_ALL_PART_DET                                                                                       float64
#  139 pct_English II_BL7_PART_DET                                                                                       float64
#  140 pct_English II_EDS_PART_DET                                                                                       float64
#  141 pct_English II_WH7_PART_DET                                                                                       float64
#  142 pct_The ACT_ALL_PART_DET                                                                                          float64
#  143 pct_The ACT_BL7_PART_DET                                                                                          float64
#  144 pct_The ACT_EDS_PART_DET                                                                                          float64
#  145 pct_The ACT_WH7_PART_DET                                                                                          float64
#  146 pct_CCR_BI_EOC_SWD_PC                                                                                             float64
#  147 pct_CCR_E2_EOC_SWD_PC                                                                                             float64
#  148 pct_CCR_M1_EOC_SWD_PC                                                                                             float64
#  149 pct_GLP_BI_EOC_AIG_PC                                                                                             float64
#  150 pct_GLP_BI_EOC_ALL_PC                                                                                             float64
#  151 pct_GLP_BI_EOC_BL7_PC                                                                                             float64
#  152 pct_GLP_BI_EOC_EDS_PC                                                                                             float64
#  153 pct_GLP_BI_EOC_FEM_PC                                                                                             float64
#  154 pct_GLP_BI_EOC_MALE_PC                                                                                            float64
#  155 pct_GLP_BI_EOC_SWD_PC                                                                                             float64
#  156 pct_GLP_BI_EOC_WH7_PC                                                                                             float64
#  157 pct_GLP_E2_EOC_SWD_PC                                                                                             float64
#  158 pct_GLP_EOC_EOC_AIG_PC                                                                                            float64
#  159 pct_GLP_EOC_EOC_SWD_PC                                                                                            float64
#  160 pct_GLP_M1_EOC_AIG_PC                                                                                             float64
#  161 pct_GLP_M1_EOC_MALE_PC                                                                                            float64
#  162 pct_GLP_M1_EOC_SWD_PC                                                                                             float64
#  163 pct_GLP_M1_EOC_WH7_PC                                                                                             float64
#  164 pct_L1_ALL_ALL_BL7_PC                                                                                             float64
#  165 pct_L1_ALL_ALL_ELS_PC                                                                                             float64
#  166 pct_L1_ALL_ALL_FEM_PC                                                                                             float64
#  167 pct_L1_ALL_ALL_HI7_PC                                                                                             float64
#  168 pct_L1_ALL_ALL_MALE_PC                                                                                            float64
#  169 pct_L1_ALL_ALL_MU7_PC                                                                                             float64
#  170 pct_L1_ALL_ALL_SWD_PC                                                                                             float64
#  171 pct_L1_ALL_ALL_WH7_PC                                                                                             float64
#  172 pct_L1_BI_EOC_ALL_PC                                                                                              float64
#  173 pct_L1_BI_EOC_BL7_PC                                                                                              float64
#  174 pct_L1_BI_EOC_EDS_PC                                                                                              float64
#  175 pct_L1_BI_EOC_FEM_PC                                                                                              float64
#  176 pct_L1_BI_EOC_HI7_PC                                                                                              float64
#  177 pct_L1_BI_EOC_MALE_PC                                                                                             float64
#  178 pct_L1_BI_EOC_SWD_PC                                                                                              float64
#  179 pct_L1_BI_EOC_WH7_PC                                                                                              float64
#  180 pct_L1_E2_EOC_ALL_PC                                                                                              float64
#  181 pct_L1_E2_EOC_BL7_PC                                                                                              float64
#  182 pct_L1_E2_EOC_EDS_PC                                                                                              float64
#  183 pct_L1_E2_EOC_FEM_PC                                                                                              float64
#  184 pct_L1_E2_EOC_HI7_PC                                                                                              float64
#  185 pct_L1_E2_EOC_MALE_PC                                                                                             float64
#  186 pct_L1_E2_EOC_SWD_PC                                                                                              float64
#  187 pct_L1_E2_EOC_WH7_PC                                                                                              float64
#  188 pct_L1_EOC_EOC_ALL_PC                                                                                             float64
#  189 pct_L1_EOC_EOC_BL7_PC                                                                                             float64
#  190 pct_L1_EOC_EOC_EDS_PC                                                                                             float64
#  191 pct_L1_EOC_EOC_ELS_PC                                                                                             float64
#  192 pct_L1_EOC_EOC_FEM_PC                                                                                             float64
#  193 pct_L1_EOC_EOC_HI7_PC                                                                                             float64
#  194 pct_L1_EOC_EOC_MALE_PC                                                                                            float64
#  195 pct_L1_EOC_EOC_MU7_PC                                                                                             float64
#  196 pct_L1_EOC_EOC_SWD_PC                                                                                             float64
#  197 pct_L1_EOC_EOC_WH7_PC                                                                                             float64
#  198 pct_L1_M1_EOC_ALL_PC                                                                                              float64
#  199 pct_L1_M1_EOC_BL7_PC                                                                                              float64
#  200 pct_L1_M1_EOC_EDS_PC                                                                                              float64
#  201 pct_L1_M1_EOC_FEM_PC                                                                                              float64
#  202 pct_L1_M1_EOC_HI7_PC                                                                                              float64
#  203 pct_L1_M1_EOC_MALE_PC                                                                                             float64
#  204 pct_L1_M1_EOC_SWD_PC                                                                                              float64
#  205 pct_L1_M1_EOC_WH7_PC                                                                                              float64
#  206 pct_L2_ALL_ALL_ALL_PC                                                                                             float64
#  207 pct_L2_ALL_ALL_BL7_PC                                                                                             float64
#  208 pct_L2_ALL_ALL_EDS_PC                                                                                             float64
#  209 pct_L2_ALL_ALL_ELS_PC                                                                                             float64
#  210 pct_L2_ALL_ALL_FEM_PC                                                                                             float64
#  211 pct_L2_ALL_ALL_HI7_PC                                                                                             float64
#  212 pct_L2_ALL_ALL_MALE_PC                                                                                            float64
#  213 pct_L2_ALL_ALL_MU7_PC                                                                                             float64
#  214 pct_L2_ALL_ALL_SWD_PC                                                                                             float64
#  215 pct_L2_ALL_ALL_WH7_PC                                                                                             float64
#  216 pct_L2_BI_EOC_ALL_PC                                                                                              float64
#  217 pct_L2_BI_EOC_BL7_PC                                                                                              float64
#  218 pct_L2_BI_EOC_EDS_PC                                                                                              float64
#  219 pct_L2_BI_EOC_FEM_PC                                                                                              float64
#  220 pct_L2_BI_EOC_HI7_PC                                                                                              float64
#  221 pct_L2_BI_EOC_MALE_PC                                                                                             float64
#  222 pct_L2_BI_EOC_SWD_PC                                                                                              float64
#  223 pct_L2_BI_EOC_WH7_PC                                                                                              float64
#  224 pct_L2_E2_EOC_ALL_PC                                                                                              float64
#  225 pct_L2_E2_EOC_BL7_PC                                                                                              float64
#  226 pct_L2_E2_EOC_EDS_PC                                                                                              float64
#  227 pct_L2_E2_EOC_FEM_PC                                                                                              float64
#  228 pct_L2_E2_EOC_HI7_PC                                                                                              float64
#  229 pct_L2_E2_EOC_MALE_PC                                                                                             float64
#  230 pct_L2_E2_EOC_SWD_PC                                                                                              float64
#  231 pct_L2_E2_EOC_WH7_PC                                                                                              float64
#  232 pct_L2_EOC_EOC_ALL_PC                                                                                             float64
#  233 pct_L2_EOC_EOC_BL7_PC                                                                                             float64
#  234 pct_L2_EOC_EOC_EDS_PC                                                                                             float64
#  235 pct_L2_EOC_EOC_ELS_PC                                                                                             float64
#  236 pct_L2_EOC_EOC_FEM_PC                                                                                             float64
#  237 pct_L2_EOC_EOC_HI7_PC                                                                                             float64
#  238 pct_L2_EOC_EOC_MALE_PC                                                                                            float64
#  239 pct_L2_EOC_EOC_MU7_PC                                                                                             float64
#  240 pct_L2_EOC_EOC_SWD_PC                                                                                             float64
#  241 pct_L2_EOC_EOC_WH7_PC                                                                                             float64
#  242 pct_L2_M1_EOC_ALL_PC                                                                                              float64
#  243 pct_L2_M1_EOC_BL7_PC                                                                                              float64
#  244 pct_L2_M1_EOC_EDS_PC                                                                                              float64
#  245 pct_L2_M1_EOC_FEM_PC                                                                                              float64
#  246 pct_L2_M1_EOC_HI7_PC                                                                                              float64
#  247 pct_L2_M1_EOC_MALE_PC                                                                                             float64
#  248 pct_L2_M1_EOC_SWD_PC                                                                                              float64
#  249 pct_L2_M1_EOC_WH7_PC                                                                                              float64
#  250 pct_L3_ALL_ALL_ALL_PC                                                                                             float64
#  251 pct_L3_ALL_ALL_BL7_PC                                                                                             float64
#  252 pct_L3_ALL_ALL_EDS_PC                                                                                             float64
#  253 pct_L3_ALL_ALL_FEM_PC                                                                                             float64
#  254 pct_L3_ALL_ALL_HI7_PC                                                                                             float64
#  255 pct_L3_ALL_ALL_MALE_PC                                                                                            float64
#  256 pct_L3_ALL_ALL_SWD_PC                                                                                             float64
#  257 pct_L3_ALL_ALL_WH7_PC                                                                                             float64
#  258 pct_L3_BI_EOC_ALL_PC                                                                                              float64
#  259 pct_L3_BI_EOC_BL7_PC                                                                                              float64
#  260 pct_L3_BI_EOC_EDS_PC                                                                                              float64
#  261 pct_L3_BI_EOC_FEM_PC                                                                                              float64
#  262 pct_L3_BI_EOC_HI7_PC                                                                                              float64
#  263 pct_L3_BI_EOC_MALE_PC                                                                                             float64
#  264 pct_L3_BI_EOC_WH7_PC                                                                                              float64
#  265 pct_L3_E2_EOC_ALL_PC                                                                                              float64
#  266 pct_L3_E2_EOC_BL7_PC                                                                                              float64
#  267 pct_L3_E2_EOC_EDS_PC                                                                                              float64
#  268 pct_L3_E2_EOC_FEM_PC                                                                                              float64
#  269 pct_L3_E2_EOC_HI7_PC                                                                                              float64
#  270 pct_L3_E2_EOC_MALE_PC                                                                                             float64
#  271 pct_L3_E2_EOC_WH7_PC                                                                                              float64
#  272 pct_L3_EOC_EOC_ALL_PC                                                                                             float64
#  273 pct_L3_EOC_EOC_BL7_PC                                                                                             float64
#  274 pct_L3_EOC_EOC_EDS_PC                                                                                             float64
#  275 pct_L3_EOC_EOC_FEM_PC                                                                                             float64
#  276 pct_L3_EOC_EOC_HI7_PC                                                                                             float64
#  277 pct_L3_EOC_EOC_MALE_PC                                                                                            float64
#  278 pct_L3_EOC_EOC_MU7_PC                                                                                             float64
#  279 pct_L3_EOC_EOC_SWD_PC                                                                                             float64
#  280 pct_L3_EOC_EOC_WH7_PC                                                                                             float64
#  281 pct_L3_M1_EOC_ALL_PC                                                                                              float64
#  282 pct_L3_M1_EOC_BL7_PC                                                                                              float64
#  283 pct_L3_M1_EOC_EDS_PC                                                                                              float64
#  284 pct_L3_M1_EOC_FEM_PC                                                                                              float64
#  285 pct_L3_M1_EOC_HI7_PC                                                                                              float64
#  286 pct_L3_M1_EOC_MALE_PC                                                                                             float64
#  287 pct_L3_M1_EOC_WH7_PC                                                                                              float64
#  288 pct_L4_ALL_ALL_ELS_PC                                                                                             float64
#  289 pct_L4_ALL_ALL_SWD_PC                                                                                             float64
#  290 pct_L4_BI_EOC_AIG_PC                                                                                              float64
#  291 pct_L4_BI_EOC_ALL_PC                                                                                              float64
#  292 pct_L4_BI_EOC_BL7_PC                                                                                              float64
#  293 pct_L4_BI_EOC_EDS_PC                                                                                              float64
#  294 pct_L4_BI_EOC_FEM_PC                                                                                              float64
#  295 pct_L4_BI_EOC_HI7_PC                                                                                              float64
#  296 pct_L4_BI_EOC_MALE_PC                                                                                             float64
#  297 pct_L4_BI_EOC_SWD_PC                                                                                              float64
#  298 pct_L4_BI_EOC_WH7_PC                                                                                              float64
#  299 pct_L4_E2_EOC_AIG_PC                                                                                              float64
#  300 pct_L4_E2_EOC_ALL_PC                                                                                              float64
#  301 pct_L4_E2_EOC_BL7_PC                                                                                              float64
#  302 pct_L4_E2_EOC_EDS_PC                                                                                              float64
#  303 pct_L4_E2_EOC_FEM_PC                                                                                              float64
#  304 pct_L4_E2_EOC_HI7_PC                                                                                              float64
#  305 pct_L4_E2_EOC_MALE_PC                                                                                             float64
#  306 pct_L4_E2_EOC_SWD_PC                                                                                              float64
#  307 pct_L4_E2_EOC_WH7_PC                                                                                              float64
#  308 pct_L4_EOC_EOC_AIG_PC                                                                                             float64
#  309 pct_L4_EOC_EOC_BL7_PC                                                                                             float64
#  310 pct_L4_EOC_EOC_EDS_PC                                                                                             float64
#  311 pct_L4_EOC_EOC_ELS_PC                                                                                             float64
#  312 pct_L4_EOC_EOC_FEM_PC                                                                                             float64
#  313 pct_L4_EOC_EOC_HI7_PC                                                                                             float64
#  314 pct_L4_EOC_EOC_MALE_PC                                                                                            float64
#  315 pct_L4_EOC_EOC_MU7_PC                                                                                             float64
#  316 pct_L4_EOC_EOC_SWD_PC                                                                                             float64
#  317 pct_L4_EOC_EOC_WH7_PC                                                                                             float64
#  318 pct_L4_M1_EOC_AIG_PC                                                                                              float64
#  319 pct_L4_M1_EOC_BL7_PC                                                                                              float64
#  320 pct_L4_M1_EOC_EDS_PC                                                                                              float64
#  321 pct_L4_M1_EOC_FEM_PC                                                                                              float64
#  322 pct_L4_M1_EOC_HI7_PC                                                                                              float64
#  323 pct_L4_M1_EOC_MALE_PC                                                                                             float64
#  324 pct_L4_M1_EOC_WH7_PC                                                                                              float64
#  325 pct_L5_ALL_ALL_HI7_PC                                                                                             float64
#  326 pct_L5_BI_EOC_AIG_PC                                                                                              float64
#  327 pct_L5_BI_EOC_ALL_PC                                                                                              float64
#  328 pct_L5_BI_EOC_EDS_PC                                                                                              float64
#  329 pct_L5_BI_EOC_FEM_PC                                                                                              float64
#  330 pct_L5_BI_EOC_HI7_PC                                                                                              float64
#  331 pct_L5_BI_EOC_MALE_PC                                                                                             float64
#  332 pct_L5_BI_EOC_WH7_PC                                                                                              float64
#  333 pct_L5_E2_EOC_AIG_PC                                                                                              float64
#  334 pct_L5_EOC_EOC_AIG_PC                                                                                             float64
#  335 pct_L5_EOC_EOC_FEM_PC                                                                                             float64
#  336 pct_L5_EOC_EOC_MALE_PC                                                                                            float64
#  337 pct_L5_EOC_EOC_WH7_PC                                                                                             float64
#  338 pct_L5_M1_EOC_AIG_PC                                                                                              float64
#  339 pct_L5_M1_EOC_FEM_PC                                                                                              float64
#  340 pct_L5_M1_EOC_MALE_PC                                                                                             float64
#  341 pct_L5_M1_EOC_WH7_PC                                                                                              float64
#  342 m1_score                                                                                                          float64
#  343 e2_score                                                                                                          float64
#  344 bi_score                                                                                                          float64
#  345 act_score                                                                                                         float64
#  346 wk_score                                                                                                          float64
#  347 cgrs_score                                                                                                        float64
#  348 eg_score                                                                                                          float64
#  349 spg_score                                                                                                         float64
#  350 aaa_score_ALL_SPG2                                                                                                float64
#  351 aaa_score_BL7_SPG2                                                                                                float64
#  352 aaa_score_EDS_SPG2                                                                                                float64
#  353 aaa_score_SWD_SPG2                                                                                                float64
#  354 aaa_score_WH7_SPG2                                                                                                float64
#  355 awa_score_ALL_SPG2                                                                                                float64
#  356 awa_score_EDS_SPG2                                                                                                float64
#  357 bi_score_ALL_SPG2                                                                                                 float64
#  358 bi_score_BL7_SPG2                                                                                                 float64
#  359 bi_score_EDS_SPG2                                                                                                 float64
#  360 bi_score_WH7_SPG2                                                                                                 float64
#  361 cgrs_score_ALL_SPG2                                                                                               float64
#  362 cgrs_score_BL7_SPG2                                                                                               float64
#  363 cgrs_score_EDS_SPG2                                                                                               float64
#  364 cgrs_score_WH7_SPG2                                                                                               float64
#  365 eg_score_ALL_SPG2                                                                                                 float64
#  366 eg_score_BL7_SPG2                                                                                                 float64
#  367 eg_score_EDS_SPG2                                                                                                 float64
#  368 eg_score_HI7_SPG2                                                                                                 float64
#  369 eg_score_SWD_SPG2                                                                                                 float64
#  370 eg_score_WH7_SPG2                                                                                                 float64
#  371 mcr_score_ALL_SPG2                                                                                                float64
#  372 mcr_score_BL7_SPG2                                                                                                float64
#  373 mcr_score_EDS_SPG2                                                                                                float64
# ...
#  710 digital_media_6                                                                                                   uint8
#  711 digital_media_7                                                                                                   uint8
#  712 digital_media_8                                                                                                   uint8
#  713 digital_media_9                                                                                                   uint8
#  714 device_access_Yes                                                                                                 uint8
#  715 device_home_Yes                                                                                                   uint8
#  716 BYOD_Neither                                                                                                      uint8
#  717 BYOD_Staff                                                                                                        uint8
#  718 BYOD_Students                                                                                                     uint8
#  719 esea_att_Met                                                                                                      uint8
#  720 agency_lea_code_020LEA                                                                                            uint8
#  721 agency_lea_code_030LEA                                                                                            uint8
#  722 agency_lea_code_040LEA                                                                                            uint8
#  723 agency_lea_code_050LEA                                                                                            uint8
#  724 agency_lea_code_060LEA                                                                                            uint8
#  725 agency_lea_code_070LEA                                                                                            uint8
#  726 agency_lea_code_080LEA                                                                                            uint8
#  727 agency_lea_code_090LEA                                                                                            uint8
#  728 agency_lea_code_100LEA                                                                                            uint8
#  729 agency_lea_code_110LEA                                                                                            uint8
#  730 agency_lea_code_111LEA                                                                                            uint8
#  731 agency_lea_code_120LEA                                                                                            uint8
#  732 agency_lea_code_130LEA                                                                                            uint8
#  733 agency_lea_code_132LEA                                                                                            uint8
#  734 agency_lea_code_140LEA                                                                                            uint8
#  735 agency_lea_code_150LEA                                                                                            uint8
#  736 agency_lea_code_160LEA                                                                                            uint8
#  737 agency_lea_code_170LEA                                                                                            uint8
#  738 agency_lea_code_180LEA                                                                                            uint8
#  739 agency_lea_code_181LEA                                                                                            uint8
#  740 agency_lea_code_182LEA                                                                                            uint8
#  741 agency_lea_code_190LEA                                                                                            uint8
#  742 agency_lea_code_200LEA                                                                                            uint8
#  743 agency_lea_code_210LEA                                                                                            uint8
#  744 agency_lea_code_220LEA                                                                                            uint8
#  745 agency_lea_code_230LEA                                                                                            uint8
#  746 agency_lea_code_240LEA                                                                                            uint8
#  747 agency_lea_code_241LEA                                                                                            uint8
#  748 agency_lea_code_250LEA                                                                                            uint8
#  749 agency_lea_code_260LEA                                                                                            uint8
#  750 agency_lea_code_270LEA                                                                                            uint8
#  751 agency_lea_code_280LEA                                                                                            uint8
#  752 agency_lea_code_290LEA                                                                                            uint8
#  753 agency_lea_code_291LEA                                                                                            uint8
#  754 agency_lea_code_292LEA                                                                                            uint8
#  755 agency_lea_code_300LEA                                                                                            uint8
#  756 agency_lea_code_310LEA                                                                                            uint8
#  757 agency_lea_code_320LEA                                                                                            uint8
#  758 agency_lea_code_330LEA                                                                                            uint8
#  759 agency_lea_code_340LEA                                                                                            uint8
#  760 agency_lea_code_350LEA                                                                                            uint8
#  761 agency_lea_code_360LEA                                                                                            uint8
#  762 agency_lea_code_370LEA                                                                                            uint8
#  763 agency_lea_code_380LEA                                                                                            uint8
#  764 agency_lea_code_390LEA                                                                                            uint8
#  765 agency_lea_code_400LEA                                                                                            uint8
#  766 agency_lea_code_410LEA                                                                                            uint8
#  767 agency_lea_code_420LEA                                                                                            uint8
#  768 agency_lea_code_421LEA                                                                                            uint8
#  769 agency_lea_code_422LEA                                                                                            uint8
#  770 agency_lea_code_430LEA                                                                                            uint8
#  771 agency_lea_code_440LEA                                                                                            uint8
#  772 agency_lea_code_450LEA                                                                                            uint8
#  773 agency_lea_code_460LEA                                                                                            uint8
#  774 agency_lea_code_470LEA                                                                                            uint8
#  775 agency_lea_code_480LEA                                                                                            uint8
#  776 agency_lea_code_490LEA                                                                                            uint8
#  777 agency_lea_code_491LEA                                                                                            uint8
#  778 agency_lea_code_500LEA                                                                                            uint8
#  779 agency_lea_code_510LEA                                                                                            uint8
#  780 agency_lea_code_520LEA                                                                                            uint8
#  781 agency_lea_code_530LEA                                                                                            uint8
#  782 agency_lea_code_540LEA                                                                                            uint8
#  783 agency_lea_code_550LEA                                                                                            uint8
#  784 agency_lea_code_560LEA                                                                                            uint8
#  785 agency_lea_code_570LEA                                                                                            uint8
#  786 agency_lea_code_580LEA                                                                                            uint8
#  787 agency_lea_code_590LEA                                                                                            uint8
#  788 agency_lea_code_600LEA                                                                                            uint8
#  789 agency_lea_code_610LEA                                                                                            uint8
#  790 agency_lea_code_620LEA                                                                                            uint8
#  791 agency_lea_code_630LEA                                                                                            uint8
#  792 agency_lea_code_640LEA                                                                                            uint8
#  793 agency_lea_code_650LEA                                                                                            uint8
#  794 agency_lea_code_660LEA                                                                                            uint8
#  795 agency_lea_code_670LEA                                                                                            uint8
#  796 agency_lea_code_680LEA                                                                                            uint8
#  797 agency_lea_code_681LEA                                                                                            uint8
#  798 agency_lea_code_690LEA                                                                                            uint8
#  799 agency_lea_code_700LEA                                                                                            uint8
#  800 agency_lea_code_710LEA                                                                                            uint8
#  801 agency_lea_code_720LEA                                                                                            uint8
#  802 agency_lea_code_730LEA                                                                                            uint8
#  803 agency_lea_code_740LEA                                                                                            uint8
#  804 agency_lea_code_750LEA                                                                                            uint8
#  805 agency_lea_code_760LEA                                                                                            uint8
#  806 agency_lea_code_761LEA                                                                                            uint8
#  807 agency_lea_code_770LEA                                                                                            uint8
#  808 agency_lea_code_780LEA                                                                                            uint8
#  809 agency_lea_code_790LEA                                                                                            uint8
#  810 agency_lea_code_800LEA                                                                                            uint8
#  811 agency_lea_code_810LEA                                                                                            uint8
#  812 agency_lea_code_820LEA                                                                                            uint8
#  813 agency_lea_code_821LEA                                                                                            uint8
#  814 agency_lea_code_830LEA                                                                                            uint8
#  815 agency_lea_code_840LEA                                                                                            uint8
#  816 agency_lea_code_850LEA                                                                                            uint8
#  817 agency_lea_code_860LEA                                                                                            uint8
#  818 agency_lea_code_861LEA                                                                                            uint8
#  819 agency_lea_code_862LEA                                                                                            uint8
#  820 agency_lea_code_870LEA                                                                                            uint8
#  821 agency_lea_code_880LEA                                                                                            uint8
#  822 agency_lea_code_890LEA                                                                                            uint8
#  823 agency_lea_code_900LEA                                                                                            uint8
#  824 agency_lea_code_910LEA                                                                                            uint8
#  825 agency_lea_code_920LEA                                                                                            uint8
#  826 agency_lea_code_930LEA                                                                                            uint8
#  827 agency_lea_code_940LEA                                                                                            uint8
#  828 agency_lea_code_950LEA                                                                                            uint8
#  829 agency_lea_code_960LEA                                                                                            uint8
#  830 agency_lea_code_970LEA                                                                                            uint8
#  831 agency_lea_code_980LEA                                                                                            uint8
#  832 agency_lea_code_990LEA                                                                                            uint8
#  833 agency_lea_code_995LEA                                                                                            uint8
#  834 agency_code                                                                                                       object
# dtypes: float64(573), object(1), uint8(261)
# memory usage: 2.8+ MB

# %%
import sklearn
import pandas as pd

print('Sklearn Version: ' + sklearn.__version__)
print('Pandas Version: ' + pd.__version__)
# Out:
# Sklearn Version: 0.22.1
# Pandas Version: 1.0.3

# %%
print('Output File Location:\r\n\r\n' + outputDir + inputFileName + '_ML.csv')
# Out:
# Output File Location:
#
# D:/BenepactLLC/Belk/NC_Report_Card_Data/2020/June 2020/2018/Machine Learning Datasets/PublicHighSchools2018_ML.csv
