# %% [markdown]
# # Create Public School Machine Learning Datasets
# ** This program creates all the _ML datasets in the NCEA repository.**
# * This notebook reads each School Dataset file located at \EducationDataNC\ *schoolYear* \School Datasets\ as input data.
# * Different school years are processed by changing the *schoolYear* parameter.
# * Different input / output files are processed / created by changing the *inputFileName* paramter in the cell below.
# * While a single program is used to create all the _ML datasets, one program copy per dataset is maintained in the repositiory so the dataset specific tranformation reports may be reviewed.
#
# **Datasets ending in ML are preprocessed for Machine Learning and go through the following transformations: **
# 1. Missing student body racial compositions are imputed using district averages.
# 2. Columns that have the same value in every single row are deleted.
# 3. Columns that have a unique value in every single row (all values are different) are deleted.
# 4. Empty columns (all values are NA or NULL) are deleted.
# 5. Numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# 6. Remaining numeric, non-race columns with missing values are imputed / populated with 0.  In many cases, schools are not reporting values when they are zero. However, mean imputation or some other more sophisticated strategy might be considered here.
# 7. Categorical / text based columns with > *uniqueThreshold* unique values are deleted.
# 8. All remaining categorical / text based columns are one-hot encoded.  In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# 9. Duplicated or highly similar columns with > 95% correlation are delelted.

# %%
#import required Libraries
import pandas as pd
import numpy as np
import os
import string

#**********************************************************************************
# Set the following variables before running this code!!!
#**********************************************************************************
#All raw data files are processed for the year below
schoolYear = 2018

#Location where copies of the raw data files will be read in from csv files.
dataDir = 'C:/Users/Jake/Documents/GitHub/EducationDataNC/' + str(schoolYear) + '/School Datasets/'

#Name of the file to be processed
#inputFileName = 'PublicSchools2018'
#inputFileName = 'PublicHighSchools2018'
inputFileName = 'PublicMiddleSchools2018'
#inputFileName = 'PublicElementarySchools2018'

#Input file being transformed for machine learning 
inputFile = dataDir + inputFileName + '.csv'

#Location where the new school datasets will be created.
outputDir = 'C:/Users/Jake/Documents/GitHub/EducationDataNC/' + str(schoolYear) + '/Machine Learning Datasets/'

#Missing Data Threshold (Per Column)
missingThreshold = 0.60

#Unique Value Threshold (Per Column)
#Delete Columns >  uniqueThreshold unique values prior to one-hot encoding. 
#(each unique value becomes a new column during one-hot encoding)
uniqueThreshold = 200

#Read in the School Data File
schoolData = pd.read_csv(inputFile, low_memory=False, dtype={'agency_code': object})
print('*********Start: Beginning Column and Row Counts********************************************')
schoolData.info(verbose=False)

#Select only public schools as charter schools are missing data for many columns.
schoolData = schoolData[(schoolData['designation_type'] == 'P') & (schoolData['avg_student_num'] > 0)]

print('\r\n*********After: Selecting Only Public School Campuses**********************************')
schoolData.info(verbose=False)

#Save primary key
agency_code = schoolData['agency_code']
#Convert zip code to string
schoolData['zip'] = schoolData['zip'].astype('object')
# Out:
# *********Start: Beginning Column and Row Counts********************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 806 entries, 0 to 805
# Columns: 1816 entries, agency_code to lea_federal_perpupil
# dtypes: float64(1765), object(51)
# memory usage: 11.2+ MB
#
# *********After: Selecting Only Public School Campuses**********************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 660 entries, 2 to 805
# Columns: 1816 entries, agency_code to lea_federal_perpupil
# dtypes: float64(1765), object(51)
# memory usage: 9.1+ MB

# %% [markdown]
# # Prepare Consolidated Dataset for Machine Learning
# **Below we perform operations on the entire dataset to remove columns and update row values that could cause problems during machine learning.**

# %% [markdown]
# ## Student Body Racial Composition Features
# **Impute / update missing Student Body Racial Composition Fields using mean imputation.**
# * When there are no racial composition percentages for a particular school campus / agency_code, fill in the missing values

# %%
#Get Student Body Racial Composition Fields
raceCompositionFields = schoolData.filter(regex='Indian|Asian|Hispanic|Black|White|PacificIsland|TwoOrMore|Minority')\
                                  .filter(regex='Pct').columns
    
rowsBefore = schoolData[raceCompositionFields].isnull().T.any().T.sum()

#Update missing race values with the district average when avaiable (No district averages for charter schools) 
schoolData[raceCompositionFields] = schoolData.groupby('lea_code')[raceCompositionFields]\
                                              .transform(lambda x: x.fillna(x.mean()))

    #Review dataset contents after Racial Composition Imputation
print('*********After: Updating Missing Racial Compostion Values****************************')   
rowsAfter = schoolData[raceCompositionFields].isnull().T.any().T.sum()
rowsUpdated = rowsBefore - rowsAfter
print('Rows Updated / Imputed: ', rowsUpdated) 
print('\r\nTotal Rows Missing Racial Compositions By District Code') 
schoolData['lea_code'][schoolData[raceCompositionFields].isnull().T.any().T].value_counts()
# Out:
# *********After: Updating Missing Racial Compostion Values****************************
# Rows Updated / Imputed:  3
#
# Total Rows Missing Racial Compositions By District Code
# Series([], Name: lea_code, dtype: int64)

# %% [markdown]
# ## Remove Columns with Problematic Data
# **Here we remove entire columns that could cause problems during machine learning.  The following operations are performed:**
# * Remove any columns that have the same value in every single row.
# * Remove any columns that have a unique value in every single row (all values are different).
# * Remove empty columns (all values are NA or NULL).

# %%
#Remove any fields that have the same value in all rows
UniqueValueCounts = schoolData.nunique(dropna=False)
SingleValueCols = UniqueValueCounts[UniqueValueCounts == 1].index
schoolData = schoolData.drop(SingleValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with the same value in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(SingleValueCols))
# Out:
# *********After: Removing columns with the same value in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 660 entries, 2 to 805
# Columns: 762 entries, agency_code to lea_federal_perpupil
# dtypes: float64(715), object(47)
# memory usage: 3.8+ MB
#
# Columns Deleted:  1054

# %%
#Remove any fields that have unique values in every row
schoolDataRecordCt = schoolData.shape[0]
UniqueValueCounts = schoolData.apply(pd.Series.nunique)
AllUniqueValueCols = UniqueValueCounts[UniqueValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(AllUniqueValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with unique values in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(AllUniqueValueCols))
# Out:
# *********After: Removing columns with unique values in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 660 entries, 2 to 805
# Columns: 760 entries, category_code to lea_federal_perpupil
# dtypes: float64(715), object(45)
# memory usage: 3.8+ MB
#
# Columns Deleted:  2

# %%
#Remove any empty fields (null values in every row)
schoolDataRecordCt = schoolData.shape[0]
NullValueCounts = schoolData.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with null / blank values in every row.*************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with null / blank values in every row.*************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 660 entries, 2 to 805
# Columns: 760 entries, category_code to lea_federal_perpupil
# dtypes: float64(715), object(45)
# memory usage: 3.8+ MB
#
# Columns Deleted:  0

# %% [markdown]
# ## Handle Other Missing Values Types
# * Here we eliminate any numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# * All remaining non-race, numeric column missing values are populated with 0.
# * In many cases, it seems that schools are not simply not reporting values when they are zero. However, mean imputation or some other strategy might be considered.

# %%
#Isolate continuous and categorical data types
#These are indexers into the schoolData dataframe and may be used similar to the schoolData dataframe 
sD_boolean = schoolData.loc[:, (schoolData.dtypes == bool) ]
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]
sD_continuous = schoolData.loc[:, (schoolData.dtypes != bool) & (schoolData.dtypes != object)]
print ("Boolean Columns: ", sD_boolean.shape[1])
print ("Nominal Columns: ", sD_nominal.shape[1])
print ("Continuous Columns: ", sD_continuous.shape[1])
print ("Columns Accounted for: ", sD_nominal.shape[1] + sD_continuous.shape[1] + sD_boolean.shape[1])
# Out:
# Boolean Columns:  0
# Nominal Columns:  45
# Continuous Columns:  715
# Columns Accounted for:  760

# %%
#Eliminate continuous columns with more than missingThreshold percentage of missing values
schoolDataRecordCt = sD_continuous.shape[0]
missingValueLimit = schoolDataRecordCt * missingThreshold
NullValueCounts = sD_continuous.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts >= missingValueLimit].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with >= missingThreshold % of missing values******')
schoolData.info(verbose=False)
print('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with >= missingThreshold % of missing values******
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 660 entries, 2 to 805
# Columns: 291 entries, category_code to lea_federal_perpupil
# dtypes: float64(246), object(45)
# memory usage: 1.5+ MB
#
# Columns Deleted:  469

# %% [markdown]
# ## One-Hot Encoding of Categorical Variables
# **All categorical / string variables are converted to numberic variables via one hot encoding.  Each unique row value will become a new binary / numeric column in the dataset.**
# * All remaining categorical columns are one-hot encoded.
# * In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# * Prior to one-hot encoding, columns with > *uniqueThreshold* unique values are deleted.

# %%
#Delete categorical columns with > uniqueThreshold unique values 
#(Each unique value becomes a column during one-hot encoding)
oneHotUniqueValueCounts = schoolData[sD_nominal.columns].apply(lambda x: x.nunique())
oneHotUniqueValueCols = oneHotUniqueValueCounts[oneHotUniqueValueCounts >= uniqueThreshold].index
schoolData.drop(oneHotUniqueValueCols, axis=1, inplace=True) 

#Remove categorical columns which do not add value to machine learning
#Grades columns dropped since they all have indicator fields (device_access, device_home, BYOD)
#with less unique values to one-hot encode
schoolData.drop(['welcome_url','device_access_grades',
                 'device_home_grades','byod_grades'], axis=1, inplace=True) 

#Review dataset contents one hot high unique value drops
print('*********After: Removing columns with >= uniqueThreshold unique values***********')
schoolData.info(verbose=False)
print('\r\nColumns Deleted: ', len(oneHotUniqueValueCols))
print(oneHotUniqueValueCols)
print('Dropped Manually: welcome_url,device_access_grades,device_home_grades,byod_grades')
# Out:
# *********After: Removing columns with >= uniqueThreshold unique values***********
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 660 entries, 2 to 805
# Columns: 281 entries, category_code to lea_federal_perpupil
# dtypes: float64(246), object(35)
# memory usage: 1.4+ MB
#
# Columns Deleted:  6
# Index(['street_addr', 'city', 'zip', 'phone', 'url', 'School Name'], dtype='object')
# Dropped Manually: welcome_url,device_access_grades,device_home_grades,byod_grades

# %%
#Isolate remaining categorical variables
begColumnCt = len(schoolData.columns)
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]

#one hot encode categorical variables
schoolData = pd.get_dummies(data=schoolData, 
                       columns=sD_nominal.columns, drop_first=True)

#Determine change in column count
endColumnCt = len(schoolData.columns)
columnsAdded = endColumnCt - begColumnCt

#Review dataset contents one hot high unique value drops
print('Columns To One-Hot Encode: ', len(sD_nominal.columns))
print('\r\n*********After: Adding New Columns Via One-Hot Encoding*************************')
schoolData.info(verbose=False)
print('\r\nNew Columns Created Via One-Hot Encoding: ', columnsAdded)
# Out:
# Columns To One-Hot Encode:  35
#
# *********After: Adding New Columns Via One-Hot Encoding*************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 660 entries, 2 to 805
# Columns: 733 entries, IndianPct to agency_lea_code_995LEA
# dtypes: float64(246), uint8(487)
# memory usage: 1.6 MB
#
# New Columns Created Via One-Hot Encoding:  452

# %%
#Remove any fields that have the same value in all rows after one-hot encoding
UniqueValueCounts = schoolData.nunique(dropna=False)
SingleValueCols = UniqueValueCounts[UniqueValueCounts == 1].index
schoolData = schoolData.drop(SingleValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing one-hot encoded columns with the same value in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(SingleValueCols))
# Out:
# *********After: Removing one-hot encoded columns with the same value in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 660 entries, 2 to 805
# Columns: 733 entries, IndianPct to agency_lea_code_995LEA
# dtypes: float64(246), uint8(487)
# memory usage: 1.6 MB
#
# Columns Deleted:  0

# %% [markdown]
# ## Impute any Remaining Missing Values as Zero

# %%
#Print out all the missing value rows
pd.set_option('display.max_rows', 1000)

print('\r\n*********The Remaining Missing Values Below will be set to Zero!*************************')

#Check for Missing values 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# *********The Remaining Missing Values Below will be set to Zero!*************************
#                                    Variable Name  Number Missing Values
# 24                                       pct_eds                      1
# 25                                   pct_ALL_ELP                    277
# 26                                   pct_EDS_ELP                    331
# 27                                   pct_ELS_ELP                    277
# 28                                   pct_HI7_ELP                    313
# 29                                  pct_MALE_ELP                    377
# 30                              pct_prof_6gr_irm                     95
# 31                   pct_met_Math Grades 3-8_LTG                     70
# 32                pct_met_Reading Grades 3-8_LTG                     70
# 33                     pct_met_Total Targets_LTG                     54
# 34                  pct_met_Math Grades 3-8_PART                     50
# 35               pct_met_Reading Grades 3-8_PART                     50
# 36               pct_met_Science Grades 5&8_PART                     82
# 37                    pct_met_Total Targets_PART                     40
# 38              pct_Math Grades 3-8_ALL_PART_DET                     50
# 39              pct_Math Grades 3-8_BL7_PART_DET                    196
# 40              pct_Math Grades 3-8_EDS_PART_DET                     67
# 41              pct_Math Grades 3-8_ELS_PART_DET                    295
# 42              pct_Math Grades 3-8_HI7_PART_DET                    183
# 43              pct_Math Grades 3-8_SWD_PART_DET                    138
# 44              pct_Math Grades 3-8_WH7_PART_DET                    123
# 45           pct_Reading Grades 3-8_ALL_PART_DET                     50
# 46           pct_Reading Grades 3-8_BL7_PART_DET                    196
# 47           pct_Reading Grades 3-8_EDS_PART_DET                     67
# 48           pct_Reading Grades 3-8_ELS_PART_DET                    295
# 49           pct_Reading Grades 3-8_HI7_PART_DET                    183
# 50           pct_Reading Grades 3-8_SWD_PART_DET                    138
# 51           pct_Reading Grades 3-8_WH7_PART_DET                    123
# 52           pct_Science Grades 5&8_ALL_PART_DET                     82
# 53           pct_Science Grades 5&8_BL7_PART_DET                    344
# 54           pct_Science Grades 5&8_EDS_PART_DET                    131
# 55           pct_Science Grades 5&8_WH7_PART_DET                    207
# 56                                      ma_score                     87
# 57                                      rd_score                     87
# 58                                      sc_score                     88
# 59                                      m1_score                    150
# 60                                     ach_score                     82
# 61                                      eg_score                     85
# 62                                     spg_score                     82
# 63                                  ma_spg_score                     87
# 64                                  rd_spg_score                     87
# 65                                   ma_eg_score                     90
# 66                                   rd_eg_score                     90
# 67                            aaa_score_ALL_SPG2                     74
# 68                            aaa_score_BL7_SPG2                    172
# 69                            aaa_score_EDS_SPG2                     78
# 70                            aaa_score_ELS_SPG2                    203
# 71                            aaa_score_HI7_SPG2                    129
# 72                            aaa_score_MU7_SPG2                    282
# 73                            aaa_score_SWD_SPG2                    101
# 74                            aaa_score_WH7_SPG2                    106
# 75                            ach_score_ALL_SPG2                     74
# 76                            ach_score_BL7_SPG2                    172
# 77                            ach_score_EDS_SPG2                     78
# 78                            ach_score_ELS_SPG2                    203
# 79                            ach_score_HI7_SPG2                    129
# 80                            ach_score_MU7_SPG2                    282
# 81                            ach_score_SWD_SPG2                    101
# 82                            ach_score_WH7_SPG2                    105
# 83                             eg_score_ALL_SPG2                     78
# 84                             eg_score_BL7_SPG2                    193
# 85                             eg_score_EDS_SPG2                     85
# 86                             eg_score_ELS_SPG2                    253
# 87                             eg_score_HI7_SPG2                    166
# 88                             eg_score_MU7_SPG2                    375
# 89                             eg_score_SWD_SPG2                    140
# 90                             eg_score_WH7_SPG2                    123
# 91                           scgs_score_ALL_SPG2                     94
# 92                           scgs_score_BL7_SPG2                    350
# 93                           scgs_score_EDS_SPG2                    141
# 94                           scgs_score_WH7_SPG2                    214
# 95                            spg_score_ALL_SPG2                     74
# 96                            spg_score_BL7_SPG2                    172
# 97                            spg_score_EDS_SPG2                     78
# 98                            spg_score_ELS_SPG2                    203
# 99                            spg_score_HI7_SPG2                    129
# 100                           spg_score_MU7_SPG2                    282
# 101                           spg_score_SWD_SPG2                    101
# 102                           spg_score_WH7_SPG2                    105
# 105                         pct_ALL_CHRON_ABSENT                      2
# 106                         pct_BL7_CHRON_ABSENT                     66
# 107                         pct_ELS_CHRON_ABSENT                    167
# 108                         pct_FEM_CHRON_ABSENT                      4
# 109                         pct_HI7_CHRON_ABSENT                     33
# 110                        pct_MALE_CHRON_ABSENT                      5
# 111                         pct_MU7_CHRON_ABSENT                     77
# 112                         pct_SWD_CHRON_ABSENT                     13
# 113                         pct_WH7_CHRON_ABSENT                      8
# 114                                   stu_enroll                     35
# 115                                   cte_enroll                     35
# 116                           cte_enrollment_pct                     35
# 117                       Book_TitlesPer_Student                     40
# 118                                          wap                      5
# 119                                    wap_class                      5
# 120                                 media_school                     35
# 121                                      devices                      2
# 122                   pct_rating_T1_Accomplished                     19
# 123                  pct_rating_T1_Distinguished                    189
# 124                     pct_rating_T1_Proficient                     37
# 125                   pct_rating_T2_Accomplished                     24
# 126                  pct_rating_T2_Distinguished                    308
# 127                     pct_rating_T2_Proficient                     62
# 128                   pct_rating_T3_Accomplished                     40
# 129                  pct_rating_T3_Distinguished                    322
# 130                     pct_rating_T3_Proficient                     45
# 131                   pct_rating_T4_Accomplished                     23
# 132                  pct_rating_T4_Distinguished                    267
# 133                     pct_rating_T4_Proficient                     36
# 134                   pct_rating_T5_Accomplished                     36
# 135                  pct_rating_T5_Distinguished                    337
# 136                     pct_rating_T5_Proficient                     38
# 137  pct_rating_TS_Does Not Meet Expected Growth                     44
# 138        pct_rating_TS_Exceeds Expected Growth                     44
# 139          pct_rating_TS_Meets Expected Growth                     44
# 140                   avg_class_teach_TeacherExp                      1
# 141                    pct_adv_degree_TeacherExp                      1
# 142                  pct_experience_0_TeacherExp                      1
# 143                 pct_experience_10_TeacherExp                      1
# 144                  pct_experience_4_TeacherExp                      1
# 145                      pct_turnover_TeacherExp                      9
# 146                         highqual_class_pct_M                    192
# 147                                        crime                      9
# 148                                   short_term                      9
# 149                                    long_term                      9
# 150                                    expulsion                      9
# 151                             arre_per1000_ALL                      9
# 152                             arre_per1000_BL7                     56
# 155                             arre_per1000_FEM                     25
# 156                             arre_per1000_HI7                     53
# 157                            arre_per1000_MALE                     15
# 158                             arre_per1000_MU7                     72
# 159                             arre_per1000_SWD                      5
# 160                             arre_per1000_WH7                     20
# 161                             blhr_per1000_ALL                      9
# 162                             blhr_per1000_BL7                     56
# 165                             blhr_per1000_FEM                     25
# 166                             blhr_per1000_HI7                     53
# 167                            blhr_per1000_MALE                     15
# 168                             blhr_per1000_MU7                     72
# 169                             blhr_per1000_SWD                      5
# 170                             blhr_per1000_WH7                     20
# 171                            crime_per1000_ALL                      9
# 172                            crime_per1000_BL7                     56
# 175                            crime_per1000_FEM                     25
# 176                            crime_per1000_HI7                     53
# 177                           crime_per1000_MALE                     15
# 178                            crime_per1000_MU7                     72
# 179                            crime_per1000_SWD                      5
# 180                            crime_per1000_WH7                     20
# 181                              exp_per1000_ALL                      9
# 182                              exp_per1000_BL7                    105
# 183                              exp_per1000_EDS                      5
# 184                              exp_per1000_ELS                    193
# 185                              exp_per1000_FEM                     33
# 186                              exp_per1000_HI7                    104
# 187                             exp_per1000_MALE                     20
# 188                              exp_per1000_MU7                    174
# 189                              exp_per1000_SWD                     25
# 190                              exp_per1000_WH7                     50
# 191                              iss_per1000_ALL                      9
# 192                              iss_per1000_BL7                    105
# 193                              iss_per1000_EDS                      5
# 194                              iss_per1000_ELS                    193
# 195                              iss_per1000_FEM                     33
# 196                              iss_per1000_HI7                    104
# 197                             iss_per1000_MALE                     20
# 198                              iss_per1000_MU7                    174
# 199                              iss_per1000_SWD                     25
# 200                              iss_per1000_WH7                     50
# 201                              lts_per1000_ALL                      9
# 202                              lts_per1000_BL7                    105
# 203                              lts_per1000_EDS                      5
# 204                              lts_per1000_ELS                    193
# 205                              lts_per1000_FEM                     33
# 206                              lts_per1000_HI7                    104
# 207                             lts_per1000_MALE                     20
# 208                              lts_per1000_MU7                    174
# 209                              lts_per1000_SWD                     25
# 210                              lts_per1000_WH7                     50
# 211                             rplw_per1000_ALL                      9
# 212                             rplw_per1000_BL7                     56
# 214                             rplw_per1000_FEM                     25
# 215                             rplw_per1000_HI7                     53
# 216                            rplw_per1000_MALE                     15
# 217                             rplw_per1000_MU7                     72
# 218                             rplw_per1000_SWD                      5
# 219                             rplw_per1000_WH7                     20
# 220                              sts_per1000_ALL                      9
# 221                              sts_per1000_BL7                    109
# 222                              sts_per1000_EDS                      5
# 223                              sts_per1000_ELS                    193
# 224                              sts_per1000_FEM                     35
# 225                              sts_per1000_HI7                    106
# 226                             sts_per1000_MALE                     24
# 227                              sts_per1000_MU7                    174
# 228                              sts_per1000_SWD                     29
# 229                              sts_per1000_WH7                     50
# 230                           pct_fully_licensed                      1
# 231                            pct_lateral_entry                      1
# 232                                    nbpts_num                      1
# 233                              avg_size_06_SAR                    134
# 234                              avg_size_07_SAR                    119
# 235                              avg_size_08_SAR                    123
# 236                          avg_size_Math I_SAR                    122

# %%
#Replace all remaining NaN with 0
schoolData = schoolData.fillna(0)

#Check for Missing values after final imputation 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# Empty DataFrame
# Columns: [Variable Name, Number Missing Values]
# Index: []

# %% [markdown]
# ## Identify and Remove Highly Correlated Features
# **Find and remove any columns / features that are > 95% correlated**
# * https://stackoverflow.com/questions/39409866/correlation-heatmap
# * https://chrisalbon.com/machine_learning/feature_selection/drop_highly_correlated_features/
# * https://codeyarns.com/2015/04/20/how-to-change-font-size-in-seaborn/

# %%
# calculate the correlation matrix
corr_matrix  = schoolData.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
#Get all of the correlation values > 95%
x = np.where(upper > 0.95)

#Display all field combinations with > 95% correlation
cf = pd.DataFrame()
cf['Field1'] = upper.columns[x[1]]
cf['Field2'] = upper.index[x[0]]

#Get the correlation values for every field combination. (There must be a more pythonic way to do this!)
corr = [0] * len(cf)
for i in range(0, len(cf)):
    corr[i] =  upper[cf['Field1'][i]][cf['Field2'][i]] 
    
cf['Correlation'] = corr

print ('There are ', str(len(cf['Field1'])), ' field correlations > 95%.')
cf
# Out:
# There are  383  field correlations > 95%.
#                                   Field1                               Field2  \
# 0                          IndianMalePct                            IndianPct
# 1                        IndianFemalePct                            IndianPct
# 2                           AsianMalePct                             AsianPct
# 3                         AsianFemalePct                             AsianPct
# 4                        HispanicMalePct                          HispanicPct
# 5                      HispanicFemalePct                          HispanicPct
# 6                            MinorityPct                             WhitePct
# 7                           WhiteMalePct                             WhitePct
# 8                         WhiteFemalePct                             WhitePct
# 9                           WhiteMalePct                          MinorityPct
# 10                        WhiteFemalePct                          MinorityPct
# 11                       IndianFemalePct                        IndianMalePct
# 12                           pct_ELS_ELP                          pct_ALL_ELP
# 13       pct_met_Reading Grades 3-8_PART         pct_met_Math Grades 3-8_PART
# 14   pct_Science Grades 5&8_ALL_PART_DET      pct_met_Science Grades 5&8_PART
# 15   pct_Reading Grades 3-8_ALL_PART_DET     pct_Math Grades 3-8_ALL_PART_DET
# 16   pct_Reading Grades 3-8_BL7_PART_DET     pct_Math Grades 3-8_BL7_PART_DET
# 17   pct_Reading Grades 3-8_EDS_PART_DET     pct_Math Grades 3-8_EDS_PART_DET
# 18   pct_Reading Grades 3-8_ELS_PART_DET     pct_Math Grades 3-8_ELS_PART_DET
# 19   pct_Reading Grades 3-8_HI7_PART_DET     pct_Math Grades 3-8_HI7_PART_DET
# 20   pct_Reading Grades 3-8_SWD_PART_DET     pct_Math Grades 3-8_SWD_PART_DET
# 21   pct_Reading Grades 3-8_WH7_PART_DET     pct_Math Grades 3-8_WH7_PART_DET
# 22                   scgs_score_WH7_SPG2  pct_Science Grades 5&8_WH7_PART_DET
# 23                              rd_score                             ma_score
# 24                          ma_spg_score                             ma_score
# 25                             ach_score                             rd_score
# 26                          ma_spg_score                             rd_score
# 27                          rd_spg_score                             rd_score
# 28                          rd_spg_score                             sc_score
# 29                             spg_score                            ach_score
# 30                          ma_spg_score                            spg_score
# 31                          rd_spg_score                            spg_score
# 32                          rd_spg_score                         ma_spg_score
# 33                    ach_score_ALL_SPG2                   aaa_score_ALL_SPG2
# 34                    spg_score_ALL_SPG2                   aaa_score_ALL_SPG2
# 35                    ach_score_BL7_SPG2                   aaa_score_BL7_SPG2
# 36                    spg_score_BL7_SPG2                   aaa_score_BL7_SPG2
# 37                    ach_score_EDS_SPG2                   aaa_score_EDS_SPG2
# 38                    spg_score_EDS_SPG2                   aaa_score_EDS_SPG2
# 39                    ach_score_ELS_SPG2                   aaa_score_ELS_SPG2
# 40                    spg_score_ELS_SPG2                   aaa_score_ELS_SPG2
# 41                    ach_score_HI7_SPG2                   aaa_score_HI7_SPG2
# 42                    spg_score_HI7_SPG2                   aaa_score_HI7_SPG2
# 43                    ach_score_MU7_SPG2                   aaa_score_MU7_SPG2
# 44                    spg_score_MU7_SPG2                   aaa_score_MU7_SPG2
# 45                    ach_score_SWD_SPG2                   aaa_score_SWD_SPG2
# 46                    ach_score_WH7_SPG2                   aaa_score_WH7_SPG2
# 47                    spg_score_WH7_SPG2                   aaa_score_WH7_SPG2
# 48                    spg_score_ALL_SPG2                   ach_score_ALL_SPG2
# 49                    spg_score_BL7_SPG2                   ach_score_BL7_SPG2
# 50                    spg_score_EDS_SPG2                   ach_score_EDS_SPG2
# 51                    spg_score_ELS_SPG2                   ach_score_ELS_SPG2
# 52                    spg_score_HI7_SPG2                   ach_score_HI7_SPG2
# 53                    spg_score_MU7_SPG2                   ach_score_MU7_SPG2
# 54                    spg_score_WH7_SPG2                   ach_score_WH7_SPG2
# 55            avg_class_teach_TeacherExp                      avg_student_num
# 56                 pct_MALE_CHRON_ABSENT                 pct_ALL_CHRON_ABSENT
# 57                       category_code_M                 highqual_class_pct_M
# 58                      arre_per1000_BL7                     arre_per1000_ALL
# 59                      arre_per1000_EDS                     arre_per1000_ALL
# 60                      arre_per1000_SWD                     arre_per1000_ALL
# 61                     crime_per1000_ELS                     arre_per1000_ALL
# 62                      grade_span_KG:13                     arre_per1000_ALL
# 63             subgroup_list_ALL,BL7,SWD                     arre_per1000_ALL
# 64                      arre_per1000_EDS                     arre_per1000_BL7
# 65                      arre_per1000_SWD                     arre_per1000_BL7
# 66                     crime_per1000_ELS                     arre_per1000_BL7
# 67                      grade_span_KG:13                     arre_per1000_BL7
# 68             subgroup_list_ALL,BL7,SWD                     arre_per1000_BL7
# 69                      arre_per1000_SWD                     arre_per1000_EDS
# 70                     crime_per1000_ELS                     arre_per1000_EDS
# 71                      grade_span_KG:13                     arre_per1000_EDS
# 72             subgroup_list_ALL,BL7,SWD                     arre_per1000_EDS
# 73                      arre_per1000_HI7                     arre_per1000_ELS
# 74                      arre_per1000_SWD                    arre_per1000_MALE
# 75                      grade_span_KG:13                    crime_per1000_ELS
# 76             subgroup_list_ALL,BL7,SWD                    crime_per1000_ELS
# 77                       exp_per1000_BL7                      exp_per1000_ALL
# 78                       exp_per1000_EDS                      exp_per1000_ALL
# 79                      exp_per1000_MALE                      exp_per1000_ALL
# 80                       exp_per1000_EDS                      exp_per1000_BL7
# 81                      exp_per1000_MALE                      exp_per1000_BL7
# 82                      exp_per1000_MALE                      exp_per1000_EDS
# 83                      iss_per1000_MALE                      iss_per1000_ALL
# 84                      lts_per1000_MALE                      lts_per1000_ALL
# 85                      county_Alexander                      lea_code_020LEA
# 86                agency_lea_code_020LEA                      lea_code_020LEA
# 87                      county_Alleghany                      lea_code_030LEA
# 88                agency_lea_code_030LEA                      lea_code_030LEA
# 89                          county_Anson                      lea_code_040LEA
# 90                agency_lea_code_040LEA                      lea_code_040LEA
# 91                           county_Ashe                      lea_code_050LEA
# 92                agency_lea_code_050LEA                      lea_code_050LEA
# 93                          county_Avery                      lea_code_060LEA
# 94                agency_lea_code_060LEA                      lea_code_060LEA
# 95                       county_Beaufort                      lea_code_070LEA
# 96                agency_lea_code_070LEA                      lea_code_070LEA
# 97                         county_Bertie                      lea_code_080LEA
# 98                agency_lea_code_080LEA                      lea_code_080LEA
# 99                         county_Bladen                      lea_code_090LEA
# 100               agency_lea_code_090LEA                      lea_code_090LEA
# 101                     county_Brunswick                      lea_code_100LEA
# 102               agency_lea_code_100LEA                      lea_code_100LEA
# 103               agency_lea_code_110LEA                      lea_code_110LEA
# 104               agency_lea_code_111LEA                      lea_code_111LEA
# 105                         county_Burke                      lea_code_120LEA
# 106               agency_lea_code_120LEA                      lea_code_120LEA
# 107                      county_Cabarrus                      lea_code_130LEA
# 108               agency_lea_code_130LEA                      lea_code_130LEA
# 109               agency_lea_code_132LEA                      lea_code_132LEA
# 110                      county_Caldwell                      lea_code_140LEA
# 111               agency_lea_code_140LEA                      lea_code_140LEA
# 112                        county_Camden                      lea_code_150LEA
# 113               agency_lea_code_150LEA                      lea_code_150LEA
# 114                      county_Carteret                      lea_code_160LEA
# 115               agency_lea_code_160LEA                      lea_code_160LEA
# 116                       county_Caswell                      lea_code_170LEA
# 117               agency_lea_code_170LEA                      lea_code_170LEA
# 118               agency_lea_code_180LEA                      lea_code_180LEA
# 119               agency_lea_code_181LEA                      lea_code_181LEA
# 120               agency_lea_code_182LEA                      lea_code_182LEA
# 121                       county_Chatham                      lea_code_190LEA
# 122               agency_lea_code_190LEA                      lea_code_190LEA
# 123                      county_Cherokee                      lea_code_200LEA
# 124               agency_lea_code_200LEA                      lea_code_200LEA
# 125                        county_Chowan                      lea_code_210LEA
# 126               agency_lea_code_210LEA                      lea_code_210LEA
# 127                          county_Clay                      lea_code_220LEA
# 128               agency_lea_code_220LEA                      lea_code_220LEA
# 129                     county_Cleveland                      lea_code_230LEA
# 130               agency_lea_code_230LEA                      lea_code_230LEA
# 131               agency_lea_code_240LEA                      lea_code_240LEA
# 132               agency_lea_code_241LEA                      lea_code_241LEA
# 133                        county_Craven                      lea_code_250LEA
# 134               agency_lea_code_250LEA                      lea_code_250LEA
# 135                    county_Cumberland                      lea_code_260LEA
# 136               agency_lea_code_260LEA                      lea_code_260LEA
# 137                     county_Currituck                      lea_code_270LEA
# 138    subgroup_list_ALL,EDS,MU7,SWD,WH7                      lea_code_270LEA
# 139               agency_lea_code_270LEA                      lea_code_270LEA
# 140                          county_Dare                      lea_code_280LEA
# 141               agency_lea_code_280LEA                      lea_code_280LEA
# 142               agency_lea_code_290LEA                      lea_code_290LEA
# 143               agency_lea_code_291LEA                      lea_code_291LEA
# 144               agency_lea_code_292LEA                      lea_code_292LEA
# 145                         county_Davie                      lea_code_300LEA
# 146               agency_lea_code_300LEA                      lea_code_300LEA
# 147                        county_Duplin                      lea_code_310LEA
# 148               agency_lea_code_310LEA                      lea_code_310LEA
# 149                        county_Durham                      lea_code_320LEA
# 150               agency_lea_code_320LEA                      lea_code_320LEA
# 151                     county_Edgecombe                      lea_code_330LEA
# 152               agency_lea_code_330LEA                      lea_code_330LEA
# 153                       county_Forsyth                      lea_code_340LEA
# 154               agency_lea_code_340LEA                      lea_code_340LEA
# 155                      county_Franklin                      lea_code_350LEA
# 156               agency_lea_code_350LEA                      lea_code_350LEA
# 157                        county_Gaston                      lea_code_360LEA
# 158               agency_lea_code_360LEA                      lea_code_360LEA
# 159                         county_Gates                      lea_code_370LEA
# 160               agency_lea_code_370LEA                      lea_code_370LEA
# 161                        county_Graham                      lea_code_380LEA
# 162               agency_lea_code_380LEA                      lea_code_380LEA
# 163                     county_Granville                      lea_code_390LEA
# 164               agency_lea_code_390LEA                      lea_code_390LEA
# 165                        county_Greene                      lea_code_400LEA
# 166               agency_lea_code_400LEA                      lea_code_400LEA
# 167                      county_Guilford                      lea_code_410LEA
# 168               agency_lea_code_410LEA                      lea_code_410LEA
# 169               agency_lea_code_420LEA                      lea_code_420LEA
# 170               agency_lea_code_421LEA                      lea_code_421LEA
# 171               agency_lea_code_422LEA                      lea_code_422LEA
# 172                       county_Harnett                      lea_code_430LEA
# 173               agency_lea_code_430LEA                      lea_code_430LEA
# 174                       county_Haywood                      lea_code_440LEA
# 175               agency_lea_code_440LEA                      lea_code_440LEA
# 176                     county_Henderson                      lea_code_450LEA
# 177               agency_lea_code_450LEA                      lea_code_450LEA
# 178                      county_Hertford                      lea_code_460LEA
# 179               agency_lea_code_460LEA                      lea_code_460LEA
# 180                          county_Hoke                      lea_code_470LEA
# 181               agency_lea_code_470LEA                      lea_code_470LEA
# 182                          county_Hyde                      lea_code_480LEA
# 183               agency_lea_code_480LEA                      lea_code_480LEA
# 184                       county_Iredell                      lea_code_490LEA
# 185               agency_lea_code_490LEA                      lea_code_490LEA
# 186               agency_lea_code_491LEA                      lea_code_491LEA
# 187                       county_Jackson                      lea_code_500LEA
# 188               agency_lea_code_500LEA                      lea_code_500LEA
# 189                      county_Johnston                      lea_code_510LEA
# 190               agency_lea_code_510LEA                      lea_code_510LEA
# 191                         county_Jones                      lea_code_520LEA
# 192               agency_lea_code_520LEA                      lea_code_520LEA
# 193                           county_Lee                      lea_code_530LEA
# 194               agency_lea_code_530LEA                      lea_code_530LEA
# 195                        county_Lenoir                      lea_code_540LEA
# 196               agency_lea_code_540LEA                      lea_code_540LEA
# 197                       county_Lincoln                      lea_code_550LEA
# 198               agency_lea_code_550LEA                      lea_code_550LEA
# 199                         county_Macon                      lea_code_560LEA
# 200               agency_lea_code_560LEA                      lea_code_560LEA
# 201                       county_Madison                      lea_code_570LEA
# 202               agency_lea_code_570LEA                      lea_code_570LEA
# 203                        county_Martin                      lea_code_580LEA
# 204               agency_lea_code_580LEA                      lea_code_580LEA
# 205                      county_McDowell                      lea_code_590LEA
# 206               agency_lea_code_590LEA                      lea_code_590LEA
# 207                   county_Mecklenburg                      lea_code_600LEA
# 208               agency_lea_code_600LEA                      lea_code_600LEA
# 209                      county_Mitchell                      lea_code_610LEA
# 210               agency_lea_code_610LEA                      lea_code_610LEA
# 211                    county_Montgomery                      lea_code_620LEA
# 212               agency_lea_code_620LEA                      lea_code_620LEA
# 213                         county_Moore                      lea_code_630LEA
# 214               agency_lea_code_630LEA                      lea_code_630LEA
# 215                          county_Nash                      lea_code_640LEA
# 216               agency_lea_code_640LEA                      lea_code_640LEA
# 217                   county_New Hanover                      lea_code_650LEA
# 218               agency_lea_code_650LEA                      lea_code_650LEA
# 219                   county_Northampton                      lea_code_660LEA
# 220               agency_lea_code_660LEA                      lea_code_660LEA
# 221                        county_Onslow                      lea_code_670LEA
# 222               agency_lea_code_670LEA                      lea_code_670LEA
# 223               agency_lea_code_680LEA                      lea_code_680LEA
# 224               agency_lea_code_681LEA                      lea_code_681LEA
# 225                       county_Pamlico                      lea_code_690LEA
# 226               agency_lea_code_690LEA                      lea_code_690LEA
# 227                    county_Pasquotank                      lea_code_700LEA
# 228               agency_lea_code_700LEA                      lea_code_700LEA
# 229                        county_Pender                      lea_code_710LEA
# 230               agency_lea_code_710LEA                      lea_code_710LEA
# 231                    county_Perquimans                      lea_code_720LEA
# 232               agency_lea_code_720LEA                      lea_code_720LEA
# 233                        county_Person                      lea_code_730LEA
# 234               agency_lea_code_730LEA                      lea_code_730LEA
# 235                          county_Pitt                      lea_code_740LEA
# 236               agency_lea_code_740LEA                      lea_code_740LEA
# 237                          county_Polk                      lea_code_750LEA
# 238               agency_lea_code_750LEA                      lea_code_750LEA
# 239               agency_lea_code_760LEA                      lea_code_760LEA
# 240               agency_lea_code_761LEA                      lea_code_761LEA
# 241                      county_Richmond                      lea_code_770LEA
# 242               agency_lea_code_770LEA                      lea_code_770LEA
# 243                       county_Robeson                      lea_code_780LEA
# 244               agency_lea_code_780LEA                      lea_code_780LEA
# 245                    county_Rockingham                      lea_code_790LEA
# 246               agency_lea_code_790LEA                      lea_code_790LEA
# 247                         county_Rowan                      lea_code_800LEA
# 248               agency_lea_code_800LEA                      lea_code_800LEA
# 249                    county_Rutherford                      lea_code_810LEA
# 250               agency_lea_code_810LEA                      lea_code_810LEA
# 251               agency_lea_code_820LEA                      lea_code_820LEA
# 252               agency_lea_code_821LEA                      lea_code_821LEA
# 253                      county_Scotland                      lea_code_830LEA
# 254               agency_lea_code_830LEA                      lea_code_830LEA
# 255                        county_Stanly                      lea_code_840LEA
# 256               agency_lea_code_840LEA                      lea_code_840LEA
# 257                        county_Stokes                      lea_code_850LEA
# 258               agency_lea_code_850LEA                      lea_code_850LEA
# 259               agency_lea_code_860LEA                      lea_code_860LEA
# 260               agency_lea_code_861LEA                      lea_code_861LEA
# 261               agency_lea_code_862LEA                      lea_code_862LEA
# 262                         county_Swain                      lea_code_870LEA
# 263               agency_lea_code_870LEA                      lea_code_870LEA
# 264                  county_Transylvania                      lea_code_880LEA
# 265               agency_lea_code_880LEA                      lea_code_880LEA
# 266                       county_Tyrrell                      lea_code_890LEA
# 267               agency_lea_code_890LEA                      lea_code_890LEA
# 268                         county_Union                      lea_code_900LEA
# 269               agency_lea_code_900LEA                      lea_code_900LEA
# 270                         county_Vance                      lea_code_910LEA
# 271               agency_lea_code_910LEA                      lea_code_910LEA
# 272                          county_Wake                      lea_code_920LEA
# 273               agency_lea_code_920LEA                      lea_code_920LEA
# 274                        county_Warren                      lea_code_930LEA
# 275               agency_lea_code_930LEA                      lea_code_930LEA
# 276                    county_Washington                      lea_code_940LEA
# 277               agency_lea_code_940LEA                      lea_code_940LEA
# 278                       county_Watauga                      lea_code_950LEA
# 279               agency_lea_code_950LEA                      lea_code_950LEA
# 280                         county_Wayne                      lea_code_960LEA
# 281               agency_lea_code_960LEA                      lea_code_960LEA
# 282                        county_Wilkes                      lea_code_970LEA
# 283               agency_lea_code_970LEA                      lea_code_970LEA
# 284                        county_Wilson                      lea_code_980LEA
# 285               agency_lea_code_980LEA                      lea_code_980LEA
# 286                        county_Yadkin                      lea_code_990LEA
# 287               agency_lea_code_990LEA                      lea_code_990LEA
# 288                        county_Yancey                      lea_code_995LEA
# 289               agency_lea_code_995LEA                      lea_code_995LEA
# 290               agency_lea_code_020LEA                     county_Alexander
# 291               agency_lea_code_030LEA                     county_Alleghany
# 292               agency_lea_code_040LEA                         county_Anson
# 293               agency_lea_code_050LEA                          county_Ashe
# 294               agency_lea_code_060LEA                         county_Avery
# 295               agency_lea_code_070LEA                      county_Beaufort
# 296               agency_lea_code_080LEA                        county_Bertie
# 297               agency_lea_code_090LEA                        county_Bladen
# 298               agency_lea_code_100LEA                     county_Brunswick
# 299               agency_lea_code_120LEA                         county_Burke
# 300               agency_lea_code_130LEA                      county_Cabarrus
# 301               agency_lea_code_140LEA                      county_Caldwell
# 302               agency_lea_code_150LEA                        county_Camden
# 303               agency_lea_code_160LEA                      county_Carteret
# 304               agency_lea_code_170LEA                       county_Caswell
# 305               agency_lea_code_190LEA                       county_Chatham
# 306               agency_lea_code_200LEA                      county_Cherokee
# 307               agency_lea_code_210LEA                        county_Chowan
# 308               agency_lea_code_220LEA                          county_Clay
# 309               agency_lea_code_230LEA                     county_Cleveland
# 310               agency_lea_code_250LEA                        county_Craven
# 311               agency_lea_code_260LEA                    county_Cumberland
# 312    subgroup_list_ALL,EDS,MU7,SWD,WH7                     county_Currituck
# 313               agency_lea_code_270LEA                     county_Currituck
# 314               agency_lea_code_280LEA                          county_Dare
# 315               agency_lea_code_300LEA                         county_Davie
# 316               agency_lea_code_310LEA                        county_Duplin
# 317               agency_lea_code_320LEA                        county_Durham
# 318               agency_lea_code_330LEA                     county_Edgecombe
# 319               agency_lea_code_340LEA                       county_Forsyth
# 320               agency_lea_code_350LEA                      county_Franklin
# 321               agency_lea_code_360LEA                        county_Gaston
# 322               agency_lea_code_370LEA                         county_Gates
# 323               agency_lea_code_380LEA                        county_Graham
# 324               agency_lea_code_390LEA                     county_Granville
# 325               agency_lea_code_400LEA                        county_Greene
# 326               agency_lea_code_410LEA                      county_Guilford
# 327               agency_lea_code_430LEA                       county_Harnett
# 328               agency_lea_code_440LEA                       county_Haywood
# 329               agency_lea_code_450LEA                     county_Henderson
# 330               agency_lea_code_460LEA                      county_Hertford
# 331               agency_lea_code_470LEA                          county_Hoke
# 332               agency_lea_code_480LEA                          county_Hyde
# 333               agency_lea_code_490LEA                       county_Iredell
# 334               agency_lea_code_500LEA                       county_Jackson
# 335               agency_lea_code_510LEA                      county_Johnston
# 336               agency_lea_code_520LEA                         county_Jones
# 337               agency_lea_code_530LEA                           county_Lee
# 338               agency_lea_code_540LEA                        county_Lenoir
# 339               agency_lea_code_550LEA                       county_Lincoln
# 340               agency_lea_code_560LEA                         county_Macon
# 341               agency_lea_code_570LEA                       county_Madison
# 342               agency_lea_code_580LEA                        county_Martin
# 343               agency_lea_code_590LEA                      county_McDowell
# 344               agency_lea_code_600LEA                   county_Mecklenburg
# 345               agency_lea_code_610LEA                      county_Mitchell
# 346               agency_lea_code_620LEA                    county_Montgomery
# 347               agency_lea_code_630LEA                         county_Moore
# 348               agency_lea_code_640LEA                          county_Nash
# 349               agency_lea_code_650LEA                   county_New Hanover
# 350               agency_lea_code_660LEA                   county_Northampton
# 351               agency_lea_code_670LEA                        county_Onslow
# 352               agency_lea_code_690LEA                       county_Pamlico
# 353               agency_lea_code_700LEA                    county_Pasquotank
# 354               agency_lea_code_710LEA                        county_Pender
# 355               agency_lea_code_720LEA                    county_Perquimans
# 356               agency_lea_code_730LEA                        county_Person
# 357               agency_lea_code_740LEA                          county_Pitt
# 358               agency_lea_code_750LEA                          county_Polk
# 359               agency_lea_code_770LEA                      county_Richmond
# 360               agency_lea_code_780LEA                       county_Robeson
# 361               agency_lea_code_790LEA                    county_Rockingham
# 362               agency_lea_code_800LEA                         county_Rowan
# 363               agency_lea_code_810LEA                    county_Rutherford
# 364               agency_lea_code_830LEA                      county_Scotland
# 365               agency_lea_code_840LEA                        county_Stanly
# 366               agency_lea_code_850LEA                        county_Stokes
# 367               agency_lea_code_870LEA                         county_Swain
# 368               agency_lea_code_880LEA                  county_Transylvania
# 369               agency_lea_code_890LEA                       county_Tyrrell
# 370               agency_lea_code_900LEA                         county_Union
# 371               agency_lea_code_910LEA                         county_Vance
# 372               agency_lea_code_920LEA                          county_Wake
# 373               agency_lea_code_930LEA                        county_Warren
# 374               agency_lea_code_940LEA                    county_Washington
# 375               agency_lea_code_950LEA                       county_Watauga
# 376               agency_lea_code_960LEA                         county_Wayne
# 377               agency_lea_code_970LEA                        county_Wilkes
# 378               agency_lea_code_980LEA                        county_Wilson
# 379               agency_lea_code_990LEA                        county_Yadkin
# 380               agency_lea_code_995LEA                        county_Yancey
# 381            subgroup_list_ALL,BL7,SWD                     grade_span_KG:13
# 382               agency_lea_code_270LEA    subgroup_list_ALL,EDS,MU7,SWD,WH7
#
#      Correlation
# 0       0.994008
# 1       0.993680
# 2       0.966715
# 3       0.962805
# 4       0.953730
# 5       0.952985
# 6       1.000000
# 7       0.966763
# 8       0.960895
# 9       0.966763
# 10      0.960895
# 11      0.975456
# 12      1.000000
# 13      0.993967
# 14      0.965325
# 15      0.999987
# 16      0.999992
# 17      0.999995
# 18      1.000000
# 19      0.999999
# 20      0.999990
# 21      0.999995
# 22      0.958643
# 23      0.958288
# 24      0.985737
# 25      0.959545
# 26      0.960904
# 27      0.989557
# 28      0.954199
# 29      0.989921
# 30      0.950344
# 31      0.955479
# 32      0.959156
# 33      0.994815
# 34      0.980341
# 35      0.994518
# 36      0.977660
# 37      0.993469
# 38      0.975557
# 39      0.998127
# 40      0.981653
# 41      0.997489
# 42      0.986728
# 43      0.999982
# 44      0.996034
# 45      0.973714
# 46      0.991865
# 47      0.985181
# 48      0.989419
# 49      0.986657
# 50      0.986248
# 51      0.984089
# 52      0.990918
# 53      0.996018
# 54      0.994305
# 55      0.953711
# 56      0.987649
# 57      0.958632
# 58      0.997494
# 59      0.988306
# 60      0.967010
# 61      0.974591
# 62      0.982406
# 63      0.982406
# 64      0.987860
# 65      0.981102
# 66      0.964228
# 67      0.970575
# 68      0.970575
# 69      0.969258
# 70      0.965432
# 71      0.973702
# 72      0.973702
# 73      1.000000
# 74      0.962051
# 75      0.987426
# 76      0.987426
# 77      1.000000
# 78      1.000000
# 79      1.000000
# 80      1.000000
# 81      1.000000
# 82      1.000000
# 83      0.961220
# 84      0.955726
# 85      1.000000
# 86      1.000000
# 87      1.000000
# 88      1.000000
# 89      1.000000
# 90      1.000000
# 91      1.000000
# 92      1.000000
# 93      1.000000
# 94      1.000000
# 95      1.000000
# 96      1.000000
# 97      1.000000
# 98      1.000000
# 99      1.000000
# 100     1.000000
# 101     1.000000
# 102     1.000000
# 103     1.000000
# 104     1.000000
# 105     1.000000
# 106     1.000000
# 107     0.952729
# 108     1.000000
# 109     1.000000
# 110     1.000000
# 111     1.000000
# 112     1.000000
# 113     1.000000
# 114     1.000000
# 115     1.000000
# 116     1.000000
# 117     1.000000
# 118     1.000000
# 119     1.000000
# 120     1.000000
# 121     1.000000
# 122     1.000000
# 123     1.000000
# 124     1.000000
# 125     1.000000
# 126     1.000000
# 127     1.000000
# 128     1.000000
# 129     1.000000
# 130     1.000000
# 131     1.000000
# 132     1.000000
# 133     1.000000
# 134     1.000000
# 135     1.000000
# 136     1.000000
# 137     1.000000
# 138     1.000000
# 139     1.000000
# 140     1.000000
# 141     1.000000
# 142     1.000000
# 143     1.000000
# 144     1.000000
# 145     1.000000
# 146     1.000000
# 147     1.000000
# 148     1.000000
# 149     1.000000
# 150     1.000000
# 151     1.000000
# 152     1.000000
# 153     1.000000
# 154     1.000000
# 155     1.000000
# 156     1.000000
# 157     1.000000
# 158     1.000000
# 159     1.000000
# 160     1.000000
# 161     1.000000
# 162     1.000000
# 163     1.000000
# 164     1.000000
# 165     1.000000
# 166     1.000000
# 167     1.000000
# 168     1.000000
# 169     1.000000
# 170     1.000000
# 171     1.000000
# 172     1.000000
# 173     1.000000
# 174     1.000000
# 175     1.000000
# 176     1.000000
# 177     1.000000
# 178     1.000000
# 179     1.000000
# 180     1.000000
# 181     1.000000
# 182     1.000000
# 183     1.000000
# 184     0.956689
# 185     1.000000
# 186     1.000000
# 187     1.000000
# 188     1.000000
# 189     1.000000
# 190     1.000000
# 191     1.000000
# 192     1.000000
# 193     1.000000
# 194     1.000000
# 195     1.000000
# 196     1.000000
# 197     1.000000
# 198     1.000000
# 199     1.000000
# 200     1.000000
# 201     1.000000
# 202     1.000000
# 203     1.000000
# 204     1.000000
# 205     1.000000
# 206     1.000000
# 207     1.000000
# 208     1.000000
# 209     1.000000
# 210     1.000000
# 211     1.000000
# 212     1.000000
# 213     1.000000
# 214     1.000000
# 215     1.000000
# 216     1.000000
# 217     1.000000
# 218     1.000000
# 219     1.000000
# 220     1.000000
# 221     1.000000
# 222     1.000000
# 223     1.000000
# 224     1.000000
# 225     1.000000
# 226     1.000000
# 227     1.000000
# 228     1.000000
# 229     1.000000
# 230     1.000000
# 231     1.000000
# 232     1.000000
# 233     1.000000
# 234     1.000000
# 235     1.000000
# 236     1.000000
# 237     1.000000
# 238     1.000000
# 239     1.000000
# 240     1.000000
# 241     1.000000
# 242     1.000000
# 243     1.000000
# 244     1.000000
# 245     1.000000
# 246     1.000000
# 247     1.000000
# 248     1.000000
# 249     1.000000
# 250     1.000000
# 251     1.000000
# 252     1.000000
# 253     1.000000
# 254     1.000000
# 255     1.000000
# 256     1.000000
# 257     1.000000
# 258     1.000000
# 259     1.000000
# 260     1.000000
# 261     1.000000
# 262     1.000000
# 263     1.000000
# 264     1.000000
# 265     1.000000
# 266     1.000000
# 267     1.000000
# 268     1.000000
# 269     1.000000
# 270     1.000000
# 271     1.000000
# 272     1.000000
# 273     1.000000
# 274     1.000000
# 275     1.000000
# 276     1.000000
# 277     1.000000
# 278     1.000000
# 279     1.000000
# 280     1.000000
# 281     1.000000
# 282     1.000000
# 283     1.000000
# 284     1.000000
# 285     1.000000
# 286     1.000000
# 287     1.000000
# 288     1.000000
# 289     1.000000
# 290     1.000000
# 291     1.000000
# 292     1.000000
# 293     1.000000
# 294     1.000000
# 295     1.000000
# 296     1.000000
# 297     1.000000
# 298     1.000000
# 299     1.000000
# 300     0.952729
# 301     1.000000
# 302     1.000000
# 303     1.000000
# 304     1.000000
# 305     1.000000
# 306     1.000000
# 307     1.000000
# 308     1.000000
# 309     1.000000
# 310     1.000000
# 311     1.000000
# 312     1.000000
# 313     1.000000
# 314     1.000000
# 315     1.000000
# 316     1.000000
# 317     1.000000
# 318     1.000000
# 319     1.000000
# 320     1.000000
# 321     1.000000
# 322     1.000000
# 323     1.000000
# 324     1.000000
# 325     1.000000
# 326     1.000000
# 327     1.000000
# 328     1.000000
# 329     1.000000
# 330     1.000000
# 331     1.000000
# 332     1.000000
# 333     0.956689
# 334     1.000000
# 335     1.000000
# 336     1.000000
# 337     1.000000
# 338     1.000000
# 339     1.000000
# 340     1.000000
# 341     1.000000
# 342     1.000000
# 343     1.000000
# 344     1.000000
# 345     1.000000
# 346     1.000000
# 347     1.000000
# 348     1.000000
# 349     1.000000
# 350     1.000000
# 351     1.000000
# 352     1.000000
# 353     1.000000
# 354     1.000000
# 355     1.000000
# 356     1.000000
# 357     1.000000
# 358     1.000000
# 359     1.000000
# 360     1.000000
# 361     1.000000
# 362     1.000000
# 363     1.000000
# 364     1.000000
# 365     1.000000
# 366     1.000000
# 367     1.000000
# 368     1.000000
# 369     1.000000
# 370     1.000000
# 371     1.000000
# 372     1.000000
# 373     1.000000
# 374     1.000000
# 375     1.000000
# 376     1.000000
# 377     1.000000
# 378     1.000000
# 379     1.000000
# 380     1.000000
# 381     1.000000
# 382     1.000000

# %%
#The old way
#print('Dropping the following ', str(len(to_drop)), ' highly correlated fields.')
#to_drop

# Comparing highly correlated unique field names in field 1 vs field 2 list above will allow you to 
# remove the least amount of fields possible.  
#len(cf['Field1'].unique())
#len(cf['Field2'].unique())

print('Dropping the following ', str(len(cf['Field2'].unique())), ' highly correlated, unique fields.')
cf['Field2'].unique()
# Out:
# Dropping the following  258  highly correlated, unique fields.
# array(['IndianPct', 'AsianPct', 'HispanicPct', 'WhitePct', 'MinorityPct',
#        'IndianMalePct', 'pct_ALL_ELP', 'pct_met_Math Grades 3-8_PART',
#        'pct_met_Science Grades 5&8_PART',
#        'pct_Math Grades 3-8_ALL_PART_DET',
#        'pct_Math Grades 3-8_BL7_PART_DET',
#        'pct_Math Grades 3-8_EDS_PART_DET',
#        'pct_Math Grades 3-8_ELS_PART_DET',
#        'pct_Math Grades 3-8_HI7_PART_DET',
#        'pct_Math Grades 3-8_SWD_PART_DET',
#        'pct_Math Grades 3-8_WH7_PART_DET',
#        'pct_Science Grades 5&8_WH7_PART_DET', 'ma_score', 'rd_score',
#        'sc_score', 'ach_score', 'spg_score', 'ma_spg_score',
#        'aaa_score_ALL_SPG2', 'aaa_score_BL7_SPG2', 'aaa_score_EDS_SPG2',
#        'aaa_score_ELS_SPG2', 'aaa_score_HI7_SPG2', 'aaa_score_MU7_SPG2',
#        'aaa_score_SWD_SPG2', 'aaa_score_WH7_SPG2', 'ach_score_ALL_SPG2',
#        'ach_score_BL7_SPG2', 'ach_score_EDS_SPG2', 'ach_score_ELS_SPG2',
#        'ach_score_HI7_SPG2', 'ach_score_MU7_SPG2', 'ach_score_WH7_SPG2',
#        'avg_student_num', 'pct_ALL_CHRON_ABSENT', 'highqual_class_pct_M',
#        'arre_per1000_ALL', 'arre_per1000_BL7', 'arre_per1000_EDS',
#        'arre_per1000_ELS', 'arre_per1000_MALE', 'crime_per1000_ELS',
#        'exp_per1000_ALL', 'exp_per1000_BL7', 'exp_per1000_EDS',
#        'iss_per1000_ALL', 'lts_per1000_ALL', 'lea_code_020LEA',
#        'lea_code_030LEA', 'lea_code_040LEA', 'lea_code_050LEA',
#        'lea_code_060LEA', 'lea_code_070LEA', 'lea_code_080LEA',
#        'lea_code_090LEA', 'lea_code_100LEA', 'lea_code_110LEA',
#        'lea_code_111LEA', 'lea_code_120LEA', 'lea_code_130LEA',
#        'lea_code_132LEA', 'lea_code_140LEA', 'lea_code_150LEA',
#        'lea_code_160LEA', 'lea_code_170LEA', 'lea_code_180LEA',
#        'lea_code_181LEA', 'lea_code_182LEA', 'lea_code_190LEA',
#        'lea_code_200LEA', 'lea_code_210LEA', 'lea_code_220LEA',
#        'lea_code_230LEA', 'lea_code_240LEA', 'lea_code_241LEA',
#        'lea_code_250LEA', 'lea_code_260LEA', 'lea_code_270LEA',
#        'lea_code_280LEA', 'lea_code_290LEA', 'lea_code_291LEA',
#        'lea_code_292LEA', 'lea_code_300LEA', 'lea_code_310LEA',
#        'lea_code_320LEA', 'lea_code_330LEA', 'lea_code_340LEA',
#        'lea_code_350LEA', 'lea_code_360LEA', 'lea_code_370LEA',
#        'lea_code_380LEA', 'lea_code_390LEA', 'lea_code_400LEA',
#        'lea_code_410LEA', 'lea_code_420LEA', 'lea_code_421LEA',
#        'lea_code_422LEA', 'lea_code_430LEA', 'lea_code_440LEA',
#        'lea_code_450LEA', 'lea_code_460LEA', 'lea_code_470LEA',
#        'lea_code_480LEA', 'lea_code_490LEA', 'lea_code_491LEA',
#        'lea_code_500LEA', 'lea_code_510LEA', 'lea_code_520LEA',
#        'lea_code_530LEA', 'lea_code_540LEA', 'lea_code_550LEA',
#        'lea_code_560LEA', 'lea_code_570LEA', 'lea_code_580LEA',
#        'lea_code_590LEA', 'lea_code_600LEA', 'lea_code_610LEA',
#        'lea_code_620LEA', 'lea_code_630LEA', 'lea_code_640LEA',
#        'lea_code_650LEA', 'lea_code_660LEA', 'lea_code_670LEA',
#        'lea_code_680LEA', 'lea_code_681LEA', 'lea_code_690LEA',
#        'lea_code_700LEA', 'lea_code_710LEA', 'lea_code_720LEA',
#        'lea_code_730LEA', 'lea_code_740LEA', 'lea_code_750LEA',
#        'lea_code_760LEA', 'lea_code_761LEA', 'lea_code_770LEA',
#        'lea_code_780LEA', 'lea_code_790LEA', 'lea_code_800LEA',
#        'lea_code_810LEA', 'lea_code_820LEA', 'lea_code_821LEA',
#        'lea_code_830LEA', 'lea_code_840LEA', 'lea_code_850LEA',
#        'lea_code_860LEA', 'lea_code_861LEA', 'lea_code_862LEA',
#        'lea_code_870LEA', 'lea_code_880LEA', 'lea_code_890LEA',
#        'lea_code_900LEA', 'lea_code_910LEA', 'lea_code_920LEA',
#        'lea_code_930LEA', 'lea_code_940LEA', 'lea_code_950LEA',
#        'lea_code_960LEA', 'lea_code_970LEA', 'lea_code_980LEA',
#        'lea_code_990LEA', 'lea_code_995LEA', 'county_Alexander',
#        'county_Alleghany', 'county_Anson', 'county_Ashe', 'county_Avery',
#        'county_Beaufort', 'county_Bertie', 'county_Bladen',
#        'county_Brunswick', 'county_Burke', 'county_Cabarrus',
#        'county_Caldwell', 'county_Camden', 'county_Carteret',
#        'county_Caswell', 'county_Chatham', 'county_Cherokee',
#        'county_Chowan', 'county_Clay', 'county_Cleveland',
#        'county_Craven', 'county_Cumberland', 'county_Currituck',
#        'county_Dare', 'county_Davie', 'county_Duplin', 'county_Durham',
#        'county_Edgecombe', 'county_Forsyth', 'county_Franklin',
#        'county_Gaston', 'county_Gates', 'county_Graham',
#        'county_Granville', 'county_Greene', 'county_Guilford',
#        'county_Harnett', 'county_Haywood', 'county_Henderson',
#        'county_Hertford', 'county_Hoke', 'county_Hyde', 'county_Iredell',
#        'county_Jackson', 'county_Johnston', 'county_Jones', 'county_Lee',
#        'county_Lenoir', 'county_Lincoln', 'county_Macon',
#        'county_Madison', 'county_Martin', 'county_McDowell',
#        'county_Mecklenburg', 'county_Mitchell', 'county_Montgomery',
#        'county_Moore', 'county_Nash', 'county_New Hanover',
#        'county_Northampton', 'county_Onslow', 'county_Pamlico',
#        'county_Pasquotank', 'county_Pender', 'county_Perquimans',
#        'county_Person', 'county_Pitt', 'county_Polk', 'county_Richmond',
#        'county_Robeson', 'county_Rockingham', 'county_Rowan',
#        'county_Rutherford', 'county_Scotland', 'county_Stanly',
#        'county_Stokes', 'county_Swain', 'county_Transylvania',
#        'county_Tyrrell', 'county_Union', 'county_Vance', 'county_Wake',
#        'county_Warren', 'county_Washington', 'county_Watauga',
#        'county_Wayne', 'county_Wilkes', 'county_Wilson', 'county_Yadkin',
#        'county_Yancey', 'grade_span_KG:13',
#        'subgroup_list_ALL,EDS,MU7,SWD,WH7'], dtype=object)

# %%
#Check columns before drop 
print('\r\n*********Before: Dropping Highly Correlated Fields*************************************')
schoolData.info(verbose=False)

# Drop the highly correlated features from our training data 
#schoolData = schoolData.drop(to_drop, axis=1)
schoolData = schoolData.drop(cf['Field2'], axis=1)

#Check columns after drop 
print('\r\n*********After: Dropping Highly Correlated Fields**************************************')
schoolData.info(verbose=False)
# Out:
# *********Before: Dropping Highly Correlated Fields*************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 660 entries, 2 to 805
# Columns: 733 entries, IndianPct to agency_lea_code_995LEA
# dtypes: float64(246), uint8(487)
# memory usage: 1.6 MB
#
# *********After: Dropping Highly Correlated Fields**************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 660 entries, 2 to 805
# Columns: 475 entries, BlackPct to agency_lea_code_995LEA
# dtypes: float64(194), uint8(281)
# memory usage: 1.2 MB

# %%
#Restore the unit_code before saving
schoolData['agency_code'] = agency_code
#Save the final dataset to a .csv file
schoolData.to_csv(outputDir + inputFileName + '_ML.csv', sep=',', index=False)

# %%
print('*********FINAL DATASET DETAILS*********************************************************\r\n')
schoolData.info(verbose=True)
# Out:
# *********FINAL DATASET DETAILS*********************************************************
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 660 entries, 2 to 805
# Data columns (total 476 columns):
# BlackPct                                                                                                            float64
# PacificIslandPct                                                                                                    float64
# TwoOrMorePct                                                                                                        float64
# AsianMalePct                                                                                                        float64
# HispanicMalePct                                                                                                     float64
# BlackMalePct                                                                                                        float64
# WhiteMalePct                                                                                                        float64
# PacificIslandMalePct                                                                                                float64
# TwoOrMoreMalePct                                                                                                    float64
# MinorityMalePct                                                                                                     float64
# IndianFemalePct                                                                                                     float64
# AsianFemalePct                                                                                                      float64
# HispanicFemalePct                                                                                                   float64
# BlackFemalePct                                                                                                      float64
# WhiteFemalePct                                                                                                      float64
# MinorityFemalePct                                                                                                   float64
# PacificIslandFemalePct                                                                                              float64
# TwoOrMoreFemalePct                                                                                                  float64
# pct_eds                                                                                                             float64
# pct_EDS_ELP                                                                                                         float64
# pct_ELS_ELP                                                                                                         float64
# pct_HI7_ELP                                                                                                         float64
# pct_MALE_ELP                                                                                                        float64
# pct_prof_6gr_irm                                                                                                    float64
# pct_met_Math Grades 3-8_LTG                                                                                         float64
# pct_met_Reading Grades 3-8_LTG                                                                                      float64
# pct_met_Total Targets_LTG                                                                                           float64
# pct_met_Reading Grades 3-8_PART                                                                                     float64
# pct_met_Total Targets_PART                                                                                          float64
# pct_Reading Grades 3-8_ALL_PART_DET                                                                                 float64
# pct_Reading Grades 3-8_BL7_PART_DET                                                                                 float64
# pct_Reading Grades 3-8_EDS_PART_DET                                                                                 float64
# pct_Reading Grades 3-8_ELS_PART_DET                                                                                 float64
# pct_Reading Grades 3-8_HI7_PART_DET                                                                                 float64
# pct_Reading Grades 3-8_SWD_PART_DET                                                                                 float64
# pct_Reading Grades 3-8_WH7_PART_DET                                                                                 float64
# pct_Science Grades 5&8_ALL_PART_DET                                                                                 float64
# pct_Science Grades 5&8_BL7_PART_DET                                                                                 float64
# pct_Science Grades 5&8_EDS_PART_DET                                                                                 float64
# m1_score                                                                                                            float64
# eg_score                                                                                                            float64
# rd_spg_score                                                                                                        float64
# ma_eg_score                                                                                                         float64
# rd_eg_score                                                                                                         float64
# ach_score_SWD_SPG2                                                                                                  float64
# eg_score_ALL_SPG2                                                                                                   float64
# eg_score_BL7_SPG2                                                                                                   float64
# eg_score_EDS_SPG2                                                                                                   float64
# eg_score_ELS_SPG2                                                                                                   float64
# eg_score_HI7_SPG2                                                                                                   float64
# eg_score_MU7_SPG2                                                                                                   float64
# eg_score_SWD_SPG2                                                                                                   float64
# eg_score_WH7_SPG2                                                                                                   float64
# scgs_score_ALL_SPG2                                                                                                 float64
# scgs_score_BL7_SPG2                                                                                                 float64
# scgs_score_EDS_SPG2                                                                                                 float64
# scgs_score_WH7_SPG2                                                                                                 float64
# spg_score_ALL_SPG2                                                                                                  float64
# spg_score_BL7_SPG2                                                                                                  float64
# spg_score_EDS_SPG2                                                                                                  float64
# spg_score_ELS_SPG2                                                                                                  float64
# spg_score_HI7_SPG2                                                                                                  float64
# spg_score_MU7_SPG2                                                                                                  float64
# spg_score_SWD_SPG2                                                                                                  float64
# spg_score_WH7_SPG2                                                                                                  float64
# pct_att                                                                                                             float64
# pct_BL7_CHRON_ABSENT                                                                                                float64
# pct_ELS_CHRON_ABSENT                                                                                                float64
# pct_FEM_CHRON_ABSENT                                                                                                float64
# pct_HI7_CHRON_ABSENT                                                                                                float64
# pct_MALE_CHRON_ABSENT                                                                                               float64
# pct_MU7_CHRON_ABSENT                                                                                                float64
# pct_SWD_CHRON_ABSENT                                                                                                float64
# pct_WH7_CHRON_ABSENT                                                                                                float64
# stu_enroll                                                                                                          float64
# cte_enroll                                                                                                          float64
# cte_enrollment_pct                                                                                                  float64
# Book_TitlesPer_Student                                                                                              float64
# wap                                                                                                                 float64
# wap_class                                                                                                           float64
# media_school                                                                                                        float64
# devices                                                                                                             float64
# pct_rating_T1_Accomplished                                                                                          float64
# pct_rating_T1_Distinguished                                                                                         float64
# pct_rating_T1_Proficient                                                                                            float64
# pct_rating_T2_Accomplished                                                                                          float64
# pct_rating_T2_Distinguished                                                                                         float64
# pct_rating_T2_Proficient                                                                                            float64
# pct_rating_T3_Accomplished                                                                                          float64
# pct_rating_T3_Distinguished                                                                                         float64
# pct_rating_T3_Proficient                                                                                            float64
# pct_rating_T4_Accomplished                                                                                          float64
# pct_rating_T4_Distinguished                                                                                         float64
# pct_rating_T4_Proficient                                                                                            float64
# pct_rating_T5_Accomplished                                                                                          float64
# pct_rating_T5_Distinguished                                                                                         float64
# pct_rating_T5_Proficient                                                                                            float64
# pct_rating_TS_Does Not Meet Expected Growth                                                                         float64
# pct_rating_TS_Exceeds Expected Growth                                                                               float64
# pct_rating_TS_Meets Expected Growth                                                                                 float64
# avg_class_teach_TeacherExp                                                                                          float64
# pct_adv_degree_TeacherExp                                                                                           float64
# pct_experience_0_TeacherExp                                                                                         float64
# pct_experience_10_TeacherExp                                                                                        float64
# pct_experience_4_TeacherExp                                                                                         float64
# pct_turnover_TeacherExp                                                                                             float64
# crime                                                                                                               float64
# short_term                                                                                                          float64
# long_term                                                                                                           float64
# expulsion                                                                                                           float64
# arre_per1000_FEM                                                                                                    float64
# arre_per1000_HI7                                                                                                    float64
# arre_per1000_MU7                                                                                                    float64
# arre_per1000_SWD                                                                                                    float64
# arre_per1000_WH7                                                                                                    float64
# blhr_per1000_ALL                                                                                                    float64
# blhr_per1000_BL7                                                                                                    float64
# blhr_per1000_EDS                                                                                                    float64
# blhr_per1000_ELS                                                                                                    float64
# blhr_per1000_FEM                                                                                                    float64
# blhr_per1000_HI7                                                                                                    float64
# blhr_per1000_MALE                                                                                                   float64
# blhr_per1000_MU7                                                                                                    float64
# blhr_per1000_SWD                                                                                                    float64
# blhr_per1000_WH7                                                                                                    float64
# crime_per1000_ALL                                                                                                   float64
# crime_per1000_BL7                                                                                                   float64
# crime_per1000_EDS                                                                                                   float64
# crime_per1000_FEM                                                                                                   float64
# crime_per1000_HI7                                                                                                   float64
# crime_per1000_MALE                                                                                                  float64
# crime_per1000_MU7                                                                                                   float64
# crime_per1000_SWD                                                                                                   float64
# crime_per1000_WH7                                                                                                   float64
# exp_per1000_ELS                                                                                                     float64
# exp_per1000_FEM                                                                                                     float64
# exp_per1000_HI7                                                                                                     float64
# exp_per1000_MALE                                                                                                    float64
# exp_per1000_MU7                                                                                                     float64
# exp_per1000_SWD                                                                                                     float64
# exp_per1000_WH7                                                                                                     float64
# iss_per1000_BL7                                                                                                     float64
# iss_per1000_EDS                                                                                                     float64
# iss_per1000_ELS                                                                                                     float64
# iss_per1000_FEM                                                                                                     float64
# iss_per1000_HI7                                                                                                     float64
# iss_per1000_MALE                                                                                                    float64
# iss_per1000_MU7                                                                                                     float64
# iss_per1000_SWD                                                                                                     float64
# iss_per1000_WH7                                                                                                     float64
# lts_per1000_BL7                                                                                                     float64
# lts_per1000_EDS                                                                                                     float64
# lts_per1000_ELS                                                                                                     float64
# lts_per1000_FEM                                                                                                     float64
# lts_per1000_HI7                                                                                                     float64
# lts_per1000_MALE                                                                                                    float64
# lts_per1000_MU7                                                                                                     float64
# lts_per1000_SWD                                                                                                     float64
# lts_per1000_WH7                                                                                                     float64
# rplw_per1000_ALL                                                                                                    float64
# rplw_per1000_BL7                                                                                                    float64
# rplw_per1000_EDS                                                                                                    float64
# rplw_per1000_FEM                                                                                                    float64
# rplw_per1000_HI7                                                                                                    float64
# rplw_per1000_MALE                                                                                                   float64
# rplw_per1000_MU7                                                                                                    float64
# rplw_per1000_SWD                                                                                                    float64
# rplw_per1000_WH7                                                                                                    float64
# sts_per1000_ALL                                                                                                     float64
# sts_per1000_BL7                                                                                                     float64
# sts_per1000_EDS                                                                                                     float64
# sts_per1000_ELS                                                                                                     float64
# sts_per1000_FEM                                                                                                     float64
# sts_per1000_HI7                                                                                                     float64
# sts_per1000_MALE                                                                                                    float64
# sts_per1000_MU7                                                                                                     float64
# sts_per1000_SWD                                                                                                     float64
# sts_per1000_WH7                                                                                                     float64
# pct_fully_licensed                                                                                                  float64
# pct_lateral_entry                                                                                                   float64
# nbpts_num                                                                                                           float64
# avg_size_06_SAR                                                                                                     float64
# avg_size_07_SAR                                                                                                     float64
# avg_size_08_SAR                                                                                                     float64
# avg_size_Math I_SAR                                                                                                 float64
# lea_total_expense                                                                                                   float64
# lea_pct_salary                                                                                                      float64
# lea_pct_benefits                                                                                                    float64
# lea_pct_services                                                                                                    float64
# lea_pct_supplies                                                                                                    float64
# lea_pct_instruct_equip                                                                                              float64
# lea_local_perpupil                                                                                                  float64
# lea_state_perpupil                                                                                                  float64
# lea_federal_perpupil                                                                                                float64
# category_code_I                                                                                                     uint8
# category_code_M                                                                                                     uint8
# category_code_T                                                                                                     uint8
# county_Buncombe                                                                                                     uint8
# county_Catawba                                                                                                      uint8
# county_Columbus                                                                                                     uint8
# county_Davidson                                                                                                     uint8
# county_Halifax                                                                                                      uint8
# county_Orange                                                                                                       uint8
# county_Randolph                                                                                                     uint8
# county_Sampson                                                                                                      uint8
# county_Surry                                                                                                        uint8
# grade_span_04:08                                                                                                    uint8
# grade_span_05:06                                                                                                    uint8
# grade_span_05:08                                                                                                    uint8
# grade_span_06:06                                                                                                    uint8
# grade_span_06:08                                                                                                    uint8
# grade_span_06:09                                                                                                    uint8
# grade_span_06:10                                                                                                    uint8
# grade_span_06:12                                                                                                    uint8
# grade_span_06:13                                                                                                    uint8
# grade_span_07:08                                                                                                    uint8
# grade_span_07:10                                                                                                    uint8
# grade_span_07:12                                                                                                    uint8
# grade_span_07:13                                                                                                    uint8
# grade_span_KG:08                                                                                                    uint8
# grade_span_KG:12                                                                                                    uint8
# grade_span_PK:08                                                                                                    uint8
# grade_span_PK:09                                                                                                    uint8
# grade_span_PK:12                                                                                                    uint8
# grade_span_PK:13                                                                                                    uint8
# school_type_Hospital School                                                                                         uint8
# school_type_Magnet School                                                                                           uint8
# school_type_Regular School                                                                                          uint8
# school_type_Special Education                                                                                       uint8
# calendar_type_Year-Round Calendar                                                                                   uint8
# csi_lp_Y                                                                                                            uint8
# csi_lg_Y                                                                                                            uint8
# tsi_cu_Y                                                                                                            uint8
# tsi_at_Y                                                                                                            uint8
# grad_project_Y                                                                                                      uint8
# lp_school_Y                                                                                                         uint8
# rlp_school_Y                                                                                                        uint8
# target_list_4 Year Graduation Rate,EL Progress,Math Grade 11,Math Grades 3-8,Reading Grade 10,Reading Grades 3-8    uint8
# target_list_4 Year Graduation Rate,Math Grade 11                                                                    uint8
# target_list_4 Year Graduation Rate,Math Grade 11,Math Grades 3-8,Reading Grade 10,Reading Grades 3-8                uint8
# target_list_4 Year Graduation Rate,Math Grade 11,Math Grades 3-8,Reading Grades 3-8                                 uint8
# target_list_4 Year Graduation Rate,Math Grade 11,Reading Grade 10                                                   uint8
# target_list_4 Year Graduation Rate,Math Grades 3-8,Reading Grades 3-8                                               uint8
# target_list_EL Progress,Math Grades 3-8,Reading Grades 3-8                                                          uint8
# target_list_Math Grade 11,Math Grades 3-8,Reading Grade 10,Reading Grades 3-8                                       uint8
# target_list_Math Grade 11,Math Grades 3-8,Reading Grades 3-8                                                        uint8
# target_list_Math Grades 3-8,Reading Grade 10,Reading Grades 3-8                                                     uint8
# target_list_Math Grades 3-8,Reading Grades 3-8                                                                      uint8
# subgroup_list_ALL,AM7,BL7,EDS                                                                                       uint8
# subgroup_list_ALL,AM7,BL7,EDS,ELS,HI7,MU7,SWD                                                                       uint8
# subgroup_list_ALL,AM7,BL7,EDS,ELS,HI7,MU7,SWD,WH7                                                                   uint8
# subgroup_list_ALL,AM7,BL7,EDS,ELS,HI7,SWD,WH7                                                                       uint8
# subgroup_list_ALL,AM7,BL7,EDS,HI7,MU7,SWD,WH7                                                                       uint8
# subgroup_list_ALL,AM7,BL7,EDS,HI7,SWD                                                                               uint8
# subgroup_list_ALL,AM7,BL7,EDS,HI7,SWD,WH7                                                                           uint8
# subgroup_list_ALL,AM7,BL7,EDS,MU7,SWD,WH7                                                                           uint8
# subgroup_list_ALL,AM7,BL7,EDS,SWD                                                                                   uint8
# subgroup_list_ALL,AM7,BL7,EDS,SWD,WH7                                                                               uint8
# subgroup_list_ALL,AM7,BL7,EDS,WH7                                                                                   uint8
# subgroup_list_ALL,AM7,EDS,SWD                                                                                       uint8
# subgroup_list_ALL,AM7,EDS,SWD,WH7                                                                                   uint8
# subgroup_list_ALL,AS7,BL7,EDS,ELS,HI7,MU7,SWD,WH7                                                                   uint8
# subgroup_list_ALL,AS7,BL7,EDS,ELS,HI7,SWD                                                                           uint8
# subgroup_list_ALL,AS7,BL7,EDS,ELS,HI7,SWD,WH7                                                                       uint8
# subgroup_list_ALL,AS7,BL7,EDS,HI7                                                                                   uint8
# subgroup_list_ALL,AS7,BL7,EDS,HI7,MU7,SWD,WH7                                                                       uint8
# subgroup_list_ALL,AS7,BL7,EDS,HI7,MU7,WH7                                                                           uint8
# subgroup_list_ALL,AS7,BL7,EDS,HI7,SWD,WH7                                                                           uint8
# subgroup_list_ALL,AS7,BL7,EDS,HI7,WH7                                                                               uint8
# subgroup_list_ALL,AS7,BL7,EDS,MU7,SWD,WH7                                                                           uint8
# subgroup_list_ALL,AS7,BL7,HI7,MU7,SWD,WH7                                                                           uint8
# subgroup_list_ALL,AS7,EDS,HI7,SWD,WH7                                                                               uint8
# subgroup_list_ALL,AS7,WH7                                                                                           uint8
# subgroup_list_ALL,BL7                                                                                               uint8
# subgroup_list_ALL,BL7,EDS                                                                                           uint8
# subgroup_list_ALL,BL7,EDS,ELS,HI7,MU7,SWD,WH7                                                                       uint8
# subgroup_list_ALL,BL7,EDS,ELS,HI7,SWD                                                                               uint8
# subgroup_list_ALL,BL7,EDS,ELS,HI7,SWD,WH7                                                                           uint8
# subgroup_list_ALL,BL7,EDS,ELS,HI7,WH7                                                                               uint8
# subgroup_list_ALL,BL7,EDS,HI7                                                                                       uint8
# subgroup_list_ALL,BL7,EDS,HI7,MU7,SWD,WH7                                                                           uint8
# subgroup_list_ALL,BL7,EDS,HI7,SWD                                                                                   uint8
# subgroup_list_ALL,BL7,EDS,HI7,SWD,WH7                                                                               uint8
# subgroup_list_ALL,BL7,EDS,HI7,WH7                                                                                   uint8
# subgroup_list_ALL,BL7,EDS,MU7,SWD,WH7                                                                               uint8
# subgroup_list_ALL,BL7,EDS,SWD                                                                                       uint8
# subgroup_list_ALL,BL7,EDS,SWD,WH7                                                                                   uint8
# subgroup_list_ALL,BL7,EDS,WH7                                                                                       uint8
# subgroup_list_ALL,BL7,SWD                                                                                           uint8
# subgroup_list_ALL,EDS                                                                                               uint8
# subgroup_list_ALL,EDS,ELS,HI7,MU7,SWD,WH7                                                                           uint8
# subgroup_list_ALL,EDS,ELS,HI7,SWD,WH7                                                                               uint8
# subgroup_list_ALL,EDS,ELS,HI7,WH7                                                                                   uint8
# subgroup_list_ALL,EDS,HI7,MU7,SWD,WH7                                                                               uint8
# subgroup_list_ALL,EDS,HI7,SWD,WH7                                                                                   uint8
# subgroup_list_ALL,EDS,HI7,WH7                                                                                       uint8
# subgroup_list_ALL,EDS,SWD                                                                                           uint8
# subgroup_list_ALL,EDS,SWD,WH7                                                                                       uint8
# subgroup_list_ALL,EDS,WH7                                                                                           uint8
# subgroup_list_ALL,SWD                                                                                               uint8
# subgroup_list_ALL,WH7                                                                                               uint8
# ma_grade_B                                                                                                          uint8
# ma_grade_C                                                                                                          uint8
# ma_grade_D                                                                                                          uint8
# ma_grade_F                                                                                                          uint8
# rd_grade_B                                                                                                          uint8
# rd_grade_C                                                                                                          uint8
# rd_grade_D                                                                                                          uint8
# rd_grade_F                                                                                                          uint8
# eg_status_Met                                                                                                       uint8
# eg_status_NotMet                                                                                                    uint8
# spg_grade_A+NG                                                                                                      uint8
# spg_grade_B                                                                                                         uint8
# spg_grade_C                                                                                                         uint8
# spg_grade_D                                                                                                         uint8
# spg_grade_F                                                                                                         uint8
# ma_eg_status_Met                                                                                                    uint8
# ma_eg_status_NotMet                                                                                                 uint8
# rd_eg_status_Met                                                                                                    uint8
# rd_eg_status_NotMet                                                                                                 uint8
# dance_cat_Y                                                                                                         uint8
# music_cat_Y                                                                                                         uint8
# theatre_cat_Y                                                                                                       uint8
# va_cat_Y                                                                                                            uint8
# digital_media_0                                                                                                     uint8
# digital_media_1                                                                                                     uint8
# digital_media_10                                                                                                    uint8
# digital_media_100                                                                                                   uint8
# digital_media_11                                                                                                    uint8
# digital_media_12                                                                                                    uint8
# digital_media_13                                                                                                    uint8
# digital_media_14                                                                                                    uint8
# digital_media_15                                                                                                    uint8
# digital_media_16                                                                                                    uint8
# digital_media_17                                                                                                    uint8
# digital_media_18                                                                                                    uint8
# digital_media_19                                                                                                    uint8
# digital_media_2                                                                                                     uint8
# digital_media_20                                                                                                    uint8
# digital_media_23                                                                                                    uint8
# digital_media_25                                                                                                    uint8
# digital_media_3                                                                                                     uint8
# digital_media_34                                                                                                    uint8
# digital_media_35                                                                                                    uint8
# digital_media_37                                                                                                    uint8
# digital_media_4                                                                                                     uint8
# digital_media_44                                                                                                    uint8
# digital_media_5                                                                                                     uint8
# digital_media_54                                                                                                    uint8
# digital_media_6                                                                                                     uint8
# digital_media_7                                                                                                     uint8
# digital_media_8                                                                                                     uint8
# digital_media_9                                                                                                     uint8
# digital_media_95                                                                                                    uint8
# device_access_Yes                                                                                                   uint8
# device_home_Yes                                                                                                     uint8
# BYOD_Both                                                                                                           uint8
# BYOD_Neither                                                                                                        uint8
# BYOD_Staff                                                                                                          uint8
# BYOD_Students                                                                                                       uint8
# esea_att_Met                                                                                                        uint8
# agency_lea_code_020LEA                                                                                              uint8
# agency_lea_code_030LEA                                                                                              uint8
# agency_lea_code_040LEA                                                                                              uint8
# agency_lea_code_050LEA                                                                                              uint8
# agency_lea_code_060LEA                                                                                              uint8
# agency_lea_code_070LEA                                                                                              uint8
# agency_lea_code_080LEA                                                                                              uint8
# agency_lea_code_090LEA                                                                                              uint8
# agency_lea_code_100LEA                                                                                              uint8
# agency_lea_code_110LEA                                                                                              uint8
# agency_lea_code_111LEA                                                                                              uint8
# agency_lea_code_120LEA                                                                                              uint8
# agency_lea_code_130LEA                                                                                              uint8
# agency_lea_code_132LEA                                                                                              uint8
# agency_lea_code_140LEA                                                                                              uint8
# agency_lea_code_150LEA                                                                                              uint8
# agency_lea_code_160LEA                                                                                              uint8
# agency_lea_code_170LEA                                                                                              uint8
# agency_lea_code_180LEA                                                                                              uint8
# agency_lea_code_181LEA                                                                                              uint8
# agency_lea_code_182LEA                                                                                              uint8
# agency_lea_code_190LEA                                                                                              uint8
# agency_lea_code_200LEA                                                                                              uint8
# agency_lea_code_210LEA                                                                                              uint8
# agency_lea_code_220LEA                                                                                              uint8
# agency_lea_code_230LEA                                                                                              uint8
# agency_lea_code_240LEA                                                                                              uint8
# agency_lea_code_241LEA                                                                                              uint8
# agency_lea_code_250LEA                                                                                              uint8
# agency_lea_code_260LEA                                                                                              uint8
# agency_lea_code_270LEA                                                                                              uint8
# agency_lea_code_280LEA                                                                                              uint8
# agency_lea_code_290LEA                                                                                              uint8
# agency_lea_code_291LEA                                                                                              uint8
# agency_lea_code_292LEA                                                                                              uint8
# agency_lea_code_300LEA                                                                                              uint8
# agency_lea_code_310LEA                                                                                              uint8
# agency_lea_code_320LEA                                                                                              uint8
# agency_lea_code_330LEA                                                                                              uint8
# agency_lea_code_340LEA                                                                                              uint8
# agency_lea_code_350LEA                                                                                              uint8
# agency_lea_code_360LEA                                                                                              uint8
# agency_lea_code_370LEA                                                                                              uint8
# agency_lea_code_380LEA                                                                                              uint8
# agency_lea_code_390LEA                                                                                              uint8
# agency_lea_code_400LEA                                                                                              uint8
# agency_lea_code_410LEA                                                                                              uint8
# agency_lea_code_420LEA                                                                                              uint8
# agency_lea_code_421LEA                                                                                              uint8
# agency_lea_code_422LEA                                                                                              uint8
# agency_lea_code_430LEA                                                                                              uint8
# agency_lea_code_440LEA                                                                                              uint8
# agency_lea_code_450LEA                                                                                              uint8
# agency_lea_code_460LEA                                                                                              uint8
# agency_lea_code_470LEA                                                                                              uint8
# agency_lea_code_480LEA                                                                                              uint8
# agency_lea_code_490LEA                                                                                              uint8
# agency_lea_code_491LEA                                                                                              uint8
# agency_lea_code_500LEA                                                                                              uint8
# agency_lea_code_510LEA                                                                                              uint8
# agency_lea_code_520LEA                                                                                              uint8
# agency_lea_code_530LEA                                                                                              uint8
# agency_lea_code_540LEA                                                                                              uint8
# agency_lea_code_550LEA                                                                                              uint8
# agency_lea_code_560LEA                                                                                              uint8
# agency_lea_code_570LEA                                                                                              uint8
# agency_lea_code_580LEA                                                                                              uint8
# agency_lea_code_590LEA                                                                                              uint8
# agency_lea_code_600LEA                                                                                              uint8
# agency_lea_code_610LEA                                                                                              uint8
# agency_lea_code_620LEA                                                                                              uint8
# agency_lea_code_630LEA                                                                                              uint8
# agency_lea_code_640LEA                                                                                              uint8
# agency_lea_code_650LEA                                                                                              uint8
# agency_lea_code_660LEA                                                                                              uint8
# agency_lea_code_670LEA                                                                                              uint8
# agency_lea_code_680LEA                                                                                              uint8
# agency_lea_code_681LEA                                                                                              uint8
# agency_lea_code_690LEA                                                                                              uint8
# agency_lea_code_700LEA                                                                                              uint8
# agency_lea_code_710LEA                                                                                              uint8
# agency_lea_code_720LEA                                                                                              uint8
# agency_lea_code_730LEA                                                                                              uint8
# agency_lea_code_740LEA                                                                                              uint8
# agency_lea_code_750LEA                                                                                              uint8
# agency_lea_code_760LEA                                                                                              uint8
# agency_lea_code_761LEA                                                                                              uint8
# agency_lea_code_770LEA                                                                                              uint8
# agency_lea_code_780LEA                                                                                              uint8
# agency_lea_code_790LEA                                                                                              uint8
# agency_lea_code_800LEA                                                                                              uint8
# agency_lea_code_810LEA                                                                                              uint8
# agency_lea_code_820LEA                                                                                              uint8
# agency_lea_code_821LEA                                                                                              uint8
# agency_lea_code_830LEA                                                                                              uint8
# agency_lea_code_840LEA                                                                                              uint8
# agency_lea_code_850LEA                                                                                              uint8
# agency_lea_code_860LEA                                                                                              uint8
# agency_lea_code_861LEA                                                                                              uint8
# agency_lea_code_862LEA                                                                                              uint8
# agency_lea_code_870LEA                                                                                              uint8
# agency_lea_code_880LEA                                                                                              uint8
# agency_lea_code_890LEA                                                                                              uint8
# agency_lea_code_900LEA                                                                                              uint8
# agency_lea_code_910LEA                                                                                              uint8
# agency_lea_code_920LEA                                                                                              uint8
# agency_lea_code_930LEA                                                                                              uint8
# agency_lea_code_940LEA                                                                                              uint8
# agency_lea_code_950LEA                                                                                              uint8
# agency_lea_code_960LEA                                                                                              uint8
# agency_lea_code_970LEA                                                                                              uint8
# agency_lea_code_980LEA                                                                                              uint8
# agency_lea_code_990LEA                                                                                              uint8
# agency_lea_code_995LEA                                                                                              uint8
# agency_code                                                                                                         object
# dtypes: float64(194), object(1), uint8(281)
# memory usage: 1.2+ MB

# %%
import sklearn
import pandas as pd

print('Sklearn Version: ' + sklearn.__version__)
print('Pandas Version: ' + pd.__version__)
# Out:
# Sklearn Version: 0.20.3
# Pandas Version: 0.24.2

# %%
print('Output File Location:\r\n\r\n' + outputDir + inputFileName + '_ML.csv')
# Out:
# Output File Location:
#
# C:/Users/Jake/Documents/GitHub/EducationDataNC/2018/Machine Learning Datasets/PublicMiddleSchools2018_ML.csv
