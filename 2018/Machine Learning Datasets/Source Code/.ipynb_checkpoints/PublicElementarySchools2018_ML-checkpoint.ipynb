# %% [markdown]
# # Create Public School Machine Learning Datasets
# ** This program creates all the _ML datasets in the NCEA repository.**
# * This notebook reads each School Dataset file located at \EducationDataNC\ *schoolYear* \School Datasets\ as input data.
# * Different school years are processed by changing the *schoolYear* parameter.
# * Different input / output files are processed / created by changing the *inputFileName* paramter in the cell below.
# * While a single program is used to create all the _ML datasets, one program copy per dataset is maintained in the repositiory so the dataset specific tranformation reports may be reviewed.
#
# **Datasets ending in ML are preprocessed for Machine Learning and go through the following transformations: **
# 1. Missing student body racial compositions are imputed using district averages.
# 2. Columns that have the same value in every single row are deleted.
# 3. Columns that have a unique value in every single row (all values are different) are deleted.
# 4. Empty columns (all values are NA or NULL) are deleted.
# 5. Numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# 6. Remaining numeric, non-race columns with missing values are imputed / populated with 0.  In many cases, schools are not reporting values when they are zero. However, mean imputation or some other more sophisticated strategy might be considered here.
# 7. Categorical / text based columns with > *uniqueThreshold* unique values are deleted.
# 8. All remaining categorical / text based columns are one-hot encoded.  In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# 9. Duplicated or highly similar columns with > 95% correlation are delelted.

# %%
#import required Libraries
import pandas as pd
import numpy as np
import os
import string

#**********************************************************************************
# Set the following variables before running this code!!!
#**********************************************************************************
#All raw data files are processed for the year below
schoolYear = 2018

#Location where copies of the raw data files will be read in from csv files.
dataDir = 'C:/Users/Jake/Documents/GitHub/EducationDataNC/' + str(schoolYear) + '/School Datasets/'

#Name of the file to be processed
#inputFileName = 'PublicSchools2018'
#inputFileName = 'PublicHighSchools2018'
#inputFileName = 'PublicMiddleSchools2018'
inputFileName = 'PublicElementarySchools2018'

#Input file being transformed for machine learning 
inputFile = dataDir + inputFileName + '.csv'

#Location where the new school datasets will be created.
outputDir = 'C:/Users/Jake/Documents/GitHub/EducationDataNC/' + str(schoolYear) + '/Machine Learning Datasets/'

#Missing Data Threshold (Per Column)
missingThreshold = 0.60

#Unique Value Threshold (Per Column)
#Delete Columns >  uniqueThreshold unique values prior to one-hot encoding. 
#(each unique value becomes a new column during one-hot encoding)
uniqueThreshold = 200

#Read in the School Data File
schoolData = pd.read_csv(inputFile, low_memory=False, dtype={'agency_code': object})
print('*********Start: Beginning Column and Row Counts********************************************')
schoolData.info(verbose=False)

#Select only public schools as charter schools are missing data for many columns.
schoolData = schoolData[(schoolData['designation_type'] == 'P') & (schoolData['avg_student_num'] > 0)]

print('\r\n*********After: Selecting Only Public School Campuses**********************************')
schoolData.info(verbose=False)

#Save primary key
agency_code = schoolData['agency_code']
#Convert zip code to string
schoolData['zip'] = schoolData['zip'].astype('object')
# Out:
# *********Start: Beginning Column and Row Counts********************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1575 entries, 0 to 1574
# Columns: 1816 entries, agency_code to lea_federal_perpupil
# dtypes: float64(1765), object(51)
# memory usage: 21.8+ MB
#
# *********After: Selecting Only Public School Campuses**********************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1422 entries, 2 to 1574
# Columns: 1816 entries, agency_code to lea_federal_perpupil
# dtypes: float64(1765), object(51)
# memory usage: 19.7+ MB

# %% [markdown]
# # Prepare Consolidated Dataset for Machine Learning
# **Below we perform operations on the entire dataset to remove columns and update row values that could cause problems during machine learning.**

# %% [markdown]
# ## Student Body Racial Composition Features
# **Impute / update missing Student Body Racial Composition Fields using mean imputation.**
# * When there are no racial composition percentages for a particular school campus / agency_code, fill in the missing values

# %%
#Get Student Body Racial Composition Fields
raceCompositionFields = schoolData.filter(regex='Indian|Asian|Hispanic|Black|White|PacificIsland|TwoOrMore|Minority')\
                                  .filter(regex='Pct').columns
    
rowsBefore = schoolData[raceCompositionFields].isnull().T.any().T.sum()

#Update missing race values with the district average when avaiable (No district averages for charter schools) 
schoolData[raceCompositionFields] = schoolData.groupby('lea_code')[raceCompositionFields]\
                                              .transform(lambda x: x.fillna(x.mean()))

    #Review dataset contents after Racial Composition Imputation
print('*********After: Updating Missing Racial Compostion Values****************************')   
rowsAfter = schoolData[raceCompositionFields].isnull().T.any().T.sum()
rowsUpdated = rowsBefore - rowsAfter
print('Rows Updated / Imputed: ', rowsUpdated) 
print('\r\nTotal Rows Missing Racial Compositions By District Code') 
schoolData['lea_code'][schoolData[raceCompositionFields].isnull().T.any().T].value_counts()
# Out:
# *********After: Updating Missing Racial Compostion Values****************************
# Rows Updated / Imputed:  2
#
# Total Rows Missing Racial Compositions By District Code
# Series([], Name: lea_code, dtype: int64)

# %% [markdown]
# ## Remove Columns with Problematic Data
# **Here we remove entire columns that could cause problems during machine learning.  The following operations are performed:**
# * Remove any columns that have the same value in every single row.
# * Remove any columns that have a unique value in every single row (all values are different).
# * Remove empty columns (all values are NA or NULL).

# %%
#Remove any fields that have the same value in all rows
UniqueValueCounts = schoolData.nunique(dropna=False)
SingleValueCols = UniqueValueCounts[UniqueValueCounts == 1].index
schoolData = schoolData.drop(SingleValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with the same value in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(SingleValueCols))
# Out:
# *********After: Removing columns with the same value in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1422 entries, 2 to 1574
# Columns: 691 entries, agency_code to lea_federal_perpupil
# dtypes: float64(644), object(47)
# memory usage: 7.5+ MB
#
# Columns Deleted:  1125

# %%
#Remove any fields that have unique values in every row
schoolDataRecordCt = schoolData.shape[0]
UniqueValueCounts = schoolData.apply(pd.Series.nunique)
AllUniqueValueCols = UniqueValueCounts[UniqueValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(AllUniqueValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with unique values in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(AllUniqueValueCols))
# Out:
# *********After: Removing columns with unique values in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1422 entries, 2 to 1574
# Columns: 689 entries, category_code to lea_federal_perpupil
# dtypes: float64(644), object(45)
# memory usage: 7.5+ MB
#
# Columns Deleted:  2

# %%
#Remove any empty fields (null values in every row)
schoolDataRecordCt = schoolData.shape[0]
NullValueCounts = schoolData.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with null / blank values in every row.*************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with null / blank values in every row.*************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1422 entries, 2 to 1574
# Columns: 689 entries, category_code to lea_federal_perpupil
# dtypes: float64(644), object(45)
# memory usage: 7.5+ MB
#
# Columns Deleted:  0

# %% [markdown]
# ## Handle Other Missing Values Types
# * Here we eliminate any numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# * All remaining non-race, numeric column missing values are populated with 0.
# * In many cases, it seems that schools are not simply not reporting values when they are zero. However, mean imputation or some other strategy might be considered.

# %%
#Isolate continuous and categorical data types
#These are indexers into the schoolData dataframe and may be used similar to the schoolData dataframe 
sD_boolean = schoolData.loc[:, (schoolData.dtypes == bool) ]
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]
sD_continuous = schoolData.loc[:, (schoolData.dtypes != bool) & (schoolData.dtypes != object)]
print ("Boolean Columns: ", sD_boolean.shape[1])
print ("Nominal Columns: ", sD_nominal.shape[1])
print ("Continuous Columns: ", sD_continuous.shape[1])
print ("Columns Accounted for: ", sD_nominal.shape[1] + sD_continuous.shape[1] + sD_boolean.shape[1])
# Out:
# Boolean Columns:  0
# Nominal Columns:  45
# Continuous Columns:  644
# Columns Accounted for:  689

# %%
#Eliminate continuous columns with more than missingThreshold percentage of missing values
schoolDataRecordCt = sD_continuous.shape[0]
missingValueLimit = schoolDataRecordCt * missingThreshold
NullValueCounts = sD_continuous.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts >= missingValueLimit].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with >= missingThreshold % of missing values******')
schoolData.info(verbose=False)
print('\r\nColumns Deleted: ', len(NullValueCols))
# Out:
# *********After: Removing columns with >= missingThreshold % of missing values******
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1422 entries, 2 to 1574
# Columns: 293 entries, category_code to lea_federal_perpupil
# dtypes: float64(248), object(45)
# memory usage: 3.2+ MB
#
# Columns Deleted:  396

# %% [markdown]
# ## One-Hot Encoding of Categorical Variables
# **All categorical / string variables are converted to numberic variables via one hot encoding.  Each unique row value will become a new binary / numeric column in the dataset.**
# * All remaining categorical columns are one-hot encoded.
# * In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# * Prior to one-hot encoding, columns with > *uniqueThreshold* unique values are deleted.

# %%
#Delete categorical columns with > uniqueThreshold unique values 
#(Each unique value becomes a column during one-hot encoding)
oneHotUniqueValueCounts = schoolData[sD_nominal.columns].apply(lambda x: x.nunique())
oneHotUniqueValueCols = oneHotUniqueValueCounts[oneHotUniqueValueCounts >= uniqueThreshold].index
schoolData.drop(oneHotUniqueValueCols, axis=1, inplace=True) 

#Remove categorical columns which do not add value to machine learning
#Grades columns dropped since they all have indicator fields (device_access, device_home, BYOD)
#with less unique values to one-hot encode
schoolData.drop(['welcome_url','device_access_grades',
                 'device_home_grades','byod_grades'], axis=1, inplace=True) 

#Review dataset contents one hot high unique value drops
print('*********After: Removing columns with >= uniqueThreshold unique values***********')
schoolData.info(verbose=False)
print('\r\nColumns Deleted: ', len(oneHotUniqueValueCols))
print(oneHotUniqueValueCols)
print('Dropped Manually: welcome_url,device_access_grades,device_home_grades,byod_grades')
# Out:
# *********After: Removing columns with >= uniqueThreshold unique values***********
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1422 entries, 2 to 1574
# Columns: 283 entries, category_code to lea_federal_perpupil
# dtypes: float64(248), object(35)
# memory usage: 3.1+ MB
#
# Columns Deleted:  6
# Index(['street_addr', 'city', 'zip', 'phone', 'url', 'School Name'], dtype='object')
# Dropped Manually: welcome_url,device_access_grades,device_home_grades,byod_grades

# %%
#Isolate remaining categorical variables
begColumnCt = len(schoolData.columns)
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]

#one hot encode categorical variables
schoolData = pd.get_dummies(data=schoolData, 
                       columns=sD_nominal.columns, drop_first=True)

#Determine change in column count
endColumnCt = len(schoolData.columns)
columnsAdded = endColumnCt - begColumnCt

#Review dataset contents one hot high unique value drops
print('Columns To One-Hot Encode: ', len(sD_nominal.columns))
print('\r\n*********After: Adding New Columns Via One-Hot Encoding*************************')
schoolData.info(verbose=False)
print('\r\nNew Columns Created Via One-Hot Encoding: ', columnsAdded)
# Out:
# Columns To One-Hot Encode:  35
#
# *********After: Adding New Columns Via One-Hot Encoding*************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1422 entries, 2 to 1574
# Columns: 751 entries, IndianPct to agency_lea_code_995LEA
# dtypes: float64(248), uint8(503)
# memory usage: 3.4 MB
#
# New Columns Created Via One-Hot Encoding:  468

# %%
#Remove any fields that have the same value in all rows after one-hot encoding
UniqueValueCounts = schoolData.nunique(dropna=False)
SingleValueCols = UniqueValueCounts[UniqueValueCounts == 1].index
schoolData = schoolData.drop(SingleValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing one-hot encoded columns with the same value in every row.*******************')
schoolData.info(verbose=False)
print ('\r\nColumns Deleted: ', len(SingleValueCols))
# Out:
# *********After: Removing one-hot encoded columns with the same value in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1422 entries, 2 to 1574
# Columns: 751 entries, IndianPct to agency_lea_code_995LEA
# dtypes: float64(248), uint8(503)
# memory usage: 3.4 MB
#
# Columns Deleted:  0

# %% [markdown]
# ## Impute any Remaining Missing Values as Zero

# %%
#Print out all the missing value rows
pd.set_option('display.max_rows', 1000)

print('\r\n*********The Remaining Missing Values Below will be set to Zero!*************************')

#Check for Missing values 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# *********The Remaining Missing Values Below will be set to Zero!*************************
#                                    Variable Name  Number Missing Values
# 24                                       pct_eds                      1
# 25                                   pct_ALL_ELP                    391
# 26                                   pct_EDS_ELP                    560
# 27                                   pct_ELS_ELP                    391
# 28                                   pct_FEM_ELP                    682
# 29                                   pct_HI7_ELP                    499
# 30                                  pct_MALE_ELP                    593
# 31                   pct_met_Math Grades 3-8_LTG                     85
# 32                pct_met_Reading Grades 3-8_LTG                     85
# 33                     pct_met_Total Targets_LTG                     73
# 34                  pct_met_Math Grades 3-8_PART                     64
# 35               pct_met_Reading Grades 3-8_PART                     64
# 36               pct_met_Science Grades 5&8_PART                    205
# 37                    pct_met_Total Targets_PART                     61
# 38              pct_Math Grades 3-8_ALL_PART_DET                     64
# 39              pct_Math Grades 3-8_BL7_PART_DET                    557
# 40              pct_Math Grades 3-8_EDS_PART_DET                    105
# 41              pct_Math Grades 3-8_HI7_PART_DET                    642
# 42              pct_Math Grades 3-8_SWD_PART_DET                    620
# 43              pct_Math Grades 3-8_WH7_PART_DET                    315
# 44           pct_Reading Grades 3-8_ALL_PART_DET                     64
# 45           pct_Reading Grades 3-8_BL7_PART_DET                    557
# 46           pct_Reading Grades 3-8_EDS_PART_DET                    105
# 47           pct_Reading Grades 3-8_HI7_PART_DET                    642
# 48           pct_Reading Grades 3-8_SWD_PART_DET                    620
# 49           pct_Reading Grades 3-8_WH7_PART_DET                    315
# 50           pct_Science Grades 5&8_ALL_PART_DET                    205
# 51           pct_Science Grades 5&8_EDS_PART_DET                    556
# 52           pct_Science Grades 5&8_WH7_PART_DET                    681
# 53                            pct_passed_eog_RTA                    133
# 54                            pct_passed_laa_RTA                    797
# 55                              pct_promoted_RTA                     99
# 56                              pct_retained_RTA                    743
# 57                                      ma_score                     83
# 58                                      rd_score                     83
# 59                                      sc_score                    167
# 60                                     ach_score                     80
# 61                                      eg_score                     82
# 62                                     spg_score                     80
# 63                                  ma_spg_score                     83
# 64                                  rd_spg_score                     83
# 65                                   ma_eg_score                    106
# 66                                   rd_eg_score                     85
# 67                            aaa_score_ALL_SPG2                     75
# 68                            aaa_score_BL7_SPG2                    402
# 69                            aaa_score_EDS_SPG2                     82
# 70                            aaa_score_ELS_SPG2                    622
# 71                            aaa_score_HI7_SPG2                    365
# 72                            aaa_score_SWD_SPG2                    198
# 73                            aaa_score_WH7_SPG2                    228
# 74                            ach_score_ALL_SPG2                     75
# 75                            ach_score_BL7_SPG2                    402
# 76                            ach_score_EDS_SPG2                     82
# 77                            ach_score_ELS_SPG2                    622
# 78                            ach_score_HI7_SPG2                    365
# 79                            ach_score_SWD_SPG2                    198
# 80                            ach_score_WH7_SPG2                    228
# 81                             eg_score_ALL_SPG2                     78
# 82                             eg_score_BL7_SPG2                    503
# 83                             eg_score_EDS_SPG2                    102
# 84                             eg_score_ELS_SPG2                    784
# 85                             eg_score_HI7_SPG2                    522
# 86                             eg_score_SWD_SPG2                    475
# 87                             eg_score_WH7_SPG2                    296
# 88                           scgs_score_ALL_SPG2                    214
# 89                           scgs_score_EDS_SPG2                    586
# 90                           scgs_score_WH7_SPG2                    687
# 91                            spg_score_ALL_SPG2                     37
# 92                            spg_score_BL7_SPG2                    367
# 93                            spg_score_EDS_SPG2                     44
# 94                            spg_score_ELS_SPG2                    597
# 95                            spg_score_HI7_SPG2                    328
# 96                            spg_score_SWD_SPG2                    160
# 97                            spg_score_WH7_SPG2                    192
# 100                         pct_ALL_CHRON_ABSENT                     10
# 101                         pct_BL7_CHRON_ABSENT                    182
# 102                         pct_ELS_CHRON_ABSENT                    333
# 103                         pct_FEM_CHRON_ABSENT                     14
# 104                         pct_HI7_CHRON_ABSENT                     99
# 105                        pct_MALE_CHRON_ABSENT                     13
# 106                         pct_MU7_CHRON_ABSENT                    210
# 107                         pct_SWD_CHRON_ABSENT                     38
# 108                         pct_WH7_CHRON_ABSENT                     35
# 109                       Book_TitlesPer_Student                     21
# 110                                          wap                      4
# 111                                    wap_class                      4
# 112                                 media_school                     18
# 113                                      devices                      2
# 114                   pct_rating_T1_Accomplished                     20
# 115                  pct_rating_T1_Distinguished                    327
# 116                     pct_rating_T1_Proficient                     64
# 117                   pct_rating_T2_Accomplished                     36
# 118                  pct_rating_T2_Distinguished                    626
# 119                     pct_rating_T2_Proficient                    116
# 120                   pct_rating_T3_Accomplished                     55
# 121                  pct_rating_T3_Distinguished                    702
# 122                     pct_rating_T3_Proficient                     71
# 123                   pct_rating_T4_Accomplished                     23
# 124                  pct_rating_T4_Distinguished                    535
# 125                     pct_rating_T4_Proficient                     71
# 126                   pct_rating_T5_Accomplished                     46
# 127                  pct_rating_T5_Distinguished                    684
# 128                     pct_rating_T5_Proficient                     79
# 129  pct_rating_TS_Does Not Meet Expected Growth                     40
# 130        pct_rating_TS_Exceeds Expected Growth                     40
# 131          pct_rating_TS_Meets Expected Growth                     40
# 137                      pct_turnover_TeacherExp                      8
# 138                         highqual_class_pct_E                    137
# 139                                        crime                      8
# 140                                   short_term                      8
# 141                                    long_term                      8
# 142                                    expulsion                      8
# 143                             arre_per1000_ALL                     35
# 144                             arre_per1000_BL7                    187
# 146                             arre_per1000_FEM                    113
# 147                             arre_per1000_HI7                    256
# 148                            arre_per1000_MALE                     42
# 149                             arre_per1000_MU7                    322
# 150                             arre_per1000_SWD                      2
# 151                             arre_per1000_WH7                     91
# 152                             blhr_per1000_ALL                     35
# 153                             blhr_per1000_BL7                    187
# 156                             blhr_per1000_FEM                    113
# 157                             blhr_per1000_HI7                    256
# 158                            blhr_per1000_MALE                     42
# 159                             blhr_per1000_MU7                    322
# 160                             blhr_per1000_SWD                      2
# 161                             blhr_per1000_WH7                     91
# 162                            crime_per1000_ALL                     35
# 163                            crime_per1000_BL7                    187
# 166                            crime_per1000_FEM                    113
# 167                            crime_per1000_HI7                    256
# 168                           crime_per1000_MALE                     42
# 169                            crime_per1000_MU7                    322
# 170                            crime_per1000_SWD                      2
# 171                            crime_per1000_WH7                     91
# 172                              exp_per1000_ALL                     36
# 173                              exp_per1000_BL7                    255
# 174                              exp_per1000_EDS                      3
# 175                              exp_per1000_ELS                    269
# 176                              exp_per1000_FEM                    116
# 177                              exp_per1000_HI7                    295
# 178                             exp_per1000_MALE                     44
# 179                              exp_per1000_MU7                    485
# 180                              exp_per1000_SWD                     20
# 181                              exp_per1000_WH7                    125
# 182                              iss_per1000_ALL                     36
# 183                              iss_per1000_BL7                    255
# 184                              iss_per1000_EDS                      3
# 185                              iss_per1000_ELS                    269
# 186                              iss_per1000_FEM                    116
# 187                              iss_per1000_HI7                    295
# 188                             iss_per1000_MALE                     44
# 189                              iss_per1000_MU7                    486
# 190                              iss_per1000_SWD                     20
# 191                              iss_per1000_WH7                    125
# 192                              lts_per1000_ALL                     36
# 193                              lts_per1000_BL7                    255
# 194                              lts_per1000_EDS                      3
# 195                              lts_per1000_ELS                    269
# 196                              lts_per1000_FEM                    116
# 197                              lts_per1000_HI7                    295
# 198                             lts_per1000_MALE                     44
# 199                              lts_per1000_MU7                    485
# 200                              lts_per1000_SWD                     20
# 201                              lts_per1000_WH7                    125
# 202                             rplw_per1000_ALL                     35
# 203                             rplw_per1000_BL7                    187
# 205                             rplw_per1000_FEM                    113
# 206                             rplw_per1000_HI7                    256
# 207                            rplw_per1000_MALE                     42
# 208                             rplw_per1000_MU7                    322
# 209                             rplw_per1000_SWD                      2
# 210                             rplw_per1000_WH7                     91
# 211                              sts_per1000_ALL                     36
# 212                              sts_per1000_BL7                    256
# 213                              sts_per1000_EDS                      3
# 214                              sts_per1000_ELS                    269
# 215                              sts_per1000_FEM                    117
# 216                              sts_per1000_HI7                    295
# 217                             sts_per1000_MALE                     44
# 218                              sts_per1000_MU7                    485
# 219                              sts_per1000_SWD                     20
# 220                              sts_per1000_WH7                    125
# 224                            pct_ALL_PK_ENROLL                    541
# 225                            pct_BL7_PK_ENROLL                    741
# 226                            pct_ELS_PK_ENROLL                    541
# 227                            pct_FEM_PK_ENROLL                    581
# 228                            pct_HI7_PK_ENROLL                    688
# 229                           pct_MALE_PK_ENROLL                    551
# 230                            pct_SWD_PK_ENROLL                    541
# 231                            pct_WH7_PK_ENROLL                    594
# 232                                pct_ready_kea                    105
# 233                              avg_size_00_SAR                    248
# 234                              avg_size_01_SAR                    250
# 235                              avg_size_02_SAR                    254
# 236                              avg_size_03_SAR                    254
# 237                              avg_size_04_SAR                    202
# 238                              avg_size_05_SAR                    254

# %%
#Replace all remaining NaN with 0
schoolData = schoolData.fillna(0)

#Check for Missing values after final imputation 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# Empty DataFrame
# Columns: [Variable Name, Number Missing Values]
# Index: []

# %% [markdown]
# ## Identify and Remove Highly Correlated Features
# **Find and remove any columns / features that are > 95% correlated**
# * https://stackoverflow.com/questions/39409866/correlation-heatmap
# * https://chrisalbon.com/machine_learning/feature_selection/drop_highly_correlated_features/
# * https://codeyarns.com/2015/04/20/how-to-change-font-size-in-seaborn/

# %%
# calculate the correlation matrix
corr_matrix  = schoolData.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
#Get all of the correlation values > 95%
x = np.where(upper > 0.95)

#Display all field combinations with > 95% correlation
cf = pd.DataFrame()
cf['Field1'] = upper.columns[x[1]]
cf['Field2'] = upper.index[x[0]]

#Get the correlation values for every field combination. (There must be a more pythonic way to do this!)
corr = [0] * len(cf)
for i in range(0, len(cf)):
    corr[i] =  upper[cf['Field1'][i]][cf['Field2'][i]] 
    
cf['Correlation'] = corr

print ('There are ', str(len(cf['Field1'])), ' field correlations > 95%.')
cf
# Out:
# There are  421  field correlations > 95%.
#                                   Field1                               Field2  \
# 0                          IndianMalePct                            IndianPct
# 1                        IndianFemalePct                            IndianPct
# 2                           AsianMalePct                             AsianPct
# 3                         AsianFemalePct                             AsianPct
# 4                        HispanicMalePct                          HispanicPct
# 5                      HispanicFemalePct                          HispanicPct
# 6                           BlackMalePct                             BlackPct
# 7                         BlackFemalePct                             BlackPct
# 8                            MinorityPct                             WhitePct
# 9                           WhiteMalePct                             WhitePct
# 10                       MinorityMalePct                             WhitePct
# 11                        WhiteFemalePct                             WhitePct
# 12                     MinorityFemalePct                             WhitePct
# 13                          WhiteMalePct                          MinorityPct
# 14                       MinorityMalePct                          MinorityPct
# 15                        WhiteFemalePct                          MinorityPct
# 16                     MinorityFemalePct                          MinorityPct
# 17                       IndianFemalePct                        IndianMalePct
# 18                        AsianFemalePct                         AsianMalePct
# 19                       MinorityMalePct                         WhiteMalePct
# 20                     MinorityFemalePct                         WhiteMalePct
# 21                        WhiteFemalePct                      MinorityMalePct
# 22                           pct_ELS_ELP                          pct_ALL_ELP
# 23       pct_met_Reading Grades 3-8_PART         pct_met_Math Grades 3-8_PART
# 24            pct_met_Total Targets_PART         pct_met_Math Grades 3-8_PART
# 25      pct_Math Grades 3-8_ALL_PART_DET         pct_met_Math Grades 3-8_PART
# 26   pct_Reading Grades 3-8_ALL_PART_DET         pct_met_Math Grades 3-8_PART
# 27            pct_met_Total Targets_PART      pct_met_Reading Grades 3-8_PART
# 28      pct_Math Grades 3-8_ALL_PART_DET      pct_met_Reading Grades 3-8_PART
# 29   pct_Reading Grades 3-8_ALL_PART_DET      pct_met_Reading Grades 3-8_PART
# 30   pct_Science Grades 5&8_ALL_PART_DET      pct_met_Science Grades 5&8_PART
# 31      pct_Math Grades 3-8_ALL_PART_DET           pct_met_Total Targets_PART
# 32   pct_Reading Grades 3-8_ALL_PART_DET           pct_met_Total Targets_PART
# 33   pct_Reading Grades 3-8_ALL_PART_DET     pct_Math Grades 3-8_ALL_PART_DET
# 34   pct_Reading Grades 3-8_BL7_PART_DET     pct_Math Grades 3-8_BL7_PART_DET
# 35   pct_Reading Grades 3-8_EDS_PART_DET     pct_Math Grades 3-8_EDS_PART_DET
# 36   pct_Reading Grades 3-8_HI7_PART_DET     pct_Math Grades 3-8_HI7_PART_DET
# 37   pct_Reading Grades 3-8_SWD_PART_DET     pct_Math Grades 3-8_SWD_PART_DET
# 38   pct_Reading Grades 3-8_WH7_PART_DET     pct_Math Grades 3-8_WH7_PART_DET
# 39                   scgs_score_WH7_SPG2  pct_Science Grades 5&8_WH7_PART_DET
# 40                             ach_score                             ma_score
# 41                             spg_score                             ma_score
# 42                          ma_spg_score                             ma_score
# 43                             ach_score                             rd_score
# 44                             spg_score                             rd_score
# 45                          rd_spg_score                             rd_score
# 46                             spg_score                            ach_score
# 47                          ma_spg_score                            ach_score
# 48                          rd_spg_score                            ach_score
# 49                          ma_spg_score                            spg_score
# 50                          rd_spg_score                            spg_score
# 51                          rd_spg_score                         ma_spg_score
# 52                    ach_score_ALL_SPG2                   aaa_score_ALL_SPG2
# 53                    ach_score_BL7_SPG2                   aaa_score_BL7_SPG2
# 54                    ach_score_EDS_SPG2                   aaa_score_EDS_SPG2
# 55                    ach_score_ELS_SPG2                   aaa_score_ELS_SPG2
# 56                    ach_score_HI7_SPG2                   aaa_score_HI7_SPG2
# 57                    ach_score_SWD_SPG2                   aaa_score_SWD_SPG2
# 58                    ach_score_WH7_SPG2                   aaa_score_WH7_SPG2
# 59                    spg_score_ELS_SPG2                   ach_score_ELS_SPG2
# 60                 pct_MALE_CHRON_ABSENT                 pct_ALL_CHRON_ABSENT
# 61                     crime_per1000_ALL                                crime
# 62                    crime_per1000_MALE                                crime
# 63                     crime_per1000_MU7                                crime
# 64                     crime_per1000_SWD                                crime
# 65                      rplw_per1000_ALL                                crime
# 66                     rplw_per1000_MALE                                crime
# 67                      rplw_per1000_SWD                                crime
# 68                      arre_per1000_BL7                     arre_per1000_ALL
# 69                      arre_per1000_EDS                     arre_per1000_ALL
# 70                     arre_per1000_MALE                     arre_per1000_ALL
# 71                      arre_per1000_SWD                     arre_per1000_ALL
# 72                      arre_per1000_WH7                     arre_per1000_ALL
# 73                     crime_per1000_ELS                     arre_per1000_ALL
# 74                      grade_span_KG:13                     arre_per1000_ALL
# 75             subgroup_list_ALL,BL7,SWD                     arre_per1000_ALL
# 76                      arre_per1000_EDS                     arre_per1000_BL7
# 77                     arre_per1000_MALE                     arre_per1000_BL7
# 78                      arre_per1000_SWD                     arre_per1000_BL7
# 79                      arre_per1000_WH7                     arre_per1000_BL7
# 80                     crime_per1000_ELS                     arre_per1000_BL7
# 81                      grade_span_KG:13                     arre_per1000_BL7
# 82             subgroup_list_ALL,BL7,SWD                     arre_per1000_BL7
# 83                     arre_per1000_MALE                     arre_per1000_EDS
# 84                      arre_per1000_SWD                     arre_per1000_EDS
# 85                      arre_per1000_WH7                     arre_per1000_EDS
# 86                     crime_per1000_ELS                     arre_per1000_EDS
# 87                      grade_span_KG:13                     arre_per1000_EDS
# 88             subgroup_list_ALL,BL7,SWD                     arre_per1000_EDS
# 89                      arre_per1000_SWD                    arre_per1000_MALE
# 90                      arre_per1000_WH7                    arre_per1000_MALE
# 91                     crime_per1000_ELS                    arre_per1000_MALE
# 92                      grade_span_KG:13                    arre_per1000_MALE
# 93             subgroup_list_ALL,BL7,SWD                    arre_per1000_MALE
# 94                      arre_per1000_WH7                     arre_per1000_SWD
# 95                     crime_per1000_ELS                     arre_per1000_SWD
# 96                      grade_span_KG:13                     arre_per1000_SWD
# 97             subgroup_list_ALL,BL7,SWD                     arre_per1000_SWD
# 98                     crime_per1000_ELS                     arre_per1000_WH7
# 99                      grade_span_KG:13                     arre_per1000_WH7
# 100            subgroup_list_ALL,BL7,SWD                     arre_per1000_WH7
# 101                   crime_per1000_MALE                    crime_per1000_ALL
# 102                    crime_per1000_MU7                    crime_per1000_ALL
# 103                    crime_per1000_SWD                    crime_per1000_ALL
# 104                     rplw_per1000_ALL                    crime_per1000_ALL
# 105                    rplw_per1000_MALE                    crime_per1000_ALL
# 106                     rplw_per1000_SWD                    crime_per1000_ALL
# 107                   crime_per1000_MALE                    crime_per1000_BL7
# 108                     rplw_per1000_BL7                    crime_per1000_BL7
# 109                    crime_per1000_HI7                    crime_per1000_ELS
# 110                     grade_span_KG:13                    crime_per1000_ELS
# 111            subgroup_list_ALL,BL7,SWD                    crime_per1000_ELS
# 112                    crime_per1000_MU7                   crime_per1000_MALE
# 113                    crime_per1000_SWD                   crime_per1000_MALE
# 114                     rplw_per1000_ALL                   crime_per1000_MALE
# 115                    rplw_per1000_MALE                   crime_per1000_MALE
# 116                     rplw_per1000_SWD                   crime_per1000_MALE
# 117                    crime_per1000_SWD                    crime_per1000_MU7
# 118                     rplw_per1000_ALL                    crime_per1000_MU7
# 119                    rplw_per1000_MALE                    crime_per1000_MU7
# 120                     rplw_per1000_SWD                    crime_per1000_MU7
# 121                     rplw_per1000_ALL                    crime_per1000_SWD
# 122                    rplw_per1000_MALE                    crime_per1000_SWD
# 123                     rplw_per1000_SWD                    crime_per1000_SWD
# 124                     iss_per1000_MALE                      iss_per1000_ALL
# 125                     iss_per1000_MALE                      iss_per1000_EDS
# 126                    rplw_per1000_MALE                     rplw_per1000_ALL
# 127                     rplw_per1000_SWD                     rplw_per1000_ALL
# 128                     rplw_per1000_SWD                    rplw_per1000_MALE
# 129                    pct_ELS_PK_ENROLL                    pct_ALL_PK_ENROLL
# 130                     county_Alexander                      lea_code_020LEA
# 131               agency_lea_code_020LEA                      lea_code_020LEA
# 132                     county_Alleghany                      lea_code_030LEA
# 133               agency_lea_code_030LEA                      lea_code_030LEA
# 134                         county_Anson                      lea_code_040LEA
# 135               agency_lea_code_040LEA                      lea_code_040LEA
# 136                          county_Ashe                      lea_code_050LEA
# 137               agency_lea_code_050LEA                      lea_code_050LEA
# 138                         county_Avery                      lea_code_060LEA
# 139               agency_lea_code_060LEA                      lea_code_060LEA
# 140                      county_Beaufort                      lea_code_070LEA
# 141               agency_lea_code_070LEA                      lea_code_070LEA
# 142                        county_Bertie                      lea_code_080LEA
# 143               agency_lea_code_080LEA                      lea_code_080LEA
# 144                        county_Bladen                      lea_code_090LEA
# 145               agency_lea_code_090LEA                      lea_code_090LEA
# 146                     county_Brunswick                      lea_code_100LEA
# 147               agency_lea_code_100LEA                      lea_code_100LEA
# 148               agency_lea_code_110LEA                      lea_code_110LEA
# 149               agency_lea_code_111LEA                      lea_code_111LEA
# 150                         county_Burke                      lea_code_120LEA
# 151               agency_lea_code_120LEA                      lea_code_120LEA
# 152               agency_lea_code_130LEA                      lea_code_130LEA
# 153               agency_lea_code_132LEA                      lea_code_132LEA
# 154                      county_Caldwell                      lea_code_140LEA
# 155               agency_lea_code_140LEA                      lea_code_140LEA
# 156                        county_Camden                      lea_code_150LEA
# 157               agency_lea_code_150LEA                      lea_code_150LEA
# 158                      county_Carteret                      lea_code_160LEA
# 159               agency_lea_code_160LEA                      lea_code_160LEA
# 160                       county_Caswell                      lea_code_170LEA
# 161               agency_lea_code_170LEA                      lea_code_170LEA
# 162               agency_lea_code_180LEA                      lea_code_180LEA
# 163               agency_lea_code_181LEA                      lea_code_181LEA
# 164               agency_lea_code_182LEA                      lea_code_182LEA
# 165                       county_Chatham                      lea_code_190LEA
# 166               agency_lea_code_190LEA                      lea_code_190LEA
# 167                      county_Cherokee                      lea_code_200LEA
# 168               agency_lea_code_200LEA                      lea_code_200LEA
# 169                        county_Chowan                      lea_code_210LEA
# 170               agency_lea_code_210LEA                      lea_code_210LEA
# 171                          county_Clay                      lea_code_220LEA
# 172               agency_lea_code_220LEA                      lea_code_220LEA
# 173                     county_Cleveland                      lea_code_230LEA
# 174               agency_lea_code_230LEA                      lea_code_230LEA
# 175               agency_lea_code_240LEA                      lea_code_240LEA
# 176               agency_lea_code_241LEA                      lea_code_241LEA
# 177                        county_Craven                      lea_code_250LEA
# 178               agency_lea_code_250LEA                      lea_code_250LEA
# 179                    county_Cumberland                      lea_code_260LEA
# 180               agency_lea_code_260LEA                      lea_code_260LEA
# 181                     county_Currituck                      lea_code_270LEA
# 182               agency_lea_code_270LEA                      lea_code_270LEA
# 183                          county_Dare                      lea_code_280LEA
# 184               agency_lea_code_280LEA                      lea_code_280LEA
# 185               agency_lea_code_290LEA                      lea_code_290LEA
# 186               agency_lea_code_291LEA                      lea_code_291LEA
# 187               agency_lea_code_292LEA                      lea_code_292LEA
# 188                         county_Davie                      lea_code_300LEA
# 189               agency_lea_code_300LEA                      lea_code_300LEA
# 190                        county_Duplin                      lea_code_310LEA
# 191               agency_lea_code_310LEA                      lea_code_310LEA
# 192                        county_Durham                      lea_code_320LEA
# 193               agency_lea_code_320LEA                      lea_code_320LEA
# 194                     county_Edgecombe                      lea_code_330LEA
# 195               agency_lea_code_330LEA                      lea_code_330LEA
# 196                       county_Forsyth                      lea_code_340LEA
# 197               agency_lea_code_340LEA                      lea_code_340LEA
# 198                      county_Franklin                      lea_code_350LEA
# 199               agency_lea_code_350LEA                      lea_code_350LEA
# 200                        county_Gaston                      lea_code_360LEA
# 201               agency_lea_code_360LEA                      lea_code_360LEA
# 202                         county_Gates                      lea_code_370LEA
# 203               agency_lea_code_370LEA                      lea_code_370LEA
# 204                        county_Graham                      lea_code_380LEA
# 205               agency_lea_code_380LEA                      lea_code_380LEA
# 206                     county_Granville                      lea_code_390LEA
# 207               agency_lea_code_390LEA                      lea_code_390LEA
# 208                        county_Greene                      lea_code_400LEA
# 209               agency_lea_code_400LEA                      lea_code_400LEA
# 210                      county_Guilford                      lea_code_410LEA
# 211               agency_lea_code_410LEA                      lea_code_410LEA
# 212               agency_lea_code_420LEA                      lea_code_420LEA
# 213               agency_lea_code_421LEA                      lea_code_421LEA
# 214               agency_lea_code_422LEA                      lea_code_422LEA
# 215                       county_Harnett                      lea_code_430LEA
# 216               agency_lea_code_430LEA                      lea_code_430LEA
# 217                       county_Haywood                      lea_code_440LEA
# 218               agency_lea_code_440LEA                      lea_code_440LEA
# 219                     county_Henderson                      lea_code_450LEA
# 220               agency_lea_code_450LEA                      lea_code_450LEA
# 221                      county_Hertford                      lea_code_460LEA
# 222               agency_lea_code_460LEA                      lea_code_460LEA
# 223                          county_Hoke                      lea_code_470LEA
# 224               agency_lea_code_470LEA                      lea_code_470LEA
# 225                          county_Hyde                      lea_code_480LEA
# 226               agency_lea_code_480LEA                      lea_code_480LEA
# 227               agency_lea_code_490LEA                      lea_code_490LEA
# 228               agency_lea_code_491LEA                      lea_code_491LEA
# 229                       county_Jackson                      lea_code_500LEA
# 230               agency_lea_code_500LEA                      lea_code_500LEA
# 231                      county_Johnston                      lea_code_510LEA
# 232               agency_lea_code_510LEA                      lea_code_510LEA
# 233                         county_Jones                      lea_code_520LEA
# 234               agency_lea_code_520LEA                      lea_code_520LEA
# 235                           county_Lee                      lea_code_530LEA
# 236               agency_lea_code_530LEA                      lea_code_530LEA
# 237                        county_Lenoir                      lea_code_540LEA
# 238               agency_lea_code_540LEA                      lea_code_540LEA
# 239                       county_Lincoln                      lea_code_550LEA
# 240               agency_lea_code_550LEA                      lea_code_550LEA
# 241                         county_Macon                      lea_code_560LEA
# 242               agency_lea_code_560LEA                      lea_code_560LEA
# 243                       county_Madison                      lea_code_570LEA
# 244               agency_lea_code_570LEA                      lea_code_570LEA
# 245                        county_Martin                      lea_code_580LEA
# 246               agency_lea_code_580LEA                      lea_code_580LEA
# 247                      county_McDowell                      lea_code_590LEA
# 248               agency_lea_code_590LEA                      lea_code_590LEA
# 249                   county_Mecklenburg                      lea_code_600LEA
# 250               agency_lea_code_600LEA                      lea_code_600LEA
# 251                      county_Mitchell                      lea_code_610LEA
# 252               agency_lea_code_610LEA                      lea_code_610LEA
# 253                    county_Montgomery                      lea_code_620LEA
# 254               agency_lea_code_620LEA                      lea_code_620LEA
# 255                         county_Moore                      lea_code_630LEA
# 256               agency_lea_code_630LEA                      lea_code_630LEA
# 257                          county_Nash                      lea_code_640LEA
# 258               agency_lea_code_640LEA                      lea_code_640LEA
# 259                   county_New Hanover                      lea_code_650LEA
# 260               agency_lea_code_650LEA                      lea_code_650LEA
# 261                   county_Northampton                      lea_code_660LEA
# 262               agency_lea_code_660LEA                      lea_code_660LEA
# 263                        county_Onslow                      lea_code_670LEA
# 264               agency_lea_code_670LEA                      lea_code_670LEA
# 265               agency_lea_code_680LEA                      lea_code_680LEA
# 266               agency_lea_code_681LEA                      lea_code_681LEA
# 267                       county_Pamlico                      lea_code_690LEA
# 268               agency_lea_code_690LEA                      lea_code_690LEA
# 269                    county_Pasquotank                      lea_code_700LEA
# 270               agency_lea_code_700LEA                      lea_code_700LEA
# 271                        county_Pender                      lea_code_710LEA
# 272               agency_lea_code_710LEA                      lea_code_710LEA
# 273                    county_Perquimans                      lea_code_720LEA
# 274               agency_lea_code_720LEA                      lea_code_720LEA
# 275                        county_Person                      lea_code_730LEA
# 276               agency_lea_code_730LEA                      lea_code_730LEA
# 277                          county_Pitt                      lea_code_740LEA
# 278               agency_lea_code_740LEA                      lea_code_740LEA
# 279                          county_Polk                      lea_code_750LEA
# 280               agency_lea_code_750LEA                      lea_code_750LEA
# 281               agency_lea_code_760LEA                      lea_code_760LEA
# 282               agency_lea_code_761LEA                      lea_code_761LEA
# 283                      county_Richmond                      lea_code_770LEA
# 284               agency_lea_code_770LEA                      lea_code_770LEA
# 285                       county_Robeson                      lea_code_780LEA
# 286               agency_lea_code_780LEA                      lea_code_780LEA
# 287                    county_Rockingham                      lea_code_790LEA
# 288               agency_lea_code_790LEA                      lea_code_790LEA
# 289                         county_Rowan                      lea_code_800LEA
# 290               agency_lea_code_800LEA                      lea_code_800LEA
# 291                    county_Rutherford                      lea_code_810LEA
# 292               agency_lea_code_810LEA                      lea_code_810LEA
# 293               agency_lea_code_820LEA                      lea_code_820LEA
# 294               agency_lea_code_821LEA                      lea_code_821LEA
# 295                      county_Scotland                      lea_code_830LEA
# 296               agency_lea_code_830LEA                      lea_code_830LEA
# 297                        county_Stanly                      lea_code_840LEA
# 298               agency_lea_code_840LEA                      lea_code_840LEA
# 299                        county_Stokes                      lea_code_850LEA
# 300               agency_lea_code_850LEA                      lea_code_850LEA
# 301               agency_lea_code_860LEA                      lea_code_860LEA
# 302               agency_lea_code_861LEA                      lea_code_861LEA
# 303               agency_lea_code_862LEA                      lea_code_862LEA
# 304                         county_Swain                      lea_code_870LEA
# 305               agency_lea_code_870LEA                      lea_code_870LEA
# 306                  county_Transylvania                      lea_code_880LEA
# 307               agency_lea_code_880LEA                      lea_code_880LEA
# 308                       county_Tyrrell                      lea_code_890LEA
# 309               agency_lea_code_890LEA                      lea_code_890LEA
# 310                         county_Union                      lea_code_900LEA
# 311               agency_lea_code_900LEA                      lea_code_900LEA
# 312                         county_Vance                      lea_code_910LEA
# 313               agency_lea_code_910LEA                      lea_code_910LEA
# 314                          county_Wake                      lea_code_920LEA
# 315               agency_lea_code_920LEA                      lea_code_920LEA
# 316                        county_Warren                      lea_code_930LEA
# 317               agency_lea_code_930LEA                      lea_code_930LEA
# 318                    county_Washington                      lea_code_940LEA
# 319               agency_lea_code_940LEA                      lea_code_940LEA
# 320                       county_Watauga                      lea_code_950LEA
# 321               agency_lea_code_950LEA                      lea_code_950LEA
# 322                         county_Wayne                      lea_code_960LEA
# 323               agency_lea_code_960LEA                      lea_code_960LEA
# 324                        county_Wilkes                      lea_code_970LEA
# 325               agency_lea_code_970LEA                      lea_code_970LEA
# 326                        county_Wilson                      lea_code_980LEA
# 327               agency_lea_code_980LEA                      lea_code_980LEA
# 328                        county_Yadkin                      lea_code_990LEA
# 329               agency_lea_code_990LEA                      lea_code_990LEA
# 330                        county_Yancey                      lea_code_995LEA
# 331               agency_lea_code_995LEA                      lea_code_995LEA
# 332               agency_lea_code_020LEA                     county_Alexander
# 333               agency_lea_code_030LEA                     county_Alleghany
# 334               agency_lea_code_040LEA                         county_Anson
# 335               agency_lea_code_050LEA                          county_Ashe
# 336               agency_lea_code_060LEA                         county_Avery
# 337               agency_lea_code_070LEA                      county_Beaufort
# 338               agency_lea_code_080LEA                        county_Bertie
# 339               agency_lea_code_090LEA                        county_Bladen
# 340               agency_lea_code_100LEA                     county_Brunswick
# 341               agency_lea_code_120LEA                         county_Burke
# 342               agency_lea_code_140LEA                      county_Caldwell
# 343               agency_lea_code_150LEA                        county_Camden
# 344               agency_lea_code_160LEA                      county_Carteret
# 345               agency_lea_code_170LEA                       county_Caswell
# 346               agency_lea_code_190LEA                       county_Chatham
# 347               agency_lea_code_200LEA                      county_Cherokee
# 348               agency_lea_code_210LEA                        county_Chowan
# 349               agency_lea_code_220LEA                          county_Clay
# 350               agency_lea_code_230LEA                     county_Cleveland
# 351               agency_lea_code_250LEA                        county_Craven
# 352               agency_lea_code_260LEA                    county_Cumberland
# 353               agency_lea_code_270LEA                     county_Currituck
# 354               agency_lea_code_280LEA                          county_Dare
# 355               agency_lea_code_300LEA                         county_Davie
# 356               agency_lea_code_310LEA                        county_Duplin
# 357               agency_lea_code_320LEA                        county_Durham
# 358               agency_lea_code_330LEA                     county_Edgecombe
# 359               agency_lea_code_340LEA                       county_Forsyth
# 360               agency_lea_code_350LEA                      county_Franklin
# 361               agency_lea_code_360LEA                        county_Gaston
# 362               agency_lea_code_370LEA                         county_Gates
# 363               agency_lea_code_380LEA                        county_Graham
# 364               agency_lea_code_390LEA                     county_Granville
# 365               agency_lea_code_400LEA                        county_Greene
# 366               agency_lea_code_410LEA                      county_Guilford
# 367               agency_lea_code_430LEA                       county_Harnett
# 368               agency_lea_code_440LEA                       county_Haywood
# 369               agency_lea_code_450LEA                     county_Henderson
# 370               agency_lea_code_460LEA                      county_Hertford
# 371               agency_lea_code_470LEA                          county_Hoke
# 372               agency_lea_code_480LEA                          county_Hyde
# 373               agency_lea_code_500LEA                       county_Jackson
# 374               agency_lea_code_510LEA                      county_Johnston
# 375               agency_lea_code_520LEA                         county_Jones
# 376               agency_lea_code_530LEA                           county_Lee
# 377               agency_lea_code_540LEA                        county_Lenoir
# 378               agency_lea_code_550LEA                       county_Lincoln
# 379               agency_lea_code_560LEA                         county_Macon
# 380               agency_lea_code_570LEA                       county_Madison
# 381               agency_lea_code_580LEA                        county_Martin
# 382               agency_lea_code_590LEA                      county_McDowell
# 383               agency_lea_code_600LEA                   county_Mecklenburg
# 384               agency_lea_code_610LEA                      county_Mitchell
# 385               agency_lea_code_620LEA                    county_Montgomery
# 386               agency_lea_code_630LEA                         county_Moore
# 387               agency_lea_code_640LEA                          county_Nash
# 388               agency_lea_code_650LEA                   county_New Hanover
# 389               agency_lea_code_660LEA                   county_Northampton
# 390               agency_lea_code_670LEA                        county_Onslow
# 391               agency_lea_code_690LEA                       county_Pamlico
# 392               agency_lea_code_700LEA                    county_Pasquotank
# 393               agency_lea_code_710LEA                        county_Pender
# 394               agency_lea_code_720LEA                    county_Perquimans
# 395               agency_lea_code_730LEA                        county_Person
# 396               agency_lea_code_740LEA                          county_Pitt
# 397               agency_lea_code_750LEA                          county_Polk
# 398               agency_lea_code_770LEA                      county_Richmond
# 399               agency_lea_code_780LEA                       county_Robeson
# 400               agency_lea_code_790LEA                    county_Rockingham
# 401               agency_lea_code_800LEA                         county_Rowan
# 402               agency_lea_code_810LEA                    county_Rutherford
# 403               agency_lea_code_830LEA                      county_Scotland
# 404               agency_lea_code_840LEA                        county_Stanly
# 405               agency_lea_code_850LEA                        county_Stokes
# 406               agency_lea_code_870LEA                         county_Swain
# 407               agency_lea_code_880LEA                  county_Transylvania
# 408               agency_lea_code_890LEA                       county_Tyrrell
# 409               agency_lea_code_900LEA                         county_Union
# 410               agency_lea_code_910LEA                         county_Vance
# 411               agency_lea_code_920LEA                          county_Wake
# 412               agency_lea_code_930LEA                        county_Warren
# 413               agency_lea_code_940LEA                    county_Washington
# 414               agency_lea_code_950LEA                       county_Watauga
# 415               agency_lea_code_960LEA                         county_Wayne
# 416               agency_lea_code_970LEA                        county_Wilkes
# 417               agency_lea_code_980LEA                        county_Wilson
# 418               agency_lea_code_990LEA                        county_Yadkin
# 419               agency_lea_code_995LEA                        county_Yancey
# 420            subgroup_list_ALL,BL7,SWD                     grade_span_KG:13
#
#      Correlation
# 0       0.995561
# 1       0.995145
# 2       0.988609
# 3       0.987644
# 4       0.981625
# 5       0.980253
# 6       0.978510
# 7       0.974613
# 8       1.000000
# 9       0.985685
# 10      0.976443
# 11      0.983635
# 12      0.973486
# 13      0.985685
# 14      0.976443
# 15      0.983635
# 16      0.973486
# 17      0.981464
# 18      0.952807
# 19      0.954974
# 20      0.967491
# 21      0.968468
# 22      1.000000
# 23      0.996484
# 24      0.974948
# 25      0.979969
# 26      0.979849
# 27      0.975082
# 28      0.985030
# 29      0.984994
# 30      0.999822
# 31      0.957887
# 32      0.957807
# 33      0.999999
# 34      0.999999
# 35      0.999998
# 36      1.000000
# 37      0.999995
# 38      1.000000
# 39      0.970449
# 40      0.972246
# 41      0.960820
# 42      0.987096
# 43      0.971790
# 44      0.954894
# 45      0.988745
# 46      0.988757
# 47      0.962711
# 48      0.967340
# 49      0.972755
# 50      0.970338
# 51      0.954082
# 52      0.996219
# 53      0.998220
# 54      0.993358
# 55      0.992758
# 56      0.997348
# 57      0.997532
# 58      0.999053
# 59      0.958637
# 60      0.974825
# 61      0.995383
# 62      0.982422
# 63      0.995952
# 64      0.993651
# 65      0.990233
# 66      0.960770
# 67      0.973800
# 68      1.000000
# 69      1.000000
# 70      1.000000
# 71      1.000000
# 72      1.000000
# 73      0.997755
# 74      1.000000
# 75      1.000000
# 76      1.000000
# 77      1.000000
# 78      1.000000
# 79      1.000000
# 80      0.997755
# 81      1.000000
# 82      1.000000
# 83      1.000000
# 84      1.000000
# 85      1.000000
# 86      0.997755
# 87      1.000000
# 88      1.000000
# 89      1.000000
# 90      1.000000
# 91      0.997755
# 92      1.000000
# 93      1.000000
# 94      1.000000
# 95      0.997755
# 96      1.000000
# 97      1.000000
# 98      0.997755
# 99      1.000000
# 100     1.000000
# 101     0.994147
# 102     0.988808
# 103     0.993202
# 104     0.986937
# 105     0.962013
# 106     0.967530
# 107     0.968706
# 108     0.984836
# 109     0.950861
# 110     0.997755
# 111     0.997755
# 112     0.974854
# 113     0.982398
# 114     0.977122
# 115     0.960749
# 116     0.954474
# 117     0.990476
# 118     0.989051
# 119     0.959925
# 120     0.974272
# 121     0.985699
# 122     0.958663
# 123     0.972738
# 124     0.977636
# 125     0.951749
# 126     0.988431
# 127     0.983946
# 128     0.972060
# 129     1.000000
# 130     1.000000
# 131     1.000000
# 132     1.000000
# 133     1.000000
# 134     1.000000
# 135     1.000000
# 136     1.000000
# 137     1.000000
# 138     1.000000
# 139     1.000000
# 140     1.000000
# 141     1.000000
# 142     1.000000
# 143     1.000000
# 144     1.000000
# 145     1.000000
# 146     1.000000
# 147     1.000000
# 148     1.000000
# 149     1.000000
# 150     1.000000
# 151     1.000000
# 152     1.000000
# 153     1.000000
# 154     1.000000
# 155     1.000000
# 156     1.000000
# 157     1.000000
# 158     1.000000
# 159     1.000000
# 160     1.000000
# 161     1.000000
# 162     1.000000
# 163     1.000000
# 164     1.000000
# 165     1.000000
# 166     1.000000
# 167     1.000000
# 168     1.000000
# 169     1.000000
# 170     1.000000
# 171     1.000000
# 172     1.000000
# 173     1.000000
# 174     1.000000
# 175     1.000000
# 176     1.000000
# 177     1.000000
# 178     1.000000
# 179     1.000000
# 180     1.000000
# 181     1.000000
# 182     1.000000
# 183     1.000000
# 184     1.000000
# 185     1.000000
# 186     1.000000
# 187     1.000000
# 188     1.000000
# 189     1.000000
# 190     1.000000
# 191     1.000000
# 192     1.000000
# 193     1.000000
# 194     1.000000
# 195     1.000000
# 196     1.000000
# 197     1.000000
# 198     1.000000
# 199     1.000000
# 200     1.000000
# 201     1.000000
# 202     1.000000
# 203     1.000000
# 204     1.000000
# 205     1.000000
# 206     1.000000
# 207     1.000000
# 208     1.000000
# 209     1.000000
# 210     1.000000
# 211     1.000000
# 212     1.000000
# 213     1.000000
# 214     1.000000
# 215     1.000000
# 216     1.000000
# 217     1.000000
# 218     1.000000
# 219     1.000000
# 220     1.000000
# 221     1.000000
# 222     1.000000
# 223     1.000000
# 224     1.000000
# 225     1.000000
# 226     1.000000
# 227     1.000000
# 228     1.000000
# 229     1.000000
# 230     1.000000
# 231     1.000000
# 232     1.000000
# 233     1.000000
# 234     1.000000
# 235     1.000000
# 236     1.000000
# 237     1.000000
# 238     1.000000
# 239     1.000000
# 240     1.000000
# 241     1.000000
# 242     1.000000
# 243     1.000000
# 244     1.000000
# 245     1.000000
# 246     1.000000
# 247     1.000000
# 248     1.000000
# 249     1.000000
# 250     1.000000
# 251     1.000000
# 252     1.000000
# 253     1.000000
# 254     1.000000
# 255     1.000000
# 256     1.000000
# 257     1.000000
# 258     1.000000
# 259     1.000000
# 260     1.000000
# 261     1.000000
# 262     1.000000
# 263     1.000000
# 264     1.000000
# 265     1.000000
# 266     1.000000
# 267     1.000000
# 268     1.000000
# 269     1.000000
# 270     1.000000
# 271     1.000000
# 272     1.000000
# 273     1.000000
# 274     1.000000
# 275     1.000000
# 276     1.000000
# 277     1.000000
# 278     1.000000
# 279     1.000000
# 280     1.000000
# 281     1.000000
# 282     1.000000
# 283     1.000000
# 284     1.000000
# 285     1.000000
# 286     1.000000
# 287     1.000000
# 288     1.000000
# 289     1.000000
# 290     1.000000
# 291     1.000000
# 292     1.000000
# 293     1.000000
# 294     1.000000
# 295     1.000000
# 296     1.000000
# 297     1.000000
# 298     1.000000
# 299     1.000000
# 300     1.000000
# 301     1.000000
# 302     1.000000
# 303     1.000000
# 304     1.000000
# 305     1.000000
# 306     1.000000
# 307     1.000000
# 308     1.000000
# 309     1.000000
# 310     1.000000
# 311     1.000000
# 312     1.000000
# 313     1.000000
# 314     1.000000
# 315     1.000000
# 316     1.000000
# 317     1.000000
# 318     1.000000
# 319     1.000000
# 320     1.000000
# 321     1.000000
# 322     1.000000
# 323     1.000000
# 324     1.000000
# 325     1.000000
# 326     1.000000
# 327     1.000000
# 328     1.000000
# 329     1.000000
# 330     1.000000
# 331     1.000000
# 332     1.000000
# 333     1.000000
# 334     1.000000
# 335     1.000000
# 336     1.000000
# 337     1.000000
# 338     1.000000
# 339     1.000000
# 340     1.000000
# 341     1.000000
# 342     1.000000
# 343     1.000000
# 344     1.000000
# 345     1.000000
# 346     1.000000
# 347     1.000000
# 348     1.000000
# 349     1.000000
# 350     1.000000
# 351     1.000000
# 352     1.000000
# 353     1.000000
# 354     1.000000
# 355     1.000000
# 356     1.000000
# 357     1.000000
# 358     1.000000
# 359     1.000000
# 360     1.000000
# 361     1.000000
# 362     1.000000
# 363     1.000000
# 364     1.000000
# 365     1.000000
# 366     1.000000
# 367     1.000000
# 368     1.000000
# 369     1.000000
# 370     1.000000
# 371     1.000000
# 372     1.000000
# 373     1.000000
# 374     1.000000
# 375     1.000000
# 376     1.000000
# 377     1.000000
# 378     1.000000
# 379     1.000000
# 380     1.000000
# 381     1.000000
# 382     1.000000
# 383     1.000000
# 384     1.000000
# 385     1.000000
# 386     1.000000
# 387     1.000000
# 388     1.000000
# 389     1.000000
# 390     1.000000
# 391     1.000000
# 392     1.000000
# 393     1.000000
# 394     1.000000
# 395     1.000000
# 396     1.000000
# 397     1.000000
# 398     1.000000
# 399     1.000000
# 400     1.000000
# 401     1.000000
# 402     1.000000
# 403     1.000000
# 404     1.000000
# 405     1.000000
# 406     1.000000
# 407     1.000000
# 408     1.000000
# 409     1.000000
# 410     1.000000
# 411     1.000000
# 412     1.000000
# 413     1.000000
# 414     1.000000
# 415     1.000000
# 416     1.000000
# 417     1.000000
# 418     1.000000
# 419     1.000000
# 420     1.000000

# %%
#The old way
#print('Dropping the following ', str(len(to_drop)), ' highly correlated fields.')
#to_drop

# Comparing highly correlated unique field names in field 1 vs field 2 list above will allow you to 
# remove the least amount of fields possible.  
#len(cf['Field1'].unique())
#len(cf['Field2'].unique())

print('Dropping the following ', str(len(cf['Field2'].unique())), ' highly correlated, unique fields.')
cf['Field2'].unique()
# Out:
# Dropping the following  257  highly correlated, unique fields.
# array(['IndianPct', 'AsianPct', 'HispanicPct', 'BlackPct', 'WhitePct',
#        'MinorityPct', 'IndianMalePct', 'AsianMalePct', 'WhiteMalePct',
#        'MinorityMalePct', 'pct_ALL_ELP', 'pct_met_Math Grades 3-8_PART',
#        'pct_met_Reading Grades 3-8_PART',
#        'pct_met_Science Grades 5&8_PART', 'pct_met_Total Targets_PART',
#        'pct_Math Grades 3-8_ALL_PART_DET',
#        'pct_Math Grades 3-8_BL7_PART_DET',
#        'pct_Math Grades 3-8_EDS_PART_DET',
#        'pct_Math Grades 3-8_HI7_PART_DET',
#        'pct_Math Grades 3-8_SWD_PART_DET',
#        'pct_Math Grades 3-8_WH7_PART_DET',
#        'pct_Science Grades 5&8_WH7_PART_DET', 'ma_score', 'rd_score',
#        'ach_score', 'spg_score', 'ma_spg_score', 'aaa_score_ALL_SPG2',
#        'aaa_score_BL7_SPG2', 'aaa_score_EDS_SPG2', 'aaa_score_ELS_SPG2',
#        'aaa_score_HI7_SPG2', 'aaa_score_SWD_SPG2', 'aaa_score_WH7_SPG2',
#        'ach_score_ELS_SPG2', 'pct_ALL_CHRON_ABSENT', 'crime',
#        'arre_per1000_ALL', 'arre_per1000_BL7', 'arre_per1000_EDS',
#        'arre_per1000_MALE', 'arre_per1000_SWD', 'arre_per1000_WH7',
#        'crime_per1000_ALL', 'crime_per1000_BL7', 'crime_per1000_ELS',
#        'crime_per1000_MALE', 'crime_per1000_MU7', 'crime_per1000_SWD',
#        'iss_per1000_ALL', 'iss_per1000_EDS', 'rplw_per1000_ALL',
#        'rplw_per1000_MALE', 'pct_ALL_PK_ENROLL', 'lea_code_020LEA',
#        'lea_code_030LEA', 'lea_code_040LEA', 'lea_code_050LEA',
#        'lea_code_060LEA', 'lea_code_070LEA', 'lea_code_080LEA',
#        'lea_code_090LEA', 'lea_code_100LEA', 'lea_code_110LEA',
#        'lea_code_111LEA', 'lea_code_120LEA', 'lea_code_130LEA',
#        'lea_code_132LEA', 'lea_code_140LEA', 'lea_code_150LEA',
#        'lea_code_160LEA', 'lea_code_170LEA', 'lea_code_180LEA',
#        'lea_code_181LEA', 'lea_code_182LEA', 'lea_code_190LEA',
#        'lea_code_200LEA', 'lea_code_210LEA', 'lea_code_220LEA',
#        'lea_code_230LEA', 'lea_code_240LEA', 'lea_code_241LEA',
#        'lea_code_250LEA', 'lea_code_260LEA', 'lea_code_270LEA',
#        'lea_code_280LEA', 'lea_code_290LEA', 'lea_code_291LEA',
#        'lea_code_292LEA', 'lea_code_300LEA', 'lea_code_310LEA',
#        'lea_code_320LEA', 'lea_code_330LEA', 'lea_code_340LEA',
#        'lea_code_350LEA', 'lea_code_360LEA', 'lea_code_370LEA',
#        'lea_code_380LEA', 'lea_code_390LEA', 'lea_code_400LEA',
#        'lea_code_410LEA', 'lea_code_420LEA', 'lea_code_421LEA',
#        'lea_code_422LEA', 'lea_code_430LEA', 'lea_code_440LEA',
#        'lea_code_450LEA', 'lea_code_460LEA', 'lea_code_470LEA',
#        'lea_code_480LEA', 'lea_code_490LEA', 'lea_code_491LEA',
#        'lea_code_500LEA', 'lea_code_510LEA', 'lea_code_520LEA',
#        'lea_code_530LEA', 'lea_code_540LEA', 'lea_code_550LEA',
#        'lea_code_560LEA', 'lea_code_570LEA', 'lea_code_580LEA',
#        'lea_code_590LEA', 'lea_code_600LEA', 'lea_code_610LEA',
#        'lea_code_620LEA', 'lea_code_630LEA', 'lea_code_640LEA',
#        'lea_code_650LEA', 'lea_code_660LEA', 'lea_code_670LEA',
#        'lea_code_680LEA', 'lea_code_681LEA', 'lea_code_690LEA',
#        'lea_code_700LEA', 'lea_code_710LEA', 'lea_code_720LEA',
#        'lea_code_730LEA', 'lea_code_740LEA', 'lea_code_750LEA',
#        'lea_code_760LEA', 'lea_code_761LEA', 'lea_code_770LEA',
#        'lea_code_780LEA', 'lea_code_790LEA', 'lea_code_800LEA',
#        'lea_code_810LEA', 'lea_code_820LEA', 'lea_code_821LEA',
#        'lea_code_830LEA', 'lea_code_840LEA', 'lea_code_850LEA',
#        'lea_code_860LEA', 'lea_code_861LEA', 'lea_code_862LEA',
#        'lea_code_870LEA', 'lea_code_880LEA', 'lea_code_890LEA',
#        'lea_code_900LEA', 'lea_code_910LEA', 'lea_code_920LEA',
#        'lea_code_930LEA', 'lea_code_940LEA', 'lea_code_950LEA',
#        'lea_code_960LEA', 'lea_code_970LEA', 'lea_code_980LEA',
#        'lea_code_990LEA', 'lea_code_995LEA', 'county_Alexander',
#        'county_Alleghany', 'county_Anson', 'county_Ashe', 'county_Avery',
#        'county_Beaufort', 'county_Bertie', 'county_Bladen',
#        'county_Brunswick', 'county_Burke', 'county_Caldwell',
#        'county_Camden', 'county_Carteret', 'county_Caswell',
#        'county_Chatham', 'county_Cherokee', 'county_Chowan',
#        'county_Clay', 'county_Cleveland', 'county_Craven',
#        'county_Cumberland', 'county_Currituck', 'county_Dare',
#        'county_Davie', 'county_Duplin', 'county_Durham',
#        'county_Edgecombe', 'county_Forsyth', 'county_Franklin',
#        'county_Gaston', 'county_Gates', 'county_Graham',
#        'county_Granville', 'county_Greene', 'county_Guilford',
#        'county_Harnett', 'county_Haywood', 'county_Henderson',
#        'county_Hertford', 'county_Hoke', 'county_Hyde', 'county_Jackson',
#        'county_Johnston', 'county_Jones', 'county_Lee', 'county_Lenoir',
#        'county_Lincoln', 'county_Macon', 'county_Madison',
#        'county_Martin', 'county_McDowell', 'county_Mecklenburg',
#        'county_Mitchell', 'county_Montgomery', 'county_Moore',
#        'county_Nash', 'county_New Hanover', 'county_Northampton',
#        'county_Onslow', 'county_Pamlico', 'county_Pasquotank',
#        'county_Pender', 'county_Perquimans', 'county_Person',
#        'county_Pitt', 'county_Polk', 'county_Richmond', 'county_Robeson',
#        'county_Rockingham', 'county_Rowan', 'county_Rutherford',
#        'county_Scotland', 'county_Stanly', 'county_Stokes',
#        'county_Swain', 'county_Transylvania', 'county_Tyrrell',
#        'county_Union', 'county_Vance', 'county_Wake', 'county_Warren',
#        'county_Washington', 'county_Watauga', 'county_Wayne',
#        'county_Wilkes', 'county_Wilson', 'county_Yadkin', 'county_Yancey',
#        'grade_span_KG:13'], dtype=object)

# %%
#Check columns before drop 
print('\r\n*********Before: Dropping Highly Correlated Fields*************************************')
schoolData.info(verbose=False)

# Drop the highly correlated features from our training data 
#schoolData = schoolData.drop(to_drop, axis=1)
schoolData = schoolData.drop(cf['Field2'], axis=1)

#Check columns after drop 
print('\r\n*********After: Dropping Highly Correlated Fields**************************************')
schoolData.info(verbose=False)
# Out:
# *********Before: Dropping Highly Correlated Fields*************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1422 entries, 2 to 1574
# Columns: 751 entries, IndianPct to agency_lea_code_995LEA
# dtypes: float64(248), uint8(503)
# memory usage: 3.4 MB
#
# *********After: Dropping Highly Correlated Fields**************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1422 entries, 2 to 1574
# Columns: 494 entries, PacificIslandPct to agency_lea_code_995LEA
# dtypes: float64(194), uint8(300)
# memory usage: 2.5 MB

# %%
#Restore the unit_code before saving
schoolData['agency_code'] = agency_code
#Save the final dataset to a .csv file
schoolData.to_csv(outputDir + inputFileName + '_ML.csv', sep=',', index=False)

# %%
print('*********FINAL DATASET DETAILS*********************************************************\r\n')
schoolData.info(verbose=True)
# Out:
# *********FINAL DATASET DETAILS*********************************************************
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1422 entries, 2 to 1574
# Data columns (total 495 columns):
# PacificIslandPct                                                         float64
# TwoOrMorePct                                                             float64
# HispanicMalePct                                                          float64
# BlackMalePct                                                             float64
# PacificIslandMalePct                                                     float64
# TwoOrMoreMalePct                                                         float64
# IndianFemalePct                                                          float64
# AsianFemalePct                                                           float64
# HispanicFemalePct                                                        float64
# BlackFemalePct                                                           float64
# WhiteFemalePct                                                           float64
# MinorityFemalePct                                                        float64
# PacificIslandFemalePct                                                   float64
# TwoOrMoreFemalePct                                                       float64
# pct_eds                                                                  float64
# pct_EDS_ELP                                                              float64
# pct_ELS_ELP                                                              float64
# pct_FEM_ELP                                                              float64
# pct_HI7_ELP                                                              float64
# pct_MALE_ELP                                                             float64
# pct_met_Math Grades 3-8_LTG                                              float64
# pct_met_Reading Grades 3-8_LTG                                           float64
# pct_met_Total Targets_LTG                                                float64
# pct_Reading Grades 3-8_ALL_PART_DET                                      float64
# pct_Reading Grades 3-8_BL7_PART_DET                                      float64
# pct_Reading Grades 3-8_EDS_PART_DET                                      float64
# pct_Reading Grades 3-8_HI7_PART_DET                                      float64
# pct_Reading Grades 3-8_SWD_PART_DET                                      float64
# pct_Reading Grades 3-8_WH7_PART_DET                                      float64
# pct_Science Grades 5&8_ALL_PART_DET                                      float64
# pct_Science Grades 5&8_EDS_PART_DET                                      float64
# pct_passed_eog_RTA                                                       float64
# pct_passed_laa_RTA                                                       float64
# pct_promoted_RTA                                                         float64
# pct_retained_RTA                                                         float64
# sc_score                                                                 float64
# eg_score                                                                 float64
# rd_spg_score                                                             float64
# ma_eg_score                                                              float64
# rd_eg_score                                                              float64
# ach_score_ALL_SPG2                                                       float64
# ach_score_BL7_SPG2                                                       float64
# ach_score_EDS_SPG2                                                       float64
# ach_score_HI7_SPG2                                                       float64
# ach_score_SWD_SPG2                                                       float64
# ach_score_WH7_SPG2                                                       float64
# eg_score_ALL_SPG2                                                        float64
# eg_score_BL7_SPG2                                                        float64
# eg_score_EDS_SPG2                                                        float64
# eg_score_ELS_SPG2                                                        float64
# eg_score_HI7_SPG2                                                        float64
# eg_score_SWD_SPG2                                                        float64
# eg_score_WH7_SPG2                                                        float64
# scgs_score_ALL_SPG2                                                      float64
# scgs_score_EDS_SPG2                                                      float64
# scgs_score_WH7_SPG2                                                      float64
# spg_score_ALL_SPG2                                                       float64
# spg_score_BL7_SPG2                                                       float64
# spg_score_EDS_SPG2                                                       float64
# spg_score_ELS_SPG2                                                       float64
# spg_score_HI7_SPG2                                                       float64
# spg_score_SWD_SPG2                                                       float64
# spg_score_WH7_SPG2                                                       float64
# avg_student_num                                                          float64
# pct_att                                                                  float64
# pct_BL7_CHRON_ABSENT                                                     float64
# pct_ELS_CHRON_ABSENT                                                     float64
# pct_FEM_CHRON_ABSENT                                                     float64
# pct_HI7_CHRON_ABSENT                                                     float64
# pct_MALE_CHRON_ABSENT                                                    float64
# pct_MU7_CHRON_ABSENT                                                     float64
# pct_SWD_CHRON_ABSENT                                                     float64
# pct_WH7_CHRON_ABSENT                                                     float64
# Book_TitlesPer_Student                                                   float64
# wap                                                                      float64
# wap_class                                                                float64
# media_school                                                             float64
# devices                                                                  float64
# pct_rating_T1_Accomplished                                               float64
# pct_rating_T1_Distinguished                                              float64
# pct_rating_T1_Proficient                                                 float64
# pct_rating_T2_Accomplished                                               float64
# pct_rating_T2_Distinguished                                              float64
# pct_rating_T2_Proficient                                                 float64
# pct_rating_T3_Accomplished                                               float64
# pct_rating_T3_Distinguished                                              float64
# pct_rating_T3_Proficient                                                 float64
# pct_rating_T4_Accomplished                                               float64
# pct_rating_T4_Distinguished                                              float64
# pct_rating_T4_Proficient                                                 float64
# pct_rating_T5_Accomplished                                               float64
# pct_rating_T5_Distinguished                                              float64
# pct_rating_T5_Proficient                                                 float64
# pct_rating_TS_Does Not Meet Expected Growth                              float64
# pct_rating_TS_Exceeds Expected Growth                                    float64
# pct_rating_TS_Meets Expected Growth                                      float64
# avg_class_teach_TeacherExp                                               float64
# pct_adv_degree_TeacherExp                                                float64
# pct_experience_0_TeacherExp                                              float64
# pct_experience_10_TeacherExp                                             float64
# pct_experience_4_TeacherExp                                              float64
# pct_turnover_TeacherExp                                                  float64
# highqual_class_pct_E                                                     float64
# short_term                                                               float64
# long_term                                                                float64
# expulsion                                                                float64
# arre_per1000_FEM                                                         float64
# arre_per1000_HI7                                                         float64
# arre_per1000_MU7                                                         float64
# blhr_per1000_ALL                                                         float64
# blhr_per1000_BL7                                                         float64
# blhr_per1000_EDS                                                         float64
# blhr_per1000_ELS                                                         float64
# blhr_per1000_FEM                                                         float64
# blhr_per1000_HI7                                                         float64
# blhr_per1000_MALE                                                        float64
# blhr_per1000_MU7                                                         float64
# blhr_per1000_SWD                                                         float64
# blhr_per1000_WH7                                                         float64
# crime_per1000_EDS                                                        float64
# crime_per1000_FEM                                                        float64
# crime_per1000_HI7                                                        float64
# crime_per1000_WH7                                                        float64
# exp_per1000_ALL                                                          float64
# exp_per1000_BL7                                                          float64
# exp_per1000_EDS                                                          float64
# exp_per1000_ELS                                                          float64
# exp_per1000_FEM                                                          float64
# exp_per1000_HI7                                                          float64
# exp_per1000_MALE                                                         float64
# exp_per1000_MU7                                                          float64
# exp_per1000_SWD                                                          float64
# exp_per1000_WH7                                                          float64
# iss_per1000_BL7                                                          float64
# iss_per1000_ELS                                                          float64
# iss_per1000_FEM                                                          float64
# iss_per1000_HI7                                                          float64
# iss_per1000_MALE                                                         float64
# iss_per1000_MU7                                                          float64
# iss_per1000_SWD                                                          float64
# iss_per1000_WH7                                                          float64
# lts_per1000_ALL                                                          float64
# lts_per1000_BL7                                                          float64
# lts_per1000_EDS                                                          float64
# lts_per1000_ELS                                                          float64
# lts_per1000_FEM                                                          float64
# lts_per1000_HI7                                                          float64
# lts_per1000_MALE                                                         float64
# lts_per1000_MU7                                                          float64
# lts_per1000_SWD                                                          float64
# lts_per1000_WH7                                                          float64
# rplw_per1000_BL7                                                         float64
# rplw_per1000_EDS                                                         float64
# rplw_per1000_FEM                                                         float64
# rplw_per1000_HI7                                                         float64
# rplw_per1000_MU7                                                         float64
# rplw_per1000_SWD                                                         float64
# rplw_per1000_WH7                                                         float64
# sts_per1000_ALL                                                          float64
# sts_per1000_BL7                                                          float64
# sts_per1000_EDS                                                          float64
# sts_per1000_ELS                                                          float64
# sts_per1000_FEM                                                          float64
# sts_per1000_HI7                                                          float64
# sts_per1000_MALE                                                         float64
# sts_per1000_MU7                                                          float64
# sts_per1000_SWD                                                          float64
# sts_per1000_WH7                                                          float64
# pct_fully_licensed                                                       float64
# pct_lateral_entry                                                        float64
# nbpts_num                                                                float64
# pct_BL7_PK_ENROLL                                                        float64
# pct_ELS_PK_ENROLL                                                        float64
# pct_FEM_PK_ENROLL                                                        float64
# pct_HI7_PK_ENROLL                                                        float64
# pct_MALE_PK_ENROLL                                                       float64
# pct_SWD_PK_ENROLL                                                        float64
# pct_WH7_PK_ENROLL                                                        float64
# pct_ready_kea                                                            float64
# avg_size_00_SAR                                                          float64
# avg_size_01_SAR                                                          float64
# avg_size_02_SAR                                                          float64
# avg_size_03_SAR                                                          float64
# avg_size_04_SAR                                                          float64
# avg_size_05_SAR                                                          float64
# lea_total_expense                                                        float64
# lea_pct_salary                                                           float64
# lea_pct_benefits                                                         float64
# lea_pct_services                                                         float64
# lea_pct_supplies                                                         float64
# lea_pct_instruct_equip                                                   float64
# lea_local_perpupil                                                       float64
# lea_state_perpupil                                                       float64
# lea_federal_perpupil                                                     float64
# category_code_E                                                          uint8
# category_code_I                                                          uint8
# county_Buncombe                                                          uint8
# county_Cabarrus                                                          uint8
# county_Catawba                                                           uint8
# county_Columbus                                                          uint8
# county_Davidson                                                          uint8
# county_Halifax                                                           uint8
# county_Iredell                                                           uint8
# county_Orange                                                            uint8
# county_Randolph                                                          uint8
# county_Sampson                                                           uint8
# county_Surry                                                             uint8
# grade_span_02:03                                                         uint8
# grade_span_02:04                                                         uint8
# grade_span_02:05                                                         uint8
# grade_span_03:05                                                         uint8
# grade_span_03:12                                                         uint8
# grade_span_04:05                                                         uint8
# grade_span_04:06                                                         uint8
# grade_span_04:08                                                         uint8
# grade_span_KG:01                                                         uint8
# grade_span_KG:02                                                         uint8
# grade_span_KG:03                                                         uint8
# grade_span_KG:04                                                         uint8
# grade_span_KG:05                                                         uint8
# grade_span_KG:06                                                         uint8
# grade_span_KG:08                                                         uint8
# grade_span_KG:12                                                         uint8
# grade_span_PK:01                                                         uint8
# grade_span_PK:02                                                         uint8
# grade_span_PK:03                                                         uint8
# grade_span_PK:04                                                         uint8
# grade_span_PK:05                                                         uint8
# grade_span_PK:06                                                         uint8
# grade_span_PK:08                                                         uint8
# grade_span_PK:09                                                         uint8
# grade_span_PK:12                                                         uint8
# grade_span_PK:13                                                         uint8
# grade_span_PK:KG                                                         uint8
# school_type_Hospital School                                              uint8
# school_type_Magnet School                                                uint8
# school_type_Regular School                                               uint8
# school_type_Special Education                                            uint8
# calendar_type_Year-Round Calendar                                        uint8
# csi_lp_Y                                                                 uint8
# csi_lg_Y                                                                 uint8
# tsi_cu_Y                                                                 uint8
# tsi_at_Y                                                                 uint8
# grad_project_Y                                                           uint8
# lp_school_Y                                                              uint8
# rlp_school_Y                                                             uint8
# target_list_4 Year Graduation Rate,Math Grade 11,Reading Grade 10        uint8
# target_list_4 Year Graduation Rate,Math Grades 3-8,Reading Grades 3-8    uint8
# target_list_EL Progress                                                  uint8
# target_list_EL Progress,Math Grades 3-8,Reading Grades 3-8               uint8
# target_list_Math Grades 3-8,Reading Grades 3-8                           uint8
# subgroup_list_ALL,AM7,BL7,EDS                                            uint8
# subgroup_list_ALL,AM7,BL7,EDS,ELS,HI7                                    uint8
# subgroup_list_ALL,AM7,BL7,EDS,ELS,HI7,MU7,SWD,WH7                        uint8
# subgroup_list_ALL,AM7,BL7,EDS,ELS,HI7,SWD                                uint8
# subgroup_list_ALL,AM7,BL7,EDS,ELS,HI7,SWD,WH7                            uint8
# subgroup_list_ALL,AM7,BL7,EDS,HI7,SWD,WH7                                uint8
# subgroup_list_ALL,AM7,BL7,EDS,SWD                                        uint8
# subgroup_list_ALL,AM7,BL7,EDS,SWD,WH7                                    uint8
# subgroup_list_ALL,AM7,BL7,EDS,WH7                                        uint8
# subgroup_list_ALL,AM7,EDS                                                uint8
# subgroup_list_ALL,AM7,EDS,ELS,HI7                                        uint8
# subgroup_list_ALL,AM7,EDS,HI7                                            uint8
# subgroup_list_ALL,AM7,EDS,HI7,SWD                                        uint8
# subgroup_list_ALL,AM7,EDS,HI7,WH7                                        uint8
# subgroup_list_ALL,AM7,EDS,SWD                                            uint8
# subgroup_list_ALL,AM7,EDS,SWD,WH7                                        uint8
# subgroup_list_ALL,AS7,BL7,EDS,ELS,HI7                                    uint8
# subgroup_list_ALL,AS7,BL7,EDS,ELS,HI7,SWD                                uint8
# subgroup_list_ALL,AS7,BL7,EDS,ELS,HI7,SWD,WH7                            uint8
# subgroup_list_ALL,AS7,BL7,EDS,ELS,HI7,WH7                                uint8
# subgroup_list_ALL,AS7,BL7,EDS,ELS,WH7                                    uint8
# subgroup_list_ALL,AS7,BL7,EDS,HI7                                        uint8
# subgroup_list_ALL,AS7,BL7,EDS,HI7,MU7,SWD,WH7                            uint8
# subgroup_list_ALL,AS7,BL7,EDS,HI7,SWD,WH7                                uint8
# subgroup_list_ALL,AS7,BL7,EDS,HI7,WH7                                    uint8
# subgroup_list_ALL,AS7,BL7,EDS,SWD,WH7                                    uint8
# subgroup_list_ALL,AS7,BL7,EDS,WH7                                        uint8
# subgroup_list_ALL,AS7,BL7,HI7,WH7                                        uint8
# subgroup_list_ALL,AS7,EDS,ELS,HI7,SWD,WH7                                uint8
# subgroup_list_ALL,AS7,EDS,ELS,HI7,WH7                                    uint8
# subgroup_list_ALL,AS7,EDS,HI7,SWD,WH7                                    uint8
# subgroup_list_ALL,AS7,EDS,SWD,WH7                                        uint8
# subgroup_list_ALL,AS7,EDS,WH7                                            uint8
# subgroup_list_ALL,AS7,ELS,SWD,WH7                                        uint8
# subgroup_list_ALL,AS7,SWD,WH7                                            uint8
# subgroup_list_ALL,AS7,WH7                                                uint8
# subgroup_list_ALL,BL7                                                    uint8
# subgroup_list_ALL,BL7,EDS                                                uint8
# subgroup_list_ALL,BL7,EDS,ELS,HI7                                        uint8
# subgroup_list_ALL,BL7,EDS,ELS,HI7,MU7,SWD,WH7                            uint8
# subgroup_list_ALL,BL7,EDS,ELS,HI7,MU7,WH7                                uint8
# subgroup_list_ALL,BL7,EDS,ELS,HI7,SWD                                    uint8
# subgroup_list_ALL,BL7,EDS,ELS,HI7,SWD,WH7                                uint8
# subgroup_list_ALL,BL7,EDS,ELS,HI7,WH7                                    uint8
# subgroup_list_ALL,BL7,EDS,HI7                                            uint8
# subgroup_list_ALL,BL7,EDS,HI7,MU7,SWD,WH7                                uint8
# subgroup_list_ALL,BL7,EDS,HI7,SWD                                        uint8
# subgroup_list_ALL,BL7,EDS,HI7,SWD,WH7                                    uint8
# subgroup_list_ALL,BL7,EDS,HI7,WH7                                        uint8
# subgroup_list_ALL,BL7,EDS,SWD                                            uint8
# subgroup_list_ALL,BL7,EDS,SWD,WH7                                        uint8
# subgroup_list_ALL,BL7,EDS,WH7                                            uint8
# subgroup_list_ALL,BL7,SWD                                                uint8
# subgroup_list_ALL,EDS                                                    uint8
# subgroup_list_ALL,EDS,ELS,HI7                                            uint8
# subgroup_list_ALL,EDS,ELS,HI7,SWD,WH7                                    uint8
# subgroup_list_ALL,EDS,ELS,HI7,WH7                                        uint8
# subgroup_list_ALL,EDS,HI7,SWD,WH7                                        uint8
# subgroup_list_ALL,EDS,HI7,WH7                                            uint8
# subgroup_list_ALL,EDS,SWD                                                uint8
# subgroup_list_ALL,EDS,SWD,WH7                                            uint8
# subgroup_list_ALL,EDS,WH7                                                uint8
# subgroup_list_ALL,HI7,SWD,WH7                                            uint8
# subgroup_list_ALL,SWD                                                    uint8
# subgroup_list_ALL,SWD,WH7                                                uint8
# subgroup_list_ALL,WH7                                                    uint8
# ma_grade_B                                                               uint8
# ma_grade_C                                                               uint8
# ma_grade_D                                                               uint8
# ma_grade_F                                                               uint8
# rd_grade_B                                                               uint8
# rd_grade_C                                                               uint8
# rd_grade_D                                                               uint8
# rd_grade_F                                                               uint8
# eg_status_Met                                                            uint8
# eg_status_NotMet                                                         uint8
# spg_grade_A+NG                                                           uint8
# spg_grade_B                                                              uint8
# spg_grade_C                                                              uint8
# spg_grade_D                                                              uint8
# spg_grade_F                                                              uint8
# ma_eg_status_Met                                                         uint8
# ma_eg_status_NotMet                                                      uint8
# rd_eg_status_Met                                                         uint8
# rd_eg_status_NotMet                                                      uint8
# dance_cat_Y                                                              uint8
# music_cat_Y                                                              uint8
# theatre_cat_Y                                                            uint8
# va_cat_Y                                                                 uint8
# digital_media_0                                                          uint8
# digital_media_1                                                          uint8
# digital_media_10                                                         uint8
# digital_media_11                                                         uint8
# digital_media_12                                                         uint8
# digital_media_13                                                         uint8
# digital_media_14                                                         uint8
# digital_media_15                                                         uint8
# digital_media_16                                                         uint8
# digital_media_17                                                         uint8
# digital_media_2                                                          uint8
# digital_media_20                                                         uint8
# digital_media_22                                                         uint8
# digital_media_23                                                         uint8
# digital_media_25                                                         uint8
# digital_media_27                                                         uint8
# digital_media_28                                                         uint8
# digital_media_3                                                          uint8
# digital_media_30                                                         uint8
# digital_media_31                                                         uint8
# digital_media_32                                                         uint8
# digital_media_33                                                         uint8
# digital_media_35                                                         uint8
# digital_media_38                                                         uint8
# digital_media_4                                                          uint8
# digital_media_5                                                          uint8
# digital_media_54                                                         uint8
# digital_media_58                                                         uint8
# digital_media_6                                                          uint8
# digital_media_7                                                          uint8
# digital_media_8                                                          uint8
# digital_media_9                                                          uint8
# digital_media_97                                                         uint8
# digital_media_99                                                         uint8
# device_access_Yes                                                        uint8
# device_home_Yes                                                          uint8
# BYOD_Neither                                                             uint8
# BYOD_Staff                                                               uint8
# BYOD_Students                                                            uint8
# esea_att_Met                                                             uint8
# agency_lea_code_020LEA                                                   uint8
# agency_lea_code_030LEA                                                   uint8
# agency_lea_code_040LEA                                                   uint8
# agency_lea_code_050LEA                                                   uint8
# agency_lea_code_060LEA                                                   uint8
# agency_lea_code_070LEA                                                   uint8
# agency_lea_code_080LEA                                                   uint8
# agency_lea_code_090LEA                                                   uint8
# agency_lea_code_100LEA                                                   uint8
# agency_lea_code_110LEA                                                   uint8
# agency_lea_code_111LEA                                                   uint8
# agency_lea_code_120LEA                                                   uint8
# agency_lea_code_130LEA                                                   uint8
# agency_lea_code_132LEA                                                   uint8
# agency_lea_code_140LEA                                                   uint8
# agency_lea_code_150LEA                                                   uint8
# agency_lea_code_160LEA                                                   uint8
# agency_lea_code_170LEA                                                   uint8
# agency_lea_code_180LEA                                                   uint8
# agency_lea_code_181LEA                                                   uint8
# agency_lea_code_182LEA                                                   uint8
# agency_lea_code_190LEA                                                   uint8
# agency_lea_code_200LEA                                                   uint8
# agency_lea_code_210LEA                                                   uint8
# agency_lea_code_220LEA                                                   uint8
# agency_lea_code_230LEA                                                   uint8
# agency_lea_code_240LEA                                                   uint8
# agency_lea_code_241LEA                                                   uint8
# agency_lea_code_250LEA                                                   uint8
# agency_lea_code_260LEA                                                   uint8
# agency_lea_code_270LEA                                                   uint8
# agency_lea_code_280LEA                                                   uint8
# agency_lea_code_290LEA                                                   uint8
# agency_lea_code_291LEA                                                   uint8
# agency_lea_code_292LEA                                                   uint8
# agency_lea_code_300LEA                                                   uint8
# agency_lea_code_310LEA                                                   uint8
# agency_lea_code_320LEA                                                   uint8
# agency_lea_code_330LEA                                                   uint8
# agency_lea_code_340LEA                                                   uint8
# agency_lea_code_350LEA                                                   uint8
# agency_lea_code_360LEA                                                   uint8
# agency_lea_code_370LEA                                                   uint8
# agency_lea_code_380LEA                                                   uint8
# agency_lea_code_390LEA                                                   uint8
# agency_lea_code_400LEA                                                   uint8
# agency_lea_code_410LEA                                                   uint8
# agency_lea_code_420LEA                                                   uint8
# agency_lea_code_421LEA                                                   uint8
# agency_lea_code_422LEA                                                   uint8
# agency_lea_code_430LEA                                                   uint8
# agency_lea_code_440LEA                                                   uint8
# agency_lea_code_450LEA                                                   uint8
# agency_lea_code_460LEA                                                   uint8
# agency_lea_code_470LEA                                                   uint8
# agency_lea_code_480LEA                                                   uint8
# agency_lea_code_490LEA                                                   uint8
# agency_lea_code_491LEA                                                   uint8
# agency_lea_code_500LEA                                                   uint8
# agency_lea_code_510LEA                                                   uint8
# agency_lea_code_520LEA                                                   uint8
# agency_lea_code_530LEA                                                   uint8
# agency_lea_code_540LEA                                                   uint8
# agency_lea_code_550LEA                                                   uint8
# agency_lea_code_560LEA                                                   uint8
# agency_lea_code_570LEA                                                   uint8
# agency_lea_code_580LEA                                                   uint8
# agency_lea_code_590LEA                                                   uint8
# agency_lea_code_600LEA                                                   uint8
# agency_lea_code_610LEA                                                   uint8
# agency_lea_code_620LEA                                                   uint8
# agency_lea_code_630LEA                                                   uint8
# agency_lea_code_640LEA                                                   uint8
# agency_lea_code_650LEA                                                   uint8
# agency_lea_code_660LEA                                                   uint8
# agency_lea_code_670LEA                                                   uint8
# agency_lea_code_680LEA                                                   uint8
# agency_lea_code_681LEA                                                   uint8
# agency_lea_code_690LEA                                                   uint8
# agency_lea_code_700LEA                                                   uint8
# agency_lea_code_710LEA                                                   uint8
# agency_lea_code_720LEA                                                   uint8
# agency_lea_code_730LEA                                                   uint8
# agency_lea_code_740LEA                                                   uint8
# agency_lea_code_750LEA                                                   uint8
# agency_lea_code_760LEA                                                   uint8
# agency_lea_code_761LEA                                                   uint8
# agency_lea_code_770LEA                                                   uint8
# agency_lea_code_780LEA                                                   uint8
# agency_lea_code_790LEA                                                   uint8
# agency_lea_code_800LEA                                                   uint8
# agency_lea_code_810LEA                                                   uint8
# agency_lea_code_820LEA                                                   uint8
# agency_lea_code_821LEA                                                   uint8
# agency_lea_code_830LEA                                                   uint8
# agency_lea_code_840LEA                                                   uint8
# agency_lea_code_850LEA                                                   uint8
# agency_lea_code_860LEA                                                   uint8
# agency_lea_code_861LEA                                                   uint8
# agency_lea_code_862LEA                                                   uint8
# agency_lea_code_870LEA                                                   uint8
# agency_lea_code_880LEA                                                   uint8
# agency_lea_code_890LEA                                                   uint8
# agency_lea_code_900LEA                                                   uint8
# agency_lea_code_910LEA                                                   uint8
# agency_lea_code_920LEA                                                   uint8
# agency_lea_code_930LEA                                                   uint8
# agency_lea_code_940LEA                                                   uint8
# agency_lea_code_950LEA                                                   uint8
# agency_lea_code_960LEA                                                   uint8
# agency_lea_code_970LEA                                                   uint8
# agency_lea_code_980LEA                                                   uint8
# agency_lea_code_990LEA                                                   uint8
# agency_lea_code_995LEA                                                   uint8
# agency_code                                                              object
# dtypes: float64(194), object(1), uint8(300)
# memory usage: 2.5+ MB

# %%
import sklearn
import pandas as pd

print('Sklearn Version: ' + sklearn.__version__)
print('Pandas Version: ' + pd.__version__)
# Out:
# Sklearn Version: 0.20.3
# Pandas Version: 0.24.2

# %%
print('Output File Location:\r\n\r\n' + outputDir + inputFileName + '_ML.csv')
# Out:
# Output File Location:
#
# C:/Users/Jake/Documents/GitHub/EducationDataNC/2018/Machine Learning Datasets/PublicElementarySchools2018_ML.csv
