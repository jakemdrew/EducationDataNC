# %% [markdown]
# # Create Public School Machine Learning Datasets
# ** This program creates all the _ML datasets in the NCEA repository.**
# * This notebook reads each School Dataset file located at \EducationDataNC\ *schoolYear* \School Datasets\ as input data.
# * Different school years are processed by changing the *schoolYear* parameter.
# * Different input / output files are processed / created by changing the *inputFileName* paramter in the cell below.
# * While a single program is used to create all the _ML datasets, one program copy per dataset is maintained in the repositiory so the dataset specific tranformation reports may be reviewed.
#
# **Datasets ending in ML are preprocessed for Machine Learning and go through the following transformations: **
# 1. Missing student body racial compositions are imputed using district averages.
# 2. Columns that have the same value in every single row are deleted.
# 3. Columns that have a unique value in every single row (all values are different) are deleted.
# 4. Empty columns (all values are NA or NULL) are deleted.
# 5. Numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# 6. Remaining numeric, non-race columns with missing values are imputed / populated with 0.  In many cases, schools are not reporting values when they are zero. However, mean imputation or some other more sophisticated strategy might be considered here.
# 7. Categorical / text based columns with > *uniqueThreshold* unique values are deleted.
# 8. All remaining categorical / text based columns are one-hot encoded.  In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# 9. Duplicated or highly similar columns with > 95% correlation are delelted.

# %%
#import required Libraries
import pandas as pd
import numpy as np
import os
import string

#**********************************************************************************
# Set the following variables before running this code!!!
#**********************************************************************************
#All raw data files are processed for the year below
schoolYear = 2014

#Location where copies of the raw data files will be read in from csv files.
dataDir = 'C:/Users/Jake/Documents/GitHub/EducationDataNC/' + str(schoolYear) + '/School Datasets/'

#Name of the file to be processed
#inputFileName = 'PublicSchools' + str(schoolYear)
#inputFileName = 'PublicHighSchools' + str(schoolYear)
inputFileName = 'PublicMiddleSchools' + str(schoolYear)
#inputFileName = 'PublicElementarySchools' + str(schoolYear)

#Input file being transformed for machine learning 
inputFile = dataDir + inputFileName + '.csv'

#Location where the new school datasets will be created.
outputDir = 'C:/Users/Jake/Documents/GitHub/EducationDataNC/' + str(schoolYear) + '/Machine Learning Datasets/'

#Missing Data Threshold (Per Column)
missingThreshold = 0.60

#Unique Value Threshold (Per Column)
#Delete Columns >  uniqueThreshold unique values prior to one-hot encoding. 
#(each unique value becomes a new column during one-hot encoding)
uniqueThreshold = 25

#Read in the School Data File
schoolData = pd.read_csv(inputFile, low_memory=False, dtype={'unit_code': object})
print('*********Start: Beginning Column and Row Counts********************************************')
schoolData.info(verbose=False)

#Select only public schools as charter schools are missing data for many columns.
schoolData = schoolData[(schoolData['type_cd'] == 'P') & (schoolData['student_num'] > 0)]

print('\r\n*********After: Selecting Only Public School Campuses**********************************')
schoolData.info(verbose=False)

#Save primary key
unit_code = schoolData['unit_code']
#Convert zip code to string
schoolData['szip_ad'] = schoolData['szip_ad'].astype('object')
#Rename Lea_Name to District Name
schoolData.rename(columns={'Lea_Name': 'District Name'}, inplace=True)
# Out:
# *********Start: Beginning Column and Row Counts********************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 538 entries, 0 to 537
# Columns: 1259 entries, vphone_ad to WhitePct
# dtypes: float64(1226), int64(3), object(30)
# memory usage: 5.2+ MB
#
# *********After: Selecting Only Public School Campuses**********************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 538 entries, 0 to 537
# Columns: 1259 entries, vphone_ad to WhitePct
# dtypes: float64(1226), int64(3), object(30)
# memory usage: 5.2+ MB

# %% [markdown]
# # Prepare Consolidated Dataset for Machine Learning
# **Below we perform operations on the entire dataset to remove columns and update row values that could cause problems during machine learning.**

# %% [markdown]
# ## Student Body Racial Composition Features
# **Impute / update missing Student Body Racial Composition Fields using mean imputation.**
# * When there are no racial composition percentages for a particular school campus / unit_code, fill in the missing values

# %%
schoolData.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 538 entries, 0 to 537
# Data columns (total 1259 columns):
# vphone_ad                                               object
# year                                                    int64
# unit_code                                               object
# street_ad                                               object
# scity_ad                                                object
# state_ad                                                object
# szip_ad                                                 object
# type_cd                                                 object
# closed_ind                                              float64
# new_ind                                                 float64
# super_nm                                                float64
# category_cd                                             object
# url_ad                                                  object
# grade_range_cd                                          object
# calendar_type_txt                                       object
# sna_pgm_type_cd                                         object
# cover_letter_ad                                         float64
# school_type_txt                                         object
# calendar_only_txt                                       object
# title1_type_cd                                          object
# clp_ind                                                 float64
# focus_clp_ind                                           float64
# summer_program_ind                                      float64
# asm_no_spg_ind                                          float64
# no_data_spg_ind                                         float64
# District Name                                           object
# School_Name                                             object
# State_Name                                              object
# esea_status                                             object
# student_num                                             float64
# lea_avg_student_num                                     float64
# st_avg_student_num                                      float64
# Grad_project_status                                     object
# stem                                                    object
# url                                                     object
# Biology_Size                                            float64
# English II_Size                                         float64
# Math I_Size                                             float64
# total_expense_num                                       float64
# salary_expense_pct                                      float64
# benefits_expense_pct                                    float64
# services_expense_pct                                    float64
# supplies_expense_pct                                    float64
# instruct_equip_exp_pct                                  float64
# other_expense_pct                                       float64
# federal_perpupil_num                                    float64
# local_perpupil_num                                      float64
# state_perpupil_num                                      float64
# lea_total_expense_num                                   float64
# lea_salary_expense_pct                                  float64
# lea_benefits_expense_pct                                float64
# lea_services_expense_pct                                float64
# lea_supplies_expense_pct                                float64
# lea_instruct_equip_exp_pct                              float64
# lea_other_expense_pct                                   float64
# lea_federal_perpupil_num                                float64
# lea_local_perpupil_num                                  float64
# lea_state_perpupil_num                                  float64
# st_total_expense_num                                    float64
# st_salary_expense_pct                                   float64
# st_benefits_expense_pct                                 float64
# st_services_expense_pct                                 float64
# st_supplies_expense_pct                                 float64
# st_instruct_equip_exp_pct                               float64
# st_other_expense_pct                                    float64
# st_federal_perpupil_num                                 float64
# st_local_perpupil_num                                   float64
# st_state_perpupil_num                                   float64
# building_expense_pct                                    float64
# lea_building_expense_pct                                float64
# st_building_expense_pct                                 float64
# LEA Name                                                object
# School Name                                             object
# SBE Region                                              float64
# SPG Grade                                               object
# SPG Score                                               float64
# Reading SPG Grade                                       object
# Reading  SPG Score                                      float64
# Math SPG Grade                                          object
# Math SPG Score                                          float64
# EVAAS Growth Status                                     object
# EVAAS Growth Score                                      float64
# Overall Achievement Score                               float64
# Read Score                                              float64
# Math Score                                              float64
# Science Score                                           float64
# Math I Score                                            float64
# English II Score                                        float64
# Biology Score                                           float64
# The ACT Score                                           float64
# ACT WorkKeys Score                                      float64
# Math Course Rigor Score                                 float64
# Cohort Graduation Rate Standard Score                   float64
# ACTCompositeScore_UNCMin_All                            float64
# ACTEnglish_ACTBenchmark_All                             float64
# ACTMath_ACTBenchmark_All                                float64
# ACTReading_ACTBenchmark_All                             float64
# ACTScience_ACTBenchmark_All                             float64
# ACTSubtests_BenchmarksMet_All                           float64
# ACTWorkKeys_SilverPlus_All                              float64
# ACTWriting_ACTBenchmark_All                             float64
# EOCBiology_CACR_All                                     float64
# EOCBiology_GLP_All                                      float64
# EOCEnglish2_CACR_All                                    float64
# EOCEnglish2_GLP_All                                     float64
# EOCMathI_CACR_All                                       float64
# EOCMathI_GLP_All                                        float64
# EOCSubjects_CACR_All                                    float64
# EOCSubjects_GLP_All                                     float64
# EOG/EOCSubjects_CACR_All                                float64
# EOG/EOCSubjects_GLP_All                                 float64
# EOGGr3_CACR_All                                         float64
# EOGGr3_GLP_All                                          float64
# EOGGr4_CACR_All                                         float64
# EOGGr4_GLP_All                                          float64
# EOGGr5_CACR_All                                         float64
# EOGGr5_GLP_All                                          float64
# EOGGr6_CACR_All                                         float64
# EOGGr6_GLP_All                                          float64
# EOGGr7_CACR_All                                         float64
# EOGGr7_GLP_All                                          float64
# EOGGr8_CACR_All                                         float64
# EOGGr8_GLP_All                                          float64
# EOGMathGr3_CACR_All                                     float64
# EOGMathGr3_GLP_All                                      float64
# EOGMathGr3-8_CACR_All                                   float64
# EOGMathGr3-8_GLP_All                                    float64
# EOGMathGr4_CACR_All                                     float64
# EOGMathGr4_GLP_All                                      float64
# EOGMathGr5_CACR_All                                     float64
# EOGMathGr5_GLP_All                                      float64
# EOGMathGr6_CACR_All                                     float64
# EOGMathGr6_GLP_All                                      float64
# EOGMathGr7_CACR_All                                     float64
# EOGMathGr7_GLP_All                                      float64
# EOGMathGr8_CACR_All                                     float64
# EOGMathGr8_GLP_All                                      float64
# EOGReadingGr3_CACR_All                                  float64
# EOGReadingGr3_GLP_All                                   float64
# EOGReadingGr3-8_CACR_All                                float64
# EOGReadingGr3-8_GLP_All                                 float64
# EOGReadingGr4_CACR_All                                  float64
# EOGReadingGr4_GLP_All                                   float64
# EOGReadingGr5_CACR_All                                  float64
# EOGReadingGr5_GLP_All                                   float64
# EOGReadingGr6_CACR_All                                  float64
# EOGReadingGr6_GLP_All                                   float64
# EOGReadingGr7_CACR_All                                  float64
# EOGReadingGr7_GLP_All                                   float64
# EOGReadingGr8_CACR_All                                  float64
# EOGReadingGr8_GLP_All                                   float64
# EOGScienceGr5_CACR_All                                  float64
# EOGScienceGr5_GLP_All                                   float64
# EOGScienceGr5&8_CACR_All                                float64
# EOGScienceGr5&8_GLP_All                                 float64
# EOGScienceGr8_CACR_All                                  float64
# EOGScienceGr8_GLP_All                                   float64
# EOGSubjects_CACR_All                                    float64
# EOGSubjects_GLP_All                                     float64
# GraduationRate_4yr_All                                  float64
# GraduationRate_5yr_All                                  float64
# ACTCompositeScore_UNCMin_Female                         float64
# ACTEnglish_ACTBenchmark_Female                          float64
# ACTMath_ACTBenchmark_Female                             float64
# ACTReading_ACTBenchmark_Female                          float64
# ACTScience_ACTBenchmark_Female                          float64
# ACTSubtests_BenchmarksMet_Female                        float64
# ACTWorkKeys_SilverPlus_Female                           float64
# ACTWriting_ACTBenchmark_Female                          float64
# EOCBiology_CACR_Female                                  float64
# EOCBiology_GLP_Female                                   float64
# EOCEnglish2_CACR_Female                                 float64
# EOCEnglish2_GLP_Female                                  float64
# EOCMathI_CACR_Female                                    float64
# EOCMathI_GLP_Female                                     float64
# EOCSubjects_CACR_Female                                 float64
# EOCSubjects_GLP_Female                                  float64
# EOG/EOCSubjects_CACR_Female                             float64
# EOG/EOCSubjects_GLP_Female                              float64
# EOGGr3_CACR_Female                                      float64
# EOGGr3_GLP_Female                                       float64
# EOGGr4_CACR_Female                                      float64
# EOGGr4_GLP_Female                                       float64
# EOGGr5_CACR_Female                                      float64
# EOGGr5_GLP_Female                                       float64
# EOGGr6_CACR_Female                                      float64
# EOGGr6_GLP_Female                                       float64
# EOGGr7_CACR_Female                                      float64
# EOGGr7_GLP_Female                                       float64
# EOGGr8_CACR_Female                                      float64
# EOGGr8_GLP_Female                                       float64
# EOGMathGr3_CACR_Female                                  float64
# EOGMathGr3_GLP_Female                                   float64
# EOGMathGr3-8_CACR_Female                                float64
# EOGMathGr3-8_GLP_Female                                 float64
# EOGMathGr4_CACR_Female                                  float64
# EOGMathGr4_GLP_Female                                   float64
# EOGMathGr5_CACR_Female                                  float64
# EOGMathGr5_GLP_Female                                   float64
# EOGMathGr6_CACR_Female                                  float64
# EOGMathGr6_GLP_Female                                   float64
# EOGMathGr7_CACR_Female                                  float64
# EOGMathGr7_GLP_Female                                   float64
# EOGMathGr8_CACR_Female                                  float64
# EOGMathGr8_GLP_Female                                   float64
# EOGReadingGr3_CACR_Female                               float64
# EOGReadingGr3_GLP_Female                                float64
# EOGReadingGr3-8_CACR_Female                             float64
# EOGReadingGr3-8_GLP_Female                              float64
# EOGReadingGr4_CACR_Female                               float64
# EOGReadingGr4_GLP_Female                                float64
# EOGReadingGr5_CACR_Female                               float64
# EOGReadingGr5_GLP_Female                                float64
# EOGReadingGr6_CACR_Female                               float64
# EOGReadingGr6_GLP_Female                                float64
# EOGReadingGr7_CACR_Female                               float64
# EOGReadingGr7_GLP_Female                                float64
# EOGReadingGr8_CACR_Female                               float64
# EOGReadingGr8_GLP_Female                                float64
# EOGScienceGr5_CACR_Female                               float64
# EOGScienceGr5_GLP_Female                                float64
# EOGScienceGr5&8_CACR_Female                             float64
# EOGScienceGr5&8_GLP_Female                              float64
# EOGScienceGr8_CACR_Female                               float64
# EOGScienceGr8_GLP_Female                                float64
# EOGSubjects_CACR_Female                                 float64
# EOGSubjects_GLP_Female                                  float64
# GraduationRate_4yr_Female                               float64
# GraduationRate_5yr_Female                               float64
# ACTCompositeScore_UNCMin_Male                           float64
# ACTEnglish_ACTBenchmark_Male                            float64
# ACTMath_ACTBenchmark_Male                               float64
# ACTReading_ACTBenchmark_Male                            float64
# ACTScience_ACTBenchmark_Male                            float64
# ACTSubtests_BenchmarksMet_Male                          float64
# ACTWorkKeys_SilverPlus_Male                             float64
# ACTWriting_ACTBenchmark_Male                            float64
# EOCBiology_CACR_Male                                    float64
# EOCBiology_GLP_Male                                     float64
# EOCEnglish2_CACR_Male                                   float64
# EOCEnglish2_GLP_Male                                    float64
# EOCMathI_CACR_Male                                      float64
# EOCMathI_GLP_Male                                       float64
# EOCSubjects_CACR_Male                                   float64
# EOCSubjects_GLP_Male                                    float64
# EOG/EOCSubjects_CACR_Male                               float64
# EOG/EOCSubjects_GLP_Male                                float64
# EOGGr3_CACR_Male                                        float64
# EOGGr3_GLP_Male                                         float64
# EOGGr4_CACR_Male                                        float64
# EOGGr4_GLP_Male                                         float64
# EOGGr5_CACR_Male                                        float64
# EOGGr5_GLP_Male                                         float64
# EOGGr6_CACR_Male                                        float64
# EOGGr6_GLP_Male                                         float64
# EOGGr7_CACR_Male                                        float64
# EOGGr7_GLP_Male                                         float64
# EOGGr8_CACR_Male                                        float64
# EOGGr8_GLP_Male                                         float64
# EOGMathGr3_CACR_Male                                    float64
# EOGMathGr3_GLP_Male                                     float64
# EOGMathGr3-8_CACR_Male                                  float64
# EOGMathGr3-8_GLP_Male                                   float64
# EOGMathGr4_CACR_Male                                    float64
# EOGMathGr4_GLP_Male                                     float64
# EOGMathGr5_CACR_Male                                    float64
# EOGMathGr5_GLP_Male                                     float64
# EOGMathGr6_CACR_Male                                    float64
# EOGMathGr6_GLP_Male                                     float64
# EOGMathGr7_CACR_Male                                    float64
# EOGMathGr7_GLP_Male                                     float64
# EOGMathGr8_CACR_Male                                    float64
# EOGMathGr8_GLP_Male                                     float64
# EOGReadingGr3_CACR_Male                                 float64
# EOGReadingGr3_GLP_Male                                  float64
# EOGReadingGr3-8_CACR_Male                               float64
# EOGReadingGr3-8_GLP_Male                                float64
# EOGReadingGr4_CACR_Male                                 float64
# EOGReadingGr4_GLP_Male                                  float64
# EOGReadingGr5_CACR_Male                                 float64
# EOGReadingGr5_GLP_Male                                  float64
# EOGReadingGr6_CACR_Male                                 float64
# EOGReadingGr6_GLP_Male                                  float64
# EOGReadingGr7_CACR_Male                                 float64
# EOGReadingGr7_GLP_Male                                  float64
# EOGReadingGr8_CACR_Male                                 float64
# EOGReadingGr8_GLP_Male                                  float64
# EOGScienceGr5_CACR_Male                                 float64
# EOGScienceGr5_GLP_Male                                  float64
# EOGScienceGr5&8_CACR_Male                               float64
# EOGScienceGr5&8_GLP_Male                                float64
# EOGScienceGr8_CACR_Male                                 float64
# EOGScienceGr8_GLP_Male                                  float64
# EOGSubjects_CACR_Male                                   float64
# EOGSubjects_GLP_Male                                    float64
# GraduationRate_4yr_Male                                 float64
# GraduationRate_5yr_Male                                 float64
# ACTCompositeScore_UNCMin_AmericanIndian                 float64
# ACTEnglish_ACTBenchmark_AmericanIndian                  float64
# ACTMath_ACTBenchmark_AmericanIndian                     float64
# ACTReading_ACTBenchmark_AmericanIndian                  float64
# ACTScience_ACTBenchmark_AmericanIndian                  float64
# ACTSubtests_BenchmarksMet_AmericanIndian                float64
# ACTWorkKeys_SilverPlus_AmericanIndian                   float64
# ACTWriting_ACTBenchmark_AmericanIndian                  float64
# EOCBiology_CACR_AmericanIndian                          float64
# EOCBiology_GLP_AmericanIndian                           float64
# EOCEnglish2_CACR_AmericanIndian                         float64
# EOCEnglish2_GLP_AmericanIndian                          float64
# EOCMathI_CACR_AmericanIndian                            float64
# EOCMathI_GLP_AmericanIndian                             float64
# EOCSubjects_CACR_AmericanIndian                         float64
# EOCSubjects_GLP_AmericanIndian                          float64
# EOG/EOCSubjects_CACR_AmericanIndian                     float64
# EOG/EOCSubjects_GLP_AmericanIndian                      float64
# EOGGr3_CACR_AmericanIndian                              float64
# EOGGr3_GLP_AmericanIndian                               float64
# EOGGr4_CACR_AmericanIndian                              float64
# EOGGr4_GLP_AmericanIndian                               float64
# EOGGr5_CACR_AmericanIndian                              float64
# EOGGr5_GLP_AmericanIndian                               float64
# EOGGr6_CACR_AmericanIndian                              float64
# EOGGr6_GLP_AmericanIndian                               float64
# EOGGr7_CACR_AmericanIndian                              float64
# EOGGr7_GLP_AmericanIndian                               float64
# EOGGr8_CACR_AmericanIndian                              float64
# EOGGr8_GLP_AmericanIndian                               float64
# EOGMathGr3_CACR_AmericanIndian                          float64
# EOGMathGr3_GLP_AmericanIndian                           float64
# EOGMathGr3-8_CACR_AmericanIndian                        float64
# EOGMathGr3-8_GLP_AmericanIndian                         float64
# EOGMathGr4_CACR_AmericanIndian                          float64
# EOGMathGr4_GLP_AmericanIndian                           float64
# EOGMathGr5_CACR_AmericanIndian                          float64
# EOGMathGr5_GLP_AmericanIndian                           float64
# EOGMathGr6_CACR_AmericanIndian                          float64
# EOGMathGr6_GLP_AmericanIndian                           float64
# EOGMathGr7_CACR_AmericanIndian                          float64
# EOGMathGr7_GLP_AmericanIndian                           float64
# EOGMathGr8_CACR_AmericanIndian                          float64
# EOGMathGr8_GLP_AmericanIndian                           float64
# EOGReadingGr3_CACR_AmericanIndian                       float64
# EOGReadingGr3_GLP_AmericanIndian                        float64
# EOGReadingGr3-8_CACR_AmericanIndian                     float64
# EOGReadingGr3-8_GLP_AmericanIndian                      float64
# EOGReadingGr4_CACR_AmericanIndian                       float64
# EOGReadingGr4_GLP_AmericanIndian                        float64
# EOGReadingGr5_CACR_AmericanIndian                       float64
# EOGReadingGr5_GLP_AmericanIndian                        float64
# EOGReadingGr6_CACR_AmericanIndian                       float64
# EOGReadingGr6_GLP_AmericanIndian                        float64
# EOGReadingGr7_CACR_AmericanIndian                       float64
# EOGReadingGr7_GLP_AmericanIndian                        float64
# EOGReadingGr8_CACR_AmericanIndian                       float64
# EOGReadingGr8_GLP_AmericanIndian                        float64
# EOGScienceGr5_CACR_AmericanIndian                       float64
# EOGScienceGr5_GLP_AmericanIndian                        float64
# EOGScienceGr5&8_CACR_AmericanIndian                     float64
# EOGScienceGr5&8_GLP_AmericanIndian                      float64
# EOGScienceGr8_CACR_AmericanIndian                       float64
# EOGScienceGr8_GLP_AmericanIndian                        float64
# EOGSubjects_CACR_AmericanIndian                         float64
# EOGSubjects_GLP_AmericanIndian                          float64
# GraduationRate_4yr_AmericanIndian                       float64
# GraduationRate_5yr_AmericanIndian                       float64
# ACTCompositeScore_UNCMin_Asian                          float64
# ACTEnglish_ACTBenchmark_Asian                           float64
# ACTMath_ACTBenchmark_Asian                              float64
# ACTReading_ACTBenchmark_Asian                           float64
# ACTScience_ACTBenchmark_Asian                           float64
# ACTSubtests_BenchmarksMet_Asian                         float64
# ACTWorkKeys_SilverPlus_Asian                            float64
# ACTWriting_ACTBenchmark_Asian                           float64
# EOCBiology_CACR_Asian                                   float64
# EOCBiology_GLP_Asian                                    float64
# EOCEnglish2_CACR_Asian                                  float64
# EOCEnglish2_GLP_Asian                                   float64
# EOCMathI_CACR_Asian                                     float64
# EOCMathI_GLP_Asian                                      float64
# EOCSubjects_CACR_Asian                                  float64
# EOCSubjects_GLP_Asian                                   float64
# EOG/EOCSubjects_CACR_Asian                              float64
# EOG/EOCSubjects_GLP_Asian                               float64
# EOGGr3_CACR_Asian                                       float64
# EOGGr3_GLP_Asian                                        float64
# EOGGr4_CACR_Asian                                       float64
# EOGGr4_GLP_Asian                                        float64
# EOGGr5_CACR_Asian                                       float64
# EOGGr5_GLP_Asian                                        float64
# EOGGr6_CACR_Asian                                       float64
# EOGGr6_GLP_Asian                                        float64
# EOGGr7_CACR_Asian                                       float64
# EOGGr7_GLP_Asian                                        float64
# EOGGr8_CACR_Asian                                       float64
# EOGGr8_GLP_Asian                                        float64
# EOGMathGr3_CACR_Asian                                   float64
# EOGMathGr3_GLP_Asian                                    float64
# EOGMathGr3-8_CACR_Asian                                 float64
# EOGMathGr3-8_GLP_Asian                                  float64
# EOGMathGr4_CACR_Asian                                   float64
# EOGMathGr4_GLP_Asian                                    float64
# EOGMathGr5_CACR_Asian                                   float64
# EOGMathGr5_GLP_Asian                                    float64
# EOGMathGr6_CACR_Asian                                   float64
# EOGMathGr6_GLP_Asian                                    float64
# EOGMathGr7_CACR_Asian                                   float64
# EOGMathGr7_GLP_Asian                                    float64
# EOGMathGr8_CACR_Asian                                   float64
# EOGMathGr8_GLP_Asian                                    float64
# EOGReadingGr3_CACR_Asian                                float64
# EOGReadingGr3_GLP_Asian                                 float64
# EOGReadingGr3-8_CACR_Asian                              float64
# EOGReadingGr3-8_GLP_Asian                               float64
# EOGReadingGr4_CACR_Asian                                float64
# EOGReadingGr4_GLP_Asian                                 float64
# EOGReadingGr5_CACR_Asian                                float64
# EOGReadingGr5_GLP_Asian                                 float64
# EOGReadingGr6_CACR_Asian                                float64
# EOGReadingGr6_GLP_Asian                                 float64
# EOGReadingGr7_CACR_Asian                                float64
# EOGReadingGr7_GLP_Asian                                 float64
# EOGReadingGr8_CACR_Asian                                float64
# EOGReadingGr8_GLP_Asian                                 float64
# EOGScienceGr5_CACR_Asian                                float64
# EOGScienceGr5_GLP_Asian                                 float64
# EOGScienceGr5&8_CACR_Asian                              float64
# EOGScienceGr5&8_GLP_Asian                               float64
# EOGScienceGr8_CACR_Asian                                float64
# EOGScienceGr8_GLP_Asian                                 float64
# EOGSubjects_CACR_Asian                                  float64
# EOGSubjects_GLP_Asian                                   float64
# GraduationRate_4yr_Asian                                float64
# GraduationRate_5yr_Asian                                float64
# ACTCompositeScore_UNCMin_Black                          float64
# ACTEnglish_ACTBenchmark_Black                           float64
# ACTMath_ACTBenchmark_Black                              float64
# ACTReading_ACTBenchmark_Black                           float64
# ACTScience_ACTBenchmark_Black                           float64
# ACTSubtests_BenchmarksMet_Black                         float64
# ACTWorkKeys_SilverPlus_Black                            float64
# ACTWriting_ACTBenchmark_Black                           float64
# EOCBiology_CACR_Black                                   float64
# EOCBiology_GLP_Black                                    float64
# EOCEnglish2_CACR_Black                                  float64
# EOCEnglish2_GLP_Black                                   float64
# EOCMathI_CACR_Black                                     float64
# EOCMathI_GLP_Black                                      float64
# EOCSubjects_CACR_Black                                  float64
# EOCSubjects_GLP_Black                                   float64
# EOG/EOCSubjects_CACR_Black                              float64
# EOG/EOCSubjects_GLP_Black                               float64
# EOGGr3_CACR_Black                                       float64
# EOGGr3_GLP_Black                                        float64
# EOGGr4_CACR_Black                                       float64
# EOGGr4_GLP_Black                                        float64
# EOGGr5_CACR_Black                                       float64
# EOGGr5_GLP_Black                                        float64
# EOGGr6_CACR_Black                                       float64
# EOGGr6_GLP_Black                                        float64
# EOGGr7_CACR_Black                                       float64
# EOGGr7_GLP_Black                                        float64
# EOGGr8_CACR_Black                                       float64
# EOGGr8_GLP_Black                                        float64
# EOGMathGr3_CACR_Black                                   float64
# EOGMathGr3_GLP_Black                                    float64
# EOGMathGr3-8_CACR_Black                                 float64
# EOGMathGr3-8_GLP_Black                                  float64
# EOGMathGr4_CACR_Black                                   float64
# EOGMathGr4_GLP_Black                                    float64
# EOGMathGr5_CACR_Black                                   float64
# EOGMathGr5_GLP_Black                                    float64
# EOGMathGr6_CACR_Black                                   float64
# EOGMathGr6_GLP_Black                                    float64
# EOGMathGr7_CACR_Black                                   float64
# EOGMathGr7_GLP_Black                                    float64
# EOGMathGr8_CACR_Black                                   float64
# EOGMathGr8_GLP_Black                                    float64
# EOGReadingGr3_CACR_Black                                float64
# EOGReadingGr3_GLP_Black                                 float64
# EOGReadingGr3-8_CACR_Black                              float64
# EOGReadingGr3-8_GLP_Black                               float64
# EOGReadingGr4_CACR_Black                                float64
# EOGReadingGr4_GLP_Black                                 float64
# EOGReadingGr5_CACR_Black                                float64
# EOGReadingGr5_GLP_Black                                 float64
# EOGReadingGr6_CACR_Black                                float64
# EOGReadingGr6_GLP_Black                                 float64
# EOGReadingGr7_CACR_Black                                float64
# EOGReadingGr7_GLP_Black                                 float64
# EOGReadingGr8_CACR_Black                                float64
# EOGReadingGr8_GLP_Black                                 float64
# EOGScienceGr5_CACR_Black                                float64
# EOGScienceGr5_GLP_Black                                 float64
# EOGScienceGr5&8_CACR_Black                              float64
# EOGScienceGr5&8_GLP_Black                               float64
# EOGScienceGr8_CACR_Black                                float64
# EOGScienceGr8_GLP_Black                                 float64
# EOGSubjects_CACR_Black                                  float64
# EOGSubjects_GLP_Black                                   float64
# GraduationRate_4yr_Black                                float64
# GraduationRate_5yr_Black                                float64
# ACTCompositeScore_UNCMin_Hispanic                       float64
# ACTEnglish_ACTBenchmark_Hispanic                        float64
# ACTMath_ACTBenchmark_Hispanic                           float64
# ACTReading_ACTBenchmark_Hispanic                        float64
# ACTScience_ACTBenchmark_Hispanic                        float64
# ACTSubtests_BenchmarksMet_Hispanic                      float64
# ACTWorkKeys_SilverPlus_Hispanic                         float64
# ACTWriting_ACTBenchmark_Hispanic                        float64
# EOCBiology_CACR_Hispanic                                float64
# EOCBiology_GLP_Hispanic                                 float64
# EOCEnglish2_CACR_Hispanic                               float64
# EOCEnglish2_GLP_Hispanic                                float64
# EOCMathI_CACR_Hispanic                                  float64
# EOCMathI_GLP_Hispanic                                   float64
# EOCSubjects_CACR_Hispanic                               float64
# EOCSubjects_GLP_Hispanic                                float64
# EOG/EOCSubjects_CACR_Hispanic                           float64
# EOG/EOCSubjects_GLP_Hispanic                            float64
# EOGGr3_CACR_Hispanic                                    float64
# EOGGr3_GLP_Hispanic                                     float64
# EOGGr4_CACR_Hispanic                                    float64
# EOGGr4_GLP_Hispanic                                     float64
# EOGGr5_CACR_Hispanic                                    float64
# EOGGr5_GLP_Hispanic                                     float64
# EOGGr6_CACR_Hispanic                                    float64
# EOGGr6_GLP_Hispanic                                     float64
# EOGGr7_CACR_Hispanic                                    float64
# EOGGr7_GLP_Hispanic                                     float64
# EOGGr8_CACR_Hispanic                                    float64
# EOGGr8_GLP_Hispanic                                     float64
# EOGMathGr3_CACR_Hispanic                                float64
# EOGMathGr3_GLP_Hispanic                                 float64
# EOGMathGr3-8_CACR_Hispanic                              float64
# EOGMathGr3-8_GLP_Hispanic                               float64
# EOGMathGr4_CACR_Hispanic                                float64
# EOGMathGr4_GLP_Hispanic                                 float64
# EOGMathGr5_CACR_Hispanic                                float64
# EOGMathGr5_GLP_Hispanic                                 float64
# EOGMathGr6_CACR_Hispanic                                float64
# EOGMathGr6_GLP_Hispanic                                 float64
# EOGMathGr7_CACR_Hispanic                                float64
# EOGMathGr7_GLP_Hispanic                                 float64
# EOGMathGr8_CACR_Hispanic                                float64
# EOGMathGr8_GLP_Hispanic                                 float64
# EOGReadingGr3_CACR_Hispanic                             float64
# EOGReadingGr3_GLP_Hispanic                              float64
# EOGReadingGr3-8_CACR_Hispanic                           float64
# EOGReadingGr3-8_GLP_Hispanic                            float64
# EOGReadingGr4_CACR_Hispanic                             float64
# EOGReadingGr4_GLP_Hispanic                              float64
# EOGReadingGr5_CACR_Hispanic                             float64
# EOGReadingGr5_GLP_Hispanic                              float64
# EOGReadingGr6_CACR_Hispanic                             float64
# EOGReadingGr6_GLP_Hispanic                              float64
# EOGReadingGr7_CACR_Hispanic                             float64
# EOGReadingGr7_GLP_Hispanic                              float64
# EOGReadingGr8_CACR_Hispanic                             float64
# EOGReadingGr8_GLP_Hispanic                              float64
# EOGScienceGr5_CACR_Hispanic                             float64
# EOGScienceGr5_GLP_Hispanic                              float64
# EOGScienceGr5&8_CACR_Hispanic                           float64
# EOGScienceGr5&8_GLP_Hispanic                            float64
# EOGScienceGr8_CACR_Hispanic                             float64
# EOGScienceGr8_GLP_Hispanic                              float64
# EOGSubjects_CACR_Hispanic                               float64
# EOGSubjects_GLP_Hispanic                                float64
# GraduationRate_4yr_Hispanic                             float64
# GraduationRate_5yr_Hispanic                             float64
# ACTCompositeScore_UNCMin_TwoorMoreRaces                 float64
# ACTEnglish_ACTBenchmark_TwoorMoreRaces                  float64
# ACTMath_ACTBenchmark_TwoorMoreRaces                     float64
# ACTReading_ACTBenchmark_TwoorMoreRaces                  float64
# ACTScience_ACTBenchmark_TwoorMoreRaces                  float64
# ACTSubtests_BenchmarksMet_TwoorMoreRaces                float64
# ACTWorkKeys_SilverPlus_TwoorMoreRaces                   float64
# ACTWriting_ACTBenchmark_TwoorMoreRaces                  float64
# EOCBiology_CACR_TwoorMoreRaces                          float64
# EOCBiology_GLP_TwoorMoreRaces                           float64
# EOCEnglish2_CACR_TwoorMoreRaces                         float64
# EOCEnglish2_GLP_TwoorMoreRaces                          float64
# EOCMathI_CACR_TwoorMoreRaces                            float64
# EOCMathI_GLP_TwoorMoreRaces                             float64
# EOCSubjects_CACR_TwoorMoreRaces                         float64
# EOCSubjects_GLP_TwoorMoreRaces                          float64
# EOG/EOCSubjects_CACR_TwoorMoreRaces                     float64
# EOG/EOCSubjects_GLP_TwoorMoreRaces                      float64
# EOGGr3_CACR_TwoorMoreRaces                              float64
# EOGGr3_GLP_TwoorMoreRaces                               float64
# EOGGr4_CACR_TwoorMoreRaces                              float64
# EOGGr4_GLP_TwoorMoreRaces                               float64
# EOGGr5_CACR_TwoorMoreRaces                              float64
# EOGGr5_GLP_TwoorMoreRaces                               float64
# EOGGr6_CACR_TwoorMoreRaces                              float64
# EOGGr6_GLP_TwoorMoreRaces                               float64
# EOGGr7_CACR_TwoorMoreRaces                              float64
# EOGGr7_GLP_TwoorMoreRaces                               float64
# EOGGr8_CACR_TwoorMoreRaces                              float64
# EOGGr8_GLP_TwoorMoreRaces                               float64
# EOGMathGr3_CACR_TwoorMoreRaces                          float64
# EOGMathGr3_GLP_TwoorMoreRaces                           float64
# EOGMathGr3-8_CACR_TwoorMoreRaces                        float64
# EOGMathGr3-8_GLP_TwoorMoreRaces                         float64
# EOGMathGr4_CACR_TwoorMoreRaces                          float64
# EOGMathGr4_GLP_TwoorMoreRaces                           float64
# EOGMathGr5_CACR_TwoorMoreRaces                          float64
# EOGMathGr5_GLP_TwoorMoreRaces                           float64
# EOGMathGr6_CACR_TwoorMoreRaces                          float64
# EOGMathGr6_GLP_TwoorMoreRaces                           float64
# EOGMathGr7_CACR_TwoorMoreRaces                          float64
# EOGMathGr7_GLP_TwoorMoreRaces                           float64
# EOGMathGr8_CACR_TwoorMoreRaces                          float64
# EOGMathGr8_GLP_TwoorMoreRaces                           float64
# EOGReadingGr3_CACR_TwoorMoreRaces                       float64
# EOGReadingGr3_GLP_TwoorMoreRaces                        float64
# EOGReadingGr3-8_CACR_TwoorMoreRaces                     float64
# EOGReadingGr3-8_GLP_TwoorMoreRaces                      float64
# EOGReadingGr4_CACR_TwoorMoreRaces                       float64
# EOGReadingGr4_GLP_TwoorMoreRaces                        float64
# EOGReadingGr5_CACR_TwoorMoreRaces                       float64
# EOGReadingGr5_GLP_TwoorMoreRaces                        float64
# EOGReadingGr6_CACR_TwoorMoreRaces                       float64
# EOGReadingGr6_GLP_TwoorMoreRaces                        float64
# EOGReadingGr7_CACR_TwoorMoreRaces                       float64
# EOGReadingGr7_GLP_TwoorMoreRaces                        float64
# EOGReadingGr8_CACR_TwoorMoreRaces                       float64
# EOGReadingGr8_GLP_TwoorMoreRaces                        float64
# EOGScienceGr5_CACR_TwoorMoreRaces                       float64
# EOGScienceGr5_GLP_TwoorMoreRaces                        float64
# EOGScienceGr5&8_CACR_TwoorMoreRaces                     float64
# EOGScienceGr5&8_GLP_TwoorMoreRaces                      float64
# EOGScienceGr8_CACR_TwoorMoreRaces                       float64
# EOGScienceGr8_GLP_TwoorMoreRaces                        float64
# EOGSubjects_CACR_TwoorMoreRaces                         float64
# EOGSubjects_GLP_TwoorMoreRaces                          float64
# GraduationRate_4yr_TwoorMoreRaces                       float64
# GraduationRate_5yr_TwoorMoreRaces                       float64
# ACTCompositeScore_UNCMin_White                          float64
# ACTEnglish_ACTBenchmark_White                           float64
# ACTMath_ACTBenchmark_White                              float64
# ACTReading_ACTBenchmark_White                           float64
# ACTScience_ACTBenchmark_White                           float64
# ACTSubtests_BenchmarksMet_White                         float64
# ACTWorkKeys_SilverPlus_White                            float64
# ACTWriting_ACTBenchmark_White                           float64
# EOCBiology_CACR_White                                   float64
# EOCBiology_GLP_White                                    float64
# EOCEnglish2_CACR_White                                  float64
# EOCEnglish2_GLP_White                                   float64
# EOCMathI_CACR_White                                     float64
# EOCMathI_GLP_White                                      float64
# EOCSubjects_CACR_White                                  float64
# EOCSubjects_GLP_White                                   float64
# EOG/EOCSubjects_CACR_White                              float64
# EOG/EOCSubjects_GLP_White                               float64
# EOGGr3_CACR_White                                       float64
# EOGGr3_GLP_White                                        float64
# EOGGr4_CACR_White                                       float64
# EOGGr4_GLP_White                                        float64
# EOGGr5_CACR_White                                       float64
# EOGGr5_GLP_White                                        float64
# EOGGr6_CACR_White                                       float64
# EOGGr6_GLP_White                                        float64
# EOGGr7_CACR_White                                       float64
# EOGGr7_GLP_White                                        float64
# EOGGr8_CACR_White                                       float64
# EOGGr8_GLP_White                                        float64
# EOGMathGr3_CACR_White                                   float64
# EOGMathGr3_GLP_White                                    float64
# EOGMathGr3-8_CACR_White                                 float64
# EOGMathGr3-8_GLP_White                                  float64
# EOGMathGr4_CACR_White                                   float64
# EOGMathGr4_GLP_White                                    float64
# EOGMathGr5_CACR_White                                   float64
# EOGMathGr5_GLP_White                                    float64
# EOGMathGr6_CACR_White                                   float64
# EOGMathGr6_GLP_White                                    float64
# EOGMathGr7_CACR_White                                   float64
# EOGMathGr7_GLP_White                                    float64
# EOGMathGr8_CACR_White                                   float64
# EOGMathGr8_GLP_White                                    float64
# EOGReadingGr3_CACR_White                                float64
# EOGReadingGr3_GLP_White                                 float64
# EOGReadingGr3-8_CACR_White                              float64
# EOGReadingGr3-8_GLP_White                               float64
# EOGReadingGr4_CACR_White                                float64
# EOGReadingGr4_GLP_White                                 float64
# EOGReadingGr5_CACR_White                                float64
# EOGReadingGr5_GLP_White                                 float64
# EOGReadingGr6_CACR_White                                float64
# EOGReadingGr6_GLP_White                                 float64
# EOGReadingGr7_CACR_White                                float64
# EOGReadingGr7_GLP_White                                 float64
# EOGReadingGr8_CACR_White                                float64
# EOGReadingGr8_GLP_White                                 float64
# EOGScienceGr5_CACR_White                                float64
# EOGScienceGr5_GLP_White                                 float64
# EOGScienceGr5&8_CACR_White                              float64
# EOGScienceGr5&8_GLP_White                               float64
# EOGScienceGr8_CACR_White                                float64
# EOGScienceGr8_GLP_White                                 float64
# EOGSubjects_CACR_White                                  float64
# EOGSubjects_GLP_White                                   float64
# GraduationRate_4yr_White                                float64
# GraduationRate_5yr_White                                float64
# ACTCompositeScore_UNCMin_EDS                            float64
# ACTEnglish_ACTBenchmark_EDS                             float64
# ACTMath_ACTBenchmark_EDS                                float64
# ACTReading_ACTBenchmark_EDS                             float64
# ACTScience_ACTBenchmark_EDS                             float64
# ACTSubtests_BenchmarksMet_EDS                           float64
# ACTWorkKeys_SilverPlus_EDS                              float64
# ACTWriting_ACTBenchmark_EDS                             float64
# EOCBiology_CACR_EDS                                     float64
# EOCBiology_GLP_EDS                                      float64
# EOCEnglish2_CACR_EDS                                    float64
# EOCEnglish2_GLP_EDS                                     float64
# EOCMathI_CACR_EDS                                       float64
# EOCMathI_GLP_EDS                                        float64
# EOCSubjects_CACR_EDS                                    float64
# EOCSubjects_GLP_EDS                                     float64
# EOG/EOCSubjects_CACR_EDS                                float64
# EOG/EOCSubjects_GLP_EDS                                 float64
# EOGGr3_CACR_EDS                                         float64
# EOGGr3_GLP_EDS                                          float64
# EOGGr4_CACR_EDS                                         float64
# EOGGr4_GLP_EDS                                          float64
# EOGGr5_CACR_EDS                                         float64
# EOGGr5_GLP_EDS                                          float64
# EOGGr6_CACR_EDS                                         float64
# EOGGr6_GLP_EDS                                          float64
# EOGGr7_CACR_EDS                                         float64
# EOGGr7_GLP_EDS                                          float64
# EOGGr8_CACR_EDS                                         float64
# EOGGr8_GLP_EDS                                          float64
# EOGMathGr3_CACR_EDS                                     float64
# EOGMathGr3_GLP_EDS                                      float64
# EOGMathGr3-8_CACR_EDS                                   float64
# EOGMathGr3-8_GLP_EDS                                    float64
# EOGMathGr4_CACR_EDS                                     float64
# EOGMathGr4_GLP_EDS                                      float64
# EOGMathGr5_CACR_EDS                                     float64
# EOGMathGr5_GLP_EDS                                      float64
# EOGMathGr6_CACR_EDS                                     float64
# EOGMathGr6_GLP_EDS                                      float64
# EOGMathGr7_CACR_EDS                                     float64
# EOGMathGr7_GLP_EDS                                      float64
# EOGMathGr8_CACR_EDS                                     float64
# ...
# st_ap_participation_pct                                 float64
# ap_pct_3_or_above                                       float64
# lea_ap_pct_3_or_above                                   float64
# st_ap_pct_3_or_above                                    float64
# ib_participation_pct                                    float64
# lea_ib_participation_pct                                float64
# st_ib_participation_pct                                 float64
# ib_pct_4_or_above                                       float64
# lea_ib_pct_4_or_above                                   float64
# st_ib_pct_4_or_above                                    float64
# total_specialized_courses                               float64
# ap_ib_courses                                           float64
# cte_courses                                             float64
# univ_college_courses                                    float64
# lea_total_specialized_courses                           float64
# lea_ap_ib_courses                                       float64
# lea_cte_courses                                         float64
# lea_univ_college_courses                                float64
# st_total_specialized_courses                            float64
# st_ap_ib_courses                                        float64
# st_cte_courses                                          float64
# st_univ_college_courses                                 float64
# AM7_American Indian_ENROLL_sch_pct                      float64
# AM7_American Indian_NOENROLL_sch_pct                    float64
# AS7_Asian_ENROLL_sch_pct                                float64
# AS7_Asian_NOENROLL_sch_pct                              float64
# All_All Student (Total or subtotal)_ENROLL_sch_pct      float64
# All_All Student (Total or subtotal)_NOENROLL_sch_pct    float64
# BL7_Black_ENROLL_sch_pct                                float64
# BL7_Black_NOENROLL_sch_pct                              float64
# ECODIS_Economically Disadvantaged_ENROLL_sch_pct        float64
# ECODIS_Economically Disadvantaged_NOENROLL_sch_pct      float64
# F_Female_ENROLL_sch_pct                                 float64
# F_Female_NOENROLL_sch_pct                               float64
# HI7_Hispanic_ENROLL_sch_pct                             float64
# HI7_Hispanic_NOENROLL_sch_pct                           float64
# LEP_Limited English Proficiency_ENROLL_sch_pct          float64
# LEP_Limited English Proficiency_NOENROLL_sch_pct        float64
# M_Male_ENROLL_sch_pct                                   float64
# M_Male_NOENROLL_sch_pct                                 float64
# MU7_Multiracial_ENROLL_sch_pct                          float64
# MU7_Multiracial_NOENROLL_sch_pct                        float64
# PI7_Pacific Islander_ENROLL_sch_pct                     float64
# PI7_Pacific Islander_NOENROLL_sch_pct                   float64
# WDIS_Students with Disabilities_ENROLL_sch_pct          float64
# WDIS_Students with Disabilities_NOENROLL_sch_pct        float64
# WH7_White_ENROLL_sch_pct                                float64
# WH7_White_NOENROLL_sch_pct                              float64
# avg_daily_attend_pct                                    float64
# crime_per_c_num                                         float64
# short_susp_per_c_num                                    float64
# long_susp_per_c_num                                     float64
# expelled_per_c_num                                      float64
# ttl_crimes_num                                          float64
# stud_internet_comp_num                                  float64
# lea_avg_daily_attend_pct                                float64
# lea_crime_per_c_num                                     float64
# lea_short_susp_per_c_num                                float64
# lea_long_susp_per_c_num                                 float64
# lea_expelled_per_c_num                                  float64
# lea_stud_internet_comp_num                              float64
# st_avg_daily_attend_pct                                 float64
# st_crime_per_c_num                                      float64
# st_short_susp_per_c_num                                 float64
# st_long_susp_per_c_num                                  float64
# st_expelled_per_c_num                                   float64
# st_stud_internet_comp_num                               float64
# digital_media_pct                                       float64
# Byod                                                    float64
# grades_BYOD                                             float64
# avg_age_media_collection                                float64
# _1_to_1_access                                          float64
# books_per_student                                       float64
# grades_1_to_1_access                                    float64
# lea_avg_age_media_collection                            float64
# lea_books_per_student                                   float64
# st_avg_age_media_collection                             float64
# st_books_per_student                                    float64
# wap_num                                                 float64
# wap_per_classroom                                       float64
# lea_wap_num                                             float64
# lea_wap_per_classroom                                   float64
# st_wap_num                                              float64
# st_wap_per_classroom                                    float64
# SRC_devices_sent_home                                   float64
# SRC_Grades_Devices_Sent_Home                            float64
# total_class_teacher_num                                 int64
# total_nbpts_num                                         int64
# prin_other_pct                                          float64
# prinyrs_0thru3_pct                                      float64
# prinyrs_4thru10_pct                                     float64
# prinyrs_11plus_pct                                      float64
# prin_advance_dgr_pct                                    float64
# _1yr_prin_trnovr_pct                                    float64
# prin_male_pct                                           float64
# prin_female_pct                                         float64
# prin_black_pct                                          float64
# prin_white_pct                                          float64
# flicensed_teach_pct                                     float64
# tchyrs_0thru3_pct                                       float64
# tchyrs_4thru10_pct                                      float64
# tchyrs_11plus_pct                                       float64
# class_teach_num                                         float64
# nbpts_num                                               float64
# advance_dgr_pct                                         float64
# _1yr_tchr_trnovr_pct                                    float64
# emer_prov_teach_pct                                     float64
# lateral_teach_pct                                       float64
# highqual_class_pct                                      float64
# lea_flicensed_teach_pct                                 float64
# lea_tchyrs_0thru3_pct                                   float64
# lea_tchyrs_4thru10_pct                                  float64
# lea_tchyrs_11plus_pct                                   float64
# lea_class_teach_num                                     float64
# lea_nbpts_num                                           float64
# lea_advance_dgr_pct                                     float64
# lea_1yr_tchr_trnovr_pct                                 float64
# lea_emer_prov_teach_pct                                 float64
# lea_lateral_teach_pct                                   float64
# lea_highqual_class_pct                                  float64
# lea_highqual_class_hp_pct                               float64
# lea_highqual_class_lp_pct                               float64
# lea_highqual_class_all_pct                              float64
# lea_not_highqual_class_hp_pct                           float64
# lea_not_highqual_class_lp_pct                           float64
# lea_not_highqual_class_all_pct                          float64
# st_flicensed_teach_pct                                  float64
# st_tchyrs_0thru3_pct                                    float64
# st_tchyrs_4thru10_pct                                   float64
# st_tchyrs_11plus_pct                                    float64
# st_class_teach_num                                      float64
# st_nbpts_num                                            float64
# st_advance_dgr_pct                                      float64
# st_1yr_tchr_trnovr_pct                                  float64
# st_emer_prov_teach_pct                                  float64
# st_lateral_teach_pct                                    float64
# st_highqual_class_pct                                   float64
# st_highqual_class_hp_pct                                float64
# st_highqual_class_lp_pct                                float64
# st_highqual_class_all_pct                               float64
# st_not_highqual_class_hp_pct                            float64
# st_not_highqual_class_lp_pct                            float64
# st_not_highqual_class_all_pct                           float64
# st_prinyrs_0thru3_pct                                   float64
# st_prinyrs_4thru10_pct                                  float64
# st_prinyrs_11plus_pct                                   float64
# st_prin_advance_dgr_pct                                 float64
# st_1yr_prin_trnovr_pct                                  float64
# st_prin_male_pct                                        float64
# st_prin_female_pct                                      float64
# st_prin_black_pct                                       float64
# st_prin_white_pct                                       float64
# st_prin_other_pct                                       float64
# 0-3 Years_Exp_Pct_Tch                                   float64
# 10+ Years_Exp_Pct_Tch                                   float64
# 4-10 Years_Exp_Pct_Tch                                  float64
# 0-3 Years_LEA_Exp_Pct_Prin                              float64
# 10+ Years_LEA_Exp_Pct_Prin                              float64
# 4-10 Years_LEA_Exp_Pct_Prin                             float64
# Accomplished_PRIN_Standard 1_Pct                        float64
# Accomplished_PRIN_Standard 2_Pct                        float64
# Accomplished_PRIN_Standard 3_Pct                        float64
# Accomplished_PRIN_Standard 4_Pct                        float64
# Accomplished_PRIN_Standard 5_Pct                        float64
# Accomplished_PRIN_Standard 6_Pct                        float64
# Accomplished_PRIN_Standard 7_Pct                        float64
# Accomplished_TCHR_Standard 1_Pct                        float64
# Accomplished_TCHR_Standard 2_Pct                        float64
# Accomplished_TCHR_Standard 3_Pct                        float64
# Accomplished_TCHR_Standard 4_Pct                        float64
# Accomplished_TCHR_Standard 5_Pct                        float64
# Developing_PRIN_Standard 1_Pct                          float64
# Developing_PRIN_Standard 2_Pct                          float64
# Developing_PRIN_Standard 3_Pct                          float64
# Developing_PRIN_Standard 4_Pct                          float64
# Developing_PRIN_Standard 5_Pct                          float64
# Developing_PRIN_Standard 6_Pct                          float64
# Developing_PRIN_Standard 7_Pct                          float64
# Developing_TCHR_Standard 1_Pct                          float64
# Developing_TCHR_Standard 2_Pct                          float64
# Developing_TCHR_Standard 3_Pct                          float64
# Developing_TCHR_Standard 4_Pct                          float64
# Developing_TCHR_Standard 5_Pct                          float64
# Distinguished_PRIN_Standard 1_Pct                       float64
# Distinguished_PRIN_Standard 2_Pct                       float64
# Distinguished_PRIN_Standard 3_Pct                       float64
# Distinguished_PRIN_Standard 4_Pct                       float64
# Distinguished_PRIN_Standard 5_Pct                       float64
# Distinguished_PRIN_Standard 6_Pct                       float64
# Distinguished_PRIN_Standard 7_Pct                       float64
# Distinguished_TCHR_Standard 1_Pct                       float64
# Distinguished_TCHR_Standard 2_Pct                       float64
# Distinguished_TCHR_Standard 3_Pct                       float64
# Distinguished_TCHR_Standard 4_Pct                       float64
# Distinguished_TCHR_Standard 5_Pct                       float64
# Does Not Meet Expected Growth_PRIN_Standard 8_Pct       float64
# Does Not Meet Expected Growth_TCHR_Standard 6_Pct       float64
# Exceeds Expected Growth_PRIN_Standard 8_Pct             float64
# Exceeds Expected Growth_TCHR_Standard 6_Pct             float64
# Meets Expected Growth_PRIN_Standard 8_Pct               float64
# Meets Expected Growth_TCHR_Standard 6_Pct               float64
# Not Demostrated_PRIN_Standard 1_Pct                     float64
# Not Demostrated_PRIN_Standard 2_Pct                     float64
# Not Demostrated_PRIN_Standard 3_Pct                     float64
# Not Demostrated_PRIN_Standard 4_Pct                     float64
# Not Demostrated_PRIN_Standard 5_Pct                     float64
# Not Demostrated_PRIN_Standard 6_Pct                     float64
# Not Demostrated_PRIN_Standard 7_Pct                     float64
# Not Demostrated_TCHR_Standard 1_Pct                     float64
# Not Demostrated_TCHR_Standard 2_Pct                     float64
# Not Demostrated_TCHR_Standard 3_Pct                     float64
# Not Demostrated_TCHR_Standard 4_Pct                     float64
# Not Demostrated_TCHR_Standard 5_Pct                     float64
# Proficient_PRIN_Standard 1_Pct                          float64
# Proficient_PRIN_Standard 2_Pct                          float64
# Proficient_PRIN_Standard 3_Pct                          float64
# Proficient_PRIN_Standard 4_Pct                          float64
# Proficient_PRIN_Standard 5_Pct                          float64
# Proficient_PRIN_Standard 6_Pct                          float64
# Proficient_PRIN_Standard 7_Pct                          float64
# Proficient_TCHR_Standard 1_Pct                          float64
# Proficient_TCHR_Standard 2_Pct                          float64
# Proficient_TCHR_Standard 3_Pct                          float64
# Proficient_TCHR_Standard 4_Pct                          float64
# Proficient_TCHR_Standard 5_Pct                          float64
# AsianFemalePct                                          float64
# AsianMalePct                                            float64
# AsianPct                                                float64
# BlackFemalePct                                          float64
# BlackMalePct                                            float64
# BlackPct                                                float64
# HispanicFemalePct                                       float64
# HispanicMalePct                                         float64
# HispanicPct                                             float64
# IndianFemalePct                                         float64
# IndianMalePct                                           float64
# IndianPct                                               float64
# MinorityFemalePct                                       float64
# MinorityMalePct                                         float64
# MinorityPct                                             float64
# PacificIslandFemalePct                                  float64
# PacificIslandMalePct                                    float64
# PacificIslandPct                                        float64
# TwoOrMoreFemalePct                                      float64
# TwoOrMoreMalePct                                        float64
# TwoOrMorePct                                            float64
# WhiteFemalePct                                          float64
# WhiteMalePct                                            float64
# WhitePct                                                float64
# dtypes: float64(1225), int64(3), object(31)
# memory usage: 5.2+ MB

# %%
#Get Student Body Racial Composition Fields
raceCompositionFields = schoolData.filter(regex='Indian|Asian|Hispanic|Black|White|PacificIsland|TwoOrMore|Minority')\
                                  .filter(regex='Pct').columns
    
rowsBefore = schoolData[raceCompositionFields].isnull().T.any().T.sum()

#Update missing race values with the district average when avaiable (No district averages for charter schools) 
schoolData[raceCompositionFields] = schoolData.groupby('District Name')[raceCompositionFields]\
                                              .transform(lambda x: x.fillna(x.mean()))

    #Review dataset contents after Racial Composition Imputation
print('*********After: Updating Missing Racial Compostion Values****************************')   
rowsAfter = schoolData[raceCompositionFields].isnull().T.any().T.sum()
rowsUpdated = rowsBefore - rowsAfter
print 'Rows Updated / Imputed: ', rowsUpdated 
print('\r\nTotal Rows Missing Racial Compositions By District Name') 
schoolData['District Name'][schoolData[raceCompositionFields].isnull().T.any().T].value_counts()
# Out:
# *********After: Updating Missing Racial Compostion Values****************************
# Rows Updated / Imputed:  0
#
# Total Rows Missing Racial Compositions By District Name
# Series([], Name: District Name, dtype: int64)

# %% [markdown]
# ## Remove Columns with Problematic Data
# **Here we remove entire columns that could cause problems during machine learning.  The following operations are performed:**
# * Remove any columns that have the same value in every single row.
# * Remove any columns that have a unique value in every single row (all values are different).
# * Remove empty columns (all values are NA or NULL).

# %%
#Remove any fields that have the same value in all rows
UniqueValueCounts = schoolData.nunique(dropna=False)
SingleValueCols = UniqueValueCounts[UniqueValueCounts == 1].index
schoolData = schoolData.drop(SingleValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with the same value in every row.*******************')
schoolData.info(verbose=False)
print '\r\nColumns Deleted: ', len(SingleValueCols)
# Out:
# *********After: Removing columns with the same value in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 538 entries, 0 to 537
# Columns: 1108 entries, vphone_ad to WhitePct
# dtypes: float64(1082), object(26)
# memory usage: 4.6+ MB
#
# Columns Deleted:  151

# %%
#Remove any fields that have unique values in every row
schoolDataRecordCt = schoolData.shape[0]
UniqueValueCounts = schoolData.apply(pd.Series.nunique)
AllUniqueValueCols = UniqueValueCounts[UniqueValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(AllUniqueValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with unique values in every row.*******************')
schoolData.info(verbose=False)
print '\r\nColumns Deleted: ', len(AllUniqueValueCols)
# Out:
# *********After: Removing columns with unique values in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 538 entries, 0 to 537
# Columns: 1105 entries, vphone_ad to WhitePct
# dtypes: float64(1082), object(23)
# memory usage: 4.6+ MB
#
# Columns Deleted:  3

# %%
#Remove any empty fields (null values in every row)
schoolDataRecordCt = schoolData.shape[0]
NullValueCounts = schoolData.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with null / blank values in every row.*************')
schoolData.info(verbose=False)
print '\r\nColumns Deleted: ', len(NullValueCols)
# Out:
# *********After: Removing columns with null / blank values in every row.*************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 538 entries, 0 to 537
# Columns: 1105 entries, vphone_ad to WhitePct
# dtypes: float64(1082), object(23)
# memory usage: 4.5+ MB
#
# Columns Deleted:  0

# %% [markdown]
# ## Handle Other Missing Values Types
# * Here we eliminate any numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# * All remaining non-race, numeric column missing values are populated with 0.
# * In many cases, it seems that schools are not simply not reporting values when they are zero. However, mean imputation or some other strategy might be considered.

# %%
#Isolate continuous and categorical data types
#These are indexers into the schoolData dataframe and may be used similar to the schoolData dataframe 
sD_boolean = schoolData.loc[:, (schoolData.dtypes == bool) ]
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]
sD_continuous = schoolData.loc[:, (schoolData.dtypes != bool) & (schoolData.dtypes != object)]
print "Boolean Columns: ", sD_boolean.shape[1]
print "Nominal Columns: ", sD_nominal.shape[1]
print "Continuous Columns: ", sD_continuous.shape[1]
print "Columns Accounted for: ", sD_nominal.shape[1] + sD_continuous.shape[1] + sD_boolean.shape[1]
# Out:
# Boolean Columns:  0
# Nominal Columns:  23
# Continuous Columns:  1082
# Columns Accounted for:  1105

# %%
#Eliminate continuous columns with more than missingThreshold percentage of missing values
schoolDataRecordCt = sD_continuous.shape[0]
missingValueLimit = schoolDataRecordCt * missingThreshold
NullValueCounts = sD_continuous.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts >= missingValueLimit].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with >= missingThreshold % of missing values******')
schoolData.info(verbose=False)
print '\r\nColumns Deleted: ', len(NullValueCols)
# Out:
# *********After: Removing columns with >= missingThreshold % of missing values******
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 538 entries, 0 to 537
# Columns: 598 entries, vphone_ad to WhitePct
# dtypes: float64(575), object(23)
# memory usage: 2.5+ MB
#
# Columns Deleted:  507

# %% [markdown]
# ## One-Hot Encoding of Categorical Variables
# **All categorical / string variables are converted to numberic variables via one hot encoding.  Each unique row value will become a new binary / numeric column in the dataset.**
# * All remaining categorical columns are one-hot encoded.
# * In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# * Prior to one-hot encoding, columns with > *uniqueThreshold* unique values are deleted.

# %%
#Delete categorical columns with > 25 unique values (Each unique value becomes a column during one-hot encoding)
oneHotUniqueValueCounts = schoolData[sD_nominal.columns].apply(lambda x: x.nunique())
oneHotUniqueValueCols = oneHotUniqueValueCounts[oneHotUniqueValueCounts >= uniqueThreshold].index
schoolData.drop(oneHotUniqueValueCols, axis=1, inplace=True) 

#Review dataset contents one hot high unique value drops
print('*********After: Removing columns with >= uniqueThreshold unique values***********')
schoolData.info(verbose=False)
print '\r\nColumns Deleted: ', len(oneHotUniqueValueCols)
# Out:
# *********After: Removing columns with >= uniqueThreshold unique values***********
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 538 entries, 0 to 537
# Columns: 590 entries, category_cd to WhitePct
# dtypes: float64(575), object(15)
# memory usage: 2.4+ MB
#
# Columns Deleted:  8

# %%
#Isolate remaining categorical variables
begColumnCt = len(schoolData.columns)
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]

#one hot encode categorical variables
schoolData = pd.get_dummies(data=schoolData, 
                       columns=sD_nominal, drop_first=True)

#Determine change in column count
endColumnCt = len(schoolData.columns)
columnsAdded = endColumnCt - begColumnCt

#Review dataset contents one hot high unique value drops
print 'Columns To One-Hot Encode: ', len(sD_nominal.columns)
print('\r\n*********After: Adding New Columns Via One-Hot Encoding*************************')
schoolData.info(verbose=False)
print '\r\nNew Columns Created Via One-Hot Encoding: ', columnsAdded
# Out:
# Columns To One-Hot Encode:  15
#
# *********After: Adding New Columns Via One-Hot Encoding*************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 538 entries, 0 to 537
# Columns: 623 entries, student_num to esea_attendance_Met
# dtypes: float64(575), uint8(48)
# memory usage: 2.4 MB
#
# New Columns Created Via One-Hot Encoding:  33

# %% [markdown]
# ## Impute any Remaining Missing Values as Zero

# %%
#Print out all the missing value rows
pd.set_option('display.max_rows', 1000)

print('\r\n*********The Remaining Missing Values Below will be set to Zero!*************************')

#Check for Missing values 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# *********The Remaining Missing Values Below will be set to Zero!*************************
#                                          Variable Name  Number Missing Values
# 3                                          Math I_Size                     53
# 15                                  Reading  SPG Score                      2
# 16                                      Math SPG Score                      2
# 19                                          Read Score                      2
# 20                                          Math Score                      2
# 21                                       Science Score                      7
# 22                                        Math I Score                     52
# 23                                   EOCMathI_CACR_All                     52
# 24                                    EOCMathI_GLP_All                     52
# 25                                EOCSubjects_CACR_All                     52
# 26                                 EOCSubjects_GLP_All                     52
# 29                                     EOGGr6_CACR_All                     35
# 30                                      EOGGr6_GLP_All                     35
# 31                                     EOGGr7_CACR_All                     18
# 32                                      EOGGr7_GLP_All                     18
# 33                                     EOGGr8_CACR_All                     20
# 34                                      EOGGr8_GLP_All                     20
# 35                               EOGMathGr3-8_CACR_All                      2
# 36                                EOGMathGr3-8_GLP_All                      2
# 37                                 EOGMathGr6_CACR_All                     36
# 38                                  EOGMathGr6_GLP_All                     36
# 39                                 EOGMathGr7_CACR_All                     19
# 40                                  EOGMathGr7_GLP_All                     19
# 41                                 EOGMathGr8_CACR_All                     20
# 42                                  EOGMathGr8_GLP_All                     20
# 43                            EOGReadingGr3-8_CACR_All                      2
# 44                             EOGReadingGr3-8_GLP_All                      2
# 45                              EOGReadingGr6_CACR_All                     36
# 46                               EOGReadingGr6_GLP_All                     36
# 47                              EOGReadingGr7_CACR_All                     19
# 48                               EOGReadingGr7_GLP_All                     19
# 49                              EOGReadingGr8_CACR_All                     20
# 50                               EOGReadingGr8_GLP_All                     20
# 51                            EOGScienceGr5&8_CACR_All                      7
# 52                             EOGScienceGr5&8_GLP_All                      7
# 53                              EOGScienceGr8_CACR_All                     20
# 54                               EOGScienceGr8_GLP_All                     20
# 55                                EOGSubjects_CACR_All                      2
# 56                                 EOGSubjects_GLP_All                      2
# 57                                EOCMathI_CACR_Female                     52
# 58                                 EOCMathI_GLP_Female                     52
# 59                             EOCSubjects_CACR_Female                     52
# 60                              EOCSubjects_GLP_Female                     52
# 63                                  EOGGr6_CACR_Female                     35
# 64                                   EOGGr6_GLP_Female                     35
# 65                                  EOGGr7_CACR_Female                     18
# 66                                   EOGGr7_GLP_Female                     18
# 67                                  EOGGr8_CACR_Female                     20
# 68                                   EOGGr8_GLP_Female                     20
# 69                            EOGMathGr3-8_CACR_Female                      2
# 70                             EOGMathGr3-8_GLP_Female                      2
# 71                              EOGMathGr6_CACR_Female                     36
# 72                               EOGMathGr6_GLP_Female                     36
# 73                              EOGMathGr7_CACR_Female                     19
# 74                               EOGMathGr7_GLP_Female                     19
# 75                              EOGMathGr8_CACR_Female                     20
# 76                               EOGMathGr8_GLP_Female                     20
# 77                         EOGReadingGr3-8_CACR_Female                      2
# 78                          EOGReadingGr3-8_GLP_Female                      2
# 79                           EOGReadingGr6_CACR_Female                     36
# 80                            EOGReadingGr6_GLP_Female                     36
# 81                           EOGReadingGr7_CACR_Female                     19
# 82                            EOGReadingGr7_GLP_Female                     19
# 83                           EOGReadingGr8_CACR_Female                     20
# 84                            EOGReadingGr8_GLP_Female                     20
# 85                         EOGScienceGr5&8_CACR_Female                      7
# 86                          EOGScienceGr5&8_GLP_Female                      7
# 87                           EOGScienceGr8_CACR_Female                     20
# 88                            EOGScienceGr8_GLP_Female                     20
# 89                             EOGSubjects_CACR_Female                      2
# 90                              EOGSubjects_GLP_Female                      2
# 91                                  EOCMathI_CACR_Male                     52
# 92                                   EOCMathI_GLP_Male                     52
# 93                               EOCSubjects_CACR_Male                     52
# 94                                EOCSubjects_GLP_Male                     52
# 97                                    EOGGr6_CACR_Male                     35
# 98                                     EOGGr6_GLP_Male                     35
# 99                                    EOGGr7_CACR_Male                     18
# 100                                    EOGGr7_GLP_Male                     18
# 101                                   EOGGr8_CACR_Male                     20
# 102                                    EOGGr8_GLP_Male                     20
# 103                             EOGMathGr3-8_CACR_Male                      2
# 104                              EOGMathGr3-8_GLP_Male                      2
# 105                               EOGMathGr6_CACR_Male                     36
# 106                                EOGMathGr6_GLP_Male                     36
# 107                               EOGMathGr7_CACR_Male                     19
# 108                                EOGMathGr7_GLP_Male                     19
# 109                               EOGMathGr8_CACR_Male                     20
# 110                                EOGMathGr8_GLP_Male                     20
# 111                          EOGReadingGr3-8_CACR_Male                      2
# 112                           EOGReadingGr3-8_GLP_Male                      2
# 113                            EOGReadingGr6_CACR_Male                     36
# 114                             EOGReadingGr6_GLP_Male                     36
# 115                            EOGReadingGr7_CACR_Male                     19
# 116                             EOGReadingGr7_GLP_Male                     19
# 117                            EOGReadingGr8_CACR_Male                     20
# 118                             EOGReadingGr8_GLP_Male                     20
# 119                          EOGScienceGr5&8_CACR_Male                      7
# 120                           EOGScienceGr5&8_GLP_Male                      7
# 121                            EOGScienceGr8_CACR_Male                     20
# 122                             EOGScienceGr8_GLP_Male                     20
# 123                              EOGSubjects_CACR_Male                      2
# 124                               EOGSubjects_GLP_Male                      2
# 125                       EOCMathI_CACR_AmericanIndian                     52
# 126                        EOCMathI_GLP_AmericanIndian                     52
# 127                    EOCSubjects_CACR_AmericanIndian                     52
# 128                     EOCSubjects_GLP_AmericanIndian                     52
# 131                         EOGGr6_CACR_AmericanIndian                     35
# 132                          EOGGr6_GLP_AmericanIndian                     35
# 133                         EOGGr7_CACR_AmericanIndian                     18
# 134                          EOGGr7_GLP_AmericanIndian                     18
# 135                         EOGGr8_CACR_AmericanIndian                     20
# 136                          EOGGr8_GLP_AmericanIndian                     20
# 137                   EOGMathGr3-8_CACR_AmericanIndian                      2
# 138                    EOGMathGr3-8_GLP_AmericanIndian                      2
# 139                     EOGMathGr6_CACR_AmericanIndian                     36
# 140                      EOGMathGr6_GLP_AmericanIndian                     36
# 141                     EOGMathGr7_CACR_AmericanIndian                     19
# 142                      EOGMathGr7_GLP_AmericanIndian                     19
# 143                     EOGMathGr8_CACR_AmericanIndian                     20
# 144                      EOGMathGr8_GLP_AmericanIndian                     20
# 145                EOGReadingGr3-8_CACR_AmericanIndian                      2
# 146                 EOGReadingGr3-8_GLP_AmericanIndian                      2
# 147                  EOGReadingGr6_CACR_AmericanIndian                     36
# 148                   EOGReadingGr6_GLP_AmericanIndian                     36
# 149                  EOGReadingGr7_CACR_AmericanIndian                     19
# 150                   EOGReadingGr7_GLP_AmericanIndian                     19
# 151                  EOGReadingGr8_CACR_AmericanIndian                     20
# 152                   EOGReadingGr8_GLP_AmericanIndian                     20
# 153                EOGScienceGr5&8_CACR_AmericanIndian                      7
# 154                 EOGScienceGr5&8_GLP_AmericanIndian                      7
# 155                  EOGScienceGr8_CACR_AmericanIndian                     20
# 156                   EOGScienceGr8_GLP_AmericanIndian                     20
# 157                    EOGSubjects_CACR_AmericanIndian                      2
# 158                     EOGSubjects_GLP_AmericanIndian                      2
# 159                                EOCMathI_CACR_Asian                     52
# 160                                 EOCMathI_GLP_Asian                     52
# 161                             EOCSubjects_CACR_Asian                     52
# 162                              EOCSubjects_GLP_Asian                     52
# 165                                  EOGGr6_CACR_Asian                     35
# 166                                   EOGGr6_GLP_Asian                     35
# 167                                  EOGGr7_CACR_Asian                     18
# 168                                   EOGGr7_GLP_Asian                     18
# 169                                  EOGGr8_CACR_Asian                     20
# 170                                   EOGGr8_GLP_Asian                     20
# 171                            EOGMathGr3-8_CACR_Asian                      2
# 172                             EOGMathGr3-8_GLP_Asian                      2
# 173                              EOGMathGr6_CACR_Asian                     36
# 174                               EOGMathGr6_GLP_Asian                     36
# 175                              EOGMathGr7_CACR_Asian                     19
# 176                               EOGMathGr7_GLP_Asian                     19
# 177                              EOGMathGr8_CACR_Asian                     20
# 178                               EOGMathGr8_GLP_Asian                     20
# 179                         EOGReadingGr3-8_CACR_Asian                      2
# 180                          EOGReadingGr3-8_GLP_Asian                      2
# 181                           EOGReadingGr6_CACR_Asian                     36
# 182                            EOGReadingGr6_GLP_Asian                     36
# 183                           EOGReadingGr7_CACR_Asian                     19
# 184                            EOGReadingGr7_GLP_Asian                     19
# 185                           EOGReadingGr8_CACR_Asian                     20
# 186                            EOGReadingGr8_GLP_Asian                     20
# 187                         EOGScienceGr5&8_CACR_Asian                      7
# 188                          EOGScienceGr5&8_GLP_Asian                      7
# 189                           EOGScienceGr8_CACR_Asian                     20
# 190                            EOGScienceGr8_GLP_Asian                     20
# 191                             EOGSubjects_CACR_Asian                      2
# 192                              EOGSubjects_GLP_Asian                      2
# 193                                EOCMathI_CACR_Black                     52
# 194                                 EOCMathI_GLP_Black                     52
# 195                             EOCSubjects_CACR_Black                     52
# 196                              EOCSubjects_GLP_Black                     52
# 199                                  EOGGr6_CACR_Black                     35
# 200                                   EOGGr6_GLP_Black                     35
# 201                                  EOGGr7_CACR_Black                     18
# 202                                   EOGGr7_GLP_Black                     18
# 203                                  EOGGr8_CACR_Black                     20
# 204                                   EOGGr8_GLP_Black                     20
# 205                            EOGMathGr3-8_CACR_Black                      2
# 206                             EOGMathGr3-8_GLP_Black                      2
# 207                              EOGMathGr6_CACR_Black                     36
# 208                               EOGMathGr6_GLP_Black                     36
# 209                              EOGMathGr7_CACR_Black                     19
# 210                               EOGMathGr7_GLP_Black                     19
# 211                              EOGMathGr8_CACR_Black                     20
# 212                               EOGMathGr8_GLP_Black                     20
# 213                         EOGReadingGr3-8_CACR_Black                      2
# 214                          EOGReadingGr3-8_GLP_Black                      2
# 215                           EOGReadingGr6_CACR_Black                     36
# 216                            EOGReadingGr6_GLP_Black                     36
# 217                           EOGReadingGr7_CACR_Black                     19
# 218                            EOGReadingGr7_GLP_Black                     19
# 219                           EOGReadingGr8_CACR_Black                     20
# 220                            EOGReadingGr8_GLP_Black                     20
# 221                         EOGScienceGr5&8_CACR_Black                      7
# 222                          EOGScienceGr5&8_GLP_Black                      7
# 223                           EOGScienceGr8_CACR_Black                     20
# 224                            EOGScienceGr8_GLP_Black                     20
# 225                             EOGSubjects_CACR_Black                      2
# 226                              EOGSubjects_GLP_Black                      2
# 227                             EOCMathI_CACR_Hispanic                     52
# 228                              EOCMathI_GLP_Hispanic                     52
# 229                          EOCSubjects_CACR_Hispanic                     52
# 230                           EOCSubjects_GLP_Hispanic                     52
# 233                               EOGGr6_CACR_Hispanic                     35
# 234                                EOGGr6_GLP_Hispanic                     35
# 235                               EOGGr7_CACR_Hispanic                     18
# 236                                EOGGr7_GLP_Hispanic                     18
# 237                               EOGGr8_CACR_Hispanic                     20
# 238                                EOGGr8_GLP_Hispanic                     20
# 239                         EOGMathGr3-8_CACR_Hispanic                      2
# 240                          EOGMathGr3-8_GLP_Hispanic                      2
# 241                           EOGMathGr6_CACR_Hispanic                     36
# 242                            EOGMathGr6_GLP_Hispanic                     36
# 243                           EOGMathGr7_CACR_Hispanic                     19
# 244                            EOGMathGr7_GLP_Hispanic                     19
# 245                           EOGMathGr8_CACR_Hispanic                     20
# 246                            EOGMathGr8_GLP_Hispanic                     20
# 247                      EOGReadingGr3-8_CACR_Hispanic                      2
# 248                       EOGReadingGr3-8_GLP_Hispanic                      2
# 249                        EOGReadingGr6_CACR_Hispanic                     36
# 250                         EOGReadingGr6_GLP_Hispanic                     36
# 251                        EOGReadingGr7_CACR_Hispanic                     19
# 252                         EOGReadingGr7_GLP_Hispanic                     19
# 253                        EOGReadingGr8_CACR_Hispanic                     20
# 254                         EOGReadingGr8_GLP_Hispanic                     20
# 255                      EOGScienceGr5&8_CACR_Hispanic                      7
# 256                       EOGScienceGr5&8_GLP_Hispanic                      7
# 257                        EOGScienceGr8_CACR_Hispanic                     20
# 258                         EOGScienceGr8_GLP_Hispanic                     20
# 259                          EOGSubjects_CACR_Hispanic                      2
# 260                           EOGSubjects_GLP_Hispanic                      2
# 261                       EOCMathI_CACR_TwoorMoreRaces                     52
# 262                        EOCMathI_GLP_TwoorMoreRaces                     52
# 263                    EOCSubjects_CACR_TwoorMoreRaces                     52
# 264                     EOCSubjects_GLP_TwoorMoreRaces                     52
# 267                         EOGGr6_CACR_TwoorMoreRaces                     35
# 268                          EOGGr6_GLP_TwoorMoreRaces                     35
# 269                         EOGGr7_CACR_TwoorMoreRaces                     18
# 270                          EOGGr7_GLP_TwoorMoreRaces                     18
# 271                         EOGGr8_CACR_TwoorMoreRaces                     20
# 272                          EOGGr8_GLP_TwoorMoreRaces                     20
# 273                   EOGMathGr3-8_CACR_TwoorMoreRaces                      2
# 274                    EOGMathGr3-8_GLP_TwoorMoreRaces                      2
# 275                     EOGMathGr6_CACR_TwoorMoreRaces                     36
# 276                      EOGMathGr6_GLP_TwoorMoreRaces                     36
# 277                     EOGMathGr7_CACR_TwoorMoreRaces                     19
# 278                      EOGMathGr7_GLP_TwoorMoreRaces                     19
# 279                     EOGMathGr8_CACR_TwoorMoreRaces                     20
# 280                      EOGMathGr8_GLP_TwoorMoreRaces                     20
# 281                EOGReadingGr3-8_CACR_TwoorMoreRaces                      2
# 282                 EOGReadingGr3-8_GLP_TwoorMoreRaces                      2
# 283                  EOGReadingGr6_CACR_TwoorMoreRaces                     36
# 284                   EOGReadingGr6_GLP_TwoorMoreRaces                     36
# 285                  EOGReadingGr7_CACR_TwoorMoreRaces                     19
# 286                   EOGReadingGr7_GLP_TwoorMoreRaces                     19
# 287                  EOGReadingGr8_CACR_TwoorMoreRaces                     20
# 288                   EOGReadingGr8_GLP_TwoorMoreRaces                     20
# 289                EOGScienceGr5&8_CACR_TwoorMoreRaces                      7
# 290                 EOGScienceGr5&8_GLP_TwoorMoreRaces                      7
# 291                  EOGScienceGr8_CACR_TwoorMoreRaces                     20
# 292                   EOGScienceGr8_GLP_TwoorMoreRaces                     20
# 293                    EOGSubjects_CACR_TwoorMoreRaces                      2
# 294                     EOGSubjects_GLP_TwoorMoreRaces                      2
# 295                                EOCMathI_CACR_White                     52
# 296                                 EOCMathI_GLP_White                     52
# 297                             EOCSubjects_CACR_White                     52
# 298                              EOCSubjects_GLP_White                     52
# 301                                  EOGGr6_CACR_White                     35
# 302                                   EOGGr6_GLP_White                     35
# 303                                  EOGGr7_CACR_White                     18
# 304                                   EOGGr7_GLP_White                     18
# 305                                  EOGGr8_CACR_White                     20
# 306                                   EOGGr8_GLP_White                     20
# 307                            EOGMathGr3-8_CACR_White                      2
# 308                             EOGMathGr3-8_GLP_White                      2
# 309                              EOGMathGr6_CACR_White                     36
# 310                               EOGMathGr6_GLP_White                     36
# 311                              EOGMathGr7_CACR_White                     19
# 312                               EOGMathGr7_GLP_White                     19
# 313                              EOGMathGr8_CACR_White                     20
# 314                               EOGMathGr8_GLP_White                     20
# 315                         EOGReadingGr3-8_CACR_White                      2
# 316                          EOGReadingGr3-8_GLP_White                      2
# 317                           EOGReadingGr6_CACR_White                     36
# 318                            EOGReadingGr6_GLP_White                     36
# 319                           EOGReadingGr7_CACR_White                     19
# 320                            EOGReadingGr7_GLP_White                     19
# 321                           EOGReadingGr8_CACR_White                     20
# 322                            EOGReadingGr8_GLP_White                     20
# 323                         EOGScienceGr5&8_CACR_White                      7
# 324                          EOGScienceGr5&8_GLP_White                      7
# 325                           EOGScienceGr8_CACR_White                     20
# 326                            EOGScienceGr8_GLP_White                     20
# 327                             EOGSubjects_CACR_White                      2
# 328                              EOGSubjects_GLP_White                      2
# 329                                  EOCMathI_CACR_EDS                     52
# 330                                   EOCMathI_GLP_EDS                     52
# 331                               EOCSubjects_CACR_EDS                     52
# 332                                EOCSubjects_GLP_EDS                     52
# 335                                    EOGGr6_CACR_EDS                     35
# 336                                     EOGGr6_GLP_EDS                     35
# 337                                    EOGGr7_CACR_EDS                     18
# 338                                     EOGGr7_GLP_EDS                     18
# 339                                    EOGGr8_CACR_EDS                     20
# 340                                     EOGGr8_GLP_EDS                     20
# 341                              EOGMathGr3-8_CACR_EDS                      2
# 342                               EOGMathGr3-8_GLP_EDS                      2
# 343                                EOGMathGr6_CACR_EDS                     36
# 344                                 EOGMathGr6_GLP_EDS                     36
# 345                                EOGMathGr7_CACR_EDS                     19
# 346                                 EOGMathGr7_GLP_EDS                     19
# 347                                EOGMathGr8_CACR_EDS                     20
# 348                                 EOGMathGr8_GLP_EDS                     20
# 349                           EOGReadingGr3-8_CACR_EDS                      2
# 350                            EOGReadingGr3-8_GLP_EDS                      2
# 351                             EOGReadingGr6_CACR_EDS                     36
# 352                              EOGReadingGr6_GLP_EDS                     36
# 353                             EOGReadingGr7_CACR_EDS                     19
# 354                              EOGReadingGr7_GLP_EDS                     19
# 355                             EOGReadingGr8_CACR_EDS                     20
# 356                              EOGReadingGr8_GLP_EDS                     20
# 357                           EOGScienceGr5&8_CACR_EDS                      7
# 358                            EOGScienceGr5&8_GLP_EDS                      7
# 359                             EOGScienceGr8_CACR_EDS                     20
# 360                              EOGScienceGr8_GLP_EDS                     20
# 361                               EOGSubjects_CACR_EDS                      2
# 362                                EOGSubjects_GLP_EDS                      2
# 363                                  EOCMathI_CACR_LEP                     52
# 364                                   EOCMathI_GLP_LEP                     52
# 365                               EOCSubjects_CACR_LEP                     52
# 366                                EOCSubjects_GLP_LEP                     52
# 369                                    EOGGr6_CACR_LEP                     35
# 370                                     EOGGr6_GLP_LEP                     35
# 371                                    EOGGr7_CACR_LEP                     18
# 372                                     EOGGr7_GLP_LEP                     18
# 373                                    EOGGr8_CACR_LEP                     20
# 374                                     EOGGr8_GLP_LEP                     20
# 375                              EOGMathGr3-8_CACR_LEP                      2
# 376                               EOGMathGr3-8_GLP_LEP                      2
# 377                                EOGMathGr6_CACR_LEP                     36
# 378                                 EOGMathGr6_GLP_LEP                     36
# 379                                EOGMathGr7_CACR_LEP                     19
# 380                                 EOGMathGr7_GLP_LEP                     19
# 381                                EOGMathGr8_CACR_LEP                     20
# 382                                 EOGMathGr8_GLP_LEP                     20
# 383                           EOGReadingGr3-8_CACR_LEP                      2
# 384                            EOGReadingGr3-8_GLP_LEP                      2
# 385                             EOGReadingGr6_CACR_LEP                     36
# 386                              EOGReadingGr6_GLP_LEP                     36
# 387                             EOGReadingGr7_CACR_LEP                     19
# 388                              EOGReadingGr7_GLP_LEP                     19
# 389                             EOGReadingGr8_CACR_LEP                     20
# 390                              EOGReadingGr8_GLP_LEP                     20
# 391                           EOGScienceGr5&8_CACR_LEP                      7
# 392                            EOGScienceGr5&8_GLP_LEP                      7
# 393                             EOGScienceGr8_CACR_LEP                     20
# 394                              EOGScienceGr8_GLP_LEP                     20
# 395                               EOGSubjects_CACR_LEP                      2
# 396                                EOGSubjects_GLP_LEP                      2
# 397                                  EOCMathI_CACR_SWD                     52
# 398                                   EOCMathI_GLP_SWD                     52
# 399                               EOCSubjects_CACR_SWD                     52
# 400                                EOCSubjects_GLP_SWD                     52
# 403                                    EOGGr6_CACR_SWD                     35
# 404                                     EOGGr6_GLP_SWD                     35
# 405                                    EOGGr7_CACR_SWD                     18
# 406                                     EOGGr7_GLP_SWD                     18
# 407                                    EOGGr8_CACR_SWD                     20
# 408                                     EOGGr8_GLP_SWD                     20
# 409                              EOGMathGr3-8_CACR_SWD                      2
# 410                               EOGMathGr3-8_GLP_SWD                      2
# 411                                EOGMathGr6_CACR_SWD                     36
# 412                                 EOGMathGr6_GLP_SWD                     36
# 413                                EOGMathGr7_CACR_SWD                     19
# 414                                 EOGMathGr7_GLP_SWD                     19
# 415                                EOGMathGr8_CACR_SWD                     20
# 416                                 EOGMathGr8_GLP_SWD                     20
# 417                           EOGReadingGr3-8_CACR_SWD                      2
# 418                            EOGReadingGr3-8_GLP_SWD                      2
# 419                             EOGReadingGr6_CACR_SWD                     36
# 420                              EOGReadingGr6_GLP_SWD                     36
# 421                             EOGReadingGr7_CACR_SWD                     19
# 422                              EOGReadingGr7_GLP_SWD                     19
# 423                             EOGReadingGr8_CACR_SWD                     20
# 424                              EOGReadingGr8_GLP_SWD                     20
# 425                           EOGScienceGr5&8_CACR_SWD                      7
# 426                            EOGScienceGr5&8_GLP_SWD                      7
# 427                             EOGScienceGr8_CACR_SWD                     20
# 428                              EOGScienceGr8_GLP_SWD                     20
# 429                               EOGSubjects_CACR_SWD                      2
# 430                                EOGSubjects_GLP_SWD                      2
# 431                                  EOCMathI_CACR_AIG                     52
# 432                                   EOCMathI_GLP_AIG                     52
# 433                               EOCSubjects_CACR_AIG                     52
# 434                                EOCSubjects_GLP_AIG                     52
# 437                                    EOGGr6_CACR_AIG                     35
# 438                                     EOGGr6_GLP_AIG                     35
# 439                                    EOGGr7_CACR_AIG                     18
# 440                                     EOGGr7_GLP_AIG                     18
# 441                                    EOGGr8_CACR_AIG                     20
# 442                                     EOGGr8_GLP_AIG                     20
# 443                              EOGMathGr3-8_CACR_AIG                      2
# 444                               EOGMathGr3-8_GLP_AIG                      2
# 445                                EOGMathGr6_CACR_AIG                     36
# 446                                 EOGMathGr6_GLP_AIG                     36
# 447                                EOGMathGr7_CACR_AIG                     19
# 448                                 EOGMathGr7_GLP_AIG                     19
# 449                                EOGMathGr8_CACR_AIG                     20
# 450                                 EOGMathGr8_GLP_AIG                     20
# 451                           EOGReadingGr3-8_CACR_AIG                      2
# 452                            EOGReadingGr3-8_GLP_AIG                      2
# 453                             EOGReadingGr6_CACR_AIG                     36
# 454                              EOGReadingGr6_GLP_AIG                     36
# 455                             EOGReadingGr7_CACR_AIG                     19
# 456                              EOGReadingGr7_GLP_AIG                     19
# 457                             EOGReadingGr8_CACR_AIG                     20
# 458                              EOGReadingGr8_GLP_AIG                     20
# 459                           EOGScienceGr5&8_CACR_AIG                      7
# 460                            EOGScienceGr5&8_GLP_AIG                      7
# 461                             EOGScienceGr8_CACR_AIG                     20
# 462                              EOGScienceGr8_GLP_AIG                     20
# 463                               EOGSubjects_CACR_AIG                      2
# 464                                EOGSubjects_GLP_AIG                      2
# 465                      CurrentYearEOC_pTarget_PctMet                    201
# 466                           MathGr3-8_pTarget_PctMet                      4
# 467                        ReadingGr3-8_pTarget_PctMet                      4
# 468                            SciGr5&8_pTarget_PctMet                     14
# 472                           lea_ap_participation_pct                    114
# 473                              lea_ap_pct_3_or_above                      4
# 488                                flicensed_teach_pct                      1
# 489                                  tchyrs_0thru3_pct                      1
# 490                                 tchyrs_4thru10_pct                      1
# 491                                  tchyrs_11plus_pct                      1
# 492                                    class_teach_num                      1
# 493                                          nbpts_num                     32
# 494                                    advance_dgr_pct                      1
# 495                               _1yr_tchr_trnovr_pct                      4
# 496                                  lateral_teach_pct                    204
# 502                                      lea_nbpts_num                      7
# 505                            lea_emer_prov_teach_pct                    276
# 506                              lea_lateral_teach_pct                     70
# 517                              0-3 Years_Exp_Pct_Tch                      1
# 518                              10+ Years_Exp_Pct_Tch                      1
# 519                             4-10 Years_Exp_Pct_Tch                      1
# 523                   Accomplished_TCHR_Standard 1_Pct                      2
# 524                   Accomplished_TCHR_Standard 2_Pct                      2
# 525                   Accomplished_TCHR_Standard 3_Pct                      2
# 526                   Accomplished_TCHR_Standard 4_Pct                      2
# 527                   Accomplished_TCHR_Standard 5_Pct                      2
# 528                     Developing_TCHR_Standard 1_Pct                      2
# 529                     Developing_TCHR_Standard 2_Pct                      2
# 530                     Developing_TCHR_Standard 3_Pct                      2
# 531                     Developing_TCHR_Standard 4_Pct                      2
# 532                     Developing_TCHR_Standard 5_Pct                      2
# 533                  Distinguished_TCHR_Standard 1_Pct                      2
# 534                  Distinguished_TCHR_Standard 2_Pct                      2
# 535                  Distinguished_TCHR_Standard 3_Pct                      2
# 536                  Distinguished_TCHR_Standard 4_Pct                      2
# 537                  Distinguished_TCHR_Standard 5_Pct                      2
# 538  Does Not Meet Expected Growth_TCHR_Standard 6_Pct                      2
# 539        Exceeds Expected Growth_TCHR_Standard 6_Pct                      2
# 540          Meets Expected Growth_TCHR_Standard 6_Pct                      2
# 541                Not Demostrated_TCHR_Standard 1_Pct                      2
# 542                Not Demostrated_TCHR_Standard 2_Pct                      2
# 543                Not Demostrated_TCHR_Standard 3_Pct                      2
# 544                Not Demostrated_TCHR_Standard 4_Pct                      2
# 545                Not Demostrated_TCHR_Standard 5_Pct                      2
# 546                     Proficient_TCHR_Standard 1_Pct                      2
# 547                     Proficient_TCHR_Standard 2_Pct                      2
# 548                     Proficient_TCHR_Standard 3_Pct                      2
# 549                     Proficient_TCHR_Standard 4_Pct                      2
# 550                     Proficient_TCHR_Standard 5_Pct                      2

# %%
#Replace all remaining NaN with 0
schoolData = schoolData.fillna(0)

#Check for Missing values after final imputation 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# Empty DataFrame
# Columns: [Variable Name, Number Missing Values]
# Index: []

# %% [markdown]
# ## Identify and Remove Highly Correlated Features
# **Find and remove any columns / features that are > 95% correlated**
# * https://stackoverflow.com/questions/39409866/correlation-heatmap
# * https://chrisalbon.com/machine_learning/feature_selection/drop_highly_correlated_features/
# * https://codeyarns.com/2015/04/20/how-to-change-font-size-in-seaborn/

# %%
# calculate the correlation matrix
corr_matrix  = schoolData.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
#Get all of the correlation values > 95%
x = np.where(upper > 0.95)

#Display all field combinations with > 95% correlation
cf = pd.DataFrame()
cf['Field1'] = upper.columns[x[1]]
cf['Field2'] = upper.index[x[0]]

#Get the correlation values for every field combination. (There must be a more pythonic way to do this!)
corr = [0] * len(cf)
for i in range(0, len(cf)):
    corr[i] =  upper[cf['Field1'][i]][cf['Field2'][i]] 
    
cf['Correlation'] = corr

print 'There are ', str(len(cf['Field1'])), ' field correlations > 95%.'
cf
# Out:
# There are  509  field correlations > 95%.
#                                     Field1  \
# 0                          class_teach_num
# 1                      lea_class_teach_num
# 2                       st_class_teach_num
# 3                       st_advance_dgr_pct
# 4                            category_cd_M
# 5                            Category_Cd_M
# 6                Overall Achievement Score
# 7                 EOG/EOCSubjects_CACR_All
# 8                  EOG/EOCSubjects_GLP_All
# 9               EOG/EOCSubjects_GLP_Female
# 10                              Read Score
# 11                EOGReadingGr3-8_CACR_All
# 12                 EOGReadingGr3-8_GLP_All
# 13                     EOGSubjects_GLP_All
# 14                              Math Score
# 15                   EOGMathGr3-8_CACR_All
# 16                    EOGMathGr3-8_GLP_All
# 17                     EOGSubjects_GLP_All
# 18                EOGMathGr3-8_CACR_Female
# 19                 EOGMathGr3-8_GLP_Female
# 20                  EOGMathGr3-8_CACR_Male
# 21                   EOGMathGr3-8_GLP_Male
# 22                EOG/EOCSubjects_CACR_All
# 23                 EOG/EOCSubjects_GLP_All
# 24             EOG/EOCSubjects_CACR_Female
# 25              EOG/EOCSubjects_GLP_Female
# 26               EOG/EOCSubjects_CACR_Male
# 27                EOG/EOCSubjects_GLP_Male
# 28                EOGReadingGr3-8_CACR_All
# 29                 EOGReadingGr3-8_GLP_All
# 30                    EOGSubjects_CACR_All
# 31                     EOGSubjects_GLP_All
# 32             EOGReadingGr3-8_CACR_Female
# 33              EOGReadingGr3-8_GLP_Female
# 34               EOGReadingGr3-8_CACR_Male
# 35                EOGReadingGr3-8_GLP_Male
# 36                   EOGMathGr3-8_CACR_All
# 37                    EOGMathGr3-8_GLP_All
# 38                    EOGSubjects_CACR_All
# 39                     EOGSubjects_GLP_All
# 40                EOGMathGr3-8_CACR_Female
# 41                 EOGMathGr3-8_GLP_Female
# 42                  EOGMathGr3-8_CACR_Male
# 43                   EOGMathGr3-8_GLP_Male
# 44                EOGScienceGr5&8_CACR_All
# 45                 EOGScienceGr5&8_GLP_All
# 46                EOGScienceGr5&8_GLP_Male
# 47                       EOCMathI_CACR_All
# 48                        EOCMathI_GLP_All
# 49                    EOCSubjects_CACR_All
# 50                     EOCSubjects_GLP_All
# 51                        EOCMathI_GLP_All
# 52                    EOCSubjects_CACR_All
# 53                     EOCSubjects_GLP_All
# 54                    EOCSubjects_CACR_All
# 55                     EOCSubjects_GLP_All
# 56                     EOCSubjects_GLP_All
# 57                 EOG/EOCSubjects_GLP_All
# 58                    EOGSubjects_CACR_All
# 59                     EOGSubjects_GLP_All
# 60             EOG/EOCSubjects_CACR_Female
# 61              EOG/EOCSubjects_GLP_Female
# 62               EOG/EOCSubjects_CACR_Male
# 63                EOG/EOCSubjects_GLP_Male
# 64                    EOGSubjects_CACR_All
# 65                     EOGSubjects_GLP_All
# 66             EOG/EOCSubjects_CACR_Female
# 67              EOG/EOCSubjects_GLP_Female
# 68               EOG/EOCSubjects_CACR_Male
# 69                EOG/EOCSubjects_GLP_Male
# 70                          EOGGr6_GLP_All
# 71                     EOGMathGr6_CACR_All
# 72                      EOGMathGr6_GLP_All
# 73                  EOGReadingGr6_CACR_All
# 74                   EOGReadingGr6_GLP_All
# 75                      EOGGr6_CACR_Female
# 76                       EOGGr6_GLP_Female
# 77                        EOGGr6_CACR_Male
# 78                         EOGGr6_GLP_Male
# 79                     EOGMathGr6_CACR_All
# 80                      EOGMathGr6_GLP_All
# 81                  EOGReadingGr6_CACR_All
# 82                   EOGReadingGr6_GLP_All
# 83                      EOGGr6_CACR_Female
# 84                       EOGGr6_GLP_Female
# 85                        EOGGr6_CACR_Male
# 86                         EOGGr6_GLP_Male
# 87                          EOGGr7_GLP_All
# 88                     EOGMathGr7_CACR_All
# 89                      EOGMathGr7_GLP_All
# 90                  EOGReadingGr7_CACR_All
# 91                      EOGGr7_CACR_Female
# 92                       EOGGr7_GLP_Female
# 93                        EOGGr7_CACR_Male
# 94                     EOGMathGr7_CACR_All
# 95                      EOGMathGr7_GLP_All
# 96                  EOGReadingGr7_CACR_All
# 97                   EOGReadingGr7_GLP_All
# 98                      EOGGr7_CACR_Female
# 99                       EOGGr7_GLP_Female
# 100                        EOGGr7_GLP_Male
# 101                         EOGGr8_GLP_All
# 102                 EOGReadingGr8_CACR_All
# 103                  EOGReadingGr8_GLP_All
# 104                     EOGGr8_CACR_Female
# 105                       EOGGr8_CACR_Male
# 106                        EOGGr8_GLP_Male
# 107                  EOGReadingGr8_GLP_All
# 108                      EOGGr8_GLP_Female
# 109                        EOGGr8_GLP_Male
# 110                   EOGMathGr3-8_GLP_All
# 111                   EOGSubjects_CACR_All
# 112                    EOGSubjects_GLP_All
# 113               EOGMathGr3-8_CACR_Female
# 114                EOGMathGr3-8_GLP_Female
# 115                 EOGMathGr3-8_CACR_Male
# 116                  EOGMathGr3-8_GLP_Male
# 117                   EOGSubjects_CACR_All
# 118                    EOGSubjects_GLP_All
# 119               EOGMathGr3-8_CACR_Female
# 120                EOGMathGr3-8_GLP_Female
# 121                 EOGMathGr3-8_CACR_Male
# 122                  EOGMathGr3-8_GLP_Male
# 123                     EOGMathGr6_GLP_All
# 124                   EOGMathGr6_CACR_Male
# 125                   EOGMathGr6_CACR_Male
# 126                    EOGMathGr6_GLP_Male
# 127                     EOGMathGr7_GLP_All
# 128                 EOGMathGr7_CACR_Female
# 129                  EOGMathGr7_GLP_Female
# 130                   EOGMathGr7_CACR_Male
# 131                 EOGMathGr7_CACR_Female
# 132                  EOGMathGr7_GLP_Female
# 133                    EOGMathGr7_GLP_Male
# 134                     EOGMathGr8_GLP_All
# 135                 EOGMathGr8_CACR_Female
# 136                EOGReadingGr3-8_GLP_All
# 137                   EOGSubjects_CACR_All
# 138                    EOGSubjects_GLP_All
# 139            EOGReadingGr3-8_CACR_Female
# 140                EOGSubjects_CACR_Female
# 141              EOGReadingGr3-8_CACR_Male
# 142               EOGReadingGr3-8_GLP_Male
# 143                  EOGSubjects_CACR_Male
# 144                   EOGSubjects_CACR_All
# 145                    EOGSubjects_GLP_All
# 146            EOGReadingGr3-8_CACR_Female
# 147             EOGReadingGr3-8_GLP_Female
# 148              EOGReadingGr3-8_CACR_Male
# 149               EOGReadingGr3-8_GLP_Male
# 150                  EOGReadingGr6_GLP_All
# 151                EOGReadingGr6_CACR_Male
# 152                 EOGReadingGr6_GLP_Male
# 153                  EOGReadingGr7_GLP_All
# 154              EOGReadingGr7_CACR_Female
# 155               EOGReadingGr7_GLP_Female
# 156                  EOGReadingGr8_GLP_All
# 157                EOGScienceGr5&8_GLP_All
# 158            EOGScienceGr5&8_CACR_Female
# 159              EOGScienceGr5&8_CACR_Male
# 160               EOGScienceGr5&8_GLP_Male
# 161                  EOGScienceGr8_GLP_All
# 162                    EOGSubjects_GLP_All
# 163                EOGSubjects_CACR_Female
# 164                 EOGSubjects_GLP_Female
# 165              EOGReadingGr3-8_CACR_Male
# 166                  EOGSubjects_CACR_Male
# 167                   EOGSubjects_GLP_Male
# 168                EOGSubjects_CACR_Female
# 169                 EOGSubjects_GLP_Female
# 170                  EOGSubjects_CACR_Male
# 171                   EOGSubjects_GLP_Male
# 172                    EOCMathI_GLP_Female
# 173                EOCSubjects_CACR_Female
# 174                 EOCSubjects_GLP_Female
# 175                 EOCSubjects_GLP_Female
# 176             EOG/EOCSubjects_GLP_Female
# 177                EOGSubjects_CACR_Female
# 178                EOGSubjects_CACR_Female
# 179                 EOGSubjects_GLP_Female
# 180                      EOGGr6_GLP_Female
# 181                 EOGMathGr6_CACR_Female
# 182                      EOGGr7_GLP_Female
# 183                 EOGMathGr7_CACR_Female
# 184                  EOGMathGr7_GLP_Female
# 185              EOGReadingGr7_CACR_Female
# 186                  EOGMathGr7_GLP_Female
# 187              EOGReadingGr7_CACR_Female
# 188               EOGReadingGr7_GLP_Female
# 189                      EOGGr8_GLP_Female
# 190              EOGReadingGr8_CACR_Female
# 191               EOGReadingGr8_GLP_Female
# 192                EOGMathGr3-8_GLP_Female
# 193                EOGSubjects_CACR_Female
# 194                EOGSubjects_CACR_Female
# 195                 EOGSubjects_GLP_Female
# 196                  EOGMathGr6_GLP_Female
# 197                  EOGMathGr7_GLP_Female
# 198                  EOGMathGr8_GLP_Female
# 199             EOGReadingGr3-8_GLP_Female
# 200                EOGSubjects_CACR_Female
# 201                 EOGSubjects_GLP_Female
# 202                EOGSubjects_CACR_Female
# 203                 EOGSubjects_GLP_Female
# 204               EOGReadingGr6_GLP_Female
# 205               EOGReadingGr7_GLP_Female
# 206               EOGReadingGr8_GLP_Female
# 207             EOGScienceGr5&8_GLP_Female
# 208               EOGScienceGr8_GLP_Female
# 209                 EOGSubjects_GLP_Female
# 210                      EOCMathI_GLP_Male
# 211                  EOCSubjects_CACR_Male
# 212                   EOCSubjects_GLP_Male
# 213                  EOCSubjects_CACR_Male
# 214                   EOCSubjects_GLP_Male
# 215                   EOCSubjects_GLP_Male
# 216               EOG/EOCSubjects_GLP_Male
# 217              EOGReadingGr3-8_CACR_Male
# 218                  EOGSubjects_CACR_Male
# 219                   EOGSubjects_GLP_Male
# 220                  EOGSubjects_CACR_Male
# 221                   EOGSubjects_GLP_Male
# 222                        EOGGr6_GLP_Male
# 223                   EOGMathGr6_CACR_Male
# 224                    EOGMathGr6_GLP_Male
# 225                EOGReadingGr6_CACR_Male
# 226                   EOGMathGr6_CACR_Male
# 227                    EOGMathGr6_GLP_Male
# 228                EOGReadingGr6_CACR_Male
# 229                 EOGReadingGr6_GLP_Male
# 230                        EOGGr7_GLP_Male
# 231                   EOGMathGr7_CACR_Male
# 232                    EOGMathGr7_GLP_Male
# 233                EOGReadingGr7_CACR_Male
# 234                    EOGMathGr7_GLP_Male
# 235                EOGReadingGr7_CACR_Male
# 236                 EOGReadingGr7_GLP_Male
# 237                        EOGGr8_GLP_Male
# 238                  EOGMathGr3-8_GLP_Male
# 239                  EOGSubjects_CACR_Male
# 240                   EOGSubjects_GLP_Male
# 241                  EOGSubjects_CACR_Male
# 242                   EOGSubjects_GLP_Male
# 243                    EOGMathGr6_GLP_Male
# 244                    EOGMathGr7_GLP_Male
# 245                    EOGMathGr8_GLP_Male
# 246               EOGReadingGr3-8_GLP_Male
# 247                  EOGSubjects_CACR_Male
# 248                   EOGSubjects_GLP_Male
# 249                  EOGSubjects_CACR_Male
# 250                   EOGSubjects_GLP_Male
# 251                 EOGReadingGr6_GLP_Male
# 252                 EOGReadingGr7_GLP_Male
# 253                 EOGReadingGr8_GLP_Male
# 254               EOGScienceGr5&8_GLP_Male
# 255                 EOGScienceGr8_GLP_Male
# 256                   EOGSubjects_GLP_Male
# 257            EOCMathI_GLP_AmericanIndian
# 258         EOCSubjects_GLP_AmericanIndian
# 259     EOG/EOCSubjects_GLP_AmericanIndian
# 260        EOGSubjects_CACR_AmericanIndian
# 261         EOGSubjects_GLP_AmericanIndian
# 262              EOGGr6_GLP_AmericanIndian
# 263              EOGGr7_GLP_AmericanIndian
# 264              EOGGr8_GLP_AmericanIndian
# 265        EOGMathGr3-8_GLP_AmericanIndian
# 266          EOGMathGr6_GLP_AmericanIndian
# 267     EOGReadingGr3-8_GLP_AmericanIndian
# 268       EOGReadingGr7_GLP_AmericanIndian
# 269     EOGScienceGr5&8_GLP_AmericanIndian
# 270      EOGScienceGr8_CACR_AmericanIndian
# 271       EOGScienceGr8_GLP_AmericanIndian
# 272       EOGScienceGr8_GLP_AmericanIndian
# 273       EOGScienceGr8_GLP_AmericanIndian
# 274         EOGSubjects_GLP_AmericanIndian
# 275                     EOCMathI_GLP_Asian
# 276                 EOCSubjects_CACR_Asian
# 277                  EOCSubjects_GLP_Asian
# 278                 EOCSubjects_CACR_Asian
# 279                  EOCSubjects_GLP_Asian
# 280                  EOCSubjects_GLP_Asian
# 281              EOG/EOCSubjects_GLP_Asian
# 282                 EOGSubjects_CACR_Asian
# 283                  EOGSubjects_GLP_Asian
# 284                 EOGSubjects_CACR_Asian
# 285                  EOGSubjects_GLP_Asian
# 286                       EOGGr6_GLP_Asian
# 287                       EOGGr7_GLP_Asian
# 288                       EOGGr8_GLP_Asian
# 289                 EOGMathGr3-8_GLP_Asian
# 290              EOGReadingGr3-8_GLP_Asian
# 291                   EOGMathGr6_GLP_Asian
# 292               EOGReadingGr6_CACR_Asian
# 293                EOGReadingGr6_GLP_Asian
# 294               EOGReadingGr6_CACR_Asian
# 295                EOGReadingGr6_GLP_Asian
# 296                   EOGMathGr7_GLP_Asian
# 297               EOGReadingGr7_CACR_Asian
# 298                EOGReadingGr7_GLP_Asian
# 299               EOGReadingGr7_CACR_Asian
# 300                EOGReadingGr7_GLP_Asian
# 301                   EOGMathGr8_GLP_Asian
# 302               EOGScienceGr8_CACR_Asian
# 303                EOGReadingGr8_GLP_Asian
# 304               EOGScienceGr8_CACR_Asian
# 305                EOGScienceGr8_GLP_Asian
# 306              EOGReadingGr3-8_GLP_Asian
# 307                EOGReadingGr6_GLP_Asian
# 308                EOGReadingGr7_GLP_Asian
# 309                EOGReadingGr8_GLP_Asian
# 310               EOGScienceGr8_CACR_Asian
# 311                EOGScienceGr8_GLP_Asian
# 312              EOGScienceGr5&8_GLP_Asian
# 313               EOGScienceGr8_CACR_Asian
# 314                EOGScienceGr8_GLP_Asian
# 315               EOGScienceGr8_CACR_Asian
# 316                EOGScienceGr8_GLP_Asian
# 317                EOGScienceGr8_GLP_Asian
# 318                  EOGSubjects_GLP_Asian
# 319                     EOCMathI_GLP_Black
# 320                 EOCSubjects_CACR_Black
# 321                  EOCSubjects_GLP_Black
# 322                 EOCSubjects_CACR_Black
# 323                  EOCSubjects_GLP_Black
# 324                  EOCSubjects_GLP_Black
# 325              EOG/EOCSubjects_GLP_Black
# 326                 EOGSubjects_CACR_Black
# 327                  EOGSubjects_GLP_Black
# 328                       EOGGr7_GLP_Black
# 329                       EOGGr8_GLP_Black
# 330                 EOGMathGr3-8_GLP_Black
# 331                   EOGMathGr7_GLP_Black
# 332              EOGScienceGr5&8_GLP_Black
# 333               EOGScienceGr8_CACR_Black
# 334                EOGScienceGr8_GLP_Black
# 335                  EOGSubjects_GLP_Black
# 336                  EOCMathI_GLP_Hispanic
# 337              EOCSubjects_CACR_Hispanic
# 338               EOCSubjects_GLP_Hispanic
# 339              EOCSubjects_CACR_Hispanic
# 340               EOCSubjects_GLP_Hispanic
# 341               EOCSubjects_GLP_Hispanic
# 342           EOG/EOCSubjects_GLP_Hispanic
# 343              EOGSubjects_CACR_Hispanic
# 344               EOGSubjects_GLP_Hispanic
# 345                    EOGGr7_GLP_Hispanic
# 346                    EOGGr8_GLP_Hispanic
# 347                EOGMathGr6_GLP_Hispanic
# 348           EOGScienceGr5&8_GLP_Hispanic
# 349             EOGScienceGr8_GLP_Hispanic
# 350               EOGSubjects_GLP_Hispanic
# 351            EOCMathI_GLP_TwoorMoreRaces
# 352        EOCSubjects_CACR_TwoorMoreRaces
# 353         EOCSubjects_GLP_TwoorMoreRaces
# 354         EOCSubjects_GLP_TwoorMoreRaces
# 355        EOGSubjects_CACR_TwoorMoreRaces
# 356         EOGSubjects_GLP_TwoorMoreRaces
# 357              EOGGr6_GLP_TwoorMoreRaces
# 358              EOGGr7_GLP_TwoorMoreRaces
# 359              EOGGr8_GLP_TwoorMoreRaces
# 360        EOGMathGr3-8_GLP_TwoorMoreRaces
# 361          EOGMathGr6_GLP_TwoorMoreRaces
# 362          EOGMathGr7_GLP_TwoorMoreRaces
# 363          EOGMathGr8_GLP_TwoorMoreRaces
# 364       EOGReadingGr6_GLP_TwoorMoreRaces
# 365       EOGReadingGr7_GLP_TwoorMoreRaces
# 366     EOGScienceGr5&8_GLP_TwoorMoreRaces
# 367      EOGScienceGr8_CACR_TwoorMoreRaces
# 368       EOGScienceGr8_GLP_TwoorMoreRaces
# 369                     EOCMathI_GLP_White
# 370                 EOCSubjects_CACR_White
# 371                  EOCSubjects_GLP_White
# 372                 EOCSubjects_CACR_White
# 373                  EOCSubjects_GLP_White
# 374                  EOCSubjects_GLP_White
# 375              EOG/EOCSubjects_GLP_White
# 376                 EOGSubjects_CACR_White
# 377                       EOGGr6_GLP_White
# 378                  EOGMathGr6_CACR_White
# 379                   EOGMathGr6_GLP_White
# 380                   EOGMathGr6_GLP_White
# 381                       EOGGr7_GLP_White
# 382                  EOGMathGr7_CACR_White
# 383                   EOGMathGr7_GLP_White
# 384               EOGReadingGr7_CACR_White
# 385                   EOGMathGr7_GLP_White
# 386               EOGReadingGr7_CACR_White
# 387                EOGReadingGr7_GLP_White
# 388                       EOGGr8_GLP_White
# 389                 EOGMathGr3-8_GLP_White
# 390                 EOGSubjects_CACR_White
# 391                  EOGSubjects_GLP_White
# 392                   EOGMathGr6_GLP_White
# 393                   EOGMathGr7_GLP_White
# 394                   EOGMathGr8_GLP_White
# 395              EOGReadingGr3-8_GLP_White
# 396                EOGReadingGr6_GLP_White
# 397                EOGReadingGr7_GLP_White
# 398                EOGReadingGr8_GLP_White
# 399              EOGScienceGr5&8_GLP_White
# 400                EOGScienceGr8_GLP_White
# 401                  EOGSubjects_GLP_White
# 402                       EOCMathI_GLP_EDS
# 403                   EOCSubjects_CACR_EDS
# 404                    EOCSubjects_GLP_EDS
# 405                   EOCSubjects_CACR_EDS
# 406                    EOCSubjects_GLP_EDS
# 407                    EOCSubjects_GLP_EDS
# 408                EOG/EOCSubjects_GLP_EDS
# 409                   EOGSubjects_CACR_EDS
# 410                         EOGGr6_GLP_EDS
# 411                         EOGGr7_GLP_EDS
# 412                         EOGGr8_GLP_EDS
# 413                   EOGMathGr3-8_GLP_EDS
# 414                     EOGMathGr6_GLP_EDS
# 415                     EOGMathGr7_GLP_EDS
# 416                     EOGMathGr8_GLP_EDS
# 417                EOGReadingGr3-8_GLP_EDS
# 418                   EOGSubjects_CACR_EDS
# 419                    EOGSubjects_GLP_EDS
# 420                  EOGReadingGr6_GLP_EDS
# 421                  EOGReadingGr7_GLP_EDS
# 422                EOGScienceGr5&8_GLP_EDS
# 423                  EOGScienceGr8_GLP_EDS
# 424                    EOGSubjects_GLP_EDS
# 425                   EOCSubjects_CACR_LEP
# 426                    EOCSubjects_GLP_LEP
# 427                    EOCSubjects_GLP_LEP
# 428                    EOCSubjects_GLP_LEP
# 429                   EOGSubjects_CACR_LEP
# 430                    EOGSubjects_GLP_LEP
# 431                 EOGScienceGr8_CACR_LEP
# 432                  EOGScienceGr8_GLP_LEP
# 433                       EOCMathI_GLP_SWD
# 434                    EOCSubjects_GLP_SWD
# 435                EOG/EOCSubjects_GLP_SWD
# 436                    EOGSubjects_GLP_SWD
# 437                       EOCMathI_GLP_AIG
# 438                   EOCSubjects_CACR_AIG
# 439                    EOCSubjects_GLP_AIG
# 440                    EOCSubjects_GLP_AIG
# 441                         EOGGr6_GLP_AIG
# 442                         EOGGr7_GLP_AIG
# 443                         EOGGr8_GLP_AIG
# 444                   EOGMathGr3-8_GLP_AIG
# 445                     EOGMathGr6_GLP_AIG
# 446                 EOGReadingGr6_CACR_AIG
# 447                  EOGReadingGr6_GLP_AIG
# 448                 EOGReadingGr6_CACR_AIG
# 449                  EOGReadingGr6_GLP_AIG
# 450                     EOGMathGr7_GLP_AIG
# 451                 EOGReadingGr7_CACR_AIG
# 452                  EOGReadingGr7_GLP_AIG
# 453                     EOGMathGr8_GLP_AIG
# 454                  EOGReadingGr8_GLP_AIG
# 455                EOGReadingGr3-8_GLP_AIG
# 456                  EOGReadingGr6_GLP_AIG
# 457                  EOGReadingGr7_GLP_AIG
# 458                  EOGReadingGr8_GLP_AIG
# 459                 EOGScienceGr8_CACR_AIG
# 460                 EOGScienceGr8_CACR_AIG
# 461                  EOGScienceGr8_GLP_AIG
# 462                EOGScienceGr5&8_GLP_AIG
# 463                  EOGScienceGr8_GLP_AIG
# 464                    EOGSubjects_GLP_AIG
# 465                st_short_susp_per_c_num
# 466                          category_cd_I
# 467                          Category_Cd_I
# 468                 st_emer_prov_teach_pct
# 469                   st_lateral_teach_pct
# 470                          category_cd_I
# 471                          Category_Cd_I
# 472                  0-3 Years_Exp_Pct_Tch
# 473                 4-10 Years_Exp_Pct_Tch
# 474                  10+ Years_Exp_Pct_Tch
# 475                  lea_lateral_teach_pct
# 476                     st_advance_dgr_pct
# 477                          category_cd_M
# 478                          Category_Cd_M
# 479                          category_cd_M
# 480                          Category_Cd_M
# 481                               AsianPct
# 482                               AsianPct
# 483                           BlackMalePct
# 484                               BlackPct
# 485                               BlackPct
# 486                            HispanicPct
# 487                            HispanicPct
# 488                          IndianMalePct
# 489                              IndianPct
# 490                              IndianPct
# 491                            MinorityPct
# 492                           WhiteMalePct
# 493                               WhitePct
# 494                            MinorityPct
# 495                         WhiteFemalePct
# 496                           WhiteMalePct
# 497                               WhitePct
# 498                         WhiteFemalePct
# 499                           WhiteMalePct
# 500                               WhitePct
# 501                               WhitePct
# 502                               WhitePct
# 503                          Category_Cd_I
# 504                          Category_Cd_M
# 505                          Category_Cd_T
# 506                      sna_pgm_type_cd_Y
# 507  calendar_only_txt_Year-Round Calendar
# 508  calendar_only_txt_Year-Round Calendar
#
#                                                 Field2  Correlation
# 0                                          student_num     0.951318
# 1                                  lea_avg_student_num     0.956811
# 2                                   st_avg_student_num     0.994943
# 3                                   st_avg_student_num     0.983738
# 4                                   st_avg_student_num     0.953044
# 5                                   st_avg_student_num     0.953044
# 6                                            SPG Score     0.983459
# 7                                            SPG Score     0.973018
# 8                                            SPG Score     0.978796
# 9                                            SPG Score     0.950341
# 10                                  Reading  SPG Score     0.987876
# 11                                  Reading  SPG Score     0.972502
# 12                                  Reading  SPG Score     0.987991
# 13                                  Reading  SPG Score     0.963484
# 14                                      Math SPG Score     0.984681
# 15                                      Math SPG Score     0.974120
# 16                                      Math SPG Score     0.984784
# 17                                      Math SPG Score     0.950210
# 18                                      Math SPG Score     0.956778
# 19                                      Math SPG Score     0.966864
# 20                                      Math SPG Score     0.953543
# 21                                      Math SPG Score     0.960603
# 22                           Overall Achievement Score     0.988326
# 23                           Overall Achievement Score     0.994565
# 24                           Overall Achievement Score     0.963008
# 25                           Overall Achievement Score     0.963031
# 26                           Overall Achievement Score     0.960954
# 27                           Overall Achievement Score     0.962007
# 28                                          Read Score     0.989153
# 29                                          Read Score     0.999827
# 30                                          Read Score     0.968367
# 31                                          Read Score     0.977941
# 32                                          Read Score     0.953052
# 33                                          Read Score     0.952674
# 34                                          Read Score     0.954327
# 35                                          Read Score     0.962081
# 36                                          Math Score     0.992458
# 37                                          Math Score     0.999842
# 38                                          Math Score     0.968771
# 39                                          Math Score     0.967899
# 40                                          Math Score     0.973157
# 41                                          Math Score     0.978842
# 42                                          Math Score     0.971218
# 43                                          Math Score     0.975869
# 44                                       Science Score     0.979190
# 45                                       Science Score     0.999868
# 46                                       Science Score     0.951204
# 47                                        Math I Score     0.958703
# 48                                        Math I Score     0.999856
# 49                                        Math I Score     0.956637
# 50                                        Math I Score     0.995705
# 51                                   EOCMathI_CACR_All     0.958914
# 52                                   EOCMathI_CACR_All     0.995076
# 53                                   EOCMathI_CACR_All     0.954497
# 54                                    EOCMathI_GLP_All     0.956849
# 55                                    EOCMathI_GLP_All     0.995866
# 56                                EOCSubjects_CACR_All     0.960376
# 57                            EOG/EOCSubjects_CACR_All     0.994433
# 58                            EOG/EOCSubjects_CACR_All     0.971872
# 59                            EOG/EOCSubjects_CACR_All     0.956130
# 60                            EOG/EOCSubjects_CACR_All     0.974943
# 61                            EOG/EOCSubjects_CACR_All     0.963202
# 62                            EOG/EOCSubjects_CACR_All     0.973621
# 63                            EOG/EOCSubjects_CACR_All     0.962774
# 64                             EOG/EOCSubjects_GLP_All     0.964288
# 65                             EOG/EOCSubjects_GLP_All     0.958648
# 66                             EOG/EOCSubjects_GLP_All     0.968920
# 67                             EOG/EOCSubjects_GLP_All     0.967986
# 68                             EOG/EOCSubjects_GLP_All     0.967233
# 69                             EOG/EOCSubjects_GLP_All     0.967131
# 70                                     EOGGr6_CACR_All     0.987730
# 71                                     EOGGr6_CACR_All     0.973644
# 72                                     EOGGr6_CACR_All     0.974539
# 73                                     EOGGr6_CACR_All     0.972757
# 74                                     EOGGr6_CACR_All     0.950930
# 75                                     EOGGr6_CACR_All     0.964148
# 76                                     EOGGr6_CACR_All     0.951526
# 77                                     EOGGr6_CACR_All     0.964782
# 78                                     EOGGr6_CACR_All     0.953327
# 79                                      EOGGr6_GLP_All     0.953954
# 80                                      EOGGr6_GLP_All     0.974469
# 81                                      EOGGr6_GLP_All     0.968748
# 82                                      EOGGr6_GLP_All     0.974863
# 83                                      EOGGr6_GLP_All     0.956159
# 84                                      EOGGr6_GLP_All     0.967109
# 85                                      EOGGr6_GLP_All     0.955069
# 86                                      EOGGr6_GLP_All     0.967754
# 87                                     EOGGr7_CACR_All     0.988866
# 88                                     EOGGr7_CACR_All     0.971478
# 89                                     EOGGr7_CACR_All     0.972467
# 90                                     EOGGr7_CACR_All     0.968919
# 91                                     EOGGr7_CACR_All     0.966847
# 92                                     EOGGr7_CACR_All     0.953360
# 93                                     EOGGr7_CACR_All     0.955081
# 94                                      EOGGr7_GLP_All     0.951152
# 95                                      EOGGr7_GLP_All     0.971967
# 96                                      EOGGr7_GLP_All     0.968155
# 97                                      EOGGr7_GLP_All     0.968633
# 98                                      EOGGr7_GLP_All     0.959030
# 99                                      EOGGr7_GLP_All     0.968255
# 100                                     EOGGr7_GLP_All     0.956796
# 101                                    EOGGr8_CACR_All     0.988546
# 102                                    EOGGr8_CACR_All     0.962406
# 103                                    EOGGr8_CACR_All     0.955075
# 104                                    EOGGr8_CACR_All     0.955973
# 105                                    EOGGr8_CACR_All     0.957083
# 106                                    EOGGr8_CACR_All     0.950446
# 107                                     EOGGr8_GLP_All     0.969234
# 108                                     EOGGr8_GLP_All     0.956951
# 109                                     EOGGr8_GLP_All     0.956872
# 110                              EOGMathGr3-8_CACR_All     0.992543
# 111                              EOGMathGr3-8_CACR_All     0.968568
# 112                              EOGMathGr3-8_CACR_All     0.957882
# 113                              EOGMathGr3-8_CACR_All     0.980982
# 114                              EOGMathGr3-8_CACR_All     0.972365
# 115                              EOGMathGr3-8_CACR_All     0.979509
# 116                              EOGMathGr3-8_CACR_All     0.969443
# 117                               EOGMathGr3-8_GLP_All     0.969181
# 118                               EOGMathGr3-8_GLP_All     0.968308
# 119                               EOGMathGr3-8_GLP_All     0.973116
# 120                               EOGMathGr3-8_GLP_All     0.978834
# 121                               EOGMathGr3-8_GLP_All     0.971463
# 122                               EOGMathGr3-8_GLP_All     0.976226
# 123                                EOGMathGr6_CACR_All     0.986998
# 124                                EOGMathGr6_CACR_All     0.961771
# 125                                 EOGMathGr6_GLP_All     0.954022
# 126                                 EOGMathGr6_GLP_All     0.962775
# 127                                EOGMathGr7_CACR_All     0.986124
# 128                                EOGMathGr7_CACR_All     0.964015
# 129                                EOGMathGr7_CACR_All     0.950985
# 130                                EOGMathGr7_CACR_All     0.956339
# 131                                 EOGMathGr7_GLP_All     0.950808
# 132                                 EOGMathGr7_GLP_All     0.966911
# 133                                 EOGMathGr7_GLP_All     0.957642
# 134                                EOGMathGr8_CACR_All     0.984956
# 135                                EOGMathGr8_CACR_All     0.955027
# 136                           EOGReadingGr3-8_CACR_All     0.989237
# 137                           EOGReadingGr3-8_CACR_All     0.979492
# 138                           EOGReadingGr3-8_CACR_All     0.975749
# 139                           EOGReadingGr3-8_CACR_All     0.963339
# 140                           EOGReadingGr3-8_CACR_All     0.952122
# 141                           EOGReadingGr3-8_CACR_All     0.966721
# 142                           EOGReadingGr3-8_CACR_All     0.954856
# 143                           EOGReadingGr3-8_CACR_All     0.951041
# 144                            EOGReadingGr3-8_GLP_All     0.968122
# 145                            EOGReadingGr3-8_GLP_All     0.977828
# 146                            EOGReadingGr3-8_GLP_All     0.953110
# 147                            EOGReadingGr3-8_GLP_All     0.952809
# 148                            EOGReadingGr3-8_GLP_All     0.954300
# 149                            EOGReadingGr3-8_GLP_All     0.962114
# 150                             EOGReadingGr6_CACR_All     0.978800
# 151                             EOGReadingGr6_CACR_All     0.952354
# 152                              EOGReadingGr6_GLP_All     0.959226
# 153                             EOGReadingGr7_CACR_All     0.982165
# 154                             EOGReadingGr7_CACR_All     0.955552
# 155                              EOGReadingGr7_GLP_All     0.957637
# 156                             EOGReadingGr8_CACR_All     0.973245
# 157                           EOGScienceGr5&8_CACR_All     0.979465
# 158                           EOGScienceGr5&8_CACR_All     0.951497
# 159                           EOGScienceGr5&8_CACR_All     0.955389
# 160                            EOGScienceGr5&8_GLP_All     0.951133
# 161                             EOGScienceGr8_CACR_All     0.978298
# 162                               EOGSubjects_CACR_All     0.993784
# 163                               EOGSubjects_CACR_All     0.974844
# 164                               EOGSubjects_CACR_All     0.962449
# 165                               EOGSubjects_CACR_All     0.950652
# 166                               EOGSubjects_CACR_All     0.973964
# 167                               EOGSubjects_CACR_All     0.964425
# 168                                EOGSubjects_GLP_All     0.969150
# 169                                EOGSubjects_GLP_All     0.969667
# 170                                EOGSubjects_GLP_All     0.966954
# 171                                EOGSubjects_GLP_All     0.968900
# 172                               EOCMathI_CACR_Female     0.952319
# 173                               EOCMathI_CACR_Female     0.991991
# 174                                EOCMathI_GLP_Female     0.993212
# 175                            EOCSubjects_CACR_Female     0.953281
# 176                        EOG/EOCSubjects_CACR_Female     0.992131
# 177                        EOG/EOCSubjects_CACR_Female     0.968896
# 178                         EOG/EOCSubjects_GLP_Female     0.961083
# 179                         EOG/EOCSubjects_GLP_Female     0.957108
# 180                                 EOGGr6_CACR_Female     0.984232
# 181                                 EOGGr6_CACR_Female     0.953182
# 182                                 EOGGr7_CACR_Female     0.983486
# 183                                 EOGGr7_CACR_Female     0.966542
# 184                                 EOGGr7_CACR_Female     0.962811
# 185                                 EOGGr7_CACR_Female     0.963921
# 186                                  EOGGr7_GLP_Female     0.966219
# 187                                  EOGGr7_GLP_Female     0.958233
# 188                                  EOGGr7_GLP_Female     0.962607
# 189                                 EOGGr8_CACR_Female     0.982063
# 190                                 EOGGr8_CACR_Female     0.955282
# 191                                  EOGGr8_GLP_Female     0.954684
# 192                           EOGMathGr3-8_CACR_Female     0.989253
# 193                           EOGMathGr3-8_CACR_Female     0.965401
# 194                            EOGMathGr3-8_GLP_Female     0.964726
# 195                            EOGMathGr3-8_GLP_Female     0.962021
# 196                             EOGMathGr6_CACR_Female     0.980825
# 197                             EOGMathGr7_CACR_Female     0.976258
# 198                             EOGMathGr8_CACR_Female     0.976834
# 199                        EOGReadingGr3-8_CACR_Female     0.983472
# 200                        EOGReadingGr3-8_CACR_Female     0.973831
# 201                        EOGReadingGr3-8_CACR_Female     0.966910
# 202                         EOGReadingGr3-8_GLP_Female     0.957801
# 203                         EOGReadingGr3-8_GLP_Female     0.969226
# 204                          EOGReadingGr6_CACR_Female     0.971435
# 205                          EOGReadingGr7_CACR_Female     0.970024
# 206                          EOGReadingGr8_CACR_Female     0.961875
# 207                        EOGScienceGr5&8_CACR_Female     0.967794
# 208                          EOGScienceGr8_CACR_Female     0.969409
# 209                            EOGSubjects_CACR_Female     0.990880
# 210                                 EOCMathI_CACR_Male     0.962208
# 211                                 EOCMathI_CACR_Male     0.995510
# 212                                 EOCMathI_CACR_Male     0.958528
# 213                                  EOCMathI_GLP_Male     0.961656
# 214                                  EOCMathI_GLP_Male     0.996550
# 215                              EOCSubjects_CACR_Male     0.964214
# 216                          EOG/EOCSubjects_CACR_Male     0.992092
# 217                          EOG/EOCSubjects_CACR_Male     0.951448
# 218                          EOG/EOCSubjects_CACR_Male     0.974845
# 219                          EOG/EOCSubjects_CACR_Male     0.959501
# 220                           EOG/EOCSubjects_GLP_Male     0.959977
# 221                           EOG/EOCSubjects_GLP_Male     0.956918
# 222                                   EOGGr6_CACR_Male     0.983554
# 223                                   EOGGr6_CACR_Male     0.970661
# 224                                   EOGGr6_CACR_Male     0.968101
# 225                                   EOGGr6_CACR_Male     0.968712
# 226                                    EOGGr6_GLP_Male     0.951115
# 227                                    EOGGr6_GLP_Male     0.971688
# 228                                    EOGGr6_GLP_Male     0.959329
# 229                                    EOGGr6_GLP_Male     0.970607
# 230                                   EOGGr7_CACR_Male     0.985547
# 231                                   EOGGr7_CACR_Male     0.964794
# 232                                   EOGGr7_CACR_Male     0.966960
# 233                                   EOGGr7_CACR_Male     0.962409
# 234                                    EOGGr7_GLP_Male     0.966580
# 235                                    EOGGr7_GLP_Male     0.958809
# 236                                    EOGGr7_GLP_Male     0.963744
# 237                                   EOGGr8_CACR_Male     0.986375
# 238                             EOGMathGr3-8_CACR_Male     0.989164
# 239                             EOGMathGr3-8_CACR_Male     0.965666
# 240                             EOGMathGr3-8_CACR_Male     0.954934
# 241                              EOGMathGr3-8_GLP_Male     0.966943
# 242                              EOGMathGr3-8_GLP_Male     0.968855
# 243                               EOGMathGr6_CACR_Male     0.984281
# 244                               EOGMathGr7_CACR_Male     0.981014
# 245                               EOGMathGr8_CACR_Male     0.980409
# 246                          EOGReadingGr3-8_CACR_Male     0.986086
# 247                          EOGReadingGr3-8_CACR_Male     0.976972
# 248                          EOGReadingGr3-8_CACR_Male     0.971532
# 249                           EOGReadingGr3-8_GLP_Male     0.965517
# 250                           EOGReadingGr3-8_GLP_Male     0.976009
# 251                            EOGReadingGr6_CACR_Male     0.967840
# 252                            EOGReadingGr7_CACR_Male     0.972049
# 253                            EOGReadingGr8_CACR_Male     0.961714
# 254                          EOGScienceGr5&8_CACR_Male     0.976355
# 255                            EOGScienceGr8_CACR_Male     0.972406
# 256                              EOGSubjects_CACR_Male     0.992496
# 257                       EOCMathI_CACR_AmericanIndian     0.995782
# 258                    EOCSubjects_CACR_AmericanIndian     0.994158
# 259                EOG/EOCSubjects_CACR_AmericanIndian     0.961658
# 260                EOG/EOCSubjects_CACR_AmericanIndian     0.976474
# 261                 EOG/EOCSubjects_GLP_AmericanIndian     0.978598
# 262                         EOGGr6_CACR_AmericanIndian     0.961983
# 263                         EOGGr7_CACR_AmericanIndian     0.971779
# 264                         EOGGr8_CACR_AmericanIndian     0.970572
# 265                   EOGMathGr3-8_CACR_AmericanIndian     0.966595
# 266                     EOGMathGr6_CACR_AmericanIndian     0.976479
# 267                EOGReadingGr3-8_CACR_AmericanIndian     0.964604
# 268                  EOGReadingGr7_CACR_AmericanIndian     0.980340
# 269                EOGScienceGr5&8_CACR_AmericanIndian     0.981507
# 270                EOGScienceGr5&8_CACR_AmericanIndian     0.978169
# 271                EOGScienceGr5&8_CACR_AmericanIndian     0.963588
# 272                 EOGScienceGr5&8_GLP_AmericanIndian     0.955563
# 273                  EOGScienceGr8_CACR_AmericanIndian     0.987157
# 274                    EOGSubjects_CACR_AmericanIndian     0.961483
# 275                                EOCMathI_CACR_Asian     0.991042
# 276                                EOCMathI_CACR_Asian     0.983370
# 277                                EOCMathI_CACR_Asian     0.975857
# 278                                 EOCMathI_GLP_Asian     0.972824
# 279                                 EOCMathI_GLP_Asian     0.982318
# 280                             EOCSubjects_CACR_Asian     0.991483
# 281                         EOG/EOCSubjects_CACR_Asian     0.980619
# 282                         EOG/EOCSubjects_CACR_Asian     0.990425
# 283                         EOG/EOCSubjects_CACR_Asian     0.971690
# 284                          EOG/EOCSubjects_GLP_Asian     0.971557
# 285                          EOG/EOCSubjects_GLP_Asian     0.991972
# 286                                  EOGGr6_CACR_Asian     0.983979
# 287                                  EOGGr7_CACR_Asian     0.988093
# 288                                  EOGGr8_CACR_Asian     0.982973
# 289                            EOGMathGr3-8_CACR_Asian     0.987802
# 290                             EOGMathGr3-8_GLP_Asian     0.951481
# 291                              EOGMathGr6_CACR_Asian     0.987773
# 292                              EOGMathGr6_CACR_Asian     0.967678
# 293                              EOGMathGr6_CACR_Asian     0.968848
# 294                               EOGMathGr6_GLP_Asian     0.966152
# 295                               EOGMathGr6_GLP_Asian     0.977213
# 296                              EOGMathGr7_CACR_Asian     0.992677
# 297                              EOGMathGr7_CACR_Asian     0.968532
# 298                              EOGMathGr7_CACR_Asian     0.971307
# 299                               EOGMathGr7_GLP_Asian     0.965430
# 300                               EOGMathGr7_GLP_Asian     0.974627
# 301                              EOGMathGr8_CACR_Asian     0.987344
# 302                              EOGMathGr8_CACR_Asian     0.953598
# 303                               EOGMathGr8_GLP_Asian     0.952211
# 304                               EOGMathGr8_GLP_Asian     0.968235
# 305                               EOGMathGr8_GLP_Asian     0.961715
# 306                         EOGReadingGr3-8_CACR_Asian     0.972374
# 307                           EOGReadingGr6_CACR_Asian     0.982723
# 308                           EOGReadingGr7_CACR_Asian     0.983849
# 309                           EOGReadingGr8_CACR_Asian     0.978540
# 310                            EOGReadingGr8_GLP_Asian     0.965384
# 311                            EOGReadingGr8_GLP_Asian     0.958918
# 312                         EOGScienceGr5&8_CACR_Asian     0.988637
# 313                         EOGScienceGr5&8_CACR_Asian     0.980460
# 314                         EOGScienceGr5&8_CACR_Asian     0.970762
# 315                          EOGScienceGr5&8_GLP_Asian     0.965003
# 316                          EOGScienceGr5&8_GLP_Asian     0.974277
# 317                           EOGScienceGr8_CACR_Asian     0.990405
# 318                             EOGSubjects_CACR_Asian     0.979461
# 319                                EOCMathI_CACR_Black     0.968331
# 320                                EOCMathI_CACR_Black     0.994562
# 321                                EOCMathI_CACR_Black     0.963544
# 322                                 EOCMathI_GLP_Black     0.963531
# 323                                 EOCMathI_GLP_Black     0.995343
# 324                             EOCSubjects_CACR_Black     0.968638
# 325                         EOG/EOCSubjects_CACR_Black     0.950704
# 326                         EOG/EOCSubjects_CACR_Black     0.969464
# 327                          EOG/EOCSubjects_GLP_Black     0.962335
# 328                                  EOGGr7_CACR_Black     0.961503
# 329                                  EOGGr8_CACR_Black     0.956903
# 330                            EOGMathGr3-8_CACR_Black     0.958537
# 331                              EOGMathGr7_CACR_Black     0.955420
# 332                         EOGScienceGr5&8_CACR_Black     0.957416
# 333                         EOGScienceGr5&8_CACR_Black     0.970431
# 334                           EOGScienceGr8_CACR_Black     0.962871
# 335                             EOGSubjects_CACR_Black     0.950631
# 336                             EOCMathI_CACR_Hispanic     0.978523
# 337                             EOCMathI_CACR_Hispanic     0.983125
# 338                             EOCMathI_CACR_Hispanic     0.957483
# 339                              EOCMathI_GLP_Hispanic     0.962163
# 340                              EOCMathI_GLP_Hispanic     0.977433
# 341                          EOCSubjects_CACR_Hispanic     0.979074
# 342                      EOG/EOCSubjects_CACR_Hispanic     0.952486
# 343                      EOG/EOCSubjects_CACR_Hispanic     0.968686
# 344                       EOG/EOCSubjects_GLP_Hispanic     0.967190
# 345                               EOGGr7_CACR_Hispanic     0.958619
# 346                               EOGGr8_CACR_Hispanic     0.954143
# 347                           EOGMathGr6_CACR_Hispanic     0.957854
# 348                      EOGScienceGr5&8_CACR_Hispanic     0.958582
# 349                        EOGScienceGr8_CACR_Hispanic     0.965887
# 350                          EOGSubjects_CACR_Hispanic     0.950383
# 351                       EOCMathI_CACR_TwoorMoreRaces     0.973798
# 352                       EOCMathI_CACR_TwoorMoreRaces     0.974008
# 353                        EOCMathI_GLP_TwoorMoreRaces     0.967826
# 354                    EOCSubjects_CACR_TwoorMoreRaces     0.975079
# 355                EOG/EOCSubjects_CACR_TwoorMoreRaces     0.983932
# 356                 EOG/EOCSubjects_GLP_TwoorMoreRaces     0.983305
# 357                         EOGGr6_CACR_TwoorMoreRaces     0.959266
# 358                         EOGGr7_CACR_TwoorMoreRaces     0.967348
# 359                         EOGGr8_CACR_TwoorMoreRaces     0.961605
# 360                   EOGMathGr3-8_CACR_TwoorMoreRaces     0.950270
# 361                     EOGMathGr6_CACR_TwoorMoreRaces     0.966433
# 362                     EOGMathGr7_CACR_TwoorMoreRaces     0.961101
# 363                     EOGMathGr8_CACR_TwoorMoreRaces     0.955960
# 364                  EOGReadingGr6_CACR_TwoorMoreRaces     0.954185
# 365                  EOGReadingGr7_CACR_TwoorMoreRaces     0.960839
# 366                EOGScienceGr5&8_CACR_TwoorMoreRaces     0.967031
# 367                EOGScienceGr5&8_CACR_TwoorMoreRaces     0.951134
# 368                  EOGScienceGr8_CACR_TwoorMoreRaces     0.970514
# 369                                EOCMathI_CACR_White     0.969903
# 370                                EOCMathI_CACR_White     0.996608
# 371                                EOCMathI_CACR_White     0.967318
# 372                                 EOCMathI_GLP_White     0.970394
# 373                                 EOCMathI_GLP_White     0.998304
# 374                             EOCSubjects_CACR_White     0.971625
# 375                         EOG/EOCSubjects_CACR_White     0.985790
# 376                         EOG/EOCSubjects_CACR_White     0.951215
# 377                                  EOGGr6_CACR_White     0.983027
# 378                                  EOGGr6_CACR_White     0.955295
# 379                                  EOGGr6_CACR_White     0.952452
# 380                                   EOGGr6_GLP_White     0.953159
# 381                                  EOGGr7_CACR_White     0.984572
# 382                                  EOGGr7_CACR_White     0.968556
# 383                                  EOGGr7_CACR_White     0.968206
# 384                                  EOGGr7_CACR_White     0.964928
# 385                                   EOGGr7_GLP_White     0.967482
# 386                                   EOGGr7_GLP_White     0.964212
# 387                                   EOGGr7_GLP_White     0.965188
# 388                                  EOGGr8_CACR_White     0.984758
# 389                            EOGMathGr3-8_CACR_White     0.986883
# 390                            EOGMathGr3-8_CACR_White     0.958879
# 391                             EOGMathGr3-8_GLP_White     0.950296
# 392                              EOGMathGr6_CACR_White     0.981275
# 393                              EOGMathGr7_CACR_White     0.979718
# 394                              EOGMathGr8_CACR_White     0.977899
# 395                         EOGReadingGr3-8_CACR_White     0.974725
# 396                           EOGReadingGr6_CACR_White     0.975736
# 397                           EOGReadingGr7_CACR_White     0.973184
# 398                           EOGReadingGr8_CACR_White     0.964290
# 399                         EOGScienceGr5&8_CACR_White     0.971456
# 400                           EOGScienceGr8_CACR_White     0.978710
# 401                             EOGSubjects_CACR_White     0.986096
# 402                                  EOCMathI_CACR_EDS     0.958839
# 403                                  EOCMathI_CACR_EDS     0.993535
# 404                                  EOCMathI_CACR_EDS     0.952610
# 405                                   EOCMathI_GLP_EDS     0.952594
# 406                                   EOCMathI_GLP_EDS     0.993031
# 407                               EOCSubjects_CACR_EDS     0.959345
# 408                           EOG/EOCSubjects_CACR_EDS     0.987534
# 409                           EOG/EOCSubjects_CACR_EDS     0.970054
# 410                                    EOGGr6_CACR_EDS     0.970557
# 411                                    EOGGr7_CACR_EDS     0.974883
# 412                                    EOGGr8_CACR_EDS     0.977972
# 413                              EOGMathGr3-8_CACR_EDS     0.984661
# 414                                EOGMathGr6_CACR_EDS     0.963712
# 415                                EOGMathGr7_CACR_EDS     0.970295
# 416                                EOGMathGr8_CACR_EDS     0.963787
# 417                           EOGReadingGr3-8_CACR_EDS     0.971737
# 418                           EOGReadingGr3-8_CACR_EDS     0.954366
# 419                            EOGReadingGr3-8_GLP_EDS     0.953572
# 420                             EOGReadingGr6_CACR_EDS     0.956135
# 421                             EOGReadingGr7_CACR_EDS     0.958416
# 422                           EOGScienceGr5&8_CACR_EDS     0.964448
# 423                             EOGScienceGr8_CACR_EDS     0.965886
# 424                               EOGSubjects_CACR_EDS     0.987641
# 425                                  EOCMathI_CACR_LEP     0.986153
# 426                                  EOCMathI_CACR_LEP     0.950071
# 427                                   EOCMathI_GLP_LEP     0.981679
# 428                               EOCSubjects_CACR_LEP     0.958157
# 429                           EOG/EOCSubjects_CACR_LEP     0.988678
# 430                            EOG/EOCSubjects_GLP_LEP     0.992647
# 431                           EOGScienceGr5&8_CACR_LEP     0.968874
# 432                            EOGScienceGr5&8_GLP_LEP     0.971570
# 433                                  EOCMathI_CACR_SWD     0.952891
# 434                               EOCSubjects_CACR_SWD     0.964712
# 435                           EOG/EOCSubjects_CACR_SWD     0.958701
# 436                               EOGSubjects_CACR_SWD     0.954075
# 437                                  EOCMathI_CACR_AIG     0.978757
# 438                                  EOCMathI_CACR_AIG     0.956487
# 439                                   EOCMathI_GLP_AIG     0.953536
# 440                               EOCSubjects_CACR_AIG     0.977193
# 441                                    EOGGr6_CACR_AIG     0.986263
# 442                                    EOGGr7_CACR_AIG     0.981439
# 443                                    EOGGr8_CACR_AIG     0.973906
# 444                              EOGMathGr3-8_CACR_AIG     0.963093
# 445                                EOGMathGr6_CACR_AIG     0.988086
# 446                                EOGMathGr6_CACR_AIG     0.954971
# 447                                EOGMathGr6_CACR_AIG     0.954707
# 448                                 EOGMathGr6_GLP_AIG     0.970832
# 449                                 EOGMathGr6_GLP_AIG     0.975059
# 450                                EOGMathGr7_CACR_AIG     0.981758
# 451                                 EOGMathGr7_GLP_AIG     0.960968
# 452                                 EOGMathGr7_GLP_AIG     0.967608
# 453                                EOGMathGr8_CACR_AIG     0.977388
# 454                                 EOGMathGr8_GLP_AIG     0.950099
# 455                           EOGReadingGr3-8_CACR_AIG     0.950148
# 456                             EOGReadingGr6_CACR_AIG     0.987774
# 457                             EOGReadingGr7_CACR_AIG     0.986534
# 458                             EOGReadingGr8_CACR_AIG     0.971929
# 459                             EOGReadingGr8_CACR_AIG     0.958574
# 460                              EOGReadingGr8_GLP_AIG     0.978790
# 461                              EOGReadingGr8_GLP_AIG     0.981113
# 462                           EOGScienceGr5&8_CACR_AIG     0.982075
# 463                             EOGScienceGr8_CACR_AIG     0.989911
# 464                               EOGSubjects_CACR_AIG     0.961715
# 465                            st_avg_daily_attend_pct     0.998278
# 466                            st_avg_daily_attend_pct     0.962203
# 467                            st_avg_daily_attend_pct     0.962203
# 468                                 st_crime_per_c_num     0.978688
# 469                                 st_crime_per_c_num     0.983131
# 470                            st_short_susp_per_c_num     0.972709
# 471                            st_short_susp_per_c_num     0.972709
# 472                                  tchyrs_0thru3_pct     1.000000
# 473                                 tchyrs_4thru10_pct     1.000000
# 474                                  tchyrs_11plus_pct     1.000000
# 475                            lea_flicensed_teach_pct     0.963817
# 476                                 st_class_teach_num     0.974707
# 477                                 st_class_teach_num     0.962032
# 478                                 st_class_teach_num     0.962032
# 479                                 st_advance_dgr_pct     0.979218
# 480                                 st_advance_dgr_pct     0.979218
# 481                                     AsianFemalePct     0.966062
# 482                                       AsianMalePct     0.970589
# 483                                     BlackFemalePct     0.954577
# 484                                     BlackFemalePct     0.988185
# 485                                       BlackMalePct     0.988967
# 486                                  HispanicFemalePct     0.985986
# 487                                    HispanicMalePct     0.987605
# 488                                    IndianFemalePct     0.984778
# 489                                    IndianFemalePct     0.995968
# 490                                      IndianMalePct     0.996400
# 491                                  MinorityFemalePct     0.980175
# 492                                  MinorityFemalePct     0.980291
# 493                                  MinorityFemalePct     0.980175
# 494                                    MinorityMalePct     0.981869
# 495                                    MinorityMalePct     0.980530
# 496                                    MinorityMalePct     0.953063
# 497                                    MinorityMalePct     0.981869
# 498                                        MinorityPct     0.983543
# 499                                        MinorityPct     0.985052
# 500                                        MinorityPct     1.000000
# 501                                     WhiteFemalePct     0.983543
# 502                                       WhiteMalePct     0.985052
# 503                                      category_cd_I     1.000000
# 504                                      category_cd_M     1.000000
# 505                                      category_cd_T     1.000000
# 506  calendar_type_txt_Regular School, Year-Round C...     1.000000
# 507  calendar_type_txt_Regular School, Year-Round C...     1.000000
# 508                                  sna_pgm_type_cd_Y     1.000000

# %%
print 'Dropping the following ', str(len(to_drop)), ' highly correlated fields.'
to_drop
# Out:
# Dropping the following  269  highly correlated fields.
# ['Overall Achievement Score',
#  'Read Score',
#  'Math Score',
#  'EOCMathI_CACR_All',
#  'EOCMathI_GLP_All',
#  'EOCSubjects_CACR_All',
#  'EOCSubjects_GLP_All',
#  'EOG/EOCSubjects_CACR_All',
#  'EOG/EOCSubjects_GLP_All',
#  'EOGGr6_GLP_All',
#  'EOGGr7_GLP_All',
#  'EOGGr8_GLP_All',
#  'EOGMathGr3-8_CACR_All',
#  'EOGMathGr3-8_GLP_All',
#  'EOGMathGr6_CACR_All',
#  'EOGMathGr6_GLP_All',
#  'EOGMathGr7_CACR_All',
#  'EOGMathGr7_GLP_All',
#  'EOGMathGr8_GLP_All',
#  'EOGReadingGr3-8_CACR_All',
#  'EOGReadingGr3-8_GLP_All',
#  'EOGReadingGr6_CACR_All',
#  'EOGReadingGr6_GLP_All',
#  'EOGReadingGr7_CACR_All',
#  'EOGReadingGr7_GLP_All',
#  'EOGReadingGr8_CACR_All',
#  'EOGReadingGr8_GLP_All',
#  'EOGScienceGr5&8_CACR_All',
#  'EOGScienceGr5&8_GLP_All',
#  'EOGScienceGr8_GLP_All',
#  'EOGSubjects_CACR_All',
#  'EOGSubjects_GLP_All',
#  'EOCMathI_GLP_Female',
#  'EOCSubjects_CACR_Female',
#  'EOCSubjects_GLP_Female',
#  'EOG/EOCSubjects_CACR_Female',
#  'EOG/EOCSubjects_GLP_Female',
#  'EOGGr6_CACR_Female',
#  'EOGGr6_GLP_Female',
#  'EOGGr7_CACR_Female',
#  'EOGGr7_GLP_Female',
#  'EOGGr8_CACR_Female',
#  'EOGGr8_GLP_Female',
#  'EOGMathGr3-8_CACR_Female',
#  'EOGMathGr3-8_GLP_Female',
#  'EOGMathGr6_CACR_Female',
#  'EOGMathGr6_GLP_Female',
#  'EOGMathGr7_CACR_Female',
#  'EOGMathGr7_GLP_Female',
#  'EOGMathGr8_CACR_Female',
#  'EOGMathGr8_GLP_Female',
#  'EOGReadingGr3-8_CACR_Female',
#  'EOGReadingGr3-8_GLP_Female',
#  'EOGReadingGr6_GLP_Female',
#  'EOGReadingGr7_CACR_Female',
#  'EOGReadingGr7_GLP_Female',
#  'EOGReadingGr8_CACR_Female',
#  'EOGReadingGr8_GLP_Female',
#  'EOGScienceGr5&8_CACR_Female',
#  'EOGScienceGr5&8_GLP_Female',
#  'EOGScienceGr8_GLP_Female',
#  'EOGSubjects_CACR_Female',
#  'EOGSubjects_GLP_Female',
#  'EOCMathI_GLP_Male',
#  'EOCSubjects_CACR_Male',
#  'EOCSubjects_GLP_Male',
#  'EOG/EOCSubjects_CACR_Male',
#  'EOG/EOCSubjects_GLP_Male',
#  'EOGGr6_CACR_Male',
#  'EOGGr6_GLP_Male',
#  'EOGGr7_CACR_Male',
#  'EOGGr7_GLP_Male',
#  'EOGGr8_CACR_Male',
#  'EOGGr8_GLP_Male',
#  'EOGMathGr3-8_CACR_Male',
#  'EOGMathGr3-8_GLP_Male',
#  'EOGMathGr6_CACR_Male',
#  'EOGMathGr6_GLP_Male',
#  'EOGMathGr7_CACR_Male',
#  'EOGMathGr7_GLP_Male',
#  'EOGMathGr8_GLP_Male',
#  'EOGReadingGr3-8_CACR_Male',
#  'EOGReadingGr3-8_GLP_Male',
#  'EOGReadingGr6_CACR_Male',
#  'EOGReadingGr6_GLP_Male',
#  'EOGReadingGr7_CACR_Male',
#  'EOGReadingGr7_GLP_Male',
#  'EOGReadingGr8_GLP_Male',
#  'EOGScienceGr5&8_CACR_Male',
#  'EOGScienceGr5&8_GLP_Male',
#  'EOGScienceGr8_GLP_Male',
#  'EOGSubjects_CACR_Male',
#  'EOGSubjects_GLP_Male',
#  'EOCMathI_GLP_AmericanIndian',
#  'EOCSubjects_GLP_AmericanIndian',
#  'EOG/EOCSubjects_GLP_AmericanIndian',
#  'EOGGr6_GLP_AmericanIndian',
#  'EOGGr7_GLP_AmericanIndian',
#  'EOGGr8_GLP_AmericanIndian',
#  'EOGMathGr3-8_GLP_AmericanIndian',
#  'EOGMathGr6_GLP_AmericanIndian',
#  'EOGReadingGr3-8_GLP_AmericanIndian',
#  'EOGReadingGr7_GLP_AmericanIndian',
#  'EOGScienceGr5&8_GLP_AmericanIndian',
#  'EOGScienceGr8_CACR_AmericanIndian',
#  'EOGScienceGr8_GLP_AmericanIndian',
#  'EOGSubjects_CACR_AmericanIndian',
#  'EOGSubjects_GLP_AmericanIndian',
#  'EOCMathI_GLP_Asian',
#  'EOCSubjects_CACR_Asian',
#  'EOCSubjects_GLP_Asian',
#  'EOG/EOCSubjects_GLP_Asian',
#  'EOGGr6_GLP_Asian',
#  'EOGGr7_GLP_Asian',
#  'EOGGr8_GLP_Asian',
#  'EOGMathGr3-8_GLP_Asian',
#  'EOGMathGr6_GLP_Asian',
#  'EOGMathGr7_GLP_Asian',
#  'EOGMathGr8_GLP_Asian',
#  'EOGReadingGr3-8_GLP_Asian',
#  'EOGReadingGr6_CACR_Asian',
#  'EOGReadingGr6_GLP_Asian',
#  'EOGReadingGr7_CACR_Asian',
#  'EOGReadingGr7_GLP_Asian',
#  'EOGReadingGr8_GLP_Asian',
#  'EOGScienceGr5&8_GLP_Asian',
#  'EOGScienceGr8_CACR_Asian',
#  'EOGScienceGr8_GLP_Asian',
#  'EOGSubjects_CACR_Asian',
#  'EOGSubjects_GLP_Asian',
#  'EOCMathI_GLP_Black',
#  'EOCSubjects_CACR_Black',
#  'EOCSubjects_GLP_Black',
#  'EOG/EOCSubjects_GLP_Black',
#  'EOGGr7_GLP_Black',
#  'EOGGr8_GLP_Black',
#  'EOGMathGr3-8_GLP_Black',
#  'EOGMathGr7_GLP_Black',
#  'EOGScienceGr5&8_GLP_Black',
#  'EOGScienceGr8_CACR_Black',
#  'EOGScienceGr8_GLP_Black',
#  'EOGSubjects_CACR_Black',
#  'EOGSubjects_GLP_Black',
#  'EOCMathI_GLP_Hispanic',
#  'EOCSubjects_CACR_Hispanic',
#  'EOCSubjects_GLP_Hispanic',
#  'EOG/EOCSubjects_GLP_Hispanic',
#  'EOGGr7_GLP_Hispanic',
#  'EOGGr8_GLP_Hispanic',
#  'EOGMathGr6_GLP_Hispanic',
#  'EOGScienceGr5&8_GLP_Hispanic',
#  'EOGScienceGr8_GLP_Hispanic',
#  'EOGSubjects_CACR_Hispanic',
#  'EOGSubjects_GLP_Hispanic',
#  'EOCMathI_GLP_TwoorMoreRaces',
#  'EOCSubjects_CACR_TwoorMoreRaces',
#  'EOCSubjects_GLP_TwoorMoreRaces',
#  'EOGGr6_GLP_TwoorMoreRaces',
#  'EOGGr7_GLP_TwoorMoreRaces',
#  'EOGGr8_GLP_TwoorMoreRaces',
#  'EOGMathGr3-8_GLP_TwoorMoreRaces',
#  'EOGMathGr6_GLP_TwoorMoreRaces',
#  'EOGMathGr7_GLP_TwoorMoreRaces',
#  'EOGMathGr8_GLP_TwoorMoreRaces',
#  'EOGReadingGr6_GLP_TwoorMoreRaces',
#  'EOGReadingGr7_GLP_TwoorMoreRaces',
#  'EOGScienceGr5&8_GLP_TwoorMoreRaces',
#  'EOGScienceGr8_CACR_TwoorMoreRaces',
#  'EOGScienceGr8_GLP_TwoorMoreRaces',
#  'EOGSubjects_CACR_TwoorMoreRaces',
#  'EOGSubjects_GLP_TwoorMoreRaces',
#  'EOCMathI_GLP_White',
#  'EOCSubjects_CACR_White',
#  'EOCSubjects_GLP_White',
#  'EOG/EOCSubjects_GLP_White',
#  'EOGGr6_GLP_White',
#  'EOGGr7_GLP_White',
#  'EOGGr8_GLP_White',
#  'EOGMathGr3-8_GLP_White',
#  'EOGMathGr6_CACR_White',
#  'EOGMathGr6_GLP_White',
#  'EOGMathGr7_CACR_White',
#  'EOGMathGr7_GLP_White',
#  'EOGMathGr8_GLP_White',
#  'EOGReadingGr3-8_GLP_White',
#  'EOGReadingGr6_GLP_White',
#  'EOGReadingGr7_CACR_White',
#  'EOGReadingGr7_GLP_White',
#  'EOGReadingGr8_GLP_White',
#  'EOGScienceGr5&8_GLP_White',
#  'EOGScienceGr8_GLP_White',
#  'EOGSubjects_CACR_White',
#  'EOGSubjects_GLP_White',
#  'EOCMathI_GLP_EDS',
#  'EOCSubjects_CACR_EDS',
#  'EOCSubjects_GLP_EDS',
#  'EOG/EOCSubjects_GLP_EDS',
#  'EOGGr6_GLP_EDS',
#  'EOGGr7_GLP_EDS',
#  'EOGGr8_GLP_EDS',
#  'EOGMathGr3-8_GLP_EDS',
#  'EOGMathGr6_GLP_EDS',
#  'EOGMathGr7_GLP_EDS',
#  'EOGMathGr8_GLP_EDS',
#  'EOGReadingGr3-8_GLP_EDS',
#  'EOGReadingGr6_GLP_EDS',
#  'EOGReadingGr7_GLP_EDS',
#  'EOGScienceGr5&8_GLP_EDS',
#  'EOGScienceGr8_GLP_EDS',
#  'EOGSubjects_CACR_EDS',
#  'EOGSubjects_GLP_EDS',
#  'EOCSubjects_CACR_LEP',
#  'EOCSubjects_GLP_LEP',
#  'EOGScienceGr8_CACR_LEP',
#  'EOGScienceGr8_GLP_LEP',
#  'EOGSubjects_CACR_LEP',
#  'EOGSubjects_GLP_LEP',
#  'EOCMathI_GLP_SWD',
#  'EOCSubjects_GLP_SWD',
#  'EOG/EOCSubjects_GLP_SWD',
#  'EOGSubjects_GLP_SWD',
#  'EOCMathI_GLP_AIG',
#  'EOCSubjects_CACR_AIG',
#  'EOCSubjects_GLP_AIG',
#  'EOGGr6_GLP_AIG',
#  'EOGGr7_GLP_AIG',
#  'EOGGr8_GLP_AIG',
#  'EOGMathGr3-8_GLP_AIG',
#  'EOGMathGr6_GLP_AIG',
#  'EOGMathGr7_GLP_AIG',
#  'EOGMathGr8_GLP_AIG',
#  'EOGReadingGr3-8_GLP_AIG',
#  'EOGReadingGr6_CACR_AIG',
#  'EOGReadingGr6_GLP_AIG',
#  'EOGReadingGr7_CACR_AIG',
#  'EOGReadingGr7_GLP_AIG',
#  'EOGReadingGr8_GLP_AIG',
#  'EOGScienceGr5&8_GLP_AIG',
#  'EOGScienceGr8_CACR_AIG',
#  'EOGScienceGr8_GLP_AIG',
#  'EOGSubjects_GLP_AIG',
#  'st_short_susp_per_c_num',
#  'class_teach_num',
#  'lea_class_teach_num',
#  'lea_lateral_teach_pct',
#  'st_class_teach_num',
#  'st_advance_dgr_pct',
#  'st_emer_prov_teach_pct',
#  'st_lateral_teach_pct',
#  '0-3 Years_Exp_Pct_Tch',
#  '10+ Years_Exp_Pct_Tch',
#  '4-10 Years_Exp_Pct_Tch',
#  'AsianPct',
#  'BlackMalePct',
#  'BlackPct',
#  'HispanicPct',
#  'IndianMalePct',
#  'IndianPct',
#  'MinorityPct',
#  'WhiteFemalePct',
#  'WhiteMalePct',
#  'WhitePct',
#  'category_cd_I',
#  'category_cd_M',
#  'sna_pgm_type_cd_Y',
#  'calendar_only_txt_Year-Round Calendar',
#  'Category_Cd_I',
#  'Category_Cd_M',
#  'Category_Cd_T']

# %%
#Check columns before drop 
print('\r\n*********Before: Dropping Highly Correlated Fields*************************************')
schoolData.info(verbose=False)

# Drop the highly correlated features from our training data 
schoolData = schoolData.drop(to_drop, axis=1)

#Check columns after drop 
print('\r\n*********After: Dropping Highly Correlated Fields**************************************')
schoolData.info(verbose=False)
# Out:
# *********Before: Dropping Highly Correlated Fields*************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 538 entries, 0 to 537
# Columns: 623 entries, student_num to esea_attendance_Met
# dtypes: float64(575), uint8(48)
# memory usage: 2.4 MB
#
# *********After: Dropping Highly Correlated Fields**************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 538 entries, 0 to 537
# Columns: 354 entries, student_num to esea_attendance_Met
# dtypes: float64(313), uint8(41)
# memory usage: 1.3 MB

# %%
#Restore the unit_code before saving
schoolData['unit_code'] = unit_code
#Save the final dataset to a .csv file
schoolData.to_csv(outputDir + inputFileName + '_ML.csv', sep=',', index=False)

# %%
print('*********FINAL DATASET DETAILS*********************************************************\r\n')
schoolData.info(verbose=True)
# Out:
# *********FINAL DATASET DETAILS*********************************************************
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 538 entries, 0 to 537
# Data columns (total 355 columns):
# student_num                                              float64
# lea_avg_student_num                                      float64
# st_avg_student_num                                       float64
# Math I_Size                                              float64
# lea_total_expense_num                                    float64
# lea_salary_expense_pct                                   float64
# lea_benefits_expense_pct                                 float64
# lea_services_expense_pct                                 float64
# lea_supplies_expense_pct                                 float64
# lea_instruct_equip_exp_pct                               float64
# lea_federal_perpupil_num                                 float64
# lea_local_perpupil_num                                   float64
# lea_state_perpupil_num                                   float64
# SBE Region                                               float64
# SPG Score                                                float64
# Reading  SPG Score                                       float64
# Math SPG Score                                           float64
# EVAAS Growth Score                                       float64
# Science Score                                            float64
# Math I Score                                             float64
# EOGGr6_CACR_All                                          float64
# EOGGr7_CACR_All                                          float64
# EOGGr8_CACR_All                                          float64
# EOGMathGr8_CACR_All                                      float64
# EOGScienceGr8_CACR_All                                   float64
# EOCMathI_CACR_Female                                     float64
# EOGReadingGr6_CACR_Female                                float64
# EOGScienceGr8_CACR_Female                                float64
# EOCMathI_CACR_Male                                       float64
# EOGMathGr8_CACR_Male                                     float64
# EOGReadingGr8_CACR_Male                                  float64
# EOGScienceGr8_CACR_Male                                  float64
# EOCMathI_CACR_AmericanIndian                             float64
# EOCSubjects_CACR_AmericanIndian                          float64
# EOG/EOCSubjects_CACR_AmericanIndian                      float64
# EOGGr6_CACR_AmericanIndian                               float64
# EOGGr7_CACR_AmericanIndian                               float64
# EOGGr8_CACR_AmericanIndian                               float64
# EOGMathGr3-8_CACR_AmericanIndian                         float64
# EOGMathGr6_CACR_AmericanIndian                           float64
# EOGMathGr7_CACR_AmericanIndian                           float64
# EOGMathGr7_GLP_AmericanIndian                            float64
# EOGMathGr8_CACR_AmericanIndian                           float64
# EOGMathGr8_GLP_AmericanIndian                            float64
# EOGReadingGr3-8_CACR_AmericanIndian                      float64
# EOGReadingGr6_CACR_AmericanIndian                        float64
# EOGReadingGr6_GLP_AmericanIndian                         float64
# EOGReadingGr7_CACR_AmericanIndian                        float64
# EOGReadingGr8_CACR_AmericanIndian                        float64
# EOGReadingGr8_GLP_AmericanIndian                         float64
# EOGScienceGr5&8_CACR_AmericanIndian                      float64
# EOCMathI_CACR_Asian                                      float64
# EOG/EOCSubjects_CACR_Asian                               float64
# EOGGr6_CACR_Asian                                        float64
# EOGGr7_CACR_Asian                                        float64
# EOGGr8_CACR_Asian                                        float64
# EOGMathGr3-8_CACR_Asian                                  float64
# EOGMathGr6_CACR_Asian                                    float64
# EOGMathGr7_CACR_Asian                                    float64
# EOGMathGr8_CACR_Asian                                    float64
# EOGReadingGr3-8_CACR_Asian                               float64
# EOGReadingGr8_CACR_Asian                                 float64
# EOGScienceGr5&8_CACR_Asian                               float64
# EOCMathI_CACR_Black                                      float64
# EOG/EOCSubjects_CACR_Black                               float64
# EOGGr6_CACR_Black                                        float64
# EOGGr6_GLP_Black                                         float64
# EOGGr7_CACR_Black                                        float64
# EOGGr8_CACR_Black                                        float64
# EOGMathGr3-8_CACR_Black                                  float64
# EOGMathGr6_CACR_Black                                    float64
# EOGMathGr6_GLP_Black                                     float64
# EOGMathGr7_CACR_Black                                    float64
# EOGMathGr8_CACR_Black                                    float64
# EOGMathGr8_GLP_Black                                     float64
# EOGReadingGr3-8_CACR_Black                               float64
# EOGReadingGr3-8_GLP_Black                                float64
# EOGReadingGr6_CACR_Black                                 float64
# EOGReadingGr6_GLP_Black                                  float64
# EOGReadingGr7_CACR_Black                                 float64
# EOGReadingGr7_GLP_Black                                  float64
# EOGReadingGr8_CACR_Black                                 float64
# EOGReadingGr8_GLP_Black                                  float64
# EOGScienceGr5&8_CACR_Black                               float64
# EOCMathI_CACR_Hispanic                                   float64
# EOG/EOCSubjects_CACR_Hispanic                            float64
# EOGGr6_CACR_Hispanic                                     float64
# EOGGr6_GLP_Hispanic                                      float64
# EOGGr7_CACR_Hispanic                                     float64
# EOGGr8_CACR_Hispanic                                     float64
# EOGMathGr3-8_CACR_Hispanic                               float64
# EOGMathGr3-8_GLP_Hispanic                                float64
# EOGMathGr6_CACR_Hispanic                                 float64
# EOGMathGr7_CACR_Hispanic                                 float64
# EOGMathGr7_GLP_Hispanic                                  float64
# EOGMathGr8_CACR_Hispanic                                 float64
# EOGMathGr8_GLP_Hispanic                                  float64
# EOGReadingGr3-8_CACR_Hispanic                            float64
# EOGReadingGr3-8_GLP_Hispanic                             float64
# EOGReadingGr6_CACR_Hispanic                              float64
# EOGReadingGr6_GLP_Hispanic                               float64
# EOGReadingGr7_CACR_Hispanic                              float64
# EOGReadingGr7_GLP_Hispanic                               float64
# EOGReadingGr8_CACR_Hispanic                              float64
# EOGReadingGr8_GLP_Hispanic                               float64
# EOGScienceGr5&8_CACR_Hispanic                            float64
# EOGScienceGr8_CACR_Hispanic                              float64
# EOCMathI_CACR_TwoorMoreRaces                             float64
# EOG/EOCSubjects_CACR_TwoorMoreRaces                      float64
# EOG/EOCSubjects_GLP_TwoorMoreRaces                       float64
# EOGGr6_CACR_TwoorMoreRaces                               float64
# EOGGr7_CACR_TwoorMoreRaces                               float64
# EOGGr8_CACR_TwoorMoreRaces                               float64
# EOGMathGr3-8_CACR_TwoorMoreRaces                         float64
# EOGMathGr6_CACR_TwoorMoreRaces                           float64
# EOGMathGr7_CACR_TwoorMoreRaces                           float64
# EOGMathGr8_CACR_TwoorMoreRaces                           float64
# EOGReadingGr3-8_CACR_TwoorMoreRaces                      float64
# EOGReadingGr3-8_GLP_TwoorMoreRaces                       float64
# EOGReadingGr6_CACR_TwoorMoreRaces                        float64
# EOGReadingGr7_CACR_TwoorMoreRaces                        float64
# EOGReadingGr8_CACR_TwoorMoreRaces                        float64
# EOGReadingGr8_GLP_TwoorMoreRaces                         float64
# EOGScienceGr5&8_CACR_TwoorMoreRaces                      float64
# EOCMathI_CACR_White                                      float64
# EOG/EOCSubjects_CACR_White                               float64
# EOGGr6_CACR_White                                        float64
# EOGGr7_CACR_White                                        float64
# EOGGr8_CACR_White                                        float64
# EOGMathGr3-8_CACR_White                                  float64
# EOGMathGr8_CACR_White                                    float64
# EOGReadingGr3-8_CACR_White                               float64
# EOGReadingGr6_CACR_White                                 float64
# EOGReadingGr8_CACR_White                                 float64
# EOGScienceGr5&8_CACR_White                               float64
# EOGScienceGr8_CACR_White                                 float64
# EOCMathI_CACR_EDS                                        float64
# EOG/EOCSubjects_CACR_EDS                                 float64
# EOGGr6_CACR_EDS                                          float64
# EOGGr7_CACR_EDS                                          float64
# EOGGr8_CACR_EDS                                          float64
# EOGMathGr3-8_CACR_EDS                                    float64
# EOGMathGr6_CACR_EDS                                      float64
# EOGMathGr7_CACR_EDS                                      float64
# EOGMathGr8_CACR_EDS                                      float64
# EOGReadingGr3-8_CACR_EDS                                 float64
# EOGReadingGr6_CACR_EDS                                   float64
# EOGReadingGr7_CACR_EDS                                   float64
# EOGReadingGr8_CACR_EDS                                   float64
# EOGReadingGr8_GLP_EDS                                    float64
# EOGScienceGr5&8_CACR_EDS                                 float64
# EOGScienceGr8_CACR_EDS                                   float64
# EOCMathI_CACR_LEP                                        float64
# EOCMathI_GLP_LEP                                         float64
# EOG/EOCSubjects_CACR_LEP                                 float64
# EOG/EOCSubjects_GLP_LEP                                  float64
# EOGGr6_CACR_LEP                                          float64
# EOGGr6_GLP_LEP                                           float64
# EOGGr7_CACR_LEP                                          float64
# EOGGr7_GLP_LEP                                           float64
# EOGGr8_CACR_LEP                                          float64
# EOGGr8_GLP_LEP                                           float64
# EOGMathGr3-8_CACR_LEP                                    float64
# EOGMathGr3-8_GLP_LEP                                     float64
# EOGMathGr6_CACR_LEP                                      float64
# EOGMathGr6_GLP_LEP                                       float64
# EOGMathGr7_CACR_LEP                                      float64
# EOGMathGr7_GLP_LEP                                       float64
# EOGMathGr8_CACR_LEP                                      float64
# EOGMathGr8_GLP_LEP                                       float64
# EOGReadingGr3-8_CACR_LEP                                 float64
# EOGReadingGr3-8_GLP_LEP                                  float64
# EOGReadingGr6_CACR_LEP                                   float64
# EOGReadingGr6_GLP_LEP                                    float64
# EOGReadingGr7_CACR_LEP                                   float64
# EOGReadingGr7_GLP_LEP                                    float64
# EOGReadingGr8_CACR_LEP                                   float64
# EOGReadingGr8_GLP_LEP                                    float64
# EOGScienceGr5&8_CACR_LEP                                 float64
# EOGScienceGr5&8_GLP_LEP                                  float64
# EOCMathI_CACR_SWD                                        float64
# EOCSubjects_CACR_SWD                                     float64
# EOG/EOCSubjects_CACR_SWD                                 float64
# EOGGr6_CACR_SWD                                          float64
# EOGGr6_GLP_SWD                                           float64
# EOGGr7_CACR_SWD                                          float64
# EOGGr7_GLP_SWD                                           float64
# EOGGr8_CACR_SWD                                          float64
# EOGGr8_GLP_SWD                                           float64
# EOGMathGr3-8_CACR_SWD                                    float64
# EOGMathGr3-8_GLP_SWD                                     float64
# EOGMathGr6_CACR_SWD                                      float64
# EOGMathGr6_GLP_SWD                                       float64
# EOGMathGr7_CACR_SWD                                      float64
# EOGMathGr7_GLP_SWD                                       float64
# EOGMathGr8_CACR_SWD                                      float64
# EOGMathGr8_GLP_SWD                                       float64
# EOGReadingGr3-8_CACR_SWD                                 float64
# EOGReadingGr3-8_GLP_SWD                                  float64
# EOGReadingGr6_CACR_SWD                                   float64
# EOGReadingGr6_GLP_SWD                                    float64
# EOGReadingGr7_CACR_SWD                                   float64
# EOGReadingGr7_GLP_SWD                                    float64
# EOGReadingGr8_CACR_SWD                                   float64
# EOGReadingGr8_GLP_SWD                                    float64
# EOGScienceGr5&8_CACR_SWD                                 float64
# EOGScienceGr5&8_GLP_SWD                                  float64
# EOGScienceGr8_CACR_SWD                                   float64
# EOGScienceGr8_GLP_SWD                                    float64
# EOGSubjects_CACR_SWD                                     float64
# EOCMathI_CACR_AIG                                        float64
# EOG/EOCSubjects_CACR_AIG                                 float64
# EOG/EOCSubjects_GLP_AIG                                  float64
# EOGGr6_CACR_AIG                                          float64
# EOGGr7_CACR_AIG                                          float64
# EOGGr8_CACR_AIG                                          float64
# EOGMathGr3-8_CACR_AIG                                    float64
# EOGMathGr6_CACR_AIG                                      float64
# EOGMathGr7_CACR_AIG                                      float64
# EOGMathGr8_CACR_AIG                                      float64
# EOGReadingGr3-8_CACR_AIG                                 float64
# EOGReadingGr8_CACR_AIG                                   float64
# EOGScienceGr5&8_CACR_AIG                                 float64
# EOGSubjects_CACR_AIG                                     float64
# CurrentYearEOC_pTarget_PctMet                            float64
# MathGr3-8_pTarget_PctMet                                 float64
# ReadingGr3-8_pTarget_PctMet                              float64
# SciGr5&8_pTarget_PctMet                                  float64
# TotalTargets_pTarget_PctMet                              float64
# lea_sat_avg_score_num                                    float64
# lea_sat_participation_pct                                float64
# lea_ap_participation_pct                                 float64
# lea_ap_pct_3_or_above                                    float64
# avg_daily_attend_pct                                     float64
# crime_per_c_num                                          float64
# short_susp_per_c_num                                     float64
# long_susp_per_c_num                                      float64
# stud_internet_comp_num                                   float64
# lea_avg_daily_attend_pct                                 float64
# lea_crime_per_c_num                                      float64
# lea_short_susp_per_c_num                                 float64
# lea_long_susp_per_c_num                                  float64
# lea_expelled_per_c_num                                   float64
# lea_stud_internet_comp_num                               float64
# st_avg_daily_attend_pct                                  float64
# st_crime_per_c_num                                       float64
# flicensed_teach_pct                                      float64
# tchyrs_0thru3_pct                                        float64
# tchyrs_4thru10_pct                                       float64
# tchyrs_11plus_pct                                        float64
# nbpts_num                                                float64
# advance_dgr_pct                                          float64
# _1yr_tchr_trnovr_pct                                     float64
# lateral_teach_pct                                        float64
# lea_flicensed_teach_pct                                  float64
# lea_tchyrs_0thru3_pct                                    float64
# lea_tchyrs_4thru10_pct                                   float64
# lea_tchyrs_11plus_pct                                    float64
# lea_nbpts_num                                            float64
# lea_advance_dgr_pct                                      float64
# lea_1yr_tchr_trnovr_pct                                  float64
# lea_emer_prov_teach_pct                                  float64
# st_flicensed_teach_pct                                   float64
# st_tchyrs_0thru3_pct                                     float64
# st_tchyrs_4thru10_pct                                    float64
# st_tchyrs_11plus_pct                                     float64
# st_nbpts_num                                             float64
# st_1yr_tchr_trnovr_pct                                   float64
# 0-3 Years_LEA_Exp_Pct_Prin                               float64
# 10+ Years_LEA_Exp_Pct_Prin                               float64
# 4-10 Years_LEA_Exp_Pct_Prin                              float64
# Accomplished_TCHR_Standard 1_Pct                         float64
# Accomplished_TCHR_Standard 2_Pct                         float64
# Accomplished_TCHR_Standard 3_Pct                         float64
# Accomplished_TCHR_Standard 4_Pct                         float64
# Accomplished_TCHR_Standard 5_Pct                         float64
# Developing_TCHR_Standard 1_Pct                           float64
# Developing_TCHR_Standard 2_Pct                           float64
# Developing_TCHR_Standard 3_Pct                           float64
# Developing_TCHR_Standard 4_Pct                           float64
# Developing_TCHR_Standard 5_Pct                           float64
# Distinguished_TCHR_Standard 1_Pct                        float64
# Distinguished_TCHR_Standard 2_Pct                        float64
# Distinguished_TCHR_Standard 3_Pct                        float64
# Distinguished_TCHR_Standard 4_Pct                        float64
# Distinguished_TCHR_Standard 5_Pct                        float64
# Does Not Meet Expected Growth_TCHR_Standard 6_Pct        float64
# Exceeds Expected Growth_TCHR_Standard 6_Pct              float64
# Meets Expected Growth_TCHR_Standard 6_Pct                float64
# Not Demostrated_TCHR_Standard 1_Pct                      float64
# Not Demostrated_TCHR_Standard 2_Pct                      float64
# Not Demostrated_TCHR_Standard 3_Pct                      float64
# Not Demostrated_TCHR_Standard 4_Pct                      float64
# Not Demostrated_TCHR_Standard 5_Pct                      float64
# Proficient_TCHR_Standard 1_Pct                           float64
# Proficient_TCHR_Standard 2_Pct                           float64
# Proficient_TCHR_Standard 3_Pct                           float64
# Proficient_TCHR_Standard 4_Pct                           float64
# Proficient_TCHR_Standard 5_Pct                           float64
# AsianFemalePct                                           float64
# AsianMalePct                                             float64
# BlackFemalePct                                           float64
# HispanicFemalePct                                        float64
# HispanicMalePct                                          float64
# IndianFemalePct                                          float64
# MinorityFemalePct                                        float64
# MinorityMalePct                                          float64
# PacificIslandFemalePct                                   float64
# PacificIslandMalePct                                     float64
# PacificIslandPct                                         float64
# TwoOrMoreFemalePct                                       float64
# TwoOrMoreMalePct                                         float64
# TwoOrMorePct                                             float64
# category_cd_T                                            uint8
# grade_range_cd_5-6                                       uint8
# grade_range_cd_5-8                                       uint8
# grade_range_cd_6-11                                      uint8
# grade_range_cd_6-12                                      uint8
# grade_range_cd_6-13                                      uint8
# grade_range_cd_6-6                                       uint8
# grade_range_cd_6-7                                       uint8
# grade_range_cd_6-8                                       uint8
# grade_range_cd_6-9                                       uint8
# grade_range_cd_7-12                                      uint8
# grade_range_cd_7-13                                      uint8
# grade_range_cd_7-8                                       uint8
# grade_range_cd_7-9                                       uint8
# grade_range_cd_8-8                                       uint8
# grade_range_cd_K-12                                      uint8
# grade_range_cd_K-8                                       uint8
# grade_range_cd_PK-12                                     uint8
# grade_range_cd_PK-7                                      uint8
# grade_range_cd_PK-8                                      uint8
# calendar_type_txt_Regular School, Year-Round Calendar    uint8
# esea_status_P                                            uint8
# esea_status_R                                            uint8
# esea_status_RF                                           uint8
# esea_status_RP                                           uint8
# Grad_project_status_Y                                    uint8
# SPG Grade_B                                              uint8
# SPG Grade_C                                              uint8
# SPG Grade_D                                              uint8
# SPG Grade_F                                              uint8
# Reading SPG Grade_B                                      uint8
# Reading SPG Grade_C                                      uint8
# Reading SPG Grade_D                                      uint8
# Reading SPG Grade_F                                      uint8
# Math SPG Grade_B                                         uint8
# Math SPG Grade_C                                         uint8
# Math SPG Grade_D                                         uint8
# Math SPG Grade_F                                         uint8
# EVAAS Growth Status_Met                                  uint8
# EVAAS Growth Status_NotMet                               uint8
# esea_attendance_Met                                      uint8
# unit_code                                                object
# dtypes: float64(313), object(1), uint8(41)
# memory usage: 1.3+ MB

# %%
import sklearn
import pandas as pd

print('Sklearn Version: ' + sklearn.__version__)
print('Pandas Version: ' + pd.__version__)
# Out:
# Sklearn Version: 0.19.1
# Pandas Version: 0.22.0

# %%
print 'Output File Location:\r\n\r\n' + outputDir + inputFileName + '_ML.csv'
# Out:
# Output File Location:
#
# C:/Users/Jake/Documents/GitHub/EducationDataNC/2014/Machine Learning Datasets/PublicMiddleSchools2014_ML.csv
