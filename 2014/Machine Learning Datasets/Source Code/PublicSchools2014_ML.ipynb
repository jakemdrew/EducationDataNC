# %% [markdown]
# # Create Public School Machine Learning Datasets
# ** This program creates all the _ML datasets in the NCEA repository.**
# * This notebook reads each School Dataset file located at \EducationDataNC\ *schoolYear* \School Datasets\ as input data.
# * Different school years are processed by changing the *schoolYear* parameter.
# * Different input / output files are processed / created by changing the *inputFileName* paramter in the cell below.
# * While a single program is used to create all the _ML datasets, one program copy per dataset is maintained in the repositiory so the dataset specific tranformation reports may be reviewed.
#
# **Datasets ending in ML are preprocessed for Machine Learning and go through the following transformations: **
# 1. Missing student body racial compositions are imputed using district averages.
# 2. Columns that have the same value in every single row are deleted.
# 3. Columns that have a unique value in every single row (all values are different) are deleted.
# 4. Empty columns (all values are NA or NULL) are deleted.
# 5. Numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# 6. Remaining numeric, non-race columns with missing values are imputed / populated with 0.  In many cases, schools are not reporting values when they are zero. However, mean imputation or some other more sophisticated strategy might be considered here.
# 7. Categorical / text based columns with > *uniqueThreshold* unique values are deleted.
# 8. All remaining categorical / text based columns are one-hot encoded.  In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# 9. Duplicated or highly similar columns with > 95% correlation are delelted.

# %%
#import required Libraries
import pandas as pd
import numpy as np
import os
import string

#**********************************************************************************
# Set the following variables before running this code!!!
#**********************************************************************************
#All raw data files are processed for the year below
schoolYear = 2014

#Location where copies of the raw data files will be read in from csv files.
dataDir = 'C:/Users/Jake/Documents/GitHub/EducationDataNC/' + str(schoolYear) + '/School Datasets/'

#Name of the file to be processed
inputFileName = 'PublicSchools' + str(schoolYear)
#inputFileName = 'PublicHighSchools' + str(schoolYear)
#inputFileName = 'PublicMiddleSchools' + str(schoolYear)
#inputFileName = 'PublicElementarySchools' + str(schoolYear)

#Input file being transformed for machine learning 
inputFile = dataDir + inputFileName + '.csv'

#Location where the new school datasets will be created.
outputDir = 'C:/Users/Jake/Documents/GitHub/EducationDataNC/' + str(schoolYear) + '/Machine Learning Datasets/'

#Missing Data Threshold (Per Column)
missingThreshold = 0.60

#Unique Value Threshold (Per Column)
#Delete Columns >  uniqueThreshold unique values prior to one-hot encoding. 
#(each unique value becomes a new column during one-hot encoding)
uniqueThreshold = 25

#Read in the School Data File
schoolData = pd.read_csv(inputFile, low_memory=False, dtype={'unit_code': object})
print('*********Start: Beginning Column and Row Counts********************************************')
schoolData.info(verbose=False)

#Select only public schools as charter schools are missing data for many columns.
schoolData = schoolData[(schoolData['type_cd'] == 'P') & (schoolData['student_num'] > 0)]

print('\r\n*********After: Selecting Only Public School Campuses**********************************')
schoolData.info(verbose=False)

#Save primary key
unit_code = schoolData['unit_code']
#Convert zip code to string
schoolData['szip_ad'] = schoolData['szip_ad'].astype('object')
#Rename Lea_Name to District Name
schoolData.rename(columns={'Lea_Name': 'District Name'}, inplace=True)
# Out:
# *********Start: Beginning Column and Row Counts********************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2561 entries, 0 to 2560
# Columns: 1259 entries, vphone_ad to WhitePct
# dtypes: float64(1225), int64(3), object(31)
# memory usage: 24.6+ MB
#
# *********After: Selecting Only Public School Campuses**********************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2426 entries, 0 to 2560
# Columns: 1259 entries, vphone_ad to WhitePct
# dtypes: float64(1225), int64(3), object(31)
# memory usage: 23.3+ MB

# %% [markdown]
# # Prepare Consolidated Dataset for Machine Learning
# **Below we perform operations on the entire dataset to remove columns and update row values that could cause problems during machine learning.**

# %% [markdown]
# ## Student Body Racial Composition Features
# **Impute / update missing Student Body Racial Composition Fields using mean imputation.**
# * When there are no racial composition percentages for a particular school campus / unit_code, fill in the missing values

# %%
schoolData.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2426 entries, 0 to 2560
# Data columns (total 1259 columns):
# vphone_ad                                               object
# year                                                    int64
# unit_code                                               object
# street_ad                                               object
# scity_ad                                                object
# state_ad                                                object
# szip_ad                                                 object
# type_cd                                                 object
# closed_ind                                              float64
# new_ind                                                 float64
# super_nm                                                object
# category_cd                                             object
# url_ad                                                  object
# grade_range_cd                                          object
# calendar_type_txt                                       object
# sna_pgm_type_cd                                         object
# cover_letter_ad                                         float64
# school_type_txt                                         object
# calendar_only_txt                                       object
# title1_type_cd                                          object
# clp_ind                                                 float64
# focus_clp_ind                                           float64
# summer_program_ind                                      float64
# asm_no_spg_ind                                          float64
# no_data_spg_ind                                         float64
# District Name                                           object
# School_Name                                             object
# State_Name                                              object
# esea_status                                             object
# student_num                                             float64
# lea_avg_student_num                                     float64
# st_avg_student_num                                      float64
# Grad_project_status                                     object
# stem                                                    object
# url                                                     object
# Biology_Size                                            float64
# English II_Size                                         float64
# Math I_Size                                             float64
# total_expense_num                                       float64
# salary_expense_pct                                      float64
# benefits_expense_pct                                    float64
# services_expense_pct                                    float64
# supplies_expense_pct                                    float64
# instruct_equip_exp_pct                                  float64
# other_expense_pct                                       float64
# federal_perpupil_num                                    float64
# local_perpupil_num                                      float64
# state_perpupil_num                                      float64
# lea_total_expense_num                                   float64
# lea_salary_expense_pct                                  float64
# lea_benefits_expense_pct                                float64
# lea_services_expense_pct                                float64
# lea_supplies_expense_pct                                float64
# lea_instruct_equip_exp_pct                              float64
# lea_other_expense_pct                                   float64
# lea_federal_perpupil_num                                float64
# lea_local_perpupil_num                                  float64
# lea_state_perpupil_num                                  float64
# st_total_expense_num                                    float64
# st_salary_expense_pct                                   float64
# st_benefits_expense_pct                                 float64
# st_services_expense_pct                                 float64
# st_supplies_expense_pct                                 float64
# st_instruct_equip_exp_pct                               float64
# st_other_expense_pct                                    float64
# st_federal_perpupil_num                                 float64
# st_local_perpupil_num                                   float64
# st_state_perpupil_num                                   float64
# building_expense_pct                                    float64
# lea_building_expense_pct                                float64
# st_building_expense_pct                                 float64
# LEA Name                                                object
# School Name                                             object
# SBE Region                                              float64
# SPG Grade                                               object
# SPG Score                                               float64
# Reading SPG Grade                                       object
# Reading  SPG Score                                      float64
# Math SPG Grade                                          object
# Math SPG Score                                          float64
# EVAAS Growth Status                                     object
# EVAAS Growth Score                                      float64
# Overall Achievement Score                               float64
# Read Score                                              float64
# Math Score                                              float64
# Science Score                                           float64
# Math I Score                                            float64
# English II Score                                        float64
# Biology Score                                           float64
# The ACT Score                                           float64
# ACT WorkKeys Score                                      float64
# Math Course Rigor Score                                 float64
# Cohort Graduation Rate Standard Score                   float64
# ACTCompositeScore_UNCMin_All                            float64
# ACTEnglish_ACTBenchmark_All                             float64
# ACTMath_ACTBenchmark_All                                float64
# ACTReading_ACTBenchmark_All                             float64
# ACTScience_ACTBenchmark_All                             float64
# ACTSubtests_BenchmarksMet_All                           float64
# ACTWorkKeys_SilverPlus_All                              float64
# ACTWriting_ACTBenchmark_All                             float64
# EOCBiology_CACR_All                                     float64
# EOCBiology_GLP_All                                      float64
# EOCEnglish2_CACR_All                                    float64
# EOCEnglish2_GLP_All                                     float64
# EOCMathI_CACR_All                                       float64
# EOCMathI_GLP_All                                        float64
# EOCSubjects_CACR_All                                    float64
# EOCSubjects_GLP_All                                     float64
# EOG/EOCSubjects_CACR_All                                float64
# EOG/EOCSubjects_GLP_All                                 float64
# EOGGr3_CACR_All                                         float64
# EOGGr3_GLP_All                                          float64
# EOGGr4_CACR_All                                         float64
# EOGGr4_GLP_All                                          float64
# EOGGr5_CACR_All                                         float64
# EOGGr5_GLP_All                                          float64
# EOGGr6_CACR_All                                         float64
# EOGGr6_GLP_All                                          float64
# EOGGr7_CACR_All                                         float64
# EOGGr7_GLP_All                                          float64
# EOGGr8_CACR_All                                         float64
# EOGGr8_GLP_All                                          float64
# EOGMathGr3_CACR_All                                     float64
# EOGMathGr3_GLP_All                                      float64
# EOGMathGr3-8_CACR_All                                   float64
# EOGMathGr3-8_GLP_All                                    float64
# EOGMathGr4_CACR_All                                     float64
# EOGMathGr4_GLP_All                                      float64
# EOGMathGr5_CACR_All                                     float64
# EOGMathGr5_GLP_All                                      float64
# EOGMathGr6_CACR_All                                     float64
# EOGMathGr6_GLP_All                                      float64
# EOGMathGr7_CACR_All                                     float64
# EOGMathGr7_GLP_All                                      float64
# EOGMathGr8_CACR_All                                     float64
# EOGMathGr8_GLP_All                                      float64
# EOGReadingGr3_CACR_All                                  float64
# EOGReadingGr3_GLP_All                                   float64
# EOGReadingGr3-8_CACR_All                                float64
# EOGReadingGr3-8_GLP_All                                 float64
# EOGReadingGr4_CACR_All                                  float64
# EOGReadingGr4_GLP_All                                   float64
# EOGReadingGr5_CACR_All                                  float64
# EOGReadingGr5_GLP_All                                   float64
# EOGReadingGr6_CACR_All                                  float64
# EOGReadingGr6_GLP_All                                   float64
# EOGReadingGr7_CACR_All                                  float64
# EOGReadingGr7_GLP_All                                   float64
# EOGReadingGr8_CACR_All                                  float64
# EOGReadingGr8_GLP_All                                   float64
# EOGScienceGr5_CACR_All                                  float64
# EOGScienceGr5_GLP_All                                   float64
# EOGScienceGr5&8_CACR_All                                float64
# EOGScienceGr5&8_GLP_All                                 float64
# EOGScienceGr8_CACR_All                                  float64
# EOGScienceGr8_GLP_All                                   float64
# EOGSubjects_CACR_All                                    float64
# EOGSubjects_GLP_All                                     float64
# GraduationRate_4yr_All                                  float64
# GraduationRate_5yr_All                                  float64
# ACTCompositeScore_UNCMin_Female                         float64
# ACTEnglish_ACTBenchmark_Female                          float64
# ACTMath_ACTBenchmark_Female                             float64
# ACTReading_ACTBenchmark_Female                          float64
# ACTScience_ACTBenchmark_Female                          float64
# ACTSubtests_BenchmarksMet_Female                        float64
# ACTWorkKeys_SilverPlus_Female                           float64
# ACTWriting_ACTBenchmark_Female                          float64
# EOCBiology_CACR_Female                                  float64
# EOCBiology_GLP_Female                                   float64
# EOCEnglish2_CACR_Female                                 float64
# EOCEnglish2_GLP_Female                                  float64
# EOCMathI_CACR_Female                                    float64
# EOCMathI_GLP_Female                                     float64
# EOCSubjects_CACR_Female                                 float64
# EOCSubjects_GLP_Female                                  float64
# EOG/EOCSubjects_CACR_Female                             float64
# EOG/EOCSubjects_GLP_Female                              float64
# EOGGr3_CACR_Female                                      float64
# EOGGr3_GLP_Female                                       float64
# EOGGr4_CACR_Female                                      float64
# EOGGr4_GLP_Female                                       float64
# EOGGr5_CACR_Female                                      float64
# EOGGr5_GLP_Female                                       float64
# EOGGr6_CACR_Female                                      float64
# EOGGr6_GLP_Female                                       float64
# EOGGr7_CACR_Female                                      float64
# EOGGr7_GLP_Female                                       float64
# EOGGr8_CACR_Female                                      float64
# EOGGr8_GLP_Female                                       float64
# EOGMathGr3_CACR_Female                                  float64
# EOGMathGr3_GLP_Female                                   float64
# EOGMathGr3-8_CACR_Female                                float64
# EOGMathGr3-8_GLP_Female                                 float64
# EOGMathGr4_CACR_Female                                  float64
# EOGMathGr4_GLP_Female                                   float64
# EOGMathGr5_CACR_Female                                  float64
# EOGMathGr5_GLP_Female                                   float64
# EOGMathGr6_CACR_Female                                  float64
# EOGMathGr6_GLP_Female                                   float64
# EOGMathGr7_CACR_Female                                  float64
# EOGMathGr7_GLP_Female                                   float64
# EOGMathGr8_CACR_Female                                  float64
# EOGMathGr8_GLP_Female                                   float64
# EOGReadingGr3_CACR_Female                               float64
# EOGReadingGr3_GLP_Female                                float64
# EOGReadingGr3-8_CACR_Female                             float64
# EOGReadingGr3-8_GLP_Female                              float64
# EOGReadingGr4_CACR_Female                               float64
# EOGReadingGr4_GLP_Female                                float64
# EOGReadingGr5_CACR_Female                               float64
# EOGReadingGr5_GLP_Female                                float64
# EOGReadingGr6_CACR_Female                               float64
# EOGReadingGr6_GLP_Female                                float64
# EOGReadingGr7_CACR_Female                               float64
# EOGReadingGr7_GLP_Female                                float64
# EOGReadingGr8_CACR_Female                               float64
# EOGReadingGr8_GLP_Female                                float64
# EOGScienceGr5_CACR_Female                               float64
# EOGScienceGr5_GLP_Female                                float64
# EOGScienceGr5&8_CACR_Female                             float64
# EOGScienceGr5&8_GLP_Female                              float64
# EOGScienceGr8_CACR_Female                               float64
# EOGScienceGr8_GLP_Female                                float64
# EOGSubjects_CACR_Female                                 float64
# EOGSubjects_GLP_Female                                  float64
# GraduationRate_4yr_Female                               float64
# GraduationRate_5yr_Female                               float64
# ACTCompositeScore_UNCMin_Male                           float64
# ACTEnglish_ACTBenchmark_Male                            float64
# ACTMath_ACTBenchmark_Male                               float64
# ACTReading_ACTBenchmark_Male                            float64
# ACTScience_ACTBenchmark_Male                            float64
# ACTSubtests_BenchmarksMet_Male                          float64
# ACTWorkKeys_SilverPlus_Male                             float64
# ACTWriting_ACTBenchmark_Male                            float64
# EOCBiology_CACR_Male                                    float64
# EOCBiology_GLP_Male                                     float64
# EOCEnglish2_CACR_Male                                   float64
# EOCEnglish2_GLP_Male                                    float64
# EOCMathI_CACR_Male                                      float64
# EOCMathI_GLP_Male                                       float64
# EOCSubjects_CACR_Male                                   float64
# EOCSubjects_GLP_Male                                    float64
# EOG/EOCSubjects_CACR_Male                               float64
# EOG/EOCSubjects_GLP_Male                                float64
# EOGGr3_CACR_Male                                        float64
# EOGGr3_GLP_Male                                         float64
# EOGGr4_CACR_Male                                        float64
# EOGGr4_GLP_Male                                         float64
# EOGGr5_CACR_Male                                        float64
# EOGGr5_GLP_Male                                         float64
# EOGGr6_CACR_Male                                        float64
# EOGGr6_GLP_Male                                         float64
# EOGGr7_CACR_Male                                        float64
# EOGGr7_GLP_Male                                         float64
# EOGGr8_CACR_Male                                        float64
# EOGGr8_GLP_Male                                         float64
# EOGMathGr3_CACR_Male                                    float64
# EOGMathGr3_GLP_Male                                     float64
# EOGMathGr3-8_CACR_Male                                  float64
# EOGMathGr3-8_GLP_Male                                   float64
# EOGMathGr4_CACR_Male                                    float64
# EOGMathGr4_GLP_Male                                     float64
# EOGMathGr5_CACR_Male                                    float64
# EOGMathGr5_GLP_Male                                     float64
# EOGMathGr6_CACR_Male                                    float64
# EOGMathGr6_GLP_Male                                     float64
# EOGMathGr7_CACR_Male                                    float64
# EOGMathGr7_GLP_Male                                     float64
# EOGMathGr8_CACR_Male                                    float64
# EOGMathGr8_GLP_Male                                     float64
# EOGReadingGr3_CACR_Male                                 float64
# EOGReadingGr3_GLP_Male                                  float64
# EOGReadingGr3-8_CACR_Male                               float64
# EOGReadingGr3-8_GLP_Male                                float64
# EOGReadingGr4_CACR_Male                                 float64
# EOGReadingGr4_GLP_Male                                  float64
# EOGReadingGr5_CACR_Male                                 float64
# EOGReadingGr5_GLP_Male                                  float64
# EOGReadingGr6_CACR_Male                                 float64
# EOGReadingGr6_GLP_Male                                  float64
# EOGReadingGr7_CACR_Male                                 float64
# EOGReadingGr7_GLP_Male                                  float64
# EOGReadingGr8_CACR_Male                                 float64
# EOGReadingGr8_GLP_Male                                  float64
# EOGScienceGr5_CACR_Male                                 float64
# EOGScienceGr5_GLP_Male                                  float64
# EOGScienceGr5&8_CACR_Male                               float64
# EOGScienceGr5&8_GLP_Male                                float64
# EOGScienceGr8_CACR_Male                                 float64
# EOGScienceGr8_GLP_Male                                  float64
# EOGSubjects_CACR_Male                                   float64
# EOGSubjects_GLP_Male                                    float64
# GraduationRate_4yr_Male                                 float64
# GraduationRate_5yr_Male                                 float64
# ACTCompositeScore_UNCMin_AmericanIndian                 float64
# ACTEnglish_ACTBenchmark_AmericanIndian                  float64
# ACTMath_ACTBenchmark_AmericanIndian                     float64
# ACTReading_ACTBenchmark_AmericanIndian                  float64
# ACTScience_ACTBenchmark_AmericanIndian                  float64
# ACTSubtests_BenchmarksMet_AmericanIndian                float64
# ACTWorkKeys_SilverPlus_AmericanIndian                   float64
# ACTWriting_ACTBenchmark_AmericanIndian                  float64
# EOCBiology_CACR_AmericanIndian                          float64
# EOCBiology_GLP_AmericanIndian                           float64
# EOCEnglish2_CACR_AmericanIndian                         float64
# EOCEnglish2_GLP_AmericanIndian                          float64
# EOCMathI_CACR_AmericanIndian                            float64
# EOCMathI_GLP_AmericanIndian                             float64
# EOCSubjects_CACR_AmericanIndian                         float64
# EOCSubjects_GLP_AmericanIndian                          float64
# EOG/EOCSubjects_CACR_AmericanIndian                     float64
# EOG/EOCSubjects_GLP_AmericanIndian                      float64
# EOGGr3_CACR_AmericanIndian                              float64
# EOGGr3_GLP_AmericanIndian                               float64
# EOGGr4_CACR_AmericanIndian                              float64
# EOGGr4_GLP_AmericanIndian                               float64
# EOGGr5_CACR_AmericanIndian                              float64
# EOGGr5_GLP_AmericanIndian                               float64
# EOGGr6_CACR_AmericanIndian                              float64
# EOGGr6_GLP_AmericanIndian                               float64
# EOGGr7_CACR_AmericanIndian                              float64
# EOGGr7_GLP_AmericanIndian                               float64
# EOGGr8_CACR_AmericanIndian                              float64
# EOGGr8_GLP_AmericanIndian                               float64
# EOGMathGr3_CACR_AmericanIndian                          float64
# EOGMathGr3_GLP_AmericanIndian                           float64
# EOGMathGr3-8_CACR_AmericanIndian                        float64
# EOGMathGr3-8_GLP_AmericanIndian                         float64
# EOGMathGr4_CACR_AmericanIndian                          float64
# EOGMathGr4_GLP_AmericanIndian                           float64
# EOGMathGr5_CACR_AmericanIndian                          float64
# EOGMathGr5_GLP_AmericanIndian                           float64
# EOGMathGr6_CACR_AmericanIndian                          float64
# EOGMathGr6_GLP_AmericanIndian                           float64
# EOGMathGr7_CACR_AmericanIndian                          float64
# EOGMathGr7_GLP_AmericanIndian                           float64
# EOGMathGr8_CACR_AmericanIndian                          float64
# EOGMathGr8_GLP_AmericanIndian                           float64
# EOGReadingGr3_CACR_AmericanIndian                       float64
# EOGReadingGr3_GLP_AmericanIndian                        float64
# EOGReadingGr3-8_CACR_AmericanIndian                     float64
# EOGReadingGr3-8_GLP_AmericanIndian                      float64
# EOGReadingGr4_CACR_AmericanIndian                       float64
# EOGReadingGr4_GLP_AmericanIndian                        float64
# EOGReadingGr5_CACR_AmericanIndian                       float64
# EOGReadingGr5_GLP_AmericanIndian                        float64
# EOGReadingGr6_CACR_AmericanIndian                       float64
# EOGReadingGr6_GLP_AmericanIndian                        float64
# EOGReadingGr7_CACR_AmericanIndian                       float64
# EOGReadingGr7_GLP_AmericanIndian                        float64
# EOGReadingGr8_CACR_AmericanIndian                       float64
# EOGReadingGr8_GLP_AmericanIndian                        float64
# EOGScienceGr5_CACR_AmericanIndian                       float64
# EOGScienceGr5_GLP_AmericanIndian                        float64
# EOGScienceGr5&8_CACR_AmericanIndian                     float64
# EOGScienceGr5&8_GLP_AmericanIndian                      float64
# EOGScienceGr8_CACR_AmericanIndian                       float64
# EOGScienceGr8_GLP_AmericanIndian                        float64
# EOGSubjects_CACR_AmericanIndian                         float64
# EOGSubjects_GLP_AmericanIndian                          float64
# GraduationRate_4yr_AmericanIndian                       float64
# GraduationRate_5yr_AmericanIndian                       float64
# ACTCompositeScore_UNCMin_Asian                          float64
# ACTEnglish_ACTBenchmark_Asian                           float64
# ACTMath_ACTBenchmark_Asian                              float64
# ACTReading_ACTBenchmark_Asian                           float64
# ACTScience_ACTBenchmark_Asian                           float64
# ACTSubtests_BenchmarksMet_Asian                         float64
# ACTWorkKeys_SilverPlus_Asian                            float64
# ACTWriting_ACTBenchmark_Asian                           float64
# EOCBiology_CACR_Asian                                   float64
# EOCBiology_GLP_Asian                                    float64
# EOCEnglish2_CACR_Asian                                  float64
# EOCEnglish2_GLP_Asian                                   float64
# EOCMathI_CACR_Asian                                     float64
# EOCMathI_GLP_Asian                                      float64
# EOCSubjects_CACR_Asian                                  float64
# EOCSubjects_GLP_Asian                                   float64
# EOG/EOCSubjects_CACR_Asian                              float64
# EOG/EOCSubjects_GLP_Asian                               float64
# EOGGr3_CACR_Asian                                       float64
# EOGGr3_GLP_Asian                                        float64
# EOGGr4_CACR_Asian                                       float64
# EOGGr4_GLP_Asian                                        float64
# EOGGr5_CACR_Asian                                       float64
# EOGGr5_GLP_Asian                                        float64
# EOGGr6_CACR_Asian                                       float64
# EOGGr6_GLP_Asian                                        float64
# EOGGr7_CACR_Asian                                       float64
# EOGGr7_GLP_Asian                                        float64
# EOGGr8_CACR_Asian                                       float64
# EOGGr8_GLP_Asian                                        float64
# EOGMathGr3_CACR_Asian                                   float64
# EOGMathGr3_GLP_Asian                                    float64
# EOGMathGr3-8_CACR_Asian                                 float64
# EOGMathGr3-8_GLP_Asian                                  float64
# EOGMathGr4_CACR_Asian                                   float64
# EOGMathGr4_GLP_Asian                                    float64
# EOGMathGr5_CACR_Asian                                   float64
# EOGMathGr5_GLP_Asian                                    float64
# EOGMathGr6_CACR_Asian                                   float64
# EOGMathGr6_GLP_Asian                                    float64
# EOGMathGr7_CACR_Asian                                   float64
# EOGMathGr7_GLP_Asian                                    float64
# EOGMathGr8_CACR_Asian                                   float64
# EOGMathGr8_GLP_Asian                                    float64
# EOGReadingGr3_CACR_Asian                                float64
# EOGReadingGr3_GLP_Asian                                 float64
# EOGReadingGr3-8_CACR_Asian                              float64
# EOGReadingGr3-8_GLP_Asian                               float64
# EOGReadingGr4_CACR_Asian                                float64
# EOGReadingGr4_GLP_Asian                                 float64
# EOGReadingGr5_CACR_Asian                                float64
# EOGReadingGr5_GLP_Asian                                 float64
# EOGReadingGr6_CACR_Asian                                float64
# EOGReadingGr6_GLP_Asian                                 float64
# EOGReadingGr7_CACR_Asian                                float64
# EOGReadingGr7_GLP_Asian                                 float64
# EOGReadingGr8_CACR_Asian                                float64
# EOGReadingGr8_GLP_Asian                                 float64
# EOGScienceGr5_CACR_Asian                                float64
# EOGScienceGr5_GLP_Asian                                 float64
# EOGScienceGr5&8_CACR_Asian                              float64
# EOGScienceGr5&8_GLP_Asian                               float64
# EOGScienceGr8_CACR_Asian                                float64
# EOGScienceGr8_GLP_Asian                                 float64
# EOGSubjects_CACR_Asian                                  float64
# EOGSubjects_GLP_Asian                                   float64
# GraduationRate_4yr_Asian                                float64
# GraduationRate_5yr_Asian                                float64
# ACTCompositeScore_UNCMin_Black                          float64
# ACTEnglish_ACTBenchmark_Black                           float64
# ACTMath_ACTBenchmark_Black                              float64
# ACTReading_ACTBenchmark_Black                           float64
# ACTScience_ACTBenchmark_Black                           float64
# ACTSubtests_BenchmarksMet_Black                         float64
# ACTWorkKeys_SilverPlus_Black                            float64
# ACTWriting_ACTBenchmark_Black                           float64
# EOCBiology_CACR_Black                                   float64
# EOCBiology_GLP_Black                                    float64
# EOCEnglish2_CACR_Black                                  float64
# EOCEnglish2_GLP_Black                                   float64
# EOCMathI_CACR_Black                                     float64
# EOCMathI_GLP_Black                                      float64
# EOCSubjects_CACR_Black                                  float64
# EOCSubjects_GLP_Black                                   float64
# EOG/EOCSubjects_CACR_Black                              float64
# EOG/EOCSubjects_GLP_Black                               float64
# EOGGr3_CACR_Black                                       float64
# EOGGr3_GLP_Black                                        float64
# EOGGr4_CACR_Black                                       float64
# EOGGr4_GLP_Black                                        float64
# EOGGr5_CACR_Black                                       float64
# EOGGr5_GLP_Black                                        float64
# EOGGr6_CACR_Black                                       float64
# EOGGr6_GLP_Black                                        float64
# EOGGr7_CACR_Black                                       float64
# EOGGr7_GLP_Black                                        float64
# EOGGr8_CACR_Black                                       float64
# EOGGr8_GLP_Black                                        float64
# EOGMathGr3_CACR_Black                                   float64
# EOGMathGr3_GLP_Black                                    float64
# EOGMathGr3-8_CACR_Black                                 float64
# EOGMathGr3-8_GLP_Black                                  float64
# EOGMathGr4_CACR_Black                                   float64
# EOGMathGr4_GLP_Black                                    float64
# EOGMathGr5_CACR_Black                                   float64
# EOGMathGr5_GLP_Black                                    float64
# EOGMathGr6_CACR_Black                                   float64
# EOGMathGr6_GLP_Black                                    float64
# EOGMathGr7_CACR_Black                                   float64
# EOGMathGr7_GLP_Black                                    float64
# EOGMathGr8_CACR_Black                                   float64
# EOGMathGr8_GLP_Black                                    float64
# EOGReadingGr3_CACR_Black                                float64
# EOGReadingGr3_GLP_Black                                 float64
# EOGReadingGr3-8_CACR_Black                              float64
# EOGReadingGr3-8_GLP_Black                               float64
# EOGReadingGr4_CACR_Black                                float64
# EOGReadingGr4_GLP_Black                                 float64
# EOGReadingGr5_CACR_Black                                float64
# EOGReadingGr5_GLP_Black                                 float64
# EOGReadingGr6_CACR_Black                                float64
# EOGReadingGr6_GLP_Black                                 float64
# EOGReadingGr7_CACR_Black                                float64
# EOGReadingGr7_GLP_Black                                 float64
# EOGReadingGr8_CACR_Black                                float64
# EOGReadingGr8_GLP_Black                                 float64
# EOGScienceGr5_CACR_Black                                float64
# EOGScienceGr5_GLP_Black                                 float64
# EOGScienceGr5&8_CACR_Black                              float64
# EOGScienceGr5&8_GLP_Black                               float64
# EOGScienceGr8_CACR_Black                                float64
# EOGScienceGr8_GLP_Black                                 float64
# EOGSubjects_CACR_Black                                  float64
# EOGSubjects_GLP_Black                                   float64
# GraduationRate_4yr_Black                                float64
# GraduationRate_5yr_Black                                float64
# ACTCompositeScore_UNCMin_Hispanic                       float64
# ACTEnglish_ACTBenchmark_Hispanic                        float64
# ACTMath_ACTBenchmark_Hispanic                           float64
# ACTReading_ACTBenchmark_Hispanic                        float64
# ACTScience_ACTBenchmark_Hispanic                        float64
# ACTSubtests_BenchmarksMet_Hispanic                      float64
# ACTWorkKeys_SilverPlus_Hispanic                         float64
# ACTWriting_ACTBenchmark_Hispanic                        float64
# EOCBiology_CACR_Hispanic                                float64
# EOCBiology_GLP_Hispanic                                 float64
# EOCEnglish2_CACR_Hispanic                               float64
# EOCEnglish2_GLP_Hispanic                                float64
# EOCMathI_CACR_Hispanic                                  float64
# EOCMathI_GLP_Hispanic                                   float64
# EOCSubjects_CACR_Hispanic                               float64
# EOCSubjects_GLP_Hispanic                                float64
# EOG/EOCSubjects_CACR_Hispanic                           float64
# EOG/EOCSubjects_GLP_Hispanic                            float64
# EOGGr3_CACR_Hispanic                                    float64
# EOGGr3_GLP_Hispanic                                     float64
# EOGGr4_CACR_Hispanic                                    float64
# EOGGr4_GLP_Hispanic                                     float64
# EOGGr5_CACR_Hispanic                                    float64
# EOGGr5_GLP_Hispanic                                     float64
# EOGGr6_CACR_Hispanic                                    float64
# EOGGr6_GLP_Hispanic                                     float64
# EOGGr7_CACR_Hispanic                                    float64
# EOGGr7_GLP_Hispanic                                     float64
# EOGGr8_CACR_Hispanic                                    float64
# EOGGr8_GLP_Hispanic                                     float64
# EOGMathGr3_CACR_Hispanic                                float64
# EOGMathGr3_GLP_Hispanic                                 float64
# EOGMathGr3-8_CACR_Hispanic                              float64
# EOGMathGr3-8_GLP_Hispanic                               float64
# EOGMathGr4_CACR_Hispanic                                float64
# EOGMathGr4_GLP_Hispanic                                 float64
# EOGMathGr5_CACR_Hispanic                                float64
# EOGMathGr5_GLP_Hispanic                                 float64
# EOGMathGr6_CACR_Hispanic                                float64
# EOGMathGr6_GLP_Hispanic                                 float64
# EOGMathGr7_CACR_Hispanic                                float64
# EOGMathGr7_GLP_Hispanic                                 float64
# EOGMathGr8_CACR_Hispanic                                float64
# EOGMathGr8_GLP_Hispanic                                 float64
# EOGReadingGr3_CACR_Hispanic                             float64
# EOGReadingGr3_GLP_Hispanic                              float64
# EOGReadingGr3-8_CACR_Hispanic                           float64
# EOGReadingGr3-8_GLP_Hispanic                            float64
# EOGReadingGr4_CACR_Hispanic                             float64
# EOGReadingGr4_GLP_Hispanic                              float64
# EOGReadingGr5_CACR_Hispanic                             float64
# EOGReadingGr5_GLP_Hispanic                              float64
# EOGReadingGr6_CACR_Hispanic                             float64
# EOGReadingGr6_GLP_Hispanic                              float64
# EOGReadingGr7_CACR_Hispanic                             float64
# EOGReadingGr7_GLP_Hispanic                              float64
# EOGReadingGr8_CACR_Hispanic                             float64
# EOGReadingGr8_GLP_Hispanic                              float64
# EOGScienceGr5_CACR_Hispanic                             float64
# EOGScienceGr5_GLP_Hispanic                              float64
# EOGScienceGr5&8_CACR_Hispanic                           float64
# EOGScienceGr5&8_GLP_Hispanic                            float64
# EOGScienceGr8_CACR_Hispanic                             float64
# EOGScienceGr8_GLP_Hispanic                              float64
# EOGSubjects_CACR_Hispanic                               float64
# EOGSubjects_GLP_Hispanic                                float64
# GraduationRate_4yr_Hispanic                             float64
# GraduationRate_5yr_Hispanic                             float64
# ACTCompositeScore_UNCMin_TwoorMoreRaces                 float64
# ACTEnglish_ACTBenchmark_TwoorMoreRaces                  float64
# ACTMath_ACTBenchmark_TwoorMoreRaces                     float64
# ACTReading_ACTBenchmark_TwoorMoreRaces                  float64
# ACTScience_ACTBenchmark_TwoorMoreRaces                  float64
# ACTSubtests_BenchmarksMet_TwoorMoreRaces                float64
# ACTWorkKeys_SilverPlus_TwoorMoreRaces                   float64
# ACTWriting_ACTBenchmark_TwoorMoreRaces                  float64
# EOCBiology_CACR_TwoorMoreRaces                          float64
# EOCBiology_GLP_TwoorMoreRaces                           float64
# EOCEnglish2_CACR_TwoorMoreRaces                         float64
# EOCEnglish2_GLP_TwoorMoreRaces                          float64
# EOCMathI_CACR_TwoorMoreRaces                            float64
# EOCMathI_GLP_TwoorMoreRaces                             float64
# EOCSubjects_CACR_TwoorMoreRaces                         float64
# EOCSubjects_GLP_TwoorMoreRaces                          float64
# EOG/EOCSubjects_CACR_TwoorMoreRaces                     float64
# EOG/EOCSubjects_GLP_TwoorMoreRaces                      float64
# EOGGr3_CACR_TwoorMoreRaces                              float64
# EOGGr3_GLP_TwoorMoreRaces                               float64
# EOGGr4_CACR_TwoorMoreRaces                              float64
# EOGGr4_GLP_TwoorMoreRaces                               float64
# EOGGr5_CACR_TwoorMoreRaces                              float64
# EOGGr5_GLP_TwoorMoreRaces                               float64
# EOGGr6_CACR_TwoorMoreRaces                              float64
# EOGGr6_GLP_TwoorMoreRaces                               float64
# EOGGr7_CACR_TwoorMoreRaces                              float64
# EOGGr7_GLP_TwoorMoreRaces                               float64
# EOGGr8_CACR_TwoorMoreRaces                              float64
# EOGGr8_GLP_TwoorMoreRaces                               float64
# EOGMathGr3_CACR_TwoorMoreRaces                          float64
# EOGMathGr3_GLP_TwoorMoreRaces                           float64
# EOGMathGr3-8_CACR_TwoorMoreRaces                        float64
# EOGMathGr3-8_GLP_TwoorMoreRaces                         float64
# EOGMathGr4_CACR_TwoorMoreRaces                          float64
# EOGMathGr4_GLP_TwoorMoreRaces                           float64
# EOGMathGr5_CACR_TwoorMoreRaces                          float64
# EOGMathGr5_GLP_TwoorMoreRaces                           float64
# EOGMathGr6_CACR_TwoorMoreRaces                          float64
# EOGMathGr6_GLP_TwoorMoreRaces                           float64
# EOGMathGr7_CACR_TwoorMoreRaces                          float64
# EOGMathGr7_GLP_TwoorMoreRaces                           float64
# EOGMathGr8_CACR_TwoorMoreRaces                          float64
# EOGMathGr8_GLP_TwoorMoreRaces                           float64
# EOGReadingGr3_CACR_TwoorMoreRaces                       float64
# EOGReadingGr3_GLP_TwoorMoreRaces                        float64
# EOGReadingGr3-8_CACR_TwoorMoreRaces                     float64
# EOGReadingGr3-8_GLP_TwoorMoreRaces                      float64
# EOGReadingGr4_CACR_TwoorMoreRaces                       float64
# EOGReadingGr4_GLP_TwoorMoreRaces                        float64
# EOGReadingGr5_CACR_TwoorMoreRaces                       float64
# EOGReadingGr5_GLP_TwoorMoreRaces                        float64
# EOGReadingGr6_CACR_TwoorMoreRaces                       float64
# EOGReadingGr6_GLP_TwoorMoreRaces                        float64
# EOGReadingGr7_CACR_TwoorMoreRaces                       float64
# EOGReadingGr7_GLP_TwoorMoreRaces                        float64
# EOGReadingGr8_CACR_TwoorMoreRaces                       float64
# EOGReadingGr8_GLP_TwoorMoreRaces                        float64
# EOGScienceGr5_CACR_TwoorMoreRaces                       float64
# EOGScienceGr5_GLP_TwoorMoreRaces                        float64
# EOGScienceGr5&8_CACR_TwoorMoreRaces                     float64
# EOGScienceGr5&8_GLP_TwoorMoreRaces                      float64
# EOGScienceGr8_CACR_TwoorMoreRaces                       float64
# EOGScienceGr8_GLP_TwoorMoreRaces                        float64
# EOGSubjects_CACR_TwoorMoreRaces                         float64
# EOGSubjects_GLP_TwoorMoreRaces                          float64
# GraduationRate_4yr_TwoorMoreRaces                       float64
# GraduationRate_5yr_TwoorMoreRaces                       float64
# ACTCompositeScore_UNCMin_White                          float64
# ACTEnglish_ACTBenchmark_White                           float64
# ACTMath_ACTBenchmark_White                              float64
# ACTReading_ACTBenchmark_White                           float64
# ACTScience_ACTBenchmark_White                           float64
# ACTSubtests_BenchmarksMet_White                         float64
# ACTWorkKeys_SilverPlus_White                            float64
# ACTWriting_ACTBenchmark_White                           float64
# EOCBiology_CACR_White                                   float64
# EOCBiology_GLP_White                                    float64
# EOCEnglish2_CACR_White                                  float64
# EOCEnglish2_GLP_White                                   float64
# EOCMathI_CACR_White                                     float64
# EOCMathI_GLP_White                                      float64
# EOCSubjects_CACR_White                                  float64
# EOCSubjects_GLP_White                                   float64
# EOG/EOCSubjects_CACR_White                              float64
# EOG/EOCSubjects_GLP_White                               float64
# EOGGr3_CACR_White                                       float64
# EOGGr3_GLP_White                                        float64
# EOGGr4_CACR_White                                       float64
# EOGGr4_GLP_White                                        float64
# EOGGr5_CACR_White                                       float64
# EOGGr5_GLP_White                                        float64
# EOGGr6_CACR_White                                       float64
# EOGGr6_GLP_White                                        float64
# EOGGr7_CACR_White                                       float64
# EOGGr7_GLP_White                                        float64
# EOGGr8_CACR_White                                       float64
# EOGGr8_GLP_White                                        float64
# EOGMathGr3_CACR_White                                   float64
# EOGMathGr3_GLP_White                                    float64
# EOGMathGr3-8_CACR_White                                 float64
# EOGMathGr3-8_GLP_White                                  float64
# EOGMathGr4_CACR_White                                   float64
# EOGMathGr4_GLP_White                                    float64
# EOGMathGr5_CACR_White                                   float64
# EOGMathGr5_GLP_White                                    float64
# EOGMathGr6_CACR_White                                   float64
# EOGMathGr6_GLP_White                                    float64
# EOGMathGr7_CACR_White                                   float64
# EOGMathGr7_GLP_White                                    float64
# EOGMathGr8_CACR_White                                   float64
# EOGMathGr8_GLP_White                                    float64
# EOGReadingGr3_CACR_White                                float64
# EOGReadingGr3_GLP_White                                 float64
# EOGReadingGr3-8_CACR_White                              float64
# EOGReadingGr3-8_GLP_White                               float64
# EOGReadingGr4_CACR_White                                float64
# EOGReadingGr4_GLP_White                                 float64
# EOGReadingGr5_CACR_White                                float64
# EOGReadingGr5_GLP_White                                 float64
# EOGReadingGr6_CACR_White                                float64
# EOGReadingGr6_GLP_White                                 float64
# EOGReadingGr7_CACR_White                                float64
# EOGReadingGr7_GLP_White                                 float64
# EOGReadingGr8_CACR_White                                float64
# EOGReadingGr8_GLP_White                                 float64
# EOGScienceGr5_CACR_White                                float64
# EOGScienceGr5_GLP_White                                 float64
# EOGScienceGr5&8_CACR_White                              float64
# EOGScienceGr5&8_GLP_White                               float64
# EOGScienceGr8_CACR_White                                float64
# EOGScienceGr8_GLP_White                                 float64
# EOGSubjects_CACR_White                                  float64
# EOGSubjects_GLP_White                                   float64
# GraduationRate_4yr_White                                float64
# GraduationRate_5yr_White                                float64
# ACTCompositeScore_UNCMin_EDS                            float64
# ACTEnglish_ACTBenchmark_EDS                             float64
# ACTMath_ACTBenchmark_EDS                                float64
# ACTReading_ACTBenchmark_EDS                             float64
# ACTScience_ACTBenchmark_EDS                             float64
# ACTSubtests_BenchmarksMet_EDS                           float64
# ACTWorkKeys_SilverPlus_EDS                              float64
# ACTWriting_ACTBenchmark_EDS                             float64
# EOCBiology_CACR_EDS                                     float64
# EOCBiology_GLP_EDS                                      float64
# EOCEnglish2_CACR_EDS                                    float64
# EOCEnglish2_GLP_EDS                                     float64
# EOCMathI_CACR_EDS                                       float64
# EOCMathI_GLP_EDS                                        float64
# EOCSubjects_CACR_EDS                                    float64
# EOCSubjects_GLP_EDS                                     float64
# EOG/EOCSubjects_CACR_EDS                                float64
# EOG/EOCSubjects_GLP_EDS                                 float64
# EOGGr3_CACR_EDS                                         float64
# EOGGr3_GLP_EDS                                          float64
# EOGGr4_CACR_EDS                                         float64
# EOGGr4_GLP_EDS                                          float64
# EOGGr5_CACR_EDS                                         float64
# EOGGr5_GLP_EDS                                          float64
# EOGGr6_CACR_EDS                                         float64
# EOGGr6_GLP_EDS                                          float64
# EOGGr7_CACR_EDS                                         float64
# EOGGr7_GLP_EDS                                          float64
# EOGGr8_CACR_EDS                                         float64
# EOGGr8_GLP_EDS                                          float64
# EOGMathGr3_CACR_EDS                                     float64
# EOGMathGr3_GLP_EDS                                      float64
# EOGMathGr3-8_CACR_EDS                                   float64
# EOGMathGr3-8_GLP_EDS                                    float64
# EOGMathGr4_CACR_EDS                                     float64
# EOGMathGr4_GLP_EDS                                      float64
# EOGMathGr5_CACR_EDS                                     float64
# EOGMathGr5_GLP_EDS                                      float64
# EOGMathGr6_CACR_EDS                                     float64
# EOGMathGr6_GLP_EDS                                      float64
# EOGMathGr7_CACR_EDS                                     float64
# EOGMathGr7_GLP_EDS                                      float64
# EOGMathGr8_CACR_EDS                                     float64
# ...
# st_ap_participation_pct                                 float64
# ap_pct_3_or_above                                       float64
# lea_ap_pct_3_or_above                                   float64
# st_ap_pct_3_or_above                                    float64
# ib_participation_pct                                    float64
# lea_ib_participation_pct                                float64
# st_ib_participation_pct                                 float64
# ib_pct_4_or_above                                       float64
# lea_ib_pct_4_or_above                                   float64
# st_ib_pct_4_or_above                                    float64
# total_specialized_courses                               float64
# ap_ib_courses                                           float64
# cte_courses                                             float64
# univ_college_courses                                    float64
# lea_total_specialized_courses                           float64
# lea_ap_ib_courses                                       float64
# lea_cte_courses                                         float64
# lea_univ_college_courses                                float64
# st_total_specialized_courses                            float64
# st_ap_ib_courses                                        float64
# st_cte_courses                                          float64
# st_univ_college_courses                                 float64
# AM7_American Indian_ENROLL_sch_pct                      float64
# AM7_American Indian_NOENROLL_sch_pct                    float64
# AS7_Asian_ENROLL_sch_pct                                float64
# AS7_Asian_NOENROLL_sch_pct                              float64
# All_All Student (Total or subtotal)_ENROLL_sch_pct      float64
# All_All Student (Total or subtotal)_NOENROLL_sch_pct    float64
# BL7_Black_ENROLL_sch_pct                                float64
# BL7_Black_NOENROLL_sch_pct                              float64
# ECODIS_Economically Disadvantaged_ENROLL_sch_pct        float64
# ECODIS_Economically Disadvantaged_NOENROLL_sch_pct      float64
# F_Female_ENROLL_sch_pct                                 float64
# F_Female_NOENROLL_sch_pct                               float64
# HI7_Hispanic_ENROLL_sch_pct                             float64
# HI7_Hispanic_NOENROLL_sch_pct                           float64
# LEP_Limited English Proficiency_ENROLL_sch_pct          float64
# LEP_Limited English Proficiency_NOENROLL_sch_pct        float64
# M_Male_ENROLL_sch_pct                                   float64
# M_Male_NOENROLL_sch_pct                                 float64
# MU7_Multiracial_ENROLL_sch_pct                          float64
# MU7_Multiracial_NOENROLL_sch_pct                        float64
# PI7_Pacific Islander_ENROLL_sch_pct                     float64
# PI7_Pacific Islander_NOENROLL_sch_pct                   float64
# WDIS_Students with Disabilities_ENROLL_sch_pct          float64
# WDIS_Students with Disabilities_NOENROLL_sch_pct        float64
# WH7_White_ENROLL_sch_pct                                float64
# WH7_White_NOENROLL_sch_pct                              float64
# avg_daily_attend_pct                                    float64
# crime_per_c_num                                         float64
# short_susp_per_c_num                                    float64
# long_susp_per_c_num                                     float64
# expelled_per_c_num                                      float64
# ttl_crimes_num                                          float64
# stud_internet_comp_num                                  float64
# lea_avg_daily_attend_pct                                float64
# lea_crime_per_c_num                                     float64
# lea_short_susp_per_c_num                                float64
# lea_long_susp_per_c_num                                 float64
# lea_expelled_per_c_num                                  float64
# lea_stud_internet_comp_num                              float64
# st_avg_daily_attend_pct                                 float64
# st_crime_per_c_num                                      float64
# st_short_susp_per_c_num                                 float64
# st_long_susp_per_c_num                                  float64
# st_expelled_per_c_num                                   float64
# st_stud_internet_comp_num                               float64
# digital_media_pct                                       float64
# Byod                                                    float64
# grades_BYOD                                             float64
# avg_age_media_collection                                float64
# _1_to_1_access                                          float64
# books_per_student                                       float64
# grades_1_to_1_access                                    float64
# lea_avg_age_media_collection                            float64
# lea_books_per_student                                   float64
# st_avg_age_media_collection                             float64
# st_books_per_student                                    float64
# wap_num                                                 float64
# wap_per_classroom                                       float64
# lea_wap_num                                             float64
# lea_wap_per_classroom                                   float64
# st_wap_num                                              float64
# st_wap_per_classroom                                    float64
# SRC_devices_sent_home                                   float64
# SRC_Grades_Devices_Sent_Home                            float64
# total_class_teacher_num                                 int64
# total_nbpts_num                                         int64
# prin_other_pct                                          float64
# prinyrs_0thru3_pct                                      float64
# prinyrs_4thru10_pct                                     float64
# prinyrs_11plus_pct                                      float64
# prin_advance_dgr_pct                                    float64
# _1yr_prin_trnovr_pct                                    float64
# prin_male_pct                                           float64
# prin_female_pct                                         float64
# prin_black_pct                                          float64
# prin_white_pct                                          float64
# flicensed_teach_pct                                     float64
# tchyrs_0thru3_pct                                       float64
# tchyrs_4thru10_pct                                      float64
# tchyrs_11plus_pct                                       float64
# class_teach_num                                         float64
# nbpts_num                                               float64
# advance_dgr_pct                                         float64
# _1yr_tchr_trnovr_pct                                    float64
# emer_prov_teach_pct                                     float64
# lateral_teach_pct                                       float64
# highqual_class_pct                                      float64
# lea_flicensed_teach_pct                                 float64
# lea_tchyrs_0thru3_pct                                   float64
# lea_tchyrs_4thru10_pct                                  float64
# lea_tchyrs_11plus_pct                                   float64
# lea_class_teach_num                                     float64
# lea_nbpts_num                                           float64
# lea_advance_dgr_pct                                     float64
# lea_1yr_tchr_trnovr_pct                                 float64
# lea_emer_prov_teach_pct                                 float64
# lea_lateral_teach_pct                                   float64
# lea_highqual_class_pct                                  float64
# lea_highqual_class_hp_pct                               float64
# lea_highqual_class_lp_pct                               float64
# lea_highqual_class_all_pct                              float64
# lea_not_highqual_class_hp_pct                           float64
# lea_not_highqual_class_lp_pct                           float64
# lea_not_highqual_class_all_pct                          float64
# st_flicensed_teach_pct                                  float64
# st_tchyrs_0thru3_pct                                    float64
# st_tchyrs_4thru10_pct                                   float64
# st_tchyrs_11plus_pct                                    float64
# st_class_teach_num                                      float64
# st_nbpts_num                                            float64
# st_advance_dgr_pct                                      float64
# st_1yr_tchr_trnovr_pct                                  float64
# st_emer_prov_teach_pct                                  float64
# st_lateral_teach_pct                                    float64
# st_highqual_class_pct                                   float64
# st_highqual_class_hp_pct                                float64
# st_highqual_class_lp_pct                                float64
# st_highqual_class_all_pct                               float64
# st_not_highqual_class_hp_pct                            float64
# st_not_highqual_class_lp_pct                            float64
# st_not_highqual_class_all_pct                           float64
# st_prinyrs_0thru3_pct                                   float64
# st_prinyrs_4thru10_pct                                  float64
# st_prinyrs_11plus_pct                                   float64
# st_prin_advance_dgr_pct                                 float64
# st_1yr_prin_trnovr_pct                                  float64
# st_prin_male_pct                                        float64
# st_prin_female_pct                                      float64
# st_prin_black_pct                                       float64
# st_prin_white_pct                                       float64
# st_prin_other_pct                                       float64
# 0-3 Years_Exp_Pct_Tch                                   float64
# 10+ Years_Exp_Pct_Tch                                   float64
# 4-10 Years_Exp_Pct_Tch                                  float64
# 0-3 Years_LEA_Exp_Pct_Prin                              float64
# 10+ Years_LEA_Exp_Pct_Prin                              float64
# 4-10 Years_LEA_Exp_Pct_Prin                             float64
# Accomplished_PRIN_Standard 1_Pct                        float64
# Accomplished_PRIN_Standard 2_Pct                        float64
# Accomplished_PRIN_Standard 3_Pct                        float64
# Accomplished_PRIN_Standard 4_Pct                        float64
# Accomplished_PRIN_Standard 5_Pct                        float64
# Accomplished_PRIN_Standard 6_Pct                        float64
# Accomplished_PRIN_Standard 7_Pct                        float64
# Accomplished_TCHR_Standard 1_Pct                        float64
# Accomplished_TCHR_Standard 2_Pct                        float64
# Accomplished_TCHR_Standard 3_Pct                        float64
# Accomplished_TCHR_Standard 4_Pct                        float64
# Accomplished_TCHR_Standard 5_Pct                        float64
# Developing_PRIN_Standard 1_Pct                          float64
# Developing_PRIN_Standard 2_Pct                          float64
# Developing_PRIN_Standard 3_Pct                          float64
# Developing_PRIN_Standard 4_Pct                          float64
# Developing_PRIN_Standard 5_Pct                          float64
# Developing_PRIN_Standard 6_Pct                          float64
# Developing_PRIN_Standard 7_Pct                          float64
# Developing_TCHR_Standard 1_Pct                          float64
# Developing_TCHR_Standard 2_Pct                          float64
# Developing_TCHR_Standard 3_Pct                          float64
# Developing_TCHR_Standard 4_Pct                          float64
# Developing_TCHR_Standard 5_Pct                          float64
# Distinguished_PRIN_Standard 1_Pct                       float64
# Distinguished_PRIN_Standard 2_Pct                       float64
# Distinguished_PRIN_Standard 3_Pct                       float64
# Distinguished_PRIN_Standard 4_Pct                       float64
# Distinguished_PRIN_Standard 5_Pct                       float64
# Distinguished_PRIN_Standard 6_Pct                       float64
# Distinguished_PRIN_Standard 7_Pct                       float64
# Distinguished_TCHR_Standard 1_Pct                       float64
# Distinguished_TCHR_Standard 2_Pct                       float64
# Distinguished_TCHR_Standard 3_Pct                       float64
# Distinguished_TCHR_Standard 4_Pct                       float64
# Distinguished_TCHR_Standard 5_Pct                       float64
# Does Not Meet Expected Growth_PRIN_Standard 8_Pct       float64
# Does Not Meet Expected Growth_TCHR_Standard 6_Pct       float64
# Exceeds Expected Growth_PRIN_Standard 8_Pct             float64
# Exceeds Expected Growth_TCHR_Standard 6_Pct             float64
# Meets Expected Growth_PRIN_Standard 8_Pct               float64
# Meets Expected Growth_TCHR_Standard 6_Pct               float64
# Not Demostrated_PRIN_Standard 1_Pct                     float64
# Not Demostrated_PRIN_Standard 2_Pct                     float64
# Not Demostrated_PRIN_Standard 3_Pct                     float64
# Not Demostrated_PRIN_Standard 4_Pct                     float64
# Not Demostrated_PRIN_Standard 5_Pct                     float64
# Not Demostrated_PRIN_Standard 6_Pct                     float64
# Not Demostrated_PRIN_Standard 7_Pct                     float64
# Not Demostrated_TCHR_Standard 1_Pct                     float64
# Not Demostrated_TCHR_Standard 2_Pct                     float64
# Not Demostrated_TCHR_Standard 3_Pct                     float64
# Not Demostrated_TCHR_Standard 4_Pct                     float64
# Not Demostrated_TCHR_Standard 5_Pct                     float64
# Proficient_PRIN_Standard 1_Pct                          float64
# Proficient_PRIN_Standard 2_Pct                          float64
# Proficient_PRIN_Standard 3_Pct                          float64
# Proficient_PRIN_Standard 4_Pct                          float64
# Proficient_PRIN_Standard 5_Pct                          float64
# Proficient_PRIN_Standard 6_Pct                          float64
# Proficient_PRIN_Standard 7_Pct                          float64
# Proficient_TCHR_Standard 1_Pct                          float64
# Proficient_TCHR_Standard 2_Pct                          float64
# Proficient_TCHR_Standard 3_Pct                          float64
# Proficient_TCHR_Standard 4_Pct                          float64
# Proficient_TCHR_Standard 5_Pct                          float64
# AsianFemalePct                                          float64
# AsianMalePct                                            float64
# AsianPct                                                float64
# BlackFemalePct                                          float64
# BlackMalePct                                            float64
# BlackPct                                                float64
# HispanicFemalePct                                       float64
# HispanicMalePct                                         float64
# HispanicPct                                             float64
# IndianFemalePct                                         float64
# IndianMalePct                                           float64
# IndianPct                                               float64
# MinorityFemalePct                                       float64
# MinorityMalePct                                         float64
# MinorityPct                                             float64
# PacificIslandFemalePct                                  float64
# PacificIslandMalePct                                    float64
# PacificIslandPct                                        float64
# TwoOrMoreFemalePct                                      float64
# TwoOrMoreMalePct                                        float64
# TwoOrMorePct                                            float64
# WhiteFemalePct                                          float64
# WhiteMalePct                                            float64
# WhitePct                                                float64
# dtypes: float64(1224), int64(3), object(32)
# memory usage: 23.3+ MB

# %%
#Get Student Body Racial Composition Fields
raceCompositionFields = schoolData.filter(regex='Indian|Asian|Hispanic|Black|White|PacificIsland|TwoOrMore|Minority')\
                                  .filter(regex='Pct').columns
    
rowsBefore = schoolData[raceCompositionFields].isnull().T.any().T.sum()

#Update missing race values with the district average when avaiable (No district averages for charter schools) 
schoolData[raceCompositionFields] = schoolData.groupby('District Name')[raceCompositionFields]\
                                              .transform(lambda x: x.fillna(x.mean()))

    #Review dataset contents after Racial Composition Imputation
print('*********After: Updating Missing Racial Compostion Values****************************')   
rowsAfter = schoolData[raceCompositionFields].isnull().T.any().T.sum()
rowsUpdated = rowsBefore - rowsAfter
print 'Rows Updated / Imputed: ', rowsUpdated 
print('\r\nTotal Rows Missing Racial Compositions By District Name') 
schoolData['District Name'][schoolData[raceCompositionFields].isnull().T.any().T].value_counts()
# Out:
# *********After: Updating Missing Racial Compostion Values****************************
# Rows Updated / Imputed:  0
#
# Total Rows Missing Racial Compositions By District Name
# Series([], Name: District Name, dtype: int64)

# %% [markdown]
# ## Remove Columns with Problematic Data
# **Here we remove entire columns that could cause problems during machine learning.  The following operations are performed:**
# * Remove any columns that have the same value in every single row.
# * Remove any columns that have a unique value in every single row (all values are different).
# * Remove empty columns (all values are NA or NULL).

# %%
#Remove any fields that have the same value in all rows
UniqueValueCounts = schoolData.nunique(dropna=False)
SingleValueCols = UniqueValueCounts[UniqueValueCounts == 1].index
schoolData = schoolData.drop(SingleValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with the same value in every row.*******************')
schoolData.info(verbose=False)
print '\r\nColumns Deleted: ', len(SingleValueCols)
# Out:
# *********After: Removing columns with the same value in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2426 entries, 0 to 2560
# Columns: 1128 entries, vphone_ad to WhitePct
# dtypes: float64(1101), object(27)
# memory usage: 21.0+ MB
#
# Columns Deleted:  131

# %%
#Remove any fields that have unique values in every row
schoolDataRecordCt = schoolData.shape[0]
UniqueValueCounts = schoolData.apply(pd.Series.nunique)
AllUniqueValueCols = UniqueValueCounts[UniqueValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(AllUniqueValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with unique values in every row.*******************')
schoolData.info(verbose=False)
print '\r\nColumns Deleted: ', len(AllUniqueValueCols)
# Out:
# *********After: Removing columns with unique values in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2426 entries, 0 to 2560
# Columns: 1126 entries, vphone_ad to WhitePct
# dtypes: float64(1101), object(25)
# memory usage: 20.9+ MB
#
# Columns Deleted:  2

# %%
#Remove any empty fields (null values in every row)
schoolDataRecordCt = schoolData.shape[0]
NullValueCounts = schoolData.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with null / blank values in every row.*************')
schoolData.info(verbose=False)
print '\r\nColumns Deleted: ', len(NullValueCols)
# Out:
# *********After: Removing columns with null / blank values in every row.*************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2426 entries, 0 to 2560
# Columns: 1126 entries, vphone_ad to WhitePct
# dtypes: float64(1101), object(25)
# memory usage: 20.9+ MB
#
# Columns Deleted:  0

# %% [markdown]
# ## Handle Other Missing Values Types
# * Here we eliminate any numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# * All remaining non-race, numeric column missing values are populated with 0.
# * In many cases, it seems that schools are not simply not reporting values when they are zero. However, mean imputation or some other strategy might be considered.

# %%
#Isolate continuous and categorical data types
#These are indexers into the schoolData dataframe and may be used similar to the schoolData dataframe 
sD_boolean = schoolData.loc[:, (schoolData.dtypes == bool) ]
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]
sD_continuous = schoolData.loc[:, (schoolData.dtypes != bool) & (schoolData.dtypes != object)]
print "Boolean Columns: ", sD_boolean.shape[1]
print "Nominal Columns: ", sD_nominal.shape[1]
print "Continuous Columns: ", sD_continuous.shape[1]
print "Columns Accounted for: ", sD_nominal.shape[1] + sD_continuous.shape[1] + sD_boolean.shape[1]
# Out:
# Boolean Columns:  0
# Nominal Columns:  25
# Continuous Columns:  1101
# Columns Accounted for:  1126

# %%
#Eliminate continuous columns with more than missingThreshold percentage of missing values
schoolDataRecordCt = sD_continuous.shape[0]
missingValueLimit = schoolDataRecordCt * missingThreshold
NullValueCounts = sD_continuous.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts >= missingValueLimit].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with >= missingThreshold % of missing values******')
schoolData.info(verbose=False)
print '\r\nColumns Deleted: ', len(NullValueCols)
# Out:
# *********After: Removing columns with >= missingThreshold % of missing values******
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2426 entries, 0 to 2560
# Columns: 618 entries, vphone_ad to WhitePct
# dtypes: float64(593), object(25)
# memory usage: 11.5+ MB
#
# Columns Deleted:  508

# %% [markdown]
# ## One-Hot Encoding of Categorical Variables
# **All categorical / string variables are converted to numberic variables via one hot encoding.  Each unique row value will become a new binary / numeric column in the dataset.**
# * All remaining categorical columns are one-hot encoded.
# * In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# * Prior to one-hot encoding, columns with > *uniqueThreshold* unique values are deleted.

# %%
#Delete categorical columns with > 25 unique values (Each unique value becomes a column during one-hot encoding)
oneHotUniqueValueCounts = schoolData[sD_nominal.columns].apply(lambda x: x.nunique())
oneHotUniqueValueCols = oneHotUniqueValueCounts[oneHotUniqueValueCounts >= uniqueThreshold].index
schoolData.drop(oneHotUniqueValueCols, axis=1, inplace=True) 

#Review dataset contents one hot high unique value drops
print('*********After: Removing columns with >= uniqueThreshold unique values***********')
schoolData.info(verbose=False)
print '\r\nColumns Deleted: ', len(oneHotUniqueValueCols)
# Out:
# *********After: Removing columns with >= uniqueThreshold unique values***********
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2426 entries, 0 to 2560
# Columns: 608 entries, closed_ind to WhitePct
# dtypes: float64(593), object(15)
# memory usage: 11.3+ MB
#
# Columns Deleted:  10

# %%
#Isolate remaining categorical variables
begColumnCt = len(schoolData.columns)
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]

#one hot encode categorical variables
schoolData = pd.get_dummies(data=schoolData, 
                       columns=sD_nominal, drop_first=True)

#Determine change in column count
endColumnCt = len(schoolData.columns)
columnsAdded = endColumnCt - begColumnCt

#Review dataset contents one hot high unique value drops
print 'Columns To One-Hot Encode: ', len(sD_nominal.columns)
print('\r\n*********After: Adding New Columns Via One-Hot Encoding*************************')
schoolData.info(verbose=False)
print '\r\nNew Columns Created Via One-Hot Encoding: ', columnsAdded
# Out:
# Columns To One-Hot Encode:  15
#
# *********After: Adding New Columns Via One-Hot Encoding*************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2426 entries, 0 to 2560
# Columns: 644 entries, closed_ind to esea_attendance_Met
# dtypes: float64(593), uint8(51)
# memory usage: 11.1 MB
#
# New Columns Created Via One-Hot Encoding:  36

# %% [markdown]
# ## Impute any Remaining Missing Values as Zero

# %%
#Print out all the missing value rows
pd.set_option('display.max_rows', 1000)

print('\r\n*********The Remaining Missing Values Below will be set to Zero!*************************')

#Check for Missing values 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# *********The Remaining Missing Values Below will be set to Zero!*************************
#                                          Variable Name  Number Missing Values
# 2                                  lea_avg_student_num                      3
# 3                                   st_avg_student_num                      3
# 4                                          Math I_Size                   1396
# 15                                           SPG Score                    128
# 16                                  Reading  SPG Score                    599
# 17                                      Math SPG Score                    599
# 18                                  EVAAS Growth Score                    141
# 19                           Overall Achievement Score                    128
# 20                                          Read Score                    599
# 21                                          Math Score                    599
# 22                                       Science Score                    688
# 23                                        Math I Score                   1445
# 24                                   EOCMathI_CACR_All                   1371
# 25                                    EOCMathI_GLP_All                   1371
# 26                                EOCSubjects_CACR_All                   1360
# 27                                 EOCSubjects_GLP_All                   1360
# 28                            EOG/EOCSubjects_CACR_All                     43
# 29                             EOG/EOCSubjects_GLP_All                     43
# 30                                     EOGGr3_CACR_All                   1096
# 31                                      EOGGr3_GLP_All                   1096
# 32                                     EOGGr4_CACR_All                   1099
# 33                                      EOGGr4_GLP_All                   1099
# 34                                     EOGGr5_CACR_All                   1122
# 35                                      EOGGr5_GLP_All                   1122
# 36                                 EOGMathGr3_CACR_All                   1103
# 37                                  EOGMathGr3_GLP_All                   1103
# 38                               EOGMathGr3-8_CACR_All                    528
# 39                                EOGMathGr3-8_GLP_All                    528
# 40                                 EOGMathGr4_CACR_All                   1108
# 41                                  EOGMathGr4_GLP_All                   1108
# 42                                 EOGMathGr5_CACR_All                   1134
# 43                                  EOGMathGr5_GLP_All                   1134
# 44                              EOGReadingGr3_CACR_All                   1103
# 45                               EOGReadingGr3_GLP_All                   1103
# 46                            EOGReadingGr3-8_CACR_All                    528
# 47                             EOGReadingGr3-8_GLP_All                    528
# 48                              EOGReadingGr4_CACR_All                   1108
# 49                               EOGReadingGr4_GLP_All                   1108
# 50                              EOGReadingGr5_CACR_All                   1134
# 51                               EOGReadingGr5_GLP_All                   1134
# 52                              EOGScienceGr5_CACR_All                   1134
# 53                               EOGScienceGr5_GLP_All                   1134
# 54                            EOGScienceGr5&8_CACR_All                    626
# 55                             EOGScienceGr5&8_GLP_All                    626
# 56                                EOGSubjects_CACR_All                    523
# 57                                 EOGSubjects_GLP_All                    523
# 58                                EOCMathI_CACR_Female                   1371
# 59                                 EOCMathI_GLP_Female                   1371
# 60                             EOCSubjects_CACR_Female                   1360
# 61                              EOCSubjects_GLP_Female                   1360
# 62                         EOG/EOCSubjects_CACR_Female                     43
# 63                          EOG/EOCSubjects_GLP_Female                     43
# 64                                  EOGGr3_CACR_Female                   1096
# 65                                   EOGGr3_GLP_Female                   1096
# 66                                  EOGGr4_CACR_Female                   1099
# 67                                   EOGGr4_GLP_Female                   1099
# 68                                  EOGGr5_CACR_Female                   1122
# 69                                   EOGGr5_GLP_Female                   1122
# 70                              EOGMathGr3_CACR_Female                   1103
# 71                               EOGMathGr3_GLP_Female                   1103
# 72                            EOGMathGr3-8_CACR_Female                    528
# 73                             EOGMathGr3-8_GLP_Female                    528
# 74                              EOGMathGr4_CACR_Female                   1108
# 75                               EOGMathGr4_GLP_Female                   1108
# 76                              EOGMathGr5_CACR_Female                   1134
# 77                               EOGMathGr5_GLP_Female                   1134
# 78                           EOGReadingGr3_CACR_Female                   1103
# 79                            EOGReadingGr3_GLP_Female                   1103
# 80                         EOGReadingGr3-8_CACR_Female                    528
# 81                          EOGReadingGr3-8_GLP_Female                    528
# 82                           EOGReadingGr4_CACR_Female                   1108
# 83                            EOGReadingGr4_GLP_Female                   1108
# 84                           EOGReadingGr5_CACR_Female                   1134
# 85                            EOGReadingGr5_GLP_Female                   1134
# 86                           EOGScienceGr5_CACR_Female                   1134
# 87                            EOGScienceGr5_GLP_Female                   1134
# 88                         EOGScienceGr5&8_CACR_Female                    626
# 89                          EOGScienceGr5&8_GLP_Female                    626
# 90                             EOGSubjects_CACR_Female                    523
# 91                              EOGSubjects_GLP_Female                    523
# 92                                  EOCMathI_CACR_Male                   1371
# 93                                   EOCMathI_GLP_Male                   1371
# 94                               EOCSubjects_CACR_Male                   1360
# 95                                EOCSubjects_GLP_Male                   1360
# 96                           EOG/EOCSubjects_CACR_Male                     43
# 97                            EOG/EOCSubjects_GLP_Male                     43
# 98                                    EOGGr3_CACR_Male                   1096
# 99                                     EOGGr3_GLP_Male                   1096
# 100                                   EOGGr4_CACR_Male                   1099
# 101                                    EOGGr4_GLP_Male                   1099
# 102                                   EOGGr5_CACR_Male                   1122
# 103                                    EOGGr5_GLP_Male                   1122
# 104                               EOGMathGr3_CACR_Male                   1103
# 105                                EOGMathGr3_GLP_Male                   1103
# 106                             EOGMathGr3-8_CACR_Male                    528
# 107                              EOGMathGr3-8_GLP_Male                    528
# 108                               EOGMathGr4_CACR_Male                   1108
# 109                                EOGMathGr4_GLP_Male                   1108
# 110                               EOGMathGr5_CACR_Male                   1134
# 111                                EOGMathGr5_GLP_Male                   1134
# 112                            EOGReadingGr3_CACR_Male                   1103
# 113                             EOGReadingGr3_GLP_Male                   1103
# 114                          EOGReadingGr3-8_CACR_Male                    528
# 115                           EOGReadingGr3-8_GLP_Male                    528
# 116                            EOGReadingGr4_CACR_Male                   1108
# 117                             EOGReadingGr4_GLP_Male                   1108
# 118                            EOGReadingGr5_CACR_Male                   1134
# 119                             EOGReadingGr5_GLP_Male                   1134
# 120                            EOGScienceGr5_CACR_Male                   1134
# 121                             EOGScienceGr5_GLP_Male                   1134
# 122                          EOGScienceGr5&8_CACR_Male                    626
# 123                           EOGScienceGr5&8_GLP_Male                    626
# 124                              EOGSubjects_CACR_Male                    523
# 125                               EOGSubjects_GLP_Male                    523
# 126                       EOCMathI_CACR_AmericanIndian                   1371
# 127                        EOCMathI_GLP_AmericanIndian                   1371
# 128                    EOCSubjects_CACR_AmericanIndian                   1360
# 129                     EOCSubjects_GLP_AmericanIndian                   1360
# 130                EOG/EOCSubjects_CACR_AmericanIndian                     43
# 131                 EOG/EOCSubjects_GLP_AmericanIndian                     43
# 132                         EOGGr3_CACR_AmericanIndian                   1096
# 133                          EOGGr3_GLP_AmericanIndian                   1096
# 134                         EOGGr4_CACR_AmericanIndian                   1099
# 135                          EOGGr4_GLP_AmericanIndian                   1099
# 136                         EOGGr5_CACR_AmericanIndian                   1122
# 137                          EOGGr5_GLP_AmericanIndian                   1122
# 138                     EOGMathGr3_CACR_AmericanIndian                   1103
# 139                      EOGMathGr3_GLP_AmericanIndian                   1103
# 140                   EOGMathGr3-8_CACR_AmericanIndian                    528
# 141                    EOGMathGr3-8_GLP_AmericanIndian                    528
# 142                     EOGMathGr4_CACR_AmericanIndian                   1108
# 143                      EOGMathGr4_GLP_AmericanIndian                   1108
# 144                     EOGMathGr5_CACR_AmericanIndian                   1134
# 145                      EOGMathGr5_GLP_AmericanIndian                   1134
# 146                  EOGReadingGr3_CACR_AmericanIndian                   1103
# 147                   EOGReadingGr3_GLP_AmericanIndian                   1103
# 148                EOGReadingGr3-8_CACR_AmericanIndian                    528
# 149                 EOGReadingGr3-8_GLP_AmericanIndian                    528
# 150                  EOGReadingGr4_CACR_AmericanIndian                   1108
# 151                   EOGReadingGr4_GLP_AmericanIndian                   1108
# 152                  EOGReadingGr5_CACR_AmericanIndian                   1134
# 153                   EOGReadingGr5_GLP_AmericanIndian                   1134
# 154                  EOGScienceGr5_CACR_AmericanIndian                   1134
# 155                   EOGScienceGr5_GLP_AmericanIndian                   1134
# 156                EOGScienceGr5&8_CACR_AmericanIndian                    626
# 157                 EOGScienceGr5&8_GLP_AmericanIndian                    626
# 158                    EOGSubjects_CACR_AmericanIndian                    523
# 159                     EOGSubjects_GLP_AmericanIndian                    523
# 160                                EOCMathI_CACR_Asian                   1371
# 161                                 EOCMathI_GLP_Asian                   1371
# 162                             EOCSubjects_CACR_Asian                   1360
# 163                              EOCSubjects_GLP_Asian                   1360
# 164                         EOG/EOCSubjects_CACR_Asian                     43
# 165                          EOG/EOCSubjects_GLP_Asian                     43
# 166                                  EOGGr3_CACR_Asian                   1096
# 167                                   EOGGr3_GLP_Asian                   1096
# 168                                  EOGGr4_CACR_Asian                   1099
# 169                                   EOGGr4_GLP_Asian                   1099
# 170                                  EOGGr5_CACR_Asian                   1122
# 171                                   EOGGr5_GLP_Asian                   1122
# 172                              EOGMathGr3_CACR_Asian                   1103
# 173                               EOGMathGr3_GLP_Asian                   1103
# 174                            EOGMathGr3-8_CACR_Asian                    528
# 175                             EOGMathGr3-8_GLP_Asian                    528
# 176                              EOGMathGr4_CACR_Asian                   1108
# 177                               EOGMathGr4_GLP_Asian                   1108
# 178                              EOGMathGr5_CACR_Asian                   1134
# 179                               EOGMathGr5_GLP_Asian                   1134
# 180                           EOGReadingGr3_CACR_Asian                   1103
# 181                            EOGReadingGr3_GLP_Asian                   1103
# 182                         EOGReadingGr3-8_CACR_Asian                    528
# 183                          EOGReadingGr3-8_GLP_Asian                    528
# 184                           EOGReadingGr4_CACR_Asian                   1108
# 185                            EOGReadingGr4_GLP_Asian                   1108
# 186                           EOGReadingGr5_CACR_Asian                   1134
# 187                            EOGReadingGr5_GLP_Asian                   1134
# 188                           EOGScienceGr5_CACR_Asian                   1134
# 189                            EOGScienceGr5_GLP_Asian                   1134
# 190                         EOGScienceGr5&8_CACR_Asian                    626
# 191                          EOGScienceGr5&8_GLP_Asian                    626
# 192                             EOGSubjects_CACR_Asian                    523
# 193                              EOGSubjects_GLP_Asian                    523
# 194                                EOCMathI_CACR_Black                   1371
# 195                                 EOCMathI_GLP_Black                   1371
# 196                             EOCSubjects_CACR_Black                   1360
# 197                              EOCSubjects_GLP_Black                   1360
# 198                         EOG/EOCSubjects_CACR_Black                     43
# 199                          EOG/EOCSubjects_GLP_Black                     43
# 200                                  EOGGr3_CACR_Black                   1096
# 201                                   EOGGr3_GLP_Black                   1096
# 202                                  EOGGr4_CACR_Black                   1099
# 203                                   EOGGr4_GLP_Black                   1099
# 204                                  EOGGr5_CACR_Black                   1122
# 205                                   EOGGr5_GLP_Black                   1122
# 206                              EOGMathGr3_CACR_Black                   1103
# 207                               EOGMathGr3_GLP_Black                   1103
# 208                            EOGMathGr3-8_CACR_Black                    528
# 209                             EOGMathGr3-8_GLP_Black                    528
# 210                              EOGMathGr4_CACR_Black                   1108
# 211                               EOGMathGr4_GLP_Black                   1108
# 212                              EOGMathGr5_CACR_Black                   1134
# 213                               EOGMathGr5_GLP_Black                   1134
# 214                           EOGReadingGr3_CACR_Black                   1103
# 215                            EOGReadingGr3_GLP_Black                   1103
# 216                         EOGReadingGr3-8_CACR_Black                    528
# 217                          EOGReadingGr3-8_GLP_Black                    528
# 218                           EOGReadingGr4_CACR_Black                   1108
# 219                            EOGReadingGr4_GLP_Black                   1108
# 220                           EOGReadingGr5_CACR_Black                   1134
# 221                            EOGReadingGr5_GLP_Black                   1134
# 222                           EOGScienceGr5_CACR_Black                   1134
# 223                            EOGScienceGr5_GLP_Black                   1134
# 224                         EOGScienceGr5&8_CACR_Black                    626
# 225                          EOGScienceGr5&8_GLP_Black                    626
# 226                             EOGSubjects_CACR_Black                    523
# 227                              EOGSubjects_GLP_Black                    523
# 228                             EOCMathI_CACR_Hispanic                   1371
# 229                              EOCMathI_GLP_Hispanic                   1371
# 230                          EOCSubjects_CACR_Hispanic                   1360
# 231                           EOCSubjects_GLP_Hispanic                   1360
# 232                      EOG/EOCSubjects_CACR_Hispanic                     43
# 233                       EOG/EOCSubjects_GLP_Hispanic                     43
# 234                               EOGGr3_CACR_Hispanic                   1096
# 235                                EOGGr3_GLP_Hispanic                   1096
# 236                               EOGGr4_CACR_Hispanic                   1099
# 237                                EOGGr4_GLP_Hispanic                   1099
# 238                               EOGGr5_CACR_Hispanic                   1122
# 239                                EOGGr5_GLP_Hispanic                   1122
# 240                           EOGMathGr3_CACR_Hispanic                   1103
# 241                            EOGMathGr3_GLP_Hispanic                   1103
# 242                         EOGMathGr3-8_CACR_Hispanic                    528
# 243                          EOGMathGr3-8_GLP_Hispanic                    528
# 244                           EOGMathGr4_CACR_Hispanic                   1108
# 245                            EOGMathGr4_GLP_Hispanic                   1108
# 246                           EOGMathGr5_CACR_Hispanic                   1134
# 247                            EOGMathGr5_GLP_Hispanic                   1134
# 248                        EOGReadingGr3_CACR_Hispanic                   1103
# 249                         EOGReadingGr3_GLP_Hispanic                   1103
# 250                      EOGReadingGr3-8_CACR_Hispanic                    528
# 251                       EOGReadingGr3-8_GLP_Hispanic                    528
# 252                        EOGReadingGr4_CACR_Hispanic                   1108
# 253                         EOGReadingGr4_GLP_Hispanic                   1108
# 254                        EOGReadingGr5_CACR_Hispanic                   1134
# 255                         EOGReadingGr5_GLP_Hispanic                   1134
# 256                        EOGScienceGr5_CACR_Hispanic                   1134
# 257                         EOGScienceGr5_GLP_Hispanic                   1134
# 258                      EOGScienceGr5&8_CACR_Hispanic                    626
# 259                       EOGScienceGr5&8_GLP_Hispanic                    626
# 260                          EOGSubjects_CACR_Hispanic                    523
# 261                           EOGSubjects_GLP_Hispanic                    523
# 262                       EOCMathI_CACR_TwoorMoreRaces                   1371
# 263                        EOCMathI_GLP_TwoorMoreRaces                   1371
# 264                    EOCSubjects_CACR_TwoorMoreRaces                   1360
# 265                     EOCSubjects_GLP_TwoorMoreRaces                   1360
# 266                EOG/EOCSubjects_CACR_TwoorMoreRaces                     43
# 267                 EOG/EOCSubjects_GLP_TwoorMoreRaces                     43
# 268                         EOGGr3_CACR_TwoorMoreRaces                   1096
# 269                          EOGGr3_GLP_TwoorMoreRaces                   1096
# 270                         EOGGr4_CACR_TwoorMoreRaces                   1099
# 271                          EOGGr4_GLP_TwoorMoreRaces                   1099
# 272                         EOGGr5_CACR_TwoorMoreRaces                   1122
# 273                          EOGGr5_GLP_TwoorMoreRaces                   1122
# 274                     EOGMathGr3_CACR_TwoorMoreRaces                   1103
# 275                      EOGMathGr3_GLP_TwoorMoreRaces                   1103
# 276                   EOGMathGr3-8_CACR_TwoorMoreRaces                    528
# 277                    EOGMathGr3-8_GLP_TwoorMoreRaces                    528
# 278                     EOGMathGr4_CACR_TwoorMoreRaces                   1108
# 279                      EOGMathGr4_GLP_TwoorMoreRaces                   1108
# 280                     EOGMathGr5_CACR_TwoorMoreRaces                   1134
# 281                      EOGMathGr5_GLP_TwoorMoreRaces                   1134
# 282                  EOGReadingGr3_CACR_TwoorMoreRaces                   1103
# 283                   EOGReadingGr3_GLP_TwoorMoreRaces                   1103
# 284                EOGReadingGr3-8_CACR_TwoorMoreRaces                    528
# 285                 EOGReadingGr3-8_GLP_TwoorMoreRaces                    528
# 286                  EOGReadingGr4_CACR_TwoorMoreRaces                   1108
# 287                   EOGReadingGr4_GLP_TwoorMoreRaces                   1108
# 288                  EOGReadingGr5_CACR_TwoorMoreRaces                   1134
# 289                   EOGReadingGr5_GLP_TwoorMoreRaces                   1134
# 290                  EOGScienceGr5_CACR_TwoorMoreRaces                   1134
# 291                   EOGScienceGr5_GLP_TwoorMoreRaces                   1134
# 292                EOGScienceGr5&8_CACR_TwoorMoreRaces                    626
# 293                 EOGScienceGr5&8_GLP_TwoorMoreRaces                    626
# 294                    EOGSubjects_CACR_TwoorMoreRaces                    523
# 295                     EOGSubjects_GLP_TwoorMoreRaces                    523
# 296                                EOCMathI_CACR_White                   1371
# 297                                 EOCMathI_GLP_White                   1371
# 298                             EOCSubjects_CACR_White                   1360
# 299                              EOCSubjects_GLP_White                   1360
# 300                         EOG/EOCSubjects_CACR_White                     43
# 301                          EOG/EOCSubjects_GLP_White                     43
# 302                                  EOGGr3_CACR_White                   1096
# 303                                   EOGGr3_GLP_White                   1096
# 304                                  EOGGr4_CACR_White                   1099
# 305                                   EOGGr4_GLP_White                   1099
# 306                                  EOGGr5_CACR_White                   1122
# 307                                   EOGGr5_GLP_White                   1122
# 308                              EOGMathGr3_CACR_White                   1103
# 309                               EOGMathGr3_GLP_White                   1103
# 310                            EOGMathGr3-8_CACR_White                    528
# 311                             EOGMathGr3-8_GLP_White                    528
# 312                              EOGMathGr4_CACR_White                   1108
# 313                               EOGMathGr4_GLP_White                   1108
# 314                              EOGMathGr5_CACR_White                   1134
# 315                               EOGMathGr5_GLP_White                   1134
# 316                           EOGReadingGr3_CACR_White                   1103
# 317                            EOGReadingGr3_GLP_White                   1103
# 318                         EOGReadingGr3-8_CACR_White                    528
# 319                          EOGReadingGr3-8_GLP_White                    528
# 320                           EOGReadingGr4_CACR_White                   1108
# 321                            EOGReadingGr4_GLP_White                   1108
# 322                           EOGReadingGr5_CACR_White                   1134
# 323                            EOGReadingGr5_GLP_White                   1134
# 324                           EOGScienceGr5_CACR_White                   1134
# 325                            EOGScienceGr5_GLP_White                   1134
# 326                         EOGScienceGr5&8_CACR_White                    626
# 327                          EOGScienceGr5&8_GLP_White                    626
# 328                             EOGSubjects_CACR_White                    523
# 329                              EOGSubjects_GLP_White                    523
# 330                                  EOCMathI_CACR_EDS                   1371
# 331                                   EOCMathI_GLP_EDS                   1371
# 332                               EOCSubjects_CACR_EDS                   1360
# 333                                EOCSubjects_GLP_EDS                   1360
# 334                           EOG/EOCSubjects_CACR_EDS                     43
# 335                            EOG/EOCSubjects_GLP_EDS                     43
# 336                                    EOGGr3_CACR_EDS                   1096
# 337                                     EOGGr3_GLP_EDS                   1096
# 338                                    EOGGr4_CACR_EDS                   1099
# 339                                     EOGGr4_GLP_EDS                   1099
# 340                                    EOGGr5_CACR_EDS                   1122
# 341                                     EOGGr5_GLP_EDS                   1122
# 342                                EOGMathGr3_CACR_EDS                   1103
# 343                                 EOGMathGr3_GLP_EDS                   1103
# 344                              EOGMathGr3-8_CACR_EDS                    528
# 345                               EOGMathGr3-8_GLP_EDS                    528
# 346                                EOGMathGr4_CACR_EDS                   1108
# 347                                 EOGMathGr4_GLP_EDS                   1108
# 348                                EOGMathGr5_CACR_EDS                   1134
# 349                                 EOGMathGr5_GLP_EDS                   1134
# 350                             EOGReadingGr3_CACR_EDS                   1103
# 351                              EOGReadingGr3_GLP_EDS                   1103
# 352                           EOGReadingGr3-8_CACR_EDS                    528
# 353                            EOGReadingGr3-8_GLP_EDS                    528
# 354                             EOGReadingGr4_CACR_EDS                   1108
# 355                              EOGReadingGr4_GLP_EDS                   1108
# 356                             EOGReadingGr5_CACR_EDS                   1134
# 357                              EOGReadingGr5_GLP_EDS                   1134
# 358                             EOGScienceGr5_CACR_EDS                   1134
# 359                              EOGScienceGr5_GLP_EDS                   1134
# 360                           EOGScienceGr5&8_CACR_EDS                    626
# 361                            EOGScienceGr5&8_GLP_EDS                    626
# 362                               EOGSubjects_CACR_EDS                    523
# 363                                EOGSubjects_GLP_EDS                    523
# 364                                  EOCMathI_CACR_LEP                   1371
# 365                                   EOCMathI_GLP_LEP                   1371
# 366                               EOCSubjects_CACR_LEP                   1360
# 367                                EOCSubjects_GLP_LEP                   1360
# 368                           EOG/EOCSubjects_CACR_LEP                     43
# 369                            EOG/EOCSubjects_GLP_LEP                     43
# 370                                    EOGGr3_CACR_LEP                   1096
# 371                                     EOGGr3_GLP_LEP                   1096
# 372                                    EOGGr4_CACR_LEP                   1099
# 373                                     EOGGr4_GLP_LEP                   1099
# 374                                    EOGGr5_CACR_LEP                   1122
# 375                                     EOGGr5_GLP_LEP                   1122
# 376                                EOGMathGr3_CACR_LEP                   1103
# 377                                 EOGMathGr3_GLP_LEP                   1103
# 378                              EOGMathGr3-8_CACR_LEP                    528
# 379                               EOGMathGr3-8_GLP_LEP                    528
# 380                                EOGMathGr4_CACR_LEP                   1108
# 381                                 EOGMathGr4_GLP_LEP                   1108
# 382                                EOGMathGr5_CACR_LEP                   1134
# 383                                 EOGMathGr5_GLP_LEP                   1134
# 384                             EOGReadingGr3_CACR_LEP                   1103
# 385                              EOGReadingGr3_GLP_LEP                   1103
# 386                           EOGReadingGr3-8_CACR_LEP                    528
# 387                            EOGReadingGr3-8_GLP_LEP                    528
# 388                             EOGReadingGr4_CACR_LEP                   1108
# 389                              EOGReadingGr4_GLP_LEP                   1108
# 390                             EOGReadingGr5_CACR_LEP                   1134
# 391                              EOGReadingGr5_GLP_LEP                   1134
# 392                             EOGScienceGr5_CACR_LEP                   1134
# 393                              EOGScienceGr5_GLP_LEP                   1134
# 394                           EOGScienceGr5&8_CACR_LEP                    626
# 395                            EOGScienceGr5&8_GLP_LEP                    626
# 396                               EOGSubjects_CACR_LEP                    523
# 397                                EOGSubjects_GLP_LEP                    523
# 398                                  EOCMathI_CACR_SWD                   1371
# 399                                   EOCMathI_GLP_SWD                   1371
# 400                               EOCSubjects_CACR_SWD                   1360
# 401                                EOCSubjects_GLP_SWD                   1360
# 402                           EOG/EOCSubjects_CACR_SWD                     43
# 403                            EOG/EOCSubjects_GLP_SWD                     43
# 404                                    EOGGr3_CACR_SWD                   1096
# 405                                     EOGGr3_GLP_SWD                   1096
# 406                                    EOGGr4_CACR_SWD                   1099
# 407                                     EOGGr4_GLP_SWD                   1099
# 408                                    EOGGr5_CACR_SWD                   1122
# 409                                     EOGGr5_GLP_SWD                   1122
# 410                                EOGMathGr3_CACR_SWD                   1103
# 411                                 EOGMathGr3_GLP_SWD                   1103
# 412                              EOGMathGr3-8_CACR_SWD                    528
# 413                               EOGMathGr3-8_GLP_SWD                    528
# 414                                EOGMathGr4_CACR_SWD                   1108
# 415                                 EOGMathGr4_GLP_SWD                   1108
# 416                                EOGMathGr5_CACR_SWD                   1134
# 417                                 EOGMathGr5_GLP_SWD                   1134
# 418                             EOGReadingGr3_CACR_SWD                   1103
# 419                              EOGReadingGr3_GLP_SWD                   1103
# 420                           EOGReadingGr3-8_CACR_SWD                    528
# 421                            EOGReadingGr3-8_GLP_SWD                    528
# 422                             EOGReadingGr4_CACR_SWD                   1108
# 423                              EOGReadingGr4_GLP_SWD                   1108
# 424                             EOGReadingGr5_CACR_SWD                   1134
# 425                              EOGReadingGr5_GLP_SWD                   1134
# 426                             EOGScienceGr5_CACR_SWD                   1134
# 427                              EOGScienceGr5_GLP_SWD                   1134
# 428                           EOGScienceGr5&8_CACR_SWD                    626
# 429                            EOGScienceGr5&8_GLP_SWD                    626
# 430                               EOGSubjects_CACR_SWD                    523
# 431                                EOGSubjects_GLP_SWD                    523
# 432                                  EOCMathI_CACR_AIG                   1371
# 433                                   EOCMathI_GLP_AIG                   1371
# 434                               EOCSubjects_CACR_AIG                   1360
# 435                                EOCSubjects_GLP_AIG                   1360
# 436                           EOG/EOCSubjects_CACR_AIG                     43
# 437                            EOG/EOCSubjects_GLP_AIG                     43
# 438                                    EOGGr3_CACR_AIG                   1096
# 439                                     EOGGr3_GLP_AIG                   1096
# 440                                    EOGGr4_CACR_AIG                   1099
# 441                                     EOGGr4_GLP_AIG                   1099
# 442                                    EOGGr5_CACR_AIG                   1122
# 443                                     EOGGr5_GLP_AIG                   1122
# 444                                EOGMathGr3_CACR_AIG                   1103
# 445                                 EOGMathGr3_GLP_AIG                   1103
# 446                              EOGMathGr3-8_CACR_AIG                    528
# 447                               EOGMathGr3-8_GLP_AIG                    528
# 448                                EOGMathGr4_CACR_AIG                   1108
# 449                                 EOGMathGr4_GLP_AIG                   1108
# 450                                EOGMathGr5_CACR_AIG                   1134
# 451                                 EOGMathGr5_GLP_AIG                   1134
# 452                             EOGReadingGr3_CACR_AIG                   1103
# 453                              EOGReadingGr3_GLP_AIG                   1103
# 454                           EOGReadingGr3-8_CACR_AIG                    528
# 455                            EOGReadingGr3-8_GLP_AIG                    528
# 456                             EOGReadingGr4_CACR_AIG                   1108
# 457                              EOGReadingGr4_GLP_AIG                   1108
# 458                             EOGReadingGr5_CACR_AIG                   1134
# 459                              EOGReadingGr5_GLP_AIG                   1134
# 460                             EOGScienceGr5_CACR_AIG                   1134
# 461                              EOGScienceGr5_GLP_AIG                   1134
# 462                           EOGScienceGr5&8_CACR_AIG                    626
# 463                            EOGScienceGr5&8_GLP_AIG                    626
# 464                               EOGSubjects_CACR_AIG                    523
# 465                                EOGSubjects_GLP_AIG                    523
# 466                                        pct_GCE_ALL                   1085
# 467                                     pct_PASSED_EOG                   1115
# 468                                       pct_PROMOTED                   1106
# 469                           MathGr3-8_pTarget_PctMet                    574
# 470                        ReadingGr3-8_pTarget_PctMet                    574
# 471                            SciGr5&8_pTarget_PctMet                    727
# 472                        TotalTargets_pTarget_PctMet                     62
# 475                           lea_ap_participation_pct                    473
# 476                              lea_ap_pct_3_or_above                     24
# 477                              lea_ib_pct_4_or_above                   1452
# 483                             stud_internet_comp_num                      4
# 484                           lea_avg_daily_attend_pct                      3
# 485                                lea_crime_per_c_num                      3
# 486                           lea_short_susp_per_c_num                      3
# 487                            lea_long_susp_per_c_num                      3
# 488                             lea_expelled_per_c_num                      3
# 489                         lea_stud_internet_comp_num                      3
# 490                            st_avg_daily_attend_pct                      3
# 491                                 st_crime_per_c_num                      3
# 492                            st_short_susp_per_c_num                      3
# 493                             st_long_susp_per_c_num                      3
# 494                              st_expelled_per_c_num                      3
# 495                          st_stud_internet_comp_num                      3
# 496                                flicensed_teach_pct                      1
# 497                                  tchyrs_0thru3_pct                      1
# 498                                 tchyrs_4thru10_pct                      1
# 499                                  tchyrs_11plus_pct                      1
# 500                                    class_teach_num                      1
# 501                                          nbpts_num                    167
# 502                                    advance_dgr_pct                      1
# 503                               _1yr_tchr_trnovr_pct                     16
# 504                                  lateral_teach_pct                   1357
# 505                            lea_flicensed_teach_pct                      3
# 506                              lea_tchyrs_0thru3_pct                      3
# 507                             lea_tchyrs_4thru10_pct                      3
# 508                              lea_tchyrs_11plus_pct                      3
# 509                                lea_class_teach_num                      3
# 510                                      lea_nbpts_num                     36
# 511                                lea_advance_dgr_pct                      3
# 512                            lea_1yr_tchr_trnovr_pct                      6
# 513                            lea_emer_prov_teach_pct                    819
# 514                              lea_lateral_teach_pct                    264
# 515                             st_flicensed_teach_pct                      3
# 516                               st_tchyrs_0thru3_pct                      3
# 517                              st_tchyrs_4thru10_pct                      3
# 518                               st_tchyrs_11plus_pct                      3
# 519                                 st_class_teach_num                      3
# 520                                       st_nbpts_num                      3
# 521                                 st_advance_dgr_pct                      3
# 522                             st_1yr_tchr_trnovr_pct                      3
# 523                             st_emer_prov_teach_pct                      3
# 524                               st_lateral_teach_pct                      3
# 525                              st_prinyrs_0thru3_pct                      3
# 526                             st_prinyrs_4thru10_pct                      3
# 527                              st_prinyrs_11plus_pct                      3
# 528                            st_prin_advance_dgr_pct                      3
# 529                             st_1yr_prin_trnovr_pct                      3
# 530                                   st_prin_male_pct                      3
# 531                                 st_prin_female_pct                      3
# 532                                  st_prin_black_pct                      3
# 533                                  st_prin_white_pct                      3
# 534                                  st_prin_other_pct                      3
# 535                              0-3 Years_Exp_Pct_Tch                      1
# 536                              10+ Years_Exp_Pct_Tch                      1
# 537                             4-10 Years_Exp_Pct_Tch                      1
# 538                         0-3 Years_LEA_Exp_Pct_Prin                      3
# 539                         10+ Years_LEA_Exp_Pct_Prin                      3
# 540                        4-10 Years_LEA_Exp_Pct_Prin                      3
# 541                   Accomplished_TCHR_Standard 1_Pct                     81
# 542                   Accomplished_TCHR_Standard 2_Pct                     81
# 543                   Accomplished_TCHR_Standard 3_Pct                     81
# 544                   Accomplished_TCHR_Standard 4_Pct                     81
# 545                   Accomplished_TCHR_Standard 5_Pct                     81
# 546                     Developing_TCHR_Standard 1_Pct                     81
# 547                     Developing_TCHR_Standard 2_Pct                     81
# 548                     Developing_TCHR_Standard 3_Pct                     81
# 549                     Developing_TCHR_Standard 4_Pct                     81
# 550                     Developing_TCHR_Standard 5_Pct                     81
# 551                  Distinguished_TCHR_Standard 1_Pct                     81
# 552                  Distinguished_TCHR_Standard 2_Pct                     81
# 553                  Distinguished_TCHR_Standard 3_Pct                     81
# 554                  Distinguished_TCHR_Standard 4_Pct                     81
# 555                  Distinguished_TCHR_Standard 5_Pct                     81
# 556  Does Not Meet Expected Growth_TCHR_Standard 6_Pct                     81
# 557        Exceeds Expected Growth_TCHR_Standard 6_Pct                     81
# 558          Meets Expected Growth_TCHR_Standard 6_Pct                     81
# 559                Not Demostrated_TCHR_Standard 1_Pct                     81
# 560                Not Demostrated_TCHR_Standard 2_Pct                     81
# 561                Not Demostrated_TCHR_Standard 3_Pct                     81
# 562                Not Demostrated_TCHR_Standard 4_Pct                     81
# 563                Not Demostrated_TCHR_Standard 5_Pct                     81
# 564                     Proficient_TCHR_Standard 1_Pct                     81
# 565                     Proficient_TCHR_Standard 2_Pct                     81
# 566                     Proficient_TCHR_Standard 3_Pct                     81
# 567                     Proficient_TCHR_Standard 4_Pct                     81
# 568                     Proficient_TCHR_Standard 5_Pct                     81

# %%
#Replace all remaining NaN with 0
schoolData = schoolData.fillna(0)

#Check for Missing values after final imputation 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# Empty DataFrame
# Columns: [Variable Name, Number Missing Values]
# Index: []

# %% [markdown]
# ## Identify and Remove Highly Correlated Features
# **Find and remove any columns / features that are > 95% correlated**
# * https://stackoverflow.com/questions/39409866/correlation-heatmap
# * https://chrisalbon.com/machine_learning/feature_selection/drop_highly_correlated_features/
# * https://codeyarns.com/2015/04/20/how-to-change-font-size-in-seaborn/

# %%
# calculate the correlation matrix
corr_matrix  = schoolData.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
#Get all of the correlation values > 95%
x = np.where(upper > 0.95)

#Display all field combinations with > 95% correlation
cf = pd.DataFrame()
cf['Field1'] = upper.columns[x[1]]
cf['Field2'] = upper.index[x[0]]

#Get the correlation values for every field combination. (There must be a more pythonic way to do this!)
corr = [0] * len(cf)
for i in range(0, len(cf)):
    corr[i] =  upper[cf['Field1'][i]][cf['Field2'][i]] 
    
cf['Correlation'] = corr

print 'There are ', str(len(cf['Field1'])), ' field correlations > 95%.'
cf
# Out:
# There are  1141  field correlations > 95%.
#                                                  Field1  \
# 0                                       class_teach_num
# 1                                   lea_class_teach_num
# 2                                    st_class_teach_num
# 3                             Overall Achievement Score
# 4                                        Math SPG Score
# 5                                            Read Score
# 6                                            Math Score
# 7                              EOGReadingGr3-8_CACR_All
# 8                               EOGReadingGr3-8_GLP_All
# 9                                  EOGSubjects_CACR_All
# 10                                  EOGSubjects_GLP_All
# 11                          EOGReadingGr3-8_CACR_Female
# 12                           EOGReadingGr3-8_GLP_Female
# 13                              EOGSubjects_CACR_Female
# 14                               EOGSubjects_GLP_Female
# 15                             EOGReadingGr3-8_GLP_Male
# 16                                 EOGSubjects_GLP_Male
# 17                                           Read Score
# 18                                           Math Score
# 19                                EOGMathGr3-8_CACR_All
# 20                                 EOGMathGr3-8_GLP_All
# 21                              EOGReadingGr3-8_GLP_All
# 22                                 EOGSubjects_CACR_All
# 23                                  EOGSubjects_GLP_All
# 24                             EOGMathGr3-8_CACR_Female
# 25                              EOGMathGr3-8_GLP_Female
# 26                              EOGSubjects_CACR_Female
# 27                               EOGSubjects_GLP_Female
# 28                               EOGMathGr3-8_CACR_Male
# 29                                EOGMathGr3-8_GLP_Male
# 30                                EOGSubjects_CACR_Male
# 31                                 EOGSubjects_GLP_Male
# 32                                           Math Score
# 33                                 EOGMathGr3-8_GLP_All
# 34                             EOGReadingGr3-8_CACR_All
# 35                              EOGReadingGr3-8_GLP_All
# 36                                 EOGSubjects_CACR_All
# 37                                  EOGSubjects_GLP_All
# 38                          EOGReadingGr3-8_CACR_Female
# 39                           EOGReadingGr3-8_GLP_Female
# 40                              EOGSubjects_CACR_Female
# 41                               EOGSubjects_GLP_Female
# 42                            EOGReadingGr3-8_CACR_Male
# 43                             EOGReadingGr3-8_GLP_Male
# 44                                EOGSubjects_CACR_Male
# 45                                 EOGSubjects_GLP_Male
# 46                                EOGMathGr3-8_CACR_All
# 47                                 EOGMathGr3-8_GLP_All
# 48                                 EOGSubjects_CACR_All
# 49                                  EOGSubjects_GLP_All
# 50                             EOGMathGr3-8_CACR_Female
# 51                              EOGMathGr3-8_GLP_Female
# 52                              EOGSubjects_CACR_Female
# 53                               EOGSubjects_GLP_Female
# 54                               EOGMathGr3-8_CACR_Male
# 55                                EOGMathGr3-8_GLP_Male
# 56                                EOGSubjects_CACR_Male
# 57                                 EOGSubjects_GLP_Male
# 58                             EOGScienceGr5&8_CACR_All
# 59                              EOGScienceGr5&8_GLP_All
# 60                          EOGScienceGr5&8_CACR_Female
# 61                           EOGScienceGr5&8_GLP_Female
# 62                            EOGScienceGr5&8_CACR_Male
# 63                             EOGScienceGr5&8_GLP_Male
# 64                              EOGScienceGr5&8_GLP_EDS
# 65                                    EOCMathI_CACR_All
# 66                                     EOCMathI_GLP_All
# 67                                 EOCSubjects_CACR_All
# 68                                  EOCSubjects_GLP_All
# 69                                 EOCMathI_CACR_Female
# 70                                  EOCMathI_GLP_Female
# 71                              EOCSubjects_CACR_Female
# 72                               EOCSubjects_GLP_Female
# 73                                   EOCMathI_CACR_Male
# 74                                    EOCMathI_GLP_Male
# 75                                EOCSubjects_CACR_Male
# 76                                 EOCSubjects_GLP_Male
# 77                                     EOCMathI_GLP_All
# 78                                 EOCSubjects_CACR_All
# 79                                  EOCSubjects_GLP_All
# 80                                 EOCMathI_CACR_Female
# 81                                  EOCMathI_GLP_Female
# 82                              EOCSubjects_CACR_Female
# 83                               EOCSubjects_GLP_Female
# 84                                   EOCMathI_CACR_Male
# 85                                EOCSubjects_CACR_Male
# 86                                  EOCMathI_CACR_White
# 87                                 EOCSubjects_CACR_All
# 88                                  EOCSubjects_GLP_All
# 89                                 EOCMathI_CACR_Female
# 90                                  EOCMathI_GLP_Female
# 91                              EOCSubjects_CACR_Female
# 92                               EOCSubjects_GLP_Female
# 93                                   EOCMathI_CACR_Male
# 94                                    EOCMathI_GLP_Male
# 95                                EOCSubjects_CACR_Male
# 96                                 EOCSubjects_GLP_Male
# 97                                  EOCSubjects_GLP_All
# 98                                 EOCMathI_CACR_Female
# 99                                  EOCMathI_GLP_Female
# 100                             EOCSubjects_CACR_Female
# 101                              EOCSubjects_GLP_Female
# 102                                  EOCMathI_CACR_Male
# 103                               EOCSubjects_CACR_Male
# 104                                EOCSubjects_GLP_Male
# 105                                 EOCMathI_CACR_White
# 106                              EOCSubjects_CACR_White
# 107                                 EOCMathI_GLP_Female
# 108                             EOCSubjects_CACR_Female
# 109                              EOCSubjects_GLP_Female
# 110                                   EOCMathI_GLP_Male
# 111                               EOCSubjects_CACR_Male
# 112                                EOCSubjects_GLP_Male
# 113                               EOCSubjects_GLP_White
# 114                             EOG/EOCSubjects_GLP_All
# 115                         EOG/EOCSubjects_CACR_Female
# 116                          EOG/EOCSubjects_GLP_Female
# 117                           EOG/EOCSubjects_CACR_Male
# 118                            EOG/EOCSubjects_GLP_Male
# 119                         EOG/EOCSubjects_CACR_Female
# 120                          EOG/EOCSubjects_GLP_Female
# 121                           EOG/EOCSubjects_CACR_Male
# 122                            EOG/EOCSubjects_GLP_Male
# 123                                      EOGGr3_GLP_All
# 124                                 EOGMathGr3_CACR_All
# 125                                  EOGMathGr3_GLP_All
# 126                              EOGReadingGr3_CACR_All
# 127                               EOGReadingGr3_GLP_All
# 128                                  EOGGr3_CACR_Female
# 129                                   EOGGr3_GLP_Female
# 130                              EOGMathGr3_CACR_Female
# 131                               EOGMathGr3_GLP_Female
# 132                           EOGReadingGr3_CACR_Female
# 133                            EOGReadingGr3_GLP_Female
# 134                                    EOGGr3_CACR_Male
# 135                                     EOGGr3_GLP_Male
# 136                                EOGMathGr3_CACR_Male
# 137                                 EOGMathGr3_GLP_Male
# 138                             EOGReadingGr3_CACR_Male
# 139                              EOGReadingGr3_GLP_Male
# 140                                     EOGGr3_CACR_EDS
# 141                                      pct_PASSED_EOG
# 142                                 EOGMathGr3_CACR_All
# 143                                  EOGMathGr3_GLP_All
# 144                              EOGReadingGr3_CACR_All
# 145                               EOGReadingGr3_GLP_All
# 146                                  EOGGr3_CACR_Female
# 147                                   EOGGr3_GLP_Female
# 148                              EOGMathGr3_CACR_Female
# 149                               EOGMathGr3_GLP_Female
# 150                           EOGReadingGr3_CACR_Female
# 151                            EOGReadingGr3_GLP_Female
# 152                                    EOGGr3_CACR_Male
# 153                                     EOGGr3_GLP_Male
# 154                                EOGMathGr3_CACR_Male
# 155                                 EOGMathGr3_GLP_Male
# 156                             EOGReadingGr3_CACR_Male
# 157                              EOGReadingGr3_GLP_Male
# 158                                    EOGGr3_GLP_White
# 159                                     EOGGr3_CACR_EDS
# 160                                      EOGGr3_GLP_EDS
# 161                                  EOGMathGr3_GLP_EDS
# 162                               EOGReadingGr3_GLP_EDS
# 163                                      pct_PASSED_EOG
# 164                                      EOGGr4_GLP_All
# 165                                 EOGMathGr4_CACR_All
# 166                                  EOGMathGr4_GLP_All
# 167                              EOGReadingGr4_CACR_All
# 168                               EOGReadingGr4_GLP_All
# 169                                  EOGGr4_CACR_Female
# 170                                   EOGGr4_GLP_Female
# 171                              EOGMathGr4_CACR_Female
# 172                               EOGMathGr4_GLP_Female
# 173                           EOGReadingGr4_CACR_Female
# 174                            EOGReadingGr4_GLP_Female
# 175                                    EOGGr4_CACR_Male
# 176                                     EOGGr4_GLP_Male
# 177                                EOGMathGr4_CACR_Male
# 178                                 EOGMathGr4_GLP_Male
# 179                             EOGReadingGr4_CACR_Male
# 180                              EOGReadingGr4_GLP_Male
# 181                                 EOGMathGr4_CACR_All
# 182                                  EOGMathGr4_GLP_All
# 183                              EOGReadingGr4_CACR_All
# 184                               EOGReadingGr4_GLP_All
# 185                                  EOGGr4_CACR_Female
# 186                                   EOGGr4_GLP_Female
# 187                              EOGMathGr4_CACR_Female
# 188                               EOGMathGr4_GLP_Female
# 189                           EOGReadingGr4_CACR_Female
# 190                            EOGReadingGr4_GLP_Female
# 191                                    EOGGr4_CACR_Male
# 192                                     EOGGr4_GLP_Male
# 193                                EOGMathGr4_CACR_Male
# 194                                 EOGMathGr4_GLP_Male
# 195                             EOGReadingGr4_CACR_Male
# 196                              EOGReadingGr4_GLP_Male
# 197                                      EOGGr4_GLP_EDS
# 198                                      EOGGr5_GLP_All
# 199                                 EOGMathGr5_CACR_All
# 200                                  EOGMathGr5_GLP_All
# 201                              EOGReadingGr5_CACR_All
# 202                               EOGReadingGr5_GLP_All
# 203                              EOGScienceGr5_CACR_All
# 204                               EOGScienceGr5_GLP_All
# 205                                  EOGGr5_CACR_Female
# 206                                   EOGGr5_GLP_Female
# 207                              EOGMathGr5_CACR_Female
# 208                               EOGMathGr5_GLP_Female
# 209                           EOGReadingGr5_CACR_Female
# 210                            EOGReadingGr5_GLP_Female
# 211                           EOGScienceGr5_CACR_Female
# 212                            EOGScienceGr5_GLP_Female
# 213                                    EOGGr5_CACR_Male
# 214                                     EOGGr5_GLP_Male
# 215                                EOGMathGr5_CACR_Male
# 216                                 EOGMathGr5_GLP_Male
# 217                             EOGReadingGr5_CACR_Male
# 218                              EOGReadingGr5_GLP_Male
# 219                             EOGScienceGr5_CACR_Male
# 220                              EOGScienceGr5_GLP_Male
# 221                                   EOGGr5_CACR_White
# 222                                     EOGGr5_CACR_EDS
# 223                                      EOGGr5_GLP_EDS
# 224                                 EOGMathGr5_CACR_All
# 225                                  EOGMathGr5_GLP_All
# 226                              EOGReadingGr5_CACR_All
# 227                               EOGReadingGr5_GLP_All
# 228                              EOGScienceGr5_CACR_All
# 229                               EOGScienceGr5_GLP_All
# 230                                  EOGGr5_CACR_Female
# 231                                   EOGGr5_GLP_Female
# 232                              EOGMathGr5_CACR_Female
# 233                               EOGMathGr5_GLP_Female
# 234                            EOGReadingGr5_GLP_Female
# 235                           EOGScienceGr5_CACR_Female
# 236                            EOGScienceGr5_GLP_Female
# 237                                    EOGGr5_CACR_Male
# 238                                     EOGGr5_GLP_Male
# 239                                EOGMathGr5_CACR_Male
# 240                                 EOGMathGr5_GLP_Male
# 241                              EOGReadingGr5_GLP_Male
# 242                             EOGScienceGr5_CACR_Male
# 243                              EOGScienceGr5_GLP_Male
# 244                                   EOGGr5_CACR_White
# 245                                    EOGGr5_GLP_White
# 246                                     EOGGr5_CACR_EDS
# 247                                      EOGGr5_GLP_EDS
# 248                                  EOGMathGr3_GLP_All
# 249                              EOGReadingGr3_CACR_All
# 250                               EOGReadingGr3_GLP_All
# 251                                  EOGGr3_CACR_Female
# 252                                   EOGGr3_GLP_Female
# 253                              EOGMathGr3_CACR_Female
# 254                               EOGMathGr3_GLP_Female
# 255                                    EOGGr3_CACR_Male
# 256                                     EOGGr3_GLP_Male
# 257                                EOGMathGr3_CACR_Male
# 258                                 EOGMathGr3_GLP_Male
# 259                              EOGReadingGr3_GLP_Male
# 260                                      pct_PASSED_EOG
# 261                              EOGReadingGr3_CACR_All
# 262                               EOGReadingGr3_GLP_All
# 263                                  EOGGr3_CACR_Female
# 264                                   EOGGr3_GLP_Female
# 265                              EOGMathGr3_CACR_Female
# 266                               EOGMathGr3_GLP_Female
# 267                           EOGReadingGr3_CACR_Female
# 268                            EOGReadingGr3_GLP_Female
# 269                                    EOGGr3_CACR_Male
# 270                                     EOGGr3_GLP_Male
# 271                                EOGMathGr3_CACR_Male
# 272                                 EOGMathGr3_GLP_Male
# 273                              EOGReadingGr3_GLP_Male
# 274                                     EOGGr3_CACR_EDS
# 275                                      EOGGr3_GLP_EDS
# 276                                  EOGMathGr3_GLP_EDS
# 277                                      pct_PASSED_EOG
# 278                                EOGMathGr3-8_GLP_All
# 279                                EOGSubjects_CACR_All
# 280                                 EOGSubjects_GLP_All
# 281                            EOGMathGr3-8_CACR_Female
# 282                             EOGMathGr3-8_GLP_Female
# 283                             EOGSubjects_CACR_Female
# 284                              EOGSubjects_GLP_Female
# 285                              EOGMathGr3-8_CACR_Male
# 286                               EOGMathGr3-8_GLP_Male
# 287                               EOGSubjects_CACR_Male
# 288                                EOGSubjects_GLP_Male
# 289                             EOGReadingGr3-8_GLP_All
# 290                                EOGSubjects_CACR_All
# 291                                 EOGSubjects_GLP_All
# 292                            EOGMathGr3-8_CACR_Female
# 293                             EOGMathGr3-8_GLP_Female
# 294                             EOGSubjects_CACR_Female
# 295                              EOGSubjects_GLP_Female
# 296                              EOGMathGr3-8_CACR_Male
# 297                               EOGMathGr3-8_GLP_Male
# 298                               EOGSubjects_CACR_Male
# 299                                EOGSubjects_GLP_Male
# 300                                EOGMathGr3-8_GLP_EDS
# 301                                  EOGMathGr4_GLP_All
# 302                              EOGReadingGr4_CACR_All
# 303                               EOGReadingGr4_GLP_All
# 304                                  EOGGr4_CACR_Female
# 305                                   EOGGr4_GLP_Female
# 306                              EOGMathGr4_CACR_Female
# 307                               EOGMathGr4_GLP_Female
# 308                                    EOGGr4_CACR_Male
# 309                                     EOGGr4_GLP_Male
# 310                                EOGMathGr4_CACR_Male
# 311                                 EOGMathGr4_GLP_Male
# 312                              EOGReadingGr4_CACR_All
# 313                               EOGReadingGr4_GLP_All
# 314                                  EOGGr4_CACR_Female
# 315                                   EOGGr4_GLP_Female
# 316                              EOGMathGr4_CACR_Female
# 317                               EOGMathGr4_GLP_Female
# 318                                    EOGGr4_CACR_Male
# 319                                     EOGGr4_GLP_Male
# 320                                EOGMathGr4_CACR_Male
# 321                                 EOGMathGr4_GLP_Male
# 322                              EOGReadingGr4_GLP_Male
# 323                                  EOGMathGr5_GLP_All
# 324                              EOGReadingGr5_CACR_All
# 325                               EOGReadingGr5_GLP_All
# 326                              EOGScienceGr5_CACR_All
# 327                               EOGScienceGr5_GLP_All
# 328                                  EOGGr5_CACR_Female
# 329                                   EOGGr5_GLP_Female
# 330                              EOGMathGr5_CACR_Female
# 331                               EOGMathGr5_GLP_Female
# 332                            EOGReadingGr5_GLP_Female
# 333                                    EOGGr5_CACR_Male
# 334                                     EOGGr5_GLP_Male
# 335                                EOGMathGr5_CACR_Male
# 336                                 EOGMathGr5_GLP_Male
# 337                              EOGReadingGr5_GLP_Male
# 338                              EOGScienceGr5_GLP_Male
# 339                              EOGReadingGr5_CACR_All
# 340                               EOGReadingGr5_GLP_All
# 341                              EOGScienceGr5_CACR_All
# 342                               EOGScienceGr5_GLP_All
# 343                                  EOGGr5_CACR_Female
# 344                                   EOGGr5_GLP_Female
# 345                              EOGMathGr5_CACR_Female
# 346                               EOGMathGr5_GLP_Female
# 347                            EOGReadingGr5_GLP_Female
# 348                            EOGScienceGr5_GLP_Female
# 349                                    EOGGr5_CACR_Male
# 350                                     EOGGr5_GLP_Male
# 351                                EOGMathGr5_CACR_Male
# 352                                 EOGMathGr5_GLP_Male
# 353                              EOGReadingGr5_GLP_Male
# 354                             EOGScienceGr5_CACR_Male
# 355                              EOGScienceGr5_GLP_Male
# 356                                      EOGGr5_GLP_EDS
# 357                                  EOGMathGr5_GLP_EDS
# 358                               EOGReadingGr3_GLP_All
# 359                                  EOGGr3_CACR_Female
# 360                                   EOGGr3_GLP_Female
# 361                               EOGMathGr3_GLP_Female
# 362                           EOGReadingGr3_CACR_Female
# 363                            EOGReadingGr3_GLP_Female
# 364                                    EOGGr3_CACR_Male
# 365                                     EOGGr3_GLP_Male
# 366                                 EOGMathGr3_GLP_Male
# 367                             EOGReadingGr3_CACR_Male
# 368                              EOGReadingGr3_GLP_Male
# 369                                      pct_PASSED_EOG
# 370                                  EOGGr3_CACR_Female
# 371                                   EOGGr3_GLP_Female
# 372                               EOGMathGr3_GLP_Female
# 373                           EOGReadingGr3_CACR_Female
# 374                            EOGReadingGr3_GLP_Female
# 375                                    EOGGr3_CACR_Male
# 376                                     EOGGr3_GLP_Male
# 377                                 EOGMathGr3_GLP_Male
# 378                             EOGReadingGr3_CACR_Male
# 379                              EOGReadingGr3_GLP_Male
# 380                                      EOGGr3_GLP_EDS
# 381                               EOGReadingGr3_GLP_EDS
# 382                                      pct_PASSED_EOG
# 383                             EOGReadingGr3-8_GLP_All
# 384                                EOGSubjects_CACR_All
# 385                                 EOGSubjects_GLP_All
# 386                         EOGReadingGr3-8_CACR_Female
# 387                          EOGReadingGr3-8_GLP_Female
# 388                             EOGSubjects_CACR_Female
# 389                              EOGSubjects_GLP_Female
# 390                           EOGReadingGr3-8_CACR_Male
# 391                            EOGReadingGr3-8_GLP_Male
# 392                               EOGSubjects_CACR_Male
# 393                                EOGSubjects_GLP_Male
# 394                                EOGSubjects_CACR_All
# 395                                 EOGSubjects_GLP_All
# 396                         EOGReadingGr3-8_CACR_Female
# 397                          EOGReadingGr3-8_GLP_Female
# 398                             EOGSubjects_CACR_Female
# 399                              EOGSubjects_GLP_Female
# 400                           EOGReadingGr3-8_CACR_Male
# 401                            EOGReadingGr3-8_GLP_Male
# 402                               EOGSubjects_CACR_Male
# 403                                EOGSubjects_GLP_Male
# 404                             EOGReadingGr3-8_GLP_EDS
# 405                               EOGReadingGr4_GLP_All
# 406                                  EOGGr4_CACR_Female
# 407                                   EOGGr4_GLP_Female
# 408                           EOGReadingGr4_CACR_Female
# 409                            EOGReadingGr4_GLP_Female
# 410                                    EOGGr4_CACR_Male
# 411                                     EOGGr4_GLP_Male
# 412                                 EOGMathGr4_GLP_Male
# 413                             EOGReadingGr4_CACR_Male
# 414                              EOGReadingGr4_GLP_Male
# 415                                  EOGGr4_CACR_Female
# 416                                   EOGGr4_GLP_Female
# 417                           EOGReadingGr4_CACR_Female
# 418                            EOGReadingGr4_GLP_Female
# 419                                    EOGGr4_CACR_Male
# 420                                     EOGGr4_GLP_Male
# 421                                 EOGMathGr4_GLP_Male
# 422                             EOGReadingGr4_CACR_Male
# 423                              EOGReadingGr4_GLP_Male
# 424                               EOGReadingGr5_GLP_All
# 425                                  EOGGr5_CACR_Female
# 426                                   EOGGr5_GLP_Female
# 427                           EOGReadingGr5_CACR_Female
# 428                            EOGReadingGr5_GLP_Female
# 429                                    EOGGr5_CACR_Male
# 430                                     EOGGr5_GLP_Male
# 431                             EOGReadingGr5_CACR_Male
# 432                              EOGReadingGr5_GLP_Male
# 433                              EOGScienceGr5_CACR_All
# 434                               EOGScienceGr5_GLP_All
# 435                                  EOGGr5_CACR_Female
# 436                                   EOGGr5_GLP_Female
# 437                           EOGReadingGr5_CACR_Female
# 438                            EOGReadingGr5_GLP_Female
# 439                            EOGScienceGr5_GLP_Female
# 440                                    EOGGr5_CACR_Male
# 441                                     EOGGr5_GLP_Male
# 442                                 EOGMathGr5_GLP_Male
# 443                             EOGReadingGr5_CACR_Male
# 444                              EOGReadingGr5_GLP_Male
# 445                             EOGScienceGr5_CACR_Male
# 446                              EOGScienceGr5_GLP_Male
# 447                                    EOGGr5_GLP_White
# 448                               EOGReadingGr5_GLP_EDS
# 449                               EOGScienceGr5_GLP_All
# 450                                  EOGGr5_CACR_Female
# 451                                   EOGGr5_GLP_Female
# 452                           EOGScienceGr5_CACR_Female
# 453                            EOGScienceGr5_GLP_Female
# 454                                    EOGGr5_CACR_Male
# 455                                     EOGGr5_GLP_Male
# 456                             EOGScienceGr5_CACR_Male
# 457                              EOGScienceGr5_GLP_Male
# 458                              EOGScienceGr5_CACR_EDS
# 459                               EOGScienceGr5_GLP_EDS
# 460                                  EOGGr5_CACR_Female
# 461                                   EOGGr5_GLP_Female
# 462                            EOGReadingGr5_GLP_Female
# 463                           EOGScienceGr5_CACR_Female
# 464                            EOGScienceGr5_GLP_Female
# 465                                    EOGGr5_CACR_Male
# 466                                     EOGGr5_GLP_Male
# 467                                 EOGMathGr5_GLP_Male
# 468                              EOGReadingGr5_GLP_Male
# 469                             EOGScienceGr5_CACR_Male
# 470                              EOGScienceGr5_GLP_Male
# 471                                      EOGGr5_GLP_EDS
# 472                               EOGScienceGr5_GLP_EDS
# 473                             EOGScienceGr5&8_GLP_All
# 474                         EOGScienceGr5&8_CACR_Female
# 475                          EOGScienceGr5&8_GLP_Female
# 476                           EOGScienceGr5&8_CACR_Male
# 477                            EOGScienceGr5&8_GLP_Male
# 478                         EOGScienceGr5&8_CACR_Female
# 479                          EOGScienceGr5&8_GLP_Female
# 480                           EOGScienceGr5&8_CACR_Male
# 481                            EOGScienceGr5&8_GLP_Male
# 482                             EOGScienceGr5&8_GLP_EDS
# 483                                 EOGSubjects_GLP_All
# 484                            EOGMathGr3-8_CACR_Female
# 485                             EOGMathGr3-8_GLP_Female
# 486                         EOGReadingGr3-8_CACR_Female
# 487                          EOGReadingGr3-8_GLP_Female
# 488                             EOGSubjects_CACR_Female
# 489                              EOGSubjects_GLP_Female
# 490                              EOGMathGr3-8_CACR_Male
# 491                               EOGMathGr3-8_GLP_Male
# 492                           EOGReadingGr3-8_CACR_Male
# 493                            EOGReadingGr3-8_GLP_Male
# 494                               EOGSubjects_CACR_Male
# 495                                EOGSubjects_GLP_Male
# 496                            EOGMathGr3-8_CACR_Female
# 497                             EOGMathGr3-8_GLP_Female
# 498                         EOGReadingGr3-8_CACR_Female
# 499                          EOGReadingGr3-8_GLP_Female
# ...                                                 ...
# 641                               EOGSubjects_CACR_Male
# 642                                EOGSubjects_GLP_Male
# 643                                 EOGSubjects_GLP_EDS
# 644                                   EOCMathI_GLP_Male
# 645                               EOCSubjects_CACR_Male
# 646                                EOCSubjects_GLP_Male
# 647                               EOCSubjects_CACR_Male
# 648                                EOCSubjects_GLP_Male
# 649                                EOCSubjects_GLP_Male
# 650                            EOG/EOCSubjects_GLP_Male
# 651                                     EOGGr3_GLP_Male
# 652                                EOGMathGr3_CACR_Male
# 653                                 EOGMathGr3_GLP_Male
# 654                             EOGReadingGr3_CACR_Male
# 655                              EOGReadingGr3_GLP_Male
# 656                                      pct_PASSED_EOG
# 657                                EOGMathGr3_CACR_Male
# 658                                 EOGMathGr3_GLP_Male
# 659                             EOGReadingGr3_CACR_Male
# 660                              EOGReadingGr3_GLP_Male
# 661                                      EOGGr3_GLP_EDS
# 662                                      pct_PASSED_EOG
# 663                                     EOGGr4_GLP_Male
# 664                                EOGMathGr4_CACR_Male
# 665                                 EOGMathGr4_GLP_Male
# 666                             EOGReadingGr4_CACR_Male
# 667                              EOGReadingGr4_GLP_Male
# 668                                EOGMathGr4_CACR_Male
# 669                                 EOGMathGr4_GLP_Male
# 670                             EOGReadingGr4_CACR_Male
# 671                              EOGReadingGr4_GLP_Male
# 672                                     EOGGr5_GLP_Male
# 673                                EOGMathGr5_CACR_Male
# 674                                 EOGMathGr5_GLP_Male
# 675                             EOGReadingGr5_CACR_Male
# 676                              EOGReadingGr5_GLP_Male
# 677                             EOGScienceGr5_CACR_Male
# 678                              EOGScienceGr5_GLP_Male
# 679                                EOGMathGr5_CACR_Male
# 680                                 EOGMathGr5_GLP_Male
# 681                             EOGReadingGr5_CACR_Male
# 682                              EOGReadingGr5_GLP_Male
# 683                             EOGScienceGr5_CACR_Male
# 684                              EOGScienceGr5_GLP_Male
# 685                                      EOGGr5_GLP_EDS
# 686                                 EOGMathGr3_GLP_Male
# 687                             EOGReadingGr3_CACR_Male
# 688                              EOGReadingGr3_GLP_Male
# 689                             EOGReadingGr3_CACR_Male
# 690                              EOGReadingGr3_GLP_Male
# 691                                      pct_PASSED_EOG
# 692                               EOGMathGr3-8_GLP_Male
# 693                               EOGSubjects_CACR_Male
# 694                                EOGSubjects_GLP_Male
# 695                            EOGReadingGr3-8_GLP_Male
# 696                               EOGSubjects_CACR_Male
# 697                                EOGSubjects_GLP_Male
# 698                                 EOGMathGr4_GLP_Male
# 699                              EOGReadingGr4_GLP_Male
# 700                              EOGReadingGr4_GLP_Male
# 701                                 EOGMathGr5_GLP_Male
# 702                              EOGReadingGr5_GLP_Male
# 703                             EOGScienceGr5_CACR_Male
# 704                              EOGScienceGr5_GLP_Male
# 705                              EOGReadingGr5_GLP_Male
# 706                             EOGScienceGr5_CACR_Male
# 707                              EOGScienceGr5_GLP_Male
# 708                              EOGReadingGr3_GLP_Male
# 709                                      pct_PASSED_EOG
# 710                                      pct_PASSED_EOG
# 711                            EOGReadingGr3-8_GLP_Male
# 712                               EOGSubjects_CACR_Male
# 713                                EOGSubjects_GLP_Male
# 714                               EOGSubjects_CACR_Male
# 715                                EOGSubjects_GLP_Male
# 716                              EOGReadingGr4_GLP_Male
# 717                              EOGReadingGr5_GLP_Male
# 718                             EOGScienceGr5_CACR_Male
# 719                              EOGScienceGr5_GLP_Male
# 720                              EOGScienceGr5_GLP_Male
# 721                                      EOGGr5_GLP_EDS
# 722                               EOGScienceGr5_GLP_EDS
# 723                            EOGScienceGr5&8_GLP_Male
# 724                             EOGScienceGr5&8_GLP_EDS
# 725                                EOGSubjects_GLP_Male
# 726                                 EOGSubjects_GLP_EDS
# 727                         EOCMathI_GLP_AmericanIndian
# 728                      EOCSubjects_GLP_AmericanIndian
# 729                  EOG/EOCSubjects_GLP_AmericanIndian
# 730                           EOGGr3_GLP_AmericanIndian
# 731                           EOGGr4_GLP_AmericanIndian
# 732                           EOGGr5_GLP_AmericanIndian
# 733                       EOGMathGr3_GLP_AmericanIndian
# 734                     EOGMathGr3-8_GLP_AmericanIndian
# 735                       EOGMathGr4_GLP_AmericanIndian
# 736                       EOGMathGr5_GLP_AmericanIndian
# 737                    EOGReadingGr3_GLP_AmericanIndian
# 738                  EOGReadingGr3-8_GLP_AmericanIndian
# 739                    EOGReadingGr4_GLP_AmericanIndian
# 740                    EOGReadingGr5_GLP_AmericanIndian
# 741                    EOGScienceGr5_GLP_AmericanIndian
# 742                  EOGScienceGr5&8_GLP_AmericanIndian
# 743                      EOGSubjects_GLP_AmericanIndian
# 744                                  EOCMathI_GLP_Asian
# 745                               EOCSubjects_GLP_Asian
# 746                           EOG/EOCSubjects_GLP_Asian
# 747                                    EOGGr3_GLP_Asian
# 748                                    EOGGr4_GLP_Asian
# 749                                    EOGGr5_GLP_Asian
# 750                                EOGMathGr3_GLP_Asian
# 751                            EOGReadingGr3_CACR_Asian
# 752                             EOGReadingGr3_GLP_Asian
# 753                            EOGReadingGr3_CACR_Asian
# 754                             EOGReadingGr3_GLP_Asian
# 755                              EOGMathGr3-8_GLP_Asian
# 756                          EOGReadingGr3-8_CACR_Asian
# 757                           EOGReadingGr3-8_GLP_Asian
# 758                          EOGReadingGr3-8_CACR_Asian
# 759                           EOGReadingGr3-8_GLP_Asian
# 760                                EOGMathGr4_GLP_Asian
# 761                            EOGReadingGr4_CACR_Asian
# 762                             EOGReadingGr4_GLP_Asian
# 763                            EOGReadingGr4_CACR_Asian
# 764                             EOGReadingGr4_GLP_Asian
# 765                                EOGMathGr5_GLP_Asian
# 766                             EOGReadingGr5_GLP_Asian
# 767                            EOGScienceGr5_CACR_Asian
# 768                             EOGScienceGr5_GLP_Asian
# 769                             EOGReadingGr5_GLP_Asian
# 770                            EOGScienceGr5_CACR_Asian
# 771                             EOGScienceGr5_GLP_Asian
# 772                             EOGReadingGr3_GLP_Asian
# 773                           EOGReadingGr3-8_GLP_Asian
# 774                             EOGReadingGr4_GLP_Asian
# 775                             EOGReadingGr5_GLP_Asian
# 776                            EOGScienceGr5_CACR_Asian
# 777                             EOGScienceGr5_GLP_Asian
# 778                             EOGScienceGr5_GLP_Asian
# 779                           EOGScienceGr5&8_GLP_Asian
# 780                               EOGSubjects_GLP_Asian
# 781                                  EOCMathI_GLP_Black
# 782                              EOCSubjects_CACR_Black
# 783                               EOCSubjects_GLP_Black
# 784                               EOCSubjects_GLP_Black
# 785                           EOG/EOCSubjects_GLP_Black
# 786                                    EOGGr3_GLP_Black
# 787                                    EOGGr4_GLP_Black
# 788                                    EOGGr5_GLP_Black
# 789                                EOGMathGr3_GLP_Black
# 790                              EOGMathGr3-8_GLP_Black
# 791                                EOGMathGr4_GLP_Black
# 792                                EOGMathGr5_GLP_Black
# 793                             EOGReadingGr3_GLP_Black
# 794                           EOGReadingGr3-8_GLP_Black
# 795                             EOGReadingGr4_GLP_Black
# 796                             EOGScienceGr5_GLP_Black
# 797                           EOGScienceGr5&8_GLP_Black
# 798                               EOGSubjects_GLP_Black
# 799                               EOCMathI_GLP_Hispanic
# 800                            EOCSubjects_GLP_Hispanic
# 801                                 EOGGr3_GLP_Hispanic
# 802                                 EOGGr4_GLP_Hispanic
# 803                                 EOGGr5_GLP_Hispanic
# 804                             EOGMathGr3_GLP_Hispanic
# 805                           EOGMathGr3-8_GLP_Hispanic
# 806                             EOGMathGr4_GLP_Hispanic
# 807                             EOGMathGr5_GLP_Hispanic
# 808                          EOGReadingGr3_GLP_Hispanic
# 809                          EOGReadingGr4_GLP_Hispanic
# 810                          EOGScienceGr5_GLP_Hispanic
# 811                        EOGScienceGr5&8_GLP_Hispanic
# 812                            EOGSubjects_GLP_Hispanic
# 813                         EOCMathI_GLP_TwoorMoreRaces
# 814                      EOCSubjects_GLP_TwoorMoreRaces
# 815                  EOG/EOCSubjects_GLP_TwoorMoreRaces
# 816                           EOGGr3_GLP_TwoorMoreRaces
# 817                           EOGGr4_GLP_TwoorMoreRaces
# 818                           EOGGr5_GLP_TwoorMoreRaces
# 819                       EOGMathGr3_GLP_TwoorMoreRaces
# 820                     EOGMathGr3-8_GLP_TwoorMoreRaces
# 821                       EOGMathGr4_GLP_TwoorMoreRaces
# 822                       EOGMathGr5_GLP_TwoorMoreRaces
# 823                    EOGScienceGr5_GLP_TwoorMoreRaces
# 824                    EOGReadingGr3_GLP_TwoorMoreRaces
# 825                  EOGReadingGr3-8_GLP_TwoorMoreRaces
# 826                    EOGReadingGr4_GLP_TwoorMoreRaces
# 827                    EOGReadingGr5_GLP_TwoorMoreRaces
# 828                    EOGScienceGr5_GLP_TwoorMoreRaces
# 829                  EOGScienceGr5&8_GLP_TwoorMoreRaces
# 830                      EOGSubjects_GLP_TwoorMoreRaces
# 831                                  EOCMathI_GLP_White
# 832                              EOCSubjects_CACR_White
# 833                               EOCSubjects_GLP_White
# 834                              EOCSubjects_CACR_White
# 835                               EOCSubjects_GLP_White
# 836                               EOCSubjects_GLP_White
# 837                           EOG/EOCSubjects_GLP_White
# 838                                    EOGGr3_GLP_White
# 839                               EOGMathGr3_CACR_White
# 840                                EOGMathGr3_GLP_White
# 841                            EOGReadingGr3_CACR_White
# 842                             EOGReadingGr3_GLP_White
# 843                               EOGMathGr3_CACR_White
# 844                                EOGMathGr3_GLP_White
# 845                            EOGReadingGr3_CACR_White
# 846                             EOGReadingGr3_GLP_White
# 847                                    EOGGr4_GLP_White
# 848                               EOGMathGr4_CACR_White
# 849                                EOGMathGr4_GLP_White
# 850                            EOGReadingGr4_CACR_White
# 851                             EOGReadingGr4_GLP_White
# 852                               EOGMathGr4_CACR_White
# 853                                EOGMathGr4_GLP_White
# 854                            EOGReadingGr4_CACR_White
# 855                             EOGReadingGr4_GLP_White
# 856                                    EOGGr5_GLP_White
# 857                               EOGMathGr5_CACR_White
# 858                                EOGMathGr5_GLP_White
# 859                            EOGReadingGr5_CACR_White
# 860                             EOGReadingGr5_GLP_White
# 861                            EOGScienceGr5_CACR_White
# 862                             EOGScienceGr5_GLP_White
# 863                               EOGMathGr5_CACR_White
# 864                                EOGMathGr5_GLP_White
# 865                             EOGReadingGr5_GLP_White
# 866                            EOGScienceGr5_CACR_White
# 867                             EOGScienceGr5_GLP_White
# 868                                EOGMathGr3_GLP_White
# 869                            EOGReadingGr3_CACR_White
# 870                             EOGReadingGr3_GLP_White
# 871                            EOGReadingGr3_CACR_White
# 872                             EOGReadingGr3_GLP_White
# 873                              EOGMathGr3-8_GLP_White
# 874                              EOGSubjects_CACR_White
# 875                           EOGReadingGr3-8_GLP_White
# 876                              EOGSubjects_CACR_White
# 877                               EOGSubjects_GLP_White
# 878                                EOGMathGr4_GLP_White
# 879                            EOGReadingGr4_CACR_White
# 880                             EOGReadingGr4_GLP_White
# 881                            EOGReadingGr4_CACR_White
# 882                             EOGReadingGr4_GLP_White
# 883                                EOGMathGr5_GLP_White
# 884                            EOGReadingGr5_CACR_White
# 885                             EOGReadingGr5_GLP_White
# 886                            EOGScienceGr5_CACR_White
# 887                             EOGScienceGr5_GLP_White
# 888                            EOGReadingGr5_CACR_White
# 889                             EOGReadingGr5_GLP_White
# 890                            EOGScienceGr5_CACR_White
# 891                             EOGScienceGr5_GLP_White
# 892                             EOGReadingGr3_GLP_White
# 893                           EOGReadingGr3-8_GLP_White
# 894                              EOGSubjects_CACR_White
# 895                               EOGSubjects_GLP_White
# 896                              EOGSubjects_CACR_White
# 897                               EOGSubjects_GLP_White
# 898                             EOGReadingGr4_GLP_White
# 899                             EOGReadingGr5_GLP_White
# 900                            EOGScienceGr5_CACR_White
# 901                             EOGScienceGr5_GLP_White
# 902                            EOGScienceGr5_CACR_White
# 903                             EOGScienceGr5_GLP_White
# 904                             EOGScienceGr5_GLP_White
# 905                           EOGScienceGr5&8_GLP_White
# 906                               EOGSubjects_GLP_White
# 907                                    EOCMathI_GLP_EDS
# 908                                EOCSubjects_CACR_EDS
# 909                                 EOCSubjects_GLP_EDS
# 910                                EOCSubjects_CACR_EDS
# 911                                 EOCSubjects_GLP_EDS
# 912                                 EOCSubjects_GLP_EDS
# 913                             EOG/EOCSubjects_GLP_EDS
# 914                                      EOGGr3_GLP_EDS
# 915                                 EOGMathGr3_CACR_EDS
# 916                                  EOGMathGr3_GLP_EDS
# 917                              EOGReadingGr3_CACR_EDS
# 918                               EOGReadingGr3_GLP_EDS
# 919                                 EOGMathGr3_CACR_EDS
# 920                                  EOGMathGr3_GLP_EDS
# 921                              EOGReadingGr3_CACR_EDS
# 922                               EOGReadingGr3_GLP_EDS
# 923                                      pct_PASSED_EOG
# 924                                      EOGGr4_GLP_EDS
# 925                                 EOGMathGr4_CACR_EDS
# 926                                  EOGMathGr4_GLP_EDS
# 927                              EOGReadingGr4_CACR_EDS
# 928                               EOGReadingGr4_GLP_EDS
# 929                                 EOGMathGr4_CACR_EDS
# 930                                  EOGMathGr4_GLP_EDS
# 931                               EOGReadingGr4_GLP_EDS
# 932                                      EOGGr5_GLP_EDS
# 933                                 EOGMathGr5_CACR_EDS
# 934                                  EOGMathGr5_GLP_EDS
# 935                              EOGScienceGr5_CACR_EDS
# 936                               EOGScienceGr5_GLP_EDS
# 937                                 EOGMathGr5_CACR_EDS
# 938                                  EOGMathGr5_GLP_EDS
# 939                               EOGReadingGr5_GLP_EDS
# 940                               EOGScienceGr5_GLP_EDS
# 941                                  EOGMathGr3_GLP_EDS
# 942                               EOGReadingGr3_GLP_EDS
# 943                                EOGMathGr3-8_GLP_EDS
# 944                                EOGSubjects_CACR_EDS
# 945                                EOGSubjects_CACR_EDS
# 946                                 EOGSubjects_GLP_EDS
# 947                                  EOGMathGr4_GLP_EDS
# 948                                  EOGMathGr5_GLP_EDS
# 949                               EOGReadingGr3_GLP_EDS
# 950                                      pct_PASSED_EOG
# ...
# 916                                     EOGGr3_CACR_EDS     0.965407
# 917                                     EOGGr3_CACR_EDS     0.967826
# 918                                     EOGGr3_CACR_EDS     0.959507
# 919                                      EOGGr3_GLP_EDS     0.950848
# 920                                      EOGGr3_GLP_EDS     0.977229
# 921                                      EOGGr3_GLP_EDS     0.959190
# 922                                      EOGGr3_GLP_EDS     0.976123
# 923                                      EOGGr3_GLP_EDS     0.959688
# 924                                     EOGGr4_CACR_EDS     0.984659
# 925                                     EOGGr4_CACR_EDS     0.966133
# 926                                     EOGGr4_CACR_EDS     0.961051
# 927                                     EOGGr4_CACR_EDS     0.961455
# 928                                     EOGGr4_CACR_EDS     0.951900
# 929                                      EOGGr4_GLP_EDS     0.954225
# 930                                      EOGGr4_GLP_EDS     0.969668
# 931                                      EOGGr4_GLP_EDS     0.969374
# 932                                     EOGGr5_CACR_EDS     0.988230
# 933                                     EOGGr5_CACR_EDS     0.953998
# 934                                     EOGGr5_CACR_EDS     0.954025
# 935                                     EOGGr5_CACR_EDS     0.955215
# 936                                     EOGGr5_CACR_EDS     0.951342
# 937                                      EOGGr5_GLP_EDS     0.950025
# 938                                      EOGGr5_GLP_EDS     0.963933
# 939                                      EOGGr5_GLP_EDS     0.963587
# 940                                      EOGGr5_GLP_EDS     0.969162
# 941                                 EOGMathGr3_CACR_EDS     0.973854
# 942                                  EOGMathGr3_GLP_EDS     0.951230
# 943                               EOGMathGr3-8_CACR_EDS     0.987287
# 944                               EOGMathGr3-8_CACR_EDS     0.960099
# 945                                EOGMathGr3-8_GLP_EDS     0.960511
# 946                                EOGMathGr3-8_GLP_EDS     0.967238
# 947                                 EOGMathGr4_CACR_EDS     0.984253
# 948                                 EOGMathGr5_CACR_EDS     0.988298
# 949                              EOGReadingGr3_CACR_EDS     0.978871
# 950                               EOGReadingGr3_GLP_EDS     0.964335
# 951                            EOGReadingGr3-8_CACR_EDS     0.980031
# 952                            EOGReadingGr3-8_CACR_EDS     0.971269
# 953                            EOGReadingGr3-8_CACR_EDS     0.961290
# 954                             EOGReadingGr3-8_GLP_EDS     0.966172
# 955                             EOGReadingGr3-8_GLP_EDS     0.979564
# 956                              EOGReadingGr4_CACR_EDS     0.971694
# 957                              EOGReadingGr5_CACR_EDS     0.961907
# 958                              EOGScienceGr5_CACR_EDS     0.978116
# 959                            EOGScienceGr5&8_CACR_EDS     0.973940
# 960                                EOGSubjects_CACR_EDS     0.988707
# 961                                     EOGGr3_CACR_LEP     0.951149
# 962                                 EOGMathGr3_CACR_LEP     0.951947
# 963                                     EOGGr5_CACR_SWD     0.954836
# 964                                EOGSubjects_CACR_SWD     0.962145
# 965                                   EOCMathI_CACR_AIG     0.991123
# 966                                   EOCMathI_CACR_AIG     0.971903
# 967                                   EOCMathI_CACR_AIG     0.963689
# 968                                    EOCMathI_GLP_AIG     0.969807
# 969                                    EOCMathI_GLP_AIG     0.973682
# 970                                EOCSubjects_CACR_AIG     0.994274
# 971                            EOG/EOCSubjects_CACR_AIG     0.981555
# 972                                     EOGGr3_CACR_AIG     0.996960
# 973                                     EOGGr4_CACR_AIG     0.997046
# 974                                     EOGGr5_CACR_AIG     0.995948
# 975                                 EOGMathGr3_CACR_AIG     0.996524
# 976                                 EOGMathGr3_CACR_AIG     0.993242
# 977                                 EOGMathGr3_CACR_AIG     0.994599
# 978                                  EOGMathGr3_GLP_AIG     0.993447
# 979                                  EOGMathGr3_GLP_AIG     0.997736
# 980                               EOGMathGr3-8_CACR_AIG     0.995761
# 981                               EOGMathGr3-8_CACR_AIG     0.978157
# 982                               EOGMathGr3-8_CACR_AIG     0.984334
# 983                                EOGMathGr3-8_GLP_AIG     0.981952
# 984                                EOGMathGr3-8_GLP_AIG     0.990261
# 985                                 EOGMathGr4_CACR_AIG     0.997666
# 986                                 EOGMathGr4_CACR_AIG     0.990317
# 987                                 EOGMathGr4_CACR_AIG     0.994126
# 988                                  EOGMathGr4_GLP_AIG     0.991285
# 989                                  EOGMathGr4_GLP_AIG     0.995811
# 990                                 EOGMathGr5_CACR_AIG     0.998477
# 991                                 EOGMathGr5_CACR_AIG     0.982699
# 992                                 EOGMathGr5_CACR_AIG     0.991446
# 993                                 EOGMathGr5_CACR_AIG     0.989162
# 994                                 EOGMathGr5_CACR_AIG     0.993289
# 995                                  EOGMathGr5_GLP_AIG     0.982599
# 996                                  EOGMathGr5_GLP_AIG     0.992113
# 997                                  EOGMathGr5_GLP_AIG     0.989272
# 998                                  EOGMathGr5_GLP_AIG     0.994265
# 999                              EOGReadingGr3_CACR_AIG     0.996183
# 1000                           EOGReadingGr3-8_CACR_AIG     0.991393
# 1001                             EOGReadingGr4_CACR_AIG     0.995524
# 1002                             EOGReadingGr5_CACR_AIG     0.991738
# 1003                             EOGReadingGr5_CACR_AIG     0.983253
# 1004                             EOGReadingGr5_CACR_AIG     0.984181
# 1005                              EOGReadingGr5_GLP_AIG     0.989042
# 1006                              EOGReadingGr5_GLP_AIG     0.993589
# 1007                             EOGScienceGr5_CACR_AIG     0.994874
# 1008                           EOGScienceGr5&8_CACR_AIG     0.994088
# 1009                               EOGSubjects_CACR_AIG     0.994551
# 1010                           lea_avg_daily_attend_pct     0.954382
# 1011                           lea_avg_daily_attend_pct     0.954175
# 1012                           lea_avg_daily_attend_pct     0.954175
# 1013                           lea_avg_daily_attend_pct     0.954175
# 1014                           lea_avg_daily_attend_pct     0.954175
# 1015                           lea_avg_daily_attend_pct     0.954175
# 1016                           lea_avg_daily_attend_pct     0.954175
# 1017                           lea_avg_daily_attend_pct     0.954175
# 1018                           lea_avg_daily_attend_pct     0.954175
# 1019                           lea_avg_daily_attend_pct     0.954175
# 1020                           lea_avg_daily_attend_pct     0.954175
# 1021                           lea_avg_daily_attend_pct     0.954175
# 1022                            st_avg_daily_attend_pct     0.999720
# 1023                            st_avg_daily_attend_pct     0.999720
# 1024                            st_avg_daily_attend_pct     0.999720
# 1025                            st_avg_daily_attend_pct     0.999720
# 1026                            st_avg_daily_attend_pct     0.999720
# 1027                            st_avg_daily_attend_pct     0.999720
# 1028                            st_avg_daily_attend_pct     0.999720
# 1029                            st_avg_daily_attend_pct     0.999720
# 1030                            st_avg_daily_attend_pct     0.999720
# 1031                            st_avg_daily_attend_pct     0.999720
# 1032                            st_avg_daily_attend_pct     0.999720
# 1033                             st_long_susp_per_c_num     0.958860
# 1034                          st_stud_internet_comp_num     1.000000
# 1035                          st_stud_internet_comp_num     1.000000
# 1036                          st_stud_internet_comp_num     1.000000
# 1037                          st_stud_internet_comp_num     1.000000
# 1038                          st_stud_internet_comp_num     1.000000
# 1039                          st_stud_internet_comp_num     1.000000
# 1040                          st_stud_internet_comp_num     1.000000
# 1041                          st_stud_internet_comp_num     1.000000
# 1042                          st_stud_internet_comp_num     1.000000
# 1043                          st_stud_internet_comp_num     1.000000
# 1044                                  tchyrs_0thru3_pct     1.000000
# 1045                                 tchyrs_4thru10_pct     1.000000
# 1046                                  tchyrs_11plus_pct     1.000000
# 1047                             st_emer_prov_teach_pct     0.989917
# 1048                             st_emer_prov_teach_pct     0.989917
# 1049                               st_lateral_teach_pct     0.972720
# 1050                               st_lateral_teach_pct     0.972720
# 1051                              st_prinyrs_0thru3_pct     1.000000
# 1052                              st_prinyrs_0thru3_pct     1.000000
# 1053                              st_prinyrs_0thru3_pct     1.000000
# 1054                              st_prinyrs_0thru3_pct     1.000000
# 1055                              st_prinyrs_0thru3_pct     1.000000
# 1056                              st_prinyrs_0thru3_pct     1.000000
# 1057                              st_prinyrs_0thru3_pct     1.000000
# 1058                              st_prinyrs_0thru3_pct     1.000000
# 1059                              st_prinyrs_0thru3_pct     1.000000
# 1060                             st_prinyrs_4thru10_pct     1.000000
# 1061                             st_prinyrs_4thru10_pct     1.000000
# 1062                             st_prinyrs_4thru10_pct     1.000000
# 1063                             st_prinyrs_4thru10_pct     1.000000
# 1064                             st_prinyrs_4thru10_pct     1.000000
# 1065                             st_prinyrs_4thru10_pct     1.000000
# 1066                             st_prinyrs_4thru10_pct     1.000000
# 1067                             st_prinyrs_4thru10_pct     1.000000
# 1068                              st_prinyrs_11plus_pct     1.000000
# 1069                              st_prinyrs_11plus_pct     1.000000
# 1070                              st_prinyrs_11plus_pct     1.000000
# 1071                              st_prinyrs_11plus_pct     1.000000
# 1072                              st_prinyrs_11plus_pct     1.000000
# 1073                              st_prinyrs_11plus_pct     1.000000
# 1074                              st_prinyrs_11plus_pct     1.000000
# 1075                            st_prin_advance_dgr_pct     1.000000
# 1076                            st_prin_advance_dgr_pct     1.000000
# 1077                            st_prin_advance_dgr_pct     1.000000
# 1078                            st_prin_advance_dgr_pct     1.000000
# 1079                            st_prin_advance_dgr_pct     1.000000
# 1080                            st_prin_advance_dgr_pct     1.000000
# 1081                             st_1yr_prin_trnovr_pct     1.000000
# 1082                             st_1yr_prin_trnovr_pct     1.000000
# 1083                             st_1yr_prin_trnovr_pct     1.000000
# 1084                             st_1yr_prin_trnovr_pct     1.000000
# 1085                             st_1yr_prin_trnovr_pct     1.000000
# 1086                                   st_prin_male_pct     1.000000
# 1087                                   st_prin_male_pct     1.000000
# 1088                                   st_prin_male_pct     1.000000
# 1089                                   st_prin_male_pct     1.000000
# 1090                                 st_prin_female_pct     1.000000
# 1091                                 st_prin_female_pct     1.000000
# 1092                                 st_prin_female_pct     1.000000
# 1093                                  st_prin_black_pct     1.000000
# 1094                                  st_prin_black_pct     1.000000
# 1095                                  st_prin_white_pct     1.000000
# 1096                Not Demostrated_TCHR_Standard 2_Pct     0.977440
# 1097                Not Demostrated_TCHR_Standard 2_Pct     0.981346
# 1098                Not Demostrated_TCHR_Standard 3_Pct     0.982893
# 1099                                     AsianFemalePct     0.977530
# 1100                                       AsianMalePct     0.979757
# 1101                                     BlackFemalePct     0.962825
# 1102                                       BlackMalePct     0.968856
# 1103                                  HispanicFemalePct     0.979581
# 1104                                    HispanicMalePct     0.980795
# 1105                                    IndianFemalePct     0.975311
# 1106                                    IndianFemalePct     0.993646
# 1107                                      IndianMalePct     0.993969
# 1108                                  MinorityFemalePct     0.954602
# 1109                                  MinorityFemalePct     0.958383
# 1110                                  MinorityFemalePct     0.954602
# 1111                                    MinorityMalePct     0.960896
# 1112                                    MinorityMalePct     0.961516
# 1113                                    MinorityMalePct     0.960896
# 1114                                        MinorityPct     0.972932
# 1115                                        MinorityPct     0.975246
# 1116                                        MinorityPct     1.000000
# 1117                                     WhiteFemalePct     0.972932
# 1118                                       WhiteMalePct     0.975246
# 1119                                      category_cd_E     1.000000
# 1120                                      category_cd_H     1.000000
# 1121                                      category_cd_I     1.000000
# 1122                                      category_cd_M     1.000000
# 1123                                      category_cd_T     1.000000
# 1124                  calendar_type_txt_Hospital School     1.000000
# 1125                  calendar_type_txt_Hospital School     1.000000
# 1126  calendar_type_txt_Magnet School, Traditional C...     1.000000
# 1127  calendar_type_txt_Magnet School, Traditional C...     0.985376
# 1128  calendar_type_txt_Magnet School, Year-Round Ca...     1.000000
# 1129  calendar_type_txt_Regular School, Traditional ...     1.000000
# 1130  calendar_type_txt_Regular School, Traditional ...     1.000000
# 1131  calendar_type_txt_Regular School, Traditional ...     1.000000
# 1132  calendar_type_txt_Regular School, Year-Round C...     1.000000
# 1133  calendar_type_txt_Regular School, Year-Round C...     0.984549
# 1134  calendar_type_txt_Special Education, Tradition...     1.000000
# 1135  calendar_type_txt_Special Education, Tradition...     1.000000
# 1136                                  sna_pgm_type_cd_H     1.000000
# 1137                                  sna_pgm_type_cd_M     0.985376
# 1138                                  sna_pgm_type_cd_S     1.000000
# 1139                                  sna_pgm_type_cd_X     1.000000
# 1140                                  sna_pgm_type_cd_Y     0.984549
#
# [1141 rows x 3 columns]

# %%
print 'Dropping the following ', str(len(to_drop)), ' highly correlated fields.'
to_drop
# Out:
# Dropping the following  320  highly correlated fields.
# ['Math SPG Score',
#  'Overall Achievement Score',
#  'Read Score',
#  'Math Score',
#  'EOCMathI_CACR_All',
#  'EOCMathI_GLP_All',
#  'EOCSubjects_CACR_All',
#  'EOCSubjects_GLP_All',
#  'EOG/EOCSubjects_GLP_All',
#  'EOGGr3_GLP_All',
#  'EOGGr4_GLP_All',
#  'EOGGr5_GLP_All',
#  'EOGMathGr3_CACR_All',
#  'EOGMathGr3_GLP_All',
#  'EOGMathGr3-8_CACR_All',
#  'EOGMathGr3-8_GLP_All',
#  'EOGMathGr4_CACR_All',
#  'EOGMathGr4_GLP_All',
#  'EOGMathGr5_CACR_All',
#  'EOGMathGr5_GLP_All',
#  'EOGReadingGr3_CACR_All',
#  'EOGReadingGr3_GLP_All',
#  'EOGReadingGr3-8_CACR_All',
#  'EOGReadingGr3-8_GLP_All',
#  'EOGReadingGr4_CACR_All',
#  'EOGReadingGr4_GLP_All',
#  'EOGReadingGr5_CACR_All',
#  'EOGReadingGr5_GLP_All',
#  'EOGScienceGr5_CACR_All',
#  'EOGScienceGr5_GLP_All',
#  'EOGScienceGr5&8_CACR_All',
#  'EOGScienceGr5&8_GLP_All',
#  'EOGSubjects_CACR_All',
#  'EOGSubjects_GLP_All',
#  'EOCMathI_CACR_Female',
#  'EOCMathI_GLP_Female',
#  'EOCSubjects_CACR_Female',
#  'EOCSubjects_GLP_Female',
#  'EOG/EOCSubjects_CACR_Female',
#  'EOG/EOCSubjects_GLP_Female',
#  'EOGGr3_CACR_Female',
#  'EOGGr3_GLP_Female',
#  'EOGGr4_CACR_Female',
#  'EOGGr4_GLP_Female',
#  'EOGGr5_CACR_Female',
#  'EOGGr5_GLP_Female',
#  'EOGMathGr3_CACR_Female',
#  'EOGMathGr3_GLP_Female',
#  'EOGMathGr3-8_CACR_Female',
#  'EOGMathGr3-8_GLP_Female',
#  'EOGMathGr4_CACR_Female',
#  'EOGMathGr4_GLP_Female',
#  'EOGMathGr5_CACR_Female',
#  'EOGMathGr5_GLP_Female',
#  'EOGReadingGr3_CACR_Female',
#  'EOGReadingGr3_GLP_Female',
#  'EOGReadingGr3-8_CACR_Female',
#  'EOGReadingGr3-8_GLP_Female',
#  'EOGReadingGr4_CACR_Female',
#  'EOGReadingGr4_GLP_Female',
#  'EOGReadingGr5_CACR_Female',
#  'EOGReadingGr5_GLP_Female',
#  'EOGScienceGr5_CACR_Female',
#  'EOGScienceGr5_GLP_Female',
#  'EOGScienceGr5&8_CACR_Female',
#  'EOGScienceGr5&8_GLP_Female',
#  'EOGSubjects_CACR_Female',
#  'EOGSubjects_GLP_Female',
#  'EOCMathI_CACR_Male',
#  'EOCMathI_GLP_Male',
#  'EOCSubjects_CACR_Male',
#  'EOCSubjects_GLP_Male',
#  'EOG/EOCSubjects_CACR_Male',
#  'EOG/EOCSubjects_GLP_Male',
#  'EOGGr3_CACR_Male',
#  'EOGGr3_GLP_Male',
#  'EOGGr4_CACR_Male',
#  'EOGGr4_GLP_Male',
#  'EOGGr5_CACR_Male',
#  'EOGGr5_GLP_Male',
#  'EOGMathGr3_CACR_Male',
#  'EOGMathGr3_GLP_Male',
#  'EOGMathGr3-8_CACR_Male',
#  'EOGMathGr3-8_GLP_Male',
#  'EOGMathGr4_CACR_Male',
#  'EOGMathGr4_GLP_Male',
#  'EOGMathGr5_CACR_Male',
#  'EOGMathGr5_GLP_Male',
#  'EOGReadingGr3_CACR_Male',
#  'EOGReadingGr3_GLP_Male',
#  'EOGReadingGr3-8_CACR_Male',
#  'EOGReadingGr3-8_GLP_Male',
#  'EOGReadingGr4_CACR_Male',
#  'EOGReadingGr4_GLP_Male',
#  'EOGReadingGr5_CACR_Male',
#  'EOGReadingGr5_GLP_Male',
#  'EOGScienceGr5_CACR_Male',
#  'EOGScienceGr5_GLP_Male',
#  'EOGScienceGr5&8_CACR_Male',
#  'EOGScienceGr5&8_GLP_Male',
#  'EOGSubjects_CACR_Male',
#  'EOGSubjects_GLP_Male',
#  'EOCMathI_GLP_AmericanIndian',
#  'EOCSubjects_GLP_AmericanIndian',
#  'EOG/EOCSubjects_GLP_AmericanIndian',
#  'EOGGr3_GLP_AmericanIndian',
#  'EOGGr4_GLP_AmericanIndian',
#  'EOGGr5_GLP_AmericanIndian',
#  'EOGMathGr3_GLP_AmericanIndian',
#  'EOGMathGr3-8_GLP_AmericanIndian',
#  'EOGMathGr4_GLP_AmericanIndian',
#  'EOGMathGr5_GLP_AmericanIndian',
#  'EOGReadingGr3_GLP_AmericanIndian',
#  'EOGReadingGr3-8_GLP_AmericanIndian',
#  'EOGReadingGr4_GLP_AmericanIndian',
#  'EOGReadingGr5_GLP_AmericanIndian',
#  'EOGScienceGr5_GLP_AmericanIndian',
#  'EOGScienceGr5&8_GLP_AmericanIndian',
#  'EOGSubjects_GLP_AmericanIndian',
#  'EOCMathI_GLP_Asian',
#  'EOCSubjects_GLP_Asian',
#  'EOG/EOCSubjects_GLP_Asian',
#  'EOGGr3_GLP_Asian',
#  'EOGGr4_GLP_Asian',
#  'EOGGr5_GLP_Asian',
#  'EOGMathGr3_GLP_Asian',
#  'EOGMathGr3-8_GLP_Asian',
#  'EOGMathGr4_GLP_Asian',
#  'EOGMathGr5_GLP_Asian',
#  'EOGReadingGr3_CACR_Asian',
#  'EOGReadingGr3_GLP_Asian',
#  'EOGReadingGr3-8_CACR_Asian',
#  'EOGReadingGr3-8_GLP_Asian',
#  'EOGReadingGr4_CACR_Asian',
#  'EOGReadingGr4_GLP_Asian',
#  'EOGReadingGr5_GLP_Asian',
#  'EOGScienceGr5_CACR_Asian',
#  'EOGScienceGr5_GLP_Asian',
#  'EOGScienceGr5&8_GLP_Asian',
#  'EOGSubjects_GLP_Asian',
#  'EOCMathI_GLP_Black',
#  'EOCSubjects_CACR_Black',
#  'EOCSubjects_GLP_Black',
#  'EOG/EOCSubjects_GLP_Black',
#  'EOGGr3_GLP_Black',
#  'EOGGr4_GLP_Black',
#  'EOGGr5_GLP_Black',
#  'EOGMathGr3_GLP_Black',
#  'EOGMathGr3-8_GLP_Black',
#  'EOGMathGr4_GLP_Black',
#  'EOGMathGr5_GLP_Black',
#  'EOGReadingGr3_GLP_Black',
#  'EOGReadingGr3-8_GLP_Black',
#  'EOGReadingGr4_GLP_Black',
#  'EOGScienceGr5_GLP_Black',
#  'EOGScienceGr5&8_GLP_Black',
#  'EOGSubjects_GLP_Black',
#  'EOCMathI_GLP_Hispanic',
#  'EOCSubjects_GLP_Hispanic',
#  'EOGGr3_GLP_Hispanic',
#  'EOGGr4_GLP_Hispanic',
#  'EOGGr5_GLP_Hispanic',
#  'EOGMathGr3_GLP_Hispanic',
#  'EOGMathGr3-8_GLP_Hispanic',
#  'EOGMathGr4_GLP_Hispanic',
#  'EOGMathGr5_GLP_Hispanic',
#  'EOGReadingGr3_GLP_Hispanic',
#  'EOGReadingGr4_GLP_Hispanic',
#  'EOGScienceGr5_GLP_Hispanic',
#  'EOGScienceGr5&8_GLP_Hispanic',
#  'EOGSubjects_GLP_Hispanic',
#  'EOCMathI_GLP_TwoorMoreRaces',
#  'EOCSubjects_GLP_TwoorMoreRaces',
#  'EOG/EOCSubjects_GLP_TwoorMoreRaces',
#  'EOGGr3_GLP_TwoorMoreRaces',
#  'EOGGr4_GLP_TwoorMoreRaces',
#  'EOGGr5_GLP_TwoorMoreRaces',
#  'EOGMathGr3_GLP_TwoorMoreRaces',
#  'EOGMathGr3-8_GLP_TwoorMoreRaces',
#  'EOGMathGr4_GLP_TwoorMoreRaces',
#  'EOGMathGr5_GLP_TwoorMoreRaces',
#  'EOGReadingGr3_GLP_TwoorMoreRaces',
#  'EOGReadingGr3-8_GLP_TwoorMoreRaces',
#  'EOGReadingGr4_GLP_TwoorMoreRaces',
#  'EOGReadingGr5_GLP_TwoorMoreRaces',
#  'EOGScienceGr5_GLP_TwoorMoreRaces',
#  'EOGScienceGr5&8_GLP_TwoorMoreRaces',
#  'EOGSubjects_GLP_TwoorMoreRaces',
#  'EOCMathI_CACR_White',
#  'EOCMathI_GLP_White',
#  'EOCSubjects_CACR_White',
#  'EOCSubjects_GLP_White',
#  'EOG/EOCSubjects_GLP_White',
#  'EOGGr3_GLP_White',
#  'EOGGr4_GLP_White',
#  'EOGGr5_CACR_White',
#  'EOGGr5_GLP_White',
#  'EOGMathGr3_CACR_White',
#  'EOGMathGr3_GLP_White',
#  'EOGMathGr3-8_GLP_White',
#  'EOGMathGr4_CACR_White',
#  'EOGMathGr4_GLP_White',
#  'EOGMathGr5_CACR_White',
#  'EOGMathGr5_GLP_White',
#  'EOGReadingGr3_CACR_White',
#  'EOGReadingGr3_GLP_White',
#  'EOGReadingGr3-8_GLP_White',
#  'EOGReadingGr4_CACR_White',
#  'EOGReadingGr4_GLP_White',
#  'EOGReadingGr5_CACR_White',
#  'EOGReadingGr5_GLP_White',
#  'EOGScienceGr5_CACR_White',
#  'EOGScienceGr5_GLP_White',
#  'EOGScienceGr5&8_GLP_White',
#  'EOGSubjects_CACR_White',
#  'EOGSubjects_GLP_White',
#  'EOCMathI_GLP_EDS',
#  'EOCSubjects_CACR_EDS',
#  'EOCSubjects_GLP_EDS',
#  'EOG/EOCSubjects_GLP_EDS',
#  'EOGGr3_CACR_EDS',
#  'EOGGr3_GLP_EDS',
#  'EOGGr4_GLP_EDS',
#  'EOGGr5_CACR_EDS',
#  'EOGGr5_GLP_EDS',
#  'EOGMathGr3_CACR_EDS',
#  'EOGMathGr3_GLP_EDS',
#  'EOGMathGr3-8_GLP_EDS',
#  'EOGMathGr4_CACR_EDS',
#  'EOGMathGr4_GLP_EDS',
#  'EOGMathGr5_CACR_EDS',
#  'EOGMathGr5_GLP_EDS',
#  'EOGReadingGr3_CACR_EDS',
#  'EOGReadingGr3_GLP_EDS',
#  'EOGReadingGr3-8_GLP_EDS',
#  'EOGReadingGr4_CACR_EDS',
#  'EOGReadingGr4_GLP_EDS',
#  'EOGReadingGr5_GLP_EDS',
#  'EOGScienceGr5_CACR_EDS',
#  'EOGScienceGr5_GLP_EDS',
#  'EOGScienceGr5&8_GLP_EDS',
#  'EOGSubjects_CACR_EDS',
#  'EOGSubjects_GLP_EDS',
#  'EOGGr3_GLP_LEP',
#  'EOGMathGr3_GLP_LEP',
#  'EOGGr5_GLP_SWD',
#  'EOGSubjects_GLP_SWD',
#  'EOCMathI_GLP_AIG',
#  'EOCSubjects_CACR_AIG',
#  'EOCSubjects_GLP_AIG',
#  'EOG/EOCSubjects_GLP_AIG',
#  'EOGGr3_GLP_AIG',
#  'EOGGr4_GLP_AIG',
#  'EOGGr5_GLP_AIG',
#  'EOGMathGr3_GLP_AIG',
#  'EOGMathGr3-8_GLP_AIG',
#  'EOGMathGr4_GLP_AIG',
#  'EOGMathGr5_GLP_AIG',
#  'EOGReadingGr3_CACR_AIG',
#  'EOGReadingGr3_GLP_AIG',
#  'EOGReadingGr3-8_CACR_AIG',
#  'EOGReadingGr3-8_GLP_AIG',
#  'EOGReadingGr4_CACR_AIG',
#  'EOGReadingGr4_GLP_AIG',
#  'EOGReadingGr5_CACR_AIG',
#  'EOGReadingGr5_GLP_AIG',
#  'EOGScienceGr5_CACR_AIG',
#  'EOGScienceGr5_GLP_AIG',
#  'EOGScienceGr5&8_GLP_AIG',
#  'EOGSubjects_GLP_AIG',
#  'pct_PASSED_EOG',
#  'st_avg_daily_attend_pct',
#  'st_stud_internet_comp_num',
#  'class_teach_num',
#  'lea_class_teach_num',
#  'st_tchyrs_11plus_pct',
#  'st_class_teach_num',
#  'st_prinyrs_0thru3_pct',
#  'st_prinyrs_4thru10_pct',
#  'st_prinyrs_11plus_pct',
#  'st_prin_advance_dgr_pct',
#  'st_1yr_prin_trnovr_pct',
#  'st_prin_male_pct',
#  'st_prin_female_pct',
#  'st_prin_black_pct',
#  'st_prin_white_pct',
#  'st_prin_other_pct',
#  '0-3 Years_Exp_Pct_Tch',
#  '10+ Years_Exp_Pct_Tch',
#  '4-10 Years_Exp_Pct_Tch',
#  'Not Demostrated_TCHR_Standard 3_Pct',
#  'Not Demostrated_TCHR_Standard 5_Pct',
#  'AsianPct',
#  'BlackPct',
#  'HispanicPct',
#  'IndianMalePct',
#  'IndianPct',
#  'MinorityPct',
#  'WhiteFemalePct',
#  'WhiteMalePct',
#  'WhitePct',
#  'category_cd_E',
#  'category_cd_H',
#  'sna_pgm_type_cd_H',
#  'sna_pgm_type_cd_M',
#  'sna_pgm_type_cd_N',
#  'sna_pgm_type_cd_R',
#  'sna_pgm_type_cd_S',
#  'sna_pgm_type_cd_X',
#  'sna_pgm_type_cd_Y',
#  'school_type_txt_Hospital School',
#  'school_type_txt_Magnet School',
#  'school_type_txt_Special Education',
#  'calendar_only_txt_Traditional Calendar plus Year-Round Calendar',
#  'calendar_only_txt_Year-Round Calendar',
#  'Category_Cd_E',
#  'Category_Cd_H',
#  'Category_Cd_I',
#  'Category_Cd_M',
#  'Category_Cd_T']

# %%
#Check columns before drop 
print('\r\n*********Before: Dropping Highly Correlated Fields*************************************')
schoolData.info(verbose=False)

# Drop the highly correlated features from our training data 
schoolData = schoolData.drop(to_drop, axis=1)

#Check columns after drop 
print('\r\n*********After: Dropping Highly Correlated Fields**************************************')
schoolData.info(verbose=False)
# Out:
# *********Before: Dropping Highly Correlated Fields*************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2426 entries, 0 to 2560
# Columns: 644 entries, closed_ind to esea_attendance_Met
# dtypes: float64(593), uint8(51)
# memory usage: 11.1 MB
#
# *********After: Dropping Highly Correlated Fields**************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2426 entries, 0 to 2560
# Columns: 324 entries, closed_ind to esea_attendance_Met
# dtypes: float64(292), uint8(32)
# memory usage: 5.5 MB

# %%
#Restore the unit_code before saving
schoolData['unit_code'] = unit_code
#Save the final dataset to a .csv file
schoolData.to_csv(outputDir + inputFileName + '_ML.csv', sep=',', index=False)

# %%
print('*********FINAL DATASET DETAILS*********************************************************\r\n')
schoolData.info(verbose=True)
# Out:
# *********FINAL DATASET DETAILS*********************************************************
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2426 entries, 0 to 2560
# Data columns (total 325 columns):
# closed_ind                                                                         float64
# student_num                                                                        float64
# lea_avg_student_num                                                                float64
# st_avg_student_num                                                                 float64
# Math I_Size                                                                        float64
# lea_total_expense_num                                                              float64
# lea_salary_expense_pct                                                             float64
# lea_benefits_expense_pct                                                           float64
# lea_services_expense_pct                                                           float64
# lea_supplies_expense_pct                                                           float64
# lea_instruct_equip_exp_pct                                                         float64
# lea_federal_perpupil_num                                                           float64
# lea_local_perpupil_num                                                             float64
# lea_state_perpupil_num                                                             float64
# SBE Region                                                                         float64
# SPG Score                                                                          float64
# Reading  SPG Score                                                                 float64
# EVAAS Growth Score                                                                 float64
# Science Score                                                                      float64
# Math I Score                                                                       float64
# EOG/EOCSubjects_CACR_All                                                           float64
# EOGGr3_CACR_All                                                                    float64
# EOGGr4_CACR_All                                                                    float64
# EOGGr5_CACR_All                                                                    float64
# EOCMathI_CACR_AmericanIndian                                                       float64
# EOCSubjects_CACR_AmericanIndian                                                    float64
# EOG/EOCSubjects_CACR_AmericanIndian                                                float64
# EOGGr3_CACR_AmericanIndian                                                         float64
# EOGGr4_CACR_AmericanIndian                                                         float64
# EOGGr5_CACR_AmericanIndian                                                         float64
# EOGMathGr3_CACR_AmericanIndian                                                     float64
# EOGMathGr3-8_CACR_AmericanIndian                                                   float64
# EOGMathGr4_CACR_AmericanIndian                                                     float64
# EOGMathGr5_CACR_AmericanIndian                                                     float64
# EOGReadingGr3_CACR_AmericanIndian                                                  float64
# EOGReadingGr3-8_CACR_AmericanIndian                                                float64
# EOGReadingGr4_CACR_AmericanIndian                                                  float64
# EOGReadingGr5_CACR_AmericanIndian                                                  float64
# EOGScienceGr5_CACR_AmericanIndian                                                  float64
# EOGScienceGr5&8_CACR_AmericanIndian                                                float64
# EOGSubjects_CACR_AmericanIndian                                                    float64
# EOCMathI_CACR_Asian                                                                float64
# EOCSubjects_CACR_Asian                                                             float64
# EOG/EOCSubjects_CACR_Asian                                                         float64
# EOGGr3_CACR_Asian                                                                  float64
# EOGGr4_CACR_Asian                                                                  float64
# EOGGr5_CACR_Asian                                                                  float64
# EOGMathGr3_CACR_Asian                                                              float64
# EOGMathGr3-8_CACR_Asian                                                            float64
# EOGMathGr4_CACR_Asian                                                              float64
# EOGMathGr5_CACR_Asian                                                              float64
# EOGReadingGr5_CACR_Asian                                                           float64
# EOGScienceGr5&8_CACR_Asian                                                         float64
# EOGSubjects_CACR_Asian                                                             float64
# EOCMathI_CACR_Black                                                                float64
# EOG/EOCSubjects_CACR_Black                                                         float64
# EOGGr3_CACR_Black                                                                  float64
# EOGGr4_CACR_Black                                                                  float64
# EOGGr5_CACR_Black                                                                  float64
# EOGMathGr3_CACR_Black                                                              float64
# EOGMathGr3-8_CACR_Black                                                            float64
# EOGMathGr4_CACR_Black                                                              float64
# EOGMathGr5_CACR_Black                                                              float64
# EOGReadingGr3_CACR_Black                                                           float64
# EOGReadingGr3-8_CACR_Black                                                         float64
# EOGReadingGr4_CACR_Black                                                           float64
# EOGReadingGr5_CACR_Black                                                           float64
# EOGReadingGr5_GLP_Black                                                            float64
# EOGScienceGr5_CACR_Black                                                           float64
# EOGScienceGr5&8_CACR_Black                                                         float64
# EOGSubjects_CACR_Black                                                             float64
# EOCMathI_CACR_Hispanic                                                             float64
# EOCSubjects_CACR_Hispanic                                                          float64
# EOG/EOCSubjects_CACR_Hispanic                                                      float64
# EOG/EOCSubjects_GLP_Hispanic                                                       float64
# EOGGr3_CACR_Hispanic                                                               float64
# EOGGr4_CACR_Hispanic                                                               float64
# EOGGr5_CACR_Hispanic                                                               float64
# EOGMathGr3_CACR_Hispanic                                                           float64
# EOGMathGr3-8_CACR_Hispanic                                                         float64
# EOGMathGr4_CACR_Hispanic                                                           float64
# EOGMathGr5_CACR_Hispanic                                                           float64
# EOGReadingGr3_CACR_Hispanic                                                        float64
# EOGReadingGr3-8_CACR_Hispanic                                                      float64
# EOGReadingGr3-8_GLP_Hispanic                                                       float64
# EOGReadingGr4_CACR_Hispanic                                                        float64
# EOGReadingGr5_CACR_Hispanic                                                        float64
# EOGReadingGr5_GLP_Hispanic                                                         float64
# EOGScienceGr5_CACR_Hispanic                                                        float64
# EOGScienceGr5&8_CACR_Hispanic                                                      float64
# EOGSubjects_CACR_Hispanic                                                          float64
# EOCMathI_CACR_TwoorMoreRaces                                                       float64
# EOCSubjects_CACR_TwoorMoreRaces                                                    float64
# EOG/EOCSubjects_CACR_TwoorMoreRaces                                                float64
# EOGGr3_CACR_TwoorMoreRaces                                                         float64
# EOGGr4_CACR_TwoorMoreRaces                                                         float64
# EOGGr5_CACR_TwoorMoreRaces                                                         float64
# EOGMathGr3_CACR_TwoorMoreRaces                                                     float64
# EOGMathGr3-8_CACR_TwoorMoreRaces                                                   float64
# EOGMathGr4_CACR_TwoorMoreRaces                                                     float64
# EOGMathGr5_CACR_TwoorMoreRaces                                                     float64
# EOGReadingGr3_CACR_TwoorMoreRaces                                                  float64
# EOGReadingGr3-8_CACR_TwoorMoreRaces                                                float64
# EOGReadingGr4_CACR_TwoorMoreRaces                                                  float64
# EOGReadingGr5_CACR_TwoorMoreRaces                                                  float64
# EOGScienceGr5_CACR_TwoorMoreRaces                                                  float64
# EOGScienceGr5&8_CACR_TwoorMoreRaces                                                float64
# EOGSubjects_CACR_TwoorMoreRaces                                                    float64
# EOG/EOCSubjects_CACR_White                                                         float64
# EOGGr3_CACR_White                                                                  float64
# EOGGr4_CACR_White                                                                  float64
# EOGMathGr3-8_CACR_White                                                            float64
# EOGReadingGr3-8_CACR_White                                                         float64
# EOGScienceGr5&8_CACR_White                                                         float64
# EOCMathI_CACR_EDS                                                                  float64
# EOG/EOCSubjects_CACR_EDS                                                           float64
# EOGGr4_CACR_EDS                                                                    float64
# EOGMathGr3-8_CACR_EDS                                                              float64
# EOGReadingGr3-8_CACR_EDS                                                           float64
# EOGReadingGr5_CACR_EDS                                                             float64
# EOGScienceGr5&8_CACR_EDS                                                           float64
# EOCMathI_CACR_LEP                                                                  float64
# EOCMathI_GLP_LEP                                                                   float64
# EOCSubjects_CACR_LEP                                                               float64
# EOCSubjects_GLP_LEP                                                                float64
# EOG/EOCSubjects_CACR_LEP                                                           float64
# EOG/EOCSubjects_GLP_LEP                                                            float64
# EOGGr3_CACR_LEP                                                                    float64
# EOGGr4_CACR_LEP                                                                    float64
# EOGGr4_GLP_LEP                                                                     float64
# EOGGr5_CACR_LEP                                                                    float64
# EOGGr5_GLP_LEP                                                                     float64
# EOGMathGr3_CACR_LEP                                                                float64
# EOGMathGr3-8_CACR_LEP                                                              float64
# EOGMathGr3-8_GLP_LEP                                                               float64
# EOGMathGr4_CACR_LEP                                                                float64
# EOGMathGr4_GLP_LEP                                                                 float64
# EOGMathGr5_CACR_LEP                                                                float64
# EOGMathGr5_GLP_LEP                                                                 float64
# EOGReadingGr3_CACR_LEP                                                             float64
# EOGReadingGr3_GLP_LEP                                                              float64
# EOGReadingGr3-8_CACR_LEP                                                           float64
# EOGReadingGr3-8_GLP_LEP                                                            float64
# EOGReadingGr4_CACR_LEP                                                             float64
# EOGReadingGr4_GLP_LEP                                                              float64
# EOGReadingGr5_CACR_LEP                                                             float64
# EOGReadingGr5_GLP_LEP                                                              float64
# EOGScienceGr5_CACR_LEP                                                             float64
# EOGScienceGr5_GLP_LEP                                                              float64
# EOGScienceGr5&8_CACR_LEP                                                           float64
# EOGScienceGr5&8_GLP_LEP                                                            float64
# EOGSubjects_CACR_LEP                                                               float64
# EOGSubjects_GLP_LEP                                                                float64
# EOCMathI_CACR_SWD                                                                  float64
# EOCMathI_GLP_SWD                                                                   float64
# EOCSubjects_CACR_SWD                                                               float64
# EOCSubjects_GLP_SWD                                                                float64
# EOG/EOCSubjects_CACR_SWD                                                           float64
# EOG/EOCSubjects_GLP_SWD                                                            float64
# EOGGr3_CACR_SWD                                                                    float64
# EOGGr3_GLP_SWD                                                                     float64
# EOGGr4_CACR_SWD                                                                    float64
# EOGGr4_GLP_SWD                                                                     float64
# EOGGr5_CACR_SWD                                                                    float64
# EOGMathGr3_CACR_SWD                                                                float64
# EOGMathGr3_GLP_SWD                                                                 float64
# EOGMathGr3-8_CACR_SWD                                                              float64
# EOGMathGr3-8_GLP_SWD                                                               float64
# EOGMathGr4_CACR_SWD                                                                float64
# EOGMathGr4_GLP_SWD                                                                 float64
# EOGMathGr5_CACR_SWD                                                                float64
# EOGMathGr5_GLP_SWD                                                                 float64
# EOGReadingGr3_CACR_SWD                                                             float64
# EOGReadingGr3_GLP_SWD                                                              float64
# EOGReadingGr3-8_CACR_SWD                                                           float64
# EOGReadingGr3-8_GLP_SWD                                                            float64
# EOGReadingGr4_CACR_SWD                                                             float64
# EOGReadingGr4_GLP_SWD                                                              float64
# EOGReadingGr5_CACR_SWD                                                             float64
# EOGReadingGr5_GLP_SWD                                                              float64
# EOGScienceGr5_CACR_SWD                                                             float64
# EOGScienceGr5_GLP_SWD                                                              float64
# EOGScienceGr5&8_CACR_SWD                                                           float64
# EOGScienceGr5&8_GLP_SWD                                                            float64
# EOGSubjects_CACR_SWD                                                               float64
# EOCMathI_CACR_AIG                                                                  float64
# EOG/EOCSubjects_CACR_AIG                                                           float64
# EOGGr3_CACR_AIG                                                                    float64
# EOGGr4_CACR_AIG                                                                    float64
# EOGGr5_CACR_AIG                                                                    float64
# EOGMathGr3_CACR_AIG                                                                float64
# EOGMathGr3-8_CACR_AIG                                                              float64
# EOGMathGr4_CACR_AIG                                                                float64
# EOGMathGr5_CACR_AIG                                                                float64
# EOGScienceGr5&8_CACR_AIG                                                           float64
# EOGSubjects_CACR_AIG                                                               float64
# pct_GCE_ALL                                                                        float64
# pct_PROMOTED                                                                       float64
# MathGr3-8_pTarget_PctMet                                                           float64
# ReadingGr3-8_pTarget_PctMet                                                        float64
# SciGr5&8_pTarget_PctMet                                                            float64
# TotalTargets_pTarget_PctMet                                                        float64
# lea_sat_avg_score_num                                                              float64
# lea_sat_participation_pct                                                          float64
# lea_ap_participation_pct                                                           float64
# lea_ap_pct_3_or_above                                                              float64
# lea_ib_pct_4_or_above                                                              float64
# avg_daily_attend_pct                                                               float64
# crime_per_c_num                                                                    float64
# short_susp_per_c_num                                                               float64
# long_susp_per_c_num                                                                float64
# expelled_per_c_num                                                                 float64
# stud_internet_comp_num                                                             float64
# lea_avg_daily_attend_pct                                                           float64
# lea_crime_per_c_num                                                                float64
# lea_short_susp_per_c_num                                                           float64
# lea_long_susp_per_c_num                                                            float64
# lea_expelled_per_c_num                                                             float64
# lea_stud_internet_comp_num                                                         float64
# st_crime_per_c_num                                                                 float64
# st_short_susp_per_c_num                                                            float64
# st_long_susp_per_c_num                                                             float64
# st_expelled_per_c_num                                                              float64
# flicensed_teach_pct                                                                float64
# tchyrs_0thru3_pct                                                                  float64
# tchyrs_4thru10_pct                                                                 float64
# tchyrs_11plus_pct                                                                  float64
# nbpts_num                                                                          float64
# advance_dgr_pct                                                                    float64
# _1yr_tchr_trnovr_pct                                                               float64
# lateral_teach_pct                                                                  float64
# lea_flicensed_teach_pct                                                            float64
# lea_tchyrs_0thru3_pct                                                              float64
# lea_tchyrs_4thru10_pct                                                             float64
# lea_tchyrs_11plus_pct                                                              float64
# lea_nbpts_num                                                                      float64
# lea_advance_dgr_pct                                                                float64
# lea_1yr_tchr_trnovr_pct                                                            float64
# lea_emer_prov_teach_pct                                                            float64
# lea_lateral_teach_pct                                                              float64
# st_flicensed_teach_pct                                                             float64
# st_tchyrs_0thru3_pct                                                               float64
# st_tchyrs_4thru10_pct                                                              float64
# st_nbpts_num                                                                       float64
# st_advance_dgr_pct                                                                 float64
# st_1yr_tchr_trnovr_pct                                                             float64
# st_emer_prov_teach_pct                                                             float64
# st_lateral_teach_pct                                                               float64
# 0-3 Years_LEA_Exp_Pct_Prin                                                         float64
# 10+ Years_LEA_Exp_Pct_Prin                                                         float64
# 4-10 Years_LEA_Exp_Pct_Prin                                                        float64
# Accomplished_TCHR_Standard 1_Pct                                                   float64
# Accomplished_TCHR_Standard 2_Pct                                                   float64
# Accomplished_TCHR_Standard 3_Pct                                                   float64
# Accomplished_TCHR_Standard 4_Pct                                                   float64
# Accomplished_TCHR_Standard 5_Pct                                                   float64
# Developing_TCHR_Standard 1_Pct                                                     float64
# Developing_TCHR_Standard 2_Pct                                                     float64
# Developing_TCHR_Standard 3_Pct                                                     float64
# Developing_TCHR_Standard 4_Pct                                                     float64
# Developing_TCHR_Standard 5_Pct                                                     float64
# Distinguished_TCHR_Standard 1_Pct                                                  float64
# Distinguished_TCHR_Standard 2_Pct                                                  float64
# Distinguished_TCHR_Standard 3_Pct                                                  float64
# Distinguished_TCHR_Standard 4_Pct                                                  float64
# Distinguished_TCHR_Standard 5_Pct                                                  float64
# Does Not Meet Expected Growth_TCHR_Standard 6_Pct                                  float64
# Exceeds Expected Growth_TCHR_Standard 6_Pct                                        float64
# Meets Expected Growth_TCHR_Standard 6_Pct                                          float64
# Not Demostrated_TCHR_Standard 1_Pct                                                float64
# Not Demostrated_TCHR_Standard 2_Pct                                                float64
# Not Demostrated_TCHR_Standard 4_Pct                                                float64
# Proficient_TCHR_Standard 1_Pct                                                     float64
# Proficient_TCHR_Standard 2_Pct                                                     float64
# Proficient_TCHR_Standard 3_Pct                                                     float64
# Proficient_TCHR_Standard 4_Pct                                                     float64
# Proficient_TCHR_Standard 5_Pct                                                     float64
# AsianFemalePct                                                                     float64
# AsianMalePct                                                                       float64
# BlackFemalePct                                                                     float64
# BlackMalePct                                                                       float64
# HispanicFemalePct                                                                  float64
# HispanicMalePct                                                                    float64
# IndianFemalePct                                                                    float64
# MinorityFemalePct                                                                  float64
# MinorityMalePct                                                                    float64
# PacificIslandFemalePct                                                             float64
# PacificIslandMalePct                                                               float64
# PacificIslandPct                                                                   float64
# TwoOrMoreFemalePct                                                                 float64
# TwoOrMoreMalePct                                                                   float64
# TwoOrMorePct                                                                       float64
# category_cd_I                                                                      uint8
# category_cd_M                                                                      uint8
# category_cd_T                                                                      uint8
# calendar_type_txt_Hospital School                                                  uint8
# calendar_type_txt_Magnet School, Traditional Calendar                              uint8
# calendar_type_txt_Magnet School, Year-Round Calendar                               uint8
# calendar_type_txt_Regular School, Traditional Calendar                             uint8
# calendar_type_txt_Regular School, Traditional Calendar plus Year-Round Calendar    uint8
# calendar_type_txt_Regular School, Year-Round Calendar                              uint8
# calendar_type_txt_Special Education, Traditional Calendar                          uint8
# school_type_txt_Regular School                                                     uint8
# esea_status_P                                                                      uint8
# esea_status_R                                                                      uint8
# esea_status_RF                                                                     uint8
# esea_status_RP                                                                     uint8
# Grad_project_status_Y                                                              uint8
# SPG Grade_B                                                                        uint8
# SPG Grade_C                                                                        uint8
# SPG Grade_D                                                                        uint8
# SPG Grade_F                                                                        uint8
# SPG Grade_I                                                                        uint8
# Reading SPG Grade_B                                                                uint8
# Reading SPG Grade_C                                                                uint8
# Reading SPG Grade_D                                                                uint8
# Reading SPG Grade_F                                                                uint8
# Math SPG Grade_B                                                                   uint8
# Math SPG Grade_C                                                                   uint8
# Math SPG Grade_D                                                                   uint8
# Math SPG Grade_F                                                                   uint8
# EVAAS Growth Status_Met                                                            uint8
# EVAAS Growth Status_NotMet                                                         uint8
# esea_attendance_Met                                                                uint8
# unit_code                                                                          object
# dtypes: float64(292), object(1), uint8(32)
# memory usage: 5.5+ MB

# %%
import sklearn
import pandas as pd

print('Sklearn Version: ' + sklearn.__version__)
print('Pandas Version: ' + pd.__version__)
# Out:
# Sklearn Version: 0.19.1
# Pandas Version: 0.22.0

# %%
print 'Output File Location:\r\n\r\n' + outputDir + inputFileName + '_ML.csv'
# Out:
# Output File Location:
#
# C:/Users/Jake/Documents/GitHub/EducationDataNC/2014/Machine Learning Datasets/PublicSchools2014_ML.csv
