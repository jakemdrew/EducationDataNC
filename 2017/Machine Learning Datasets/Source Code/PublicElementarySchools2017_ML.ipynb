# %% [markdown]
# # Create Public School Machine Learning Datasets
# ** This program creates all the _ML datasets in the NCEA repository.**
# * This notebook reads each School Dataset file located at \EducationDataNC\ *schoolYear* \School Datasets\ as input data.
# * Different school years are processed by changing the *schoolYear* parameter.
# * Different input / output files are processed / created by changing the *inputFileName* paramter in the cell below.
# * While a single program is used to create all the _ML datasets, one program copy per dataset is maintained in the repositiory so the dataset specific tranformation reports may be reviewed.
#
# **Datasets ending in ML are preprocessed for Machine Learning and go through the following transformations: **
# 1. Missing student body racial compositions are imputed using district averages.
# 2. Columns that have the same value in every single row are deleted.
# 3. Columns that have a unique value in every single row (all values are different) are deleted.
# 4. Empty columns (all values are NA or NULL) are deleted.
# 5. Numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# 6. Remaining numeric, non-race columns with missing values are imputed / populated with 0.  In many cases, schools are not reporting values when they are zero. However, mean imputation or some other more sophisticated strategy might be considered here.
# 7. Categorical / text based columns with > *uniqueThreshold* unique values are deleted.
# 8. All remaining categorical / text based columns are one-hot encoded.  In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# 9. Duplicated or highly similar columns with > 95% correlation are delelted.

# %%
#import required Libraries
import pandas as pd
import numpy as np
import os
import string

#**********************************************************************************
# Set the following variables before running this code!!!
#**********************************************************************************
#All raw data files are processed for the year below
schoolYear = 2017

#Location where copies of the raw data files will be read in from csv files.
dataDir = 'C:/Users/Jake/Documents/GitHub/EducationDataNC/' + str(schoolYear) + '/School Datasets/'

#Name of the file to be processed
#inputFileName = 'PublicSchools2017'
#inputFileName = 'PublicHighSchools2017'
#inputFileName = 'PublicMiddleSchools2017'
inputFileName = 'PublicElementarySchools2017'

#Input file being transformed for machine learning 
inputFile = dataDir + inputFileName + '.csv'

#Location where the new school datasets will be created.
outputDir = 'C:/Users/Jake/Documents/GitHub/EducationDataNC/' + str(schoolYear) + '/Machine Learning Datasets/'

#Missing Data Threshold (Per Column)
missingThreshold = 0.60

#Unique Value Threshold (Per Column)
#Delete Columns >  uniqueThreshold unique values prior to one-hot encoding. 
#(each unique value becomes a new column during one-hot encoding)
uniqueThreshold = 25

#Read in the School Data File
schoolData = pd.read_csv(inputFile, low_memory=False, dtype={'unit_code': object})
print('*********Start: Beginning Column and Row Counts********************************************')
schoolData.info(verbose=False)

#Select only public schools as charter schools are missing data for many columns.
schoolData = schoolData[(schoolData['type_cd'] == 'P') & (schoolData['student_num'] > 0)]

print('\r\n*********After: Selecting Only Public School Campuses**********************************')
schoolData.info(verbose=False)

#Save primary key
unit_code = schoolData['unit_code']
#Convert zip code to string
schoolData['szip_ad'] = schoolData['szip_ad'].astype('object')
# Out:
# *********Start: Beginning Column and Row Counts********************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1268 entries, 0 to 1267
# Columns: 1279 entries, vphone_ad to Number_Industry_Recognized_Crede
# dtypes: float64(1238), int64(3), object(38)
# memory usage: 12.4+ MB
#
# *********After: Selecting Only Public School Campuses**********************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1268 entries, 0 to 1267
# Columns: 1279 entries, vphone_ad to Number_Industry_Recognized_Crede
# dtypes: float64(1238), int64(3), object(38)
# memory usage: 12.4+ MB

# %% [markdown]
# # Prepare Consolidated Dataset for Machine Learning
# **Below we perform operations on the entire dataset to remove columns and update row values that could cause problems during machine learning.**

# %% [markdown]
# ## Student Body Racial Composition Features
# **Impute / update missing Student Body Racial Composition Fields using mean imputation.**
# * When there are no racial composition percentages for a particular school campus / unit_code, fill in the missing values

# %%
#Get Student Body Racial Composition Fields
raceCompositionFields = schoolData.filter(regex='Indian|Asian|Hispanic|Black|White|PacificIsland|TwoOrMore|Minority')\
                                  .filter(regex='Pct').columns
    
rowsBefore = schoolData[raceCompositionFields].isnull().T.any().T.sum()

#Update missing race values with the district average when avaiable (No district averages for charter schools) 
schoolData[raceCompositionFields] = schoolData.groupby('District Name')[raceCompositionFields]\
                                              .transform(lambda x: x.fillna(x.mean()))

    #Review dataset contents after Racial Composition Imputation
print('*********After: Updating Missing Racial Compostion Values****************************')   
rowsAfter = schoolData[raceCompositionFields].isnull().T.any().T.sum()
rowsUpdated = rowsBefore - rowsAfter
print 'Rows Updated / Imputed: ', rowsUpdated 
print('\r\nTotal Rows Missing Racial Compositions By District Name') 
schoolData['District Name'][schoolData[raceCompositionFields].isnull().T.any().T].value_counts()
# Out:
# *********After: Updating Missing Racial Compostion Values****************************
# Rows Updated / Imputed:  0
#
# Total Rows Missing Racial Compositions By District Name
# Series([], Name: District Name, dtype: int64)

# %% [markdown]
# ## Remove Columns with Problematic Data
# **Here we remove entire columns that could cause problems during machine learning.  The following operations are performed:**
# * Remove any columns that have the same value in every single row.
# * Remove any columns that have a unique value in every single row (all values are different).
# * Remove empty columns (all values are NA or NULL).

# %%
#Remove any fields that have the same value in all rows
UniqueValueCounts = schoolData.nunique(dropna=False)
SingleValueCols = UniqueValueCounts[UniqueValueCounts == 1].index
schoolData = schoolData.drop(SingleValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with the same value in every row.*******************')
schoolData.info(verbose=False)
print '\r\nColumns Deleted: ', len(SingleValueCols)
# Out:
# *********After: Removing columns with the same value in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1268 entries, 0 to 1267
# Columns: 1138 entries, vphone_ad to Number_Industry_Recognized_Crede
# dtypes: float64(1103), object(35)
# memory usage: 11.1+ MB
#
# Columns Deleted:  141

# %%
#Remove any fields that have unique values in every row
schoolDataRecordCt = schoolData.shape[0]
UniqueValueCounts = schoolData.apply(pd.Series.nunique)
AllUniqueValueCols = UniqueValueCounts[UniqueValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(AllUniqueValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with unique values in every row.*******************')
schoolData.info(verbose=False)
print '\r\nColumns Deleted: ', len(AllUniqueValueCols)
# Out:
# *********After: Removing columns with unique values in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1268 entries, 0 to 1267
# Columns: 1135 entries, street_ad to Number_Industry_Recognized_Crede
# dtypes: float64(1103), object(32)
# memory usage: 11.0+ MB
#
# Columns Deleted:  3

# %%
#Remove any empty fields (null values in every row)
schoolDataRecordCt = schoolData.shape[0]
NullValueCounts = schoolData.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with null / blank values in every row.*************')
schoolData.info(verbose=False)
print '\r\nColumns Deleted: ', len(NullValueCols)
# Out:
# *********After: Removing columns with null / blank values in every row.*************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1268 entries, 0 to 1267
# Columns: 1135 entries, street_ad to Number_Industry_Recognized_Crede
# dtypes: float64(1103), object(32)
# memory usage: 11.0+ MB
#
# Columns Deleted:  0

# %% [markdown]
# ## Handle Other Missing Values Types
# * Here we eliminate any numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# * All remaining non-race, numeric column missing values are populated with 0.
# * In many cases, it seems that schools are not simply not reporting values when they are zero. However, mean imputation or some other strategy might be considered.

# %%
#Isolate continuous and categorical data types
#These are indexers into the schoolData dataframe and may be used similar to the schoolData dataframe 
sD_boolean = schoolData.loc[:, (schoolData.dtypes == bool) ]
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]
sD_continuous = schoolData.loc[:, (schoolData.dtypes != bool) & (schoolData.dtypes != object)]
print "Boolean Columns: ", sD_boolean.shape[1]
print "Nominal Columns: ", sD_nominal.shape[1]
print "Continuous Columns: ", sD_continuous.shape[1]
print "Columns Accounted for: ", sD_nominal.shape[1] + sD_continuous.shape[1] + sD_boolean.shape[1]
# Out:
# Boolean Columns:  0
# Nominal Columns:  32
# Continuous Columns:  1103
# Columns Accounted for:  1135

# %%
#Eliminate continuous columns with more than missingThreshold percentage of missing values
schoolDataRecordCt = sD_continuous.shape[0]
missingValueLimit = schoolDataRecordCt * missingThreshold
NullValueCounts = sD_continuous.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts >= missingValueLimit].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with >= missingThreshold % of missing values******')
schoolData.info(verbose=False)
print '\r\nColumns Deleted: ', len(NullValueCols)
# Out:
# *********After: Removing columns with >= missingThreshold % of missing values******
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1268 entries, 0 to 1267
# Columns: 572 entries, street_ad to pct_eds
# dtypes: float64(540), object(32)
# memory usage: 5.5+ MB
#
# Columns Deleted:  563

# %% [markdown]
# ## One-Hot Encoding of Categorical Variables
# **All categorical / string variables are converted to numberic variables via one hot encoding.  Each unique row value will become a new binary / numeric column in the dataset.**
# * All remaining categorical columns are one-hot encoded.
# * In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# * Prior to one-hot encoding, columns with > *uniqueThreshold* unique values are deleted.

# %%
#Delete categorical columns with > 25 unique values (Each unique value becomes a column during one-hot encoding)
oneHotUniqueValueCounts = schoolData[sD_nominal.columns].apply(lambda x: x.nunique())
oneHotUniqueValueCols = oneHotUniqueValueCounts[oneHotUniqueValueCounts >= uniqueThreshold].index
schoolData.drop(oneHotUniqueValueCols, axis=1, inplace=True) 

#Review dataset contents one hot high unique value drops
print('*********After: Removing columns with >= uniqueThreshold unique values***********')
schoolData.info(verbose=False)
print '\r\nColumns Deleted: ', len(oneHotUniqueValueCols)
# Out:
# *********After: Removing columns with >= uniqueThreshold unique values***********
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1268 entries, 0 to 1267
# Columns: 560 entries, category_cd to pct_eds
# dtypes: float64(540), object(20)
# memory usage: 5.4+ MB
#
# Columns Deleted:  12

# %%
#Isolate remaining categorical variables
begColumnCt = len(schoolData.columns)
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]

#one hot encode categorical variables
schoolData = pd.get_dummies(data=schoolData, 
                       columns=sD_nominal, drop_first=True)

#Determine change in column count
endColumnCt = len(schoolData.columns)
columnsAdded = endColumnCt - begColumnCt

#Review dataset contents one hot high unique value drops
print 'Columns To One-Hot Encode: ', len(sD_nominal.columns)
print('\r\n*********After: Adding New Columns Via One-Hot Encoding*************************')
schoolData.info(verbose=False)
print '\r\nNew Columns Created Via One-Hot Encoding: ', columnsAdded
# Out:
# Columns To One-Hot Encode:  20
#
# *********After: Adding New Columns Via One-Hot Encoding*************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1268 entries, 0 to 1267
# Columns: 589 entries, student_num to SRC_Grades_Devices_Sent_Home_PK
# dtypes: float64(540), uint8(49)
# memory usage: 5.3 MB
#
# New Columns Created Via One-Hot Encoding:  29

# %% [markdown]
# ## Impute any Remaining Missing Values as Zero

# %%
#Print out all the missing value rows
pd.set_option('display.max_rows', 1000)

print('\r\n*********The Remaining Missing Values Below will be set to Zero!*************************')

#Check for Missing values 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# *********The Remaining Missing Values Below will be set to Zero!*************************
#                                          Variable Name  Number Missing Values
# 3                                              00_Size                     75
# 4                                              01_Size                     78
# 5                                              02_Size                     72
# 6                                              03_Size                     79
# 7                                              04_Size                     72
# 8                                              05_Size                    134
# 17                                           SPG Score                     35
# 18                                   Reading SPG Score                     38
# 19                                      Math SPG Score                     38
# 20                                  EVAAS Growth Score                     36
# 21                           Overall Achievement Score                     35
# 22                                       Reading Score                     38
# 23                                          Math Score                     38
# 24                                       Science Score                    121
# 25                            EOG/EOCSubjects_CACR_All                     35
# 26                             EOG/EOCSubjects_GLP_All                     35
# 27                                     EOGGr3_CACR_All                     60
# 28                                      EOGGr3_GLP_All                     60
# 29                                     EOGGr4_CACR_All                     64
# 30                                      EOGGr4_GLP_All                     64
# 31                                     EOGGr5_CACR_All                    126
# 32                                      EOGGr5_GLP_All                    126
# 33                                 EOGMathGr3_CACR_All                     61
# 34                                  EOGMathGr3_GLP_All                     61
# 35                               EOGMathGr3-8_CACR_All                     38
# 36                                EOGMathGr3-8_GLP_All                     38
# 37                                 EOGMathGr4_CACR_All                     65
# 38                                  EOGMathGr4_GLP_All                     65
# 39                                 EOGMathGr5_CACR_All                    129
# 40                                  EOGMathGr5_GLP_All                    129
# 41                              EOGReadingGr3_CACR_All                     61
# 42                               EOGReadingGr3_GLP_All                     61
# 43                            EOGReadingGr3-8_CACR_All                     38
# 44                             EOGReadingGr3-8_GLP_All                     38
# 45                              EOGReadingGr4_CACR_All                     65
# 46                               EOGReadingGr4_GLP_All                     65
# 47                              EOGReadingGr5_CACR_All                    129
# 48                               EOGReadingGr5_GLP_All                    129
# 49                              EOGScienceGr5_CACR_All                    129
# 50                               EOGScienceGr5_GLP_All                    129
# 51                            EOGScienceGr5&8_CACR_All                    124
# 52                             EOGScienceGr5&8_GLP_All                    124
# 53                                EOGSubjects_CACR_All                     38
# 54                                 EOGSubjects_GLP_All                     38
# 55                         EOG/EOCSubjects_CACR_Female                     35
# 56                          EOG/EOCSubjects_GLP_Female                     35
# 57                                  EOGGr3_CACR_Female                     60
# 58                                   EOGGr3_GLP_Female                     60
# 59                                  EOGGr4_CACR_Female                     64
# 60                                   EOGGr4_GLP_Female                     64
# 61                                  EOGGr5_CACR_Female                    126
# 62                                   EOGGr5_GLP_Female                    126
# 63                              EOGMathGr3_CACR_Female                     61
# 64                               EOGMathGr3_GLP_Female                     61
# 65                            EOGMathGr3-8_CACR_Female                     38
# 66                             EOGMathGr3-8_GLP_Female                     38
# 67                              EOGMathGr4_CACR_Female                     65
# 68                               EOGMathGr4_GLP_Female                     65
# 69                              EOGMathGr5_CACR_Female                    129
# 70                               EOGMathGr5_GLP_Female                    129
# 71                           EOGReadingGr3_CACR_Female                     61
# 72                            EOGReadingGr3_GLP_Female                     61
# 73                         EOGReadingGr3-8_CACR_Female                     38
# 74                          EOGReadingGr3-8_GLP_Female                     38
# 75                           EOGReadingGr4_CACR_Female                     65
# 76                            EOGReadingGr4_GLP_Female                     65
# 77                           EOGReadingGr5_CACR_Female                    129
# 78                            EOGReadingGr5_GLP_Female                    129
# 79                           EOGScienceGr5_CACR_Female                    129
# 80                            EOGScienceGr5_GLP_Female                    129
# 81                         EOGScienceGr5&8_CACR_Female                    124
# 82                          EOGScienceGr5&8_GLP_Female                    124
# 83                             EOGSubjects_CACR_Female                     38
# 84                              EOGSubjects_GLP_Female                     38
# 85                           EOG/EOCSubjects_CACR_Male                     35
# 86                            EOG/EOCSubjects_GLP_Male                     35
# 87                                    EOGGr3_CACR_Male                     60
# 88                                     EOGGr3_GLP_Male                     60
# 89                                    EOGGr4_CACR_Male                     64
# 90                                     EOGGr4_GLP_Male                     64
# 91                                    EOGGr5_CACR_Male                    126
# 92                                     EOGGr5_GLP_Male                    126
# 93                                EOGMathGr3_CACR_Male                     61
# 94                                 EOGMathGr3_GLP_Male                     61
# 95                              EOGMathGr3-8_CACR_Male                     38
# 96                               EOGMathGr3-8_GLP_Male                     38
# 97                                EOGMathGr4_CACR_Male                     65
# 98                                 EOGMathGr4_GLP_Male                     65
# 99                                EOGMathGr5_CACR_Male                    129
# 100                                EOGMathGr5_GLP_Male                    129
# 101                            EOGReadingGr3_CACR_Male                     61
# 102                             EOGReadingGr3_GLP_Male                     61
# 103                          EOGReadingGr3-8_CACR_Male                     38
# 104                           EOGReadingGr3-8_GLP_Male                     38
# 105                            EOGReadingGr4_CACR_Male                     65
# 106                             EOGReadingGr4_GLP_Male                     65
# 107                            EOGReadingGr5_CACR_Male                    129
# 108                             EOGReadingGr5_GLP_Male                    129
# 109                            EOGScienceGr5_CACR_Male                    129
# 110                             EOGScienceGr5_GLP_Male                    129
# 111                          EOGScienceGr5&8_CACR_Male                    124
# 112                           EOGScienceGr5&8_GLP_Male                    124
# 113                              EOGSubjects_CACR_Male                     38
# 114                               EOGSubjects_GLP_Male                     38
# 115                EOG/EOCSubjects_CACR_AmericanIndian                     35
# 116                 EOG/EOCSubjects_GLP_AmericanIndian                     35
# 117                         EOGGr3_CACR_AmericanIndian                     60
# 118                          EOGGr3_GLP_AmericanIndian                     60
# 119                         EOGGr4_CACR_AmericanIndian                     64
# 120                          EOGGr4_GLP_AmericanIndian                     64
# 121                         EOGGr5_CACR_AmericanIndian                    126
# 122                          EOGGr5_GLP_AmericanIndian                    126
# 123                     EOGMathGr3_CACR_AmericanIndian                     61
# 124                      EOGMathGr3_GLP_AmericanIndian                     61
# 125                   EOGMathGr3-8_CACR_AmericanIndian                     38
# 126                    EOGMathGr3-8_GLP_AmericanIndian                     38
# 127                     EOGMathGr4_CACR_AmericanIndian                     65
# 128                      EOGMathGr4_GLP_AmericanIndian                     65
# 129                     EOGMathGr5_CACR_AmericanIndian                    129
# 130                      EOGMathGr5_GLP_AmericanIndian                    129
# 131                  EOGReadingGr3_CACR_AmericanIndian                     61
# 132                   EOGReadingGr3_GLP_AmericanIndian                     61
# 133                EOGReadingGr3-8_CACR_AmericanIndian                     38
# 134                 EOGReadingGr3-8_GLP_AmericanIndian                     38
# 135                  EOGReadingGr4_CACR_AmericanIndian                     65
# 136                   EOGReadingGr4_GLP_AmericanIndian                     65
# 137                  EOGReadingGr5_CACR_AmericanIndian                    129
# 138                   EOGReadingGr5_GLP_AmericanIndian                    129
# 139                  EOGScienceGr5_CACR_AmericanIndian                    129
# 140                   EOGScienceGr5_GLP_AmericanIndian                    129
# 141                EOGScienceGr5&8_CACR_AmericanIndian                    124
# 142                 EOGScienceGr5&8_GLP_AmericanIndian                    124
# 143                    EOGSubjects_CACR_AmericanIndian                     38
# 144                     EOGSubjects_GLP_AmericanIndian                     38
# 145                         EOG/EOCSubjects_CACR_Asian                     35
# 146                          EOG/EOCSubjects_GLP_Asian                     35
# 147                                  EOGGr3_CACR_Asian                     60
# 148                                   EOGGr3_GLP_Asian                     60
# 149                                  EOGGr4_CACR_Asian                     64
# 150                                   EOGGr4_GLP_Asian                     64
# 151                                  EOGGr5_CACR_Asian                    126
# 152                                   EOGGr5_GLP_Asian                    126
# 153                              EOGMathGr3_CACR_Asian                     61
# 154                               EOGMathGr3_GLP_Asian                     61
# 155                            EOGMathGr3-8_CACR_Asian                     38
# 156                             EOGMathGr3-8_GLP_Asian                     38
# 157                              EOGMathGr4_CACR_Asian                     65
# 158                               EOGMathGr4_GLP_Asian                     65
# 159                              EOGMathGr5_CACR_Asian                    129
# 160                               EOGMathGr5_GLP_Asian                    129
# 161                           EOGReadingGr3_CACR_Asian                     61
# 162                            EOGReadingGr3_GLP_Asian                     61
# 163                         EOGReadingGr3-8_CACR_Asian                     38
# 164                          EOGReadingGr3-8_GLP_Asian                     38
# 165                           EOGReadingGr4_CACR_Asian                     65
# 166                            EOGReadingGr4_GLP_Asian                     65
# 167                           EOGReadingGr5_CACR_Asian                    129
# 168                            EOGReadingGr5_GLP_Asian                    129
# 169                           EOGScienceGr5_CACR_Asian                    129
# 170                            EOGScienceGr5_GLP_Asian                    129
# 171                         EOGScienceGr5&8_CACR_Asian                    124
# 172                          EOGScienceGr5&8_GLP_Asian                    124
# 173                             EOGSubjects_CACR_Asian                     38
# 174                              EOGSubjects_GLP_Asian                     38
# 175                         EOG/EOCSubjects_CACR_Black                     35
# 176                          EOG/EOCSubjects_GLP_Black                     35
# 177                                  EOGGr3_CACR_Black                     60
# 178                                   EOGGr3_GLP_Black                     60
# 179                                  EOGGr4_CACR_Black                     64
# 180                                   EOGGr4_GLP_Black                     64
# 181                                  EOGGr5_CACR_Black                    126
# 182                                   EOGGr5_GLP_Black                    126
# 183                              EOGMathGr3_CACR_Black                     61
# 184                               EOGMathGr3_GLP_Black                     61
# 185                            EOGMathGr3-8_CACR_Black                     38
# 186                             EOGMathGr3-8_GLP_Black                     38
# 187                              EOGMathGr4_CACR_Black                     65
# 188                               EOGMathGr4_GLP_Black                     65
# 189                              EOGMathGr5_CACR_Black                    129
# 190                               EOGMathGr5_GLP_Black                    129
# 191                           EOGReadingGr3_CACR_Black                     61
# 192                            EOGReadingGr3_GLP_Black                     61
# 193                         EOGReadingGr3-8_CACR_Black                     38
# 194                          EOGReadingGr3-8_GLP_Black                     38
# 195                           EOGReadingGr4_CACR_Black                     65
# 196                            EOGReadingGr4_GLP_Black                     65
# 197                           EOGReadingGr5_CACR_Black                    129
# 198                            EOGReadingGr5_GLP_Black                    129
# 199                           EOGScienceGr5_CACR_Black                    129
# 200                            EOGScienceGr5_GLP_Black                    129
# 201                         EOGScienceGr5&8_CACR_Black                    124
# 202                          EOGScienceGr5&8_GLP_Black                    124
# 203                             EOGSubjects_CACR_Black                     38
# 204                              EOGSubjects_GLP_Black                     38
# 205                      EOG/EOCSubjects_CACR_Hispanic                     35
# 206                       EOG/EOCSubjects_GLP_Hispanic                     35
# 207                               EOGGr3_CACR_Hispanic                     60
# 208                                EOGGr3_GLP_Hispanic                     60
# 209                               EOGGr4_CACR_Hispanic                     64
# 210                                EOGGr4_GLP_Hispanic                     64
# 211                               EOGGr5_CACR_Hispanic                    126
# 212                                EOGGr5_GLP_Hispanic                    126
# 213                           EOGMathGr3_CACR_Hispanic                     61
# 214                            EOGMathGr3_GLP_Hispanic                     61
# 215                         EOGMathGr3-8_CACR_Hispanic                     38
# 216                          EOGMathGr3-8_GLP_Hispanic                     38
# 217                           EOGMathGr4_CACR_Hispanic                     65
# 218                            EOGMathGr4_GLP_Hispanic                     65
# 219                           EOGMathGr5_CACR_Hispanic                    129
# 220                            EOGMathGr5_GLP_Hispanic                    129
# 221                        EOGReadingGr3_CACR_Hispanic                     61
# 222                         EOGReadingGr3_GLP_Hispanic                     61
# 223                      EOGReadingGr3-8_CACR_Hispanic                     38
# 224                       EOGReadingGr3-8_GLP_Hispanic                     38
# 225                        EOGReadingGr4_CACR_Hispanic                     65
# 226                         EOGReadingGr4_GLP_Hispanic                     65
# 227                        EOGReadingGr5_CACR_Hispanic                    129
# 228                         EOGReadingGr5_GLP_Hispanic                    129
# 229                        EOGScienceGr5_CACR_Hispanic                    129
# 230                         EOGScienceGr5_GLP_Hispanic                    129
# 231                      EOGScienceGr5&8_CACR_Hispanic                    124
# 232                       EOGScienceGr5&8_GLP_Hispanic                    124
# 233                          EOGSubjects_CACR_Hispanic                     38
# 234                           EOGSubjects_GLP_Hispanic                     38
# 235                EOG/EOCSubjects_CACR_TwoorMoreRaces                     35
# 236                 EOG/EOCSubjects_GLP_TwoorMoreRaces                     35
# 237                         EOGGr3_CACR_TwoorMoreRaces                     60
# 238                          EOGGr3_GLP_TwoorMoreRaces                     60
# 239                         EOGGr4_CACR_TwoorMoreRaces                     64
# 240                          EOGGr4_GLP_TwoorMoreRaces                     64
# 241                         EOGGr5_CACR_TwoorMoreRaces                    126
# 242                          EOGGr5_GLP_TwoorMoreRaces                    126
# 243                     EOGMathGr3_CACR_TwoorMoreRaces                     61
# 244                      EOGMathGr3_GLP_TwoorMoreRaces                     61
# 245                   EOGMathGr3-8_CACR_TwoorMoreRaces                     38
# 246                    EOGMathGr3-8_GLP_TwoorMoreRaces                     38
# 247                     EOGMathGr4_CACR_TwoorMoreRaces                     65
# 248                      EOGMathGr4_GLP_TwoorMoreRaces                     65
# 249                     EOGMathGr5_CACR_TwoorMoreRaces                    129
# 250                      EOGMathGr5_GLP_TwoorMoreRaces                    129
# 251                  EOGReadingGr3_CACR_TwoorMoreRaces                     61
# 252                   EOGReadingGr3_GLP_TwoorMoreRaces                     61
# 253                EOGReadingGr3-8_CACR_TwoorMoreRaces                     38
# 254                 EOGReadingGr3-8_GLP_TwoorMoreRaces                     38
# 255                  EOGReadingGr4_CACR_TwoorMoreRaces                     65
# 256                   EOGReadingGr4_GLP_TwoorMoreRaces                     65
# 257                  EOGReadingGr5_CACR_TwoorMoreRaces                    129
# 258                   EOGReadingGr5_GLP_TwoorMoreRaces                    129
# 259                  EOGScienceGr5_CACR_TwoorMoreRaces                    129
# 260                   EOGScienceGr5_GLP_TwoorMoreRaces                    129
# 261                EOGScienceGr5&8_CACR_TwoorMoreRaces                    124
# 262                 EOGScienceGr5&8_GLP_TwoorMoreRaces                    124
# 263                    EOGSubjects_CACR_TwoorMoreRaces                     38
# 264                     EOGSubjects_GLP_TwoorMoreRaces                     38
# 265                         EOG/EOCSubjects_CACR_White                     35
# 266                          EOG/EOCSubjects_GLP_White                     35
# 267                                  EOGGr3_CACR_White                     60
# 268                                   EOGGr3_GLP_White                     60
# 269                                  EOGGr4_CACR_White                     64
# 270                                   EOGGr4_GLP_White                     64
# 271                                  EOGGr5_CACR_White                    126
# 272                                   EOGGr5_GLP_White                    126
# 273                              EOGMathGr3_CACR_White                     61
# 274                               EOGMathGr3_GLP_White                     61
# 275                            EOGMathGr3-8_CACR_White                     38
# 276                             EOGMathGr3-8_GLP_White                     38
# 277                              EOGMathGr4_CACR_White                     65
# 278                               EOGMathGr4_GLP_White                     65
# 279                              EOGMathGr5_CACR_White                    129
# 280                               EOGMathGr5_GLP_White                    129
# 281                           EOGReadingGr3_CACR_White                     61
# 282                            EOGReadingGr3_GLP_White                     61
# 283                         EOGReadingGr3-8_CACR_White                     38
# 284                          EOGReadingGr3-8_GLP_White                     38
# 285                           EOGReadingGr4_CACR_White                     65
# 286                            EOGReadingGr4_GLP_White                     65
# 287                           EOGReadingGr5_CACR_White                    129
# 288                            EOGReadingGr5_GLP_White                    129
# 289                           EOGScienceGr5_CACR_White                    129
# 290                            EOGScienceGr5_GLP_White                    129
# 291                         EOGScienceGr5&8_CACR_White                    124
# 292                          EOGScienceGr5&8_GLP_White                    124
# 293                             EOGSubjects_CACR_White                     38
# 294                              EOGSubjects_GLP_White                     38
# 295                           EOG/EOCSubjects_CACR_EDS                     35
# 296                            EOG/EOCSubjects_GLP_EDS                     35
# 297                                    EOGGr3_CACR_EDS                     60
# 298                                     EOGGr3_GLP_EDS                     60
# 299                                    EOGGr4_CACR_EDS                     64
# 300                                     EOGGr4_GLP_EDS                     64
# 301                                    EOGGr5_CACR_EDS                    126
# 302                                     EOGGr5_GLP_EDS                    126
# 303                                EOGMathGr3_CACR_EDS                     61
# 304                                 EOGMathGr3_GLP_EDS                     61
# 305                              EOGMathGr3-8_CACR_EDS                     38
# 306                               EOGMathGr3-8_GLP_EDS                     38
# 307                                EOGMathGr4_CACR_EDS                     65
# 308                                 EOGMathGr4_GLP_EDS                     65
# 309                                EOGMathGr5_CACR_EDS                    129
# 310                                 EOGMathGr5_GLP_EDS                    129
# 311                             EOGReadingGr3_CACR_EDS                     61
# 312                              EOGReadingGr3_GLP_EDS                     61
# 313                           EOGReadingGr3-8_CACR_EDS                     38
# 314                            EOGReadingGr3-8_GLP_EDS                     38
# 315                             EOGReadingGr4_CACR_EDS                     65
# 316                              EOGReadingGr4_GLP_EDS                     65
# 317                             EOGReadingGr5_CACR_EDS                    129
# 318                              EOGReadingGr5_GLP_EDS                    129
# 319                             EOGScienceGr5_CACR_EDS                    129
# 320                              EOGScienceGr5_GLP_EDS                    129
# 321                           EOGScienceGr5&8_CACR_EDS                    124
# 322                            EOGScienceGr5&8_GLP_EDS                    124
# 323                               EOGSubjects_CACR_EDS                     38
# 324                                EOGSubjects_GLP_EDS                     38
# 325                           EOG/EOCSubjects_CACR_LEP                     35
# 326                            EOG/EOCSubjects_GLP_LEP                     35
# 327                                    EOGGr3_CACR_LEP                     60
# 328                                     EOGGr3_GLP_LEP                     60
# 329                                    EOGGr4_CACR_LEP                     64
# 330                                     EOGGr4_GLP_LEP                     64
# 331                                    EOGGr5_CACR_LEP                    126
# 332                                     EOGGr5_GLP_LEP                    126
# 333                                EOGMathGr3_CACR_LEP                     61
# 334                                 EOGMathGr3_GLP_LEP                     61
# 335                              EOGMathGr3-8_CACR_LEP                     38
# 336                               EOGMathGr3-8_GLP_LEP                     38
# 337                                EOGMathGr4_CACR_LEP                     65
# 338                                 EOGMathGr4_GLP_LEP                     65
# 339                                EOGMathGr5_CACR_LEP                    129
# 340                                 EOGMathGr5_GLP_LEP                    129
# 341                             EOGReadingGr3_CACR_LEP                     61
# 342                              EOGReadingGr3_GLP_LEP                     61
# 343                           EOGReadingGr3-8_CACR_LEP                     38
# 344                            EOGReadingGr3-8_GLP_LEP                     38
# 345                             EOGReadingGr4_CACR_LEP                     65
# 346                              EOGReadingGr4_GLP_LEP                     65
# 347                             EOGReadingGr5_CACR_LEP                    129
# 348                              EOGReadingGr5_GLP_LEP                    129
# 349                             EOGScienceGr5_CACR_LEP                    129
# 350                              EOGScienceGr5_GLP_LEP                    129
# 351                           EOGScienceGr5&8_CACR_LEP                    124
# 352                            EOGScienceGr5&8_GLP_LEP                    124
# 353                               EOGSubjects_CACR_LEP                     38
# 354                                EOGSubjects_GLP_LEP                     38
# 355                           EOG/EOCSubjects_CACR_SWD                     35
# 356                            EOG/EOCSubjects_GLP_SWD                     35
# 357                                    EOGGr3_CACR_SWD                     60
# 358                                     EOGGr3_GLP_SWD                     60
# 359                                    EOGGr4_CACR_SWD                     64
# 360                                     EOGGr4_GLP_SWD                     64
# 361                                    EOGGr5_CACR_SWD                    126
# 362                                     EOGGr5_GLP_SWD                    126
# 363                                EOGMathGr3_CACR_SWD                     61
# 364                                 EOGMathGr3_GLP_SWD                     61
# 365                              EOGMathGr3-8_CACR_SWD                     38
# 366                               EOGMathGr3-8_GLP_SWD                     38
# 367                                EOGMathGr4_CACR_SWD                     65
# 368                                 EOGMathGr4_GLP_SWD                     65
# 369                                EOGMathGr5_CACR_SWD                    129
# 370                                 EOGMathGr5_GLP_SWD                    129
# 371                             EOGReadingGr3_CACR_SWD                     61
# 372                              EOGReadingGr3_GLP_SWD                     61
# 373                           EOGReadingGr3-8_CACR_SWD                     38
# 374                            EOGReadingGr3-8_GLP_SWD                     38
# 375                             EOGReadingGr4_CACR_SWD                     65
# 376                              EOGReadingGr4_GLP_SWD                     65
# 377                             EOGReadingGr5_CACR_SWD                    129
# 378                              EOGReadingGr5_GLP_SWD                    129
# 379                             EOGScienceGr5_CACR_SWD                    129
# 380                              EOGScienceGr5_GLP_SWD                    129
# 381                           EOGScienceGr5&8_CACR_SWD                    124
# 382                            EOGScienceGr5&8_GLP_SWD                    124
# 383                               EOGSubjects_CACR_SWD                     38
# 384                                EOGSubjects_GLP_SWD                     38
# 385                           EOG/EOCSubjects_CACR_AIG                     35
# 386                            EOG/EOCSubjects_GLP_AIG                     35
# 387                                    EOGGr3_CACR_AIG                     60
# 388                                     EOGGr3_GLP_AIG                     60
# 389                                    EOGGr4_CACR_AIG                     64
# 390                                     EOGGr4_GLP_AIG                     64
# 391                                    EOGGr5_CACR_AIG                    126
# 392                                     EOGGr5_GLP_AIG                    126
# 393                                EOGMathGr3_CACR_AIG                     61
# 394                                 EOGMathGr3_GLP_AIG                     61
# 395                              EOGMathGr3-8_CACR_AIG                     38
# 396                               EOGMathGr3-8_GLP_AIG                     38
# 397                                EOGMathGr4_CACR_AIG                     65
# 398                                 EOGMathGr4_GLP_AIG                     65
# 399                                EOGMathGr5_CACR_AIG                    129
# 400                                 EOGMathGr5_GLP_AIG                    129
# 401                             EOGReadingGr3_CACR_AIG                     61
# 402                              EOGReadingGr3_GLP_AIG                     61
# 403                           EOGReadingGr3-8_CACR_AIG                     38
# 404                            EOGReadingGr3-8_GLP_AIG                     38
# 405                             EOGReadingGr4_CACR_AIG                     65
# 406                              EOGReadingGr4_GLP_AIG                     65
# 407                             EOGReadingGr5_CACR_AIG                    129
# 408                              EOGReadingGr5_GLP_AIG                    129
# 409                             EOGScienceGr5_CACR_AIG                    129
# 410                              EOGScienceGr5_GLP_AIG                    129
# 411                           EOGScienceGr5&8_CACR_AIG                    124
# 412                            EOGScienceGr5&8_GLP_AIG                    124
# 413                               EOGSubjects_CACR_AIG                     38
# 414                                EOGSubjects_GLP_AIG                     38
# 415                                        pct_GCE_ALL                     59
# 416                                     pct_PASSED_EOG                     88
# 417                                     pct_PASSED_LAA                    745
# 418                                       pct_PROMOTED                     61
# 419                                       pct_RETAINED                    741
# 420                           MathGr3-8_pTarget_PctMet                     39
# 421                        ReadingGr3-8_pTarget_PctMet                     39
# 422                            SciGr5&8_pTarget_PctMet                    167
# 423                        TotalTargets_pTarget_PctMet                     36
# 424                              lea_sat_avg_score_num                      4
# 425                          lea_sat_participation_pct                      4
# 426                           lea_ap_participation_pct                    133
# 427                              lea_ap_pct_3_or_above                     33
# 428                              lea_ib_pct_4_or_above                    717
# 433                             stud_internet_comp_num                      3
# 443                                  digital_media_pct                      4
# 444                           avg_age_media_collection                      3
# 445                                  books_per_student                      4
# 446                       lea_avg_age_media_collection                      3
# 447                              lea_books_per_student                      4
# 448                                            wap_num                      2
# 449                                  wap_per_classroom                      2
# 459                               _1yr_tchr_trnovr_pct                      6
# 460                                  lateral_teach_pct                    638
# 469                            lea_emer_prov_teach_pct                    414
# 470                              lea_lateral_teach_pct                     68
# 487                   Accomplished_TCHR_Standard 1_Pct                      2
# 488                   Accomplished_TCHR_Standard 2_Pct                      2
# 489                   Accomplished_TCHR_Standard 3_Pct                      2
# 490                   Accomplished_TCHR_Standard 4_Pct                      2
# 491                   Accomplished_TCHR_Standard 5_Pct                      2
# 492                     Developing_TCHR_Standard 1_Pct                      2
# 493                     Developing_TCHR_Standard 2_Pct                      2
# 494                     Developing_TCHR_Standard 3_Pct                      2
# 495                     Developing_TCHR_Standard 4_Pct                      2
# 496                     Developing_TCHR_Standard 5_Pct                      2
# 497                  Distinguished_TCHR_Standard 1_Pct                      2
# 498                  Distinguished_TCHR_Standard 2_Pct                      2
# 499                  Distinguished_TCHR_Standard 3_Pct                      2
# 500                  Distinguished_TCHR_Standard 4_Pct                      2
# 501                  Distinguished_TCHR_Standard 5_Pct                      2
# 502  Does Not Meet Expected Growth_TCHR_Student Gro...                      6
# 503    Exceeds Expected Growth_TCHR_Student Growth_Pct                      6
# 504      Meets Expected Growth_TCHR_Student Growth_Pct                      6
# 505                Not Demostrated_TCHR_Standard 1_Pct                      2
# 506                Not Demostrated_TCHR_Standard 2_Pct                      2
# 507                Not Demostrated_TCHR_Standard 3_Pct                      2
# 508                Not Demostrated_TCHR_Standard 4_Pct                      2
# 509                Not Demostrated_TCHR_Standard 5_Pct                      2
# 510                     Proficient_TCHR_Standard 1_Pct                      2
# 511                     Proficient_TCHR_Standard 2_Pct                      2
# 512                     Proficient_TCHR_Standard 3_Pct                      2
# 513                     Proficient_TCHR_Standard 4_Pct                      2
# 514                     Proficient_TCHR_Standard 5_Pct                      2

# %%
#Replace all remaining NaN with 0
schoolData = schoolData.fillna(0)

#Check for Missing values after final imputation 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# Empty DataFrame
# Columns: [Variable Name, Number Missing Values]
# Index: []

# %% [markdown]
# ## Identify and Remove Highly Correlated Features
# **Find and remove any columns / features that are > 95% correlated**
# * https://stackoverflow.com/questions/39409866/correlation-heatmap
# * https://chrisalbon.com/machine_learning/feature_selection/drop_highly_correlated_features/
# * https://codeyarns.com/2015/04/20/how-to-change-font-size-in-seaborn/

# %%
# calculate the correlation matrix
corr_matrix  = schoolData.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
#Get all of the correlation values > 95%
x = np.where(upper > 0.95)

#Display all field combinations with > 95% correlation
cf = pd.DataFrame()
cf['Field1'] = upper.columns[x[1]]
cf['Field2'] = upper.index[x[0]]

#Get the correlation values for every field combination. (There must be a more pythonic way to do this!)
corr = [0] * len(cf)
for i in range(0, len(cf)):
    corr[i] =  upper[cf['Field1'][i]][cf['Field2'][i]] 
    
cf['Correlation'] = corr

print 'There are ', str(len(cf['Field1'])), ' field correlations > 95%.'
cf
# Out:
# There are  701  field correlations > 95%.
#                                     Field1  \
# 0                      lea_class_teach_num
# 1                     st_tchyrs_0thru3_pct
# 2                       st_class_teach_num
# 3                             st_nbpts_num
# 4                        Reading SPG Score
# 5                           Math SPG Score
# 6                Overall Achievement Score
# 7                               Math Score
# 8                 EOG/EOCSubjects_CACR_All
# 9                  EOG/EOCSubjects_GLP_All
# 10                    EOGMathGr3-8_GLP_All
# 11                     EOGSubjects_GLP_All
# 12              EOG/EOCSubjects_GLP_Female
# 13                  EOGSubjects_GLP_Female
# 14                EOG/EOCSubjects_GLP_Male
# 15                    EOGSubjects_GLP_Male
# 16               Overall Achievement Score
# 17                           Reading Score
# 18                 EOG/EOCSubjects_GLP_All
# 19                 EOGReadingGr3-8_GLP_All
# 20                    EOGSubjects_CACR_All
# 21                     EOGSubjects_GLP_All
# 22              EOGReadingGr3-8_GLP_Female
# 23                  EOGSubjects_GLP_Female
# 24                EOG/EOCSubjects_GLP_Male
# 25                EOGReadingGr3-8_GLP_Male
# 26                    EOGSubjects_GLP_Male
# 27                              Math Score
# 28                 EOG/EOCSubjects_GLP_All
# 29                   EOGMathGr3-8_CACR_All
# 30                    EOGMathGr3-8_GLP_All
# 31                     EOGSubjects_GLP_All
# 32                 EOGMathGr3-8_GLP_Female
# 33                  EOGSubjects_GLP_Female
# 34                   EOGMathGr3-8_GLP_Male
# 35                    EOGSubjects_GLP_Male
# 36                           Reading Score
# 37                              Math Score
# 38                EOG/EOCSubjects_CACR_All
# 39                 EOG/EOCSubjects_GLP_All
# 40                   EOGMathGr3-8_CACR_All
# 41                    EOGMathGr3-8_GLP_All
# 42                 EOGReadingGr3-8_GLP_All
# 43                    EOGSubjects_CACR_All
# 44                     EOGSubjects_GLP_All
# 45             EOG/EOCSubjects_CACR_Female
# 46              EOG/EOCSubjects_GLP_Female
# 47                 EOGSubjects_CACR_Female
# 48                  EOGSubjects_GLP_Female
# 49               EOG/EOCSubjects_CACR_Male
# 50                EOG/EOCSubjects_GLP_Male
# 51                   EOGSubjects_CACR_Male
# 52                    EOGSubjects_GLP_Male
# 53                EOG/EOCSubjects_CACR_All
# 54                 EOG/EOCSubjects_GLP_All
# 55                EOGReadingGr3-8_CACR_All
# 56                 EOGReadingGr3-8_GLP_All
# 57                    EOGSubjects_CACR_All
# 58                     EOGSubjects_GLP_All
# 59              EOG/EOCSubjects_GLP_Female
# 60             EOGReadingGr3-8_CACR_Female
# 61              EOGReadingGr3-8_GLP_Female
# 62                 EOGSubjects_CACR_Female
# 63                  EOGSubjects_GLP_Female
# 64                EOG/EOCSubjects_GLP_Male
# 65               EOGReadingGr3-8_CACR_Male
# 66                EOGReadingGr3-8_GLP_Male
# 67                   EOGSubjects_CACR_Male
# 68                    EOGSubjects_GLP_Male
# 69                EOG/EOCSubjects_CACR_All
# 70                 EOG/EOCSubjects_GLP_All
# 71                   EOGMathGr3-8_CACR_All
# 72                    EOGMathGr3-8_GLP_All
# 73                    EOGSubjects_CACR_All
# 74                     EOGSubjects_GLP_All
# 75              EOG/EOCSubjects_GLP_Female
# 76                EOGMathGr3-8_CACR_Female
# 77                 EOGMathGr3-8_GLP_Female
# 78                  EOGSubjects_GLP_Female
# 79                EOG/EOCSubjects_GLP_Male
# 80                  EOGMathGr3-8_CACR_Male
# 81                   EOGMathGr3-8_GLP_Male
# 82                   EOGSubjects_CACR_Male
# 83                    EOGSubjects_GLP_Male
# 84                          EOGGr5_GLP_All
# 85                  EOGScienceGr5_CACR_All
# 86                   EOGScienceGr5_GLP_All
# 87                EOGScienceGr5&8_CACR_All
# 88                 EOGScienceGr5&8_GLP_All
# 89                 EOG/EOCSubjects_GLP_All
# 90                   EOGMathGr3-8_CACR_All
# 91                    EOGMathGr3-8_GLP_All
# 92                EOGReadingGr3-8_CACR_All
# 93                 EOGReadingGr3-8_GLP_All
# 94                    EOGSubjects_CACR_All
# 95                     EOGSubjects_GLP_All
# 96             EOG/EOCSubjects_CACR_Female
# 97              EOG/EOCSubjects_GLP_Female
# 98                EOGMathGr3-8_CACR_Female
# 99                 EOGSubjects_CACR_Female
# 100                 EOGSubjects_GLP_Female
# 101              EOG/EOCSubjects_CACR_Male
# 102               EOG/EOCSubjects_GLP_Male
# 103                 EOGMathGr3-8_CACR_Male
# 104              EOGReadingGr3-8_CACR_Male
# 105                  EOGSubjects_CACR_Male
# 106                   EOGSubjects_GLP_Male
# 107                  EOGMathGr3-8_CACR_All
# 108                   EOGMathGr3-8_GLP_All
# 109                EOGReadingGr3-8_GLP_All
# 110                   EOGSubjects_CACR_All
# 111                    EOGSubjects_GLP_All
# 112            EOG/EOCSubjects_CACR_Female
# 113             EOG/EOCSubjects_GLP_Female
# 114                EOGMathGr3-8_GLP_Female
# 115             EOGReadingGr3-8_GLP_Female
# 116                EOGSubjects_CACR_Female
# 117                 EOGSubjects_GLP_Female
# 118              EOG/EOCSubjects_CACR_Male
# 119               EOG/EOCSubjects_GLP_Male
# 120                  EOGMathGr3-8_GLP_Male
# 121               EOGReadingGr3-8_GLP_Male
# 122                  EOGSubjects_CACR_Male
# 123                   EOGSubjects_GLP_Male
# 124                         EOGGr3_GLP_All
# 125                    EOGMathGr3_CACR_All
# 126                 EOGReadingGr3_CACR_All
# 127                  EOGReadingGr3_GLP_All
# 128                     EOGGr3_CACR_Female
# 129                       EOGGr3_CACR_Male
# 130                    EOGMathGr3_CACR_All
# 131                     EOGMathGr3_GLP_All
# 132                  EOGReadingGr3_GLP_All
# 133                      EOGGr3_GLP_Female
# 134                        EOGGr3_GLP_Male
# 135                         EOGGr4_GLP_All
# 136                    EOGMathGr4_CACR_All
# 137                     EOGMathGr4_GLP_All
# 138                 EOGReadingGr4_CACR_All
# 139                       EOGGr4_CACR_Male
# 140                    EOGMathGr4_CACR_All
# 141                     EOGMathGr4_GLP_All
# 142                  EOGReadingGr4_GLP_All
# 143                        EOGGr4_GLP_Male
# 144                         EOGGr5_GLP_All
# 145                    EOGMathGr5_CACR_All
# 146                     EOGMathGr5_GLP_All
# 147                  EOGReadingGr5_GLP_All
# 148                 EOGScienceGr5_CACR_All
# 149                     EOGGr5_CACR_Female
# 150                      EOGGr5_GLP_Female
# 151                       EOGGr5_CACR_Male
# 152                        EOGGr5_GLP_Male
# 153                     EOGMathGr5_GLP_All
# 154                  EOGReadingGr5_GLP_All
# 155                  EOGScienceGr5_GLP_All
# 156                EOGScienceGr5&8_GLP_All
# 157                     EOGGr5_CACR_Female
# 158                      EOGGr5_GLP_Female
# 159                       EOGGr5_CACR_Male
# 160                        EOGGr5_GLP_Male
# 161                     EOGMathGr3_GLP_All
# 162                   EOGMathGr3-8_GLP_All
# 163                   EOGSubjects_CACR_All
# 164                    EOGSubjects_GLP_All
# 165            EOG/EOCSubjects_CACR_Female
# 166               EOGMathGr3-8_CACR_Female
# 167                EOGMathGr3-8_GLP_Female
# 168                EOGSubjects_CACR_Female
# 169                 EOGSubjects_GLP_Female
# 170              EOG/EOCSubjects_CACR_Male
# 171               EOG/EOCSubjects_GLP_Male
# 172                 EOGMathGr3-8_CACR_Male
# 173                  EOGMathGr3-8_GLP_Male
# 174                  EOGSubjects_CACR_Male
# 175                   EOGSubjects_GLP_Male
# 176                   EOGSubjects_CACR_All
# 177                    EOGSubjects_GLP_All
# 178             EOG/EOCSubjects_GLP_Female
# 179               EOGMathGr3-8_CACR_Female
# 180                EOGMathGr3-8_GLP_Female
# 181                 EOGSubjects_GLP_Female
# 182               EOG/EOCSubjects_GLP_Male
# 183                 EOGMathGr3-8_CACR_Male
# 184                  EOGMathGr3-8_GLP_Male
# 185                  EOGSubjects_CACR_Male
# 186                   EOGSubjects_GLP_Male
# 187                     EOGMathGr4_GLP_All
# 188                     EOGMathGr5_GLP_All
# 189                      EOGGr5_GLP_Female
# 190                  EOGReadingGr3_GLP_All
# 191                         pct_PASSED_EOG
# 192                EOGReadingGr3-8_GLP_All
# 193                   EOGSubjects_CACR_All
# 194            EOG/EOCSubjects_CACR_Female
# 195            EOGReadingGr3-8_CACR_Female
# 196             EOGReadingGr3-8_GLP_Female
# 197                EOGSubjects_CACR_Female
# 198              EOG/EOCSubjects_CACR_Male
# 199              EOGReadingGr3-8_CACR_Male
# 200               EOGReadingGr3-8_GLP_Male
# 201                  EOGSubjects_CACR_Male
# 202                   EOGSubjects_CACR_All
# 203                    EOGSubjects_GLP_All
# 204             EOG/EOCSubjects_GLP_Female
# 205            EOGReadingGr3-8_CACR_Female
# 206             EOGReadingGr3-8_GLP_Female
# 207                EOGSubjects_CACR_Female
# 208                 EOGSubjects_GLP_Female
# 209               EOG/EOCSubjects_GLP_Male
# 210              EOGReadingGr3-8_CACR_Male
# 211               EOGReadingGr3-8_GLP_Male
# 212                  EOGSubjects_CACR_Male
# 213                   EOGSubjects_GLP_Male
# 214                  EOGReadingGr4_GLP_All
# 215                  EOGReadingGr5_GLP_All
# 216                  EOGScienceGr5_GLP_All
# 217               EOGScienceGr5&8_CACR_All
# 218                EOGScienceGr5&8_GLP_All
# 219               EOGScienceGr5&8_CACR_All
# 220                EOGScienceGr5&8_GLP_All
# 221                EOGScienceGr5&8_GLP_All
# 222                    EOGSubjects_GLP_All
# 223            EOG/EOCSubjects_CACR_Female
# 224             EOG/EOCSubjects_GLP_Female
# 225               EOGMathGr3-8_CACR_Female
# 226            EOGReadingGr3-8_CACR_Female
# 227             EOGReadingGr3-8_GLP_Female
# 228                EOGSubjects_CACR_Female
# 229                 EOGSubjects_GLP_Female
# 230              EOG/EOCSubjects_CACR_Male
# 231               EOG/EOCSubjects_GLP_Male
# 232                 EOGMathGr3-8_CACR_Male
# 233              EOGReadingGr3-8_CACR_Male
# 234               EOGReadingGr3-8_GLP_Male
# 235                  EOGSubjects_CACR_Male
# 236                   EOGSubjects_GLP_Male
# 237            EOG/EOCSubjects_CACR_Female
# 238             EOG/EOCSubjects_GLP_Female
# 239               EOGMathGr3-8_CACR_Female
# 240                EOGMathGr3-8_GLP_Female
# 241             EOGReadingGr3-8_GLP_Female
# 242                EOGSubjects_CACR_Female
# 243                 EOGSubjects_GLP_Female
# 244              EOG/EOCSubjects_CACR_Male
# 245               EOG/EOCSubjects_GLP_Male
# 246                 EOGMathGr3-8_CACR_Male
# 247                  EOGMathGr3-8_GLP_Male
# 248               EOGReadingGr3-8_GLP_Male
# 249                  EOGSubjects_CACR_Male
# 250                   EOGSubjects_GLP_Male
# 251             EOG/EOCSubjects_GLP_Female
# 252               EOGMathGr3-8_CACR_Female
# 253            EOGReadingGr3-8_CACR_Female
# 254                EOGSubjects_CACR_Female
# 255                 EOGSubjects_GLP_Female
# 256               EOGMathGr3-8_CACR_Female
# 257                EOGMathGr3-8_GLP_Female
# 258             EOGReadingGr3-8_GLP_Female
# 259                EOGSubjects_CACR_Female
# 260                 EOGSubjects_GLP_Female
# 261                      EOGGr3_GLP_Female
# 262                      EOGGr4_GLP_Female
# 263                      EOGGr5_GLP_Female
# 264                  EOGMathGr3_GLP_Female
# 265                EOGMathGr3-8_GLP_Female
# 266                EOGSubjects_CACR_Female
# 267                 EOGSubjects_GLP_Female
# 268                EOGSubjects_CACR_Female
# 269                 EOGSubjects_GLP_Female
# 270                  EOGMathGr4_GLP_Female
# 271                  EOGMathGr5_GLP_Female
# 272               EOGReadingGr3_GLP_Female
# 273             EOGReadingGr3-8_GLP_Female
# 274                EOGSubjects_CACR_Female
# 275                EOGSubjects_CACR_Female
# 276                 EOGSubjects_GLP_Female
# 277               EOGReadingGr5_GLP_Female
# 278               EOGScienceGr5_GLP_Female
# 279            EOGScienceGr5&8_CACR_Female
# 280             EOGScienceGr5&8_GLP_Female
# 281             EOGScienceGr5&8_GLP_Female
# 282                 EOGSubjects_GLP_Female
# 283               EOG/EOCSubjects_GLP_Male
# 284                 EOGMathGr3-8_CACR_Male
# 285              EOGReadingGr3-8_CACR_Male
# 286               EOGReadingGr3-8_GLP_Male
# 287                  EOGSubjects_CACR_Male
# 288                   EOGSubjects_GLP_Male
# 289                 EOGMathGr3-8_CACR_Male
# 290                  EOGMathGr3-8_GLP_Male
# 291               EOGReadingGr3-8_GLP_Male
# 292                  EOGSubjects_CACR_Male
# 293                   EOGSubjects_GLP_Male
# 294                        EOGGr3_GLP_Male
# 295                        EOGGr4_GLP_Male
# 296                        EOGGr5_GLP_Male
# 297                    EOGMathGr3_GLP_Male
# 298                  EOGMathGr3-8_GLP_Male
# 299                  EOGSubjects_CACR_Male
# 300                   EOGSubjects_GLP_Male
# 301                  EOGSubjects_CACR_Male
# 302                   EOGSubjects_GLP_Male
# 303                    EOGMathGr4_GLP_Male
# 304                    EOGMathGr5_GLP_Male
# 305                 EOGReadingGr3_GLP_Male
# 306               EOGReadingGr3-8_GLP_Male
# 307                  EOGSubjects_CACR_Male
# 308                  EOGSubjects_CACR_Male
# 309                   EOGSubjects_GLP_Male
# 310                 EOGReadingGr5_GLP_Male
# 311                 EOGScienceGr5_GLP_Male
# 312              EOGScienceGr5&8_CACR_Male
# 313               EOGScienceGr5&8_GLP_Male
# 314               EOGScienceGr5&8_GLP_Male
# 315                   EOGSubjects_GLP_Male
# 316     EOG/EOCSubjects_GLP_AmericanIndian
# 317        EOGSubjects_CACR_AmericanIndian
# 318         EOGSubjects_GLP_AmericanIndian
# 319        EOGSubjects_CACR_AmericanIndian
# 320         EOGSubjects_GLP_AmericanIndian
# 321              EOGGr3_GLP_AmericanIndian
# 322              EOGGr4_GLP_AmericanIndian
# 323              EOGGr5_GLP_AmericanIndian
# 324          EOGMathGr3_GLP_AmericanIndian
# 325       EOGReadingGr3_GLP_AmericanIndian
# 326        EOGMathGr3-8_GLP_AmericanIndian
# 327     EOGReadingGr3-8_GLP_AmericanIndian
# 328    EOGReadingGr3-8_CACR_AmericanIndian
# 329     EOGReadingGr3-8_GLP_AmericanIndian
# 330          EOGMathGr4_GLP_AmericanIndian
# 331       EOGReadingGr4_GLP_AmericanIndian
# 332          EOGMathGr5_GLP_AmericanIndian
# 333       EOGReadingGr5_GLP_AmericanIndian
# 334       EOGScienceGr5_GLP_AmericanIndian
# 335       EOGReadingGr3_GLP_AmericanIndian
# 336     EOGReadingGr3-8_GLP_AmericanIndian
# 337       EOGReadingGr4_GLP_AmericanIndian
# 338       EOGScienceGr5_GLP_AmericanIndian
# 339       EOGScienceGr5_GLP_AmericanIndian
# 340    EOGScienceGr5&8_CACR_AmericanIndian
# 341     EOGScienceGr5&8_GLP_AmericanIndian
# 342    EOGScienceGr5&8_CACR_AmericanIndian
# 343     EOGScienceGr5&8_GLP_AmericanIndian
# 344     EOGScienceGr5&8_GLP_AmericanIndian
# 345         EOGSubjects_GLP_AmericanIndian
# 346              EOG/EOCSubjects_GLP_Asian
# 347                 EOGSubjects_CACR_Asian
# 348                  EOGSubjects_GLP_Asian
# 349                 EOGSubjects_CACR_Asian
# 350                  EOGSubjects_GLP_Asian
# 351                       EOGGr3_GLP_Asian
# 352                       EOGGr4_GLP_Asian
# 353                       EOGGr5_GLP_Asian
# 354                   EOGMathGr3_GLP_Asian
# 355               EOGReadingGr3_CACR_Asian
# 356                EOGReadingGr3_GLP_Asian
# 357               EOGReadingGr3_CACR_Asian
# 358                EOGReadingGr3_GLP_Asian
# 359                 EOGMathGr3-8_GLP_Asian
# 360             EOGReadingGr3-8_CACR_Asian
# 361              EOGReadingGr3-8_GLP_Asian
# 362             EOGReadingGr3-8_CACR_Asian
# 363              EOGReadingGr3-8_GLP_Asian
# 364                   EOGMathGr4_GLP_Asian
# 365               EOGReadingGr4_CACR_Asian
# 366                EOGReadingGr4_GLP_Asian
# 367               EOGReadingGr4_CACR_Asian
# 368                EOGReadingGr4_GLP_Asian
# 369                   EOGMathGr5_GLP_Asian
# 370               EOGReadingGr5_CACR_Asian
# 371                EOGReadingGr5_GLP_Asian
# 372               EOGScienceGr5_CACR_Asian
# 373                EOGScienceGr5_GLP_Asian
# 374             EOGScienceGr5&8_CACR_Asian
# 375              EOGScienceGr5&8_GLP_Asian
# 376               EOGReadingGr5_CACR_Asian
# 377                EOGReadingGr5_GLP_Asian
# 378               EOGScienceGr5_CACR_Asian
# 379                EOGScienceGr5_GLP_Asian
# 380             EOGScienceGr5&8_CACR_Asian
# 381              EOGScienceGr5&8_GLP_Asian
# 382                EOGReadingGr3_GLP_Asian
# 383              EOGReadingGr3-8_GLP_Asian
# 384                EOGReadingGr4_GLP_Asian
# 385                EOGReadingGr5_GLP_Asian
# 386               EOGScienceGr5_CACR_Asian
# 387                EOGScienceGr5_GLP_Asian
# 388             EOGScienceGr5&8_CACR_Asian
# 389              EOGScienceGr5&8_GLP_Asian
# 390               EOGScienceGr5_CACR_Asian
# 391                EOGScienceGr5_GLP_Asian
# 392             EOGScienceGr5&8_CACR_Asian
# 393              EOGScienceGr5&8_GLP_Asian
# 394                EOGScienceGr5_GLP_Asian
# 395             EOGScienceGr5&8_CACR_Asian
# 396              EOGScienceGr5&8_GLP_Asian
# 397             EOGScienceGr5&8_CACR_Asian
# 398              EOGScienceGr5&8_GLP_Asian
# 399              EOGScienceGr5&8_GLP_Asian
# 400                  EOGSubjects_GLP_Asian
# 401              EOG/EOCSubjects_GLP_Black
# 402                 EOGSubjects_CACR_Black
# 403                  EOGSubjects_GLP_Black
# 404                 EOGSubjects_CACR_Black
# 405                  EOGSubjects_GLP_Black
# 406                       EOGGr3_GLP_Black
# 407                       EOGGr4_GLP_Black
# 408                       EOGGr5_GLP_Black
# 409                   EOGMathGr3_GLP_Black
# 410                 EOGMathGr3-8_GLP_Black
# 411                   EOGMathGr4_GLP_Black
# 412                   EOGMathGr5_GLP_Black
# 413                EOGReadingGr3_GLP_Black
# 414              EOGReadingGr3-8_GLP_Black
# 415                EOGReadingGr4_GLP_Black
# 416                EOGScienceGr5_GLP_Black
# 417             EOGScienceGr5&8_CACR_Black
# 418              EOGScienceGr5&8_GLP_Black
# 419             EOGScienceGr5&8_CACR_Black
# 420              EOGScienceGr5&8_GLP_Black
# 421              EOGScienceGr5&8_GLP_Black
# 422                  EOGSubjects_GLP_Black
# 423           EOG/EOCSubjects_GLP_Hispanic
# 424              EOGSubjects_CACR_Hispanic
# 425               EOGSubjects_GLP_Hispanic
# 426              EOGSubjects_CACR_Hispanic
# 427               EOGSubjects_GLP_Hispanic
# 428                    EOGGr3_GLP_Hispanic
# 429                    EOGGr4_GLP_Hispanic
# 430                    EOGGr5_GLP_Hispanic
# 431                EOGMathGr3_GLP_Hispanic
# 432              EOGMathGr3-8_GLP_Hispanic
# 433                EOGMathGr4_GLP_Hispanic
# 434                EOGMathGr5_GLP_Hispanic
# 435             EOGScienceGr5_GLP_Hispanic
# 436             EOGReadingGr3_GLP_Hispanic
# 437             EOGReadingGr4_GLP_Hispanic
# 438             EOGReadingGr5_GLP_Hispanic
# 439             EOGScienceGr5_GLP_Hispanic
# 440          EOGScienceGr5&8_CACR_Hispanic
# 441           EOGScienceGr5&8_GLP_Hispanic
# 442          EOGScienceGr5&8_CACR_Hispanic
# 443           EOGScienceGr5&8_GLP_Hispanic
# 444           EOGScienceGr5&8_GLP_Hispanic
# 445               EOGSubjects_GLP_Hispanic
# 446     EOG/EOCSubjects_GLP_TwoorMoreRaces
# 447        EOGSubjects_CACR_TwoorMoreRaces
# 448         EOGSubjects_GLP_TwoorMoreRaces
# 449        EOGSubjects_CACR_TwoorMoreRaces
# 450         EOGSubjects_GLP_TwoorMoreRaces
# 451              EOGGr3_GLP_TwoorMoreRaces
# 452              EOGGr4_GLP_TwoorMoreRaces
# 453              EOGGr5_GLP_TwoorMoreRaces
# 454          EOGMathGr3_GLP_TwoorMoreRaces
# 455      EOGReadingGr3_CACR_TwoorMoreRaces
# 456       EOGReadingGr3_GLP_TwoorMoreRaces
# 457      EOGReadingGr3_CACR_TwoorMoreRaces
# 458       EOGReadingGr3_GLP_TwoorMoreRaces
# 459        EOGMathGr3-8_GLP_TwoorMoreRaces
# 460     EOGReadingGr3-8_GLP_TwoorMoreRaces
# 461          EOGMathGr4_GLP_TwoorMoreRaces
# 462       EOGReadingGr4_GLP_TwoorMoreRaces
# 463      EOGReadingGr4_CACR_TwoorMoreRaces
# 464       EOGReadingGr4_GLP_TwoorMoreRaces
# 465          EOGMathGr5_GLP_TwoorMoreRaces
# 466      EOGReadingGr5_CACR_TwoorMoreRaces
# 467       EOGReadingGr5_GLP_TwoorMoreRaces
# 468       EOGScienceGr5_GLP_TwoorMoreRaces
# 469      EOGReadingGr5_CACR_TwoorMoreRaces
# 470       EOGReadingGr5_GLP_TwoorMoreRaces
# 471      EOGScienceGr5_CACR_TwoorMoreRaces
# 472       EOGScienceGr5_GLP_TwoorMoreRaces
# 473     EOGScienceGr5&8_GLP_TwoorMoreRaces
# 474       EOGReadingGr3_GLP_TwoorMoreRaces
# 475     EOGReadingGr3-8_GLP_TwoorMoreRaces
# 476       EOGReadingGr4_GLP_TwoorMoreRaces
# 477       EOGReadingGr5_GLP_TwoorMoreRaces
# 478      EOGScienceGr5_CACR_TwoorMoreRaces
# 479       EOGScienceGr5_GLP_TwoorMoreRaces
# 480    EOGScienceGr5&8_CACR_TwoorMoreRaces
# 481      EOGScienceGr5_CACR_TwoorMoreRaces
# 482       EOGScienceGr5_GLP_TwoorMoreRaces
# 483    EOGScienceGr5&8_CACR_TwoorMoreRaces
# 484     EOGScienceGr5&8_GLP_TwoorMoreRaces
# 485       EOGScienceGr5_GLP_TwoorMoreRaces
# 486    EOGScienceGr5&8_CACR_TwoorMoreRaces
# 487     EOGScienceGr5&8_GLP_TwoorMoreRaces
# 488    EOGScienceGr5&8_CACR_TwoorMoreRaces
# 489     EOGScienceGr5&8_GLP_TwoorMoreRaces
# 490     EOGScienceGr5&8_GLP_TwoorMoreRaces
# 491         EOGSubjects_GLP_TwoorMoreRaces
# 492              EOG/EOCSubjects_GLP_White
# 493                 EOGSubjects_CACR_White
# 494                  EOGSubjects_GLP_White
# 495                 EOGSubjects_CACR_White
# 496                  EOGSubjects_GLP_White
# 497                       EOGGr3_GLP_White
# 498                       EOGGr4_GLP_White
# 499                       EOGGr5_GLP_White
# 500                   EOGMathGr3_GLP_White
# 501                EOGReadingGr3_GLP_White
# 502                 EOGMathGr3-8_GLP_White
# 503              EOGReadingGr3-8_GLP_White
# 504                   EOGMathGr4_GLP_White
# 505                EOGReadingGr4_GLP_White
# 506                   EOGMathGr5_GLP_White
# 507                EOGReadingGr5_GLP_White
# 508                EOGReadingGr5_GLP_White
# 509               EOGScienceGr5_CACR_White
# 510                EOGScienceGr5_GLP_White
# 511                EOGReadingGr3_GLP_White
# 512              EOGReadingGr3-8_GLP_White
# 513                EOGReadingGr4_GLP_White
# 514                EOGReadingGr5_GLP_White
# 515               EOGScienceGr5_CACR_White
# 516                EOGScienceGr5_GLP_White
# 517                EOGScienceGr5_GLP_White
# 518             EOGScienceGr5&8_CACR_White
# 519              EOGScienceGr5&8_GLP_White
# 520             EOGScienceGr5&8_CACR_White
# 521              EOGScienceGr5&8_GLP_White
# 522              EOGScienceGr5&8_GLP_White
# 523                  EOGSubjects_GLP_White
# 524                EOG/EOCSubjects_GLP_EDS
# 525                   EOGSubjects_CACR_EDS
# 526                    EOGSubjects_GLP_EDS
# 527                   EOGSubjects_CACR_EDS
# 528                    EOGSubjects_GLP_EDS
# 529                         EOGGr3_GLP_EDS
# 530                         EOGGr4_GLP_EDS
# 531                         EOGGr5_GLP_EDS
# 532                   EOGMathGr3-8_GLP_EDS
# 533                     EOGMathGr4_GLP_EDS
# 534                     EOGMathGr5_GLP_EDS
# 535                EOGReadingGr3-8_GLP_EDS
# 536                  EOGScienceGr5_GLP_EDS
# 537               EOGScienceGr5&8_CACR_EDS
# 538                EOGScienceGr5&8_GLP_EDS
# 539                EOGScienceGr5&8_GLP_EDS
# 540                    EOGSubjects_GLP_EDS
# 541                   EOGSubjects_CACR_LEP
# 542                    EOGSubjects_GLP_LEP
# 543                         EOGGr3_GLP_LEP
# 544                         EOGGr5_GLP_LEP
# 545                     EOGMathGr3_GLP_LEP
# 546                   EOGMathGr3-8_GLP_LEP
# 547                     EOGMathGr4_GLP_LEP
# 548                     EOGMathGr5_GLP_LEP
# 549               EOGScienceGr5&8_CACR_LEP
# 550                EOGScienceGr5&8_GLP_LEP
# 551                EOG/EOCSubjects_GLP_SWD
# 552                   EOGSubjects_CACR_SWD
# 553                    EOGSubjects_GLP_SWD
# 554                   EOGSubjects_CACR_SWD
# 555                    EOGSubjects_GLP_SWD
# 556                     EOGMathGr4_GLP_SWD
# 557               EOGScienceGr5&8_CACR_SWD
# 558                EOGScienceGr5&8_GLP_SWD
# 559                    EOGSubjects_GLP_SWD
# 560                EOG/EOCSubjects_GLP_AIG
# 561                   EOGSubjects_CACR_AIG
# 562                    EOGSubjects_GLP_AIG
# 563                   EOGSubjects_CACR_AIG
# 564                    EOGSubjects_GLP_AIG
# 565                         EOGGr3_GLP_AIG
# 566                         EOGGr4_GLP_AIG
# 567                         EOGGr5_GLP_AIG
# 568                     EOGMathGr3_GLP_AIG
# 569                 EOGReadingGr3_CACR_AIG
# 570                  EOGReadingGr3_GLP_AIG
# 571                 EOGReadingGr3_CACR_AIG
# 572                  EOGReadingGr3_GLP_AIG
# 573                   EOGMathGr3-8_GLP_AIG
# 574               EOGReadingGr3-8_CACR_AIG
# 575                EOGReadingGr3-8_GLP_AIG
# 576               EOGReadingGr3-8_CACR_AIG
# 577                EOGReadingGr3-8_GLP_AIG
# 578                     EOGMathGr4_GLP_AIG
# 579                 EOGReadingGr4_CACR_AIG
# 580                  EOGReadingGr4_GLP_AIG
# 581                 EOGReadingGr4_CACR_AIG
# 582                  EOGReadingGr4_GLP_AIG
# 583                     EOGMathGr5_GLP_AIG
# 584                 EOGReadingGr5_CACR_AIG
# 585                  EOGReadingGr5_GLP_AIG
# 586                 EOGScienceGr5_CACR_AIG
# 587                  EOGScienceGr5_GLP_AIG
# 588               EOGScienceGr5&8_CACR_AIG
# 589                EOGScienceGr5&8_GLP_AIG
# 590                 EOGReadingGr5_CACR_AIG
# 591                  EOGReadingGr5_GLP_AIG
# 592                 EOGScienceGr5_CACR_AIG
# 593                  EOGScienceGr5_GLP_AIG
# 594               EOGScienceGr5&8_CACR_AIG
# 595                EOGScienceGr5&8_GLP_AIG
# 596                  EOGReadingGr3_GLP_AIG
# 597                EOGReadingGr3-8_GLP_AIG
# 598                  EOGReadingGr4_GLP_AIG
# 599                  EOGReadingGr5_GLP_AIG
# 600                 EOGScienceGr5_CACR_AIG
# 601                  EOGScienceGr5_GLP_AIG
# 602               EOGScienceGr5&8_CACR_AIG
# 603                EOGScienceGr5&8_GLP_AIG
# 604                 EOGScienceGr5_CACR_AIG
# 605                  EOGScienceGr5_GLP_AIG
# 606               EOGScienceGr5&8_CACR_AIG
# 607                EOGScienceGr5&8_GLP_AIG
# 608                  EOGScienceGr5_GLP_AIG
# 609               EOGScienceGr5&8_CACR_AIG
# 610                EOGScienceGr5&8_GLP_AIG
# 611               EOGScienceGr5&8_CACR_AIG
# 612                EOGScienceGr5&8_GLP_AIG
# 613                EOGScienceGr5&8_GLP_AIG
# 614                    EOGSubjects_GLP_AIG
# 615            ReadingGr3-8_pTarget_PctMet
# 616            TotalTargets_pTarget_PctMet
# 617            TotalTargets_pTarget_PctMet
# 618                            SPG Grade_I
# 619                st_short_susp_per_c_num
# 620                  st_tchyrs_4thru10_pct
# 621                     st_advance_dgr_pct
# 622                 st_emer_prov_teach_pct
# 623                   st_lateral_teach_pct
# 624                          category_cd_E
# 625                          Category_Cd_E
# 626                 st_long_susp_per_c_num
# 627                 st_flicensed_teach_pct
# 628                     st_advance_dgr_pct
# 629                 st_1yr_tchr_trnovr_pct
# 630                 st_emer_prov_teach_pct
# 631                   st_lateral_teach_pct
# 632                          category_cd_E
# 633                          category_cd_I
# 634                          Category_Cd_E
# 635                          Category_Cd_I
# 636                 st_flicensed_teach_pct
# 637                      lateral_teach_pct
# 638                  0-3 Years_Exp_Pct_Tch
# 639                 4-10 Years_Exp_Pct_Tch
# 640                  10+ Years_Exp_Pct_Tch
# 641                  lea_lateral_teach_pct
# 642                  st_tchyrs_4thru10_pct
# 643                   st_lateral_teach_pct
# 644                           st_nbpts_num
# 645                     st_advance_dgr_pct
# 646                 st_emer_prov_teach_pct
# 647                   st_lateral_teach_pct
# 648                          category_cd_E
# 649                          Category_Cd_E
# 650                           st_nbpts_num
# 651                 st_1yr_tchr_trnovr_pct
# 652                 st_emer_prov_teach_pct
# 653                   st_lateral_teach_pct
# 654                          category_cd_E
# 655                          category_cd_I
# 656                          Category_Cd_E
# 657                          Category_Cd_I
# 658                          category_cd_I
# 659                          Category_Cd_I
# 660                   st_lateral_teach_pct
# 661                          category_cd_E
# 662                          Category_Cd_E
# 663                          category_cd_E
# 664                          Category_Cd_E
# 665    Not Demostrated_TCHR_Standard 3_Pct
# 666    Not Demostrated_TCHR_Standard 5_Pct
# 667    Not Demostrated_TCHR_Standard 5_Pct
# 668                           AsianMalePct
# 669                               AsianPct
# 670                               AsianPct
# 671                           BlackMalePct
# 672                               BlackPct
# 673                               BlackPct
# 674                        HispanicMalePct
# 675                            HispanicPct
# 676                            HispanicPct
# 677                          IndianMalePct
# 678                              IndianPct
# 679                              IndianPct
# 680                        MinorityMalePct
# 681                            MinorityPct
# 682                         WhiteFemalePct
# 683                           WhiteMalePct
# 684                               WhitePct
# 685                            MinorityPct
# 686                         WhiteFemalePct
# 687                           WhiteMalePct
# 688                               WhitePct
# 689                         WhiteFemalePct
# 690                           WhiteMalePct
# 691                               WhitePct
# 692                           WhiteMalePct
# 693                               WhitePct
# 694                               WhitePct
# 695                          Category_Cd_E
# 696                          Category_Cd_I
# 697                      sna_pgm_type_cd_Y
# 698  calendar_only_txt_Year-Round Calendar
# 699  calendar_only_txt_Year-Round Calendar
# 700                   State Gap Compared_Y
#
#                                                 Field2  Correlation
# 0                                  lea_avg_student_num     0.965360
# 1                                   st_avg_student_num     0.965338
# 2                                   st_avg_student_num     0.986832
# 3                                   st_avg_student_num     0.999492
# 4                                            SPG Score     0.957693
# 5                                            SPG Score     0.960318
# 6                                            SPG Score     0.987480
# 7                                            SPG Score     0.950276
# 8                                            SPG Score     0.959578
# 9                                            SPG Score     0.986810
# 10                                           SPG Score     0.950429
# 11                                           SPG Score     0.970857
# 12                                           SPG Score     0.974568
# 13                                           SPG Score     0.958936
# 14                                           SPG Score     0.972743
# 15                                           SPG Score     0.957845
# 16                                   Reading SPG Score     0.955696
# 17                                   Reading SPG Score     0.988735
# 18                                   Reading SPG Score     0.961952
# 19                                   Reading SPG Score     0.988752
# 20                                   Reading SPG Score     0.953698
# 21                                   Reading SPG Score     0.976506
# 22                                   Reading SPG Score     0.973388
# 23                                   Reading SPG Score     0.963534
# 24                                   Reading SPG Score     0.951052
# 25                                   Reading SPG Score     0.969792
# 26                                   Reading SPG Score     0.964342
# 27                                      Math SPG Score     0.985489
# 28                                      Math SPG Score     0.955464
# 29                                      Math SPG Score     0.961647
# 30                                      Math SPG Score     0.985600
# 31                                      Math SPG Score     0.970666
# 32                                      Math SPG Score     0.968919
# 33                                      Math SPG Score     0.958679
# 34                                      Math SPG Score     0.969621
# 35                                      Math SPG Score     0.957646
# 36                           Overall Achievement Score     0.963291
# 37                           Overall Achievement Score     0.962842
# 38                           Overall Achievement Score     0.983279
# 39                           Overall Achievement Score     0.999179
# 40                           Overall Achievement Score     0.955607
# 41                           Overall Achievement Score     0.962986
# 42                           Overall Achievement Score     0.963229
# 43                           Overall Achievement Score     0.971437
# 44                           Overall Achievement Score     0.982716
# 45                           Overall Achievement Score     0.967877
# 46                           Overall Achievement Score     0.985512
# 47                           Overall Achievement Score     0.956176
# 48                           Overall Achievement Score     0.969250
# 49                           Overall Achievement Score     0.969860
# 50                           Overall Achievement Score     0.986164
# 51                           Overall Achievement Score     0.958825
# 52                           Overall Achievement Score     0.970856
# 53                                       Reading Score     0.959421
# 54                                       Reading Score     0.968834
# 55                                       Reading Score     0.974619
# 56                                       Reading Score     0.999875
# 57                                       Reading Score     0.969819
# 58                                       Reading Score     0.979238
# 59                                       Reading Score     0.952788
# 60                                       Reading Score     0.954473
# 61                                       Reading Score     0.981918
# 62                                       Reading Score     0.955113
# 63                                       Reading Score     0.965100
# 64                                       Reading Score     0.958494
# 65                                       Reading Score     0.956344
# 66                                       Reading Score     0.982960
# 67                                       Reading Score     0.956651
# 68                                       Reading Score     0.968028
# 69                                          Math Score     0.951653
# 70                                          Math Score     0.968249
# 71                                          Math Score     0.984781
# 72                                          Math Score     0.999888
# 73                                          Math Score     0.963005
# 74                                          Math Score     0.979609
# 75                                          Math Score     0.953576
# 76                                          Math Score     0.966586
# 77                                          Math Score     0.982369
# 78                                          Math Score     0.966738
# 79                                          Math Score     0.956817
# 80                                          Math Score     0.967487
# 81                                          Math Score     0.984154
# 82                                          Math Score     0.950943
# 83                                          Math Score     0.967362
# 84                                       Science Score     0.958807
# 85                                       Science Score     0.954794
# 86                                       Science Score     0.976975
# 87                                       Science Score     0.970797
# 88                                       Science Score     0.994524
# 89                            EOG/EOCSubjects_CACR_All     0.984291
# 90                            EOG/EOCSubjects_CACR_All     0.969797
# 91                            EOG/EOCSubjects_CACR_All     0.951834
# 92                            EOG/EOCSubjects_CACR_All     0.967814
# 93                            EOG/EOCSubjects_CACR_All     0.959391
# 94                            EOG/EOCSubjects_CACR_All     0.991850
# 95                            EOG/EOCSubjects_CACR_All     0.972908
# 96                            EOG/EOCSubjects_CACR_All     0.984863
# 97                            EOG/EOCSubjects_CACR_All     0.969663
# 98                            EOG/EOCSubjects_CACR_All     0.952567
# 99                            EOG/EOCSubjects_CACR_All     0.977276
# 100                           EOG/EOCSubjects_CACR_All     0.958738
# 101                           EOG/EOCSubjects_CACR_All     0.985909
# 102                           EOG/EOCSubjects_CACR_All     0.972595
# 103                           EOG/EOCSubjects_CACR_All     0.952190
# 104                           EOG/EOCSubjects_CACR_All     0.950913
# 105                           EOG/EOCSubjects_CACR_All     0.978154
# 106                           EOG/EOCSubjects_CACR_All     0.961967
# 107                            EOG/EOCSubjects_GLP_All     0.960499
# 108                            EOG/EOCSubjects_GLP_All     0.968379
# 109                            EOG/EOCSubjects_GLP_All     0.968759
# 110                            EOG/EOCSubjects_GLP_All     0.976429
# 111                            EOG/EOCSubjects_GLP_All     0.988431
# 112                            EOG/EOCSubjects_GLP_All     0.968612
# 113                            EOG/EOCSubjects_GLP_All     0.985992
# 114                            EOG/EOCSubjects_GLP_All     0.951261
# 115                            EOG/EOCSubjects_GLP_All     0.950861
# 116                            EOG/EOCSubjects_GLP_All     0.961263
# 117                            EOG/EOCSubjects_GLP_All     0.974895
# 118                            EOG/EOCSubjects_GLP_All     0.971069
# 119                            EOG/EOCSubjects_GLP_All     0.987222
# 120                            EOG/EOCSubjects_GLP_All     0.953457
# 121                            EOG/EOCSubjects_GLP_All     0.953029
# 122                            EOG/EOCSubjects_GLP_All     0.963588
# 123                            EOG/EOCSubjects_GLP_All     0.976447
# 124                                    EOGGr3_CACR_All     0.976466
# 125                                    EOGGr3_CACR_All     0.969881
# 126                                    EOGGr3_CACR_All     0.964311
# 127                                    EOGGr3_CACR_All     0.951155
# 128                                    EOGGr3_CACR_All     0.953925
# 129                                    EOGGr3_CACR_All     0.955953
# 130                                     EOGGr3_GLP_All     0.952009
# 131                                     EOGGr3_GLP_All     0.968587
# 132                                     EOGGr3_GLP_All     0.965557
# 133                                     EOGGr3_GLP_All     0.950521
# 134                                     EOGGr3_GLP_All     0.955029
# 135                                    EOGGr4_CACR_All     0.978935
# 136                                    EOGGr4_CACR_All     0.971406
# 137                                    EOGGr4_CACR_All     0.956305
# 138                                    EOGGr4_CACR_All     0.964316
# 139                                    EOGGr4_CACR_All     0.957114
# 140                                     EOGGr4_GLP_All     0.957470
# 141                                     EOGGr4_GLP_All     0.972932
# 142                                     EOGGr4_GLP_All     0.969241
# 143                                     EOGGr4_GLP_All     0.956144
# 144                                    EOGGr5_CACR_All     0.984786
# 145                                    EOGGr5_CACR_All     0.961319
# 146                                    EOGGr5_CACR_All     0.955584
# 147                                    EOGGr5_CACR_All     0.951148
# 148                                    EOGGr5_CACR_All     0.952050
# 149                                    EOGGr5_CACR_All     0.971414
# 150                                    EOGGr5_CACR_All     0.960322
# 151                                    EOGGr5_CACR_All     0.969405
# 152                                    EOGGr5_CACR_All     0.958455
# 153                                     EOGGr5_GLP_All     0.964123
# 154                                     EOGGr5_GLP_All     0.960057
# 155                                     EOGGr5_GLP_All     0.958938
# 156                                     EOGGr5_GLP_All     0.951902
# 157                                     EOGGr5_GLP_All     0.954208
# 158                                     EOGGr5_GLP_All     0.974529
# 159                                     EOGGr5_GLP_All     0.957557
# 160                                     EOGGr5_GLP_All     0.974569
# 161                                EOGMathGr3_CACR_All     0.967224
# 162                              EOGMathGr3-8_CACR_All     0.984896
# 163                              EOGMathGr3-8_CACR_All     0.978231
# 164                              EOGMathGr3-8_CACR_All     0.968794
# 165                              EOGMathGr3-8_CACR_All     0.952361
# 166                              EOGMathGr3-8_CACR_All     0.980907
# 167                              EOGMathGr3-8_CACR_All     0.965618
# 168                              EOGMathGr3-8_CACR_All     0.962740
# 169                              EOGMathGr3-8_CACR_All     0.954603
# 170                              EOGMathGr3-8_CACR_All     0.958643
# 171                              EOGMathGr3-8_CACR_All     0.950461
# 172                              EOGMathGr3-8_CACR_All     0.982857
# 173                              EOGMathGr3-8_CACR_All     0.971285
# 174                              EOGMathGr3-8_CACR_All     0.965901
# 175                              EOGMathGr3-8_CACR_All     0.958099
# 176                               EOGMathGr3-8_GLP_All     0.963178
# 177                               EOGMathGr3-8_GLP_All     0.979722
# 178                               EOGMathGr3-8_GLP_All     0.953699
# 179                               EOGMathGr3-8_GLP_All     0.966689
# 180                               EOGMathGr3-8_GLP_All     0.982487
# 181                               EOGMathGr3-8_GLP_All     0.966849
# 182                               EOGMathGr3-8_GLP_All     0.956938
# 183                               EOGMathGr3-8_GLP_All     0.967616
# 184                               EOGMathGr3-8_GLP_All     0.984257
# 185                               EOGMathGr3-8_GLP_All     0.951088
# 186                               EOGMathGr3-8_GLP_All     0.967463
# 187                                EOGMathGr4_CACR_All     0.981581
# 188                                EOGMathGr5_CACR_All     0.986711
# 189                                 EOGMathGr5_GLP_All     0.951297
# 190                             EOGReadingGr3_CACR_All     0.966993
# 191                              EOGReadingGr3_GLP_All     0.955510
# 192                           EOGReadingGr3-8_CACR_All     0.974796
# 193                           EOGReadingGr3-8_CACR_All     0.974442
# 194                           EOGReadingGr3-8_CACR_All     0.952969
# 195                           EOGReadingGr3-8_CACR_All     0.979710
# 196                           EOGReadingGr3-8_CACR_All     0.956052
# 197                           EOGReadingGr3-8_CACR_All     0.961403
# 198                           EOGReadingGr3-8_CACR_All     0.954169
# 199                           EOGReadingGr3-8_CACR_All     0.980728
# 200                           EOGReadingGr3-8_CACR_All     0.959316
# 201                           EOGReadingGr3-8_CACR_All     0.959747
# 202                            EOGReadingGr3-8_GLP_All     0.969771
# 203                            EOGReadingGr3-8_GLP_All     0.979148
# 204                            EOGReadingGr3-8_GLP_All     0.952559
# 205                            EOGReadingGr3-8_GLP_All     0.954490
# 206                            EOGReadingGr3-8_GLP_All     0.981862
# 207                            EOGReadingGr3-8_GLP_All     0.954900
# 208                            EOGReadingGr3-8_GLP_All     0.964854
# 209                            EOGReadingGr3-8_GLP_All     0.958585
# 210                            EOGReadingGr3-8_GLP_All     0.956677
# 211                            EOGReadingGr3-8_GLP_All     0.983256
# 212                            EOGReadingGr3-8_GLP_All     0.956773
# 213                            EOGReadingGr3-8_GLP_All     0.968103
# 214                             EOGReadingGr4_CACR_All     0.957611
# 215                             EOGReadingGr5_CACR_All     0.962046
# 216                             EOGScienceGr5_CACR_All     0.975640
# 217                             EOGScienceGr5_CACR_All     0.983731
# 218                             EOGScienceGr5_CACR_All     0.959173
# 219                              EOGScienceGr5_GLP_All     0.958759
# 220                              EOGScienceGr5_GLP_All     0.982189
# 221                           EOGScienceGr5&8_CACR_All     0.975424
# ...
# 473                      EOGMathGr5_GLP_TwoorMoreRaces     0.951967
# 474                  EOGReadingGr3_CACR_TwoorMoreRaces     0.975851
# 475                EOGReadingGr3-8_CACR_TwoorMoreRaces     0.968188
# 476                  EOGReadingGr4_CACR_TwoorMoreRaces     0.970250
# 477                  EOGReadingGr5_CACR_TwoorMoreRaces     0.983351
# 478                  EOGReadingGr5_CACR_TwoorMoreRaces     0.957829
# 479                  EOGReadingGr5_CACR_TwoorMoreRaces     0.959453
# 480                  EOGReadingGr5_CACR_TwoorMoreRaces     0.950831
# 481                   EOGReadingGr5_GLP_TwoorMoreRaces     0.964259
# 482                   EOGReadingGr5_GLP_TwoorMoreRaces     0.975703
# 483                   EOGReadingGr5_GLP_TwoorMoreRaces     0.956611
# 484                   EOGReadingGr5_GLP_TwoorMoreRaces     0.962646
# 485                  EOGScienceGr5_CACR_TwoorMoreRaces     0.988880
# 486                  EOGScienceGr5_CACR_TwoorMoreRaces     0.992899
# 487                  EOGScienceGr5_CACR_TwoorMoreRaces     0.976539
# 488                   EOGScienceGr5_GLP_TwoorMoreRaces     0.982166
# 489                   EOGScienceGr5_GLP_TwoorMoreRaces     0.987799
# 490                EOGScienceGr5&8_CACR_TwoorMoreRaces     0.988384
# 491                    EOGSubjects_CACR_TwoorMoreRaces     0.965412
# 492                         EOG/EOCSubjects_CACR_White     0.977329
# 493                         EOG/EOCSubjects_CACR_White     0.992552
# 494                         EOG/EOCSubjects_CACR_White     0.968057
# 495                          EOG/EOCSubjects_GLP_White     0.969907
# 496                          EOG/EOCSubjects_GLP_White     0.990143
# 497                                  EOGGr3_CACR_White     0.978323
# 498                                  EOGGr4_CACR_White     0.977285
# 499                                  EOGGr5_CACR_White     0.985323
# 500                              EOGMathGr3_CACR_White     0.978954
# 501                               EOGMathGr3_GLP_White     0.954333
# 502                            EOGMathGr3-8_CACR_White     0.983295
# 503                             EOGMathGr3-8_GLP_White     0.953212
# 504                              EOGMathGr4_CACR_White     0.984904
# 505                               EOGMathGr4_GLP_White     0.960113
# 506                              EOGMathGr5_CACR_White     0.990325
# 507                              EOGMathGr5_CACR_White     0.952038
# 508                               EOGMathGr5_GLP_White     0.962046
# 509                               EOGMathGr5_GLP_White     0.956287
# 510                               EOGMathGr5_GLP_White     0.961443
# 511                           EOGReadingGr3_CACR_White     0.976755
# 512                         EOGReadingGr3-8_CACR_White     0.969778
# 513                           EOGReadingGr4_CACR_White     0.966245
# 514                           EOGReadingGr5_CACR_White     0.972176
# 515                            EOGReadingGr5_GLP_White     0.953761
# 516                            EOGReadingGr5_GLP_White     0.961536
# 517                           EOGScienceGr5_CACR_White     0.983631
# 518                           EOGScienceGr5_CACR_White     0.984701
# 519                           EOGScienceGr5_CACR_White     0.967166
# 520                            EOGScienceGr5_GLP_White     0.969363
# 521                            EOGScienceGr5_GLP_White     0.983604
# 522                         EOGScienceGr5&8_CACR_White     0.983772
# 523                             EOGSubjects_CACR_White     0.977735
# 524                           EOG/EOCSubjects_CACR_EDS     0.976559
# 525                           EOG/EOCSubjects_CACR_EDS     0.991265
# 526                           EOG/EOCSubjects_CACR_EDS     0.965261
# 527                            EOG/EOCSubjects_GLP_EDS     0.968192
# 528                            EOG/EOCSubjects_GLP_EDS     0.988377
# 529                                    EOGGr3_CACR_EDS     0.957299
# 530                                    EOGGr4_CACR_EDS     0.960573
# 531                                    EOGGr5_CACR_EDS     0.976730
# 532                              EOGMathGr3-8_CACR_EDS     0.974509
# 533                                EOGMathGr4_CACR_EDS     0.966540
# 534                                EOGMathGr5_CACR_EDS     0.976038
# 535                           EOGReadingGr3-8_CACR_EDS     0.953747
# 536                             EOGScienceGr5_CACR_EDS     0.963076
# 537                             EOGScienceGr5_CACR_EDS     0.963771
# 538                              EOGScienceGr5_GLP_EDS     0.962709
# 539                           EOGScienceGr5&8_CACR_EDS     0.961407
# 540                               EOGSubjects_CACR_EDS     0.976901
# 541                           EOG/EOCSubjects_CACR_LEP     0.999917
# 542                            EOG/EOCSubjects_GLP_LEP     0.999988
# 543                                    EOGGr3_CACR_LEP     0.953692
# 544                                    EOGGr5_CACR_LEP     0.956158
# 545                                EOGMathGr3_CACR_LEP     0.968384
# 546                              EOGMathGr3-8_CACR_LEP     0.964153
# 547                                EOGMathGr4_CACR_LEP     0.958092
# 548                                EOGMathGr5_CACR_LEP     0.967954
# 549                             EOGScienceGr5_CACR_LEP     0.953613
# 550                              EOGScienceGr5_GLP_LEP     0.953575
# 551                           EOG/EOCSubjects_CACR_SWD     0.954566
# 552                           EOG/EOCSubjects_CACR_SWD     0.999203
# 553                           EOG/EOCSubjects_CACR_SWD     0.953684
# 554                            EOG/EOCSubjects_GLP_SWD     0.954000
# 555                            EOG/EOCSubjects_GLP_SWD     0.998700
# 556                                EOGMathGr4_CACR_SWD     0.953109
# 557                             EOGScienceGr5_CACR_SWD     0.969343
# 558                              EOGScienceGr5_GLP_SWD     0.962106
# 559                               EOGSubjects_CACR_SWD     0.954825
# 560                           EOG/EOCSubjects_CACR_AIG     0.989276
# 561                           EOG/EOCSubjects_CACR_AIG     0.990417
# 562                           EOG/EOCSubjects_CACR_AIG     0.979585
# 563                            EOG/EOCSubjects_GLP_AIG     0.979862
# 564                            EOG/EOCSubjects_GLP_AIG     0.990205
# 565                                    EOGGr3_CACR_AIG     0.999044
# 566                                    EOGGr4_CACR_AIG     0.995726
# 567                                    EOGGr5_CACR_AIG     0.993853
# 568                                EOGMathGr3_CACR_AIG     0.999370
# 569                                EOGMathGr3_CACR_AIG     0.997820
# 570                                EOGMathGr3_CACR_AIG     0.998708
# 571                                 EOGMathGr3_GLP_AIG     0.998059
# 572                                 EOGMathGr3_GLP_AIG     0.999285
# 573                              EOGMathGr3-8_CACR_AIG     0.997494
# 574                              EOGMathGr3-8_CACR_AIG     0.985713
# 575                              EOGMathGr3-8_CACR_AIG     0.992702
# 576                               EOGMathGr3-8_GLP_AIG     0.986252
# 577                               EOGMathGr3-8_GLP_AIG     0.995338
# 578                                EOGMathGr4_CACR_AIG     0.998807
# 579                                EOGMathGr4_CACR_AIG     0.993860
# 580                                EOGMathGr4_CACR_AIG     0.997471
# 581                                 EOGMathGr4_GLP_AIG     0.993890
# 582                                 EOGMathGr4_GLP_AIG     0.998510
# 583                                EOGMathGr5_CACR_AIG     0.999083
# 584                                EOGMathGr5_CACR_AIG     0.990490
# 585                                EOGMathGr5_CACR_AIG     0.996655
# 586                                EOGMathGr5_CACR_AIG     0.996338
# 587                                EOGMathGr5_CACR_AIG     0.997268
# 588                                EOGMathGr5_CACR_AIG     0.957004
# 589                                EOGMathGr5_CACR_AIG     0.958471
# 590                                 EOGMathGr5_GLP_AIG     0.990321
# 591                                 EOGMathGr5_GLP_AIG     0.997182
# 592                                 EOGMathGr5_GLP_AIG     0.996624
# 593                                 EOGMathGr5_GLP_AIG     0.998202
# 594                                 EOGMathGr5_GLP_AIG     0.957323
# 595                                 EOGMathGr5_GLP_AIG     0.959377
# 596                             EOGReadingGr3_CACR_AIG     0.999022
# 597                           EOGReadingGr3-8_CACR_AIG     0.991574
# 598                             EOGReadingGr4_CACR_AIG     0.995773
# 599                             EOGReadingGr5_CACR_AIG     0.994218
# 600                             EOGReadingGr5_CACR_AIG     0.991410
# 601                             EOGReadingGr5_CACR_AIG     0.990895
# 602                             EOGReadingGr5_CACR_AIG     0.952515
# 603                             EOGReadingGr5_CACR_AIG     0.952445
# 604                              EOGReadingGr5_GLP_AIG     0.996735
# 605                              EOGReadingGr5_GLP_AIG     0.997922
# 606                              EOGReadingGr5_GLP_AIG     0.957484
# 607                              EOGReadingGr5_GLP_AIG     0.959137
# 608                             EOGScienceGr5_CACR_AIG     0.998124
# 609                             EOGScienceGr5_CACR_AIG     0.960638
# 610                             EOGScienceGr5_CACR_AIG     0.959347
# 611                              EOGScienceGr5_GLP_AIG     0.958790
# 612                              EOGScienceGr5_GLP_AIG     0.961122
# 613                           EOGScienceGr5&8_CACR_AIG     0.998159
# 614                               EOGSubjects_CACR_AIG     0.989462
# 615                           MathGr3-8_pTarget_PctMet     0.998393
# 616                           MathGr3-8_pTarget_PctMet     0.960280
# 617                        ReadingGr3-8_pTarget_PctMet     0.960296
# 618                        TotalTargets_pTarget_PctMet     0.983930
# 619                            st_avg_daily_attend_pct     0.970420
# 620                            st_avg_daily_attend_pct     0.990094
# 621                            st_avg_daily_attend_pct     0.987355
# 622                            st_avg_daily_attend_pct     0.999058
# 623                            st_avg_daily_attend_pct     0.999042
# 624                            st_avg_daily_attend_pct     0.999058
# 625                            st_avg_daily_attend_pct     0.999058
# 626                                 st_crime_per_c_num     0.998816
# 627                                 st_crime_per_c_num     0.957170
# 628                            st_short_susp_per_c_num     0.996421
# 629                            st_short_susp_per_c_num     0.989327
# 630                            st_short_susp_per_c_num     0.979983
# 631                            st_short_susp_per_c_num     0.958922
# 632                            st_short_susp_per_c_num     0.979983
# 633                            st_short_susp_per_c_num     0.991659
# 634                            st_short_susp_per_c_num     0.979983
# 635                            st_short_susp_per_c_num     0.991659
# 636                             st_long_susp_per_c_num     0.970122
# 637                                flicensed_teach_pct     0.954045
# 638                                  tchyrs_0thru3_pct     1.000000
# 639                                 tchyrs_4thru10_pct     1.000000
# 640                                  tchyrs_11plus_pct     1.000000
# 641                            lea_flicensed_teach_pct     0.974174
# 642                             st_flicensed_teach_pct     0.981915
# 643                             st_flicensed_teach_pct     0.958941
# 644                               st_tchyrs_0thru3_pct     0.973164
# 645                              st_tchyrs_4thru10_pct     0.955316
# 646                              st_tchyrs_4thru10_pct     0.983068
# 647                              st_tchyrs_4thru10_pct     0.995291
# 648                              st_tchyrs_4thru10_pct     0.983068
# 649                              st_tchyrs_4thru10_pct     0.983068
# 650                                 st_class_teach_num     0.981176
# 651                                 st_advance_dgr_pct     0.973469
# 652                                 st_advance_dgr_pct     0.993304
# 653                                 st_advance_dgr_pct     0.979469
# 654                                 st_advance_dgr_pct     0.993304
# 655                                 st_advance_dgr_pct     0.977215
# 656                                 st_advance_dgr_pct     0.993304
# 657                                 st_advance_dgr_pct     0.977215
# 658                             st_1yr_tchr_trnovr_pct     0.999856
# 659                             st_1yr_tchr_trnovr_pct     0.999856
# 660                             st_emer_prov_teach_pct     0.996201
# 661                             st_emer_prov_teach_pct     1.000000
# 662                             st_emer_prov_teach_pct     1.000000
# 663                               st_lateral_teach_pct     0.996201
# 664                               st_lateral_teach_pct     0.996201
# 665                Not Demostrated_TCHR_Standard 2_Pct     0.986209
# 666                Not Demostrated_TCHR_Standard 2_Pct     0.967922
# 667                Not Demostrated_TCHR_Standard 3_Pct     0.954566
# 668                                     AsianFemalePct     0.957970
# 669                                     AsianFemalePct     0.988770
# 670                                       AsianMalePct     0.990084
# 671                                     BlackFemalePct     0.975414
# 672                                     BlackFemalePct     0.993464
# 673                                       BlackMalePct     0.994194
# 674                                  HispanicFemalePct     0.955356
# 675                                  HispanicFemalePct     0.988191
# 676                                    HispanicMalePct     0.989346
# 677                                    IndianFemalePct     0.984255
# 678                                    IndianFemalePct     0.995691
# 679                                      IndianMalePct     0.996405
# 680                                  MinorityFemalePct     0.966450
# 681                                  MinorityFemalePct     0.991029
# 682                                  MinorityFemalePct     0.981283
# 683                                  MinorityFemalePct     0.981637
# 684                                  MinorityFemalePct     0.991029
# 685                                    MinorityMalePct     0.992108
# 686                                    MinorityMalePct     0.981655
# 687                                    MinorityMalePct     0.983366
# 688                                    MinorityMalePct     0.992108
# 689                                        MinorityPct     0.989803
# 690                                        MinorityPct     0.990866
# 691                                        MinorityPct     1.000000
# 692                                     WhiteFemalePct     0.961555
# 693                                     WhiteFemalePct     0.989803
# 694                                       WhiteMalePct     0.990866
# 695                                      category_cd_E     1.000000
# 696                                      category_cd_I     1.000000
# 697  calendar_type_txt_Regular School, Year-Round C...     1.000000
# 698  calendar_type_txt_Regular School, Year-Round C...     1.000000
# 699                                  sna_pgm_type_cd_Y     1.000000
# 700                                     SPG Grade_A+NG     0.964909

# %%
print 'Dropping the following ', str(len(to_drop)), ' highly correlated fields.'
to_drop
# Out:
# Dropping the following  279  highly correlated fields.
# ['Reading SPG Score',
#  'Math SPG Score',
#  'Overall Achievement Score',
#  'Reading Score',
#  'Math Score',
#  'EOG/EOCSubjects_CACR_All',
#  'EOG/EOCSubjects_GLP_All',
#  'EOGGr3_GLP_All',
#  'EOGGr4_GLP_All',
#  'EOGGr5_GLP_All',
#  'EOGMathGr3_CACR_All',
#  'EOGMathGr3_GLP_All',
#  'EOGMathGr3-8_CACR_All',
#  'EOGMathGr3-8_GLP_All',
#  'EOGMathGr4_CACR_All',
#  'EOGMathGr4_GLP_All',
#  'EOGMathGr5_CACR_All',
#  'EOGMathGr5_GLP_All',
#  'EOGReadingGr3_CACR_All',
#  'EOGReadingGr3_GLP_All',
#  'EOGReadingGr3-8_CACR_All',
#  'EOGReadingGr3-8_GLP_All',
#  'EOGReadingGr4_CACR_All',
#  'EOGReadingGr4_GLP_All',
#  'EOGReadingGr5_GLP_All',
#  'EOGScienceGr5_CACR_All',
#  'EOGScienceGr5_GLP_All',
#  'EOGScienceGr5&8_CACR_All',
#  'EOGScienceGr5&8_GLP_All',
#  'EOGSubjects_CACR_All',
#  'EOGSubjects_GLP_All',
#  'EOG/EOCSubjects_CACR_Female',
#  'EOG/EOCSubjects_GLP_Female',
#  'EOGGr3_CACR_Female',
#  'EOGGr3_GLP_Female',
#  'EOGGr4_GLP_Female',
#  'EOGGr5_CACR_Female',
#  'EOGGr5_GLP_Female',
#  'EOGMathGr3_GLP_Female',
#  'EOGMathGr3-8_CACR_Female',
#  'EOGMathGr3-8_GLP_Female',
#  'EOGMathGr4_GLP_Female',
#  'EOGMathGr5_GLP_Female',
#  'EOGReadingGr3_GLP_Female',
#  'EOGReadingGr3-8_CACR_Female',
#  'EOGReadingGr3-8_GLP_Female',
#  'EOGReadingGr5_GLP_Female',
#  'EOGScienceGr5_GLP_Female',
#  'EOGScienceGr5&8_CACR_Female',
#  'EOGScienceGr5&8_GLP_Female',
#  'EOGSubjects_CACR_Female',
#  'EOGSubjects_GLP_Female',
#  'EOG/EOCSubjects_CACR_Male',
#  'EOG/EOCSubjects_GLP_Male',
#  'EOGGr3_CACR_Male',
#  'EOGGr3_GLP_Male',
#  'EOGGr4_CACR_Male',
#  'EOGGr4_GLP_Male',
#  'EOGGr5_CACR_Male',
#  'EOGGr5_GLP_Male',
#  'EOGMathGr3_GLP_Male',
#  'EOGMathGr3-8_CACR_Male',
#  'EOGMathGr3-8_GLP_Male',
#  'EOGMathGr4_GLP_Male',
#  'EOGMathGr5_GLP_Male',
#  'EOGReadingGr3_GLP_Male',
#  'EOGReadingGr3-8_CACR_Male',
#  'EOGReadingGr3-8_GLP_Male',
#  'EOGReadingGr5_GLP_Male',
#  'EOGScienceGr5_GLP_Male',
#  'EOGScienceGr5&8_CACR_Male',
#  'EOGScienceGr5&8_GLP_Male',
#  'EOGSubjects_CACR_Male',
#  'EOGSubjects_GLP_Male',
#  'EOG/EOCSubjects_GLP_AmericanIndian',
#  'EOGGr3_GLP_AmericanIndian',
#  'EOGGr4_GLP_AmericanIndian',
#  'EOGGr5_GLP_AmericanIndian',
#  'EOGMathGr3_GLP_AmericanIndian',
#  'EOGMathGr3-8_GLP_AmericanIndian',
#  'EOGMathGr4_GLP_AmericanIndian',
#  'EOGMathGr5_GLP_AmericanIndian',
#  'EOGReadingGr3_GLP_AmericanIndian',
#  'EOGReadingGr3-8_CACR_AmericanIndian',
#  'EOGReadingGr3-8_GLP_AmericanIndian',
#  'EOGReadingGr4_GLP_AmericanIndian',
#  'EOGReadingGr5_GLP_AmericanIndian',
#  'EOGScienceGr5_GLP_AmericanIndian',
#  'EOGScienceGr5&8_CACR_AmericanIndian',
#  'EOGScienceGr5&8_GLP_AmericanIndian',
#  'EOGSubjects_CACR_AmericanIndian',
#  'EOGSubjects_GLP_AmericanIndian',
#  'EOG/EOCSubjects_GLP_Asian',
#  'EOGGr3_GLP_Asian',
#  'EOGGr4_GLP_Asian',
#  'EOGGr5_GLP_Asian',
#  'EOGMathGr3_GLP_Asian',
#  'EOGMathGr3-8_GLP_Asian',
#  'EOGMathGr4_GLP_Asian',
#  'EOGMathGr5_GLP_Asian',
#  'EOGReadingGr3_CACR_Asian',
#  'EOGReadingGr3_GLP_Asian',
#  'EOGReadingGr3-8_CACR_Asian',
#  'EOGReadingGr3-8_GLP_Asian',
#  'EOGReadingGr4_CACR_Asian',
#  'EOGReadingGr4_GLP_Asian',
#  'EOGReadingGr5_CACR_Asian',
#  'EOGReadingGr5_GLP_Asian',
#  'EOGScienceGr5_CACR_Asian',
#  'EOGScienceGr5_GLP_Asian',
#  'EOGScienceGr5&8_CACR_Asian',
#  'EOGScienceGr5&8_GLP_Asian',
#  'EOGSubjects_CACR_Asian',
#  'EOGSubjects_GLP_Asian',
#  'EOG/EOCSubjects_GLP_Black',
#  'EOGGr3_GLP_Black',
#  'EOGGr4_GLP_Black',
#  'EOGGr5_GLP_Black',
#  'EOGMathGr3_GLP_Black',
#  'EOGMathGr3-8_GLP_Black',
#  'EOGMathGr4_GLP_Black',
#  'EOGMathGr5_GLP_Black',
#  'EOGReadingGr3_GLP_Black',
#  'EOGReadingGr3-8_GLP_Black',
#  'EOGReadingGr4_GLP_Black',
#  'EOGScienceGr5_GLP_Black',
#  'EOGScienceGr5&8_CACR_Black',
#  'EOGScienceGr5&8_GLP_Black',
#  'EOGSubjects_CACR_Black',
#  'EOGSubjects_GLP_Black',
#  'EOG/EOCSubjects_GLP_Hispanic',
#  'EOGGr3_GLP_Hispanic',
#  'EOGGr4_GLP_Hispanic',
#  'EOGGr5_GLP_Hispanic',
#  'EOGMathGr3_GLP_Hispanic',
#  'EOGMathGr3-8_GLP_Hispanic',
#  'EOGMathGr4_GLP_Hispanic',
#  'EOGMathGr5_GLP_Hispanic',
#  'EOGReadingGr3_GLP_Hispanic',
#  'EOGReadingGr4_GLP_Hispanic',
#  'EOGReadingGr5_GLP_Hispanic',
#  'EOGScienceGr5_GLP_Hispanic',
#  'EOGScienceGr5&8_CACR_Hispanic',
#  'EOGScienceGr5&8_GLP_Hispanic',
#  'EOGSubjects_CACR_Hispanic',
#  'EOGSubjects_GLP_Hispanic',
#  'EOG/EOCSubjects_GLP_TwoorMoreRaces',
#  'EOGGr3_GLP_TwoorMoreRaces',
#  'EOGGr4_GLP_TwoorMoreRaces',
#  'EOGGr5_GLP_TwoorMoreRaces',
#  'EOGMathGr3_GLP_TwoorMoreRaces',
#  'EOGMathGr3-8_GLP_TwoorMoreRaces',
#  'EOGMathGr4_GLP_TwoorMoreRaces',
#  'EOGMathGr5_GLP_TwoorMoreRaces',
#  'EOGReadingGr3_CACR_TwoorMoreRaces',
#  'EOGReadingGr3_GLP_TwoorMoreRaces',
#  'EOGReadingGr3-8_GLP_TwoorMoreRaces',
#  'EOGReadingGr4_CACR_TwoorMoreRaces',
#  'EOGReadingGr4_GLP_TwoorMoreRaces',
#  'EOGReadingGr5_CACR_TwoorMoreRaces',
#  'EOGReadingGr5_GLP_TwoorMoreRaces',
#  'EOGScienceGr5_CACR_TwoorMoreRaces',
#  'EOGScienceGr5_GLP_TwoorMoreRaces',
#  'EOGScienceGr5&8_CACR_TwoorMoreRaces',
#  'EOGScienceGr5&8_GLP_TwoorMoreRaces',
#  'EOGSubjects_CACR_TwoorMoreRaces',
#  'EOGSubjects_GLP_TwoorMoreRaces',
#  'EOG/EOCSubjects_GLP_White',
#  'EOGGr3_GLP_White',
#  'EOGGr4_GLP_White',
#  'EOGGr5_GLP_White',
#  'EOGMathGr3_GLP_White',
#  'EOGMathGr3-8_GLP_White',
#  'EOGMathGr4_GLP_White',
#  'EOGMathGr5_GLP_White',
#  'EOGReadingGr3_GLP_White',
#  'EOGReadingGr3-8_GLP_White',
#  'EOGReadingGr4_GLP_White',
#  'EOGReadingGr5_GLP_White',
#  'EOGScienceGr5_CACR_White',
#  'EOGScienceGr5_GLP_White',
#  'EOGScienceGr5&8_CACR_White',
#  'EOGScienceGr5&8_GLP_White',
#  'EOGSubjects_CACR_White',
#  'EOGSubjects_GLP_White',
#  'EOG/EOCSubjects_GLP_EDS',
#  'EOGGr3_GLP_EDS',
#  'EOGGr4_GLP_EDS',
#  'EOGGr5_GLP_EDS',
#  'EOGMathGr3-8_GLP_EDS',
#  'EOGMathGr4_GLP_EDS',
#  'EOGMathGr5_GLP_EDS',
#  'EOGReadingGr3-8_GLP_EDS',
#  'EOGScienceGr5_GLP_EDS',
#  'EOGScienceGr5&8_CACR_EDS',
#  'EOGScienceGr5&8_GLP_EDS',
#  'EOGSubjects_CACR_EDS',
#  'EOGSubjects_GLP_EDS',
#  'EOGGr3_GLP_LEP',
#  'EOGGr5_GLP_LEP',
#  'EOGMathGr3_GLP_LEP',
#  'EOGMathGr3-8_GLP_LEP',
#  'EOGMathGr4_GLP_LEP',
#  'EOGMathGr5_GLP_LEP',
#  'EOGScienceGr5&8_CACR_LEP',
#  'EOGScienceGr5&8_GLP_LEP',
#  'EOGSubjects_CACR_LEP',
#  'EOGSubjects_GLP_LEP',
#  'EOG/EOCSubjects_GLP_SWD',
#  'EOGMathGr4_GLP_SWD',
#  'EOGScienceGr5&8_CACR_SWD',
#  'EOGScienceGr5&8_GLP_SWD',
#  'EOGSubjects_CACR_SWD',
#  'EOGSubjects_GLP_SWD',
#  'EOG/EOCSubjects_GLP_AIG',
#  'EOGGr3_GLP_AIG',
#  'EOGGr4_GLP_AIG',
#  'EOGGr5_GLP_AIG',
#  'EOGMathGr3_GLP_AIG',
#  'EOGMathGr3-8_GLP_AIG',
#  'EOGMathGr4_GLP_AIG',
#  'EOGMathGr5_GLP_AIG',
#  'EOGReadingGr3_CACR_AIG',
#  'EOGReadingGr3_GLP_AIG',
#  'EOGReadingGr3-8_CACR_AIG',
#  'EOGReadingGr3-8_GLP_AIG',
#  'EOGReadingGr4_CACR_AIG',
#  'EOGReadingGr4_GLP_AIG',
#  'EOGReadingGr5_CACR_AIG',
#  'EOGReadingGr5_GLP_AIG',
#  'EOGScienceGr5_CACR_AIG',
#  'EOGScienceGr5_GLP_AIG',
#  'EOGScienceGr5&8_CACR_AIG',
#  'EOGScienceGr5&8_GLP_AIG',
#  'EOGSubjects_CACR_AIG',
#  'EOGSubjects_GLP_AIG',
#  'pct_PASSED_EOG',
#  'ReadingGr3-8_pTarget_PctMet',
#  'TotalTargets_pTarget_PctMet',
#  'st_short_susp_per_c_num',
#  'st_long_susp_per_c_num',
#  'lateral_teach_pct',
#  'lea_class_teach_num',
#  'lea_lateral_teach_pct',
#  'st_flicensed_teach_pct',
#  'st_tchyrs_0thru3_pct',
#  'st_tchyrs_4thru10_pct',
#  'st_class_teach_num',
#  'st_nbpts_num',
#  'st_advance_dgr_pct',
#  'st_1yr_tchr_trnovr_pct',
#  'st_emer_prov_teach_pct',
#  'st_lateral_teach_pct',
#  '0-3 Years_Exp_Pct_Tch',
#  '10+ Years_Exp_Pct_Tch',
#  '4-10 Years_Exp_Pct_Tch',
#  'Not Demostrated_TCHR_Standard 3_Pct',
#  'Not Demostrated_TCHR_Standard 5_Pct',
#  'AsianMalePct',
#  'AsianPct',
#  'BlackMalePct',
#  'BlackPct',
#  'HispanicMalePct',
#  'HispanicPct',
#  'IndianMalePct',
#  'IndianPct',
#  'MinorityMalePct',
#  'MinorityPct',
#  'WhiteFemalePct',
#  'WhiteMalePct',
#  'WhitePct',
#  'category_cd_E',
#  'category_cd_I',
#  'sna_pgm_type_cd_Y',
#  'calendar_only_txt_Year-Round Calendar',
#  'SPG Grade_I',
#  'State Gap Compared_Y',
#  'Category_Cd_E',
#  'Category_Cd_I']

# %%
#Check columns before drop 
print('\r\n*********Before: Dropping Highly Correlated Fields*************************************')
schoolData.info(verbose=False)

# Drop the highly correlated features from our training data 
schoolData = schoolData.drop(to_drop, axis=1)

#Check columns after drop 
print('\r\n*********After: Dropping Highly Correlated Fields**************************************')
schoolData.info(verbose=False)
# Out:
# *********Before: Dropping Highly Correlated Fields*************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1268 entries, 0 to 1267
# Columns: 589 entries, student_num to SRC_Grades_Devices_Sent_Home_PK
# dtypes: float64(540), uint8(49)
# memory usage: 5.3 MB
#
# *********After: Dropping Highly Correlated Fields**************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1268 entries, 0 to 1267
# Columns: 310 entries, student_num to SRC_Grades_Devices_Sent_Home_PK
# dtypes: float64(269), uint8(41)
# memory usage: 2.7 MB

# %%
#Restore the unit_code before saving
schoolData['unit_code'] = unit_code
#Save the final dataset to a .csv file
schoolData.to_csv(outputDir + inputFileName + '_ML.csv', sep=',', index=False)

# %%
print('*********FINAL DATASET DETAILS*********************************************************\r\n')
schoolData.info(verbose=True)
# Out:
# *********FINAL DATASET DETAILS*********************************************************
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1268 entries, 0 to 1267
# Data columns (total 311 columns):
# student_num                                              float64
# lea_avg_student_num                                      float64
# st_avg_student_num                                       float64
# 00_Size                                                  float64
# 01_Size                                                  float64
# 02_Size                                                  float64
# 03_Size                                                  float64
# 04_Size                                                  float64
# 05_Size                                                  float64
# lea_total_expense_num                                    float64
# lea_salary_expense_pct                                   float64
# lea_services_expense_pct                                 float64
# lea_supplies_expense_pct                                 float64
# lea_instruct_equip_exp_pct                               float64
# lea_federal_perpupil_num                                 float64
# lea_local_perpupil_num                                   float64
# lea_state_perpupil_num                                   float64
# SPG Score                                                float64
# EVAAS Growth Score                                       float64
# Science Score                                            float64
# EOGGr3_CACR_All                                          float64
# EOGGr4_CACR_All                                          float64
# EOGGr5_CACR_All                                          float64
# EOGReadingGr5_CACR_All                                   float64
# EOGGr4_CACR_Female                                       float64
# EOGMathGr3_CACR_Female                                   float64
# EOGMathGr4_CACR_Female                                   float64
# EOGMathGr5_CACR_Female                                   float64
# EOGReadingGr3_CACR_Female                                float64
# EOGReadingGr4_CACR_Female                                float64
# EOGReadingGr4_GLP_Female                                 float64
# EOGReadingGr5_CACR_Female                                float64
# EOGScienceGr5_CACR_Female                                float64
# EOGMathGr3_CACR_Male                                     float64
# EOGMathGr4_CACR_Male                                     float64
# EOGMathGr5_CACR_Male                                     float64
# EOGReadingGr3_CACR_Male                                  float64
# EOGReadingGr4_CACR_Male                                  float64
# EOGReadingGr4_GLP_Male                                   float64
# EOGReadingGr5_CACR_Male                                  float64
# EOGScienceGr5_CACR_Male                                  float64
# EOG/EOCSubjects_CACR_AmericanIndian                      float64
# EOGGr3_CACR_AmericanIndian                               float64
# EOGGr4_CACR_AmericanIndian                               float64
# EOGGr5_CACR_AmericanIndian                               float64
# EOGMathGr3_CACR_AmericanIndian                           float64
# EOGMathGr3-8_CACR_AmericanIndian                         float64
# EOGMathGr4_CACR_AmericanIndian                           float64
# EOGMathGr5_CACR_AmericanIndian                           float64
# EOGReadingGr3_CACR_AmericanIndian                        float64
# EOGReadingGr4_CACR_AmericanIndian                        float64
# EOGReadingGr5_CACR_AmericanIndian                        float64
# EOGScienceGr5_CACR_AmericanIndian                        float64
# EOG/EOCSubjects_CACR_Asian                               float64
# EOGGr3_CACR_Asian                                        float64
# EOGGr4_CACR_Asian                                        float64
# EOGGr5_CACR_Asian                                        float64
# EOGMathGr3_CACR_Asian                                    float64
# EOGMathGr3-8_CACR_Asian                                  float64
# EOGMathGr4_CACR_Asian                                    float64
# EOGMathGr5_CACR_Asian                                    float64
# EOG/EOCSubjects_CACR_Black                               float64
# EOGGr3_CACR_Black                                        float64
# EOGGr4_CACR_Black                                        float64
# EOGGr5_CACR_Black                                        float64
# EOGMathGr3_CACR_Black                                    float64
# EOGMathGr3-8_CACR_Black                                  float64
# EOGMathGr4_CACR_Black                                    float64
# EOGMathGr5_CACR_Black                                    float64
# EOGReadingGr3_CACR_Black                                 float64
# EOGReadingGr3-8_CACR_Black                               float64
# EOGReadingGr4_CACR_Black                                 float64
# EOGReadingGr5_CACR_Black                                 float64
# EOGReadingGr5_GLP_Black                                  float64
# EOGScienceGr5_CACR_Black                                 float64
# EOG/EOCSubjects_CACR_Hispanic                            float64
# EOGGr3_CACR_Hispanic                                     float64
# EOGGr4_CACR_Hispanic                                     float64
# EOGGr5_CACR_Hispanic                                     float64
# EOGMathGr3_CACR_Hispanic                                 float64
# EOGMathGr3-8_CACR_Hispanic                               float64
# EOGMathGr4_CACR_Hispanic                                 float64
# EOGMathGr5_CACR_Hispanic                                 float64
# EOGReadingGr3_CACR_Hispanic                              float64
# EOGReadingGr3-8_CACR_Hispanic                            float64
# EOGReadingGr3-8_GLP_Hispanic                             float64
# EOGReadingGr4_CACR_Hispanic                              float64
# EOGReadingGr5_CACR_Hispanic                              float64
# EOGScienceGr5_CACR_Hispanic                              float64
# EOG/EOCSubjects_CACR_TwoorMoreRaces                      float64
# EOGGr3_CACR_TwoorMoreRaces                               float64
# EOGGr4_CACR_TwoorMoreRaces                               float64
# EOGGr5_CACR_TwoorMoreRaces                               float64
# EOGMathGr3_CACR_TwoorMoreRaces                           float64
# EOGMathGr3-8_CACR_TwoorMoreRaces                         float64
# EOGMathGr4_CACR_TwoorMoreRaces                           float64
# EOGMathGr5_CACR_TwoorMoreRaces                           float64
# EOGReadingGr3-8_CACR_TwoorMoreRaces                      float64
# EOG/EOCSubjects_CACR_White                               float64
# EOGGr3_CACR_White                                        float64
# EOGGr4_CACR_White                                        float64
# EOGGr5_CACR_White                                        float64
# EOGMathGr3_CACR_White                                    float64
# EOGMathGr3-8_CACR_White                                  float64
# EOGMathGr4_CACR_White                                    float64
# EOGMathGr5_CACR_White                                    float64
# EOGReadingGr3_CACR_White                                 float64
# EOGReadingGr3-8_CACR_White                               float64
# EOGReadingGr4_CACR_White                                 float64
# EOGReadingGr5_CACR_White                                 float64
# EOG/EOCSubjects_CACR_EDS                                 float64
# EOGGr3_CACR_EDS                                          float64
# EOGGr4_CACR_EDS                                          float64
# EOGGr5_CACR_EDS                                          float64
# EOGMathGr3_CACR_EDS                                      float64
# EOGMathGr3_GLP_EDS                                       float64
# EOGMathGr3-8_CACR_EDS                                    float64
# EOGMathGr4_CACR_EDS                                      float64
# EOGMathGr5_CACR_EDS                                      float64
# EOGReadingGr3_CACR_EDS                                   float64
# EOGReadingGr3_GLP_EDS                                    float64
# EOGReadingGr3-8_CACR_EDS                                 float64
# EOGReadingGr4_CACR_EDS                                   float64
# EOGReadingGr4_GLP_EDS                                    float64
# EOGReadingGr5_CACR_EDS                                   float64
# EOGReadingGr5_GLP_EDS                                    float64
# EOGScienceGr5_CACR_EDS                                   float64
# EOG/EOCSubjects_CACR_LEP                                 float64
# EOG/EOCSubjects_GLP_LEP                                  float64
# EOGGr3_CACR_LEP                                          float64
# EOGGr4_CACR_LEP                                          float64
# EOGGr4_GLP_LEP                                           float64
# EOGGr5_CACR_LEP                                          float64
# EOGMathGr3_CACR_LEP                                      float64
# EOGMathGr3-8_CACR_LEP                                    float64
# EOGMathGr4_CACR_LEP                                      float64
# EOGMathGr5_CACR_LEP                                      float64
# EOGReadingGr3_CACR_LEP                                   float64
# EOGReadingGr3_GLP_LEP                                    float64
# EOGReadingGr3-8_CACR_LEP                                 float64
# EOGReadingGr3-8_GLP_LEP                                  float64
# EOGReadingGr4_CACR_LEP                                   float64
# EOGReadingGr4_GLP_LEP                                    float64
# EOGReadingGr5_CACR_LEP                                   float64
# EOGReadingGr5_GLP_LEP                                    float64
# EOGScienceGr5_CACR_LEP                                   float64
# EOGScienceGr5_GLP_LEP                                    float64
# EOG/EOCSubjects_CACR_SWD                                 float64
# EOGGr3_CACR_SWD                                          float64
# EOGGr3_GLP_SWD                                           float64
# EOGGr4_CACR_SWD                                          float64
# EOGGr4_GLP_SWD                                           float64
# EOGGr5_CACR_SWD                                          float64
# EOGGr5_GLP_SWD                                           float64
# EOGMathGr3_CACR_SWD                                      float64
# EOGMathGr3_GLP_SWD                                       float64
# EOGMathGr3-8_CACR_SWD                                    float64
# EOGMathGr3-8_GLP_SWD                                     float64
# EOGMathGr4_CACR_SWD                                      float64
# EOGMathGr5_CACR_SWD                                      float64
# EOGMathGr5_GLP_SWD                                       float64
# EOGReadingGr3_CACR_SWD                                   float64
# EOGReadingGr3_GLP_SWD                                    float64
# EOGReadingGr3-8_CACR_SWD                                 float64
# EOGReadingGr3-8_GLP_SWD                                  float64
# EOGReadingGr4_CACR_SWD                                   float64
# EOGReadingGr4_GLP_SWD                                    float64
# EOGReadingGr5_CACR_SWD                                   float64
# EOGReadingGr5_GLP_SWD                                    float64
# EOGScienceGr5_CACR_SWD                                   float64
# EOGScienceGr5_GLP_SWD                                    float64
# EOG/EOCSubjects_CACR_AIG                                 float64
# EOGGr3_CACR_AIG                                          float64
# EOGGr4_CACR_AIG                                          float64
# EOGGr5_CACR_AIG                                          float64
# EOGMathGr3_CACR_AIG                                      float64
# EOGMathGr3-8_CACR_AIG                                    float64
# EOGMathGr4_CACR_AIG                                      float64
# EOGMathGr5_CACR_AIG                                      float64
# pct_GCE_ALL                                              float64
# pct_PASSED_LAA                                           float64
# pct_PROMOTED                                             float64
# pct_RETAINED                                             float64
# MathGr3-8_pTarget_PctMet                                 float64
# SciGr5&8_pTarget_PctMet                                  float64
# lea_sat_avg_score_num                                    float64
# lea_sat_participation_pct                                float64
# lea_ap_participation_pct                                 float64
# lea_ap_pct_3_or_above                                    float64
# lea_ib_pct_4_or_above                                    float64
# avg_daily_attend_pct                                     float64
# crime_per_c_num                                          float64
# short_susp_per_c_num                                     float64
# long_susp_per_c_num                                      float64
# stud_internet_comp_num                                   float64
# lea_avg_daily_attend_pct                                 float64
# lea_crime_per_c_num                                      float64
# lea_short_susp_per_c_num                                 float64
# lea_long_susp_per_c_num                                  float64
# lea_stud_internet_comp_num                               float64
# st_avg_daily_attend_pct                                  float64
# st_crime_per_c_num                                       float64
# digital_media_pct                                        float64
# avg_age_media_collection                                 float64
# books_per_student                                        float64
# lea_avg_age_media_collection                             float64
# lea_books_per_student                                    float64
# wap_num                                                  float64
# wap_per_classroom                                        float64
# lea_wap_num                                              float64
# lea_wap_per_classroom                                    float64
# flicensed_teach_pct                                      float64
# tchyrs_0thru3_pct                                        float64
# tchyrs_4thru10_pct                                       float64
# tchyrs_11plus_pct                                        float64
# class_teach_num                                          float64
# nbpts_num                                                float64
# advance_dgr_pct                                          float64
# _1yr_tchr_trnovr_pct                                     float64
# lea_flicensed_teach_pct                                  float64
# lea_tchyrs_0thru3_pct                                    float64
# lea_tchyrs_4thru10_pct                                   float64
# lea_tchyrs_11plus_pct                                    float64
# lea_nbpts_num                                            float64
# lea_advance_dgr_pct                                      float64
# lea_1yr_tchr_trnovr_pct                                  float64
# lea_emer_prov_teach_pct                                  float64
# st_tchyrs_11plus_pct                                     float64
# 0-3 Years_LEA_Exp_Pct_Prin                               float64
# 10+ Years_LEA_Exp_Pct_Prin                               float64
# 4-10 Years_LEA_Exp_Pct_Prin                              float64
# Accomplished_TCHR_Standard 1_Pct                         float64
# Accomplished_TCHR_Standard 2_Pct                         float64
# Accomplished_TCHR_Standard 3_Pct                         float64
# Accomplished_TCHR_Standard 4_Pct                         float64
# Accomplished_TCHR_Standard 5_Pct                         float64
# Developing_TCHR_Standard 1_Pct                           float64
# Developing_TCHR_Standard 2_Pct                           float64
# Developing_TCHR_Standard 3_Pct                           float64
# Developing_TCHR_Standard 4_Pct                           float64
# Developing_TCHR_Standard 5_Pct                           float64
# Distinguished_TCHR_Standard 1_Pct                        float64
# Distinguished_TCHR_Standard 2_Pct                        float64
# Distinguished_TCHR_Standard 3_Pct                        float64
# Distinguished_TCHR_Standard 4_Pct                        float64
# Distinguished_TCHR_Standard 5_Pct                        float64
# Does Not Meet Expected Growth_TCHR_Student Growth_Pct    float64
# Exceeds Expected Growth_TCHR_Student Growth_Pct          float64
# Meets Expected Growth_TCHR_Student Growth_Pct            float64
# Not Demostrated_TCHR_Standard 1_Pct                      float64
# Not Demostrated_TCHR_Standard 2_Pct                      float64
# Not Demostrated_TCHR_Standard 4_Pct                      float64
# Proficient_TCHR_Standard 1_Pct                           float64
# Proficient_TCHR_Standard 2_Pct                           float64
# Proficient_TCHR_Standard 3_Pct                           float64
# Proficient_TCHR_Standard 4_Pct                           float64
# Proficient_TCHR_Standard 5_Pct                           float64
# AsianFemalePct                                           float64
# BlackFemalePct                                           float64
# HispanicFemalePct                                        float64
# IndianFemalePct                                          float64
# MinorityFemalePct                                        float64
# PacificIslandFemalePct                                   float64
# PacificIslandMalePct                                     float64
# PacificIslandPct                                         float64
# TwoOrMoreFemalePct                                       float64
# TwoOrMoreMalePct                                         float64
# TwoOrMorePct                                             float64
# pct_eds                                                  float64
# calendar_type_txt_Regular School, Year-Round Calendar    uint8
# esea_status_P                                            uint8
# Grad_project_status_Y                                    uint8
# SBE District_Northeast                                   uint8
# SBE District_Northwest                                   uint8
# SBE District_Piedmont-Triad                              uint8
# SBE District_Sandhills                                   uint8
# SBE District_Southeast                                   uint8
# SBE District_Southwest                                   uint8
# SBE District_Western                                     uint8
# SPG Grade_A+NG                                           uint8
# SPG Grade_B                                              uint8
# SPG Grade_C                                              uint8
# SPG Grade_D                                              uint8
# SPG Grade_F                                              uint8
# Reading SPG Grade_B                                      uint8
# Reading SPG Grade_C                                      uint8
# Reading SPG Grade_D                                      uint8
# Reading SPG Grade_F                                      uint8
# Math SPG Grade_B                                         uint8
# Math SPG Grade_C                                         uint8
# Math SPG Grade_D                                         uint8
# Math SPG Grade_F                                         uint8
# EVAAS Growth Status_Met                                  uint8
# EVAAS Growth Status_NotMet                               uint8
# Byod_Yes                                                 uint8
# _1_to_1_access_Yes                                       uint8
# SRC_devices_sent_home_Yes                                uint8
# SRC_Grades_Devices_Sent_Home_3                           uint8
# SRC_Grades_Devices_Sent_Home_3:04:05                     uint8
# SRC_Grades_Devices_Sent_Home_4:05                        uint8
# SRC_Grades_Devices_Sent_Home_4:05:06                     uint8
# SRC_Grades_Devices_Sent_Home_5                           uint8
# SRC_Grades_Devices_Sent_Home_6:07:08                     uint8
# SRC_Grades_Devices_Sent_Home_6:7:8:9:10:11:12            uint8
# SRC_Grades_Devices_Sent_Home_7                           uint8
# SRC_Grades_Devices_Sent_Home_8                           uint8
# SRC_Grades_Devices_Sent_Home_9:10:11:12                  uint8
# SRC_Grades_Devices_Sent_Home_K:1:2:3:4:5                 uint8
# SRC_Grades_Devices_Sent_Home_K:1:2:3:4:5:6:7:8           uint8
# SRC_Grades_Devices_Sent_Home_PK                          uint8
# unit_code                                                object
# dtypes: float64(269), object(1), uint8(41)
# memory usage: 2.7+ MB

# %%
import sklearn
import pandas as pd

print('Sklearn Version: ' + sklearn.__version__)
print('Pandas Version: ' + pd.__version__)
# Out:
# Sklearn Version: 0.19.1
# Pandas Version: 0.22.0

# %%
print 'Output File Location:\r\n\r\n' + outputDir + inputFileName + '_ML.csv'
# Out:
# Output File Location:
#
# C:/Users/Jake/Documents/GitHub/EducationDataNC/2017/Machine Learning Datasets/PublicElementarySchools2017_ML.csv
