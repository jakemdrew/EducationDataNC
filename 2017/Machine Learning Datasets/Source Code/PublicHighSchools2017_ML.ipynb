# %% [markdown]
# # Create Public School Machine Learning Datasets
# ** This program creates all the _ML datasets in the NCEA repository.**
# * This notebook reads each School Dataset file located at \EducationDataNC\ *schoolYear* \School Datasets\ as input data.
# * Different school years are processed by changing the *schoolYear* parameter.
# * Different input / output files are processed / created by changing the *inputFileName* paramter in the cell below.
# * While a single program is used to create all the _ML datasets, one program copy per dataset is maintained in the repositiory so the dataset specific tranformation reports may be reviewed.
#
# **Datasets ending in ML are preprocessed for Machine Learning and go through the following transformations: **
# 1. Missing student body racial compositions are imputed using district averages.
# 2. Columns that have the same value in every single row are deleted.
# 3. Columns that have a unique value in every single row (all values are different) are deleted.
# 4. Empty columns (all values are NA or NULL) are deleted.
# 5. Numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# 6. Remaining numeric, non-race columns with missing values are imputed / populated with 0.  In many cases, schools are not reporting values when they are zero. However, mean imputation or some other more sophisticated strategy might be considered here.
# 7. Categorical / text based columns with > *uniqueThreshold* unique values are deleted.
# 8. All remaining categorical / text based columns are one-hot encoded.  In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# 9. Duplicated or highly similar columns with > 95% correlation are delelted.

# %%
#import required Libraries
import pandas as pd
import numpy as np
import os
import string

#**********************************************************************************
# Set the following variables before running this code!!!
#**********************************************************************************
#All raw data files are processed for the year below
schoolYear = 2017

#Location where copies of the raw data files will be read in from csv files.
dataDir = 'C:/Users/Jake/Documents/GitHub/EducationDataNC/' + str(schoolYear) + '/School Datasets/'

#Name of the file to be processed
#inputFileName = 'PublicSchools2017'
inputFileName = 'PublicHighSchools2017'
#inputFileName = 'PublicMiddleSchools2017'
#inputFileName = 'PublicElementarySchools2017'

#Input file being transformed for machine learning 
inputFile = dataDir + inputFileName + '.csv'

#Location where the new school datasets will be created.
outputDir = 'C:/Users/Jake/Documents/GitHub/EducationDataNC/' + str(schoolYear) + '/Machine Learning Datasets/'

#Missing Data Threshold (Per Column)
missingThreshold = 0.60

#Unique Value Threshold (Per Column)
#Delete Columns >  uniqueThreshold unique values prior to one-hot encoding. 
#(each unique value becomes a new column during one-hot encoding)
uniqueThreshold = 25

#Read in the School Data File
schoolData = pd.read_csv(inputFile, low_memory=False, dtype={'unit_code': object})
print('*********Start: Beginning Column and Row Counts********************************************')
schoolData.info(verbose=False)

#Select only public schools as charter schools are missing data for many columns.
schoolData = schoolData[(schoolData['type_cd'] == 'P') & (schoolData['student_num'] > 0)]

print('\r\n*********After: Selecting Only Public School Campuses**********************************')
schoolData.info(verbose=False)

#Save primary key
unit_code = schoolData['unit_code']
#Convert zip code to string
schoolData['szip_ad'] = schoolData['szip_ad'].astype('object')
# Out:
# *********Start: Beginning Column and Row Counts********************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 470 entries, 0 to 469
# Columns: 1279 entries, vphone_ad to Number_Industry_Recognized_Crede
# dtypes: float64(1237), int64(3), object(39)
# memory usage: 4.6+ MB
#
# *********After: Selecting Only Public School Campuses**********************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 470 entries, 0 to 469
# Columns: 1279 entries, vphone_ad to Number_Industry_Recognized_Crede
# dtypes: float64(1237), int64(3), object(39)
# memory usage: 4.6+ MB

# %% [markdown]
# # Prepare Consolidated Dataset for Machine Learning
# **Below we perform operations on the entire dataset to remove columns and update row values that could cause problems during machine learning.**

# %% [markdown]
# ## Student Body Racial Composition Features
# **Impute / update missing Student Body Racial Composition Fields using mean imputation.**
# * When there are no racial composition percentages for a particular school campus / unit_code, fill in the missing values

# %%
#Get Student Body Racial Composition Fields
raceCompositionFields = schoolData.filter(regex='Indian|Asian|Hispanic|Black|White|PacificIsland|TwoOrMore|Minority')\
                                  .filter(regex='Pct').columns
    
rowsBefore = schoolData[raceCompositionFields].isnull().T.any().T.sum()

#Update missing race values with the district average when avaiable (No district averages for charter schools) 
schoolData[raceCompositionFields] = schoolData.groupby('District Name')[raceCompositionFields]\
                                              .transform(lambda x: x.fillna(x.mean()))

    #Review dataset contents after Racial Composition Imputation
print('*********After: Updating Missing Racial Compostion Values****************************')   
rowsAfter = schoolData[raceCompositionFields].isnull().T.any().T.sum()
rowsUpdated = rowsBefore - rowsAfter
print 'Rows Updated / Imputed: ', rowsUpdated 
print('\r\nTotal Rows Missing Racial Compositions By District Name') 
schoolData['District Name'][schoolData[raceCompositionFields].isnull().T.any().T].value_counts()
# Out:
# *********After: Updating Missing Racial Compostion Values****************************
# Rows Updated / Imputed:  0
#
# Total Rows Missing Racial Compositions By District Name
# Series([], Name: District Name, dtype: int64)

# %% [markdown]
# ## Remove Columns with Problematic Data
# **Here we remove entire columns that could cause problems during machine learning.  The following operations are performed:**
# * Remove any columns that have the same value in every single row.
# * Remove any columns that have a unique value in every single row (all values are different).
# * Remove empty columns (all values are NA or NULL).

# %%
#Remove any fields that have the same value in all rows
UniqueValueCounts = schoolData.nunique(dropna=False)
SingleValueCols = UniqueValueCounts[UniqueValueCounts == 1].index
schoolData = schoolData.drop(SingleValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with the same value in every row.*******************')
schoolData.info(verbose=False)
print '\r\nColumns Deleted: ', len(SingleValueCols)
# Out:
# *********After: Removing columns with the same value in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 470 entries, 0 to 469
# Columns: 1145 entries, vphone_ad to Number_Industry_Recognized_Crede
# dtypes: float64(1109), object(36)
# memory usage: 4.1+ MB
#
# Columns Deleted:  134

# %%
#Remove any fields that have unique values in every row
schoolDataRecordCt = schoolData.shape[0]
UniqueValueCounts = schoolData.apply(pd.Series.nunique)
AllUniqueValueCols = UniqueValueCounts[UniqueValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(AllUniqueValueCols, axis=1)

#Review dataset contents after drops
print('*********After: Removing columns with unique values in every row.*******************')
schoolData.info(verbose=False)
print '\r\nColumns Deleted: ', len(AllUniqueValueCols)
# Out:
# *********After: Removing columns with unique values in every row.*******************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 470 entries, 0 to 469
# Columns: 1143 entries, vphone_ad to Number_Industry_Recognized_Crede
# dtypes: float64(1109), object(34)
# memory usage: 4.1+ MB
#
# Columns Deleted:  2

# %%
#Remove any empty fields (null values in every row)
schoolDataRecordCt = schoolData.shape[0]
NullValueCounts = schoolData.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts == schoolDataRecordCt].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with null / blank values in every row.*************')
schoolData.info(verbose=False)
print '\r\nColumns Deleted: ', len(NullValueCols)
# Out:
# *********After: Removing columns with null / blank values in every row.*************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 470 entries, 0 to 469
# Columns: 1143 entries, vphone_ad to Number_Industry_Recognized_Crede
# dtypes: float64(1109), object(34)
# memory usage: 4.1+ MB
#
# Columns Deleted:  0

# %% [markdown]
# ## Handle Other Missing Values Types
# * Here we eliminate any numeric columns with more than the percentage of missing values specified by the *missingThreshold* parameter.
# * All remaining non-race, numeric column missing values are populated with 0.
# * In many cases, it seems that schools are not simply not reporting values when they are zero. However, mean imputation or some other strategy might be considered.

# %%
#Isolate continuous and categorical data types
#These are indexers into the schoolData dataframe and may be used similar to the schoolData dataframe 
sD_boolean = schoolData.loc[:, (schoolData.dtypes == bool) ]
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]
sD_continuous = schoolData.loc[:, (schoolData.dtypes != bool) & (schoolData.dtypes != object)]
print "Boolean Columns: ", sD_boolean.shape[1]
print "Nominal Columns: ", sD_nominal.shape[1]
print "Continuous Columns: ", sD_continuous.shape[1]
print "Columns Accounted for: ", sD_nominal.shape[1] + sD_continuous.shape[1] + sD_boolean.shape[1]
# Out:
# Boolean Columns:  0
# Nominal Columns:  34
# Continuous Columns:  1109
# Columns Accounted for:  1143

# %%
#Eliminate continuous columns with more than missingThreshold percentage of missing values
schoolDataRecordCt = sD_continuous.shape[0]
missingValueLimit = schoolDataRecordCt * missingThreshold
NullValueCounts = sD_continuous.isnull().sum()
NullValueCols = NullValueCounts[NullValueCounts >= missingValueLimit].index
schoolData = schoolData.drop(NullValueCols, axis=1)

#Review dataset contents after empty field drops
print('*********After: Removing columns with >= missingThreshold % of missing values******')
schoolData.info(verbose=False)
print '\r\nColumns Deleted: ', len(NullValueCols)
# Out:
# *********After: Removing columns with >= missingThreshold % of missing values******
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 470 entries, 0 to 469
# Columns: 482 entries, vphone_ad to Number_Industry_Recognized_Crede
# dtypes: float64(448), object(34)
# memory usage: 1.7+ MB
#
# Columns Deleted:  661

# %% [markdown]
# ## One-Hot Encoding of Categorical Variables
# **All categorical / string variables are converted to numberic variables via one hot encoding.  Each unique row value will become a new binary / numeric column in the dataset.**
# * All remaining categorical columns are one-hot encoded.
# * In categorical columns, one-hot encoding creates one new boolean / binary field per unique value in the target column, converting all categorical columns to a numeric data type.
# * Prior to one-hot encoding, columns with > *uniqueThreshold* unique values are deleted.

# %%
#Delete categorical columns with > 25 unique values (Each unique value becomes a column during one-hot encoding)
oneHotUniqueValueCounts = schoolData[sD_nominal.columns].apply(lambda x: x.nunique())
oneHotUniqueValueCols = oneHotUniqueValueCounts[oneHotUniqueValueCounts >= uniqueThreshold].index
schoolData.drop(oneHotUniqueValueCols, axis=1, inplace=True) 

#Review dataset contents one hot high unique value drops
print('*********After: Removing columns with >= uniqueThreshold unique values***********')
schoolData.info(verbose=False)
print '\r\nColumns Deleted: ', len(oneHotUniqueValueCols)
# Out:
# *********After: Removing columns with >= uniqueThreshold unique values***********
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 470 entries, 0 to 469
# Columns: 472 entries, category_cd to Number_Industry_Recognized_Crede
# dtypes: float64(448), object(24)
# memory usage: 1.7+ MB
#
# Columns Deleted:  10

# %%
#Isolate remaining categorical variables
begColumnCt = len(schoolData.columns)
sD_nominal = schoolData.loc[:, (schoolData.dtypes == object)]

#one hot encode categorical variables
schoolData = pd.get_dummies(data=schoolData, 
                       columns=sD_nominal, drop_first=True)

#Determine change in column count
endColumnCt = len(schoolData.columns)
columnsAdded = endColumnCt - begColumnCt

#Review dataset contents one hot high unique value drops
print 'Columns To One-Hot Encode: ', len(sD_nominal.columns)
print('\r\n*********After: Adding New Columns Via One-Hot Encoding*************************')
schoolData.info(verbose=False)
print '\r\nNew Columns Created Via One-Hot Encoding: ', columnsAdded
# Out:
# Columns To One-Hot Encode:  24
#
# *********After: Adding New Columns Via One-Hot Encoding*************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 470 entries, 0 to 469
# Columns: 540 entries, student_num to SRC_Grades_Devices_Sent_Home_9:10:12
# dtypes: float64(448), uint8(92)
# memory usage: 1.7 MB
#
# New Columns Created Via One-Hot Encoding:  68

# %% [markdown]
# ## Impute any Remaining Missing Values as Zero

# %%
#Print out all the missing value rows
pd.set_option('display.max_rows', 1000)

print('\r\n*********The Remaining Missing Values Below will be set to Zero!*************************')

#Check for Missing values 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# *********The Remaining Missing Values Below will be set to Zero!*************************
#                                          Variable Name  Number Missing Values
# 3                                              09_Size                     54
# 4                                              10_Size                     75
# 5                                              11_Size                     81
# 6                                              12_Size                    103
# 7                                         Biology_Size                     15
# 8                                      English II_Size                     17
# 9                                          Math I_Size                     16
# 19                                  EVAAS Growth Score                     11
# 21                                     NC Math 1 Score                     12
# 22                                    English II Score                     17
# 23                                       Biology Score                     17
# 24                                           ACT Score                     11
# 25                                  ACT WorkKeys Score                     89
# 26                                   Passing NC Math 3                     14
# 27                 4-Year Cohort Graduation Rate Score                     13
# 28                        ACTCompositeScore_UNCMin_All                     13
# 29                         ACTEnglish_ACTBenchmark_All                     13
# 30                            ACTMath_ACTBenchmark_All                     13
# 31                         ACTReading_ACTBenchmark_All                     13
# 32                         ACTScience_ACTBenchmark_All                     13
# 33                       ACTSubtests_BenchmarksMet_All                      9
# 34                          ACTWorkKeys_SilverPlus_All                    108
# 35                         ACTWriting_ACTBenchmark_All                     13
# 36                                 EOCBiology_CACR_All                     19
# 37                                  EOCBiology_GLP_All                     19
# 38                                EOCEnglish2_CACR_All                     19
# 39                                 EOCEnglish2_GLP_All                     19
# 40                                   EOCMathI_CACR_All                     13
# 41                                    EOCMathI_GLP_All                     13
# 42                                EOCSubjects_CACR_All                     10
# 43                                 EOCSubjects_GLP_All                     10
# 44                            EOG/EOCSubjects_CACR_All                      9
# 45                             EOG/EOCSubjects_GLP_All                      9
# 46                              GraduationRate_4yr_All                     14
# 47                              GraduationRate_5yr_All                     24
# 48                     ACTCompositeScore_UNCMin_Female                     13
# 49                      ACTEnglish_ACTBenchmark_Female                     13
# 50                         ACTMath_ACTBenchmark_Female                     13
# 51                      ACTReading_ACTBenchmark_Female                     13
# 52                      ACTScience_ACTBenchmark_Female                     13
# 53                    ACTSubtests_BenchmarksMet_Female                      9
# 54                       ACTWorkKeys_SilverPlus_Female                    108
# 55                      ACTWriting_ACTBenchmark_Female                     13
# 56                              EOCBiology_CACR_Female                     19
# 57                               EOCBiology_GLP_Female                     19
# 58                             EOCEnglish2_CACR_Female                     19
# 59                              EOCEnglish2_GLP_Female                     19
# 60                                EOCMathI_CACR_Female                     13
# 61                                 EOCMathI_GLP_Female                     13
# 62                             EOCSubjects_CACR_Female                     10
# 63                              EOCSubjects_GLP_Female                     10
# 64                         EOG/EOCSubjects_CACR_Female                      9
# 65                          EOG/EOCSubjects_GLP_Female                      9
# 66                           GraduationRate_4yr_Female                     14
# 67                           GraduationRate_5yr_Female                     24
# 68                       ACTCompositeScore_UNCMin_Male                     13
# 69                        ACTEnglish_ACTBenchmark_Male                     13
# 70                           ACTMath_ACTBenchmark_Male                     13
# 71                        ACTReading_ACTBenchmark_Male                     13
# 72                        ACTScience_ACTBenchmark_Male                     13
# 73                      ACTSubtests_BenchmarksMet_Male                      9
# 74                         ACTWorkKeys_SilverPlus_Male                    108
# 75                        ACTWriting_ACTBenchmark_Male                     13
# 76                                EOCBiology_CACR_Male                     19
# 77                                 EOCBiology_GLP_Male                     19
# 78                               EOCEnglish2_CACR_Male                     19
# 79                                EOCEnglish2_GLP_Male                     19
# 80                                  EOCMathI_CACR_Male                     13
# 81                                   EOCMathI_GLP_Male                     13
# 82                               EOCSubjects_CACR_Male                     10
# 83                                EOCSubjects_GLP_Male                     10
# 84                           EOG/EOCSubjects_CACR_Male                      9
# 85                            EOG/EOCSubjects_GLP_Male                      9
# 86                             GraduationRate_4yr_Male                     14
# 87                             GraduationRate_5yr_Male                     24
# 88             ACTCompositeScore_UNCMin_AmericanIndian                     13
# 89              ACTEnglish_ACTBenchmark_AmericanIndian                     13
# 90                 ACTMath_ACTBenchmark_AmericanIndian                     13
# 91              ACTReading_ACTBenchmark_AmericanIndian                     13
# 92              ACTScience_ACTBenchmark_AmericanIndian                     13
# 93            ACTSubtests_BenchmarksMet_AmericanIndian                      9
# 94               ACTWorkKeys_SilverPlus_AmericanIndian                    108
# 95              ACTWriting_ACTBenchmark_AmericanIndian                     13
# 96                      EOCBiology_CACR_AmericanIndian                     19
# 97                       EOCBiology_GLP_AmericanIndian                     19
# 98                     EOCEnglish2_CACR_AmericanIndian                     19
# 99                      EOCEnglish2_GLP_AmericanIndian                     19
# 100                       EOCMathI_CACR_AmericanIndian                     13
# 101                        EOCMathI_GLP_AmericanIndian                     13
# 102                    EOCSubjects_CACR_AmericanIndian                     10
# 103                     EOCSubjects_GLP_AmericanIndian                     10
# 104                EOG/EOCSubjects_CACR_AmericanIndian                      9
# 105                 EOG/EOCSubjects_GLP_AmericanIndian                      9
# 106                  GraduationRate_4yr_AmericanIndian                     14
# 107                  GraduationRate_5yr_AmericanIndian                     24
# 108                     ACTCompositeScore_UNCMin_Asian                     13
# 109                      ACTEnglish_ACTBenchmark_Asian                     13
# 110                         ACTMath_ACTBenchmark_Asian                     13
# 111                      ACTReading_ACTBenchmark_Asian                     13
# 112                      ACTScience_ACTBenchmark_Asian                     13
# 113                    ACTSubtests_BenchmarksMet_Asian                      9
# 114                       ACTWorkKeys_SilverPlus_Asian                    108
# 115                      ACTWriting_ACTBenchmark_Asian                     13
# 116                              EOCBiology_CACR_Asian                     19
# 117                               EOCBiology_GLP_Asian                     19
# 118                             EOCEnglish2_CACR_Asian                     19
# 119                              EOCEnglish2_GLP_Asian                     19
# 120                                EOCMathI_CACR_Asian                     13
# 121                                 EOCMathI_GLP_Asian                     13
# 122                             EOCSubjects_CACR_Asian                     10
# 123                              EOCSubjects_GLP_Asian                     10
# 124                         EOG/EOCSubjects_CACR_Asian                      9
# 125                          EOG/EOCSubjects_GLP_Asian                      9
# 126                           GraduationRate_4yr_Asian                     14
# 127                           GraduationRate_5yr_Asian                     24
# 128                     ACTCompositeScore_UNCMin_Black                     13
# 129                      ACTEnglish_ACTBenchmark_Black                     13
# 130                         ACTMath_ACTBenchmark_Black                     13
# 131                      ACTReading_ACTBenchmark_Black                     13
# 132                      ACTScience_ACTBenchmark_Black                     13
# 133                    ACTSubtests_BenchmarksMet_Black                      9
# 134                       ACTWorkKeys_SilverPlus_Black                    108
# 135                      ACTWriting_ACTBenchmark_Black                     13
# 136                              EOCBiology_CACR_Black                     19
# 137                               EOCBiology_GLP_Black                     19
# 138                             EOCEnglish2_CACR_Black                     19
# 139                              EOCEnglish2_GLP_Black                     19
# 140                                EOCMathI_CACR_Black                     13
# 141                                 EOCMathI_GLP_Black                     13
# 142                             EOCSubjects_CACR_Black                     10
# 143                              EOCSubjects_GLP_Black                     10
# 144                         EOG/EOCSubjects_CACR_Black                      9
# 145                          EOG/EOCSubjects_GLP_Black                      9
# 146                           GraduationRate_4yr_Black                     14
# 147                           GraduationRate_5yr_Black                     24
# 148                  ACTCompositeScore_UNCMin_Hispanic                     13
# 149                   ACTEnglish_ACTBenchmark_Hispanic                     13
# 150                      ACTMath_ACTBenchmark_Hispanic                     13
# 151                   ACTReading_ACTBenchmark_Hispanic                     13
# 152                   ACTScience_ACTBenchmark_Hispanic                     13
# 153                 ACTSubtests_BenchmarksMet_Hispanic                      9
# 154                    ACTWorkKeys_SilverPlus_Hispanic                    108
# 155                   ACTWriting_ACTBenchmark_Hispanic                     13
# 156                           EOCBiology_CACR_Hispanic                     19
# 157                            EOCBiology_GLP_Hispanic                     19
# 158                          EOCEnglish2_CACR_Hispanic                     19
# 159                           EOCEnglish2_GLP_Hispanic                     19
# 160                             EOCMathI_CACR_Hispanic                     13
# 161                              EOCMathI_GLP_Hispanic                     13
# 162                          EOCSubjects_CACR_Hispanic                     10
# 163                           EOCSubjects_GLP_Hispanic                     10
# 164                      EOG/EOCSubjects_CACR_Hispanic                      9
# 165                       EOG/EOCSubjects_GLP_Hispanic                      9
# 166                        GraduationRate_4yr_Hispanic                     14
# 167                        GraduationRate_5yr_Hispanic                     24
# 168            ACTCompositeScore_UNCMin_TwoorMoreRaces                     13
# 169             ACTEnglish_ACTBenchmark_TwoorMoreRaces                     13
# 170                ACTMath_ACTBenchmark_TwoorMoreRaces                     13
# 171             ACTReading_ACTBenchmark_TwoorMoreRaces                     13
# 172             ACTScience_ACTBenchmark_TwoorMoreRaces                     13
# 173           ACTSubtests_BenchmarksMet_TwoorMoreRaces                      9
# 174              ACTWorkKeys_SilverPlus_TwoorMoreRaces                    108
# 175             ACTWriting_ACTBenchmark_TwoorMoreRaces                     13
# 176                     EOCBiology_CACR_TwoorMoreRaces                     19
# 177                      EOCBiology_GLP_TwoorMoreRaces                     19
# 178                    EOCEnglish2_CACR_TwoorMoreRaces                     19
# 179                     EOCEnglish2_GLP_TwoorMoreRaces                     19
# 180                       EOCMathI_CACR_TwoorMoreRaces                     13
# 181                        EOCMathI_GLP_TwoorMoreRaces                     13
# 182                    EOCSubjects_CACR_TwoorMoreRaces                     10
# 183                     EOCSubjects_GLP_TwoorMoreRaces                     10
# 184                EOG/EOCSubjects_CACR_TwoorMoreRaces                      9
# 185                 EOG/EOCSubjects_GLP_TwoorMoreRaces                      9
# 186                  GraduationRate_4yr_TwoorMoreRaces                     14
# 187                  GraduationRate_5yr_TwoorMoreRaces                     24
# 188                     ACTCompositeScore_UNCMin_White                     13
# 189                      ACTEnglish_ACTBenchmark_White                     13
# 190                         ACTMath_ACTBenchmark_White                     13
# 191                      ACTReading_ACTBenchmark_White                     13
# 192                      ACTScience_ACTBenchmark_White                     13
# 193                    ACTSubtests_BenchmarksMet_White                      9
# 194                       ACTWorkKeys_SilverPlus_White                    108
# 195                      ACTWriting_ACTBenchmark_White                     13
# 196                              EOCBiology_CACR_White                     19
# 197                               EOCBiology_GLP_White                     19
# 198                             EOCEnglish2_CACR_White                     19
# 199                              EOCEnglish2_GLP_White                     19
# 200                                EOCMathI_CACR_White                     13
# 201                                 EOCMathI_GLP_White                     13
# 202                             EOCSubjects_CACR_White                     10
# 203                              EOCSubjects_GLP_White                     10
# 204                         EOG/EOCSubjects_CACR_White                      9
# 205                          EOG/EOCSubjects_GLP_White                      9
# 206                           GraduationRate_4yr_White                     14
# 207                           GraduationRate_5yr_White                     24
# 208                       ACTCompositeScore_UNCMin_EDS                     13
# 209                        ACTEnglish_ACTBenchmark_EDS                     13
# 210                           ACTMath_ACTBenchmark_EDS                     13
# 211                        ACTReading_ACTBenchmark_EDS                     13
# 212                        ACTScience_ACTBenchmark_EDS                     13
# 213                      ACTSubtests_BenchmarksMet_EDS                      9
# 214                         ACTWorkKeys_SilverPlus_EDS                    108
# 215                        ACTWriting_ACTBenchmark_EDS                     13
# 216                                EOCBiology_CACR_EDS                     19
# 217                                 EOCBiology_GLP_EDS                     19
# 218                               EOCEnglish2_CACR_EDS                     19
# 219                                EOCEnglish2_GLP_EDS                     19
# 220                                  EOCMathI_CACR_EDS                     13
# 221                                   EOCMathI_GLP_EDS                     13
# 222                               EOCSubjects_CACR_EDS                     10
# 223                                EOCSubjects_GLP_EDS                     10
# 224                           EOG/EOCSubjects_CACR_EDS                      9
# 225                            EOG/EOCSubjects_GLP_EDS                      9
# 226                             GraduationRate_4yr_EDS                     14
# 227                             GraduationRate_5yr_EDS                     24
# 228                       ACTCompositeScore_UNCMin_LEP                     13
# 229                        ACTEnglish_ACTBenchmark_LEP                     13
# 230                           ACTMath_ACTBenchmark_LEP                     13
# 231                        ACTReading_ACTBenchmark_LEP                     13
# 232                        ACTScience_ACTBenchmark_LEP                     13
# 233                      ACTSubtests_BenchmarksMet_LEP                      9
# 234                         ACTWorkKeys_SilverPlus_LEP                    108
# 235                        ACTWriting_ACTBenchmark_LEP                     13
# 236                                EOCBiology_CACR_LEP                     19
# 237                                 EOCBiology_GLP_LEP                     19
# 238                               EOCEnglish2_CACR_LEP                     19
# 239                                EOCEnglish2_GLP_LEP                     19
# 240                                  EOCMathI_CACR_LEP                     13
# 241                                   EOCMathI_GLP_LEP                     13
# 242                               EOCSubjects_CACR_LEP                     10
# 243                                EOCSubjects_GLP_LEP                     10
# 244                           EOG/EOCSubjects_CACR_LEP                      9
# 245                            EOG/EOCSubjects_GLP_LEP                      9
# 246                             GraduationRate_4yr_LEP                     14
# 247                             GraduationRate_5yr_LEP                     24
# 248                       ACTCompositeScore_UNCMin_SWD                     13
# 249                        ACTEnglish_ACTBenchmark_SWD                     13
# 250                           ACTMath_ACTBenchmark_SWD                     13
# 251                        ACTReading_ACTBenchmark_SWD                     13
# 252                        ACTScience_ACTBenchmark_SWD                     13
# 253                      ACTSubtests_BenchmarksMet_SWD                      9
# 254                         ACTWorkKeys_SilverPlus_SWD                    108
# 255                        ACTWriting_ACTBenchmark_SWD                     13
# 256                                EOCBiology_CACR_SWD                     19
# 257                                 EOCBiology_GLP_SWD                     19
# 258                               EOCEnglish2_CACR_SWD                     19
# 259                                EOCEnglish2_GLP_SWD                     19
# 260                                  EOCMathI_CACR_SWD                     13
# 261                                   EOCMathI_GLP_SWD                     13
# 262                               EOCSubjects_CACR_SWD                     10
# 263                                EOCSubjects_GLP_SWD                     10
# 264                           EOG/EOCSubjects_CACR_SWD                      9
# 265                            EOG/EOCSubjects_GLP_SWD                      9
# 266                             GraduationRate_4yr_SWD                     14
# 267                             GraduationRate_5yr_SWD                     24
# 268                       ACTCompositeScore_UNCMin_AIG                     13
# 269                        ACTEnglish_ACTBenchmark_AIG                     13
# 270                           ACTMath_ACTBenchmark_AIG                     13
# 271                        ACTReading_ACTBenchmark_AIG                     13
# 272                        ACTScience_ACTBenchmark_AIG                     13
# 273                      ACTSubtests_BenchmarksMet_AIG                      9
# 274                         ACTWorkKeys_SilverPlus_AIG                    108
# 275                        ACTWriting_ACTBenchmark_AIG                     13
# 276                                EOCBiology_CACR_AIG                     19
# 277                                 EOCBiology_GLP_AIG                     19
# 278                               EOCEnglish2_CACR_AIG                     19
# 279                                EOCEnglish2_GLP_AIG                     19
# 280                                  EOCMathI_CACR_AIG                     13
# 281                                   EOCMathI_GLP_AIG                     13
# 282                               EOCSubjects_CACR_AIG                     10
# 283                                EOCSubjects_GLP_AIG                     10
# 284                           EOG/EOCSubjects_CACR_AIG                      9
# 285                            EOG/EOCSubjects_GLP_AIG                      9
# 286                             GraduationRate_4yr_AIG                     14
# 287                             GraduationRate_5yr_AIG                     24
# 288                                 ACT_pTarget_PctMet                     30
# 289                         ACTWorkKeys_pTarget_PctMet                    140
# 290                      CurrentYearEOC_pTarget_PctMet                     13
# 291                            MathGr10_pTarget_PctMet                     31
# 292                         ReadingGr10_pTarget_PctMet                     31
# 293                             SciGr11_pTarget_PctMet                     33
# 294                        TotalTargets_pTarget_PctMet                      1
# 295                                  sat_avg_score_num                     49
# 296                              lea_sat_avg_score_num                      1
# 297                              sat_participation_pct                     49
# 298                          lea_sat_participation_pct                      1
# 299                               ap_participation_pct                    161
# 300                           lea_ap_participation_pct                     71
# 301                                  ap_pct_3_or_above                    121
# 302                              lea_ap_pct_3_or_above                     18
# 303                          total_specialized_courses                      6
# 304                                      ap_ib_courses                    111
# 305                                        cte_courses                     13
# 306                               univ_college_courses                     61
# 307                      lea_total_specialized_courses                      6
# 308                                  lea_ap_ib_courses                     15
# 309                                    lea_cte_courses                      6
# 310                           lea_univ_college_courses                      9
# 311                       st_total_specialized_courses                      6
# 312                                   st_ap_ib_courses                      6
# 313                                     st_cte_courses                      6
# 314                            st_univ_college_courses                      6
# 315  ALL_All Students (Total or Subtotal_ENROLL_sch...                     29
# 316   ECODIS_Economically Disadvantaged_ENROLL_sch_pct                    112
# 317                            F_Female_ENROLL_sch_pct                     30
# 318                              M_Male_ENROLL_sch_pct                     31
# 319                            MB_Black_ENROLL_sch_pct                    165
# 320                            MW_White_ENROLL_sch_pct                     58
# 326                             stud_internet_comp_num                      4
# 338                                  digital_media_pct                     91
# 339                           avg_age_media_collection                     85
# 340                                  books_per_student                     94
# 341                       lea_avg_age_media_collection                     85
# 342                              lea_books_per_student                     94
# 343                                            wap_num                     11
# 344                                  wap_per_classroom                     11
# 347                                flicensed_teach_pct                      2
# 348                                  tchyrs_0thru3_pct                      2
# 349                                 tchyrs_4thru10_pct                      2
# 350                                  tchyrs_11plus_pct                      2
# 351                                    class_teach_num                      2
# 352                                          nbpts_num                      2
# 353                                    advance_dgr_pct                      2
# 354                               _1yr_tchr_trnovr_pct                     12
# 355                                  lateral_teach_pct                     82
# 364                            lea_emer_prov_teach_pct                    263
# 365                              lea_lateral_teach_pct                      5
# 376                              0-3 Years_Exp_Pct_Tch                      2
# 377                              10+ Years_Exp_Pct_Tch                      2
# 378                             4-10 Years_Exp_Pct_Tch                      2
# 382                   Accomplished_TCHR_Standard 1_Pct                      3
# 383                   Accomplished_TCHR_Standard 2_Pct                      3
# 384                   Accomplished_TCHR_Standard 3_Pct                      3
# 385                   Accomplished_TCHR_Standard 4_Pct                      3
# 386                   Accomplished_TCHR_Standard 5_Pct                      3
# 387                     Developing_TCHR_Standard 1_Pct                      3
# 388                     Developing_TCHR_Standard 2_Pct                      3
# 389                     Developing_TCHR_Standard 3_Pct                      3
# 390                     Developing_TCHR_Standard 4_Pct                      3
# 391                     Developing_TCHR_Standard 5_Pct                      3
# 392                  Distinguished_TCHR_Standard 1_Pct                      3
# 393                  Distinguished_TCHR_Standard 2_Pct                      3
# 394                  Distinguished_TCHR_Standard 3_Pct                      3
# 395                  Distinguished_TCHR_Standard 4_Pct                      3
# 396                  Distinguished_TCHR_Standard 5_Pct                      3
# 397  Does Not Meet Expected Growth_TCHR_Student Gro...                     11
# 398    Exceeds Expected Growth_TCHR_Student Growth_Pct                     11
# 399      Meets Expected Growth_TCHR_Student Growth_Pct                     11
# 400                Not Demostrated_TCHR_Standard 1_Pct                      3
# 401                Not Demostrated_TCHR_Standard 2_Pct                      3
# 402                Not Demostrated_TCHR_Standard 3_Pct                      3
# 403                Not Demostrated_TCHR_Standard 4_Pct                      3
# 404                Not Demostrated_TCHR_Standard 5_Pct                      3
# 405                     Proficient_TCHR_Standard 1_Pct                      3
# 406                     Proficient_TCHR_Standard 2_Pct                      3
# 407                     Proficient_TCHR_Standard 3_Pct                      3
# 408                     Proficient_TCHR_Standard 4_Pct                      3
# 409                     Proficient_TCHR_Standard 5_Pct                      3
# 434                                      Gr_9_Pct_Prof                     13
# 436                               AAVC_Concentrator_Ct                    247
# 437                               AGNR_Concentrator_Ct                    147
# 438                               ARCH_Concentrator_Ct                    164
# 439                                BMA_Concentrator_Ct                    150
# 440                               HLTH_Concentrator_Ct                    148
# 441                               HOSP_Concentrator_Ct                    140
# 442                               INFO_Concentrator_Ct                    143
# 443                               MANU_Concentrator_Ct                    228
# 444                               MRKT_Concentrator_Ct                    269
# 445                               STEM_Concentrator_Ct                    259
# 446                               TRAN_Concentrator_Ct                    268
# 447                   Number_Industry_Recognized_Crede                     57

# %%
#Replace all remaining NaN with 0
schoolData = schoolData.fillna(0)

#Check for Missing values after final imputation 
missing_values = schoolData.isnull().sum().reset_index()
missing_values.columns = ['Variable Name', 'Number Missing Values']
missing_values = missing_values[missing_values['Number Missing Values'] > 0] 
missing_values
# Out:
# Empty DataFrame
# Columns: [Variable Name, Number Missing Values]
# Index: []

# %% [markdown]
# ## Identify and Remove Highly Correlated Features
# **Find and remove any columns / features that are > 95% correlated**
# * https://stackoverflow.com/questions/39409866/correlation-heatmap
# * https://chrisalbon.com/machine_learning/feature_selection/drop_highly_correlated_features/
# * https://codeyarns.com/2015/04/20/how-to-change-font-size-in-seaborn/

# %%
# calculate the correlation matrix
corr_matrix  = schoolData.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
#Get all of the correlation values > 95%
x = np.where(upper > 0.95)

#Display all field combinations with > 95% correlation
cf = pd.DataFrame()
cf['Field1'] = upper.columns[x[1]]
cf['Field2'] = upper.index[x[0]]

#Get the correlation values for every field combination. (There must be a more pythonic way to do this!)
corr = [0] * len(cf)
for i in range(0, len(cf)):
    corr[i] =  upper[cf['Field1'][i]][cf['Field2'][i]] 
    
cf['Correlation'] = corr

print 'There are ', str(len(cf['Field1'])), ' field correlations > 95%.'
cf
# Out:
# There are  211  field correlations > 95%.
#                                              Field1  \
# 0                                   class_teach_num
# 1                               lea_class_teach_num
# 2                                st_class_teach_num
# 3                                      st_nbpts_num
# 4                                st_advance_dgr_pct
# 5                                     category_cd_H
# 6                                     Category_Cd_H
# 7                         Overall Achievement Score
# 8                                 EOCMathI_CACR_All
# 9                                  EOCMathI_GLP_All
# 10                             EOCEnglish2_CACR_All
# 11                              EOCEnglish2_GLP_All
# 12                              EOCBiology_CACR_All
# 13                               EOCBiology_GLP_All
# 14                     ACTCompositeScore_UNCMin_All
# 15                      ACTEnglish_ACTBenchmark_All
# 16                           GraduationRate_4yr_All
# 17                      ACTEnglish_ACTBenchmark_All
# 18                      ACTReading_ACTBenchmark_All
# 19                    ACTSubtests_BenchmarksMet_All
# 20                    ACTSubtests_BenchmarksMet_All
# 21                    ACTSubtests_BenchmarksMet_All
# 22                    ACTSubtests_BenchmarksMet_All
# 23                 ACTSubtests_BenchmarksMet_Female
# 24                   ACTSubtests_BenchmarksMet_Male
# 25                   ACTWriting_ACTBenchmark_Female
# 26                               EOCBiology_GLP_All
# 27                              EOCEnglish2_GLP_All
# 28                                 EOCMathI_GLP_All
# 29                             EOCMathI_CACR_Female
# 30                              EOCSubjects_GLP_All
# 31                         EOG/EOCSubjects_CACR_All
# 32                          EOG/EOCSubjects_GLP_All
# 33                          EOCSubjects_CACR_Female
# 34                            EOCSubjects_CACR_Male
# 35                         EOG/EOCSubjects_CACR_All
# 36                          EOG/EOCSubjects_GLP_All
# 37                          EOG/EOCSubjects_GLP_All
# 38                      EOG/EOCSubjects_CACR_Female
# 39                        EOG/EOCSubjects_CACR_Male
# 40                 ACTSubtests_BenchmarksMet_Female
# 41                            EOCBiology_GLP_Female
# 42                           EOCEnglish2_GLP_Female
# 43                              EOCMathI_GLP_Female
# 44                           EOCSubjects_GLP_Female
# 45                      EOG/EOCSubjects_CACR_Female
# 46                       EOG/EOCSubjects_GLP_Female
# 47                      EOG/EOCSubjects_CACR_Female
# 48                       EOG/EOCSubjects_GLP_Female
# 49                       EOG/EOCSubjects_GLP_Female
# 50                     ACTEnglish_ACTBenchmark_Male
# 51                     ACTReading_ACTBenchmark_Male
# 52                              EOCBiology_GLP_Male
# 53                             EOCEnglish2_GLP_Male
# 54                                EOCMathI_GLP_Male
# 55                             EOCSubjects_GLP_Male
# 56                        EOG/EOCSubjects_CACR_Male
# 57                         EOG/EOCSubjects_GLP_Male
# 58                        EOG/EOCSubjects_CACR_Male
# 59                         EOG/EOCSubjects_GLP_Male
# 60                         EOG/EOCSubjects_GLP_Male
# 61           ACTEnglish_ACTBenchmark_AmericanIndian
# 62           ACTReading_ACTBenchmark_AmericanIndian
# 63           ACTScience_ACTBenchmark_AmericanIndian
# 64                    EOCBiology_GLP_AmericanIndian
# 65                   EOCEnglish2_GLP_AmericanIndian
# 66                      EOCMathI_GLP_AmericanIndian
# 67                   EOCSubjects_GLP_AmericanIndian
# 68              EOG/EOCSubjects_CACR_AmericanIndian
# 69               EOG/EOCSubjects_GLP_AmericanIndian
# 70              EOG/EOCSubjects_CACR_AmericanIndian
# 71               EOG/EOCSubjects_GLP_AmericanIndian
# 72               EOG/EOCSubjects_GLP_AmericanIndian
# 73                    ACTEnglish_ACTBenchmark_Asian
# 74                       ACTMath_ACTBenchmark_Asian
# 75                    ACTReading_ACTBenchmark_Asian
# 76                       ACTMath_ACTBenchmark_Asian
# 77                    ACTReading_ACTBenchmark_Asian
# 78                    ACTScience_ACTBenchmark_Asian
# 79                    ACTReading_ACTBenchmark_Asian
# 80                    ACTScience_ACTBenchmark_Asian
# 81                    ACTScience_ACTBenchmark_Asian
# 82                             EOCBiology_GLP_Asian
# 83                            EOCEnglish2_GLP_Asian
# 84                               EOCMathI_GLP_Asian
# 85                            EOCSubjects_GLP_Asian
# 86                       EOG/EOCSubjects_CACR_Asian
# 87                        EOG/EOCSubjects_GLP_Asian
# 88                       EOG/EOCSubjects_CACR_Asian
# 89                        EOG/EOCSubjects_GLP_Asian
# 90                        EOG/EOCSubjects_GLP_Asian
# 91                             EOCBiology_GLP_Black
# 92                            EOCEnglish2_GLP_Black
# 93                               EOCMathI_GLP_Black
# 94                            EOCSubjects_GLP_Black
# 95                       EOG/EOCSubjects_CACR_Black
# 96                        EOG/EOCSubjects_GLP_Black
# 97                       EOG/EOCSubjects_CACR_Black
# 98                        EOG/EOCSubjects_GLP_Black
# 99                        EOG/EOCSubjects_GLP_Black
# 100                         EOCBiology_GLP_Hispanic
# 101                        EOCEnglish2_GLP_Hispanic
# 102                           EOCMathI_GLP_Hispanic
# 103                        EOCSubjects_GLP_Hispanic
# 104                   EOG/EOCSubjects_CACR_Hispanic
# 105                    EOG/EOCSubjects_GLP_Hispanic
# 106                   EOG/EOCSubjects_CACR_Hispanic
# 107                    EOG/EOCSubjects_GLP_Hispanic
# 108                    EOG/EOCSubjects_GLP_Hispanic
# 109          ACTEnglish_ACTBenchmark_TwoorMoreRaces
# 110                   EOCBiology_GLP_TwoorMoreRaces
# 111                  EOCEnglish2_GLP_TwoorMoreRaces
# 112                     EOCMathI_GLP_TwoorMoreRaces
# 113                  EOCSubjects_GLP_TwoorMoreRaces
# 114             EOG/EOCSubjects_CACR_TwoorMoreRaces
# 115              EOG/EOCSubjects_GLP_TwoorMoreRaces
# 116              EOG/EOCSubjects_GLP_TwoorMoreRaces
# 117                   ACTEnglish_ACTBenchmark_White
# 118                   ACTReading_ACTBenchmark_White
# 119                            EOCBiology_GLP_White
# 120                           EOCEnglish2_GLP_White
# 121                              EOCMathI_GLP_White
# 122                           EOCSubjects_GLP_White
# 123                      EOG/EOCSubjects_CACR_White
# 124                       EOG/EOCSubjects_GLP_White
# 125                      EOG/EOCSubjects_CACR_White
# 126                       EOG/EOCSubjects_GLP_White
# 127                       EOG/EOCSubjects_GLP_White
# 128                              EOCBiology_GLP_EDS
# 129                             EOCEnglish2_GLP_EDS
# 130                                EOCMathI_GLP_EDS
# 131                             EOCSubjects_GLP_EDS
# 132                        EOG/EOCSubjects_CACR_EDS
# 133                         EOG/EOCSubjects_GLP_EDS
# 134                        EOG/EOCSubjects_CACR_EDS
# 135                         EOG/EOCSubjects_GLP_EDS
# 136                         EOG/EOCSubjects_GLP_EDS
# 137                        EOG/EOCSubjects_CACR_LEP
# 138                     ACTEnglish_ACTBenchmark_AIG
# 139                     ACTReading_ACTBenchmark_AIG
# 140                     ACTReading_ACTBenchmark_AIG
# 141                              EOCBiology_GLP_AIG
# 142                             EOCEnglish2_GLP_AIG
# 143                                EOCMathI_GLP_AIG
# 144                             EOCSubjects_GLP_AIG
# 145                        EOG/EOCSubjects_CACR_AIG
# 146                         EOG/EOCSubjects_GLP_AIG
# 147                         EOG/EOCSubjects_GLP_AIG
# 148                                   ap_ib_courses
# 149                               lea_ap_ib_courses
# 150                                st_ap_ib_courses
# 151                                  st_cte_courses
# 152                         st_univ_college_courses
# 153                                  st_cte_courses
# 154                         st_univ_college_courses
# 155                         st_univ_college_courses
# 156                          st_flicensed_teach_pct
# 157                            st_tchyrs_11plus_pct
# 158                            st_tchyrs_0thru3_pct
# 159                           st_tchyrs_4thru10_pct
# 160                          st_long_susp_per_c_num
# 161                           st_expelled_per_c_num
# 162                          st_1yr_tchr_trnovr_pct
# 163                          st_emer_prov_teach_pct
# 164                                   category_cd_T
# 165                                   Category_Cd_T
# 166                           st_expelled_per_c_num
# 167                          st_emer_prov_teach_pct
# 168                                   category_cd_T
# 169                                   Category_Cd_T
# 170                          st_emer_prov_teach_pct
# 171                                   category_cd_T
# 172                                   Category_Cd_T
# 173                    lea_avg_age_media_collection
# 174                           0-3 Years_Exp_Pct_Tch
# 175                          4-10 Years_Exp_Pct_Tch
# 176                           10+ Years_Exp_Pct_Tch
# 177                           lea_lateral_teach_pct
# 178                            st_tchyrs_11plus_pct
# 179                            st_lateral_teach_pct
# 180                          st_1yr_tchr_trnovr_pct
# 181                              st_advance_dgr_pct
# 182                              st_advance_dgr_pct
# 183                                   category_cd_H
# 184                                   Category_Cd_H
# 185                                   category_cd_H
# 186                                   Category_Cd_H
# 187                                   category_cd_T
# 188                                   Category_Cd_T
# 189                                        AsianPct
# 190                                        AsianPct
# 191                                   IndianMalePct
# 192                                       IndianPct
# 193                                       IndianPct
# 194                                  WhiteFemalePct
# 195                                    WhiteMalePct
# 196                                        WhitePct
# 197                                        WhitePct
# 198                                        WhitePct
# 199                                   Category_Cd_H
# 200                                   Category_Cd_T
# 201                                     SPG Grade_F
# 202                      grades_BYOD_7:8:9:10:11:12
# 203          grades_1_to_1_access_7:8:9:10:11:12:13
# 204  SRC_Grades_Devices_Sent_Home_7:8:9:10:11:12:13
# 205                               sna_pgm_type_cd_Y
# 206           calendar_only_txt_Year-Round Calendar
# 207           calendar_only_txt_Year-Round Calendar
# 208              SRC_Grades_Devices_Sent_Home_11:12
# 209  SRC_Grades_Devices_Sent_Home_7:8:9:10:11:12:13
# 210                  SRC_Grades_Devices_Sent_Home_9
#
#                                                 Field2  Correlation
# 0                                          student_num     0.974346
# 1                                  lea_avg_student_num     0.955817
# 2                                   st_avg_student_num     0.999278
# 3                                   st_avg_student_num     0.954552
# 4                                   st_avg_student_num     0.972677
# 5                                   st_avg_student_num     0.954552
# 6                                   st_avg_student_num     0.954552
# 7                                            SPG Score     0.980687
# 8                                      NC Math 1 Score     0.960701
# 9                                      NC Math 1 Score     0.979723
# 10                                    English II Score     0.964481
# 11                                    English II Score     0.981600
# 12                                       Biology Score     0.977045
# 13                                       Biology Score     0.992867
# 14                                           ACT Score     0.981594
# 15                                           ACT Score     0.952992
# 16                 4-Year Cohort Graduation Rate Score     0.965864
# 17                        ACTCompositeScore_UNCMin_All     0.965221
# 18                         ACTEnglish_ACTBenchmark_All     0.954590
# 19                         ACTEnglish_ACTBenchmark_All     0.961262
# 20                            ACTMath_ACTBenchmark_All     0.954449
# 21                         ACTReading_ACTBenchmark_All     0.971449
# 22                         ACTScience_ACTBenchmark_All     0.961547
# 23                       ACTSubtests_BenchmarksMet_All     0.965816
# 24                       ACTSubtests_BenchmarksMet_All     0.964913
# 25                         ACTWriting_ACTBenchmark_All     0.959485
# 26                                 EOCBiology_CACR_All     0.981598
# 27                                EOCEnglish2_CACR_All     0.977103
# 28                                   EOCMathI_CACR_All     0.976245
# 29                                   EOCMathI_CACR_All     0.955066
# 30                                EOCSubjects_CACR_All     0.984881
# 31                                EOCSubjects_CACR_All     0.989736
# 32                                EOCSubjects_CACR_All     0.973222
# 33                                EOCSubjects_CACR_All     0.957192
# 34                                EOCSubjects_CACR_All     0.955299
# 35                                 EOCSubjects_GLP_All     0.973414
# 36                                 EOCSubjects_GLP_All     0.986291
# 37                            EOG/EOCSubjects_CACR_All     0.985074
# 38                            EOG/EOCSubjects_CACR_All     0.957356
# 39                            EOG/EOCSubjects_CACR_All     0.953674
# 40                      ACTReading_ACTBenchmark_Female     0.953589
# 41                              EOCBiology_CACR_Female     0.976239
# 42                             EOCEnglish2_CACR_Female     0.969976
# 43                                EOCMathI_CACR_Female     0.968087
# 44                             EOCSubjects_CACR_Female     0.980691
# 45                             EOCSubjects_CACR_Female     0.982378
# 46                             EOCSubjects_CACR_Female     0.959254
# 47                              EOCSubjects_GLP_Female     0.956222
# 48                              EOCSubjects_GLP_Female     0.969746
# 49                         EOG/EOCSubjects_CACR_Female     0.980491
# 50                       ACTCompositeScore_UNCMin_Male     0.959892
# 51                        ACTEnglish_ACTBenchmark_Male     0.951631
# 52                                EOCBiology_CACR_Male     0.978800
# 53                               EOCEnglish2_CACR_Male     0.973446
# 54                                  EOCMathI_CACR_Male     0.971862
# 55                               EOCSubjects_CACR_Male     0.981262
# 56                               EOCSubjects_CACR_Male     0.990119
# 57                               EOCSubjects_CACR_Male     0.971410
# 58                                EOCSubjects_GLP_Male     0.970153
# 59                                EOCSubjects_GLP_Male     0.988106
# 60                           EOG/EOCSubjects_CACR_Male     0.981386
# 61             ACTCompositeScore_UNCMin_AmericanIndian     0.957500
# 62              ACTEnglish_ACTBenchmark_AmericanIndian     0.980176
# 63                 ACTMath_ACTBenchmark_AmericanIndian     0.978161
# 64                      EOCBiology_CACR_AmericanIndian     0.986525
# 65                     EOCEnglish2_CACR_AmericanIndian     0.975814
# 66                        EOCMathI_CACR_AmericanIndian     0.993760
# 67                     EOCSubjects_CACR_AmericanIndian     0.974010
# 68                     EOCSubjects_CACR_AmericanIndian     1.000000
# 69                     EOCSubjects_CACR_AmericanIndian     0.974010
# 70                      EOCSubjects_GLP_AmericanIndian     0.974010
# 71                      EOCSubjects_GLP_AmericanIndian     1.000000
# 72                 EOG/EOCSubjects_CACR_AmericanIndian     0.974010
# 73                      ACTCompositeScore_UNCMin_Asian     0.977201
# 74                      ACTCompositeScore_UNCMin_Asian     0.968093
# 75                      ACTCompositeScore_UNCMin_Asian     0.961547
# 76                       ACTEnglish_ACTBenchmark_Asian     0.977458
# 77                       ACTEnglish_ACTBenchmark_Asian     0.978859
# 78                       ACTEnglish_ACTBenchmark_Asian     0.950814
# 79                          ACTMath_ACTBenchmark_Asian     0.979763
# 80                          ACTMath_ACTBenchmark_Asian     0.970307
# 81                       ACTReading_ACTBenchmark_Asian     0.970199
# 82                               EOCBiology_CACR_Asian     0.993342
# 83                              EOCEnglish2_CACR_Asian     0.994838
# 84                                 EOCMathI_CACR_Asian     0.994359
# 85                              EOCSubjects_CACR_Asian     0.992160
# 86                              EOCSubjects_CACR_Asian     0.979139
# 87                              EOCSubjects_CACR_Asian     0.970926
# 88                               EOCSubjects_GLP_Asian     0.971056
# 89                               EOCSubjects_GLP_Asian     0.978387
# 90                          EOG/EOCSubjects_CACR_Asian     0.992162
# 91                               EOCBiology_CACR_Black     0.973502
# 92                              EOCEnglish2_CACR_Black     0.965975
# 93                                 EOCMathI_CACR_Black     0.959156
# 94                              EOCSubjects_CACR_Black     0.973857
# 95                              EOCSubjects_CACR_Black     0.995549
# 96                              EOCSubjects_CACR_Black     0.971330
# 97                               EOCSubjects_GLP_Black     0.968796
# 98                               EOCSubjects_GLP_Black     0.996726
# 99                          EOG/EOCSubjects_CACR_Black     0.973643
# 100                           EOCBiology_CACR_Hispanic     0.974485
# 101                          EOCEnglish2_CACR_Hispanic     0.969016
# 102                             EOCMathI_CACR_Hispanic     0.967353
# 103                          EOCSubjects_CACR_Hispanic     0.972348
# 104                          EOCSubjects_CACR_Hispanic     0.984427
# 105                          EOCSubjects_CACR_Hispanic     0.956092
# 106                           EOCSubjects_GLP_Hispanic     0.953370
# 107                           EOCSubjects_GLP_Hispanic     0.979817
# 108                      EOG/EOCSubjects_CACR_Hispanic     0.971955
# 109            ACTCompositeScore_UNCMin_TwoorMoreRaces     0.951499
# 110                     EOCBiology_CACR_TwoorMoreRaces     0.981567
# 111                    EOCEnglish2_CACR_TwoorMoreRaces     0.978526
# 112                       EOCMathI_CACR_TwoorMoreRaces     0.972358
# 113                    EOCSubjects_CACR_TwoorMoreRaces     0.971224
# 114                    EOCSubjects_CACR_TwoorMoreRaces     0.959957
# 115                     EOCSubjects_GLP_TwoorMoreRaces     0.959937
# 116                EOG/EOCSubjects_CACR_TwoorMoreRaces     0.970539
# 117                     ACTCompositeScore_UNCMin_White     0.960668
# 118                      ACTEnglish_ACTBenchmark_White     0.954587
# 119                              EOCBiology_CACR_White     0.975355
# 120                             EOCEnglish2_CACR_White     0.978516
# 121                                EOCMathI_CACR_White     0.972126
# 122                             EOCSubjects_CACR_White     0.976799
# 123                             EOCSubjects_CACR_White     0.986806
# 124                             EOCSubjects_CACR_White     0.963062
# 125                              EOCSubjects_GLP_White     0.960213
# 126                              EOCSubjects_GLP_White     0.981897
# 127                         EOG/EOCSubjects_CACR_White     0.976874
# 128                                EOCBiology_CACR_EDS     0.976019
# 129                               EOCEnglish2_CACR_EDS     0.966844
# 130                                  EOCMathI_CACR_EDS     0.967775
# 131                               EOCSubjects_CACR_EDS     0.981622
# 132                               EOCSubjects_CACR_EDS     0.977050
# 133                               EOCSubjects_CACR_EDS     0.959505
# 134                                EOCSubjects_GLP_EDS     0.953694
# 135                                EOCSubjects_GLP_EDS     0.971606
# 136                           EOG/EOCSubjects_CACR_EDS     0.982012
# 137                               EOCSubjects_CACR_LEP     0.976578
# 138                       ACTCompositeScore_UNCMin_AIG     0.973205
# 139                        ACTEnglish_ACTBenchmark_AIG     0.964416
# 140                           ACTMath_ACTBenchmark_AIG     0.950694
# 141                                EOCBiology_CACR_AIG     0.991781
# 142                               EOCEnglish2_CACR_AIG     0.992399
# 143                                  EOCMathI_CACR_AIG     0.986043
# 144                               EOCSubjects_CACR_AIG     0.975633
# 145                               EOCSubjects_CACR_AIG     0.965934
# 146                                EOCSubjects_GLP_AIG     0.953254
# 147                           EOG/EOCSubjects_CACR_AIG     0.972960
# 148                               ap_participation_pct     0.963786
# 149                           lea_ap_participation_pct     0.958653
# 150                       st_total_specialized_courses     1.000000
# 151                       st_total_specialized_courses     1.000000
# 152                       st_total_specialized_courses     1.000000
# 153                                   st_ap_ib_courses     1.000000
# 154                                   st_ap_ib_courses     1.000000
# 155                                     st_cte_courses     1.000000
# 156                            st_avg_daily_attend_pct     0.999830
# 157                            st_avg_daily_attend_pct     0.986173
# 158                                 st_crime_per_c_num     0.955897
# 159                                 st_crime_per_c_num     0.981979
# 160                            st_short_susp_per_c_num     0.960606
# 161                            st_short_susp_per_c_num     0.960606
# 162                            st_short_susp_per_c_num     0.975221
# 163                            st_short_susp_per_c_num     0.960606
# 164                            st_short_susp_per_c_num     0.960606
# 165                            st_short_susp_per_c_num     0.960606
# 166                             st_long_susp_per_c_num     1.000000
# 167                             st_long_susp_per_c_num     1.000000
# 168                             st_long_susp_per_c_num     1.000000
# 169                             st_long_susp_per_c_num     1.000000
# 170                              st_expelled_per_c_num     1.000000
# 171                              st_expelled_per_c_num     1.000000
# 172                              st_expelled_per_c_num     1.000000
# 173                           avg_age_media_collection     0.999983
# 174                                  tchyrs_0thru3_pct     1.000000
# 175                                 tchyrs_4thru10_pct     1.000000
# 176                                  tchyrs_11plus_pct     1.000000
# 177                            lea_flicensed_teach_pct     0.984964
# 178                             st_flicensed_teach_pct     0.982946
# 179                               st_tchyrs_0thru3_pct     0.988566
# 180                              st_tchyrs_4thru10_pct     0.984976
# 181                                 st_class_teach_num     0.963157
# 182                                       st_nbpts_num     0.997665
# 183                                       st_nbpts_num     1.000000
# 184                                       st_nbpts_num     1.000000
# 185                                 st_advance_dgr_pct     0.997665
# 186                                 st_advance_dgr_pct     0.997665
# 187                             st_emer_prov_teach_pct     1.000000
# 188                             st_emer_prov_teach_pct     1.000000
# 189                                     AsianFemalePct     0.960089
# 190                                       AsianMalePct     0.964989
# 191                                    IndianFemalePct     0.965551
# 192                                    IndianFemalePct     0.991604
# 193                                      IndianMalePct     0.991093
# 194                                        MinorityPct     0.956523
# 195                                        MinorityPct     0.955798
# 196                                        MinorityPct     1.000000
# 197                                     WhiteFemalePct     0.956523
# 198                                       WhiteMalePct     0.955798
# 199                                      category_cd_H     1.000000
# 200                                      category_cd_T     1.000000
# 201                                grade_range_cd_3-12     1.000000
# 202                                grade_range_cd_7-12     1.000000
# 203                                grade_range_cd_7-13     1.000000
# 204                                grade_range_cd_7-13     1.000000
# 205  calendar_type_txt_Regular School, Year-Round C...     1.000000
# 206  calendar_type_txt_Regular School, Year-Round C...     1.000000
# 207                                  sna_pgm_type_cd_Y     1.000000
# 208                         grades_1_to_1_access_11:12     1.000000
# 209             grades_1_to_1_access_7:8:9:10:11:12:13     1.000000
# 210                             grades_1_to_1_access_9     0.959719

# %%
print 'Dropping the following ', str(len(to_drop)), ' highly correlated fields.'
to_drop
# Out:
# Dropping the following  138  highly correlated fields.
# ['Overall Achievement Score',
#  'ACTCompositeScore_UNCMin_All',
#  'ACTEnglish_ACTBenchmark_All',
#  'ACTReading_ACTBenchmark_All',
#  'ACTSubtests_BenchmarksMet_All',
#  'EOCBiology_CACR_All',
#  'EOCBiology_GLP_All',
#  'EOCEnglish2_CACR_All',
#  'EOCEnglish2_GLP_All',
#  'EOCMathI_CACR_All',
#  'EOCMathI_GLP_All',
#  'EOCSubjects_GLP_All',
#  'EOG/EOCSubjects_CACR_All',
#  'EOG/EOCSubjects_GLP_All',
#  'GraduationRate_4yr_All',
#  'ACTSubtests_BenchmarksMet_Female',
#  'ACTWriting_ACTBenchmark_Female',
#  'EOCBiology_GLP_Female',
#  'EOCEnglish2_GLP_Female',
#  'EOCMathI_CACR_Female',
#  'EOCMathI_GLP_Female',
#  'EOCSubjects_CACR_Female',
#  'EOCSubjects_GLP_Female',
#  'EOG/EOCSubjects_CACR_Female',
#  'EOG/EOCSubjects_GLP_Female',
#  'ACTEnglish_ACTBenchmark_Male',
#  'ACTReading_ACTBenchmark_Male',
#  'ACTSubtests_BenchmarksMet_Male',
#  'EOCBiology_GLP_Male',
#  'EOCEnglish2_GLP_Male',
#  'EOCMathI_GLP_Male',
#  'EOCSubjects_CACR_Male',
#  'EOCSubjects_GLP_Male',
#  'EOG/EOCSubjects_CACR_Male',
#  'EOG/EOCSubjects_GLP_Male',
#  'ACTEnglish_ACTBenchmark_AmericanIndian',
#  'ACTReading_ACTBenchmark_AmericanIndian',
#  'ACTScience_ACTBenchmark_AmericanIndian',
#  'EOCBiology_GLP_AmericanIndian',
#  'EOCEnglish2_GLP_AmericanIndian',
#  'EOCMathI_GLP_AmericanIndian',
#  'EOCSubjects_GLP_AmericanIndian',
#  'EOG/EOCSubjects_CACR_AmericanIndian',
#  'EOG/EOCSubjects_GLP_AmericanIndian',
#  'ACTEnglish_ACTBenchmark_Asian',
#  'ACTMath_ACTBenchmark_Asian',
#  'ACTReading_ACTBenchmark_Asian',
#  'ACTScience_ACTBenchmark_Asian',
#  'EOCBiology_GLP_Asian',
#  'EOCEnglish2_GLP_Asian',
#  'EOCMathI_GLP_Asian',
#  'EOCSubjects_GLP_Asian',
#  'EOG/EOCSubjects_CACR_Asian',
#  'EOG/EOCSubjects_GLP_Asian',
#  'EOCBiology_GLP_Black',
#  'EOCEnglish2_GLP_Black',
#  'EOCMathI_GLP_Black',
#  'EOCSubjects_GLP_Black',
#  'EOG/EOCSubjects_CACR_Black',
#  'EOG/EOCSubjects_GLP_Black',
#  'EOCBiology_GLP_Hispanic',
#  'EOCEnglish2_GLP_Hispanic',
#  'EOCMathI_GLP_Hispanic',
#  'EOCSubjects_GLP_Hispanic',
#  'EOG/EOCSubjects_CACR_Hispanic',
#  'EOG/EOCSubjects_GLP_Hispanic',
#  'ACTEnglish_ACTBenchmark_TwoorMoreRaces',
#  'EOCBiology_GLP_TwoorMoreRaces',
#  'EOCEnglish2_GLP_TwoorMoreRaces',
#  'EOCMathI_GLP_TwoorMoreRaces',
#  'EOCSubjects_GLP_TwoorMoreRaces',
#  'EOG/EOCSubjects_CACR_TwoorMoreRaces',
#  'EOG/EOCSubjects_GLP_TwoorMoreRaces',
#  'ACTEnglish_ACTBenchmark_White',
#  'ACTReading_ACTBenchmark_White',
#  'EOCBiology_GLP_White',
#  'EOCEnglish2_GLP_White',
#  'EOCMathI_GLP_White',
#  'EOCSubjects_GLP_White',
#  'EOG/EOCSubjects_CACR_White',
#  'EOG/EOCSubjects_GLP_White',
#  'EOCBiology_GLP_EDS',
#  'EOCEnglish2_GLP_EDS',
#  'EOCMathI_GLP_EDS',
#  'EOCSubjects_GLP_EDS',
#  'EOG/EOCSubjects_CACR_EDS',
#  'EOG/EOCSubjects_GLP_EDS',
#  'EOG/EOCSubjects_CACR_LEP',
#  'ACTEnglish_ACTBenchmark_AIG',
#  'ACTReading_ACTBenchmark_AIG',
#  'EOCBiology_GLP_AIG',
#  'EOCEnglish2_GLP_AIG',
#  'EOCMathI_GLP_AIG',
#  'EOCSubjects_GLP_AIG',
#  'EOG/EOCSubjects_CACR_AIG',
#  'EOG/EOCSubjects_GLP_AIG',
#  'ap_ib_courses',
#  'lea_ap_ib_courses',
#  'st_ap_ib_courses',
#  'st_cte_courses',
#  'st_univ_college_courses',
#  'st_long_susp_per_c_num',
#  'st_expelled_per_c_num',
#  'lea_avg_age_media_collection',
#  'class_teach_num',
#  'lea_class_teach_num',
#  'lea_lateral_teach_pct',
#  'st_flicensed_teach_pct',
#  'st_tchyrs_0thru3_pct',
#  'st_tchyrs_4thru10_pct',
#  'st_tchyrs_11plus_pct',
#  'st_class_teach_num',
#  'st_nbpts_num',
#  'st_advance_dgr_pct',
#  'st_1yr_tchr_trnovr_pct',
#  'st_emer_prov_teach_pct',
#  'st_lateral_teach_pct',
#  '0-3 Years_Exp_Pct_Tch',
#  '10+ Years_Exp_Pct_Tch',
#  '4-10 Years_Exp_Pct_Tch',
#  'AsianPct',
#  'IndianMalePct',
#  'IndianPct',
#  'WhiteFemalePct',
#  'WhiteMalePct',
#  'WhitePct',
#  'category_cd_H',
#  'category_cd_T',
#  'sna_pgm_type_cd_Y',
#  'calendar_only_txt_Year-Round Calendar',
#  'SPG Grade_F',
#  'Category_Cd_H',
#  'Category_Cd_T',
#  'grades_BYOD_7:8:9:10:11:12',
#  'grades_1_to_1_access_7:8:9:10:11:12:13',
#  'SRC_Grades_Devices_Sent_Home_11:12',
#  'SRC_Grades_Devices_Sent_Home_7:8:9:10:11:12:13',
#  'SRC_Grades_Devices_Sent_Home_9']

# %%
#Check columns before drop 
print('\r\n*********Before: Dropping Highly Correlated Fields*************************************')
schoolData.info(verbose=False)

# Drop the highly correlated features from our training data 
schoolData = schoolData.drop(to_drop, axis=1)

#Check columns after drop 
print('\r\n*********After: Dropping Highly Correlated Fields**************************************')
schoolData.info(verbose=False)
# Out:
# *********Before: Dropping Highly Correlated Fields*************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 470 entries, 0 to 469
# Columns: 540 entries, student_num to SRC_Grades_Devices_Sent_Home_9:10:12
# dtypes: float64(448), uint8(92)
# memory usage: 1.7 MB
#
# *********After: Dropping Highly Correlated Fields**************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 470 entries, 0 to 469
# Columns: 402 entries, student_num to SRC_Grades_Devices_Sent_Home_9:10:12
# dtypes: float64(322), uint8(80)
# memory usage: 1.2 MB

# %%
#Restore the unit_code before saving
schoolData['unit_code'] = unit_code
#Save the final dataset to a .csv file
schoolData.to_csv(outputDir + inputFileName + '_ML.csv', sep=',', index=False)

# %%
print('*********FINAL DATASET DETAILS*********************************************************\r\n')
schoolData.info(verbose=True)
# Out:
# *********FINAL DATASET DETAILS*********************************************************
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 470 entries, 0 to 469
# Data columns (total 403 columns):
# student_num                                              float64
# lea_avg_student_num                                      float64
# st_avg_student_num                                       float64
# 09_Size                                                  float64
# 10_Size                                                  float64
# 11_Size                                                  float64
# 12_Size                                                  float64
# Biology_Size                                             float64
# English II_Size                                          float64
# Math I_Size                                              float64
# lea_total_expense_num                                    float64
# lea_salary_expense_pct                                   float64
# lea_services_expense_pct                                 float64
# lea_supplies_expense_pct                                 float64
# lea_instruct_equip_exp_pct                               float64
# lea_federal_perpupil_num                                 float64
# lea_local_perpupil_num                                   float64
# lea_state_perpupil_num                                   float64
# SPG Score                                                float64
# EVAAS Growth Score                                       float64
# NC Math 1 Score                                          float64
# English II Score                                         float64
# Biology Score                                            float64
# ACT Score                                                float64
# ACT WorkKeys Score                                       float64
# Passing NC Math 3                                        float64
# 4-Year Cohort Graduation Rate Score                      float64
# ACTMath_ACTBenchmark_All                                 float64
# ACTScience_ACTBenchmark_All                              float64
# ACTWorkKeys_SilverPlus_All                               float64
# ACTWriting_ACTBenchmark_All                              float64
# EOCSubjects_CACR_All                                     float64
# GraduationRate_5yr_All                                   float64
# ACTCompositeScore_UNCMin_Female                          float64
# ACTEnglish_ACTBenchmark_Female                           float64
# ACTMath_ACTBenchmark_Female                              float64
# ACTReading_ACTBenchmark_Female                           float64
# ACTScience_ACTBenchmark_Female                           float64
# ACTWorkKeys_SilverPlus_Female                            float64
# EOCBiology_CACR_Female                                   float64
# EOCEnglish2_CACR_Female                                  float64
# GraduationRate_4yr_Female                                float64
# GraduationRate_5yr_Female                                float64
# ACTCompositeScore_UNCMin_Male                            float64
# ACTMath_ACTBenchmark_Male                                float64
# ACTScience_ACTBenchmark_Male                             float64
# ACTWorkKeys_SilverPlus_Male                              float64
# ACTWriting_ACTBenchmark_Male                             float64
# EOCBiology_CACR_Male                                     float64
# EOCEnglish2_CACR_Male                                    float64
# EOCMathI_CACR_Male                                       float64
# GraduationRate_4yr_Male                                  float64
# GraduationRate_5yr_Male                                  float64
# ACTCompositeScore_UNCMin_AmericanIndian                  float64
# ACTMath_ACTBenchmark_AmericanIndian                      float64
# ACTSubtests_BenchmarksMet_AmericanIndian                 float64
# ACTWorkKeys_SilverPlus_AmericanIndian                    float64
# ACTWriting_ACTBenchmark_AmericanIndian                   float64
# EOCBiology_CACR_AmericanIndian                           float64
# EOCEnglish2_CACR_AmericanIndian                          float64
# EOCMathI_CACR_AmericanIndian                             float64
# EOCSubjects_CACR_AmericanIndian                          float64
# GraduationRate_4yr_AmericanIndian                        float64
# GraduationRate_5yr_AmericanIndian                        float64
# ACTCompositeScore_UNCMin_Asian                           float64
# ACTSubtests_BenchmarksMet_Asian                          float64
# ACTWorkKeys_SilverPlus_Asian                             float64
# ACTWriting_ACTBenchmark_Asian                            float64
# EOCBiology_CACR_Asian                                    float64
# EOCEnglish2_CACR_Asian                                   float64
# EOCMathI_CACR_Asian                                      float64
# EOCSubjects_CACR_Asian                                   float64
# GraduationRate_4yr_Asian                                 float64
# GraduationRate_5yr_Asian                                 float64
# ACTCompositeScore_UNCMin_Black                           float64
# ACTEnglish_ACTBenchmark_Black                            float64
# ACTMath_ACTBenchmark_Black                               float64
# ACTReading_ACTBenchmark_Black                            float64
# ACTScience_ACTBenchmark_Black                            float64
# ACTSubtests_BenchmarksMet_Black                          float64
# ACTWorkKeys_SilverPlus_Black                             float64
# ACTWriting_ACTBenchmark_Black                            float64
# EOCBiology_CACR_Black                                    float64
# EOCEnglish2_CACR_Black                                   float64
# EOCMathI_CACR_Black                                      float64
# EOCSubjects_CACR_Black                                   float64
# GraduationRate_4yr_Black                                 float64
# GraduationRate_5yr_Black                                 float64
# ACTCompositeScore_UNCMin_Hispanic                        float64
# ACTEnglish_ACTBenchmark_Hispanic                         float64
# ACTMath_ACTBenchmark_Hispanic                            float64
# ACTReading_ACTBenchmark_Hispanic                         float64
# ACTScience_ACTBenchmark_Hispanic                         float64
# ACTSubtests_BenchmarksMet_Hispanic                       float64
# ACTWorkKeys_SilverPlus_Hispanic                          float64
# ACTWriting_ACTBenchmark_Hispanic                         float64
# EOCBiology_CACR_Hispanic                                 float64
# EOCEnglish2_CACR_Hispanic                                float64
# EOCMathI_CACR_Hispanic                                   float64
# EOCSubjects_CACR_Hispanic                                float64
# GraduationRate_4yr_Hispanic                              float64
# GraduationRate_5yr_Hispanic                              float64
# ACTCompositeScore_UNCMin_TwoorMoreRaces                  float64
# ACTMath_ACTBenchmark_TwoorMoreRaces                      float64
# ACTReading_ACTBenchmark_TwoorMoreRaces                   float64
# ACTScience_ACTBenchmark_TwoorMoreRaces                   float64
# ACTSubtests_BenchmarksMet_TwoorMoreRaces                 float64
# ACTWorkKeys_SilverPlus_TwoorMoreRaces                    float64
# ACTWriting_ACTBenchmark_TwoorMoreRaces                   float64
# EOCBiology_CACR_TwoorMoreRaces                           float64
# EOCEnglish2_CACR_TwoorMoreRaces                          float64
# EOCMathI_CACR_TwoorMoreRaces                             float64
# EOCSubjects_CACR_TwoorMoreRaces                          float64
# GraduationRate_4yr_TwoorMoreRaces                        float64
# GraduationRate_5yr_TwoorMoreRaces                        float64
# ACTCompositeScore_UNCMin_White                           float64
# ACTMath_ACTBenchmark_White                               float64
# ACTScience_ACTBenchmark_White                            float64
# ACTSubtests_BenchmarksMet_White                          float64
# ACTWorkKeys_SilverPlus_White                             float64
# ACTWriting_ACTBenchmark_White                            float64
# EOCBiology_CACR_White                                    float64
# EOCEnglish2_CACR_White                                   float64
# EOCMathI_CACR_White                                      float64
# EOCSubjects_CACR_White                                   float64
# GraduationRate_4yr_White                                 float64
# GraduationRate_5yr_White                                 float64
# ACTCompositeScore_UNCMin_EDS                             float64
# ACTEnglish_ACTBenchmark_EDS                              float64
# ACTMath_ACTBenchmark_EDS                                 float64
# ACTReading_ACTBenchmark_EDS                              float64
# ACTScience_ACTBenchmark_EDS                              float64
# ACTSubtests_BenchmarksMet_EDS                            float64
# ACTWorkKeys_SilverPlus_EDS                               float64
# ACTWriting_ACTBenchmark_EDS                              float64
# EOCBiology_CACR_EDS                                      float64
# EOCEnglish2_CACR_EDS                                     float64
# EOCMathI_CACR_EDS                                        float64
# EOCSubjects_CACR_EDS                                     float64
# GraduationRate_4yr_EDS                                   float64
# GraduationRate_5yr_EDS                                   float64
# ACTCompositeScore_UNCMin_LEP                             float64
# ACTEnglish_ACTBenchmark_LEP                              float64
# ACTMath_ACTBenchmark_LEP                                 float64
# ACTReading_ACTBenchmark_LEP                              float64
# ACTScience_ACTBenchmark_LEP                              float64
# ACTSubtests_BenchmarksMet_LEP                            float64
# ACTWorkKeys_SilverPlus_LEP                               float64
# ACTWriting_ACTBenchmark_LEP                              float64
# EOCBiology_CACR_LEP                                      float64
# EOCBiology_GLP_LEP                                       float64
# EOCEnglish2_CACR_LEP                                     float64
# EOCEnglish2_GLP_LEP                                      float64
# EOCMathI_CACR_LEP                                        float64
# EOCMathI_GLP_LEP                                         float64
# EOCSubjects_CACR_LEP                                     float64
# EOCSubjects_GLP_LEP                                      float64
# EOG/EOCSubjects_GLP_LEP                                  float64
# GraduationRate_4yr_LEP                                   float64
# GraduationRate_5yr_LEP                                   float64
# ACTCompositeScore_UNCMin_SWD                             float64
# ACTEnglish_ACTBenchmark_SWD                              float64
# ACTMath_ACTBenchmark_SWD                                 float64
# ACTReading_ACTBenchmark_SWD                              float64
# ACTScience_ACTBenchmark_SWD                              float64
# ACTSubtests_BenchmarksMet_SWD                            float64
# ACTWorkKeys_SilverPlus_SWD                               float64
# ACTWriting_ACTBenchmark_SWD                              float64
# EOCBiology_CACR_SWD                                      float64
# EOCBiology_GLP_SWD                                       float64
# EOCEnglish2_CACR_SWD                                     float64
# EOCEnglish2_GLP_SWD                                      float64
# EOCMathI_CACR_SWD                                        float64
# EOCMathI_GLP_SWD                                         float64
# EOCSubjects_CACR_SWD                                     float64
# EOCSubjects_GLP_SWD                                      float64
# EOG/EOCSubjects_CACR_SWD                                 float64
# EOG/EOCSubjects_GLP_SWD                                  float64
# GraduationRate_4yr_SWD                                   float64
# GraduationRate_5yr_SWD                                   float64
# ACTCompositeScore_UNCMin_AIG                             float64
# ACTMath_ACTBenchmark_AIG                                 float64
# ACTScience_ACTBenchmark_AIG                              float64
# ACTSubtests_BenchmarksMet_AIG                            float64
# ACTWorkKeys_SilverPlus_AIG                               float64
# ACTWriting_ACTBenchmark_AIG                              float64
# EOCBiology_CACR_AIG                                      float64
# EOCEnglish2_CACR_AIG                                     float64
# EOCMathI_CACR_AIG                                        float64
# EOCSubjects_CACR_AIG                                     float64
# GraduationRate_4yr_AIG                                   float64
# GraduationRate_5yr_AIG                                   float64
# ACT_pTarget_PctMet                                       float64
# ACTWorkKeys_pTarget_PctMet                               float64
# CurrentYearEOC_pTarget_PctMet                            float64
# MathGr10_pTarget_PctMet                                  float64
# ReadingGr10_pTarget_PctMet                               float64
# SciGr11_pTarget_PctMet                                   float64
# TotalTargets_pTarget_PctMet                              float64
# sat_avg_score_num                                        float64
# lea_sat_avg_score_num                                    float64
# sat_participation_pct                                    float64
# lea_sat_participation_pct                                float64
# ap_participation_pct                                     float64
# lea_ap_participation_pct                                 float64
# ap_pct_3_or_above                                        float64
# lea_ap_pct_3_or_above                                    float64
# total_specialized_courses                                float64
# cte_courses                                              float64
# univ_college_courses                                     float64
# lea_total_specialized_courses                            float64
# lea_cte_courses                                          float64
# lea_univ_college_courses                                 float64
# st_total_specialized_courses                             float64
# ALL_All Students (Total or Subtotal_ENROLL_sch_pct       float64
# ECODIS_Economically Disadvantaged_ENROLL_sch_pct         float64
# F_Female_ENROLL_sch_pct                                  float64
# M_Male_ENROLL_sch_pct                                    float64
# MB_Black_ENROLL_sch_pct                                  float64
# MW_White_ENROLL_sch_pct                                  float64
# avg_daily_attend_pct                                     float64
# crime_per_c_num                                          float64
# short_susp_per_c_num                                     float64
# long_susp_per_c_num                                      float64
# expelled_per_c_num                                       float64
# stud_internet_comp_num                                   float64
# lea_avg_daily_attend_pct                                 float64
# lea_crime_per_c_num                                      float64
# lea_short_susp_per_c_num                                 float64
# lea_long_susp_per_c_num                                  float64
# lea_expelled_per_c_num                                   float64
# lea_stud_internet_comp_num                               float64
# st_avg_daily_attend_pct                                  float64
# st_crime_per_c_num                                       float64
# st_short_susp_per_c_num                                  float64
# digital_media_pct                                        float64
# avg_age_media_collection                                 float64
# books_per_student                                        float64
# lea_books_per_student                                    float64
# wap_num                                                  float64
# wap_per_classroom                                        float64
# lea_wap_num                                              float64
# lea_wap_per_classroom                                    float64
# flicensed_teach_pct                                      float64
# tchyrs_0thru3_pct                                        float64
# tchyrs_4thru10_pct                                       float64
# tchyrs_11plus_pct                                        float64
# nbpts_num                                                float64
# advance_dgr_pct                                          float64
# _1yr_tchr_trnovr_pct                                     float64
# lateral_teach_pct                                        float64
# lea_flicensed_teach_pct                                  float64
# lea_tchyrs_0thru3_pct                                    float64
# lea_tchyrs_4thru10_pct                                   float64
# lea_tchyrs_11plus_pct                                    float64
# lea_nbpts_num                                            float64
# lea_advance_dgr_pct                                      float64
# lea_1yr_tchr_trnovr_pct                                  float64
# lea_emer_prov_teach_pct                                  float64
# 0-3 Years_LEA_Exp_Pct_Prin                               float64
# 10+ Years_LEA_Exp_Pct_Prin                               float64
# 4-10 Years_LEA_Exp_Pct_Prin                              float64
# Accomplished_TCHR_Standard 1_Pct                         float64
# Accomplished_TCHR_Standard 2_Pct                         float64
# Accomplished_TCHR_Standard 3_Pct                         float64
# Accomplished_TCHR_Standard 4_Pct                         float64
# Accomplished_TCHR_Standard 5_Pct                         float64
# Developing_TCHR_Standard 1_Pct                           float64
# Developing_TCHR_Standard 2_Pct                           float64
# Developing_TCHR_Standard 3_Pct                           float64
# Developing_TCHR_Standard 4_Pct                           float64
# Developing_TCHR_Standard 5_Pct                           float64
# Distinguished_TCHR_Standard 1_Pct                        float64
# Distinguished_TCHR_Standard 2_Pct                        float64
# Distinguished_TCHR_Standard 3_Pct                        float64
# Distinguished_TCHR_Standard 4_Pct                        float64
# Distinguished_TCHR_Standard 5_Pct                        float64
# Does Not Meet Expected Growth_TCHR_Student Growth_Pct    float64
# Exceeds Expected Growth_TCHR_Student Growth_Pct          float64
# Meets Expected Growth_TCHR_Student Growth_Pct            float64
# Not Demostrated_TCHR_Standard 1_Pct                      float64
# Not Demostrated_TCHR_Standard 2_Pct                      float64
# Not Demostrated_TCHR_Standard 3_Pct                      float64
# Not Demostrated_TCHR_Standard 4_Pct                      float64
# Not Demostrated_TCHR_Standard 5_Pct                      float64
# Proficient_TCHR_Standard 1_Pct                           float64
# Proficient_TCHR_Standard 2_Pct                           float64
# Proficient_TCHR_Standard 3_Pct                           float64
# Proficient_TCHR_Standard 4_Pct                           float64
# Proficient_TCHR_Standard 5_Pct                           float64
# AsianFemalePct                                           float64
# AsianMalePct                                             float64
# BlackFemalePct                                           float64
# BlackMalePct                                             float64
# BlackPct                                                 float64
# HispanicFemalePct                                        float64
# HispanicMalePct                                          float64
# HispanicPct                                              float64
# IndianFemalePct                                          float64
# MinorityFemalePct                                        float64
# MinorityMalePct                                          float64
# MinorityPct                                              float64
# PacificIslandFemalePct                                   float64
# PacificIslandMalePct                                     float64
# PacificIslandPct                                         float64
# TwoOrMoreFemalePct                                       float64
# TwoOrMoreMalePct                                         float64
# TwoOrMorePct                                             float64
# Gr_9_Pct_Prof                                            float64
# pct_eds                                                  float64
# AAVC_Concentrator_Ct                                     float64
# AGNR_Concentrator_Ct                                     float64
# ARCH_Concentrator_Ct                                     float64
# BMA_Concentrator_Ct                                      float64
# HLTH_Concentrator_Ct                                     float64
# HOSP_Concentrator_Ct                                     float64
# INFO_Concentrator_Ct                                     float64
# MANU_Concentrator_Ct                                     float64
# MRKT_Concentrator_Ct                                     float64
# STEM_Concentrator_Ct                                     float64
# TRAN_Concentrator_Ct                                     float64
# Number_Industry_Recognized_Crede                         float64
# grade_range_cd_11-12                                     uint8
# grade_range_cd_11-13                                     uint8
# grade_range_cd_3-12                                      uint8
# grade_range_cd_6-12                                      uint8
# grade_range_cd_6-13                                      uint8
# grade_range_cd_7-12                                      uint8
# grade_range_cd_7-13                                      uint8
# grade_range_cd_8-12                                      uint8
# grade_range_cd_9-11                                      uint8
# grade_range_cd_9-12                                      uint8
# grade_range_cd_9-13                                      uint8
# grade_range_cd_9-9                                       uint8
# grade_range_cd_K-12                                      uint8
# grade_range_cd_PK-12                                     uint8
# grade_range_cd_PK-13                                     uint8
# calendar_type_txt_Regular School, Year-Round Calendar    uint8
# esea_status_P                                            uint8
# Grad_project_status_Y                                    uint8
# SBE District_Northeast                                   uint8
# SBE District_Northwest                                   uint8
# SBE District_Piedmont-Triad                              uint8
# SBE District_Sandhills                                   uint8
# SBE District_Southeast                                   uint8
# SBE District_Southwest                                   uint8
# SBE District_Western                                     uint8
# SPG Grade_A+NG                                           uint8
# SPG Grade_B                                              uint8
# SPG Grade_C                                              uint8
# SPG Grade_D                                              uint8
# Reading SPG Grade_B                                      uint8
# Reading SPG Grade_C                                      uint8
# Reading SPG Grade_D                                      uint8
# Reading SPG Grade_F                                      uint8
# Math SPG Grade_B                                         uint8
# Math SPG Grade_C                                         uint8
# Math SPG Grade_D                                         uint8
# Math SPG Grade_F                                         uint8
# EVAAS Growth Status_Met                                  uint8
# EVAAS Growth Status_NotMet                               uint8
# State Gap Compared_Y                                     uint8
# Byod_Yes                                                 uint8
# grades_BYOD_11:12                                        uint8
# grades_BYOD_11:12:13                                     uint8
# grades_BYOD_12                                           uint8
# grades_BYOD_6:7:8:9:10:11:12                             uint8
# grades_BYOD_6:7:8:9:10:11:12:13                          uint8
# grades_BYOD_8:9:10:11:12                                 uint8
# grades_BYOD_9                                            uint8
# grades_BYOD_9:10:11                                      uint8
# grades_BYOD_9:10:11:12                                   uint8
# grades_BYOD_9:10:11:12:13                                uint8
# grades_BYOD_9:11:12                                      uint8
# grades_BYOD_PK:9:10:11:12                                uint8
# _1_to_1_access_Yes                                       uint8
# grades_1_to_1_access_10:11:12                            uint8
# grades_1_to_1_access_10:11:12:13                         uint8
# grades_1_to_1_access_11                                  uint8
# grades_1_to_1_access_11:12                               uint8
# grades_1_to_1_access_11:12:13                            uint8
# grades_1_to_1_access_6:07:08                             uint8
# grades_1_to_1_access_6:7:8:9:10:11:12                    uint8
# grades_1_to_1_access_6:7:8:9:10:11:12:13                 uint8
# grades_1_to_1_access_9                                   uint8
# grades_1_to_1_access_9:10                                uint8
# grades_1_to_1_access_9:10:11                             uint8
# grades_1_to_1_access_9:10:11:12                          uint8
# grades_1_to_1_access_9:10:11:12:13                       uint8
# grades_1_to_1_access_9:11:12:13                          uint8
# SRC_devices_sent_home_Yes                                uint8
# SRC_Grades_Devices_Sent_Home_10:11:12                    uint8
# SRC_Grades_Devices_Sent_Home_10:11:12:13                 uint8
# SRC_Grades_Devices_Sent_Home_6:07:08                     uint8
# SRC_Grades_Devices_Sent_Home_6:7:8:9:10:11:12            uint8
# SRC_Grades_Devices_Sent_Home_6:7:8:9:10:11:12:13         uint8
# SRC_Grades_Devices_Sent_Home_8:9:10:11:12:13             uint8
# SRC_Grades_Devices_Sent_Home_9:10                        uint8
# SRC_Grades_Devices_Sent_Home_9:10:11                     uint8
# SRC_Grades_Devices_Sent_Home_9:10:11:12                  uint8
# SRC_Grades_Devices_Sent_Home_9:10:11:12:13               uint8
# SRC_Grades_Devices_Sent_Home_9:10:12                     uint8
# unit_code                                                object
# dtypes: float64(322), object(1), uint8(80)
# memory usage: 1.2+ MB

# %%
import sklearn
import pandas as pd

print('Sklearn Version: ' + sklearn.__version__)
print('Pandas Version: ' + pd.__version__)
# Out:
# Sklearn Version: 0.19.1
# Pandas Version: 0.22.0

# %%
print 'Output File Location:\r\n\r\n' + outputDir + inputFileName + '_ML.csv'
# Out:
# Output File Location:
#
# C:/Users/Jake/Documents/GitHub/EducationDataNC/2017/Machine Learning Datasets/PublicHighSchools2017_ML.csv
